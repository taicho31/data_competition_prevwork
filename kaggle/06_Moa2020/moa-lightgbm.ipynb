# %% [markdown]
# - pca to remove unnecessary c vars
# - remove g vars by variance threshold
# - try 2nd layer again
# - refactoring

# %%
import os
import sys
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from tqdm._tqdm_notebook import tqdm_notebook
from sklearn.model_selection import StratifiedKFold, KFold
sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   del sys.path[0]

# %%
DIR = "/kaggle/input/lish-moa/"
train = pd.read_csv(DIR+"train_features.csv")
test = pd.read_csv(DIR+"test_features.csv")
nontargets = pd.read_csv(DIR+"train_targets_nonscored.csv")
targets = pd.read_csv(DIR+"train_targets_scored.csv")
sub = pd.read_csv(DIR+"sample_submission.csv")

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
n_targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
n_nontargets = nontargets[nontargets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i) for i in range(c_num)]
pca = PCA(n_components=c_num)
pca_c_train = pca.fit_transform(train[c_feats])
pca_c_test = pca.transform(test[c_feats])
pca_c_train = pd.DataFrame(pca_c_train, columns=pca_c_cols)
pca_c_test = pd.DataFrame(pca_c_test, columns=pca_c_cols)

train = pd.concat([train, pca_c_train], axis=1)
test = pd.concat([test, pca_c_test], axis=1)

# %%
X = train[g_feats].copy().values
select = VarianceThreshold(threshold=1)
X_new = select.fit_transform(X)
X.shape, X_new.shape
drop_g_feats = list(np.array(g_feats)[select.get_support()==False])
len(drop_g_feats)
# Out:
# 181

# %% [markdown]
# # preprocess

# %%
categoricals = ["cp_dose"]

def encoding(tr, te):
    for f in categoricals:
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(tr[f]))
        tr[f] = lbl.transform(list(tr[f]))
        te[f] = lbl.transform(list(te[f])) 
        
    return tr, te

n_train, n_test = encoding(train, test)

# %% [markdown]
# # feature engineering

# %%
def fe(df, remove_features):
    df.drop(remove_features, axis=1, inplace=True)
    return df

remove_features = ["cp_type", "sig_id"] + c_feats + drop_g_feats
        
n_train = fe(n_train, remove_features)
n_test = fe(n_test, remove_features)

print(train.shape, test.shape)
# Out:
# (21948, 603) (3982, 603)

# %% [markdown]
# # 1st model

# %%
def modelling_lgb(new_train, target_train, new_test, target, layer):
    
    X_train = new_train.copy()
    y_train = target_train[target].copy()
    X_test = new_test.copy()
    
    if layer == 1:
        params = {'objective': 'binary', 'boosting_type': 'gbdt', 'tree_learner': 'serial', 'learning_rate': 0.01, 
               "num_leaves": 10, 'random_seed':44, 'max_depth': 5} 
    else:
        params = {'objective': 'binary', 'boosting_type': 'gbdt', 'tree_learner': 'serial', 'learning_rate': 0.02, 
               "num_leaves": 10, 'random_seed':44, 'max_depth': 5} 
        
    n_folds=4
    if target not in ["erbb2_inhibitor", "atp-sensitive_potassium_channel_antagonist"]:
        skf=StratifiedKFold(n_splits = n_folds, shuffle=True, random_state=0)
    else:
        skf=KFold(n_splits = n_folds, shuffle=True, random_state=0)
    
    pred_value = np.zeros(X_test.shape[0])
    valid = np.zeros([X_train.shape[0]])
    for i , (train_index, test_index) in enumerate(skf.split(X_train, y_train)):
        X_train2 = X_train.iloc[train_index,:]
        y_train2 = y_train.iloc[train_index]

        X_valid2 = X_train.iloc[test_index,:]
        y_valid2 = y_train.iloc[test_index]
        
        lgb_train = lgb.Dataset(X_train2, y_train2)
        lgb_eval = lgb.Dataset(X_valid2, y_valid2, reference=lgb_train)
        
        clf = lgb.train(params, lgb_train,valid_sets=[lgb_train, lgb_eval], 
               num_boost_round=10000,early_stopping_rounds=25,verbose_eval = 0) 

        valid_predict = clf.predict(X_valid2, num_iteration = clf.best_iteration)
        valid[test_index] = valid_predict
        pred_value += clf.predict(X_test, num_iteration = clf.best_iteration) / n_folds
            
    score = log_loss(y_train, valid)
            
    return valid, pred_value, score

# %%
train_checkscore = targets.copy()
target_list = []
log_loss_list = []

for ind, target in enumerate(target_feats):
    print(ind, target)
    valid, pred_value, score = modelling_lgb(n_train, n_targets, n_test, target,1)
    train_checkscore.loc[cons_train_index, target] = valid
    train_checkscore.loc[noncons_train_index, target] = 0
    print("oof log_loss= {}, all log_loss= {}".format(score, log_loss(targets[target], train_checkscore[target])))
    target_list.append(target)
    log_loss_list.append(score)
    sub[target] = pred_value
    sub.loc[noncons_test_index, target] = 0
# Out:
# 0 5-alpha_reductase_inhibitor
# oof log_loss= 0.0059683912524128, all log_loss= 0.0055007244145443
# 1 11-beta-hsd1_inhibitor
# oof log_loss= 0.006582542422770321, all log_loss= 0.006066752376541733
# 2 acat_inhibitor
# oof log_loss= 0.008541915591584945, all log_loss= 0.007872594415222483
# 3 acetylcholine_receptor_agonist
# oof log_loss= 0.048923522632396944, all log_loss= 0.04509000901721046
# 4 acetylcholine_receptor_antagonist
# oof log_loss= 0.0706912686301947, all log_loss= 0.06515209388996035
# 5 acetylcholinesterase_inhibitor
# oof log_loss= 0.022266243277750446, all log_loss= 0.02052152126732463
# 6 adenosine_receptor_agonist
# oof log_loss= 0.017230753256759365, all log_loss= 0.015880598491616545
# 7 adenosine_receptor_antagonist
# oof log_loss= 0.027462410753360627, all log_loss= 0.02531053125114474
# 8 adenylyl_cyclase_activator
# oof log_loss= 0.0037872430592830555, all log_loss= 0.0034904850367492384
# 9 adrenergic_receptor_agonist
# oof log_loss= 0.06147672954787622, all log_loss= 0.056659580923691485
# 10 adrenergic_receptor_antagonist
# oof log_loss= 0.08092722351046294, all log_loss= 0.07458598730190823
# 11 akt_inhibitor
# oof log_loss= 0.016043354037082416, all log_loss= 0.014786240631808462
# 12 aldehyde_dehydrogenase_inhibitor
# oof log_loss= 0.0025224873472873693, all log_loss= 0.0023248321280870524
# 13 alk_inhibitor
# oof log_loss= 0.012233448118098376, all log_loss= 0.011274868535148447
# 14 ampk_activator
# oof log_loss= 0.004589623981758201, all log_loss= 0.004229993581575159
# 15 analgesic
# oof log_loss= 0.004666140891836708, all log_loss= 0.00430051483556034
# 16 androgen_receptor_agonist
# oof log_loss= 0.015457985515752717, all log_loss= 0.014246739989071243
# 17 androgen_receptor_antagonist
# oof log_loss= 0.02631350651616085, all log_loss= 0.02425165201212313
# 18 anesthetic_-_local
# oof log_loss= 0.02397212735101705, all log_loss= 0.02209373692366356
# 19 angiogenesis_inhibitor
# oof log_loss= 0.01214030098658432, all log_loss= 0.011189020158459498
# 20 angiotensin_receptor_antagonist
# oof log_loss= 0.012397447287785749, all log_loss= 0.011426017177808155
# 21 anti-inflammatory
# oof log_loss= 0.021405670850366414, all log_loss= 0.019728380944983786
# 22 antiarrhythmic
# oof log_loss= 0.002526565327293927, all log_loss= 0.002328590568717938
# 23 antibiotic
# oof log_loss= 0.01342777501023783, all log_loss= 0.012375611233925497
# 24 anticonvulsant
# oof log_loss= 0.004659724605264378, all log_loss= 0.0042946013116798715
# 25 antifungal
# oof log_loss= 0.005010328426216499, all log_loss= 0.004617732774779609
# 26 antihistamine
# oof log_loss= 0.004661798462420046, all log_loss= 0.00429651266705287
# 27 antimalarial
# oof log_loss= 0.00637874684956079, all log_loss= 0.00587892566784925
# 28 antioxidant
# oof log_loss= 0.022148710365859484, all log_loss= 0.020413197913407486
# 29 antiprotozoal
# oof log_loss= 0.012026489599419246, all log_loss= 0.011084126720754829
# 30 antiviral
# oof log_loss= 0.008208562138140196, all log_loss= 0.007565361627945866
# 31 apoptosis_stimulant
# oof log_loss= 0.015368044428452533, all log_loss= 0.01416384643972781
# 32 aromatase_inhibitor
# oof log_loss= 0.015102836212126445, all log_loss= 0.013919419214905228
# 33 atm_kinase_inhibitor
# oof log_loss= 0.0024141453589903526, all log_loss= 0.0022249795220929754
# 34 atp-sensitive_potassium_channel_antagonist
# oof log_loss= 0.001573843484120112, all log_loss= 0.001450521407133201
# 35 atp_synthase_inhibitor
# oof log_loss= 0.0031467023266450373, all log_loss= 0.0029001353264973186
# 36 atpase_inhibitor
# oof log_loss= 0.022772802248707962, all log_loss= 0.020988387660814824
# 37 atr_kinase_inhibitor
# oof log_loss= 0.005602373154330111, all log_loss= 0.005163386494970989
# 38 aurora_kinase_inhibitor
# oof log_loss= 0.014940624835613859, all log_loss= 0.013769918278829884
# 39 autotaxin_inhibitor
# oof log_loss= 0.0025009630429415654, all log_loss= 0.0023049944094433246
# 40 bacterial_30s_ribosomal_subunit_inhibitor
# oof log_loss= 0.018871958283390503, all log_loss= 0.01739320317476512
# 41 bacterial_50s_ribosomal_subunit_inhibitor
# oof log_loss= 0.023654042032677118, all log_loss= 0.021800575902124773
# 42 bacterial_antifolate
# oof log_loss= 0.012007855888052307, all log_loss= 0.01106695309611883
# 43 bacterial_cell_wall_synthesis_inhibitor
# oof log_loss= 0.04914845440481824, all log_loss= 0.04529731575027096
# 44 bacterial_dna_gyrase_inhibitor
# oof log_loss= 0.02592259027066805, all log_loss= 0.02389136689596977
# 45 bacterial_dna_inhibitor
# oof log_loss= 0.03266372567991251, all log_loss= 0.03010428534570931
# 46 bacterial_membrane_integrity_inhibitor
# oof log_loss= 0.0022074367135967057, all log_loss= 0.0020344680015966393
# 47 bcl_inhibitor
# oof log_loss= 0.010159198155622606, all log_loss= 0.00936315113461018
# 48 bcr-abl_inhibitor
# oof log_loss= 0.011009901413148997, all log_loss= 0.010147195608289075
# 49 benzodiazepine_receptor_agonist
# oof log_loss= 0.0204029446799338, all log_loss= 0.018804225658654108
# 50 beta_amyloid_inhibitor
# oof log_loss= 0.008538287405714162, all log_loss= 0.007869250524087356
# 51 bromodomain_inhibitor
# oof log_loss= 0.014679355055605242, all log_loss= 0.01352912088521146
# 52 btk_inhibitor
# oof log_loss= 0.009909072378394865, all log_loss= 0.009132624530150853
# 53 calcineurin_inhibitor
# oof log_loss= 0.0024941449682628412, all log_loss= 0.002298710580475128
# 54 calcium_channel_blocker
# oof log_loss= 0.0670510553459299, all log_loss= 0.06179711777662178
# 55 cannabinoid_receptor_agonist
# oof log_loss= 0.013861044124243539, all log_loss= 0.012774930563487828
# 56 cannabinoid_receptor_antagonist
# oof log_loss= 0.017344857345569998, all log_loss= 0.01598576169566525
# 57 carbonic_anhydrase_inhibitor
# oof log_loss= 0.012138842786409303, all log_loss= 0.011187676218867607
# 58 casein_kinase_inhibitor
# oof log_loss= 0.011751503065050595, all log_loss= 0.010830687380185283
# 59 caspase_activator
# oof log_loss= 0.006534660082451098, all log_loss= 0.00602262196563528
# 60 catechol_o_methyltransferase_inhibitor
# oof log_loss= 0.004664725972607827, all log_loss= 0.004299210785537853
# 61 cc_chemokine_receptor_antagonist
# oof log_loss= 0.029246119247179916, all log_loss= 0.026954473218993313
# 62 cck_receptor_antagonist
# oof log_loss= 0.0066079611096831956, all log_loss= 0.006090179324570784
# 63 cdk_inhibitor
# oof log_loss= 0.02166395105797971, all log_loss= 0.01996642302093477
# 64 chelating_agent
# oof log_loss= 0.017239606677285794, all log_loss= 0.01588875818229069
# 65 chk_inhibitor
# oof log_loss= 0.005530317573778296, all log_loss= 0.005096976992915424
# 66 chloride_channel_blocker
# oof log_loss= 0.013853090230289447, all log_loss= 0.012767599914940567
# 67 cholesterol_inhibitor
# oof log_loss= 0.015460927531953972, all log_loss= 0.0142494514769181
# 68 cholinergic_receptor_antagonist
# oof log_loss= 0.01720535714239368, all log_loss= 0.01585719234741154
# 69 coagulation_factor_inhibitor
# oof log_loss= 0.0025265494160901614, all log_loss= 0.002328575904272644
# 70 corticosteroid_agonist
# oof log_loss= 0.009332480313015099, all log_loss= 0.008601212644245284
# 71 cyclooxygenase_inhibitor
# oof log_loss= 0.09485694855840152, all log_loss= 0.08742421713948932
# 72 cytochrome_p450_inhibitor
# oof log_loss= 0.02949457748683, all log_loss= 0.02718346294956524
# 73 dihydrofolate_reductase_inhibitor
# oof log_loss= 0.010591890446438662, all log_loss= 0.009761938839272595
# 74 dipeptidyl_peptidase_inhibitor
# oof log_loss= 0.00878210534232869, all log_loss= 0.00809396355309616
# 75 diuretic
# oof log_loss= 0.0025315126518465634, all log_loss= 0.002333150234430597
# 76 dna_alkylating_agent
# oof log_loss= 0.015233758672866516, all log_loss= 0.01404008294919275
# 77 dna_inhibitor
# oof log_loss= 0.08494242805668595, all log_loss= 0.0782865713860815
# 78 dopamine_receptor_agonist
# oof log_loss= 0.03357533639442154, all log_loss= 0.030944464734390102
# 79 dopamine_receptor_antagonist
# oof log_loss= 0.08967622127602694, all log_loss= 0.08264943749753259
# 80 egfr_inhibitor
# oof log_loss= 0.026200511682610297, all log_loss= 0.024147511145121887
# 81 elastase_inhibitor
# oof log_loss= 0.002539056119310634, all log_loss= 0.0023401026163866493
# 82 erbb2_inhibitor
# oof log_loss= 0.0015739474430314902, all log_loss= 0.0014506172201082144
# 83 estrogen_receptor_agonist
# oof log_loss= 0.04093575485437648, all log_loss= 0.03772814090635159
# 84 estrogen_receptor_antagonist
# oof log_loss= 0.015333668663846783, all log_loss= 0.014132164266150627
# 85 faah_inhibitor
# oof log_loss= 0.011931027417619602, all log_loss= 0.010996144694797889
# 86 farnesyltransferase_inhibitor
# oof log_loss= 0.005609994803475554, all log_loss= 0.005170410932505389
# 87 fatty_acid_receptor_agonist
# oof log_loss= 0.008547442247152067, all log_loss= 0.007877688017153585
# 88 fgfr_inhibitor
# oof log_loss= 0.011661956020578693, all log_loss= 0.010748156997550306
# 89 flt3_inhibitor
# oof log_loss= 0.033101307038634335, all log_loss= 0.030507579024269264
# 90 focal_adhesion_kinase_inhibitor
# oof log_loss= 0.005075477335229936, all log_loss= 0.004677776793215273
# 91 free_radical_scavenger
# oof log_loss= 0.0066588686668499234, all log_loss= 0.006137097904594943
# 92 fungal_squalene_epoxidase_inhibitor
# oof log_loss= 0.008208478623043289, all log_loss= 0.007565284656863861
# 93 gaba_receptor_agonist
# oof log_loss= 0.03021867977074656, all log_loss= 0.02785082655615803
# 94 gaba_receptor_antagonist
# oof log_loss= 0.04351482469865279, all log_loss= 0.04010512188149967
# 95 gamma_secretase_inhibitor
# oof log_loss= 0.012849198103783327, all log_loss= 0.011842370033670876
# 96 glucocorticoid_receptor_agonist
# oof log_loss= 0.015148255971705321, all log_loss= 0.013961280006172428
# 97 glutamate_inhibitor
# oof log_loss= 0.004991752493043193, all log_loss= 0.004600612400995797
# 98 glutamate_receptor_agonist
# oof log_loss= 0.02224251288794604, all log_loss= 0.020499650326053647
# 99 glutamate_receptor_antagonist
# oof log_loss= 0.08301230290736193, all log_loss= 0.07650768557196531
# 100 gonadotropin_receptor_agonist
# oof log_loss= 0.0066618952233520705, all log_loss= 0.006139887308395611
# 101 gsk_inhibitor
# oof log_loss= 0.013155110663160392, all log_loss= 0.012124312120393306
# 102 hcv_inhibitor
# oof log_loss= 0.021990148835377817, all log_loss= 0.02026706083139641
# 103 hdac_inhibitor
# oof log_loss= 0.013522794172449261, all log_loss= 0.012463184954099198
# 104 histamine_receptor_agonist
# oof log_loss= 0.01841091150167081, all log_loss= 0.016968282759665443
# 105 histamine_receptor_antagonist
# oof log_loss= 0.059137972520294825, all log_loss= 0.05450408250925643
# 106 histone_lysine_demethylase_inhibitor
# oof log_loss= 0.0071559177624654306, all log_loss= 0.0065951995906018785
# 107 histone_lysine_methyltransferase_inhibitor
# oof log_loss= 0.010636490019333379, all log_loss= 0.009803043711444144
# 108 hiv_inhibitor
# oof log_loss= 0.021716344861441254, all log_loss= 0.02001471138905327
# 109 hmgcr_inhibitor
# oof log_loss= 0.01370454070171032, all log_loss= 0.012630690321707395
# 110 hsp_inhibitor
# oof log_loss= 0.0088008246711633, all log_loss= 0.008111216086448896
# 111 igf-1_inhibitor
# oof log_loss= 0.01134393258361631, all log_loss= 0.010455053008533326
# 112 ikk_inhibitor
# oof log_loss= 0.008332346901200539, all log_loss= 0.007679446955049603
# 113 imidazoline_receptor_agonist
# oof log_loss= 0.010503456989186992, all log_loss= 0.009680434786204667
# 114 immunosuppressant
# oof log_loss= 0.020263830396410693, all log_loss= 0.01867601199044359
# 115 insulin_secretagogue
# oof log_loss= 0.010317038024006972, all log_loss= 0.009508623101994913
# 116 insulin_sensitizer
# oof log_loss= 0.01463177876620671, all log_loss= 0.013485272543911428
# 117 integrin_inhibitor
# oof log_loss= 0.013898360462407146, all log_loss= 0.012809322895310064
# 118 jak_inhibitor
# oof log_loss= 0.015770697877015367, all log_loss= 0.014534949063774887
# 119 kit_inhibitor
# oof log_loss= 0.027838095299483806, all log_loss= 0.02565677818229077
# 120 laxative
# oof log_loss= 0.0025409940404062022, all log_loss= 0.002341888687277954
# 121 leukotriene_inhibitor
# oof log_loss= 0.0024655862996740617, all log_loss= 0.002272389691158485
# 122 leukotriene_receptor_antagonist
# oof log_loss= 0.01933634211082225, all log_loss= 0.017821199153788887
# 123 lipase_inhibitor
# oof log_loss= 0.00463083152343342, all log_loss= 0.004267972212829369
# 124 lipoxygenase_inhibitor
# oof log_loss= 0.01864038411170212, all log_loss= 0.017179774522702612
# 125 lxr_agonist
# oof log_loss= 0.002639980535883157, all log_loss= 0.0024331188713179385
# 126 mdm_inhibitor
# oof log_loss= 0.007413638793992667, all log_loss= 0.0068327263059777
# 127 mek_inhibitor
# oof log_loss= 0.010502932176583274, all log_loss= 0.009679951096483227
# 128 membrane_integrity_inhibitor
# oof log_loss= 0.022077950707424715, all log_loss= 0.020347982788551253
# 129 mineralocorticoid_receptor_antagonist
# oof log_loss= 0.008762749143561878, all log_loss= 0.008076124053199712
# 130 monoacylglycerol_lipase_inhibitor
# oof log_loss= 0.004664495874796321, all log_loss= 0.004298998717562421
# 131 monoamine_oxidase_inhibitor
# oof log_loss= 0.025156632241116705, all log_loss= 0.02318542724565513
# 132 monopolar_spindle_1_kinase_inhibitor
# oof log_loss= 0.00664495173847473, all log_loss= 0.00612427146871778
# 133 mtor_inhibitor
# oof log_loss= 0.017562538835007736, all log_loss= 0.016186386258115047
# 134 mucolytic_agent
# oof log_loss= 0.01537363723306988, all log_loss= 0.01416900100745022
# 135 neuropeptide_receptor_antagonist
# oof log_loss= 0.012418616667058542, all log_loss= 0.01144552778233824
# 136 nfkb_inhibitor
# oof log_loss= 0.03348773840528256, all log_loss= 0.030863730684435355
# 137 nicotinic_receptor_agonist
# oof log_loss= 0.0025722803896773014, all log_loss= 0.0023707235236684002
# 138 nitric_oxide_donor
# oof log_loss= 0.009117974853552082, all log_loss= 0.008403515246735658
# 139 nitric_oxide_production_inhibitor
# oof log_loss= 0.004376539941513862, all log_loss= 0.004033606224756366
# 140 nitric_oxide_synthase_inhibitor
# oof log_loss= 0.009166701129903724, all log_loss= 0.008448423465151962
# 141 norepinephrine_reuptake_inhibitor
# oof log_loss= 0.0028955102457671055, all log_loss= 0.002668625971029575
# 142 nrf2_activator
# oof log_loss= 0.005232356883810791, all log_loss= 0.004822363688833507
# 143 opioid_receptor_agonist
# oof log_loss= 0.0190284871602531, all log_loss= 0.017537466876343194
# 144 opioid_receptor_antagonist
# oof log_loss= 0.027893716955574143, all log_loss= 0.025708041477321877
# 145 orexin_receptor_antagonist
# oof log_loss= 0.012418856469524592, all log_loss= 0.011445748794537983
# 146 p38_mapk_inhibitor
# oof log_loss= 0.012416035412171003, all log_loss= 0.011443148787533847
# 147 p-glycoprotein_inhibitor
# oof log_loss= 0.00853989499073826, all log_loss= 0.007870732143139547
# 148 parp_inhibitor
# oof log_loss= 0.018022770133072567, all log_loss= 0.016610555088631837
# 149 pdgfr_inhibitor
# oof log_loss= 0.029788429108432855, all log_loss= 0.027454289160657012
# 150 pdk_inhibitor
# oof log_loss= 0.006474418702957607, all log_loss= 0.005967100936109658
# 151 phosphodiesterase_inhibitor
# oof log_loss= 0.06275289128183136, all log_loss= 0.057835746109584134
# 152 phospholipase_inhibitor
# oof log_loss= 0.008797699292910318, all log_loss= 0.00810833560429989
# 153 pi3k_inhibitor
# oof log_loss= 0.030161333809246342, all log_loss= 0.027797974067579598
# 154 pkc_inhibitor
# oof log_loss= 0.0105070231191995, all log_loss= 0.00968372148400909
# 155 potassium_channel_activator
# oof log_loss= 0.017236647877904274, all log_loss= 0.01588603122634773
# 156 potassium_channel_antagonist
# oof log_loss= 0.028362410486182717, all log_loss= 0.026140009462952047
# 157 ppar_receptor_agonist
# oof log_loss= 0.027191014636213068, all log_loss= 0.02506040099250887
# 158 ppar_receptor_antagonist
# oof log_loss= 0.010380330639671299, all log_loss= 0.009566956281158457
# 159 progesterone_receptor_agonist
# oof log_loss= 0.030860257479676436, all log_loss= 0.028442131988071735
# 160 progesterone_receptor_antagonist
# oof log_loss= 0.0062865753354232395, all log_loss= 0.005793976461823765
# 161 prostaglandin_inhibitor
# oof log_loss= 0.012072256641472054, all log_loss= 0.011126307582389793
# 162 prostanoid_receptor_antagonist
# oof log_loss= 0.02504635959460911, all log_loss= 0.023083795262554906
# 163 proteasome_inhibitor
# oof log_loss= 0.0010179024867138918, all log_loss= 0.000938142427916283
# 164 protein_kinase_inhibitor
# oof log_loss= 0.015230263369624028, all log_loss= 0.01403686152836609
# 165 protein_phosphatase_inhibitor
# oof log_loss= 0.0024349458114971494, all log_loss= 0.0022441501079508404
# 166 protein_synthesis_inhibitor
# oof log_loss= 0.025451222832358934, all log_loss= 0.023456934522743576
# 167 protein_tyrosine_kinase_inhibitor
# oof log_loss= 0.006969079599900959, all log_loss= 0.006423001556169821
# 168 radiopaque_medium
# oof log_loss= 0.017685317899932648, all log_loss= 0.01629954469084251
# 169 raf_inhibitor
# oof log_loss= 0.010037624171128164, all log_loss= 0.009251103355501925
# 170 ras_gtpase_inhibitor
# oof log_loss= 0.004566693790567822, all log_loss= 0.004208860137540288
# 171 retinoid_receptor_agonist
# oof log_loss= 0.012434645830988139, all log_loss= 0.011460300944760625
# 172 retinoid_receptor_antagonist
# oof log_loss= 0.0025283620165114694, all log_loss= 0.0023302464742754507
# 173 rho_associated_kinase_inhibitor
# oof log_loss= 0.010674754526734716, all log_loss= 0.009838309916552258
# 174 ribonucleoside_reductase_inhibitor
# oof log_loss= 0.010104512562769943, all log_loss= 0.00931275055545799
# 175 rna_polymerase_inhibitor
# oof log_loss= 0.008777170944829524, all log_loss= 0.008089415801508367
# 176 serotonin_receptor_agonist
# oof log_loss= 0.05848472527019699, all log_loss= 0.05390202192954923
# 177 serotonin_receptor_antagonist
# oof log_loss= 0.08817974514578486, all log_loss= 0.08127022114973075
# 178 serotonin_reuptake_inhibitor
# oof log_loss= 0.014440164643180386, all log_loss= 0.013308672780235366
# 179 sigma_receptor_agonist
# oof log_loss= 0.012130296389852717, all log_loss= 0.011179799494603567
# 180 sigma_receptor_antagonist
# oof log_loss= 0.012004740403133232, all log_loss= 0.011064081732089111
# 181 smoothened_receptor_antagonist
# oof log_loss= 0.008536017890056067, all log_loss= 0.007867158841477803
# 182 sodium_channel_inhibitor
# oof log_loss= 0.06467926287806891, all log_loss= 0.05961117248878216
# 183 sphingosine_receptor_agonist
# oof log_loss= 0.008811890362829863, all log_loss= 0.008121414700738712
# 184 src_inhibitor
# oof log_loss= 0.01787888890899179, all log_loss= 0.016477948004306443
# 185 steroid
# oof log_loss= 0.002517924473135922, all log_loss= 0.0023206267882921426
# 186 syk_inhibitor
# oof log_loss= 0.006184977232283295, all log_loss= 0.005700339308564527
# 187 tachykinin_antagonist
# oof log_loss= 0.018789564992783662, all log_loss= 0.017317265997380434
# 188 tgf-beta_receptor_inhibitor
# oof log_loss= 0.004428814230903394, all log_loss= 0.004081784443599124
# 189 thrombin_inhibitor
# oof log_loss= 0.0069716136041118254, all log_loss= 0.006425337002731512
# 190 thymidylate_synthase_inhibitor
# oof log_loss= 0.011730229756199412, all log_loss= 0.01081108098971473
# 191 tlr_agonist
# oof log_loss= 0.01038676082990478, all log_loss= 0.009572882619247165
# 192 tlr_antagonist
# oof log_loss= 0.0028920675238762027, all log_loss= 0.0026654530114233964
# 193 tnf_inhibitor
# oof log_loss= 0.011887355301357712, all log_loss= 0.010955894606290456
# 194 topoisomerase_inhibitor
# oof log_loss= 0.01744605722173728, all log_loss= 0.016079031825929777
# 195 transient_receptor_potential_channel_antagonist
# oof log_loss= 0.0066420105488323306, all log_loss= 0.0061215607426628816
# 196 tropomyosin_receptor_kinase_inhibitor
# oof log_loss= 0.0025311711250832433, all log_loss= 0.002332835468771685
# 197 trpv_agonist
# oof log_loss= 0.00761025899049452, all log_loss= 0.007013939880884168
# 198 trpv_antagonist
# oof log_loss= 0.015413909583847979, all log_loss= 0.014206117726811846
# 199 tubulin_inhibitor
# oof log_loss= 0.02498399435297155, all log_loss= 0.02302631679092221
# 200 tyrosine_kinase_inhibitor
# oof log_loss= 0.021952617186425633, all log_loss= 0.020232470059950942
# 201 ubiquitin_specific_protease_inhibitor
# oof log_loss= 0.0025292575225749955, all log_loss= 0.002331071810929615
# 202 vegfr_inhibitor
# oof log_loss= 0.03073214050144509, all log_loss= 0.028324053906345785
# 203 vitamin_b
# oof log_loss= 0.009154875793560143, all log_loss= 0.008437524729867299
# 204 vitamin_d_receptor_agonist
# oof log_loss= 0.008198753358518569, all log_loss= 0.00755632143750598
# 205 wnt_inhibitor
# oof log_loss= 0.010342142333641764, all log_loss= 0.009531760306490774

# %%
# local score
scores = []
for target_col in target_feats:
    scores.append(log_loss(targets[target_col], train_checkscore[target_col]))
print(np.mean(scores))
# Out:
# 0.015958240181755234

# %% [markdown]
# # 2nd model

# %%
first_layer_train = train_checkscore[train_checkscore.index.isin(cons_train_index)].copy()
first_layer_test = sub[sub.index.isin(cons_test_index)].copy()

first_layer_train.drop("sig_id", axis=1, inplace=True)
first_layer_test.drop("sig_id", axis=1, inplace=True)

#n_train_feat2 = pd.merge(n_train, first_layer_train_feat, on="sig_id", how="outer") 
#n_test_feat2 = pd.merge(n_test, first_layer_test_feat, on="sig_id", how="outer")

# %%
final = pd.read_csv(DIR+"sample_submission.csv")

# %%
train_checkscore2 = targets.copy()
target_list2 = []
log_loss_list2 = []

for ind, target in enumerate(target_feats):
    print(ind, target)
    valid, pred_value, score = modelling_lgb(first_layer_train, n_targets, first_layer_test, target, 2)
    train_checkscore2.loc[cons_train_index, target] = valid
    train_checkscore2.loc[noncons_train_index, target] = 0
    print("oof log_loss= {}, all log_loss= {}".format(score, log_loss(targets[target], train_checkscore2[target])))
    target_list2.append(target)
    log_loss_list2.append(score)
    final.loc[cons_test_index, target] = pred_value
    final.loc[noncons_test_index, target] = 0
# Out:
# 0 5-alpha_reductase_inhibitor
# oof log_loss= 0.006135499462646391, all log_loss= 0.005654738481824341
# 1 11-beta-hsd1_inhibitor
# oof log_loss= 0.006661695931129607, all log_loss= 0.0061397036321674
# 2 acat_inhibitor
# oof log_loss= 0.00849497070345881, all log_loss= 0.007829328000315605
# 3 acetylcholine_receptor_agonist
# oof log_loss= 0.04854364904554355, all log_loss= 0.04473990128712487
# 4 acetylcholine_receptor_antagonist
# oof log_loss= 0.07035453199225535, all log_loss= 0.06484174301528606
# 5 acetylcholinesterase_inhibitor
# oof log_loss= 0.02196866452474375, all log_loss= 0.020247259972666406
# 6 adenosine_receptor_agonist
# oof log_loss= 0.01712068620411885, all log_loss= 0.015779155992609487
# 7 adenosine_receptor_antagonist
# oof log_loss= 0.027699246147637257, all log_loss= 0.02552880887076276
# 8 adenylyl_cyclase_activator
# oof log_loss= 0.0045651639792127175, all log_loss= 0.004207450198024801
# 9 adrenergic_receptor_agonist
# oof log_loss= 0.061731746063859304, all log_loss= 0.05689461504197472
# 10 adrenergic_receptor_antagonist
# oof log_loss= 0.08149196067528178, all log_loss= 0.0751064732048831
# 11 akt_inhibitor
# oof log_loss= 0.015566827115986467, all log_loss= 0.014347053058775209
# 12 aldehyde_dehydrogenase_inhibitor
# oof log_loss= 0.0026393580322543846, all log_loss= 0.0024325451453733565
# 13 alk_inhibitor
# oof log_loss= 0.01207896059789334, all log_loss= 0.011132486235095529
# 14 ampk_activator
# oof log_loss= 0.004693800467331271, all log_loss= 0.004326007082262056
# 15 analgesic
# oof log_loss= 0.004598507234924156, all log_loss= 0.0042381807672846735
# 16 androgen_receptor_agonist
# oof log_loss= 0.01534297410652412, all log_loss= 0.014140740559754485
# 17 androgen_receptor_antagonist
# oof log_loss= 0.026130736634106737, all log_loss= 0.024083203478851792
# 18 anesthetic_-_local
# oof log_loss= 0.023915194161189653, all log_loss= 0.022041264863097012
# 19 angiogenesis_inhibitor
# oof log_loss= 0.01216097310010622, all log_loss= 0.011208072461624807
# 20 angiotensin_receptor_antagonist
# oof log_loss= 0.012317968093448952, all log_loss= 0.011352765756068677
# 21 anti-inflammatory
# oof log_loss= 0.021256302103563666, all log_loss= 0.019590716325229577
# 22 antiarrhythmic
# oof log_loss= 0.0025616133940185443, all log_loss= 0.0023608923646561216
# 23 antibiotic
# oof log_loss= 0.013148019733199614, all log_loss= 0.012117776816337742
# 24 anticonvulsant
# oof log_loss= 0.0046677856990162536, all log_loss= 0.004302030760141539
# 25 antifungal
# oof log_loss= 0.004978696219315382, all log_loss= 0.004588579181218437
# 26 antihistamine
# oof log_loss= 0.00461755183246165, all log_loss= 0.0042557330821730984
# 27 antimalarial
# oof log_loss= 0.006557088639628864, all log_loss= 0.006043293082328719
# 28 antioxidant
# oof log_loss= 0.02191467405556316, all log_loss= 0.020197500049193837
# 29 antiprotozoal
# oof log_loss= 0.012006787050997008, all log_loss= 0.01106596801021602
# 30 antiviral
# oof log_loss= 0.008135208090282533, all log_loss= 0.00749775540293621
# 31 apoptosis_stimulant
# oof log_loss= 0.015724855316236713, all log_loss= 0.014492698600855182
# 32 aromatase_inhibitor
# oof log_loss= 0.015279358567536481, all log_loss= 0.01408210976065728
# 33 atm_kinase_inhibitor
# oof log_loss= 0.0027303772965175804, all log_loss= 0.0025164323886776568
# 34 atp-sensitive_potassium_channel_antagonist
# oof log_loss= 0.0016029303580196112, all log_loss= 0.001477329113035033
# 35 atp_synthase_inhibitor
# oof log_loss= 0.0024454506675517114, all log_loss= 0.002253831832175478
# 36 atpase_inhibitor
# oof log_loss= 0.024370771825473127, all log_loss= 0.022461144705865715
# 37 atr_kinase_inhibitor
# oof log_loss= 0.0054538061804654606, all log_loss= 0.005026460823417224
# 38 aurora_kinase_inhibitor
# oof log_loss= 0.01513772613642972, all log_loss= 0.013951575260030291
# 39 autotaxin_inhibitor
# oof log_loss= 0.002561727374150644, all log_loss= 0.0023609974136163687
# 40 bacterial_30s_ribosomal_subunit_inhibitor
# oof log_loss= 0.018881208428108576, all log_loss= 0.017401728503406773
# 41 bacterial_50s_ribosomal_subunit_inhibitor
# oof log_loss= 0.02383040648249606, all log_loss= 0.02196312091533658
# 42 bacterial_antifolate
# oof log_loss= 0.012128882633262388, all log_loss= 0.01117849651611845
# 43 bacterial_cell_wall_synthesis_inhibitor
# oof log_loss= 0.04923662742022883, all log_loss= 0.04537857976900916
# 44 bacterial_dna_gyrase_inhibitor
# oof log_loss= 0.026119069074753386, all log_loss= 0.024072450157583324
# 45 bacterial_dna_inhibitor
# oof log_loss= 0.03218462914955905, all log_loss= 0.029662729510981936
# 46 bacterial_membrane_integrity_inhibitor
# oof log_loss= 0.0032654746319427724, all log_loss= 0.0030096009583388695
# 47 bcl_inhibitor
# oof log_loss= 0.0103336075452561, all log_loss= 0.009523894280813083
# 48 bcr-abl_inhibitor
# oof log_loss= 0.01079312661546104, all log_loss= 0.009947406691699872
# 49 benzodiazepine_receptor_agonist
# oof log_loss= 0.02059966609498279, all log_loss= 0.018985532520898803
# 50 beta_amyloid_inhibitor
# oof log_loss= 0.0085373894398079, all log_loss= 0.007868422920337013
# 51 bromodomain_inhibitor
# oof log_loss= 0.015628971779342034, all log_loss= 0.01440432823603766
# 52 btk_inhibitor
# oof log_loss= 0.009793971812301048, all log_loss= 0.00902654293005733
# 53 calcineurin_inhibitor
# oof log_loss= 0.002577904417869999, all log_loss= 0.0023759068683720757
# 54 calcium_channel_blocker
# oof log_loss= 0.06731529967827124, all log_loss= 0.06204065664477614
# 55 cannabinoid_receptor_agonist
# oof log_loss= 0.01386391282459921, all log_loss= 0.012777574480318523
# 56 cannabinoid_receptor_antagonist
# oof log_loss= 0.017428139143868242, all log_loss= 0.0160625177597053
# 57 carbonic_anhydrase_inhibitor
# oof log_loss= 0.012146144268620714, all log_loss= 0.011194405576874499
# 58 casein_kinase_inhibitor
# oof log_loss= 0.011929213394155473, all log_loss= 0.010994472813258004
# 59 caspase_activator
# oof log_loss= 0.006668130438325918, all log_loss= 0.006145633948953519
# 60 catechol_o_methyltransferase_inhibitor
# oof log_loss= 0.004761756223732844, all log_loss= 0.004388638011190489
# 61 cc_chemokine_receptor_antagonist
# oof log_loss= 0.02927385082196526, all log_loss= 0.026980031823318023
# 62 cck_receptor_antagonist
# oof log_loss= 0.006569854997931299, all log_loss= 0.006055059103661628
# 63 cdk_inhibitor
# oof log_loss= 0.02146073080997212, all log_loss= 0.01977912655653271
# 64 chelating_agent
# oof log_loss= 0.01689819873435804, all log_loss= 0.015574102033328801
# 65 chk_inhibitor
# oof log_loss= 0.005861117631703464, all log_loss= 0.005401856461771625
# 66 chloride_channel_blocker
# oof log_loss= 0.01332594989767024, all log_loss= 0.012281764859077362
# 67 cholesterol_inhibitor
# oof log_loss= 0.01529092787369529, all log_loss= 0.014092772527583192
# 68 cholinergic_receptor_antagonist
# oof log_loss= 0.016926140737094326, all log_loss= 0.015599854577044934
# 69 coagulation_factor_inhibitor
# oof log_loss= 0.0025755748254034073, all log_loss= 0.002373759816408661
# 70 corticosteroid_agonist
# oof log_loss= 0.01059479881526645, all log_loss= 0.00976461931626228
# 71 cyclooxygenase_inhibitor
# oof log_loss= 0.095225978478696, all log_loss= 0.08776433088311168
# 72 cytochrome_p450_inhibitor
# oof log_loss= 0.029830541085968727, all log_loss= 0.027493101358648
# 73 dihydrofolate_reductase_inhibitor
# oof log_loss= 0.010650547210664461, all log_loss= 0.009815999419655054
# 74 dipeptidyl_peptidase_inhibitor
# oof log_loss= 0.008786147201489992, all log_loss= 0.008097688703212574
# 75 diuretic
# oof log_loss= 0.0025922463294180405, all log_loss= 0.002389124986901361
# 76 dna_alkylating_agent
# oof log_loss= 0.015281380622595557, all log_loss= 0.0140839733730045
# 77 dna_inhibitor
# oof log_loss= 0.08603440315276248, all log_loss= 0.07929298229599532
# 78 dopamine_receptor_agonist
# oof log_loss= 0.03350745535191845, all log_loss= 0.030881902664983116
# 79 dopamine_receptor_antagonist
# oof log_loss= 0.09036493435269485, all log_loss= 0.08328418489850291
# 80 egfr_inhibitor
# oof log_loss= 0.023859780555117404, all log_loss= 0.0219901933158528
# 81 elastase_inhibitor
# oof log_loss= 0.002547762815598232, all log_loss= 0.0023481270797325892
# 82 erbb2_inhibitor
# oof log_loss= 0.0016074342758837304, all log_loss= 0.0014814801161962701
# 83 estrogen_receptor_agonist
# oof log_loss= 0.04080077279796482, all log_loss= 0.03760373567522187
# 84 estrogen_receptor_antagonist
# oof log_loss= 0.015479100440121612, all log_loss= 0.014266200405634963
# 85 faah_inhibitor
# oof log_loss= 0.011727603337984107, all log_loss= 0.010808660370457591
# 86 farnesyltransferase_inhibitor
# oof log_loss= 0.005634101091361632, all log_loss= 0.005192628317511
# 87 fatty_acid_receptor_agonist
# oof log_loss= 0.008815775177810342, all log_loss= 0.008124995112227399
# 88 fgfr_inhibitor
# oof log_loss= 0.01191697394295981, all log_loss= 0.010983192412030059
# 89 flt3_inhibitor
# oof log_loss= 0.029883407109794122, all log_loss= 0.027541824945232354
# 90 focal_adhesion_kinase_inhibitor
# oof log_loss= 0.0052500286203695425, all log_loss= 0.004838650716379969
# 91 free_radical_scavenger
# oof log_loss= 0.006483369242201209, all log_loss= 0.005975350135543544
# 92 fungal_squalene_epoxidase_inhibitor
# oof log_loss= 0.008201421062118883, all log_loss= 0.007558780107138118
# 93 gaba_receptor_agonist
# oof log_loss= 0.030359357007010573, all log_loss= 0.027980480708401353
# 94 gaba_receptor_antagonist
# oof log_loss= 0.043480153302206725, all log_loss= 0.040073167240985766
# 95 gamma_secretase_inhibitor
# oof log_loss= 0.01220371556735014, all log_loss= 0.011247465745872287
# 96 glucocorticoid_receptor_agonist
# oof log_loss= 0.015959470982456505, all log_loss= 0.014708930424244445
# 97 glutamate_inhibitor
# oof log_loss= 0.0050274307803537125, all log_loss= 0.004633495035156008
# 98 glutamate_receptor_agonist
# oof log_loss= 0.02235618142975571, all log_loss= 0.02060441211137483
# 99 glutamate_receptor_antagonist
# oof log_loss= 0.0828352278672741, all log_loss= 0.07634448564839733
# 100 gonadotropin_receptor_agonist
# oof log_loss= 0.006628312650597363, all log_loss= 0.006108936174322364
# 101 gsk_inhibitor
# oof log_loss= 0.012880978150405066, all log_loss= 0.011871659882635936
# 102 hcv_inhibitor
# oof log_loss= 0.021920118636377727, all log_loss= 0.020202518007525833
# 103 hdac_inhibitor
# oof log_loss= 0.012707206122375152, all log_loss= 0.0117115041561221
# 104 histamine_receptor_agonist
# oof log_loss= 0.018450281045804477, all log_loss= 0.017004567413845578
# 105 histamine_receptor_antagonist
# oof log_loss= 0.05918012310197839, all log_loss= 0.05454293028647953
# 106 histone_lysine_demethylase_inhibitor
# oof log_loss= 0.007234274172531713, all log_loss= 0.006667416206379772
# 107 histone_lysine_methyltransferase_inhibitor
# oof log_loss= 0.010819276038441647, all log_loss= 0.009971507117314149
# 108 hiv_inhibitor
# oof log_loss= 0.02191051524459482, all log_loss= 0.020193667111294573
# 109 hmgcr_inhibitor
# oof log_loss= 0.013681112183442626, all log_loss= 0.012609097598143978
# 110 hsp_inhibitor
# oof log_loss= 0.008839434113102793, all log_loss= 0.008146800197966824
# 111 igf-1_inhibitor
# oof log_loss= 0.011821715412206928, all log_loss= 0.010895398079580062
# 112 ikk_inhibitor
# oof log_loss= 0.007749587844685631, all log_loss= 0.007142351306591169
# 113 imidazoline_receptor_agonist
# oof log_loss= 0.010557256889055212, all log_loss= 0.009730019072855702
# 114 immunosuppressant
# oof log_loss= 0.020181048775017266, all log_loss= 0.018599716910812164
# 115 insulin_secretagogue
# oof log_loss= 0.010348575382241007, all log_loss= 0.009537689278971506
# 116 insulin_sensitizer
# oof log_loss= 0.014339924093387685, all log_loss= 0.013216286806150782
# 117 integrin_inhibitor
# oof log_loss= 0.013812559914706962, all log_loss= 0.012730245444192085
# 118 jak_inhibitor
# oof log_loss= 0.015518573277216905, all log_loss= 0.014302580259022361
# 119 kit_inhibitor
# oof log_loss= 0.025549613779771427, all log_loss= 0.023547615824238897
# 120 laxative
# oof log_loss= 0.0025724554116586945, all log_loss= 0.0023708848314053454
# 121 leukotriene_inhibitor
# oof log_loss= 0.0025159477302051617, all log_loss= 0.002318804937538622
# 122 leukotriene_receptor_antagonist
# oof log_loss= 0.0193796530644171, all log_loss= 0.017861116379349475
# 123 lipase_inhibitor
# oof log_loss= 0.004630426538318407, all log_loss= 0.004267598961241886
# 124 lipoxygenase_inhibitor
# oof log_loss= 0.018748061790710483, all log_loss= 0.01727901487286955
# 125 lxr_agonist
# oof log_loss= 0.002651931968709102, all log_loss= 0.0024441338225089956
# 126 mdm_inhibitor
# oof log_loss= 0.007338953989820325, all log_loss= 0.006763893599083665
# 127 mek_inhibitor
# oof log_loss= 0.009289675507696575, all log_loss= 0.008561761906564472
# 128 membrane_integrity_inhibitor
# oof log_loss= 0.02213960722561536, all log_loss= 0.020404808070370692
# 129 mineralocorticoid_receptor_antagonist
# oof log_loss= 0.008585868609607545, all log_loss= 0.007913103394795847
# 130 monoacylglycerol_lipase_inhibitor
# oof log_loss= 0.004521118515858435, all log_loss= 0.004166856016883463
# 131 monoamine_oxidase_inhibitor
# oof log_loss= 0.024939730589455755, all log_loss= 0.0229855214150238
# 132 monopolar_spindle_1_kinase_inhibitor
# oof log_loss= 0.0066056472589740975, all log_loss= 0.006088046780883739
# 133 mtor_inhibitor
# oof log_loss= 0.018161572734955854, all log_loss= 0.016738481497724573
# 134 mucolytic_agent
# oof log_loss= 0.015540669835330373, all log_loss= 0.014322945391191435
# 135 neuropeptide_receptor_antagonist
# oof log_loss= 0.012470429638100633, all log_loss= 0.011493280830479324
# 136 nfkb_inhibitor
# oof log_loss= 0.03301322206586381, all log_loss= 0.0304263961493903
# 137 nicotinic_receptor_agonist
# oof log_loss= 0.00256632812492787, all log_loss= 0.0023652376621281068
# 138 nitric_oxide_donor
# oof log_loss= 0.009092609284949576, all log_loss= 0.008380137254811251
# 139 nitric_oxide_production_inhibitor
# oof log_loss= 0.004680999671535549, all log_loss= 0.0043142093218637816
# 140 nitric_oxide_synthase_inhibitor
# oof log_loss= 0.009140447617626264, all log_loss= 0.008424227106393846
# 141 norepinephrine_reuptake_inhibitor
# oof log_loss= 0.002903307894460063, all log_loss= 0.0026758126172676303
# 142 nrf2_activator
# oof log_loss= 0.005652199353703472, all log_loss= 0.005209308449445103
# 143 opioid_receptor_agonist
# oof log_loss= 0.018968126662226022, all log_loss= 0.01748183606208695
# 144 opioid_receptor_antagonist
# oof log_loss= 0.027965094103945036, all log_loss= 0.025773825707289304
# 145 orexin_receptor_antagonist
# oof log_loss= 0.01237622423684654, all log_loss= 0.011406457107176863
# 146 p38_mapk_inhibitor
# oof log_loss= 0.0121900613800005, all log_loss= 0.01123488146335151
# 147 p-glycoprotein_inhibitor
# oof log_loss= 0.008542552201311992, all log_loss= 0.007873181141950007
# 148 parp_inhibitor
# oof log_loss= 0.018657341863266914, all log_loss= 0.01719540351116923
# 149 pdgfr_inhibitor
# oof log_loss= 0.028437946600764118, all log_loss= 0.026209626773896558
# 150 pdk_inhibitor
# oof log_loss= 0.006562073170784033, all log_loss= 0.006047887039236156
# 151 phosphodiesterase_inhibitor
# oof log_loss= 0.06296342033253609, all log_loss= 0.05802977867886553
# 152 phospholipase_inhibitor
# oof log_loss= 0.008660341438015034, all log_loss= 0.007981740735767021
# 153 pi3k_inhibitor
# oof log_loss= 0.03234634696643091, all log_loss= 0.029811775561402014
# 154 pkc_inhibitor
# oof log_loss= 0.010573410271313958, all log_loss= 0.009744906720198227
# 155 potassium_channel_activator
# oof log_loss= 0.01750537649461152, all log_loss= 0.016133703002592405
# 156 potassium_channel_antagonist
# oof log_loss= 0.028364466925966544, all log_loss= 0.026141904765730896
# 157 ppar_receptor_agonist
# oof log_loss= 0.026910902921865033, all log_loss= 0.02480223806706541
# 158 ppar_receptor_antagonist
# oof log_loss= 0.010247619106344655, all log_loss= 0.009444643661125992
# 159 progesterone_receptor_agonist
# oof log_loss= 0.0308956723725429, all log_loss= 0.028474771866657155
# 160 progesterone_receptor_antagonist
# oof log_loss= 0.006413649666069216, all log_loss= 0.0059110935949814826
# 161 prostaglandin_inhibitor
# oof log_loss= 0.012166999833797432, all log_loss= 0.01121362695692399
# 162 prostanoid_receptor_antagonist
# oof log_loss= 0.024818331683138368, all log_loss= 0.02287363499544481
# 163 proteasome_inhibitor
# oof log_loss= 0.0015233489740899922, all log_loss= 0.0014039835090001263
# 164 protein_kinase_inhibitor
# oof log_loss= 0.015291096684938221, all log_loss= 0.014092928111238178
# 165 protein_phosphatase_inhibitor
# oof log_loss= 0.0027576763501586487, all log_loss= 0.0025415923630336735
# 166 protein_synthesis_inhibitor
# oof log_loss= 0.025417114111701673, all log_loss= 0.023425498468280428
# 167 protein_tyrosine_kinase_inhibitor
# oof log_loss= 0.006998477522014337, all log_loss= 0.0064500959373970145
# 168 radiopaque_medium
# oof log_loss= 0.017592268573435006, all log_loss= 0.016213786455436016
# 169 raf_inhibitor
# oof log_loss= 0.010084014334947121, all log_loss= 0.009293858512783288
# 170 ras_gtpase_inhibitor
# oof log_loss= 0.004691530682795363, all log_loss= 0.004323915151843223
# 171 retinoid_receptor_agonist
# oof log_loss= 0.012937159474876959, all log_loss= 0.011923438991962765
# 172 retinoid_receptor_antagonist
# oof log_loss= 0.0025649664905656924, all log_loss= 0.002363982721715701
# 173 rho_associated_kinase_inhibitor
# oof log_loss= 0.010203595834139581, all log_loss= 0.009404069932296021
# 174 ribonucleoside_reductase_inhibitor
# oof log_loss= 0.010323651698320797, all log_loss= 0.009514718546852555
# 175 rna_polymerase_inhibitor
# oof log_loss= 0.00838272460467002, all log_loss= 0.007725877199265115
# 176 serotonin_receptor_agonist
# oof log_loss= 0.05794582997857792, all log_loss= 0.05340535300116865
# 177 serotonin_receptor_antagonist
# oof log_loss= 0.08806685233040014, all log_loss= 0.08116617430703048
# 178 serotonin_reuptake_inhibitor
# oof log_loss= 0.014474574967905569, all log_loss= 0.013340386805895409
# 179 sigma_receptor_agonist
# oof log_loss= 0.01198931016656652, all log_loss= 0.01104986056671722
# 180 sigma_receptor_antagonist
# oof log_loss= 0.012021581403176091, all log_loss= 0.011079603117364186
# 181 smoothened_receptor_antagonist
# oof log_loss= 0.008507535639293573, all log_loss= 0.007840908382095288
# 182 sodium_channel_inhibitor
# oof log_loss= 0.06400589224043277, all log_loss= 0.05899056533522382
# 183 sphingosine_receptor_agonist
# oof log_loss= 0.008867813076572246, all log_loss= 0.008172955463366487
# 184 src_inhibitor
# oof log_loss= 0.016622997846431054, all log_loss= 0.015320465135360319
# 185 steroid
# oof log_loss= 0.002715816264965835, all log_loss= 0.002503012319789705
# 186 syk_inhibitor
# oof log_loss= 0.006135122057333359, all log_loss= 0.005654390648960881
# 187 tachykinin_antagonist
# oof log_loss= 0.018819529361886966, all log_loss= 0.017344882440358488
# 188 tgf-beta_receptor_inhibitor
# oof log_loss= 0.004587752914549713, all log_loss= 0.004228269126082933
# 189 thrombin_inhibitor
# oof log_loss= 0.006991556773743179, all log_loss= 0.006443717480058669
# 190 thymidylate_synthase_inhibitor
# oof log_loss= 0.01190109428340321, all log_loss= 0.010968557039226315
# 191 tlr_agonist
# oof log_loss= 0.010366079524664482, all log_loss= 0.009553821844601408
# 192 tlr_antagonist
# oof log_loss= 0.003020369239577238, all log_loss= 0.0027837013550954513
# 193 tnf_inhibitor
# oof log_loss= 0.012165907987117957, all log_loss= 0.011212620664368306
# 194 topoisomerase_inhibitor
# oof log_loss= 0.017133166890672163, all log_loss= 0.01579065872665132
# 195 transient_receptor_potential_channel_antagonist
# oof log_loss= 0.006668932044398151, all log_loss= 0.006146372743363251
# 196 tropomyosin_receptor_kinase_inhibitor
# oof log_loss= 0.0025550716653478874, all log_loss= 0.0023548632279775466
# 197 trpv_agonist
# oof log_loss= 0.008016055373054089, all log_loss= 0.007387939167203874
# 198 trpv_antagonist
# oof log_loss= 0.01559917231344509, all log_loss= 0.014376863774901095
# 199 tubulin_inhibitor
# oof log_loss= 0.024095715745476476, all log_loss= 0.02220764126907364
# 200 tyrosine_kinase_inhibitor
# oof log_loss= 0.02195368703189399, all log_loss= 0.02023345607525032
# 201 ubiquitin_specific_protease_inhibitor
# oof log_loss= 0.002632265491352992, all log_loss= 0.0024260083566060857
# 202 vegfr_inhibitor
# oof log_loss= 0.03172982999770712, all log_loss= 0.02924356717853691
# 203 vitamin_b
# oof log_loss= 0.008980505031584485, all log_loss= 0.008276817184564465
# 204 vitamin_d_receptor_agonist
# oof log_loss= 0.008962369369090869, all log_loss= 0.008260102583052332
# 205 wnt_inhibitor
# oof log_loss= 0.010280159107917035, all log_loss= 0.009474633917047321

# %%
# local score
scores = []
for target_col in target_feats:
    scores.append(log_loss(targets[target_col], train_checkscore2[target_col]))
print(np.mean(scores))
# Out:
# 0.01595553579771805

# %% [markdown]
# # submission

# %%
final.to_csv("submission.csv", index=False)

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
import xgboost as xgb
from datetime import datetime
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf'] #'Quarter'
#top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)
#top20_winddirection = list(train.WindDirection.value_counts(normalize=True, dropna=False).cumsum().head(20).index)
#top20_windspeed = list(train.WindSpeed.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    #df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]
    
    df["AttackAngle"] =  np.arctan((df["Y"] - df["RushY"]) / (df["X"] - df["RushX"])) * 180 / np.pi

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1
    
    df_single = df[df.is_run==True].copy()
        
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])
    df_single["1stDefender_AttackAngle"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["AttackAngle"])
    #df_single["1stDefenderID"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["NflId"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    #def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    #off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    #df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY"]#"InfluToBall",, "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:856: RuntimeWarning: invalid value encountered in arctan
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# CPU times: user 6min 36s, sys: 3.1 s, total: 6min 39s
# Wall time: 6min 38s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1125)
average_crps = 0
models = []
crps_scores = []
xgb_params = {
    "objective" : "multi:softprob",
    "eval_metric" : "mlogloss", 
    "max_depth" : 4,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.05,
    "colsample_bytree": 0.9,
}

num_boost_round=100000
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    X_test2= X_train.iloc[test_index,:]
    y_train2= y_train.iloc[train_index]
    y_test2= y_train.iloc[test_index]
    xgb_train = xgb.DMatrix(X_train2, label = y_train2)
    xgb_eval = xgb.DMatrix(X_test2, label = y_test2)
    watchlist = [(xgb_train, "train"), (xgb_eval, "eval")]
    
    clf = xgb.train(
            xgb_params, xgb_train, num_boost_round, watchlist,
            early_stopping_rounds=10,
        )
    
    models.append(clf)
    temp_predict = clf.predict(xgb_eval, ntree_limit=clf.best_ntree_limit)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    if i == 0:
        feature_importance_df = pd.DataFrame(clf.get_score(importance_type="total_gain").items(), columns =["Features", "Fold_"+str(i+1)])
    else:
        feature_importance_df["Fold_"+str(i+1)] = list(clf.get_score(importance_type="total_gain").values())
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-mlogloss:4.85655	eval-mlogloss:4.87084
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:4.60652	eval-mlogloss:4.62939
# [2]	train-mlogloss:4.4208	eval-mlogloss:4.45335
# [3]	train-mlogloss:4.27015	eval-mlogloss:4.31074
# [4]	train-mlogloss:4.14351	eval-mlogloss:4.18932
# [5]	train-mlogloss:4.03541	eval-mlogloss:4.08796
# [6]	train-mlogloss:3.93892	eval-mlogloss:3.99663
# [7]	train-mlogloss:3.85417	eval-mlogloss:3.91821
# [8]	train-mlogloss:3.77732	eval-mlogloss:3.84891
# [9]	train-mlogloss:3.70725	eval-mlogloss:3.78425
# [10]	train-mlogloss:3.6423	eval-mlogloss:3.72545
# [11]	train-mlogloss:3.58315	eval-mlogloss:3.67302
# [12]	train-mlogloss:3.52881	eval-mlogloss:3.62369
# [13]	train-mlogloss:3.47855	eval-mlogloss:3.57821
# [14]	train-mlogloss:3.43082	eval-mlogloss:3.53644
# [15]	train-mlogloss:3.38635	eval-mlogloss:3.49786
# [16]	train-mlogloss:3.34448	eval-mlogloss:3.46154
# [17]	train-mlogloss:3.30513	eval-mlogloss:3.42731
# [18]	train-mlogloss:3.26701	eval-mlogloss:3.39522
# [19]	train-mlogloss:3.23131	eval-mlogloss:3.36513
# [20]	train-mlogloss:3.19741	eval-mlogloss:3.33584
# [21]	train-mlogloss:3.16471	eval-mlogloss:3.3095
# [22]	train-mlogloss:3.13335	eval-mlogloss:3.28396
# [23]	train-mlogloss:3.10339	eval-mlogloss:3.25969
# [24]	train-mlogloss:3.07505	eval-mlogloss:3.23675
# [25]	train-mlogloss:3.04871	eval-mlogloss:3.21511
# [26]	train-mlogloss:3.02308	eval-mlogloss:3.19502
# [27]	train-mlogloss:2.99841	eval-mlogloss:3.17525
# [28]	train-mlogloss:2.97468	eval-mlogloss:3.15687
# [29]	train-mlogloss:2.95196	eval-mlogloss:3.13897
# [30]	train-mlogloss:2.9299	eval-mlogloss:3.12168
# [31]	train-mlogloss:2.90902	eval-mlogloss:3.1057
# [32]	train-mlogloss:2.88836	eval-mlogloss:3.09006
# [33]	train-mlogloss:2.86814	eval-mlogloss:3.07469
# [34]	train-mlogloss:2.84906	eval-mlogloss:3.06017
# [35]	train-mlogloss:2.83065	eval-mlogloss:3.04659
# [36]	train-mlogloss:2.81254	eval-mlogloss:3.03325
# [37]	train-mlogloss:2.79476	eval-mlogloss:3.02073
# [38]	train-mlogloss:2.77806	eval-mlogloss:3.00862
# [39]	train-mlogloss:2.76212	eval-mlogloss:2.99713
# [40]	train-mlogloss:2.7463	eval-mlogloss:2.98584
# [41]	train-mlogloss:2.7313	eval-mlogloss:2.97507
# [42]	train-mlogloss:2.71617	eval-mlogloss:2.96473
# [43]	train-mlogloss:2.70152	eval-mlogloss:2.95477
# [44]	train-mlogloss:2.68759	eval-mlogloss:2.94494
# [45]	train-mlogloss:2.67367	eval-mlogloss:2.93529
# [46]	train-mlogloss:2.66057	eval-mlogloss:2.92636
# [47]	train-mlogloss:2.64745	eval-mlogloss:2.91786
# [48]	train-mlogloss:2.63435	eval-mlogloss:2.90916
# [49]	train-mlogloss:2.62157	eval-mlogloss:2.90115
# [50]	train-mlogloss:2.60968	eval-mlogloss:2.89377
# [51]	train-mlogloss:2.59785	eval-mlogloss:2.88623
# [52]	train-mlogloss:2.58621	eval-mlogloss:2.87922
# [53]	train-mlogloss:2.57458	eval-mlogloss:2.87164
# [54]	train-mlogloss:2.56385	eval-mlogloss:2.86503
# [55]	train-mlogloss:2.55277	eval-mlogloss:2.85834
# [56]	train-mlogloss:2.54257	eval-mlogloss:2.85188
# [57]	train-mlogloss:2.53245	eval-mlogloss:2.84579
# [58]	train-mlogloss:2.52244	eval-mlogloss:2.83962
# [59]	train-mlogloss:2.51251	eval-mlogloss:2.83393
# [60]	train-mlogloss:2.50292	eval-mlogloss:2.82838
# [61]	train-mlogloss:2.49346	eval-mlogloss:2.82301
# [62]	train-mlogloss:2.48377	eval-mlogloss:2.81805
# [63]	train-mlogloss:2.4748	eval-mlogloss:2.81325
# [64]	train-mlogloss:2.46585	eval-mlogloss:2.8083
# [65]	train-mlogloss:2.45708	eval-mlogloss:2.80378
# [66]	train-mlogloss:2.44847	eval-mlogloss:2.79921
# [67]	train-mlogloss:2.43991	eval-mlogloss:2.79492
# [68]	train-mlogloss:2.43131	eval-mlogloss:2.79028
# [69]	train-mlogloss:2.42336	eval-mlogloss:2.78656
# [70]	train-mlogloss:2.41558	eval-mlogloss:2.78266
# [71]	train-mlogloss:2.40821	eval-mlogloss:2.77929
# [72]	train-mlogloss:2.40061	eval-mlogloss:2.77571
# [73]	train-mlogloss:2.39342	eval-mlogloss:2.77235
# [74]	train-mlogloss:2.38629	eval-mlogloss:2.76902
# [75]	train-mlogloss:2.37923	eval-mlogloss:2.76575
# [76]	train-mlogloss:2.37227	eval-mlogloss:2.76253
# [77]	train-mlogloss:2.36525	eval-mlogloss:2.75926
# [78]	train-mlogloss:2.35861	eval-mlogloss:2.75624
# [79]	train-mlogloss:2.35193	eval-mlogloss:2.75357
# [80]	train-mlogloss:2.34496	eval-mlogloss:2.75057
# [81]	train-mlogloss:2.33882	eval-mlogloss:2.74801
# [82]	train-mlogloss:2.33219	eval-mlogloss:2.74531
# [83]	train-mlogloss:2.32607	eval-mlogloss:2.74297
# [84]	train-mlogloss:2.32012	eval-mlogloss:2.7406
# [85]	train-mlogloss:2.31418	eval-mlogloss:2.73834
# [86]	train-mlogloss:2.30834	eval-mlogloss:2.73582
# [87]	train-mlogloss:2.30266	eval-mlogloss:2.73368
# [88]	train-mlogloss:2.29674	eval-mlogloss:2.73164
# [89]	train-mlogloss:2.29097	eval-mlogloss:2.7294
# [90]	train-mlogloss:2.28506	eval-mlogloss:2.7274
# [91]	train-mlogloss:2.27971	eval-mlogloss:2.72545
# [92]	train-mlogloss:2.27403	eval-mlogloss:2.72378
# [93]	train-mlogloss:2.26862	eval-mlogloss:2.72198
# [94]	train-mlogloss:2.26311	eval-mlogloss:2.72011
# [95]	train-mlogloss:2.25796	eval-mlogloss:2.71847
# [96]	train-mlogloss:2.25303	eval-mlogloss:2.71678
# [97]	train-mlogloss:2.24739	eval-mlogloss:2.71498
# [98]	train-mlogloss:2.2426	eval-mlogloss:2.71337
# [99]	train-mlogloss:2.23781	eval-mlogloss:2.71202
# [100]	train-mlogloss:2.23266	eval-mlogloss:2.71052
# [101]	train-mlogloss:2.22778	eval-mlogloss:2.70921
# [102]	train-mlogloss:2.22316	eval-mlogloss:2.7077
# [103]	train-mlogloss:2.21876	eval-mlogloss:2.70633
# [104]	train-mlogloss:2.214	eval-mlogloss:2.70493
# [105]	train-mlogloss:2.20921	eval-mlogloss:2.70362
# [106]	train-mlogloss:2.2049	eval-mlogloss:2.70246
# [107]	train-mlogloss:2.20036	eval-mlogloss:2.70133
# [108]	train-mlogloss:2.19622	eval-mlogloss:2.70027
# [109]	train-mlogloss:2.1917	eval-mlogloss:2.69913
# [110]	train-mlogloss:2.18765	eval-mlogloss:2.69799
# [111]	train-mlogloss:2.1835	eval-mlogloss:2.69707
# [112]	train-mlogloss:2.17957	eval-mlogloss:2.69605
# [113]	train-mlogloss:2.17553	eval-mlogloss:2.69502
# [114]	train-mlogloss:2.17114	eval-mlogloss:2.69392
# [115]	train-mlogloss:2.16697	eval-mlogloss:2.69317
# [116]	train-mlogloss:2.16306	eval-mlogloss:2.69232
# [117]	train-mlogloss:2.1592	eval-mlogloss:2.69153
# [118]	train-mlogloss:2.15529	eval-mlogloss:2.69089
# [119]	train-mlogloss:2.15151	eval-mlogloss:2.69021
# [120]	train-mlogloss:2.1476	eval-mlogloss:2.68949
# [121]	train-mlogloss:2.14388	eval-mlogloss:2.68877
# [122]	train-mlogloss:2.14059	eval-mlogloss:2.68806
# [123]	train-mlogloss:2.13695	eval-mlogloss:2.68737
# [124]	train-mlogloss:2.13314	eval-mlogloss:2.6869
# [125]	train-mlogloss:2.12953	eval-mlogloss:2.68618
# [126]	train-mlogloss:2.12626	eval-mlogloss:2.68561
# [127]	train-mlogloss:2.12272	eval-mlogloss:2.68499
# [128]	train-mlogloss:2.11935	eval-mlogloss:2.68446
# [129]	train-mlogloss:2.1156	eval-mlogloss:2.68368
# [130]	train-mlogloss:2.11222	eval-mlogloss:2.6833
# [131]	train-mlogloss:2.10901	eval-mlogloss:2.68281
# [132]	train-mlogloss:2.10545	eval-mlogloss:2.68216
# [133]	train-mlogloss:2.1024	eval-mlogloss:2.68177
# [134]	train-mlogloss:2.09896	eval-mlogloss:2.68157
# [135]	train-mlogloss:2.09577	eval-mlogloss:2.68099
# [136]	train-mlogloss:2.0923	eval-mlogloss:2.68072
# [137]	train-mlogloss:2.08894	eval-mlogloss:2.68016
# [138]	train-mlogloss:2.08575	eval-mlogloss:2.67994
# [139]	train-mlogloss:2.08263	eval-mlogloss:2.67945
# [140]	train-mlogloss:2.07951	eval-mlogloss:2.67927
# [141]	train-mlogloss:2.07685	eval-mlogloss:2.67879
# [142]	train-mlogloss:2.07396	eval-mlogloss:2.67845
# [143]	train-mlogloss:2.07053	eval-mlogloss:2.67811
# [144]	train-mlogloss:2.06727	eval-mlogloss:2.67779
# [145]	train-mlogloss:2.06412	eval-mlogloss:2.67774
# [146]	train-mlogloss:2.06152	eval-mlogloss:2.67744
# [147]	train-mlogloss:2.05856	eval-mlogloss:2.67723
# [148]	train-mlogloss:2.05571	eval-mlogloss:2.67698
# [149]	train-mlogloss:2.05243	eval-mlogloss:2.67683
# [150]	train-mlogloss:2.04941	eval-mlogloss:2.67653
# [151]	train-mlogloss:2.0465	eval-mlogloss:2.67625
# [152]	train-mlogloss:2.04369	eval-mlogloss:2.67608
# [153]	train-mlogloss:2.04068	eval-mlogloss:2.67595
# [154]	train-mlogloss:2.03789	eval-mlogloss:2.67578
# [155]	train-mlogloss:2.03514	eval-mlogloss:2.67549
# [156]	train-mlogloss:2.03232	eval-mlogloss:2.67542
# [157]	train-mlogloss:2.02945	eval-mlogloss:2.67534
# [158]	train-mlogloss:2.02694	eval-mlogloss:2.67518
# [159]	train-mlogloss:2.02412	eval-mlogloss:2.67499
# [160]	train-mlogloss:2.02129	eval-mlogloss:2.67485
# [161]	train-mlogloss:2.01839	eval-mlogloss:2.67477
# [162]	train-mlogloss:2.01561	eval-mlogloss:2.6747
# [163]	train-mlogloss:2.01283	eval-mlogloss:2.67457
# [164]	train-mlogloss:2.01013	eval-mlogloss:2.67458
# [165]	train-mlogloss:2.0077	eval-mlogloss:2.6744
# [166]	train-mlogloss:2.00519	eval-mlogloss:2.67446
# [167]	train-mlogloss:2.00252	eval-mlogloss:2.67463
# [168]	train-mlogloss:2.00028	eval-mlogloss:2.67468
# [169]	train-mlogloss:1.99772	eval-mlogloss:2.67461
# [170]	train-mlogloss:1.9952	eval-mlogloss:2.67462
# [171]	train-mlogloss:1.9929	eval-mlogloss:2.67456
# [172]	train-mlogloss:1.99043	eval-mlogloss:2.6744
# [173]	train-mlogloss:1.98791	eval-mlogloss:2.67443
# [174]	train-mlogloss:1.9855	eval-mlogloss:2.67458
# [175]	train-mlogloss:1.98297	eval-mlogloss:2.6747
# Stopping. Best iteration:
# [165]	train-mlogloss:2.0077	eval-mlogloss:2.6744
#
# 0.012261196553920611
# [0]	train-mlogloss:4.85844	eval-mlogloss:4.86391
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:4.60821	eval-mlogloss:4.61811
# [2]	train-mlogloss:4.42307	eval-mlogloss:4.44036
# [3]	train-mlogloss:4.27296	eval-mlogloss:4.29322
# [4]	train-mlogloss:4.1471	eval-mlogloss:4.17265
# [5]	train-mlogloss:4.03854	eval-mlogloss:4.07069
# [6]	train-mlogloss:3.94306	eval-mlogloss:3.98081
# [7]	train-mlogloss:3.85742	eval-mlogloss:3.90247
# [8]	train-mlogloss:3.78103	eval-mlogloss:3.83233
# [9]	train-mlogloss:3.71089	eval-mlogloss:3.7689
# [10]	train-mlogloss:3.64655	eval-mlogloss:3.71059
# [11]	train-mlogloss:3.58738	eval-mlogloss:3.65745
# [12]	train-mlogloss:3.53284	eval-mlogloss:3.60917
# [13]	train-mlogloss:3.48172	eval-mlogloss:3.56298
# [14]	train-mlogloss:3.43365	eval-mlogloss:3.52083
# [15]	train-mlogloss:3.38899	eval-mlogloss:3.48118
# [16]	train-mlogloss:3.34664	eval-mlogloss:3.44478
# [17]	train-mlogloss:3.30709	eval-mlogloss:3.41065
# [18]	train-mlogloss:3.26973	eval-mlogloss:3.37865
# [19]	train-mlogloss:3.23317	eval-mlogloss:3.34821
# [20]	train-mlogloss:3.1985	eval-mlogloss:3.31989
# [21]	train-mlogloss:3.16637	eval-mlogloss:3.29306
# [22]	train-mlogloss:3.13502	eval-mlogloss:3.26689
# [23]	train-mlogloss:3.10551	eval-mlogloss:3.24273
# [24]	train-mlogloss:3.07707	eval-mlogloss:3.2199
# [25]	train-mlogloss:3.0502	eval-mlogloss:3.1987
# [26]	train-mlogloss:3.02418	eval-mlogloss:3.17789
# [27]	train-mlogloss:2.99934	eval-mlogloss:3.15842
# [28]	train-mlogloss:2.97472	eval-mlogloss:3.13938
# [29]	train-mlogloss:2.95227	eval-mlogloss:3.12156
# [30]	train-mlogloss:2.92958	eval-mlogloss:3.10418
# [31]	train-mlogloss:2.90802	eval-mlogloss:3.08773
# [32]	train-mlogloss:2.88734	eval-mlogloss:3.07202
# [33]	train-mlogloss:2.86785	eval-mlogloss:3.05686
# [34]	train-mlogloss:2.84841	eval-mlogloss:3.04287
# [35]	train-mlogloss:2.83041	eval-mlogloss:3.02933
# [36]	train-mlogloss:2.81234	eval-mlogloss:3.01648
# [37]	train-mlogloss:2.79454	eval-mlogloss:3.00407
# [38]	train-mlogloss:2.77768	eval-mlogloss:2.99218
# [39]	train-mlogloss:2.76143	eval-mlogloss:2.98055
# [40]	train-mlogloss:2.7454	eval-mlogloss:2.9692
# [41]	train-mlogloss:2.72981	eval-mlogloss:2.95831
# [42]	train-mlogloss:2.71465	eval-mlogloss:2.94802
# [43]	train-mlogloss:2.70011	eval-mlogloss:2.93791
# [44]	train-mlogloss:2.6859	eval-mlogloss:2.92828
# [45]	train-mlogloss:2.67192	eval-mlogloss:2.91927
# [46]	train-mlogloss:2.65844	eval-mlogloss:2.91052
# [47]	train-mlogloss:2.64519	eval-mlogloss:2.90196
# [48]	train-mlogloss:2.6321	eval-mlogloss:2.89372
# [49]	train-mlogloss:2.61996	eval-mlogloss:2.88567
# [50]	train-mlogloss:2.60748	eval-mlogloss:2.87816
# [51]	train-mlogloss:2.59549	eval-mlogloss:2.87093
# [52]	train-mlogloss:2.58445	eval-mlogloss:2.86367
# [53]	train-mlogloss:2.57302	eval-mlogloss:2.85674
# [54]	train-mlogloss:2.56269	eval-mlogloss:2.85012
# [55]	train-mlogloss:2.55198	eval-mlogloss:2.84368
# [56]	train-mlogloss:2.54155	eval-mlogloss:2.8372
# [57]	train-mlogloss:2.53143	eval-mlogloss:2.83146
# [58]	train-mlogloss:2.52128	eval-mlogloss:2.82563
# [59]	train-mlogloss:2.51152	eval-mlogloss:2.82021
# [60]	train-mlogloss:2.50207	eval-mlogloss:2.81487
# [61]	train-mlogloss:2.49272	eval-mlogloss:2.80993
# [62]	train-mlogloss:2.48353	eval-mlogloss:2.80499
# [63]	train-mlogloss:2.4746	eval-mlogloss:2.79997
# [64]	train-mlogloss:2.46563	eval-mlogloss:2.79527
# [65]	train-mlogloss:2.4571	eval-mlogloss:2.79084
# [66]	train-mlogloss:2.44866	eval-mlogloss:2.78633
# [67]	train-mlogloss:2.44032	eval-mlogloss:2.78209
# [68]	train-mlogloss:2.43212	eval-mlogloss:2.77788
# [69]	train-mlogloss:2.4238	eval-mlogloss:2.77396
# [70]	train-mlogloss:2.41627	eval-mlogloss:2.77004
# [71]	train-mlogloss:2.4086	eval-mlogloss:2.76623
# [72]	train-mlogloss:2.40123	eval-mlogloss:2.76281
# [73]	train-mlogloss:2.39391	eval-mlogloss:2.75941
# [74]	train-mlogloss:2.38647	eval-mlogloss:2.756
# [75]	train-mlogloss:2.37948	eval-mlogloss:2.75256
# [76]	train-mlogloss:2.37248	eval-mlogloss:2.74952
# [77]	train-mlogloss:2.36598	eval-mlogloss:2.74657
# [78]	train-mlogloss:2.35935	eval-mlogloss:2.74335
# [79]	train-mlogloss:2.35262	eval-mlogloss:2.7404
# [80]	train-mlogloss:2.34633	eval-mlogloss:2.73775
# [81]	train-mlogloss:2.33996	eval-mlogloss:2.73494
# [82]	train-mlogloss:2.33385	eval-mlogloss:2.7324
# [83]	train-mlogloss:2.32783	eval-mlogloss:2.72996
# [84]	train-mlogloss:2.32176	eval-mlogloss:2.72732
# [85]	train-mlogloss:2.31563	eval-mlogloss:2.72518
# [86]	train-mlogloss:2.30971	eval-mlogloss:2.72303
# [87]	train-mlogloss:2.30374	eval-mlogloss:2.72075
# [88]	train-mlogloss:2.29792	eval-mlogloss:2.71868
# [89]	train-mlogloss:2.29248	eval-mlogloss:2.71654
# [90]	train-mlogloss:2.28701	eval-mlogloss:2.71454
# [91]	train-mlogloss:2.28157	eval-mlogloss:2.7124
# [92]	train-mlogloss:2.27642	eval-mlogloss:2.71041
# [93]	train-mlogloss:2.27106	eval-mlogloss:2.70853
# [94]	train-mlogloss:2.26573	eval-mlogloss:2.70667
# [95]	train-mlogloss:2.26049	eval-mlogloss:2.70501
# [96]	train-mlogloss:2.25523	eval-mlogloss:2.70325
# [97]	train-mlogloss:2.25025	eval-mlogloss:2.70131
# [98]	train-mlogloss:2.24513	eval-mlogloss:2.69976
# [99]	train-mlogloss:2.24	eval-mlogloss:2.69808
# [100]	train-mlogloss:2.23509	eval-mlogloss:2.69661
# [101]	train-mlogloss:2.23021	eval-mlogloss:2.69513
# [102]	train-mlogloss:2.22543	eval-mlogloss:2.6937
# [103]	train-mlogloss:2.22079	eval-mlogloss:2.69241
# [104]	train-mlogloss:2.21633	eval-mlogloss:2.69125
# [105]	train-mlogloss:2.21199	eval-mlogloss:2.69002
# [106]	train-mlogloss:2.20781	eval-mlogloss:2.68891
# [107]	train-mlogloss:2.20358	eval-mlogloss:2.68768
# [108]	train-mlogloss:2.19904	eval-mlogloss:2.68648
# [109]	train-mlogloss:2.19463	eval-mlogloss:2.68547
# [110]	train-mlogloss:2.19053	eval-mlogloss:2.68432
# [111]	train-mlogloss:2.18642	eval-mlogloss:2.6834
# [112]	train-mlogloss:2.18211	eval-mlogloss:2.68253
# [113]	train-mlogloss:2.17786	eval-mlogloss:2.68142
# [114]	train-mlogloss:2.17389	eval-mlogloss:2.68058
# [115]	train-mlogloss:2.16989	eval-mlogloss:2.67961
# [116]	train-mlogloss:2.16599	eval-mlogloss:2.67868
# [117]	train-mlogloss:2.16213	eval-mlogloss:2.67794
# [118]	train-mlogloss:2.15845	eval-mlogloss:2.67707
# [119]	train-mlogloss:2.15442	eval-mlogloss:2.67605
# [120]	train-mlogloss:2.15076	eval-mlogloss:2.67506
# [121]	train-mlogloss:2.14694	eval-mlogloss:2.67441
# [122]	train-mlogloss:2.14339	eval-mlogloss:2.67364
# [123]	train-mlogloss:2.13978	eval-mlogloss:2.67297
# [124]	train-mlogloss:2.13587	eval-mlogloss:2.67228
# [125]	train-mlogloss:2.1325	eval-mlogloss:2.67153
# [126]	train-mlogloss:2.12894	eval-mlogloss:2.67088
# [127]	train-mlogloss:2.1254	eval-mlogloss:2.67017
# [128]	train-mlogloss:2.1221	eval-mlogloss:2.6696
# [129]	train-mlogloss:2.11857	eval-mlogloss:2.66889
# [130]	train-mlogloss:2.11536	eval-mlogloss:2.66837
# [131]	train-mlogloss:2.11221	eval-mlogloss:2.66783
# [132]	train-mlogloss:2.10899	eval-mlogloss:2.66741
# [133]	train-mlogloss:2.1055	eval-mlogloss:2.66697
# [134]	train-mlogloss:2.10199	eval-mlogloss:2.66655
# [135]	train-mlogloss:2.09854	eval-mlogloss:2.66615
# [136]	train-mlogloss:2.09526	eval-mlogloss:2.66592
# [137]	train-mlogloss:2.09207	eval-mlogloss:2.66545
# [138]	train-mlogloss:2.08907	eval-mlogloss:2.66513
# [139]	train-mlogloss:2.08609	eval-mlogloss:2.66469
# [140]	train-mlogloss:2.08313	eval-mlogloss:2.66445
# [141]	train-mlogloss:2.08001	eval-mlogloss:2.66405
# [142]	train-mlogloss:2.07686	eval-mlogloss:2.66369
# [143]	train-mlogloss:2.07356	eval-mlogloss:2.66347
# [144]	train-mlogloss:2.07054	eval-mlogloss:2.66317
# [145]	train-mlogloss:2.06734	eval-mlogloss:2.66295
# [146]	train-mlogloss:2.06418	eval-mlogloss:2.66247
# [147]	train-mlogloss:2.06129	eval-mlogloss:2.66229
# [148]	train-mlogloss:2.05823	eval-mlogloss:2.6621
# [149]	train-mlogloss:2.0555	eval-mlogloss:2.66179
# [150]	train-mlogloss:2.05281	eval-mlogloss:2.66141
# [151]	train-mlogloss:2.04976	eval-mlogloss:2.66115
# [152]	train-mlogloss:2.04693	eval-mlogloss:2.66119
# [153]	train-mlogloss:2.04444	eval-mlogloss:2.66106
# [154]	train-mlogloss:2.04172	eval-mlogloss:2.66082
# [155]	train-mlogloss:2.03872	eval-mlogloss:2.66076
# [156]	train-mlogloss:2.03597	eval-mlogloss:2.66069
# [157]	train-mlogloss:2.03327	eval-mlogloss:2.66051
# [158]	train-mlogloss:2.03063	eval-mlogloss:2.6601
# [159]	train-mlogloss:2.0279	eval-mlogloss:2.66006
# [160]	train-mlogloss:2.02513	eval-mlogloss:2.66002
# [161]	train-mlogloss:2.02248	eval-mlogloss:2.65986
# [162]	train-mlogloss:2.01987	eval-mlogloss:2.65983
# [163]	train-mlogloss:2.01704	eval-mlogloss:2.65979
# [164]	train-mlogloss:2.01464	eval-mlogloss:2.65964
# [165]	train-mlogloss:2.01193	eval-mlogloss:2.6597
# [166]	train-mlogloss:2.00906	eval-mlogloss:2.6596
# [167]	train-mlogloss:2.00654	eval-mlogloss:2.65946
# [168]	train-mlogloss:2.00382	eval-mlogloss:2.65945
# [169]	train-mlogloss:2.0013	eval-mlogloss:2.65943
# [170]	train-mlogloss:1.99888	eval-mlogloss:2.65939
# [171]	train-mlogloss:1.99638	eval-mlogloss:2.65939
# [172]	train-mlogloss:1.9938	eval-mlogloss:2.65938
# [173]	train-mlogloss:1.99147	eval-mlogloss:2.65934
# [174]	train-mlogloss:1.98913	eval-mlogloss:2.65928
# [175]	train-mlogloss:1.9868	eval-mlogloss:2.65925
# [176]	train-mlogloss:1.9843	eval-mlogloss:2.65926
# [177]	train-mlogloss:1.982	eval-mlogloss:2.65926
# [178]	train-mlogloss:1.97948	eval-mlogloss:2.65932
# [179]	train-mlogloss:1.97665	eval-mlogloss:2.65949
# [180]	train-mlogloss:1.97434	eval-mlogloss:2.65947
# [181]	train-mlogloss:1.97179	eval-mlogloss:2.65949
# [182]	train-mlogloss:1.96923	eval-mlogloss:2.65946
# [183]	train-mlogloss:1.96683	eval-mlogloss:2.65937
# [184]	train-mlogloss:1.96469	eval-mlogloss:2.65935
# [185]	train-mlogloss:1.96237	eval-mlogloss:2.65949
# Stopping. Best iteration:
# [175]	train-mlogloss:1.9868	eval-mlogloss:2.65925
#
# 0.012071131912255782
# [0]	train-mlogloss:4.85371	eval-mlogloss:4.86962
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:4.60015	eval-mlogloss:4.62992
# [2]	train-mlogloss:4.41297	eval-mlogloss:4.45281
# [3]	train-mlogloss:4.26176	eval-mlogloss:4.31081
# [4]	train-mlogloss:4.13521	eval-mlogloss:4.19152
# [5]	train-mlogloss:4.02622	eval-mlogloss:4.09018
# [6]	train-mlogloss:3.93032	eval-mlogloss:4.0022
# [7]	train-mlogloss:3.84413	eval-mlogloss:3.92374
# [8]	train-mlogloss:3.76739	eval-mlogloss:3.85408
# [9]	train-mlogloss:3.69717	eval-mlogloss:3.79074
# [10]	train-mlogloss:3.63253	eval-mlogloss:3.73285
# [11]	train-mlogloss:3.57292	eval-mlogloss:3.6798
# [12]	train-mlogloss:3.51788	eval-mlogloss:3.63082
# [13]	train-mlogloss:3.46638	eval-mlogloss:3.58567
# [14]	train-mlogloss:3.41881	eval-mlogloss:3.54382
# [15]	train-mlogloss:3.37432	eval-mlogloss:3.50527
# [16]	train-mlogloss:3.33195	eval-mlogloss:3.46882
# [17]	train-mlogloss:3.29255	eval-mlogloss:3.43491
# [18]	train-mlogloss:3.25462	eval-mlogloss:3.40235
# [19]	train-mlogloss:3.21891	eval-mlogloss:3.37224
# [20]	train-mlogloss:3.18456	eval-mlogloss:3.34428
# [21]	train-mlogloss:3.15238	eval-mlogloss:3.31767
# [22]	train-mlogloss:3.12164	eval-mlogloss:3.29211
# [23]	train-mlogloss:3.09206	eval-mlogloss:3.26826
# [24]	train-mlogloss:3.0635	eval-mlogloss:3.24591
# [25]	train-mlogloss:3.03623	eval-mlogloss:3.22437
# [26]	train-mlogloss:3.01022	eval-mlogloss:3.20383
# [27]	train-mlogloss:2.98526	eval-mlogloss:3.18463
# [28]	train-mlogloss:2.9616	eval-mlogloss:3.16629
# [29]	train-mlogloss:2.93918	eval-mlogloss:3.14864
# [30]	train-mlogloss:2.91648	eval-mlogloss:3.13118
# [31]	train-mlogloss:2.89492	eval-mlogloss:3.11506
# [32]	train-mlogloss:2.87458	eval-mlogloss:3.09962
# [33]	train-mlogloss:2.85493	eval-mlogloss:3.08488
# [34]	train-mlogloss:2.83542	eval-mlogloss:3.07088
# [35]	train-mlogloss:2.81711	eval-mlogloss:3.05743
# [36]	train-mlogloss:2.79874	eval-mlogloss:3.04435
# [37]	train-mlogloss:2.78093	eval-mlogloss:3.03212
# [38]	train-mlogloss:2.76435	eval-mlogloss:3.01995
# [39]	train-mlogloss:2.74776	eval-mlogloss:3.00858
# [40]	train-mlogloss:2.73167	eval-mlogloss:2.9975
# [41]	train-mlogloss:2.71628	eval-mlogloss:2.98682
# [42]	train-mlogloss:2.70122	eval-mlogloss:2.97661
# [43]	train-mlogloss:2.68635	eval-mlogloss:2.96681
# [44]	train-mlogloss:2.67204	eval-mlogloss:2.95729
# [45]	train-mlogloss:2.6582	eval-mlogloss:2.94809
# [46]	train-mlogloss:2.64479	eval-mlogloss:2.93915
# [47]	train-mlogloss:2.63145	eval-mlogloss:2.93063
# [48]	train-mlogloss:2.6189	eval-mlogloss:2.92261
# [49]	train-mlogloss:2.60647	eval-mlogloss:2.91467
# [50]	train-mlogloss:2.59412	eval-mlogloss:2.90679
# [51]	train-mlogloss:2.58163	eval-mlogloss:2.89917
# [52]	train-mlogloss:2.57026	eval-mlogloss:2.89182
# [53]	train-mlogloss:2.55862	eval-mlogloss:2.88507
# [54]	train-mlogloss:2.54776	eval-mlogloss:2.8784
# [55]	train-mlogloss:2.53727	eval-mlogloss:2.87215
# [56]	train-mlogloss:2.52684	eval-mlogloss:2.86572
# [57]	train-mlogloss:2.51609	eval-mlogloss:2.85956
# [58]	train-mlogloss:2.50567	eval-mlogloss:2.85369
# [59]	train-mlogloss:2.49607	eval-mlogloss:2.84801
# [60]	train-mlogloss:2.48638	eval-mlogloss:2.8427
# [61]	train-mlogloss:2.47679	eval-mlogloss:2.83731
# [62]	train-mlogloss:2.46727	eval-mlogloss:2.83207
# [63]	train-mlogloss:2.45844	eval-mlogloss:2.82719
# [64]	train-mlogloss:2.44972	eval-mlogloss:2.82234
# [65]	train-mlogloss:2.44097	eval-mlogloss:2.81771
# [66]	train-mlogloss:2.43208	eval-mlogloss:2.81334
# [67]	train-mlogloss:2.42372	eval-mlogloss:2.80898
# [68]	train-mlogloss:2.41518	eval-mlogloss:2.80466
# [69]	train-mlogloss:2.40702	eval-mlogloss:2.80049
# [70]	train-mlogloss:2.39941	eval-mlogloss:2.79643
# [71]	train-mlogloss:2.39158	eval-mlogloss:2.79255
# [72]	train-mlogloss:2.3841	eval-mlogloss:2.78886
# [73]	train-mlogloss:2.37651	eval-mlogloss:2.78543
# [74]	train-mlogloss:2.36919	eval-mlogloss:2.78206
# [75]	train-mlogloss:2.36247	eval-mlogloss:2.77866
# [76]	train-mlogloss:2.35548	eval-mlogloss:2.77545
# [77]	train-mlogloss:2.34859	eval-mlogloss:2.77205
# [78]	train-mlogloss:2.34171	eval-mlogloss:2.76894
# [79]	train-mlogloss:2.33495	eval-mlogloss:2.76607
# [80]	train-mlogloss:2.32842	eval-mlogloss:2.76334
# [81]	train-mlogloss:2.3219	eval-mlogloss:2.76046
# [82]	train-mlogloss:2.31548	eval-mlogloss:2.75783
# [83]	train-mlogloss:2.30941	eval-mlogloss:2.75511
# [84]	train-mlogloss:2.30314	eval-mlogloss:2.75268
# [85]	train-mlogloss:2.29728	eval-mlogloss:2.75029
# [86]	train-mlogloss:2.29153	eval-mlogloss:2.74771
# [87]	train-mlogloss:2.2852	eval-mlogloss:2.74536
# [88]	train-mlogloss:2.27925	eval-mlogloss:2.74283
# [89]	train-mlogloss:2.27354	eval-mlogloss:2.74077
# [90]	train-mlogloss:2.26781	eval-mlogloss:2.73866
# [91]	train-mlogloss:2.26234	eval-mlogloss:2.73644
# [92]	train-mlogloss:2.25683	eval-mlogloss:2.73447
# [93]	train-mlogloss:2.25117	eval-mlogloss:2.73234
# [94]	train-mlogloss:2.24541	eval-mlogloss:2.73037
# [95]	train-mlogloss:2.23977	eval-mlogloss:2.72862
# [96]	train-mlogloss:2.23458	eval-mlogloss:2.72683
# [97]	train-mlogloss:2.22972	eval-mlogloss:2.72514
# [98]	train-mlogloss:2.22466	eval-mlogloss:2.72344
# [99]	train-mlogloss:2.21967	eval-mlogloss:2.72181
# [100]	train-mlogloss:2.21474	eval-mlogloss:2.7202
# [101]	train-mlogloss:2.20999	eval-mlogloss:2.71863
# [102]	train-mlogloss:2.20523	eval-mlogloss:2.71701
# [103]	train-mlogloss:2.20044	eval-mlogloss:2.71567
# [104]	train-mlogloss:2.19571	eval-mlogloss:2.7143
# [105]	train-mlogloss:2.19089	eval-mlogloss:2.713
# [106]	train-mlogloss:2.18646	eval-mlogloss:2.7117
# [107]	train-mlogloss:2.18218	eval-mlogloss:2.71036
# [108]	train-mlogloss:2.17788	eval-mlogloss:2.70895
# [109]	train-mlogloss:2.17331	eval-mlogloss:2.70768
# [110]	train-mlogloss:2.16873	eval-mlogloss:2.70647
# [111]	train-mlogloss:2.16447	eval-mlogloss:2.70544
# [112]	train-mlogloss:2.16033	eval-mlogloss:2.70426
# [113]	train-mlogloss:2.15591	eval-mlogloss:2.70315
# [114]	train-mlogloss:2.1517	eval-mlogloss:2.702
# [115]	train-mlogloss:2.14775	eval-mlogloss:2.701
# [116]	train-mlogloss:2.14372	eval-mlogloss:2.69993
# [117]	train-mlogloss:2.13984	eval-mlogloss:2.69904
# [118]	train-mlogloss:2.13593	eval-mlogloss:2.69797
# [119]	train-mlogloss:2.13186	eval-mlogloss:2.69711
# [120]	train-mlogloss:2.1278	eval-mlogloss:2.69608
# [121]	train-mlogloss:2.12412	eval-mlogloss:2.69515
# [122]	train-mlogloss:2.12036	eval-mlogloss:2.69441
# [123]	train-mlogloss:2.11644	eval-mlogloss:2.69347
# [124]	train-mlogloss:2.11281	eval-mlogloss:2.69283
# [125]	train-mlogloss:2.10909	eval-mlogloss:2.69201
# [126]	train-mlogloss:2.10547	eval-mlogloss:2.69118
# [127]	train-mlogloss:2.10194	eval-mlogloss:2.69057
# [128]	train-mlogloss:2.09838	eval-mlogloss:2.68998
# [129]	train-mlogloss:2.0948	eval-mlogloss:2.68924
# [130]	train-mlogloss:2.09149	eval-mlogloss:2.68832
# [131]	train-mlogloss:2.08816	eval-mlogloss:2.68779
# [132]	train-mlogloss:2.08467	eval-mlogloss:2.68727
# [133]	train-mlogloss:2.08164	eval-mlogloss:2.68675
# [134]	train-mlogloss:2.07823	eval-mlogloss:2.68639
# [135]	train-mlogloss:2.07489	eval-mlogloss:2.68578
# [136]	train-mlogloss:2.07208	eval-mlogloss:2.68512
# [137]	train-mlogloss:2.06882	eval-mlogloss:2.68463
# [138]	train-mlogloss:2.06562	eval-mlogloss:2.68417
# [139]	train-mlogloss:2.06227	eval-mlogloss:2.68343
# [140]	train-mlogloss:2.05906	eval-mlogloss:2.68311
# [141]	train-mlogloss:2.05567	eval-mlogloss:2.68274
# [142]	train-mlogloss:2.05216	eval-mlogloss:2.6823
# [143]	train-mlogloss:2.04898	eval-mlogloss:2.68191
# [144]	train-mlogloss:2.04641	eval-mlogloss:2.68176
# [145]	train-mlogloss:2.0434	eval-mlogloss:2.68131
# [146]	train-mlogloss:2.04052	eval-mlogloss:2.681
# [147]	train-mlogloss:2.03739	eval-mlogloss:2.68063
# [148]	train-mlogloss:2.03434	eval-mlogloss:2.68044
# [149]	train-mlogloss:2.03149	eval-mlogloss:2.68001
# [150]	train-mlogloss:2.02852	eval-mlogloss:2.67971
# [151]	train-mlogloss:2.02575	eval-mlogloss:2.67931
# [152]	train-mlogloss:2.0231	eval-mlogloss:2.67903
# [153]	train-mlogloss:2.02022	eval-mlogloss:2.67863
# [154]	train-mlogloss:2.0174	eval-mlogloss:2.6782
# [155]	train-mlogloss:2.01458	eval-mlogloss:2.67803
# [156]	train-mlogloss:2.01172	eval-mlogloss:2.67797
# [157]	train-mlogloss:2.00886	eval-mlogloss:2.67785
# [158]	train-mlogloss:2.0061	eval-mlogloss:2.67771
# [159]	train-mlogloss:2.0033	eval-mlogloss:2.67752
# [160]	train-mlogloss:2.00064	eval-mlogloss:2.67736
# [161]	train-mlogloss:1.9982	eval-mlogloss:2.67724
# [162]	train-mlogloss:1.99545	eval-mlogloss:2.67693
# [163]	train-mlogloss:1.99314	eval-mlogloss:2.67676
# [164]	train-mlogloss:1.99027	eval-mlogloss:2.67652
# [165]	train-mlogloss:1.98749	eval-mlogloss:2.67634
# [166]	train-mlogloss:1.985	eval-mlogloss:2.67612
# [167]	train-mlogloss:1.98234	eval-mlogloss:2.67604
# [168]	train-mlogloss:1.9799	eval-mlogloss:2.67593
# [169]	train-mlogloss:1.97746	eval-mlogloss:2.67578
# [170]	train-mlogloss:1.97479	eval-mlogloss:2.67589
# [171]	train-mlogloss:1.97232	eval-mlogloss:2.67578
# [172]	train-mlogloss:1.96978	eval-mlogloss:2.67572
# [173]	train-mlogloss:1.96737	eval-mlogloss:2.67587
# [174]	train-mlogloss:1.96498	eval-mlogloss:2.67571
# [175]	train-mlogloss:1.9624	eval-mlogloss:2.67548
# [176]	train-mlogloss:1.95978	eval-mlogloss:2.67532
# [177]	train-mlogloss:1.9573	eval-mlogloss:2.67537
# [178]	train-mlogloss:1.95481	eval-mlogloss:2.67529
# [179]	train-mlogloss:1.95224	eval-mlogloss:2.67541
# [180]	train-mlogloss:1.94992	eval-mlogloss:2.67529
# [181]	train-mlogloss:1.94749	eval-mlogloss:2.6753
# [182]	train-mlogloss:1.94527	eval-mlogloss:2.67531
# [183]	train-mlogloss:1.94261	eval-mlogloss:2.67533
# [184]	train-mlogloss:1.94028	eval-mlogloss:2.67517
# [185]	train-mlogloss:1.93759	eval-mlogloss:2.67534
# [186]	train-mlogloss:1.93588	eval-mlogloss:2.67547
# [187]	train-mlogloss:1.93364	eval-mlogloss:2.67528
# [188]	train-mlogloss:1.93151	eval-mlogloss:2.6753
# [189]	train-mlogloss:1.92957	eval-mlogloss:2.67527
# [190]	train-mlogloss:1.92718	eval-mlogloss:2.67535
# [191]	train-mlogloss:1.92488	eval-mlogloss:2.67544
# [192]	train-mlogloss:1.9223	eval-mlogloss:2.67535
# [193]	train-mlogloss:1.92014	eval-mlogloss:2.67516
# [194]	train-mlogloss:1.91777	eval-mlogloss:2.67518
# [195]	train-mlogloss:1.91577	eval-mlogloss:2.67518
# [196]	train-mlogloss:1.91377	eval-mlogloss:2.67507
# [197]	train-mlogloss:1.91177	eval-mlogloss:2.67511
# [198]	train-mlogloss:1.9097	eval-mlogloss:2.67517
# [199]	train-mlogloss:1.90769	eval-mlogloss:2.67534
# [200]	train-mlogloss:1.90516	eval-mlogloss:2.67545
# [201]	train-mlogloss:1.90293	eval-mlogloss:2.67542
# [202]	train-mlogloss:1.90067	eval-mlogloss:2.67558
# [203]	train-mlogloss:1.89848	eval-mlogloss:2.67557
# [204]	train-mlogloss:1.89652	eval-mlogloss:2.67549
# [205]	train-mlogloss:1.89457	eval-mlogloss:2.67565
# [206]	train-mlogloss:1.89254	eval-mlogloss:2.6757
# Stopping. Best iteration:
# [196]	train-mlogloss:1.91377	eval-mlogloss:2.67507
#
# 0.011744246241396935
# [0]	train-mlogloss:4.84151	eval-mlogloss:4.89908
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:4.58112	eval-mlogloss:4.67416
# [2]	train-mlogloss:4.38983	eval-mlogloss:4.50905
# [3]	train-mlogloss:4.23503	eval-mlogloss:4.37839
# [4]	train-mlogloss:4.10523	eval-mlogloss:4.27035
# [5]	train-mlogloss:3.99344	eval-mlogloss:4.17673
# [6]	train-mlogloss:3.89528	eval-mlogloss:4.09384
# [7]	train-mlogloss:3.80798	eval-mlogloss:4.02032
# [8]	train-mlogloss:3.7298	eval-mlogloss:3.95511
# [9]	train-mlogloss:3.65814	eval-mlogloss:3.89562
# [10]	train-mlogloss:3.59238	eval-mlogloss:3.84245
# [11]	train-mlogloss:3.53214	eval-mlogloss:3.793
# [12]	train-mlogloss:3.47633	eval-mlogloss:3.74714
# [13]	train-mlogloss:3.42421	eval-mlogloss:3.70494
# [14]	train-mlogloss:3.37483	eval-mlogloss:3.66565
# [15]	train-mlogloss:3.3293	eval-mlogloss:3.62959
# [16]	train-mlogloss:3.28666	eval-mlogloss:3.5965
# [17]	train-mlogloss:3.24665	eval-mlogloss:3.56419
# [18]	train-mlogloss:3.20853	eval-mlogloss:3.53402
# [19]	train-mlogloss:3.17215	eval-mlogloss:3.50595
# [20]	train-mlogloss:3.13769	eval-mlogloss:3.4795
# [21]	train-mlogloss:3.10449	eval-mlogloss:3.45422
# [22]	train-mlogloss:3.07391	eval-mlogloss:3.42998
# [23]	train-mlogloss:3.04423	eval-mlogloss:3.40749
# [24]	train-mlogloss:3.01555	eval-mlogloss:3.3861
# [25]	train-mlogloss:2.98793	eval-mlogloss:3.3662
# [26]	train-mlogloss:2.96167	eval-mlogloss:3.34683
# [27]	train-mlogloss:2.93656	eval-mlogloss:3.32834
# [28]	train-mlogloss:2.91227	eval-mlogloss:3.31093
# [29]	train-mlogloss:2.88809	eval-mlogloss:3.29421
# [30]	train-mlogloss:2.86575	eval-mlogloss:3.27864
# [31]	train-mlogloss:2.84403	eval-mlogloss:3.26314
# [32]	train-mlogloss:2.82302	eval-mlogloss:3.24867
# [33]	train-mlogloss:2.80287	eval-mlogloss:3.235
# [34]	train-mlogloss:2.78373	eval-mlogloss:3.22151
# [35]	train-mlogloss:2.76487	eval-mlogloss:3.20847
# [36]	train-mlogloss:2.74712	eval-mlogloss:3.19634
# [37]	train-mlogloss:2.72931	eval-mlogloss:3.18481
# [38]	train-mlogloss:2.71229	eval-mlogloss:3.17338
# [39]	train-mlogloss:2.69576	eval-mlogloss:3.16258
# [40]	train-mlogloss:2.67956	eval-mlogloss:3.15201
# [41]	train-mlogloss:2.66424	eval-mlogloss:3.14203
# [42]	train-mlogloss:2.64926	eval-mlogloss:3.13233
# [43]	train-mlogloss:2.6352	eval-mlogloss:3.12277
# [44]	train-mlogloss:2.62089	eval-mlogloss:3.11398
# [45]	train-mlogloss:2.60671	eval-mlogloss:3.10557
# [46]	train-mlogloss:2.59315	eval-mlogloss:3.09742
# [47]	train-mlogloss:2.58019	eval-mlogloss:3.08941
# [48]	train-mlogloss:2.56737	eval-mlogloss:3.08139
# [49]	train-mlogloss:2.55451	eval-mlogloss:3.07419
# [50]	train-mlogloss:2.54257	eval-mlogloss:3.06707
# [51]	train-mlogloss:2.53105	eval-mlogloss:3.06006
# [52]	train-mlogloss:2.51977	eval-mlogloss:3.05331
# [53]	train-mlogloss:2.50841	eval-mlogloss:3.04718
# [54]	train-mlogloss:2.49718	eval-mlogloss:3.04076
# [55]	train-mlogloss:2.48676	eval-mlogloss:3.03482
# [56]	train-mlogloss:2.47603	eval-mlogloss:3.02896
# [57]	train-mlogloss:2.46581	eval-mlogloss:3.02355
# [58]	train-mlogloss:2.45553	eval-mlogloss:3.0181
# [59]	train-mlogloss:2.44581	eval-mlogloss:3.01276
# [60]	train-mlogloss:2.43618	eval-mlogloss:3.00764
# [61]	train-mlogloss:2.42672	eval-mlogloss:3.00265
# [62]	train-mlogloss:2.41758	eval-mlogloss:2.99783
# [63]	train-mlogloss:2.4085	eval-mlogloss:2.99312
# [64]	train-mlogloss:2.3996	eval-mlogloss:2.98869
# [65]	train-mlogloss:2.39064	eval-mlogloss:2.98443
# [66]	train-mlogloss:2.38193	eval-mlogloss:2.98027
# [67]	train-mlogloss:2.37392	eval-mlogloss:2.97636
# [68]	train-mlogloss:2.36549	eval-mlogloss:2.97227
# [69]	train-mlogloss:2.35771	eval-mlogloss:2.96847
# [70]	train-mlogloss:2.34998	eval-mlogloss:2.96498
# [71]	train-mlogloss:2.34204	eval-mlogloss:2.96151
# [72]	train-mlogloss:2.33424	eval-mlogloss:2.95833
# [73]	train-mlogloss:2.32669	eval-mlogloss:2.95528
# [74]	train-mlogloss:2.31962	eval-mlogloss:2.95213
# [75]	train-mlogloss:2.31243	eval-mlogloss:2.94908
# [76]	train-mlogloss:2.30542	eval-mlogloss:2.94612
# [77]	train-mlogloss:2.29901	eval-mlogloss:2.94339
# [78]	train-mlogloss:2.2922	eval-mlogloss:2.94085
# [79]	train-mlogloss:2.28528	eval-mlogloss:2.93826
# [80]	train-mlogloss:2.27875	eval-mlogloss:2.93574
# [81]	train-mlogloss:2.27254	eval-mlogloss:2.93332
# [82]	train-mlogloss:2.26643	eval-mlogloss:2.93099
# [83]	train-mlogloss:2.26013	eval-mlogloss:2.92873
# [84]	train-mlogloss:2.25388	eval-mlogloss:2.92664
# [85]	train-mlogloss:2.24815	eval-mlogloss:2.92448
# [86]	train-mlogloss:2.24203	eval-mlogloss:2.92258
# [87]	train-mlogloss:2.23634	eval-mlogloss:2.92049
# [88]	train-mlogloss:2.23049	eval-mlogloss:2.91845
# [89]	train-mlogloss:2.2249	eval-mlogloss:2.91669
# [90]	train-mlogloss:2.21927	eval-mlogloss:2.91511
# [91]	train-mlogloss:2.21375	eval-mlogloss:2.91352
# [92]	train-mlogloss:2.20864	eval-mlogloss:2.91178
# [93]	train-mlogloss:2.20298	eval-mlogloss:2.91003
# [94]	train-mlogloss:2.19752	eval-mlogloss:2.9086
# [95]	train-mlogloss:2.19236	eval-mlogloss:2.90707
# [96]	train-mlogloss:2.1876	eval-mlogloss:2.90567
# [97]	train-mlogloss:2.1827	eval-mlogloss:2.90418
# [98]	train-mlogloss:2.17747	eval-mlogloss:2.90275
# [99]	train-mlogloss:2.17285	eval-mlogloss:2.90151
# [100]	train-mlogloss:2.16785	eval-mlogloss:2.90019
# [101]	train-mlogloss:2.163	eval-mlogloss:2.899
# [102]	train-mlogloss:2.15837	eval-mlogloss:2.89781
# [103]	train-mlogloss:2.15371	eval-mlogloss:2.89668
# [104]	train-mlogloss:2.14917	eval-mlogloss:2.89552
# [105]	train-mlogloss:2.14499	eval-mlogloss:2.89433
# [106]	train-mlogloss:2.14046	eval-mlogloss:2.89339
# [107]	train-mlogloss:2.13608	eval-mlogloss:2.89241
# [108]	train-mlogloss:2.13153	eval-mlogloss:2.89137
# [109]	train-mlogloss:2.12728	eval-mlogloss:2.89059
# [110]	train-mlogloss:2.12293	eval-mlogloss:2.88992
# [111]	train-mlogloss:2.11874	eval-mlogloss:2.88894
# [112]	train-mlogloss:2.11482	eval-mlogloss:2.88814
# [113]	train-mlogloss:2.1109	eval-mlogloss:2.88727
# [114]	train-mlogloss:2.10693	eval-mlogloss:2.88663
# [115]	train-mlogloss:2.10281	eval-mlogloss:2.886
# [116]	train-mlogloss:2.09873	eval-mlogloss:2.88532
# [117]	train-mlogloss:2.09496	eval-mlogloss:2.88469
# [118]	train-mlogloss:2.09112	eval-mlogloss:2.88393
# [119]	train-mlogloss:2.08695	eval-mlogloss:2.88331
# [120]	train-mlogloss:2.08317	eval-mlogloss:2.88268
# [121]	train-mlogloss:2.07955	eval-mlogloss:2.88206
# [122]	train-mlogloss:2.07597	eval-mlogloss:2.88146
# [123]	train-mlogloss:2.07268	eval-mlogloss:2.88103
# [124]	train-mlogloss:2.0686	eval-mlogloss:2.88054
# [125]	train-mlogloss:2.06502	eval-mlogloss:2.8802
# [126]	train-mlogloss:2.06133	eval-mlogloss:2.87979
# [127]	train-mlogloss:2.0579	eval-mlogloss:2.87923
# [128]	train-mlogloss:2.05449	eval-mlogloss:2.87872
# [129]	train-mlogloss:2.0513	eval-mlogloss:2.878
# [130]	train-mlogloss:2.04769	eval-mlogloss:2.87776
# [131]	train-mlogloss:2.04422	eval-mlogloss:2.87712
# [132]	train-mlogloss:2.04103	eval-mlogloss:2.87668
# [133]	train-mlogloss:2.03756	eval-mlogloss:2.87627
# [134]	train-mlogloss:2.0341	eval-mlogloss:2.87601
# [135]	train-mlogloss:2.03095	eval-mlogloss:2.87563
# [136]	train-mlogloss:2.02765	eval-mlogloss:2.87531
# [137]	train-mlogloss:2.02433	eval-mlogloss:2.87507
# [138]	train-mlogloss:2.02091	eval-mlogloss:2.87493
# [139]	train-mlogloss:2.01774	eval-mlogloss:2.87472
# [140]	train-mlogloss:2.01449	eval-mlogloss:2.87447
# [141]	train-mlogloss:2.01153	eval-mlogloss:2.87427
# [142]	train-mlogloss:2.0087	eval-mlogloss:2.87392
# [143]	train-mlogloss:2.00545	eval-mlogloss:2.87373
# [144]	train-mlogloss:2.00232	eval-mlogloss:2.87347
# [145]	train-mlogloss:1.99949	eval-mlogloss:2.87328
# [146]	train-mlogloss:1.99655	eval-mlogloss:2.87308
# [147]	train-mlogloss:1.99369	eval-mlogloss:2.873
# [148]	train-mlogloss:1.99089	eval-mlogloss:2.8727
# [149]	train-mlogloss:1.98811	eval-mlogloss:2.87259
# [150]	train-mlogloss:1.98558	eval-mlogloss:2.87236
# [151]	train-mlogloss:1.9828	eval-mlogloss:2.87249
# [152]	train-mlogloss:1.97998	eval-mlogloss:2.87246
# [153]	train-mlogloss:1.9771	eval-mlogloss:2.87238
# [154]	train-mlogloss:1.97424	eval-mlogloss:2.87225
# [155]	train-mlogloss:1.97131	eval-mlogloss:2.87226
# [156]	train-mlogloss:1.9684	eval-mlogloss:2.87219
# [157]	train-mlogloss:1.96581	eval-mlogloss:2.87188
# [158]	train-mlogloss:1.96333	eval-mlogloss:2.87184
# [159]	train-mlogloss:1.96083	eval-mlogloss:2.87178
# [160]	train-mlogloss:1.95829	eval-mlogloss:2.87191
# [161]	train-mlogloss:1.95577	eval-mlogloss:2.87197
# [162]	train-mlogloss:1.95282	eval-mlogloss:2.87199
# [163]	train-mlogloss:1.95008	eval-mlogloss:2.87203
# [164]	train-mlogloss:1.94751	eval-mlogloss:2.87221
# [165]	train-mlogloss:1.94504	eval-mlogloss:2.87212
# [166]	train-mlogloss:1.94253	eval-mlogloss:2.87217
# [167]	train-mlogloss:1.94003	eval-mlogloss:2.87217
# [168]	train-mlogloss:1.93778	eval-mlogloss:2.87223
# [169]	train-mlogloss:1.9351	eval-mlogloss:2.87229
# Stopping. Best iteration:
# [159]	train-mlogloss:1.96083	eval-mlogloss:2.87178
#
# 0.014137257132469196
# [0]	train-mlogloss:4.84204	eval-mlogloss:4.8932
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:4.5811	eval-mlogloss:4.67025
# [2]	train-mlogloss:4.3913	eval-mlogloss:4.5017
# [3]	train-mlogloss:4.23694	eval-mlogloss:4.36648
# [4]	train-mlogloss:4.10792	eval-mlogloss:4.2549
# [5]	train-mlogloss:3.9975	eval-mlogloss:4.15884
# [6]	train-mlogloss:3.89978	eval-mlogloss:4.07613
# [7]	train-mlogloss:3.81254	eval-mlogloss:4.00213
# [8]	train-mlogloss:3.73476	eval-mlogloss:3.93526
# [9]	train-mlogloss:3.66327	eval-mlogloss:3.87557
# [10]	train-mlogloss:3.59797	eval-mlogloss:3.82064
# [11]	train-mlogloss:3.53819	eval-mlogloss:3.77054
# [12]	train-mlogloss:3.48258	eval-mlogloss:3.72465
# [13]	train-mlogloss:3.43075	eval-mlogloss:3.68191
# [14]	train-mlogloss:3.38289	eval-mlogloss:3.6424
# [15]	train-mlogloss:3.33754	eval-mlogloss:3.60609
# [16]	train-mlogloss:3.29494	eval-mlogloss:3.57166
# [17]	train-mlogloss:3.25516	eval-mlogloss:3.53902
# [18]	train-mlogloss:3.217	eval-mlogloss:3.509
# [19]	train-mlogloss:3.18092	eval-mlogloss:3.48073
# [20]	train-mlogloss:3.14632	eval-mlogloss:3.45434
# [21]	train-mlogloss:3.11353	eval-mlogloss:3.4286
# [22]	train-mlogloss:3.08253	eval-mlogloss:3.40451
# [23]	train-mlogloss:3.05277	eval-mlogloss:3.38155
# [24]	train-mlogloss:3.0243	eval-mlogloss:3.35953
# [25]	train-mlogloss:2.99678	eval-mlogloss:3.33888
# [26]	train-mlogloss:2.97078	eval-mlogloss:3.31978
# [27]	train-mlogloss:2.94573	eval-mlogloss:3.30145
# [28]	train-mlogloss:2.92158	eval-mlogloss:3.28411
# [29]	train-mlogloss:2.89856	eval-mlogloss:3.26695
# [30]	train-mlogloss:2.87629	eval-mlogloss:3.25078
# [31]	train-mlogloss:2.85484	eval-mlogloss:3.23535
# [32]	train-mlogloss:2.83428	eval-mlogloss:3.22056
# [33]	train-mlogloss:2.81404	eval-mlogloss:3.20674
# [34]	train-mlogloss:2.79491	eval-mlogloss:3.19294
# [35]	train-mlogloss:2.77628	eval-mlogloss:3.18006
# [36]	train-mlogloss:2.75802	eval-mlogloss:3.16786
# [37]	train-mlogloss:2.74035	eval-mlogloss:3.15599
# [38]	train-mlogloss:2.72369	eval-mlogloss:3.14455
# [39]	train-mlogloss:2.70752	eval-mlogloss:3.13356
# [40]	train-mlogloss:2.69137	eval-mlogloss:3.12325
# [41]	train-mlogloss:2.6754	eval-mlogloss:3.11322
# [42]	train-mlogloss:2.66063	eval-mlogloss:3.10338
# [43]	train-mlogloss:2.64634	eval-mlogloss:3.09414
# [44]	train-mlogloss:2.63204	eval-mlogloss:3.08514
# [45]	train-mlogloss:2.61788	eval-mlogloss:3.07658
# [46]	train-mlogloss:2.60455	eval-mlogloss:3.06827
# [47]	train-mlogloss:2.59169	eval-mlogloss:3.0604
# [48]	train-mlogloss:2.57862	eval-mlogloss:3.05273
# [49]	train-mlogloss:2.56567	eval-mlogloss:3.04528
# [50]	train-mlogloss:2.55412	eval-mlogloss:3.03826
# [51]	train-mlogloss:2.54229	eval-mlogloss:3.03123
# [52]	train-mlogloss:2.53086	eval-mlogloss:3.02447
# [53]	train-mlogloss:2.51963	eval-mlogloss:3.01776
# [54]	train-mlogloss:2.50872	eval-mlogloss:3.01158
# [55]	train-mlogloss:2.4979	eval-mlogloss:3.0057
# [56]	train-mlogloss:2.48785	eval-mlogloss:2.99981
# [57]	train-mlogloss:2.47796	eval-mlogloss:2.99427
# [58]	train-mlogloss:2.46776	eval-mlogloss:2.98879
# [59]	train-mlogloss:2.45794	eval-mlogloss:2.98364
# [60]	train-mlogloss:2.44826	eval-mlogloss:2.97854
# [61]	train-mlogloss:2.43887	eval-mlogloss:2.97353
# [62]	train-mlogloss:2.42962	eval-mlogloss:2.96881
# [63]	train-mlogloss:2.42039	eval-mlogloss:2.96457
# [64]	train-mlogloss:2.41145	eval-mlogloss:2.96052
# [65]	train-mlogloss:2.40287	eval-mlogloss:2.95638
# [66]	train-mlogloss:2.39435	eval-mlogloss:2.95195
# [67]	train-mlogloss:2.38583	eval-mlogloss:2.94776
# [68]	train-mlogloss:2.37776	eval-mlogloss:2.94381
# [69]	train-mlogloss:2.36977	eval-mlogloss:2.94022
# [70]	train-mlogloss:2.36169	eval-mlogloss:2.93684
# [71]	train-mlogloss:2.35427	eval-mlogloss:2.93345
# [72]	train-mlogloss:2.34679	eval-mlogloss:2.92998
# [73]	train-mlogloss:2.33955	eval-mlogloss:2.92688
# [74]	train-mlogloss:2.3322	eval-mlogloss:2.92374
# [75]	train-mlogloss:2.32485	eval-mlogloss:2.92081
# [76]	train-mlogloss:2.31783	eval-mlogloss:2.91788
# [77]	train-mlogloss:2.31115	eval-mlogloss:2.91477
# [78]	train-mlogloss:2.30467	eval-mlogloss:2.91202
# [79]	train-mlogloss:2.29811	eval-mlogloss:2.90924
# [80]	train-mlogloss:2.29102	eval-mlogloss:2.90676
# [81]	train-mlogloss:2.28407	eval-mlogloss:2.90413
# [82]	train-mlogloss:2.27769	eval-mlogloss:2.9018
# [83]	train-mlogloss:2.27194	eval-mlogloss:2.89945
# [84]	train-mlogloss:2.2659	eval-mlogloss:2.89727
# [85]	train-mlogloss:2.25965	eval-mlogloss:2.8951
# [86]	train-mlogloss:2.25391	eval-mlogloss:2.89296
# [87]	train-mlogloss:2.24806	eval-mlogloss:2.891
# [88]	train-mlogloss:2.24242	eval-mlogloss:2.88897
# [89]	train-mlogloss:2.23669	eval-mlogloss:2.88711
# [90]	train-mlogloss:2.23112	eval-mlogloss:2.88539
# [91]	train-mlogloss:2.22576	eval-mlogloss:2.88378
# [92]	train-mlogloss:2.2202	eval-mlogloss:2.88189
# [93]	train-mlogloss:2.21505	eval-mlogloss:2.88018
# [94]	train-mlogloss:2.20977	eval-mlogloss:2.87829
# [95]	train-mlogloss:2.20428	eval-mlogloss:2.87703
# [96]	train-mlogloss:2.19909	eval-mlogloss:2.87557
# [97]	train-mlogloss:2.19426	eval-mlogloss:2.87421
# [98]	train-mlogloss:2.18937	eval-mlogloss:2.87272
# [99]	train-mlogloss:2.18464	eval-mlogloss:2.87107
# [100]	train-mlogloss:2.1798	eval-mlogloss:2.8697
# [101]	train-mlogloss:2.17499	eval-mlogloss:2.8687
# [102]	train-mlogloss:2.17011	eval-mlogloss:2.86777
# [103]	train-mlogloss:2.1654	eval-mlogloss:2.86665
# [104]	train-mlogloss:2.16053	eval-mlogloss:2.86563
# [105]	train-mlogloss:2.15578	eval-mlogloss:2.86447
# [106]	train-mlogloss:2.15112	eval-mlogloss:2.86362
# [107]	train-mlogloss:2.14694	eval-mlogloss:2.86244
# [108]	train-mlogloss:2.14272	eval-mlogloss:2.86151
# [109]	train-mlogloss:2.13829	eval-mlogloss:2.86064
# [110]	train-mlogloss:2.13433	eval-mlogloss:2.8596
# [111]	train-mlogloss:2.12994	eval-mlogloss:2.85897
# [112]	train-mlogloss:2.12581	eval-mlogloss:2.8582
# [113]	train-mlogloss:2.12157	eval-mlogloss:2.85734
# [114]	train-mlogloss:2.11766	eval-mlogloss:2.85626
# [115]	train-mlogloss:2.11365	eval-mlogloss:2.85546
# [116]	train-mlogloss:2.10968	eval-mlogloss:2.85475
# [117]	train-mlogloss:2.10568	eval-mlogloss:2.85404
# [118]	train-mlogloss:2.10174	eval-mlogloss:2.85342
# [119]	train-mlogloss:2.09812	eval-mlogloss:2.85282
# [120]	train-mlogloss:2.09432	eval-mlogloss:2.85236
# [121]	train-mlogloss:2.0908	eval-mlogloss:2.85171
# [122]	train-mlogloss:2.08706	eval-mlogloss:2.85129
# [123]	train-mlogloss:2.08312	eval-mlogloss:2.85094
# [124]	train-mlogloss:2.07944	eval-mlogloss:2.85046
# [125]	train-mlogloss:2.07588	eval-mlogloss:2.85013
# [126]	train-mlogloss:2.07231	eval-mlogloss:2.8498
# [127]	train-mlogloss:2.06856	eval-mlogloss:2.84949
# [128]	train-mlogloss:2.06512	eval-mlogloss:2.84903
# [129]	train-mlogloss:2.06164	eval-mlogloss:2.84851
# [130]	train-mlogloss:2.0583	eval-mlogloss:2.84815
# [131]	train-mlogloss:2.05483	eval-mlogloss:2.84765
# [132]	train-mlogloss:2.05157	eval-mlogloss:2.84726
# [133]	train-mlogloss:2.04814	eval-mlogloss:2.84691
# [134]	train-mlogloss:2.04526	eval-mlogloss:2.84658
# [135]	train-mlogloss:2.04179	eval-mlogloss:2.84622
# [136]	train-mlogloss:2.03856	eval-mlogloss:2.84593
# [137]	train-mlogloss:2.0354	eval-mlogloss:2.84565
# [138]	train-mlogloss:2.03243	eval-mlogloss:2.84528
# [139]	train-mlogloss:2.02915	eval-mlogloss:2.84506
# [140]	train-mlogloss:2.02585	eval-mlogloss:2.84483
# [141]	train-mlogloss:2.02268	eval-mlogloss:2.84464
# [142]	train-mlogloss:2.01981	eval-mlogloss:2.84452
# [143]	train-mlogloss:2.0168	eval-mlogloss:2.84448
# [144]	train-mlogloss:2.01391	eval-mlogloss:2.84429
# [145]	train-mlogloss:2.01103	eval-mlogloss:2.84412
# [146]	train-mlogloss:2.00806	eval-mlogloss:2.84406
# [147]	train-mlogloss:2.00494	eval-mlogloss:2.84381
# [148]	train-mlogloss:2.00176	eval-mlogloss:2.84395
# [149]	train-mlogloss:1.99869	eval-mlogloss:2.84374
# [150]	train-mlogloss:1.99601	eval-mlogloss:2.84369
# [151]	train-mlogloss:1.99322	eval-mlogloss:2.84368
# [152]	train-mlogloss:1.9903	eval-mlogloss:2.84359
# [153]	train-mlogloss:1.98739	eval-mlogloss:2.84351
# [154]	train-mlogloss:1.98478	eval-mlogloss:2.84344
# [155]	train-mlogloss:1.98177	eval-mlogloss:2.84354
# [156]	train-mlogloss:1.97898	eval-mlogloss:2.84332
# [157]	train-mlogloss:1.97661	eval-mlogloss:2.84316
# [158]	train-mlogloss:1.97428	eval-mlogloss:2.84319
# [159]	train-mlogloss:1.97171	eval-mlogloss:2.8432
# [160]	train-mlogloss:1.96874	eval-mlogloss:2.84326
# [161]	train-mlogloss:1.96591	eval-mlogloss:2.84301
# [162]	train-mlogloss:1.96315	eval-mlogloss:2.84311
# [163]	train-mlogloss:1.96069	eval-mlogloss:2.84322
# [164]	train-mlogloss:1.95819	eval-mlogloss:2.84344
# [165]	train-mlogloss:1.95583	eval-mlogloss:2.84351
# [166]	train-mlogloss:1.9535	eval-mlogloss:2.84356
# [167]	train-mlogloss:1.95072	eval-mlogloss:2.84376
# [168]	train-mlogloss:1.94823	eval-mlogloss:2.84387
# [169]	train-mlogloss:1.94537	eval-mlogloss:2.844
# [170]	train-mlogloss:1.94273	eval-mlogloss:2.84407
# [171]	train-mlogloss:1.94036	eval-mlogloss:2.84422
# Stopping. Best iteration:
# [161]	train-mlogloss:1.96591	eval-mlogloss:2.84301
#
# 0.013967980270501354
# crps list: [0.012261196553920611, 0.012071131912255782, 0.011744246241396935, 0.014137257132469196, 0.013967980270501354]
# average crps: 0.012836362422108775

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Quarter',
#        'Down', 'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'AttackAngle', 'time_end', 'Grass', 'DefendersInTheBox_vs_Distance',
#        'DisToQB', 'runner_height', 'DefenseAveX', 'DefenseAveY',
#        'DefenseAveMomentum', 'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos',
#        '1stDefender_AttackAngle', 'RusherVoronoi', 'FirstDefenderVoronoi'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Fold_5").head(70).reset_index(drop=True)
# Out:
#                          Features        Fold_1        Fold_2        Fold_3  \
# 0                        Humidity   3341.159604   1612.669988   1269.406944
# 1                       WindSpeed   2309.587678    676.331132    731.241849
# 2                        Distance   1223.235409   6180.500119   7652.784839
# 3                   WindDirection   2707.047234   1315.182411   6099.926492
# 4                           Grass    312.165169    416.478986    231.959470
# 5                        time_end   5539.222146   1824.816465   3095.969481
# 6                OffenseFormation    711.878290    216.555650    546.790944
# 7                     StadiumType   1182.832296   2453.833895   2873.268994
# 8                  DefenseSpreadX   6664.429349   6527.040521   3235.959035
# 9                     Temperature   3759.336378   4468.507956   4674.746515
# 10                  RusherVoronoi   2129.419217   2318.847505   5863.644146
# 11                       YardLine  10651.106465   6871.107242   1841.853092
# 12                   JerseyNumber   3613.871474   2964.322897   2226.071937
# 13                    DefenseAveX   5219.654140   6076.022680   2349.413859
# 14                        Quarter    110.147027    726.289684   1369.389658
# 15         DefenseStdMomentum_cos   6961.057280   2792.841549   8063.944685
# 16            HomeScoreBeforePlay   2498.465099   2075.806610   4434.816098
# 17                       Location   2995.485977   2433.912685   3650.107744
# 18  DefendersInTheBox_vs_Distance   6436.610889   5008.074466   6396.948661
# 19                 OffenseSpreadX   4009.408498   5808.977046  10936.919377
# 20         RunnerToOffenseCentoid   6124.066052   5543.954632   3629.783610
# 21                         Season   2800.910024   4482.850395   2998.016255
# 22                    OffenseStdY   3996.126264   5139.464278   5025.873256
# 23                              Y   5351.623397  14595.475032   2683.091498
# 24                  MinTackleTime  10276.398898   5536.566889   7464.747303
# 25             DefenseAveMomentum   6990.371515   5594.256121   3646.033737
# 26                           Down    739.988323   3168.912438   1705.085564
# 27              DefendersInTheBox   1273.109346   1287.950719   7591.930672
# 28                       Momentum   5190.257178   3675.502328   7971.721239
# 29             DefenseStdMomentum   6116.920633   1467.537728   2204.508668
# 30                           Week   2373.351225     91.192555    116.377894
# 31                            age   5285.155116   5928.656030   7487.463010
# 32                              X   9033.767206   7171.384344   6228.354273
# 33                            Dir   5629.711929  14793.637288   6248.549355
# 34               OffensePersonnel   1516.225653   6878.721948   1724.694515
# 35         OffenseStdMomentum_cos   5381.315206   5930.276994   3308.673537
# 36                        Stadium   2905.118139   1548.297849    763.120388
# 37                           Team    506.635413   5319.042940   7864.438862
# 38                    DefenseStdY   4813.621809   3390.921676   4712.621329
# 39             OffenseAveMomentum   5174.181251   5817.709945  10112.476079
# 40                    Orientation   5419.618132   5561.008380   6880.236836
# 41         OffenseAveMomentum_cos   7994.614453   6203.340339  23605.626838
# 42         VisitorScoreBeforePlay   2264.131344   2811.221100   4031.578849
# 43              RunnerToScrimmage   7511.550793   2932.127728   5714.236908
# 44                    DefenseStdX   7792.056888   3699.885942   6446.682073
# 45                            Dis   2857.353945   3805.497470  12865.645594
# 46        1stDefender_AttackAngle   7443.602035   7609.564596   6127.689938
# 47           FirstDefenderVoronoi   6119.427063   5741.373129   3528.355252
# 48                  runner_height   1666.016990   2643.181630   4684.815474
# 49             OffenseStdMomentum   5883.479467   8208.531274   6701.433539
# 50                    OffenseStdX   4871.970830   1917.167242   9357.339448
# 51                    DefenseAveY   5284.608902   7525.583818   9065.417773
# 52                    GameWeather   2745.858558   3046.192121   7838.212566
# 53       1stOffenser_Momentum_cos   7806.299478   6383.599735   5338.166118
# 54         DefenseAveMomentum_cos  11145.506140   5393.127050  18134.746519
# 55               DefensePersonnel   1136.374818   6744.882455   6714.485629
# 56                   PlayerWeight   3509.920021   7493.528452   7508.564020
# 57       1stDefender_Momentum_cos  14988.957672   8013.557040   3788.556475
# 58                          NflId   3656.000330   7907.210487   5452.477878
# 59         RunnerToDefenseCentoid   6916.436132  10578.238852   3218.676396
# 60                        Dir_cos   7710.968758   8364.806934   9111.651566
# 61                   Momentum_cos  16304.954187  11928.960535   6572.087957
# 62              PlayerCollegeName   3638.007023   2593.813123   1586.211890
# 63                        DisToQB   6764.495545   5400.674309   6060.097068
# 64                              S   5317.712548  14240.611538   7491.285260
# 65                              A  18736.807139  18559.407711  15600.497777
#
#           Fold_4        Fold_5       Average          Std        Cv
# 0    2466.892502    106.018595   1759.229527  1095.244439  0.622571
# 1    2021.075972    236.067781   1194.860882   815.885669  0.682829
# 2    2186.837594    276.638597   3503.999311  2888.900624  0.824458
# 3    3163.557921    613.958610   2779.934533  1897.987173  0.682745
# 4     632.324354    656.592528    449.904102   169.461718  0.376662
# 5    6109.914238   1226.144940   3559.213454  1954.095468  0.549025
# 6    1747.696995   1248.017971    894.187970   541.623559  0.605716
# 7    3323.756151   1283.571946   2223.452657   854.666140  0.384387
# 8    6565.022760   1515.447416   4901.579816  2133.400507  0.435248
# 9    2160.161112   1621.154514   3336.781295  1231.041776  0.368931
# 10   6582.495628   1782.177456   3735.316790  2051.158218  0.549126
# 11   9250.684450   2143.362104   6151.622671  3605.758255  0.586148
# 12   5362.267558   2353.455047   3303.997783  1141.344017  0.345443
# 13   4927.102682   2368.283714   4188.095415  1540.582941  0.367848
# 14   4621.620223   2394.421749   1844.373668  1581.070205  0.857240
# 15   4772.010055   2408.239283   4999.618570  2230.437330  0.446121
# 16   1405.704721   2500.682404   2583.094986  1008.604428  0.390464
# 17   1396.097427   2923.203978   2679.761562   749.500248  0.279689
# 18   3618.251550   2936.548834   4879.286880  1421.941125  0.291424
# 19   3966.043249   3189.385522   5582.146738  2811.961746  0.503742
# 20   3279.260586   3308.336494   4377.080275  1209.911461  0.276420
# 21   7062.459097   3343.853631   4137.617880  1574.129796  0.380443
# 22   6037.480582   3351.402624   4710.069401   938.277432  0.199207
# 23   8929.982822   3488.306937   7009.695937  4361.202523  0.622167
# 24   5125.365051   3526.779579   6385.971544  2314.509789  0.362437
# 25   5701.231087   3545.996638   5095.577820  1319.705949  0.258990
# 26   7005.788146   3692.805697   3262.516034  2144.515454  0.657320
# 27   2239.046946   3733.644183   3225.136373  2360.633083  0.731948
# 28   5778.737352   4217.643908   5366.772401  1494.491348  0.278471
# 29    134.471097   4222.376067   2829.162839  2109.785476  0.745728
# 30    674.094002   4344.026492   1519.808434  1638.934803  1.078382
# 31    357.409402   4395.893697   4690.915451  2390.485862  0.509599
# 32   5532.510687   4668.122445   6526.827791  1498.848684  0.229644
# 33  20327.540184   4756.898442  10351.267440  6159.269670  0.595026
# 34   6298.899212   4787.839490   4241.276164  2247.120283  0.529822
# 35   1440.758105   4945.131504   4201.231069  1634.163772  0.388973
# 36   4743.472318   5036.258638   2999.253467  1691.514959  0.563979
# 37   2575.138861   5115.214065   4276.094028  2520.720145  0.589491
# 38   1451.285146   5168.049424   3907.299877  1368.072097  0.350132
# 39  12684.354833   5222.352288   7802.214879  3055.261328  0.391589
# 40   3968.185697   5300.593732   5425.928555   924.556328  0.170396
# 41   7282.645860   5326.156701  10082.476838  6822.669419  0.676686
# 42   2858.750973   5459.703235   3485.077100  1143.231158  0.328036
# 43   2937.247160   5625.949132   4944.222344  1773.433018  0.358688
# 44   7249.061203   5943.567748   6226.250771  1414.843375  0.227238
# 45    234.777289   6202.054553   5193.065770  4286.071854  0.825345
# 46   5775.848436   6229.514618   6637.243925   743.439511  0.112010
# 47   2825.976989   6413.017059   4925.629898  1460.399126  0.296490
# 48   4961.265184   6702.761026   4131.608061  1783.241404  0.431610
# 49   2994.635047   6959.566729   6149.529211  1744.957783  0.283755
# 50   8630.151685   6981.070890   6351.540019  2700.962694  0.425245
# 51   6178.492018   7011.239276   7013.068357  1277.411705  0.182147
# 52   1135.572574   7101.745340   4373.516232  2620.789678  0.599241
# 53   5446.160778   7320.560985   6458.957419   984.408481  0.152410
# 54   9989.663848   7429.828055  10418.574322  4346.019603  0.417141
# 55   5198.380805   7664.233268   5491.671395  2316.914558  0.421896
# 56   3222.827904   8002.342451   5947.436570  2117.316061  0.356005
# 57   5026.145453   8811.811973   8125.805723  3898.863523  0.479813
# 58   3128.490111   9128.185444   5854.472850  2339.093381  0.399540
# 59   8166.188182   9241.256723   7624.159257  2511.753853  0.329447
# 60   9700.013410   9348.320775   8847.152289   717.226864  0.081069
# 61   6215.511379  10467.625695  10297.827951  3723.477877  0.361579
# 62  15207.613365  12179.271944   7040.983469  5553.520650  0.788742
# 63   4791.693740  13610.025890   7325.397310  3210.494177  0.438269
# 64   5951.794703  21201.945622  10840.669934  6075.165410  0.560405
# 65  29217.723249  29081.712472  22239.229670  5751.517329  0.258620

# %% [markdown]
# # prediction

# %%
w = [0.3, 0.25, 0.2, 0.15, 0.1]
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    dtest = xgb.DMatrix(X_test)
    for idx, model in enumerate(models):
        pred_value += model.predict(dtest, ntree_limit = model.best_ntree_limit)[0] * w[i]
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

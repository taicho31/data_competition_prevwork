# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf', 'Quarter']
top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]
    
    #df["Jersey_cat"] = df["JerseyNumber"].apply(lambda x: 0 if x>=1 and x <=9 else #: quarterbacks, kickers, and punters
    #                                            (1 if x>=10 and x <= 19 else
    ##                                            (2 if x>=20 and x <= 39 else
    #                                            (3 if x>=40 and x <= 49 else
    #                                            (4 if x>=50 and x <= 59 else
    #                                            (5 if x>=60 and x <= 79 else
    #                                            (6 if x>=80 and x <= 89 else
    #                                            (7 if x>=90 and x <= 99 else 8))))))))

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    #df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]
    
    df["AttackAngle"] =  np.arctan((df["Y"] - df["RushY"]) / (df["X"] - df["RushX"])) * 180 / np.pi

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1
    
    df_single = df[df.is_run==True].copy()
        
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])
    df_single["1stDefender_AttackAngle"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["AttackAngle"])
    #df_single["1stDefenderID"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["NflId"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    #def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    #off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    #df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY"]#"InfluToBall",, "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:856: RuntimeWarning: invalid value encountered in arctan
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# CPU times: user 5min 28s, sys: 2.44 s, total: 5min 31s
# Wall time: 5min 29s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
xgb_params = {
    "objective" : "multi:softprob",
    "eval_metric" : "mlogloss", 
    "max_depth" : 8,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.1,
}
#evals_result = {}
num_boost_round=100000
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    xgb_train = xgb.DMatrix(X_train2, label = y_train2)
    xgb_eval = xgb.DMatrix(X_test2, label = y_test2)
    watchlist = [(xgb_train, "train"), (xgb_eval, "eval")]
    
    clf = xgb.train(
        xgb_params, xgb_train, num_boost_round, watchlist,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(xgb_eval, ntree_limit=clf.best_ntree_limit)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    if i == 0:
        feature_importance_df = pd.DataFrame(clf.get_fscore().items(), columns =["Features", "Fold_"+str(i+1)])
    else:
        feature_importance_df["Fold_"+str(i+1)] = list(clf.get_fscore().values())
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-mlogloss:4.35413	eval-mlogloss:4.47973
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:3.99549	eval-mlogloss:4.21856
# [2]	train-mlogloss:3.73336	eval-mlogloss:4.02565
# [3]	train-mlogloss:3.52898	eval-mlogloss:3.88334
# [4]	train-mlogloss:3.35552	eval-mlogloss:3.76739
# [5]	train-mlogloss:3.20291	eval-mlogloss:3.67004
# [6]	train-mlogloss:3.06545	eval-mlogloss:3.58997
# [7]	train-mlogloss:2.94691	eval-mlogloss:3.5193
# [8]	train-mlogloss:2.8462	eval-mlogloss:3.45565
# [9]	train-mlogloss:2.74964	eval-mlogloss:3.40031
# [10]	train-mlogloss:2.65978	eval-mlogloss:3.35034
# [11]	train-mlogloss:2.57965	eval-mlogloss:3.30735
# [12]	train-mlogloss:2.50633	eval-mlogloss:3.2678
# [13]	train-mlogloss:2.43732	eval-mlogloss:3.2318
# [14]	train-mlogloss:2.37183	eval-mlogloss:3.19956
# [15]	train-mlogloss:2.31397	eval-mlogloss:3.16955
# [16]	train-mlogloss:2.25689	eval-mlogloss:3.1423
# [17]	train-mlogloss:2.2066	eval-mlogloss:3.11727
# [18]	train-mlogloss:2.15719	eval-mlogloss:3.09428
# [19]	train-mlogloss:2.10735	eval-mlogloss:3.07205
# [20]	train-mlogloss:2.06439	eval-mlogloss:3.05296
# [21]	train-mlogloss:2.02152	eval-mlogloss:3.03596
# [22]	train-mlogloss:1.98228	eval-mlogloss:3.01922
# [23]	train-mlogloss:1.945	eval-mlogloss:3.00265
# [24]	train-mlogloss:1.90941	eval-mlogloss:2.98795
# [25]	train-mlogloss:1.87474	eval-mlogloss:2.97498
# [26]	train-mlogloss:1.84281	eval-mlogloss:2.9617
# [27]	train-mlogloss:1.81093	eval-mlogloss:2.95056
# [28]	train-mlogloss:1.78198	eval-mlogloss:2.94021
# [29]	train-mlogloss:1.7506	eval-mlogloss:2.93007
# [30]	train-mlogloss:1.72222	eval-mlogloss:2.9201
# [31]	train-mlogloss:1.69421	eval-mlogloss:2.91099
# [32]	train-mlogloss:1.66628	eval-mlogloss:2.90306
# [33]	train-mlogloss:1.63889	eval-mlogloss:2.89544
# [34]	train-mlogloss:1.61507	eval-mlogloss:2.88892
# [35]	train-mlogloss:1.59261	eval-mlogloss:2.88223
# [36]	train-mlogloss:1.56879	eval-mlogloss:2.87539
# [37]	train-mlogloss:1.54707	eval-mlogloss:2.86998
# [38]	train-mlogloss:1.52719	eval-mlogloss:2.86486
# [39]	train-mlogloss:1.50753	eval-mlogloss:2.85966
# [40]	train-mlogloss:1.48676	eval-mlogloss:2.85443
# [41]	train-mlogloss:1.46916	eval-mlogloss:2.84993
# [42]	train-mlogloss:1.44992	eval-mlogloss:2.84559
# [43]	train-mlogloss:1.4307	eval-mlogloss:2.84176
# [44]	train-mlogloss:1.41389	eval-mlogloss:2.83822
# [45]	train-mlogloss:1.39389	eval-mlogloss:2.83486
# [46]	train-mlogloss:1.38026	eval-mlogloss:2.83242
# [47]	train-mlogloss:1.36337	eval-mlogloss:2.82932
# [48]	train-mlogloss:1.34748	eval-mlogloss:2.8265
# [49]	train-mlogloss:1.3309	eval-mlogloss:2.82407
# [50]	train-mlogloss:1.31695	eval-mlogloss:2.82173
# [51]	train-mlogloss:1.304	eval-mlogloss:2.81944
# [52]	train-mlogloss:1.29007	eval-mlogloss:2.81791
# [53]	train-mlogloss:1.27693	eval-mlogloss:2.81645
# [54]	train-mlogloss:1.26401	eval-mlogloss:2.81474
# [55]	train-mlogloss:1.24727	eval-mlogloss:2.81307
# [56]	train-mlogloss:1.23371	eval-mlogloss:2.81204
# [57]	train-mlogloss:1.22207	eval-mlogloss:2.81092
# [58]	train-mlogloss:1.21111	eval-mlogloss:2.81002
# [59]	train-mlogloss:1.19901	eval-mlogloss:2.80907
# [60]	train-mlogloss:1.18595	eval-mlogloss:2.80817
# [61]	train-mlogloss:1.17355	eval-mlogloss:2.80794
# [62]	train-mlogloss:1.16131	eval-mlogloss:2.80775
# [63]	train-mlogloss:1.14979	eval-mlogloss:2.80756
# [64]	train-mlogloss:1.14012	eval-mlogloss:2.80721
# [65]	train-mlogloss:1.12946	eval-mlogloss:2.80728
# [66]	train-mlogloss:1.11811	eval-mlogloss:2.80705
# [67]	train-mlogloss:1.10864	eval-mlogloss:2.80755
# [68]	train-mlogloss:1.0993	eval-mlogloss:2.80775
# [69]	train-mlogloss:1.0904	eval-mlogloss:2.80796
# [70]	train-mlogloss:1.08055	eval-mlogloss:2.80787
# [71]	train-mlogloss:1.07064	eval-mlogloss:2.80788
# [72]	train-mlogloss:1.06078	eval-mlogloss:2.80895
# [73]	train-mlogloss:1.05127	eval-mlogloss:2.80904
# [74]	train-mlogloss:1.04178	eval-mlogloss:2.80937
# [75]	train-mlogloss:1.03204	eval-mlogloss:2.80964
# [76]	train-mlogloss:1.02199	eval-mlogloss:2.81037
# Stopping. Best iteration:
# [66]	train-mlogloss:1.11811	eval-mlogloss:2.80705
#
# 0.012463530769226253
# [0]	train-mlogloss:4.35337	eval-mlogloss:4.4597
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:3.99347	eval-mlogloss:4.18588
# [2]	train-mlogloss:3.73169	eval-mlogloss:3.99933
# [3]	train-mlogloss:3.52171	eval-mlogloss:3.85695
# [4]	train-mlogloss:3.34657	eval-mlogloss:3.73735
# [5]	train-mlogloss:3.19456	eval-mlogloss:3.64122
# [6]	train-mlogloss:3.06435	eval-mlogloss:3.55791
# [7]	train-mlogloss:2.94509	eval-mlogloss:3.48681
# [8]	train-mlogloss:2.84076	eval-mlogloss:3.42378
# [9]	train-mlogloss:2.74167	eval-mlogloss:3.37003
# [10]	train-mlogloss:2.65255	eval-mlogloss:3.31953
# [11]	train-mlogloss:2.57325	eval-mlogloss:3.27569
# [12]	train-mlogloss:2.49216	eval-mlogloss:3.23759
# [13]	train-mlogloss:2.42127	eval-mlogloss:3.20197
# [14]	train-mlogloss:2.35961	eval-mlogloss:3.17018
# [15]	train-mlogloss:2.302	eval-mlogloss:3.14006
# [16]	train-mlogloss:2.24532	eval-mlogloss:3.11288
# [17]	train-mlogloss:2.19661	eval-mlogloss:3.08808
# [18]	train-mlogloss:2.14754	eval-mlogloss:3.06527
# [19]	train-mlogloss:2.10294	eval-mlogloss:3.04474
# [20]	train-mlogloss:2.05707	eval-mlogloss:3.02558
# [21]	train-mlogloss:2.00879	eval-mlogloss:3.00795
# [22]	train-mlogloss:1.96494	eval-mlogloss:2.99197
# [23]	train-mlogloss:1.9268	eval-mlogloss:2.97666
# [24]	train-mlogloss:1.89177	eval-mlogloss:2.96242
# [25]	train-mlogloss:1.85661	eval-mlogloss:2.94958
# [26]	train-mlogloss:1.82246	eval-mlogloss:2.93762
# [27]	train-mlogloss:1.79201	eval-mlogloss:2.926
# [28]	train-mlogloss:1.76327	eval-mlogloss:2.91547
# [29]	train-mlogloss:1.73693	eval-mlogloss:2.90538
# [30]	train-mlogloss:1.71048	eval-mlogloss:2.89655
# [31]	train-mlogloss:1.68669	eval-mlogloss:2.88761
# [32]	train-mlogloss:1.65552	eval-mlogloss:2.8805
# [33]	train-mlogloss:1.62796	eval-mlogloss:2.87249
# [34]	train-mlogloss:1.6058	eval-mlogloss:2.86574
# [35]	train-mlogloss:1.58468	eval-mlogloss:2.85925
# [36]	train-mlogloss:1.56231	eval-mlogloss:2.85316
# [37]	train-mlogloss:1.54285	eval-mlogloss:2.84751
# [38]	train-mlogloss:1.52235	eval-mlogloss:2.84222
# [39]	train-mlogloss:1.50035	eval-mlogloss:2.83709
# [40]	train-mlogloss:1.47836	eval-mlogloss:2.83227
# [41]	train-mlogloss:1.45592	eval-mlogloss:2.82746
# [42]	train-mlogloss:1.43654	eval-mlogloss:2.82372
# [43]	train-mlogloss:1.41948	eval-mlogloss:2.82016
# [44]	train-mlogloss:1.39928	eval-mlogloss:2.81686
# [45]	train-mlogloss:1.37931	eval-mlogloss:2.81376
# [46]	train-mlogloss:1.36265	eval-mlogloss:2.81045
# [47]	train-mlogloss:1.34855	eval-mlogloss:2.80791
# [48]	train-mlogloss:1.33438	eval-mlogloss:2.80567
# [49]	train-mlogloss:1.31757	eval-mlogloss:2.80309
# [50]	train-mlogloss:1.30225	eval-mlogloss:2.80083
# [51]	train-mlogloss:1.28696	eval-mlogloss:2.79837
# [52]	train-mlogloss:1.27129	eval-mlogloss:2.79644
# [53]	train-mlogloss:1.25779	eval-mlogloss:2.79488
# [54]	train-mlogloss:1.24464	eval-mlogloss:2.79307
# [55]	train-mlogloss:1.23012	eval-mlogloss:2.79126
# [56]	train-mlogloss:1.21783	eval-mlogloss:2.7901
# [57]	train-mlogloss:1.20329	eval-mlogloss:2.78895
# [58]	train-mlogloss:1.18941	eval-mlogloss:2.78776
# [59]	train-mlogloss:1.17794	eval-mlogloss:2.78693
# [60]	train-mlogloss:1.16494	eval-mlogloss:2.78584
# [61]	train-mlogloss:1.15313	eval-mlogloss:2.78496
# [62]	train-mlogloss:1.14136	eval-mlogloss:2.78434
# [63]	train-mlogloss:1.12924	eval-mlogloss:2.78442
# [64]	train-mlogloss:1.11628	eval-mlogloss:2.78411
# [65]	train-mlogloss:1.10616	eval-mlogloss:2.78435
# [66]	train-mlogloss:1.09696	eval-mlogloss:2.7843
# [67]	train-mlogloss:1.08781	eval-mlogloss:2.78429
# [68]	train-mlogloss:1.07818	eval-mlogloss:2.78422
# [69]	train-mlogloss:1.067	eval-mlogloss:2.78425
# [70]	train-mlogloss:1.05507	eval-mlogloss:2.78451
# [71]	train-mlogloss:1.0457	eval-mlogloss:2.78482
# [72]	train-mlogloss:1.03742	eval-mlogloss:2.7849
# [73]	train-mlogloss:1.02878	eval-mlogloss:2.78508
# [74]	train-mlogloss:1.02046	eval-mlogloss:2.78492
# Stopping. Best iteration:
# [64]	train-mlogloss:1.11628	eval-mlogloss:2.78411
#
# 0.012254392817461731
# [0]	train-mlogloss:4.34069	eval-mlogloss:4.47787
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:3.97153	eval-mlogloss:4.21647
# [2]	train-mlogloss:3.69768	eval-mlogloss:4.03039
# [3]	train-mlogloss:3.48985	eval-mlogloss:3.88635
# [4]	train-mlogloss:3.30977	eval-mlogloss:3.77345
# [5]	train-mlogloss:3.15928	eval-mlogloss:3.67685
# [6]	train-mlogloss:3.03435	eval-mlogloss:3.59416
# [7]	train-mlogloss:2.91819	eval-mlogloss:3.52322
# [8]	train-mlogloss:2.81334	eval-mlogloss:3.45985
# [9]	train-mlogloss:2.72077	eval-mlogloss:3.4042
# [10]	train-mlogloss:2.63286	eval-mlogloss:3.35555
# [11]	train-mlogloss:2.54607	eval-mlogloss:3.31098
# [12]	train-mlogloss:2.47323	eval-mlogloss:3.27165
# [13]	train-mlogloss:2.40804	eval-mlogloss:3.23614
# [14]	train-mlogloss:2.34109	eval-mlogloss:3.2038
# [15]	train-mlogloss:2.28311	eval-mlogloss:3.17361
# [16]	train-mlogloss:2.22303	eval-mlogloss:3.14683
# [17]	train-mlogloss:2.17225	eval-mlogloss:3.12134
# [18]	train-mlogloss:2.12213	eval-mlogloss:3.09953
# [19]	train-mlogloss:2.07242	eval-mlogloss:3.07804
# [20]	train-mlogloss:2.02883	eval-mlogloss:3.05885
# [21]	train-mlogloss:1.98331	eval-mlogloss:3.04124
# [22]	train-mlogloss:1.94242	eval-mlogloss:3.02401
# [23]	train-mlogloss:1.90364	eval-mlogloss:3.00789
# [24]	train-mlogloss:1.86736	eval-mlogloss:2.99419
# [25]	train-mlogloss:1.83138	eval-mlogloss:2.98156
# [26]	train-mlogloss:1.79886	eval-mlogloss:2.96851
# [27]	train-mlogloss:1.76775	eval-mlogloss:2.95707
# [28]	train-mlogloss:1.73554	eval-mlogloss:2.94574
# [29]	train-mlogloss:1.70764	eval-mlogloss:2.93572
# [30]	train-mlogloss:1.67817	eval-mlogloss:2.92639
# [31]	train-mlogloss:1.65335	eval-mlogloss:2.91677
# [32]	train-mlogloss:1.62763	eval-mlogloss:2.90795
# [33]	train-mlogloss:1.60413	eval-mlogloss:2.90002
# [34]	train-mlogloss:1.58093	eval-mlogloss:2.89233
# [35]	train-mlogloss:1.55732	eval-mlogloss:2.88484
# [36]	train-mlogloss:1.53422	eval-mlogloss:2.87807
# [37]	train-mlogloss:1.51454	eval-mlogloss:2.8722
# [38]	train-mlogloss:1.48971	eval-mlogloss:2.8666
# [39]	train-mlogloss:1.46903	eval-mlogloss:2.86147
# [40]	train-mlogloss:1.44979	eval-mlogloss:2.85692
# [41]	train-mlogloss:1.43419	eval-mlogloss:2.85174
# [42]	train-mlogloss:1.41252	eval-mlogloss:2.84816
# [43]	train-mlogloss:1.39736	eval-mlogloss:2.84385
# [44]	train-mlogloss:1.37823	eval-mlogloss:2.8397
# [45]	train-mlogloss:1.36212	eval-mlogloss:2.8363
# [46]	train-mlogloss:1.34366	eval-mlogloss:2.8331
# [47]	train-mlogloss:1.32645	eval-mlogloss:2.83039
# [48]	train-mlogloss:1.3084	eval-mlogloss:2.82788
# [49]	train-mlogloss:1.29421	eval-mlogloss:2.82512
# [50]	train-mlogloss:1.28039	eval-mlogloss:2.82274
# [51]	train-mlogloss:1.26485	eval-mlogloss:2.82068
# [52]	train-mlogloss:1.25167	eval-mlogloss:2.81863
# [53]	train-mlogloss:1.23551	eval-mlogloss:2.817
# [54]	train-mlogloss:1.22228	eval-mlogloss:2.81548
# [55]	train-mlogloss:1.20791	eval-mlogloss:2.81334
# [56]	train-mlogloss:1.19659	eval-mlogloss:2.81187
# [57]	train-mlogloss:1.18463	eval-mlogloss:2.8105
# [58]	train-mlogloss:1.17026	eval-mlogloss:2.80909
# [59]	train-mlogloss:1.15552	eval-mlogloss:2.80781
# [60]	train-mlogloss:1.14114	eval-mlogloss:2.80673
# [61]	train-mlogloss:1.1271	eval-mlogloss:2.80666
# [62]	train-mlogloss:1.1161	eval-mlogloss:2.80633
# [63]	train-mlogloss:1.10431	eval-mlogloss:2.80578
# [64]	train-mlogloss:1.09346	eval-mlogloss:2.80523
# [65]	train-mlogloss:1.08038	eval-mlogloss:2.80502
# [66]	train-mlogloss:1.07001	eval-mlogloss:2.80535
# [67]	train-mlogloss:1.05631	eval-mlogloss:2.80431
# [68]	train-mlogloss:1.04707	eval-mlogloss:2.80421
# [69]	train-mlogloss:1.03599	eval-mlogloss:2.80383
# [70]	train-mlogloss:1.02491	eval-mlogloss:2.80434
# [71]	train-mlogloss:1.01495	eval-mlogloss:2.80408
# [72]	train-mlogloss:1.00514	eval-mlogloss:2.80439
# [73]	train-mlogloss:0.993501	eval-mlogloss:2.8045
# [74]	train-mlogloss:0.985406	eval-mlogloss:2.8048
# [75]	train-mlogloss:0.974695	eval-mlogloss:2.805
# [76]	train-mlogloss:0.966986	eval-mlogloss:2.80504
# [77]	train-mlogloss:0.95693	eval-mlogloss:2.80529
# [78]	train-mlogloss:0.947596	eval-mlogloss:2.80566
# [79]	train-mlogloss:0.938649	eval-mlogloss:2.80639
# Stopping. Best iteration:
# [69]	train-mlogloss:1.03599	eval-mlogloss:2.80383
#
# 0.011967620183047138
# [0]	train-mlogloss:4.31101	eval-mlogloss:4.59051
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:3.94219	eval-mlogloss:4.34286
# [2]	train-mlogloss:3.67484	eval-mlogloss:4.16276
# [3]	train-mlogloss:3.46063	eval-mlogloss:4.03269
# [4]	train-mlogloss:3.28248	eval-mlogloss:3.92273
# [5]	train-mlogloss:3.13036	eval-mlogloss:3.83214
# [6]	train-mlogloss:2.99511	eval-mlogloss:3.75392
# [7]	train-mlogloss:2.87375	eval-mlogloss:3.68838
# [8]	train-mlogloss:2.76392	eval-mlogloss:3.62853
# [9]	train-mlogloss:2.66228	eval-mlogloss:3.57649
# [10]	train-mlogloss:2.57587	eval-mlogloss:3.52967
# [11]	train-mlogloss:2.49467	eval-mlogloss:3.48746
# [12]	train-mlogloss:2.42172	eval-mlogloss:3.44907
# [13]	train-mlogloss:2.35026	eval-mlogloss:3.41454
# [14]	train-mlogloss:2.2867	eval-mlogloss:3.38349
# [15]	train-mlogloss:2.22289	eval-mlogloss:3.35472
# [16]	train-mlogloss:2.16657	eval-mlogloss:3.32892
# [17]	train-mlogloss:2.11623	eval-mlogloss:3.30368
# [18]	train-mlogloss:2.06497	eval-mlogloss:3.282
# [19]	train-mlogloss:2.01673	eval-mlogloss:3.26212
# [20]	train-mlogloss:1.97395	eval-mlogloss:3.2431
# [21]	train-mlogloss:1.93002	eval-mlogloss:3.22637
# [22]	train-mlogloss:1.89006	eval-mlogloss:3.2099
# [23]	train-mlogloss:1.84993	eval-mlogloss:3.19558
# [24]	train-mlogloss:1.81564	eval-mlogloss:3.18107
# [25]	train-mlogloss:1.77915	eval-mlogloss:3.169
# [26]	train-mlogloss:1.74408	eval-mlogloss:3.1576
# [27]	train-mlogloss:1.71302	eval-mlogloss:3.14665
# [28]	train-mlogloss:1.68056	eval-mlogloss:3.13586
# [29]	train-mlogloss:1.65285	eval-mlogloss:3.12603
# [30]	train-mlogloss:1.62587	eval-mlogloss:3.11634
# [31]	train-mlogloss:1.59929	eval-mlogloss:3.10731
# [32]	train-mlogloss:1.57414	eval-mlogloss:3.09979
# [33]	train-mlogloss:1.54931	eval-mlogloss:3.09249
# [34]	train-mlogloss:1.52655	eval-mlogloss:3.08595
# [35]	train-mlogloss:1.5039	eval-mlogloss:3.07998
# [36]	train-mlogloss:1.47953	eval-mlogloss:3.07533
# [37]	train-mlogloss:1.45978	eval-mlogloss:3.06946
# [38]	train-mlogloss:1.44061	eval-mlogloss:3.06458
# [39]	train-mlogloss:1.42009	eval-mlogloss:3.05905
# [40]	train-mlogloss:1.39945	eval-mlogloss:3.05456
# [41]	train-mlogloss:1.3791	eval-mlogloss:3.05065
# [42]	train-mlogloss:1.36238	eval-mlogloss:3.04707
# [43]	train-mlogloss:1.34568	eval-mlogloss:3.04335
# [44]	train-mlogloss:1.33001	eval-mlogloss:3.04041
# [45]	train-mlogloss:1.31168	eval-mlogloss:3.0381
# [46]	train-mlogloss:1.29402	eval-mlogloss:3.03593
# [47]	train-mlogloss:1.27926	eval-mlogloss:3.03369
# [48]	train-mlogloss:1.26445	eval-mlogloss:3.03116
# [49]	train-mlogloss:1.25225	eval-mlogloss:3.02929
# [50]	train-mlogloss:1.23689	eval-mlogloss:3.02721
# [51]	train-mlogloss:1.22003	eval-mlogloss:3.02556
# [52]	train-mlogloss:1.20811	eval-mlogloss:3.02427
# [53]	train-mlogloss:1.19307	eval-mlogloss:3.02343
# [54]	train-mlogloss:1.18214	eval-mlogloss:3.02228
# [55]	train-mlogloss:1.16678	eval-mlogloss:3.02142
# [56]	train-mlogloss:1.15404	eval-mlogloss:3.02067
# [57]	train-mlogloss:1.14205	eval-mlogloss:3.02002
# [58]	train-mlogloss:1.13084	eval-mlogloss:3.02002
# [59]	train-mlogloss:1.11921	eval-mlogloss:3.01943
# [60]	train-mlogloss:1.10545	eval-mlogloss:3.01958
# [61]	train-mlogloss:1.09342	eval-mlogloss:3.01956
# [62]	train-mlogloss:1.08216	eval-mlogloss:3.01901
# [63]	train-mlogloss:1.06997	eval-mlogloss:3.01863
# [64]	train-mlogloss:1.05815	eval-mlogloss:3.01897
# [65]	train-mlogloss:1.04763	eval-mlogloss:3.01964
# [66]	train-mlogloss:1.03595	eval-mlogloss:3.01978
# [67]	train-mlogloss:1.02521	eval-mlogloss:3.02001
# [68]	train-mlogloss:1.01492	eval-mlogloss:3.02069
# [69]	train-mlogloss:1.00474	eval-mlogloss:3.02107
# [70]	train-mlogloss:0.99407	eval-mlogloss:3.02199
# [71]	train-mlogloss:0.984136	eval-mlogloss:3.02279
# [72]	train-mlogloss:0.975558	eval-mlogloss:3.02335
# [73]	train-mlogloss:0.965668	eval-mlogloss:3.02379
# Stopping. Best iteration:
# [63]	train-mlogloss:1.06997	eval-mlogloss:3.01863
#
# 0.01439946003900104
# [0]	train-mlogloss:4.31729	eval-mlogloss:4.59369
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:3.95861	eval-mlogloss:4.33741
# [2]	train-mlogloss:3.69091	eval-mlogloss:4.15911
# [3]	train-mlogloss:3.47822	eval-mlogloss:4.02204
# [4]	train-mlogloss:3.30684	eval-mlogloss:3.91036
# [5]	train-mlogloss:3.15005	eval-mlogloss:3.81969
# [6]	train-mlogloss:3.0156	eval-mlogloss:3.74074
# [7]	train-mlogloss:2.88941	eval-mlogloss:3.67137
# [8]	train-mlogloss:2.78002	eval-mlogloss:3.61216
# [9]	train-mlogloss:2.68291	eval-mlogloss:3.55978
# [10]	train-mlogloss:2.59571	eval-mlogloss:3.51276
# [11]	train-mlogloss:2.51761	eval-mlogloss:3.47094
# [12]	train-mlogloss:2.4449	eval-mlogloss:3.43278
# [13]	train-mlogloss:2.37137	eval-mlogloss:3.39832
# [14]	train-mlogloss:2.30454	eval-mlogloss:3.36632
# [15]	train-mlogloss:2.25045	eval-mlogloss:3.33796
# [16]	train-mlogloss:2.19191	eval-mlogloss:3.311
# [17]	train-mlogloss:2.13747	eval-mlogloss:3.28571
# [18]	train-mlogloss:2.08829	eval-mlogloss:3.2627
# [19]	train-mlogloss:2.03864	eval-mlogloss:3.2437
# [20]	train-mlogloss:1.99383	eval-mlogloss:3.22531
# [21]	train-mlogloss:1.95135	eval-mlogloss:3.20803
# [22]	train-mlogloss:1.91098	eval-mlogloss:3.19104
# [23]	train-mlogloss:1.8738	eval-mlogloss:3.17527
# [24]	train-mlogloss:1.83438	eval-mlogloss:3.16113
# [25]	train-mlogloss:1.79995	eval-mlogloss:3.14811
# [26]	train-mlogloss:1.76416	eval-mlogloss:3.13679
# [27]	train-mlogloss:1.72903	eval-mlogloss:3.12669
# [28]	train-mlogloss:1.69905	eval-mlogloss:3.11642
# [29]	train-mlogloss:1.66988	eval-mlogloss:3.10618
# [30]	train-mlogloss:1.64177	eval-mlogloss:3.09661
# [31]	train-mlogloss:1.61383	eval-mlogloss:3.08699
# [32]	train-mlogloss:1.59085	eval-mlogloss:3.07865
# [33]	train-mlogloss:1.56791	eval-mlogloss:3.07106
# [34]	train-mlogloss:1.54597	eval-mlogloss:3.06419
# [35]	train-mlogloss:1.52473	eval-mlogloss:3.05764
# [36]	train-mlogloss:1.50041	eval-mlogloss:3.0517
# [37]	train-mlogloss:1.47808	eval-mlogloss:3.04695
# [38]	train-mlogloss:1.45774	eval-mlogloss:3.04186
# [39]	train-mlogloss:1.43493	eval-mlogloss:3.03692
# [40]	train-mlogloss:1.41407	eval-mlogloss:3.03271
# [41]	train-mlogloss:1.39452	eval-mlogloss:3.02927
# [42]	train-mlogloss:1.37557	eval-mlogloss:3.02577
# [43]	train-mlogloss:1.35564	eval-mlogloss:3.02143
# [44]	train-mlogloss:1.339	eval-mlogloss:3.01821
# [45]	train-mlogloss:1.32225	eval-mlogloss:3.01505
# [46]	train-mlogloss:1.30462	eval-mlogloss:3.0126
# [47]	train-mlogloss:1.28805	eval-mlogloss:3.01042
# [48]	train-mlogloss:1.27213	eval-mlogloss:3.00895
# [49]	train-mlogloss:1.25677	eval-mlogloss:3.00712
# [50]	train-mlogloss:1.24168	eval-mlogloss:3.00581
# [51]	train-mlogloss:1.22787	eval-mlogloss:3.00424
# [52]	train-mlogloss:1.21522	eval-mlogloss:3.00333
# [53]	train-mlogloss:1.20178	eval-mlogloss:3.00203
# [54]	train-mlogloss:1.18703	eval-mlogloss:3.00075
# [55]	train-mlogloss:1.17333	eval-mlogloss:2.99984
# [56]	train-mlogloss:1.16092	eval-mlogloss:2.99887
# [57]	train-mlogloss:1.14667	eval-mlogloss:2.99845
# [58]	train-mlogloss:1.13653	eval-mlogloss:2.99824
# [59]	train-mlogloss:1.12356	eval-mlogloss:2.99768
# [60]	train-mlogloss:1.11249	eval-mlogloss:2.99703
# [61]	train-mlogloss:1.10307	eval-mlogloss:2.99695
# [62]	train-mlogloss:1.0887	eval-mlogloss:2.9972
# [63]	train-mlogloss:1.07705	eval-mlogloss:2.99779
# [64]	train-mlogloss:1.06489	eval-mlogloss:2.99843
# [65]	train-mlogloss:1.05344	eval-mlogloss:2.99813
# [66]	train-mlogloss:1.04419	eval-mlogloss:2.99783
# [67]	train-mlogloss:1.03367	eval-mlogloss:2.99797
# [68]	train-mlogloss:1.02373	eval-mlogloss:2.99831
# [69]	train-mlogloss:1.01318	eval-mlogloss:2.99824
# [70]	train-mlogloss:1.00418	eval-mlogloss:2.99849
# [71]	train-mlogloss:0.994855	eval-mlogloss:2.99907
# Stopping. Best iteration:
# [61]	train-mlogloss:1.10307	eval-mlogloss:2.99695
#
# 0.014263435465008889
# crps list: [0.012463530769226253, 0.012254392817461731, 0.011967620183047138, 0.01439946003900104, 0.014263435465008889]
# average crps: 0.01306968785474901

# %% [markdown]
# - DIrから最後30個まで
# - crps list: [0.01306208230030206, 0.012845522370741002, 0.012312934091543165, 0.014272256152330345, 0.01411467909845058]
# - average crps: 0.013321494802673431
# -
# - 全変数での確認
# - crps list: [0.012463530769226253, 0.012254392817461731, 0.011967620183047138, 0.01439946003900104, 0.014263435465008889]
# - average crps: 0.01306968785474901

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'AttackAngle', 'time_end', 'Grass', 'DefendersInTheBox_vs_Distance',
#        'DisToQB', 'runner_height', 'DefenseAveX', 'DefenseAveY',
#        'DefenseAveMomentum', 'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos',
#        '1stDefender_AttackAngle', 'RusherVoronoi', 'FirstDefenderVoronoi'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                          Features  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                        Distance     400     118     177     219     263
# 1                           Grass     154     609     227     422     182
# 2                OffenseFormation     282     379     763     797     425
# 3               DefendersInTheBox     360     318     324    1175    1044
# 4                     DefenseAveX    1700     268     456     326     705
# 5                            Team     226     652     764     701    2474
# 6                         Stadium    1464    1183     363    1764     707
# 7                            Down     258    1140    1479    1162    1661
# 8                  OffenseSpreadX    1899     230    2098    1328     432
# 9                     StadiumType     679    1863    3176     270     262
# 10                            age    2362     711    2672     124     653
# 11                  WindDirection    1337     263    1434    1374    2430
# 12         VisitorScoreBeforePlay    1151    1355    1950    2257     153
# 13                           Week    1234    1753    1242    1169    1796
# 14                   JerseyNumber    1397    1149    1243    1263    2286
# 15             DefenseStdMomentum    2749     216    2370    1706     942
# 16                      WindSpeed    1187    2269    3171     285    1121
# 17                       YardLine    1104    1010    2985    2933     292
# 18               OffensePersonnel     690    2704    1259    2313    1366
# 19       1stOffenser_Momentum_cos    2694    2811     730    1085    1054
# 20         DefenseStdMomentum_cos    2956    1362     333     678    3152
# 21                    DefenseStdY    2253    1593    1533    1951    1152
# 22                    DefenseStdX    2301    2407    1195     329    2295
# 23                         Season     274    2197    3004    2275    1458
# 24                  RusherVoronoi    1126    1094    3164    1397    2517
# 25              PlayerCollegeName    1857    1061    2365    1151    2903
# 26  DefendersInTheBox_vs_Distance    1057    2709    2541    1702    1334
# 27             OffenseAveMomentum    2346    1370    2275    2384    1320
# 28                    Temperature    1751    2107    2601    2096    1158
# 29                        DisToQB    3036    1027    1040    2443    2204
# 30                              S    1567    1499    2460    1656    2598
# 31                    OffenseStdY    2151    2618    1690    2333    1164
# 32         RunnerToOffenseCentoid    2628    1841    2985     723    1789
# 33                          NflId    1711    3091     758    2087    2360
# 34                       time_end    2753    1285    1302    2417    2282
# 35                  MinTackleTime    2698    2232    2719    1019    1371
# 36            HomeScoreBeforePlay    1170     761    3039    2582    2683
# 37                       Humidity    1872    2963    1513    1815    2127
# 38                            Dir    2104    2501    1341    2651    1694
# 39             DefenseAveMomentum    2360    2466    2488    1060    1953
# 40                        Dir_cos    2160    2050    2250    2026    1918
# 41                   PlayerWeight    1381    2501    2672    1258    2695
# 42           FirstDefenderVoronoi    2890    2330    2811    1351    1177
# 43              RunnerToScrimmage    2267    1635    2285    1527    2862
# 44                  runner_height     729    2948    1995    2374    2624
# 45         OffenseAveMomentum_cos    3047    2359     291    2425    2646
# 46                       Location    1364    2252    1941    2501    2752
# 47                            Dis    1118    2862    1877    2888    2147
# 48                 DefenseSpreadX    2599    2476    2578    2667     633
# 49                              Y    2442    2928    1235    2746    1663
# 50               DefensePersonnel     626    2876    3151    2267    2130
# 51                   Momentum_cos    2595    2278    1252    2909    2088
# 52                              X    1754    2235    3743    1528    1897
# 53       1stDefender_Momentum_cos    3088    2598    1826    2164    1712
# 54             OffenseStdMomentum    2948    1725    1646    2975    2156
# 55                    Orientation    2433    1884    2821    1883    2469
# 56                    DefenseAveY    2577    1374    1975    2813    2822
# 57         RunnerToDefenseCentoid    2352    2457    2051    2662    2058
# 58                       Momentum    1919    1838    2395    2874    2818
# 59         OffenseStdMomentum_cos    2209    2324    3079    2963    1337
# 60        1stDefender_AttackAngle    3134    2358    2634    2850    1631
# 61                    GameWeather    1137    3029    3101    2551    2854
# 62         DefenseAveMomentum_cos    2992    1142    2593    3160    2888
# 63                    OffenseStdX    2172    2837    3091    2101    2838
# 64                              A    3488    3408    3269    3633    3548
#
#     Average          Std        Cv
# 0     235.4    95.202101  0.404427
# 1     318.8   172.723363  0.541792
# 2     529.2   210.192674  0.397189
# 3     644.2   382.437655  0.593663
# 4     691.0   526.432522  0.761842
# 5     963.4   778.621243  0.808201
# 6    1096.2   505.534727  0.461170
# 7    1140.0   482.653085  0.423380
# 8    1197.4   753.933578  0.629642
# 9    1250.0  1126.750194  0.901400
# 10   1304.4  1015.739849  0.778703
# 11   1367.6   686.180909  0.501741
# 12   1373.2   728.339591  0.530396
# 13   1438.8   275.600726  0.191549
# 14   1467.6   416.791363  0.283995
# 15   1596.6   924.413241  0.578989
# 16   1606.6  1004.452010  0.625204
# 17   1664.8  1093.535441  0.656857
# 18   1666.4   735.428746  0.441328
# 19   1674.8   889.451831  0.531079
# 20   1696.2  1158.722124  0.683128
# 21   1696.4   376.400638  0.221882
# 22   1705.4   818.485822  0.479938
# 23   1841.6   924.103587  0.501794
# 24   1859.6   833.300090  0.448107
# 25   1867.4   704.796595  0.377421
# 26   1868.6   652.784988  0.349344
# 27   1939.0   486.516598  0.250911
# 28   1942.6   476.729945  0.245408
# 29   1950.0   795.863054  0.408135
# 30   1956.0   472.514550  0.241572
# 31   1991.2   511.902881  0.257083
# 32   1993.2   782.931517  0.392801
# 33   2001.4   768.573380  0.384018
# 34   2007.8   603.083212  0.300370
# 35   2007.8   695.080830  0.346190
# 36   2047.0   905.285590  0.442250
# 37   2058.0   492.839933  0.239475
# 38   2058.2   489.203189  0.237685
# 39   2065.4   538.390787  0.260671
# 40   2080.8   114.330049  0.054945
# 41   2101.4   643.105777  0.306037
# 42   2111.8   720.382510  0.341123
# 43   2115.2   487.064020  0.230269
# 44   2134.0   768.588577  0.360163
# 45   2153.6   961.846890  0.446623
# 46   2162.0   480.991892  0.222475
# 47   2178.4   661.379951  0.303608
# 48   2190.6   781.203840  0.356616
# 49   2202.8   649.032942  0.294640
# 50   2210.0   877.239078  0.396941
# 51   2224.4   560.903058  0.252159
# 52   2231.4   789.867483  0.353978
# 53   2277.6   509.147366  0.223546
# 54   2290.0   575.170583  0.251166
# 55   2298.0   364.586341  0.158654
# 56   2312.2   561.202067  0.242713
# 57   2316.0   235.661622  0.101754
# 58   2368.8   433.996037  0.183213
# 59   2382.4   624.289548  0.262042
# 60   2521.4   512.922450  0.203428
# 61   2534.4   723.990497  0.285665
# 62   2555.0   730.191208  0.285789
# 63   2607.8   396.427749  0.152016
# 64   3469.2   124.272925  0.035822

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    dtest = xgb.DMatrix(X_test)
    for model in models:
        pred_value += model.predict(dtest)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

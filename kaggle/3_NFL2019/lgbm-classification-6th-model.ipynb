# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
from sklearn.metrics import roc_auc_score,mean_squared_error,mean_absolute_error
import xgboost as xgb
from datetime import datetime
import gc
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
      
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                   'Turf', 'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'PossessionTeam', 'FieldPosition', 
                   'HomeTeamAbbr', 'VisitorTeamAbbr', 'PlayerHeight']

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    rusher_x = np.repeat(rusher_x, 22) # repeat each elemnt 22 times df["RusherX"]
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    rusher_y = np.repeat(rusher_y, 22) # df["RusherY"]
    df["DisToRusher"] = np.sqrt((df["X"] - rusher_x) ** 2 + (df["Y"] - rusher_y) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]

    rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    rusher_s = np.repeat(rusher_s, 22)
    df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single['TimeHandoff'] = df_single['TimeHandoff'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    df_single['TimeSnap'] = df_single['TimeSnap'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    df_single['handoff_snap_diff'] = (df_single['TimeHandoff'] - df_single['TimeSnap']).map(lambda x:x.seconds)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #top20_weather = list(df.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    #df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["OffenseFormation"] = df_single["OffenseFormation"].apply(lambda x: "SHOTGUN" if x== "ACE" else x)

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])

    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])

    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])

    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - df_single["YardLine"]

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    #first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    #df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher"]#, "TackleTimeToRusher", "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)
    
    #if "Yards" in df_single.columns:
    #    df["Yards"] = df["Yards"] + 99 # to categorize

    return df_single

# %%
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : -1,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86899
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86684
# [3]	valid_0's multi_logloss: 2.86488
# [4]	valid_0's multi_logloss: 2.86249
# [5]	valid_0's multi_logloss: 2.86049
# [6]	valid_0's multi_logloss: 2.85849
# [7]	valid_0's multi_logloss: 2.85658
# [8]	valid_0's multi_logloss: 2.85492
# [9]	valid_0's multi_logloss: 2.85309
# [10]	valid_0's multi_logloss: 2.85133
# [11]	valid_0's multi_logloss: 2.84962
# [12]	valid_0's multi_logloss: 2.84812
# [13]	valid_0's multi_logloss: 2.84638
# [14]	valid_0's multi_logloss: 2.8446
# [15]	valid_0's multi_logloss: 2.84306
# [16]	valid_0's multi_logloss: 2.84142
# [17]	valid_0's multi_logloss: 2.8399
# [18]	valid_0's multi_logloss: 2.83834
# [19]	valid_0's multi_logloss: 2.83689
# [20]	valid_0's multi_logloss: 2.83549
# [21]	valid_0's multi_logloss: 2.83405
# [22]	valid_0's multi_logloss: 2.83262
# [23]	valid_0's multi_logloss: 2.83124
# [24]	valid_0's multi_logloss: 2.83
# [25]	valid_0's multi_logloss: 2.82861
# [26]	valid_0's multi_logloss: 2.82731
# [27]	valid_0's multi_logloss: 2.82602
# [28]	valid_0's multi_logloss: 2.82472
# [29]	valid_0's multi_logloss: 2.82355
# [30]	valid_0's multi_logloss: 2.82229
# [31]	valid_0's multi_logloss: 2.82106
# [32]	valid_0's multi_logloss: 2.81981
# [33]	valid_0's multi_logloss: 2.81859
# [34]	valid_0's multi_logloss: 2.81748
# [35]	valid_0's multi_logloss: 2.81635
# [36]	valid_0's multi_logloss: 2.81509
# [37]	valid_0's multi_logloss: 2.81397
# [38]	valid_0's multi_logloss: 2.81273
# [39]	valid_0's multi_logloss: 2.81146
# [40]	valid_0's multi_logloss: 2.81028
# [41]	valid_0's multi_logloss: 2.80918
# [42]	valid_0's multi_logloss: 2.80806
# [43]	valid_0's multi_logloss: 2.80704
# [44]	valid_0's multi_logloss: 2.80598
# [45]	valid_0's multi_logloss: 2.80491
# [46]	valid_0's multi_logloss: 2.80396
# [47]	valid_0's multi_logloss: 2.80296
# [48]	valid_0's multi_logloss: 2.80203
# [49]	valid_0's multi_logloss: 2.80101
# [50]	valid_0's multi_logloss: 2.80008
# [51]	valid_0's multi_logloss: 2.79914
# [52]	valid_0's multi_logloss: 2.79814
# [53]	valid_0's multi_logloss: 2.7971
# [54]	valid_0's multi_logloss: 2.7962
# [55]	valid_0's multi_logloss: 2.79531
# [56]	valid_0's multi_logloss: 2.79446
# [57]	valid_0's multi_logloss: 2.79358
# [58]	valid_0's multi_logloss: 2.79271
# [59]	valid_0's multi_logloss: 2.79194
# [60]	valid_0's multi_logloss: 2.79099
# [61]	valid_0's multi_logloss: 2.79019
# [62]	valid_0's multi_logloss: 2.78932
# [63]	valid_0's multi_logloss: 2.78846
# [64]	valid_0's multi_logloss: 2.78756
# [65]	valid_0's multi_logloss: 2.78676
# [66]	valid_0's multi_logloss: 2.78586
# [67]	valid_0's multi_logloss: 2.78503
# [68]	valid_0's multi_logloss: 2.78417
# [69]	valid_0's multi_logloss: 2.78354
# [70]	valid_0's multi_logloss: 2.78269
# [71]	valid_0's multi_logloss: 2.78199
# [72]	valid_0's multi_logloss: 2.78124
# [73]	valid_0's multi_logloss: 2.78038
# [74]	valid_0's multi_logloss: 2.77964
# [75]	valid_0's multi_logloss: 2.7788
# [76]	valid_0's multi_logloss: 2.77805
# [77]	valid_0's multi_logloss: 2.77719
# [78]	valid_0's multi_logloss: 2.77648
# [79]	valid_0's multi_logloss: 2.77574
# [80]	valid_0's multi_logloss: 2.77499
# [81]	valid_0's multi_logloss: 2.77425
# [82]	valid_0's multi_logloss: 2.77357
# [83]	valid_0's multi_logloss: 2.77293
# [84]	valid_0's multi_logloss: 2.77224
# [85]	valid_0's multi_logloss: 2.77157
# [86]	valid_0's multi_logloss: 2.77091
# [87]	valid_0's multi_logloss: 2.77022
# [88]	valid_0's multi_logloss: 2.76956
# [89]	valid_0's multi_logloss: 2.76894
# [90]	valid_0's multi_logloss: 2.76829
# [91]	valid_0's multi_logloss: 2.76765
# [92]	valid_0's multi_logloss: 2.76695
# [93]	valid_0's multi_logloss: 2.7663
# [94]	valid_0's multi_logloss: 2.76567
# [95]	valid_0's multi_logloss: 2.765
# [96]	valid_0's multi_logloss: 2.76431
# [97]	valid_0's multi_logloss: 2.76368
# [98]	valid_0's multi_logloss: 2.76302
# [99]	valid_0's multi_logloss: 2.76232
# [100]	valid_0's multi_logloss: 2.76172
# [101]	valid_0's multi_logloss: 2.76105
# [102]	valid_0's multi_logloss: 2.7604
# [103]	valid_0's multi_logloss: 2.75984
# [104]	valid_0's multi_logloss: 2.7592
# [105]	valid_0's multi_logloss: 2.75868
# [106]	valid_0's multi_logloss: 2.75804
# [107]	valid_0's multi_logloss: 2.75753
# [108]	valid_0's multi_logloss: 2.75688
# [109]	valid_0's multi_logloss: 2.75629
# [110]	valid_0's multi_logloss: 2.75568
# [111]	valid_0's multi_logloss: 2.75519
# [112]	valid_0's multi_logloss: 2.75451
# [113]	valid_0's multi_logloss: 2.75395
# [114]	valid_0's multi_logloss: 2.75347
# [115]	valid_0's multi_logloss: 2.75298
# [116]	valid_0's multi_logloss: 2.75239
# [117]	valid_0's multi_logloss: 2.75178
# [118]	valid_0's multi_logloss: 2.75124
# [119]	valid_0's multi_logloss: 2.75072
# [120]	valid_0's multi_logloss: 2.7502
# [121]	valid_0's multi_logloss: 2.74972
# [122]	valid_0's multi_logloss: 2.74922
# [123]	valid_0's multi_logloss: 2.74868
# [124]	valid_0's multi_logloss: 2.74813
# [125]	valid_0's multi_logloss: 2.7477
# [126]	valid_0's multi_logloss: 2.74718
# [127]	valid_0's multi_logloss: 2.74674
# [128]	valid_0's multi_logloss: 2.74633
# [129]	valid_0's multi_logloss: 2.74579
# [130]	valid_0's multi_logloss: 2.74535
# [131]	valid_0's multi_logloss: 2.74491
# [132]	valid_0's multi_logloss: 2.74442
# [133]	valid_0's multi_logloss: 2.74398
# [134]	valid_0's multi_logloss: 2.74346
# [135]	valid_0's multi_logloss: 2.74301
# [136]	valid_0's multi_logloss: 2.74252
# [137]	valid_0's multi_logloss: 2.74203
# [138]	valid_0's multi_logloss: 2.74162
# [139]	valid_0's multi_logloss: 2.7411
# [140]	valid_0's multi_logloss: 2.74061
# [141]	valid_0's multi_logloss: 2.74012
# [142]	valid_0's multi_logloss: 2.73971
# [143]	valid_0's multi_logloss: 2.73931
# [144]	valid_0's multi_logloss: 2.73886
# [145]	valid_0's multi_logloss: 2.73838
# [146]	valid_0's multi_logloss: 2.73801
# [147]	valid_0's multi_logloss: 2.73752
# [148]	valid_0's multi_logloss: 2.73714
# [149]	valid_0's multi_logloss: 2.73671
# [150]	valid_0's multi_logloss: 2.73631
# [151]	valid_0's multi_logloss: 2.73594
# [152]	valid_0's multi_logloss: 2.73549
# [153]	valid_0's multi_logloss: 2.73506
# [154]	valid_0's multi_logloss: 2.7346
# [155]	valid_0's multi_logloss: 2.73423
# [156]	valid_0's multi_logloss: 2.7339
# [157]	valid_0's multi_logloss: 2.73348
# [158]	valid_0's multi_logloss: 2.73314
# [159]	valid_0's multi_logloss: 2.73278
# [160]	valid_0's multi_logloss: 2.7324
# [161]	valid_0's multi_logloss: 2.73197
# [162]	valid_0's multi_logloss: 2.73162
# [163]	valid_0's multi_logloss: 2.73119
# [164]	valid_0's multi_logloss: 2.73091
# [165]	valid_0's multi_logloss: 2.73056
# [166]	valid_0's multi_logloss: 2.73027
# [167]	valid_0's multi_logloss: 2.7299
# [168]	valid_0's multi_logloss: 2.72959
# [169]	valid_0's multi_logloss: 2.72925
# [170]	valid_0's multi_logloss: 2.72887
# [171]	valid_0's multi_logloss: 2.72847
# [172]	valid_0's multi_logloss: 2.72815
# [173]	valid_0's multi_logloss: 2.72783
# [174]	valid_0's multi_logloss: 2.72755
# [175]	valid_0's multi_logloss: 2.72718
# [176]	valid_0's multi_logloss: 2.72674
# [177]	valid_0's multi_logloss: 2.72643
# [178]	valid_0's multi_logloss: 2.72613
# [179]	valid_0's multi_logloss: 2.72577
# [180]	valid_0's multi_logloss: 2.72542
# [181]	valid_0's multi_logloss: 2.72505
# [182]	valid_0's multi_logloss: 2.72476
# [183]	valid_0's multi_logloss: 2.7245
# [184]	valid_0's multi_logloss: 2.72419
# [185]	valid_0's multi_logloss: 2.72393
# [186]	valid_0's multi_logloss: 2.72361
# [187]	valid_0's multi_logloss: 2.72337
# [188]	valid_0's multi_logloss: 2.72298
# [189]	valid_0's multi_logloss: 2.72276
# [190]	valid_0's multi_logloss: 2.72247
# [191]	valid_0's multi_logloss: 2.72222
# [192]	valid_0's multi_logloss: 2.72201
# [193]	valid_0's multi_logloss: 2.72176
# [194]	valid_0's multi_logloss: 2.7214
# [195]	valid_0's multi_logloss: 2.72115
# [196]	valid_0's multi_logloss: 2.72088
# [197]	valid_0's multi_logloss: 2.72057
# [198]	valid_0's multi_logloss: 2.72035
# [199]	valid_0's multi_logloss: 2.7201
# [200]	valid_0's multi_logloss: 2.71986
# [201]	valid_0's multi_logloss: 2.71955
# [202]	valid_0's multi_logloss: 2.71931
# [203]	valid_0's multi_logloss: 2.71907
# [204]	valid_0's multi_logloss: 2.71887
# [205]	valid_0's multi_logloss: 2.71865
# [206]	valid_0's multi_logloss: 2.71837
# [207]	valid_0's multi_logloss: 2.71815
# [208]	valid_0's multi_logloss: 2.71784
# [209]	valid_0's multi_logloss: 2.71765
# [210]	valid_0's multi_logloss: 2.71742
# [211]	valid_0's multi_logloss: 2.71715
# [212]	valid_0's multi_logloss: 2.7169
# [213]	valid_0's multi_logloss: 2.71667
# [214]	valid_0's multi_logloss: 2.71649
# [215]	valid_0's multi_logloss: 2.71629
# [216]	valid_0's multi_logloss: 2.7161
# [217]	valid_0's multi_logloss: 2.71589
# [218]	valid_0's multi_logloss: 2.7157
# [219]	valid_0's multi_logloss: 2.71545
# [220]	valid_0's multi_logloss: 2.7152
# [221]	valid_0's multi_logloss: 2.71501
# [222]	valid_0's multi_logloss: 2.71477
# [223]	valid_0's multi_logloss: 2.71456
# [224]	valid_0's multi_logloss: 2.71435
# [225]	valid_0's multi_logloss: 2.71414
# [226]	valid_0's multi_logloss: 2.71393
# [227]	valid_0's multi_logloss: 2.71376
# [228]	valid_0's multi_logloss: 2.71357
# [229]	valid_0's multi_logloss: 2.71331
# [230]	valid_0's multi_logloss: 2.71308
# [231]	valid_0's multi_logloss: 2.7129
# [232]	valid_0's multi_logloss: 2.71272
# [233]	valid_0's multi_logloss: 2.71254
# [234]	valid_0's multi_logloss: 2.71231
# [235]	valid_0's multi_logloss: 2.71216
# [236]	valid_0's multi_logloss: 2.71194
# [237]	valid_0's multi_logloss: 2.71175
# [238]	valid_0's multi_logloss: 2.71162
# [239]	valid_0's multi_logloss: 2.7114
# [240]	valid_0's multi_logloss: 2.71118
# [241]	valid_0's multi_logloss: 2.71094
# [242]	valid_0's multi_logloss: 2.71083
# [243]	valid_0's multi_logloss: 2.71061
# [244]	valid_0's multi_logloss: 2.7104
# [245]	valid_0's multi_logloss: 2.71028
# [246]	valid_0's multi_logloss: 2.71003
# [247]	valid_0's multi_logloss: 2.70984
# [248]	valid_0's multi_logloss: 2.7097
# [249]	valid_0's multi_logloss: 2.70952
# [250]	valid_0's multi_logloss: 2.70937
# [251]	valid_0's multi_logloss: 2.70919
# [252]	valid_0's multi_logloss: 2.70902
# [253]	valid_0's multi_logloss: 2.70881
# [254]	valid_0's multi_logloss: 2.70864
# [255]	valid_0's multi_logloss: 2.70854
# [256]	valid_0's multi_logloss: 2.70833
# [257]	valid_0's multi_logloss: 2.7082
# [258]	valid_0's multi_logloss: 2.70806
# [259]	valid_0's multi_logloss: 2.70793
# [260]	valid_0's multi_logloss: 2.70775
# [261]	valid_0's multi_logloss: 2.70761
# [262]	valid_0's multi_logloss: 2.70739
# [263]	valid_0's multi_logloss: 2.70726
# [264]	valid_0's multi_logloss: 2.7071
# [265]	valid_0's multi_logloss: 2.7069
# [266]	valid_0's multi_logloss: 2.70683
# [267]	valid_0's multi_logloss: 2.70668
# [268]	valid_0's multi_logloss: 2.70657
# [269]	valid_0's multi_logloss: 2.7064
# [270]	valid_0's multi_logloss: 2.70625
# [271]	valid_0's multi_logloss: 2.70608
# [272]	valid_0's multi_logloss: 2.70594
# [273]	valid_0's multi_logloss: 2.70589
# [274]	valid_0's multi_logloss: 2.7057
# [275]	valid_0's multi_logloss: 2.70556
# [276]	valid_0's multi_logloss: 2.70541
# [277]	valid_0's multi_logloss: 2.70532
# [278]	valid_0's multi_logloss: 2.70514
# [279]	valid_0's multi_logloss: 2.70495
# [280]	valid_0's multi_logloss: 2.70484
# [281]	valid_0's multi_logloss: 2.70473
# [282]	valid_0's multi_logloss: 2.70455
# [283]	valid_0's multi_logloss: 2.70445
# [284]	valid_0's multi_logloss: 2.7043
# [285]	valid_0's multi_logloss: 2.70417
# [286]	valid_0's multi_logloss: 2.70404
# [287]	valid_0's multi_logloss: 2.70389
# [288]	valid_0's multi_logloss: 2.70369
# [289]	valid_0's multi_logloss: 2.70355
# [290]	valid_0's multi_logloss: 2.70345
# [291]	valid_0's multi_logloss: 2.70329
# [292]	valid_0's multi_logloss: 2.7032
# [293]	valid_0's multi_logloss: 2.7031
# [294]	valid_0's multi_logloss: 2.70298
# [295]	valid_0's multi_logloss: 2.70281
# [296]	valid_0's multi_logloss: 2.70271
# [297]	valid_0's multi_logloss: 2.70261
# [298]	valid_0's multi_logloss: 2.70244
# [299]	valid_0's multi_logloss: 2.70221
# [300]	valid_0's multi_logloss: 2.70217
# [301]	valid_0's multi_logloss: 2.70212
# [302]	valid_0's multi_logloss: 2.70193
# [303]	valid_0's multi_logloss: 2.70177
# [304]	valid_0's multi_logloss: 2.70163
# [305]	valid_0's multi_logloss: 2.70154
# [306]	valid_0's multi_logloss: 2.70141
# [307]	valid_0's multi_logloss: 2.70124
# [308]	valid_0's multi_logloss: 2.70115
# [309]	valid_0's multi_logloss: 2.70098
# [310]	valid_0's multi_logloss: 2.7009
# [311]	valid_0's multi_logloss: 2.70077
# [312]	valid_0's multi_logloss: 2.70072
# [313]	valid_0's multi_logloss: 2.70057
# [314]	valid_0's multi_logloss: 2.70053
# [315]	valid_0's multi_logloss: 2.70041
# [316]	valid_0's multi_logloss: 2.70029
# [317]	valid_0's multi_logloss: 2.70017
# [318]	valid_0's multi_logloss: 2.70011
# [319]	valid_0's multi_logloss: 2.69996
# [320]	valid_0's multi_logloss: 2.69977
# [321]	valid_0's multi_logloss: 2.69973
# [322]	valid_0's multi_logloss: 2.69954
# [323]	valid_0's multi_logloss: 2.69948
# [324]	valid_0's multi_logloss: 2.69934
# [325]	valid_0's multi_logloss: 2.69929
# [326]	valid_0's multi_logloss: 2.6992
# [327]	valid_0's multi_logloss: 2.69912
# [328]	valid_0's multi_logloss: 2.69907
# [329]	valid_0's multi_logloss: 2.69895
# [330]	valid_0's multi_logloss: 2.69884
# [331]	valid_0's multi_logloss: 2.69871
# [332]	valid_0's multi_logloss: 2.69857
# [333]	valid_0's multi_logloss: 2.69846
# [334]	valid_0's multi_logloss: 2.69843
# [335]	valid_0's multi_logloss: 2.69833
# [336]	valid_0's multi_logloss: 2.69827
# [337]	valid_0's multi_logloss: 2.69823
# [338]	valid_0's multi_logloss: 2.69812
# [339]	valid_0's multi_logloss: 2.69802
# [340]	valid_0's multi_logloss: 2.69791
# [341]	valid_0's multi_logloss: 2.69781
# [342]	valid_0's multi_logloss: 2.69776
# [343]	valid_0's multi_logloss: 2.69772
# [344]	valid_0's multi_logloss: 2.69761
# [345]	valid_0's multi_logloss: 2.69749
# [346]	valid_0's multi_logloss: 2.69742
# [347]	valid_0's multi_logloss: 2.69736
# [348]	valid_0's multi_logloss: 2.69732
# [349]	valid_0's multi_logloss: 2.69728
# [350]	valid_0's multi_logloss: 2.69721
# [351]	valid_0's multi_logloss: 2.69721
# [352]	valid_0's multi_logloss: 2.6971
# [353]	valid_0's multi_logloss: 2.69707
# [354]	valid_0's multi_logloss: 2.69696
# [355]	valid_0's multi_logloss: 2.69694
# [356]	valid_0's multi_logloss: 2.69692
# [357]	valid_0's multi_logloss: 2.69686
# [358]	valid_0's multi_logloss: 2.69682
# [359]	valid_0's multi_logloss: 2.69676
# [360]	valid_0's multi_logloss: 2.69669
# [361]	valid_0's multi_logloss: 2.69662
# [362]	valid_0's multi_logloss: 2.69654
# [363]	valid_0's multi_logloss: 2.69646
# [364]	valid_0's multi_logloss: 2.69637
# [365]	valid_0's multi_logloss: 2.6963
# [366]	valid_0's multi_logloss: 2.69621
# [367]	valid_0's multi_logloss: 2.69612
# [368]	valid_0's multi_logloss: 2.69614
# [369]	valid_0's multi_logloss: 2.69612
# [370]	valid_0's multi_logloss: 2.69604
# [371]	valid_0's multi_logloss: 2.69599
# [372]	valid_0's multi_logloss: 2.6959
# [373]	valid_0's multi_logloss: 2.69587
# [374]	valid_0's multi_logloss: 2.69583
# [375]	valid_0's multi_logloss: 2.69583
# [376]	valid_0's multi_logloss: 2.69586
# [377]	valid_0's multi_logloss: 2.69579
# [378]	valid_0's multi_logloss: 2.69576
# [379]	valid_0's multi_logloss: 2.69568
# [380]	valid_0's multi_logloss: 2.6957
# [381]	valid_0's multi_logloss: 2.69571
# [382]	valid_0's multi_logloss: 2.69569
# [383]	valid_0's multi_logloss: 2.69571
# [384]	valid_0's multi_logloss: 2.69567
# [385]	valid_0's multi_logloss: 2.69565
# [386]	valid_0's multi_logloss: 2.69564
# [387]	valid_0's multi_logloss: 2.69565
# [388]	valid_0's multi_logloss: 2.69565
# [389]	valid_0's multi_logloss: 2.69557
# [390]	valid_0's multi_logloss: 2.69557
# [391]	valid_0's multi_logloss: 2.69554
# [392]	valid_0's multi_logloss: 2.69551
# [393]	valid_0's multi_logloss: 2.6955
# [394]	valid_0's multi_logloss: 2.69548
# [395]	valid_0's multi_logloss: 2.69552
# [396]	valid_0's multi_logloss: 2.69552
# [397]	valid_0's multi_logloss: 2.69546
# [398]	valid_0's multi_logloss: 2.69546
# [399]	valid_0's multi_logloss: 2.69548
# [400]	valid_0's multi_logloss: 2.69548
# [401]	valid_0's multi_logloss: 2.69544
# [402]	valid_0's multi_logloss: 2.69545
# [403]	valid_0's multi_logloss: 2.69544
# [404]	valid_0's multi_logloss: 2.69542
# [405]	valid_0's multi_logloss: 2.6954
# [406]	valid_0's multi_logloss: 2.69542
# [407]	valid_0's multi_logloss: 2.69538
# [408]	valid_0's multi_logloss: 2.69537
# [409]	valid_0's multi_logloss: 2.69538
# [410]	valid_0's multi_logloss: 2.69533
# [411]	valid_0's multi_logloss: 2.69532
# [412]	valid_0's multi_logloss: 2.69532
# [413]	valid_0's multi_logloss: 2.69531
# [414]	valid_0's multi_logloss: 2.69529
# [415]	valid_0's multi_logloss: 2.69525
# [416]	valid_0's multi_logloss: 2.69527
# [417]	valid_0's multi_logloss: 2.69524
# [418]	valid_0's multi_logloss: 2.69528
# [419]	valid_0's multi_logloss: 2.69526
# [420]	valid_0's multi_logloss: 2.69524
# [421]	valid_0's multi_logloss: 2.69519
# [422]	valid_0's multi_logloss: 2.69517
# [423]	valid_0's multi_logloss: 2.69515
# [424]	valid_0's multi_logloss: 2.69514
# [425]	valid_0's multi_logloss: 2.69513
# [426]	valid_0's multi_logloss: 2.69512
# [427]	valid_0's multi_logloss: 2.69507
# [428]	valid_0's multi_logloss: 2.69504
# [429]	valid_0's multi_logloss: 2.69508
# [430]	valid_0's multi_logloss: 2.69512
# [431]	valid_0's multi_logloss: 2.69511
# [432]	valid_0's multi_logloss: 2.69509
# [433]	valid_0's multi_logloss: 2.69508
# [434]	valid_0's multi_logloss: 2.69507
# [435]	valid_0's multi_logloss: 2.69509
# [436]	valid_0's multi_logloss: 2.69504
# [437]	valid_0's multi_logloss: 2.69506
# [438]	valid_0's multi_logloss: 2.69506
# [439]	valid_0's multi_logloss: 2.69504
# [440]	valid_0's multi_logloss: 2.69502
# [441]	valid_0's multi_logloss: 2.69502
# [442]	valid_0's multi_logloss: 2.69501
# [443]	valid_0's multi_logloss: 2.69503
# [444]	valid_0's multi_logloss: 2.69507
# [445]	valid_0's multi_logloss: 2.69504
# [446]	valid_0's multi_logloss: 2.69504
# [447]	valid_0's multi_logloss: 2.69502
# [448]	valid_0's multi_logloss: 2.69499
# [449]	valid_0's multi_logloss: 2.695
# [450]	valid_0's multi_logloss: 2.695
# [451]	valid_0's multi_logloss: 2.69503
# [452]	valid_0's multi_logloss: 2.69502
# [453]	valid_0's multi_logloss: 2.69504
# [454]	valid_0's multi_logloss: 2.69503
# [455]	valid_0's multi_logloss: 2.69506
# [456]	valid_0's multi_logloss: 2.69512
# [457]	valid_0's multi_logloss: 2.69509
# [458]	valid_0's multi_logloss: 2.69508
# Early stopping, best iteration is:
# [448]	valid_0's multi_logloss: 2.69499
# 0.012515307398608297
# [1]	valid_0's multi_logloss: 2.88685
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88437
# [3]	valid_0's multi_logloss: 2.88225
# [4]	valid_0's multi_logloss: 2.88009
# [5]	valid_0's multi_logloss: 2.878
# [6]	valid_0's multi_logloss: 2.87597
# [7]	valid_0's multi_logloss: 2.874
# [8]	valid_0's multi_logloss: 2.87224
# [9]	valid_0's multi_logloss: 2.87037
# [10]	valid_0's multi_logloss: 2.86855
# [11]	valid_0's multi_logloss: 2.86675
# [12]	valid_0's multi_logloss: 2.8651
# [13]	valid_0's multi_logloss: 2.86334
# [14]	valid_0's multi_logloss: 2.86178
# [15]	valid_0's multi_logloss: 2.86018
# [16]	valid_0's multi_logloss: 2.85866
# [17]	valid_0's multi_logloss: 2.85713
# [18]	valid_0's multi_logloss: 2.85553
# [19]	valid_0's multi_logloss: 2.85406
# [20]	valid_0's multi_logloss: 2.85254
# [21]	valid_0's multi_logloss: 2.85096
# [22]	valid_0's multi_logloss: 2.84956
# [23]	valid_0's multi_logloss: 2.8482
# [24]	valid_0's multi_logloss: 2.84672
# [25]	valid_0's multi_logloss: 2.84532
# [26]	valid_0's multi_logloss: 2.84397
# [27]	valid_0's multi_logloss: 2.84268
# [28]	valid_0's multi_logloss: 2.84147
# [29]	valid_0's multi_logloss: 2.84012
# [30]	valid_0's multi_logloss: 2.83882
# [31]	valid_0's multi_logloss: 2.83749
# [32]	valid_0's multi_logloss: 2.83625
# [33]	valid_0's multi_logloss: 2.83508
# [34]	valid_0's multi_logloss: 2.83388
# [35]	valid_0's multi_logloss: 2.83255
# [36]	valid_0's multi_logloss: 2.8314
# [37]	valid_0's multi_logloss: 2.83018
# [38]	valid_0's multi_logloss: 2.82897
# [39]	valid_0's multi_logloss: 2.82773
# [40]	valid_0's multi_logloss: 2.82665
# [41]	valid_0's multi_logloss: 2.8254
# [42]	valid_0's multi_logloss: 2.8243
# [43]	valid_0's multi_logloss: 2.82315
# [44]	valid_0's multi_logloss: 2.82216
# [45]	valid_0's multi_logloss: 2.82105
# [46]	valid_0's multi_logloss: 2.81999
# [47]	valid_0's multi_logloss: 2.81896
# [48]	valid_0's multi_logloss: 2.81782
# [49]	valid_0's multi_logloss: 2.81689
# [50]	valid_0's multi_logloss: 2.81593
# [51]	valid_0's multi_logloss: 2.81486
# [52]	valid_0's multi_logloss: 2.81379
# [53]	valid_0's multi_logloss: 2.81277
# [54]	valid_0's multi_logloss: 2.81181
# [55]	valid_0's multi_logloss: 2.81075
# [56]	valid_0's multi_logloss: 2.80973
# [57]	valid_0's multi_logloss: 2.80871
# [58]	valid_0's multi_logloss: 2.80766
# [59]	valid_0's multi_logloss: 2.80674
# [60]	valid_0's multi_logloss: 2.80576
# [61]	valid_0's multi_logloss: 2.80488
# [62]	valid_0's multi_logloss: 2.80382
# [63]	valid_0's multi_logloss: 2.8029
# [64]	valid_0's multi_logloss: 2.80195
# [65]	valid_0's multi_logloss: 2.80109
# [66]	valid_0's multi_logloss: 2.8002
# [67]	valid_0's multi_logloss: 2.79929
# [68]	valid_0's multi_logloss: 2.7984
# [69]	valid_0's multi_logloss: 2.79754
# [70]	valid_0's multi_logloss: 2.79659
# [71]	valid_0's multi_logloss: 2.79582
# [72]	valid_0's multi_logloss: 2.79497
# [73]	valid_0's multi_logloss: 2.79416
# [74]	valid_0's multi_logloss: 2.79333
# [75]	valid_0's multi_logloss: 2.79248
# [76]	valid_0's multi_logloss: 2.79164
# [77]	valid_0's multi_logloss: 2.79086
# [78]	valid_0's multi_logloss: 2.78989
# [79]	valid_0's multi_logloss: 2.78908
# [80]	valid_0's multi_logloss: 2.78831
# [81]	valid_0's multi_logloss: 2.78753
# [82]	valid_0's multi_logloss: 2.78671
# [83]	valid_0's multi_logloss: 2.78587
# [84]	valid_0's multi_logloss: 2.78505
# [85]	valid_0's multi_logloss: 2.7844
# [86]	valid_0's multi_logloss: 2.78359
# [87]	valid_0's multi_logloss: 2.78283
# [88]	valid_0's multi_logloss: 2.78204
# [89]	valid_0's multi_logloss: 2.78133
# [90]	valid_0's multi_logloss: 2.78059
# [91]	valid_0's multi_logloss: 2.77982
# [92]	valid_0's multi_logloss: 2.77909
# [93]	valid_0's multi_logloss: 2.77835
# [94]	valid_0's multi_logloss: 2.77754
# [95]	valid_0's multi_logloss: 2.77693
# [96]	valid_0's multi_logloss: 2.77619
# [97]	valid_0's multi_logloss: 2.77544
# [98]	valid_0's multi_logloss: 2.77476
# [99]	valid_0's multi_logloss: 2.77407
# [100]	valid_0's multi_logloss: 2.77337
# [101]	valid_0's multi_logloss: 2.7727
# [102]	valid_0's multi_logloss: 2.77203
# [103]	valid_0's multi_logloss: 2.77133
# [104]	valid_0's multi_logloss: 2.77065
# [105]	valid_0's multi_logloss: 2.76991
# [106]	valid_0's multi_logloss: 2.76929
# [107]	valid_0's multi_logloss: 2.76858
# [108]	valid_0's multi_logloss: 2.7679
# [109]	valid_0's multi_logloss: 2.76732
# [110]	valid_0's multi_logloss: 2.76668
# [111]	valid_0's multi_logloss: 2.76604
# [112]	valid_0's multi_logloss: 2.76537
# [113]	valid_0's multi_logloss: 2.76488
# [114]	valid_0's multi_logloss: 2.76419
# [115]	valid_0's multi_logloss: 2.76361
# [116]	valid_0's multi_logloss: 2.76297
# [117]	valid_0's multi_logloss: 2.76241
# [118]	valid_0's multi_logloss: 2.7619
# [119]	valid_0's multi_logloss: 2.76134
# [120]	valid_0's multi_logloss: 2.7608
# [121]	valid_0's multi_logloss: 2.76028
# [122]	valid_0's multi_logloss: 2.75971
# [123]	valid_0's multi_logloss: 2.75921
# [124]	valid_0's multi_logloss: 2.75863
# [125]	valid_0's multi_logloss: 2.7581
# [126]	valid_0's multi_logloss: 2.75764
# [127]	valid_0's multi_logloss: 2.75707
# [128]	valid_0's multi_logloss: 2.7566
# [129]	valid_0's multi_logloss: 2.75611
# [130]	valid_0's multi_logloss: 2.75564
# [131]	valid_0's multi_logloss: 2.75509
# [132]	valid_0's multi_logloss: 2.7546
# [133]	valid_0's multi_logloss: 2.75405
# [134]	valid_0's multi_logloss: 2.75351
# [135]	valid_0's multi_logloss: 2.75308
# [136]	valid_0's multi_logloss: 2.75257
# [137]	valid_0's multi_logloss: 2.75203
# [138]	valid_0's multi_logloss: 2.75148
# [139]	valid_0's multi_logloss: 2.75098
# [140]	valid_0's multi_logloss: 2.75055
# [141]	valid_0's multi_logloss: 2.75003
# [142]	valid_0's multi_logloss: 2.74956
# [143]	valid_0's multi_logloss: 2.74903
# [144]	valid_0's multi_logloss: 2.7485
# [145]	valid_0's multi_logloss: 2.74796
# [146]	valid_0's multi_logloss: 2.74753
# [147]	valid_0's multi_logloss: 2.74699
# [148]	valid_0's multi_logloss: 2.74658
# [149]	valid_0's multi_logloss: 2.74613
# [150]	valid_0's multi_logloss: 2.74566
# [151]	valid_0's multi_logloss: 2.74517
# [152]	valid_0's multi_logloss: 2.74474
# [153]	valid_0's multi_logloss: 2.74425
# [154]	valid_0's multi_logloss: 2.74372
# [155]	valid_0's multi_logloss: 2.74332
# [156]	valid_0's multi_logloss: 2.74288
# [157]	valid_0's multi_logloss: 2.74243
# [158]	valid_0's multi_logloss: 2.74206
# [159]	valid_0's multi_logloss: 2.74161
# [160]	valid_0's multi_logloss: 2.74121
# [161]	valid_0's multi_logloss: 2.7408
# [162]	valid_0's multi_logloss: 2.74037
# [163]	valid_0's multi_logloss: 2.73992
# [164]	valid_0's multi_logloss: 2.73955
# [165]	valid_0's multi_logloss: 2.73915
# [166]	valid_0's multi_logloss: 2.73872
# [167]	valid_0's multi_logloss: 2.73834
# [168]	valid_0's multi_logloss: 2.73799
# [169]	valid_0's multi_logloss: 2.73764
# [170]	valid_0's multi_logloss: 2.73722
# [171]	valid_0's multi_logloss: 2.73678
# [172]	valid_0's multi_logloss: 2.73642
# [173]	valid_0's multi_logloss: 2.73608
# [174]	valid_0's multi_logloss: 2.7357
# [175]	valid_0's multi_logloss: 2.73531
# [176]	valid_0's multi_logloss: 2.73496
# [177]	valid_0's multi_logloss: 2.73461
# [178]	valid_0's multi_logloss: 2.73425
# [179]	valid_0's multi_logloss: 2.73394
# [180]	valid_0's multi_logloss: 2.73357
# [181]	valid_0's multi_logloss: 2.73319
# [182]	valid_0's multi_logloss: 2.73285
# [183]	valid_0's multi_logloss: 2.73252
# [184]	valid_0's multi_logloss: 2.73218
# [185]	valid_0's multi_logloss: 2.73178
# [186]	valid_0's multi_logloss: 2.73149
# [187]	valid_0's multi_logloss: 2.73114
# [188]	valid_0's multi_logloss: 2.7308
# [189]	valid_0's multi_logloss: 2.73045
# [190]	valid_0's multi_logloss: 2.73008
# [191]	valid_0's multi_logloss: 2.72975
# [192]	valid_0's multi_logloss: 2.72948
# [193]	valid_0's multi_logloss: 2.7292
# [194]	valid_0's multi_logloss: 2.72883
# [195]	valid_0's multi_logloss: 2.72855
# [196]	valid_0's multi_logloss: 2.72823
# [197]	valid_0's multi_logloss: 2.7279
# [198]	valid_0's multi_logloss: 2.72765
# [199]	valid_0's multi_logloss: 2.72735
# [200]	valid_0's multi_logloss: 2.72705
# [201]	valid_0's multi_logloss: 2.72676
# [202]	valid_0's multi_logloss: 2.7265
# [203]	valid_0's multi_logloss: 2.72617
# [204]	valid_0's multi_logloss: 2.72588
# [205]	valid_0's multi_logloss: 2.72564
# [206]	valid_0's multi_logloss: 2.7254
# [207]	valid_0's multi_logloss: 2.72513
# [208]	valid_0's multi_logloss: 2.7248
# [209]	valid_0's multi_logloss: 2.72457
# [210]	valid_0's multi_logloss: 2.72431
# [211]	valid_0's multi_logloss: 2.72404
# [212]	valid_0's multi_logloss: 2.72378
# [213]	valid_0's multi_logloss: 2.72348
# [214]	valid_0's multi_logloss: 2.72323
# [215]	valid_0's multi_logloss: 2.72298
# [216]	valid_0's multi_logloss: 2.72272
# [217]	valid_0's multi_logloss: 2.72249
# [218]	valid_0's multi_logloss: 2.7222
# [219]	valid_0's multi_logloss: 2.72197
# [220]	valid_0's multi_logloss: 2.72174
# [221]	valid_0's multi_logloss: 2.72149
# [222]	valid_0's multi_logloss: 2.72123
# [223]	valid_0's multi_logloss: 2.72098
# [224]	valid_0's multi_logloss: 2.72068
# [225]	valid_0's multi_logloss: 2.72043
# [226]	valid_0's multi_logloss: 2.72016
# [227]	valid_0's multi_logloss: 2.7199
# [228]	valid_0's multi_logloss: 2.71969
# [229]	valid_0's multi_logloss: 2.71947
# [230]	valid_0's multi_logloss: 2.71913
# [231]	valid_0's multi_logloss: 2.71886
# [232]	valid_0's multi_logloss: 2.71863
# [233]	valid_0's multi_logloss: 2.71837
# [234]	valid_0's multi_logloss: 2.7182
# [235]	valid_0's multi_logloss: 2.7179
# [236]	valid_0's multi_logloss: 2.71771
# [237]	valid_0's multi_logloss: 2.7175
# [238]	valid_0's multi_logloss: 2.7173
# [239]	valid_0's multi_logloss: 2.717
# [240]	valid_0's multi_logloss: 2.71676
# [241]	valid_0's multi_logloss: 2.71659
# [242]	valid_0's multi_logloss: 2.71641
# [243]	valid_0's multi_logloss: 2.71619
# [244]	valid_0's multi_logloss: 2.71598
# [245]	valid_0's multi_logloss: 2.71577
# [246]	valid_0's multi_logloss: 2.71555
# [247]	valid_0's multi_logloss: 2.71534
# [248]	valid_0's multi_logloss: 2.7151
# [249]	valid_0's multi_logloss: 2.71488
# [250]	valid_0's multi_logloss: 2.71467
# [251]	valid_0's multi_logloss: 2.71448
# [252]	valid_0's multi_logloss: 2.71429
# [253]	valid_0's multi_logloss: 2.71405
# [254]	valid_0's multi_logloss: 2.71385
# [255]	valid_0's multi_logloss: 2.71361
# [256]	valid_0's multi_logloss: 2.71343
# [257]	valid_0's multi_logloss: 2.71322
# [258]	valid_0's multi_logloss: 2.713
# [259]	valid_0's multi_logloss: 2.71275
# [260]	valid_0's multi_logloss: 2.71248
# [261]	valid_0's multi_logloss: 2.71223
# [262]	valid_0's multi_logloss: 2.71202
# [263]	valid_0's multi_logloss: 2.71181
# [264]	valid_0's multi_logloss: 2.71165
# [265]	valid_0's multi_logloss: 2.71143
# [266]	valid_0's multi_logloss: 2.71119
# [267]	valid_0's multi_logloss: 2.71103
# [268]	valid_0's multi_logloss: 2.71084
# [269]	valid_0's multi_logloss: 2.71067
# [270]	valid_0's multi_logloss: 2.71045
# [271]	valid_0's multi_logloss: 2.71026
# [272]	valid_0's multi_logloss: 2.71008
# [273]	valid_0's multi_logloss: 2.70993
# [274]	valid_0's multi_logloss: 2.70975
# [275]	valid_0's multi_logloss: 2.70957
# [276]	valid_0's multi_logloss: 2.70939
# [277]	valid_0's multi_logloss: 2.70915
# [278]	valid_0's multi_logloss: 2.70896
# [279]	valid_0's multi_logloss: 2.7088
# [280]	valid_0's multi_logloss: 2.70861
# [281]	valid_0's multi_logloss: 2.70842
# [282]	valid_0's multi_logloss: 2.7082
# [283]	valid_0's multi_logloss: 2.70803
# [284]	valid_0's multi_logloss: 2.70789
# [285]	valid_0's multi_logloss: 2.70772
# [286]	valid_0's multi_logloss: 2.70755
# [287]	valid_0's multi_logloss: 2.70733
# [288]	valid_0's multi_logloss: 2.70724
# [289]	valid_0's multi_logloss: 2.70707
# [290]	valid_0's multi_logloss: 2.70688
# [291]	valid_0's multi_logloss: 2.70674
# [292]	valid_0's multi_logloss: 2.70657
# [293]	valid_0's multi_logloss: 2.70645
# [294]	valid_0's multi_logloss: 2.70632
# [295]	valid_0's multi_logloss: 2.70615
# [296]	valid_0's multi_logloss: 2.70602
# [297]	valid_0's multi_logloss: 2.70585
# [298]	valid_0's multi_logloss: 2.7057
# [299]	valid_0's multi_logloss: 2.70557
# [300]	valid_0's multi_logloss: 2.70539
# [301]	valid_0's multi_logloss: 2.70517
# [302]	valid_0's multi_logloss: 2.70506
# [303]	valid_0's multi_logloss: 2.70493
# [304]	valid_0's multi_logloss: 2.70485
# [305]	valid_0's multi_logloss: 2.70468
# [306]	valid_0's multi_logloss: 2.70453
# [307]	valid_0's multi_logloss: 2.70437
# [308]	valid_0's multi_logloss: 2.70424
# [309]	valid_0's multi_logloss: 2.70407
# [310]	valid_0's multi_logloss: 2.70396
# [311]	valid_0's multi_logloss: 2.70382
# [312]	valid_0's multi_logloss: 2.70368
# [313]	valid_0's multi_logloss: 2.7035
# [314]	valid_0's multi_logloss: 2.70339
# [315]	valid_0's multi_logloss: 2.70323
# [316]	valid_0's multi_logloss: 2.70308
# [317]	valid_0's multi_logloss: 2.70301
# [318]	valid_0's multi_logloss: 2.70285
# [319]	valid_0's multi_logloss: 2.70276
# [320]	valid_0's multi_logloss: 2.70258
# [321]	valid_0's multi_logloss: 2.70243
# [322]	valid_0's multi_logloss: 2.70231
# [323]	valid_0's multi_logloss: 2.70212
# [324]	valid_0's multi_logloss: 2.70202
# [325]	valid_0's multi_logloss: 2.7019
# [326]	valid_0's multi_logloss: 2.70176
# [327]	valid_0's multi_logloss: 2.70167
# [328]	valid_0's multi_logloss: 2.70159
# [329]	valid_0's multi_logloss: 2.70147
# [330]	valid_0's multi_logloss: 2.70132
# [331]	valid_0's multi_logloss: 2.70121
# [332]	valid_0's multi_logloss: 2.70114
# [333]	valid_0's multi_logloss: 2.70106
# [334]	valid_0's multi_logloss: 2.70093
# [335]	valid_0's multi_logloss: 2.70086
# [336]	valid_0's multi_logloss: 2.70077
# [337]	valid_0's multi_logloss: 2.70069
# [338]	valid_0's multi_logloss: 2.70055
# [339]	valid_0's multi_logloss: 2.70043
# [340]	valid_0's multi_logloss: 2.70035
# [341]	valid_0's multi_logloss: 2.70024
# [342]	valid_0's multi_logloss: 2.70017
# [343]	valid_0's multi_logloss: 2.7001
# [344]	valid_0's multi_logloss: 2.7
# [345]	valid_0's multi_logloss: 2.69983
# [346]	valid_0's multi_logloss: 2.69975
# [347]	valid_0's multi_logloss: 2.69971
# [348]	valid_0's multi_logloss: 2.69958
# [349]	valid_0's multi_logloss: 2.69948
# [350]	valid_0's multi_logloss: 2.69938
# [351]	valid_0's multi_logloss: 2.69933
# [352]	valid_0's multi_logloss: 2.69927
# [353]	valid_0's multi_logloss: 2.69924
# [354]	valid_0's multi_logloss: 2.69915
# [355]	valid_0's multi_logloss: 2.69902
# [356]	valid_0's multi_logloss: 2.6989
# [357]	valid_0's multi_logloss: 2.69872
# [358]	valid_0's multi_logloss: 2.69865
# [359]	valid_0's multi_logloss: 2.69865
# [360]	valid_0's multi_logloss: 2.69858
# [361]	valid_0's multi_logloss: 2.6985
# [362]	valid_0's multi_logloss: 2.69836
# [363]	valid_0's multi_logloss: 2.69831
# [364]	valid_0's multi_logloss: 2.69819
# [365]	valid_0's multi_logloss: 2.69816
# [366]	valid_0's multi_logloss: 2.69802
# [367]	valid_0's multi_logloss: 2.698
# [368]	valid_0's multi_logloss: 2.6979
# [369]	valid_0's multi_logloss: 2.69782
# [370]	valid_0's multi_logloss: 2.69772
# [371]	valid_0's multi_logloss: 2.6977
# [372]	valid_0's multi_logloss: 2.69759
# [373]	valid_0's multi_logloss: 2.69756
# [374]	valid_0's multi_logloss: 2.69749
# [375]	valid_0's multi_logloss: 2.69745
# [376]	valid_0's multi_logloss: 2.6974
# [377]	valid_0's multi_logloss: 2.69738
# [378]	valid_0's multi_logloss: 2.69733
# [379]	valid_0's multi_logloss: 2.69726
# [380]	valid_0's multi_logloss: 2.69718
# [381]	valid_0's multi_logloss: 2.69706
# [382]	valid_0's multi_logloss: 2.697
# [383]	valid_0's multi_logloss: 2.6969
# [384]	valid_0's multi_logloss: 2.69685
# [385]	valid_0's multi_logloss: 2.69682
# [386]	valid_0's multi_logloss: 2.6968
# [387]	valid_0's multi_logloss: 2.69667
# [388]	valid_0's multi_logloss: 2.69663
# [389]	valid_0's multi_logloss: 2.6966
# [390]	valid_0's multi_logloss: 2.69654
# [391]	valid_0's multi_logloss: 2.69647
# [392]	valid_0's multi_logloss: 2.69646
# [393]	valid_0's multi_logloss: 2.69647
# [394]	valid_0's multi_logloss: 2.6964
# [395]	valid_0's multi_logloss: 2.69634
# [396]	valid_0's multi_logloss: 2.69633
# [397]	valid_0's multi_logloss: 2.69624
# [398]	valid_0's multi_logloss: 2.6962
# [399]	valid_0's multi_logloss: 2.69617
# [400]	valid_0's multi_logloss: 2.69609
# [401]	valid_0's multi_logloss: 2.69603
# [402]	valid_0's multi_logloss: 2.69603
# [403]	valid_0's multi_logloss: 2.69597
# [404]	valid_0's multi_logloss: 2.69595
# [405]	valid_0's multi_logloss: 2.69593
# [406]	valid_0's multi_logloss: 2.69586
# [407]	valid_0's multi_logloss: 2.69584
# [408]	valid_0's multi_logloss: 2.69576
# [409]	valid_0's multi_logloss: 2.69564
# [410]	valid_0's multi_logloss: 2.69563
# [411]	valid_0's multi_logloss: 2.69557
# [412]	valid_0's multi_logloss: 2.69551
# [413]	valid_0's multi_logloss: 2.69547
# [414]	valid_0's multi_logloss: 2.69543
# [415]	valid_0's multi_logloss: 2.69539
# [416]	valid_0's multi_logloss: 2.69538
# [417]	valid_0's multi_logloss: 2.69538
# [418]	valid_0's multi_logloss: 2.69538
# [419]	valid_0's multi_logloss: 2.69533
# [420]	valid_0's multi_logloss: 2.69527
# [421]	valid_0's multi_logloss: 2.69521
# [422]	valid_0's multi_logloss: 2.69514
# [423]	valid_0's multi_logloss: 2.69516
# [424]	valid_0's multi_logloss: 2.69513
# [425]	valid_0's multi_logloss: 2.69506
# [426]	valid_0's multi_logloss: 2.69498
# [427]	valid_0's multi_logloss: 2.69498
# [428]	valid_0's multi_logloss: 2.69499
# [429]	valid_0's multi_logloss: 2.69495
# [430]	valid_0's multi_logloss: 2.69495
# [431]	valid_0's multi_logloss: 2.69489
# [432]	valid_0's multi_logloss: 2.69487
# [433]	valid_0's multi_logloss: 2.69481
# [434]	valid_0's multi_logloss: 2.69476
# [435]	valid_0's multi_logloss: 2.69477
# [436]	valid_0's multi_logloss: 2.69471
# [437]	valid_0's multi_logloss: 2.69467
# [438]	valid_0's multi_logloss: 2.69462
# [439]	valid_0's multi_logloss: 2.69462
# [440]	valid_0's multi_logloss: 2.69461
# [441]	valid_0's multi_logloss: 2.69451
# [442]	valid_0's multi_logloss: 2.69448
# [443]	valid_0's multi_logloss: 2.69448
# [444]	valid_0's multi_logloss: 2.69446
# [445]	valid_0's multi_logloss: 2.69444
# [446]	valid_0's multi_logloss: 2.69442
# [447]	valid_0's multi_logloss: 2.69441
# [448]	valid_0's multi_logloss: 2.69439
# [449]	valid_0's multi_logloss: 2.69437
# [450]	valid_0's multi_logloss: 2.69435
# [451]	valid_0's multi_logloss: 2.69435
# [452]	valid_0's multi_logloss: 2.69427
# [453]	valid_0's multi_logloss: 2.69423
# [454]	valid_0's multi_logloss: 2.69425
# [455]	valid_0's multi_logloss: 2.69419
# [456]	valid_0's multi_logloss: 2.69415
# [457]	valid_0's multi_logloss: 2.6942
# [458]	valid_0's multi_logloss: 2.69414
# [459]	valid_0's multi_logloss: 2.69408
# [460]	valid_0's multi_logloss: 2.69407
# [461]	valid_0's multi_logloss: 2.69408
# [462]	valid_0's multi_logloss: 2.69403
# [463]	valid_0's multi_logloss: 2.69406
# [464]	valid_0's multi_logloss: 2.694
# [465]	valid_0's multi_logloss: 2.69403
# [466]	valid_0's multi_logloss: 2.69404
# [467]	valid_0's multi_logloss: 2.69398
# [468]	valid_0's multi_logloss: 2.69398
# [469]	valid_0's multi_logloss: 2.69396
# [470]	valid_0's multi_logloss: 2.69397
# [471]	valid_0's multi_logloss: 2.6939
# [472]	valid_0's multi_logloss: 2.69391
# [473]	valid_0's multi_logloss: 2.69388
# [474]	valid_0's multi_logloss: 2.69388
# [475]	valid_0's multi_logloss: 2.69391
# [476]	valid_0's multi_logloss: 2.69386
# [477]	valid_0's multi_logloss: 2.6938
# [478]	valid_0's multi_logloss: 2.69379
# [479]	valid_0's multi_logloss: 2.69379
# [480]	valid_0's multi_logloss: 2.69378
# [481]	valid_0's multi_logloss: 2.69381
# [482]	valid_0's multi_logloss: 2.69378
# [483]	valid_0's multi_logloss: 2.69381
# [484]	valid_0's multi_logloss: 2.69379
# [485]	valid_0's multi_logloss: 2.69374
# [486]	valid_0's multi_logloss: 2.6937
# [487]	valid_0's multi_logloss: 2.69372
# [488]	valid_0's multi_logloss: 2.69367
# [489]	valid_0's multi_logloss: 2.69366
# [490]	valid_0's multi_logloss: 2.69371
# [491]	valid_0's multi_logloss: 2.69372
# [492]	valid_0's multi_logloss: 2.69375
# [493]	valid_0's multi_logloss: 2.69378
# [494]	valid_0's multi_logloss: 2.6938
# [495]	valid_0's multi_logloss: 2.69381
# [496]	valid_0's multi_logloss: 2.69378
# [497]	valid_0's multi_logloss: 2.69382
# [498]	valid_0's multi_logloss: 2.69385
# [499]	valid_0's multi_logloss: 2.69385
# Early stopping, best iteration is:
# [489]	valid_0's multi_logloss: 2.69366
# 0.012319837839153434
# [1]	valid_0's multi_logloss: 2.85876
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85689
# [3]	valid_0's multi_logloss: 2.85484
# [4]	valid_0's multi_logloss: 2.8532
# [5]	valid_0's multi_logloss: 2.85151
# [6]	valid_0's multi_logloss: 2.84991
# [7]	valid_0's multi_logloss: 2.84839
# [8]	valid_0's multi_logloss: 2.84665
# [9]	valid_0's multi_logloss: 2.84517
# [10]	valid_0's multi_logloss: 2.84354
# [11]	valid_0's multi_logloss: 2.84185
# [12]	valid_0's multi_logloss: 2.84032
# [13]	valid_0's multi_logloss: 2.83889
# [14]	valid_0's multi_logloss: 2.83745
# [15]	valid_0's multi_logloss: 2.83597
# [16]	valid_0's multi_logloss: 2.83464
# [17]	valid_0's multi_logloss: 2.83338
# [18]	valid_0's multi_logloss: 2.83207
# [19]	valid_0's multi_logloss: 2.83083
# [20]	valid_0's multi_logloss: 2.82949
# [21]	valid_0's multi_logloss: 2.82825
# [22]	valid_0's multi_logloss: 2.82711
# [23]	valid_0's multi_logloss: 2.82601
# [24]	valid_0's multi_logloss: 2.82493
# [25]	valid_0's multi_logloss: 2.82381
# [26]	valid_0's multi_logloss: 2.82271
# [27]	valid_0's multi_logloss: 2.82154
# [28]	valid_0's multi_logloss: 2.82037
# [29]	valid_0's multi_logloss: 2.81928
# [30]	valid_0's multi_logloss: 2.81822
# [31]	valid_0's multi_logloss: 2.81717
# [32]	valid_0's multi_logloss: 2.81612
# [33]	valid_0's multi_logloss: 2.81508
# [34]	valid_0's multi_logloss: 2.8141
# [35]	valid_0's multi_logloss: 2.81324
# [36]	valid_0's multi_logloss: 2.81227
# [37]	valid_0's multi_logloss: 2.81129
# [38]	valid_0's multi_logloss: 2.81027
# [39]	valid_0's multi_logloss: 2.80923
# [40]	valid_0's multi_logloss: 2.80834
# [41]	valid_0's multi_logloss: 2.80733
# [42]	valid_0's multi_logloss: 2.80625
# [43]	valid_0's multi_logloss: 2.80538
# [44]	valid_0's multi_logloss: 2.80449
# [45]	valid_0's multi_logloss: 2.80359
# [46]	valid_0's multi_logloss: 2.80274
# [47]	valid_0's multi_logloss: 2.80189
# [48]	valid_0's multi_logloss: 2.80099
# [49]	valid_0's multi_logloss: 2.80013
# [50]	valid_0's multi_logloss: 2.79929
# [51]	valid_0's multi_logloss: 2.79842
# [52]	valid_0's multi_logloss: 2.79753
# [53]	valid_0's multi_logloss: 2.79668
# [54]	valid_0's multi_logloss: 2.79585
# [55]	valid_0's multi_logloss: 2.79515
# [56]	valid_0's multi_logloss: 2.79425
# [57]	valid_0's multi_logloss: 2.79354
# [58]	valid_0's multi_logloss: 2.79272
# [59]	valid_0's multi_logloss: 2.7919
# [60]	valid_0's multi_logloss: 2.79109
# [61]	valid_0's multi_logloss: 2.79033
# [62]	valid_0's multi_logloss: 2.78956
# [63]	valid_0's multi_logloss: 2.7888
# [64]	valid_0's multi_logloss: 2.78798
# [65]	valid_0's multi_logloss: 2.78723
# [66]	valid_0's multi_logloss: 2.78651
# [67]	valid_0's multi_logloss: 2.7858
# [68]	valid_0's multi_logloss: 2.78508
# [69]	valid_0's multi_logloss: 2.78438
# [70]	valid_0's multi_logloss: 2.78367
# [71]	valid_0's multi_logloss: 2.78293
# [72]	valid_0's multi_logloss: 2.78233
# [73]	valid_0's multi_logloss: 2.78155
# [74]	valid_0's multi_logloss: 2.78086
# [75]	valid_0's multi_logloss: 2.78022
# [76]	valid_0's multi_logloss: 2.77952
# [77]	valid_0's multi_logloss: 2.77894
# [78]	valid_0's multi_logloss: 2.77825
# [79]	valid_0's multi_logloss: 2.77759
# [80]	valid_0's multi_logloss: 2.77695
# [81]	valid_0's multi_logloss: 2.77629
# [82]	valid_0's multi_logloss: 2.77564
# [83]	valid_0's multi_logloss: 2.77493
# [84]	valid_0's multi_logloss: 2.77433
# [85]	valid_0's multi_logloss: 2.77374
# [86]	valid_0's multi_logloss: 2.77314
# [87]	valid_0's multi_logloss: 2.77257
# [88]	valid_0's multi_logloss: 2.77185
# [89]	valid_0's multi_logloss: 2.77124
# [90]	valid_0's multi_logloss: 2.77058
# [91]	valid_0's multi_logloss: 2.76995
# [92]	valid_0's multi_logloss: 2.76935
# [93]	valid_0's multi_logloss: 2.76873
# [94]	valid_0's multi_logloss: 2.76817
# [95]	valid_0's multi_logloss: 2.7676
# [96]	valid_0's multi_logloss: 2.76697
# [97]	valid_0's multi_logloss: 2.76644
# [98]	valid_0's multi_logloss: 2.7658
# [99]	valid_0's multi_logloss: 2.76528
# [100]	valid_0's multi_logloss: 2.76474
# [101]	valid_0's multi_logloss: 2.76416
# [102]	valid_0's multi_logloss: 2.76363
# [103]	valid_0's multi_logloss: 2.76306
# [104]	valid_0's multi_logloss: 2.76258
# [105]	valid_0's multi_logloss: 2.76216
# [106]	valid_0's multi_logloss: 2.76161
# [107]	valid_0's multi_logloss: 2.76105
# [108]	valid_0's multi_logloss: 2.76051
# [109]	valid_0's multi_logloss: 2.76005
# [110]	valid_0's multi_logloss: 2.75961
# [111]	valid_0's multi_logloss: 2.75909
# [112]	valid_0's multi_logloss: 2.75857
# [113]	valid_0's multi_logloss: 2.75806
# [114]	valid_0's multi_logloss: 2.75761
# [115]	valid_0's multi_logloss: 2.75712
# [116]	valid_0's multi_logloss: 2.75657
# [117]	valid_0's multi_logloss: 2.75609
# [118]	valid_0's multi_logloss: 2.75554
# [119]	valid_0's multi_logloss: 2.75515
# [120]	valid_0's multi_logloss: 2.75463
# [121]	valid_0's multi_logloss: 2.75417
# [122]	valid_0's multi_logloss: 2.75369
# [123]	valid_0's multi_logloss: 2.75331
# [124]	valid_0's multi_logloss: 2.7529
# [125]	valid_0's multi_logloss: 2.75236
# [126]	valid_0's multi_logloss: 2.75188
# [127]	valid_0's multi_logloss: 2.75152
# [128]	valid_0's multi_logloss: 2.75113
# [129]	valid_0's multi_logloss: 2.75065
# [130]	valid_0's multi_logloss: 2.75021
# [131]	valid_0's multi_logloss: 2.74975
# [132]	valid_0's multi_logloss: 2.74935
# [133]	valid_0's multi_logloss: 2.74897
# [134]	valid_0's multi_logloss: 2.74854
# [135]	valid_0's multi_logloss: 2.74815
# [136]	valid_0's multi_logloss: 2.74774
# [137]	valid_0's multi_logloss: 2.74732
# [138]	valid_0's multi_logloss: 2.74693
# [139]	valid_0's multi_logloss: 2.7466
# [140]	valid_0's multi_logloss: 2.74623
# [141]	valid_0's multi_logloss: 2.74592
# [142]	valid_0's multi_logloss: 2.7455
# [143]	valid_0's multi_logloss: 2.74512
# [144]	valid_0's multi_logloss: 2.74481
# [145]	valid_0's multi_logloss: 2.74444
# [146]	valid_0's multi_logloss: 2.74398
# [147]	valid_0's multi_logloss: 2.74361
# [148]	valid_0's multi_logloss: 2.74324
# [149]	valid_0's multi_logloss: 2.74279
# [150]	valid_0's multi_logloss: 2.74252
# [151]	valid_0's multi_logloss: 2.74221
# [152]	valid_0's multi_logloss: 2.74184
# [153]	valid_0's multi_logloss: 2.74149
# [154]	valid_0's multi_logloss: 2.74111
# [155]	valid_0's multi_logloss: 2.74078
# [156]	valid_0's multi_logloss: 2.74048
# [157]	valid_0's multi_logloss: 2.74015
# [158]	valid_0's multi_logloss: 2.73985
# [159]	valid_0's multi_logloss: 2.73958
# [160]	valid_0's multi_logloss: 2.7393
# [161]	valid_0's multi_logloss: 2.73897
# [162]	valid_0's multi_logloss: 2.73861
# [163]	valid_0's multi_logloss: 2.73829
# [164]	valid_0's multi_logloss: 2.73791
# [165]	valid_0's multi_logloss: 2.73761
# [166]	valid_0's multi_logloss: 2.7373
# [167]	valid_0's multi_logloss: 2.73688
# [168]	valid_0's multi_logloss: 2.73663
# [169]	valid_0's multi_logloss: 2.73633
# [170]	valid_0's multi_logloss: 2.73602
# [171]	valid_0's multi_logloss: 2.73567
# [172]	valid_0's multi_logloss: 2.73539
# [173]	valid_0's multi_logloss: 2.7351
# [174]	valid_0's multi_logloss: 2.7348
# [175]	valid_0's multi_logloss: 2.7345
# [176]	valid_0's multi_logloss: 2.73415
# [177]	valid_0's multi_logloss: 2.7338
# [178]	valid_0's multi_logloss: 2.73352
# [179]	valid_0's multi_logloss: 2.73317
# [180]	valid_0's multi_logloss: 2.7329
# [181]	valid_0's multi_logloss: 2.7326
# [182]	valid_0's multi_logloss: 2.7323
# [183]	valid_0's multi_logloss: 2.73201
# [184]	valid_0's multi_logloss: 2.73168
# [185]	valid_0's multi_logloss: 2.73138
# [186]	valid_0's multi_logloss: 2.73109
# [187]	valid_0's multi_logloss: 2.73079
# [188]	valid_0's multi_logloss: 2.73051
# [189]	valid_0's multi_logloss: 2.73025
# [190]	valid_0's multi_logloss: 2.72992
# [191]	valid_0's multi_logloss: 2.72966
# [192]	valid_0's multi_logloss: 2.72938
# [193]	valid_0's multi_logloss: 2.72905
# [194]	valid_0's multi_logloss: 2.72874
# [195]	valid_0's multi_logloss: 2.7284
# [196]	valid_0's multi_logloss: 2.72817
# [197]	valid_0's multi_logloss: 2.72792
# [198]	valid_0's multi_logloss: 2.72764
# [199]	valid_0's multi_logloss: 2.72739
# [200]	valid_0's multi_logloss: 2.72714
# [201]	valid_0's multi_logloss: 2.72685
# [202]	valid_0's multi_logloss: 2.72658
# [203]	valid_0's multi_logloss: 2.72633
# [204]	valid_0's multi_logloss: 2.72609
# [205]	valid_0's multi_logloss: 2.72587
# [206]	valid_0's multi_logloss: 2.72564
# [207]	valid_0's multi_logloss: 2.72542
# [208]	valid_0's multi_logloss: 2.72522
# [209]	valid_0's multi_logloss: 2.725
# [210]	valid_0's multi_logloss: 2.7248
# [211]	valid_0's multi_logloss: 2.72454
# [212]	valid_0's multi_logloss: 2.72434
# [213]	valid_0's multi_logloss: 2.72406
# [214]	valid_0's multi_logloss: 2.7239
# [215]	valid_0's multi_logloss: 2.72368
# [216]	valid_0's multi_logloss: 2.7235
# [217]	valid_0's multi_logloss: 2.72328
# [218]	valid_0's multi_logloss: 2.72308
# [219]	valid_0's multi_logloss: 2.72286
# [220]	valid_0's multi_logloss: 2.72266
# [221]	valid_0's multi_logloss: 2.7225
# [222]	valid_0's multi_logloss: 2.72232
# [223]	valid_0's multi_logloss: 2.72209
# [224]	valid_0's multi_logloss: 2.72188
# [225]	valid_0's multi_logloss: 2.72167
# [226]	valid_0's multi_logloss: 2.72148
# [227]	valid_0's multi_logloss: 2.72125
# [228]	valid_0's multi_logloss: 2.72107
# [229]	valid_0's multi_logloss: 2.72085
# [230]	valid_0's multi_logloss: 2.72066
# [231]	valid_0's multi_logloss: 2.72044
# [232]	valid_0's multi_logloss: 2.72023
# [233]	valid_0's multi_logloss: 2.72006
# [234]	valid_0's multi_logloss: 2.71985
# [235]	valid_0's multi_logloss: 2.71972
# [236]	valid_0's multi_logloss: 2.71954
# [237]	valid_0's multi_logloss: 2.7194
# [238]	valid_0's multi_logloss: 2.71922
# [239]	valid_0's multi_logloss: 2.71903
# [240]	valid_0's multi_logloss: 2.71886
# [241]	valid_0's multi_logloss: 2.71867
# [242]	valid_0's multi_logloss: 2.71855
# [243]	valid_0's multi_logloss: 2.71836
# [244]	valid_0's multi_logloss: 2.71818
# [245]	valid_0's multi_logloss: 2.71802
# [246]	valid_0's multi_logloss: 2.71776
# [247]	valid_0's multi_logloss: 2.71757
# [248]	valid_0's multi_logloss: 2.71743
# [249]	valid_0's multi_logloss: 2.71727
# [250]	valid_0's multi_logloss: 2.71705
# [251]	valid_0's multi_logloss: 2.71693
# [252]	valid_0's multi_logloss: 2.71671
# [253]	valid_0's multi_logloss: 2.71653
# [254]	valid_0's multi_logloss: 2.71637
# [255]	valid_0's multi_logloss: 2.7162
# [256]	valid_0's multi_logloss: 2.71609
# [257]	valid_0's multi_logloss: 2.71596
# [258]	valid_0's multi_logloss: 2.71578
# [259]	valid_0's multi_logloss: 2.71565
# [260]	valid_0's multi_logloss: 2.71546
# [261]	valid_0's multi_logloss: 2.71532
# [262]	valid_0's multi_logloss: 2.71518
# [263]	valid_0's multi_logloss: 2.71506
# [264]	valid_0's multi_logloss: 2.71493
# [265]	valid_0's multi_logloss: 2.7148
# [266]	valid_0's multi_logloss: 2.71467
# [267]	valid_0's multi_logloss: 2.71456
# [268]	valid_0's multi_logloss: 2.71448
# [269]	valid_0's multi_logloss: 2.71431
# [270]	valid_0's multi_logloss: 2.71414
# [271]	valid_0's multi_logloss: 2.71404
# [272]	valid_0's multi_logloss: 2.71388
# [273]	valid_0's multi_logloss: 2.71376
# [274]	valid_0's multi_logloss: 2.71364
# [275]	valid_0's multi_logloss: 2.71352
# [276]	valid_0's multi_logloss: 2.71331
# ...
# [212]	valid_0's multi_logloss: 2.91566
# [213]	valid_0's multi_logloss: 2.91555
# [214]	valid_0's multi_logloss: 2.91546
# [215]	valid_0's multi_logloss: 2.91533
# [216]	valid_0's multi_logloss: 2.91522
# [217]	valid_0's multi_logloss: 2.91511
# [218]	valid_0's multi_logloss: 2.915
# [219]	valid_0's multi_logloss: 2.91488
# [220]	valid_0's multi_logloss: 2.91479
# [221]	valid_0's multi_logloss: 2.91469
# [222]	valid_0's multi_logloss: 2.91451
# [223]	valid_0's multi_logloss: 2.91446
# [224]	valid_0's multi_logloss: 2.9143
# [225]	valid_0's multi_logloss: 2.91424
# [226]	valid_0's multi_logloss: 2.91417
# [227]	valid_0's multi_logloss: 2.914
# [228]	valid_0's multi_logloss: 2.91394
# [229]	valid_0's multi_logloss: 2.91386
# [230]	valid_0's multi_logloss: 2.91371
# [231]	valid_0's multi_logloss: 2.91365
# [232]	valid_0's multi_logloss: 2.91356
# [233]	valid_0's multi_logloss: 2.91342
# [234]	valid_0's multi_logloss: 2.91336
# [235]	valid_0's multi_logloss: 2.91328
# [236]	valid_0's multi_logloss: 2.91314
# [237]	valid_0's multi_logloss: 2.91312
# [238]	valid_0's multi_logloss: 2.91309
# [239]	valid_0's multi_logloss: 2.913
# [240]	valid_0's multi_logloss: 2.91298
# [241]	valid_0's multi_logloss: 2.91293
# [242]	valid_0's multi_logloss: 2.91283
# [243]	valid_0's multi_logloss: 2.91272
# [244]	valid_0's multi_logloss: 2.91266
# [245]	valid_0's multi_logloss: 2.91263
# [246]	valid_0's multi_logloss: 2.91259
# [247]	valid_0's multi_logloss: 2.91246
# [248]	valid_0's multi_logloss: 2.91238
# [249]	valid_0's multi_logloss: 2.91237
# [250]	valid_0's multi_logloss: 2.91225
# [251]	valid_0's multi_logloss: 2.91223
# [252]	valid_0's multi_logloss: 2.91225
# [253]	valid_0's multi_logloss: 2.91213
# [254]	valid_0's multi_logloss: 2.91211
# [255]	valid_0's multi_logloss: 2.91211
# [256]	valid_0's multi_logloss: 2.9121
# [257]	valid_0's multi_logloss: 2.91206
# [258]	valid_0's multi_logloss: 2.91201
# [259]	valid_0's multi_logloss: 2.91197
# [260]	valid_0's multi_logloss: 2.91195
# [261]	valid_0's multi_logloss: 2.91188
# [262]	valid_0's multi_logloss: 2.91182
# [263]	valid_0's multi_logloss: 2.91176
# [264]	valid_0's multi_logloss: 2.91172
# [265]	valid_0's multi_logloss: 2.91166
# [266]	valid_0's multi_logloss: 2.91163
# [267]	valid_0's multi_logloss: 2.9116
# [268]	valid_0's multi_logloss: 2.91153
# [269]	valid_0's multi_logloss: 2.9115
# [270]	valid_0's multi_logloss: 2.91144
# [271]	valid_0's multi_logloss: 2.91145
# [272]	valid_0's multi_logloss: 2.9114
# [273]	valid_0's multi_logloss: 2.91134
# [274]	valid_0's multi_logloss: 2.91126
# [275]	valid_0's multi_logloss: 2.91119
# [276]	valid_0's multi_logloss: 2.91109
# [277]	valid_0's multi_logloss: 2.91105
# [278]	valid_0's multi_logloss: 2.91101
# [279]	valid_0's multi_logloss: 2.911
# [280]	valid_0's multi_logloss: 2.91099
# [281]	valid_0's multi_logloss: 2.91094
# [282]	valid_0's multi_logloss: 2.91092
# [283]	valid_0's multi_logloss: 2.91087
# [284]	valid_0's multi_logloss: 2.91081
# [285]	valid_0's multi_logloss: 2.9108
# [286]	valid_0's multi_logloss: 2.91073
# [287]	valid_0's multi_logloss: 2.91073
# [288]	valid_0's multi_logloss: 2.91073
# [289]	valid_0's multi_logloss: 2.9107
# [290]	valid_0's multi_logloss: 2.91064
# [291]	valid_0's multi_logloss: 2.91058
# [292]	valid_0's multi_logloss: 2.91055
# [293]	valid_0's multi_logloss: 2.91052
# [294]	valid_0's multi_logloss: 2.9105
# [295]	valid_0's multi_logloss: 2.91045
# [296]	valid_0's multi_logloss: 2.91044
# [297]	valid_0's multi_logloss: 2.91047
# [298]	valid_0's multi_logloss: 2.91041
# [299]	valid_0's multi_logloss: 2.91036
# [300]	valid_0's multi_logloss: 2.91033
# [301]	valid_0's multi_logloss: 2.91032
# [302]	valid_0's multi_logloss: 2.91036
# [303]	valid_0's multi_logloss: 2.9103
# [304]	valid_0's multi_logloss: 2.91033
# [305]	valid_0's multi_logloss: 2.91032
# [306]	valid_0's multi_logloss: 2.91029
# [307]	valid_0's multi_logloss: 2.9103
# [308]	valid_0's multi_logloss: 2.9103
# [309]	valid_0's multi_logloss: 2.91028
# [310]	valid_0's multi_logloss: 2.91028
# [311]	valid_0's multi_logloss: 2.91032
# [312]	valid_0's multi_logloss: 2.91029
# [313]	valid_0's multi_logloss: 2.91029
# [314]	valid_0's multi_logloss: 2.91033
# [315]	valid_0's multi_logloss: 2.91037
# [316]	valid_0's multi_logloss: 2.91041
# [317]	valid_0's multi_logloss: 2.91046
# [318]	valid_0's multi_logloss: 2.91048
# [319]	valid_0's multi_logloss: 2.91047
# Early stopping, best iteration is:
# [309]	valid_0's multi_logloss: 2.91028
# 0.014350408704261257
# [1]	valid_0's multi_logloss: 2.92628
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92491
# [3]	valid_0's multi_logloss: 2.9239
# [4]	valid_0's multi_logloss: 2.92296
# [5]	valid_0's multi_logloss: 2.92225
# [6]	valid_0's multi_logloss: 2.92137
# [7]	valid_0's multi_logloss: 2.92048
# [8]	valid_0's multi_logloss: 2.91967
# [9]	valid_0's multi_logloss: 2.91889
# [10]	valid_0's multi_logloss: 2.91802
# [11]	valid_0's multi_logloss: 2.91733
# [12]	valid_0's multi_logloss: 2.9167
# [13]	valid_0's multi_logloss: 2.91592
# [14]	valid_0's multi_logloss: 2.91525
# [15]	valid_0's multi_logloss: 2.91461
# [16]	valid_0's multi_logloss: 2.91391
# [17]	valid_0's multi_logloss: 2.91321
# [18]	valid_0's multi_logloss: 2.91258
# [19]	valid_0's multi_logloss: 2.91203
# [20]	valid_0's multi_logloss: 2.91129
# [21]	valid_0's multi_logloss: 2.91058
# [22]	valid_0's multi_logloss: 2.91
# [23]	valid_0's multi_logloss: 2.9095
# [24]	valid_0's multi_logloss: 2.90894
# [25]	valid_0's multi_logloss: 2.90839
# [26]	valid_0's multi_logloss: 2.90787
# [27]	valid_0's multi_logloss: 2.90736
# [28]	valid_0's multi_logloss: 2.90677
# [29]	valid_0's multi_logloss: 2.90625
# [30]	valid_0's multi_logloss: 2.90579
# [31]	valid_0's multi_logloss: 2.9053
# [32]	valid_0's multi_logloss: 2.90484
# [33]	valid_0's multi_logloss: 2.9044
# [34]	valid_0's multi_logloss: 2.90394
# [35]	valid_0's multi_logloss: 2.90351
# [36]	valid_0's multi_logloss: 2.90308
# [37]	valid_0's multi_logloss: 2.90273
# [38]	valid_0's multi_logloss: 2.90222
# [39]	valid_0's multi_logloss: 2.90194
# [40]	valid_0's multi_logloss: 2.90155
# [41]	valid_0's multi_logloss: 2.90122
# [42]	valid_0's multi_logloss: 2.90075
# [43]	valid_0's multi_logloss: 2.90039
# [44]	valid_0's multi_logloss: 2.90001
# [45]	valid_0's multi_logloss: 2.89964
# [46]	valid_0's multi_logloss: 2.8992
# [47]	valid_0's multi_logloss: 2.89881
# [48]	valid_0's multi_logloss: 2.89836
# [49]	valid_0's multi_logloss: 2.89791
# [50]	valid_0's multi_logloss: 2.89751
# [51]	valid_0's multi_logloss: 2.89713
# [52]	valid_0's multi_logloss: 2.8967
# [53]	valid_0's multi_logloss: 2.89625
# [54]	valid_0's multi_logloss: 2.89589
# [55]	valid_0's multi_logloss: 2.89551
# [56]	valid_0's multi_logloss: 2.89513
# [57]	valid_0's multi_logloss: 2.89478
# [58]	valid_0's multi_logloss: 2.89441
# [59]	valid_0's multi_logloss: 2.89402
# [60]	valid_0's multi_logloss: 2.89372
# [61]	valid_0's multi_logloss: 2.89335
# [62]	valid_0's multi_logloss: 2.89297
# [63]	valid_0's multi_logloss: 2.89271
# [64]	valid_0's multi_logloss: 2.89236
# [65]	valid_0's multi_logloss: 2.89203
# [66]	valid_0's multi_logloss: 2.89175
# [67]	valid_0's multi_logloss: 2.89138
# [68]	valid_0's multi_logloss: 2.89106
# [69]	valid_0's multi_logloss: 2.89074
# [70]	valid_0's multi_logloss: 2.89042
# [71]	valid_0's multi_logloss: 2.89016
# [72]	valid_0's multi_logloss: 2.8899
# [73]	valid_0's multi_logloss: 2.88957
# [74]	valid_0's multi_logloss: 2.88919
# [75]	valid_0's multi_logloss: 2.88888
# [76]	valid_0's multi_logloss: 2.88853
# [77]	valid_0's multi_logloss: 2.88816
# [78]	valid_0's multi_logloss: 2.88788
# [79]	valid_0's multi_logloss: 2.88756
# [80]	valid_0's multi_logloss: 2.88729
# [81]	valid_0's multi_logloss: 2.88685
# [82]	valid_0's multi_logloss: 2.88659
# [83]	valid_0's multi_logloss: 2.88635
# [84]	valid_0's multi_logloss: 2.88605
# [85]	valid_0's multi_logloss: 2.88575
# [86]	valid_0's multi_logloss: 2.88548
# [87]	valid_0's multi_logloss: 2.88531
# [88]	valid_0's multi_logloss: 2.88507
# [89]	valid_0's multi_logloss: 2.88477
# [90]	valid_0's multi_logloss: 2.88452
# [91]	valid_0's multi_logloss: 2.88429
# [92]	valid_0's multi_logloss: 2.88406
# [93]	valid_0's multi_logloss: 2.88385
# [94]	valid_0's multi_logloss: 2.88359
# [95]	valid_0's multi_logloss: 2.88332
# [96]	valid_0's multi_logloss: 2.88314
# [97]	valid_0's multi_logloss: 2.88295
# [98]	valid_0's multi_logloss: 2.88265
# [99]	valid_0's multi_logloss: 2.88244
# [100]	valid_0's multi_logloss: 2.88217
# [101]	valid_0's multi_logloss: 2.88199
# [102]	valid_0's multi_logloss: 2.88162
# [103]	valid_0's multi_logloss: 2.88142
# [104]	valid_0's multi_logloss: 2.88119
# [105]	valid_0's multi_logloss: 2.88103
# [106]	valid_0's multi_logloss: 2.88083
# [107]	valid_0's multi_logloss: 2.88048
# [108]	valid_0's multi_logloss: 2.88023
# [109]	valid_0's multi_logloss: 2.88006
# [110]	valid_0's multi_logloss: 2.87983
# [111]	valid_0's multi_logloss: 2.87961
# [112]	valid_0's multi_logloss: 2.87936
# [113]	valid_0's multi_logloss: 2.87914
# [114]	valid_0's multi_logloss: 2.87894
# [115]	valid_0's multi_logloss: 2.87872
# [116]	valid_0's multi_logloss: 2.87857
# [117]	valid_0's multi_logloss: 2.87842
# [118]	valid_0's multi_logloss: 2.87826
# [119]	valid_0's multi_logloss: 2.87805
# [120]	valid_0's multi_logloss: 2.87788
# [121]	valid_0's multi_logloss: 2.87764
# [122]	valid_0's multi_logloss: 2.8775
# [123]	valid_0's multi_logloss: 2.8773
# [124]	valid_0's multi_logloss: 2.87717
# [125]	valid_0's multi_logloss: 2.87692
# [126]	valid_0's multi_logloss: 2.87676
# [127]	valid_0's multi_logloss: 2.87658
# [128]	valid_0's multi_logloss: 2.87638
# [129]	valid_0's multi_logloss: 2.87624
# [130]	valid_0's multi_logloss: 2.87611
# [131]	valid_0's multi_logloss: 2.87594
# [132]	valid_0's multi_logloss: 2.87582
# [133]	valid_0's multi_logloss: 2.87565
# [134]	valid_0's multi_logloss: 2.87553
# [135]	valid_0's multi_logloss: 2.87538
# [136]	valid_0's multi_logloss: 2.87513
# [137]	valid_0's multi_logloss: 2.87495
# [138]	valid_0's multi_logloss: 2.87476
# [139]	valid_0's multi_logloss: 2.87454
# [140]	valid_0's multi_logloss: 2.87433
# [141]	valid_0's multi_logloss: 2.87412
# [142]	valid_0's multi_logloss: 2.87395
# [143]	valid_0's multi_logloss: 2.87376
# [144]	valid_0's multi_logloss: 2.87363
# [145]	valid_0's multi_logloss: 2.87346
# [146]	valid_0's multi_logloss: 2.87323
# [147]	valid_0's multi_logloss: 2.87308
# [148]	valid_0's multi_logloss: 2.87295
# [149]	valid_0's multi_logloss: 2.87276
# [150]	valid_0's multi_logloss: 2.87253
# [151]	valid_0's multi_logloss: 2.8724
# [152]	valid_0's multi_logloss: 2.87219
# [153]	valid_0's multi_logloss: 2.87199
# [154]	valid_0's multi_logloss: 2.87177
# [155]	valid_0's multi_logloss: 2.87161
# [156]	valid_0's multi_logloss: 2.87147
# [157]	valid_0's multi_logloss: 2.87127
# [158]	valid_0's multi_logloss: 2.87109
# [159]	valid_0's multi_logloss: 2.87099
# [160]	valid_0's multi_logloss: 2.87078
# [161]	valid_0's multi_logloss: 2.87069
# [162]	valid_0's multi_logloss: 2.87052
# [163]	valid_0's multi_logloss: 2.8703
# [164]	valid_0's multi_logloss: 2.87021
# [165]	valid_0's multi_logloss: 2.87002
# [166]	valid_0's multi_logloss: 2.86986
# [167]	valid_0's multi_logloss: 2.86976
# [168]	valid_0's multi_logloss: 2.86963
# [169]	valid_0's multi_logloss: 2.86945
# [170]	valid_0's multi_logloss: 2.86929
# [171]	valid_0's multi_logloss: 2.8691
# [172]	valid_0's multi_logloss: 2.8689
# [173]	valid_0's multi_logloss: 2.86879
# [174]	valid_0's multi_logloss: 2.86871
# [175]	valid_0's multi_logloss: 2.86862
# [176]	valid_0's multi_logloss: 2.86854
# [177]	valid_0's multi_logloss: 2.86845
# [178]	valid_0's multi_logloss: 2.86829
# [179]	valid_0's multi_logloss: 2.86818
# [180]	valid_0's multi_logloss: 2.86804
# [181]	valid_0's multi_logloss: 2.86794
# [182]	valid_0's multi_logloss: 2.8678
# [183]	valid_0's multi_logloss: 2.86768
# [184]	valid_0's multi_logloss: 2.8676
# [185]	valid_0's multi_logloss: 2.8675
# [186]	valid_0's multi_logloss: 2.86738
# [187]	valid_0's multi_logloss: 2.86728
# [188]	valid_0's multi_logloss: 2.86711
# [189]	valid_0's multi_logloss: 2.86701
# [190]	valid_0's multi_logloss: 2.86691
# [191]	valid_0's multi_logloss: 2.86683
# [192]	valid_0's multi_logloss: 2.86663
# [193]	valid_0's multi_logloss: 2.8666
# [194]	valid_0's multi_logloss: 2.86646
# [195]	valid_0's multi_logloss: 2.8663
# [196]	valid_0's multi_logloss: 2.86624
# [197]	valid_0's multi_logloss: 2.86613
# [198]	valid_0's multi_logloss: 2.86603
# [199]	valid_0's multi_logloss: 2.86588
# [200]	valid_0's multi_logloss: 2.86577
# [201]	valid_0's multi_logloss: 2.86568
# [202]	valid_0's multi_logloss: 2.86559
# [203]	valid_0's multi_logloss: 2.86548
# [204]	valid_0's multi_logloss: 2.86537
# [205]	valid_0's multi_logloss: 2.86527
# [206]	valid_0's multi_logloss: 2.86516
# [207]	valid_0's multi_logloss: 2.865
# [208]	valid_0's multi_logloss: 2.86491
# [209]	valid_0's multi_logloss: 2.86478
# [210]	valid_0's multi_logloss: 2.86468
# [211]	valid_0's multi_logloss: 2.86458
# [212]	valid_0's multi_logloss: 2.8645
# [213]	valid_0's multi_logloss: 2.86443
# [214]	valid_0's multi_logloss: 2.86438
# [215]	valid_0's multi_logloss: 2.86432
# [216]	valid_0's multi_logloss: 2.86423
# [217]	valid_0's multi_logloss: 2.86413
# [218]	valid_0's multi_logloss: 2.86407
# [219]	valid_0's multi_logloss: 2.86398
# [220]	valid_0's multi_logloss: 2.86397
# [221]	valid_0's multi_logloss: 2.86376
# [222]	valid_0's multi_logloss: 2.86369
# [223]	valid_0's multi_logloss: 2.86365
# [224]	valid_0's multi_logloss: 2.86356
# [225]	valid_0's multi_logloss: 2.86354
# [226]	valid_0's multi_logloss: 2.8634
# [227]	valid_0's multi_logloss: 2.8633
# [228]	valid_0's multi_logloss: 2.86323
# [229]	valid_0's multi_logloss: 2.86316
# [230]	valid_0's multi_logloss: 2.86311
# [231]	valid_0's multi_logloss: 2.86304
# [232]	valid_0's multi_logloss: 2.86302
# [233]	valid_0's multi_logloss: 2.86296
# [234]	valid_0's multi_logloss: 2.86288
# [235]	valid_0's multi_logloss: 2.86287
# [236]	valid_0's multi_logloss: 2.8628
# [237]	valid_0's multi_logloss: 2.86275
# [238]	valid_0's multi_logloss: 2.86269
# [239]	valid_0's multi_logloss: 2.86261
# [240]	valid_0's multi_logloss: 2.86257
# [241]	valid_0's multi_logloss: 2.86249
# [242]	valid_0's multi_logloss: 2.86246
# [243]	valid_0's multi_logloss: 2.86241
# [244]	valid_0's multi_logloss: 2.86237
# [245]	valid_0's multi_logloss: 2.86232
# [246]	valid_0's multi_logloss: 2.86226
# [247]	valid_0's multi_logloss: 2.86223
# [248]	valid_0's multi_logloss: 2.86217
# [249]	valid_0's multi_logloss: 2.86208
# [250]	valid_0's multi_logloss: 2.86205
# [251]	valid_0's multi_logloss: 2.86201
# [252]	valid_0's multi_logloss: 2.86198
# [253]	valid_0's multi_logloss: 2.8619
# [254]	valid_0's multi_logloss: 2.86181
# [255]	valid_0's multi_logloss: 2.86178
# [256]	valid_0's multi_logloss: 2.86169
# [257]	valid_0's multi_logloss: 2.86163
# [258]	valid_0's multi_logloss: 2.86155
# [259]	valid_0's multi_logloss: 2.86151
# [260]	valid_0's multi_logloss: 2.86148
# [261]	valid_0's multi_logloss: 2.86142
# [262]	valid_0's multi_logloss: 2.86134
# [263]	valid_0's multi_logloss: 2.86133
# [264]	valid_0's multi_logloss: 2.86127
# [265]	valid_0's multi_logloss: 2.86132
# [266]	valid_0's multi_logloss: 2.86128
# [267]	valid_0's multi_logloss: 2.86126
# [268]	valid_0's multi_logloss: 2.86128
# [269]	valid_0's multi_logloss: 2.86123
# [270]	valid_0's multi_logloss: 2.86121
# [271]	valid_0's multi_logloss: 2.86122
# [272]	valid_0's multi_logloss: 2.86119
# [273]	valid_0's multi_logloss: 2.86118
# [274]	valid_0's multi_logloss: 2.86111
# [275]	valid_0's multi_logloss: 2.86111
# [276]	valid_0's multi_logloss: 2.86104
# [277]	valid_0's multi_logloss: 2.86095
# [278]	valid_0's multi_logloss: 2.86098
# [279]	valid_0's multi_logloss: 2.861
# [280]	valid_0's multi_logloss: 2.86095
# [281]	valid_0's multi_logloss: 2.86093
# [282]	valid_0's multi_logloss: 2.86096
# [283]	valid_0's multi_logloss: 2.86097
# [284]	valid_0's multi_logloss: 2.86096
# [285]	valid_0's multi_logloss: 2.86096
# [286]	valid_0's multi_logloss: 2.86097
# [287]	valid_0's multi_logloss: 2.86095
# [288]	valid_0's multi_logloss: 2.86097
# [289]	valid_0's multi_logloss: 2.86092
# [290]	valid_0's multi_logloss: 2.86096
# [291]	valid_0's multi_logloss: 2.86096
# [292]	valid_0's multi_logloss: 2.86096
# [293]	valid_0's multi_logloss: 2.86096
# [294]	valid_0's multi_logloss: 2.86098
# [295]	valid_0's multi_logloss: 2.86104
# [296]	valid_0's multi_logloss: 2.86102
# [297]	valid_0's multi_logloss: 2.86105
# [298]	valid_0's multi_logloss: 2.86103
# [299]	valid_0's multi_logloss: 2.861
# Early stopping, best iteration is:
# [289]	valid_0's multi_logloss: 2.86092
# 0.01416067694572492
# average crps: 0.013058585000902404

# %% [markdown]
# - 0.013047467316719177 # improved from 0.01305858500 by adding first offenser momentum_cos

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Quarter',
#        'Down', 'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Position',
#        'Week', 'Stadium', 'Location', 'StadiumType', 'GameWeather',
#        'Temperature', 'Humidity', 'WindSpeed', 'WindDirection', 'YardLine',
#        'X', 'Y', 'Orientation', 'Dir', 'age', 'Momentum', 'TackleTimeToRusher',
#        'Dir_cos', 'Momentum_cos', 'RatioSToRusher', 'time_quarter', 'time_end',
#        'handoff_snap_diff', 'Grass', 'DefendersInTheBox_vs_Distance',
#        'runner_height', 'DefenseAveX', 'OffenseAveX', 'DefenseAveY',
#        'OffenseAveY', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid',
#        'DefenseSpreadX', 'OffenseSpreadX', 'RunnerToScrimmage',
#        'MinTackleTime', '1stDefender_Momentum_cos', 'RusherVoronoi',
#        'FirstDefenderVoronoi'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Cv").head(30)
# Out:
#                      Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  Average  \
# 2                          A   26772   26347   25063   20181   22452  24163.0
# 3                        Dis    6675    6022    5136    5085    4631   5509.8
# 6                     Season    2414    2290    2992    2005    2161   2372.4
# 14         DefendersInTheBox    3232    3236    2832    2233    2263   2759.2
# 52               OffenseStdY    7828    8643    8278    6589    5428   7353.2
# 12          OffenseFormation    1435    1181    1562    1460     951   1317.8
# 49               DefenseStdX   10035   11326    9696    8034    6788   9175.8
# 59  1stDefender_Momentum_cos   17679   20584   17618   12936   13370  16437.4
# 17         PlayerCollegeName   10560   10480    9772    6632    7492   8987.2
# 13          OffensePersonnel    4437    5614    5213    3596    3546   4481.2
# 37              Momentum_cos   18030   18284   18088   12873   11337  15722.4
# 15          DefensePersonnel    3209    4200    3744    2529    2563   3249.0
# 1                          S    8777    8613    6657    5382    5553   6996.4
# 47               DefenseAveY    7690    7981    8054    5204    4815   6748.8
# 20                   Stadium    6813    7832    7556    5447    4214   6372.4
# 53    RunnerToDefenseCentoid    8310   11637    9854    7215    6420   8687.2
# 11    VisitorScoreBeforePlay    6064    7511    5239    3979    4738   5506.2
# 26                 WindSpeed    6878    6190    5412    3496    4583   5311.8
# 23               GameWeather    4613    5521    5163    3664    2844   4361.0
# 58             MinTackleTime   17156   18521   16037   10195   11039  14589.6
# 45               DefenseAveX    6823    8737    9102    6668    4469   7159.8
# 10       HomeScoreBeforePlay    4828    6239    5137    3091    3836   4626.2
# 28                  YardLine   10981   12860   10803    6907    7309   9772.0
# 57         RunnerToScrimmage   15024   16652   12397   10509    8328  12582.0
# 61      FirstDefenderVoronoi   13611   15579   14045    9200    8095  12106.0
# 55            DefenseSpreadX   14106   14520   13902    8677    7992  11839.4
# 56            OffenseSpreadX   10443   13613    8444    8178    6861   9507.8
# 50               OffenseStdX   11333   11130    8775    5905    6877   8804.0
# 24               Temperature    8652    8710    7237    4987    4783   6873.8
# 31               Orientation   10170    8517    8604    4795    6222   7661.6
#
#             Std        Cv
# 2   2496.821259  0.103332
# 3    736.547459  0.133680
# 6    338.259427  0.142581
# 14   442.555940  0.160393
# 52  1186.142555  0.161310
# 12   222.192169  0.168608
# 49  1589.810605  0.173261
# 59  2891.311924  0.175898
# 17  1618.681735  0.180110
# 13   834.134138  0.186141
# 37  2994.451175  0.190458
# 15   654.220452  0.201361
# 1   1455.253600  0.208000
# 47  1430.643967  0.211985
# 20  1359.450271  0.213334
# 53  1871.501579  0.215432
# 11  1210.308291  0.219808
# 26  1188.489529  0.223745
# 23   983.809534  0.225593
# 58  3348.329470  0.229501
# 45  1664.656529  0.232500
# 10  1084.805863  0.234492
# 28  2294.993682  0.234854
# 57  2998.544113  0.238320
# 61  2919.569557  0.241167
# 55  2876.827113  0.242988
# 56  2350.866002  0.247257
# 50  2187.440879  0.248460
# 24  1708.625108  0.248571
# 31  1907.969664  0.249030

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf', 'Quarter']
top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "InfluToBall", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY"]#, "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# CPU times: user 14min 26s, sys: 5.46 s, total: 14min 31s
# Wall time: 14min 28s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : -1,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86896
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86624
# [3]	valid_0's multi_logloss: 2.86388
# [4]	valid_0's multi_logloss: 2.86178
# [5]	valid_0's multi_logloss: 2.85967
# [6]	valid_0's multi_logloss: 2.85771
# [7]	valid_0's multi_logloss: 2.85596
# [8]	valid_0's multi_logloss: 2.85426
# [9]	valid_0's multi_logloss: 2.85231
# [10]	valid_0's multi_logloss: 2.85064
# [11]	valid_0's multi_logloss: 2.84909
# [12]	valid_0's multi_logloss: 2.84738
# [13]	valid_0's multi_logloss: 2.84569
# [14]	valid_0's multi_logloss: 2.84404
# [15]	valid_0's multi_logloss: 2.84246
# [16]	valid_0's multi_logloss: 2.84096
# [17]	valid_0's multi_logloss: 2.83942
# [18]	valid_0's multi_logloss: 2.83787
# [19]	valid_0's multi_logloss: 2.83661
# [20]	valid_0's multi_logloss: 2.83527
# [21]	valid_0's multi_logloss: 2.83397
# [22]	valid_0's multi_logloss: 2.83246
# [23]	valid_0's multi_logloss: 2.83107
# [24]	valid_0's multi_logloss: 2.82966
# [25]	valid_0's multi_logloss: 2.82838
# [26]	valid_0's multi_logloss: 2.82706
# [27]	valid_0's multi_logloss: 2.82572
# [28]	valid_0's multi_logloss: 2.82457
# [29]	valid_0's multi_logloss: 2.82329
# [30]	valid_0's multi_logloss: 2.82207
# [31]	valid_0's multi_logloss: 2.82077
# [32]	valid_0's multi_logloss: 2.81957
# [33]	valid_0's multi_logloss: 2.81836
# [34]	valid_0's multi_logloss: 2.81721
# [35]	valid_0's multi_logloss: 2.81608
# [36]	valid_0's multi_logloss: 2.81499
# [37]	valid_0's multi_logloss: 2.81395
# [38]	valid_0's multi_logloss: 2.81288
# [39]	valid_0's multi_logloss: 2.81169
# [40]	valid_0's multi_logloss: 2.81068
# [41]	valid_0's multi_logloss: 2.80951
# [42]	valid_0's multi_logloss: 2.80847
# [43]	valid_0's multi_logloss: 2.80746
# [44]	valid_0's multi_logloss: 2.80636
# [45]	valid_0's multi_logloss: 2.80525
# [46]	valid_0's multi_logloss: 2.80428
# [47]	valid_0's multi_logloss: 2.80336
# [48]	valid_0's multi_logloss: 2.8024
# [49]	valid_0's multi_logloss: 2.80133
# [50]	valid_0's multi_logloss: 2.80048
# [51]	valid_0's multi_logloss: 2.79942
# [52]	valid_0's multi_logloss: 2.79844
# [53]	valid_0's multi_logloss: 2.79757
# [54]	valid_0's multi_logloss: 2.79663
# [55]	valid_0's multi_logloss: 2.7956
# [56]	valid_0's multi_logloss: 2.79459
# [57]	valid_0's multi_logloss: 2.79364
# [58]	valid_0's multi_logloss: 2.79282
# [59]	valid_0's multi_logloss: 2.79204
# [60]	valid_0's multi_logloss: 2.79104
# [61]	valid_0's multi_logloss: 2.79024
# [62]	valid_0's multi_logloss: 2.78932
# [63]	valid_0's multi_logloss: 2.78844
# [64]	valid_0's multi_logloss: 2.7876
# [65]	valid_0's multi_logloss: 2.7867
# [66]	valid_0's multi_logloss: 2.78581
# [67]	valid_0's multi_logloss: 2.78491
# [68]	valid_0's multi_logloss: 2.78405
# [69]	valid_0's multi_logloss: 2.78321
# [70]	valid_0's multi_logloss: 2.78244
# [71]	valid_0's multi_logloss: 2.78149
# [72]	valid_0's multi_logloss: 2.78072
# [73]	valid_0's multi_logloss: 2.77984
# [74]	valid_0's multi_logloss: 2.77896
# [75]	valid_0's multi_logloss: 2.77826
# [76]	valid_0's multi_logloss: 2.77739
# [77]	valid_0's multi_logloss: 2.77654
# [78]	valid_0's multi_logloss: 2.77568
# [79]	valid_0's multi_logloss: 2.77492
# [80]	valid_0's multi_logloss: 2.77413
# [81]	valid_0's multi_logloss: 2.77349
# [82]	valid_0's multi_logloss: 2.77261
# [83]	valid_0's multi_logloss: 2.77187
# [84]	valid_0's multi_logloss: 2.77111
# [85]	valid_0's multi_logloss: 2.77046
# [86]	valid_0's multi_logloss: 2.76968
# [87]	valid_0's multi_logloss: 2.76882
# [88]	valid_0's multi_logloss: 2.76821
# [89]	valid_0's multi_logloss: 2.76749
# [90]	valid_0's multi_logloss: 2.76679
# [91]	valid_0's multi_logloss: 2.76618
# [92]	valid_0's multi_logloss: 2.76557
# [93]	valid_0's multi_logloss: 2.76487
# [94]	valid_0's multi_logloss: 2.76427
# [95]	valid_0's multi_logloss: 2.76357
# [96]	valid_0's multi_logloss: 2.76295
# [97]	valid_0's multi_logloss: 2.76231
# [98]	valid_0's multi_logloss: 2.76171
# [99]	valid_0's multi_logloss: 2.76103
# [100]	valid_0's multi_logloss: 2.76033
# [101]	valid_0's multi_logloss: 2.75973
# [102]	valid_0's multi_logloss: 2.75917
# [103]	valid_0's multi_logloss: 2.75854
# [104]	valid_0's multi_logloss: 2.75788
# [105]	valid_0's multi_logloss: 2.75732
# [106]	valid_0's multi_logloss: 2.75665
# [107]	valid_0's multi_logloss: 2.75598
# [108]	valid_0's multi_logloss: 2.75538
# [109]	valid_0's multi_logloss: 2.75473
# [110]	valid_0's multi_logloss: 2.75417
# [111]	valid_0's multi_logloss: 2.75358
# [112]	valid_0's multi_logloss: 2.75304
# [113]	valid_0's multi_logloss: 2.75252
# [114]	valid_0's multi_logloss: 2.75196
# [115]	valid_0's multi_logloss: 2.75137
# [116]	valid_0's multi_logloss: 2.75083
# [117]	valid_0's multi_logloss: 2.7503
# [118]	valid_0's multi_logloss: 2.74977
# [119]	valid_0's multi_logloss: 2.74919
# [120]	valid_0's multi_logloss: 2.7487
# [121]	valid_0's multi_logloss: 2.7481
# [122]	valid_0's multi_logloss: 2.74755
# [123]	valid_0's multi_logloss: 2.74703
# [124]	valid_0's multi_logloss: 2.74662
# [125]	valid_0's multi_logloss: 2.74606
# [126]	valid_0's multi_logloss: 2.74546
# [127]	valid_0's multi_logloss: 2.74495
# [128]	valid_0's multi_logloss: 2.74446
# [129]	valid_0's multi_logloss: 2.74403
# [130]	valid_0's multi_logloss: 2.74352
# [131]	valid_0's multi_logloss: 2.74302
# [132]	valid_0's multi_logloss: 2.74265
# [133]	valid_0's multi_logloss: 2.7422
# [134]	valid_0's multi_logloss: 2.7418
# [135]	valid_0's multi_logloss: 2.74121
# [136]	valid_0's multi_logloss: 2.74072
# [137]	valid_0's multi_logloss: 2.7403
# [138]	valid_0's multi_logloss: 2.7398
# [139]	valid_0's multi_logloss: 2.73932
# [140]	valid_0's multi_logloss: 2.73885
# [141]	valid_0's multi_logloss: 2.73843
# [142]	valid_0's multi_logloss: 2.73797
# [143]	valid_0's multi_logloss: 2.73739
# [144]	valid_0's multi_logloss: 2.73695
# [145]	valid_0's multi_logloss: 2.73648
# [146]	valid_0's multi_logloss: 2.73607
# [147]	valid_0's multi_logloss: 2.73564
# [148]	valid_0's multi_logloss: 2.73524
# [149]	valid_0's multi_logloss: 2.73481
# [150]	valid_0's multi_logloss: 2.73438
# [151]	valid_0's multi_logloss: 2.73396
# [152]	valid_0's multi_logloss: 2.73348
# [153]	valid_0's multi_logloss: 2.73306
# [154]	valid_0's multi_logloss: 2.73256
# [155]	valid_0's multi_logloss: 2.73216
# [156]	valid_0's multi_logloss: 2.73169
# [157]	valid_0's multi_logloss: 2.7312
# [158]	valid_0's multi_logloss: 2.73085
# [159]	valid_0's multi_logloss: 2.73049
# [160]	valid_0's multi_logloss: 2.73004
# [161]	valid_0's multi_logloss: 2.72961
# [162]	valid_0's multi_logloss: 2.72921
# [163]	valid_0's multi_logloss: 2.72881
# [164]	valid_0's multi_logloss: 2.7284
# [165]	valid_0's multi_logloss: 2.72805
# [166]	valid_0's multi_logloss: 2.72777
# [167]	valid_0's multi_logloss: 2.7273
# [168]	valid_0's multi_logloss: 2.72692
# [169]	valid_0's multi_logloss: 2.72651
# [170]	valid_0's multi_logloss: 2.7262
# [171]	valid_0's multi_logloss: 2.72585
# [172]	valid_0's multi_logloss: 2.72535
# [173]	valid_0's multi_logloss: 2.72499
# [174]	valid_0's multi_logloss: 2.72466
# [175]	valid_0's multi_logloss: 2.72427
# [176]	valid_0's multi_logloss: 2.72402
# [177]	valid_0's multi_logloss: 2.72362
# [178]	valid_0's multi_logloss: 2.72322
# [179]	valid_0's multi_logloss: 2.7229
# [180]	valid_0's multi_logloss: 2.72257
# [181]	valid_0's multi_logloss: 2.72222
# [182]	valid_0's multi_logloss: 2.72189
# [183]	valid_0's multi_logloss: 2.72154
# [184]	valid_0's multi_logloss: 2.72129
# [185]	valid_0's multi_logloss: 2.72094
# [186]	valid_0's multi_logloss: 2.72062
# [187]	valid_0's multi_logloss: 2.72037
# [188]	valid_0's multi_logloss: 2.72005
# [189]	valid_0's multi_logloss: 2.7197
# [190]	valid_0's multi_logloss: 2.7195
# [191]	valid_0's multi_logloss: 2.71925
# [192]	valid_0's multi_logloss: 2.71893
# [193]	valid_0's multi_logloss: 2.71866
# [194]	valid_0's multi_logloss: 2.71836
# [195]	valid_0's multi_logloss: 2.71805
# [196]	valid_0's multi_logloss: 2.71779
# [197]	valid_0's multi_logloss: 2.71756
# [198]	valid_0's multi_logloss: 2.71732
# [199]	valid_0's multi_logloss: 2.71713
# [200]	valid_0's multi_logloss: 2.71688
# [201]	valid_0's multi_logloss: 2.71659
# [202]	valid_0's multi_logloss: 2.71632
# [203]	valid_0's multi_logloss: 2.71602
# [204]	valid_0's multi_logloss: 2.7157
# [205]	valid_0's multi_logloss: 2.7155
# [206]	valid_0's multi_logloss: 2.71528
# [207]	valid_0's multi_logloss: 2.71506
# [208]	valid_0's multi_logloss: 2.71477
# [209]	valid_0's multi_logloss: 2.71449
# [210]	valid_0's multi_logloss: 2.71429
# [211]	valid_0's multi_logloss: 2.71408
# [212]	valid_0's multi_logloss: 2.71387
# [213]	valid_0's multi_logloss: 2.71368
# [214]	valid_0's multi_logloss: 2.71336
# [215]	valid_0's multi_logloss: 2.71311
# [216]	valid_0's multi_logloss: 2.71287
# [217]	valid_0's multi_logloss: 2.7126
# [218]	valid_0's multi_logloss: 2.71243
# [219]	valid_0's multi_logloss: 2.71222
# [220]	valid_0's multi_logloss: 2.71203
# [221]	valid_0's multi_logloss: 2.71183
# [222]	valid_0's multi_logloss: 2.71161
# [223]	valid_0's multi_logloss: 2.71141
# [224]	valid_0's multi_logloss: 2.71117
# [225]	valid_0's multi_logloss: 2.71096
# [226]	valid_0's multi_logloss: 2.71076
# [227]	valid_0's multi_logloss: 2.71053
# [228]	valid_0's multi_logloss: 2.7104
# [229]	valid_0's multi_logloss: 2.71023
# [230]	valid_0's multi_logloss: 2.71004
# [231]	valid_0's multi_logloss: 2.70982
# [232]	valid_0's multi_logloss: 2.70959
# [233]	valid_0's multi_logloss: 2.70938
# [234]	valid_0's multi_logloss: 2.70923
# [235]	valid_0's multi_logloss: 2.70905
# [236]	valid_0's multi_logloss: 2.70888
# [237]	valid_0's multi_logloss: 2.70865
# [238]	valid_0's multi_logloss: 2.70848
# [239]	valid_0's multi_logloss: 2.70831
# [240]	valid_0's multi_logloss: 2.70813
# [241]	valid_0's multi_logloss: 2.70795
# [242]	valid_0's multi_logloss: 2.70777
# [243]	valid_0's multi_logloss: 2.7076
# [244]	valid_0's multi_logloss: 2.70748
# [245]	valid_0's multi_logloss: 2.7073
# [246]	valid_0's multi_logloss: 2.70708
# [247]	valid_0's multi_logloss: 2.70691
# [248]	valid_0's multi_logloss: 2.70678
# [249]	valid_0's multi_logloss: 2.7066
# [250]	valid_0's multi_logloss: 2.7065
# [251]	valid_0's multi_logloss: 2.7063
# [252]	valid_0's multi_logloss: 2.70617
# [253]	valid_0's multi_logloss: 2.70603
# [254]	valid_0's multi_logloss: 2.70587
# [255]	valid_0's multi_logloss: 2.70564
# [256]	valid_0's multi_logloss: 2.70552
# [257]	valid_0's multi_logloss: 2.70537
# [258]	valid_0's multi_logloss: 2.70525
# [259]	valid_0's multi_logloss: 2.70507
# [260]	valid_0's multi_logloss: 2.70492
# [261]	valid_0's multi_logloss: 2.70475
# [262]	valid_0's multi_logloss: 2.70456
# [263]	valid_0's multi_logloss: 2.7045
# [264]	valid_0's multi_logloss: 2.70439
# [265]	valid_0's multi_logloss: 2.70428
# [266]	valid_0's multi_logloss: 2.70416
# [267]	valid_0's multi_logloss: 2.70409
# [268]	valid_0's multi_logloss: 2.70396
# [269]	valid_0's multi_logloss: 2.70382
# [270]	valid_0's multi_logloss: 2.70367
# [271]	valid_0's multi_logloss: 2.70359
# [272]	valid_0's multi_logloss: 2.7034
# [273]	valid_0's multi_logloss: 2.70326
# [274]	valid_0's multi_logloss: 2.70307
# [275]	valid_0's multi_logloss: 2.70297
# [276]	valid_0's multi_logloss: 2.70282
# [277]	valid_0's multi_logloss: 2.70273
# [278]	valid_0's multi_logloss: 2.70261
# [279]	valid_0's multi_logloss: 2.7025
# [280]	valid_0's multi_logloss: 2.70239
# [281]	valid_0's multi_logloss: 2.70229
# [282]	valid_0's multi_logloss: 2.7022
# [283]	valid_0's multi_logloss: 2.70206
# [284]	valid_0's multi_logloss: 2.702
# [285]	valid_0's multi_logloss: 2.70191
# [286]	valid_0's multi_logloss: 2.70184
# [287]	valid_0's multi_logloss: 2.70165
# [288]	valid_0's multi_logloss: 2.70156
# [289]	valid_0's multi_logloss: 2.70152
# [290]	valid_0's multi_logloss: 2.70143
# [291]	valid_0's multi_logloss: 2.70136
# [292]	valid_0's multi_logloss: 2.70118
# [293]	valid_0's multi_logloss: 2.70109
# [294]	valid_0's multi_logloss: 2.70094
# [295]	valid_0's multi_logloss: 2.70077
# [296]	valid_0's multi_logloss: 2.70066
# [297]	valid_0's multi_logloss: 2.70058
# [298]	valid_0's multi_logloss: 2.70037
# [299]	valid_0's multi_logloss: 2.70028
# [300]	valid_0's multi_logloss: 2.70013
# [301]	valid_0's multi_logloss: 2.70002
# [302]	valid_0's multi_logloss: 2.69996
# [303]	valid_0's multi_logloss: 2.69988
# [304]	valid_0's multi_logloss: 2.69977
# [305]	valid_0's multi_logloss: 2.6997
# [306]	valid_0's multi_logloss: 2.69959
# [307]	valid_0's multi_logloss: 2.6995
# [308]	valid_0's multi_logloss: 2.6994
# [309]	valid_0's multi_logloss: 2.69926
# [310]	valid_0's multi_logloss: 2.6992
# [311]	valid_0's multi_logloss: 2.69913
# [312]	valid_0's multi_logloss: 2.69909
# [313]	valid_0's multi_logloss: 2.69896
# [314]	valid_0's multi_logloss: 2.69892
# [315]	valid_0's multi_logloss: 2.69887
# [316]	valid_0's multi_logloss: 2.6988
# [317]	valid_0's multi_logloss: 2.69873
# [318]	valid_0's multi_logloss: 2.6987
# [319]	valid_0's multi_logloss: 2.69861
# [320]	valid_0's multi_logloss: 2.69845
# [321]	valid_0's multi_logloss: 2.69833
# [322]	valid_0's multi_logloss: 2.69824
# [323]	valid_0's multi_logloss: 2.69813
# [324]	valid_0's multi_logloss: 2.69806
# [325]	valid_0's multi_logloss: 2.69792
# [326]	valid_0's multi_logloss: 2.69784
# [327]	valid_0's multi_logloss: 2.69779
# [328]	valid_0's multi_logloss: 2.69778
# [329]	valid_0's multi_logloss: 2.69766
# [330]	valid_0's multi_logloss: 2.69758
# [331]	valid_0's multi_logloss: 2.69755
# [332]	valid_0's multi_logloss: 2.69746
# [333]	valid_0's multi_logloss: 2.69747
# [334]	valid_0's multi_logloss: 2.69737
# [335]	valid_0's multi_logloss: 2.69732
# [336]	valid_0's multi_logloss: 2.6973
# [337]	valid_0's multi_logloss: 2.69726
# [338]	valid_0's multi_logloss: 2.6972
# [339]	valid_0's multi_logloss: 2.69714
# [340]	valid_0's multi_logloss: 2.69708
# [341]	valid_0's multi_logloss: 2.69706
# [342]	valid_0's multi_logloss: 2.69702
# [343]	valid_0's multi_logloss: 2.69694
# [344]	valid_0's multi_logloss: 2.6969
# [345]	valid_0's multi_logloss: 2.69683
# [346]	valid_0's multi_logloss: 2.69678
# [347]	valid_0's multi_logloss: 2.69677
# [348]	valid_0's multi_logloss: 2.6967
# [349]	valid_0's multi_logloss: 2.69663
# [350]	valid_0's multi_logloss: 2.69662
# [351]	valid_0's multi_logloss: 2.69663
# [352]	valid_0's multi_logloss: 2.6966
# [353]	valid_0's multi_logloss: 2.69654
# [354]	valid_0's multi_logloss: 2.69648
# [355]	valid_0's multi_logloss: 2.69642
# [356]	valid_0's multi_logloss: 2.69642
# [357]	valid_0's multi_logloss: 2.69636
# [358]	valid_0's multi_logloss: 2.6963
# [359]	valid_0's multi_logloss: 2.69628
# [360]	valid_0's multi_logloss: 2.69626
# [361]	valid_0's multi_logloss: 2.6962
# [362]	valid_0's multi_logloss: 2.69609
# [363]	valid_0's multi_logloss: 2.69599
# [364]	valid_0's multi_logloss: 2.69597
# [365]	valid_0's multi_logloss: 2.69587
# [366]	valid_0's multi_logloss: 2.69582
# [367]	valid_0's multi_logloss: 2.69575
# [368]	valid_0's multi_logloss: 2.6957
# [369]	valid_0's multi_logloss: 2.69563
# [370]	valid_0's multi_logloss: 2.69566
# [371]	valid_0's multi_logloss: 2.6956
# [372]	valid_0's multi_logloss: 2.69559
# [373]	valid_0's multi_logloss: 2.6956
# [374]	valid_0's multi_logloss: 2.69554
# [375]	valid_0's multi_logloss: 2.69545
# [376]	valid_0's multi_logloss: 2.69539
# [377]	valid_0's multi_logloss: 2.69532
# [378]	valid_0's multi_logloss: 2.69523
# [379]	valid_0's multi_logloss: 2.69525
# [380]	valid_0's multi_logloss: 2.69517
# [381]	valid_0's multi_logloss: 2.69513
# [382]	valid_0's multi_logloss: 2.69511
# [383]	valid_0's multi_logloss: 2.69507
# [384]	valid_0's multi_logloss: 2.69509
# [385]	valid_0's multi_logloss: 2.69507
# [386]	valid_0's multi_logloss: 2.69501
# [387]	valid_0's multi_logloss: 2.69495
# [388]	valid_0's multi_logloss: 2.69496
# [389]	valid_0's multi_logloss: 2.69491
# [390]	valid_0's multi_logloss: 2.69484
# [391]	valid_0's multi_logloss: 2.69484
# [392]	valid_0's multi_logloss: 2.69486
# [393]	valid_0's multi_logloss: 2.69484
# [394]	valid_0's multi_logloss: 2.69474
# [395]	valid_0's multi_logloss: 2.69477
# [396]	valid_0's multi_logloss: 2.69479
# [397]	valid_0's multi_logloss: 2.69473
# [398]	valid_0's multi_logloss: 2.69475
# [399]	valid_0's multi_logloss: 2.69479
# [400]	valid_0's multi_logloss: 2.6948
# [401]	valid_0's multi_logloss: 2.69475
# [402]	valid_0's multi_logloss: 2.69467
# [403]	valid_0's multi_logloss: 2.69466
# [404]	valid_0's multi_logloss: 2.69468
# [405]	valid_0's multi_logloss: 2.69469
# [406]	valid_0's multi_logloss: 2.69463
# [407]	valid_0's multi_logloss: 2.69464
# [408]	valid_0's multi_logloss: 2.69465
# [409]	valid_0's multi_logloss: 2.69461
# [410]	valid_0's multi_logloss: 2.6946
# [411]	valid_0's multi_logloss: 2.69458
# [412]	valid_0's multi_logloss: 2.6946
# [413]	valid_0's multi_logloss: 2.69453
# [414]	valid_0's multi_logloss: 2.69453
# [415]	valid_0's multi_logloss: 2.69458
# [416]	valid_0's multi_logloss: 2.69456
# [417]	valid_0's multi_logloss: 2.69452
# [418]	valid_0's multi_logloss: 2.69456
# [419]	valid_0's multi_logloss: 2.69457
# [420]	valid_0's multi_logloss: 2.69455
# [421]	valid_0's multi_logloss: 2.69454
# [422]	valid_0's multi_logloss: 2.69456
# [423]	valid_0's multi_logloss: 2.69449
# [424]	valid_0's multi_logloss: 2.6945
# [425]	valid_0's multi_logloss: 2.69449
# [426]	valid_0's multi_logloss: 2.69451
# [427]	valid_0's multi_logloss: 2.6945
# [428]	valid_0's multi_logloss: 2.69449
# [429]	valid_0's multi_logloss: 2.69449
# [430]	valid_0's multi_logloss: 2.69449
# [431]	valid_0's multi_logloss: 2.69447
# [432]	valid_0's multi_logloss: 2.69446
# [433]	valid_0's multi_logloss: 2.69442
# [434]	valid_0's multi_logloss: 2.69448
# [435]	valid_0's multi_logloss: 2.69452
# [436]	valid_0's multi_logloss: 2.69455
# [437]	valid_0's multi_logloss: 2.69453
# [438]	valid_0's multi_logloss: 2.69454
# [439]	valid_0's multi_logloss: 2.69458
# [440]	valid_0's multi_logloss: 2.69459
# [441]	valid_0's multi_logloss: 2.6946
# [442]	valid_0's multi_logloss: 2.69455
# [443]	valid_0's multi_logloss: 2.69453
# Early stopping, best iteration is:
# [433]	valid_0's multi_logloss: 2.69442
# 0.01249812426521828
# [1]	valid_0's multi_logloss: 2.88671
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88374
# [3]	valid_0's multi_logloss: 2.88144
# [4]	valid_0's multi_logloss: 2.87905
# [5]	valid_0's multi_logloss: 2.87695
# [6]	valid_0's multi_logloss: 2.87475
# [7]	valid_0's multi_logloss: 2.87274
# [8]	valid_0's multi_logloss: 2.87089
# [9]	valid_0's multi_logloss: 2.86907
# [10]	valid_0's multi_logloss: 2.86717
# [11]	valid_0's multi_logloss: 2.86542
# [12]	valid_0's multi_logloss: 2.86352
# [13]	valid_0's multi_logloss: 2.8617
# [14]	valid_0's multi_logloss: 2.86022
# [15]	valid_0's multi_logloss: 2.85857
# [16]	valid_0's multi_logloss: 2.85692
# [17]	valid_0's multi_logloss: 2.85542
# [18]	valid_0's multi_logloss: 2.85382
# [19]	valid_0's multi_logloss: 2.85218
# [20]	valid_0's multi_logloss: 2.85066
# [21]	valid_0's multi_logloss: 2.84912
# [22]	valid_0's multi_logloss: 2.8477
# [23]	valid_0's multi_logloss: 2.84618
# [24]	valid_0's multi_logloss: 2.84472
# [25]	valid_0's multi_logloss: 2.84335
# [26]	valid_0's multi_logloss: 2.84183
# [27]	valid_0's multi_logloss: 2.8403
# [28]	valid_0's multi_logloss: 2.83891
# [29]	valid_0's multi_logloss: 2.83759
# [30]	valid_0's multi_logloss: 2.83615
# [31]	valid_0's multi_logloss: 2.8348
# [32]	valid_0's multi_logloss: 2.83348
# [33]	valid_0's multi_logloss: 2.83214
# [34]	valid_0's multi_logloss: 2.83077
# [35]	valid_0's multi_logloss: 2.82948
# [36]	valid_0's multi_logloss: 2.82827
# [37]	valid_0's multi_logloss: 2.82697
# [38]	valid_0's multi_logloss: 2.82574
# [39]	valid_0's multi_logloss: 2.82462
# [40]	valid_0's multi_logloss: 2.82338
# [41]	valid_0's multi_logloss: 2.8222
# [42]	valid_0's multi_logloss: 2.82111
# [43]	valid_0's multi_logloss: 2.81998
# [44]	valid_0's multi_logloss: 2.8188
# [45]	valid_0's multi_logloss: 2.81777
# [46]	valid_0's multi_logloss: 2.81671
# [47]	valid_0's multi_logloss: 2.81568
# [48]	valid_0's multi_logloss: 2.8146
# [49]	valid_0's multi_logloss: 2.81349
# [50]	valid_0's multi_logloss: 2.81248
# [51]	valid_0's multi_logloss: 2.81153
# [52]	valid_0's multi_logloss: 2.81048
# [53]	valid_0's multi_logloss: 2.8097
# [54]	valid_0's multi_logloss: 2.8086
# [55]	valid_0's multi_logloss: 2.80773
# [56]	valid_0's multi_logloss: 2.80666
# [57]	valid_0's multi_logloss: 2.80563
# [58]	valid_0's multi_logloss: 2.80467
# [59]	valid_0's multi_logloss: 2.80371
# [60]	valid_0's multi_logloss: 2.80285
# [61]	valid_0's multi_logloss: 2.80196
# [62]	valid_0's multi_logloss: 2.80103
# [63]	valid_0's multi_logloss: 2.80009
# [64]	valid_0's multi_logloss: 2.79915
# [65]	valid_0's multi_logloss: 2.79831
# [66]	valid_0's multi_logloss: 2.7974
# [67]	valid_0's multi_logloss: 2.79655
# [68]	valid_0's multi_logloss: 2.7956
# [69]	valid_0's multi_logloss: 2.79471
# [70]	valid_0's multi_logloss: 2.79376
# [71]	valid_0's multi_logloss: 2.793
# [72]	valid_0's multi_logloss: 2.7921
# [73]	valid_0's multi_logloss: 2.7913
# [74]	valid_0's multi_logloss: 2.79049
# [75]	valid_0's multi_logloss: 2.78964
# [76]	valid_0's multi_logloss: 2.78875
# [77]	valid_0's multi_logloss: 2.78794
# [78]	valid_0's multi_logloss: 2.78705
# [79]	valid_0's multi_logloss: 2.78622
# [80]	valid_0's multi_logloss: 2.78544
# [81]	valid_0's multi_logloss: 2.78472
# [82]	valid_0's multi_logloss: 2.78391
# [83]	valid_0's multi_logloss: 2.78317
# [84]	valid_0's multi_logloss: 2.78237
# [85]	valid_0's multi_logloss: 2.78161
# [86]	valid_0's multi_logloss: 2.78094
# [87]	valid_0's multi_logloss: 2.78012
# [88]	valid_0's multi_logloss: 2.77933
# [89]	valid_0's multi_logloss: 2.77861
# [90]	valid_0's multi_logloss: 2.77779
# [91]	valid_0's multi_logloss: 2.77706
# [92]	valid_0's multi_logloss: 2.77631
# [93]	valid_0's multi_logloss: 2.77559
# [94]	valid_0's multi_logloss: 2.77479
# [95]	valid_0's multi_logloss: 2.77407
# [96]	valid_0's multi_logloss: 2.77328
# [97]	valid_0's multi_logloss: 2.77259
# [98]	valid_0's multi_logloss: 2.77184
# [99]	valid_0's multi_logloss: 2.77118
# [100]	valid_0's multi_logloss: 2.77044
# [101]	valid_0's multi_logloss: 2.76982
# [102]	valid_0's multi_logloss: 2.76906
# [103]	valid_0's multi_logloss: 2.76835
# [104]	valid_0's multi_logloss: 2.76762
# [105]	valid_0's multi_logloss: 2.76695
# [106]	valid_0's multi_logloss: 2.76629
# [107]	valid_0's multi_logloss: 2.76566
# [108]	valid_0's multi_logloss: 2.76501
# [109]	valid_0's multi_logloss: 2.76446
# [110]	valid_0's multi_logloss: 2.76385
# [111]	valid_0's multi_logloss: 2.76326
# [112]	valid_0's multi_logloss: 2.76271
# [113]	valid_0's multi_logloss: 2.76202
# [114]	valid_0's multi_logloss: 2.76139
# [115]	valid_0's multi_logloss: 2.76081
# [116]	valid_0's multi_logloss: 2.76029
# [117]	valid_0's multi_logloss: 2.75967
# [118]	valid_0's multi_logloss: 2.75907
# [119]	valid_0's multi_logloss: 2.75847
# [120]	valid_0's multi_logloss: 2.75793
# [121]	valid_0's multi_logloss: 2.7573
# [122]	valid_0's multi_logloss: 2.75669
# [123]	valid_0's multi_logloss: 2.7561
# [124]	valid_0's multi_logloss: 2.75548
# [125]	valid_0's multi_logloss: 2.75479
# [126]	valid_0's multi_logloss: 2.75428
# [127]	valid_0's multi_logloss: 2.7537
# [128]	valid_0's multi_logloss: 2.75308
# [129]	valid_0's multi_logloss: 2.75261
# [130]	valid_0's multi_logloss: 2.75199
# [131]	valid_0's multi_logloss: 2.75146
# [132]	valid_0's multi_logloss: 2.75088
# [133]	valid_0's multi_logloss: 2.75034
# [134]	valid_0's multi_logloss: 2.74979
# [135]	valid_0's multi_logloss: 2.74928
# [136]	valid_0's multi_logloss: 2.74877
# [137]	valid_0's multi_logloss: 2.74829
# [138]	valid_0's multi_logloss: 2.74771
# [139]	valid_0's multi_logloss: 2.74723
# [140]	valid_0's multi_logloss: 2.74673
# [141]	valid_0's multi_logloss: 2.74615
# [142]	valid_0's multi_logloss: 2.74575
# [143]	valid_0's multi_logloss: 2.74528
# [144]	valid_0's multi_logloss: 2.74477
# [145]	valid_0's multi_logloss: 2.74437
# [146]	valid_0's multi_logloss: 2.74389
# [147]	valid_0's multi_logloss: 2.74344
# [148]	valid_0's multi_logloss: 2.74302
# [149]	valid_0's multi_logloss: 2.74256
# [150]	valid_0's multi_logloss: 2.74206
# [151]	valid_0's multi_logloss: 2.74165
# [152]	valid_0's multi_logloss: 2.74122
# [153]	valid_0's multi_logloss: 2.74075
# [154]	valid_0's multi_logloss: 2.7403
# [155]	valid_0's multi_logloss: 2.73976
# [156]	valid_0's multi_logloss: 2.73934
# [157]	valid_0's multi_logloss: 2.73892
# [158]	valid_0's multi_logloss: 2.7386
# [159]	valid_0's multi_logloss: 2.73817
# [160]	valid_0's multi_logloss: 2.73773
# [161]	valid_0's multi_logloss: 2.73738
# [162]	valid_0's multi_logloss: 2.73698
# [163]	valid_0's multi_logloss: 2.73657
# [164]	valid_0's multi_logloss: 2.73617
# [165]	valid_0's multi_logloss: 2.73579
# [166]	valid_0's multi_logloss: 2.73534
# [167]	valid_0's multi_logloss: 2.73492
# [168]	valid_0's multi_logloss: 2.73453
# [169]	valid_0's multi_logloss: 2.7341
# [170]	valid_0's multi_logloss: 2.73368
# [171]	valid_0's multi_logloss: 2.73326
# [172]	valid_0's multi_logloss: 2.73285
# [173]	valid_0's multi_logloss: 2.73248
# [174]	valid_0's multi_logloss: 2.73209
# [175]	valid_0's multi_logloss: 2.73177
# [176]	valid_0's multi_logloss: 2.73142
# [177]	valid_0's multi_logloss: 2.73102
# [178]	valid_0's multi_logloss: 2.73067
# [179]	valid_0's multi_logloss: 2.73031
# [180]	valid_0's multi_logloss: 2.72988
# [181]	valid_0's multi_logloss: 2.72954
# [182]	valid_0's multi_logloss: 2.72916
# [183]	valid_0's multi_logloss: 2.72889
# [184]	valid_0's multi_logloss: 2.7285
# [185]	valid_0's multi_logloss: 2.72813
# [186]	valid_0's multi_logloss: 2.72787
# [187]	valid_0's multi_logloss: 2.72748
# [188]	valid_0's multi_logloss: 2.72707
# [189]	valid_0's multi_logloss: 2.72683
# [190]	valid_0's multi_logloss: 2.72654
# [191]	valid_0's multi_logloss: 2.72623
# [192]	valid_0's multi_logloss: 2.72585
# [193]	valid_0's multi_logloss: 2.72551
# [194]	valid_0's multi_logloss: 2.72523
# [195]	valid_0's multi_logloss: 2.72488
# [196]	valid_0's multi_logloss: 2.72466
# [197]	valid_0's multi_logloss: 2.72442
# [198]	valid_0's multi_logloss: 2.72411
# [199]	valid_0's multi_logloss: 2.72382
# [200]	valid_0's multi_logloss: 2.72349
# [201]	valid_0's multi_logloss: 2.7232
# [202]	valid_0's multi_logloss: 2.72286
# [203]	valid_0's multi_logloss: 2.72257
# [204]	valid_0's multi_logloss: 2.72232
# [205]	valid_0's multi_logloss: 2.72203
# [206]	valid_0's multi_logloss: 2.72165
# [207]	valid_0's multi_logloss: 2.72138
# [208]	valid_0's multi_logloss: 2.72108
# [209]	valid_0's multi_logloss: 2.72079
# [210]	valid_0's multi_logloss: 2.72047
# [211]	valid_0's multi_logloss: 2.72016
# [212]	valid_0's multi_logloss: 2.71985
# [213]	valid_0's multi_logloss: 2.71958
# [214]	valid_0's multi_logloss: 2.71926
# [215]	valid_0's multi_logloss: 2.71903
# [216]	valid_0's multi_logloss: 2.71871
# [217]	valid_0's multi_logloss: 2.71839
# [218]	valid_0's multi_logloss: 2.71806
# [219]	valid_0's multi_logloss: 2.71778
# [220]	valid_0's multi_logloss: 2.71749
# [221]	valid_0's multi_logloss: 2.71725
# [222]	valid_0's multi_logloss: 2.71698
# [223]	valid_0's multi_logloss: 2.71671
# [224]	valid_0's multi_logloss: 2.71647
# [225]	valid_0's multi_logloss: 2.71628
# [226]	valid_0's multi_logloss: 2.71598
# [227]	valid_0's multi_logloss: 2.71569
# [228]	valid_0's multi_logloss: 2.71544
# [229]	valid_0's multi_logloss: 2.71515
# [230]	valid_0's multi_logloss: 2.71489
# [231]	valid_0's multi_logloss: 2.71461
# [232]	valid_0's multi_logloss: 2.71434
# [233]	valid_0's multi_logloss: 2.71407
# [234]	valid_0's multi_logloss: 2.7138
# [235]	valid_0's multi_logloss: 2.71359
# [236]	valid_0's multi_logloss: 2.71335
# [237]	valid_0's multi_logloss: 2.71312
# [238]	valid_0's multi_logloss: 2.7128
# [239]	valid_0's multi_logloss: 2.71258
# [240]	valid_0's multi_logloss: 2.7124
# [241]	valid_0's multi_logloss: 2.71216
# [242]	valid_0's multi_logloss: 2.7119
# [243]	valid_0's multi_logloss: 2.71169
# [244]	valid_0's multi_logloss: 2.71143
# [245]	valid_0's multi_logloss: 2.71121
# [246]	valid_0's multi_logloss: 2.71101
# [247]	valid_0's multi_logloss: 2.71067
# [248]	valid_0's multi_logloss: 2.71044
# [249]	valid_0's multi_logloss: 2.71023
# [250]	valid_0's multi_logloss: 2.70997
# [251]	valid_0's multi_logloss: 2.70983
# [252]	valid_0's multi_logloss: 2.70956
# [253]	valid_0's multi_logloss: 2.70931
# [254]	valid_0's multi_logloss: 2.70906
# [255]	valid_0's multi_logloss: 2.70891
# [256]	valid_0's multi_logloss: 2.70874
# [257]	valid_0's multi_logloss: 2.7085
# [258]	valid_0's multi_logloss: 2.70833
# [259]	valid_0's multi_logloss: 2.70816
# [260]	valid_0's multi_logloss: 2.7079
# [261]	valid_0's multi_logloss: 2.70771
# [262]	valid_0's multi_logloss: 2.70748
# [263]	valid_0's multi_logloss: 2.70731
# [264]	valid_0's multi_logloss: 2.70714
# [265]	valid_0's multi_logloss: 2.70697
# [266]	valid_0's multi_logloss: 2.70667
# [267]	valid_0's multi_logloss: 2.70644
# [268]	valid_0's multi_logloss: 2.70626
# [269]	valid_0's multi_logloss: 2.70607
# [270]	valid_0's multi_logloss: 2.70586
# [271]	valid_0's multi_logloss: 2.70568
# [272]	valid_0's multi_logloss: 2.70549
# [273]	valid_0's multi_logloss: 2.70524
# [274]	valid_0's multi_logloss: 2.70505
# [275]	valid_0's multi_logloss: 2.70484
# [276]	valid_0's multi_logloss: 2.70469
# [277]	valid_0's multi_logloss: 2.7045
# [278]	valid_0's multi_logloss: 2.70429
# [279]	valid_0's multi_logloss: 2.70405
# [280]	valid_0's multi_logloss: 2.70386
# [281]	valid_0's multi_logloss: 2.70364
# [282]	valid_0's multi_logloss: 2.70345
# [283]	valid_0's multi_logloss: 2.70326
# [284]	valid_0's multi_logloss: 2.70311
# [285]	valid_0's multi_logloss: 2.70291
# [286]	valid_0's multi_logloss: 2.70271
# [287]	valid_0's multi_logloss: 2.7025
# [288]	valid_0's multi_logloss: 2.70233
# [289]	valid_0's multi_logloss: 2.70217
# [290]	valid_0's multi_logloss: 2.702
# [291]	valid_0's multi_logloss: 2.70182
# [292]	valid_0's multi_logloss: 2.70174
# [293]	valid_0's multi_logloss: 2.70151
# [294]	valid_0's multi_logloss: 2.70138
# [295]	valid_0's multi_logloss: 2.70122
# [296]	valid_0's multi_logloss: 2.70107
# [297]	valid_0's multi_logloss: 2.70091
# [298]	valid_0's multi_logloss: 2.70076
# [299]	valid_0's multi_logloss: 2.7006
# [300]	valid_0's multi_logloss: 2.7004
# [301]	valid_0's multi_logloss: 2.70021
# [302]	valid_0's multi_logloss: 2.70004
# [303]	valid_0's multi_logloss: 2.69992
# [304]	valid_0's multi_logloss: 2.69976
# [305]	valid_0's multi_logloss: 2.69958
# [306]	valid_0's multi_logloss: 2.6994
# [307]	valid_0's multi_logloss: 2.69931
# [308]	valid_0's multi_logloss: 2.69917
# [309]	valid_0's multi_logloss: 2.69898
# [310]	valid_0's multi_logloss: 2.69884
# [311]	valid_0's multi_logloss: 2.69864
# [312]	valid_0's multi_logloss: 2.6985
# [313]	valid_0's multi_logloss: 2.69838
# [314]	valid_0's multi_logloss: 2.69822
# [315]	valid_0's multi_logloss: 2.69809
# [316]	valid_0's multi_logloss: 2.69792
# [317]	valid_0's multi_logloss: 2.69778
# [318]	valid_0's multi_logloss: 2.69762
# [319]	valid_0's multi_logloss: 2.69747
# [320]	valid_0's multi_logloss: 2.69733
# [321]	valid_0's multi_logloss: 2.69723
# [322]	valid_0's multi_logloss: 2.69705
# [323]	valid_0's multi_logloss: 2.69691
# [324]	valid_0's multi_logloss: 2.6968
# [325]	valid_0's multi_logloss: 2.69676
# [326]	valid_0's multi_logloss: 2.69667
# [327]	valid_0's multi_logloss: 2.6966
# [328]	valid_0's multi_logloss: 2.69654
# [329]	valid_0's multi_logloss: 2.69644
# [330]	valid_0's multi_logloss: 2.69634
# [331]	valid_0's multi_logloss: 2.69628
# [332]	valid_0's multi_logloss: 2.69613
# [333]	valid_0's multi_logloss: 2.69606
# [334]	valid_0's multi_logloss: 2.69593
# [335]	valid_0's multi_logloss: 2.69591
# [336]	valid_0's multi_logloss: 2.69582
# [337]	valid_0's multi_logloss: 2.6957
# [338]	valid_0's multi_logloss: 2.69564
# [339]	valid_0's multi_logloss: 2.69554
# [340]	valid_0's multi_logloss: 2.69542
# [341]	valid_0's multi_logloss: 2.69532
# [342]	valid_0's multi_logloss: 2.69526
# [343]	valid_0's multi_logloss: 2.69515
# [344]	valid_0's multi_logloss: 2.69506
# [345]	valid_0's multi_logloss: 2.69494
# [346]	valid_0's multi_logloss: 2.6948
# [347]	valid_0's multi_logloss: 2.69471
# [348]	valid_0's multi_logloss: 2.69458
# [349]	valid_0's multi_logloss: 2.69453
# [350]	valid_0's multi_logloss: 2.69448
# [351]	valid_0's multi_logloss: 2.69434
# [352]	valid_0's multi_logloss: 2.69425
# [353]	valid_0's multi_logloss: 2.69412
# [354]	valid_0's multi_logloss: 2.69404
# [355]	valid_0's multi_logloss: 2.69396
# [356]	valid_0's multi_logloss: 2.69387
# [357]	valid_0's multi_logloss: 2.69383
# [358]	valid_0's multi_logloss: 2.69377
# [359]	valid_0's multi_logloss: 2.69366
# [360]	valid_0's multi_logloss: 2.69357
# [361]	valid_0's multi_logloss: 2.69354
# [362]	valid_0's multi_logloss: 2.69346
# [363]	valid_0's multi_logloss: 2.69336
# [364]	valid_0's multi_logloss: 2.69326
# [365]	valid_0's multi_logloss: 2.69314
# [366]	valid_0's multi_logloss: 2.69316
# [367]	valid_0's multi_logloss: 2.693
# [368]	valid_0's multi_logloss: 2.6929
# [369]	valid_0's multi_logloss: 2.69286
# [370]	valid_0's multi_logloss: 2.6928
# [371]	valid_0's multi_logloss: 2.6927
# [372]	valid_0's multi_logloss: 2.69263
# [373]	valid_0's multi_logloss: 2.69258
# [374]	valid_0's multi_logloss: 2.69245
# [375]	valid_0's multi_logloss: 2.69245
# [376]	valid_0's multi_logloss: 2.69237
# [377]	valid_0's multi_logloss: 2.69229
# [378]	valid_0's multi_logloss: 2.69222
# [379]	valid_0's multi_logloss: 2.69222
# [380]	valid_0's multi_logloss: 2.6922
# [381]	valid_0's multi_logloss: 2.69216
# [382]	valid_0's multi_logloss: 2.69204
# [383]	valid_0's multi_logloss: 2.692
# [384]	valid_0's multi_logloss: 2.69192
# [385]	valid_0's multi_logloss: 2.69188
# [386]	valid_0's multi_logloss: 2.69178
# [387]	valid_0's multi_logloss: 2.69172
# [388]	valid_0's multi_logloss: 2.69173
# [389]	valid_0's multi_logloss: 2.69167
# [390]	valid_0's multi_logloss: 2.69163
# [391]	valid_0's multi_logloss: 2.69156
# [392]	valid_0's multi_logloss: 2.69148
# [393]	valid_0's multi_logloss: 2.69138
# [394]	valid_0's multi_logloss: 2.69139
# [395]	valid_0's multi_logloss: 2.69133
# [396]	valid_0's multi_logloss: 2.69129
# [397]	valid_0's multi_logloss: 2.6912
# [398]	valid_0's multi_logloss: 2.69114
# [399]	valid_0's multi_logloss: 2.69112
# [400]	valid_0's multi_logloss: 2.69103
# [401]	valid_0's multi_logloss: 2.69093
# [402]	valid_0's multi_logloss: 2.69089
# [403]	valid_0's multi_logloss: 2.69089
# [404]	valid_0's multi_logloss: 2.69084
# [405]	valid_0's multi_logloss: 2.69079
# [406]	valid_0's multi_logloss: 2.69072
# [407]	valid_0's multi_logloss: 2.69065
# [408]	valid_0's multi_logloss: 2.69056
# [409]	valid_0's multi_logloss: 2.69049
# [410]	valid_0's multi_logloss: 2.69048
# [411]	valid_0's multi_logloss: 2.69047
# [412]	valid_0's multi_logloss: 2.69039
# [413]	valid_0's multi_logloss: 2.69036
# [414]	valid_0's multi_logloss: 2.69031
# [415]	valid_0's multi_logloss: 2.69026
# [416]	valid_0's multi_logloss: 2.69022
# [417]	valid_0's multi_logloss: 2.69013
# [418]	valid_0's multi_logloss: 2.69009
# [419]	valid_0's multi_logloss: 2.69006
# [420]	valid_0's multi_logloss: 2.69002
# [421]	valid_0's multi_logloss: 2.68994
# [422]	valid_0's multi_logloss: 2.68997
# [423]	valid_0's multi_logloss: 2.68988
# [424]	valid_0's multi_logloss: 2.68988
# [425]	valid_0's multi_logloss: 2.68981
# [426]	valid_0's multi_logloss: 2.68979
# [427]	valid_0's multi_logloss: 2.68973
# [428]	valid_0's multi_logloss: 2.68972
# [429]	valid_0's multi_logloss: 2.68971
# [430]	valid_0's multi_logloss: 2.6897
# [431]	valid_0's multi_logloss: 2.68961
# [432]	valid_0's multi_logloss: 2.6896
# [433]	valid_0's multi_logloss: 2.68959
# [434]	valid_0's multi_logloss: 2.68962
# [435]	valid_0's multi_logloss: 2.68959
# [436]	valid_0's multi_logloss: 2.68955
# [437]	valid_0's multi_logloss: 2.68955
# [438]	valid_0's multi_logloss: 2.68949
# [439]	valid_0's multi_logloss: 2.68945
# [440]	valid_0's multi_logloss: 2.68943
# [441]	valid_0's multi_logloss: 2.6894
# [442]	valid_0's multi_logloss: 2.68938
# [443]	valid_0's multi_logloss: 2.68931
# [444]	valid_0's multi_logloss: 2.68935
# [445]	valid_0's multi_logloss: 2.68937
# [446]	valid_0's multi_logloss: 2.68935
# [447]	valid_0's multi_logloss: 2.68929
# [448]	valid_0's multi_logloss: 2.68929
# [449]	valid_0's multi_logloss: 2.68931
# [450]	valid_0's multi_logloss: 2.68929
# [451]	valid_0's multi_logloss: 2.68927
# [452]	valid_0's multi_logloss: 2.68925
# [453]	valid_0's multi_logloss: 2.68919
# [454]	valid_0's multi_logloss: 2.68913
# [455]	valid_0's multi_logloss: 2.68914
# [456]	valid_0's multi_logloss: 2.68913
# [457]	valid_0's multi_logloss: 2.68911
# [458]	valid_0's multi_logloss: 2.68917
# [459]	valid_0's multi_logloss: 2.68918
# [460]	valid_0's multi_logloss: 2.68914
# [461]	valid_0's multi_logloss: 2.68906
# [462]	valid_0's multi_logloss: 2.68906
# [463]	valid_0's multi_logloss: 2.68906
# [464]	valid_0's multi_logloss: 2.68905
# [465]	valid_0's multi_logloss: 2.68905
# [466]	valid_0's multi_logloss: 2.68904
# [467]	valid_0's multi_logloss: 2.689
# [468]	valid_0's multi_logloss: 2.68895
# [469]	valid_0's multi_logloss: 2.68896
# [470]	valid_0's multi_logloss: 2.68898
# [471]	valid_0's multi_logloss: 2.68896
# [472]	valid_0's multi_logloss: 2.68893
# [473]	valid_0's multi_logloss: 2.68891
# [474]	valid_0's multi_logloss: 2.68893
# [475]	valid_0's multi_logloss: 2.68897
# [476]	valid_0's multi_logloss: 2.68892
# [477]	valid_0's multi_logloss: 2.68893
# [478]	valid_0's multi_logloss: 2.68893
# [479]	valid_0's multi_logloss: 2.68885
# [480]	valid_0's multi_logloss: 2.68888
# [481]	valid_0's multi_logloss: 2.68892
# [482]	valid_0's multi_logloss: 2.6889
# [483]	valid_0's multi_logloss: 2.68889
# [484]	valid_0's multi_logloss: 2.68885
# [485]	valid_0's multi_logloss: 2.68884
# [486]	valid_0's multi_logloss: 2.68886
# [487]	valid_0's multi_logloss: 2.68889
# [488]	valid_0's multi_logloss: 2.68889
# [489]	valid_0's multi_logloss: 2.68892
# [490]	valid_0's multi_logloss: 2.68893
# [491]	valid_0's multi_logloss: 2.68895
# [492]	valid_0's multi_logloss: 2.689
# [493]	valid_0's multi_logloss: 2.68902
# [494]	valid_0's multi_logloss: 2.689
# [495]	valid_0's multi_logloss: 2.68899
# Early stopping, best iteration is:
# [485]	valid_0's multi_logloss: 2.68884
# 0.01228799313898565
# [1]	valid_0's multi_logloss: 2.85876
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.8568
# [3]	valid_0's multi_logloss: 2.85496
# [4]	valid_0's multi_logloss: 2.85297
# [5]	valid_0's multi_logloss: 2.85112
# [6]	valid_0's multi_logloss: 2.8493
# [7]	valid_0's multi_logloss: 2.84755
# [8]	valid_0's multi_logloss: 2.84574
# [9]	valid_0's multi_logloss: 2.84417
# [10]	valid_0's multi_logloss: 2.84262
# [11]	valid_0's multi_logloss: 2.84103
# [12]	valid_0's multi_logloss: 2.83954
# [13]	valid_0's multi_logloss: 2.83791
# [14]	valid_0's multi_logloss: 2.83636
# [15]	valid_0's multi_logloss: 2.83494
# [16]	valid_0's multi_logloss: 2.83351
# [17]	valid_0's multi_logloss: 2.83211
# [18]	valid_0's multi_logloss: 2.83064
# [19]	valid_0's multi_logloss: 2.8294
# [20]	valid_0's multi_logloss: 2.82817
# [21]	valid_0's multi_logloss: 2.82686
# [22]	valid_0's multi_logloss: 2.82571
# [23]	valid_0's multi_logloss: 2.82443
# [24]	valid_0's multi_logloss: 2.82334
# [25]	valid_0's multi_logloss: 2.82203
# [26]	valid_0's multi_logloss: 2.82091
# [27]	valid_0's multi_logloss: 2.81979
# [28]	valid_0's multi_logloss: 2.81866
# [29]	valid_0's multi_logloss: 2.81752
# [30]	valid_0's multi_logloss: 2.81651
# [31]	valid_0's multi_logloss: 2.81552
# [32]	valid_0's multi_logloss: 2.81444
# [33]	valid_0's multi_logloss: 2.81345
# [34]	valid_0's multi_logloss: 2.81239
# [35]	valid_0's multi_logloss: 2.81142
# [36]	valid_0's multi_logloss: 2.8104
# [37]	valid_0's multi_logloss: 2.80951
# [38]	valid_0's multi_logloss: 2.80864
# [39]	valid_0's multi_logloss: 2.80765
# [40]	valid_0's multi_logloss: 2.80671
# [41]	valid_0's multi_logloss: 2.80577
# [42]	valid_0's multi_logloss: 2.80486
# [43]	valid_0's multi_logloss: 2.80402
# [44]	valid_0's multi_logloss: 2.80309
# [45]	valid_0's multi_logloss: 2.80224
# [46]	valid_0's multi_logloss: 2.80131
# [47]	valid_0's multi_logloss: 2.80048
# [48]	valid_0's multi_logloss: 2.79953
# [49]	valid_0's multi_logloss: 2.79877
# [50]	valid_0's multi_logloss: 2.79792
# [51]	valid_0's multi_logloss: 2.797
# [52]	valid_0's multi_logloss: 2.79616
# [53]	valid_0's multi_logloss: 2.79529
# [54]	valid_0's multi_logloss: 2.79446
# [55]	valid_0's multi_logloss: 2.79359
# [56]	valid_0's multi_logloss: 2.79273
# [57]	valid_0's multi_logloss: 2.79196
# [58]	valid_0's multi_logloss: 2.79118
# [59]	valid_0's multi_logloss: 2.79033
# [60]	valid_0's multi_logloss: 2.78949
# [61]	valid_0's multi_logloss: 2.78869
# [62]	valid_0's multi_logloss: 2.7879
# [63]	valid_0's multi_logloss: 2.78707
# [64]	valid_0's multi_logloss: 2.78629
# [65]	valid_0's multi_logloss: 2.78542
# [66]	valid_0's multi_logloss: 2.78462
# [67]	valid_0's multi_logloss: 2.78387
# [68]	valid_0's multi_logloss: 2.78307
# [69]	valid_0's multi_logloss: 2.78231
# [70]	valid_0's multi_logloss: 2.78157
# [71]	valid_0's multi_logloss: 2.78085
# [72]	valid_0's multi_logloss: 2.78014
# [73]	valid_0's multi_logloss: 2.77944
# [74]	valid_0's multi_logloss: 2.77887
# [75]	valid_0's multi_logloss: 2.7782
# [76]	valid_0's multi_logloss: 2.77752
# [77]	valid_0's multi_logloss: 2.7768
# [78]	valid_0's multi_logloss: 2.77612
# [79]	valid_0's multi_logloss: 2.77549
# [80]	valid_0's multi_logloss: 2.7748
# [81]	valid_0's multi_logloss: 2.7742
# [82]	valid_0's multi_logloss: 2.77353
# [83]	valid_0's multi_logloss: 2.77302
# [84]	valid_0's multi_logloss: 2.77241
# [85]	valid_0's multi_logloss: 2.77185
# [86]	valid_0's multi_logloss: 2.77116
# [87]	valid_0's multi_logloss: 2.77057
# [88]	valid_0's multi_logloss: 2.77002
# [89]	valid_0's multi_logloss: 2.76937
# [90]	valid_0's multi_logloss: 2.76875
# [91]	valid_0's multi_logloss: 2.76802
# [92]	valid_0's multi_logloss: 2.7674
# [93]	valid_0's multi_logloss: 2.76684
# [94]	valid_0's multi_logloss: 2.76631
# [95]	valid_0's multi_logloss: 2.76576
# [96]	valid_0's multi_logloss: 2.76517
# [97]	valid_0's multi_logloss: 2.76462
# [98]	valid_0's multi_logloss: 2.76406
# [99]	valid_0's multi_logloss: 2.76352
# [100]	valid_0's multi_logloss: 2.76294
# [101]	valid_0's multi_logloss: 2.76235
# [102]	valid_0's multi_logloss: 2.76177
# [103]	valid_0's multi_logloss: 2.76116
# [104]	valid_0's multi_logloss: 2.76063
# [105]	valid_0's multi_logloss: 2.76012
# [106]	valid_0's multi_logloss: 2.75962
# [107]	valid_0's multi_logloss: 2.75909
# [108]	valid_0's multi_logloss: 2.75852
# [109]	valid_0's multi_logloss: 2.7579
# [110]	valid_0's multi_logloss: 2.75731
# [111]	valid_0's multi_logloss: 2.75681
# [112]	valid_0's multi_logloss: 2.75627
# [113]	valid_0's multi_logloss: 2.75574
# [114]	valid_0's multi_logloss: 2.75518
# [115]	valid_0's multi_logloss: 2.75464
# [116]	valid_0's multi_logloss: 2.75411
# [117]	valid_0's multi_logloss: 2.75356
# [118]	valid_0's multi_logloss: 2.75296
# [119]	valid_0's multi_logloss: 2.7525
# [120]	valid_0's multi_logloss: 2.75199
# [121]	valid_0's multi_logloss: 2.75152
# [122]	valid_0's multi_logloss: 2.75101
# [123]	valid_0's multi_logloss: 2.75053
# [124]	valid_0's multi_logloss: 2.74996
# [125]	valid_0's multi_logloss: 2.74948
# [126]	valid_0's multi_logloss: 2.74899
# [127]	valid_0's multi_logloss: 2.74855
# [128]	valid_0's multi_logloss: 2.74805
# [129]	valid_0's multi_logloss: 2.74756
# [130]	valid_0's multi_logloss: 2.74705
# [131]	valid_0's multi_logloss: 2.74662
# [132]	valid_0's multi_logloss: 2.74618
# [133]	valid_0's multi_logloss: 2.74572
# [134]	valid_0's multi_logloss: 2.74532
# [135]	valid_0's multi_logloss: 2.74493
# [136]	valid_0's multi_logloss: 2.74441
# [137]	valid_0's multi_logloss: 2.74395
# [138]	valid_0's multi_logloss: 2.74346
# [139]	valid_0's multi_logloss: 2.74305
# [140]	valid_0's multi_logloss: 2.7426
# [141]	valid_0's multi_logloss: 2.74218
# [142]	valid_0's multi_logloss: 2.74182
# [143]	valid_0's multi_logloss: 2.74144
# [144]	valid_0's multi_logloss: 2.74108
# [145]	valid_0's multi_logloss: 2.7406
# [146]	valid_0's multi_logloss: 2.74025
# [147]	valid_0's multi_logloss: 2.73986
# [148]	valid_0's multi_logloss: 2.73947
# [149]	valid_0's multi_logloss: 2.73898
# [150]	valid_0's multi_logloss: 2.73859
# [151]	valid_0's multi_logloss: 2.73823
# [152]	valid_0's multi_logloss: 2.73784
# [153]	valid_0's multi_logloss: 2.7375
# [154]	valid_0's multi_logloss: 2.73716
# [155]	valid_0's multi_logloss: 2.73676
# [156]	valid_0's multi_logloss: 2.73635
# [157]	valid_0's multi_logloss: 2.73594
# [158]	valid_0's multi_logloss: 2.73559
# [159]	valid_0's multi_logloss: 2.73527
# [160]	valid_0's multi_logloss: 2.73495
# [161]	valid_0's multi_logloss: 2.73459
# [162]	valid_0's multi_logloss: 2.73422
# [163]	valid_0's multi_logloss: 2.73384
# [164]	valid_0's multi_logloss: 2.73354
# [165]	valid_0's multi_logloss: 2.7332
# [166]	valid_0's multi_logloss: 2.73288
# [167]	valid_0's multi_logloss: 2.73256
# [168]	valid_0's multi_logloss: 2.73223
# [169]	valid_0's multi_logloss: 2.73189
# [170]	valid_0's multi_logloss: 2.73153
# [171]	valid_0's multi_logloss: 2.73126
# [172]	valid_0's multi_logloss: 2.73088
# [173]	valid_0's multi_logloss: 2.73056
# [174]	valid_0's multi_logloss: 2.73022
# [175]	valid_0's multi_logloss: 2.7299
# [176]	valid_0's multi_logloss: 2.72968
# [177]	valid_0's multi_logloss: 2.72931
# [178]	valid_0's multi_logloss: 2.72903
# [179]	valid_0's multi_logloss: 2.72874
# [180]	valid_0's multi_logloss: 2.72839
# [181]	valid_0's multi_logloss: 2.72812
# [182]	valid_0's multi_logloss: 2.72782
# [183]	valid_0's multi_logloss: 2.72756
# [184]	valid_0's multi_logloss: 2.72723
# [185]	valid_0's multi_logloss: 2.72696
# [186]	valid_0's multi_logloss: 2.72664
# [187]	valid_0's multi_logloss: 2.72632
# [188]	valid_0's multi_logloss: 2.72604
# [189]	valid_0's multi_logloss: 2.7258
# [190]	valid_0's multi_logloss: 2.72543
# [191]	valid_0's multi_logloss: 2.72517
# [192]	valid_0's multi_logloss: 2.72491
# [193]	valid_0's multi_logloss: 2.72461
# [194]	valid_0's multi_logloss: 2.72437
# [195]	valid_0's multi_logloss: 2.72406
# [196]	valid_0's multi_logloss: 2.72378
# [197]	valid_0's multi_logloss: 2.72348
# [198]	valid_0's multi_logloss: 2.72326
# [199]	valid_0's multi_logloss: 2.72296
# [200]	valid_0's multi_logloss: 2.7227
# [201]	valid_0's multi_logloss: 2.72246
# [202]	valid_0's multi_logloss: 2.72215
# [203]	valid_0's multi_logloss: 2.72188
# [204]	valid_0's multi_logloss: 2.72163
# [205]	valid_0's multi_logloss: 2.72138
# [206]	valid_0's multi_logloss: 2.72112
# [207]	valid_0's multi_logloss: 2.72085
# [208]	valid_0's multi_logloss: 2.7206
# [209]	valid_0's multi_logloss: 2.72039
# [210]	valid_0's multi_logloss: 2.72014
# [211]	valid_0's multi_logloss: 2.71996
# [212]	valid_0's multi_logloss: 2.71969
# [213]	valid_0's multi_logloss: 2.71946
# [214]	valid_0's multi_logloss: 2.71926
# [215]	valid_0's multi_logloss: 2.71909
# [216]	valid_0's multi_logloss: 2.71881
# [217]	valid_0's multi_logloss: 2.7186
# [218]	valid_0's multi_logloss: 2.7184
# [219]	valid_0's multi_logloss: 2.71822
# [220]	valid_0's multi_logloss: 2.71801
# [221]	valid_0's multi_logloss: 2.71782
# [222]	valid_0's multi_logloss: 2.71761
# [223]	valid_0's multi_logloss: 2.71745
# [224]	valid_0's multi_logloss: 2.71724
# [225]	valid_0's multi_logloss: 2.71699
# [226]	valid_0's multi_logloss: 2.71682
# [227]	valid_0's multi_logloss: 2.71664
# [228]	valid_0's multi_logloss: 2.71637
# [229]	valid_0's multi_logloss: 2.71617
# [230]	valid_0's multi_logloss: 2.71597
# [231]	valid_0's multi_logloss: 2.71579
# [232]	valid_0's multi_logloss: 2.71564
# [233]	valid_0's multi_logloss: 2.71543
# [234]	valid_0's multi_logloss: 2.71526
# [235]	valid_0's multi_logloss: 2.71507
# [236]	valid_0's multi_logloss: 2.71492
# [237]	valid_0's multi_logloss: 2.71472
# [238]	valid_0's multi_logloss: 2.7146
# [239]	valid_0's multi_logloss: 2.7144
# [240]	valid_0's multi_logloss: 2.71424
# [241]	valid_0's multi_logloss: 2.71408
# [242]	valid_0's multi_logloss: 2.71391
# [243]	valid_0's multi_logloss: 2.71369
# [244]	valid_0's multi_logloss: 2.71352
# [245]	valid_0's multi_logloss: 2.71335
# [246]	valid_0's multi_logloss: 2.71319
# [247]	valid_0's multi_logloss: 2.71304
# [248]	valid_0's multi_logloss: 2.7129
# [249]	valid_0's multi_logloss: 2.71271
# [250]	valid_0's multi_logloss: 2.71255
# [251]	valid_0's multi_logloss: 2.7124
# [252]	valid_0's multi_logloss: 2.71228
# [253]	valid_0's multi_logloss: 2.71214
# [254]	valid_0's multi_logloss: 2.71201
# [255]	valid_0's multi_logloss: 2.71183
# [256]	valid_0's multi_logloss: 2.71166
# [257]	valid_0's multi_logloss: 2.71147
# [258]	valid_0's multi_logloss: 2.71135
# [259]	valid_0's multi_logloss: 2.71124
# [260]	valid_0's multi_logloss: 2.71107
# [261]	valid_0's multi_logloss: 2.7109
# [262]	valid_0's multi_logloss: 2.71078
# [263]	valid_0's multi_logloss: 2.71064
# [264]	valid_0's multi_logloss: 2.71049
# [265]	valid_0's multi_logloss: 2.71034
# [266]	valid_0's multi_logloss: 2.71021
# [267]	valid_0's multi_logloss: 2.71007
# [268]	valid_0's multi_logloss: 2.70997
# [269]	valid_0's multi_logloss: 2.70976
# [270]	valid_0's multi_logloss: 2.70964
# [271]	valid_0's multi_logloss: 2.70952
# [272]	valid_0's multi_logloss: 2.70937
# [273]	valid_0's multi_logloss: 2.70924
# [274]	valid_0's multi_logloss: 2.70906
# [275]	valid_0's multi_logloss: 2.70894
# [276]	valid_0's multi_logloss: 2.70885
# [277]	valid_0's multi_logloss: 2.70874
# [278]	valid_0's multi_logloss: 2.70856
# [279]	valid_0's multi_logloss: 2.70843
# [280]	valid_0's multi_logloss: 2.70827
# [281]	valid_0's multi_logloss: 2.70812
# [282]	valid_0's multi_logloss: 2.70799
# [283]	valid_0's multi_logloss: 2.70788
# [284]	valid_0's multi_logloss: 2.70778
# [285]	valid_0's multi_logloss: 2.7076
# [286]	valid_0's multi_logloss: 2.70745
# [287]	valid_0's multi_logloss: 2.70734
# [288]	valid_0's multi_logloss: 2.70729
# [289]	valid_0's multi_logloss: 2.70715
# [290]	valid_0's multi_logloss: 2.70702
# [291]	valid_0's multi_logloss: 2.70692
# [292]	valid_0's multi_logloss: 2.70683
# [293]	valid_0's multi_logloss: 2.70674
# [294]	valid_0's multi_logloss: 2.70664
# [295]	valid_0's multi_logloss: 2.70648
# ...
# [232]	valid_0's multi_logloss: 2.91002
# [233]	valid_0's multi_logloss: 2.90992
# [234]	valid_0's multi_logloss: 2.90984
# [235]	valid_0's multi_logloss: 2.90976
# [236]	valid_0's multi_logloss: 2.90968
# [237]	valid_0's multi_logloss: 2.90964
# [238]	valid_0's multi_logloss: 2.90954
# [239]	valid_0's multi_logloss: 2.90949
# [240]	valid_0's multi_logloss: 2.90945
# [241]	valid_0's multi_logloss: 2.9094
# [242]	valid_0's multi_logloss: 2.90931
# [243]	valid_0's multi_logloss: 2.90918
# [244]	valid_0's multi_logloss: 2.90912
# [245]	valid_0's multi_logloss: 2.90908
# [246]	valid_0's multi_logloss: 2.90905
# [247]	valid_0's multi_logloss: 2.90894
# [248]	valid_0's multi_logloss: 2.90891
# [249]	valid_0's multi_logloss: 2.90883
# [250]	valid_0's multi_logloss: 2.90878
# [251]	valid_0's multi_logloss: 2.90872
# [252]	valid_0's multi_logloss: 2.90861
# [253]	valid_0's multi_logloss: 2.90864
# [254]	valid_0's multi_logloss: 2.90865
# [255]	valid_0's multi_logloss: 2.90862
# [256]	valid_0's multi_logloss: 2.90859
# [257]	valid_0's multi_logloss: 2.9085
# [258]	valid_0's multi_logloss: 2.90853
# [259]	valid_0's multi_logloss: 2.90843
# [260]	valid_0's multi_logloss: 2.90839
# [261]	valid_0's multi_logloss: 2.90836
# [262]	valid_0's multi_logloss: 2.90829
# [263]	valid_0's multi_logloss: 2.90821
# [264]	valid_0's multi_logloss: 2.90817
# [265]	valid_0's multi_logloss: 2.90814
# [266]	valid_0's multi_logloss: 2.90803
# [267]	valid_0's multi_logloss: 2.90806
# [268]	valid_0's multi_logloss: 2.90803
# [269]	valid_0's multi_logloss: 2.908
# [270]	valid_0's multi_logloss: 2.90795
# [271]	valid_0's multi_logloss: 2.90796
# [272]	valid_0's multi_logloss: 2.90785
# [273]	valid_0's multi_logloss: 2.9078
# [274]	valid_0's multi_logloss: 2.90774
# [275]	valid_0's multi_logloss: 2.90769
# [276]	valid_0's multi_logloss: 2.90763
# [277]	valid_0's multi_logloss: 2.90759
# [278]	valid_0's multi_logloss: 2.90753
# [279]	valid_0's multi_logloss: 2.90752
# [280]	valid_0's multi_logloss: 2.90749
# [281]	valid_0's multi_logloss: 2.90742
# [282]	valid_0's multi_logloss: 2.9074
# [283]	valid_0's multi_logloss: 2.90736
# [284]	valid_0's multi_logloss: 2.90733
# [285]	valid_0's multi_logloss: 2.90727
# [286]	valid_0's multi_logloss: 2.90721
# [287]	valid_0's multi_logloss: 2.90716
# [288]	valid_0's multi_logloss: 2.90709
# [289]	valid_0's multi_logloss: 2.90706
# [290]	valid_0's multi_logloss: 2.907
# [291]	valid_0's multi_logloss: 2.90698
# [292]	valid_0's multi_logloss: 2.90696
# [293]	valid_0's multi_logloss: 2.90689
# [294]	valid_0's multi_logloss: 2.90689
# [295]	valid_0's multi_logloss: 2.90681
# [296]	valid_0's multi_logloss: 2.90674
# [297]	valid_0's multi_logloss: 2.90667
# [298]	valid_0's multi_logloss: 2.90668
# [299]	valid_0's multi_logloss: 2.90664
# [300]	valid_0's multi_logloss: 2.90665
# [301]	valid_0's multi_logloss: 2.90665
# [302]	valid_0's multi_logloss: 2.90656
# [303]	valid_0's multi_logloss: 2.90652
# [304]	valid_0's multi_logloss: 2.90655
# [305]	valid_0's multi_logloss: 2.90654
# [306]	valid_0's multi_logloss: 2.90652
# [307]	valid_0's multi_logloss: 2.90651
# [308]	valid_0's multi_logloss: 2.9065
# [309]	valid_0's multi_logloss: 2.90649
# [310]	valid_0's multi_logloss: 2.90652
# [311]	valid_0's multi_logloss: 2.90648
# [312]	valid_0's multi_logloss: 2.90646
# [313]	valid_0's multi_logloss: 2.90642
# [314]	valid_0's multi_logloss: 2.9064
# [315]	valid_0's multi_logloss: 2.9064
# [316]	valid_0's multi_logloss: 2.90638
# [317]	valid_0's multi_logloss: 2.90638
# [318]	valid_0's multi_logloss: 2.90636
# [319]	valid_0's multi_logloss: 2.90634
# [320]	valid_0's multi_logloss: 2.90632
# [321]	valid_0's multi_logloss: 2.90632
# [322]	valid_0's multi_logloss: 2.90633
# [323]	valid_0's multi_logloss: 2.9063
# [324]	valid_0's multi_logloss: 2.90624
# [325]	valid_0's multi_logloss: 2.90626
# [326]	valid_0's multi_logloss: 2.90621
# [327]	valid_0's multi_logloss: 2.9062
# [328]	valid_0's multi_logloss: 2.90615
# [329]	valid_0's multi_logloss: 2.90611
# [330]	valid_0's multi_logloss: 2.90612
# [331]	valid_0's multi_logloss: 2.90611
# [332]	valid_0's multi_logloss: 2.90618
# [333]	valid_0's multi_logloss: 2.90615
# [334]	valid_0's multi_logloss: 2.90611
# [335]	valid_0's multi_logloss: 2.90615
# [336]	valid_0's multi_logloss: 2.90617
# [337]	valid_0's multi_logloss: 2.9061
# [338]	valid_0's multi_logloss: 2.90612
# [339]	valid_0's multi_logloss: 2.90615
# [340]	valid_0's multi_logloss: 2.90616
# [341]	valid_0's multi_logloss: 2.90623
# [342]	valid_0's multi_logloss: 2.90628
# [343]	valid_0's multi_logloss: 2.90623
# [344]	valid_0's multi_logloss: 2.90627
# [345]	valid_0's multi_logloss: 2.9063
# [346]	valid_0's multi_logloss: 2.90633
# [347]	valid_0's multi_logloss: 2.90632
# Early stopping, best iteration is:
# [337]	valid_0's multi_logloss: 2.9061
# 0.014292959840650085
# [1]	valid_0's multi_logloss: 2.92635
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92528
# [3]	valid_0's multi_logloss: 2.92428
# [4]	valid_0's multi_logloss: 2.92317
# [5]	valid_0's multi_logloss: 2.92216
# [6]	valid_0's multi_logloss: 2.92143
# [7]	valid_0's multi_logloss: 2.92057
# [8]	valid_0's multi_logloss: 2.91989
# [9]	valid_0's multi_logloss: 2.91916
# [10]	valid_0's multi_logloss: 2.91828
# [11]	valid_0's multi_logloss: 2.91762
# [12]	valid_0's multi_logloss: 2.91689
# [13]	valid_0's multi_logloss: 2.91624
# [14]	valid_0's multi_logloss: 2.91553
# [15]	valid_0's multi_logloss: 2.91488
# [16]	valid_0's multi_logloss: 2.91425
# [17]	valid_0's multi_logloss: 2.91356
# [18]	valid_0's multi_logloss: 2.913
# [19]	valid_0's multi_logloss: 2.91236
# [20]	valid_0's multi_logloss: 2.91161
# [21]	valid_0's multi_logloss: 2.91096
# [22]	valid_0's multi_logloss: 2.91035
# [23]	valid_0's multi_logloss: 2.90966
# [24]	valid_0's multi_logloss: 2.90902
# [25]	valid_0's multi_logloss: 2.90838
# [26]	valid_0's multi_logloss: 2.90784
# [27]	valid_0's multi_logloss: 2.90726
# [28]	valid_0's multi_logloss: 2.90667
# [29]	valid_0's multi_logloss: 2.90619
# [30]	valid_0's multi_logloss: 2.90565
# [31]	valid_0's multi_logloss: 2.90513
# [32]	valid_0's multi_logloss: 2.90471
# [33]	valid_0's multi_logloss: 2.90415
# [34]	valid_0's multi_logloss: 2.90357
# [35]	valid_0's multi_logloss: 2.90308
# [36]	valid_0's multi_logloss: 2.90249
# [37]	valid_0's multi_logloss: 2.90201
# [38]	valid_0's multi_logloss: 2.90157
# [39]	valid_0's multi_logloss: 2.9011
# [40]	valid_0's multi_logloss: 2.90055
# [41]	valid_0's multi_logloss: 2.90008
# [42]	valid_0's multi_logloss: 2.89962
# [43]	valid_0's multi_logloss: 2.89916
# [44]	valid_0's multi_logloss: 2.89873
# [45]	valid_0's multi_logloss: 2.89819
# [46]	valid_0's multi_logloss: 2.89768
# [47]	valid_0's multi_logloss: 2.89715
# [48]	valid_0's multi_logloss: 2.89665
# [49]	valid_0's multi_logloss: 2.89616
# [50]	valid_0's multi_logloss: 2.89573
# [51]	valid_0's multi_logloss: 2.89518
# [52]	valid_0's multi_logloss: 2.89477
# [53]	valid_0's multi_logloss: 2.89443
# [54]	valid_0's multi_logloss: 2.89402
# [55]	valid_0's multi_logloss: 2.89366
# [56]	valid_0's multi_logloss: 2.89322
# [57]	valid_0's multi_logloss: 2.89287
# [58]	valid_0's multi_logloss: 2.8925
# [59]	valid_0's multi_logloss: 2.89211
# [60]	valid_0's multi_logloss: 2.89182
# [61]	valid_0's multi_logloss: 2.89148
# [62]	valid_0's multi_logloss: 2.89117
# [63]	valid_0's multi_logloss: 2.89072
# [64]	valid_0's multi_logloss: 2.89043
# [65]	valid_0's multi_logloss: 2.89009
# [66]	valid_0's multi_logloss: 2.88975
# [67]	valid_0's multi_logloss: 2.8894
# [68]	valid_0's multi_logloss: 2.88909
# [69]	valid_0's multi_logloss: 2.88873
# [70]	valid_0's multi_logloss: 2.88831
# [71]	valid_0's multi_logloss: 2.888
# [72]	valid_0's multi_logloss: 2.88768
# [73]	valid_0's multi_logloss: 2.88734
# [74]	valid_0's multi_logloss: 2.88695
# [75]	valid_0's multi_logloss: 2.88664
# [76]	valid_0's multi_logloss: 2.88633
# [77]	valid_0's multi_logloss: 2.88595
# [78]	valid_0's multi_logloss: 2.88563
# [79]	valid_0's multi_logloss: 2.88534
# [80]	valid_0's multi_logloss: 2.88501
# [81]	valid_0's multi_logloss: 2.88467
# [82]	valid_0's multi_logloss: 2.88441
# [83]	valid_0's multi_logloss: 2.88399
# [84]	valid_0's multi_logloss: 2.88369
# [85]	valid_0's multi_logloss: 2.88338
# [86]	valid_0's multi_logloss: 2.88301
# [87]	valid_0's multi_logloss: 2.88279
# [88]	valid_0's multi_logloss: 2.8825
# [89]	valid_0's multi_logloss: 2.88218
# [90]	valid_0's multi_logloss: 2.88188
# [91]	valid_0's multi_logloss: 2.88157
# [92]	valid_0's multi_logloss: 2.88131
# [93]	valid_0's multi_logloss: 2.881
# [94]	valid_0's multi_logloss: 2.8807
# [95]	valid_0's multi_logloss: 2.88035
# [96]	valid_0's multi_logloss: 2.88001
# [97]	valid_0's multi_logloss: 2.87973
# [98]	valid_0's multi_logloss: 2.87941
# [99]	valid_0's multi_logloss: 2.87918
# [100]	valid_0's multi_logloss: 2.87891
# [101]	valid_0's multi_logloss: 2.87865
# [102]	valid_0's multi_logloss: 2.87842
# [103]	valid_0's multi_logloss: 2.87819
# [104]	valid_0's multi_logloss: 2.87786
# [105]	valid_0's multi_logloss: 2.87763
# [106]	valid_0's multi_logloss: 2.87736
# [107]	valid_0's multi_logloss: 2.87713
# [108]	valid_0's multi_logloss: 2.87689
# [109]	valid_0's multi_logloss: 2.87666
# [110]	valid_0's multi_logloss: 2.87644
# [111]	valid_0's multi_logloss: 2.87621
# [112]	valid_0's multi_logloss: 2.87591
# [113]	valid_0's multi_logloss: 2.87572
# [114]	valid_0's multi_logloss: 2.87551
# [115]	valid_0's multi_logloss: 2.87525
# [116]	valid_0's multi_logloss: 2.87499
# [117]	valid_0's multi_logloss: 2.87483
# [118]	valid_0's multi_logloss: 2.87455
# [119]	valid_0's multi_logloss: 2.87437
# [120]	valid_0's multi_logloss: 2.87417
# [121]	valid_0's multi_logloss: 2.87397
# [122]	valid_0's multi_logloss: 2.87372
# [123]	valid_0's multi_logloss: 2.87359
# [124]	valid_0's multi_logloss: 2.87337
# [125]	valid_0's multi_logloss: 2.87313
# [126]	valid_0's multi_logloss: 2.87292
# [127]	valid_0's multi_logloss: 2.87271
# [128]	valid_0's multi_logloss: 2.87249
# [129]	valid_0's multi_logloss: 2.87239
# [130]	valid_0's multi_logloss: 2.87217
# [131]	valid_0's multi_logloss: 2.87194
# [132]	valid_0's multi_logloss: 2.87179
# [133]	valid_0's multi_logloss: 2.87161
# [134]	valid_0's multi_logloss: 2.87144
# [135]	valid_0's multi_logloss: 2.87119
# [136]	valid_0's multi_logloss: 2.87098
# [137]	valid_0's multi_logloss: 2.87076
# [138]	valid_0's multi_logloss: 2.87055
# [139]	valid_0's multi_logloss: 2.87039
# [140]	valid_0's multi_logloss: 2.87023
# [141]	valid_0's multi_logloss: 2.87002
# [142]	valid_0's multi_logloss: 2.86986
# [143]	valid_0's multi_logloss: 2.86965
# [144]	valid_0's multi_logloss: 2.86943
# [145]	valid_0's multi_logloss: 2.86921
# [146]	valid_0's multi_logloss: 2.86895
# [147]	valid_0's multi_logloss: 2.86876
# [148]	valid_0's multi_logloss: 2.86851
# [149]	valid_0's multi_logloss: 2.86827
# [150]	valid_0's multi_logloss: 2.86808
# [151]	valid_0's multi_logloss: 2.86787
# [152]	valid_0's multi_logloss: 2.86769
# [153]	valid_0's multi_logloss: 2.86739
# [154]	valid_0's multi_logloss: 2.86721
# [155]	valid_0's multi_logloss: 2.86702
# [156]	valid_0's multi_logloss: 2.86689
# [157]	valid_0's multi_logloss: 2.86671
# [158]	valid_0's multi_logloss: 2.86654
# [159]	valid_0's multi_logloss: 2.86631
# [160]	valid_0's multi_logloss: 2.86613
# [161]	valid_0's multi_logloss: 2.86601
# [162]	valid_0's multi_logloss: 2.86589
# [163]	valid_0's multi_logloss: 2.86574
# [164]	valid_0's multi_logloss: 2.86559
# [165]	valid_0's multi_logloss: 2.86542
# [166]	valid_0's multi_logloss: 2.86526
# [167]	valid_0's multi_logloss: 2.86514
# [168]	valid_0's multi_logloss: 2.86497
# [169]	valid_0's multi_logloss: 2.86485
# [170]	valid_0's multi_logloss: 2.86475
# [171]	valid_0's multi_logloss: 2.86464
# [172]	valid_0's multi_logloss: 2.86445
# [173]	valid_0's multi_logloss: 2.86434
# [174]	valid_0's multi_logloss: 2.86421
# [175]	valid_0's multi_logloss: 2.86412
# [176]	valid_0's multi_logloss: 2.86393
# [177]	valid_0's multi_logloss: 2.86383
# [178]	valid_0's multi_logloss: 2.86372
# [179]	valid_0's multi_logloss: 2.86356
# [180]	valid_0's multi_logloss: 2.86339
# [181]	valid_0's multi_logloss: 2.86317
# [182]	valid_0's multi_logloss: 2.86305
# [183]	valid_0's multi_logloss: 2.86294
# [184]	valid_0's multi_logloss: 2.86271
# [185]	valid_0's multi_logloss: 2.86259
# [186]	valid_0's multi_logloss: 2.86247
# [187]	valid_0's multi_logloss: 2.86232
# [188]	valid_0's multi_logloss: 2.86221
# [189]	valid_0's multi_logloss: 2.86207
# [190]	valid_0's multi_logloss: 2.86198
# [191]	valid_0's multi_logloss: 2.86185
# [192]	valid_0's multi_logloss: 2.86169
# [193]	valid_0's multi_logloss: 2.86157
# [194]	valid_0's multi_logloss: 2.86149
# [195]	valid_0's multi_logloss: 2.86145
# [196]	valid_0's multi_logloss: 2.86134
# [197]	valid_0's multi_logloss: 2.86122
# [198]	valid_0's multi_logloss: 2.86112
# [199]	valid_0's multi_logloss: 2.86103
# [200]	valid_0's multi_logloss: 2.86087
# [201]	valid_0's multi_logloss: 2.86075
# [202]	valid_0's multi_logloss: 2.86069
# [203]	valid_0's multi_logloss: 2.86058
# [204]	valid_0's multi_logloss: 2.86046
# [205]	valid_0's multi_logloss: 2.86034
# [206]	valid_0's multi_logloss: 2.86026
# [207]	valid_0's multi_logloss: 2.86019
# [208]	valid_0's multi_logloss: 2.86002
# [209]	valid_0's multi_logloss: 2.85994
# [210]	valid_0's multi_logloss: 2.85988
# [211]	valid_0's multi_logloss: 2.85977
# [212]	valid_0's multi_logloss: 2.85968
# [213]	valid_0's multi_logloss: 2.85958
# [214]	valid_0's multi_logloss: 2.85947
# [215]	valid_0's multi_logloss: 2.85942
# [216]	valid_0's multi_logloss: 2.85932
# [217]	valid_0's multi_logloss: 2.85924
# [218]	valid_0's multi_logloss: 2.85914
# [219]	valid_0's multi_logloss: 2.8591
# [220]	valid_0's multi_logloss: 2.85904
# [221]	valid_0's multi_logloss: 2.85899
# [222]	valid_0's multi_logloss: 2.85895
# [223]	valid_0's multi_logloss: 2.8589
# [224]	valid_0's multi_logloss: 2.85884
# [225]	valid_0's multi_logloss: 2.8588
# [226]	valid_0's multi_logloss: 2.85875
# [227]	valid_0's multi_logloss: 2.85872
# [228]	valid_0's multi_logloss: 2.85868
# [229]	valid_0's multi_logloss: 2.85864
# [230]	valid_0's multi_logloss: 2.85858
# [231]	valid_0's multi_logloss: 2.85856
# [232]	valid_0's multi_logloss: 2.85849
# [233]	valid_0's multi_logloss: 2.85843
# [234]	valid_0's multi_logloss: 2.85835
# [235]	valid_0's multi_logloss: 2.85835
# [236]	valid_0's multi_logloss: 2.85834
# [237]	valid_0's multi_logloss: 2.85828
# [238]	valid_0's multi_logloss: 2.8582
# [239]	valid_0's multi_logloss: 2.85817
# [240]	valid_0's multi_logloss: 2.85814
# [241]	valid_0's multi_logloss: 2.85806
# [242]	valid_0's multi_logloss: 2.85803
# [243]	valid_0's multi_logloss: 2.85805
# [244]	valid_0's multi_logloss: 2.85796
# [245]	valid_0's multi_logloss: 2.8579
# [246]	valid_0's multi_logloss: 2.8579
# [247]	valid_0's multi_logloss: 2.85783
# [248]	valid_0's multi_logloss: 2.85779
# [249]	valid_0's multi_logloss: 2.85778
# [250]	valid_0's multi_logloss: 2.85773
# [251]	valid_0's multi_logloss: 2.8577
# [252]	valid_0's multi_logloss: 2.85761
# [253]	valid_0's multi_logloss: 2.85761
# [254]	valid_0's multi_logloss: 2.8576
# [255]	valid_0's multi_logloss: 2.85763
# [256]	valid_0's multi_logloss: 2.85754
# [257]	valid_0's multi_logloss: 2.85755
# [258]	valid_0's multi_logloss: 2.85755
# [259]	valid_0's multi_logloss: 2.85753
# [260]	valid_0's multi_logloss: 2.8575
# [261]	valid_0's multi_logloss: 2.85749
# [262]	valid_0's multi_logloss: 2.85751
# [263]	valid_0's multi_logloss: 2.85744
# [264]	valid_0's multi_logloss: 2.85741
# [265]	valid_0's multi_logloss: 2.8574
# [266]	valid_0's multi_logloss: 2.85746
# [267]	valid_0's multi_logloss: 2.8574
# [268]	valid_0's multi_logloss: 2.85739
# [269]	valid_0's multi_logloss: 2.85741
# [270]	valid_0's multi_logloss: 2.85741
# [271]	valid_0's multi_logloss: 2.85738
# [272]	valid_0's multi_logloss: 2.85735
# [273]	valid_0's multi_logloss: 2.85738
# [274]	valid_0's multi_logloss: 2.85734
# [275]	valid_0's multi_logloss: 2.85732
# [276]	valid_0's multi_logloss: 2.85731
# [277]	valid_0's multi_logloss: 2.85729
# [278]	valid_0's multi_logloss: 2.85732
# [279]	valid_0's multi_logloss: 2.85731
# [280]	valid_0's multi_logloss: 2.85731
# [281]	valid_0's multi_logloss: 2.85734
# [282]	valid_0's multi_logloss: 2.85737
# [283]	valid_0's multi_logloss: 2.85735
# [284]	valid_0's multi_logloss: 2.85735
# [285]	valid_0's multi_logloss: 2.8573
# [286]	valid_0's multi_logloss: 2.85735
# [287]	valid_0's multi_logloss: 2.8574
# Early stopping, best iteration is:
# [277]	valid_0's multi_logloss: 2.85729
# 0.014103602820952124
# crps list: [0.01249812426521828, 0.01228799313898565, 0.011919767476942388, 0.014292959840650085, 0.014103602820952124]
# average crps: 0.013020489508549705

# %% [markdown]
# - add dis to QB: adopt the variable
# - crps list: [0.012515628350231308, 0.012298853878681225, 0.011915330815077537, 0.014294835316849287, 0.014101613409510005]
# - average crps: 0.013025252354069872
#
# - add 1stdefender-A: ???
# - crps list: [0.0125247228082462, 0.012296215156899494, 0.011916285356289271, 0.014306146851340863, 0.014102316052056543]
# - average crps: 0.013029137244966474
#
# - add 1stdefender-A and remove time-quarter ???
# - crps list: [0.012523490979887779, 0.012286428715232334, 0.011914518302048987, 0.01430454212564282, 0.01410691518299643]
# - average crps: 0.013027179061161671
#
# - add dis-to-QB and remove time-quarter: let's remove time-quarter
# - crps list: [0.01249812426521828, 0.01228799313898565, 0.011919767476942388, 0.014292959840650085, 0.014103602820952124]
# - average crps: 0.013020489508549705
#
# - remove time-quarter only: let's add dis-to-QB
# - crps list: [0.012524438750643537, 0.012288396999616777, 0.011927183426129969, 0.014302574842381769, 0.01410739179035138]
# - average crps: 0.013029997161824687
#
# - final conclusion : add dis-to-QB and remove time-quarter

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'time_end', 'Grass', 'DefendersInTheBox_vs_Distance', 'DisToQB',
#        'runner_height', 'DefenseAveX', 'DefenseAveY', 'DefenseAveMomentum',
#        'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos', 'RusherVoronoi',
#        'FirstDefenderVoronoi', 'PitchControl'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                           Grass     446     320     307     235     154
# 1                            Team     345     745     529     405     363
# 2                OffenseFormation     821     834    1000     794     532
# 3                            Down     909    1176    1144     726     588
# 4                          Season    2339    1613    2457    1658    1521
# 5               DefendersInTheBox    2446    1536    2274    2116    1644
# 6                DefensePersonnel    2347    2978    1954    1580    1596
# 7                   runner_height    1413    3609    3455    2159    1167
# 8                     StadiumType    3150    4255    3713    2025    1929
# 9                OffensePersonnel    2682    3960    3653    3410    2771
# 10                    GameWeather    3800    3942    4206    3003    1756
# 11            HomeScoreBeforePlay    3809    4855    4066    2307    3296
# 12                           Week    5081    5205    4097    2381    2615
# 13                       Distance    2628    6128    5345    3931    1415
# 14                  RusherVoronoi    4388    4566    5333    3959    2951
# 15                      WindSpeed    5168    4937    4635    3098    4009
# 16                            Dis    4985    5254    4160    3919    3587
# 17                  WindDirection    5338    7004    4210    3175    2364
# 18         VisitorScoreBeforePlay    4579    6331    4037    4129    3380
# 19                       Location    4747    6762    4182    4251    2600
# 20                   PlayerWeight    6362    6466    4035    3438    3559
# 21                        Stadium    6150    5469    5560    4907    3663
# 22                   JerseyNumber    5547    7653    5439    4435    3360
# 23                       Humidity    6488    6886    6008    3783    4727
# 24                    Temperature    6335    6426    6610    4621    4107
# 25                    Orientation    7013    6839    6158    4079    4273
# 26  DefendersInTheBox_vs_Distance   10114    6204    3990    4794    3263
# 27                              S    7315    6271    5970    4482    4581
# 28             OffenseAveMomentum    7168    7535    6326    4266    4555
# 29                    DefenseStdY    7148    7576    6252    4920    4391
# 30                    OffenseStdY    5954    7515    6460    5737    4711
# 31         RunnerToDefenseCentoid    7212    6541    7644    5551    4926
# 32                    OffenseStdX    8636    8034    6242    4938    4910
# 33                              X    7590    7758    8003    5089    4790
# 34         RunnerToOffenseCentoid    8537    9605    6861    5802    4671
# 35                          NflId    8429    8339    9040    5055    4762
# 36                       Momentum    7691    9680    7855    5387    5265
# 37                              Y    8574    9522    8037    4708    5080
# 38                            Dir    8055    9015    8422    6185    4939
# 39                 OffenseSpreadX    8474   11214    6322    5913    5408
# 40                    DefenseAveX    7409    9562    8533    7599    4238
# 41                    DefenseStdX    9044    9564    7708    6988    4929
# 42              PlayerCollegeName    9014    9070    7785    7172    5855
# 43             DefenseAveMomentum    8111   10553    9149    6791    4997
# 44                    DefenseAveY    8826    9523    9540    6728    5034
# 45         OffenseStdMomentum_cos    8702   11320    7969    6391    5849
# 46         OffenseAveMomentum_cos   10167   10076    9345    5535    5635
# 47                            age   11013    9347    8827    6437    5209
# 48                 DefenseSpreadX   10807   10726    8520    6424    5717
# 49             DefenseStdMomentum    8967   11168   11128    6486    5270
# 50                        DisToQB   10647   11096   10079    6422    5583
# 51         DefenseStdMomentum_cos   10007   10304   10720    7331    6463
# 52                        Dir_cos    9816   11785   10001    7085    6567
# 53                       time_end    9681   12188    9352    7735    7018
# 54             OffenseStdMomentum   10428   12991    9409    7943    6606
# 55                  MinTackleTime   10879   13897    9937    5922    7411
# 56                   PitchControl   11742   12804   10074    8408    5943
# 57              RunnerToScrimmage   11923   12789    9973    8151    6630
# 58           FirstDefenderVoronoi   11050   14294   11560    7580    6575
# 59                       YardLine   11793   13548   12136    8106    7056
# 60       1stOffenser_Momentum_cos   14131   12615   12018    9062    7267
# 61         DefenseAveMomentum_cos   14500   12722   12763    9185    7797
# 62                   Momentum_cos   13156   14364   13704   10592    8980
# 63       1stDefender_Momentum_cos   14077   16938   12644   10474    8345
# 64                              A   22310   21625   18663   19876   17976
#
#     Average          Std        Cv
# 0     292.4    96.971336  0.331639
# 1     477.4   148.412398  0.310876
# 2     796.2   150.588711  0.189134
# 3     908.6   229.365734  0.252439
# 4    1917.6   396.483341  0.206760
# 5    2003.2   354.803833  0.177119
# 6    2091.0   524.827591  0.250994
# 7    2360.6  1011.877779  0.428653
# 8    3014.4   916.790401  0.304137
# 9    3295.2   496.781401  0.150759
# 10   3341.4   888.434038  0.265887
# 11   3666.6   845.925434  0.230711
# 12   3875.8  1190.987221  0.307288
# 13   3889.4  1723.114459  0.443028
# 14   4239.4   782.727181  0.184632
# 15   4369.4   745.227643  0.170556
# 16   4381.0   635.557393  0.145071
# 17   4418.2  1633.464098  0.369713
# 18   4491.2   996.476272  0.221873
# 19   4508.4  1337.940597  0.296766
# 20   4772.0  1355.863562  0.284129
# 21   5149.8   841.436724  0.163392
# 22   5286.8  1423.228218  0.269204
# 23   5578.4  1154.996900  0.207048
# 24   5619.8  1041.933856  0.185404
# 25   5672.4  1256.281433  0.221473
# 26   5673.0  2425.599802  0.427569
# 27   5723.8  1071.449374  0.187192
# 28   5970.0  1335.440452  0.223692
# 29   6057.4  1233.206487  0.203587
# 30   6075.4   917.736912  0.151058
# 31   6374.8  1011.638552  0.158693
# 32   6552.0  1545.098055  0.235821
# 33   6646.0  1402.719787  0.211062
# 34   7095.2  1787.839187  0.251979
# 35   7125.0  1828.119580  0.256578
# 36   7175.6  1664.254980  0.231933
# 37   7184.2  1933.046549  0.269069
# 38   7323.2  1522.168769  0.207856
# 39   7466.2  2145.668977  0.287384
# 40   7468.2  1787.322176  0.239324
# 41   7646.6  1640.245299  0.214506
# 42   7779.2  1205.169432  0.154922
# 43   7920.2  1913.017554  0.241537
# 44   7930.2  1775.622978  0.223906
# 45   8046.2  1935.002574  0.240487
# 46   8151.6  2115.146671  0.259476
# 47   8166.6  2081.844336  0.254922
# 48   8438.8  2112.527529  0.250335
# 49   8603.8  2394.907965  0.278355
# 50   8765.4  2294.203705  0.261734
# 51   8965.0  1725.611196  0.192483
# 52   9050.8  1949.250769  0.215368
# 53   9194.8  1793.868602  0.195096
# 54   9475.4  2184.170561  0.230510
# 55   9609.2  2776.061988  0.288896
# 56   9794.2  2436.571394  0.248777
# 57   9893.2  2288.923275  0.231363
# 58  10211.8  2804.898030  0.274672
# 59  10527.8  2499.086105  0.237380
# 60  11018.6  2495.480443  0.226479
# 61  11393.4  2494.115843  0.218909
# 62  12159.2  2039.832777  0.167760
# 63  12495.6  2952.020095  0.236245
# 64  20090.0  1663.475037  0.082801

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf', 'Quarter']
top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]
    
    #df["Jersey_cat"] = df["JerseyNumber"].apply(lambda x: 0 if x>=1 and x <=9 else #: quarterbacks, kickers, and punters
    #                                            (1 if x>=10 and x <= 19 else
    #                                            (2 if x>=20 and x <= 39 else
    #                                            (3 if x>=40 and x <= 49 else
    #                                            (4 if x>=50 and x <= 59 else
    #                                            (5 if x>=60 and x <= 79 else
    #                                            (6 if x>=80 and x <= 89 else
    #                                            (7 if x>=90 and x <= 99 else 8))))))))

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    #df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]
    
    df["AttackAngle"] =  np.arctan((df["Y"] - df["RushY"]) / (df["X"] - df["RushX"])) * 180 / np.pi

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    if 2017 in list(df["Season"].unique()):
        df_fb = df[df.Position == "FB"].copy()
        tmp = df_fb.groupby(["PlayId", "OnOffense"]).agg(np.mean)["PlayerWeight"].reset_index()
        tmp = tmp[tmp.OnOffense==True]
        tmp.rename(columns={'PlayerWeight': 'PlayerWeight_FB'}, inplace=True)
        df_single = pd.merge(df_single, tmp[["PlayId", "PlayerWeight_FB"]], on = "PlayId", how="left")
    else:
        if "FB" in list(df.Position.unique()): # details of offensive full-back
            df_fb = df[df.Position == "FB"].copy()
            tmp = df_fb.groupby(["PlayId", "OnOffense"]).agg(np.mean)["PlayerWeight"].reset_index()
            tmp = tmp[tmp.OnOffense==True]
            tmp.rename(columns={'PlayerWeight': 'PlayerWeight_FB'}, inplace=True)
            df_single = pd.merge(df_single, tmp[["PlayId", "PlayerWeight_FB"]], on = "PlayId", how="left")
        else:
            df_single["PlayerWeight_FB"] = -999 
        
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])
    df_single["1stDefender_AttackAngle"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["AttackAngle"])
    # df_single["1stDefenderID"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["NflId"])
    
    #df_single["OffenseLine_Weight"] = np.array(train.groupby(["PlayId", "OnOffense"])["PlayerWeight"].max()[1::2])
    #df_single["OffenseLine_Height"] = np.array(train.groupby(["PlayId", "OnOffense"])["PlayerHeight"].max()[1::2])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    #def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    #off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    #df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY", "AttackAngle"]#"InfluToBall", , "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:856: RuntimeWarning: invalid value encountered in arctan
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# CPU times: user 5min 22s, sys: 2.37 s, total: 5min 25s
# Wall time: 5min 23s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : 5,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86884
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86602
# [3]	valid_0's multi_logloss: 2.86391
# [4]	valid_0's multi_logloss: 2.86174
# [5]	valid_0's multi_logloss: 2.85968
# [6]	valid_0's multi_logloss: 2.85759
# [7]	valid_0's multi_logloss: 2.8556
# [8]	valid_0's multi_logloss: 2.85373
# [9]	valid_0's multi_logloss: 2.85209
# [10]	valid_0's multi_logloss: 2.85038
# [11]	valid_0's multi_logloss: 2.84856
# [12]	valid_0's multi_logloss: 2.84688
# [13]	valid_0's multi_logloss: 2.84527
# [14]	valid_0's multi_logloss: 2.84359
# [15]	valid_0's multi_logloss: 2.84196
# [16]	valid_0's multi_logloss: 2.84056
# [17]	valid_0's multi_logloss: 2.83909
# [18]	valid_0's multi_logloss: 2.83746
# [19]	valid_0's multi_logloss: 2.8361
# [20]	valid_0's multi_logloss: 2.8347
# [21]	valid_0's multi_logloss: 2.83322
# [22]	valid_0's multi_logloss: 2.8318
# [23]	valid_0's multi_logloss: 2.83029
# [24]	valid_0's multi_logloss: 2.82891
# [25]	valid_0's multi_logloss: 2.82753
# [26]	valid_0's multi_logloss: 2.8262
# [27]	valid_0's multi_logloss: 2.82486
# [28]	valid_0's multi_logloss: 2.82345
# [29]	valid_0's multi_logloss: 2.8221
# [30]	valid_0's multi_logloss: 2.8208
# [31]	valid_0's multi_logloss: 2.8196
# [32]	valid_0's multi_logloss: 2.81836
# [33]	valid_0's multi_logloss: 2.81709
# [34]	valid_0's multi_logloss: 2.81593
# [35]	valid_0's multi_logloss: 2.81465
# [36]	valid_0's multi_logloss: 2.8135
# [37]	valid_0's multi_logloss: 2.81235
# [38]	valid_0's multi_logloss: 2.81126
# [39]	valid_0's multi_logloss: 2.81019
# [40]	valid_0's multi_logloss: 2.8091
# [41]	valid_0's multi_logloss: 2.80806
# [42]	valid_0's multi_logloss: 2.80705
# [43]	valid_0's multi_logloss: 2.80605
# [44]	valid_0's multi_logloss: 2.80501
# [45]	valid_0's multi_logloss: 2.804
# [46]	valid_0's multi_logloss: 2.803
# [47]	valid_0's multi_logloss: 2.802
# [48]	valid_0's multi_logloss: 2.80101
# [49]	valid_0's multi_logloss: 2.80005
# [50]	valid_0's multi_logloss: 2.79906
# [51]	valid_0's multi_logloss: 2.79796
# [52]	valid_0's multi_logloss: 2.79713
# [53]	valid_0's multi_logloss: 2.79613
# [54]	valid_0's multi_logloss: 2.79527
# [55]	valid_0's multi_logloss: 2.79438
# [56]	valid_0's multi_logloss: 2.79349
# [57]	valid_0's multi_logloss: 2.79255
# [58]	valid_0's multi_logloss: 2.79156
# [59]	valid_0's multi_logloss: 2.79066
# [60]	valid_0's multi_logloss: 2.78971
# [61]	valid_0's multi_logloss: 2.78884
# [62]	valid_0's multi_logloss: 2.78804
# [63]	valid_0's multi_logloss: 2.78709
# [64]	valid_0's multi_logloss: 2.78622
# [65]	valid_0's multi_logloss: 2.7852
# [66]	valid_0's multi_logloss: 2.78441
# [67]	valid_0's multi_logloss: 2.78342
# [68]	valid_0's multi_logloss: 2.78249
# [69]	valid_0's multi_logloss: 2.78162
# [70]	valid_0's multi_logloss: 2.78075
# [71]	valid_0's multi_logloss: 2.77991
# [72]	valid_0's multi_logloss: 2.77897
# [73]	valid_0's multi_logloss: 2.77814
# [74]	valid_0's multi_logloss: 2.7773
# [75]	valid_0's multi_logloss: 2.77647
# [76]	valid_0's multi_logloss: 2.7756
# [77]	valid_0's multi_logloss: 2.77487
# [78]	valid_0's multi_logloss: 2.77397
# [79]	valid_0's multi_logloss: 2.7732
# [80]	valid_0's multi_logloss: 2.77238
# [81]	valid_0's multi_logloss: 2.77161
# [82]	valid_0's multi_logloss: 2.77085
# [83]	valid_0's multi_logloss: 2.77011
# [84]	valid_0's multi_logloss: 2.76931
# [85]	valid_0's multi_logloss: 2.76864
# [86]	valid_0's multi_logloss: 2.76785
# [87]	valid_0's multi_logloss: 2.76708
# [88]	valid_0's multi_logloss: 2.76633
# [89]	valid_0's multi_logloss: 2.76557
# [90]	valid_0's multi_logloss: 2.76483
# [91]	valid_0's multi_logloss: 2.76405
# [92]	valid_0's multi_logloss: 2.76336
# [93]	valid_0's multi_logloss: 2.76266
# [94]	valid_0's multi_logloss: 2.76202
# [95]	valid_0's multi_logloss: 2.76131
# [96]	valid_0's multi_logloss: 2.76059
# [97]	valid_0's multi_logloss: 2.7599
# [98]	valid_0's multi_logloss: 2.75927
# [99]	valid_0's multi_logloss: 2.75855
# [100]	valid_0's multi_logloss: 2.7579
# [101]	valid_0's multi_logloss: 2.7573
# [102]	valid_0's multi_logloss: 2.75655
# [103]	valid_0's multi_logloss: 2.75584
# [104]	valid_0's multi_logloss: 2.75531
# [105]	valid_0's multi_logloss: 2.75456
# [106]	valid_0's multi_logloss: 2.75391
# [107]	valid_0's multi_logloss: 2.75334
# [108]	valid_0's multi_logloss: 2.75272
# [109]	valid_0's multi_logloss: 2.7521
# [110]	valid_0's multi_logloss: 2.75145
# [111]	valid_0's multi_logloss: 2.75081
# [112]	valid_0's multi_logloss: 2.7502
# [113]	valid_0's multi_logloss: 2.74962
# [114]	valid_0's multi_logloss: 2.74904
# [115]	valid_0's multi_logloss: 2.74852
# [116]	valid_0's multi_logloss: 2.74795
# [117]	valid_0's multi_logloss: 2.74739
# [118]	valid_0's multi_logloss: 2.74687
# [119]	valid_0's multi_logloss: 2.74619
# [120]	valid_0's multi_logloss: 2.74569
# [121]	valid_0's multi_logloss: 2.74516
# [122]	valid_0's multi_logloss: 2.74457
# [123]	valid_0's multi_logloss: 2.74403
# [124]	valid_0's multi_logloss: 2.74348
# [125]	valid_0's multi_logloss: 2.74293
# [126]	valid_0's multi_logloss: 2.74236
# [127]	valid_0's multi_logloss: 2.74189
# [128]	valid_0's multi_logloss: 2.74137
# [129]	valid_0's multi_logloss: 2.74092
# [130]	valid_0's multi_logloss: 2.74045
# [131]	valid_0's multi_logloss: 2.73999
# [132]	valid_0's multi_logloss: 2.73954
# [133]	valid_0's multi_logloss: 2.73908
# [134]	valid_0's multi_logloss: 2.73858
# [135]	valid_0's multi_logloss: 2.73814
# [136]	valid_0's multi_logloss: 2.73768
# [137]	valid_0's multi_logloss: 2.73726
# [138]	valid_0's multi_logloss: 2.7368
# [139]	valid_0's multi_logloss: 2.73631
# [140]	valid_0's multi_logloss: 2.73583
# [141]	valid_0's multi_logloss: 2.73539
# [142]	valid_0's multi_logloss: 2.73493
# [143]	valid_0's multi_logloss: 2.73453
# [144]	valid_0's multi_logloss: 2.73409
# [145]	valid_0's multi_logloss: 2.73366
# [146]	valid_0's multi_logloss: 2.73318
# [147]	valid_0's multi_logloss: 2.73269
# [148]	valid_0's multi_logloss: 2.73227
# [149]	valid_0's multi_logloss: 2.73189
# [150]	valid_0's multi_logloss: 2.73145
# [151]	valid_0's multi_logloss: 2.73111
# [152]	valid_0's multi_logloss: 2.7306
# [153]	valid_0's multi_logloss: 2.73013
# [154]	valid_0's multi_logloss: 2.72974
# [155]	valid_0's multi_logloss: 2.72934
# [156]	valid_0's multi_logloss: 2.72897
# [157]	valid_0's multi_logloss: 2.7285
# [158]	valid_0's multi_logloss: 2.72811
# [159]	valid_0's multi_logloss: 2.72767
# [160]	valid_0's multi_logloss: 2.72729
# [161]	valid_0's multi_logloss: 2.72689
# [162]	valid_0's multi_logloss: 2.72654
# [163]	valid_0's multi_logloss: 2.72613
# [164]	valid_0's multi_logloss: 2.72566
# [165]	valid_0's multi_logloss: 2.72531
# [166]	valid_0's multi_logloss: 2.72494
# [167]	valid_0's multi_logloss: 2.72457
# [168]	valid_0's multi_logloss: 2.72426
# [169]	valid_0's multi_logloss: 2.7238
# [170]	valid_0's multi_logloss: 2.72349
# [171]	valid_0's multi_logloss: 2.72312
# [172]	valid_0's multi_logloss: 2.72272
# [173]	valid_0's multi_logloss: 2.72242
# [174]	valid_0's multi_logloss: 2.72205
# [175]	valid_0's multi_logloss: 2.72168
# [176]	valid_0's multi_logloss: 2.7214
# [177]	valid_0's multi_logloss: 2.721
# [178]	valid_0's multi_logloss: 2.72066
# [179]	valid_0's multi_logloss: 2.72037
# [180]	valid_0's multi_logloss: 2.71997
# [181]	valid_0's multi_logloss: 2.71964
# [182]	valid_0's multi_logloss: 2.71934
# [183]	valid_0's multi_logloss: 2.71898
# [184]	valid_0's multi_logloss: 2.71862
# [185]	valid_0's multi_logloss: 2.7183
# [186]	valid_0's multi_logloss: 2.71797
# [187]	valid_0's multi_logloss: 2.71773
# [188]	valid_0's multi_logloss: 2.71744
# [189]	valid_0's multi_logloss: 2.71718
# [190]	valid_0's multi_logloss: 2.71688
# [191]	valid_0's multi_logloss: 2.71652
# [192]	valid_0's multi_logloss: 2.71623
# [193]	valid_0's multi_logloss: 2.71589
# [194]	valid_0's multi_logloss: 2.71565
# [195]	valid_0's multi_logloss: 2.71539
# [196]	valid_0's multi_logloss: 2.71512
# [197]	valid_0's multi_logloss: 2.71492
# [198]	valid_0's multi_logloss: 2.71462
# [199]	valid_0's multi_logloss: 2.71436
# [200]	valid_0's multi_logloss: 2.71412
# [201]	valid_0's multi_logloss: 2.71384
# [202]	valid_0's multi_logloss: 2.71359
# [203]	valid_0's multi_logloss: 2.71333
# [204]	valid_0's multi_logloss: 2.71306
# [205]	valid_0's multi_logloss: 2.71285
# [206]	valid_0's multi_logloss: 2.71255
# [207]	valid_0's multi_logloss: 2.71231
# [208]	valid_0's multi_logloss: 2.71209
# [209]	valid_0's multi_logloss: 2.71183
# [210]	valid_0's multi_logloss: 2.71156
# [211]	valid_0's multi_logloss: 2.71136
# [212]	valid_0's multi_logloss: 2.71111
# [213]	valid_0's multi_logloss: 2.71093
# [214]	valid_0's multi_logloss: 2.71068
# [215]	valid_0's multi_logloss: 2.71047
# [216]	valid_0's multi_logloss: 2.7102
# [217]	valid_0's multi_logloss: 2.71002
# [218]	valid_0's multi_logloss: 2.70977
# [219]	valid_0's multi_logloss: 2.7096
# [220]	valid_0's multi_logloss: 2.70939
# [221]	valid_0's multi_logloss: 2.70915
# [222]	valid_0's multi_logloss: 2.70895
# [223]	valid_0's multi_logloss: 2.70874
# [224]	valid_0's multi_logloss: 2.70851
# [225]	valid_0's multi_logloss: 2.7083
# [226]	valid_0's multi_logloss: 2.7081
# [227]	valid_0's multi_logloss: 2.70791
# [228]	valid_0's multi_logloss: 2.70771
# [229]	valid_0's multi_logloss: 2.70754
# [230]	valid_0's multi_logloss: 2.70735
# [231]	valid_0's multi_logloss: 2.70716
# [232]	valid_0's multi_logloss: 2.70693
# [233]	valid_0's multi_logloss: 2.70672
# [234]	valid_0's multi_logloss: 2.70649
# [235]	valid_0's multi_logloss: 2.70631
# [236]	valid_0's multi_logloss: 2.70607
# [237]	valid_0's multi_logloss: 2.70589
# [238]	valid_0's multi_logloss: 2.7057
# [239]	valid_0's multi_logloss: 2.70552
# [240]	valid_0's multi_logloss: 2.70535
# [241]	valid_0's multi_logloss: 2.7052
# [242]	valid_0's multi_logloss: 2.70504
# [243]	valid_0's multi_logloss: 2.70485
# [244]	valid_0's multi_logloss: 2.70462
# [245]	valid_0's multi_logloss: 2.70443
# [246]	valid_0's multi_logloss: 2.70427
# [247]	valid_0's multi_logloss: 2.70406
# [248]	valid_0's multi_logloss: 2.70391
# [249]	valid_0's multi_logloss: 2.7037
# [250]	valid_0's multi_logloss: 2.70352
# [251]	valid_0's multi_logloss: 2.70343
# [252]	valid_0's multi_logloss: 2.70325
# [253]	valid_0's multi_logloss: 2.70307
# [254]	valid_0's multi_logloss: 2.7029
# [255]	valid_0's multi_logloss: 2.70274
# [256]	valid_0's multi_logloss: 2.70259
# [257]	valid_0's multi_logloss: 2.7024
# [258]	valid_0's multi_logloss: 2.70223
# [259]	valid_0's multi_logloss: 2.7021
# [260]	valid_0's multi_logloss: 2.70193
# [261]	valid_0's multi_logloss: 2.7018
# [262]	valid_0's multi_logloss: 2.70167
# [263]	valid_0's multi_logloss: 2.70154
# [264]	valid_0's multi_logloss: 2.70138
# [265]	valid_0's multi_logloss: 2.70116
# [266]	valid_0's multi_logloss: 2.70099
# [267]	valid_0's multi_logloss: 2.70087
# [268]	valid_0's multi_logloss: 2.70071
# [269]	valid_0's multi_logloss: 2.70058
# [270]	valid_0's multi_logloss: 2.70045
# [271]	valid_0's multi_logloss: 2.7003
# [272]	valid_0's multi_logloss: 2.70014
# [273]	valid_0's multi_logloss: 2.70003
# [274]	valid_0's multi_logloss: 2.69987
# [275]	valid_0's multi_logloss: 2.6997
# [276]	valid_0's multi_logloss: 2.69949
# [277]	valid_0's multi_logloss: 2.69934
# [278]	valid_0's multi_logloss: 2.69919
# [279]	valid_0's multi_logloss: 2.69907
# [280]	valid_0's multi_logloss: 2.69895
# [281]	valid_0's multi_logloss: 2.69879
# [282]	valid_0's multi_logloss: 2.69863
# [283]	valid_0's multi_logloss: 2.69851
# [284]	valid_0's multi_logloss: 2.69837
# [285]	valid_0's multi_logloss: 2.69826
# [286]	valid_0's multi_logloss: 2.69812
# [287]	valid_0's multi_logloss: 2.69793
# [288]	valid_0's multi_logloss: 2.69782
# [289]	valid_0's multi_logloss: 2.69767
# [290]	valid_0's multi_logloss: 2.69754
# [291]	valid_0's multi_logloss: 2.69741
# [292]	valid_0's multi_logloss: 2.69728
# [293]	valid_0's multi_logloss: 2.69716
# [294]	valid_0's multi_logloss: 2.69706
# [295]	valid_0's multi_logloss: 2.69692
# [296]	valid_0's multi_logloss: 2.69685
# [297]	valid_0's multi_logloss: 2.69666
# [298]	valid_0's multi_logloss: 2.69651
# [299]	valid_0's multi_logloss: 2.6964
# [300]	valid_0's multi_logloss: 2.69628
# [301]	valid_0's multi_logloss: 2.69616
# [302]	valid_0's multi_logloss: 2.696
# [303]	valid_0's multi_logloss: 2.69592
# [304]	valid_0's multi_logloss: 2.69583
# [305]	valid_0's multi_logloss: 2.6957
# [306]	valid_0's multi_logloss: 2.69559
# [307]	valid_0's multi_logloss: 2.69547
# [308]	valid_0's multi_logloss: 2.6954
# [309]	valid_0's multi_logloss: 2.69528
# [310]	valid_0's multi_logloss: 2.69517
# [311]	valid_0's multi_logloss: 2.69513
# [312]	valid_0's multi_logloss: 2.695
# [313]	valid_0's multi_logloss: 2.69486
# [314]	valid_0's multi_logloss: 2.69482
# [315]	valid_0's multi_logloss: 2.69469
# [316]	valid_0's multi_logloss: 2.69463
# [317]	valid_0's multi_logloss: 2.69457
# [318]	valid_0's multi_logloss: 2.69443
# [319]	valid_0's multi_logloss: 2.69434
# [320]	valid_0's multi_logloss: 2.69422
# [321]	valid_0's multi_logloss: 2.69419
# [322]	valid_0's multi_logloss: 2.69403
# [323]	valid_0's multi_logloss: 2.69396
# [324]	valid_0's multi_logloss: 2.69383
# [325]	valid_0's multi_logloss: 2.69378
# [326]	valid_0's multi_logloss: 2.69373
# [327]	valid_0's multi_logloss: 2.69366
# [328]	valid_0's multi_logloss: 2.69348
# [329]	valid_0's multi_logloss: 2.69339
# [330]	valid_0's multi_logloss: 2.69332
# [331]	valid_0's multi_logloss: 2.69326
# [332]	valid_0's multi_logloss: 2.69319
# [333]	valid_0's multi_logloss: 2.69316
# [334]	valid_0's multi_logloss: 2.69302
# [335]	valid_0's multi_logloss: 2.69291
# [336]	valid_0's multi_logloss: 2.69284
# [337]	valid_0's multi_logloss: 2.69277
# [338]	valid_0's multi_logloss: 2.69269
# [339]	valid_0's multi_logloss: 2.69263
# [340]	valid_0's multi_logloss: 2.69248
# [341]	valid_0's multi_logloss: 2.69245
# [342]	valid_0's multi_logloss: 2.69234
# [343]	valid_0's multi_logloss: 2.69231
# [344]	valid_0's multi_logloss: 2.69226
# [345]	valid_0's multi_logloss: 2.69212
# [346]	valid_0's multi_logloss: 2.69211
# [347]	valid_0's multi_logloss: 2.69209
# [348]	valid_0's multi_logloss: 2.69196
# [349]	valid_0's multi_logloss: 2.69182
# [350]	valid_0's multi_logloss: 2.69176
# [351]	valid_0's multi_logloss: 2.69172
# [352]	valid_0's multi_logloss: 2.69167
# [353]	valid_0's multi_logloss: 2.6916
# [354]	valid_0's multi_logloss: 2.69156
# [355]	valid_0's multi_logloss: 2.69152
# [356]	valid_0's multi_logloss: 2.6914
# [357]	valid_0's multi_logloss: 2.69127
# [358]	valid_0's multi_logloss: 2.69122
# [359]	valid_0's multi_logloss: 2.69116
# [360]	valid_0's multi_logloss: 2.69107
# [361]	valid_0's multi_logloss: 2.69106
# [362]	valid_0's multi_logloss: 2.69101
# [363]	valid_0's multi_logloss: 2.69103
# [364]	valid_0's multi_logloss: 2.69093
# [365]	valid_0's multi_logloss: 2.69088
# [366]	valid_0's multi_logloss: 2.69082
# [367]	valid_0's multi_logloss: 2.69075
# [368]	valid_0's multi_logloss: 2.6907
# [369]	valid_0's multi_logloss: 2.6906
# [370]	valid_0's multi_logloss: 2.69054
# [371]	valid_0's multi_logloss: 2.69049
# [372]	valid_0's multi_logloss: 2.69046
# [373]	valid_0's multi_logloss: 2.6904
# [374]	valid_0's multi_logloss: 2.69029
# [375]	valid_0's multi_logloss: 2.69025
# [376]	valid_0's multi_logloss: 2.69016
# [377]	valid_0's multi_logloss: 2.69013
# [378]	valid_0's multi_logloss: 2.69014
# [379]	valid_0's multi_logloss: 2.69007
# [380]	valid_0's multi_logloss: 2.69004
# [381]	valid_0's multi_logloss: 2.68997
# [382]	valid_0's multi_logloss: 2.68996
# [383]	valid_0's multi_logloss: 2.68992
# [384]	valid_0's multi_logloss: 2.68994
# [385]	valid_0's multi_logloss: 2.68984
# [386]	valid_0's multi_logloss: 2.68977
# [387]	valid_0's multi_logloss: 2.68976
# [388]	valid_0's multi_logloss: 2.68971
# [389]	valid_0's multi_logloss: 2.68969
# [390]	valid_0's multi_logloss: 2.68964
# [391]	valid_0's multi_logloss: 2.68962
# [392]	valid_0's multi_logloss: 2.68956
# [393]	valid_0's multi_logloss: 2.68954
# [394]	valid_0's multi_logloss: 2.68949
# [395]	valid_0's multi_logloss: 2.68945
# [396]	valid_0's multi_logloss: 2.6894
# [397]	valid_0's multi_logloss: 2.68935
# [398]	valid_0's multi_logloss: 2.68933
# [399]	valid_0's multi_logloss: 2.68932
# [400]	valid_0's multi_logloss: 2.6893
# [401]	valid_0's multi_logloss: 2.68929
# [402]	valid_0's multi_logloss: 2.68923
# [403]	valid_0's multi_logloss: 2.68916
# [404]	valid_0's multi_logloss: 2.68916
# [405]	valid_0's multi_logloss: 2.68908
# [406]	valid_0's multi_logloss: 2.689
# [407]	valid_0's multi_logloss: 2.68891
# [408]	valid_0's multi_logloss: 2.6889
# [409]	valid_0's multi_logloss: 2.68889
# [410]	valid_0's multi_logloss: 2.68883
# [411]	valid_0's multi_logloss: 2.68877
# [412]	valid_0's multi_logloss: 2.68872
# [413]	valid_0's multi_logloss: 2.68873
# [414]	valid_0's multi_logloss: 2.68872
# [415]	valid_0's multi_logloss: 2.68866
# [416]	valid_0's multi_logloss: 2.68862
# [417]	valid_0's multi_logloss: 2.68863
# [418]	valid_0's multi_logloss: 2.6885
# [419]	valid_0's multi_logloss: 2.6885
# [420]	valid_0's multi_logloss: 2.68851
# [421]	valid_0's multi_logloss: 2.68847
# [422]	valid_0's multi_logloss: 2.68846
# [423]	valid_0's multi_logloss: 2.68843
# [424]	valid_0's multi_logloss: 2.6884
# [425]	valid_0's multi_logloss: 2.68845
# [426]	valid_0's multi_logloss: 2.68848
# [427]	valid_0's multi_logloss: 2.68845
# [428]	valid_0's multi_logloss: 2.68842
# [429]	valid_0's multi_logloss: 2.68838
# [430]	valid_0's multi_logloss: 2.68834
# [431]	valid_0's multi_logloss: 2.68834
# [432]	valid_0's multi_logloss: 2.68831
# [433]	valid_0's multi_logloss: 2.68826
# [434]	valid_0's multi_logloss: 2.68825
# [435]	valid_0's multi_logloss: 2.68824
# [436]	valid_0's multi_logloss: 2.68823
# [437]	valid_0's multi_logloss: 2.68819
# [438]	valid_0's multi_logloss: 2.68815
# [439]	valid_0's multi_logloss: 2.68813
# [440]	valid_0's multi_logloss: 2.68811
# [441]	valid_0's multi_logloss: 2.68809
# [442]	valid_0's multi_logloss: 2.68802
# [443]	valid_0's multi_logloss: 2.68797
# [444]	valid_0's multi_logloss: 2.68797
# [445]	valid_0's multi_logloss: 2.68791
# [446]	valid_0's multi_logloss: 2.68788
# [447]	valid_0's multi_logloss: 2.68786
# [448]	valid_0's multi_logloss: 2.68787
# [449]	valid_0's multi_logloss: 2.68789
# [450]	valid_0's multi_logloss: 2.68788
# [451]	valid_0's multi_logloss: 2.68786
# [452]	valid_0's multi_logloss: 2.68788
# [453]	valid_0's multi_logloss: 2.68787
# [454]	valid_0's multi_logloss: 2.68783
# [455]	valid_0's multi_logloss: 2.68783
# [456]	valid_0's multi_logloss: 2.68779
# [457]	valid_0's multi_logloss: 2.68776
# [458]	valid_0's multi_logloss: 2.6878
# [459]	valid_0's multi_logloss: 2.68781
# [460]	valid_0's multi_logloss: 2.68779
# [461]	valid_0's multi_logloss: 2.68774
# [462]	valid_0's multi_logloss: 2.68771
# [463]	valid_0's multi_logloss: 2.6877
# [464]	valid_0's multi_logloss: 2.68764
# [465]	valid_0's multi_logloss: 2.68763
# [466]	valid_0's multi_logloss: 2.68763
# [467]	valid_0's multi_logloss: 2.68763
# [468]	valid_0's multi_logloss: 2.68769
# [469]	valid_0's multi_logloss: 2.68768
# [470]	valid_0's multi_logloss: 2.68767
# [471]	valid_0's multi_logloss: 2.68771
# [472]	valid_0's multi_logloss: 2.68776
# [473]	valid_0's multi_logloss: 2.68786
# [474]	valid_0's multi_logloss: 2.68782
# [475]	valid_0's multi_logloss: 2.68787
# [476]	valid_0's multi_logloss: 2.68788
# Early stopping, best iteration is:
# [466]	valid_0's multi_logloss: 2.68763
# 0.012425238984138066
# [1]	valid_0's multi_logloss: 2.88699
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88384
# [3]	valid_0's multi_logloss: 2.88126
# [4]	valid_0's multi_logloss: 2.87885
# [5]	valid_0's multi_logloss: 2.87683
# [6]	valid_0's multi_logloss: 2.87458
# [7]	valid_0's multi_logloss: 2.87264
# [8]	valid_0's multi_logloss: 2.87044
# [9]	valid_0's multi_logloss: 2.86845
# [10]	valid_0's multi_logloss: 2.8664
# [11]	valid_0's multi_logloss: 2.86453
# [12]	valid_0's multi_logloss: 2.86266
# [13]	valid_0's multi_logloss: 2.86093
# [14]	valid_0's multi_logloss: 2.85908
# [15]	valid_0's multi_logloss: 2.85745
# [16]	valid_0's multi_logloss: 2.8557
# [17]	valid_0's multi_logloss: 2.85398
# [18]	valid_0's multi_logloss: 2.85236
# [19]	valid_0's multi_logloss: 2.85065
# [20]	valid_0's multi_logloss: 2.84903
# [21]	valid_0's multi_logloss: 2.84734
# [22]	valid_0's multi_logloss: 2.84571
# [23]	valid_0's multi_logloss: 2.84422
# [24]	valid_0's multi_logloss: 2.84266
# [25]	valid_0's multi_logloss: 2.84112
# [26]	valid_0's multi_logloss: 2.83962
# [27]	valid_0's multi_logloss: 2.8381
# [28]	valid_0's multi_logloss: 2.83662
# [29]	valid_0's multi_logloss: 2.8353
# [30]	valid_0's multi_logloss: 2.83381
# [31]	valid_0's multi_logloss: 2.8324
# [32]	valid_0's multi_logloss: 2.8309
# [33]	valid_0's multi_logloss: 2.82954
# [34]	valid_0's multi_logloss: 2.8281
# [35]	valid_0's multi_logloss: 2.82675
# [36]	valid_0's multi_logloss: 2.82547
# [37]	valid_0's multi_logloss: 2.82422
# [38]	valid_0's multi_logloss: 2.82287
# [39]	valid_0's multi_logloss: 2.82176
# [40]	valid_0's multi_logloss: 2.82067
# [41]	valid_0's multi_logloss: 2.81951
# [42]	valid_0's multi_logloss: 2.81822
# [43]	valid_0's multi_logloss: 2.81709
# [44]	valid_0's multi_logloss: 2.81601
# [45]	valid_0's multi_logloss: 2.81487
# [46]	valid_0's multi_logloss: 2.81385
# [47]	valid_0's multi_logloss: 2.81266
# [48]	valid_0's multi_logloss: 2.81151
# [49]	valid_0's multi_logloss: 2.81049
# [50]	valid_0's multi_logloss: 2.80941
# [51]	valid_0's multi_logloss: 2.80839
# [52]	valid_0's multi_logloss: 2.80733
# [53]	valid_0's multi_logloss: 2.80635
# [54]	valid_0's multi_logloss: 2.80525
# [55]	valid_0's multi_logloss: 2.8043
# [56]	valid_0's multi_logloss: 2.80333
# [57]	valid_0's multi_logloss: 2.80229
# [58]	valid_0's multi_logloss: 2.80133
# [59]	valid_0's multi_logloss: 2.80034
# [60]	valid_0's multi_logloss: 2.79933
# [61]	valid_0's multi_logloss: 2.79844
# [62]	valid_0's multi_logloss: 2.79759
# [63]	valid_0's multi_logloss: 2.79661
# [64]	valid_0's multi_logloss: 2.79575
# [65]	valid_0's multi_logloss: 2.79481
# [66]	valid_0's multi_logloss: 2.79389
# [67]	valid_0's multi_logloss: 2.79294
# [68]	valid_0's multi_logloss: 2.79197
# [69]	valid_0's multi_logloss: 2.79102
# [70]	valid_0's multi_logloss: 2.79017
# [71]	valid_0's multi_logloss: 2.78923
# [72]	valid_0's multi_logloss: 2.78842
# [73]	valid_0's multi_logloss: 2.78754
# [74]	valid_0's multi_logloss: 2.78668
# [75]	valid_0's multi_logloss: 2.78585
# [76]	valid_0's multi_logloss: 2.78496
# [77]	valid_0's multi_logloss: 2.78411
# [78]	valid_0's multi_logloss: 2.78336
# [79]	valid_0's multi_logloss: 2.78249
# [80]	valid_0's multi_logloss: 2.78165
# [81]	valid_0's multi_logloss: 2.78076
# [82]	valid_0's multi_logloss: 2.77997
# [83]	valid_0's multi_logloss: 2.7792
# [84]	valid_0's multi_logloss: 2.77848
# [85]	valid_0's multi_logloss: 2.7776
# [86]	valid_0's multi_logloss: 2.77687
# [87]	valid_0's multi_logloss: 2.77613
# [88]	valid_0's multi_logloss: 2.77525
# [89]	valid_0's multi_logloss: 2.77445
# [90]	valid_0's multi_logloss: 2.77372
# [91]	valid_0's multi_logloss: 2.77296
# [92]	valid_0's multi_logloss: 2.77225
# [93]	valid_0's multi_logloss: 2.77148
# [94]	valid_0's multi_logloss: 2.77077
# [95]	valid_0's multi_logloss: 2.77002
# [96]	valid_0's multi_logloss: 2.76933
# [97]	valid_0's multi_logloss: 2.7685
# [98]	valid_0's multi_logloss: 2.76788
# [99]	valid_0's multi_logloss: 2.76722
# [100]	valid_0's multi_logloss: 2.76654
# [101]	valid_0's multi_logloss: 2.76585
# [102]	valid_0's multi_logloss: 2.76515
# [103]	valid_0's multi_logloss: 2.76448
# [104]	valid_0's multi_logloss: 2.76384
# [105]	valid_0's multi_logloss: 2.76314
# [106]	valid_0's multi_logloss: 2.76242
# [107]	valid_0's multi_logloss: 2.76172
# [108]	valid_0's multi_logloss: 2.76109
# [109]	valid_0's multi_logloss: 2.76039
# [110]	valid_0's multi_logloss: 2.75976
# [111]	valid_0's multi_logloss: 2.75916
# [112]	valid_0's multi_logloss: 2.75849
# [113]	valid_0's multi_logloss: 2.75785
# [114]	valid_0's multi_logloss: 2.75724
# [115]	valid_0's multi_logloss: 2.75658
# [116]	valid_0's multi_logloss: 2.75597
# [117]	valid_0's multi_logloss: 2.7554
# [118]	valid_0's multi_logloss: 2.75482
# [119]	valid_0's multi_logloss: 2.75417
# [120]	valid_0's multi_logloss: 2.75352
# [121]	valid_0's multi_logloss: 2.75294
# [122]	valid_0's multi_logloss: 2.75232
# [123]	valid_0's multi_logloss: 2.75175
# [124]	valid_0's multi_logloss: 2.75115
# [125]	valid_0's multi_logloss: 2.75056
# [126]	valid_0's multi_logloss: 2.75
# [127]	valid_0's multi_logloss: 2.74946
# [128]	valid_0's multi_logloss: 2.74895
# [129]	valid_0's multi_logloss: 2.74841
# [130]	valid_0's multi_logloss: 2.74778
# [131]	valid_0's multi_logloss: 2.74715
# [132]	valid_0's multi_logloss: 2.74658
# [133]	valid_0's multi_logloss: 2.74606
# [134]	valid_0's multi_logloss: 2.7455
# [135]	valid_0's multi_logloss: 2.74499
# [136]	valid_0's multi_logloss: 2.74444
# [137]	valid_0's multi_logloss: 2.74389
# [138]	valid_0's multi_logloss: 2.74341
# [139]	valid_0's multi_logloss: 2.7429
# [140]	valid_0's multi_logloss: 2.74237
# [141]	valid_0's multi_logloss: 2.74177
# [142]	valid_0's multi_logloss: 2.74136
# [143]	valid_0's multi_logloss: 2.74088
# [144]	valid_0's multi_logloss: 2.74039
# [145]	valid_0's multi_logloss: 2.73993
# [146]	valid_0's multi_logloss: 2.73937
# [147]	valid_0's multi_logloss: 2.73891
# [148]	valid_0's multi_logloss: 2.7384
# [149]	valid_0's multi_logloss: 2.73792
# [150]	valid_0's multi_logloss: 2.73751
# [151]	valid_0's multi_logloss: 2.73705
# [152]	valid_0's multi_logloss: 2.73659
# [153]	valid_0's multi_logloss: 2.73616
# [154]	valid_0's multi_logloss: 2.73568
# [155]	valid_0's multi_logloss: 2.73525
# [156]	valid_0's multi_logloss: 2.73477
# [157]	valid_0's multi_logloss: 2.73435
# [158]	valid_0's multi_logloss: 2.73395
# [159]	valid_0's multi_logloss: 2.73351
# [160]	valid_0's multi_logloss: 2.73307
# [161]	valid_0's multi_logloss: 2.73258
# [162]	valid_0's multi_logloss: 2.73218
# [163]	valid_0's multi_logloss: 2.73178
# [164]	valid_0's multi_logloss: 2.73126
# [165]	valid_0's multi_logloss: 2.73088
# [166]	valid_0's multi_logloss: 2.7304
# [167]	valid_0's multi_logloss: 2.73002
# [168]	valid_0's multi_logloss: 2.72959
# [169]	valid_0's multi_logloss: 2.72914
# [170]	valid_0's multi_logloss: 2.72871
# [171]	valid_0's multi_logloss: 2.72829
# [172]	valid_0's multi_logloss: 2.72787
# [173]	valid_0's multi_logloss: 2.72756
# [174]	valid_0's multi_logloss: 2.72719
# [175]	valid_0's multi_logloss: 2.7268
# [176]	valid_0's multi_logloss: 2.72639
# [177]	valid_0's multi_logloss: 2.72593
# [178]	valid_0's multi_logloss: 2.72549
# [179]	valid_0's multi_logloss: 2.72515
# [180]	valid_0's multi_logloss: 2.7248
# [181]	valid_0's multi_logloss: 2.72442
# [182]	valid_0's multi_logloss: 2.724
# [183]	valid_0's multi_logloss: 2.72367
# [184]	valid_0's multi_logloss: 2.72333
# [185]	valid_0's multi_logloss: 2.72291
# [186]	valid_0's multi_logloss: 2.7226
# [187]	valid_0's multi_logloss: 2.72215
# [188]	valid_0's multi_logloss: 2.72182
# [189]	valid_0's multi_logloss: 2.7215
# [190]	valid_0's multi_logloss: 2.72112
# [191]	valid_0's multi_logloss: 2.72082
# [192]	valid_0's multi_logloss: 2.72049
# [193]	valid_0's multi_logloss: 2.72015
# [194]	valid_0's multi_logloss: 2.71977
# [195]	valid_0's multi_logloss: 2.71949
# [196]	valid_0's multi_logloss: 2.71915
# [197]	valid_0's multi_logloss: 2.71881
# [198]	valid_0's multi_logloss: 2.71842
# [199]	valid_0's multi_logloss: 2.71809
# [200]	valid_0's multi_logloss: 2.71783
# [201]	valid_0's multi_logloss: 2.71751
# [202]	valid_0's multi_logloss: 2.71716
# [203]	valid_0's multi_logloss: 2.71685
# [204]	valid_0's multi_logloss: 2.71657
# [205]	valid_0's multi_logloss: 2.71627
# [206]	valid_0's multi_logloss: 2.71593
# [207]	valid_0's multi_logloss: 2.71561
# [208]	valid_0's multi_logloss: 2.71525
# [209]	valid_0's multi_logloss: 2.715
# [210]	valid_0's multi_logloss: 2.71469
# [211]	valid_0's multi_logloss: 2.71434
# [212]	valid_0's multi_logloss: 2.71411
# [213]	valid_0's multi_logloss: 2.71374
# [214]	valid_0's multi_logloss: 2.7134
# [215]	valid_0's multi_logloss: 2.71311
# [216]	valid_0's multi_logloss: 2.71282
# [217]	valid_0's multi_logloss: 2.71254
# [218]	valid_0's multi_logloss: 2.71226
# [219]	valid_0's multi_logloss: 2.71199
# [220]	valid_0's multi_logloss: 2.71169
# [221]	valid_0's multi_logloss: 2.71136
# [222]	valid_0's multi_logloss: 2.71102
# [223]	valid_0's multi_logloss: 2.71068
# [224]	valid_0's multi_logloss: 2.71037
# [225]	valid_0's multi_logloss: 2.71014
# [226]	valid_0's multi_logloss: 2.70986
# [227]	valid_0's multi_logloss: 2.70952
# [228]	valid_0's multi_logloss: 2.70918
# [229]	valid_0's multi_logloss: 2.70886
# [230]	valid_0's multi_logloss: 2.7086
# [231]	valid_0's multi_logloss: 2.70832
# [232]	valid_0's multi_logloss: 2.70808
# [233]	valid_0's multi_logloss: 2.70784
# [234]	valid_0's multi_logloss: 2.70757
# [235]	valid_0's multi_logloss: 2.70727
# [236]	valid_0's multi_logloss: 2.70703
# [237]	valid_0's multi_logloss: 2.70677
# [238]	valid_0's multi_logloss: 2.70646
# [239]	valid_0's multi_logloss: 2.70612
# [240]	valid_0's multi_logloss: 2.70588
# [241]	valid_0's multi_logloss: 2.70572
# [242]	valid_0's multi_logloss: 2.70545
# [243]	valid_0's multi_logloss: 2.70521
# [244]	valid_0's multi_logloss: 2.70497
# [245]	valid_0's multi_logloss: 2.70473
# [246]	valid_0's multi_logloss: 2.70453
# [247]	valid_0's multi_logloss: 2.70433
# [248]	valid_0's multi_logloss: 2.70411
# [249]	valid_0's multi_logloss: 2.70388
# [250]	valid_0's multi_logloss: 2.70365
# [251]	valid_0's multi_logloss: 2.70346
# [252]	valid_0's multi_logloss: 2.70323
# [253]	valid_0's multi_logloss: 2.70305
# [254]	valid_0's multi_logloss: 2.70279
# [255]	valid_0's multi_logloss: 2.70263
# [256]	valid_0's multi_logloss: 2.70242
# [257]	valid_0's multi_logloss: 2.70223
# [258]	valid_0's multi_logloss: 2.70203
# [259]	valid_0's multi_logloss: 2.70192
# [260]	valid_0's multi_logloss: 2.70172
# [261]	valid_0's multi_logloss: 2.70154
# [262]	valid_0's multi_logloss: 2.7013
# [263]	valid_0's multi_logloss: 2.70108
# [264]	valid_0's multi_logloss: 2.70082
# [265]	valid_0's multi_logloss: 2.70065
# [266]	valid_0's multi_logloss: 2.70039
# [267]	valid_0's multi_logloss: 2.70026
# [268]	valid_0's multi_logloss: 2.70002
# [269]	valid_0's multi_logloss: 2.69985
# [270]	valid_0's multi_logloss: 2.69967
# [271]	valid_0's multi_logloss: 2.69942
# [272]	valid_0's multi_logloss: 2.69913
# [273]	valid_0's multi_logloss: 2.69894
# [274]	valid_0's multi_logloss: 2.69876
# [275]	valid_0's multi_logloss: 2.69857
# [276]	valid_0's multi_logloss: 2.69839
# [277]	valid_0's multi_logloss: 2.69817
# [278]	valid_0's multi_logloss: 2.69795
# [279]	valid_0's multi_logloss: 2.69776
# [280]	valid_0's multi_logloss: 2.69751
# [281]	valid_0's multi_logloss: 2.69736
# [282]	valid_0's multi_logloss: 2.69712
# [283]	valid_0's multi_logloss: 2.69685
# [284]	valid_0's multi_logloss: 2.69661
# [285]	valid_0's multi_logloss: 2.69638
# [286]	valid_0's multi_logloss: 2.69613
# [287]	valid_0's multi_logloss: 2.69594
# [288]	valid_0's multi_logloss: 2.69578
# [289]	valid_0's multi_logloss: 2.69565
# [290]	valid_0's multi_logloss: 2.69548
# [291]	valid_0's multi_logloss: 2.69527
# [292]	valid_0's multi_logloss: 2.6951
# [293]	valid_0's multi_logloss: 2.69486
# [294]	valid_0's multi_logloss: 2.69466
# [295]	valid_0's multi_logloss: 2.69447
# [296]	valid_0's multi_logloss: 2.69428
# [297]	valid_0's multi_logloss: 2.69411
# [298]	valid_0's multi_logloss: 2.69398
# [299]	valid_0's multi_logloss: 2.69378
# [300]	valid_0's multi_logloss: 2.6936
# [301]	valid_0's multi_logloss: 2.69344
# [302]	valid_0's multi_logloss: 2.69323
# [303]	valid_0's multi_logloss: 2.69303
# [304]	valid_0's multi_logloss: 2.69286
# [305]	valid_0's multi_logloss: 2.69268
# [306]	valid_0's multi_logloss: 2.69254
# [307]	valid_0's multi_logloss: 2.69244
# [308]	valid_0's multi_logloss: 2.69219
# [309]	valid_0's multi_logloss: 2.69202
# [310]	valid_0's multi_logloss: 2.69184
# [311]	valid_0's multi_logloss: 2.69165
# [312]	valid_0's multi_logloss: 2.69151
# [313]	valid_0's multi_logloss: 2.69135
# [314]	valid_0's multi_logloss: 2.6912
# [315]	valid_0's multi_logloss: 2.69098
# [316]	valid_0's multi_logloss: 2.69078
# [317]	valid_0's multi_logloss: 2.69065
# [318]	valid_0's multi_logloss: 2.69047
# [319]	valid_0's multi_logloss: 2.6903
# [320]	valid_0's multi_logloss: 2.69019
# [321]	valid_0's multi_logloss: 2.69002
# [322]	valid_0's multi_logloss: 2.68984
# [323]	valid_0's multi_logloss: 2.68969
# [324]	valid_0's multi_logloss: 2.68952
# [325]	valid_0's multi_logloss: 2.68941
# [326]	valid_0's multi_logloss: 2.68929
# [327]	valid_0's multi_logloss: 2.68915
# [328]	valid_0's multi_logloss: 2.68899
# [329]	valid_0's multi_logloss: 2.68886
# [330]	valid_0's multi_logloss: 2.68876
# [331]	valid_0's multi_logloss: 2.68863
# [332]	valid_0's multi_logloss: 2.68841
# [333]	valid_0's multi_logloss: 2.6883
# [334]	valid_0's multi_logloss: 2.68813
# [335]	valid_0's multi_logloss: 2.68804
# [336]	valid_0's multi_logloss: 2.68794
# [337]	valid_0's multi_logloss: 2.68783
# [338]	valid_0's multi_logloss: 2.68774
# [339]	valid_0's multi_logloss: 2.68757
# [340]	valid_0's multi_logloss: 2.68747
# [341]	valid_0's multi_logloss: 2.68736
# [342]	valid_0's multi_logloss: 2.68722
# [343]	valid_0's multi_logloss: 2.68715
# [344]	valid_0's multi_logloss: 2.68698
# [345]	valid_0's multi_logloss: 2.68684
# [346]	valid_0's multi_logloss: 2.68676
# [347]	valid_0's multi_logloss: 2.68666
# [348]	valid_0's multi_logloss: 2.68654
# [349]	valid_0's multi_logloss: 2.68642
# [350]	valid_0's multi_logloss: 2.68628
# [351]	valid_0's multi_logloss: 2.68621
# [352]	valid_0's multi_logloss: 2.68611
# [353]	valid_0's multi_logloss: 2.68599
# [354]	valid_0's multi_logloss: 2.6859
# [355]	valid_0's multi_logloss: 2.68583
# [356]	valid_0's multi_logloss: 2.68574
# [357]	valid_0's multi_logloss: 2.68556
# [358]	valid_0's multi_logloss: 2.68545
# [359]	valid_0's multi_logloss: 2.68539
# [360]	valid_0's multi_logloss: 2.68523
# [361]	valid_0's multi_logloss: 2.68517
# [362]	valid_0's multi_logloss: 2.68511
# [363]	valid_0's multi_logloss: 2.68505
# [364]	valid_0's multi_logloss: 2.68499
# [365]	valid_0's multi_logloss: 2.68491
# [366]	valid_0's multi_logloss: 2.68483
# [367]	valid_0's multi_logloss: 2.68478
# [368]	valid_0's multi_logloss: 2.6846
# [369]	valid_0's multi_logloss: 2.68455
# [370]	valid_0's multi_logloss: 2.68445
# [371]	valid_0's multi_logloss: 2.68437
# [372]	valid_0's multi_logloss: 2.68431
# [373]	valid_0's multi_logloss: 2.68423
# [374]	valid_0's multi_logloss: 2.68416
# [375]	valid_0's multi_logloss: 2.68409
# [376]	valid_0's multi_logloss: 2.68402
# [377]	valid_0's multi_logloss: 2.68393
# [378]	valid_0's multi_logloss: 2.68385
# [379]	valid_0's multi_logloss: 2.68375
# [380]	valid_0's multi_logloss: 2.68368
# [381]	valid_0's multi_logloss: 2.6836
# [382]	valid_0's multi_logloss: 2.68354
# [383]	valid_0's multi_logloss: 2.68341
# [384]	valid_0's multi_logloss: 2.68338
# [385]	valid_0's multi_logloss: 2.68329
# [386]	valid_0's multi_logloss: 2.6832
# [387]	valid_0's multi_logloss: 2.68313
# [388]	valid_0's multi_logloss: 2.68302
# [389]	valid_0's multi_logloss: 2.68295
# [390]	valid_0's multi_logloss: 2.68289
# [391]	valid_0's multi_logloss: 2.68283
# [392]	valid_0's multi_logloss: 2.68275
# [393]	valid_0's multi_logloss: 2.68273
# [394]	valid_0's multi_logloss: 2.68265
# [395]	valid_0's multi_logloss: 2.68258
# [396]	valid_0's multi_logloss: 2.68252
# [397]	valid_0's multi_logloss: 2.68246
# [398]	valid_0's multi_logloss: 2.68239
# [399]	valid_0's multi_logloss: 2.68229
# [400]	valid_0's multi_logloss: 2.68225
# [401]	valid_0's multi_logloss: 2.68219
# [402]	valid_0's multi_logloss: 2.68209
# [403]	valid_0's multi_logloss: 2.68201
# [404]	valid_0's multi_logloss: 2.68187
# [405]	valid_0's multi_logloss: 2.68182
# [406]	valid_0's multi_logloss: 2.68177
# [407]	valid_0's multi_logloss: 2.68169
# [408]	valid_0's multi_logloss: 2.68165
# [409]	valid_0's multi_logloss: 2.68158
# [410]	valid_0's multi_logloss: 2.68157
# [411]	valid_0's multi_logloss: 2.68153
# [412]	valid_0's multi_logloss: 2.68152
# [413]	valid_0's multi_logloss: 2.68144
# [414]	valid_0's multi_logloss: 2.68142
# [415]	valid_0's multi_logloss: 2.68138
# [416]	valid_0's multi_logloss: 2.68129
# [417]	valid_0's multi_logloss: 2.68131
# [418]	valid_0's multi_logloss: 2.68126
# [419]	valid_0's multi_logloss: 2.68119
# [420]	valid_0's multi_logloss: 2.68114
# [421]	valid_0's multi_logloss: 2.68107
# [422]	valid_0's multi_logloss: 2.68102
# [423]	valid_0's multi_logloss: 2.68098
# [424]	valid_0's multi_logloss: 2.68098
# [425]	valid_0's multi_logloss: 2.6809
# [426]	valid_0's multi_logloss: 2.68088
# [427]	valid_0's multi_logloss: 2.68085
# [428]	valid_0's multi_logloss: 2.68081
# [429]	valid_0's multi_logloss: 2.68071
# [430]	valid_0's multi_logloss: 2.68069
# [431]	valid_0's multi_logloss: 2.68065
# [432]	valid_0's multi_logloss: 2.68059
# [433]	valid_0's multi_logloss: 2.6806
# [434]	valid_0's multi_logloss: 2.68059
# [435]	valid_0's multi_logloss: 2.68055
# [436]	valid_0's multi_logloss: 2.6805
# [437]	valid_0's multi_logloss: 2.68047
# [438]	valid_0's multi_logloss: 2.68041
# [439]	valid_0's multi_logloss: 2.6804
# [440]	valid_0's multi_logloss: 2.68031
# [441]	valid_0's multi_logloss: 2.68025
# [442]	valid_0's multi_logloss: 2.68022
# [443]	valid_0's multi_logloss: 2.6802
# [444]	valid_0's multi_logloss: 2.68015
# [445]	valid_0's multi_logloss: 2.6801
# [446]	valid_0's multi_logloss: 2.68008
# [447]	valid_0's multi_logloss: 2.68
# [448]	valid_0's multi_logloss: 2.67996
# [449]	valid_0's multi_logloss: 2.67996
# [450]	valid_0's multi_logloss: 2.67992
# [451]	valid_0's multi_logloss: 2.67987
# [452]	valid_0's multi_logloss: 2.67986
# [453]	valid_0's multi_logloss: 2.67977
# [454]	valid_0's multi_logloss: 2.67972
# [455]	valid_0's multi_logloss: 2.67964
# [456]	valid_0's multi_logloss: 2.67959
# [457]	valid_0's multi_logloss: 2.67953
# [458]	valid_0's multi_logloss: 2.67944
# [459]	valid_0's multi_logloss: 2.67947
# [460]	valid_0's multi_logloss: 2.67944
# [461]	valid_0's multi_logloss: 2.67939
# [462]	valid_0's multi_logloss: 2.67933
# [463]	valid_0's multi_logloss: 2.67931
# [464]	valid_0's multi_logloss: 2.67925
# [465]	valid_0's multi_logloss: 2.67924
# [466]	valid_0's multi_logloss: 2.67916
# [467]	valid_0's multi_logloss: 2.67914
# [468]	valid_0's multi_logloss: 2.67913
# [469]	valid_0's multi_logloss: 2.67912
# [470]	valid_0's multi_logloss: 2.67912
# [471]	valid_0's multi_logloss: 2.67908
# [472]	valid_0's multi_logloss: 2.67907
# [473]	valid_0's multi_logloss: 2.67901
# [474]	valid_0's multi_logloss: 2.67898
# [475]	valid_0's multi_logloss: 2.67898
# [476]	valid_0's multi_logloss: 2.67896
# [477]	valid_0's multi_logloss: 2.67894
# [478]	valid_0's multi_logloss: 2.67888
# [479]	valid_0's multi_logloss: 2.6789
# [480]	valid_0's multi_logloss: 2.67886
# [481]	valid_0's multi_logloss: 2.67884
# [482]	valid_0's multi_logloss: 2.67887
# [483]	valid_0's multi_logloss: 2.67886
# [484]	valid_0's multi_logloss: 2.67887
# [485]	valid_0's multi_logloss: 2.67885
# [486]	valid_0's multi_logloss: 2.67883
# [487]	valid_0's multi_logloss: 2.67882
# [488]	valid_0's multi_logloss: 2.67875
# [489]	valid_0's multi_logloss: 2.67875
# [490]	valid_0's multi_logloss: 2.67875
# [491]	valid_0's multi_logloss: 2.67873
# [492]	valid_0's multi_logloss: 2.67875
# [493]	valid_0's multi_logloss: 2.6787
# [494]	valid_0's multi_logloss: 2.67871
# [495]	valid_0's multi_logloss: 2.6787
# [496]	valid_0's multi_logloss: 2.6787
# [497]	valid_0's multi_logloss: 2.67866
# [498]	valid_0's multi_logloss: 2.67861
# [499]	valid_0's multi_logloss: 2.67862
# [500]	valid_0's multi_logloss: 2.67862
# [501]	valid_0's multi_logloss: 2.67863
# [502]	valid_0's multi_logloss: 2.67861
# [503]	valid_0's multi_logloss: 2.67859
# [504]	valid_0's multi_logloss: 2.67861
# [505]	valid_0's multi_logloss: 2.67863
# [506]	valid_0's multi_logloss: 2.67865
# [507]	valid_0's multi_logloss: 2.67859
# [508]	valid_0's multi_logloss: 2.67857
# [509]	valid_0's multi_logloss: 2.67856
# [510]	valid_0's multi_logloss: 2.67855
# [511]	valid_0's multi_logloss: 2.67855
# [512]	valid_0's multi_logloss: 2.6785
# [513]	valid_0's multi_logloss: 2.67852
# [514]	valid_0's multi_logloss: 2.67852
# [515]	valid_0's multi_logloss: 2.6785
# [516]	valid_0's multi_logloss: 2.67853
# [517]	valid_0's multi_logloss: 2.67854
# [518]	valid_0's multi_logloss: 2.67856
# [519]	valid_0's multi_logloss: 2.67854
# [520]	valid_0's multi_logloss: 2.67849
# [521]	valid_0's multi_logloss: 2.67845
# [522]	valid_0's multi_logloss: 2.67847
# [523]	valid_0's multi_logloss: 2.67849
# [524]	valid_0's multi_logloss: 2.67852
# [525]	valid_0's multi_logloss: 2.67848
# [526]	valid_0's multi_logloss: 2.6785
# [527]	valid_0's multi_logloss: 2.67853
# [528]	valid_0's multi_logloss: 2.67854
# [529]	valid_0's multi_logloss: 2.67859
# [530]	valid_0's multi_logloss: 2.6786
# [531]	valid_0's multi_logloss: 2.67859
# Early stopping, best iteration is:
# [521]	valid_0's multi_logloss: 2.67845
# 0.012197367454729107
# [1]	valid_0's multi_logloss: 2.85872
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85674
# [3]	valid_0's multi_logloss: 2.85488
# [4]	valid_0's multi_logloss: 2.85303
# [5]	valid_0's multi_logloss: 2.85121
# [6]	valid_0's multi_logloss: 2.84949
# [7]	valid_0's multi_logloss: 2.8476
# [8]	valid_0's multi_logloss: 2.84583
# [9]	valid_0's multi_logloss: 2.84411
# [10]	valid_0's multi_logloss: 2.8424
# [11]	valid_0's multi_logloss: 2.84059
# [12]	valid_0's multi_logloss: 2.83902
# [13]	valid_0's multi_logloss: 2.8373
# [14]	valid_0's multi_logloss: 2.83586
# [15]	valid_0's multi_logloss: 2.83433
# [16]	valid_0's multi_logloss: 2.83294
# [17]	valid_0's multi_logloss: 2.83145
# [18]	valid_0's multi_logloss: 2.83
# [19]	valid_0's multi_logloss: 2.82867
# [20]	valid_0's multi_logloss: 2.82727
# [21]	valid_0's multi_logloss: 2.826
# [22]	valid_0's multi_logloss: 2.82466
# [23]	valid_0's multi_logloss: 2.82346
# [24]	valid_0's multi_logloss: 2.82221
# [25]	valid_0's multi_logloss: 2.82111
# [26]	valid_0's multi_logloss: 2.81991
# [27]	valid_0's multi_logloss: 2.81873
# [28]	valid_0's multi_logloss: 2.8175
# [29]	valid_0's multi_logloss: 2.81633
# [30]	valid_0's multi_logloss: 2.81517
# [31]	valid_0's multi_logloss: 2.81408
# [32]	valid_0's multi_logloss: 2.81299
# [33]	valid_0's multi_logloss: 2.81193
# [34]	valid_0's multi_logloss: 2.81085
# [35]	valid_0's multi_logloss: 2.80979
# [36]	valid_0's multi_logloss: 2.80881
# [37]	valid_0's multi_logloss: 2.80778
# [38]	valid_0's multi_logloss: 2.80681
# [39]	valid_0's multi_logloss: 2.80574
# [40]	valid_0's multi_logloss: 2.80478
# [41]	valid_0's multi_logloss: 2.80384
# [42]	valid_0's multi_logloss: 2.80288
# [43]	valid_0's multi_logloss: 2.80199
# [44]	valid_0's multi_logloss: 2.8011
# [45]	valid_0's multi_logloss: 2.80016
# [46]	valid_0's multi_logloss: 2.79925
# [47]	valid_0's multi_logloss: 2.79837
# [48]	valid_0's multi_logloss: 2.79753
# [49]	valid_0's multi_logloss: 2.79653
# [50]	valid_0's multi_logloss: 2.79561
# [51]	valid_0's multi_logloss: 2.79476
# [52]	valid_0's multi_logloss: 2.79394
# [53]	valid_0's multi_logloss: 2.79309
# [54]	valid_0's multi_logloss: 2.79218
# [55]	valid_0's multi_logloss: 2.79136
# [56]	valid_0's multi_logloss: 2.79056
# [57]	valid_0's multi_logloss: 2.78972
# [58]	valid_0's multi_logloss: 2.78887
# [59]	valid_0's multi_logloss: 2.78807
# [60]	valid_0's multi_logloss: 2.78727
# [61]	valid_0's multi_logloss: 2.78651
# [62]	valid_0's multi_logloss: 2.78569
# [63]	valid_0's multi_logloss: 2.78485
# [64]	valid_0's multi_logloss: 2.784
# [65]	valid_0's multi_logloss: 2.7832
# [66]	valid_0's multi_logloss: 2.78242
# [67]	valid_0's multi_logloss: 2.78175
# [68]	valid_0's multi_logloss: 2.78102
# [69]	valid_0's multi_logloss: 2.78028
# [70]	valid_0's multi_logloss: 2.77952
# [71]	valid_0's multi_logloss: 2.77889
# [72]	valid_0's multi_logloss: 2.77817
# [73]	valid_0's multi_logloss: 2.77745
# [74]	valid_0's multi_logloss: 2.77679
# [75]	valid_0's multi_logloss: 2.77615
# [76]	valid_0's multi_logloss: 2.7755
# [77]	valid_0's multi_logloss: 2.77484
# [78]	valid_0's multi_logloss: 2.77421
# [79]	valid_0's multi_logloss: 2.77349
# [80]	valid_0's multi_logloss: 2.77277
# [81]	valid_0's multi_logloss: 2.7721
# [82]	valid_0's multi_logloss: 2.77145
# [83]	valid_0's multi_logloss: 2.77085
# [84]	valid_0's multi_logloss: 2.77019
# [85]	valid_0's multi_logloss: 2.76961
# [86]	valid_0's multi_logloss: 2.76904
# [87]	valid_0's multi_logloss: 2.7684
# [88]	valid_0's multi_logloss: 2.76781
# [89]	valid_0's multi_logloss: 2.76718
# [90]	valid_0's multi_logloss: 2.76657
# [91]	valid_0's multi_logloss: 2.76595
# [92]	valid_0's multi_logloss: 2.76529
# [93]	valid_0's multi_logloss: 2.76473
# [94]	valid_0's multi_logloss: 2.76412
# [95]	valid_0's multi_logloss: 2.76359
# [96]	valid_0's multi_logloss: 2.76297
# [97]	valid_0's multi_logloss: 2.76239
# [98]	valid_0's multi_logloss: 2.76185
# [99]	valid_0's multi_logloss: 2.76118
# [100]	valid_0's multi_logloss: 2.76064
# [101]	valid_0's multi_logloss: 2.76008
# [102]	valid_0's multi_logloss: 2.75951
# [103]	valid_0's multi_logloss: 2.75893
# [104]	valid_0's multi_logloss: 2.75836
# [105]	valid_0's multi_logloss: 2.75782
# [106]	valid_0's multi_logloss: 2.75729
# [107]	valid_0's multi_logloss: 2.75669
# [108]	valid_0's multi_logloss: 2.75612
# [109]	valid_0's multi_logloss: 2.75563
# [110]	valid_0's multi_logloss: 2.75504
# [111]	valid_0's multi_logloss: 2.75456
# [112]	valid_0's multi_logloss: 2.75401
# [113]	valid_0's multi_logloss: 2.75346
# [114]	valid_0's multi_logloss: 2.75292
# [115]	valid_0's multi_logloss: 2.75236
# [116]	valid_0's multi_logloss: 2.75185
# [117]	valid_0's multi_logloss: 2.75132
# [118]	valid_0's multi_logloss: 2.75075
# [119]	valid_0's multi_logloss: 2.7502
# [120]	valid_0's multi_logloss: 2.74966
# [121]	valid_0's multi_logloss: 2.74918
# [122]	valid_0's multi_logloss: 2.7487
# [123]	valid_0's multi_logloss: 2.74817
# [124]	valid_0's multi_logloss: 2.74768
# [125]	valid_0's multi_logloss: 2.74727
# [126]	valid_0's multi_logloss: 2.74678
# [127]	valid_0's multi_logloss: 2.74633
# [128]	valid_0's multi_logloss: 2.74584
# [129]	valid_0's multi_logloss: 2.74532
# [130]	valid_0's multi_logloss: 2.74488
# [131]	valid_0's multi_logloss: 2.74442
# [132]	valid_0's multi_logloss: 2.74383
# [133]	valid_0's multi_logloss: 2.7434
# [134]	valid_0's multi_logloss: 2.743
# [135]	valid_0's multi_logloss: 2.74256
# [136]	valid_0's multi_logloss: 2.74211
# [137]	valid_0's multi_logloss: 2.74169
# [138]	valid_0's multi_logloss: 2.74128
# [139]	valid_0's multi_logloss: 2.74084
# [140]	valid_0's multi_logloss: 2.74041
# [141]	valid_0's multi_logloss: 2.73998
# [142]	valid_0's multi_logloss: 2.7395
# [143]	valid_0's multi_logloss: 2.73909
# [144]	valid_0's multi_logloss: 2.73865
# [145]	valid_0's multi_logloss: 2.73826
# [146]	valid_0's multi_logloss: 2.73784
# [147]	valid_0's multi_logloss: 2.73745
# [148]	valid_0's multi_logloss: 2.7371
# [149]	valid_0's multi_logloss: 2.7367
# [150]	valid_0's multi_logloss: 2.73635
# [151]	valid_0's multi_logloss: 2.73599
# [152]	valid_0's multi_logloss: 2.73561
# [153]	valid_0's multi_logloss: 2.73523
# [154]	valid_0's multi_logloss: 2.73486
# [155]	valid_0's multi_logloss: 2.73441
# [156]	valid_0's multi_logloss: 2.73404
# [157]	valid_0's multi_logloss: 2.73367
# [158]	valid_0's multi_logloss: 2.7333
# [159]	valid_0's multi_logloss: 2.73297
# [160]	valid_0's multi_logloss: 2.7326
# [161]	valid_0's multi_logloss: 2.73221
# [162]	valid_0's multi_logloss: 2.73189
# [163]	valid_0's multi_logloss: 2.73155
# [164]	valid_0's multi_logloss: 2.73116
# [165]	valid_0's multi_logloss: 2.73088
# [166]	valid_0's multi_logloss: 2.73053
# [167]	valid_0's multi_logloss: 2.73017
# [168]	valid_0's multi_logloss: 2.72987
# [169]	valid_0's multi_logloss: 2.72955
# [170]	valid_0's multi_logloss: 2.72924
# [171]	valid_0's multi_logloss: 2.72883
# [172]	valid_0's multi_logloss: 2.72852
# [173]	valid_0's multi_logloss: 2.72814
# [174]	valid_0's multi_logloss: 2.72788
# [175]	valid_0's multi_logloss: 2.72756
# [176]	valid_0's multi_logloss: 2.72728
# [177]	valid_0's multi_logloss: 2.72697
# [178]	valid_0's multi_logloss: 2.72663
# [179]	valid_0's multi_logloss: 2.7263
# [180]	valid_0's multi_logloss: 2.72598
# [181]	valid_0's multi_logloss: 2.72568
# [182]	valid_0's multi_logloss: 2.7254
# [183]	valid_0's multi_logloss: 2.72509
# [184]	valid_0's multi_logloss: 2.72479
# [185]	valid_0's multi_logloss: 2.7245
# [186]	valid_0's multi_logloss: 2.7242
# [187]	valid_0's multi_logloss: 2.72392
# [188]	valid_0's multi_logloss: 2.72362
# [189]	valid_0's multi_logloss: 2.72335
# [190]	valid_0's multi_logloss: 2.72308
# [191]	valid_0's multi_logloss: 2.72277
# [192]	valid_0's multi_logloss: 2.72248
# [193]	valid_0's multi_logloss: 2.72221
# [194]	valid_0's multi_logloss: 2.72191
# [195]	valid_0's multi_logloss: 2.72168
# [196]	valid_0's multi_logloss: 2.72138
# [197]	valid_0's multi_logloss: 2.7211
# [198]	valid_0's multi_logloss: 2.72087
# [199]	valid_0's multi_logloss: 2.72062
# [200]	valid_0's multi_logloss: 2.72034
# [201]	valid_0's multi_logloss: 2.72008
# [202]	valid_0's multi_logloss: 2.7198
# [203]	valid_0's multi_logloss: 2.71955
# [204]	valid_0's multi_logloss: 2.71929
# [205]	valid_0's multi_logloss: 2.71905
# [206]	valid_0's multi_logloss: 2.71877
# [207]	valid_0's multi_logloss: 2.71849
# [208]	valid_0's multi_logloss: 2.71816
# [209]	valid_0's multi_logloss: 2.71796
# [210]	valid_0's multi_logloss: 2.71773
# [211]	valid_0's multi_logloss: 2.71749
# [212]	valid_0's multi_logloss: 2.71722
# [213]	valid_0's multi_logloss: 2.71695
# [214]	valid_0's multi_logloss: 2.71666
# [215]	valid_0's multi_logloss: 2.71643
# [216]	valid_0's multi_logloss: 2.71621
# [217]	valid_0's multi_logloss: 2.71597
# [218]	valid_0's multi_logloss: 2.71574
# [219]	valid_0's multi_logloss: 2.7155
# [220]	valid_0's multi_logloss: 2.71528
# [221]	valid_0's multi_logloss: 2.71501
# [222]	valid_0's multi_logloss: 2.71478
# [223]	valid_0's multi_logloss: 2.71452
# [224]	valid_0's multi_logloss: 2.71437
# [225]	valid_0's multi_logloss: 2.71416
# [226]	valid_0's multi_logloss: 2.71389
# ...
# [221]	valid_0's multi_logloss: 2.90731
# [222]	valid_0's multi_logloss: 2.90723
# [223]	valid_0's multi_logloss: 2.90709
# [224]	valid_0's multi_logloss: 2.90693
# [225]	valid_0's multi_logloss: 2.90682
# [226]	valid_0's multi_logloss: 2.90672
# [227]	valid_0's multi_logloss: 2.90665
# [228]	valid_0's multi_logloss: 2.90654
# [229]	valid_0's multi_logloss: 2.90645
# [230]	valid_0's multi_logloss: 2.9064
# [231]	valid_0's multi_logloss: 2.90628
# [232]	valid_0's multi_logloss: 2.90623
# [233]	valid_0's multi_logloss: 2.9061
# [234]	valid_0's multi_logloss: 2.90601
# [235]	valid_0's multi_logloss: 2.90592
# [236]	valid_0's multi_logloss: 2.90583
# [237]	valid_0's multi_logloss: 2.90579
# [238]	valid_0's multi_logloss: 2.90569
# [239]	valid_0's multi_logloss: 2.90563
# [240]	valid_0's multi_logloss: 2.90553
# [241]	valid_0's multi_logloss: 2.90548
# [242]	valid_0's multi_logloss: 2.90541
# [243]	valid_0's multi_logloss: 2.90538
# [244]	valid_0's multi_logloss: 2.90529
# [245]	valid_0's multi_logloss: 2.90526
# [246]	valid_0's multi_logloss: 2.90514
# [247]	valid_0's multi_logloss: 2.90512
# [248]	valid_0's multi_logloss: 2.90505
# [249]	valid_0's multi_logloss: 2.905
# [250]	valid_0's multi_logloss: 2.90496
# [251]	valid_0's multi_logloss: 2.90494
# [252]	valid_0's multi_logloss: 2.90487
# [253]	valid_0's multi_logloss: 2.90484
# [254]	valid_0's multi_logloss: 2.90481
# [255]	valid_0's multi_logloss: 2.90475
# [256]	valid_0's multi_logloss: 2.90472
# [257]	valid_0's multi_logloss: 2.90469
# [258]	valid_0's multi_logloss: 2.90464
# [259]	valid_0's multi_logloss: 2.90467
# [260]	valid_0's multi_logloss: 2.90461
# [261]	valid_0's multi_logloss: 2.90462
# [262]	valid_0's multi_logloss: 2.90456
# [263]	valid_0's multi_logloss: 2.9045
# [264]	valid_0's multi_logloss: 2.90449
# [265]	valid_0's multi_logloss: 2.90443
# [266]	valid_0's multi_logloss: 2.90434
# [267]	valid_0's multi_logloss: 2.90435
# [268]	valid_0's multi_logloss: 2.9043
# [269]	valid_0's multi_logloss: 2.9043
# [270]	valid_0's multi_logloss: 2.90422
# [271]	valid_0's multi_logloss: 2.90415
# [272]	valid_0's multi_logloss: 2.9041
# [273]	valid_0's multi_logloss: 2.90411
# [274]	valid_0's multi_logloss: 2.90401
# [275]	valid_0's multi_logloss: 2.90398
# [276]	valid_0's multi_logloss: 2.90396
# [277]	valid_0's multi_logloss: 2.90392
# [278]	valid_0's multi_logloss: 2.90388
# [279]	valid_0's multi_logloss: 2.90388
# [280]	valid_0's multi_logloss: 2.90387
# [281]	valid_0's multi_logloss: 2.90382
# [282]	valid_0's multi_logloss: 2.90378
# [283]	valid_0's multi_logloss: 2.90377
# [284]	valid_0's multi_logloss: 2.90375
# [285]	valid_0's multi_logloss: 2.90374
# [286]	valid_0's multi_logloss: 2.90372
# [287]	valid_0's multi_logloss: 2.90365
# [288]	valid_0's multi_logloss: 2.90358
# [289]	valid_0's multi_logloss: 2.90359
# [290]	valid_0's multi_logloss: 2.90364
# [291]	valid_0's multi_logloss: 2.9036
# [292]	valid_0's multi_logloss: 2.90359
# [293]	valid_0's multi_logloss: 2.9036
# [294]	valid_0's multi_logloss: 2.90362
# [295]	valid_0's multi_logloss: 2.90358
# [296]	valid_0's multi_logloss: 2.90351
# [297]	valid_0's multi_logloss: 2.90347
# [298]	valid_0's multi_logloss: 2.90347
# [299]	valid_0's multi_logloss: 2.90349
# [300]	valid_0's multi_logloss: 2.90343
# [301]	valid_0's multi_logloss: 2.90343
# [302]	valid_0's multi_logloss: 2.90343
# [303]	valid_0's multi_logloss: 2.90342
# [304]	valid_0's multi_logloss: 2.90343
# [305]	valid_0's multi_logloss: 2.90342
# [306]	valid_0's multi_logloss: 2.90338
# [307]	valid_0's multi_logloss: 2.90342
# [308]	valid_0's multi_logloss: 2.90341
# [309]	valid_0's multi_logloss: 2.90338
# [310]	valid_0's multi_logloss: 2.90338
# [311]	valid_0's multi_logloss: 2.90338
# [312]	valid_0's multi_logloss: 2.90342
# [313]	valid_0's multi_logloss: 2.90341
# [314]	valid_0's multi_logloss: 2.90336
# [315]	valid_0's multi_logloss: 2.90338
# [316]	valid_0's multi_logloss: 2.90339
# [317]	valid_0's multi_logloss: 2.90334
# [318]	valid_0's multi_logloss: 2.90333
# [319]	valid_0's multi_logloss: 2.9033
# [320]	valid_0's multi_logloss: 2.90328
# [321]	valid_0's multi_logloss: 2.90328
# [322]	valid_0's multi_logloss: 2.90332
# [323]	valid_0's multi_logloss: 2.90332
# [324]	valid_0's multi_logloss: 2.90333
# [325]	valid_0's multi_logloss: 2.90331
# [326]	valid_0's multi_logloss: 2.90332
# [327]	valid_0's multi_logloss: 2.90335
# [328]	valid_0's multi_logloss: 2.90335
# [329]	valid_0's multi_logloss: 2.90331
# [330]	valid_0's multi_logloss: 2.90332
# Early stopping, best iteration is:
# [320]	valid_0's multi_logloss: 2.90328
# 0.014271675194074315
# [1]	valid_0's multi_logloss: 2.92636
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92518
# [3]	valid_0's multi_logloss: 2.92399
# [4]	valid_0's multi_logloss: 2.92298
# [5]	valid_0's multi_logloss: 2.92198
# [6]	valid_0's multi_logloss: 2.92111
# [7]	valid_0's multi_logloss: 2.92023
# [8]	valid_0's multi_logloss: 2.91951
# [9]	valid_0's multi_logloss: 2.91849
# [10]	valid_0's multi_logloss: 2.91772
# [11]	valid_0's multi_logloss: 2.91696
# [12]	valid_0's multi_logloss: 2.91618
# [13]	valid_0's multi_logloss: 2.91536
# [14]	valid_0's multi_logloss: 2.9146
# [15]	valid_0's multi_logloss: 2.91391
# [16]	valid_0's multi_logloss: 2.9132
# [17]	valid_0's multi_logloss: 2.91245
# [18]	valid_0's multi_logloss: 2.91174
# [19]	valid_0's multi_logloss: 2.91102
# [20]	valid_0's multi_logloss: 2.91032
# [21]	valid_0's multi_logloss: 2.90964
# [22]	valid_0's multi_logloss: 2.909
# [23]	valid_0's multi_logloss: 2.90836
# [24]	valid_0's multi_logloss: 2.90769
# [25]	valid_0's multi_logloss: 2.90707
# [26]	valid_0's multi_logloss: 2.90641
# [27]	valid_0's multi_logloss: 2.9059
# [28]	valid_0's multi_logloss: 2.90525
# [29]	valid_0's multi_logloss: 2.90463
# [30]	valid_0's multi_logloss: 2.90404
# [31]	valid_0's multi_logloss: 2.90344
# [32]	valid_0's multi_logloss: 2.90289
# [33]	valid_0's multi_logloss: 2.90222
# [34]	valid_0's multi_logloss: 2.90167
# [35]	valid_0's multi_logloss: 2.90114
# [36]	valid_0's multi_logloss: 2.90059
# [37]	valid_0's multi_logloss: 2.90002
# [38]	valid_0's multi_logloss: 2.89954
# [39]	valid_0's multi_logloss: 2.89889
# [40]	valid_0's multi_logloss: 2.89834
# [41]	valid_0's multi_logloss: 2.89786
# [42]	valid_0's multi_logloss: 2.89738
# [43]	valid_0's multi_logloss: 2.89688
# [44]	valid_0's multi_logloss: 2.89638
# [45]	valid_0's multi_logloss: 2.89571
# [46]	valid_0's multi_logloss: 2.89521
# [47]	valid_0's multi_logloss: 2.89465
# [48]	valid_0's multi_logloss: 2.89422
# [49]	valid_0's multi_logloss: 2.89367
# [50]	valid_0's multi_logloss: 2.89319
# [51]	valid_0's multi_logloss: 2.89276
# [52]	valid_0's multi_logloss: 2.89228
# [53]	valid_0's multi_logloss: 2.89183
# [54]	valid_0's multi_logloss: 2.89136
# [55]	valid_0's multi_logloss: 2.89095
# [56]	valid_0's multi_logloss: 2.89054
# [57]	valid_0's multi_logloss: 2.89014
# [58]	valid_0's multi_logloss: 2.8897
# [59]	valid_0's multi_logloss: 2.88927
# [60]	valid_0's multi_logloss: 2.88878
# [61]	valid_0's multi_logloss: 2.88839
# [62]	valid_0's multi_logloss: 2.88802
# [63]	valid_0's multi_logloss: 2.88772
# [64]	valid_0's multi_logloss: 2.88739
# [65]	valid_0's multi_logloss: 2.887
# [66]	valid_0's multi_logloss: 2.88671
# [67]	valid_0's multi_logloss: 2.88628
# [68]	valid_0's multi_logloss: 2.88589
# [69]	valid_0's multi_logloss: 2.88556
# [70]	valid_0's multi_logloss: 2.88514
# [71]	valid_0's multi_logloss: 2.88487
# [72]	valid_0's multi_logloss: 2.88456
# [73]	valid_0's multi_logloss: 2.88424
# [74]	valid_0's multi_logloss: 2.8839
# [75]	valid_0's multi_logloss: 2.8836
# [76]	valid_0's multi_logloss: 2.88327
# [77]	valid_0's multi_logloss: 2.88293
# [78]	valid_0's multi_logloss: 2.88261
# [79]	valid_0's multi_logloss: 2.88232
# [80]	valid_0's multi_logloss: 2.88202
# [81]	valid_0's multi_logloss: 2.88178
# [82]	valid_0's multi_logloss: 2.88154
# [83]	valid_0's multi_logloss: 2.88117
# [84]	valid_0's multi_logloss: 2.8809
# [85]	valid_0's multi_logloss: 2.88064
# [86]	valid_0's multi_logloss: 2.88035
# [87]	valid_0's multi_logloss: 2.88003
# [88]	valid_0's multi_logloss: 2.87978
# [89]	valid_0's multi_logloss: 2.87957
# [90]	valid_0's multi_logloss: 2.87927
# [91]	valid_0's multi_logloss: 2.87894
# [92]	valid_0's multi_logloss: 2.87869
# [93]	valid_0's multi_logloss: 2.87847
# [94]	valid_0's multi_logloss: 2.87816
# [95]	valid_0's multi_logloss: 2.87789
# [96]	valid_0's multi_logloss: 2.87763
# [97]	valid_0's multi_logloss: 2.8774
# [98]	valid_0's multi_logloss: 2.8771
# [99]	valid_0's multi_logloss: 2.87683
# [100]	valid_0's multi_logloss: 2.87656
# [101]	valid_0's multi_logloss: 2.87636
# [102]	valid_0's multi_logloss: 2.87613
# [103]	valid_0's multi_logloss: 2.87588
# [104]	valid_0's multi_logloss: 2.87574
# [105]	valid_0's multi_logloss: 2.87544
# [106]	valid_0's multi_logloss: 2.87518
# [107]	valid_0's multi_logloss: 2.87494
# [108]	valid_0's multi_logloss: 2.87473
# [109]	valid_0's multi_logloss: 2.8745
# [110]	valid_0's multi_logloss: 2.87421
# [111]	valid_0's multi_logloss: 2.87404
# [112]	valid_0's multi_logloss: 2.87377
# [113]	valid_0's multi_logloss: 2.87354
# [114]	valid_0's multi_logloss: 2.8733
# [115]	valid_0's multi_logloss: 2.8731
# [116]	valid_0's multi_logloss: 2.87286
# [117]	valid_0's multi_logloss: 2.87267
# [118]	valid_0's multi_logloss: 2.87249
# [119]	valid_0's multi_logloss: 2.87224
# [120]	valid_0's multi_logloss: 2.87207
# [121]	valid_0's multi_logloss: 2.87184
# [122]	valid_0's multi_logloss: 2.87163
# [123]	valid_0's multi_logloss: 2.87143
# [124]	valid_0's multi_logloss: 2.87122
# [125]	valid_0's multi_logloss: 2.87096
# [126]	valid_0's multi_logloss: 2.87084
# [127]	valid_0's multi_logloss: 2.87057
# [128]	valid_0's multi_logloss: 2.87039
# [129]	valid_0's multi_logloss: 2.8702
# [130]	valid_0's multi_logloss: 2.86992
# [131]	valid_0's multi_logloss: 2.86968
# [132]	valid_0's multi_logloss: 2.8695
# [133]	valid_0's multi_logloss: 2.8693
# [134]	valid_0's multi_logloss: 2.86909
# [135]	valid_0's multi_logloss: 2.86886
# [136]	valid_0's multi_logloss: 2.86866
# [137]	valid_0's multi_logloss: 2.86848
# [138]	valid_0's multi_logloss: 2.86826
# [139]	valid_0's multi_logloss: 2.86799
# [140]	valid_0's multi_logloss: 2.86778
# [141]	valid_0's multi_logloss: 2.86764
# [142]	valid_0's multi_logloss: 2.86737
# [143]	valid_0's multi_logloss: 2.86715
# [144]	valid_0's multi_logloss: 2.867
# [145]	valid_0's multi_logloss: 2.86675
# [146]	valid_0's multi_logloss: 2.86655
# [147]	valid_0's multi_logloss: 2.86626
# [148]	valid_0's multi_logloss: 2.86604
# [149]	valid_0's multi_logloss: 2.86583
# [150]	valid_0's multi_logloss: 2.86569
# [151]	valid_0's multi_logloss: 2.86551
# [152]	valid_0's multi_logloss: 2.86535
# [153]	valid_0's multi_logloss: 2.86509
# [154]	valid_0's multi_logloss: 2.86487
# [155]	valid_0's multi_logloss: 2.8646
# [156]	valid_0's multi_logloss: 2.86434
# [157]	valid_0's multi_logloss: 2.86416
# [158]	valid_0's multi_logloss: 2.86393
# [159]	valid_0's multi_logloss: 2.86376
# [160]	valid_0's multi_logloss: 2.86358
# [161]	valid_0's multi_logloss: 2.86339
# [162]	valid_0's multi_logloss: 2.86316
# [163]	valid_0's multi_logloss: 2.86292
# [164]	valid_0's multi_logloss: 2.86277
# [165]	valid_0's multi_logloss: 2.86262
# [166]	valid_0's multi_logloss: 2.86246
# [167]	valid_0's multi_logloss: 2.86224
# [168]	valid_0's multi_logloss: 2.86207
# [169]	valid_0's multi_logloss: 2.8619
# [170]	valid_0's multi_logloss: 2.8618
# [171]	valid_0's multi_logloss: 2.86155
# [172]	valid_0's multi_logloss: 2.86143
# [173]	valid_0's multi_logloss: 2.86127
# [174]	valid_0's multi_logloss: 2.86113
# [175]	valid_0's multi_logloss: 2.86091
# [176]	valid_0's multi_logloss: 2.86076
# [177]	valid_0's multi_logloss: 2.86065
# [178]	valid_0's multi_logloss: 2.86046
# [179]	valid_0's multi_logloss: 2.86027
# [180]	valid_0's multi_logloss: 2.86022
# [181]	valid_0's multi_logloss: 2.86008
# [182]	valid_0's multi_logloss: 2.85991
# [183]	valid_0's multi_logloss: 2.85975
# [184]	valid_0's multi_logloss: 2.85961
# [185]	valid_0's multi_logloss: 2.85952
# [186]	valid_0's multi_logloss: 2.85938
# [187]	valid_0's multi_logloss: 2.85928
# [188]	valid_0's multi_logloss: 2.85912
# [189]	valid_0's multi_logloss: 2.85903
# [190]	valid_0's multi_logloss: 2.8589
# [191]	valid_0's multi_logloss: 2.85878
# [192]	valid_0's multi_logloss: 2.85863
# [193]	valid_0's multi_logloss: 2.85858
# [194]	valid_0's multi_logloss: 2.85839
# [195]	valid_0's multi_logloss: 2.85828
# [196]	valid_0's multi_logloss: 2.8582
# [197]	valid_0's multi_logloss: 2.85803
# [198]	valid_0's multi_logloss: 2.85793
# [199]	valid_0's multi_logloss: 2.8578
# [200]	valid_0's multi_logloss: 2.85769
# [201]	valid_0's multi_logloss: 2.85757
# [202]	valid_0's multi_logloss: 2.85748
# [203]	valid_0's multi_logloss: 2.85733
# [204]	valid_0's multi_logloss: 2.85724
# [205]	valid_0's multi_logloss: 2.85714
# [206]	valid_0's multi_logloss: 2.85697
# [207]	valid_0's multi_logloss: 2.85691
# [208]	valid_0's multi_logloss: 2.85676
# [209]	valid_0's multi_logloss: 2.85666
# [210]	valid_0's multi_logloss: 2.85651
# [211]	valid_0's multi_logloss: 2.85648
# [212]	valid_0's multi_logloss: 2.85633
# [213]	valid_0's multi_logloss: 2.85629
# [214]	valid_0's multi_logloss: 2.85619
# [215]	valid_0's multi_logloss: 2.85607
# [216]	valid_0's multi_logloss: 2.85599
# [217]	valid_0's multi_logloss: 2.85589
# [218]	valid_0's multi_logloss: 2.85582
# [219]	valid_0's multi_logloss: 2.85571
# [220]	valid_0's multi_logloss: 2.85564
# [221]	valid_0's multi_logloss: 2.85557
# [222]	valid_0's multi_logloss: 2.85555
# [223]	valid_0's multi_logloss: 2.85544
# [224]	valid_0's multi_logloss: 2.8554
# [225]	valid_0's multi_logloss: 2.85533
# [226]	valid_0's multi_logloss: 2.85526
# [227]	valid_0's multi_logloss: 2.85516
# [228]	valid_0's multi_logloss: 2.85509
# [229]	valid_0's multi_logloss: 2.85499
# [230]	valid_0's multi_logloss: 2.85497
# [231]	valid_0's multi_logloss: 2.85489
# [232]	valid_0's multi_logloss: 2.8548
# [233]	valid_0's multi_logloss: 2.85474
# [234]	valid_0's multi_logloss: 2.85471
# [235]	valid_0's multi_logloss: 2.85465
# [236]	valid_0's multi_logloss: 2.85464
# [237]	valid_0's multi_logloss: 2.8546
# [238]	valid_0's multi_logloss: 2.85455
# [239]	valid_0's multi_logloss: 2.85446
# [240]	valid_0's multi_logloss: 2.85439
# [241]	valid_0's multi_logloss: 2.85433
# [242]	valid_0's multi_logloss: 2.85429
# [243]	valid_0's multi_logloss: 2.85425
# [244]	valid_0's multi_logloss: 2.85421
# [245]	valid_0's multi_logloss: 2.85415
# [246]	valid_0's multi_logloss: 2.85412
# [247]	valid_0's multi_logloss: 2.85409
# [248]	valid_0's multi_logloss: 2.85394
# [249]	valid_0's multi_logloss: 2.85383
# [250]	valid_0's multi_logloss: 2.85381
# [251]	valid_0's multi_logloss: 2.8538
# [252]	valid_0's multi_logloss: 2.85373
# [253]	valid_0's multi_logloss: 2.85367
# [254]	valid_0's multi_logloss: 2.85359
# [255]	valid_0's multi_logloss: 2.85351
# [256]	valid_0's multi_logloss: 2.85348
# [257]	valid_0's multi_logloss: 2.8534
# [258]	valid_0's multi_logloss: 2.85337
# [259]	valid_0's multi_logloss: 2.85333
# [260]	valid_0's multi_logloss: 2.85336
# [261]	valid_0's multi_logloss: 2.85327
# [262]	valid_0's multi_logloss: 2.85319
# [263]	valid_0's multi_logloss: 2.85319
# [264]	valid_0's multi_logloss: 2.85321
# [265]	valid_0's multi_logloss: 2.85322
# [266]	valid_0's multi_logloss: 2.85316
# [267]	valid_0's multi_logloss: 2.85309
# [268]	valid_0's multi_logloss: 2.85311
# [269]	valid_0's multi_logloss: 2.85306
# [270]	valid_0's multi_logloss: 2.85304
# [271]	valid_0's multi_logloss: 2.85302
# [272]	valid_0's multi_logloss: 2.85301
# [273]	valid_0's multi_logloss: 2.85298
# [274]	valid_0's multi_logloss: 2.85299
# [275]	valid_0's multi_logloss: 2.85305
# [276]	valid_0's multi_logloss: 2.85304
# [277]	valid_0's multi_logloss: 2.85297
# [278]	valid_0's multi_logloss: 2.85293
# [279]	valid_0's multi_logloss: 2.85293
# [280]	valid_0's multi_logloss: 2.85291
# [281]	valid_0's multi_logloss: 2.85291
# [282]	valid_0's multi_logloss: 2.8529
# [283]	valid_0's multi_logloss: 2.85287
# [284]	valid_0's multi_logloss: 2.85288
# [285]	valid_0's multi_logloss: 2.85289
# [286]	valid_0's multi_logloss: 2.8529
# [287]	valid_0's multi_logloss: 2.8529
# [288]	valid_0's multi_logloss: 2.85293
# [289]	valid_0's multi_logloss: 2.85294
# [290]	valid_0's multi_logloss: 2.85294
# [291]	valid_0's multi_logloss: 2.85292
# [292]	valid_0's multi_logloss: 2.85293
# [293]	valid_0's multi_logloss: 2.85294
# Early stopping, best iteration is:
# [283]	valid_0's multi_logloss: 2.85287
# 0.014067420597188853
# crps list: [0.012425238984138066, 0.012197367454729107, 0.011851869178585427, 0.014271675194074315, 0.014067420597188853]
# average crps: 0.012962714281743153

# %% [markdown]
# - lgbm_params = {"max_depth" : -1, "boosting": 'gbdt', "num_class": 199, "num_leaves" : 13, "learning_rate" : 0.01,
# - crps list: [0.0124807291491228, 0.01229469803667161, 0.011914769756526881, 0.014301423941255343, 0.014099192560802385]
# - average crps: 0.013018162688875805
# -
# - lgbm_params = {"max_depth" : 5, "boosting": 'gbdt', "num_class": 199, "num_leaves" : 13, "learning_rate" : 0.01,
# - crps list: [0.012425238984138066, 0.012197367454729107, 0.011851869178585427, 0.014271675194074315, 0.014067420597188853]
# - average crps: 0.012962714281743153
# -
# - lgbm_params = {"max_depth" : 6, "boosting": 'gbdt', "num_class": 199, "num_leaves" : 13, "learning_rate" : 0.01,
# - crps list: [0.012465517593583183, 0.01223429539592954, 0.011873068597941796, 0.014290295699311364, 0.01407310568487725]
# - average crps: 0.012987256594328625 improve
# -
# - lgbm_params = {"max_depth" : 7, "boosting": 'gbdt', "num_class": 199, "num_leaves" : 13, "learning_rate" : 0.01,
# - crps list: [0.012468265996343599, 0.012288989039125241, 0.011896904370287889, 0.01430189792280917, 0.01408582103847273]
# - average crps: 0.013008375673407726 deteriorate
# -
# - lgbm_params = {"max_depth" : 8, "boosting": 'gbdt', "num_class": 199, "num_leaves" : 13, "learning_rate" : 0.01,
# - crps list: [0.012470511605153885, 0.012296108963923903, 0.011906301553807855, 0.014299981099797857, 0.014102823067334219]
# - average crps: 0.013015145258003544

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'PlayerWeight_FB', 'time_end', 'Grass', 'DefendersInTheBox_vs_Distance',
#        'DisToQB', 'runner_height', 'DefenseAveX', 'DefenseAveY',
#        'DefenseAveMomentum', 'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos',
#        '1stDefender_AttackAngle', 'RusherVoronoi', 'FirstDefenderVoronoi'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                           Grass     523     306     444     231     101
# 1                            Team     480     801     416     317     237
# 2                OffenseFormation     837     916     878     595     432
# 3                            Down     993    1501    1187     512     479
# 4                DefensePersonnel    2198    2474    2060    1222    1721
# 5                          Season    1853    1765    2791    1671    1701
# 6               DefendersInTheBox    2722    1844    2320    2038    1711
# 7                   runner_height    2462    3687    3388    2317    2069
# 8                 PlayerWeight_FB    2291    3332    4096    2142    2083
# 9                            Week    4373    3989    4003    1928    2215
# 10                    StadiumType    3447    4511    4135    1792    2693
# 11            HomeScoreBeforePlay    3732    4596    3500    2237    2985
# 12                    GameWeather    3466    4383    4406    2911    1903
# 13               OffensePersonnel    3400    3751    4256    3556    2735
# 14                      WindSpeed    4605    5200    3849    2000    3383
# 15                       Location    4809    5515    4090    3378    2480
# 16                  WindDirection    4668    5949    4639    2896    2498
# 17         VisitorScoreBeforePlay    4737    5928    4395    3826    3233
# 18                  RusherVoronoi    5136    4696    5768    4448    3148
# 19                   PlayerWeight    6676    6195    4519    2863    3328
# 20                        Stadium    5726    5285    5351    4317    3330
# 21                            Dis    5979    5565    5044    4109    3921
# 22                       Distance    7891    7386    8076    2618    1230
# 23                   JerseyNumber    6469    7448    5944    3872    3909
# 24                    Temperature    6667    7433    6180    4280    4002
# 25                    OffenseStdX    8096    7662    6000    4785    3907
# 26                              S    7596    7036    6000    4547    5346
# 27                       Humidity    7022    7953    7399    3671    5210
# 28                              X    7759    7286    7575    4658    4121
# 29                    Orientation    7734    8160    7023    4330    4217
# 30                    OffenseStdY    6836    8462    7219    4542    4585
# 31             OffenseAveMomentum    8039    8662    7235    3836    4225
# 32  DefendersInTheBox_vs_Distance   10096    9224    4558    5164    3043
# 33                    DefenseStdY    8667    8673    6519    4403    4041
# 34                    DefenseAveX    6410    8806    8595    6427    4743
# 35         RunnerToDefenseCentoid    7858    8430    8407    5797    4706
# 36         RunnerToOffenseCentoid    9573    9656    8275    5314    4882
# 37              PlayerCollegeName    8915    8667    8619    6734    5394
# 38                    DefenseAveY    9137    8809    9833    5804    4754
# 39                              Y    9972   10619    8825    4002    4930
# 40                          NflId    8420    9033   10923    5525    4722
# 41                       Momentum    8147   11171    9034    4865    6293
# 42                            Dir    9286    9646   10165    5661    5083
# 43             DefenseAveMomentum    9291   10241    9372    6241    4717
# 44                 OffenseSpreadX    8727   12353    7950    5792    5620
# 45         OffenseStdMomentum_cos    9064   10703    8699    6245    5897
# 46           FirstDefenderVoronoi    8691   11314   10096    5936    5472
# 47                    DefenseStdX    8988   12141    9100    6420    5186
# 48         OffenseAveMomentum_cos   10551   10210   10927    5106    5363
# 49             DefenseStdMomentum    9178   10306   11562    6164    4967
# 50                            age   12071   10689    8860    6036    4619
# 51                 DefenseSpreadX   12251   11796    9392    6124    5638
# 52         DefenseStdMomentum_cos   10922   10773   10528    7212    5923
# 53                  MinTackleTime   10564   13569   10753    5480    6667
# 54                        DisToQB   11372   11972   11491    6089    6360
# 55                        Dir_cos   12264   12461   11427    6335    6336
# 56             OffenseStdMomentum   10484   12937   10059    8620    7389
# 57                       time_end   10576   14343    9604    8107    7133
# 58                       YardLine   12746   13786   11904    8216    7572
# 59              RunnerToScrimmage   12357   14572   11561    9092    7001
# 60       1stOffenser_Momentum_cos   13943   13785   11821    7978    7496
# 61        1stDefender_AttackAngle   13458   15662   10933    7981    7635
# 62         DefenseAveMomentum_cos   16153   15903   13385    7405    7151
# 63                   Momentum_cos   13606   15109   15849    9264    9679
# 64       1stDefender_Momentum_cos   14000   18833   14576   10076    7002
# 65                              A   27016   28267   23251   21206   22691
#
#     Average          Std        Cv
# 0     321.0   150.105296  0.467618
# 1     450.2   194.069472  0.431074
# 2     731.6   187.064267  0.255692
# 3     934.4   393.468474  0.421092
# 4    1935.0   431.156584  0.222820
# 5    1956.2   422.034311  0.215742
# 6    2127.0   361.203544  0.169818
# 7    2784.6   634.542544  0.227876
# 8    2788.8   796.008392  0.285430
# 9    3301.6  1017.826626  0.308283
# 10   3315.6   982.512209  0.296330
# 11   3410.0   784.210941  0.229974
# 12   3413.8   944.654307  0.276716
# 13   3539.6   494.986303  0.139842
# 14   3807.4  1097.637572  0.288291
# 15   4054.4  1062.101050  0.261963
# 16   4130.0  1268.342698  0.307105
# 17   4423.8   909.605497  0.205616
# 18   4639.2   869.995494  0.187531
# 19   4716.2  1511.820280  0.320559
# 20   4801.8   870.686488  0.181325
# 21   4923.6   801.066689  0.162699
# 22   5440.2  2913.094465  0.535476
# 23   5528.4  1421.860274  0.257192
# 24   5712.4  1346.670947  0.235745
# 25   6090.0  1610.703821  0.264483
# 26   6105.0  1104.926423  0.180987
# 27   6251.0  1584.249349  0.253439
# 28   6279.8  1560.042743  0.248422
# 29   6292.8  1688.680834  0.268351
# 30   6328.8  1538.424051  0.243083
# 31   6399.4  1990.221556  0.311001
# 32   6417.0  2750.420186  0.428615
# 33   6460.6  1992.712082  0.308441
# 34   6996.2  1521.582518  0.217487
# 35   7039.6  1514.101529  0.215083
# 36   7540.0  2057.707948  0.272906
# 37   7665.8  1378.464276  0.179820
# 38   7667.4  2005.639908  0.261580
# 39   7669.6  2694.128920  0.351274
# 40   7724.6  2292.557576  0.296787
# 41   7902.0  2183.577798  0.276332
# 42   7968.2  2145.930605  0.269312
# 43   7972.4  2118.466766  0.265725
# 44   8088.4  2448.682470  0.302740
# 45   8121.6  1808.624184  0.222693
# 46   8301.8  2282.487976  0.274939
# 47   8367.0  2411.454996  0.288210
# 48   8431.4  2621.354810  0.310904
# 49   8435.4  2490.593632  0.295255
# 50   8455.0  2785.558974  0.329457
# 51   9040.2  2760.674584  0.305378
# 52   9071.6  2088.618548  0.230237
# 53   9406.6  2946.236148  0.313209
# 54   9456.8  2648.185749  0.280030
# 55   9764.6  2821.297616  0.288931
# 56   9897.8  1872.602617  0.189194
# 57   9952.6  2495.682079  0.250757
# 58  10844.8  2490.338644  0.229634
# 59  10916.6  2627.281530  0.240668
# 60  11004.6  2774.956187  0.252163
# 61  11133.8  3102.533507  0.278659
# 62  11999.4  3975.572090  0.331314
# 63  12701.4  2737.621055  0.215537
# 64  12897.4  4049.217485  0.313956
# 65  24486.2  2690.818121  0.109891

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test, num_iteration = model.best_iteration)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

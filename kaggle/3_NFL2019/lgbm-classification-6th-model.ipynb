# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf', 'Quarter']
top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]
    
    #df["Jersey_cat"] = df["JerseyNumber"].apply(lambda x: 0 if x>=1 and x <=9 else #: quarterbacks, kickers, and punters
    #                                            (1 if x>=10 and x <= 19 else
    #                                            (2 if x>=20 and x <= 39 else
    #                                            (3 if x>=40 and x <= 49 else
    #                                            (4 if x>=50 and x <= 59 else
    #                                            (5 if x>=60 and x <= 79 else
    #                                            (6 if x>=80 and x <= 89 else
    #                                            (7 if x>=90 and x <= 99 else 8))))))))

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    #df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]
    
    df["AttackAngle"] =  np.arctan((df["Y"] - df["RushY"]) / (df["X"] - df["RushX"])) * 180 / np.pi

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    if "FB" in list(df.Position.unique()): # details of offensive full-back
        df_fb = df[df.Position == "FB"].copy()
        tmp = df_fb.groupby(["PlayId", "OnOffense"]).agg(np.mean)["PlayerWeight"].reset_index()
        tmp = tmp[tmp.OnOffense==True]
        tmp.rename(columns={'PlayerWeight': 'PlayerWeight_FB'}, inplace=True)
        df_single = pd.merge(df_single, tmp[["PlayId", "PlayerWeight_FB"]], on = "PlayId", how="left")
        
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])
    df_single["1stDefender_AttackAngle"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["AttackAngle"])
    # df_single["1stDefenderID"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["NflId"])
    
    #df_single["OffenseLine_Weight"] = np.array(train.groupby(["PlayId", "OnOffense"])["PlayerWeight"].max()[1::2])
    #df_single["OffenseLine_Height"] = np.array(train.groupby(["PlayId", "OnOffense"])["PlayerHeight"].max()[1::2])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    #def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    #off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    #df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY", "AttackAngle"]#"InfluToBall", , "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:856: RuntimeWarning: invalid value encountered in arctan
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# CPU times: user 5min 14s, sys: 2.22 s, total: 5min 16s
# Wall time: 5min 14s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : -1,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86895
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86628
# [3]	valid_0's multi_logloss: 2.8642
# [4]	valid_0's multi_logloss: 2.8621
# [5]	valid_0's multi_logloss: 2.85999
# [6]	valid_0's multi_logloss: 2.85811
# [7]	valid_0's multi_logloss: 2.85642
# [8]	valid_0's multi_logloss: 2.85482
# [9]	valid_0's multi_logloss: 2.85288
# [10]	valid_0's multi_logloss: 2.85119
# [11]	valid_0's multi_logloss: 2.84942
# [12]	valid_0's multi_logloss: 2.84773
# [13]	valid_0's multi_logloss: 2.84617
# [14]	valid_0's multi_logloss: 2.84452
# [15]	valid_0's multi_logloss: 2.84292
# [16]	valid_0's multi_logloss: 2.84141
# [17]	valid_0's multi_logloss: 2.83995
# [18]	valid_0's multi_logloss: 2.83842
# [19]	valid_0's multi_logloss: 2.83709
# [20]	valid_0's multi_logloss: 2.83567
# [21]	valid_0's multi_logloss: 2.83438
# [22]	valid_0's multi_logloss: 2.83303
# [23]	valid_0's multi_logloss: 2.83174
# [24]	valid_0's multi_logloss: 2.83046
# [25]	valid_0's multi_logloss: 2.82916
# [26]	valid_0's multi_logloss: 2.82792
# [27]	valid_0's multi_logloss: 2.82656
# [28]	valid_0's multi_logloss: 2.82537
# [29]	valid_0's multi_logloss: 2.8241
# [30]	valid_0's multi_logloss: 2.82286
# [31]	valid_0's multi_logloss: 2.82162
# [32]	valid_0's multi_logloss: 2.82056
# [33]	valid_0's multi_logloss: 2.81931
# [34]	valid_0's multi_logloss: 2.81818
# [35]	valid_0's multi_logloss: 2.81705
# [36]	valid_0's multi_logloss: 2.81585
# [37]	valid_0's multi_logloss: 2.81472
# [38]	valid_0's multi_logloss: 2.81358
# [39]	valid_0's multi_logloss: 2.81247
# [40]	valid_0's multi_logloss: 2.8114
# [41]	valid_0's multi_logloss: 2.81041
# [42]	valid_0's multi_logloss: 2.80935
# [43]	valid_0's multi_logloss: 2.80822
# [44]	valid_0's multi_logloss: 2.80722
# [45]	valid_0's multi_logloss: 2.80617
# [46]	valid_0's multi_logloss: 2.80522
# [47]	valid_0's multi_logloss: 2.80413
# [48]	valid_0's multi_logloss: 2.80315
# [49]	valid_0's multi_logloss: 2.80222
# [50]	valid_0's multi_logloss: 2.8013
# [51]	valid_0's multi_logloss: 2.80032
# [52]	valid_0's multi_logloss: 2.79933
# [53]	valid_0's multi_logloss: 2.79835
# [54]	valid_0's multi_logloss: 2.79738
# [55]	valid_0's multi_logloss: 2.79642
# [56]	valid_0's multi_logloss: 2.79547
# [57]	valid_0's multi_logloss: 2.7946
# [58]	valid_0's multi_logloss: 2.79357
# [59]	valid_0's multi_logloss: 2.79271
# [60]	valid_0's multi_logloss: 2.79181
# [61]	valid_0's multi_logloss: 2.79098
# [62]	valid_0's multi_logloss: 2.7901
# [63]	valid_0's multi_logloss: 2.78914
# [64]	valid_0's multi_logloss: 2.78816
# [65]	valid_0's multi_logloss: 2.78737
# [66]	valid_0's multi_logloss: 2.78639
# [67]	valid_0's multi_logloss: 2.78552
# [68]	valid_0's multi_logloss: 2.78469
# [69]	valid_0's multi_logloss: 2.78381
# [70]	valid_0's multi_logloss: 2.78305
# [71]	valid_0's multi_logloss: 2.78216
# [72]	valid_0's multi_logloss: 2.7813
# [73]	valid_0's multi_logloss: 2.78047
# [74]	valid_0's multi_logloss: 2.77978
# [75]	valid_0's multi_logloss: 2.77889
# [76]	valid_0's multi_logloss: 2.77811
# [77]	valid_0's multi_logloss: 2.77727
# [78]	valid_0's multi_logloss: 2.77651
# [79]	valid_0's multi_logloss: 2.77564
# [80]	valid_0's multi_logloss: 2.77477
# [81]	valid_0's multi_logloss: 2.7742
# [82]	valid_0's multi_logloss: 2.77337
# [83]	valid_0's multi_logloss: 2.77271
# [84]	valid_0's multi_logloss: 2.77189
# [85]	valid_0's multi_logloss: 2.77118
# [86]	valid_0's multi_logloss: 2.77038
# [87]	valid_0's multi_logloss: 2.7696
# [88]	valid_0's multi_logloss: 2.76896
# [89]	valid_0's multi_logloss: 2.76821
# [90]	valid_0's multi_logloss: 2.76738
# [91]	valid_0's multi_logloss: 2.76678
# [92]	valid_0's multi_logloss: 2.76616
# [93]	valid_0's multi_logloss: 2.76549
# [94]	valid_0's multi_logloss: 2.76488
# [95]	valid_0's multi_logloss: 2.76427
# [96]	valid_0's multi_logloss: 2.76364
# [97]	valid_0's multi_logloss: 2.76305
# [98]	valid_0's multi_logloss: 2.76237
# [99]	valid_0's multi_logloss: 2.76175
# [100]	valid_0's multi_logloss: 2.76111
# [101]	valid_0's multi_logloss: 2.76046
# [102]	valid_0's multi_logloss: 2.75989
# [103]	valid_0's multi_logloss: 2.75931
# [104]	valid_0's multi_logloss: 2.75878
# [105]	valid_0's multi_logloss: 2.7582
# [106]	valid_0's multi_logloss: 2.75763
# [107]	valid_0's multi_logloss: 2.75694
# [108]	valid_0's multi_logloss: 2.75647
# [109]	valid_0's multi_logloss: 2.75579
# [110]	valid_0's multi_logloss: 2.75527
# [111]	valid_0's multi_logloss: 2.75466
# [112]	valid_0's multi_logloss: 2.7541
# [113]	valid_0's multi_logloss: 2.75352
# [114]	valid_0's multi_logloss: 2.75301
# [115]	valid_0's multi_logloss: 2.75251
# [116]	valid_0's multi_logloss: 2.75193
# [117]	valid_0's multi_logloss: 2.75137
# [118]	valid_0's multi_logloss: 2.75087
# [119]	valid_0's multi_logloss: 2.75021
# [120]	valid_0's multi_logloss: 2.7497
# [121]	valid_0's multi_logloss: 2.74918
# [122]	valid_0's multi_logloss: 2.74862
# [123]	valid_0's multi_logloss: 2.74808
# [124]	valid_0's multi_logloss: 2.74755
# [125]	valid_0's multi_logloss: 2.74702
# [126]	valid_0's multi_logloss: 2.74651
# [127]	valid_0's multi_logloss: 2.74606
# [128]	valid_0's multi_logloss: 2.74555
# [129]	valid_0's multi_logloss: 2.74507
# [130]	valid_0's multi_logloss: 2.74457
# [131]	valid_0's multi_logloss: 2.74408
# [132]	valid_0's multi_logloss: 2.7436
# [133]	valid_0's multi_logloss: 2.7431
# [134]	valid_0's multi_logloss: 2.74261
# [135]	valid_0's multi_logloss: 2.74223
# [136]	valid_0's multi_logloss: 2.74181
# [137]	valid_0's multi_logloss: 2.74129
# [138]	valid_0's multi_logloss: 2.74079
# [139]	valid_0's multi_logloss: 2.7404
# [140]	valid_0's multi_logloss: 2.73992
# [141]	valid_0's multi_logloss: 2.73939
# [142]	valid_0's multi_logloss: 2.73896
# [143]	valid_0's multi_logloss: 2.73848
# [144]	valid_0's multi_logloss: 2.73805
# [145]	valid_0's multi_logloss: 2.73759
# [146]	valid_0's multi_logloss: 2.73713
# [147]	valid_0's multi_logloss: 2.7367
# [148]	valid_0's multi_logloss: 2.73619
# [149]	valid_0's multi_logloss: 2.73573
# [150]	valid_0's multi_logloss: 2.7353
# [151]	valid_0's multi_logloss: 2.73475
# [152]	valid_0's multi_logloss: 2.73436
# [153]	valid_0's multi_logloss: 2.7339
# [154]	valid_0's multi_logloss: 2.73355
# [155]	valid_0's multi_logloss: 2.73314
# [156]	valid_0's multi_logloss: 2.73266
# [157]	valid_0's multi_logloss: 2.73222
# [158]	valid_0's multi_logloss: 2.73176
# [159]	valid_0's multi_logloss: 2.73144
# [160]	valid_0's multi_logloss: 2.73109
# [161]	valid_0's multi_logloss: 2.73064
# [162]	valid_0's multi_logloss: 2.73022
# [163]	valid_0's multi_logloss: 2.72982
# [164]	valid_0's multi_logloss: 2.72941
# [165]	valid_0's multi_logloss: 2.72896
# [166]	valid_0's multi_logloss: 2.72862
# [167]	valid_0's multi_logloss: 2.72824
# [168]	valid_0's multi_logloss: 2.72781
# [169]	valid_0's multi_logloss: 2.72743
# [170]	valid_0's multi_logloss: 2.72703
# [171]	valid_0's multi_logloss: 2.72669
# [172]	valid_0's multi_logloss: 2.72635
# [173]	valid_0's multi_logloss: 2.72591
# [174]	valid_0's multi_logloss: 2.7256
# [175]	valid_0's multi_logloss: 2.72525
# [176]	valid_0's multi_logloss: 2.72479
# [177]	valid_0's multi_logloss: 2.7245
# [178]	valid_0's multi_logloss: 2.72416
# [179]	valid_0's multi_logloss: 2.72386
# [180]	valid_0's multi_logloss: 2.72349
# [181]	valid_0's multi_logloss: 2.72313
# [182]	valid_0's multi_logloss: 2.72288
# [183]	valid_0's multi_logloss: 2.72248
# [184]	valid_0's multi_logloss: 2.72218
# [185]	valid_0's multi_logloss: 2.72188
# [186]	valid_0's multi_logloss: 2.72155
# [187]	valid_0's multi_logloss: 2.72127
# [188]	valid_0's multi_logloss: 2.72098
# [189]	valid_0's multi_logloss: 2.72064
# [190]	valid_0's multi_logloss: 2.72033
# [191]	valid_0's multi_logloss: 2.72008
# [192]	valid_0's multi_logloss: 2.71982
# [193]	valid_0's multi_logloss: 2.71952
# [194]	valid_0's multi_logloss: 2.71927
# [195]	valid_0's multi_logloss: 2.71896
# [196]	valid_0's multi_logloss: 2.71875
# [197]	valid_0's multi_logloss: 2.7185
# [198]	valid_0's multi_logloss: 2.7182
# [199]	valid_0's multi_logloss: 2.71792
# [200]	valid_0's multi_logloss: 2.71773
# [201]	valid_0's multi_logloss: 2.71751
# [202]	valid_0's multi_logloss: 2.71725
# [203]	valid_0's multi_logloss: 2.71698
# [204]	valid_0's multi_logloss: 2.71673
# [205]	valid_0's multi_logloss: 2.7165
# [206]	valid_0's multi_logloss: 2.71623
# [207]	valid_0's multi_logloss: 2.71597
# [208]	valid_0's multi_logloss: 2.71571
# [209]	valid_0's multi_logloss: 2.71549
# [210]	valid_0's multi_logloss: 2.7153
# [211]	valid_0's multi_logloss: 2.71503
# [212]	valid_0's multi_logloss: 2.71476
# [213]	valid_0's multi_logloss: 2.71447
# [214]	valid_0's multi_logloss: 2.71424
# [215]	valid_0's multi_logloss: 2.71411
# [216]	valid_0's multi_logloss: 2.71389
# [217]	valid_0's multi_logloss: 2.7137
# [218]	valid_0's multi_logloss: 2.71353
# [219]	valid_0's multi_logloss: 2.71328
# [220]	valid_0's multi_logloss: 2.71301
# [221]	valid_0's multi_logloss: 2.71281
# [222]	valid_0's multi_logloss: 2.71261
# [223]	valid_0's multi_logloss: 2.7124
# [224]	valid_0's multi_logloss: 2.71221
# [225]	valid_0's multi_logloss: 2.71204
# [226]	valid_0's multi_logloss: 2.71181
# [227]	valid_0's multi_logloss: 2.7116
# [228]	valid_0's multi_logloss: 2.71137
# [229]	valid_0's multi_logloss: 2.71115
# [230]	valid_0's multi_logloss: 2.71103
# [231]	valid_0's multi_logloss: 2.71086
# [232]	valid_0's multi_logloss: 2.71071
# [233]	valid_0's multi_logloss: 2.71052
# [234]	valid_0's multi_logloss: 2.71033
# [235]	valid_0's multi_logloss: 2.71014
# [236]	valid_0's multi_logloss: 2.70992
# [237]	valid_0's multi_logloss: 2.70973
# [238]	valid_0's multi_logloss: 2.7096
# [239]	valid_0's multi_logloss: 2.70945
# [240]	valid_0's multi_logloss: 2.7092
# [241]	valid_0's multi_logloss: 2.70901
# [242]	valid_0's multi_logloss: 2.70881
# [243]	valid_0's multi_logloss: 2.70866
# [244]	valid_0's multi_logloss: 2.70846
# [245]	valid_0's multi_logloss: 2.70827
# [246]	valid_0's multi_logloss: 2.70809
# [247]	valid_0's multi_logloss: 2.7079
# [248]	valid_0's multi_logloss: 2.7078
# [249]	valid_0's multi_logloss: 2.70759
# [250]	valid_0's multi_logloss: 2.70744
# [251]	valid_0's multi_logloss: 2.70731
# [252]	valid_0's multi_logloss: 2.70712
# [253]	valid_0's multi_logloss: 2.70701
# [254]	valid_0's multi_logloss: 2.70684
# [255]	valid_0's multi_logloss: 2.70671
# [256]	valid_0's multi_logloss: 2.70656
# [257]	valid_0's multi_logloss: 2.70639
# [258]	valid_0's multi_logloss: 2.70625
# [259]	valid_0's multi_logloss: 2.70609
# [260]	valid_0's multi_logloss: 2.70589
# [261]	valid_0's multi_logloss: 2.70574
# [262]	valid_0's multi_logloss: 2.70557
# [263]	valid_0's multi_logloss: 2.70547
# [264]	valid_0's multi_logloss: 2.70531
# [265]	valid_0's multi_logloss: 2.70518
# [266]	valid_0's multi_logloss: 2.70508
# [267]	valid_0's multi_logloss: 2.705
# [268]	valid_0's multi_logloss: 2.7049
# [269]	valid_0's multi_logloss: 2.70477
# [270]	valid_0's multi_logloss: 2.70459
# [271]	valid_0's multi_logloss: 2.70447
# [272]	valid_0's multi_logloss: 2.70438
# [273]	valid_0's multi_logloss: 2.7043
# [274]	valid_0's multi_logloss: 2.70416
# [275]	valid_0's multi_logloss: 2.70404
# [276]	valid_0's multi_logloss: 2.70391
# [277]	valid_0's multi_logloss: 2.70375
# [278]	valid_0's multi_logloss: 2.70363
# [279]	valid_0's multi_logloss: 2.70358
# [280]	valid_0's multi_logloss: 2.7035
# [281]	valid_0's multi_logloss: 2.70329
# [282]	valid_0's multi_logloss: 2.70318
# [283]	valid_0's multi_logloss: 2.70303
# [284]	valid_0's multi_logloss: 2.7029
# [285]	valid_0's multi_logloss: 2.70278
# [286]	valid_0's multi_logloss: 2.70266
# [287]	valid_0's multi_logloss: 2.70257
# [288]	valid_0's multi_logloss: 2.70239
# [289]	valid_0's multi_logloss: 2.7023
# [290]	valid_0's multi_logloss: 2.70217
# [291]	valid_0's multi_logloss: 2.70202
# [292]	valid_0's multi_logloss: 2.70196
# [293]	valid_0's multi_logloss: 2.70181
# [294]	valid_0's multi_logloss: 2.70165
# [295]	valid_0's multi_logloss: 2.70154
# [296]	valid_0's multi_logloss: 2.70138
# [297]	valid_0's multi_logloss: 2.70128
# [298]	valid_0's multi_logloss: 2.70121
# [299]	valid_0's multi_logloss: 2.70111
# [300]	valid_0's multi_logloss: 2.70095
# [301]	valid_0's multi_logloss: 2.70079
# [302]	valid_0's multi_logloss: 2.70069
# [303]	valid_0's multi_logloss: 2.70059
# [304]	valid_0's multi_logloss: 2.70053
# [305]	valid_0's multi_logloss: 2.70038
# [306]	valid_0's multi_logloss: 2.7003
# [307]	valid_0's multi_logloss: 2.70016
# [308]	valid_0's multi_logloss: 2.70008
# [309]	valid_0's multi_logloss: 2.69998
# [310]	valid_0's multi_logloss: 2.69985
# [311]	valid_0's multi_logloss: 2.69978
# [312]	valid_0's multi_logloss: 2.69967
# [313]	valid_0's multi_logloss: 2.69955
# [314]	valid_0's multi_logloss: 2.69945
# [315]	valid_0's multi_logloss: 2.69927
# [316]	valid_0's multi_logloss: 2.6992
# [317]	valid_0's multi_logloss: 2.69915
# [318]	valid_0's multi_logloss: 2.69907
# [319]	valid_0's multi_logloss: 2.699
# [320]	valid_0's multi_logloss: 2.69888
# [321]	valid_0's multi_logloss: 2.69884
# [322]	valid_0's multi_logloss: 2.69877
# [323]	valid_0's multi_logloss: 2.6987
# [324]	valid_0's multi_logloss: 2.69863
# [325]	valid_0's multi_logloss: 2.69852
# [326]	valid_0's multi_logloss: 2.69847
# [327]	valid_0's multi_logloss: 2.6984
# [328]	valid_0's multi_logloss: 2.6983
# [329]	valid_0's multi_logloss: 2.69821
# [330]	valid_0's multi_logloss: 2.69817
# [331]	valid_0's multi_logloss: 2.69813
# [332]	valid_0's multi_logloss: 2.69805
# [333]	valid_0's multi_logloss: 2.69797
# [334]	valid_0's multi_logloss: 2.69792
# [335]	valid_0's multi_logloss: 2.69781
# [336]	valid_0's multi_logloss: 2.69767
# [337]	valid_0's multi_logloss: 2.69758
# [338]	valid_0's multi_logloss: 2.69755
# [339]	valid_0's multi_logloss: 2.69748
# [340]	valid_0's multi_logloss: 2.69739
# [341]	valid_0's multi_logloss: 2.69731
# [342]	valid_0's multi_logloss: 2.69723
# [343]	valid_0's multi_logloss: 2.69727
# [344]	valid_0's multi_logloss: 2.69722
# [345]	valid_0's multi_logloss: 2.69715
# [346]	valid_0's multi_logloss: 2.69711
# [347]	valid_0's multi_logloss: 2.69702
# [348]	valid_0's multi_logloss: 2.69702
# [349]	valid_0's multi_logloss: 2.69698
# [350]	valid_0's multi_logloss: 2.69695
# [351]	valid_0's multi_logloss: 2.69693
# [352]	valid_0's multi_logloss: 2.69684
# [353]	valid_0's multi_logloss: 2.69677
# [354]	valid_0's multi_logloss: 2.69675
# [355]	valid_0's multi_logloss: 2.6967
# [356]	valid_0's multi_logloss: 2.69663
# [357]	valid_0's multi_logloss: 2.69658
# [358]	valid_0's multi_logloss: 2.69657
# [359]	valid_0's multi_logloss: 2.69643
# [360]	valid_0's multi_logloss: 2.69644
# [361]	valid_0's multi_logloss: 2.69638
# [362]	valid_0's multi_logloss: 2.69636
# [363]	valid_0's multi_logloss: 2.69627
# [364]	valid_0's multi_logloss: 2.69616
# [365]	valid_0's multi_logloss: 2.6961
# [366]	valid_0's multi_logloss: 2.69601
# [367]	valid_0's multi_logloss: 2.69593
# [368]	valid_0's multi_logloss: 2.69594
# [369]	valid_0's multi_logloss: 2.69591
# [370]	valid_0's multi_logloss: 2.69586
# [371]	valid_0's multi_logloss: 2.69585
# [372]	valid_0's multi_logloss: 2.69577
# [373]	valid_0's multi_logloss: 2.69574
# [374]	valid_0's multi_logloss: 2.69576
# [375]	valid_0's multi_logloss: 2.6957
# [376]	valid_0's multi_logloss: 2.6956
# [377]	valid_0's multi_logloss: 2.69554
# [378]	valid_0's multi_logloss: 2.6956
# [379]	valid_0's multi_logloss: 2.69559
# [380]	valid_0's multi_logloss: 2.69557
# [381]	valid_0's multi_logloss: 2.69552
# [382]	valid_0's multi_logloss: 2.69553
# [383]	valid_0's multi_logloss: 2.69541
# [384]	valid_0's multi_logloss: 2.69546
# [385]	valid_0's multi_logloss: 2.6955
# [386]	valid_0's multi_logloss: 2.69543
# [387]	valid_0's multi_logloss: 2.69535
# [388]	valid_0's multi_logloss: 2.69534
# [389]	valid_0's multi_logloss: 2.69531
# [390]	valid_0's multi_logloss: 2.69528
# [391]	valid_0's multi_logloss: 2.69529
# [392]	valid_0's multi_logloss: 2.69525
# [393]	valid_0's multi_logloss: 2.69526
# [394]	valid_0's multi_logloss: 2.69524
# [395]	valid_0's multi_logloss: 2.69527
# [396]	valid_0's multi_logloss: 2.69524
# [397]	valid_0's multi_logloss: 2.69524
# [398]	valid_0's multi_logloss: 2.69521
# [399]	valid_0's multi_logloss: 2.69515
# [400]	valid_0's multi_logloss: 2.6951
# [401]	valid_0's multi_logloss: 2.69509
# [402]	valid_0's multi_logloss: 2.69508
# [403]	valid_0's multi_logloss: 2.69498
# [404]	valid_0's multi_logloss: 2.69494
# [405]	valid_0's multi_logloss: 2.69499
# [406]	valid_0's multi_logloss: 2.69491
# [407]	valid_0's multi_logloss: 2.69495
# [408]	valid_0's multi_logloss: 2.6949
# [409]	valid_0's multi_logloss: 2.69492
# [410]	valid_0's multi_logloss: 2.69493
# [411]	valid_0's multi_logloss: 2.69489
# [412]	valid_0's multi_logloss: 2.69489
# [413]	valid_0's multi_logloss: 2.6949
# [414]	valid_0's multi_logloss: 2.69485
# [415]	valid_0's multi_logloss: 2.69484
# [416]	valid_0's multi_logloss: 2.6948
# [417]	valid_0's multi_logloss: 2.69484
# [418]	valid_0's multi_logloss: 2.69476
# [419]	valid_0's multi_logloss: 2.6947
# [420]	valid_0's multi_logloss: 2.69467
# [421]	valid_0's multi_logloss: 2.69469
# [422]	valid_0's multi_logloss: 2.69462
# [423]	valid_0's multi_logloss: 2.69463
# [424]	valid_0's multi_logloss: 2.69459
# [425]	valid_0's multi_logloss: 2.6946
# [426]	valid_0's multi_logloss: 2.69461
# [427]	valid_0's multi_logloss: 2.69454
# [428]	valid_0's multi_logloss: 2.69454
# [429]	valid_0's multi_logloss: 2.6945
# [430]	valid_0's multi_logloss: 2.6945
# [431]	valid_0's multi_logloss: 2.69449
# [432]	valid_0's multi_logloss: 2.69454
# [433]	valid_0's multi_logloss: 2.69448
# [434]	valid_0's multi_logloss: 2.6945
# [435]	valid_0's multi_logloss: 2.69447
# [436]	valid_0's multi_logloss: 2.69445
# [437]	valid_0's multi_logloss: 2.69446
# [438]	valid_0's multi_logloss: 2.69436
# [439]	valid_0's multi_logloss: 2.69437
# [440]	valid_0's multi_logloss: 2.69435
# [441]	valid_0's multi_logloss: 2.69436
# [442]	valid_0's multi_logloss: 2.69436
# [443]	valid_0's multi_logloss: 2.69439
# [444]	valid_0's multi_logloss: 2.69432
# [445]	valid_0's multi_logloss: 2.69433
# [446]	valid_0's multi_logloss: 2.69434
# [447]	valid_0's multi_logloss: 2.69435
# [448]	valid_0's multi_logloss: 2.69436
# [449]	valid_0's multi_logloss: 2.6944
# [450]	valid_0's multi_logloss: 2.69427
# [451]	valid_0's multi_logloss: 2.69427
# [452]	valid_0's multi_logloss: 2.69428
# [453]	valid_0's multi_logloss: 2.69428
# [454]	valid_0's multi_logloss: 2.69427
# [455]	valid_0's multi_logloss: 2.69418
# [456]	valid_0's multi_logloss: 2.69423
# [457]	valid_0's multi_logloss: 2.69426
# [458]	valid_0's multi_logloss: 2.69426
# [459]	valid_0's multi_logloss: 2.69432
# [460]	valid_0's multi_logloss: 2.69432
# [461]	valid_0's multi_logloss: 2.69435
# [462]	valid_0's multi_logloss: 2.69436
# [463]	valid_0's multi_logloss: 2.69438
# [464]	valid_0's multi_logloss: 2.69437
# [465]	valid_0's multi_logloss: 2.69438
# Early stopping, best iteration is:
# [455]	valid_0's multi_logloss: 2.69418
# 0.0124807291491228
# [1]	valid_0's multi_logloss: 2.88688
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.8838
# [3]	valid_0's multi_logloss: 2.88159
# [4]	valid_0's multi_logloss: 2.87931
# [5]	valid_0's multi_logloss: 2.87726
# [6]	valid_0's multi_logloss: 2.87493
# [7]	valid_0's multi_logloss: 2.87299
# [8]	valid_0's multi_logloss: 2.87106
# [9]	valid_0's multi_logloss: 2.86915
# [10]	valid_0's multi_logloss: 2.86731
# [11]	valid_0's multi_logloss: 2.86556
# [12]	valid_0's multi_logloss: 2.86361
# [13]	valid_0's multi_logloss: 2.86194
# [14]	valid_0's multi_logloss: 2.86032
# [15]	valid_0's multi_logloss: 2.85859
# [16]	valid_0's multi_logloss: 2.85707
# [17]	valid_0's multi_logloss: 2.85542
# [18]	valid_0's multi_logloss: 2.85388
# [19]	valid_0's multi_logloss: 2.8523
# [20]	valid_0's multi_logloss: 2.85086
# [21]	valid_0's multi_logloss: 2.8493
# [22]	valid_0's multi_logloss: 2.84771
# [23]	valid_0's multi_logloss: 2.84631
# [24]	valid_0's multi_logloss: 2.84484
# [25]	valid_0's multi_logloss: 2.84343
# [26]	valid_0's multi_logloss: 2.84194
# [27]	valid_0's multi_logloss: 2.84044
# [28]	valid_0's multi_logloss: 2.839
# [29]	valid_0's multi_logloss: 2.83764
# [30]	valid_0's multi_logloss: 2.83621
# [31]	valid_0's multi_logloss: 2.83475
# [32]	valid_0's multi_logloss: 2.8334
# [33]	valid_0's multi_logloss: 2.83199
# [34]	valid_0's multi_logloss: 2.83072
# [35]	valid_0's multi_logloss: 2.82945
# [36]	valid_0's multi_logloss: 2.82825
# [37]	valid_0's multi_logloss: 2.82693
# [38]	valid_0's multi_logloss: 2.82567
# [39]	valid_0's multi_logloss: 2.82453
# [40]	valid_0's multi_logloss: 2.8233
# [41]	valid_0's multi_logloss: 2.82225
# [42]	valid_0's multi_logloss: 2.82111
# [43]	valid_0's multi_logloss: 2.81998
# [44]	valid_0's multi_logloss: 2.81882
# [45]	valid_0's multi_logloss: 2.81778
# [46]	valid_0's multi_logloss: 2.81667
# [47]	valid_0's multi_logloss: 2.81565
# [48]	valid_0's multi_logloss: 2.81456
# [49]	valid_0's multi_logloss: 2.81348
# [50]	valid_0's multi_logloss: 2.8125
# [51]	valid_0's multi_logloss: 2.81142
# [52]	valid_0's multi_logloss: 2.8103
# [53]	valid_0's multi_logloss: 2.80929
# [54]	valid_0's multi_logloss: 2.80826
# [55]	valid_0's multi_logloss: 2.80734
# [56]	valid_0's multi_logloss: 2.80634
# [57]	valid_0's multi_logloss: 2.80542
# [58]	valid_0's multi_logloss: 2.80447
# [59]	valid_0's multi_logloss: 2.80346
# [60]	valid_0's multi_logloss: 2.8025
# [61]	valid_0's multi_logloss: 2.80153
# [62]	valid_0's multi_logloss: 2.8006
# [63]	valid_0's multi_logloss: 2.79974
# [64]	valid_0's multi_logloss: 2.79877
# [65]	valid_0's multi_logloss: 2.79788
# [66]	valid_0's multi_logloss: 2.79693
# [67]	valid_0's multi_logloss: 2.79608
# [68]	valid_0's multi_logloss: 2.79522
# [69]	valid_0's multi_logloss: 2.79445
# [70]	valid_0's multi_logloss: 2.79341
# [71]	valid_0's multi_logloss: 2.79255
# [72]	valid_0's multi_logloss: 2.79171
# [73]	valid_0's multi_logloss: 2.79091
# [74]	valid_0's multi_logloss: 2.79004
# [75]	valid_0's multi_logloss: 2.78911
# [76]	valid_0's multi_logloss: 2.7883
# [77]	valid_0's multi_logloss: 2.78746
# [78]	valid_0's multi_logloss: 2.78652
# [79]	valid_0's multi_logloss: 2.78565
# [80]	valid_0's multi_logloss: 2.78483
# [81]	valid_0's multi_logloss: 2.78413
# [82]	valid_0's multi_logloss: 2.7834
# [83]	valid_0's multi_logloss: 2.78266
# [84]	valid_0's multi_logloss: 2.78184
# [85]	valid_0's multi_logloss: 2.78104
# [86]	valid_0's multi_logloss: 2.7804
# [87]	valid_0's multi_logloss: 2.77963
# [88]	valid_0's multi_logloss: 2.77896
# [89]	valid_0's multi_logloss: 2.77831
# [90]	valid_0's multi_logloss: 2.77753
# [91]	valid_0's multi_logloss: 2.77672
# [92]	valid_0's multi_logloss: 2.77606
# [93]	valid_0's multi_logloss: 2.7754
# [94]	valid_0's multi_logloss: 2.77465
# [95]	valid_0's multi_logloss: 2.77381
# [96]	valid_0's multi_logloss: 2.7731
# [97]	valid_0's multi_logloss: 2.7724
# [98]	valid_0's multi_logloss: 2.77172
# [99]	valid_0's multi_logloss: 2.77101
# [100]	valid_0's multi_logloss: 2.77034
# [101]	valid_0's multi_logloss: 2.76963
# [102]	valid_0's multi_logloss: 2.76884
# [103]	valid_0's multi_logloss: 2.76813
# [104]	valid_0's multi_logloss: 2.76752
# [105]	valid_0's multi_logloss: 2.76691
# [106]	valid_0's multi_logloss: 2.76621
# [107]	valid_0's multi_logloss: 2.76567
# [108]	valid_0's multi_logloss: 2.76498
# [109]	valid_0's multi_logloss: 2.7644
# [110]	valid_0's multi_logloss: 2.76371
# [111]	valid_0's multi_logloss: 2.76302
# [112]	valid_0's multi_logloss: 2.76248
# [113]	valid_0's multi_logloss: 2.76188
# [114]	valid_0's multi_logloss: 2.76131
# [115]	valid_0's multi_logloss: 2.76077
# [116]	valid_0's multi_logloss: 2.7602
# [117]	valid_0's multi_logloss: 2.75973
# [118]	valid_0's multi_logloss: 2.75915
# [119]	valid_0's multi_logloss: 2.75864
# [120]	valid_0's multi_logloss: 2.75804
# [121]	valid_0's multi_logloss: 2.75748
# [122]	valid_0's multi_logloss: 2.75686
# [123]	valid_0's multi_logloss: 2.75631
# [124]	valid_0's multi_logloss: 2.75576
# [125]	valid_0's multi_logloss: 2.75514
# [126]	valid_0's multi_logloss: 2.75453
# [127]	valid_0's multi_logloss: 2.75391
# [128]	valid_0's multi_logloss: 2.75342
# [129]	valid_0's multi_logloss: 2.75284
# [130]	valid_0's multi_logloss: 2.7523
# [131]	valid_0's multi_logloss: 2.75182
# [132]	valid_0's multi_logloss: 2.75127
# [133]	valid_0's multi_logloss: 2.75065
# [134]	valid_0's multi_logloss: 2.75011
# [135]	valid_0's multi_logloss: 2.74956
# [136]	valid_0's multi_logloss: 2.74909
# [137]	valid_0's multi_logloss: 2.74858
# [138]	valid_0's multi_logloss: 2.74812
# [139]	valid_0's multi_logloss: 2.74754
# [140]	valid_0's multi_logloss: 2.74699
# [141]	valid_0's multi_logloss: 2.74643
# [142]	valid_0's multi_logloss: 2.74596
# [143]	valid_0's multi_logloss: 2.74551
# [144]	valid_0's multi_logloss: 2.74504
# [145]	valid_0's multi_logloss: 2.74458
# [146]	valid_0's multi_logloss: 2.74412
# [147]	valid_0's multi_logloss: 2.7437
# [148]	valid_0's multi_logloss: 2.74327
# [149]	valid_0's multi_logloss: 2.74276
# [150]	valid_0's multi_logloss: 2.74232
# [151]	valid_0's multi_logloss: 2.74185
# [152]	valid_0's multi_logloss: 2.74139
# [153]	valid_0's multi_logloss: 2.74095
# [154]	valid_0's multi_logloss: 2.74052
# [155]	valid_0's multi_logloss: 2.74013
# [156]	valid_0's multi_logloss: 2.73963
# [157]	valid_0's multi_logloss: 2.73918
# [158]	valid_0's multi_logloss: 2.73873
# [159]	valid_0's multi_logloss: 2.73832
# [160]	valid_0's multi_logloss: 2.73782
# [161]	valid_0's multi_logloss: 2.73744
# [162]	valid_0's multi_logloss: 2.73707
# [163]	valid_0's multi_logloss: 2.73659
# [164]	valid_0's multi_logloss: 2.73626
# [165]	valid_0's multi_logloss: 2.73579
# [166]	valid_0's multi_logloss: 2.73534
# [167]	valid_0's multi_logloss: 2.73491
# [168]	valid_0's multi_logloss: 2.73443
# [169]	valid_0's multi_logloss: 2.73398
# [170]	valid_0's multi_logloss: 2.7336
# [171]	valid_0's multi_logloss: 2.73321
# [172]	valid_0's multi_logloss: 2.73283
# [173]	valid_0's multi_logloss: 2.7325
# [174]	valid_0's multi_logloss: 2.73218
# [175]	valid_0's multi_logloss: 2.73177
# [176]	valid_0's multi_logloss: 2.7314
# [177]	valid_0's multi_logloss: 2.73098
# [178]	valid_0's multi_logloss: 2.73066
# [179]	valid_0's multi_logloss: 2.73029
# [180]	valid_0's multi_logloss: 2.7299
# [181]	valid_0's multi_logloss: 2.72956
# [182]	valid_0's multi_logloss: 2.72919
# [183]	valid_0's multi_logloss: 2.72885
# [184]	valid_0's multi_logloss: 2.72857
# [185]	valid_0's multi_logloss: 2.72817
# [186]	valid_0's multi_logloss: 2.7278
# [187]	valid_0's multi_logloss: 2.72747
# [188]	valid_0's multi_logloss: 2.72713
# [189]	valid_0's multi_logloss: 2.72676
# [190]	valid_0's multi_logloss: 2.72646
# [191]	valid_0's multi_logloss: 2.7261
# [192]	valid_0's multi_logloss: 2.72575
# [193]	valid_0's multi_logloss: 2.72542
# [194]	valid_0's multi_logloss: 2.72514
# [195]	valid_0's multi_logloss: 2.7249
# [196]	valid_0's multi_logloss: 2.72461
# [197]	valid_0's multi_logloss: 2.72427
# [198]	valid_0's multi_logloss: 2.72399
# [199]	valid_0's multi_logloss: 2.72364
# [200]	valid_0's multi_logloss: 2.72327
# [201]	valid_0's multi_logloss: 2.72299
# [202]	valid_0's multi_logloss: 2.72261
# [203]	valid_0's multi_logloss: 2.72237
# [204]	valid_0's multi_logloss: 2.72199
# [205]	valid_0's multi_logloss: 2.72164
# [206]	valid_0's multi_logloss: 2.72134
# [207]	valid_0's multi_logloss: 2.72102
# [208]	valid_0's multi_logloss: 2.72068
# [209]	valid_0's multi_logloss: 2.72046
# [210]	valid_0's multi_logloss: 2.72016
# [211]	valid_0's multi_logloss: 2.71987
# [212]	valid_0's multi_logloss: 2.71955
# [213]	valid_0's multi_logloss: 2.71925
# [214]	valid_0's multi_logloss: 2.71898
# [215]	valid_0's multi_logloss: 2.71871
# [216]	valid_0's multi_logloss: 2.7185
# [217]	valid_0's multi_logloss: 2.71819
# [218]	valid_0's multi_logloss: 2.71797
# [219]	valid_0's multi_logloss: 2.71767
# [220]	valid_0's multi_logloss: 2.71736
# [221]	valid_0's multi_logloss: 2.71705
# [222]	valid_0's multi_logloss: 2.7168
# [223]	valid_0's multi_logloss: 2.7165
# [224]	valid_0's multi_logloss: 2.71622
# [225]	valid_0's multi_logloss: 2.71593
# [226]	valid_0's multi_logloss: 2.71566
# [227]	valid_0's multi_logloss: 2.71535
# [228]	valid_0's multi_logloss: 2.71512
# [229]	valid_0's multi_logloss: 2.7148
# [230]	valid_0's multi_logloss: 2.71451
# [231]	valid_0's multi_logloss: 2.71427
# [232]	valid_0's multi_logloss: 2.71401
# [233]	valid_0's multi_logloss: 2.71373
# [234]	valid_0's multi_logloss: 2.71348
# [235]	valid_0's multi_logloss: 2.71327
# [236]	valid_0's multi_logloss: 2.71307
# [237]	valid_0's multi_logloss: 2.71272
# [238]	valid_0's multi_logloss: 2.71247
# [239]	valid_0's multi_logloss: 2.7122
# [240]	valid_0's multi_logloss: 2.71196
# [241]	valid_0's multi_logloss: 2.71171
# [242]	valid_0's multi_logloss: 2.71148
# [243]	valid_0's multi_logloss: 2.71127
# [244]	valid_0's multi_logloss: 2.71093
# [245]	valid_0's multi_logloss: 2.71072
# [246]	valid_0's multi_logloss: 2.71054
# [247]	valid_0's multi_logloss: 2.7103
# [248]	valid_0's multi_logloss: 2.71001
# [249]	valid_0's multi_logloss: 2.7098
# [250]	valid_0's multi_logloss: 2.70958
# [251]	valid_0's multi_logloss: 2.70941
# [252]	valid_0's multi_logloss: 2.7092
# [253]	valid_0's multi_logloss: 2.70892
# [254]	valid_0's multi_logloss: 2.70872
# [255]	valid_0's multi_logloss: 2.70851
# [256]	valid_0's multi_logloss: 2.70828
# [257]	valid_0's multi_logloss: 2.70804
# [258]	valid_0's multi_logloss: 2.70786
# [259]	valid_0's multi_logloss: 2.70767
# [260]	valid_0's multi_logloss: 2.70744
# [261]	valid_0's multi_logloss: 2.70721
# [262]	valid_0's multi_logloss: 2.70701
# [263]	valid_0's multi_logloss: 2.70668
# [264]	valid_0's multi_logloss: 2.7065
# [265]	valid_0's multi_logloss: 2.70628
# [266]	valid_0's multi_logloss: 2.70604
# [267]	valid_0's multi_logloss: 2.70586
# [268]	valid_0's multi_logloss: 2.70562
# [269]	valid_0's multi_logloss: 2.70544
# [270]	valid_0's multi_logloss: 2.70526
# [271]	valid_0's multi_logloss: 2.70497
# [272]	valid_0's multi_logloss: 2.70476
# [273]	valid_0's multi_logloss: 2.70452
# [274]	valid_0's multi_logloss: 2.7043
# [275]	valid_0's multi_logloss: 2.70407
# [276]	valid_0's multi_logloss: 2.70389
# [277]	valid_0's multi_logloss: 2.70362
# [278]	valid_0's multi_logloss: 2.70337
# [279]	valid_0's multi_logloss: 2.7032
# [280]	valid_0's multi_logloss: 2.70302
# [281]	valid_0's multi_logloss: 2.70283
# [282]	valid_0's multi_logloss: 2.70267
# [283]	valid_0's multi_logloss: 2.70249
# [284]	valid_0's multi_logloss: 2.70227
# [285]	valid_0's multi_logloss: 2.70215
# [286]	valid_0's multi_logloss: 2.70201
# [287]	valid_0's multi_logloss: 2.70181
# [288]	valid_0's multi_logloss: 2.70164
# [289]	valid_0's multi_logloss: 2.70138
# [290]	valid_0's multi_logloss: 2.70126
# [291]	valid_0's multi_logloss: 2.70111
# [292]	valid_0's multi_logloss: 2.70094
# [293]	valid_0's multi_logloss: 2.70079
# [294]	valid_0's multi_logloss: 2.70067
# [295]	valid_0's multi_logloss: 2.70047
# [296]	valid_0's multi_logloss: 2.70034
# [297]	valid_0's multi_logloss: 2.70012
# [298]	valid_0's multi_logloss: 2.70001
# [299]	valid_0's multi_logloss: 2.69981
# [300]	valid_0's multi_logloss: 2.69965
# [301]	valid_0's multi_logloss: 2.69948
# [302]	valid_0's multi_logloss: 2.69933
# [303]	valid_0's multi_logloss: 2.69921
# [304]	valid_0's multi_logloss: 2.69904
# [305]	valid_0's multi_logloss: 2.69887
# [306]	valid_0's multi_logloss: 2.69872
# [307]	valid_0's multi_logloss: 2.69855
# [308]	valid_0's multi_logloss: 2.69841
# [309]	valid_0's multi_logloss: 2.69821
# [310]	valid_0's multi_logloss: 2.69805
# [311]	valid_0's multi_logloss: 2.69789
# [312]	valid_0's multi_logloss: 2.69774
# [313]	valid_0's multi_logloss: 2.69759
# [314]	valid_0's multi_logloss: 2.69742
# [315]	valid_0's multi_logloss: 2.69724
# [316]	valid_0's multi_logloss: 2.69702
# [317]	valid_0's multi_logloss: 2.69692
# [318]	valid_0's multi_logloss: 2.69675
# [319]	valid_0's multi_logloss: 2.69666
# [320]	valid_0's multi_logloss: 2.69654
# [321]	valid_0's multi_logloss: 2.69636
# [322]	valid_0's multi_logloss: 2.69632
# [323]	valid_0's multi_logloss: 2.69619
# [324]	valid_0's multi_logloss: 2.69606
# [325]	valid_0's multi_logloss: 2.69597
# [326]	valid_0's multi_logloss: 2.69579
# [327]	valid_0's multi_logloss: 2.69567
# [328]	valid_0's multi_logloss: 2.69551
# [329]	valid_0's multi_logloss: 2.69541
# [330]	valid_0's multi_logloss: 2.6953
# [331]	valid_0's multi_logloss: 2.69523
# [332]	valid_0's multi_logloss: 2.69516
# [333]	valid_0's multi_logloss: 2.69508
# [334]	valid_0's multi_logloss: 2.69498
# [335]	valid_0's multi_logloss: 2.69495
# [336]	valid_0's multi_logloss: 2.69482
# [337]	valid_0's multi_logloss: 2.69471
# [338]	valid_0's multi_logloss: 2.6946
# [339]	valid_0's multi_logloss: 2.69454
# [340]	valid_0's multi_logloss: 2.69446
# [341]	valid_0's multi_logloss: 2.69434
# [342]	valid_0's multi_logloss: 2.69421
# [343]	valid_0's multi_logloss: 2.69415
# [344]	valid_0's multi_logloss: 2.69408
# [345]	valid_0's multi_logloss: 2.69399
# [346]	valid_0's multi_logloss: 2.69389
# [347]	valid_0's multi_logloss: 2.69383
# [348]	valid_0's multi_logloss: 2.69373
# [349]	valid_0's multi_logloss: 2.69361
# [350]	valid_0's multi_logloss: 2.69352
# [351]	valid_0's multi_logloss: 2.69341
# [352]	valid_0's multi_logloss: 2.6934
# [353]	valid_0's multi_logloss: 2.69334
# [354]	valid_0's multi_logloss: 2.6933
# [355]	valid_0's multi_logloss: 2.69323
# [356]	valid_0's multi_logloss: 2.69312
# [357]	valid_0's multi_logloss: 2.69307
# [358]	valid_0's multi_logloss: 2.69302
# [359]	valid_0's multi_logloss: 2.69299
# [360]	valid_0's multi_logloss: 2.69294
# [361]	valid_0's multi_logloss: 2.69285
# [362]	valid_0's multi_logloss: 2.69276
# [363]	valid_0's multi_logloss: 2.6927
# [364]	valid_0's multi_logloss: 2.69261
# [365]	valid_0's multi_logloss: 2.69254
# [366]	valid_0's multi_logloss: 2.69248
# [367]	valid_0's multi_logloss: 2.69247
# [368]	valid_0's multi_logloss: 2.69236
# [369]	valid_0's multi_logloss: 2.69227
# [370]	valid_0's multi_logloss: 2.69219
# [371]	valid_0's multi_logloss: 2.69211
# [372]	valid_0's multi_logloss: 2.69207
# [373]	valid_0's multi_logloss: 2.69205
# [374]	valid_0's multi_logloss: 2.69193
# [375]	valid_0's multi_logloss: 2.69188
# [376]	valid_0's multi_logloss: 2.69185
# [377]	valid_0's multi_logloss: 2.69173
# [378]	valid_0's multi_logloss: 2.69167
# [379]	valid_0's multi_logloss: 2.69166
# [380]	valid_0's multi_logloss: 2.6916
# [381]	valid_0's multi_logloss: 2.69156
# [382]	valid_0's multi_logloss: 2.69148
# [383]	valid_0's multi_logloss: 2.69137
# [384]	valid_0's multi_logloss: 2.69127
# [385]	valid_0's multi_logloss: 2.69124
# [386]	valid_0's multi_logloss: 2.69119
# [387]	valid_0's multi_logloss: 2.69116
# [388]	valid_0's multi_logloss: 2.69112
# [389]	valid_0's multi_logloss: 2.69108
# [390]	valid_0's multi_logloss: 2.69104
# [391]	valid_0's multi_logloss: 2.69098
# [392]	valid_0's multi_logloss: 2.69093
# [393]	valid_0's multi_logloss: 2.69086
# [394]	valid_0's multi_logloss: 2.69077
# [395]	valid_0's multi_logloss: 2.69073
# [396]	valid_0's multi_logloss: 2.69072
# [397]	valid_0's multi_logloss: 2.69065
# [398]	valid_0's multi_logloss: 2.6906
# [399]	valid_0's multi_logloss: 2.69053
# [400]	valid_0's multi_logloss: 2.69046
# [401]	valid_0's multi_logloss: 2.6904
# [402]	valid_0's multi_logloss: 2.69039
# [403]	valid_0's multi_logloss: 2.69032
# [404]	valid_0's multi_logloss: 2.69027
# [405]	valid_0's multi_logloss: 2.69022
# [406]	valid_0's multi_logloss: 2.69013
# [407]	valid_0's multi_logloss: 2.69003
# [408]	valid_0's multi_logloss: 2.69
# [409]	valid_0's multi_logloss: 2.68992
# [410]	valid_0's multi_logloss: 2.68985
# [411]	valid_0's multi_logloss: 2.68979
# [412]	valid_0's multi_logloss: 2.68974
# [413]	valid_0's multi_logloss: 2.68972
# [414]	valid_0's multi_logloss: 2.68966
# [415]	valid_0's multi_logloss: 2.68962
# [416]	valid_0's multi_logloss: 2.68958
# [417]	valid_0's multi_logloss: 2.68955
# [418]	valid_0's multi_logloss: 2.68953
# [419]	valid_0's multi_logloss: 2.68953
# [420]	valid_0's multi_logloss: 2.68953
# [421]	valid_0's multi_logloss: 2.68948
# [422]	valid_0's multi_logloss: 2.68943
# [423]	valid_0's multi_logloss: 2.6894
# [424]	valid_0's multi_logloss: 2.68932
# [425]	valid_0's multi_logloss: 2.68927
# [426]	valid_0's multi_logloss: 2.68923
# [427]	valid_0's multi_logloss: 2.68916
# [428]	valid_0's multi_logloss: 2.68912
# [429]	valid_0's multi_logloss: 2.68911
# [430]	valid_0's multi_logloss: 2.68903
# [431]	valid_0's multi_logloss: 2.689
# [432]	valid_0's multi_logloss: 2.68897
# [433]	valid_0's multi_logloss: 2.68897
# [434]	valid_0's multi_logloss: 2.6889
# [435]	valid_0's multi_logloss: 2.68888
# [436]	valid_0's multi_logloss: 2.68885
# [437]	valid_0's multi_logloss: 2.6888
# [438]	valid_0's multi_logloss: 2.68867
# [439]	valid_0's multi_logloss: 2.68862
# [440]	valid_0's multi_logloss: 2.68858
# [441]	valid_0's multi_logloss: 2.68859
# [442]	valid_0's multi_logloss: 2.68858
# [443]	valid_0's multi_logloss: 2.68857
# [444]	valid_0's multi_logloss: 2.68856
# [445]	valid_0's multi_logloss: 2.68856
# [446]	valid_0's multi_logloss: 2.68856
# [447]	valid_0's multi_logloss: 2.68857
# [448]	valid_0's multi_logloss: 2.68851
# [449]	valid_0's multi_logloss: 2.68853
# [450]	valid_0's multi_logloss: 2.68853
# [451]	valid_0's multi_logloss: 2.68848
# [452]	valid_0's multi_logloss: 2.68849
# [453]	valid_0's multi_logloss: 2.68848
# [454]	valid_0's multi_logloss: 2.68847
# [455]	valid_0's multi_logloss: 2.68844
# [456]	valid_0's multi_logloss: 2.68838
# [457]	valid_0's multi_logloss: 2.68845
# [458]	valid_0's multi_logloss: 2.68838
# [459]	valid_0's multi_logloss: 2.68839
# [460]	valid_0's multi_logloss: 2.68837
# [461]	valid_0's multi_logloss: 2.68839
# [462]	valid_0's multi_logloss: 2.68838
# [463]	valid_0's multi_logloss: 2.68836
# [464]	valid_0's multi_logloss: 2.68834
# [465]	valid_0's multi_logloss: 2.68837
# [466]	valid_0's multi_logloss: 2.68835
# [467]	valid_0's multi_logloss: 2.68835
# [468]	valid_0's multi_logloss: 2.6884
# [469]	valid_0's multi_logloss: 2.6884
# [470]	valid_0's multi_logloss: 2.68841
# [471]	valid_0's multi_logloss: 2.6884
# [472]	valid_0's multi_logloss: 2.6884
# [473]	valid_0's multi_logloss: 2.68835
# [474]	valid_0's multi_logloss: 2.68832
# [475]	valid_0's multi_logloss: 2.68828
# [476]	valid_0's multi_logloss: 2.68827
# [477]	valid_0's multi_logloss: 2.68824
# [478]	valid_0's multi_logloss: 2.68832
# [479]	valid_0's multi_logloss: 2.68829
# [480]	valid_0's multi_logloss: 2.6883
# [481]	valid_0's multi_logloss: 2.68831
# [482]	valid_0's multi_logloss: 2.68828
# [483]	valid_0's multi_logloss: 2.68831
# [484]	valid_0's multi_logloss: 2.68831
# [485]	valid_0's multi_logloss: 2.68833
# [486]	valid_0's multi_logloss: 2.68839
# [487]	valid_0's multi_logloss: 2.68841
# Early stopping, best iteration is:
# [477]	valid_0's multi_logloss: 2.68824
# 0.01229469803667161
# [1]	valid_0's multi_logloss: 2.85876
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85678
# [3]	valid_0's multi_logloss: 2.85482
# [4]	valid_0's multi_logloss: 2.85312
# [5]	valid_0's multi_logloss: 2.85124
# [6]	valid_0's multi_logloss: 2.8495
# [7]	valid_0's multi_logloss: 2.84763
# [8]	valid_0's multi_logloss: 2.84579
# [9]	valid_0's multi_logloss: 2.8441
# [10]	valid_0's multi_logloss: 2.84238
# [11]	valid_0's multi_logloss: 2.84066
# [12]	valid_0's multi_logloss: 2.83904
# [13]	valid_0's multi_logloss: 2.83749
# [14]	valid_0's multi_logloss: 2.83593
# [15]	valid_0's multi_logloss: 2.83441
# [16]	valid_0's multi_logloss: 2.83306
# [17]	valid_0's multi_logloss: 2.83155
# [18]	valid_0's multi_logloss: 2.8302
# [19]	valid_0's multi_logloss: 2.82872
# [20]	valid_0's multi_logloss: 2.82749
# [21]	valid_0's multi_logloss: 2.82616
# [22]	valid_0's multi_logloss: 2.82487
# [23]	valid_0's multi_logloss: 2.82362
# [24]	valid_0's multi_logloss: 2.82237
# [25]	valid_0's multi_logloss: 2.82122
# [26]	valid_0's multi_logloss: 2.82011
# [27]	valid_0's multi_logloss: 2.81897
# [28]	valid_0's multi_logloss: 2.81782
# [29]	valid_0's multi_logloss: 2.81673
# [30]	valid_0's multi_logloss: 2.81571
# [31]	valid_0's multi_logloss: 2.81467
# [32]	valid_0's multi_logloss: 2.81355
# [33]	valid_0's multi_logloss: 2.81254
# [34]	valid_0's multi_logloss: 2.81151
# [35]	valid_0's multi_logloss: 2.81056
# [36]	valid_0's multi_logloss: 2.8096
# [37]	valid_0's multi_logloss: 2.80861
# [38]	valid_0's multi_logloss: 2.80762
# [39]	valid_0's multi_logloss: 2.80671
# [40]	valid_0's multi_logloss: 2.80574
# [41]	valid_0's multi_logloss: 2.80478
# [42]	valid_0's multi_logloss: 2.80392
# [43]	valid_0's multi_logloss: 2.80304
# [44]	valid_0's multi_logloss: 2.80206
# [45]	valid_0's multi_logloss: 2.80124
# [46]	valid_0's multi_logloss: 2.80027
# [47]	valid_0's multi_logloss: 2.79939
# [48]	valid_0's multi_logloss: 2.79846
# [49]	valid_0's multi_logloss: 2.79766
# [50]	valid_0's multi_logloss: 2.7968
# [51]	valid_0's multi_logloss: 2.79585
# [52]	valid_0's multi_logloss: 2.79511
# [53]	valid_0's multi_logloss: 2.79426
# [54]	valid_0's multi_logloss: 2.79343
# [55]	valid_0's multi_logloss: 2.7926
# [56]	valid_0's multi_logloss: 2.79177
# [57]	valid_0's multi_logloss: 2.79094
# [58]	valid_0's multi_logloss: 2.79014
# [59]	valid_0's multi_logloss: 2.78932
# [60]	valid_0's multi_logloss: 2.78866
# [61]	valid_0's multi_logloss: 2.7878
# [62]	valid_0's multi_logloss: 2.78702
# [63]	valid_0's multi_logloss: 2.78626
# [64]	valid_0's multi_logloss: 2.78546
# [65]	valid_0's multi_logloss: 2.78467
# [66]	valid_0's multi_logloss: 2.78392
# [67]	valid_0's multi_logloss: 2.78317
# [68]	valid_0's multi_logloss: 2.78236
# [69]	valid_0's multi_logloss: 2.78164
# [70]	valid_0's multi_logloss: 2.78085
# [71]	valid_0's multi_logloss: 2.78017
# [72]	valid_0's multi_logloss: 2.77949
# [73]	valid_0's multi_logloss: 2.77877
# [74]	valid_0's multi_logloss: 2.77802
# [75]	valid_0's multi_logloss: 2.77738
# [76]	valid_0's multi_logloss: 2.7766
# [77]	valid_0's multi_logloss: 2.77593
# [78]	valid_0's multi_logloss: 2.77525
# [79]	valid_0's multi_logloss: 2.77458
# [80]	valid_0's multi_logloss: 2.77399
# [81]	valid_0's multi_logloss: 2.77334
# [82]	valid_0's multi_logloss: 2.77273
# [83]	valid_0's multi_logloss: 2.77215
# [84]	valid_0's multi_logloss: 2.77154
# [85]	valid_0's multi_logloss: 2.77097
# [86]	valid_0's multi_logloss: 2.77028
# [87]	valid_0's multi_logloss: 2.76972
# [88]	valid_0's multi_logloss: 2.76904
# [89]	valid_0's multi_logloss: 2.76848
# [90]	valid_0's multi_logloss: 2.76792
# [91]	valid_0's multi_logloss: 2.76732
# [92]	valid_0's multi_logloss: 2.76673
# [93]	valid_0's multi_logloss: 2.76609
# [94]	valid_0's multi_logloss: 2.7655
# [95]	valid_0's multi_logloss: 2.76489
# [96]	valid_0's multi_logloss: 2.76432
# [97]	valid_0's multi_logloss: 2.76372
# [98]	valid_0's multi_logloss: 2.7632
# [99]	valid_0's multi_logloss: 2.76268
# [100]	valid_0's multi_logloss: 2.76209
# [101]	valid_0's multi_logloss: 2.76145
# [102]	valid_0's multi_logloss: 2.76092
# [103]	valid_0's multi_logloss: 2.76034
# [104]	valid_0's multi_logloss: 2.75976
# [105]	valid_0's multi_logloss: 2.75918
# [106]	valid_0's multi_logloss: 2.75855
# [107]	valid_0's multi_logloss: 2.758
# [108]	valid_0's multi_logloss: 2.75745
# [109]	valid_0's multi_logloss: 2.7568
# [110]	valid_0's multi_logloss: 2.75628
# [111]	valid_0's multi_logloss: 2.75572
# [112]	valid_0's multi_logloss: 2.75518
# [113]	valid_0's multi_logloss: 2.75466
# [114]	valid_0's multi_logloss: 2.75411
# [115]	valid_0's multi_logloss: 2.75356
# [116]	valid_0's multi_logloss: 2.75306
# [117]	valid_0's multi_logloss: 2.75241
# [118]	valid_0's multi_logloss: 2.75186
# [119]	valid_0's multi_logloss: 2.75143
# [120]	valid_0's multi_logloss: 2.75089
# [121]	valid_0's multi_logloss: 2.75045
# [122]	valid_0's multi_logloss: 2.74985
# [123]	valid_0's multi_logloss: 2.74936
# [124]	valid_0's multi_logloss: 2.74885
# [125]	valid_0's multi_logloss: 2.74835
# [126]	valid_0's multi_logloss: 2.7479
# [127]	valid_0's multi_logloss: 2.74748
# [128]	valid_0's multi_logloss: 2.74704
# [129]	valid_0's multi_logloss: 2.74653
# [130]	valid_0's multi_logloss: 2.7461
# [131]	valid_0's multi_logloss: 2.74554
# [132]	valid_0's multi_logloss: 2.74511
# [133]	valid_0's multi_logloss: 2.7447
# [134]	valid_0's multi_logloss: 2.74426
# [135]	valid_0's multi_logloss: 2.74392
# [136]	valid_0's multi_logloss: 2.74338
# [137]	valid_0's multi_logloss: 2.74301
# [138]	valid_0's multi_logloss: 2.74246
# [139]	valid_0's multi_logloss: 2.74208
# [140]	valid_0's multi_logloss: 2.74165
# [141]	valid_0's multi_logloss: 2.74133
# [142]	valid_0's multi_logloss: 2.7409
# [143]	valid_0's multi_logloss: 2.74053
# [144]	valid_0's multi_logloss: 2.74012
# [145]	valid_0's multi_logloss: 2.73976
# [146]	valid_0's multi_logloss: 2.73928
# [147]	valid_0's multi_logloss: 2.73889
# [148]	valid_0's multi_logloss: 2.73846
# [149]	valid_0's multi_logloss: 2.73807
# [150]	valid_0's multi_logloss: 2.73768
# [151]	valid_0's multi_logloss: 2.7373
# [152]	valid_0's multi_logloss: 2.73694
# [153]	valid_0's multi_logloss: 2.73662
# [154]	valid_0's multi_logloss: 2.7362
# [155]	valid_0's multi_logloss: 2.73593
# [156]	valid_0's multi_logloss: 2.73547
# [157]	valid_0's multi_logloss: 2.73503
# [158]	valid_0's multi_logloss: 2.73467
# [159]	valid_0's multi_logloss: 2.73428
# [160]	valid_0's multi_logloss: 2.73393
# [161]	valid_0's multi_logloss: 2.73359
# [162]	valid_0's multi_logloss: 2.73322
# [163]	valid_0's multi_logloss: 2.73285
# [164]	valid_0's multi_logloss: 2.73246
# [165]	valid_0's multi_logloss: 2.73215
# [166]	valid_0's multi_logloss: 2.73183
# [167]	valid_0's multi_logloss: 2.73147
# [168]	valid_0's multi_logloss: 2.73119
# [169]	valid_0's multi_logloss: 2.73089
# [170]	valid_0's multi_logloss: 2.73061
# [171]	valid_0's multi_logloss: 2.73031
# [172]	valid_0's multi_logloss: 2.72997
# [173]	valid_0's multi_logloss: 2.72964
# [174]	valid_0's multi_logloss: 2.72939
# [175]	valid_0's multi_logloss: 2.72901
# [176]	valid_0's multi_logloss: 2.7287
# [177]	valid_0's multi_logloss: 2.72841
# [178]	valid_0's multi_logloss: 2.72806
# [179]	valid_0's multi_logloss: 2.72771
# [180]	valid_0's multi_logloss: 2.72743
# [181]	valid_0's multi_logloss: 2.72712
# [182]	valid_0's multi_logloss: 2.72681
# [183]	valid_0's multi_logloss: 2.72655
# [184]	valid_0's multi_logloss: 2.72616
# [185]	valid_0's multi_logloss: 2.72592
# [186]	valid_0's multi_logloss: 2.7256
# [187]	valid_0's multi_logloss: 2.72539
# [188]	valid_0's multi_logloss: 2.72508
# [189]	valid_0's multi_logloss: 2.72476
# [190]	valid_0's multi_logloss: 2.72445
# [191]	valid_0's multi_logloss: 2.72411
# [192]	valid_0's multi_logloss: 2.72381
# [193]	valid_0's multi_logloss: 2.72353
# [194]	valid_0's multi_logloss: 2.72327
# [195]	valid_0's multi_logloss: 2.72298
# [196]	valid_0's multi_logloss: 2.72271
# [197]	valid_0's multi_logloss: 2.72243
# [198]	valid_0's multi_logloss: 2.72216
# [199]	valid_0's multi_logloss: 2.72186
# [200]	valid_0's multi_logloss: 2.72165
# [201]	valid_0's multi_logloss: 2.72141
# [202]	valid_0's multi_logloss: 2.72117
# [203]	valid_0's multi_logloss: 2.7209
# [204]	valid_0's multi_logloss: 2.7207
# [205]	valid_0's multi_logloss: 2.72046
# [206]	valid_0's multi_logloss: 2.72025
# [207]	valid_0's multi_logloss: 2.72002
# [208]	valid_0's multi_logloss: 2.71973
# [209]	valid_0's multi_logloss: 2.71944
# [210]	valid_0's multi_logloss: 2.71922
# [211]	valid_0's multi_logloss: 2.71906
# [212]	valid_0's multi_logloss: 2.71881
# [213]	valid_0's multi_logloss: 2.71862
# [214]	valid_0's multi_logloss: 2.71841
# [215]	valid_0's multi_logloss: 2.71816
# [216]	valid_0's multi_logloss: 2.71793
# [217]	valid_0's multi_logloss: 2.71776
# [218]	valid_0's multi_logloss: 2.71755
# [219]	valid_0's multi_logloss: 2.7174
# [220]	valid_0's multi_logloss: 2.71723
# [221]	valid_0's multi_logloss: 2.71697
# [222]	valid_0's multi_logloss: 2.71679
# [223]	valid_0's multi_logloss: 2.71656
# [224]	valid_0's multi_logloss: 2.71634
# [225]	valid_0's multi_logloss: 2.71614
# [226]	valid_0's multi_logloss: 2.71592
# [227]	valid_0's multi_logloss: 2.71573
# [228]	valid_0's multi_logloss: 2.71553
# [229]	valid_0's multi_logloss: 2.7154
# [230]	valid_0's multi_logloss: 2.71519
# [231]	valid_0's multi_logloss: 2.71503
# [232]	valid_0's multi_logloss: 2.71479
# [233]	valid_0's multi_logloss: 2.71462
# [234]	valid_0's multi_logloss: 2.71437
# [235]	valid_0's multi_logloss: 2.71418
# [236]	valid_0's multi_logloss: 2.714
# [237]	valid_0's multi_logloss: 2.71387
# [238]	valid_0's multi_logloss: 2.71362
# [239]	valid_0's multi_logloss: 2.71344
# [240]	valid_0's multi_logloss: 2.71325
# [241]	valid_0's multi_logloss: 2.71305
# [242]	valid_0's multi_logloss: 2.71283
# [243]	valid_0's multi_logloss: 2.71263
# [244]	valid_0's multi_logloss: 2.71247
# [245]	valid_0's multi_logloss: 2.71226
# [246]	valid_0's multi_logloss: 2.7121
# [247]	valid_0's multi_logloss: 2.71194
# [248]	valid_0's multi_logloss: 2.71179
# [249]	valid_0's multi_logloss: 2.71166
# [250]	valid_0's multi_logloss: 2.7115
# [251]	valid_0's multi_logloss: 2.7113
# [252]	valid_0's multi_logloss: 2.71116
# [253]	valid_0's multi_logloss: 2.71099
# [254]	valid_0's multi_logloss: 2.71084
# [255]	valid_0's multi_logloss: 2.71068
# [256]	valid_0's multi_logloss: 2.71051
# [257]	valid_0's multi_logloss: 2.71034
# [258]	valid_0's multi_logloss: 2.71022
# [259]	valid_0's multi_logloss: 2.71007
# [260]	valid_0's multi_logloss: 2.70991
# [261]	valid_0's multi_logloss: 2.70978
# [262]	valid_0's multi_logloss: 2.70956
# [263]	valid_0's multi_logloss: 2.70942
# [264]	valid_0's multi_logloss: 2.70926
# [265]	valid_0's multi_logloss: 2.70906
# [266]	valid_0's multi_logloss: 2.70891
# [267]	valid_0's multi_logloss: 2.70876
# [268]	valid_0's multi_logloss: 2.70865
# [269]	valid_0's multi_logloss: 2.7085
# [270]	valid_0's multi_logloss: 2.70832
# [271]	valid_0's multi_logloss: 2.70816
# [272]	valid_0's multi_logloss: 2.70803
# [273]	valid_0's multi_logloss: 2.70787
# [274]	valid_0's multi_logloss: 2.70771
# [275]	valid_0's multi_logloss: 2.70758
# [276]	valid_0's multi_logloss: 2.70744
# [277]	valid_0's multi_logloss: 2.70726
# [278]	valid_0's multi_logloss: 2.70712
# [279]	valid_0's multi_logloss: 2.70703
# [280]	valid_0's multi_logloss: 2.70693
# [281]	valid_0's multi_logloss: 2.70677
# ...
# [240]	valid_0's multi_logloss: 2.9084
# [241]	valid_0's multi_logloss: 2.90828
# [242]	valid_0's multi_logloss: 2.90817
# [243]	valid_0's multi_logloss: 2.90809
# [244]	valid_0's multi_logloss: 2.908
# [245]	valid_0's multi_logloss: 2.90795
# [246]	valid_0's multi_logloss: 2.90787
# [247]	valid_0's multi_logloss: 2.90781
# [248]	valid_0's multi_logloss: 2.90774
# [249]	valid_0's multi_logloss: 2.90767
# [250]	valid_0's multi_logloss: 2.90757
# [251]	valid_0's multi_logloss: 2.90754
# [252]	valid_0's multi_logloss: 2.9075
# [253]	valid_0's multi_logloss: 2.9074
# [254]	valid_0's multi_logloss: 2.90734
# [255]	valid_0's multi_logloss: 2.90733
# [256]	valid_0's multi_logloss: 2.90726
# [257]	valid_0's multi_logloss: 2.90717
# [258]	valid_0's multi_logloss: 2.90718
# [259]	valid_0's multi_logloss: 2.90714
# [260]	valid_0's multi_logloss: 2.90713
# [261]	valid_0's multi_logloss: 2.90709
# [262]	valid_0's multi_logloss: 2.90708
# [263]	valid_0's multi_logloss: 2.90698
# [264]	valid_0's multi_logloss: 2.90693
# [265]	valid_0's multi_logloss: 2.90687
# [266]	valid_0's multi_logloss: 2.9068
# [267]	valid_0's multi_logloss: 2.90678
# [268]	valid_0's multi_logloss: 2.90675
# [269]	valid_0's multi_logloss: 2.90668
# [270]	valid_0's multi_logloss: 2.90664
# [271]	valid_0's multi_logloss: 2.9066
# [272]	valid_0's multi_logloss: 2.90657
# [273]	valid_0's multi_logloss: 2.90652
# [274]	valid_0's multi_logloss: 2.9065
# [275]	valid_0's multi_logloss: 2.90644
# [276]	valid_0's multi_logloss: 2.90645
# [277]	valid_0's multi_logloss: 2.90637
# [278]	valid_0's multi_logloss: 2.90631
# [279]	valid_0's multi_logloss: 2.90624
# [280]	valid_0's multi_logloss: 2.90623
# [281]	valid_0's multi_logloss: 2.90619
# [282]	valid_0's multi_logloss: 2.90615
# [283]	valid_0's multi_logloss: 2.90611
# [284]	valid_0's multi_logloss: 2.90611
# [285]	valid_0's multi_logloss: 2.90608
# [286]	valid_0's multi_logloss: 2.90606
# [287]	valid_0's multi_logloss: 2.90603
# [288]	valid_0's multi_logloss: 2.90597
# [289]	valid_0's multi_logloss: 2.90587
# [290]	valid_0's multi_logloss: 2.90586
# [291]	valid_0's multi_logloss: 2.9058
# [292]	valid_0's multi_logloss: 2.90582
# [293]	valid_0's multi_logloss: 2.90576
# [294]	valid_0's multi_logloss: 2.90573
# [295]	valid_0's multi_logloss: 2.90569
# [296]	valid_0's multi_logloss: 2.9057
# [297]	valid_0's multi_logloss: 2.90567
# [298]	valid_0's multi_logloss: 2.90559
# [299]	valid_0's multi_logloss: 2.90552
# [300]	valid_0's multi_logloss: 2.90555
# [301]	valid_0's multi_logloss: 2.90552
# [302]	valid_0's multi_logloss: 2.90548
# [303]	valid_0's multi_logloss: 2.90546
# [304]	valid_0's multi_logloss: 2.90547
# [305]	valid_0's multi_logloss: 2.90544
# [306]	valid_0's multi_logloss: 2.90539
# [307]	valid_0's multi_logloss: 2.90535
# [308]	valid_0's multi_logloss: 2.90535
# [309]	valid_0's multi_logloss: 2.90538
# [310]	valid_0's multi_logloss: 2.90537
# [311]	valid_0's multi_logloss: 2.90534
# [312]	valid_0's multi_logloss: 2.90529
# [313]	valid_0's multi_logloss: 2.90523
# [314]	valid_0's multi_logloss: 2.90524
# [315]	valid_0's multi_logloss: 2.90521
# [316]	valid_0's multi_logloss: 2.90519
# [317]	valid_0's multi_logloss: 2.90518
# [318]	valid_0's multi_logloss: 2.90514
# [319]	valid_0's multi_logloss: 2.90509
# [320]	valid_0's multi_logloss: 2.90509
# [321]	valid_0's multi_logloss: 2.905
# [322]	valid_0's multi_logloss: 2.90503
# [323]	valid_0's multi_logloss: 2.90504
# [324]	valid_0's multi_logloss: 2.90503
# [325]	valid_0's multi_logloss: 2.905
# [326]	valid_0's multi_logloss: 2.90499
# [327]	valid_0's multi_logloss: 2.90497
# [328]	valid_0's multi_logloss: 2.90489
# [329]	valid_0's multi_logloss: 2.90485
# [330]	valid_0's multi_logloss: 2.90483
# [331]	valid_0's multi_logloss: 2.90488
# [332]	valid_0's multi_logloss: 2.90486
# [333]	valid_0's multi_logloss: 2.90484
# [334]	valid_0's multi_logloss: 2.90487
# [335]	valid_0's multi_logloss: 2.90486
# [336]	valid_0's multi_logloss: 2.90482
# [337]	valid_0's multi_logloss: 2.9048
# [338]	valid_0's multi_logloss: 2.90479
# [339]	valid_0's multi_logloss: 2.90483
# [340]	valid_0's multi_logloss: 2.90482
# [341]	valid_0's multi_logloss: 2.90484
# [342]	valid_0's multi_logloss: 2.90488
# [343]	valid_0's multi_logloss: 2.90488
# [344]	valid_0's multi_logloss: 2.90494
# [345]	valid_0's multi_logloss: 2.90496
# [346]	valid_0's multi_logloss: 2.90495
# [347]	valid_0's multi_logloss: 2.90498
# [348]	valid_0's multi_logloss: 2.90503
# Early stopping, best iteration is:
# [338]	valid_0's multi_logloss: 2.90479
# 0.014301423941255343
# [1]	valid_0's multi_logloss: 2.92634
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92527
# [3]	valid_0's multi_logloss: 2.92414
# [4]	valid_0's multi_logloss: 2.92308
# [5]	valid_0's multi_logloss: 2.92218
# [6]	valid_0's multi_logloss: 2.92133
# [7]	valid_0's multi_logloss: 2.92051
# [8]	valid_0's multi_logloss: 2.91985
# [9]	valid_0's multi_logloss: 2.91901
# [10]	valid_0's multi_logloss: 2.91826
# [11]	valid_0's multi_logloss: 2.91759
# [12]	valid_0's multi_logloss: 2.9169
# [13]	valid_0's multi_logloss: 2.91621
# [14]	valid_0's multi_logloss: 2.91553
# [15]	valid_0's multi_logloss: 2.91489
# [16]	valid_0's multi_logloss: 2.91418
# [17]	valid_0's multi_logloss: 2.91346
# [18]	valid_0's multi_logloss: 2.91283
# [19]	valid_0's multi_logloss: 2.91217
# [20]	valid_0's multi_logloss: 2.91148
# [21]	valid_0's multi_logloss: 2.91079
# [22]	valid_0's multi_logloss: 2.91025
# [23]	valid_0's multi_logloss: 2.90958
# [24]	valid_0's multi_logloss: 2.90902
# [25]	valid_0's multi_logloss: 2.90829
# [26]	valid_0's multi_logloss: 2.90769
# [27]	valid_0's multi_logloss: 2.90711
# [28]	valid_0's multi_logloss: 2.9066
# [29]	valid_0's multi_logloss: 2.90604
# [30]	valid_0's multi_logloss: 2.9055
# [31]	valid_0's multi_logloss: 2.90494
# [32]	valid_0's multi_logloss: 2.90441
# [33]	valid_0's multi_logloss: 2.90393
# [34]	valid_0's multi_logloss: 2.90339
# [35]	valid_0's multi_logloss: 2.90288
# [36]	valid_0's multi_logloss: 2.90234
# [37]	valid_0's multi_logloss: 2.90177
# [38]	valid_0's multi_logloss: 2.90132
# [39]	valid_0's multi_logloss: 2.90081
# [40]	valid_0's multi_logloss: 2.90033
# [41]	valid_0's multi_logloss: 2.89975
# [42]	valid_0's multi_logloss: 2.89929
# [43]	valid_0's multi_logloss: 2.8988
# [44]	valid_0's multi_logloss: 2.89824
# [45]	valid_0's multi_logloss: 2.89773
# [46]	valid_0's multi_logloss: 2.89718
# [47]	valid_0's multi_logloss: 2.89666
# [48]	valid_0's multi_logloss: 2.89621
# [49]	valid_0's multi_logloss: 2.89567
# [50]	valid_0's multi_logloss: 2.8952
# [51]	valid_0's multi_logloss: 2.8947
# [52]	valid_0's multi_logloss: 2.89421
# [53]	valid_0's multi_logloss: 2.89378
# [54]	valid_0's multi_logloss: 2.89335
# [55]	valid_0's multi_logloss: 2.89303
# [56]	valid_0's multi_logloss: 2.89258
# [57]	valid_0's multi_logloss: 2.89226
# [58]	valid_0's multi_logloss: 2.8919
# [59]	valid_0's multi_logloss: 2.89147
# [60]	valid_0's multi_logloss: 2.89112
# [61]	valid_0's multi_logloss: 2.89082
# [62]	valid_0's multi_logloss: 2.89039
# [63]	valid_0's multi_logloss: 2.89006
# [64]	valid_0's multi_logloss: 2.88981
# [65]	valid_0's multi_logloss: 2.88944
# [66]	valid_0's multi_logloss: 2.88911
# [67]	valid_0's multi_logloss: 2.88872
# [68]	valid_0's multi_logloss: 2.88844
# [69]	valid_0's multi_logloss: 2.88815
# [70]	valid_0's multi_logloss: 2.88783
# [71]	valid_0's multi_logloss: 2.88747
# [72]	valid_0's multi_logloss: 2.88717
# [73]	valid_0's multi_logloss: 2.88687
# [74]	valid_0's multi_logloss: 2.88645
# [75]	valid_0's multi_logloss: 2.88609
# [76]	valid_0's multi_logloss: 2.88581
# [77]	valid_0's multi_logloss: 2.88546
# [78]	valid_0's multi_logloss: 2.88506
# [79]	valid_0's multi_logloss: 2.88477
# [80]	valid_0's multi_logloss: 2.88451
# [81]	valid_0's multi_logloss: 2.88417
# [82]	valid_0's multi_logloss: 2.88389
# [83]	valid_0's multi_logloss: 2.88364
# [84]	valid_0's multi_logloss: 2.88326
# [85]	valid_0's multi_logloss: 2.88304
# [86]	valid_0's multi_logloss: 2.8827
# [87]	valid_0's multi_logloss: 2.88246
# [88]	valid_0's multi_logloss: 2.88216
# [89]	valid_0's multi_logloss: 2.88187
# [90]	valid_0's multi_logloss: 2.88164
# [91]	valid_0's multi_logloss: 2.88135
# [92]	valid_0's multi_logloss: 2.88104
# [93]	valid_0's multi_logloss: 2.88079
# [94]	valid_0's multi_logloss: 2.88051
# [95]	valid_0's multi_logloss: 2.8802
# [96]	valid_0's multi_logloss: 2.87987
# [97]	valid_0's multi_logloss: 2.87957
# [98]	valid_0's multi_logloss: 2.87928
# [99]	valid_0's multi_logloss: 2.87895
# [100]	valid_0's multi_logloss: 2.87876
# [101]	valid_0's multi_logloss: 2.87854
# [102]	valid_0's multi_logloss: 2.87831
# [103]	valid_0's multi_logloss: 2.87803
# [104]	valid_0's multi_logloss: 2.87776
# [105]	valid_0's multi_logloss: 2.87749
# [106]	valid_0's multi_logloss: 2.87722
# [107]	valid_0's multi_logloss: 2.8769
# [108]	valid_0's multi_logloss: 2.87667
# [109]	valid_0's multi_logloss: 2.8765
# [110]	valid_0's multi_logloss: 2.8763
# [111]	valid_0's multi_logloss: 2.87596
# [112]	valid_0's multi_logloss: 2.8757
# [113]	valid_0's multi_logloss: 2.87542
# [114]	valid_0's multi_logloss: 2.87522
# [115]	valid_0's multi_logloss: 2.87499
# [116]	valid_0's multi_logloss: 2.8747
# [117]	valid_0's multi_logloss: 2.87444
# [118]	valid_0's multi_logloss: 2.87428
# [119]	valid_0's multi_logloss: 2.8741
# [120]	valid_0's multi_logloss: 2.87383
# [121]	valid_0's multi_logloss: 2.87371
# [122]	valid_0's multi_logloss: 2.87353
# [123]	valid_0's multi_logloss: 2.87334
# [124]	valid_0's multi_logloss: 2.87307
# [125]	valid_0's multi_logloss: 2.87288
# [126]	valid_0's multi_logloss: 2.87268
# [127]	valid_0's multi_logloss: 2.87249
# [128]	valid_0's multi_logloss: 2.87222
# [129]	valid_0's multi_logloss: 2.872
# [130]	valid_0's multi_logloss: 2.87187
# [131]	valid_0's multi_logloss: 2.87168
# [132]	valid_0's multi_logloss: 2.8715
# [133]	valid_0's multi_logloss: 2.87126
# [134]	valid_0's multi_logloss: 2.87116
# [135]	valid_0's multi_logloss: 2.87096
# [136]	valid_0's multi_logloss: 2.8707
# [137]	valid_0's multi_logloss: 2.87047
# [138]	valid_0's multi_logloss: 2.87024
# [139]	valid_0's multi_logloss: 2.86999
# [140]	valid_0's multi_logloss: 2.86978
# [141]	valid_0's multi_logloss: 2.8696
# [142]	valid_0's multi_logloss: 2.86939
# [143]	valid_0's multi_logloss: 2.8691
# [144]	valid_0's multi_logloss: 2.86892
# [145]	valid_0's multi_logloss: 2.86852
# [146]	valid_0's multi_logloss: 2.86832
# [147]	valid_0's multi_logloss: 2.86815
# [148]	valid_0's multi_logloss: 2.86792
# [149]	valid_0's multi_logloss: 2.86772
# [150]	valid_0's multi_logloss: 2.86749
# [151]	valid_0's multi_logloss: 2.86716
# [152]	valid_0's multi_logloss: 2.86697
# [153]	valid_0's multi_logloss: 2.86681
# [154]	valid_0's multi_logloss: 2.86653
# [155]	valid_0's multi_logloss: 2.86636
# [156]	valid_0's multi_logloss: 2.86614
# [157]	valid_0's multi_logloss: 2.86594
# [158]	valid_0's multi_logloss: 2.86573
# [159]	valid_0's multi_logloss: 2.86558
# [160]	valid_0's multi_logloss: 2.8654
# [161]	valid_0's multi_logloss: 2.86523
# [162]	valid_0's multi_logloss: 2.86512
# [163]	valid_0's multi_logloss: 2.86489
# [164]	valid_0's multi_logloss: 2.8647
# [165]	valid_0's multi_logloss: 2.86448
# [166]	valid_0's multi_logloss: 2.86432
# [167]	valid_0's multi_logloss: 2.86416
# [168]	valid_0's multi_logloss: 2.86401
# [169]	valid_0's multi_logloss: 2.86395
# [170]	valid_0's multi_logloss: 2.86377
# [171]	valid_0's multi_logloss: 2.86367
# [172]	valid_0's multi_logloss: 2.86348
# [173]	valid_0's multi_logloss: 2.86331
# [174]	valid_0's multi_logloss: 2.86319
# [175]	valid_0's multi_logloss: 2.86305
# [176]	valid_0's multi_logloss: 2.8629
# [177]	valid_0's multi_logloss: 2.86276
# [178]	valid_0's multi_logloss: 2.86258
# [179]	valid_0's multi_logloss: 2.86241
# [180]	valid_0's multi_logloss: 2.86222
# [181]	valid_0's multi_logloss: 2.86207
# [182]	valid_0's multi_logloss: 2.86191
# [183]	valid_0's multi_logloss: 2.86175
# [184]	valid_0's multi_logloss: 2.86159
# [185]	valid_0's multi_logloss: 2.8614
# [186]	valid_0's multi_logloss: 2.86135
# [187]	valid_0's multi_logloss: 2.86117
# [188]	valid_0's multi_logloss: 2.86101
# [189]	valid_0's multi_logloss: 2.86085
# [190]	valid_0's multi_logloss: 2.86075
# [191]	valid_0's multi_logloss: 2.86065
# [192]	valid_0's multi_logloss: 2.86053
# [193]	valid_0's multi_logloss: 2.86049
# [194]	valid_0's multi_logloss: 2.86033
# [195]	valid_0's multi_logloss: 2.86022
# [196]	valid_0's multi_logloss: 2.86012
# [197]	valid_0's multi_logloss: 2.8601
# [198]	valid_0's multi_logloss: 2.85998
# [199]	valid_0's multi_logloss: 2.85993
# [200]	valid_0's multi_logloss: 2.85984
# [201]	valid_0's multi_logloss: 2.85974
# [202]	valid_0's multi_logloss: 2.85962
# [203]	valid_0's multi_logloss: 2.85957
# [204]	valid_0's multi_logloss: 2.85944
# [205]	valid_0's multi_logloss: 2.85933
# [206]	valid_0's multi_logloss: 2.85925
# [207]	valid_0's multi_logloss: 2.85918
# [208]	valid_0's multi_logloss: 2.85908
# [209]	valid_0's multi_logloss: 2.85897
# [210]	valid_0's multi_logloss: 2.85881
# [211]	valid_0's multi_logloss: 2.85872
# [212]	valid_0's multi_logloss: 2.85862
# [213]	valid_0's multi_logloss: 2.85854
# [214]	valid_0's multi_logloss: 2.85841
# [215]	valid_0's multi_logloss: 2.85834
# [216]	valid_0's multi_logloss: 2.85826
# [217]	valid_0's multi_logloss: 2.85818
# [218]	valid_0's multi_logloss: 2.85813
# [219]	valid_0's multi_logloss: 2.85806
# [220]	valid_0's multi_logloss: 2.8579
# [221]	valid_0's multi_logloss: 2.85776
# [222]	valid_0's multi_logloss: 2.85774
# [223]	valid_0's multi_logloss: 2.8577
# [224]	valid_0's multi_logloss: 2.85758
# [225]	valid_0's multi_logloss: 2.85759
# [226]	valid_0's multi_logloss: 2.85751
# [227]	valid_0's multi_logloss: 2.85741
# [228]	valid_0's multi_logloss: 2.85741
# [229]	valid_0's multi_logloss: 2.85734
# [230]	valid_0's multi_logloss: 2.85725
# [231]	valid_0's multi_logloss: 2.85716
# [232]	valid_0's multi_logloss: 2.85714
# [233]	valid_0's multi_logloss: 2.85708
# [234]	valid_0's multi_logloss: 2.85702
# [235]	valid_0's multi_logloss: 2.85701
# [236]	valid_0's multi_logloss: 2.85699
# [237]	valid_0's multi_logloss: 2.85693
# [238]	valid_0's multi_logloss: 2.85684
# [239]	valid_0's multi_logloss: 2.85676
# [240]	valid_0's multi_logloss: 2.85673
# [241]	valid_0's multi_logloss: 2.85667
# [242]	valid_0's multi_logloss: 2.85665
# [243]	valid_0's multi_logloss: 2.85658
# [244]	valid_0's multi_logloss: 2.85648
# [245]	valid_0's multi_logloss: 2.85641
# [246]	valid_0's multi_logloss: 2.85641
# [247]	valid_0's multi_logloss: 2.8564
# [248]	valid_0's multi_logloss: 2.85633
# [249]	valid_0's multi_logloss: 2.85626
# [250]	valid_0's multi_logloss: 2.85622
# [251]	valid_0's multi_logloss: 2.85621
# [252]	valid_0's multi_logloss: 2.85615
# [253]	valid_0's multi_logloss: 2.85613
# [254]	valid_0's multi_logloss: 2.85611
# [255]	valid_0's multi_logloss: 2.85607
# [256]	valid_0's multi_logloss: 2.85605
# [257]	valid_0's multi_logloss: 2.85604
# [258]	valid_0's multi_logloss: 2.85596
# [259]	valid_0's multi_logloss: 2.85585
# [260]	valid_0's multi_logloss: 2.85584
# [261]	valid_0's multi_logloss: 2.85586
# [262]	valid_0's multi_logloss: 2.85585
# [263]	valid_0's multi_logloss: 2.85585
# [264]	valid_0's multi_logloss: 2.85582
# [265]	valid_0's multi_logloss: 2.85581
# [266]	valid_0's multi_logloss: 2.85578
# [267]	valid_0's multi_logloss: 2.85576
# [268]	valid_0's multi_logloss: 2.85577
# [269]	valid_0's multi_logloss: 2.85578
# [270]	valid_0's multi_logloss: 2.85578
# [271]	valid_0's multi_logloss: 2.85574
# [272]	valid_0's multi_logloss: 2.85571
# [273]	valid_0's multi_logloss: 2.85565
# [274]	valid_0's multi_logloss: 2.85565
# [275]	valid_0's multi_logloss: 2.85563
# [276]	valid_0's multi_logloss: 2.85562
# [277]	valid_0's multi_logloss: 2.8556
# [278]	valid_0's multi_logloss: 2.85558
# [279]	valid_0's multi_logloss: 2.85555
# [280]	valid_0's multi_logloss: 2.85554
# [281]	valid_0's multi_logloss: 2.85551
# [282]	valid_0's multi_logloss: 2.85549
# [283]	valid_0's multi_logloss: 2.85547
# [284]	valid_0's multi_logloss: 2.85546
# [285]	valid_0's multi_logloss: 2.85554
# [286]	valid_0's multi_logloss: 2.85554
# [287]	valid_0's multi_logloss: 2.85552
# [288]	valid_0's multi_logloss: 2.85556
# [289]	valid_0's multi_logloss: 2.85556
# [290]	valid_0's multi_logloss: 2.85554
# [291]	valid_0's multi_logloss: 2.85559
# [292]	valid_0's multi_logloss: 2.85562
# [293]	valid_0's multi_logloss: 2.85563
# [294]	valid_0's multi_logloss: 2.85564
# Early stopping, best iteration is:
# [284]	valid_0's multi_logloss: 2.85546
# 0.014099192560802385
# crps list: [0.0124807291491228, 0.01229469803667161, 0.011914769756526881, 0.014301423941255343, 0.014099192560802385]
# average crps: 0.013018162688875805

# %% [markdown]
# - current status
# - crps list: [0.012499079618353474, 0.01228833604650279, 0.01192337912890213, 0.014299112499296895, 0.014103185890054359]
# - average crps: 0.013022618636621928
# -
# - when remove pithccontrol: let's remove
# - crps list: [0.012490041776871835, 0.012288235394010798, 0.011906650642501735, 0.014306268700305188, 0.01410241801072192]
# - average crps: 0.013018722904882294
# -
# - when further remove jerseycat let's remove
# -
# - when add physical data of offensive full-back
# - crps list: [0.0124807291491228, 0.01229469803667161, 0.011914769756526881, 0.014301423941255343, 0.014099192560802385]
# - average crps: 0.013018162688875805

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'PlayerWeight_FB', 'time_end', 'Grass', 'DefendersInTheBox_vs_Distance',
#        'DisToQB', 'runner_height', 'DefenseAveX', 'DefenseAveY',
#        'DefenseAveMomentum', 'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos',
#        '1stDefender_AttackAngle', 'RusherVoronoi', 'FirstDefenderVoronoi'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                           Grass     564     295     289     262     138
# 1                            Team     360     821     448     333     334
# 2                OffenseFormation     899     868     969     817     500
# 3                            Down     897    1214    1061     564     556
# 4                          Season    1855    1610    2508    1641    1596
# 5               DefendersInTheBox    2484    1532    2263    2157    1799
# 6                 PlayerWeight_FB    1955    1626    2795    2045    1823
# 7                DefensePersonnel    2481    2877    1870    1508    1691
# 8                   runner_height    1940    3522    3148    2011    1248
# 9                     StadiumType    3491    3844    3709    2026    2259
# 10               OffensePersonnel    3054    3704    3557    3752    2817
# 11                    GameWeather    4168    4002    4216    3319    1736
# 12            HomeScoreBeforePlay    3676    4646    3730    2182    3322
# 13                           Week    5452    4937    3994    2354    2392
# 14                       Distance    3342    6132    5442    3817    1269
# 15                      WindSpeed    5319    4465    4240    2982    3726
# 16                  WindDirection    4828    6595    4019    3058    2698
# 17                  RusherVoronoi    4992    4251    5049    3796    3139
# 18         VisitorScoreBeforePlay    4966    5951    4049    3772    3226
# 19                       Location    4780    6510    4014    4224    2658
# 20                            Dis    5929    5050    4021    3898    3595
# 21                   PlayerWeight    6496    6402    3862    2997    3255
# 22                        Stadium    6267    5276    5621    4849    3597
# 23                   JerseyNumber    5897    7151    5344    4264    3606
# 24                       Humidity    6575    6904    5830    3876    4971
# 25  DefendersInTheBox_vs_Distance   10678    6125    3668    4721    3187
# 26                              S    7302    6358    5353    4635    4966
# 27                    Temperature    7204    6251    6319    5172    4503
# 28                    Orientation    7142    7049    6929    4863    4161
# 29                    OffenseStdX    8590    7189    5669    4756    4125
# 30             OffenseAveMomentum    7965    7753    6187    4388    4544
# 31                    OffenseStdY    7074    7542    6583    5438    4563
# 32                    DefenseStdY    8866    7531    6268    5244    4219
# 33         RunnerToDefenseCentoid    7535    6712    7414    6059    5131
# 34                              X    8388    7576    7801    4888    4991
# 35         RunnerToOffenseCentoid    9216    9409    6602    5544    4888
# 36                          NflId    8028    8073    9670    5333    4876
# 37                              Y    9439    9507    7610    4549    5255
# 38                    DefenseAveX    6984    9247    8343    7393    4982
# 39                       Momentum    7912   10423    7928    5860    5613
# 40                 OffenseSpreadX    8848   10973    6868    6420    5701
# 41              PlayerCollegeName    9091    9121    7733    7318    5548
# 42         OffenseAveMomentum_cos    9817    9195    8928    5730    5170
# 43                            Dir    9120    9467    8883    6389    5077
# 44                    DefenseStdX    9564    9479    7894    6919    5406
# 45                            age   11026    8699    8396    6110    5252
# 46         OffenseStdMomentum_cos    9340   10172    8112    6419    5785
# 47             DefenseAveMomentum    8468   10193    9296    6666    5356
# 48                    DefenseAveY   10451    8992    9690    6836    5007
# 49                 DefenseSpreadX   11017   10544    7889    6189    5412
# 50             DefenseStdMomentum    9424    9992   10684    6538    5333
# 51                        DisToQB   11451   10643    9958    6754    5612
# 52           FirstDefenderVoronoi    9841   12469   10030    6737    5949
# 53             OffenseStdMomentum   10344   11534    9132    8268    7068
# 54                        Dir_cos   10976   12048   10117    6971    6334
# 55         DefenseStdMomentum_cos   11378   10457   10697    7625    6798
# 56                       time_end   10364   13561    8523    7949    7081
# 57                  MinTackleTime   11518   13363    9539    6251    7253
# 58              RunnerToScrimmage   12204   12788   10240    8664    6706
# 59                       YardLine   11825   13366   11821    7875    6792
# 60         DefenseAveMomentum_cos   14339   12380   11006    7760    7212
# 61       1stOffenser_Momentum_cos   14249   12843   11431    9099    7476
# 62        1stDefender_AttackAngle   13613   15045   10650    8812    8726
# 63                   Momentum_cos   13537   14065   12736    9738    9429
# 64       1stDefender_Momentum_cos   13891   16041   12288   10437    8151
# 65                              A   22543   22237   17859   18986   19098
#
#     Average          Std        Cv
# 0     309.6   139.333557  0.450044
# 1     459.2   185.723881  0.404451
# 2     810.6   162.919121  0.200986
# 3     858.4   263.478728  0.306942
# 4    1842.0   345.967050  0.187821
# 5    2047.0   339.544990  0.165874
# 6    2048.8   398.841522  0.194671
# 7    2085.4   513.511285  0.246241
# 8    2373.8   837.255134  0.352707
# 9    3065.8   765.794594  0.249786
# 10   3376.8   373.599465  0.110637
# 11   3488.2   933.235747  0.267541
# 12   3511.2   795.659827  0.226606
# 13   3825.8  1275.112607  0.333293
# 14   4000.4  1705.848833  0.426420
# 15   4146.4   776.893970  0.187366
# 16   4239.6  1393.951018  0.328793
# 17   4245.4   725.161665  0.170811
# 18   4392.8   961.411338  0.218861
# 19   4437.2  1249.329164  0.281558
# 20   4498.6   866.648856  0.192649
# 21   4602.4  1533.966701  0.333297
# 22   5122.0   892.624893  0.174273
# 23   5252.4  1242.268023  0.236514
# 24   5631.2  1101.534457  0.195613
# 25   5675.8  2696.694821  0.475122
# 26   5722.8   978.790968  0.171034
# 27   5889.8   946.599261  0.160718
# 28   6028.8  1260.011809  0.208999
# 29   6065.8  1629.287869  0.268602
# 30   6167.4  1519.708472  0.246410
# 31   6240.0  1092.148525  0.175024
# 32   6425.6  1641.192323  0.255415
# 33   6570.2   893.931407  0.136058
# 34   6728.8  1485.180043  0.220720
# 35   7131.8  1863.650439  0.261316
# 36   7196.0  1813.019470  0.251948
# 37   7272.0  2063.413483  0.283748
# 38   7389.8  1436.660489  0.194411
# 39   7547.2  1739.890043  0.230535
# 40   7762.0  1915.089450  0.246726
# 41   7762.2  1320.067786  0.170064
# 42   7768.0  1922.674075  0.247512
# 43   7787.2  1737.757682  0.223156
# 44   7852.4  1576.910980  0.200819
# 45   7896.6  2043.146554  0.258738
# 46   7965.6  1668.867712  0.209509
# 47   7995.8  1759.437001  0.220045
# 48   8195.2  1998.499177  0.243862
# 49   8210.2  2251.359181  0.274215
# 50   8394.2  2081.973141  0.248025
# 51   8883.6  2283.853288  0.257086
# 52   9005.2  2376.206085  0.263870
# 53   9269.2  1558.911210  0.168182
# 54   9289.2  2247.166340  0.241912
# 55   9391.0  1823.873132  0.194215
# 56   9495.6  2299.991791  0.242217
# 57   9584.8  2629.283887  0.274318
# 58  10120.4  2247.265503  0.222053
# 59  10335.8  2538.491788  0.245602
# 60  10539.4  2714.374300  0.257545
# 61  11019.6  2456.374043  0.222910
# 62  11369.2  2553.004928  0.224554
# 63  11901.0  1941.441217  0.163133
# 64  12161.6  2724.544116  0.224028
# 65  20144.6  1886.380301  0.093642

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

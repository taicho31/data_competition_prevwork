# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
from datetime import datetime
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf', 'Quarter']
top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]
    
    #df["Jersey_cat"] = df["JerseyNumber"].apply(lambda x: 0 if x>=1 and x <=9 else #: quarterbacks, kickers, and punters
    #                                            (1 if x>=10 and x <= 19 else
    #                                            (2 if x>=20 and x <= 39 else
    #                                            (3 if x>=40 and x <= 49 else
    #                                            (4 if x>=50 and x <= 59 else
    #                                            (5 if x>=60 and x <= 79 else
    #                                            (6 if x>=80 and x <= 89 else
    #                                            (7 if x>=90 and x <= 99 else 8))))))))

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    #df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]
    
    df["AttackAngle"] =  np.arctan((df["Y"] - df["RushY"]) / (df["X"] - df["RushX"])) * 180 / np.pi

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    #if 2017 in list(df["Season"].unique()):
    #    df_fb = df[df.Position == "FB"].copy()
    #    tmp = df_fb.groupby(["PlayId", "OnOffense"]).agg(np.mean)["PlayerWeight"].reset_index()
    #    tmp = tmp[tmp.OnOffense==True]
    #    tmp.rename(columns={'PlayerWeight': 'PlayerWeight_FB'}, inplace=True)
    #    df_single = pd.merge(df_single, tmp[["PlayId", "PlayerWeight_FB"]], on = "PlayId", how="left")
    #else:
    #    if "FB" in list(df.Position.unique()): # details of offensive full-back
    #        df_fb = df[df.Position == "FB"].copy()
    #        tmp = df_fb.groupby(["PlayId", "OnOffense"]).agg(np.mean)["PlayerWeight"].reset_index()
    #        tmp = tmp[tmp.OnOffense==True]
    #        tmp.rename(columns={'PlayerWeight': 'PlayerWeight_FB'}, inplace=True)
    #        df_single = pd.merge(df_single, tmp[["PlayId", "PlayerWeight_FB"]], on = "PlayId", how="left")
    #    else:
    #        df_single["PlayerWeight_FB"] = -999 
        
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])
    df_single["1stDefender_AttackAngle"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["AttackAngle"])
    # df_single["1stDefenderID"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["NflId"])
    
    #df_single["OffenseLine_Weight"] = np.array(train.groupby(["PlayId", "OnOffense"])["PlayerWeight"].max()[1::2])
    #df_single["OffenseLine_Height"] = np.array(train.groupby(["PlayId", "OnOffense"])["PlayerHeight"].max()[1::2])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    #def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    #off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    #df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY", "AttackAngle"]#"InfluToBall", , "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:856: RuntimeWarning: invalid value encountered in arctan
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# CPU times: user 5min 26s, sys: 2.53 s, total: 5min 28s
# Wall time: 5min 27s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : 5,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86884
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86602
# [3]	valid_0's multi_logloss: 2.86391
# [4]	valid_0's multi_logloss: 2.86174
# [5]	valid_0's multi_logloss: 2.85968
# [6]	valid_0's multi_logloss: 2.85758
# [7]	valid_0's multi_logloss: 2.8556
# [8]	valid_0's multi_logloss: 2.85373
# [9]	valid_0's multi_logloss: 2.85209
# [10]	valid_0's multi_logloss: 2.85038
# [11]	valid_0's multi_logloss: 2.84852
# [12]	valid_0's multi_logloss: 2.84687
# [13]	valid_0's multi_logloss: 2.84525
# [14]	valid_0's multi_logloss: 2.84357
# [15]	valid_0's multi_logloss: 2.84194
# [16]	valid_0's multi_logloss: 2.84051
# [17]	valid_0's multi_logloss: 2.83904
# [18]	valid_0's multi_logloss: 2.83742
# [19]	valid_0's multi_logloss: 2.83604
# [20]	valid_0's multi_logloss: 2.83459
# [21]	valid_0's multi_logloss: 2.83313
# [22]	valid_0's multi_logloss: 2.83171
# [23]	valid_0's multi_logloss: 2.83024
# [24]	valid_0's multi_logloss: 2.82883
# [25]	valid_0's multi_logloss: 2.82748
# [26]	valid_0's multi_logloss: 2.8261
# [27]	valid_0's multi_logloss: 2.82475
# [28]	valid_0's multi_logloss: 2.8234
# [29]	valid_0's multi_logloss: 2.82204
# [30]	valid_0's multi_logloss: 2.82078
# [31]	valid_0's multi_logloss: 2.81951
# [32]	valid_0's multi_logloss: 2.81825
# [33]	valid_0's multi_logloss: 2.81705
# [34]	valid_0's multi_logloss: 2.8158
# [35]	valid_0's multi_logloss: 2.81458
# [36]	valid_0's multi_logloss: 2.81348
# [37]	valid_0's multi_logloss: 2.81226
# [38]	valid_0's multi_logloss: 2.81119
# [39]	valid_0's multi_logloss: 2.81019
# [40]	valid_0's multi_logloss: 2.80917
# [41]	valid_0's multi_logloss: 2.808
# [42]	valid_0's multi_logloss: 2.80696
# [43]	valid_0's multi_logloss: 2.80595
# [44]	valid_0's multi_logloss: 2.80488
# [45]	valid_0's multi_logloss: 2.80389
# [46]	valid_0's multi_logloss: 2.80291
# [47]	valid_0's multi_logloss: 2.80194
# [48]	valid_0's multi_logloss: 2.80091
# [49]	valid_0's multi_logloss: 2.79992
# [50]	valid_0's multi_logloss: 2.7989
# [51]	valid_0's multi_logloss: 2.79794
# [52]	valid_0's multi_logloss: 2.79705
# [53]	valid_0's multi_logloss: 2.79604
# [54]	valid_0's multi_logloss: 2.79512
# [55]	valid_0's multi_logloss: 2.79421
# [56]	valid_0's multi_logloss: 2.79327
# [57]	valid_0's multi_logloss: 2.79239
# [58]	valid_0's multi_logloss: 2.79145
# [59]	valid_0's multi_logloss: 2.79058
# [60]	valid_0's multi_logloss: 2.78959
# [61]	valid_0's multi_logloss: 2.78865
# [62]	valid_0's multi_logloss: 2.78787
# [63]	valid_0's multi_logloss: 2.7869
# [64]	valid_0's multi_logloss: 2.78605
# [65]	valid_0's multi_logloss: 2.78507
# [66]	valid_0's multi_logloss: 2.78414
# [67]	valid_0's multi_logloss: 2.78312
# [68]	valid_0's multi_logloss: 2.78218
# [69]	valid_0's multi_logloss: 2.78137
# [70]	valid_0's multi_logloss: 2.78054
# [71]	valid_0's multi_logloss: 2.77973
# [72]	valid_0's multi_logloss: 2.77881
# [73]	valid_0's multi_logloss: 2.77795
# [74]	valid_0's multi_logloss: 2.77714
# [75]	valid_0's multi_logloss: 2.77629
# [76]	valid_0's multi_logloss: 2.77543
# [77]	valid_0's multi_logloss: 2.77455
# [78]	valid_0's multi_logloss: 2.7738
# [79]	valid_0's multi_logloss: 2.77299
# [80]	valid_0's multi_logloss: 2.77218
# [81]	valid_0's multi_logloss: 2.77136
# [82]	valid_0's multi_logloss: 2.7706
# [83]	valid_0's multi_logloss: 2.76981
# [84]	valid_0's multi_logloss: 2.76896
# [85]	valid_0's multi_logloss: 2.76827
# [86]	valid_0's multi_logloss: 2.7675
# [87]	valid_0's multi_logloss: 2.76669
# [88]	valid_0's multi_logloss: 2.76602
# [89]	valid_0's multi_logloss: 2.76532
# [90]	valid_0's multi_logloss: 2.76462
# [91]	valid_0's multi_logloss: 2.76389
# [92]	valid_0's multi_logloss: 2.76319
# [93]	valid_0's multi_logloss: 2.76248
# [94]	valid_0's multi_logloss: 2.7618
# [95]	valid_0's multi_logloss: 2.76115
# [96]	valid_0's multi_logloss: 2.76042
# [97]	valid_0's multi_logloss: 2.7597
# [98]	valid_0's multi_logloss: 2.75919
# [99]	valid_0's multi_logloss: 2.75852
# [100]	valid_0's multi_logloss: 2.7578
# [101]	valid_0's multi_logloss: 2.75711
# [102]	valid_0's multi_logloss: 2.75643
# [103]	valid_0's multi_logloss: 2.75568
# [104]	valid_0's multi_logloss: 2.75499
# [105]	valid_0's multi_logloss: 2.7543
# [106]	valid_0's multi_logloss: 2.7537
# [107]	valid_0's multi_logloss: 2.75305
# [108]	valid_0's multi_logloss: 2.7524
# [109]	valid_0's multi_logloss: 2.75181
# [110]	valid_0's multi_logloss: 2.7512
# [111]	valid_0's multi_logloss: 2.75068
# [112]	valid_0's multi_logloss: 2.75003
# [113]	valid_0's multi_logloss: 2.74947
# [114]	valid_0's multi_logloss: 2.74883
# [115]	valid_0's multi_logloss: 2.74828
# [116]	valid_0's multi_logloss: 2.74767
# [117]	valid_0's multi_logloss: 2.74715
# [118]	valid_0's multi_logloss: 2.74657
# [119]	valid_0's multi_logloss: 2.74604
# [120]	valid_0's multi_logloss: 2.74543
# [121]	valid_0's multi_logloss: 2.74481
# [122]	valid_0's multi_logloss: 2.74439
# [123]	valid_0's multi_logloss: 2.74384
# [124]	valid_0's multi_logloss: 2.74335
# [125]	valid_0's multi_logloss: 2.74281
# [126]	valid_0's multi_logloss: 2.74225
# [127]	valid_0's multi_logloss: 2.74171
# [128]	valid_0's multi_logloss: 2.74125
# [129]	valid_0's multi_logloss: 2.74069
# [130]	valid_0's multi_logloss: 2.74016
# [131]	valid_0's multi_logloss: 2.7397
# [132]	valid_0's multi_logloss: 2.73933
# [133]	valid_0's multi_logloss: 2.73884
# [134]	valid_0's multi_logloss: 2.73835
# [135]	valid_0's multi_logloss: 2.73788
# [136]	valid_0's multi_logloss: 2.73744
# [137]	valid_0's multi_logloss: 2.73702
# [138]	valid_0's multi_logloss: 2.73663
# [139]	valid_0's multi_logloss: 2.73615
# [140]	valid_0's multi_logloss: 2.73573
# [141]	valid_0's multi_logloss: 2.73531
# [142]	valid_0's multi_logloss: 2.7348
# [143]	valid_0's multi_logloss: 2.73434
# [144]	valid_0's multi_logloss: 2.73388
# [145]	valid_0's multi_logloss: 2.73341
# [146]	valid_0's multi_logloss: 2.733
# [147]	valid_0's multi_logloss: 2.73252
# [148]	valid_0's multi_logloss: 2.73209
# [149]	valid_0's multi_logloss: 2.73166
# [150]	valid_0's multi_logloss: 2.73129
# [151]	valid_0's multi_logloss: 2.73084
# [152]	valid_0's multi_logloss: 2.73045
# [153]	valid_0's multi_logloss: 2.73001
# [154]	valid_0's multi_logloss: 2.72961
# [155]	valid_0's multi_logloss: 2.72921
# [156]	valid_0's multi_logloss: 2.72875
# [157]	valid_0's multi_logloss: 2.72835
# [158]	valid_0's multi_logloss: 2.72791
# [159]	valid_0's multi_logloss: 2.72745
# [160]	valid_0's multi_logloss: 2.72708
# [161]	valid_0's multi_logloss: 2.72669
# [162]	valid_0's multi_logloss: 2.72629
# [163]	valid_0's multi_logloss: 2.72589
# [164]	valid_0's multi_logloss: 2.72554
# [165]	valid_0's multi_logloss: 2.72514
# [166]	valid_0's multi_logloss: 2.72471
# [167]	valid_0's multi_logloss: 2.72433
# [168]	valid_0's multi_logloss: 2.72399
# [169]	valid_0's multi_logloss: 2.72362
# [170]	valid_0's multi_logloss: 2.72323
# [171]	valid_0's multi_logloss: 2.72287
# [172]	valid_0's multi_logloss: 2.72254
# [173]	valid_0's multi_logloss: 2.72219
# [174]	valid_0's multi_logloss: 2.72185
# [175]	valid_0's multi_logloss: 2.72146
# [176]	valid_0's multi_logloss: 2.72116
# [177]	valid_0's multi_logloss: 2.72079
# [178]	valid_0's multi_logloss: 2.7204
# [179]	valid_0's multi_logloss: 2.72003
# [180]	valid_0's multi_logloss: 2.71975
# [181]	valid_0's multi_logloss: 2.71941
# [182]	valid_0's multi_logloss: 2.71904
# [183]	valid_0's multi_logloss: 2.71872
# [184]	valid_0's multi_logloss: 2.71837
# [185]	valid_0's multi_logloss: 2.71806
# [186]	valid_0's multi_logloss: 2.71773
# [187]	valid_0's multi_logloss: 2.71742
# [188]	valid_0's multi_logloss: 2.71716
# [189]	valid_0's multi_logloss: 2.71688
# [190]	valid_0's multi_logloss: 2.7166
# [191]	valid_0's multi_logloss: 2.71629
# [192]	valid_0's multi_logloss: 2.71597
# [193]	valid_0's multi_logloss: 2.71567
# [194]	valid_0's multi_logloss: 2.71539
# [195]	valid_0's multi_logloss: 2.71514
# [196]	valid_0's multi_logloss: 2.71481
# [197]	valid_0's multi_logloss: 2.71452
# [198]	valid_0's multi_logloss: 2.71426
# [199]	valid_0's multi_logloss: 2.71396
# [200]	valid_0's multi_logloss: 2.71377
# [201]	valid_0's multi_logloss: 2.71347
# [202]	valid_0's multi_logloss: 2.71322
# [203]	valid_0's multi_logloss: 2.71299
# [204]	valid_0's multi_logloss: 2.71275
# [205]	valid_0's multi_logloss: 2.7125
# [206]	valid_0's multi_logloss: 2.71225
# [207]	valid_0's multi_logloss: 2.71199
# [208]	valid_0's multi_logloss: 2.71177
# [209]	valid_0's multi_logloss: 2.71155
# [210]	valid_0's multi_logloss: 2.71131
# [211]	valid_0's multi_logloss: 2.71112
# [212]	valid_0's multi_logloss: 2.7108
# [213]	valid_0's multi_logloss: 2.71057
# [214]	valid_0's multi_logloss: 2.71035
# [215]	valid_0's multi_logloss: 2.71016
# [216]	valid_0's multi_logloss: 2.70994
# [217]	valid_0's multi_logloss: 2.70974
# [218]	valid_0's multi_logloss: 2.70954
# [219]	valid_0's multi_logloss: 2.70927
# [220]	valid_0's multi_logloss: 2.70905
# [221]	valid_0's multi_logloss: 2.7088
# [222]	valid_0's multi_logloss: 2.70863
# [223]	valid_0's multi_logloss: 2.70838
# [224]	valid_0's multi_logloss: 2.70817
# [225]	valid_0's multi_logloss: 2.70792
# [226]	valid_0's multi_logloss: 2.70768
# [227]	valid_0's multi_logloss: 2.70751
# [228]	valid_0's multi_logloss: 2.70732
# [229]	valid_0's multi_logloss: 2.70713
# [230]	valid_0's multi_logloss: 2.70686
# [231]	valid_0's multi_logloss: 2.70668
# [232]	valid_0's multi_logloss: 2.70653
# [233]	valid_0's multi_logloss: 2.70629
# [234]	valid_0's multi_logloss: 2.70614
# [235]	valid_0's multi_logloss: 2.70595
# [236]	valid_0's multi_logloss: 2.70575
# [237]	valid_0's multi_logloss: 2.70557
# [238]	valid_0's multi_logloss: 2.70541
# [239]	valid_0's multi_logloss: 2.70523
# [240]	valid_0's multi_logloss: 2.70508
# [241]	valid_0's multi_logloss: 2.7049
# [242]	valid_0's multi_logloss: 2.70477
# [243]	valid_0's multi_logloss: 2.7045
# [244]	valid_0's multi_logloss: 2.70434
# [245]	valid_0's multi_logloss: 2.70415
# [246]	valid_0's multi_logloss: 2.70393
# [247]	valid_0's multi_logloss: 2.70375
# [248]	valid_0's multi_logloss: 2.70359
# [249]	valid_0's multi_logloss: 2.70344
# [250]	valid_0's multi_logloss: 2.70317
# [251]	valid_0's multi_logloss: 2.70302
# [252]	valid_0's multi_logloss: 2.70293
# [253]	valid_0's multi_logloss: 2.70277
# [254]	valid_0's multi_logloss: 2.70257
# [255]	valid_0's multi_logloss: 2.70238
# [256]	valid_0's multi_logloss: 2.70227
# [257]	valid_0's multi_logloss: 2.70217
# [258]	valid_0's multi_logloss: 2.70198
# [259]	valid_0's multi_logloss: 2.7018
# [260]	valid_0's multi_logloss: 2.70163
# [261]	valid_0's multi_logloss: 2.70149
# [262]	valid_0's multi_logloss: 2.7013
# [263]	valid_0's multi_logloss: 2.70118
# [264]	valid_0's multi_logloss: 2.70107
# [265]	valid_0's multi_logloss: 2.70093
# [266]	valid_0's multi_logloss: 2.70078
# [267]	valid_0's multi_logloss: 2.70061
# [268]	valid_0's multi_logloss: 2.70046
# [269]	valid_0's multi_logloss: 2.70027
# [270]	valid_0's multi_logloss: 2.70012
# [271]	valid_0's multi_logloss: 2.69994
# [272]	valid_0's multi_logloss: 2.69981
# [273]	valid_0's multi_logloss: 2.69967
# [274]	valid_0's multi_logloss: 2.69957
# [275]	valid_0's multi_logloss: 2.69941
# [276]	valid_0's multi_logloss: 2.69927
# [277]	valid_0's multi_logloss: 2.69914
# [278]	valid_0's multi_logloss: 2.69893
# [279]	valid_0's multi_logloss: 2.69878
# [280]	valid_0's multi_logloss: 2.69864
# [281]	valid_0's multi_logloss: 2.69846
# [282]	valid_0's multi_logloss: 2.69835
# [283]	valid_0's multi_logloss: 2.69824
# [284]	valid_0's multi_logloss: 2.6981
# [285]	valid_0's multi_logloss: 2.69794
# [286]	valid_0's multi_logloss: 2.6978
# [287]	valid_0's multi_logloss: 2.69768
# [288]	valid_0's multi_logloss: 2.69753
# [289]	valid_0's multi_logloss: 2.69742
# [290]	valid_0's multi_logloss: 2.69731
# [291]	valid_0's multi_logloss: 2.69712
# [292]	valid_0's multi_logloss: 2.69696
# [293]	valid_0's multi_logloss: 2.69682
# [294]	valid_0's multi_logloss: 2.69675
# [295]	valid_0's multi_logloss: 2.6966
# [296]	valid_0's multi_logloss: 2.69646
# [297]	valid_0's multi_logloss: 2.69637
# [298]	valid_0's multi_logloss: 2.69618
# [299]	valid_0's multi_logloss: 2.69604
# [300]	valid_0's multi_logloss: 2.69594
# [301]	valid_0's multi_logloss: 2.69584
# [302]	valid_0's multi_logloss: 2.69579
# [303]	valid_0's multi_logloss: 2.69563
# [304]	valid_0's multi_logloss: 2.69551
# [305]	valid_0's multi_logloss: 2.69542
# [306]	valid_0's multi_logloss: 2.69531
# [307]	valid_0's multi_logloss: 2.69517
# [308]	valid_0's multi_logloss: 2.69509
# [309]	valid_0's multi_logloss: 2.69497
# [310]	valid_0's multi_logloss: 2.69477
# [311]	valid_0's multi_logloss: 2.69469
# [312]	valid_0's multi_logloss: 2.69457
# [313]	valid_0's multi_logloss: 2.69443
# [314]	valid_0's multi_logloss: 2.69434
# [315]	valid_0's multi_logloss: 2.69424
# [316]	valid_0's multi_logloss: 2.69414
# [317]	valid_0's multi_logloss: 2.69404
# [318]	valid_0's multi_logloss: 2.69388
# [319]	valid_0's multi_logloss: 2.69381
# [320]	valid_0's multi_logloss: 2.69371
# [321]	valid_0's multi_logloss: 2.69366
# [322]	valid_0's multi_logloss: 2.69354
# [323]	valid_0's multi_logloss: 2.69343
# [324]	valid_0's multi_logloss: 2.69329
# [325]	valid_0's multi_logloss: 2.69323
# [326]	valid_0's multi_logloss: 2.6931
# [327]	valid_0's multi_logloss: 2.69305
# [328]	valid_0's multi_logloss: 2.693
# [329]	valid_0's multi_logloss: 2.69295
# [330]	valid_0's multi_logloss: 2.69283
# [331]	valid_0's multi_logloss: 2.6928
# [332]	valid_0's multi_logloss: 2.69267
# [333]	valid_0's multi_logloss: 2.69259
# [334]	valid_0's multi_logloss: 2.69254
# [335]	valid_0's multi_logloss: 2.69249
# [336]	valid_0's multi_logloss: 2.69243
# [337]	valid_0's multi_logloss: 2.69229
# [338]	valid_0's multi_logloss: 2.69218
# [339]	valid_0's multi_logloss: 2.69213
# [340]	valid_0's multi_logloss: 2.692
# [341]	valid_0's multi_logloss: 2.69197
# [342]	valid_0's multi_logloss: 2.69195
# [343]	valid_0's multi_logloss: 2.69183
# [344]	valid_0's multi_logloss: 2.69178
# [345]	valid_0's multi_logloss: 2.69172
# [346]	valid_0's multi_logloss: 2.69168
# [347]	valid_0's multi_logloss: 2.69158
# [348]	valid_0's multi_logloss: 2.69151
# [349]	valid_0's multi_logloss: 2.69144
# [350]	valid_0's multi_logloss: 2.69134
# [351]	valid_0's multi_logloss: 2.69127
# [352]	valid_0's multi_logloss: 2.69123
# [353]	valid_0's multi_logloss: 2.69117
# [354]	valid_0's multi_logloss: 2.6911
# [355]	valid_0's multi_logloss: 2.69107
# [356]	valid_0's multi_logloss: 2.69094
# [357]	valid_0's multi_logloss: 2.6909
# [358]	valid_0's multi_logloss: 2.69087
# [359]	valid_0's multi_logloss: 2.69083
# [360]	valid_0's multi_logloss: 2.69075
# [361]	valid_0's multi_logloss: 2.69071
# [362]	valid_0's multi_logloss: 2.69063
# [363]	valid_0's multi_logloss: 2.69057
# [364]	valid_0's multi_logloss: 2.6905
# [365]	valid_0's multi_logloss: 2.69038
# [366]	valid_0's multi_logloss: 2.6903
# [367]	valid_0's multi_logloss: 2.69027
# [368]	valid_0's multi_logloss: 2.69026
# [369]	valid_0's multi_logloss: 2.69019
# [370]	valid_0's multi_logloss: 2.69017
# [371]	valid_0's multi_logloss: 2.69016
# [372]	valid_0's multi_logloss: 2.69009
# [373]	valid_0's multi_logloss: 2.69002
# [374]	valid_0's multi_logloss: 2.68995
# [375]	valid_0's multi_logloss: 2.68988
# [376]	valid_0's multi_logloss: 2.6899
# [377]	valid_0's multi_logloss: 2.68984
# [378]	valid_0's multi_logloss: 2.6898
# [379]	valid_0's multi_logloss: 2.68975
# [380]	valid_0's multi_logloss: 2.68973
# [381]	valid_0's multi_logloss: 2.68963
# [382]	valid_0's multi_logloss: 2.68966
# [383]	valid_0's multi_logloss: 2.68963
# [384]	valid_0's multi_logloss: 2.68955
# [385]	valid_0's multi_logloss: 2.6895
# [386]	valid_0's multi_logloss: 2.68941
# [387]	valid_0's multi_logloss: 2.68935
# [388]	valid_0's multi_logloss: 2.68932
# [389]	valid_0's multi_logloss: 2.68932
# [390]	valid_0's multi_logloss: 2.6893
# [391]	valid_0's multi_logloss: 2.68917
# [392]	valid_0's multi_logloss: 2.68915
# [393]	valid_0's multi_logloss: 2.68913
# [394]	valid_0's multi_logloss: 2.6891
# [395]	valid_0's multi_logloss: 2.68908
# [396]	valid_0's multi_logloss: 2.68901
# [397]	valid_0's multi_logloss: 2.68899
# [398]	valid_0's multi_logloss: 2.68899
# [399]	valid_0's multi_logloss: 2.68891
# [400]	valid_0's multi_logloss: 2.68886
# [401]	valid_0's multi_logloss: 2.68883
# [402]	valid_0's multi_logloss: 2.68887
# [403]	valid_0's multi_logloss: 2.68886
# [404]	valid_0's multi_logloss: 2.68881
# [405]	valid_0's multi_logloss: 2.68876
# [406]	valid_0's multi_logloss: 2.68876
# [407]	valid_0's multi_logloss: 2.68868
# [408]	valid_0's multi_logloss: 2.68863
# [409]	valid_0's multi_logloss: 2.6886
# [410]	valid_0's multi_logloss: 2.68854
# [411]	valid_0's multi_logloss: 2.68848
# [412]	valid_0's multi_logloss: 2.68847
# [413]	valid_0's multi_logloss: 2.68842
# [414]	valid_0's multi_logloss: 2.68832
# [415]	valid_0's multi_logloss: 2.68835
# [416]	valid_0's multi_logloss: 2.68825
# [417]	valid_0's multi_logloss: 2.68825
# [418]	valid_0's multi_logloss: 2.68819
# [419]	valid_0's multi_logloss: 2.68817
# [420]	valid_0's multi_logloss: 2.68813
# [421]	valid_0's multi_logloss: 2.68811
# [422]	valid_0's multi_logloss: 2.68812
# [423]	valid_0's multi_logloss: 2.68805
# [424]	valid_0's multi_logloss: 2.68805
# [425]	valid_0's multi_logloss: 2.68801
# [426]	valid_0's multi_logloss: 2.68801
# [427]	valid_0's multi_logloss: 2.688
# [428]	valid_0's multi_logloss: 2.68799
# [429]	valid_0's multi_logloss: 2.68795
# [430]	valid_0's multi_logloss: 2.68793
# [431]	valid_0's multi_logloss: 2.68786
# [432]	valid_0's multi_logloss: 2.68786
# [433]	valid_0's multi_logloss: 2.68787
# [434]	valid_0's multi_logloss: 2.68786
# [435]	valid_0's multi_logloss: 2.68782
# [436]	valid_0's multi_logloss: 2.68779
# [437]	valid_0's multi_logloss: 2.68781
# [438]	valid_0's multi_logloss: 2.68781
# [439]	valid_0's multi_logloss: 2.68779
# [440]	valid_0's multi_logloss: 2.68777
# [441]	valid_0's multi_logloss: 2.68778
# [442]	valid_0's multi_logloss: 2.68775
# [443]	valid_0's multi_logloss: 2.68774
# [444]	valid_0's multi_logloss: 2.68773
# [445]	valid_0's multi_logloss: 2.68774
# [446]	valid_0's multi_logloss: 2.68766
# [447]	valid_0's multi_logloss: 2.68765
# [448]	valid_0's multi_logloss: 2.68758
# [449]	valid_0's multi_logloss: 2.68757
# [450]	valid_0's multi_logloss: 2.68756
# [451]	valid_0's multi_logloss: 2.68756
# [452]	valid_0's multi_logloss: 2.6875
# [453]	valid_0's multi_logloss: 2.68746
# [454]	valid_0's multi_logloss: 2.68743
# [455]	valid_0's multi_logloss: 2.68739
# [456]	valid_0's multi_logloss: 2.68739
# [457]	valid_0's multi_logloss: 2.68738
# [458]	valid_0's multi_logloss: 2.6874
# [459]	valid_0's multi_logloss: 2.68737
# [460]	valid_0's multi_logloss: 2.68733
# [461]	valid_0's multi_logloss: 2.6873
# [462]	valid_0's multi_logloss: 2.68733
# [463]	valid_0's multi_logloss: 2.68732
# [464]	valid_0's multi_logloss: 2.68728
# [465]	valid_0's multi_logloss: 2.6873
# [466]	valid_0's multi_logloss: 2.68732
# [467]	valid_0's multi_logloss: 2.6873
# [468]	valid_0's multi_logloss: 2.68731
# [469]	valid_0's multi_logloss: 2.6873
# [470]	valid_0's multi_logloss: 2.68729
# [471]	valid_0's multi_logloss: 2.68727
# [472]	valid_0's multi_logloss: 2.68734
# [473]	valid_0's multi_logloss: 2.68732
# [474]	valid_0's multi_logloss: 2.68732
# [475]	valid_0's multi_logloss: 2.68727
# [476]	valid_0's multi_logloss: 2.68731
# [477]	valid_0's multi_logloss: 2.68733
# [478]	valid_0's multi_logloss: 2.68736
# [479]	valid_0's multi_logloss: 2.68736
# [480]	valid_0's multi_logloss: 2.68736
# [481]	valid_0's multi_logloss: 2.68737
# [482]	valid_0's multi_logloss: 2.68744
# [483]	valid_0's multi_logloss: 2.68746
# [484]	valid_0's multi_logloss: 2.68746
# [485]	valid_0's multi_logloss: 2.68743
# Early stopping, best iteration is:
# [475]	valid_0's multi_logloss: 2.68727
# 0.012420848725659819
# [1]	valid_0's multi_logloss: 2.88699
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88384
# [3]	valid_0's multi_logloss: 2.88128
# [4]	valid_0's multi_logloss: 2.87887
# [5]	valid_0's multi_logloss: 2.87685
# [6]	valid_0's multi_logloss: 2.87462
# [7]	valid_0's multi_logloss: 2.87267
# [8]	valid_0's multi_logloss: 2.87049
# [9]	valid_0's multi_logloss: 2.86849
# [10]	valid_0's multi_logloss: 2.86644
# [11]	valid_0's multi_logloss: 2.86456
# [12]	valid_0's multi_logloss: 2.86269
# [13]	valid_0's multi_logloss: 2.86096
# [14]	valid_0's multi_logloss: 2.85912
# [15]	valid_0's multi_logloss: 2.85749
# [16]	valid_0's multi_logloss: 2.85572
# [17]	valid_0's multi_logloss: 2.854
# [18]	valid_0's multi_logloss: 2.8524
# [19]	valid_0's multi_logloss: 2.85062
# [20]	valid_0's multi_logloss: 2.84903
# [21]	valid_0's multi_logloss: 2.84737
# [22]	valid_0's multi_logloss: 2.84575
# [23]	valid_0's multi_logloss: 2.84417
# [24]	valid_0's multi_logloss: 2.84262
# [25]	valid_0's multi_logloss: 2.84106
# [26]	valid_0's multi_logloss: 2.83962
# [27]	valid_0's multi_logloss: 2.83808
# [28]	valid_0's multi_logloss: 2.83665
# [29]	valid_0's multi_logloss: 2.8353
# [30]	valid_0's multi_logloss: 2.83387
# [31]	valid_0's multi_logloss: 2.8325
# [32]	valid_0's multi_logloss: 2.831
# [33]	valid_0's multi_logloss: 2.82952
# [34]	valid_0's multi_logloss: 2.82814
# [35]	valid_0's multi_logloss: 2.82682
# [36]	valid_0's multi_logloss: 2.82553
# [37]	valid_0's multi_logloss: 2.82425
# [38]	valid_0's multi_logloss: 2.82309
# [39]	valid_0's multi_logloss: 2.82192
# [40]	valid_0's multi_logloss: 2.82073
# [41]	valid_0's multi_logloss: 2.81954
# [42]	valid_0's multi_logloss: 2.8183
# [43]	valid_0's multi_logloss: 2.81718
# [44]	valid_0's multi_logloss: 2.81609
# [45]	valid_0's multi_logloss: 2.81493
# [46]	valid_0's multi_logloss: 2.8139
# [47]	valid_0's multi_logloss: 2.81276
# [48]	valid_0's multi_logloss: 2.8116
# [49]	valid_0's multi_logloss: 2.81059
# [50]	valid_0's multi_logloss: 2.8095
# [51]	valid_0's multi_logloss: 2.80847
# [52]	valid_0's multi_logloss: 2.80739
# [53]	valid_0's multi_logloss: 2.80639
# [54]	valid_0's multi_logloss: 2.80539
# [55]	valid_0's multi_logloss: 2.80437
# [56]	valid_0's multi_logloss: 2.80341
# [57]	valid_0's multi_logloss: 2.80239
# [58]	valid_0's multi_logloss: 2.80142
# [59]	valid_0's multi_logloss: 2.80041
# [60]	valid_0's multi_logloss: 2.79946
# [61]	valid_0's multi_logloss: 2.79853
# [62]	valid_0's multi_logloss: 2.79756
# [63]	valid_0's multi_logloss: 2.79667
# [64]	valid_0's multi_logloss: 2.79577
# [65]	valid_0's multi_logloss: 2.79483
# [66]	valid_0's multi_logloss: 2.79396
# [67]	valid_0's multi_logloss: 2.79308
# [68]	valid_0's multi_logloss: 2.79209
# [69]	valid_0's multi_logloss: 2.79114
# [70]	valid_0's multi_logloss: 2.79029
# [71]	valid_0's multi_logloss: 2.78941
# [72]	valid_0's multi_logloss: 2.78858
# [73]	valid_0's multi_logloss: 2.78765
# [74]	valid_0's multi_logloss: 2.78674
# [75]	valid_0's multi_logloss: 2.78592
# [76]	valid_0's multi_logloss: 2.78509
# [77]	valid_0's multi_logloss: 2.7842
# [78]	valid_0's multi_logloss: 2.78339
# [79]	valid_0's multi_logloss: 2.78255
# [80]	valid_0's multi_logloss: 2.78178
# [81]	valid_0's multi_logloss: 2.78093
# [82]	valid_0's multi_logloss: 2.78012
# [83]	valid_0's multi_logloss: 2.77934
# [84]	valid_0's multi_logloss: 2.77852
# [85]	valid_0's multi_logloss: 2.77773
# [86]	valid_0's multi_logloss: 2.77687
# [87]	valid_0's multi_logloss: 2.77609
# [88]	valid_0's multi_logloss: 2.77529
# [89]	valid_0's multi_logloss: 2.77455
# [90]	valid_0's multi_logloss: 2.7738
# [91]	valid_0's multi_logloss: 2.77311
# [92]	valid_0's multi_logloss: 2.77246
# [93]	valid_0's multi_logloss: 2.77163
# [94]	valid_0's multi_logloss: 2.77096
# [95]	valid_0's multi_logloss: 2.77022
# [96]	valid_0's multi_logloss: 2.76954
# [97]	valid_0's multi_logloss: 2.76885
# [98]	valid_0's multi_logloss: 2.76809
# [99]	valid_0's multi_logloss: 2.76736
# [100]	valid_0's multi_logloss: 2.7667
# [101]	valid_0's multi_logloss: 2.766
# [102]	valid_0's multi_logloss: 2.76537
# [103]	valid_0's multi_logloss: 2.76468
# [104]	valid_0's multi_logloss: 2.76402
# [105]	valid_0's multi_logloss: 2.76334
# [106]	valid_0's multi_logloss: 2.7626
# [107]	valid_0's multi_logloss: 2.76188
# [108]	valid_0's multi_logloss: 2.76123
# [109]	valid_0's multi_logloss: 2.76063
# [110]	valid_0's multi_logloss: 2.75997
# [111]	valid_0's multi_logloss: 2.75932
# [112]	valid_0's multi_logloss: 2.75867
# [113]	valid_0's multi_logloss: 2.758
# [114]	valid_0's multi_logloss: 2.75741
# [115]	valid_0's multi_logloss: 2.7568
# [116]	valid_0's multi_logloss: 2.75628
# [117]	valid_0's multi_logloss: 2.75564
# [118]	valid_0's multi_logloss: 2.75504
# [119]	valid_0's multi_logloss: 2.75438
# [120]	valid_0's multi_logloss: 2.75375
# [121]	valid_0's multi_logloss: 2.75317
# [122]	valid_0's multi_logloss: 2.75255
# [123]	valid_0's multi_logloss: 2.75194
# [124]	valid_0's multi_logloss: 2.75137
# [125]	valid_0's multi_logloss: 2.75076
# [126]	valid_0's multi_logloss: 2.75022
# [127]	valid_0's multi_logloss: 2.74966
# [128]	valid_0's multi_logloss: 2.74906
# [129]	valid_0's multi_logloss: 2.7485
# [130]	valid_0's multi_logloss: 2.74792
# [131]	valid_0's multi_logloss: 2.74735
# [132]	valid_0's multi_logloss: 2.74679
# [133]	valid_0's multi_logloss: 2.74631
# [134]	valid_0's multi_logloss: 2.7458
# [135]	valid_0's multi_logloss: 2.74514
# [136]	valid_0's multi_logloss: 2.74456
# [137]	valid_0's multi_logloss: 2.74401
# [138]	valid_0's multi_logloss: 2.74355
# [139]	valid_0's multi_logloss: 2.74306
# [140]	valid_0's multi_logloss: 2.74254
# [141]	valid_0's multi_logloss: 2.74204
# [142]	valid_0's multi_logloss: 2.74151
# [143]	valid_0's multi_logloss: 2.74106
# [144]	valid_0's multi_logloss: 2.7405
# [145]	valid_0's multi_logloss: 2.74003
# [146]	valid_0's multi_logloss: 2.73952
# [147]	valid_0's multi_logloss: 2.73915
# [148]	valid_0's multi_logloss: 2.73871
# [149]	valid_0's multi_logloss: 2.73827
# [150]	valid_0's multi_logloss: 2.73778
# [151]	valid_0's multi_logloss: 2.7373
# [152]	valid_0's multi_logloss: 2.73688
# [153]	valid_0's multi_logloss: 2.73638
# [154]	valid_0's multi_logloss: 2.73592
# [155]	valid_0's multi_logloss: 2.73549
# [156]	valid_0's multi_logloss: 2.73505
# [157]	valid_0's multi_logloss: 2.73459
# [158]	valid_0's multi_logloss: 2.73418
# [159]	valid_0's multi_logloss: 2.73366
# [160]	valid_0's multi_logloss: 2.73318
# [161]	valid_0's multi_logloss: 2.73273
# [162]	valid_0's multi_logloss: 2.73226
# [163]	valid_0's multi_logloss: 2.73185
# [164]	valid_0's multi_logloss: 2.73139
# [165]	valid_0's multi_logloss: 2.73096
# [166]	valid_0's multi_logloss: 2.73055
# [167]	valid_0's multi_logloss: 2.73009
# [168]	valid_0's multi_logloss: 2.7296
# [169]	valid_0's multi_logloss: 2.72921
# [170]	valid_0's multi_logloss: 2.72882
# [171]	valid_0's multi_logloss: 2.7284
# [172]	valid_0's multi_logloss: 2.72804
# [173]	valid_0's multi_logloss: 2.72761
# [174]	valid_0's multi_logloss: 2.72716
# [175]	valid_0's multi_logloss: 2.72681
# [176]	valid_0's multi_logloss: 2.72642
# [177]	valid_0's multi_logloss: 2.72611
# [178]	valid_0's multi_logloss: 2.72568
# [179]	valid_0's multi_logloss: 2.72533
# [180]	valid_0's multi_logloss: 2.72489
# [181]	valid_0's multi_logloss: 2.72456
# [182]	valid_0's multi_logloss: 2.72413
# [183]	valid_0's multi_logloss: 2.7238
# [184]	valid_0's multi_logloss: 2.72345
# [185]	valid_0's multi_logloss: 2.72305
# [186]	valid_0's multi_logloss: 2.72269
# [187]	valid_0's multi_logloss: 2.72238
# [188]	valid_0's multi_logloss: 2.72202
# [189]	valid_0's multi_logloss: 2.72169
# [190]	valid_0's multi_logloss: 2.72133
# [191]	valid_0's multi_logloss: 2.72091
# [192]	valid_0's multi_logloss: 2.72061
# [193]	valid_0's multi_logloss: 2.72029
# [194]	valid_0's multi_logloss: 2.71991
# [195]	valid_0's multi_logloss: 2.71959
# [196]	valid_0's multi_logloss: 2.71927
# [197]	valid_0's multi_logloss: 2.71889
# [198]	valid_0's multi_logloss: 2.7186
# [199]	valid_0's multi_logloss: 2.71823
# [200]	valid_0's multi_logloss: 2.71791
# [201]	valid_0's multi_logloss: 2.7176
# [202]	valid_0's multi_logloss: 2.71734
# [203]	valid_0's multi_logloss: 2.71704
# [204]	valid_0's multi_logloss: 2.71674
# [205]	valid_0's multi_logloss: 2.71644
# [206]	valid_0's multi_logloss: 2.71611
# [207]	valid_0's multi_logloss: 2.7157
# [208]	valid_0's multi_logloss: 2.71542
# [209]	valid_0's multi_logloss: 2.71506
# [210]	valid_0's multi_logloss: 2.71477
# [211]	valid_0's multi_logloss: 2.71442
# [212]	valid_0's multi_logloss: 2.71414
# [213]	valid_0's multi_logloss: 2.71387
# [214]	valid_0's multi_logloss: 2.71347
# [215]	valid_0's multi_logloss: 2.71324
# [216]	valid_0's multi_logloss: 2.71293
# [217]	valid_0's multi_logloss: 2.71262
# [218]	valid_0's multi_logloss: 2.71221
# [219]	valid_0's multi_logloss: 2.71189
# [220]	valid_0's multi_logloss: 2.7116
# [221]	valid_0's multi_logloss: 2.71136
# [222]	valid_0's multi_logloss: 2.71107
# [223]	valid_0's multi_logloss: 2.71067
# [224]	valid_0's multi_logloss: 2.71044
# [225]	valid_0's multi_logloss: 2.71019
# [226]	valid_0's multi_logloss: 2.70988
# [227]	valid_0's multi_logloss: 2.70964
# [228]	valid_0's multi_logloss: 2.70942
# [229]	valid_0's multi_logloss: 2.70909
# [230]	valid_0's multi_logloss: 2.70893
# [231]	valid_0's multi_logloss: 2.70858
# [232]	valid_0's multi_logloss: 2.70828
# [233]	valid_0's multi_logloss: 2.70805
# [234]	valid_0's multi_logloss: 2.70773
# [235]	valid_0's multi_logloss: 2.70749
# [236]	valid_0's multi_logloss: 2.70714
# [237]	valid_0's multi_logloss: 2.70687
# [238]	valid_0's multi_logloss: 2.70665
# [239]	valid_0's multi_logloss: 2.70638
# [240]	valid_0's multi_logloss: 2.70621
# [241]	valid_0's multi_logloss: 2.70593
# [242]	valid_0's multi_logloss: 2.70564
# [243]	valid_0's multi_logloss: 2.70538
# [244]	valid_0's multi_logloss: 2.70522
# [245]	valid_0's multi_logloss: 2.70499
# [246]	valid_0's multi_logloss: 2.7047
# [247]	valid_0's multi_logloss: 2.7044
# [248]	valid_0's multi_logloss: 2.70423
# [249]	valid_0's multi_logloss: 2.70399
# [250]	valid_0's multi_logloss: 2.70376
# [251]	valid_0's multi_logloss: 2.70353
# [252]	valid_0's multi_logloss: 2.70335
# [253]	valid_0's multi_logloss: 2.70313
# [254]	valid_0's multi_logloss: 2.70287
# [255]	valid_0's multi_logloss: 2.70264
# [256]	valid_0's multi_logloss: 2.70244
# [257]	valid_0's multi_logloss: 2.70224
# [258]	valid_0's multi_logloss: 2.70204
# [259]	valid_0's multi_logloss: 2.70182
# [260]	valid_0's multi_logloss: 2.70158
# [261]	valid_0's multi_logloss: 2.70135
# [262]	valid_0's multi_logloss: 2.70108
# [263]	valid_0's multi_logloss: 2.70089
# [264]	valid_0's multi_logloss: 2.70073
# [265]	valid_0's multi_logloss: 2.70045
# [266]	valid_0's multi_logloss: 2.70028
# [267]	valid_0's multi_logloss: 2.7
# [268]	valid_0's multi_logloss: 2.6998
# [269]	valid_0's multi_logloss: 2.69957
# [270]	valid_0's multi_logloss: 2.69934
# [271]	valid_0's multi_logloss: 2.69912
# [272]	valid_0's multi_logloss: 2.69892
# [273]	valid_0's multi_logloss: 2.69872
# [274]	valid_0's multi_logloss: 2.69858
# [275]	valid_0's multi_logloss: 2.69835
# [276]	valid_0's multi_logloss: 2.69818
# [277]	valid_0's multi_logloss: 2.69803
# [278]	valid_0's multi_logloss: 2.69775
# [279]	valid_0's multi_logloss: 2.69759
# [280]	valid_0's multi_logloss: 2.69732
# [281]	valid_0's multi_logloss: 2.69711
# [282]	valid_0's multi_logloss: 2.69686
# [283]	valid_0's multi_logloss: 2.69663
# [284]	valid_0's multi_logloss: 2.6964
# [285]	valid_0's multi_logloss: 2.6963
# [286]	valid_0's multi_logloss: 2.69608
# [287]	valid_0's multi_logloss: 2.69583
# [288]	valid_0's multi_logloss: 2.69572
# [289]	valid_0's multi_logloss: 2.69558
# [290]	valid_0's multi_logloss: 2.69533
# [291]	valid_0's multi_logloss: 2.69507
# [292]	valid_0's multi_logloss: 2.69492
# [293]	valid_0's multi_logloss: 2.69477
# [294]	valid_0's multi_logloss: 2.69458
# [295]	valid_0's multi_logloss: 2.69438
# [296]	valid_0's multi_logloss: 2.6942
# [297]	valid_0's multi_logloss: 2.69404
# [298]	valid_0's multi_logloss: 2.69388
# [299]	valid_0's multi_logloss: 2.69368
# [300]	valid_0's multi_logloss: 2.69344
# [301]	valid_0's multi_logloss: 2.69331
# [302]	valid_0's multi_logloss: 2.69309
# [303]	valid_0's multi_logloss: 2.69295
# [304]	valid_0's multi_logloss: 2.69279
# [305]	valid_0's multi_logloss: 2.69264
# [306]	valid_0's multi_logloss: 2.69246
# [307]	valid_0's multi_logloss: 2.69231
# [308]	valid_0's multi_logloss: 2.69213
# [309]	valid_0's multi_logloss: 2.69197
# [310]	valid_0's multi_logloss: 2.69182
# [311]	valid_0's multi_logloss: 2.69164
# [312]	valid_0's multi_logloss: 2.69145
# [313]	valid_0's multi_logloss: 2.69131
# [314]	valid_0's multi_logloss: 2.69115
# [315]	valid_0's multi_logloss: 2.69097
# [316]	valid_0's multi_logloss: 2.6908
# [317]	valid_0's multi_logloss: 2.69066
# [318]	valid_0's multi_logloss: 2.69052
# [319]	valid_0's multi_logloss: 2.6904
# [320]	valid_0's multi_logloss: 2.69027
# [321]	valid_0's multi_logloss: 2.69011
# [322]	valid_0's multi_logloss: 2.68999
# [323]	valid_0's multi_logloss: 2.68982
# [324]	valid_0's multi_logloss: 2.68965
# [325]	valid_0's multi_logloss: 2.68952
# [326]	valid_0's multi_logloss: 2.68934
# [327]	valid_0's multi_logloss: 2.68921
# [328]	valid_0's multi_logloss: 2.68898
# [329]	valid_0's multi_logloss: 2.68881
# [330]	valid_0's multi_logloss: 2.68864
# [331]	valid_0's multi_logloss: 2.68857
# [332]	valid_0's multi_logloss: 2.68834
# [333]	valid_0's multi_logloss: 2.68821
# [334]	valid_0's multi_logloss: 2.68811
# [335]	valid_0's multi_logloss: 2.688
# [336]	valid_0's multi_logloss: 2.68788
# [337]	valid_0's multi_logloss: 2.68784
# [338]	valid_0's multi_logloss: 2.68761
# [339]	valid_0's multi_logloss: 2.68753
# [340]	valid_0's multi_logloss: 2.68743
# [341]	valid_0's multi_logloss: 2.68725
# [342]	valid_0's multi_logloss: 2.68717
# [343]	valid_0's multi_logloss: 2.68707
# [344]	valid_0's multi_logloss: 2.68695
# [345]	valid_0's multi_logloss: 2.68689
# [346]	valid_0's multi_logloss: 2.68678
# [347]	valid_0's multi_logloss: 2.68665
# [348]	valid_0's multi_logloss: 2.68652
# [349]	valid_0's multi_logloss: 2.68633
# [350]	valid_0's multi_logloss: 2.68629
# [351]	valid_0's multi_logloss: 2.68615
# [352]	valid_0's multi_logloss: 2.68603
# [353]	valid_0's multi_logloss: 2.68594
# [354]	valid_0's multi_logloss: 2.6858
# [355]	valid_0's multi_logloss: 2.68568
# [356]	valid_0's multi_logloss: 2.68563
# [357]	valid_0's multi_logloss: 2.6855
# [358]	valid_0's multi_logloss: 2.68541
# [359]	valid_0's multi_logloss: 2.68528
# [360]	valid_0's multi_logloss: 2.68518
# [361]	valid_0's multi_logloss: 2.6851
# [362]	valid_0's multi_logloss: 2.68502
# [363]	valid_0's multi_logloss: 2.68492
# [364]	valid_0's multi_logloss: 2.68481
# [365]	valid_0's multi_logloss: 2.68472
# [366]	valid_0's multi_logloss: 2.68472
# [367]	valid_0's multi_logloss: 2.68468
# [368]	valid_0's multi_logloss: 2.68458
# [369]	valid_0's multi_logloss: 2.68449
# [370]	valid_0's multi_logloss: 2.68439
# [371]	valid_0's multi_logloss: 2.68431
# [372]	valid_0's multi_logloss: 2.68416
# [373]	valid_0's multi_logloss: 2.68412
# [374]	valid_0's multi_logloss: 2.68401
# [375]	valid_0's multi_logloss: 2.68392
# [376]	valid_0's multi_logloss: 2.68391
# [377]	valid_0's multi_logloss: 2.68384
# [378]	valid_0's multi_logloss: 2.68372
# [379]	valid_0's multi_logloss: 2.68364
# [380]	valid_0's multi_logloss: 2.68359
# [381]	valid_0's multi_logloss: 2.6835
# [382]	valid_0's multi_logloss: 2.6834
# [383]	valid_0's multi_logloss: 2.68335
# [384]	valid_0's multi_logloss: 2.68327
# [385]	valid_0's multi_logloss: 2.68313
# [386]	valid_0's multi_logloss: 2.68309
# [387]	valid_0's multi_logloss: 2.68303
# [388]	valid_0's multi_logloss: 2.68294
# [389]	valid_0's multi_logloss: 2.68285
# [390]	valid_0's multi_logloss: 2.68284
# [391]	valid_0's multi_logloss: 2.68275
# [392]	valid_0's multi_logloss: 2.68266
# [393]	valid_0's multi_logloss: 2.68258
# [394]	valid_0's multi_logloss: 2.68251
# [395]	valid_0's multi_logloss: 2.68243
# [396]	valid_0's multi_logloss: 2.68233
# [397]	valid_0's multi_logloss: 2.68225
# [398]	valid_0's multi_logloss: 2.6822
# [399]	valid_0's multi_logloss: 2.68213
# [400]	valid_0's multi_logloss: 2.68211
# [401]	valid_0's multi_logloss: 2.68201
# [402]	valid_0's multi_logloss: 2.68194
# [403]	valid_0's multi_logloss: 2.68186
# [404]	valid_0's multi_logloss: 2.68179
# [405]	valid_0's multi_logloss: 2.68172
# [406]	valid_0's multi_logloss: 2.68163
# [407]	valid_0's multi_logloss: 2.6816
# [408]	valid_0's multi_logloss: 2.68153
# [409]	valid_0's multi_logloss: 2.68146
# [410]	valid_0's multi_logloss: 2.68143
# [411]	valid_0's multi_logloss: 2.68138
# [412]	valid_0's multi_logloss: 2.68127
# [413]	valid_0's multi_logloss: 2.68119
# [414]	valid_0's multi_logloss: 2.68116
# [415]	valid_0's multi_logloss: 2.68114
# [416]	valid_0's multi_logloss: 2.68111
# [417]	valid_0's multi_logloss: 2.68105
# [418]	valid_0's multi_logloss: 2.68104
# [419]	valid_0's multi_logloss: 2.681
# [420]	valid_0's multi_logloss: 2.68093
# [421]	valid_0's multi_logloss: 2.68089
# [422]	valid_0's multi_logloss: 2.68085
# [423]	valid_0's multi_logloss: 2.68079
# [424]	valid_0's multi_logloss: 2.68072
# [425]	valid_0's multi_logloss: 2.68067
# [426]	valid_0's multi_logloss: 2.68059
# [427]	valid_0's multi_logloss: 2.6805
# [428]	valid_0's multi_logloss: 2.68049
# [429]	valid_0's multi_logloss: 2.68049
# [430]	valid_0's multi_logloss: 2.68046
# [431]	valid_0's multi_logloss: 2.68042
# [432]	valid_0's multi_logloss: 2.68036
# [433]	valid_0's multi_logloss: 2.68026
# [434]	valid_0's multi_logloss: 2.68023
# [435]	valid_0's multi_logloss: 2.68017
# [436]	valid_0's multi_logloss: 2.68014
# [437]	valid_0's multi_logloss: 2.68012
# [438]	valid_0's multi_logloss: 2.68005
# [439]	valid_0's multi_logloss: 2.68003
# [440]	valid_0's multi_logloss: 2.67999
# [441]	valid_0's multi_logloss: 2.67995
# [442]	valid_0's multi_logloss: 2.67993
# [443]	valid_0's multi_logloss: 2.67989
# [444]	valid_0's multi_logloss: 2.67982
# [445]	valid_0's multi_logloss: 2.67978
# [446]	valid_0's multi_logloss: 2.67974
# [447]	valid_0's multi_logloss: 2.67963
# [448]	valid_0's multi_logloss: 2.6796
# [449]	valid_0's multi_logloss: 2.67953
# [450]	valid_0's multi_logloss: 2.67948
# [451]	valid_0's multi_logloss: 2.6795
# [452]	valid_0's multi_logloss: 2.67946
# [453]	valid_0's multi_logloss: 2.67941
# [454]	valid_0's multi_logloss: 2.67934
# [455]	valid_0's multi_logloss: 2.67931
# [456]	valid_0's multi_logloss: 2.67933
# [457]	valid_0's multi_logloss: 2.67927
# [458]	valid_0's multi_logloss: 2.67917
# [459]	valid_0's multi_logloss: 2.67916
# [460]	valid_0's multi_logloss: 2.67911
# [461]	valid_0's multi_logloss: 2.67908
# [462]	valid_0's multi_logloss: 2.67903
# [463]	valid_0's multi_logloss: 2.67898
# [464]	valid_0's multi_logloss: 2.6789
# [465]	valid_0's multi_logloss: 2.67891
# [466]	valid_0's multi_logloss: 2.67882
# [467]	valid_0's multi_logloss: 2.67879
# [468]	valid_0's multi_logloss: 2.67878
# [469]	valid_0's multi_logloss: 2.67875
# [470]	valid_0's multi_logloss: 2.67877
# [471]	valid_0's multi_logloss: 2.6787
# [472]	valid_0's multi_logloss: 2.6787
# [473]	valid_0's multi_logloss: 2.67868
# [474]	valid_0's multi_logloss: 2.67867
# [475]	valid_0's multi_logloss: 2.67862
# [476]	valid_0's multi_logloss: 2.67859
# [477]	valid_0's multi_logloss: 2.67858
# [478]	valid_0's multi_logloss: 2.67856
# [479]	valid_0's multi_logloss: 2.67864
# [480]	valid_0's multi_logloss: 2.67864
# [481]	valid_0's multi_logloss: 2.67862
# [482]	valid_0's multi_logloss: 2.67863
# [483]	valid_0's multi_logloss: 2.67864
# [484]	valid_0's multi_logloss: 2.67858
# [485]	valid_0's multi_logloss: 2.67859
# [486]	valid_0's multi_logloss: 2.67863
# [487]	valid_0's multi_logloss: 2.67866
# [488]	valid_0's multi_logloss: 2.67861
# Early stopping, best iteration is:
# [478]	valid_0's multi_logloss: 2.67856
# 0.012221910774790802
# [1]	valid_0's multi_logloss: 2.85872
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85673
# [3]	valid_0's multi_logloss: 2.85488
# [4]	valid_0's multi_logloss: 2.85303
# [5]	valid_0's multi_logloss: 2.85121
# [6]	valid_0's multi_logloss: 2.84948
# [7]	valid_0's multi_logloss: 2.84759
# [8]	valid_0's multi_logloss: 2.84583
# [9]	valid_0's multi_logloss: 2.84411
# [10]	valid_0's multi_logloss: 2.8424
# [11]	valid_0's multi_logloss: 2.84067
# [12]	valid_0's multi_logloss: 2.8391
# [13]	valid_0's multi_logloss: 2.83739
# [14]	valid_0's multi_logloss: 2.83596
# [15]	valid_0's multi_logloss: 2.83441
# [16]	valid_0's multi_logloss: 2.83298
# [17]	valid_0's multi_logloss: 2.83151
# [18]	valid_0's multi_logloss: 2.83003
# [19]	valid_0's multi_logloss: 2.82872
# [20]	valid_0's multi_logloss: 2.82735
# [21]	valid_0's multi_logloss: 2.82609
# [22]	valid_0's multi_logloss: 2.82476
# [23]	valid_0's multi_logloss: 2.82356
# [24]	valid_0's multi_logloss: 2.82229
# [25]	valid_0's multi_logloss: 2.82115
# [26]	valid_0's multi_logloss: 2.81998
# [27]	valid_0's multi_logloss: 2.81875
# [28]	valid_0's multi_logloss: 2.81757
# [29]	valid_0's multi_logloss: 2.81644
# [30]	valid_0's multi_logloss: 2.81529
# [31]	valid_0's multi_logloss: 2.81417
# [32]	valid_0's multi_logloss: 2.81305
# [33]	valid_0's multi_logloss: 2.81202
# [34]	valid_0's multi_logloss: 2.81094
# [35]	valid_0's multi_logloss: 2.80994
# [36]	valid_0's multi_logloss: 2.80892
# [37]	valid_0's multi_logloss: 2.80784
# [38]	valid_0's multi_logloss: 2.80683
# [39]	valid_0's multi_logloss: 2.80579
# [40]	valid_0's multi_logloss: 2.80483
# [41]	valid_0's multi_logloss: 2.80381
# [42]	valid_0's multi_logloss: 2.80285
# [43]	valid_0's multi_logloss: 2.80191
# [44]	valid_0's multi_logloss: 2.80107
# [45]	valid_0's multi_logloss: 2.80017
# [46]	valid_0's multi_logloss: 2.79929
# [47]	valid_0's multi_logloss: 2.79837
# [48]	valid_0's multi_logloss: 2.79752
# [49]	valid_0's multi_logloss: 2.79652
# [50]	valid_0's multi_logloss: 2.79561
# [51]	valid_0's multi_logloss: 2.79475
# [52]	valid_0's multi_logloss: 2.79392
# [53]	valid_0's multi_logloss: 2.79312
# [54]	valid_0's multi_logloss: 2.7922
# [55]	valid_0's multi_logloss: 2.79139
# [56]	valid_0's multi_logloss: 2.79057
# [57]	valid_0's multi_logloss: 2.7897
# [58]	valid_0's multi_logloss: 2.78889
# [59]	valid_0's multi_logloss: 2.7881
# [60]	valid_0's multi_logloss: 2.78725
# [61]	valid_0's multi_logloss: 2.78653
# [62]	valid_0's multi_logloss: 2.78572
# [63]	valid_0's multi_logloss: 2.78487
# [64]	valid_0's multi_logloss: 2.7841
# [65]	valid_0's multi_logloss: 2.78317
# [66]	valid_0's multi_logloss: 2.78247
# [67]	valid_0's multi_logloss: 2.78174
# [68]	valid_0's multi_logloss: 2.78099
# [69]	valid_0's multi_logloss: 2.78024
# [70]	valid_0's multi_logloss: 2.77947
# [71]	valid_0's multi_logloss: 2.77885
# [72]	valid_0's multi_logloss: 2.77811
# [73]	valid_0's multi_logloss: 2.77742
# [74]	valid_0's multi_logloss: 2.77668
# [75]	valid_0's multi_logloss: 2.77606
# [76]	valid_0's multi_logloss: 2.7754
# [77]	valid_0's multi_logloss: 2.77462
# [78]	valid_0's multi_logloss: 2.77396
# [79]	valid_0's multi_logloss: 2.77329
# [80]	valid_0's multi_logloss: 2.77257
# [81]	valid_0's multi_logloss: 2.7719
# [82]	valid_0's multi_logloss: 2.77124
# [83]	valid_0's multi_logloss: 2.77066
# [84]	valid_0's multi_logloss: 2.77008
# [85]	valid_0's multi_logloss: 2.76942
# [86]	valid_0's multi_logloss: 2.76885
# [87]	valid_0's multi_logloss: 2.76819
# [88]	valid_0's multi_logloss: 2.76763
# [89]	valid_0's multi_logloss: 2.767
# [90]	valid_0's multi_logloss: 2.76638
# [91]	valid_0's multi_logloss: 2.76576
# [92]	valid_0's multi_logloss: 2.76513
# [93]	valid_0's multi_logloss: 2.76451
# [94]	valid_0's multi_logloss: 2.76392
# [95]	valid_0's multi_logloss: 2.76337
# [96]	valid_0's multi_logloss: 2.76282
# [97]	valid_0's multi_logloss: 2.76222
# [98]	valid_0's multi_logloss: 2.76159
# [99]	valid_0's multi_logloss: 2.76101
# [100]	valid_0's multi_logloss: 2.76046
# [101]	valid_0's multi_logloss: 2.7599
# [102]	valid_0's multi_logloss: 2.75934
# [103]	valid_0's multi_logloss: 2.75881
# [104]	valid_0's multi_logloss: 2.75822
# [105]	valid_0's multi_logloss: 2.75765
# [106]	valid_0's multi_logloss: 2.75707
# [107]	valid_0's multi_logloss: 2.75649
# [108]	valid_0's multi_logloss: 2.75593
# [109]	valid_0's multi_logloss: 2.75547
# [110]	valid_0's multi_logloss: 2.7549
# [111]	valid_0's multi_logloss: 2.75437
# [112]	valid_0's multi_logloss: 2.75389
# [113]	valid_0's multi_logloss: 2.75331
# [114]	valid_0's multi_logloss: 2.75273
# [115]	valid_0's multi_logloss: 2.75226
# [116]	valid_0's multi_logloss: 2.75173
# [117]	valid_0's multi_logloss: 2.75121
# [118]	valid_0's multi_logloss: 2.75068
# [119]	valid_0's multi_logloss: 2.75015
# [120]	valid_0's multi_logloss: 2.74967
# [121]	valid_0's multi_logloss: 2.74916
# [122]	valid_0's multi_logloss: 2.74865
# [123]	valid_0's multi_logloss: 2.74814
# [124]	valid_0's multi_logloss: 2.74766
# [125]	valid_0's multi_logloss: 2.74724
# [126]	valid_0's multi_logloss: 2.74673
# [127]	valid_0's multi_logloss: 2.74622
# [128]	valid_0's multi_logloss: 2.74575
# [129]	valid_0's multi_logloss: 2.74531
# [130]	valid_0's multi_logloss: 2.74487
# [131]	valid_0's multi_logloss: 2.74436
# [132]	valid_0's multi_logloss: 2.74388
# [133]	valid_0's multi_logloss: 2.74347
# [134]	valid_0's multi_logloss: 2.74299
# [135]	valid_0's multi_logloss: 2.74256
# [136]	valid_0's multi_logloss: 2.74212
# [137]	valid_0's multi_logloss: 2.74168
# [138]	valid_0's multi_logloss: 2.7412
# [139]	valid_0's multi_logloss: 2.74077
# [140]	valid_0's multi_logloss: 2.74035
# [141]	valid_0's multi_logloss: 2.73991
# [142]	valid_0's multi_logloss: 2.73949
# [143]	valid_0's multi_logloss: 2.73905
# [144]	valid_0's multi_logloss: 2.73863
# [145]	valid_0's multi_logloss: 2.73829
# [146]	valid_0's multi_logloss: 2.73788
# [147]	valid_0's multi_logloss: 2.73742
# [148]	valid_0's multi_logloss: 2.73702
# [149]	valid_0's multi_logloss: 2.7366
# [150]	valid_0's multi_logloss: 2.73622
# [151]	valid_0's multi_logloss: 2.73585
# [152]	valid_0's multi_logloss: 2.73548
# [153]	valid_0's multi_logloss: 2.73513
# [154]	valid_0's multi_logloss: 2.73474
# [155]	valid_0's multi_logloss: 2.73437
# [156]	valid_0's multi_logloss: 2.73407
# [157]	valid_0's multi_logloss: 2.73369
# [158]	valid_0's multi_logloss: 2.73334
# [159]	valid_0's multi_logloss: 2.73297
# [160]	valid_0's multi_logloss: 2.73266
# [161]	valid_0's multi_logloss: 2.73225
# [162]	valid_0's multi_logloss: 2.73193
# [163]	valid_0's multi_logloss: 2.73157
# [164]	valid_0's multi_logloss: 2.73123
# [165]	valid_0's multi_logloss: 2.7309
# [166]	valid_0's multi_logloss: 2.73053
# [167]	valid_0's multi_logloss: 2.73023
# [168]	valid_0's multi_logloss: 2.72991
# [169]	valid_0's multi_logloss: 2.72951
# [170]	valid_0's multi_logloss: 2.72923
# [171]	valid_0's multi_logloss: 2.7289
# [172]	valid_0's multi_logloss: 2.72864
# [173]	valid_0's multi_logloss: 2.72826
# [174]	valid_0's multi_logloss: 2.72798
# [175]	valid_0's multi_logloss: 2.72766
# [176]	valid_0's multi_logloss: 2.72734
# [177]	valid_0's multi_logloss: 2.72709
# [178]	valid_0's multi_logloss: 2.72671
# [179]	valid_0's multi_logloss: 2.72642
# [180]	valid_0's multi_logloss: 2.72611
# [181]	valid_0's multi_logloss: 2.72579
# [182]	valid_0's multi_logloss: 2.72548
# [183]	valid_0's multi_logloss: 2.72526
# [184]	valid_0's multi_logloss: 2.72495
# [185]	valid_0's multi_logloss: 2.72471
# [186]	valid_0's multi_logloss: 2.72443
# [187]	valid_0's multi_logloss: 2.72418
# [188]	valid_0's multi_logloss: 2.72389
# [189]	valid_0's multi_logloss: 2.72357
# [190]	valid_0's multi_logloss: 2.72333
# [191]	valid_0's multi_logloss: 2.72301
# [192]	valid_0's multi_logloss: 2.72267
# [193]	valid_0's multi_logloss: 2.7224
# [194]	valid_0's multi_logloss: 2.72213
# [195]	valid_0's multi_logloss: 2.72189
# [196]	valid_0's multi_logloss: 2.72159
# [197]	valid_0's multi_logloss: 2.72131
# [198]	valid_0's multi_logloss: 2.72103
# [199]	valid_0's multi_logloss: 2.72076
# [200]	valid_0's multi_logloss: 2.72051
# [201]	valid_0's multi_logloss: 2.72025
# [202]	valid_0's multi_logloss: 2.72003
# [203]	valid_0's multi_logloss: 2.71978
# [204]	valid_0's multi_logloss: 2.71957
# [205]	valid_0's multi_logloss: 2.71931
# [206]	valid_0's multi_logloss: 2.71905
# [207]	valid_0's multi_logloss: 2.71878
# [208]	valid_0's multi_logloss: 2.71851
# [209]	valid_0's multi_logloss: 2.71825
# [210]	valid_0's multi_logloss: 2.718
# [211]	valid_0's multi_logloss: 2.71775
# [212]	valid_0's multi_logloss: 2.71752
# [213]	valid_0's multi_logloss: 2.71726
# [214]	valid_0's multi_logloss: 2.717
# [215]	valid_0's multi_logloss: 2.71678
# [216]	valid_0's multi_logloss: 2.71656
# [217]	valid_0's multi_logloss: 2.7163
# [218]	valid_0's multi_logloss: 2.71604
# [219]	valid_0's multi_logloss: 2.71582
# [220]	valid_0's multi_logloss: 2.71562
# [221]	valid_0's multi_logloss: 2.71542
# [222]	valid_0's multi_logloss: 2.71517
# [223]	valid_0's multi_logloss: 2.71494
# [224]	valid_0's multi_logloss: 2.71472
# [225]	valid_0's multi_logloss: 2.71451
# [226]	valid_0's multi_logloss: 2.71428
# [227]	valid_0's multi_logloss: 2.71409
# [228]	valid_0's multi_logloss: 2.71386
# [229]	valid_0's multi_logloss: 2.71364
# [230]	valid_0's multi_logloss: 2.7134
# [231]	valid_0's multi_logloss: 2.71324
# [232]	valid_0's multi_logloss: 2.71304
# [233]	valid_0's multi_logloss: 2.71281
# [234]	valid_0's multi_logloss: 2.7126
# [235]	valid_0's multi_logloss: 2.71246
# [236]	valid_0's multi_logloss: 2.71227
# [237]	valid_0's multi_logloss: 2.71201
# [238]	valid_0's multi_logloss: 2.71183
# [239]	valid_0's multi_logloss: 2.71166
# [240]	valid_0's multi_logloss: 2.7115
# [241]	valid_0's multi_logloss: 2.71132
# [242]	valid_0's multi_logloss: 2.71114
# [243]	valid_0's multi_logloss: 2.71094
# [244]	valid_0's multi_logloss: 2.71077
# [245]	valid_0's multi_logloss: 2.7106
# [246]	valid_0's multi_logloss: 2.71041
# [247]	valid_0's multi_logloss: 2.71026
# [248]	valid_0's multi_logloss: 2.71007
# [249]	valid_0's multi_logloss: 2.70993
# [250]	valid_0's multi_logloss: 2.70977
# [251]	valid_0's multi_logloss: 2.70962
# [252]	valid_0's multi_logloss: 2.70945
# [253]	valid_0's multi_logloss: 2.70927
# [254]	valid_0's multi_logloss: 2.70911
# [255]	valid_0's multi_logloss: 2.70893
# [256]	valid_0's multi_logloss: 2.70873
# [257]	valid_0's multi_logloss: 2.7086
# [258]	valid_0's multi_logloss: 2.70842
# [259]	valid_0's multi_logloss: 2.70827
# [260]	valid_0's multi_logloss: 2.70808
# ...
# [231]	valid_0's multi_logloss: 2.90617
# [232]	valid_0's multi_logloss: 2.90614
# [233]	valid_0's multi_logloss: 2.90605
# [234]	valid_0's multi_logloss: 2.90599
# [235]	valid_0's multi_logloss: 2.9059
# [236]	valid_0's multi_logloss: 2.90578
# [237]	valid_0's multi_logloss: 2.90575
# [238]	valid_0's multi_logloss: 2.90572
# [239]	valid_0's multi_logloss: 2.90564
# [240]	valid_0's multi_logloss: 2.90555
# [241]	valid_0's multi_logloss: 2.90541
# [242]	valid_0's multi_logloss: 2.90533
# [243]	valid_0's multi_logloss: 2.90529
# [244]	valid_0's multi_logloss: 2.90514
# [245]	valid_0's multi_logloss: 2.90515
# [246]	valid_0's multi_logloss: 2.90512
# [247]	valid_0's multi_logloss: 2.90511
# [248]	valid_0's multi_logloss: 2.90503
# [249]	valid_0's multi_logloss: 2.90492
# [250]	valid_0's multi_logloss: 2.90488
# [251]	valid_0's multi_logloss: 2.90485
# [252]	valid_0's multi_logloss: 2.90476
# [253]	valid_0's multi_logloss: 2.90472
# [254]	valid_0's multi_logloss: 2.90469
# [255]	valid_0's multi_logloss: 2.90461
# [256]	valid_0's multi_logloss: 2.90459
# [257]	valid_0's multi_logloss: 2.90453
# [258]	valid_0's multi_logloss: 2.90449
# [259]	valid_0's multi_logloss: 2.90446
# [260]	valid_0's multi_logloss: 2.90441
# [261]	valid_0's multi_logloss: 2.90433
# [262]	valid_0's multi_logloss: 2.90431
# [263]	valid_0's multi_logloss: 2.90421
# [264]	valid_0's multi_logloss: 2.90416
# [265]	valid_0's multi_logloss: 2.90405
# [266]	valid_0's multi_logloss: 2.90404
# [267]	valid_0's multi_logloss: 2.904
# [268]	valid_0's multi_logloss: 2.90399
# [269]	valid_0's multi_logloss: 2.90393
# [270]	valid_0's multi_logloss: 2.90386
# [271]	valid_0's multi_logloss: 2.90387
# [272]	valid_0's multi_logloss: 2.90379
# [273]	valid_0's multi_logloss: 2.90376
# [274]	valid_0's multi_logloss: 2.90372
# [275]	valid_0's multi_logloss: 2.90371
# [276]	valid_0's multi_logloss: 2.90368
# [277]	valid_0's multi_logloss: 2.90365
# [278]	valid_0's multi_logloss: 2.90354
# [279]	valid_0's multi_logloss: 2.90353
# [280]	valid_0's multi_logloss: 2.90351
# [281]	valid_0's multi_logloss: 2.90347
# [282]	valid_0's multi_logloss: 2.90351
# [283]	valid_0's multi_logloss: 2.90348
# [284]	valid_0's multi_logloss: 2.90344
# [285]	valid_0's multi_logloss: 2.90343
# [286]	valid_0's multi_logloss: 2.9034
# [287]	valid_0's multi_logloss: 2.90338
# [288]	valid_0's multi_logloss: 2.90336
# [289]	valid_0's multi_logloss: 2.90329
# [290]	valid_0's multi_logloss: 2.90326
# [291]	valid_0's multi_logloss: 2.90329
# [292]	valid_0's multi_logloss: 2.90327
# [293]	valid_0's multi_logloss: 2.90324
# [294]	valid_0's multi_logloss: 2.90323
# [295]	valid_0's multi_logloss: 2.90316
# [296]	valid_0's multi_logloss: 2.90321
# [297]	valid_0's multi_logloss: 2.90316
# [298]	valid_0's multi_logloss: 2.90311
# [299]	valid_0's multi_logloss: 2.9031
# [300]	valid_0's multi_logloss: 2.90312
# [301]	valid_0's multi_logloss: 2.90315
# [302]	valid_0's multi_logloss: 2.90312
# [303]	valid_0's multi_logloss: 2.90305
# [304]	valid_0's multi_logloss: 2.90302
# [305]	valid_0's multi_logloss: 2.90303
# [306]	valid_0's multi_logloss: 2.90305
# [307]	valid_0's multi_logloss: 2.90304
# [308]	valid_0's multi_logloss: 2.90308
# [309]	valid_0's multi_logloss: 2.90307
# [310]	valid_0's multi_logloss: 2.90302
# [311]	valid_0's multi_logloss: 2.90297
# [312]	valid_0's multi_logloss: 2.90299
# [313]	valid_0's multi_logloss: 2.90295
# [314]	valid_0's multi_logloss: 2.90294
# [315]	valid_0's multi_logloss: 2.90295
# [316]	valid_0's multi_logloss: 2.90296
# [317]	valid_0's multi_logloss: 2.90295
# [318]	valid_0's multi_logloss: 2.90295
# [319]	valid_0's multi_logloss: 2.90294
# [320]	valid_0's multi_logloss: 2.90292
# [321]	valid_0's multi_logloss: 2.90291
# [322]	valid_0's multi_logloss: 2.90295
# [323]	valid_0's multi_logloss: 2.90294
# [324]	valid_0's multi_logloss: 2.90291
# [325]	valid_0's multi_logloss: 2.90292
# [326]	valid_0's multi_logloss: 2.90289
# [327]	valid_0's multi_logloss: 2.90287
# [328]	valid_0's multi_logloss: 2.90286
# [329]	valid_0's multi_logloss: 2.90288
# [330]	valid_0's multi_logloss: 2.90292
# [331]	valid_0's multi_logloss: 2.90293
# [332]	valid_0's multi_logloss: 2.90294
# [333]	valid_0's multi_logloss: 2.90293
# [334]	valid_0's multi_logloss: 2.90291
# [335]	valid_0's multi_logloss: 2.90292
# [336]	valid_0's multi_logloss: 2.90294
# [337]	valid_0's multi_logloss: 2.90296
# [338]	valid_0's multi_logloss: 2.90299
# Early stopping, best iteration is:
# [328]	valid_0's multi_logloss: 2.90286
# 0.014267223971276218
# [1]	valid_0's multi_logloss: 2.92636
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92518
# [3]	valid_0's multi_logloss: 2.924
# [4]	valid_0's multi_logloss: 2.92299
# [5]	valid_0's multi_logloss: 2.92199
# [6]	valid_0's multi_logloss: 2.92112
# [7]	valid_0's multi_logloss: 2.92024
# [8]	valid_0's multi_logloss: 2.91952
# [9]	valid_0's multi_logloss: 2.91853
# [10]	valid_0's multi_logloss: 2.91773
# [11]	valid_0's multi_logloss: 2.917
# [12]	valid_0's multi_logloss: 2.9162
# [13]	valid_0's multi_logloss: 2.91538
# [14]	valid_0's multi_logloss: 2.91462
# [15]	valid_0's multi_logloss: 2.91394
# [16]	valid_0's multi_logloss: 2.91322
# [17]	valid_0's multi_logloss: 2.91248
# [18]	valid_0's multi_logloss: 2.91177
# [19]	valid_0's multi_logloss: 2.91105
# [20]	valid_0's multi_logloss: 2.91035
# [21]	valid_0's multi_logloss: 2.90969
# [22]	valid_0's multi_logloss: 2.90905
# [23]	valid_0's multi_logloss: 2.90836
# [24]	valid_0's multi_logloss: 2.90768
# [25]	valid_0's multi_logloss: 2.90709
# [26]	valid_0's multi_logloss: 2.90639
# [27]	valid_0's multi_logloss: 2.90591
# [28]	valid_0's multi_logloss: 2.9053
# [29]	valid_0's multi_logloss: 2.90462
# [30]	valid_0's multi_logloss: 2.90405
# [31]	valid_0's multi_logloss: 2.90348
# [32]	valid_0's multi_logloss: 2.90295
# [33]	valid_0's multi_logloss: 2.9023
# [34]	valid_0's multi_logloss: 2.90172
# [35]	valid_0's multi_logloss: 2.9012
# [36]	valid_0's multi_logloss: 2.90063
# [37]	valid_0's multi_logloss: 2.90006
# [38]	valid_0's multi_logloss: 2.89959
# [39]	valid_0's multi_logloss: 2.89892
# [40]	valid_0's multi_logloss: 2.89837
# [41]	valid_0's multi_logloss: 2.89788
# [42]	valid_0's multi_logloss: 2.89737
# [43]	valid_0's multi_logloss: 2.89686
# [44]	valid_0's multi_logloss: 2.89636
# [45]	valid_0's multi_logloss: 2.89576
# [46]	valid_0's multi_logloss: 2.89519
# [47]	valid_0's multi_logloss: 2.89471
# [48]	valid_0's multi_logloss: 2.8942
# [49]	valid_0's multi_logloss: 2.8937
# [50]	valid_0's multi_logloss: 2.89317
# [51]	valid_0's multi_logloss: 2.89272
# [52]	valid_0's multi_logloss: 2.89227
# [53]	valid_0's multi_logloss: 2.89182
# [54]	valid_0's multi_logloss: 2.89141
# [55]	valid_0's multi_logloss: 2.89095
# [56]	valid_0's multi_logloss: 2.89057
# [57]	valid_0's multi_logloss: 2.89019
# [58]	valid_0's multi_logloss: 2.88978
# [59]	valid_0's multi_logloss: 2.88933
# [60]	valid_0's multi_logloss: 2.88886
# [61]	valid_0's multi_logloss: 2.88847
# [62]	valid_0's multi_logloss: 2.88817
# [63]	valid_0's multi_logloss: 2.88777
# [64]	valid_0's multi_logloss: 2.88748
# [65]	valid_0's multi_logloss: 2.88708
# [66]	valid_0's multi_logloss: 2.88681
# [67]	valid_0's multi_logloss: 2.88637
# [68]	valid_0's multi_logloss: 2.886
# [69]	valid_0's multi_logloss: 2.88567
# [70]	valid_0's multi_logloss: 2.88534
# [71]	valid_0's multi_logloss: 2.88496
# [72]	valid_0's multi_logloss: 2.88468
# [73]	valid_0's multi_logloss: 2.8844
# [74]	valid_0's multi_logloss: 2.88407
# [75]	valid_0's multi_logloss: 2.88378
# [76]	valid_0's multi_logloss: 2.88348
# [77]	valid_0's multi_logloss: 2.88316
# [78]	valid_0's multi_logloss: 2.88279
# [79]	valid_0's multi_logloss: 2.8825
# [80]	valid_0's multi_logloss: 2.88227
# [81]	valid_0's multi_logloss: 2.88201
# [82]	valid_0's multi_logloss: 2.88168
# [83]	valid_0's multi_logloss: 2.88132
# [84]	valid_0's multi_logloss: 2.88111
# [85]	valid_0's multi_logloss: 2.88081
# [86]	valid_0's multi_logloss: 2.88057
# [87]	valid_0's multi_logloss: 2.88032
# [88]	valid_0's multi_logloss: 2.88006
# [89]	valid_0's multi_logloss: 2.87983
# [90]	valid_0's multi_logloss: 2.87961
# [91]	valid_0's multi_logloss: 2.87931
# [92]	valid_0's multi_logloss: 2.87905
# [93]	valid_0's multi_logloss: 2.87879
# [94]	valid_0's multi_logloss: 2.87854
# [95]	valid_0's multi_logloss: 2.87819
# [96]	valid_0's multi_logloss: 2.87794
# [97]	valid_0's multi_logloss: 2.87769
# [98]	valid_0's multi_logloss: 2.87743
# [99]	valid_0's multi_logloss: 2.8772
# [100]	valid_0's multi_logloss: 2.87695
# [101]	valid_0's multi_logloss: 2.87674
# [102]	valid_0's multi_logloss: 2.87649
# [103]	valid_0's multi_logloss: 2.87622
# [104]	valid_0's multi_logloss: 2.87599
# [105]	valid_0's multi_logloss: 2.87569
# [106]	valid_0's multi_logloss: 2.87544
# [107]	valid_0's multi_logloss: 2.87516
# [108]	valid_0's multi_logloss: 2.87491
# [109]	valid_0's multi_logloss: 2.87467
# [110]	valid_0's multi_logloss: 2.87448
# [111]	valid_0's multi_logloss: 2.87427
# [112]	valid_0's multi_logloss: 2.87403
# [113]	valid_0's multi_logloss: 2.87378
# [114]	valid_0's multi_logloss: 2.87358
# [115]	valid_0's multi_logloss: 2.8734
# [116]	valid_0's multi_logloss: 2.87318
# [117]	valid_0's multi_logloss: 2.87291
# [118]	valid_0's multi_logloss: 2.87274
# [119]	valid_0's multi_logloss: 2.87253
# [120]	valid_0's multi_logloss: 2.87234
# [121]	valid_0's multi_logloss: 2.87212
# [122]	valid_0's multi_logloss: 2.87199
# [123]	valid_0's multi_logloss: 2.87172
# [124]	valid_0's multi_logloss: 2.87151
# [125]	valid_0's multi_logloss: 2.87131
# [126]	valid_0's multi_logloss: 2.87109
# [127]	valid_0's multi_logloss: 2.87087
# [128]	valid_0's multi_logloss: 2.87071
# [129]	valid_0's multi_logloss: 2.87049
# [130]	valid_0's multi_logloss: 2.87026
# [131]	valid_0's multi_logloss: 2.87007
# [132]	valid_0's multi_logloss: 2.86988
# [133]	valid_0's multi_logloss: 2.86956
# [134]	valid_0's multi_logloss: 2.8693
# [135]	valid_0's multi_logloss: 2.86908
# [136]	valid_0's multi_logloss: 2.86876
# [137]	valid_0's multi_logloss: 2.8686
# [138]	valid_0's multi_logloss: 2.86841
# [139]	valid_0's multi_logloss: 2.86818
# [140]	valid_0's multi_logloss: 2.86801
# [141]	valid_0's multi_logloss: 2.86783
# [142]	valid_0's multi_logloss: 2.86759
# [143]	valid_0's multi_logloss: 2.86735
# [144]	valid_0's multi_logloss: 2.86718
# [145]	valid_0's multi_logloss: 2.86691
# [146]	valid_0's multi_logloss: 2.86668
# [147]	valid_0's multi_logloss: 2.8665
# [148]	valid_0's multi_logloss: 2.86627
# [149]	valid_0's multi_logloss: 2.8661
# [150]	valid_0's multi_logloss: 2.86587
# [151]	valid_0's multi_logloss: 2.8657
# [152]	valid_0's multi_logloss: 2.86553
# [153]	valid_0's multi_logloss: 2.8653
# [154]	valid_0's multi_logloss: 2.86506
# [155]	valid_0's multi_logloss: 2.86478
# [156]	valid_0's multi_logloss: 2.86456
# [157]	valid_0's multi_logloss: 2.86438
# [158]	valid_0's multi_logloss: 2.86416
# [159]	valid_0's multi_logloss: 2.86399
# [160]	valid_0's multi_logloss: 2.86373
# [161]	valid_0's multi_logloss: 2.86355
# [162]	valid_0's multi_logloss: 2.8634
# [163]	valid_0's multi_logloss: 2.86316
# [164]	valid_0's multi_logloss: 2.86295
# [165]	valid_0's multi_logloss: 2.86277
# [166]	valid_0's multi_logloss: 2.86255
# [167]	valid_0's multi_logloss: 2.86248
# [168]	valid_0's multi_logloss: 2.86226
# [169]	valid_0's multi_logloss: 2.86211
# [170]	valid_0's multi_logloss: 2.86195
# [171]	valid_0's multi_logloss: 2.8618
# [172]	valid_0's multi_logloss: 2.86166
# [173]	valid_0's multi_logloss: 2.86151
# [174]	valid_0's multi_logloss: 2.86135
# [175]	valid_0's multi_logloss: 2.86116
# [176]	valid_0's multi_logloss: 2.86106
# [177]	valid_0's multi_logloss: 2.86091
# [178]	valid_0's multi_logloss: 2.86077
# [179]	valid_0's multi_logloss: 2.86058
# [180]	valid_0's multi_logloss: 2.86048
# [181]	valid_0's multi_logloss: 2.86033
# [182]	valid_0's multi_logloss: 2.86027
# [183]	valid_0's multi_logloss: 2.8601
# [184]	valid_0's multi_logloss: 2.85997
# [185]	valid_0's multi_logloss: 2.85984
# [186]	valid_0's multi_logloss: 2.85974
# [187]	valid_0's multi_logloss: 2.85959
# [188]	valid_0's multi_logloss: 2.85945
# [189]	valid_0's multi_logloss: 2.85932
# [190]	valid_0's multi_logloss: 2.8592
# [191]	valid_0's multi_logloss: 2.85907
# [192]	valid_0's multi_logloss: 2.85895
# [193]	valid_0's multi_logloss: 2.85882
# [194]	valid_0's multi_logloss: 2.85868
# [195]	valid_0's multi_logloss: 2.8586
# [196]	valid_0's multi_logloss: 2.85848
# [197]	valid_0's multi_logloss: 2.85831
# [198]	valid_0's multi_logloss: 2.85822
# [199]	valid_0's multi_logloss: 2.85816
# [200]	valid_0's multi_logloss: 2.85806
# [201]	valid_0's multi_logloss: 2.85791
# [202]	valid_0's multi_logloss: 2.85784
# [203]	valid_0's multi_logloss: 2.85774
# [204]	valid_0's multi_logloss: 2.85759
# [205]	valid_0's multi_logloss: 2.8574
# [206]	valid_0's multi_logloss: 2.8573
# [207]	valid_0's multi_logloss: 2.85717
# [208]	valid_0's multi_logloss: 2.85711
# [209]	valid_0's multi_logloss: 2.85698
# [210]	valid_0's multi_logloss: 2.85685
# [211]	valid_0's multi_logloss: 2.85676
# [212]	valid_0's multi_logloss: 2.85664
# [213]	valid_0's multi_logloss: 2.85651
# [214]	valid_0's multi_logloss: 2.85642
# [215]	valid_0's multi_logloss: 2.85641
# [216]	valid_0's multi_logloss: 2.85629
# [217]	valid_0's multi_logloss: 2.85622
# [218]	valid_0's multi_logloss: 2.85614
# [219]	valid_0's multi_logloss: 2.85604
# [220]	valid_0's multi_logloss: 2.85591
# [221]	valid_0's multi_logloss: 2.85584
# [222]	valid_0's multi_logloss: 2.8558
# [223]	valid_0's multi_logloss: 2.85568
# [224]	valid_0's multi_logloss: 2.85565
# [225]	valid_0's multi_logloss: 2.85558
# [226]	valid_0's multi_logloss: 2.85551
# [227]	valid_0's multi_logloss: 2.85544
# [228]	valid_0's multi_logloss: 2.85539
# [229]	valid_0's multi_logloss: 2.85531
# [230]	valid_0's multi_logloss: 2.85527
# [231]	valid_0's multi_logloss: 2.85515
# [232]	valid_0's multi_logloss: 2.85518
# [233]	valid_0's multi_logloss: 2.85509
# [234]	valid_0's multi_logloss: 2.85501
# [235]	valid_0's multi_logloss: 2.855
# [236]	valid_0's multi_logloss: 2.85493
# [237]	valid_0's multi_logloss: 2.85489
# [238]	valid_0's multi_logloss: 2.85487
# [239]	valid_0's multi_logloss: 2.85485
# [240]	valid_0's multi_logloss: 2.8548
# [241]	valid_0's multi_logloss: 2.85474
# [242]	valid_0's multi_logloss: 2.8547
# [243]	valid_0's multi_logloss: 2.85467
# [244]	valid_0's multi_logloss: 2.85455
# [245]	valid_0's multi_logloss: 2.8545
# [246]	valid_0's multi_logloss: 2.85452
# [247]	valid_0's multi_logloss: 2.85451
# [248]	valid_0's multi_logloss: 2.85443
# [249]	valid_0's multi_logloss: 2.85433
# [250]	valid_0's multi_logloss: 2.85428
# [251]	valid_0's multi_logloss: 2.8542
# [252]	valid_0's multi_logloss: 2.85411
# [253]	valid_0's multi_logloss: 2.85411
# [254]	valid_0's multi_logloss: 2.85404
# [255]	valid_0's multi_logloss: 2.85405
# [256]	valid_0's multi_logloss: 2.85401
# [257]	valid_0's multi_logloss: 2.854
# [258]	valid_0's multi_logloss: 2.85392
# [259]	valid_0's multi_logloss: 2.85387
# [260]	valid_0's multi_logloss: 2.85391
# [261]	valid_0's multi_logloss: 2.85383
# [262]	valid_0's multi_logloss: 2.8539
# [263]	valid_0's multi_logloss: 2.85381
# [264]	valid_0's multi_logloss: 2.85379
# [265]	valid_0's multi_logloss: 2.85373
# [266]	valid_0's multi_logloss: 2.85368
# [267]	valid_0's multi_logloss: 2.85363
# [268]	valid_0's multi_logloss: 2.85359
# [269]	valid_0's multi_logloss: 2.8536
# [270]	valid_0's multi_logloss: 2.85356
# [271]	valid_0's multi_logloss: 2.85356
# [272]	valid_0's multi_logloss: 2.85347
# [273]	valid_0's multi_logloss: 2.85343
# [274]	valid_0's multi_logloss: 2.85338
# [275]	valid_0's multi_logloss: 2.85339
# [276]	valid_0's multi_logloss: 2.85338
# [277]	valid_0's multi_logloss: 2.85334
# [278]	valid_0's multi_logloss: 2.85336
# [279]	valid_0's multi_logloss: 2.85337
# [280]	valid_0's multi_logloss: 2.85338
# [281]	valid_0's multi_logloss: 2.85334
# [282]	valid_0's multi_logloss: 2.85338
# [283]	valid_0's multi_logloss: 2.85335
# [284]	valid_0's multi_logloss: 2.85331
# [285]	valid_0's multi_logloss: 2.85331
# [286]	valid_0's multi_logloss: 2.85334
# [287]	valid_0's multi_logloss: 2.85341
# [288]	valid_0's multi_logloss: 2.85332
# [289]	valid_0's multi_logloss: 2.85332
# [290]	valid_0's multi_logloss: 2.85342
# [291]	valid_0's multi_logloss: 2.85337
# [292]	valid_0's multi_logloss: 2.85335
# [293]	valid_0's multi_logloss: 2.85333
# [294]	valid_0's multi_logloss: 2.85335
# [295]	valid_0's multi_logloss: 2.85338
# Early stopping, best iteration is:
# [285]	valid_0's multi_logloss: 2.85331
# 0.014067381353163199
# crps list: [0.012420848725659819, 0.012221910774790802, 0.011849587843216314, 0.014267223971276218, 0.014067381353163199]
# average crps: 0.01296539053362127

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'time_end', 'Grass', 'DefendersInTheBox_vs_Distance', 'DisToQB',
#        'runner_height', 'DefenseAveX', 'DefenseAveY', 'DefenseAveMomentum',
#        'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos',
#        '1stDefender_AttackAngle', 'RusherVoronoi', 'FirstDefenderVoronoi'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                           Grass     539     298     413     231     101
# 1                            Team     441     715     445     315     275
# 2                OffenseFormation     920     836     944     607     494
# 3                            Down     979    1327    1228     531     484
# 4                DefensePersonnel    2252    2171    2200    1348    1736
# 5                          Season    2024    1675    2776    1702    1727
# 6               DefendersInTheBox    2773    1770    2370    2095    1738
# 7                   runner_height    2086    3423    3384    2425    2107
# 8                     StadiumType    3486    4113    4106    1868    2723
# 9                            Week    4536    3601    4101    1918    2218
# 10                    GameWeather    3443    3918    4441    3013    1936
# 11            HomeScoreBeforePlay    3860    4169    3548    2286    2987
# 12               OffensePersonnel    3449    3697    4327    3621    2762
# 13                      WindSpeed    4680    4944    4186    2312    3388
# 14                       Location    4999    5038    4173    3502    2509
# 15                  WindDirection    4869    5495    4722    2952    2516
# 16         VisitorScoreBeforePlay    4926    5317    4544    4138    3463
# 17                  RusherVoronoi    5172    4360    6154    4364    3169
# 18                   PlayerWeight    6698    6061    4462    2984    3422
# 19                        Stadium    5515    4793    5567    4462    3291
# 20                            Dis    6103    5355    5288    4279    3985
# 21                       Distance    8050    7143    8170    2718    1206
# 22                   JerseyNumber    6587    6723    6043    3978    3963
# 23                    Temperature    6805    7024    6730    4419    3777
# 24                    OffenseStdY    6616    7860    6763    4174    4322
# 25                    OffenseStdX    8293    7015    6133    5083    3795
# 26                       Humidity    7024    7436    6994    3870    5238
# 27  DefendersInTheBox_vs_Distance   10032    8011    4574    5220    3095
# 28                              X    7958    6496    7694    4718    4194
# 29                              S    8063    6528    6615    4707    5603
# 30                    Orientation    8328    7543    7131    4398    4262
# 31                    DefenseStdY    8629    8032    6603    4527    4024
# 32             OffenseAveMomentum    8281    7836    7398    4025    4278
# 33         RunnerToDefenseCentoid    7975    7559    8513    5663    4756
# 34                    DefenseAveX    6454    8143    8661    6544    4693
# 35         RunnerToOffenseCentoid    9729    8733    7970    5239    4639
# 36              PlayerCollegeName    9173    7949    8658    6940    5425
# 37                              Y   10007    9422    8833    4676    5343
# 38                    DefenseAveY    9400    8165   10044    6094    4749
# 39                          NflId    9196    8184   10807    5679    4828
# 40             DefenseAveMomentum    9391    9329    9452    6189    4758
# 41                       Momentum    8443   10282    9176    4826    6661
# 42                 OffenseSpreadX    8829   11305    7427    6099    5771
# 43                            Dir    9417    8854   10516    5838    5131
# 44         OffenseStdMomentum_cos    9353    9840    8886    6726    6215
# 45           FirstDefenderVoronoi    8874   10430   10262    6131    5473
# 46                    DefenseStdX    9222   11700    9262    6377    5193
# 47         OffenseAveMomentum_cos   10844    9294   11087    5201    5439
# 48             DefenseStdMomentum    9413    9417   11718    6407    5163
# 49                            age   12656    9901    9011    6159    4665
# 50                 DefenseSpreadX   12535   10888    9495    6303    5650
# 51         DefenseStdMomentum_cos   11788    9778   10768    7354    5958
# 52                        DisToQB   11736   11011   12048    6273    6483
# 53                  MinTackleTime   11016   12902   11154    5654    7097
# 54                        Dir_cos   12505   11281   11800    6521    6389
# 55             OffenseStdMomentum   10477   11829   10231    8873    7398
# 56                       time_end   10856   13603   10448    8250    7397
# 57              RunnerToScrimmage   12518   13517   11528    9446    7116
# 58                       YardLine   12961   13052   12105    8446    7655
# 59       1stOffenser_Momentum_cos   14188   12548   12047    8361    7482
# 60        1stDefender_AttackAngle   13951   14341   11010    8172    7725
# 61         DefenseAveMomentum_cos   16730   14991   14766    8491    8147
# 62                   Momentum_cos   13769   14015   16471    9623    9735
# 63       1stDefender_Momentum_cos   14403   17845   14539   10428    6982
# 64                              A   27925   25979   23586   21723   22450
#
#     Average          Std        Cv
# 0     316.4   150.273883  0.474949
# 1     438.2   153.938169  0.351297
# 2     760.2   178.547921  0.234870
# 3     909.8   347.819148  0.382303
# 4    1941.4   349.392387  0.179969
# 5    1980.8   417.101139  0.210572
# 6    2149.2   388.251156  0.180649
# 7    2685.0   598.954088  0.223074
# 8    3259.2   862.604289  0.264667
# 9    3274.8  1033.186411  0.315496
# 10   3350.2   852.586512  0.254488
# 11   3370.0   668.121246  0.198256
# 12   3571.2   501.851930  0.140528
# 13   3902.0   955.405673  0.244850
# 14   4044.2   955.687271  0.236311
# 15   4110.8  1161.950670  0.282658
# 16   4477.6   641.062431  0.143171
# 17   4643.8   989.299227  0.213037
# 18   4725.4  1447.458683  0.306315
# 19   4725.6   832.251308  0.176115
# 20   5002.0   771.443323  0.154227
# 21   5457.4  2915.466865  0.534223
# 22   5458.8  1236.326235  0.226483
# 23   5751.0  1368.267956  0.237918
# 24   5947.0  1453.075359  0.244338
# 25   6063.8  1548.439524  0.255358
# 26   6112.4  1353.002823  0.221354
# 27   6186.4  2498.332292  0.403843
# 28   6212.0  1525.113504  0.245511
# 29   6303.2  1120.962515  0.177840
# 30   6332.4  1680.130543  0.265323
# 31   6363.0  1834.106540  0.288246
# 32   6363.6  1829.379414  0.287476
# 33   6893.2  1436.547862  0.208401
# 34   6899.0  1403.044262  0.203369
# 35   7262.0  1986.144607  0.273498
# 36   7629.0  1332.479944  0.174660
# 37   7656.2  2202.800708  0.287715
# 38   7690.4  1994.378961  0.259334
# 39   7738.8  2211.380510  0.285752
# 40   7823.8  1972.028337  0.252055
# 41   7877.6  1927.642975  0.244699
# 42   7886.2  2022.675693  0.256483
# 43   7951.2  2095.755654  0.263577
# 44   8204.0  1456.188587  0.177497
# 45   8234.0  2068.358286  0.251197
# 46   8350.8  2309.718719  0.276587
# 47   8373.0  2568.650151  0.306778
# 48   8423.6  2345.933298  0.278495
# 49   8478.4  2817.141502  0.332273
# 50   8974.2  2638.134750  0.293969
# 51   9129.2  2162.575724  0.236886
# 52   9510.2  2580.326289  0.271322
# 53   9564.6  2725.906646  0.285000
# 54   9699.2  2677.549058  0.276059
# 55   9761.6  1508.806893  0.154566
# 56  10110.8  2176.776277  0.215292
# 57  10825.0  2291.970506  0.211729
# 58  10843.8  2318.068109  0.213769
# 59  10925.2  2567.821131  0.235037
# 60  11039.8  2777.987430  0.251634
# 61  12625.0  3582.605253  0.283771
# 62  12722.6  2658.910574  0.208991
# 63  12839.4  3755.356207  0.292487
# 64  24332.6  2303.370452  0.094662

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test, num_iteration = model.best_iteration)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
    
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf', 'Quarter']
top20_weather = list(train.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]
    
    df["Jersey_cat"] = df["JerseyNumber"].apply(lambda x: 0 if x>=1 and x <=9 else #: quarterbacks, kickers, and punters
                                                (1 if x>=10 and x <= 19 else
                                                (2 if x>=20 and x <= 39 else
                                                (3 if x>=40 and x <= 49 else
                                                (4 if x>=50 and x <= 59 else
                                                (5 if x>=60 and x <= 79 else
                                                (6 if x>=80 and x <= 89 else
                                                (7 if x>=90 and x <= 99 else 8))))))))

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]
    
    df["AttackAngle"] =  np.arctan((df["Y"] - df["RushY"]) / (df["X"] - df["RushX"])) * 180 / np.pi

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    #df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])
    df_single["1stDefender_AttackAngle"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["AttackAngle"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "InfluToBall", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY"]#, "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:856: RuntimeWarning: invalid value encountered in arctan
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# CPU times: user 15min 6s, sys: 5.75 s, total: 15min 12s
# Wall time: 15min 9s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : -1,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86908
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86625
# [3]	valid_0's multi_logloss: 2.86404
# [4]	valid_0's multi_logloss: 2.86193
# [5]	valid_0's multi_logloss: 2.85986
# [6]	valid_0's multi_logloss: 2.85791
# [7]	valid_0's multi_logloss: 2.85622
# [8]	valid_0's multi_logloss: 2.85458
# [9]	valid_0's multi_logloss: 2.85262
# [10]	valid_0's multi_logloss: 2.85104
# [11]	valid_0's multi_logloss: 2.84939
# [12]	valid_0's multi_logloss: 2.84756
# [13]	valid_0's multi_logloss: 2.84593
# [14]	valid_0's multi_logloss: 2.84433
# [15]	valid_0's multi_logloss: 2.84276
# [16]	valid_0's multi_logloss: 2.84126
# [17]	valid_0's multi_logloss: 2.83982
# [18]	valid_0's multi_logloss: 2.83835
# [19]	valid_0's multi_logloss: 2.83704
# [20]	valid_0's multi_logloss: 2.8358
# [21]	valid_0's multi_logloss: 2.83438
# [22]	valid_0's multi_logloss: 2.83288
# [23]	valid_0's multi_logloss: 2.83152
# [24]	valid_0's multi_logloss: 2.83013
# [25]	valid_0's multi_logloss: 2.82876
# [26]	valid_0's multi_logloss: 2.82733
# [27]	valid_0's multi_logloss: 2.82594
# [28]	valid_0's multi_logloss: 2.82467
# [29]	valid_0's multi_logloss: 2.82334
# [30]	valid_0's multi_logloss: 2.82219
# [31]	valid_0's multi_logloss: 2.82093
# [32]	valid_0's multi_logloss: 2.81976
# [33]	valid_0's multi_logloss: 2.8186
# [34]	valid_0's multi_logloss: 2.81744
# [35]	valid_0's multi_logloss: 2.8162
# [36]	valid_0's multi_logloss: 2.81516
# [37]	valid_0's multi_logloss: 2.8141
# [38]	valid_0's multi_logloss: 2.81296
# [39]	valid_0's multi_logloss: 2.8119
# [40]	valid_0's multi_logloss: 2.81081
# [41]	valid_0's multi_logloss: 2.80967
# [42]	valid_0's multi_logloss: 2.80866
# [43]	valid_0's multi_logloss: 2.80768
# [44]	valid_0's multi_logloss: 2.8066
# [45]	valid_0's multi_logloss: 2.80559
# [46]	valid_0's multi_logloss: 2.80453
# [47]	valid_0's multi_logloss: 2.80369
# [48]	valid_0's multi_logloss: 2.80264
# [49]	valid_0's multi_logloss: 2.80168
# [50]	valid_0's multi_logloss: 2.80075
# [51]	valid_0's multi_logloss: 2.79988
# [52]	valid_0's multi_logloss: 2.79887
# [53]	valid_0's multi_logloss: 2.79799
# [54]	valid_0's multi_logloss: 2.797
# [55]	valid_0's multi_logloss: 2.79593
# [56]	valid_0's multi_logloss: 2.79499
# [57]	valid_0's multi_logloss: 2.79409
# [58]	valid_0's multi_logloss: 2.79323
# [59]	valid_0's multi_logloss: 2.79245
# [60]	valid_0's multi_logloss: 2.79146
# [61]	valid_0's multi_logloss: 2.79059
# [62]	valid_0's multi_logloss: 2.78975
# [63]	valid_0's multi_logloss: 2.78871
# [64]	valid_0's multi_logloss: 2.78785
# [65]	valid_0's multi_logloss: 2.78698
# [66]	valid_0's multi_logloss: 2.78615
# [67]	valid_0's multi_logloss: 2.78521
# [68]	valid_0's multi_logloss: 2.78433
# [69]	valid_0's multi_logloss: 2.7835
# [70]	valid_0's multi_logloss: 2.78277
# [71]	valid_0's multi_logloss: 2.78179
# [72]	valid_0's multi_logloss: 2.781
# [73]	valid_0's multi_logloss: 2.78014
# [74]	valid_0's multi_logloss: 2.77948
# [75]	valid_0's multi_logloss: 2.77859
# [76]	valid_0's multi_logloss: 2.77775
# [77]	valid_0's multi_logloss: 2.77701
# [78]	valid_0's multi_logloss: 2.77616
# [79]	valid_0's multi_logloss: 2.77533
# [80]	valid_0's multi_logloss: 2.77441
# [81]	valid_0's multi_logloss: 2.77376
# [82]	valid_0's multi_logloss: 2.77301
# [83]	valid_0's multi_logloss: 2.77227
# [84]	valid_0's multi_logloss: 2.7715
# [85]	valid_0's multi_logloss: 2.77073
# [86]	valid_0's multi_logloss: 2.77004
# [87]	valid_0's multi_logloss: 2.76918
# [88]	valid_0's multi_logloss: 2.76849
# [89]	valid_0's multi_logloss: 2.76779
# [90]	valid_0's multi_logloss: 2.76705
# [91]	valid_0's multi_logloss: 2.76632
# [92]	valid_0's multi_logloss: 2.76576
# [93]	valid_0's multi_logloss: 2.76499
# [94]	valid_0's multi_logloss: 2.76434
# [95]	valid_0's multi_logloss: 2.76378
# [96]	valid_0's multi_logloss: 2.76307
# [97]	valid_0's multi_logloss: 2.76246
# [98]	valid_0's multi_logloss: 2.7618
# [99]	valid_0's multi_logloss: 2.76119
# [100]	valid_0's multi_logloss: 2.76061
# [101]	valid_0's multi_logloss: 2.75992
# [102]	valid_0's multi_logloss: 2.75933
# [103]	valid_0's multi_logloss: 2.75871
# [104]	valid_0's multi_logloss: 2.75823
# [105]	valid_0's multi_logloss: 2.7576
# [106]	valid_0's multi_logloss: 2.75689
# [107]	valid_0's multi_logloss: 2.75631
# [108]	valid_0's multi_logloss: 2.75568
# [109]	valid_0's multi_logloss: 2.75516
# [110]	valid_0's multi_logloss: 2.75457
# [111]	valid_0's multi_logloss: 2.75393
# [112]	valid_0's multi_logloss: 2.75326
# [113]	valid_0's multi_logloss: 2.75277
# [114]	valid_0's multi_logloss: 2.75219
# [115]	valid_0's multi_logloss: 2.75159
# [116]	valid_0's multi_logloss: 2.75109
# [117]	valid_0's multi_logloss: 2.7506
# [118]	valid_0's multi_logloss: 2.74999
# [119]	valid_0's multi_logloss: 2.74948
# [120]	valid_0's multi_logloss: 2.74893
# [121]	valid_0's multi_logloss: 2.74847
# [122]	valid_0's multi_logloss: 2.74788
# [123]	valid_0's multi_logloss: 2.74736
# [124]	valid_0's multi_logloss: 2.74686
# [125]	valid_0's multi_logloss: 2.74629
# [126]	valid_0's multi_logloss: 2.74582
# [127]	valid_0's multi_logloss: 2.7453
# [128]	valid_0's multi_logloss: 2.74477
# [129]	valid_0's multi_logloss: 2.74432
# [130]	valid_0's multi_logloss: 2.74387
# [131]	valid_0's multi_logloss: 2.7434
# [132]	valid_0's multi_logloss: 2.7429
# [133]	valid_0's multi_logloss: 2.74246
# [134]	valid_0's multi_logloss: 2.74204
# [135]	valid_0's multi_logloss: 2.74156
# [136]	valid_0's multi_logloss: 2.74118
# [137]	valid_0's multi_logloss: 2.7407
# [138]	valid_0's multi_logloss: 2.74026
# [139]	valid_0's multi_logloss: 2.73978
# [140]	valid_0's multi_logloss: 2.73928
# [141]	valid_0's multi_logloss: 2.73885
# [142]	valid_0's multi_logloss: 2.73843
# [143]	valid_0's multi_logloss: 2.73794
# [144]	valid_0's multi_logloss: 2.7374
# [145]	valid_0's multi_logloss: 2.73694
# [146]	valid_0's multi_logloss: 2.7365
# [147]	valid_0's multi_logloss: 2.73601
# [148]	valid_0's multi_logloss: 2.73563
# [149]	valid_0's multi_logloss: 2.7352
# [150]	valid_0's multi_logloss: 2.73475
# [151]	valid_0's multi_logloss: 2.73425
# [152]	valid_0's multi_logloss: 2.73391
# [153]	valid_0's multi_logloss: 2.73343
# [154]	valid_0's multi_logloss: 2.733
# [155]	valid_0's multi_logloss: 2.73257
# [156]	valid_0's multi_logloss: 2.73216
# [157]	valid_0's multi_logloss: 2.73164
# [158]	valid_0's multi_logloss: 2.73123
# [159]	valid_0's multi_logloss: 2.73077
# [160]	valid_0's multi_logloss: 2.73033
# [161]	valid_0's multi_logloss: 2.72995
# [162]	valid_0's multi_logloss: 2.72965
# [163]	valid_0's multi_logloss: 2.72919
# [164]	valid_0's multi_logloss: 2.72873
# [165]	valid_0's multi_logloss: 2.72834
# [166]	valid_0's multi_logloss: 2.72801
# [167]	valid_0's multi_logloss: 2.72764
# [168]	valid_0's multi_logloss: 2.72726
# [169]	valid_0's multi_logloss: 2.72693
# [170]	valid_0's multi_logloss: 2.72665
# [171]	valid_0's multi_logloss: 2.72617
# [172]	valid_0's multi_logloss: 2.72581
# [173]	valid_0's multi_logloss: 2.72538
# [174]	valid_0's multi_logloss: 2.72502
# [175]	valid_0's multi_logloss: 2.72467
# [176]	valid_0's multi_logloss: 2.72426
# [177]	valid_0's multi_logloss: 2.72396
# [178]	valid_0's multi_logloss: 2.72361
# [179]	valid_0's multi_logloss: 2.72336
# [180]	valid_0's multi_logloss: 2.72298
# [181]	valid_0's multi_logloss: 2.7227
# [182]	valid_0's multi_logloss: 2.72232
# [183]	valid_0's multi_logloss: 2.72199
# [184]	valid_0's multi_logloss: 2.72157
# [185]	valid_0's multi_logloss: 2.72121
# [186]	valid_0's multi_logloss: 2.72095
# [187]	valid_0's multi_logloss: 2.72069
# [188]	valid_0's multi_logloss: 2.72043
# [189]	valid_0's multi_logloss: 2.72015
# [190]	valid_0's multi_logloss: 2.71986
# [191]	valid_0's multi_logloss: 2.71956
# [192]	valid_0's multi_logloss: 2.71933
# [193]	valid_0's multi_logloss: 2.71906
# [194]	valid_0's multi_logloss: 2.71879
# [195]	valid_0's multi_logloss: 2.71852
# [196]	valid_0's multi_logloss: 2.71832
# [197]	valid_0's multi_logloss: 2.71805
# [198]	valid_0's multi_logloss: 2.7178
# [199]	valid_0's multi_logloss: 2.71756
# [200]	valid_0's multi_logloss: 2.71728
# [201]	valid_0's multi_logloss: 2.71694
# [202]	valid_0's multi_logloss: 2.71675
# [203]	valid_0's multi_logloss: 2.71648
# [204]	valid_0's multi_logloss: 2.71631
# [205]	valid_0's multi_logloss: 2.71605
# [206]	valid_0's multi_logloss: 2.71575
# [207]	valid_0's multi_logloss: 2.71551
# [208]	valid_0's multi_logloss: 2.71533
# [209]	valid_0's multi_logloss: 2.71505
# [210]	valid_0's multi_logloss: 2.71477
# [211]	valid_0's multi_logloss: 2.71459
# [212]	valid_0's multi_logloss: 2.71438
# [213]	valid_0's multi_logloss: 2.71407
# [214]	valid_0's multi_logloss: 2.71379
# [215]	valid_0's multi_logloss: 2.71357
# [216]	valid_0's multi_logloss: 2.71338
# [217]	valid_0's multi_logloss: 2.71312
# [218]	valid_0's multi_logloss: 2.71285
# [219]	valid_0's multi_logloss: 2.71262
# [220]	valid_0's multi_logloss: 2.71241
# [221]	valid_0's multi_logloss: 2.71219
# [222]	valid_0's multi_logloss: 2.71191
# [223]	valid_0's multi_logloss: 2.71174
# [224]	valid_0's multi_logloss: 2.71151
# [225]	valid_0's multi_logloss: 2.71138
# [226]	valid_0's multi_logloss: 2.71116
# [227]	valid_0's multi_logloss: 2.71098
# [228]	valid_0's multi_logloss: 2.71076
# [229]	valid_0's multi_logloss: 2.7106
# [230]	valid_0's multi_logloss: 2.71041
# [231]	valid_0's multi_logloss: 2.71018
# [232]	valid_0's multi_logloss: 2.70996
# [233]	valid_0's multi_logloss: 2.7098
# [234]	valid_0's multi_logloss: 2.70963
# [235]	valid_0's multi_logloss: 2.70944
# [236]	valid_0's multi_logloss: 2.70929
# [237]	valid_0's multi_logloss: 2.70913
# [238]	valid_0's multi_logloss: 2.70901
# [239]	valid_0's multi_logloss: 2.70887
# [240]	valid_0's multi_logloss: 2.70862
# [241]	valid_0's multi_logloss: 2.70847
# [242]	valid_0's multi_logloss: 2.70836
# [243]	valid_0's multi_logloss: 2.70816
# [244]	valid_0's multi_logloss: 2.70798
# [245]	valid_0's multi_logloss: 2.70783
# [246]	valid_0's multi_logloss: 2.70763
# [247]	valid_0's multi_logloss: 2.70743
# [248]	valid_0's multi_logloss: 2.70728
# [249]	valid_0's multi_logloss: 2.70709
# [250]	valid_0's multi_logloss: 2.70693
# [251]	valid_0's multi_logloss: 2.70675
# [252]	valid_0's multi_logloss: 2.70662
# [253]	valid_0's multi_logloss: 2.70644
# [254]	valid_0's multi_logloss: 2.7063
# [255]	valid_0's multi_logloss: 2.70613
# [256]	valid_0's multi_logloss: 2.70597
# [257]	valid_0's multi_logloss: 2.7057
# [258]	valid_0's multi_logloss: 2.7056
# [259]	valid_0's multi_logloss: 2.70546
# [260]	valid_0's multi_logloss: 2.7053
# [261]	valid_0's multi_logloss: 2.70514
# [262]	valid_0's multi_logloss: 2.70499
# [263]	valid_0's multi_logloss: 2.70489
# [264]	valid_0's multi_logloss: 2.70475
# [265]	valid_0's multi_logloss: 2.70461
# [266]	valid_0's multi_logloss: 2.70447
# [267]	valid_0's multi_logloss: 2.70426
# [268]	valid_0's multi_logloss: 2.70405
# [269]	valid_0's multi_logloss: 2.70395
# [270]	valid_0's multi_logloss: 2.70383
# [271]	valid_0's multi_logloss: 2.70374
# [272]	valid_0's multi_logloss: 2.70359
# [273]	valid_0's multi_logloss: 2.70349
# [274]	valid_0's multi_logloss: 2.7033
# [275]	valid_0's multi_logloss: 2.70323
# [276]	valid_0's multi_logloss: 2.70307
# [277]	valid_0's multi_logloss: 2.70293
# [278]	valid_0's multi_logloss: 2.70277
# [279]	valid_0's multi_logloss: 2.70268
# [280]	valid_0's multi_logloss: 2.70262
# [281]	valid_0's multi_logloss: 2.70254
# [282]	valid_0's multi_logloss: 2.70241
# [283]	valid_0's multi_logloss: 2.70226
# [284]	valid_0's multi_logloss: 2.7021
# [285]	valid_0's multi_logloss: 2.70205
# [286]	valid_0's multi_logloss: 2.70193
# [287]	valid_0's multi_logloss: 2.70178
# [288]	valid_0's multi_logloss: 2.70172
# [289]	valid_0's multi_logloss: 2.70163
# [290]	valid_0's multi_logloss: 2.70152
# [291]	valid_0's multi_logloss: 2.70139
# [292]	valid_0's multi_logloss: 2.7013
# [293]	valid_0's multi_logloss: 2.70118
# [294]	valid_0's multi_logloss: 2.70107
# [295]	valid_0's multi_logloss: 2.70098
# [296]	valid_0's multi_logloss: 2.70082
# [297]	valid_0's multi_logloss: 2.70074
# [298]	valid_0's multi_logloss: 2.70064
# [299]	valid_0's multi_logloss: 2.70055
# [300]	valid_0's multi_logloss: 2.70038
# [301]	valid_0's multi_logloss: 2.70034
# [302]	valid_0's multi_logloss: 2.70023
# [303]	valid_0's multi_logloss: 2.70018
# [304]	valid_0's multi_logloss: 2.70011
# [305]	valid_0's multi_logloss: 2.70005
# [306]	valid_0's multi_logloss: 2.69987
# [307]	valid_0's multi_logloss: 2.69976
# [308]	valid_0's multi_logloss: 2.6997
# [309]	valid_0's multi_logloss: 2.69962
# [310]	valid_0's multi_logloss: 2.6996
# [311]	valid_0's multi_logloss: 2.6995
# [312]	valid_0's multi_logloss: 2.69938
# [313]	valid_0's multi_logloss: 2.69927
# [314]	valid_0's multi_logloss: 2.69921
# [315]	valid_0's multi_logloss: 2.69917
# [316]	valid_0's multi_logloss: 2.69911
# [317]	valid_0's multi_logloss: 2.69894
# [318]	valid_0's multi_logloss: 2.69883
# [319]	valid_0's multi_logloss: 2.69869
# [320]	valid_0's multi_logloss: 2.69858
# [321]	valid_0's multi_logloss: 2.69852
# [322]	valid_0's multi_logloss: 2.69844
# [323]	valid_0's multi_logloss: 2.69839
# [324]	valid_0's multi_logloss: 2.69837
# [325]	valid_0's multi_logloss: 2.69828
# [326]	valid_0's multi_logloss: 2.69821
# [327]	valid_0's multi_logloss: 2.69814
# [328]	valid_0's multi_logloss: 2.69808
# [329]	valid_0's multi_logloss: 2.69802
# [330]	valid_0's multi_logloss: 2.69804
# [331]	valid_0's multi_logloss: 2.69792
# [332]	valid_0's multi_logloss: 2.69785
# [333]	valid_0's multi_logloss: 2.69777
# [334]	valid_0's multi_logloss: 2.69777
# [335]	valid_0's multi_logloss: 2.69776
# [336]	valid_0's multi_logloss: 2.69761
# [337]	valid_0's multi_logloss: 2.6975
# [338]	valid_0's multi_logloss: 2.69743
# [339]	valid_0's multi_logloss: 2.6974
# [340]	valid_0's multi_logloss: 2.69737
# [341]	valid_0's multi_logloss: 2.69727
# [342]	valid_0's multi_logloss: 2.69723
# [343]	valid_0's multi_logloss: 2.69721
# [344]	valid_0's multi_logloss: 2.69721
# [345]	valid_0's multi_logloss: 2.69715
# [346]	valid_0's multi_logloss: 2.69706
# [347]	valid_0's multi_logloss: 2.69694
# [348]	valid_0's multi_logloss: 2.69686
# [349]	valid_0's multi_logloss: 2.69675
# [350]	valid_0's multi_logloss: 2.69668
# [351]	valid_0's multi_logloss: 2.69662
# [352]	valid_0's multi_logloss: 2.69656
# [353]	valid_0's multi_logloss: 2.69654
# [354]	valid_0's multi_logloss: 2.69651
# [355]	valid_0's multi_logloss: 2.69642
# [356]	valid_0's multi_logloss: 2.69629
# [357]	valid_0's multi_logloss: 2.69615
# [358]	valid_0's multi_logloss: 2.69616
# [359]	valid_0's multi_logloss: 2.69613
# [360]	valid_0's multi_logloss: 2.69609
# [361]	valid_0's multi_logloss: 2.69602
# [362]	valid_0's multi_logloss: 2.696
# [363]	valid_0's multi_logloss: 2.69595
# [364]	valid_0's multi_logloss: 2.69587
# [365]	valid_0's multi_logloss: 2.69584
# [366]	valid_0's multi_logloss: 2.69576
# [367]	valid_0's multi_logloss: 2.69571
# [368]	valid_0's multi_logloss: 2.69563
# [369]	valid_0's multi_logloss: 2.6956
# [370]	valid_0's multi_logloss: 2.69558
# [371]	valid_0's multi_logloss: 2.69551
# [372]	valid_0's multi_logloss: 2.69545
# [373]	valid_0's multi_logloss: 2.69539
# [374]	valid_0's multi_logloss: 2.69536
# [375]	valid_0's multi_logloss: 2.69533
# [376]	valid_0's multi_logloss: 2.69526
# [377]	valid_0's multi_logloss: 2.69521
# [378]	valid_0's multi_logloss: 2.69513
# [379]	valid_0's multi_logloss: 2.6951
# [380]	valid_0's multi_logloss: 2.69515
# [381]	valid_0's multi_logloss: 2.69509
# [382]	valid_0's multi_logloss: 2.69501
# [383]	valid_0's multi_logloss: 2.69501
# [384]	valid_0's multi_logloss: 2.69495
# [385]	valid_0's multi_logloss: 2.69492
# [386]	valid_0's multi_logloss: 2.6948
# [387]	valid_0's multi_logloss: 2.69486
# [388]	valid_0's multi_logloss: 2.69485
# [389]	valid_0's multi_logloss: 2.69482
# [390]	valid_0's multi_logloss: 2.69474
# [391]	valid_0's multi_logloss: 2.69474
# [392]	valid_0's multi_logloss: 2.69481
# [393]	valid_0's multi_logloss: 2.69478
# [394]	valid_0's multi_logloss: 2.69474
# [395]	valid_0's multi_logloss: 2.69471
# [396]	valid_0's multi_logloss: 2.69466
# [397]	valid_0's multi_logloss: 2.69467
# [398]	valid_0's multi_logloss: 2.69458
# [399]	valid_0's multi_logloss: 2.69457
# [400]	valid_0's multi_logloss: 2.69452
# [401]	valid_0's multi_logloss: 2.69446
# [402]	valid_0's multi_logloss: 2.69445
# [403]	valid_0's multi_logloss: 2.69443
# [404]	valid_0's multi_logloss: 2.69448
# [405]	valid_0's multi_logloss: 2.69445
# [406]	valid_0's multi_logloss: 2.69441
# [407]	valid_0's multi_logloss: 2.69445
# [408]	valid_0's multi_logloss: 2.69441
# [409]	valid_0's multi_logloss: 2.69438
# [410]	valid_0's multi_logloss: 2.69438
# [411]	valid_0's multi_logloss: 2.69443
# [412]	valid_0's multi_logloss: 2.69436
# [413]	valid_0's multi_logloss: 2.69438
# [414]	valid_0's multi_logloss: 2.69438
# [415]	valid_0's multi_logloss: 2.69438
# [416]	valid_0's multi_logloss: 2.69439
# [417]	valid_0's multi_logloss: 2.69433
# [418]	valid_0's multi_logloss: 2.69432
# [419]	valid_0's multi_logloss: 2.69435
# [420]	valid_0's multi_logloss: 2.69437
# [421]	valid_0's multi_logloss: 2.6944
# [422]	valid_0's multi_logloss: 2.69442
# [423]	valid_0's multi_logloss: 2.69436
# [424]	valid_0's multi_logloss: 2.69434
# [425]	valid_0's multi_logloss: 2.69433
# [426]	valid_0's multi_logloss: 2.69434
# [427]	valid_0's multi_logloss: 2.6943
# [428]	valid_0's multi_logloss: 2.6943
# [429]	valid_0's multi_logloss: 2.69426
# [430]	valid_0's multi_logloss: 2.69426
# [431]	valid_0's multi_logloss: 2.69428
# [432]	valid_0's multi_logloss: 2.69426
# [433]	valid_0's multi_logloss: 2.69423
# [434]	valid_0's multi_logloss: 2.69424
# [435]	valid_0's multi_logloss: 2.69427
# [436]	valid_0's multi_logloss: 2.69431
# [437]	valid_0's multi_logloss: 2.69425
# [438]	valid_0's multi_logloss: 2.69428
# [439]	valid_0's multi_logloss: 2.69429
# [440]	valid_0's multi_logloss: 2.69431
# [441]	valid_0's multi_logloss: 2.69434
# [442]	valid_0's multi_logloss: 2.69431
# [443]	valid_0's multi_logloss: 2.69429
# Early stopping, best iteration is:
# [433]	valid_0's multi_logloss: 2.69423
# 0.012499079618353474
# [1]	valid_0's multi_logloss: 2.88684
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88393
# [3]	valid_0's multi_logloss: 2.88168
# [4]	valid_0's multi_logloss: 2.87924
# [5]	valid_0's multi_logloss: 2.87719
# [6]	valid_0's multi_logloss: 2.87489
# [7]	valid_0's multi_logloss: 2.87305
# [8]	valid_0's multi_logloss: 2.87111
# [9]	valid_0's multi_logloss: 2.86924
# [10]	valid_0's multi_logloss: 2.86738
# [11]	valid_0's multi_logloss: 2.86564
# [12]	valid_0's multi_logloss: 2.8637
# [13]	valid_0's multi_logloss: 2.86188
# [14]	valid_0's multi_logloss: 2.86027
# [15]	valid_0's multi_logloss: 2.85848
# [16]	valid_0's multi_logloss: 2.85699
# [17]	valid_0's multi_logloss: 2.85549
# [18]	valid_0's multi_logloss: 2.85389
# [19]	valid_0's multi_logloss: 2.85229
# [20]	valid_0's multi_logloss: 2.85074
# [21]	valid_0's multi_logloss: 2.84919
# [22]	valid_0's multi_logloss: 2.84776
# [23]	valid_0's multi_logloss: 2.8462
# [24]	valid_0's multi_logloss: 2.84459
# [25]	valid_0's multi_logloss: 2.84325
# [26]	valid_0's multi_logloss: 2.84194
# [27]	valid_0's multi_logloss: 2.84035
# [28]	valid_0's multi_logloss: 2.83899
# [29]	valid_0's multi_logloss: 2.83761
# [30]	valid_0's multi_logloss: 2.83622
# [31]	valid_0's multi_logloss: 2.83484
# [32]	valid_0's multi_logloss: 2.8335
# [33]	valid_0's multi_logloss: 2.83203
# [34]	valid_0's multi_logloss: 2.83077
# [35]	valid_0's multi_logloss: 2.8295
# [36]	valid_0's multi_logloss: 2.82829
# [37]	valid_0's multi_logloss: 2.82695
# [38]	valid_0's multi_logloss: 2.82575
# [39]	valid_0's multi_logloss: 2.82453
# [40]	valid_0's multi_logloss: 2.82338
# [41]	valid_0's multi_logloss: 2.82216
# [42]	valid_0's multi_logloss: 2.82105
# [43]	valid_0's multi_logloss: 2.81999
# [44]	valid_0's multi_logloss: 2.81888
# [45]	valid_0's multi_logloss: 2.81774
# [46]	valid_0's multi_logloss: 2.81665
# [47]	valid_0's multi_logloss: 2.81565
# [48]	valid_0's multi_logloss: 2.81456
# [49]	valid_0's multi_logloss: 2.81358
# [50]	valid_0's multi_logloss: 2.8125
# [51]	valid_0's multi_logloss: 2.81148
# [52]	valid_0's multi_logloss: 2.81051
# [53]	valid_0's multi_logloss: 2.80953
# [54]	valid_0's multi_logloss: 2.80855
# [55]	valid_0's multi_logloss: 2.80769
# [56]	valid_0's multi_logloss: 2.80674
# [57]	valid_0's multi_logloss: 2.80576
# [58]	valid_0's multi_logloss: 2.80486
# [59]	valid_0's multi_logloss: 2.80391
# [60]	valid_0's multi_logloss: 2.80296
# [61]	valid_0's multi_logloss: 2.80196
# [62]	valid_0's multi_logloss: 2.801
# [63]	valid_0's multi_logloss: 2.80018
# [64]	valid_0's multi_logloss: 2.79925
# [65]	valid_0's multi_logloss: 2.79845
# [66]	valid_0's multi_logloss: 2.79762
# [67]	valid_0's multi_logloss: 2.79678
# [68]	valid_0's multi_logloss: 2.79592
# [69]	valid_0's multi_logloss: 2.79508
# [70]	valid_0's multi_logloss: 2.79419
# [71]	valid_0's multi_logloss: 2.79325
# [72]	valid_0's multi_logloss: 2.79242
# [73]	valid_0's multi_logloss: 2.79167
# [74]	valid_0's multi_logloss: 2.79085
# [75]	valid_0's multi_logloss: 2.78996
# [76]	valid_0's multi_logloss: 2.78917
# [77]	valid_0's multi_logloss: 2.78837
# [78]	valid_0's multi_logloss: 2.78757
# [79]	valid_0's multi_logloss: 2.78663
# [80]	valid_0's multi_logloss: 2.78584
# [81]	valid_0's multi_logloss: 2.78511
# [82]	valid_0's multi_logloss: 2.7843
# [83]	valid_0's multi_logloss: 2.78349
# [84]	valid_0's multi_logloss: 2.7827
# [85]	valid_0's multi_logloss: 2.7819
# [86]	valid_0's multi_logloss: 2.78119
# [87]	valid_0's multi_logloss: 2.7804
# [88]	valid_0's multi_logloss: 2.77962
# [89]	valid_0's multi_logloss: 2.77887
# [90]	valid_0's multi_logloss: 2.77814
# [91]	valid_0's multi_logloss: 2.77743
# [92]	valid_0's multi_logloss: 2.77677
# [93]	valid_0's multi_logloss: 2.77609
# [94]	valid_0's multi_logloss: 2.77524
# [95]	valid_0's multi_logloss: 2.77453
# [96]	valid_0's multi_logloss: 2.77379
# [97]	valid_0's multi_logloss: 2.77313
# [98]	valid_0's multi_logloss: 2.77232
# [99]	valid_0's multi_logloss: 2.77168
# [100]	valid_0's multi_logloss: 2.77097
# [101]	valid_0's multi_logloss: 2.77026
# [102]	valid_0's multi_logloss: 2.76964
# [103]	valid_0's multi_logloss: 2.76896
# [104]	valid_0's multi_logloss: 2.7683
# [105]	valid_0's multi_logloss: 2.76775
# [106]	valid_0's multi_logloss: 2.76708
# [107]	valid_0's multi_logloss: 2.76644
# [108]	valid_0's multi_logloss: 2.76578
# [109]	valid_0's multi_logloss: 2.76507
# [110]	valid_0's multi_logloss: 2.76444
# [111]	valid_0's multi_logloss: 2.76385
# [112]	valid_0's multi_logloss: 2.76326
# [113]	valid_0's multi_logloss: 2.7628
# [114]	valid_0's multi_logloss: 2.76221
# [115]	valid_0's multi_logloss: 2.76154
# [116]	valid_0's multi_logloss: 2.76103
# [117]	valid_0's multi_logloss: 2.76038
# [118]	valid_0's multi_logloss: 2.75982
# [119]	valid_0's multi_logloss: 2.75928
# [120]	valid_0's multi_logloss: 2.75865
# [121]	valid_0's multi_logloss: 2.75797
# [122]	valid_0's multi_logloss: 2.75739
# [123]	valid_0's multi_logloss: 2.75685
# [124]	valid_0's multi_logloss: 2.75627
# [125]	valid_0's multi_logloss: 2.75564
# [126]	valid_0's multi_logloss: 2.75513
# [127]	valid_0's multi_logloss: 2.75456
# [128]	valid_0's multi_logloss: 2.75398
# [129]	valid_0's multi_logloss: 2.75335
# [130]	valid_0's multi_logloss: 2.75269
# [131]	valid_0's multi_logloss: 2.75216
# [132]	valid_0's multi_logloss: 2.75157
# [133]	valid_0's multi_logloss: 2.75108
# [134]	valid_0's multi_logloss: 2.75057
# [135]	valid_0's multi_logloss: 2.75007
# [136]	valid_0's multi_logloss: 2.74952
# [137]	valid_0's multi_logloss: 2.74904
# [138]	valid_0's multi_logloss: 2.74854
# [139]	valid_0's multi_logloss: 2.74808
# [140]	valid_0's multi_logloss: 2.74755
# [141]	valid_0's multi_logloss: 2.74708
# [142]	valid_0's multi_logloss: 2.74666
# [143]	valid_0's multi_logloss: 2.7462
# [144]	valid_0's multi_logloss: 2.7457
# [145]	valid_0's multi_logloss: 2.7452
# [146]	valid_0's multi_logloss: 2.74474
# [147]	valid_0's multi_logloss: 2.74429
# [148]	valid_0's multi_logloss: 2.74387
# [149]	valid_0's multi_logloss: 2.74344
# [150]	valid_0's multi_logloss: 2.74297
# [151]	valid_0's multi_logloss: 2.74259
# [152]	valid_0's multi_logloss: 2.74213
# [153]	valid_0's multi_logloss: 2.7417
# [154]	valid_0's multi_logloss: 2.74123
# [155]	valid_0's multi_logloss: 2.74073
# [156]	valid_0's multi_logloss: 2.74037
# [157]	valid_0's multi_logloss: 2.73997
# [158]	valid_0's multi_logloss: 2.73957
# [159]	valid_0's multi_logloss: 2.73914
# [160]	valid_0's multi_logloss: 2.73875
# [161]	valid_0's multi_logloss: 2.73828
# [162]	valid_0's multi_logloss: 2.7379
# [163]	valid_0's multi_logloss: 2.73752
# [164]	valid_0's multi_logloss: 2.73705
# [165]	valid_0's multi_logloss: 2.73663
# [166]	valid_0's multi_logloss: 2.73617
# [167]	valid_0's multi_logloss: 2.73571
# [168]	valid_0's multi_logloss: 2.73537
# [169]	valid_0's multi_logloss: 2.73496
# [170]	valid_0's multi_logloss: 2.73452
# [171]	valid_0's multi_logloss: 2.73418
# [172]	valid_0's multi_logloss: 2.73371
# [173]	valid_0's multi_logloss: 2.7334
# [174]	valid_0's multi_logloss: 2.73303
# [175]	valid_0's multi_logloss: 2.73264
# [176]	valid_0's multi_logloss: 2.73222
# [177]	valid_0's multi_logloss: 2.7319
# [178]	valid_0's multi_logloss: 2.73148
# [179]	valid_0's multi_logloss: 2.73112
# [180]	valid_0's multi_logloss: 2.73074
# [181]	valid_0's multi_logloss: 2.7304
# [182]	valid_0's multi_logloss: 2.73007
# [183]	valid_0's multi_logloss: 2.72961
# [184]	valid_0's multi_logloss: 2.72926
# [185]	valid_0's multi_logloss: 2.72888
# [186]	valid_0's multi_logloss: 2.72849
# [187]	valid_0's multi_logloss: 2.72817
# [188]	valid_0's multi_logloss: 2.72781
# [189]	valid_0's multi_logloss: 2.7275
# [190]	valid_0's multi_logloss: 2.72719
# [191]	valid_0's multi_logloss: 2.72686
# [192]	valid_0's multi_logloss: 2.72649
# [193]	valid_0's multi_logloss: 2.72622
# [194]	valid_0's multi_logloss: 2.72594
# [195]	valid_0's multi_logloss: 2.7256
# [196]	valid_0's multi_logloss: 2.72527
# [197]	valid_0's multi_logloss: 2.72498
# [198]	valid_0's multi_logloss: 2.72464
# [199]	valid_0's multi_logloss: 2.72435
# [200]	valid_0's multi_logloss: 2.72406
# [201]	valid_0's multi_logloss: 2.72374
# [202]	valid_0's multi_logloss: 2.72351
# [203]	valid_0's multi_logloss: 2.72319
# [204]	valid_0's multi_logloss: 2.72288
# [205]	valid_0's multi_logloss: 2.7225
# [206]	valid_0's multi_logloss: 2.72213
# [207]	valid_0's multi_logloss: 2.72185
# [208]	valid_0's multi_logloss: 2.72154
# [209]	valid_0's multi_logloss: 2.72126
# [210]	valid_0's multi_logloss: 2.72101
# [211]	valid_0's multi_logloss: 2.72071
# [212]	valid_0's multi_logloss: 2.72046
# [213]	valid_0's multi_logloss: 2.72009
# [214]	valid_0's multi_logloss: 2.71977
# [215]	valid_0's multi_logloss: 2.71944
# [216]	valid_0's multi_logloss: 2.71915
# [217]	valid_0's multi_logloss: 2.71886
# [218]	valid_0's multi_logloss: 2.71861
# [219]	valid_0's multi_logloss: 2.71833
# [220]	valid_0's multi_logloss: 2.7181
# [221]	valid_0's multi_logloss: 2.71779
# [222]	valid_0's multi_logloss: 2.71755
# [223]	valid_0's multi_logloss: 2.71715
# [224]	valid_0's multi_logloss: 2.71686
# [225]	valid_0's multi_logloss: 2.71661
# [226]	valid_0's multi_logloss: 2.71632
# [227]	valid_0's multi_logloss: 2.7161
# [228]	valid_0's multi_logloss: 2.71584
# [229]	valid_0's multi_logloss: 2.71557
# [230]	valid_0's multi_logloss: 2.71532
# [231]	valid_0's multi_logloss: 2.715
# [232]	valid_0's multi_logloss: 2.71477
# [233]	valid_0's multi_logloss: 2.71449
# [234]	valid_0's multi_logloss: 2.71428
# [235]	valid_0's multi_logloss: 2.7141
# [236]	valid_0's multi_logloss: 2.71381
# [237]	valid_0's multi_logloss: 2.7136
# [238]	valid_0's multi_logloss: 2.71328
# [239]	valid_0's multi_logloss: 2.71307
# [240]	valid_0's multi_logloss: 2.71289
# [241]	valid_0's multi_logloss: 2.71265
# [242]	valid_0's multi_logloss: 2.7124
# [243]	valid_0's multi_logloss: 2.71215
# [244]	valid_0's multi_logloss: 2.71194
# [245]	valid_0's multi_logloss: 2.71174
# [246]	valid_0's multi_logloss: 2.71153
# [247]	valid_0's multi_logloss: 2.71123
# [248]	valid_0's multi_logloss: 2.71104
# [249]	valid_0's multi_logloss: 2.71077
# [250]	valid_0's multi_logloss: 2.7106
# [251]	valid_0's multi_logloss: 2.71035
# [252]	valid_0's multi_logloss: 2.71021
# [253]	valid_0's multi_logloss: 2.71001
# [254]	valid_0's multi_logloss: 2.7098
# [255]	valid_0's multi_logloss: 2.70953
# [256]	valid_0's multi_logloss: 2.70937
# [257]	valid_0's multi_logloss: 2.70916
# [258]	valid_0's multi_logloss: 2.70894
# [259]	valid_0's multi_logloss: 2.70877
# [260]	valid_0's multi_logloss: 2.70849
# [261]	valid_0's multi_logloss: 2.70829
# [262]	valid_0's multi_logloss: 2.70801
# [263]	valid_0's multi_logloss: 2.70785
# [264]	valid_0's multi_logloss: 2.70765
# [265]	valid_0's multi_logloss: 2.70746
# [266]	valid_0's multi_logloss: 2.70727
# [267]	valid_0's multi_logloss: 2.70703
# [268]	valid_0's multi_logloss: 2.70679
# [269]	valid_0's multi_logloss: 2.70655
# [270]	valid_0's multi_logloss: 2.70637
# [271]	valid_0's multi_logloss: 2.70614
# [272]	valid_0's multi_logloss: 2.70594
# [273]	valid_0's multi_logloss: 2.70569
# [274]	valid_0's multi_logloss: 2.70547
# [275]	valid_0's multi_logloss: 2.70526
# [276]	valid_0's multi_logloss: 2.70504
# [277]	valid_0's multi_logloss: 2.70488
# [278]	valid_0's multi_logloss: 2.70472
# [279]	valid_0's multi_logloss: 2.70452
# [280]	valid_0's multi_logloss: 2.70427
# [281]	valid_0's multi_logloss: 2.70414
# [282]	valid_0's multi_logloss: 2.70394
# [283]	valid_0's multi_logloss: 2.70381
# [284]	valid_0's multi_logloss: 2.70359
# [285]	valid_0's multi_logloss: 2.70336
# [286]	valid_0's multi_logloss: 2.70321
# [287]	valid_0's multi_logloss: 2.70298
# [288]	valid_0's multi_logloss: 2.70281
# [289]	valid_0's multi_logloss: 2.70265
# [290]	valid_0's multi_logloss: 2.70248
# [291]	valid_0's multi_logloss: 2.70237
# [292]	valid_0's multi_logloss: 2.70216
# [293]	valid_0's multi_logloss: 2.70201
# [294]	valid_0's multi_logloss: 2.70185
# [295]	valid_0's multi_logloss: 2.70173
# [296]	valid_0's multi_logloss: 2.70157
# [297]	valid_0's multi_logloss: 2.7014
# [298]	valid_0's multi_logloss: 2.70127
# [299]	valid_0's multi_logloss: 2.70114
# [300]	valid_0's multi_logloss: 2.701
# [301]	valid_0's multi_logloss: 2.70079
# [302]	valid_0's multi_logloss: 2.70068
# [303]	valid_0's multi_logloss: 2.70055
# [304]	valid_0's multi_logloss: 2.70041
# [305]	valid_0's multi_logloss: 2.70026
# [306]	valid_0's multi_logloss: 2.70015
# [307]	valid_0's multi_logloss: 2.70002
# [308]	valid_0's multi_logloss: 2.69978
# [309]	valid_0's multi_logloss: 2.69964
# [310]	valid_0's multi_logloss: 2.69949
# [311]	valid_0's multi_logloss: 2.69931
# [312]	valid_0's multi_logloss: 2.69915
# [313]	valid_0's multi_logloss: 2.69901
# [314]	valid_0's multi_logloss: 2.6989
# [315]	valid_0's multi_logloss: 2.6988
# [316]	valid_0's multi_logloss: 2.6986
# [317]	valid_0's multi_logloss: 2.69847
# [318]	valid_0's multi_logloss: 2.69832
# [319]	valid_0's multi_logloss: 2.69819
# [320]	valid_0's multi_logloss: 2.69802
# [321]	valid_0's multi_logloss: 2.69788
# [322]	valid_0's multi_logloss: 2.69777
# [323]	valid_0's multi_logloss: 2.69765
# [324]	valid_0's multi_logloss: 2.6976
# [325]	valid_0's multi_logloss: 2.69752
# [326]	valid_0's multi_logloss: 2.69738
# [327]	valid_0's multi_logloss: 2.69723
# [328]	valid_0's multi_logloss: 2.69714
# [329]	valid_0's multi_logloss: 2.69707
# [330]	valid_0's multi_logloss: 2.69696
# [331]	valid_0's multi_logloss: 2.69685
# [332]	valid_0's multi_logloss: 2.69678
# [333]	valid_0's multi_logloss: 2.69669
# [334]	valid_0's multi_logloss: 2.69659
# [335]	valid_0's multi_logloss: 2.69649
# [336]	valid_0's multi_logloss: 2.69643
# [337]	valid_0's multi_logloss: 2.69633
# [338]	valid_0's multi_logloss: 2.69622
# [339]	valid_0's multi_logloss: 2.69618
# [340]	valid_0's multi_logloss: 2.69611
# [341]	valid_0's multi_logloss: 2.69606
# [342]	valid_0's multi_logloss: 2.69592
# [343]	valid_0's multi_logloss: 2.69588
# [344]	valid_0's multi_logloss: 2.69584
# [345]	valid_0's multi_logloss: 2.69571
# [346]	valid_0's multi_logloss: 2.6956
# [347]	valid_0's multi_logloss: 2.69549
# [348]	valid_0's multi_logloss: 2.69545
# [349]	valid_0's multi_logloss: 2.69539
# [350]	valid_0's multi_logloss: 2.69527
# [351]	valid_0's multi_logloss: 2.69514
# [352]	valid_0's multi_logloss: 2.69506
# [353]	valid_0's multi_logloss: 2.69495
# [354]	valid_0's multi_logloss: 2.69491
# [355]	valid_0's multi_logloss: 2.69488
# [356]	valid_0's multi_logloss: 2.69481
# [357]	valid_0's multi_logloss: 2.69472
# [358]	valid_0's multi_logloss: 2.69464
# [359]	valid_0's multi_logloss: 2.69462
# [360]	valid_0's multi_logloss: 2.6945
# [361]	valid_0's multi_logloss: 2.69447
# [362]	valid_0's multi_logloss: 2.69436
# [363]	valid_0's multi_logloss: 2.69424
# [364]	valid_0's multi_logloss: 2.69419
# [365]	valid_0's multi_logloss: 2.69412
# [366]	valid_0's multi_logloss: 2.69409
# [367]	valid_0's multi_logloss: 2.69406
# [368]	valid_0's multi_logloss: 2.69393
# [369]	valid_0's multi_logloss: 2.6939
# [370]	valid_0's multi_logloss: 2.69384
# [371]	valid_0's multi_logloss: 2.6938
# [372]	valid_0's multi_logloss: 2.69373
# [373]	valid_0's multi_logloss: 2.69369
# [374]	valid_0's multi_logloss: 2.69364
# [375]	valid_0's multi_logloss: 2.69355
# [376]	valid_0's multi_logloss: 2.6935
# [377]	valid_0's multi_logloss: 2.69344
# [378]	valid_0's multi_logloss: 2.69337
# [379]	valid_0's multi_logloss: 2.69333
# [380]	valid_0's multi_logloss: 2.69327
# [381]	valid_0's multi_logloss: 2.69317
# [382]	valid_0's multi_logloss: 2.69313
# [383]	valid_0's multi_logloss: 2.69304
# [384]	valid_0's multi_logloss: 2.69295
# [385]	valid_0's multi_logloss: 2.69288
# [386]	valid_0's multi_logloss: 2.69279
# [387]	valid_0's multi_logloss: 2.69272
# [388]	valid_0's multi_logloss: 2.69262
# [389]	valid_0's multi_logloss: 2.69264
# [390]	valid_0's multi_logloss: 2.69261
# [391]	valid_0's multi_logloss: 2.69253
# [392]	valid_0's multi_logloss: 2.69247
# [393]	valid_0's multi_logloss: 2.69241
# [394]	valid_0's multi_logloss: 2.69241
# [395]	valid_0's multi_logloss: 2.69239
# [396]	valid_0's multi_logloss: 2.69233
# [397]	valid_0's multi_logloss: 2.69229
# [398]	valid_0's multi_logloss: 2.69221
# [399]	valid_0's multi_logloss: 2.69218
# [400]	valid_0's multi_logloss: 2.69211
# [401]	valid_0's multi_logloss: 2.69203
# [402]	valid_0's multi_logloss: 2.69197
# [403]	valid_0's multi_logloss: 2.69195
# [404]	valid_0's multi_logloss: 2.6919
# [405]	valid_0's multi_logloss: 2.69187
# [406]	valid_0's multi_logloss: 2.69182
# [407]	valid_0's multi_logloss: 2.69175
# [408]	valid_0's multi_logloss: 2.69173
# [409]	valid_0's multi_logloss: 2.69167
# [410]	valid_0's multi_logloss: 2.69165
# [411]	valid_0's multi_logloss: 2.69163
# [412]	valid_0's multi_logloss: 2.69154
# [413]	valid_0's multi_logloss: 2.69149
# [414]	valid_0's multi_logloss: 2.69145
# [415]	valid_0's multi_logloss: 2.69139
# [416]	valid_0's multi_logloss: 2.6913
# [417]	valid_0's multi_logloss: 2.69129
# [418]	valid_0's multi_logloss: 2.6912
# [419]	valid_0's multi_logloss: 2.69119
# [420]	valid_0's multi_logloss: 2.69115
# [421]	valid_0's multi_logloss: 2.69114
# [422]	valid_0's multi_logloss: 2.6911
# [423]	valid_0's multi_logloss: 2.69107
# [424]	valid_0's multi_logloss: 2.69101
# [425]	valid_0's multi_logloss: 2.69098
# [426]	valid_0's multi_logloss: 2.69095
# [427]	valid_0's multi_logloss: 2.69092
# [428]	valid_0's multi_logloss: 2.69091
# [429]	valid_0's multi_logloss: 2.6909
# [430]	valid_0's multi_logloss: 2.69087
# [431]	valid_0's multi_logloss: 2.69083
# [432]	valid_0's multi_logloss: 2.69082
# [433]	valid_0's multi_logloss: 2.69077
# [434]	valid_0's multi_logloss: 2.69073
# [435]	valid_0's multi_logloss: 2.69073
# [436]	valid_0's multi_logloss: 2.69068
# [437]	valid_0's multi_logloss: 2.69063
# [438]	valid_0's multi_logloss: 2.69055
# [439]	valid_0's multi_logloss: 2.69056
# [440]	valid_0's multi_logloss: 2.69055
# [441]	valid_0's multi_logloss: 2.69051
# [442]	valid_0's multi_logloss: 2.69049
# [443]	valid_0's multi_logloss: 2.69041
# [444]	valid_0's multi_logloss: 2.69035
# [445]	valid_0's multi_logloss: 2.69029
# [446]	valid_0's multi_logloss: 2.6903
# [447]	valid_0's multi_logloss: 2.69031
# [448]	valid_0's multi_logloss: 2.69031
# [449]	valid_0's multi_logloss: 2.69024
# [450]	valid_0's multi_logloss: 2.6902
# [451]	valid_0's multi_logloss: 2.69018
# [452]	valid_0's multi_logloss: 2.69012
# [453]	valid_0's multi_logloss: 2.69008
# [454]	valid_0's multi_logloss: 2.69012
# [455]	valid_0's multi_logloss: 2.69009
# [456]	valid_0's multi_logloss: 2.69007
# [457]	valid_0's multi_logloss: 2.69005
# [458]	valid_0's multi_logloss: 2.69004
# [459]	valid_0's multi_logloss: 2.68998
# [460]	valid_0's multi_logloss: 2.68996
# [461]	valid_0's multi_logloss: 2.68992
# [462]	valid_0's multi_logloss: 2.68987
# [463]	valid_0's multi_logloss: 2.68988
# [464]	valid_0's multi_logloss: 2.68987
# [465]	valid_0's multi_logloss: 2.68988
# [466]	valid_0's multi_logloss: 2.6899
# [467]	valid_0's multi_logloss: 2.68996
# [468]	valid_0's multi_logloss: 2.6899
# [469]	valid_0's multi_logloss: 2.6899
# [470]	valid_0's multi_logloss: 2.68987
# [471]	valid_0's multi_logloss: 2.6899
# [472]	valid_0's multi_logloss: 2.68988
# [473]	valid_0's multi_logloss: 2.68988
# [474]	valid_0's multi_logloss: 2.6899
# [475]	valid_0's multi_logloss: 2.6899
# [476]	valid_0's multi_logloss: 2.68988
# [477]	valid_0's multi_logloss: 2.68986
# [478]	valid_0's multi_logloss: 2.68987
# [479]	valid_0's multi_logloss: 2.68988
# [480]	valid_0's multi_logloss: 2.68979
# [481]	valid_0's multi_logloss: 2.68979
# [482]	valid_0's multi_logloss: 2.6898
# [483]	valid_0's multi_logloss: 2.68977
# [484]	valid_0's multi_logloss: 2.68977
# [485]	valid_0's multi_logloss: 2.68977
# [486]	valid_0's multi_logloss: 2.68969
# [487]	valid_0's multi_logloss: 2.68971
# [488]	valid_0's multi_logloss: 2.68968
# [489]	valid_0's multi_logloss: 2.68967
# [490]	valid_0's multi_logloss: 2.6897
# [491]	valid_0's multi_logloss: 2.68974
# [492]	valid_0's multi_logloss: 2.68976
# [493]	valid_0's multi_logloss: 2.68979
# [494]	valid_0's multi_logloss: 2.68979
# [495]	valid_0's multi_logloss: 2.68978
# [496]	valid_0's multi_logloss: 2.68983
# [497]	valid_0's multi_logloss: 2.68982
# [498]	valid_0's multi_logloss: 2.68986
# [499]	valid_0's multi_logloss: 2.68989
# Early stopping, best iteration is:
# [489]	valid_0's multi_logloss: 2.68967
# 0.01228833604650279
# [1]	valid_0's multi_logloss: 2.85878
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85682
# [3]	valid_0's multi_logloss: 2.85485
# [4]	valid_0's multi_logloss: 2.85306
# [5]	valid_0's multi_logloss: 2.85117
# [6]	valid_0's multi_logloss: 2.84946
# [7]	valid_0's multi_logloss: 2.84767
# [8]	valid_0's multi_logloss: 2.8459
# [9]	valid_0's multi_logloss: 2.84425
# [10]	valid_0's multi_logloss: 2.84258
# [11]	valid_0's multi_logloss: 2.841
# [12]	valid_0's multi_logloss: 2.83945
# [13]	valid_0's multi_logloss: 2.83781
# [14]	valid_0's multi_logloss: 2.83636
# [15]	valid_0's multi_logloss: 2.83489
# [16]	valid_0's multi_logloss: 2.83342
# [17]	valid_0's multi_logloss: 2.83198
# [18]	valid_0's multi_logloss: 2.83062
# [19]	valid_0's multi_logloss: 2.82931
# [20]	valid_0's multi_logloss: 2.82809
# [21]	valid_0's multi_logloss: 2.82663
# [22]	valid_0's multi_logloss: 2.82549
# [23]	valid_0's multi_logloss: 2.82422
# [24]	valid_0's multi_logloss: 2.82307
# [25]	valid_0's multi_logloss: 2.82196
# [26]	valid_0's multi_logloss: 2.82085
# [27]	valid_0's multi_logloss: 2.8196
# [28]	valid_0's multi_logloss: 2.81845
# [29]	valid_0's multi_logloss: 2.81727
# [30]	valid_0's multi_logloss: 2.81621
# [31]	valid_0's multi_logloss: 2.81523
# [32]	valid_0's multi_logloss: 2.81424
# [33]	valid_0's multi_logloss: 2.81318
# [34]	valid_0's multi_logloss: 2.81218
# [35]	valid_0's multi_logloss: 2.81114
# [36]	valid_0's multi_logloss: 2.81008
# [37]	valid_0's multi_logloss: 2.80912
# [38]	valid_0's multi_logloss: 2.80818
# [39]	valid_0's multi_logloss: 2.80725
# [40]	valid_0's multi_logloss: 2.80629
# [41]	valid_0's multi_logloss: 2.80536
# [42]	valid_0's multi_logloss: 2.80444
# [43]	valid_0's multi_logloss: 2.80354
# [44]	valid_0's multi_logloss: 2.80268
# [45]	valid_0's multi_logloss: 2.80182
# [46]	valid_0's multi_logloss: 2.80087
# [47]	valid_0's multi_logloss: 2.80002
# [48]	valid_0's multi_logloss: 2.79914
# [49]	valid_0's multi_logloss: 2.79832
# [50]	valid_0's multi_logloss: 2.79753
# [51]	valid_0's multi_logloss: 2.79677
# [52]	valid_0's multi_logloss: 2.79595
# [53]	valid_0's multi_logloss: 2.79521
# [54]	valid_0's multi_logloss: 2.7944
# [55]	valid_0's multi_logloss: 2.79352
# [56]	valid_0's multi_logloss: 2.79273
# [57]	valid_0's multi_logloss: 2.79195
# [58]	valid_0's multi_logloss: 2.79115
# [59]	valid_0's multi_logloss: 2.79026
# [60]	valid_0's multi_logloss: 2.78948
# [61]	valid_0's multi_logloss: 2.7887
# [62]	valid_0's multi_logloss: 2.78782
# [63]	valid_0's multi_logloss: 2.78712
# [64]	valid_0's multi_logloss: 2.78633
# [65]	valid_0's multi_logloss: 2.78552
# [66]	valid_0's multi_logloss: 2.78476
# [67]	valid_0's multi_logloss: 2.78397
# [68]	valid_0's multi_logloss: 2.78323
# [69]	valid_0's multi_logloss: 2.78249
# [70]	valid_0's multi_logloss: 2.78169
# [71]	valid_0's multi_logloss: 2.78096
# [72]	valid_0's multi_logloss: 2.78016
# [73]	valid_0's multi_logloss: 2.7795
# [74]	valid_0's multi_logloss: 2.77878
# [75]	valid_0's multi_logloss: 2.77808
# [76]	valid_0's multi_logloss: 2.77741
# [77]	valid_0's multi_logloss: 2.77668
# [78]	valid_0's multi_logloss: 2.77593
# [79]	valid_0's multi_logloss: 2.77533
# [80]	valid_0's multi_logloss: 2.77465
# [81]	valid_0's multi_logloss: 2.77401
# [82]	valid_0's multi_logloss: 2.77333
# [83]	valid_0's multi_logloss: 2.77281
# [84]	valid_0's multi_logloss: 2.77212
# [85]	valid_0's multi_logloss: 2.77156
# [86]	valid_0's multi_logloss: 2.77093
# [87]	valid_0's multi_logloss: 2.77037
# [88]	valid_0's multi_logloss: 2.76977
# [89]	valid_0's multi_logloss: 2.76916
# [90]	valid_0's multi_logloss: 2.76863
# [91]	valid_0's multi_logloss: 2.76801
# [92]	valid_0's multi_logloss: 2.76735
# [93]	valid_0's multi_logloss: 2.7668
# [94]	valid_0's multi_logloss: 2.76617
# [95]	valid_0's multi_logloss: 2.76556
# [96]	valid_0's multi_logloss: 2.76497
# [97]	valid_0's multi_logloss: 2.76454
# [98]	valid_0's multi_logloss: 2.76396
# [99]	valid_0's multi_logloss: 2.76343
# [100]	valid_0's multi_logloss: 2.76294
# [101]	valid_0's multi_logloss: 2.76234
# [102]	valid_0's multi_logloss: 2.7617
# [103]	valid_0's multi_logloss: 2.7611
# [104]	valid_0's multi_logloss: 2.76054
# [105]	valid_0's multi_logloss: 2.76003
# [106]	valid_0's multi_logloss: 2.75942
# [107]	valid_0's multi_logloss: 2.75885
# [108]	valid_0's multi_logloss: 2.75829
# [109]	valid_0's multi_logloss: 2.75775
# [110]	valid_0's multi_logloss: 2.75722
# [111]	valid_0's multi_logloss: 2.75658
# [112]	valid_0's multi_logloss: 2.75611
# [113]	valid_0's multi_logloss: 2.75558
# [114]	valid_0's multi_logloss: 2.75499
# [115]	valid_0's multi_logloss: 2.7544
# [116]	valid_0's multi_logloss: 2.7538
# [117]	valid_0's multi_logloss: 2.75324
# [118]	valid_0's multi_logloss: 2.75275
# [119]	valid_0's multi_logloss: 2.75226
# [120]	valid_0's multi_logloss: 2.75173
# [121]	valid_0's multi_logloss: 2.75127
# [122]	valid_0's multi_logloss: 2.75074
# [123]	valid_0's multi_logloss: 2.75026
# [124]	valid_0's multi_logloss: 2.74975
# [125]	valid_0's multi_logloss: 2.74923
# [126]	valid_0's multi_logloss: 2.74873
# [127]	valid_0's multi_logloss: 2.74823
# [128]	valid_0's multi_logloss: 2.74779
# [129]	valid_0's multi_logloss: 2.74726
# [130]	valid_0's multi_logloss: 2.74681
# [131]	valid_0's multi_logloss: 2.74642
# [132]	valid_0's multi_logloss: 2.74585
# [133]	valid_0's multi_logloss: 2.74541
# [134]	valid_0's multi_logloss: 2.74501
# [135]	valid_0's multi_logloss: 2.7446
# [136]	valid_0's multi_logloss: 2.74417
# [137]	valid_0's multi_logloss: 2.74377
# [138]	valid_0's multi_logloss: 2.74335
# [139]	valid_0's multi_logloss: 2.74296
# [140]	valid_0's multi_logloss: 2.74255
# [141]	valid_0's multi_logloss: 2.74214
# [142]	valid_0's multi_logloss: 2.74173
# [143]	valid_0's multi_logloss: 2.74137
# [144]	valid_0's multi_logloss: 2.74096
# [145]	valid_0's multi_logloss: 2.74049
# [146]	valid_0's multi_logloss: 2.74007
# [147]	valid_0's multi_logloss: 2.73975
# [148]	valid_0's multi_logloss: 2.73937
# [149]	valid_0's multi_logloss: 2.73894
# [150]	valid_0's multi_logloss: 2.73858
# [151]	valid_0's multi_logloss: 2.73817
# [152]	valid_0's multi_logloss: 2.73781
# [153]	valid_0's multi_logloss: 2.73747
# [154]	valid_0's multi_logloss: 2.7371
# [155]	valid_0's multi_logloss: 2.73671
# [156]	valid_0's multi_logloss: 2.7363
# [157]	valid_0's multi_logloss: 2.73595
# [158]	valid_0's multi_logloss: 2.73562
# [159]	valid_0's multi_logloss: 2.7353
# [160]	valid_0's multi_logloss: 2.73495
# [161]	valid_0's multi_logloss: 2.7346
# [162]	valid_0's multi_logloss: 2.73422
# [163]	valid_0's multi_logloss: 2.73387
# [164]	valid_0's multi_logloss: 2.73349
# [165]	valid_0's multi_logloss: 2.73311
# [166]	valid_0's multi_logloss: 2.73277
# [167]	valid_0's multi_logloss: 2.73246
# [168]	valid_0's multi_logloss: 2.73212
# [169]	valid_0's multi_logloss: 2.73183
# [170]	valid_0's multi_logloss: 2.73151
# [171]	valid_0's multi_logloss: 2.73125
# [172]	valid_0's multi_logloss: 2.73098
# [173]	valid_0's multi_logloss: 2.73067
# [174]	valid_0's multi_logloss: 2.73035
# [175]	valid_0's multi_logloss: 2.73008
# [176]	valid_0's multi_logloss: 2.72976
# [177]	valid_0's multi_logloss: 2.72947
# [178]	valid_0's multi_logloss: 2.7292
# [179]	valid_0's multi_logloss: 2.72891
# [180]	valid_0's multi_logloss: 2.72862
# [181]	valid_0's multi_logloss: 2.72838
# [182]	valid_0's multi_logloss: 2.72807
# [183]	valid_0's multi_logloss: 2.72779
# [184]	valid_0's multi_logloss: 2.72741
# [185]	valid_0's multi_logloss: 2.72714
# [186]	valid_0's multi_logloss: 2.72684
# [187]	valid_0's multi_logloss: 2.72656
# [188]	valid_0's multi_logloss: 2.72628
# [189]	valid_0's multi_logloss: 2.72598
# [190]	valid_0's multi_logloss: 2.72573
# [191]	valid_0's multi_logloss: 2.72542
# [192]	valid_0's multi_logloss: 2.72513
# [193]	valid_0's multi_logloss: 2.72483
# [194]	valid_0's multi_logloss: 2.72456
# [195]	valid_0's multi_logloss: 2.72428
# [196]	valid_0's multi_logloss: 2.72401
# [197]	valid_0's multi_logloss: 2.72371
# [198]	valid_0's multi_logloss: 2.72346
# [199]	valid_0's multi_logloss: 2.72322
# [200]	valid_0's multi_logloss: 2.72294
# [201]	valid_0's multi_logloss: 2.72274
# [202]	valid_0's multi_logloss: 2.72249
# [203]	valid_0's multi_logloss: 2.72226
# [204]	valid_0's multi_logloss: 2.72207
# [205]	valid_0's multi_logloss: 2.72182
# [206]	valid_0's multi_logloss: 2.72153
# [207]	valid_0's multi_logloss: 2.72129
# [208]	valid_0's multi_logloss: 2.72109
# [209]	valid_0's multi_logloss: 2.72087
# [210]	valid_0's multi_logloss: 2.72065
# [211]	valid_0's multi_logloss: 2.72041
# [212]	valid_0's multi_logloss: 2.72016
# [213]	valid_0's multi_logloss: 2.72
# [214]	valid_0's multi_logloss: 2.71978
# [215]	valid_0's multi_logloss: 2.71961
# [216]	valid_0's multi_logloss: 2.71938
# [217]	valid_0's multi_logloss: 2.71918
# [218]	valid_0's multi_logloss: 2.71894
# [219]	valid_0's multi_logloss: 2.71877
# [220]	valid_0's multi_logloss: 2.71855
# [221]	valid_0's multi_logloss: 2.71837
# [222]	valid_0's multi_logloss: 2.71816
# [223]	valid_0's multi_logloss: 2.71796
# [224]	valid_0's multi_logloss: 2.71773
# [225]	valid_0's multi_logloss: 2.71754
# [226]	valid_0's multi_logloss: 2.71731
# [227]	valid_0's multi_logloss: 2.71715
# [228]	valid_0's multi_logloss: 2.71693
# [229]	valid_0's multi_logloss: 2.71676
# [230]	valid_0's multi_logloss: 2.71655
# [231]	valid_0's multi_logloss: 2.71636
# [232]	valid_0's multi_logloss: 2.71622
# [233]	valid_0's multi_logloss: 2.71598
# [234]	valid_0's multi_logloss: 2.71584
# [235]	valid_0's multi_logloss: 2.71563
# [236]	valid_0's multi_logloss: 2.71545
# [237]	valid_0's multi_logloss: 2.71527
# [238]	valid_0's multi_logloss: 2.7151
# [239]	valid_0's multi_logloss: 2.7149
# [240]	valid_0's multi_logloss: 2.71475
# [241]	valid_0's multi_logloss: 2.71464
# [242]	valid_0's multi_logloss: 2.71445
# [243]	valid_0's multi_logloss: 2.71424
# [244]	valid_0's multi_logloss: 2.71412
# [245]	valid_0's multi_logloss: 2.71393
# [246]	valid_0's multi_logloss: 2.71374
# [247]	valid_0's multi_logloss: 2.71355
# [248]	valid_0's multi_logloss: 2.71339
# [249]	valid_0's multi_logloss: 2.71323
# [250]	valid_0's multi_logloss: 2.71311
# [251]	valid_0's multi_logloss: 2.71294
# [252]	valid_0's multi_logloss: 2.71279
# [253]	valid_0's multi_logloss: 2.71263
# [254]	valid_0's multi_logloss: 2.71252
# [255]	valid_0's multi_logloss: 2.71235
# [256]	valid_0's multi_logloss: 2.71224
# [257]	valid_0's multi_logloss: 2.71208
# [258]	valid_0's multi_logloss: 2.7119
# [259]	valid_0's multi_logloss: 2.71174
# [260]	valid_0's multi_logloss: 2.71159
# [261]	valid_0's multi_logloss: 2.71143
# [262]	valid_0's multi_logloss: 2.71123
# [263]	valid_0's multi_logloss: 2.71106
# [264]	valid_0's multi_logloss: 2.71084
# [265]	valid_0's multi_logloss: 2.7107
# [266]	valid_0's multi_logloss: 2.71062
# [267]	valid_0's multi_logloss: 2.71051
# [268]	valid_0's multi_logloss: 2.71035
# [269]	valid_0's multi_logloss: 2.71019
# [270]	valid_0's multi_logloss: 2.71006
# [271]	valid_0's multi_logloss: 2.70994
# [272]	valid_0's multi_logloss: 2.70977
# [273]	valid_0's multi_logloss: 2.70965
# [274]	valid_0's multi_logloss: 2.70949
# [275]	valid_0's multi_logloss: 2.70936
# [276]	valid_0's multi_logloss: 2.70923
# [277]	valid_0's multi_logloss: 2.70914
# [278]	valid_0's multi_logloss: 2.70894
# [279]	valid_0's multi_logloss: 2.70885
# [280]	valid_0's multi_logloss: 2.7087
# [281]	valid_0's multi_logloss: 2.70858
# [282]	valid_0's multi_logloss: 2.70846
# [283]	valid_0's multi_logloss: 2.70836
# [284]	valid_0's multi_logloss: 2.7082
# [285]	valid_0's multi_logloss: 2.70803
# [286]	valid_0's multi_logloss: 2.7079
# [287]	valid_0's multi_logloss: 2.70781
# [288]	valid_0's multi_logloss: 2.70764
# [289]	valid_0's multi_logloss: 2.70746
# [290]	valid_0's multi_logloss: 2.70734
# [291]	valid_0's multi_logloss: 2.70724
# ...
# [226]	valid_0's multi_logloss: 2.91045
# [227]	valid_0's multi_logloss: 2.91029
# [228]	valid_0's multi_logloss: 2.91021
# [229]	valid_0's multi_logloss: 2.91004
# [230]	valid_0's multi_logloss: 2.90995
# [231]	valid_0's multi_logloss: 2.9099
# [232]	valid_0's multi_logloss: 2.90978
# [233]	valid_0's multi_logloss: 2.90966
# [234]	valid_0's multi_logloss: 2.90956
# [235]	valid_0's multi_logloss: 2.9095
# [236]	valid_0's multi_logloss: 2.90942
# [237]	valid_0's multi_logloss: 2.90934
# [238]	valid_0's multi_logloss: 2.90927
# [239]	valid_0's multi_logloss: 2.90915
# [240]	valid_0's multi_logloss: 2.90909
# [241]	valid_0's multi_logloss: 2.90901
# [242]	valid_0's multi_logloss: 2.90896
# [243]	valid_0's multi_logloss: 2.90886
# [244]	valid_0's multi_logloss: 2.90877
# [245]	valid_0's multi_logloss: 2.90874
# [246]	valid_0's multi_logloss: 2.90867
# [247]	valid_0's multi_logloss: 2.90853
# [248]	valid_0's multi_logloss: 2.90849
# [249]	valid_0's multi_logloss: 2.90845
# [250]	valid_0's multi_logloss: 2.90838
# [251]	valid_0's multi_logloss: 2.90834
# [252]	valid_0's multi_logloss: 2.90833
# [253]	valid_0's multi_logloss: 2.90829
# [254]	valid_0's multi_logloss: 2.90819
# [255]	valid_0's multi_logloss: 2.90812
# [256]	valid_0's multi_logloss: 2.90805
# [257]	valid_0's multi_logloss: 2.90795
# [258]	valid_0's multi_logloss: 2.90795
# [259]	valid_0's multi_logloss: 2.90795
# [260]	valid_0's multi_logloss: 2.90792
# [261]	valid_0's multi_logloss: 2.90785
# [262]	valid_0's multi_logloss: 2.9078
# [263]	valid_0's multi_logloss: 2.90777
# [264]	valid_0's multi_logloss: 2.9077
# [265]	valid_0's multi_logloss: 2.90768
# [266]	valid_0's multi_logloss: 2.90761
# [267]	valid_0's multi_logloss: 2.90755
# [268]	valid_0's multi_logloss: 2.90753
# [269]	valid_0's multi_logloss: 2.90748
# [270]	valid_0's multi_logloss: 2.9074
# [271]	valid_0's multi_logloss: 2.90733
# [272]	valid_0's multi_logloss: 2.90725
# [273]	valid_0's multi_logloss: 2.90724
# [274]	valid_0's multi_logloss: 2.90719
# [275]	valid_0's multi_logloss: 2.90716
# [276]	valid_0's multi_logloss: 2.90714
# [277]	valid_0's multi_logloss: 2.90708
# [278]	valid_0's multi_logloss: 2.90703
# [279]	valid_0's multi_logloss: 2.907
# [280]	valid_0's multi_logloss: 2.90698
# [281]	valid_0's multi_logloss: 2.90692
# [282]	valid_0's multi_logloss: 2.90686
# [283]	valid_0's multi_logloss: 2.90685
# [284]	valid_0's multi_logloss: 2.90683
# [285]	valid_0's multi_logloss: 2.90677
# [286]	valid_0's multi_logloss: 2.90678
# [287]	valid_0's multi_logloss: 2.90676
# [288]	valid_0's multi_logloss: 2.90672
# [289]	valid_0's multi_logloss: 2.90668
# [290]	valid_0's multi_logloss: 2.90666
# [291]	valid_0's multi_logloss: 2.90663
# [292]	valid_0's multi_logloss: 2.90654
# [293]	valid_0's multi_logloss: 2.90651
# [294]	valid_0's multi_logloss: 2.90651
# [295]	valid_0's multi_logloss: 2.90648
# [296]	valid_0's multi_logloss: 2.90644
# [297]	valid_0's multi_logloss: 2.90634
# [298]	valid_0's multi_logloss: 2.90632
# [299]	valid_0's multi_logloss: 2.90629
# [300]	valid_0's multi_logloss: 2.90626
# [301]	valid_0's multi_logloss: 2.90625
# [302]	valid_0's multi_logloss: 2.90622
# [303]	valid_0's multi_logloss: 2.9062
# [304]	valid_0's multi_logloss: 2.90618
# [305]	valid_0's multi_logloss: 2.90614
# [306]	valid_0's multi_logloss: 2.90612
# [307]	valid_0's multi_logloss: 2.90604
# [308]	valid_0's multi_logloss: 2.90604
# [309]	valid_0's multi_logloss: 2.906
# [310]	valid_0's multi_logloss: 2.90597
# [311]	valid_0's multi_logloss: 2.90598
# [312]	valid_0's multi_logloss: 2.90593
# [313]	valid_0's multi_logloss: 2.90593
# [314]	valid_0's multi_logloss: 2.90593
# [315]	valid_0's multi_logloss: 2.90591
# [316]	valid_0's multi_logloss: 2.90589
# [317]	valid_0's multi_logloss: 2.90587
# [318]	valid_0's multi_logloss: 2.90589
# [319]	valid_0's multi_logloss: 2.90592
# [320]	valid_0's multi_logloss: 2.9059
# [321]	valid_0's multi_logloss: 2.90584
# [322]	valid_0's multi_logloss: 2.90586
# [323]	valid_0's multi_logloss: 2.90582
# [324]	valid_0's multi_logloss: 2.90584
# [325]	valid_0's multi_logloss: 2.90583
# [326]	valid_0's multi_logloss: 2.90589
# [327]	valid_0's multi_logloss: 2.90589
# [328]	valid_0's multi_logloss: 2.90583
# [329]	valid_0's multi_logloss: 2.90577
# [330]	valid_0's multi_logloss: 2.90576
# [331]	valid_0's multi_logloss: 2.90579
# [332]	valid_0's multi_logloss: 2.90579
# [333]	valid_0's multi_logloss: 2.9058
# [334]	valid_0's multi_logloss: 2.9058
# [335]	valid_0's multi_logloss: 2.90585
# [336]	valid_0's multi_logloss: 2.90582
# [337]	valid_0's multi_logloss: 2.90582
# [338]	valid_0's multi_logloss: 2.90583
# [339]	valid_0's multi_logloss: 2.90581
# [340]	valid_0's multi_logloss: 2.9058
# Early stopping, best iteration is:
# [330]	valid_0's multi_logloss: 2.90576
# 0.014299112499296895
# [1]	valid_0's multi_logloss: 2.92634
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92529
# [3]	valid_0's multi_logloss: 2.92422
# [4]	valid_0's multi_logloss: 2.92313
# [5]	valid_0's multi_logloss: 2.92209
# [6]	valid_0's multi_logloss: 2.92127
# [7]	valid_0's multi_logloss: 2.92043
# [8]	valid_0's multi_logloss: 2.91977
# [9]	valid_0's multi_logloss: 2.91905
# [10]	valid_0's multi_logloss: 2.91816
# [11]	valid_0's multi_logloss: 2.91753
# [12]	valid_0's multi_logloss: 2.9168
# [13]	valid_0's multi_logloss: 2.91619
# [14]	valid_0's multi_logloss: 2.91544
# [15]	valid_0's multi_logloss: 2.91482
# [16]	valid_0's multi_logloss: 2.91411
# [17]	valid_0's multi_logloss: 2.9134
# [18]	valid_0's multi_logloss: 2.91281
# [19]	valid_0's multi_logloss: 2.91217
# [20]	valid_0's multi_logloss: 2.91148
# [21]	valid_0's multi_logloss: 2.91082
# [22]	valid_0's multi_logloss: 2.9103
# [23]	valid_0's multi_logloss: 2.90966
# [24]	valid_0's multi_logloss: 2.90912
# [25]	valid_0's multi_logloss: 2.90853
# [26]	valid_0's multi_logloss: 2.908
# [27]	valid_0's multi_logloss: 2.90741
# [28]	valid_0's multi_logloss: 2.90692
# [29]	valid_0's multi_logloss: 2.90644
# [30]	valid_0's multi_logloss: 2.90588
# [31]	valid_0's multi_logloss: 2.90536
# [32]	valid_0's multi_logloss: 2.90483
# [33]	valid_0's multi_logloss: 2.90433
# [34]	valid_0's multi_logloss: 2.90383
# [35]	valid_0's multi_logloss: 2.9033
# [36]	valid_0's multi_logloss: 2.90279
# [37]	valid_0's multi_logloss: 2.90225
# [38]	valid_0's multi_logloss: 2.90177
# [39]	valid_0's multi_logloss: 2.9013
# [40]	valid_0's multi_logloss: 2.90081
# [41]	valid_0's multi_logloss: 2.90028
# [42]	valid_0's multi_logloss: 2.89978
# [43]	valid_0's multi_logloss: 2.89921
# [44]	valid_0's multi_logloss: 2.89878
# [45]	valid_0's multi_logloss: 2.89827
# [46]	valid_0's multi_logloss: 2.89779
# [47]	valid_0's multi_logloss: 2.89729
# [48]	valid_0's multi_logloss: 2.8968
# [49]	valid_0's multi_logloss: 2.89631
# [50]	valid_0's multi_logloss: 2.89585
# [51]	valid_0's multi_logloss: 2.89537
# [52]	valid_0's multi_logloss: 2.89496
# [53]	valid_0's multi_logloss: 2.89447
# [54]	valid_0's multi_logloss: 2.8941
# [55]	valid_0's multi_logloss: 2.89369
# [56]	valid_0's multi_logloss: 2.89331
# [57]	valid_0's multi_logloss: 2.8929
# [58]	valid_0's multi_logloss: 2.89253
# [59]	valid_0's multi_logloss: 2.89215
# [60]	valid_0's multi_logloss: 2.89182
# [61]	valid_0's multi_logloss: 2.89142
# [62]	valid_0's multi_logloss: 2.89112
# [63]	valid_0's multi_logloss: 2.89077
# [64]	valid_0's multi_logloss: 2.89039
# [65]	valid_0's multi_logloss: 2.89006
# [66]	valid_0's multi_logloss: 2.8898
# [67]	valid_0's multi_logloss: 2.88943
# [68]	valid_0's multi_logloss: 2.88908
# [69]	valid_0's multi_logloss: 2.88868
# [70]	valid_0's multi_logloss: 2.8883
# [71]	valid_0's multi_logloss: 2.88796
# [72]	valid_0's multi_logloss: 2.8877
# [73]	valid_0's multi_logloss: 2.88741
# [74]	valid_0's multi_logloss: 2.88718
# [75]	valid_0's multi_logloss: 2.88681
# [76]	valid_0's multi_logloss: 2.88645
# [77]	valid_0's multi_logloss: 2.88612
# [78]	valid_0's multi_logloss: 2.88573
# [79]	valid_0's multi_logloss: 2.88538
# [80]	valid_0's multi_logloss: 2.88513
# [81]	valid_0's multi_logloss: 2.88481
# [82]	valid_0's multi_logloss: 2.88447
# [83]	valid_0's multi_logloss: 2.88419
# [84]	valid_0's multi_logloss: 2.88384
# [85]	valid_0's multi_logloss: 2.88352
# [86]	valid_0's multi_logloss: 2.88324
# [87]	valid_0's multi_logloss: 2.88292
# [88]	valid_0's multi_logloss: 2.88268
# [89]	valid_0's multi_logloss: 2.8824
# [90]	valid_0's multi_logloss: 2.88208
# [91]	valid_0's multi_logloss: 2.88173
# [92]	valid_0's multi_logloss: 2.88143
# [93]	valid_0's multi_logloss: 2.88117
# [94]	valid_0's multi_logloss: 2.88094
# [95]	valid_0's multi_logloss: 2.88053
# [96]	valid_0's multi_logloss: 2.88022
# [97]	valid_0's multi_logloss: 2.87997
# [98]	valid_0's multi_logloss: 2.87974
# [99]	valid_0's multi_logloss: 2.87943
# [100]	valid_0's multi_logloss: 2.87926
# [101]	valid_0's multi_logloss: 2.879
# [102]	valid_0's multi_logloss: 2.87875
# [103]	valid_0's multi_logloss: 2.87845
# [104]	valid_0's multi_logloss: 2.87814
# [105]	valid_0's multi_logloss: 2.87791
# [106]	valid_0's multi_logloss: 2.87764
# [107]	valid_0's multi_logloss: 2.8774
# [108]	valid_0's multi_logloss: 2.87722
# [109]	valid_0's multi_logloss: 2.87696
# [110]	valid_0's multi_logloss: 2.87674
# [111]	valid_0's multi_logloss: 2.87652
# [112]	valid_0's multi_logloss: 2.87629
# [113]	valid_0's multi_logloss: 2.87602
# [114]	valid_0's multi_logloss: 2.87581
# [115]	valid_0's multi_logloss: 2.87556
# [116]	valid_0's multi_logloss: 2.87529
# [117]	valid_0's multi_logloss: 2.87503
# [118]	valid_0's multi_logloss: 2.87485
# [119]	valid_0's multi_logloss: 2.87457
# [120]	valid_0's multi_logloss: 2.87438
# [121]	valid_0's multi_logloss: 2.8741
# [122]	valid_0's multi_logloss: 2.87391
# [123]	valid_0's multi_logloss: 2.87365
# [124]	valid_0's multi_logloss: 2.87351
# [125]	valid_0's multi_logloss: 2.87334
# [126]	valid_0's multi_logloss: 2.87311
# [127]	valid_0's multi_logloss: 2.87293
# [128]	valid_0's multi_logloss: 2.87274
# [129]	valid_0's multi_logloss: 2.87257
# [130]	valid_0's multi_logloss: 2.87238
# [131]	valid_0's multi_logloss: 2.87218
# [132]	valid_0's multi_logloss: 2.872
# [133]	valid_0's multi_logloss: 2.87186
# [134]	valid_0's multi_logloss: 2.87167
# [135]	valid_0's multi_logloss: 2.87149
# [136]	valid_0's multi_logloss: 2.87128
# [137]	valid_0's multi_logloss: 2.8711
# [138]	valid_0's multi_logloss: 2.87089
# [139]	valid_0's multi_logloss: 2.8707
# [140]	valid_0's multi_logloss: 2.87046
# [141]	valid_0's multi_logloss: 2.87029
# [142]	valid_0's multi_logloss: 2.87006
# [143]	valid_0's multi_logloss: 2.86982
# [144]	valid_0's multi_logloss: 2.86964
# [145]	valid_0's multi_logloss: 2.86939
# [146]	valid_0's multi_logloss: 2.86923
# [147]	valid_0's multi_logloss: 2.86897
# [148]	valid_0's multi_logloss: 2.86873
# [149]	valid_0's multi_logloss: 2.86845
# [150]	valid_0's multi_logloss: 2.86826
# [151]	valid_0's multi_logloss: 2.868
# [152]	valid_0's multi_logloss: 2.86784
# [153]	valid_0's multi_logloss: 2.86762
# [154]	valid_0's multi_logloss: 2.86738
# [155]	valid_0's multi_logloss: 2.86716
# [156]	valid_0's multi_logloss: 2.867
# [157]	valid_0's multi_logloss: 2.86681
# [158]	valid_0's multi_logloss: 2.86662
# [159]	valid_0's multi_logloss: 2.86646
# [160]	valid_0's multi_logloss: 2.86628
# [161]	valid_0's multi_logloss: 2.86605
# [162]	valid_0's multi_logloss: 2.86583
# [163]	valid_0's multi_logloss: 2.86572
# [164]	valid_0's multi_logloss: 2.86558
# [165]	valid_0's multi_logloss: 2.86543
# [166]	valid_0's multi_logloss: 2.86527
# [167]	valid_0's multi_logloss: 2.86514
# [168]	valid_0's multi_logloss: 2.86495
# [169]	valid_0's multi_logloss: 2.86484
# [170]	valid_0's multi_logloss: 2.86464
# [171]	valid_0's multi_logloss: 2.86452
# [172]	valid_0's multi_logloss: 2.86435
# [173]	valid_0's multi_logloss: 2.86424
# [174]	valid_0's multi_logloss: 2.86405
# [175]	valid_0's multi_logloss: 2.86388
# [176]	valid_0's multi_logloss: 2.86374
# [177]	valid_0's multi_logloss: 2.86359
# [178]	valid_0's multi_logloss: 2.86352
# [179]	valid_0's multi_logloss: 2.86331
# [180]	valid_0's multi_logloss: 2.86315
# [181]	valid_0's multi_logloss: 2.86305
# [182]	valid_0's multi_logloss: 2.86292
# [183]	valid_0's multi_logloss: 2.86268
# [184]	valid_0's multi_logloss: 2.86262
# [185]	valid_0's multi_logloss: 2.86249
# [186]	valid_0's multi_logloss: 2.86239
# [187]	valid_0's multi_logloss: 2.86215
# [188]	valid_0's multi_logloss: 2.86203
# [189]	valid_0's multi_logloss: 2.86198
# [190]	valid_0's multi_logloss: 2.86189
# [191]	valid_0's multi_logloss: 2.86176
# [192]	valid_0's multi_logloss: 2.86157
# [193]	valid_0's multi_logloss: 2.86146
# [194]	valid_0's multi_logloss: 2.8613
# [195]	valid_0's multi_logloss: 2.86122
# [196]	valid_0's multi_logloss: 2.86112
# [197]	valid_0's multi_logloss: 2.86099
# [198]	valid_0's multi_logloss: 2.86086
# [199]	valid_0's multi_logloss: 2.86083
# [200]	valid_0's multi_logloss: 2.8607
# [201]	valid_0's multi_logloss: 2.86056
# [202]	valid_0's multi_logloss: 2.8605
# [203]	valid_0's multi_logloss: 2.8604
# [204]	valid_0's multi_logloss: 2.8603
# [205]	valid_0's multi_logloss: 2.86028
# [206]	valid_0's multi_logloss: 2.86016
# [207]	valid_0's multi_logloss: 2.86001
# [208]	valid_0's multi_logloss: 2.85992
# [209]	valid_0's multi_logloss: 2.85979
# [210]	valid_0's multi_logloss: 2.8597
# [211]	valid_0's multi_logloss: 2.85955
# [212]	valid_0's multi_logloss: 2.85943
# [213]	valid_0's multi_logloss: 2.8594
# [214]	valid_0's multi_logloss: 2.85931
# [215]	valid_0's multi_logloss: 2.85926
# [216]	valid_0's multi_logloss: 2.85918
# [217]	valid_0's multi_logloss: 2.85905
# [218]	valid_0's multi_logloss: 2.85899
# [219]	valid_0's multi_logloss: 2.85892
# [220]	valid_0's multi_logloss: 2.85887
# [221]	valid_0's multi_logloss: 2.85882
# [222]	valid_0's multi_logloss: 2.85872
# [223]	valid_0's multi_logloss: 2.85865
# [224]	valid_0's multi_logloss: 2.8586
# [225]	valid_0's multi_logloss: 2.85858
# [226]	valid_0's multi_logloss: 2.85848
# [227]	valid_0's multi_logloss: 2.85843
# [228]	valid_0's multi_logloss: 2.85839
# [229]	valid_0's multi_logloss: 2.85828
# [230]	valid_0's multi_logloss: 2.8582
# [231]	valid_0's multi_logloss: 2.85814
# [232]	valid_0's multi_logloss: 2.85806
# [233]	valid_0's multi_logloss: 2.85797
# [234]	valid_0's multi_logloss: 2.85794
# [235]	valid_0's multi_logloss: 2.85786
# [236]	valid_0's multi_logloss: 2.85778
# [237]	valid_0's multi_logloss: 2.85769
# [238]	valid_0's multi_logloss: 2.85765
# [239]	valid_0's multi_logloss: 2.85757
# [240]	valid_0's multi_logloss: 2.8575
# [241]	valid_0's multi_logloss: 2.85747
# [242]	valid_0's multi_logloss: 2.85741
# [243]	valid_0's multi_logloss: 2.85734
# [244]	valid_0's multi_logloss: 2.85728
# [245]	valid_0's multi_logloss: 2.85728
# [246]	valid_0's multi_logloss: 2.85722
# [247]	valid_0's multi_logloss: 2.85716
# [248]	valid_0's multi_logloss: 2.85707
# [249]	valid_0's multi_logloss: 2.85706
# [250]	valid_0's multi_logloss: 2.85703
# [251]	valid_0's multi_logloss: 2.85701
# [252]	valid_0's multi_logloss: 2.85697
# [253]	valid_0's multi_logloss: 2.85695
# [254]	valid_0's multi_logloss: 2.85694
# [255]	valid_0's multi_logloss: 2.8569
# [256]	valid_0's multi_logloss: 2.85686
# [257]	valid_0's multi_logloss: 2.85683
# [258]	valid_0's multi_logloss: 2.85678
# [259]	valid_0's multi_logloss: 2.85679
# [260]	valid_0's multi_logloss: 2.85677
# [261]	valid_0's multi_logloss: 2.85675
# [262]	valid_0's multi_logloss: 2.85669
# [263]	valid_0's multi_logloss: 2.85666
# [264]	valid_0's multi_logloss: 2.85667
# [265]	valid_0's multi_logloss: 2.85668
# [266]	valid_0's multi_logloss: 2.85657
# [267]	valid_0's multi_logloss: 2.85658
# [268]	valid_0's multi_logloss: 2.85659
# [269]	valid_0's multi_logloss: 2.85658
# [270]	valid_0's multi_logloss: 2.85661
# [271]	valid_0's multi_logloss: 2.85659
# [272]	valid_0's multi_logloss: 2.85661
# [273]	valid_0's multi_logloss: 2.85659
# [274]	valid_0's multi_logloss: 2.85656
# [275]	valid_0's multi_logloss: 2.85658
# [276]	valid_0's multi_logloss: 2.8566
# [277]	valid_0's multi_logloss: 2.85661
# [278]	valid_0's multi_logloss: 2.85655
# [279]	valid_0's multi_logloss: 2.85651
# [280]	valid_0's multi_logloss: 2.85653
# [281]	valid_0's multi_logloss: 2.8566
# [282]	valid_0's multi_logloss: 2.85659
# [283]	valid_0's multi_logloss: 2.85661
# [284]	valid_0's multi_logloss: 2.85661
# [285]	valid_0's multi_logloss: 2.85661
# [286]	valid_0's multi_logloss: 2.85664
# [287]	valid_0's multi_logloss: 2.8566
# [288]	valid_0's multi_logloss: 2.85658
# [289]	valid_0's multi_logloss: 2.85655
# Early stopping, best iteration is:
# [279]	valid_0's multi_logloss: 2.85651
# 0.014103185890054359
# crps list: [0.012499079618353474, 0.01228833604650279, 0.01192337912890213, 0.014299112499296895, 0.014103185890054359]
# average crps: 0.013022618636621928

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Jersey_cat', 'Dir_cos',
#        'Momentum_cos', 'AttackAngle', 'time_end', 'Grass',
#        'DefendersInTheBox_vs_Distance', 'DisToQB', 'runner_height',
#        'DefenseAveX', 'DefenseAveY', 'DefenseAveMomentum',
#        'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos',
#        '1stDefender_AttackAngle', 'RusherVoronoi', 'FirstDefenderVoronoi',
#        'PitchControl'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                     AttackAngle       0       0       0       0       0
# 1                      Jersey_cat       0       4       0       0       0
# 2                           Grass     518     277     320     244     110
# 3                            Team     309     800     422     372     309
# 4                OffenseFormation     854     836     960     791     559
# 5                            Down     886    1378    1057     489     533
# 6                          Season    2287    1557    2401    1608    1516
# 7               DefendersInTheBox    2332    1496    2204    2028    1718
# 8                DefensePersonnel    2302    2960    1880    1369    1544
# 9                   runner_height    1357    3487    3234    1940    1165
# 10                    StadiumType    3181    4303    3589    1948    2249
# 11               OffensePersonnel    2770    3845    3558    3645    2613
# 12                    GameWeather    3848    4003    4223    2854    1686
# 13            HomeScoreBeforePlay    3566    4808    3766    2017    3228
# 14                       Distance    2502    6064    5403    3880    1237
# 15                           Week    5376    5174    4090    2184    2304
# 16                      WindSpeed    4902    4438    4517    2983    3856
# 17                  WindDirection    4836    6609    3984    3033    2324
# 18                  RusherVoronoi    4586    4281    5164    3801    3093
# 19         VisitorScoreBeforePlay    4550    6218    3856    3905    3149
# 20                            Dis    5321    5190    4042    3797    3405
# 21                       Location    4607    6735    4146    3995    2558
# 22                   PlayerWeight    5970    6103    3712    3211    3365
# 23                        Stadium    5613    5075    5344    4586    3402
# 24                   JerseyNumber    5463    7462    5415    4205    3424
# 25                    Orientation    6607    6541    5926    4163    4019
# 26                       Humidity    6186    7120    5738    3711    4703
# 27                    Temperature    6413    6192    6796    4582    4100
# 28                              S    7236    6129    5865    4428    4586
# 29  DefendersInTheBox_vs_Distance   10334    6261    3910    5071    3153
# 30                    OffenseStdY    6164    7579    6105    4688    4212
# 31             OffenseAveMomentum    7254    7017    6660    3938    4482
# 32                    OffenseStdX    7988    7984    5534    4650    3854
# 33                    DefenseStdY    7726    7597    6150    4939    3920
# 34         RunnerToDefenseCentoid    6993    6481    7395    5302    4859
# 35                              X    7877    8031    7751    4830    4799
# 36         RunnerToOffenseCentoid    8328    9453    6458    5532    4585
# 37                              Y    8538    9425    7377    4219    5014
# 38                       Momentum    7147    9799    7704    5576    5333
# 39                          NflId    8052    8628    9360    4906    4765
# 40                    DefenseAveX    6705    9153    8440    7016    4583
# 41                            Dir    8114    9010    8323    6073    4872
# 42                    DefenseStdX    8638    9834    7779    6485    4893
# 43                 OffenseSpreadX    8546   10565    6813    6276    5499
# 44              PlayerCollegeName    8804    8882    7623    6987    5740
# 45         OffenseStdMomentum_cos    8219   10152    7947    6061    5683
# 46             DefenseAveMomentum    7480   10363    9120    6581    5023
# 47         OffenseAveMomentum_cos    9779    9387    9257    5501    5254
# 48                    DefenseAveY    9064    9353    9406    6791    5017
# 49                            age   10886    9402    8310    5925    5191
# 50                 DefenseSpreadX   10539   10623    7988    6078    5551
# 51             DefenseStdMomentum    8856   11143   10858    6421    5254
# 52                        DisToQB    9788   10651    9986    6615    5641
# 53           FirstDefenderVoronoi    9154   12410   10027    6581    5858
# 54                        Dir_cos   10140   11077    9971    6753    6280
# 55         DefenseStdMomentum_cos   10318   10561   10531    7088    6537
# 56                   PitchControl   11171   12626    8778    7479    5899
# 57                       time_end    9848   12020    9423    7711    7065
# 58                  MinTackleTime   10582   13642    9703    5551    7235
# 59             OffenseStdMomentum    9901   12758    9347    7802    6982
# 60              RunnerToScrimmage   11260   13034    9704    8030    6331
# 61                       YardLine   11070   13749   11535    7676    6739
# 62       1stOffenser_Momentum_cos   13434   12396   11341    8399    7539
# 63        1stDefender_AttackAngle   12836   14775   10410    8410    8511
# 64         DefenseAveMomentum_cos   14389   12755   12384    8466    7369
# 65                   Momentum_cos   12990   14245   12982    9481    9291
# 66       1stDefender_Momentum_cos   13285   16698   12284    9967    7805
# 67                              A   21838   21241   17966   18925   17916
#
#     Average          Std        Cv
# 0       0.0     0.000000       NaN
# 1       0.8     1.600000  2.000000
# 2     293.8   132.285147  0.450256
# 3     442.4   183.761367  0.415374
# 4     800.0   132.645392  0.165807
# 5     868.6   332.267723  0.382532
# 6    1873.8   386.705780  0.206375
# 7    1955.6   308.644520  0.157826
# 8    2011.0   571.436086  0.284155
# 9    2236.6   955.855763  0.427370
# 10   3054.0   864.131471  0.282951
# 11   3286.2   496.896528  0.151207
# 12   3322.8   943.160092  0.283845
# 13   3477.0   900.733479  0.259055
# 14   3817.2  1786.280986  0.467956
# 15   3825.6  1363.960938  0.356535
# 16   4139.2   667.963891  0.161375
# 17   4157.2  1491.746547  0.358834
# 18   4185.0   702.620523  0.167890
# 19   4335.6  1040.466165  0.239982
# 20   4351.0   767.089825  0.176302
# 21   4408.2  1350.277216  0.306310
# 22   4472.2  1288.202996  0.288047
# 23   4804.0   778.800360  0.162115
# 24   5193.8  1369.382839  0.263657
# 25   5451.2  1136.629122  0.208510
# 26   5491.6  1182.118201  0.215259
# 27   5616.6  1070.214483  0.190545
# 28   5648.8  1040.810722  0.184253
# 29   5745.8  2524.485643  0.439362
# 30   5749.6  1194.650510  0.207780
# 31   5870.2  1379.444294  0.234991
# 32   6002.0  1704.896009  0.284055
# 33   6066.4  1482.029770  0.244301
# 34   6206.0   973.687835  0.156895
# 35   6657.6  1507.527990  0.226437
# 36   6871.2  1787.672162  0.260169
# 37   6914.6  2001.493902  0.289459
# 38   7111.8  1618.381587  0.227563
# 39   7142.2  1929.022799  0.270088
# 40   7179.4  1579.699794  0.220032
# 41   7278.4  1551.232104  0.213128
# 42   7525.8  1711.361259  0.227399
# 43   7539.8  1814.087473  0.240602
# 44   7607.2  1177.181277  0.154746
# 45   7612.4  1616.101185  0.212299
# 46   7713.4  1874.777918  0.243055
# 47   7835.6  2015.888846  0.257273
# 48   7926.2  1747.700134  0.220497
# 49   7942.8  2124.638642  0.267492
# 50   8155.8  2139.958448  0.262385
# 51   8506.4  2346.525142  0.275854
# 52   8536.2  2010.696138  0.235549
# 53   8806.0  2376.640065  0.269889
# 54   8844.2  1943.317308  0.219728
# 55   9007.0  1802.202763  0.200089
# 56   9190.6  2435.504104  0.264999
# 57   9213.4  1743.357749  0.189220
# 58   9342.6  2791.739572  0.298818
# 59   9358.0  1996.070239  0.213301
# 60   9671.8  2353.051500  0.243290
# 61  10153.8  2587.390608  0.254820
# 62  10621.8  2281.140013  0.214760
# 63  10988.4  2484.840808  0.226133
# 64  11072.6  2685.507967  0.242536
# 65  11797.8  2023.070281  0.171479
# 66  12007.8  3017.744018  0.251315
# 67  19577.2  1652.898230  0.084430

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0
      
def transform_height(te):
    return (int(te.split('-')[0])*12 + int(te.split('-')[1]))*2.54/100

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'Quarter',
                   'Turf', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'PlayerHeight']

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single['TimeHandoff'] = df_single['TimeHandoff'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    df_single['TimeSnap'] = df_single['TimeSnap'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    df_single['handoff_snap_diff'] = (df_single['TimeHandoff'] - df_single['TimeSnap']).map(lambda x:x.seconds)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #top20_weather = list(df.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    #df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    #df_single["OffenseFormation"] = df_single["OffenseFormation"].apply(lambda x: "SHOTGUN" if x== "ACE" else x)

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single['runner_height'] = df_single.PlayerHeight.map(transform_height)
    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    #df_single["RunnerToScrimmage"] = df_single["X"] - df_single["YardLine"]
    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "InfluToBall", "TackleTimeToRusher"]#, "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# CPU times: user 14min 20s, sys: 8.29 s, total: 14min 28s
# Wall time: 14min 26s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : -1,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86917
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86674
# [3]	valid_0's multi_logloss: 2.86437
# [4]	valid_0's multi_logloss: 2.86227
# [5]	valid_0's multi_logloss: 2.86021
# [6]	valid_0's multi_logloss: 2.85815
# [7]	valid_0's multi_logloss: 2.85646
# [8]	valid_0's multi_logloss: 2.85476
# [9]	valid_0's multi_logloss: 2.85305
# [10]	valid_0's multi_logloss: 2.85138
# [11]	valid_0's multi_logloss: 2.84955
# [12]	valid_0's multi_logloss: 2.84772
# [13]	valid_0's multi_logloss: 2.84605
# [14]	valid_0's multi_logloss: 2.84447
# [15]	valid_0's multi_logloss: 2.8429
# [16]	valid_0's multi_logloss: 2.84134
# [17]	valid_0's multi_logloss: 2.83986
# [18]	valid_0's multi_logloss: 2.83843
# [19]	valid_0's multi_logloss: 2.83702
# [20]	valid_0's multi_logloss: 2.83567
# [21]	valid_0's multi_logloss: 2.83433
# [22]	valid_0's multi_logloss: 2.83301
# [23]	valid_0's multi_logloss: 2.83163
# [24]	valid_0's multi_logloss: 2.83032
# [25]	valid_0's multi_logloss: 2.82899
# [26]	valid_0's multi_logloss: 2.82768
# [27]	valid_0's multi_logloss: 2.82629
# [28]	valid_0's multi_logloss: 2.82498
# [29]	valid_0's multi_logloss: 2.82364
# [30]	valid_0's multi_logloss: 2.82247
# [31]	valid_0's multi_logloss: 2.82125
# [32]	valid_0's multi_logloss: 2.82008
# [33]	valid_0's multi_logloss: 2.81891
# [34]	valid_0's multi_logloss: 2.8178
# [35]	valid_0's multi_logloss: 2.81673
# [36]	valid_0's multi_logloss: 2.81555
# [37]	valid_0's multi_logloss: 2.81444
# [38]	valid_0's multi_logloss: 2.81347
# [39]	valid_0's multi_logloss: 2.81237
# [40]	valid_0's multi_logloss: 2.81122
# [41]	valid_0's multi_logloss: 2.81007
# [42]	valid_0's multi_logloss: 2.80894
# [43]	valid_0's multi_logloss: 2.80772
# [44]	valid_0's multi_logloss: 2.80668
# [45]	valid_0's multi_logloss: 2.80564
# [46]	valid_0's multi_logloss: 2.80471
# [47]	valid_0's multi_logloss: 2.8038
# [48]	valid_0's multi_logloss: 2.80279
# [49]	valid_0's multi_logloss: 2.80186
# [50]	valid_0's multi_logloss: 2.80094
# [51]	valid_0's multi_logloss: 2.79984
# [52]	valid_0's multi_logloss: 2.79904
# [53]	valid_0's multi_logloss: 2.79792
# [54]	valid_0's multi_logloss: 2.79707
# [55]	valid_0's multi_logloss: 2.79616
# [56]	valid_0's multi_logloss: 2.79524
# [57]	valid_0's multi_logloss: 2.79426
# [58]	valid_0's multi_logloss: 2.79321
# [59]	valid_0's multi_logloss: 2.79232
# [60]	valid_0's multi_logloss: 2.7914
# [61]	valid_0's multi_logloss: 2.79053
# [62]	valid_0's multi_logloss: 2.7895
# [63]	valid_0's multi_logloss: 2.78869
# [64]	valid_0's multi_logloss: 2.7877
# [65]	valid_0's multi_logloss: 2.78684
# [66]	valid_0's multi_logloss: 2.78601
# [67]	valid_0's multi_logloss: 2.78522
# [68]	valid_0's multi_logloss: 2.78422
# [69]	valid_0's multi_logloss: 2.78337
# [70]	valid_0's multi_logloss: 2.78244
# [71]	valid_0's multi_logloss: 2.78155
# [72]	valid_0's multi_logloss: 2.78066
# [73]	valid_0's multi_logloss: 2.77991
# [74]	valid_0's multi_logloss: 2.77898
# [75]	valid_0's multi_logloss: 2.77813
# [76]	valid_0's multi_logloss: 2.77737
# [77]	valid_0's multi_logloss: 2.77654
# [78]	valid_0's multi_logloss: 2.77571
# [79]	valid_0's multi_logloss: 2.77485
# [80]	valid_0's multi_logloss: 2.77398
# [81]	valid_0's multi_logloss: 2.77317
# [82]	valid_0's multi_logloss: 2.77235
# [83]	valid_0's multi_logloss: 2.77165
# [84]	valid_0's multi_logloss: 2.77085
# [85]	valid_0's multi_logloss: 2.77
# [86]	valid_0's multi_logloss: 2.76938
# [87]	valid_0's multi_logloss: 2.76862
# [88]	valid_0's multi_logloss: 2.76794
# [89]	valid_0's multi_logloss: 2.76723
# [90]	valid_0's multi_logloss: 2.76632
# [91]	valid_0's multi_logloss: 2.76567
# [92]	valid_0's multi_logloss: 2.76491
# [93]	valid_0's multi_logloss: 2.76427
# [94]	valid_0's multi_logloss: 2.76358
# [95]	valid_0's multi_logloss: 2.76282
# [96]	valid_0's multi_logloss: 2.76212
# [97]	valid_0's multi_logloss: 2.76146
# [98]	valid_0's multi_logloss: 2.76084
# [99]	valid_0's multi_logloss: 2.76014
# [100]	valid_0's multi_logloss: 2.75947
# [101]	valid_0's multi_logloss: 2.75889
# [102]	valid_0's multi_logloss: 2.7583
# [103]	valid_0's multi_logloss: 2.75766
# [104]	valid_0's multi_logloss: 2.757
# [105]	valid_0's multi_logloss: 2.75645
# [106]	valid_0's multi_logloss: 2.75595
# [107]	valid_0's multi_logloss: 2.75536
# [108]	valid_0's multi_logloss: 2.75469
# [109]	valid_0's multi_logloss: 2.75418
# [110]	valid_0's multi_logloss: 2.7537
# [111]	valid_0's multi_logloss: 2.75311
# [112]	valid_0's multi_logloss: 2.75251
# [113]	valid_0's multi_logloss: 2.75192
# [114]	valid_0's multi_logloss: 2.75137
# [115]	valid_0's multi_logloss: 2.75074
# [116]	valid_0's multi_logloss: 2.75009
# [117]	valid_0's multi_logloss: 2.74946
# [118]	valid_0's multi_logloss: 2.74891
# [119]	valid_0's multi_logloss: 2.74832
# [120]	valid_0's multi_logloss: 2.74783
# [121]	valid_0's multi_logloss: 2.7473
# [122]	valid_0's multi_logloss: 2.74676
# [123]	valid_0's multi_logloss: 2.74633
# [124]	valid_0's multi_logloss: 2.74575
# [125]	valid_0's multi_logloss: 2.74513
# [126]	valid_0's multi_logloss: 2.74467
# [127]	valid_0's multi_logloss: 2.7442
# [128]	valid_0's multi_logloss: 2.7437
# [129]	valid_0's multi_logloss: 2.74323
# [130]	valid_0's multi_logloss: 2.74279
# [131]	valid_0's multi_logloss: 2.74232
# [132]	valid_0's multi_logloss: 2.7418
# [133]	valid_0's multi_logloss: 2.74135
# [134]	valid_0's multi_logloss: 2.74085
# [135]	valid_0's multi_logloss: 2.74035
# [136]	valid_0's multi_logloss: 2.73992
# [137]	valid_0's multi_logloss: 2.73942
# [138]	valid_0's multi_logloss: 2.73891
# [139]	valid_0's multi_logloss: 2.7385
# [140]	valid_0's multi_logloss: 2.73807
# [141]	valid_0's multi_logloss: 2.73756
# [142]	valid_0's multi_logloss: 2.73711
# [143]	valid_0's multi_logloss: 2.73667
# [144]	valid_0's multi_logloss: 2.7361
# [145]	valid_0's multi_logloss: 2.73565
# [146]	valid_0's multi_logloss: 2.73521
# [147]	valid_0's multi_logloss: 2.73476
# [148]	valid_0's multi_logloss: 2.73434
# [149]	valid_0's multi_logloss: 2.73384
# [150]	valid_0's multi_logloss: 2.73346
# [151]	valid_0's multi_logloss: 2.733
# [152]	valid_0's multi_logloss: 2.73261
# [153]	valid_0's multi_logloss: 2.73225
# [154]	valid_0's multi_logloss: 2.73179
# [155]	valid_0's multi_logloss: 2.73144
# [156]	valid_0's multi_logloss: 2.73109
# [157]	valid_0's multi_logloss: 2.73063
# [158]	valid_0's multi_logloss: 2.73024
# [159]	valid_0's multi_logloss: 2.7298
# [160]	valid_0's multi_logloss: 2.72946
# [161]	valid_0's multi_logloss: 2.72903
# [162]	valid_0's multi_logloss: 2.7287
# [163]	valid_0's multi_logloss: 2.72836
# [164]	valid_0's multi_logloss: 2.72802
# [165]	valid_0's multi_logloss: 2.72753
# [166]	valid_0's multi_logloss: 2.72723
# [167]	valid_0's multi_logloss: 2.72685
# [168]	valid_0's multi_logloss: 2.72647
# [169]	valid_0's multi_logloss: 2.726
# [170]	valid_0's multi_logloss: 2.72569
# [171]	valid_0's multi_logloss: 2.72534
# [172]	valid_0's multi_logloss: 2.72501
# [173]	valid_0's multi_logloss: 2.72472
# [174]	valid_0's multi_logloss: 2.72437
# [175]	valid_0's multi_logloss: 2.7241
# [176]	valid_0's multi_logloss: 2.72373
# [177]	valid_0's multi_logloss: 2.72337
# [178]	valid_0's multi_logloss: 2.72305
# [179]	valid_0's multi_logloss: 2.72272
# [180]	valid_0's multi_logloss: 2.72243
# [181]	valid_0's multi_logloss: 2.72213
# [182]	valid_0's multi_logloss: 2.72184
# [183]	valid_0's multi_logloss: 2.72151
# [184]	valid_0's multi_logloss: 2.7212
# [185]	valid_0's multi_logloss: 2.72094
# [186]	valid_0's multi_logloss: 2.7206
# [187]	valid_0's multi_logloss: 2.72035
# [188]	valid_0's multi_logloss: 2.72006
# [189]	valid_0's multi_logloss: 2.71971
# [190]	valid_0's multi_logloss: 2.71949
# [191]	valid_0's multi_logloss: 2.71917
# [192]	valid_0's multi_logloss: 2.71892
# [193]	valid_0's multi_logloss: 2.71867
# [194]	valid_0's multi_logloss: 2.71838
# [195]	valid_0's multi_logloss: 2.71813
# [196]	valid_0's multi_logloss: 2.7179
# [197]	valid_0's multi_logloss: 2.71766
# [198]	valid_0's multi_logloss: 2.71737
# [199]	valid_0's multi_logloss: 2.71708
# [200]	valid_0's multi_logloss: 2.71689
# [201]	valid_0's multi_logloss: 2.71666
# [202]	valid_0's multi_logloss: 2.71634
# [203]	valid_0's multi_logloss: 2.71609
# [204]	valid_0's multi_logloss: 2.71583
# [205]	valid_0's multi_logloss: 2.71556
# [206]	valid_0's multi_logloss: 2.71534
# [207]	valid_0's multi_logloss: 2.71516
# [208]	valid_0's multi_logloss: 2.71489
# [209]	valid_0's multi_logloss: 2.71473
# [210]	valid_0's multi_logloss: 2.71448
# [211]	valid_0's multi_logloss: 2.71426
# [212]	valid_0's multi_logloss: 2.71404
# [213]	valid_0's multi_logloss: 2.71377
# [214]	valid_0's multi_logloss: 2.71352
# [215]	valid_0's multi_logloss: 2.7132
# [216]	valid_0's multi_logloss: 2.71296
# [217]	valid_0's multi_logloss: 2.71277
# [218]	valid_0's multi_logloss: 2.71255
# [219]	valid_0's multi_logloss: 2.7123
# [220]	valid_0's multi_logloss: 2.71205
# [221]	valid_0's multi_logloss: 2.71188
# [222]	valid_0's multi_logloss: 2.71173
# [223]	valid_0's multi_logloss: 2.71153
# [224]	valid_0's multi_logloss: 2.71138
# [225]	valid_0's multi_logloss: 2.71126
# [226]	valid_0's multi_logloss: 2.71106
# [227]	valid_0's multi_logloss: 2.7108
# [228]	valid_0's multi_logloss: 2.71064
# [229]	valid_0's multi_logloss: 2.71045
# [230]	valid_0's multi_logloss: 2.71031
# [231]	valid_0's multi_logloss: 2.71005
# [232]	valid_0's multi_logloss: 2.70992
# [233]	valid_0's multi_logloss: 2.70979
# [234]	valid_0's multi_logloss: 2.70959
# [235]	valid_0's multi_logloss: 2.70945
# [236]	valid_0's multi_logloss: 2.70923
# [237]	valid_0's multi_logloss: 2.70906
# [238]	valid_0's multi_logloss: 2.70892
# [239]	valid_0's multi_logloss: 2.70879
# [240]	valid_0's multi_logloss: 2.7086
# [241]	valid_0's multi_logloss: 2.70854
# [242]	valid_0's multi_logloss: 2.70834
# [243]	valid_0's multi_logloss: 2.70814
# [244]	valid_0's multi_logloss: 2.70794
# [245]	valid_0's multi_logloss: 2.70783
# [246]	valid_0's multi_logloss: 2.70767
# [247]	valid_0's multi_logloss: 2.70745
# [248]	valid_0's multi_logloss: 2.70727
# [249]	valid_0's multi_logloss: 2.70713
# [250]	valid_0's multi_logloss: 2.70698
# [251]	valid_0's multi_logloss: 2.70678
# [252]	valid_0's multi_logloss: 2.70667
# [253]	valid_0's multi_logloss: 2.70654
# [254]	valid_0's multi_logloss: 2.70643
# [255]	valid_0's multi_logloss: 2.70628
# [256]	valid_0's multi_logloss: 2.70608
# [257]	valid_0's multi_logloss: 2.70598
# [258]	valid_0's multi_logloss: 2.70586
# [259]	valid_0's multi_logloss: 2.70571
# [260]	valid_0's multi_logloss: 2.70563
# [261]	valid_0's multi_logloss: 2.70546
# [262]	valid_0's multi_logloss: 2.70529
# [263]	valid_0's multi_logloss: 2.70509
# [264]	valid_0's multi_logloss: 2.70497
# [265]	valid_0's multi_logloss: 2.70485
# [266]	valid_0's multi_logloss: 2.70473
# [267]	valid_0's multi_logloss: 2.70459
# [268]	valid_0's multi_logloss: 2.70447
# [269]	valid_0's multi_logloss: 2.70438
# [270]	valid_0's multi_logloss: 2.70428
# [271]	valid_0's multi_logloss: 2.70419
# [272]	valid_0's multi_logloss: 2.70403
# [273]	valid_0's multi_logloss: 2.70392
# [274]	valid_0's multi_logloss: 2.70386
# [275]	valid_0's multi_logloss: 2.70377
# [276]	valid_0's multi_logloss: 2.70368
# [277]	valid_0's multi_logloss: 2.70359
# [278]	valid_0's multi_logloss: 2.70345
# [279]	valid_0's multi_logloss: 2.70332
# [280]	valid_0's multi_logloss: 2.70326
# [281]	valid_0's multi_logloss: 2.70315
# [282]	valid_0's multi_logloss: 2.70311
# [283]	valid_0's multi_logloss: 2.70302
# [284]	valid_0's multi_logloss: 2.70291
# [285]	valid_0's multi_logloss: 2.70282
# [286]	valid_0's multi_logloss: 2.70268
# [287]	valid_0's multi_logloss: 2.70257
# [288]	valid_0's multi_logloss: 2.70245
# [289]	valid_0's multi_logloss: 2.70241
# [290]	valid_0's multi_logloss: 2.70231
# [291]	valid_0's multi_logloss: 2.70212
# [292]	valid_0's multi_logloss: 2.70208
# [293]	valid_0's multi_logloss: 2.70202
# [294]	valid_0's multi_logloss: 2.70189
# [295]	valid_0's multi_logloss: 2.70178
# [296]	valid_0's multi_logloss: 2.7016
# [297]	valid_0's multi_logloss: 2.70157
# [298]	valid_0's multi_logloss: 2.70143
# [299]	valid_0's multi_logloss: 2.70129
# [300]	valid_0's multi_logloss: 2.70121
# [301]	valid_0's multi_logloss: 2.70102
# [302]	valid_0's multi_logloss: 2.70092
# [303]	valid_0's multi_logloss: 2.70083
# [304]	valid_0's multi_logloss: 2.70074
# [305]	valid_0's multi_logloss: 2.70067
# [306]	valid_0's multi_logloss: 2.70058
# [307]	valid_0's multi_logloss: 2.70047
# [308]	valid_0's multi_logloss: 2.70038
# [309]	valid_0's multi_logloss: 2.70023
# [310]	valid_0's multi_logloss: 2.70006
# [311]	valid_0's multi_logloss: 2.69994
# [312]	valid_0's multi_logloss: 2.69985
# [313]	valid_0's multi_logloss: 2.69979
# [314]	valid_0's multi_logloss: 2.6997
# [315]	valid_0's multi_logloss: 2.69961
# [316]	valid_0's multi_logloss: 2.6995
# [317]	valid_0's multi_logloss: 2.69946
# [318]	valid_0's multi_logloss: 2.69933
# [319]	valid_0's multi_logloss: 2.69921
# [320]	valid_0's multi_logloss: 2.69918
# [321]	valid_0's multi_logloss: 2.69906
# [322]	valid_0's multi_logloss: 2.69897
# [323]	valid_0's multi_logloss: 2.69886
# [324]	valid_0's multi_logloss: 2.6988
# [325]	valid_0's multi_logloss: 2.69869
# [326]	valid_0's multi_logloss: 2.69856
# [327]	valid_0's multi_logloss: 2.69853
# [328]	valid_0's multi_logloss: 2.69847
# [329]	valid_0's multi_logloss: 2.69834
# [330]	valid_0's multi_logloss: 2.69828
# [331]	valid_0's multi_logloss: 2.69828
# [332]	valid_0's multi_logloss: 2.69824
# [333]	valid_0's multi_logloss: 2.69816
# [334]	valid_0's multi_logloss: 2.69813
# [335]	valid_0's multi_logloss: 2.69801
# [336]	valid_0's multi_logloss: 2.6979
# [337]	valid_0's multi_logloss: 2.6978
# [338]	valid_0's multi_logloss: 2.69774
# [339]	valid_0's multi_logloss: 2.69767
# [340]	valid_0's multi_logloss: 2.69764
# [341]	valid_0's multi_logloss: 2.69763
# [342]	valid_0's multi_logloss: 2.69754
# [343]	valid_0's multi_logloss: 2.69743
# [344]	valid_0's multi_logloss: 2.69732
# [345]	valid_0's multi_logloss: 2.69723
# [346]	valid_0's multi_logloss: 2.69714
# [347]	valid_0's multi_logloss: 2.69711
# [348]	valid_0's multi_logloss: 2.69705
# [349]	valid_0's multi_logloss: 2.69695
# [350]	valid_0's multi_logloss: 2.6969
# [351]	valid_0's multi_logloss: 2.69687
# [352]	valid_0's multi_logloss: 2.6968
# [353]	valid_0's multi_logloss: 2.69675
# [354]	valid_0's multi_logloss: 2.69665
# [355]	valid_0's multi_logloss: 2.69653
# [356]	valid_0's multi_logloss: 2.69643
# [357]	valid_0's multi_logloss: 2.69639
# [358]	valid_0's multi_logloss: 2.69636
# [359]	valid_0's multi_logloss: 2.69633
# [360]	valid_0's multi_logloss: 2.69624
# [361]	valid_0's multi_logloss: 2.69619
# [362]	valid_0's multi_logloss: 2.69617
# [363]	valid_0's multi_logloss: 2.69611
# [364]	valid_0's multi_logloss: 2.69607
# [365]	valid_0's multi_logloss: 2.69604
# [366]	valid_0's multi_logloss: 2.69603
# [367]	valid_0's multi_logloss: 2.69602
# [368]	valid_0's multi_logloss: 2.69596
# [369]	valid_0's multi_logloss: 2.69592
# [370]	valid_0's multi_logloss: 2.69582
# [371]	valid_0's multi_logloss: 2.69576
# [372]	valid_0's multi_logloss: 2.69582
# [373]	valid_0's multi_logloss: 2.69579
# [374]	valid_0's multi_logloss: 2.69574
# [375]	valid_0's multi_logloss: 2.69566
# [376]	valid_0's multi_logloss: 2.69568
# [377]	valid_0's multi_logloss: 2.69562
# [378]	valid_0's multi_logloss: 2.69553
# [379]	valid_0's multi_logloss: 2.69552
# [380]	valid_0's multi_logloss: 2.6955
# [381]	valid_0's multi_logloss: 2.6955
# [382]	valid_0's multi_logloss: 2.69551
# [383]	valid_0's multi_logloss: 2.6955
# [384]	valid_0's multi_logloss: 2.69544
# [385]	valid_0's multi_logloss: 2.69535
# [386]	valid_0's multi_logloss: 2.69526
# [387]	valid_0's multi_logloss: 2.69522
# [388]	valid_0's multi_logloss: 2.6952
# [389]	valid_0's multi_logloss: 2.69518
# [390]	valid_0's multi_logloss: 2.69511
# [391]	valid_0's multi_logloss: 2.69512
# [392]	valid_0's multi_logloss: 2.69516
# [393]	valid_0's multi_logloss: 2.69513
# [394]	valid_0's multi_logloss: 2.69502
# [395]	valid_0's multi_logloss: 2.69504
# [396]	valid_0's multi_logloss: 2.69501
# [397]	valid_0's multi_logloss: 2.69501
# [398]	valid_0's multi_logloss: 2.695
# [399]	valid_0's multi_logloss: 2.69494
# [400]	valid_0's multi_logloss: 2.69494
# [401]	valid_0's multi_logloss: 2.69491
# [402]	valid_0's multi_logloss: 2.69488
# [403]	valid_0's multi_logloss: 2.69487
# [404]	valid_0's multi_logloss: 2.69485
# [405]	valid_0's multi_logloss: 2.6948
# [406]	valid_0's multi_logloss: 2.6948
# [407]	valid_0's multi_logloss: 2.69478
# [408]	valid_0's multi_logloss: 2.69478
# [409]	valid_0's multi_logloss: 2.69476
# [410]	valid_0's multi_logloss: 2.69472
# [411]	valid_0's multi_logloss: 2.69472
# [412]	valid_0's multi_logloss: 2.69472
# [413]	valid_0's multi_logloss: 2.69469
# [414]	valid_0's multi_logloss: 2.6947
# [415]	valid_0's multi_logloss: 2.69472
# [416]	valid_0's multi_logloss: 2.69468
# [417]	valid_0's multi_logloss: 2.69462
# [418]	valid_0's multi_logloss: 2.69464
# [419]	valid_0's multi_logloss: 2.69465
# [420]	valid_0's multi_logloss: 2.69465
# [421]	valid_0's multi_logloss: 2.69464
# [422]	valid_0's multi_logloss: 2.6946
# [423]	valid_0's multi_logloss: 2.69466
# [424]	valid_0's multi_logloss: 2.69465
# [425]	valid_0's multi_logloss: 2.69457
# [426]	valid_0's multi_logloss: 2.69461
# [427]	valid_0's multi_logloss: 2.69458
# [428]	valid_0's multi_logloss: 2.69456
# [429]	valid_0's multi_logloss: 2.69456
# [430]	valid_0's multi_logloss: 2.69459
# [431]	valid_0's multi_logloss: 2.69462
# [432]	valid_0's multi_logloss: 2.69462
# [433]	valid_0's multi_logloss: 2.69458
# [434]	valid_0's multi_logloss: 2.69465
# [435]	valid_0's multi_logloss: 2.69462
# [436]	valid_0's multi_logloss: 2.69461
# [437]	valid_0's multi_logloss: 2.69465
# [438]	valid_0's multi_logloss: 2.69467
# Early stopping, best iteration is:
# [428]	valid_0's multi_logloss: 2.69456
# 0.01251251411522651
# [1]	valid_0's multi_logloss: 2.88683
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88408
# [3]	valid_0's multi_logloss: 2.88191
# [4]	valid_0's multi_logloss: 2.87961
# [5]	valid_0's multi_logloss: 2.87766
# [6]	valid_0's multi_logloss: 2.87532
# [7]	valid_0's multi_logloss: 2.87318
# [8]	valid_0's multi_logloss: 2.87137
# [9]	valid_0's multi_logloss: 2.86949
# [10]	valid_0's multi_logloss: 2.86753
# [11]	valid_0's multi_logloss: 2.86566
# [12]	valid_0's multi_logloss: 2.86386
# [13]	valid_0's multi_logloss: 2.86209
# [14]	valid_0's multi_logloss: 2.8605
# [15]	valid_0's multi_logloss: 2.85891
# [16]	valid_0's multi_logloss: 2.8572
# [17]	valid_0's multi_logloss: 2.85566
# [18]	valid_0's multi_logloss: 2.85407
# [19]	valid_0's multi_logloss: 2.85256
# [20]	valid_0's multi_logloss: 2.85098
# [21]	valid_0's multi_logloss: 2.84946
# [22]	valid_0's multi_logloss: 2.84796
# [23]	valid_0's multi_logloss: 2.84631
# [24]	valid_0's multi_logloss: 2.84501
# [25]	valid_0's multi_logloss: 2.84368
# [26]	valid_0's multi_logloss: 2.84204
# [27]	valid_0's multi_logloss: 2.84051
# [28]	valid_0's multi_logloss: 2.83915
# [29]	valid_0's multi_logloss: 2.83759
# [30]	valid_0's multi_logloss: 2.83617
# [31]	valid_0's multi_logloss: 2.83469
# [32]	valid_0's multi_logloss: 2.8333
# [33]	valid_0's multi_logloss: 2.83201
# [34]	valid_0's multi_logloss: 2.83068
# [35]	valid_0's multi_logloss: 2.82927
# [36]	valid_0's multi_logloss: 2.82796
# [37]	valid_0's multi_logloss: 2.82674
# [38]	valid_0's multi_logloss: 2.82544
# [39]	valid_0's multi_logloss: 2.82422
# [40]	valid_0's multi_logloss: 2.82302
# [41]	valid_0's multi_logloss: 2.82187
# [42]	valid_0's multi_logloss: 2.82078
# [43]	valid_0's multi_logloss: 2.8197
# [44]	valid_0's multi_logloss: 2.8186
# [45]	valid_0's multi_logloss: 2.81764
# [46]	valid_0's multi_logloss: 2.81658
# [47]	valid_0's multi_logloss: 2.81543
# [48]	valid_0's multi_logloss: 2.81435
# [49]	valid_0's multi_logloss: 2.81336
# [50]	valid_0's multi_logloss: 2.81235
# [51]	valid_0's multi_logloss: 2.81136
# [52]	valid_0's multi_logloss: 2.81047
# [53]	valid_0's multi_logloss: 2.80944
# [54]	valid_0's multi_logloss: 2.8086
# [55]	valid_0's multi_logloss: 2.80761
# [56]	valid_0's multi_logloss: 2.80664
# [57]	valid_0's multi_logloss: 2.80569
# [58]	valid_0's multi_logloss: 2.80472
# [59]	valid_0's multi_logloss: 2.80363
# [60]	valid_0's multi_logloss: 2.80274
# [61]	valid_0's multi_logloss: 2.80176
# [62]	valid_0's multi_logloss: 2.80085
# [63]	valid_0's multi_logloss: 2.79989
# [64]	valid_0's multi_logloss: 2.79897
# [65]	valid_0's multi_logloss: 2.79805
# [66]	valid_0's multi_logloss: 2.79708
# [67]	valid_0's multi_logloss: 2.79622
# [68]	valid_0's multi_logloss: 2.79536
# [69]	valid_0's multi_logloss: 2.7945
# [70]	valid_0's multi_logloss: 2.79373
# [71]	valid_0's multi_logloss: 2.79283
# [72]	valid_0's multi_logloss: 2.79204
# [73]	valid_0's multi_logloss: 2.79115
# [74]	valid_0's multi_logloss: 2.79037
# [75]	valid_0's multi_logloss: 2.7895
# [76]	valid_0's multi_logloss: 2.78865
# [77]	valid_0's multi_logloss: 2.78785
# [78]	valid_0's multi_logloss: 2.78698
# [79]	valid_0's multi_logloss: 2.78609
# [80]	valid_0's multi_logloss: 2.78529
# [81]	valid_0's multi_logloss: 2.78465
# [82]	valid_0's multi_logloss: 2.78383
# [83]	valid_0's multi_logloss: 2.78306
# [84]	valid_0's multi_logloss: 2.78222
# [85]	valid_0's multi_logloss: 2.78151
# [86]	valid_0's multi_logloss: 2.78074
# [87]	valid_0's multi_logloss: 2.77999
# [88]	valid_0's multi_logloss: 2.77913
# [89]	valid_0's multi_logloss: 2.77847
# [90]	valid_0's multi_logloss: 2.77772
# [91]	valid_0's multi_logloss: 2.77704
# [92]	valid_0's multi_logloss: 2.77633
# [93]	valid_0's multi_logloss: 2.77568
# [94]	valid_0's multi_logloss: 2.77494
# [95]	valid_0's multi_logloss: 2.77414
# [96]	valid_0's multi_logloss: 2.77334
# [97]	valid_0's multi_logloss: 2.77268
# [98]	valid_0's multi_logloss: 2.77198
# [99]	valid_0's multi_logloss: 2.77117
# [100]	valid_0's multi_logloss: 2.77043
# [101]	valid_0's multi_logloss: 2.76977
# [102]	valid_0's multi_logloss: 2.76912
# [103]	valid_0's multi_logloss: 2.76834
# [104]	valid_0's multi_logloss: 2.76772
# [105]	valid_0's multi_logloss: 2.76706
# [106]	valid_0's multi_logloss: 2.76644
# [107]	valid_0's multi_logloss: 2.76582
# [108]	valid_0's multi_logloss: 2.76523
# [109]	valid_0's multi_logloss: 2.76449
# [110]	valid_0's multi_logloss: 2.76388
# [111]	valid_0's multi_logloss: 2.76332
# [112]	valid_0's multi_logloss: 2.76275
# [113]	valid_0's multi_logloss: 2.76211
# [114]	valid_0's multi_logloss: 2.76154
# [115]	valid_0's multi_logloss: 2.76111
# [116]	valid_0's multi_logloss: 2.76056
# [117]	valid_0's multi_logloss: 2.75995
# [118]	valid_0's multi_logloss: 2.75944
# [119]	valid_0's multi_logloss: 2.75885
# [120]	valid_0's multi_logloss: 2.75822
# [121]	valid_0's multi_logloss: 2.75773
# [122]	valid_0's multi_logloss: 2.75714
# [123]	valid_0's multi_logloss: 2.75654
# [124]	valid_0's multi_logloss: 2.75594
# [125]	valid_0's multi_logloss: 2.75549
# [126]	valid_0's multi_logloss: 2.75493
# [127]	valid_0's multi_logloss: 2.75431
# [128]	valid_0's multi_logloss: 2.75375
# [129]	valid_0's multi_logloss: 2.75317
# [130]	valid_0's multi_logloss: 2.75264
# [131]	valid_0's multi_logloss: 2.75212
# [132]	valid_0's multi_logloss: 2.75158
# [133]	valid_0's multi_logloss: 2.75108
# [134]	valid_0's multi_logloss: 2.75055
# [135]	valid_0's multi_logloss: 2.7501
# [136]	valid_0's multi_logloss: 2.74956
# [137]	valid_0's multi_logloss: 2.74899
# [138]	valid_0's multi_logloss: 2.74851
# [139]	valid_0's multi_logloss: 2.74801
# [140]	valid_0's multi_logloss: 2.74749
# [141]	valid_0's multi_logloss: 2.74695
# [142]	valid_0's multi_logloss: 2.74646
# [143]	valid_0's multi_logloss: 2.746
# [144]	valid_0's multi_logloss: 2.7455
# [145]	valid_0's multi_logloss: 2.74505
# [146]	valid_0's multi_logloss: 2.74453
# [147]	valid_0's multi_logloss: 2.74403
# [148]	valid_0's multi_logloss: 2.74359
# [149]	valid_0's multi_logloss: 2.74314
# [150]	valid_0's multi_logloss: 2.74271
# [151]	valid_0's multi_logloss: 2.74222
# [152]	valid_0's multi_logloss: 2.74183
# [153]	valid_0's multi_logloss: 2.74136
# [154]	valid_0's multi_logloss: 2.74089
# [155]	valid_0's multi_logloss: 2.74042
# [156]	valid_0's multi_logloss: 2.73988
# [157]	valid_0's multi_logloss: 2.7395
# [158]	valid_0's multi_logloss: 2.73915
# [159]	valid_0's multi_logloss: 2.73865
# [160]	valid_0's multi_logloss: 2.73823
# [161]	valid_0's multi_logloss: 2.7378
# [162]	valid_0's multi_logloss: 2.73744
# [163]	valid_0's multi_logloss: 2.73706
# [164]	valid_0's multi_logloss: 2.73666
# [165]	valid_0's multi_logloss: 2.73622
# [166]	valid_0's multi_logloss: 2.7358
# [167]	valid_0's multi_logloss: 2.73544
# [168]	valid_0's multi_logloss: 2.735
# [169]	valid_0's multi_logloss: 2.73457
# [170]	valid_0's multi_logloss: 2.73416
# [171]	valid_0's multi_logloss: 2.7337
# [172]	valid_0's multi_logloss: 2.73332
# [173]	valid_0's multi_logloss: 2.73297
# [174]	valid_0's multi_logloss: 2.73252
# [175]	valid_0's multi_logloss: 2.73214
# [176]	valid_0's multi_logloss: 2.73187
# [177]	valid_0's multi_logloss: 2.73142
# [178]	valid_0's multi_logloss: 2.73106
# [179]	valid_0's multi_logloss: 2.73076
# [180]	valid_0's multi_logloss: 2.73043
# [181]	valid_0's multi_logloss: 2.73001
# [182]	valid_0's multi_logloss: 2.72964
# [183]	valid_0's multi_logloss: 2.72929
# [184]	valid_0's multi_logloss: 2.72893
# [185]	valid_0's multi_logloss: 2.72854
# [186]	valid_0's multi_logloss: 2.72816
# [187]	valid_0's multi_logloss: 2.72779
# [188]	valid_0's multi_logloss: 2.72751
# [189]	valid_0's multi_logloss: 2.72719
# [190]	valid_0's multi_logloss: 2.72685
# [191]	valid_0's multi_logloss: 2.7265
# [192]	valid_0's multi_logloss: 2.7262
# [193]	valid_0's multi_logloss: 2.72587
# [194]	valid_0's multi_logloss: 2.7256
# [195]	valid_0's multi_logloss: 2.72527
# [196]	valid_0's multi_logloss: 2.72493
# [197]	valid_0's multi_logloss: 2.72468
# [198]	valid_0's multi_logloss: 2.72438
# [199]	valid_0's multi_logloss: 2.72408
# [200]	valid_0's multi_logloss: 2.72388
# [201]	valid_0's multi_logloss: 2.72351
# [202]	valid_0's multi_logloss: 2.72317
# [203]	valid_0's multi_logloss: 2.72289
# [204]	valid_0's multi_logloss: 2.72254
# [205]	valid_0's multi_logloss: 2.72225
# [206]	valid_0's multi_logloss: 2.7219
# [207]	valid_0's multi_logloss: 2.7216
# [208]	valid_0's multi_logloss: 2.72124
# [209]	valid_0's multi_logloss: 2.72096
# [210]	valid_0's multi_logloss: 2.72061
# [211]	valid_0's multi_logloss: 2.72036
# [212]	valid_0's multi_logloss: 2.72004
# [213]	valid_0's multi_logloss: 2.71977
# [214]	valid_0's multi_logloss: 2.7195
# [215]	valid_0's multi_logloss: 2.71928
# [216]	valid_0's multi_logloss: 2.71898
# [217]	valid_0's multi_logloss: 2.71871
# [218]	valid_0's multi_logloss: 2.71842
# [219]	valid_0's multi_logloss: 2.71823
# [220]	valid_0's multi_logloss: 2.71791
# [221]	valid_0's multi_logloss: 2.71765
# [222]	valid_0's multi_logloss: 2.71742
# [223]	valid_0's multi_logloss: 2.71716
# [224]	valid_0's multi_logloss: 2.71689
# [225]	valid_0's multi_logloss: 2.71661
# [226]	valid_0's multi_logloss: 2.71631
# [227]	valid_0's multi_logloss: 2.7161
# [228]	valid_0's multi_logloss: 2.71581
# [229]	valid_0's multi_logloss: 2.71553
# [230]	valid_0's multi_logloss: 2.71518
# [231]	valid_0's multi_logloss: 2.71498
# [232]	valid_0's multi_logloss: 2.71473
# [233]	valid_0's multi_logloss: 2.71452
# [234]	valid_0's multi_logloss: 2.71424
# [235]	valid_0's multi_logloss: 2.71405
# [236]	valid_0's multi_logloss: 2.71374
# [237]	valid_0's multi_logloss: 2.71355
# [238]	valid_0's multi_logloss: 2.71324
# [239]	valid_0's multi_logloss: 2.71305
# [240]	valid_0's multi_logloss: 2.71286
# [241]	valid_0's multi_logloss: 2.71262
# [242]	valid_0's multi_logloss: 2.71236
# [243]	valid_0's multi_logloss: 2.71219
# [244]	valid_0's multi_logloss: 2.71193
# [245]	valid_0's multi_logloss: 2.71167
# [246]	valid_0's multi_logloss: 2.71153
# [247]	valid_0's multi_logloss: 2.71136
# [248]	valid_0's multi_logloss: 2.71117
# [249]	valid_0's multi_logloss: 2.71099
# [250]	valid_0's multi_logloss: 2.71086
# [251]	valid_0's multi_logloss: 2.71061
# [252]	valid_0's multi_logloss: 2.71041
# [253]	valid_0's multi_logloss: 2.71025
# [254]	valid_0's multi_logloss: 2.71011
# [255]	valid_0's multi_logloss: 2.70994
# [256]	valid_0's multi_logloss: 2.70973
# [257]	valid_0's multi_logloss: 2.70951
# [258]	valid_0's multi_logloss: 2.70936
# [259]	valid_0's multi_logloss: 2.70912
# [260]	valid_0's multi_logloss: 2.70891
# [261]	valid_0's multi_logloss: 2.70873
# [262]	valid_0's multi_logloss: 2.70849
# [263]	valid_0's multi_logloss: 2.70829
# [264]	valid_0's multi_logloss: 2.70814
# [265]	valid_0's multi_logloss: 2.70789
# [266]	valid_0's multi_logloss: 2.70772
# [267]	valid_0's multi_logloss: 2.70752
# [268]	valid_0's multi_logloss: 2.7073
# [269]	valid_0's multi_logloss: 2.70714
# [270]	valid_0's multi_logloss: 2.70698
# [271]	valid_0's multi_logloss: 2.70679
# [272]	valid_0's multi_logloss: 2.70655
# [273]	valid_0's multi_logloss: 2.70638
# [274]	valid_0's multi_logloss: 2.70624
# [275]	valid_0's multi_logloss: 2.70601
# [276]	valid_0's multi_logloss: 2.70573
# [277]	valid_0's multi_logloss: 2.70555
# [278]	valid_0's multi_logloss: 2.70535
# [279]	valid_0's multi_logloss: 2.70522
# [280]	valid_0's multi_logloss: 2.70508
# [281]	valid_0's multi_logloss: 2.70492
# [282]	valid_0's multi_logloss: 2.70478
# [283]	valid_0's multi_logloss: 2.70453
# [284]	valid_0's multi_logloss: 2.7043
# [285]	valid_0's multi_logloss: 2.70412
# [286]	valid_0's multi_logloss: 2.70394
# [287]	valid_0's multi_logloss: 2.70377
# [288]	valid_0's multi_logloss: 2.70359
# [289]	valid_0's multi_logloss: 2.70342
# [290]	valid_0's multi_logloss: 2.70322
# [291]	valid_0's multi_logloss: 2.70311
# [292]	valid_0's multi_logloss: 2.70298
# [293]	valid_0's multi_logloss: 2.70279
# [294]	valid_0's multi_logloss: 2.70262
# [295]	valid_0's multi_logloss: 2.70253
# [296]	valid_0's multi_logloss: 2.70234
# [297]	valid_0's multi_logloss: 2.70222
# [298]	valid_0's multi_logloss: 2.70207
# [299]	valid_0's multi_logloss: 2.70188
# [300]	valid_0's multi_logloss: 2.70173
# [301]	valid_0's multi_logloss: 2.70156
# [302]	valid_0's multi_logloss: 2.70142
# [303]	valid_0's multi_logloss: 2.70128
# [304]	valid_0's multi_logloss: 2.70119
# [305]	valid_0's multi_logloss: 2.70106
# [306]	valid_0's multi_logloss: 2.70094
# [307]	valid_0's multi_logloss: 2.70078
# [308]	valid_0's multi_logloss: 2.70068
# [309]	valid_0's multi_logloss: 2.70055
# [310]	valid_0's multi_logloss: 2.70046
# [311]	valid_0's multi_logloss: 2.70028
# [312]	valid_0's multi_logloss: 2.70014
# [313]	valid_0's multi_logloss: 2.69995
# [314]	valid_0's multi_logloss: 2.69982
# [315]	valid_0's multi_logloss: 2.69969
# [316]	valid_0's multi_logloss: 2.6995
# [317]	valid_0's multi_logloss: 2.69934
# [318]	valid_0's multi_logloss: 2.69924
# [319]	valid_0's multi_logloss: 2.69914
# [320]	valid_0's multi_logloss: 2.69898
# [321]	valid_0's multi_logloss: 2.69886
# [322]	valid_0's multi_logloss: 2.69873
# [323]	valid_0's multi_logloss: 2.69856
# [324]	valid_0's multi_logloss: 2.69855
# [325]	valid_0's multi_logloss: 2.69841
# [326]	valid_0's multi_logloss: 2.69835
# [327]	valid_0's multi_logloss: 2.69829
# [328]	valid_0's multi_logloss: 2.69816
# [329]	valid_0's multi_logloss: 2.69805
# [330]	valid_0's multi_logloss: 2.69796
# [331]	valid_0's multi_logloss: 2.6978
# [332]	valid_0's multi_logloss: 2.69777
# [333]	valid_0's multi_logloss: 2.6977
# [334]	valid_0's multi_logloss: 2.69758
# [335]	valid_0's multi_logloss: 2.69748
# [336]	valid_0's multi_logloss: 2.69736
# [337]	valid_0's multi_logloss: 2.69723
# [338]	valid_0's multi_logloss: 2.69716
# [339]	valid_0's multi_logloss: 2.69707
# [340]	valid_0's multi_logloss: 2.69696
# [341]	valid_0's multi_logloss: 2.69683
# [342]	valid_0's multi_logloss: 2.69673
# [343]	valid_0's multi_logloss: 2.69665
# [344]	valid_0's multi_logloss: 2.69657
# [345]	valid_0's multi_logloss: 2.69651
# [346]	valid_0's multi_logloss: 2.69639
# [347]	valid_0's multi_logloss: 2.69634
# [348]	valid_0's multi_logloss: 2.69624
# [349]	valid_0's multi_logloss: 2.69614
# [350]	valid_0's multi_logloss: 2.69609
# [351]	valid_0's multi_logloss: 2.69602
# [352]	valid_0's multi_logloss: 2.69589
# [353]	valid_0's multi_logloss: 2.69584
# [354]	valid_0's multi_logloss: 2.69573
# [355]	valid_0's multi_logloss: 2.69567
# [356]	valid_0's multi_logloss: 2.69561
# [357]	valid_0's multi_logloss: 2.69554
# [358]	valid_0's multi_logloss: 2.69542
# [359]	valid_0's multi_logloss: 2.69535
# [360]	valid_0's multi_logloss: 2.69529
# [361]	valid_0's multi_logloss: 2.69521
# [362]	valid_0's multi_logloss: 2.69514
# [363]	valid_0's multi_logloss: 2.69507
# [364]	valid_0's multi_logloss: 2.69497
# [365]	valid_0's multi_logloss: 2.69491
# [366]	valid_0's multi_logloss: 2.69481
# [367]	valid_0's multi_logloss: 2.69482
# [368]	valid_0's multi_logloss: 2.69473
# [369]	valid_0's multi_logloss: 2.69463
# [370]	valid_0's multi_logloss: 2.69452
# [371]	valid_0's multi_logloss: 2.6945
# [372]	valid_0's multi_logloss: 2.69442
# [373]	valid_0's multi_logloss: 2.69432
# [374]	valid_0's multi_logloss: 2.69429
# [375]	valid_0's multi_logloss: 2.69424
# [376]	valid_0's multi_logloss: 2.69421
# [377]	valid_0's multi_logloss: 2.6941
# [378]	valid_0's multi_logloss: 2.69397
# [379]	valid_0's multi_logloss: 2.6939
# [380]	valid_0's multi_logloss: 2.69382
# [381]	valid_0's multi_logloss: 2.69377
# [382]	valid_0's multi_logloss: 2.69369
# [383]	valid_0's multi_logloss: 2.6936
# [384]	valid_0's multi_logloss: 2.69355
# [385]	valid_0's multi_logloss: 2.69348
# [386]	valid_0's multi_logloss: 2.69341
# [387]	valid_0's multi_logloss: 2.69339
# [388]	valid_0's multi_logloss: 2.69334
# [389]	valid_0's multi_logloss: 2.69325
# [390]	valid_0's multi_logloss: 2.69317
# [391]	valid_0's multi_logloss: 2.6931
# [392]	valid_0's multi_logloss: 2.693
# [393]	valid_0's multi_logloss: 2.69296
# [394]	valid_0's multi_logloss: 2.69293
# [395]	valid_0's multi_logloss: 2.69287
# [396]	valid_0's multi_logloss: 2.69282
# [397]	valid_0's multi_logloss: 2.69275
# [398]	valid_0's multi_logloss: 2.69268
# [399]	valid_0's multi_logloss: 2.69262
# [400]	valid_0's multi_logloss: 2.69261
# [401]	valid_0's multi_logloss: 2.69256
# [402]	valid_0's multi_logloss: 2.69253
# [403]	valid_0's multi_logloss: 2.69256
# [404]	valid_0's multi_logloss: 2.69247
# [405]	valid_0's multi_logloss: 2.69245
# [406]	valid_0's multi_logloss: 2.69235
# [407]	valid_0's multi_logloss: 2.69237
# [408]	valid_0's multi_logloss: 2.69233
# [409]	valid_0's multi_logloss: 2.69232
# [410]	valid_0's multi_logloss: 2.69228
# [411]	valid_0's multi_logloss: 2.69228
# [412]	valid_0's multi_logloss: 2.69225
# [413]	valid_0's multi_logloss: 2.6922
# [414]	valid_0's multi_logloss: 2.69222
# [415]	valid_0's multi_logloss: 2.6922
# [416]	valid_0's multi_logloss: 2.69213
# [417]	valid_0's multi_logloss: 2.69205
# [418]	valid_0's multi_logloss: 2.69191
# [419]	valid_0's multi_logloss: 2.6919
# [420]	valid_0's multi_logloss: 2.69181
# [421]	valid_0's multi_logloss: 2.69179
# [422]	valid_0's multi_logloss: 2.69179
# [423]	valid_0's multi_logloss: 2.69171
# [424]	valid_0's multi_logloss: 2.69165
# [425]	valid_0's multi_logloss: 2.69158
# [426]	valid_0's multi_logloss: 2.69155
# [427]	valid_0's multi_logloss: 2.69154
# [428]	valid_0's multi_logloss: 2.69147
# [429]	valid_0's multi_logloss: 2.69148
# [430]	valid_0's multi_logloss: 2.69147
# [431]	valid_0's multi_logloss: 2.69138
# [432]	valid_0's multi_logloss: 2.69138
# [433]	valid_0's multi_logloss: 2.69137
# [434]	valid_0's multi_logloss: 2.69134
# [435]	valid_0's multi_logloss: 2.69127
# [436]	valid_0's multi_logloss: 2.69123
# [437]	valid_0's multi_logloss: 2.69126
# [438]	valid_0's multi_logloss: 2.69124
# [439]	valid_0's multi_logloss: 2.69123
# [440]	valid_0's multi_logloss: 2.69122
# [441]	valid_0's multi_logloss: 2.69123
# [442]	valid_0's multi_logloss: 2.69123
# [443]	valid_0's multi_logloss: 2.69123
# [444]	valid_0's multi_logloss: 2.69114
# [445]	valid_0's multi_logloss: 2.69112
# [446]	valid_0's multi_logloss: 2.69115
# [447]	valid_0's multi_logloss: 2.69115
# [448]	valid_0's multi_logloss: 2.69111
# [449]	valid_0's multi_logloss: 2.69109
# [450]	valid_0's multi_logloss: 2.69104
# [451]	valid_0's multi_logloss: 2.69098
# [452]	valid_0's multi_logloss: 2.69097
# [453]	valid_0's multi_logloss: 2.69095
# [454]	valid_0's multi_logloss: 2.69098
# [455]	valid_0's multi_logloss: 2.69094
# [456]	valid_0's multi_logloss: 2.69087
# [457]	valid_0's multi_logloss: 2.69087
# [458]	valid_0's multi_logloss: 2.69083
# [459]	valid_0's multi_logloss: 2.69082
# [460]	valid_0's multi_logloss: 2.6908
# [461]	valid_0's multi_logloss: 2.69074
# [462]	valid_0's multi_logloss: 2.69076
# [463]	valid_0's multi_logloss: 2.69074
# [464]	valid_0's multi_logloss: 2.69071
# [465]	valid_0's multi_logloss: 2.69069
# [466]	valid_0's multi_logloss: 2.6907
# [467]	valid_0's multi_logloss: 2.69065
# [468]	valid_0's multi_logloss: 2.69067
# [469]	valid_0's multi_logloss: 2.69068
# [470]	valid_0's multi_logloss: 2.69066
# [471]	valid_0's multi_logloss: 2.69068
# [472]	valid_0's multi_logloss: 2.69065
# [473]	valid_0's multi_logloss: 2.69063
# [474]	valid_0's multi_logloss: 2.69065
# [475]	valid_0's multi_logloss: 2.69062
# [476]	valid_0's multi_logloss: 2.69067
# [477]	valid_0's multi_logloss: 2.69068
# [478]	valid_0's multi_logloss: 2.69074
# [479]	valid_0's multi_logloss: 2.69075
# [480]	valid_0's multi_logloss: 2.6907
# [481]	valid_0's multi_logloss: 2.69073
# [482]	valid_0's multi_logloss: 2.69071
# [483]	valid_0's multi_logloss: 2.69065
# [484]	valid_0's multi_logloss: 2.69063
# [485]	valid_0's multi_logloss: 2.69059
# [486]	valid_0's multi_logloss: 2.69061
# [487]	valid_0's multi_logloss: 2.69064
# [488]	valid_0's multi_logloss: 2.6906
# [489]	valid_0's multi_logloss: 2.69055
# [490]	valid_0's multi_logloss: 2.69059
# [491]	valid_0's multi_logloss: 2.69057
# [492]	valid_0's multi_logloss: 2.6906
# [493]	valid_0's multi_logloss: 2.69055
# [494]	valid_0's multi_logloss: 2.69052
# [495]	valid_0's multi_logloss: 2.69052
# [496]	valid_0's multi_logloss: 2.69052
# [497]	valid_0's multi_logloss: 2.69053
# [498]	valid_0's multi_logloss: 2.69051
# [499]	valid_0's multi_logloss: 2.69057
# [500]	valid_0's multi_logloss: 2.69055
# [501]	valid_0's multi_logloss: 2.69055
# [502]	valid_0's multi_logloss: 2.69056
# [503]	valid_0's multi_logloss: 2.69061
# [504]	valid_0's multi_logloss: 2.69062
# [505]	valid_0's multi_logloss: 2.6906
# [506]	valid_0's multi_logloss: 2.6906
# [507]	valid_0's multi_logloss: 2.69062
# [508]	valid_0's multi_logloss: 2.69055
# Early stopping, best iteration is:
# [498]	valid_0's multi_logloss: 2.69051
# 0.012283518251745252
# [1]	valid_0's multi_logloss: 2.85896
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85706
# [3]	valid_0's multi_logloss: 2.85538
# [4]	valid_0's multi_logloss: 2.85344
# [5]	valid_0's multi_logloss: 2.85161
# [6]	valid_0's multi_logloss: 2.84986
# [7]	valid_0's multi_logloss: 2.84815
# [8]	valid_0's multi_logloss: 2.8465
# [9]	valid_0's multi_logloss: 2.84482
# [10]	valid_0's multi_logloss: 2.84323
# [11]	valid_0's multi_logloss: 2.84158
# [12]	valid_0's multi_logloss: 2.84003
# [13]	valid_0's multi_logloss: 2.83827
# [14]	valid_0's multi_logloss: 2.83682
# [15]	valid_0's multi_logloss: 2.83537
# [16]	valid_0's multi_logloss: 2.83398
# [17]	valid_0's multi_logloss: 2.83258
# [18]	valid_0's multi_logloss: 2.83127
# [19]	valid_0's multi_logloss: 2.83003
# [20]	valid_0's multi_logloss: 2.82867
# [21]	valid_0's multi_logloss: 2.8274
# [22]	valid_0's multi_logloss: 2.82617
# [23]	valid_0's multi_logloss: 2.82502
# [24]	valid_0's multi_logloss: 2.82375
# [25]	valid_0's multi_logloss: 2.82264
# [26]	valid_0's multi_logloss: 2.82142
# [27]	valid_0's multi_logloss: 2.82034
# [28]	valid_0's multi_logloss: 2.81908
# [29]	valid_0's multi_logloss: 2.81795
# [30]	valid_0's multi_logloss: 2.81693
# [31]	valid_0's multi_logloss: 2.81594
# [32]	valid_0's multi_logloss: 2.81491
# [33]	valid_0's multi_logloss: 2.81388
# [34]	valid_0's multi_logloss: 2.81288
# [35]	valid_0's multi_logloss: 2.81197
# [36]	valid_0's multi_logloss: 2.81104
# [37]	valid_0's multi_logloss: 2.80999
# [38]	valid_0's multi_logloss: 2.80904
# [39]	valid_0's multi_logloss: 2.80811
# [40]	valid_0's multi_logloss: 2.80719
# [41]	valid_0's multi_logloss: 2.80633
# [42]	valid_0's multi_logloss: 2.80537
# [43]	valid_0's multi_logloss: 2.80449
# [44]	valid_0's multi_logloss: 2.80356
# [45]	valid_0's multi_logloss: 2.80267
# [46]	valid_0's multi_logloss: 2.80177
# [47]	valid_0's multi_logloss: 2.80099
# [48]	valid_0's multi_logloss: 2.80009
# [49]	valid_0's multi_logloss: 2.79932
# [50]	valid_0's multi_logloss: 2.79847
# [51]	valid_0's multi_logloss: 2.7976
# [52]	valid_0's multi_logloss: 2.7968
# [53]	valid_0's multi_logloss: 2.79591
# [54]	valid_0's multi_logloss: 2.79504
# [55]	valid_0's multi_logloss: 2.79417
# [56]	valid_0's multi_logloss: 2.79337
# [57]	valid_0's multi_logloss: 2.79253
# [58]	valid_0's multi_logloss: 2.7917
# [59]	valid_0's multi_logloss: 2.79088
# [60]	valid_0's multi_logloss: 2.79015
# [61]	valid_0's multi_logloss: 2.78928
# [62]	valid_0's multi_logloss: 2.7885
# [63]	valid_0's multi_logloss: 2.78771
# [64]	valid_0's multi_logloss: 2.78695
# [65]	valid_0's multi_logloss: 2.78619
# [66]	valid_0's multi_logloss: 2.78543
# [67]	valid_0's multi_logloss: 2.78469
# [68]	valid_0's multi_logloss: 2.78399
# [69]	valid_0's multi_logloss: 2.78319
# [70]	valid_0's multi_logloss: 2.78249
# [71]	valid_0's multi_logloss: 2.78175
# [72]	valid_0's multi_logloss: 2.78102
# [73]	valid_0's multi_logloss: 2.78028
# [74]	valid_0's multi_logloss: 2.77963
# [75]	valid_0's multi_logloss: 2.77894
# [76]	valid_0's multi_logloss: 2.77817
# [77]	valid_0's multi_logloss: 2.77757
# [78]	valid_0's multi_logloss: 2.77689
# [79]	valid_0's multi_logloss: 2.7763
# [80]	valid_0's multi_logloss: 2.77566
# [81]	valid_0's multi_logloss: 2.77499
# [82]	valid_0's multi_logloss: 2.77436
# [83]	valid_0's multi_logloss: 2.77369
# [84]	valid_0's multi_logloss: 2.77304
# [85]	valid_0's multi_logloss: 2.77242
# [86]	valid_0's multi_logloss: 2.77178
# [87]	valid_0's multi_logloss: 2.77117
# [88]	valid_0's multi_logloss: 2.77057
# [89]	valid_0's multi_logloss: 2.76997
# [90]	valid_0's multi_logloss: 2.76935
# [91]	valid_0's multi_logloss: 2.76876
# [92]	valid_0's multi_logloss: 2.76818
# [93]	valid_0's multi_logloss: 2.76755
# [94]	valid_0's multi_logloss: 2.76701
# [95]	valid_0's multi_logloss: 2.76643
# [96]	valid_0's multi_logloss: 2.76584
# [97]	valid_0's multi_logloss: 2.76525
# [98]	valid_0's multi_logloss: 2.76467
# [99]	valid_0's multi_logloss: 2.76409
# [100]	valid_0's multi_logloss: 2.76355
# [101]	valid_0's multi_logloss: 2.76298
# [102]	valid_0's multi_logloss: 2.76238
# [103]	valid_0's multi_logloss: 2.76181
# [104]	valid_0's multi_logloss: 2.76128
# [105]	valid_0's multi_logloss: 2.7607
# [106]	valid_0's multi_logloss: 2.7601
# [107]	valid_0's multi_logloss: 2.75954
# [108]	valid_0's multi_logloss: 2.75893
# [109]	valid_0's multi_logloss: 2.75843
# [110]	valid_0's multi_logloss: 2.75787
# [111]	valid_0's multi_logloss: 2.75732
# [112]	valid_0's multi_logloss: 2.75673
# [113]	valid_0's multi_logloss: 2.75617
# [114]	valid_0's multi_logloss: 2.75564
# [115]	valid_0's multi_logloss: 2.75503
# [116]	valid_0's multi_logloss: 2.7545
# [117]	valid_0's multi_logloss: 2.75396
# [118]	valid_0's multi_logloss: 2.75342
# [119]	valid_0's multi_logloss: 2.7529
# [120]	valid_0's multi_logloss: 2.75245
# [121]	valid_0's multi_logloss: 2.75191
# [122]	valid_0's multi_logloss: 2.75142
# [123]	valid_0's multi_logloss: 2.75095
# [124]	valid_0's multi_logloss: 2.75037
# [125]	valid_0's multi_logloss: 2.74984
# [126]	valid_0's multi_logloss: 2.74943
# [127]	valid_0's multi_logloss: 2.7489
# [128]	valid_0's multi_logloss: 2.74851
# [129]	valid_0's multi_logloss: 2.748
# [130]	valid_0's multi_logloss: 2.7475
# [131]	valid_0's multi_logloss: 2.74702
# [132]	valid_0's multi_logloss: 2.74657
# [133]	valid_0's multi_logloss: 2.74617
# [134]	valid_0's multi_logloss: 2.7457
# [135]	valid_0's multi_logloss: 2.74535
# [136]	valid_0's multi_logloss: 2.74492
# [137]	valid_0's multi_logloss: 2.74446
# [138]	valid_0's multi_logloss: 2.74404
# [139]	valid_0's multi_logloss: 2.74367
# [140]	valid_0's multi_logloss: 2.74336
# [141]	valid_0's multi_logloss: 2.74294
# [142]	valid_0's multi_logloss: 2.74255
# [143]	valid_0's multi_logloss: 2.74207
# [144]	valid_0's multi_logloss: 2.74167
# [145]	valid_0's multi_logloss: 2.74135
# [146]	valid_0's multi_logloss: 2.74095
# [147]	valid_0's multi_logloss: 2.74056
# [148]	valid_0's multi_logloss: 2.74009
# [149]	valid_0's multi_logloss: 2.73979
# [150]	valid_0's multi_logloss: 2.7394
# [151]	valid_0's multi_logloss: 2.73898
# [152]	valid_0's multi_logloss: 2.73855
# [153]	valid_0's multi_logloss: 2.73824
# [154]	valid_0's multi_logloss: 2.73785
# [155]	valid_0's multi_logloss: 2.73748
# [156]	valid_0's multi_logloss: 2.73714
# [157]	valid_0's multi_logloss: 2.73678
# [158]	valid_0's multi_logloss: 2.73636
# [159]	valid_0's multi_logloss: 2.73597
# [160]	valid_0's multi_logloss: 2.7357
# [161]	valid_0's multi_logloss: 2.73541
# [162]	valid_0's multi_logloss: 2.73499
# [163]	valid_0's multi_logloss: 2.73468
# [164]	valid_0's multi_logloss: 2.73428
# [165]	valid_0's multi_logloss: 2.73397
# [166]	valid_0's multi_logloss: 2.73368
# [167]	valid_0's multi_logloss: 2.73336
# [168]	valid_0's multi_logloss: 2.73304
# [169]	valid_0's multi_logloss: 2.73268
# [170]	valid_0's multi_logloss: 2.7324
# [171]	valid_0's multi_logloss: 2.73213
# [172]	valid_0's multi_logloss: 2.73179
# [173]	valid_0's multi_logloss: 2.73146
# [174]	valid_0's multi_logloss: 2.73117
# [175]	valid_0's multi_logloss: 2.73084
# [176]	valid_0's multi_logloss: 2.73056
# [177]	valid_0's multi_logloss: 2.73024
# [178]	valid_0's multi_logloss: 2.72993
# [179]	valid_0's multi_logloss: 2.72958
# [180]	valid_0's multi_logloss: 2.72926
# [181]	valid_0's multi_logloss: 2.72896
# [182]	valid_0's multi_logloss: 2.7287
# [183]	valid_0's multi_logloss: 2.72843
# [184]	valid_0's multi_logloss: 2.72814
# [185]	valid_0's multi_logloss: 2.72784
# [186]	valid_0's multi_logloss: 2.72751
# [187]	valid_0's multi_logloss: 2.72726
# [188]	valid_0's multi_logloss: 2.72699
# [189]	valid_0's multi_logloss: 2.72669
# [190]	valid_0's multi_logloss: 2.72646
# [191]	valid_0's multi_logloss: 2.72612
# [192]	valid_0's multi_logloss: 2.72586
# [193]	valid_0's multi_logloss: 2.72558
# [194]	valid_0's multi_logloss: 2.72531
# [195]	valid_0's multi_logloss: 2.72501
# [196]	valid_0's multi_logloss: 2.72471
# [197]	valid_0's multi_logloss: 2.72448
# [198]	valid_0's multi_logloss: 2.7242
# [199]	valid_0's multi_logloss: 2.7239
# [200]	valid_0's multi_logloss: 2.7237
# [201]	valid_0's multi_logloss: 2.72337
# [202]	valid_0's multi_logloss: 2.72315
# [203]	valid_0's multi_logloss: 2.72292
# [204]	valid_0's multi_logloss: 2.72268
# [205]	valid_0's multi_logloss: 2.72245
# [206]	valid_0's multi_logloss: 2.72226
# [207]	valid_0's multi_logloss: 2.72208
# [208]	valid_0's multi_logloss: 2.72187
# [209]	valid_0's multi_logloss: 2.72163
# [210]	valid_0's multi_logloss: 2.72143
# [211]	valid_0's multi_logloss: 2.72125
# [212]	valid_0's multi_logloss: 2.72098
# [213]	valid_0's multi_logloss: 2.72074
# [214]	valid_0's multi_logloss: 2.72059
# [215]	valid_0's multi_logloss: 2.72035
# [216]	valid_0's multi_logloss: 2.72017
# [217]	valid_0's multi_logloss: 2.72002
# [218]	valid_0's multi_logloss: 2.7198
# [219]	valid_0's multi_logloss: 2.71964
# [220]	valid_0's multi_logloss: 2.71941
# [221]	valid_0's multi_logloss: 2.71921
# [222]	valid_0's multi_logloss: 2.719
# [223]	valid_0's multi_logloss: 2.71884
# [224]	valid_0's multi_logloss: 2.71864
# [225]	valid_0's multi_logloss: 2.71847
# [226]	valid_0's multi_logloss: 2.71832
# [227]	valid_0's multi_logloss: 2.71816
# [228]	valid_0's multi_logloss: 2.71798
# [229]	valid_0's multi_logloss: 2.71778
# [230]	valid_0's multi_logloss: 2.71759
# [231]	valid_0's multi_logloss: 2.71732
# [232]	valid_0's multi_logloss: 2.71713
# [233]	valid_0's multi_logloss: 2.71701
# [234]	valid_0's multi_logloss: 2.71686
# [235]	valid_0's multi_logloss: 2.71669
# [236]	valid_0's multi_logloss: 2.71651
# [237]	valid_0's multi_logloss: 2.71633
# [238]	valid_0's multi_logloss: 2.71615
# [239]	valid_0's multi_logloss: 2.71596
# [240]	valid_0's multi_logloss: 2.71583
# [241]	valid_0's multi_logloss: 2.71566
# [242]	valid_0's multi_logloss: 2.71552
# [243]	valid_0's multi_logloss: 2.71536
# [244]	valid_0's multi_logloss: 2.71521
# [245]	valid_0's multi_logloss: 2.71509
# [246]	valid_0's multi_logloss: 2.71494
# [247]	valid_0's multi_logloss: 2.71481
# [248]	valid_0's multi_logloss: 2.71467
# [249]	valid_0's multi_logloss: 2.71455
# [250]	valid_0's multi_logloss: 2.71441
# [251]	valid_0's multi_logloss: 2.71425
# [252]	valid_0's multi_logloss: 2.71415
# [253]	valid_0's multi_logloss: 2.71403
# [254]	valid_0's multi_logloss: 2.71389
# [255]	valid_0's multi_logloss: 2.71373
# [256]	valid_0's multi_logloss: 2.71359
# [257]	valid_0's multi_logloss: 2.7134
# [258]	valid_0's multi_logloss: 2.71326
# [259]	valid_0's multi_logloss: 2.71312
# [260]	valid_0's multi_logloss: 2.71294
# [261]	valid_0's multi_logloss: 2.71282
# [262]	valid_0's multi_logloss: 2.71264
# [263]	valid_0's multi_logloss: 2.71252
# [264]	valid_0's multi_logloss: 2.71237
# [265]	valid_0's multi_logloss: 2.71224
# [266]	valid_0's multi_logloss: 2.71207
# [267]	valid_0's multi_logloss: 2.71193
# [268]	valid_0's multi_logloss: 2.7118
# [269]	valid_0's multi_logloss: 2.71165
# [270]	valid_0's multi_logloss: 2.71148
# [271]	valid_0's multi_logloss: 2.71137
# [272]	valid_0's multi_logloss: 2.71119
# [273]	valid_0's multi_logloss: 2.71106
# [274]	valid_0's multi_logloss: 2.71098
# [275]	valid_0's multi_logloss: 2.71079
# [276]	valid_0's multi_logloss: 2.71068
# [277]	valid_0's multi_logloss: 2.71058
# [278]	valid_0's multi_logloss: 2.71045
# [279]	valid_0's multi_logloss: 2.71025
# [280]	valid_0's multi_logloss: 2.71011
# [281]	valid_0's multi_logloss: 2.70999
# [282]	valid_0's multi_logloss: 2.70989
# [283]	valid_0's multi_logloss: 2.70979
# [284]	valid_0's multi_logloss: 2.70969
# [285]	valid_0's multi_logloss: 2.70955
# [286]	valid_0's multi_logloss: 2.70942
# ...
# [206]	valid_0's multi_logloss: 2.91293
# [207]	valid_0's multi_logloss: 2.91283
# [208]	valid_0's multi_logloss: 2.9127
# [209]	valid_0's multi_logloss: 2.91253
# [210]	valid_0's multi_logloss: 2.91244
# [211]	valid_0's multi_logloss: 2.91223
# [212]	valid_0's multi_logloss: 2.9121
# [213]	valid_0's multi_logloss: 2.912
# [214]	valid_0's multi_logloss: 2.91184
# [215]	valid_0's multi_logloss: 2.91174
# [216]	valid_0's multi_logloss: 2.91168
# [217]	valid_0's multi_logloss: 2.91151
# [218]	valid_0's multi_logloss: 2.91133
# [219]	valid_0's multi_logloss: 2.91124
# [220]	valid_0's multi_logloss: 2.91108
# [221]	valid_0's multi_logloss: 2.91101
# [222]	valid_0's multi_logloss: 2.91091
# [223]	valid_0's multi_logloss: 2.91087
# [224]	valid_0's multi_logloss: 2.91071
# [225]	valid_0's multi_logloss: 2.9106
# [226]	valid_0's multi_logloss: 2.91051
# [227]	valid_0's multi_logloss: 2.91037
# [228]	valid_0's multi_logloss: 2.9103
# [229]	valid_0's multi_logloss: 2.91024
# [230]	valid_0's multi_logloss: 2.91017
# [231]	valid_0's multi_logloss: 2.91007
# [232]	valid_0's multi_logloss: 2.90999
# [233]	valid_0's multi_logloss: 2.9099
# [234]	valid_0's multi_logloss: 2.9099
# [235]	valid_0's multi_logloss: 2.90982
# [236]	valid_0's multi_logloss: 2.90975
# [237]	valid_0's multi_logloss: 2.90963
# [238]	valid_0's multi_logloss: 2.90961
# [239]	valid_0's multi_logloss: 2.90954
# [240]	valid_0's multi_logloss: 2.90948
# [241]	valid_0's multi_logloss: 2.90941
# [242]	valid_0's multi_logloss: 2.90928
# [243]	valid_0's multi_logloss: 2.90925
# [244]	valid_0's multi_logloss: 2.90917
# [245]	valid_0's multi_logloss: 2.90911
# [246]	valid_0's multi_logloss: 2.90911
# [247]	valid_0's multi_logloss: 2.90904
# [248]	valid_0's multi_logloss: 2.90895
# [249]	valid_0's multi_logloss: 2.90886
# [250]	valid_0's multi_logloss: 2.90881
# [251]	valid_0's multi_logloss: 2.90877
# [252]	valid_0's multi_logloss: 2.90868
# [253]	valid_0's multi_logloss: 2.90863
# [254]	valid_0's multi_logloss: 2.90856
# [255]	valid_0's multi_logloss: 2.90851
# [256]	valid_0's multi_logloss: 2.90848
# [257]	valid_0's multi_logloss: 2.90845
# [258]	valid_0's multi_logloss: 2.90839
# [259]	valid_0's multi_logloss: 2.90833
# [260]	valid_0's multi_logloss: 2.90827
# [261]	valid_0's multi_logloss: 2.90827
# [262]	valid_0's multi_logloss: 2.90819
# [263]	valid_0's multi_logloss: 2.90812
# [264]	valid_0's multi_logloss: 2.90808
# [265]	valid_0's multi_logloss: 2.90802
# [266]	valid_0's multi_logloss: 2.90797
# [267]	valid_0's multi_logloss: 2.90795
# [268]	valid_0's multi_logloss: 2.90787
# [269]	valid_0's multi_logloss: 2.90783
# [270]	valid_0's multi_logloss: 2.90782
# [271]	valid_0's multi_logloss: 2.9078
# [272]	valid_0's multi_logloss: 2.90779
# [273]	valid_0's multi_logloss: 2.90777
# [274]	valid_0's multi_logloss: 2.90772
# [275]	valid_0's multi_logloss: 2.90764
# [276]	valid_0's multi_logloss: 2.90759
# [277]	valid_0's multi_logloss: 2.90755
# [278]	valid_0's multi_logloss: 2.90754
# [279]	valid_0's multi_logloss: 2.90753
# [280]	valid_0's multi_logloss: 2.90748
# [281]	valid_0's multi_logloss: 2.90748
# [282]	valid_0's multi_logloss: 2.90749
# [283]	valid_0's multi_logloss: 2.90745
# [284]	valid_0's multi_logloss: 2.90741
# [285]	valid_0's multi_logloss: 2.90736
# [286]	valid_0's multi_logloss: 2.90729
# [287]	valid_0's multi_logloss: 2.90732
# [288]	valid_0's multi_logloss: 2.90723
# [289]	valid_0's multi_logloss: 2.9072
# [290]	valid_0's multi_logloss: 2.90719
# [291]	valid_0's multi_logloss: 2.90715
# [292]	valid_0's multi_logloss: 2.90711
# [293]	valid_0's multi_logloss: 2.90698
# [294]	valid_0's multi_logloss: 2.90699
# [295]	valid_0's multi_logloss: 2.90698
# [296]	valid_0's multi_logloss: 2.9069
# [297]	valid_0's multi_logloss: 2.90684
# [298]	valid_0's multi_logloss: 2.90682
# [299]	valid_0's multi_logloss: 2.90675
# [300]	valid_0's multi_logloss: 2.90676
# [301]	valid_0's multi_logloss: 2.90675
# [302]	valid_0's multi_logloss: 2.90673
# [303]	valid_0's multi_logloss: 2.90669
# [304]	valid_0's multi_logloss: 2.90674
# [305]	valid_0's multi_logloss: 2.90669
# [306]	valid_0's multi_logloss: 2.90664
# [307]	valid_0's multi_logloss: 2.90661
# [308]	valid_0's multi_logloss: 2.90664
# [309]	valid_0's multi_logloss: 2.90668
# [310]	valid_0's multi_logloss: 2.90662
# [311]	valid_0's multi_logloss: 2.90665
# [312]	valid_0's multi_logloss: 2.90661
# [313]	valid_0's multi_logloss: 2.90657
# [314]	valid_0's multi_logloss: 2.9066
# [315]	valid_0's multi_logloss: 2.90662
# [316]	valid_0's multi_logloss: 2.90657
# [317]	valid_0's multi_logloss: 2.90661
# [318]	valid_0's multi_logloss: 2.90667
# [319]	valid_0's multi_logloss: 2.90665
# [320]	valid_0's multi_logloss: 2.90666
# [321]	valid_0's multi_logloss: 2.90666
# [322]	valid_0's multi_logloss: 2.90665
# [323]	valid_0's multi_logloss: 2.90663
# [324]	valid_0's multi_logloss: 2.90667
# [325]	valid_0's multi_logloss: 2.90665
# [326]	valid_0's multi_logloss: 2.90665
# Early stopping, best iteration is:
# [316]	valid_0's multi_logloss: 2.90657
# 0.01430396643999849
# [1]	valid_0's multi_logloss: 2.92636
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.9254
# [3]	valid_0's multi_logloss: 2.92433
# [4]	valid_0's multi_logloss: 2.9234
# [5]	valid_0's multi_logloss: 2.92253
# [6]	valid_0's multi_logloss: 2.92176
# [7]	valid_0's multi_logloss: 2.9209
# [8]	valid_0's multi_logloss: 2.92016
# [9]	valid_0's multi_logloss: 2.91943
# [10]	valid_0's multi_logloss: 2.91864
# [11]	valid_0's multi_logloss: 2.91795
# [12]	valid_0's multi_logloss: 2.91723
# [13]	valid_0's multi_logloss: 2.91653
# [14]	valid_0's multi_logloss: 2.91587
# [15]	valid_0's multi_logloss: 2.91514
# [16]	valid_0's multi_logloss: 2.91448
# [17]	valid_0's multi_logloss: 2.91384
# [18]	valid_0's multi_logloss: 2.91323
# [19]	valid_0's multi_logloss: 2.91253
# [20]	valid_0's multi_logloss: 2.91187
# [21]	valid_0's multi_logloss: 2.91117
# [22]	valid_0's multi_logloss: 2.91073
# [23]	valid_0's multi_logloss: 2.91002
# [24]	valid_0's multi_logloss: 2.90946
# [25]	valid_0's multi_logloss: 2.90892
# [26]	valid_0's multi_logloss: 2.90841
# [27]	valid_0's multi_logloss: 2.90778
# [28]	valid_0's multi_logloss: 2.90722
# [29]	valid_0's multi_logloss: 2.90669
# [30]	valid_0's multi_logloss: 2.90619
# [31]	valid_0's multi_logloss: 2.9057
# [32]	valid_0's multi_logloss: 2.90512
# [33]	valid_0's multi_logloss: 2.90459
# [34]	valid_0's multi_logloss: 2.90414
# [35]	valid_0's multi_logloss: 2.90365
# [36]	valid_0's multi_logloss: 2.90306
# [37]	valid_0's multi_logloss: 2.90257
# [38]	valid_0's multi_logloss: 2.90209
# [39]	valid_0's multi_logloss: 2.90157
# [40]	valid_0's multi_logloss: 2.90113
# [41]	valid_0's multi_logloss: 2.90064
# [42]	valid_0's multi_logloss: 2.90016
# [43]	valid_0's multi_logloss: 2.89967
# [44]	valid_0's multi_logloss: 2.89917
# [45]	valid_0's multi_logloss: 2.89862
# [46]	valid_0's multi_logloss: 2.89805
# [47]	valid_0's multi_logloss: 2.8975
# [48]	valid_0's multi_logloss: 2.8971
# [49]	valid_0's multi_logloss: 2.89661
# [50]	valid_0's multi_logloss: 2.89614
# [51]	valid_0's multi_logloss: 2.89572
# [52]	valid_0's multi_logloss: 2.89522
# [53]	valid_0's multi_logloss: 2.8948
# [54]	valid_0's multi_logloss: 2.89436
# [55]	valid_0's multi_logloss: 2.89387
# [56]	valid_0's multi_logloss: 2.89352
# [57]	valid_0's multi_logloss: 2.8932
# [58]	valid_0's multi_logloss: 2.8928
# [59]	valid_0's multi_logloss: 2.89241
# [60]	valid_0's multi_logloss: 2.89207
# [61]	valid_0's multi_logloss: 2.89169
# [62]	valid_0's multi_logloss: 2.89132
# [63]	valid_0's multi_logloss: 2.89096
# [64]	valid_0's multi_logloss: 2.89072
# [65]	valid_0's multi_logloss: 2.89039
# [66]	valid_0's multi_logloss: 2.88994
# [67]	valid_0's multi_logloss: 2.88968
# [68]	valid_0's multi_logloss: 2.88926
# [69]	valid_0's multi_logloss: 2.88891
# [70]	valid_0's multi_logloss: 2.8886
# [71]	valid_0's multi_logloss: 2.88827
# [72]	valid_0's multi_logloss: 2.8879
# [73]	valid_0's multi_logloss: 2.88753
# [74]	valid_0's multi_logloss: 2.88717
# [75]	valid_0's multi_logloss: 2.88691
# [76]	valid_0's multi_logloss: 2.88649
# [77]	valid_0's multi_logloss: 2.88606
# [78]	valid_0's multi_logloss: 2.88579
# [79]	valid_0's multi_logloss: 2.88536
# [80]	valid_0's multi_logloss: 2.88507
# [81]	valid_0's multi_logloss: 2.88476
# [82]	valid_0's multi_logloss: 2.88443
# [83]	valid_0's multi_logloss: 2.88401
# [84]	valid_0's multi_logloss: 2.88376
# [85]	valid_0's multi_logloss: 2.88351
# [86]	valid_0's multi_logloss: 2.88325
# [87]	valid_0's multi_logloss: 2.88292
# [88]	valid_0's multi_logloss: 2.88266
# [89]	valid_0's multi_logloss: 2.88238
# [90]	valid_0's multi_logloss: 2.88214
# [91]	valid_0's multi_logloss: 2.88179
# [92]	valid_0's multi_logloss: 2.88161
# [93]	valid_0's multi_logloss: 2.88133
# [94]	valid_0's multi_logloss: 2.88104
# [95]	valid_0's multi_logloss: 2.88079
# [96]	valid_0's multi_logloss: 2.88057
# [97]	valid_0's multi_logloss: 2.88029
# [98]	valid_0's multi_logloss: 2.88002
# [99]	valid_0's multi_logloss: 2.87974
# [100]	valid_0's multi_logloss: 2.87948
# [101]	valid_0's multi_logloss: 2.87917
# [102]	valid_0's multi_logloss: 2.8789
# [103]	valid_0's multi_logloss: 2.87863
# [104]	valid_0's multi_logloss: 2.87847
# [105]	valid_0's multi_logloss: 2.87821
# [106]	valid_0's multi_logloss: 2.87796
# [107]	valid_0's multi_logloss: 2.87771
# [108]	valid_0's multi_logloss: 2.87752
# [109]	valid_0's multi_logloss: 2.87729
# [110]	valid_0's multi_logloss: 2.87704
# [111]	valid_0's multi_logloss: 2.87674
# [112]	valid_0's multi_logloss: 2.87653
# [113]	valid_0's multi_logloss: 2.87633
# [114]	valid_0's multi_logloss: 2.87613
# [115]	valid_0's multi_logloss: 2.87592
# [116]	valid_0's multi_logloss: 2.87571
# [117]	valid_0's multi_logloss: 2.87541
# [118]	valid_0's multi_logloss: 2.87525
# [119]	valid_0's multi_logloss: 2.87505
# [120]	valid_0's multi_logloss: 2.87488
# [121]	valid_0's multi_logloss: 2.87462
# [122]	valid_0's multi_logloss: 2.87435
# [123]	valid_0's multi_logloss: 2.87415
# [124]	valid_0's multi_logloss: 2.87401
# [125]	valid_0's multi_logloss: 2.87382
# [126]	valid_0's multi_logloss: 2.87364
# [127]	valid_0's multi_logloss: 2.87347
# [128]	valid_0's multi_logloss: 2.8733
# [129]	valid_0's multi_logloss: 2.87314
# [130]	valid_0's multi_logloss: 2.8729
# [131]	valid_0's multi_logloss: 2.87263
# [132]	valid_0's multi_logloss: 2.87244
# [133]	valid_0's multi_logloss: 2.87227
# [134]	valid_0's multi_logloss: 2.87211
# [135]	valid_0's multi_logloss: 2.87189
# [136]	valid_0's multi_logloss: 2.87165
# [137]	valid_0's multi_logloss: 2.87145
# [138]	valid_0's multi_logloss: 2.87125
# [139]	valid_0's multi_logloss: 2.87102
# [140]	valid_0's multi_logloss: 2.87084
# [141]	valid_0's multi_logloss: 2.8706
# [142]	valid_0's multi_logloss: 2.87047
# [143]	valid_0's multi_logloss: 2.87017
# [144]	valid_0's multi_logloss: 2.86992
# [145]	valid_0's multi_logloss: 2.86972
# [146]	valid_0's multi_logloss: 2.86949
# [147]	valid_0's multi_logloss: 2.86927
# [148]	valid_0's multi_logloss: 2.86909
# [149]	valid_0's multi_logloss: 2.86895
# [150]	valid_0's multi_logloss: 2.86873
# [151]	valid_0's multi_logloss: 2.86846
# [152]	valid_0's multi_logloss: 2.86829
# [153]	valid_0's multi_logloss: 2.86812
# [154]	valid_0's multi_logloss: 2.86794
# [155]	valid_0's multi_logloss: 2.86777
# [156]	valid_0's multi_logloss: 2.86765
# [157]	valid_0's multi_logloss: 2.86741
# [158]	valid_0's multi_logloss: 2.86724
# [159]	valid_0's multi_logloss: 2.86708
# [160]	valid_0's multi_logloss: 2.86688
# [161]	valid_0's multi_logloss: 2.86676
# [162]	valid_0's multi_logloss: 2.86663
# [163]	valid_0's multi_logloss: 2.86645
# [164]	valid_0's multi_logloss: 2.86626
# [165]	valid_0's multi_logloss: 2.8661
# [166]	valid_0's multi_logloss: 2.86594
# [167]	valid_0's multi_logloss: 2.86581
# [168]	valid_0's multi_logloss: 2.8657
# [169]	valid_0's multi_logloss: 2.86549
# [170]	valid_0's multi_logloss: 2.86534
# [171]	valid_0's multi_logloss: 2.8652
# [172]	valid_0's multi_logloss: 2.86505
# [173]	valid_0's multi_logloss: 2.86488
# [174]	valid_0's multi_logloss: 2.86472
# [175]	valid_0's multi_logloss: 2.86462
# [176]	valid_0's multi_logloss: 2.8645
# [177]	valid_0's multi_logloss: 2.86437
# [178]	valid_0's multi_logloss: 2.86418
# [179]	valid_0's multi_logloss: 2.86399
# [180]	valid_0's multi_logloss: 2.86379
# [181]	valid_0's multi_logloss: 2.86364
# [182]	valid_0's multi_logloss: 2.86356
# [183]	valid_0's multi_logloss: 2.86342
# [184]	valid_0's multi_logloss: 2.86329
# [185]	valid_0's multi_logloss: 2.86322
# [186]	valid_0's multi_logloss: 2.86306
# [187]	valid_0's multi_logloss: 2.86298
# [188]	valid_0's multi_logloss: 2.86283
# [189]	valid_0's multi_logloss: 2.86271
# [190]	valid_0's multi_logloss: 2.86257
# [191]	valid_0's multi_logloss: 2.86241
# [192]	valid_0's multi_logloss: 2.86232
# [193]	valid_0's multi_logloss: 2.8622
# [194]	valid_0's multi_logloss: 2.86209
# [195]	valid_0's multi_logloss: 2.86196
# [196]	valid_0's multi_logloss: 2.86187
# [197]	valid_0's multi_logloss: 2.86176
# [198]	valid_0's multi_logloss: 2.86168
# [199]	valid_0's multi_logloss: 2.8616
# [200]	valid_0's multi_logloss: 2.86148
# [201]	valid_0's multi_logloss: 2.86142
# [202]	valid_0's multi_logloss: 2.86137
# [203]	valid_0's multi_logloss: 2.86123
# [204]	valid_0's multi_logloss: 2.86118
# [205]	valid_0's multi_logloss: 2.8611
# [206]	valid_0's multi_logloss: 2.86108
# [207]	valid_0's multi_logloss: 2.861
# [208]	valid_0's multi_logloss: 2.86087
# [209]	valid_0's multi_logloss: 2.86082
# [210]	valid_0's multi_logloss: 2.8607
# [211]	valid_0's multi_logloss: 2.86063
# [212]	valid_0's multi_logloss: 2.86053
# [213]	valid_0's multi_logloss: 2.86045
# [214]	valid_0's multi_logloss: 2.86043
# [215]	valid_0's multi_logloss: 2.86035
# [216]	valid_0's multi_logloss: 2.86032
# [217]	valid_0's multi_logloss: 2.86024
# [218]	valid_0's multi_logloss: 2.8601
# [219]	valid_0's multi_logloss: 2.86
# [220]	valid_0's multi_logloss: 2.85994
# [221]	valid_0's multi_logloss: 2.8599
# [222]	valid_0's multi_logloss: 2.85982
# [223]	valid_0's multi_logloss: 2.85977
# [224]	valid_0's multi_logloss: 2.85976
# [225]	valid_0's multi_logloss: 2.85962
# [226]	valid_0's multi_logloss: 2.85955
# [227]	valid_0's multi_logloss: 2.8595
# [228]	valid_0's multi_logloss: 2.8594
# [229]	valid_0's multi_logloss: 2.85932
# [230]	valid_0's multi_logloss: 2.85928
# [231]	valid_0's multi_logloss: 2.85925
# [232]	valid_0's multi_logloss: 2.85923
# [233]	valid_0's multi_logloss: 2.85914
# [234]	valid_0's multi_logloss: 2.85911
# [235]	valid_0's multi_logloss: 2.85906
# [236]	valid_0's multi_logloss: 2.85901
# [237]	valid_0's multi_logloss: 2.85898
# [238]	valid_0's multi_logloss: 2.85893
# [239]	valid_0's multi_logloss: 2.85891
# [240]	valid_0's multi_logloss: 2.85886
# [241]	valid_0's multi_logloss: 2.85879
# [242]	valid_0's multi_logloss: 2.85873
# [243]	valid_0's multi_logloss: 2.85863
# [244]	valid_0's multi_logloss: 2.85857
# [245]	valid_0's multi_logloss: 2.85851
# [246]	valid_0's multi_logloss: 2.85843
# [247]	valid_0's multi_logloss: 2.85841
# [248]	valid_0's multi_logloss: 2.8584
# [249]	valid_0's multi_logloss: 2.85838
# [250]	valid_0's multi_logloss: 2.85835
# [251]	valid_0's multi_logloss: 2.85835
# [252]	valid_0's multi_logloss: 2.85828
# [253]	valid_0's multi_logloss: 2.85821
# [254]	valid_0's multi_logloss: 2.85816
# [255]	valid_0's multi_logloss: 2.85813
# [256]	valid_0's multi_logloss: 2.85809
# [257]	valid_0's multi_logloss: 2.85807
# [258]	valid_0's multi_logloss: 2.85803
# [259]	valid_0's multi_logloss: 2.85799
# [260]	valid_0's multi_logloss: 2.85799
# [261]	valid_0's multi_logloss: 2.85799
# [262]	valid_0's multi_logloss: 2.85795
# [263]	valid_0's multi_logloss: 2.85795
# [264]	valid_0's multi_logloss: 2.85802
# [265]	valid_0's multi_logloss: 2.85794
# [266]	valid_0's multi_logloss: 2.85793
# [267]	valid_0's multi_logloss: 2.85792
# [268]	valid_0's multi_logloss: 2.85795
# [269]	valid_0's multi_logloss: 2.85792
# [270]	valid_0's multi_logloss: 2.85792
# [271]	valid_0's multi_logloss: 2.85789
# [272]	valid_0's multi_logloss: 2.85787
# [273]	valid_0's multi_logloss: 2.85787
# [274]	valid_0's multi_logloss: 2.85789
# [275]	valid_0's multi_logloss: 2.85791
# [276]	valid_0's multi_logloss: 2.85791
# [277]	valid_0's multi_logloss: 2.85796
# [278]	valid_0's multi_logloss: 2.85798
# [279]	valid_0's multi_logloss: 2.85795
# [280]	valid_0's multi_logloss: 2.858
# [281]	valid_0's multi_logloss: 2.85797
# [282]	valid_0's multi_logloss: 2.85797
# Early stopping, best iteration is:
# [272]	valid_0's multi_logloss: 2.85787
# 0.014111107812111025
# crps list: [0.01251251411522651, 0.012283518251745252, 0.011915633068215076, 0.01430396643999849, 0.014111107812111025]
# average crps: 0.01302534793745927

# %% [markdown]
# - crps list: [0.012512939313856079, 0.012300464489795541, 0.011915838211248257, 0.014302740068327924, 0.014103753559198315]
# - average crps: 0.013027147128485222
# - remove quarter
# - crps list: [0.01251251411522651, 0.012283518251745252, 0.011915633068215076, 0.01430396643999849, 0.014111107812111025]
# - average crps: 0.01302534793745927

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Down',
#        'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'time_quarter', 'time_end', 'handoff_snap_diff', 'Grass',
#        'DefendersInTheBox_vs_Distance', 'runner_height', 'DefenseAveX',
#        'OffenseAveX', 'DefenseAveY', 'OffenseAveY', 'DefenseAveMomentum',
#        'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos', 'RusherVoronoi',
#        'FirstDefenderVoronoi', 'PitchControl'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                           Grass     490     265     261     175     113
# 1                            Team     401     756     541     309     297
# 2               handoff_snap_diff     649     736     981     459     360
# 3                OffenseFormation    1120     775     969     648     414
# 4                            Down     905    1201    1159     664     490
# 5                          Season    1951    1906    2523    1523    1439
# 6               DefendersInTheBox    2393    1541    2388    1921    1574
# 7                DefensePersonnel    2481    3140    2299    1833    1928
# 8                   runner_height    1269    3658    3083    2781    1593
# 9                     StadiumType    3082    4573    3773    1868    1739
# 10               OffensePersonnel    2824    4059    3974    2939    2618
# 11                    GameWeather    3783    3909    4306    3340    1951
# 12            HomeScoreBeforePlay    3474    4998    4113    2122    3239
# 13                       Distance    2929    5689    5786    3637    1309
# 14                           Week    5576    5306    4065    1937    2681
# 15                  RusherVoronoi    4123    4676    5637    3361    2907
# 16                       Location    4666    6369    4233    3880    2675
# 17                      WindSpeed    5635    5329    4460    2878    3633
# 18         VisitorScoreBeforePlay    4474    6256    4370    3818    3308
# 19                            Dis    4904    6346    4191    3561    3469
# 20                    OffenseAveX    3444    6000    6926    3768    2731
# 21                   PlayerWeight    6050    6345    4146    3505    3417
# 22                  WindDirection    6000    7399    5115    3009    2813
# 23                        Stadium    5947    5755    5939    4706    3401
# 24  DefendersInTheBox_vs_Distance    9121    6025    4277    4462    3171
# 25                   JerseyNumber    5859    8120    5652    4456    3134
# 26                    Orientation    6527    6255    6587    3826    4098
# 27                    DefenseAveY    5511    6150    7817    3996    3899
# 28                    OffenseAveY    7103    7858    5188    4037    3322
# 29                              X    6442    6516    6595    3722    4245
# 30                       Humidity    6468    7281    5957    3599    4221
# 31                    Temperature    6466    6759    6175    4135    4146
# 32             OffenseAveMomentum    7348    7335    6016    3720    4299
# 33                              S    7211    7395    5980    3957    5085
# 34                    OffenseStdY    5650    7114    7063    5415    4477
# 35                    DefenseStdY    7479    7344    5976    4712    4308
# 36                    DefenseAveX    6491    7948    7072    6032    3359
# 37         RunnerToDefenseCentoid    6714    7462    7766    5429    4260
# 38                    OffenseStdX    8214    7762    6216    4859    4737
# 39                              Y    7668    9621    7069    4068    3959
# 40                       Momentum    6968    8793    7740    4722    4780
# 41                          NflId    8667    8794    9686    4841    4785
# 42                 OffenseSpreadX    8063   11129    6418    6282    5405
# 43                            Dir    8614    9684    8674    5360    4982
# 44         RunnerToOffenseCentoid    9032   10866    8214    4826    5030
# 45                    DefenseStdX    8836    9977    7820    6945    4884
# 46              PlayerCollegeName    8838    9421    7872    6348    6009
# 47             DefenseAveMomentum    7707   10363    9236    6186    5076
# 48         OffenseStdMomentum_cos    8029   10747    8590    6365    6024
# 49         OffenseAveMomentum_cos   10011   10577   10156    5146    5436
# 50                   time_quarter    8852   12218    9553    5123    5600
# 51                            age   11063    9772    9499    5805    5247
# 52                       YardLine    9960   10879   10079    5847    5946
# 53                 DefenseSpreadX   10151   11517    9716    6374    5683
# 54                       time_end    8785   12804    8760    6442    6814
# 55             DefenseStdMomentum    9087   11199   11487    6533    5479
# 56         DefenseStdMomentum_cos   10557    9730   10929    6720    6262
# 57             OffenseStdMomentum   10090   12298    9848    7300    5954
# 58                        Dir_cos    9946   13212   10774    6254    6001
# 59                  MinTackleTime   11429   13506   10285    5380    7089
# 60              RunnerToScrimmage   10970   13417   10148    7848    5900
# 61                   PitchControl   11699   13049   10621    7335    5756
# 62           FirstDefenderVoronoi   10663   13692   11547    6948    6155
# 63         DefenseAveMomentum_cos   14074   13222   12194    8314    6755
# 64       1stOffenser_Momentum_cos   13097   12752   13097    8903    7238
# 65                   Momentum_cos   13394   13856   14145   10051    8405
# 66       1stDefender_Momentum_cos   13796   15874   14002    9937    8046
# 67                              A   21553   22499   19456   18900   18169
#
#     Average          Std        Cv
# 0     260.8   127.872436  0.490308
# 1     460.8   171.478745  0.372133
# 2     637.0   217.574815  0.341562
# 3     785.2   246.004390  0.313302
# 4     883.8   275.750177  0.312005
# 5    1868.4   384.817671  0.205961
# 6    1963.4   373.280913  0.190120
# 7    2336.2   466.536772  0.199699
# 8    2476.8   905.000862  0.365391
# 9    3007.0  1090.860394  0.362774
# 10   3282.8   608.423997  0.185337
# 11   3457.8   814.015086  0.235414
# 12   3589.2   953.695004  0.265712
# 13   3870.0  1701.664362  0.439707
# 14   3913.0  1424.887504  0.364142
# 15   4140.8   964.958113  0.233037
# 16   4364.6  1201.279751  0.275232
# 17   4387.0  1029.154410  0.234592
# 18   4445.2   997.204573  0.224333
# 19   4494.2  1059.332507  0.235711
# 20   4573.8  1605.525758  0.351027
# 21   4692.6  1257.718665  0.268022
# 22   4867.2  1756.547568  0.360895
# 23   5149.6   987.916110  0.191843
# 24   5411.2  2066.168086  0.381832
# 25   5444.2  1654.612269  0.303922
# 26   5458.6  1230.092127  0.225349
# 27   5474.6  1456.921494  0.266124
# 28   5501.6  1738.456626  0.315991
# 29   5504.0  1253.385336  0.227723
# 30   5505.2  1383.281663  0.251268
# 31   5536.2  1154.456651  0.208529
# 32   5743.6  1507.493363  0.262465
# 33   5925.6  1295.865981  0.218689
# 34   5943.8  1013.846813  0.170572
# 35   5963.8  1304.577234  0.218749
# 36   6180.4  1549.074123  0.250643
# 37   6326.2  1310.542239  0.207161
# 38   6357.6  1436.019303  0.225874
# 39   6477.0  2181.618023  0.336825
# 40   6600.6  1617.625123  0.245072
# 41   7354.6  2104.790783  0.286187
# 42   7459.4  2025.914174  0.271592
# 43   7462.8  1913.224127  0.256368
# 44   7593.6  2340.689950  0.308245
# 45   7692.4  1731.428150  0.225083
# 46   7697.6  1339.688412  0.174040
# 47   7713.6  1930.158605  0.250228
# 48   7951.0  1700.632000  0.213889
# 49   8265.2  2437.258411  0.294882
# 50   8269.2  2630.742207  0.318137
# 51   8277.2  2314.380643  0.279609
# 52   8542.2  2183.433205  0.255605
# 53   8688.2  2262.079344  0.260362
# 54   8721.0  2258.627725  0.258987
# 55   8757.0  2417.297003  0.276042
# 56   8839.6  1961.866112  0.221941
# 57   9098.0  2231.775258  0.245304
# 58   9237.4  2758.102942  0.298580
# 59   9537.8  2938.213022  0.308060
# 60   9656.6  2588.056383  0.268009
# 61   9692.0  2727.932697  0.281462
# 62   9801.0  2841.280204  0.289897
# 63  10911.8  2863.847789  0.262454
# 64  11017.4  2466.287137  0.223854
# 65  11970.2  2311.154811  0.193076
# 66  12331.0  2883.878500  0.233872
# 67  20115.4  1640.043975  0.081532

# %%
#cv_low_feats = list(feature_importance_df[feature_importance_df.Cv <= 0.3]["Feature"])
#X_train_mod = X_train[cv_low_feats]
#n_folds=5
#kf=KFold(n_splits = n_folds, random_state=1108)
#average_crps = 0
##models = []
#crps_scores = []
#lgbm_params = {
#    "objective" : "multiclass",
#    "metric" : "multi_logloss", 
#    "tree_learner": "serial",
#    "max_depth" : -1,
#    "boosting": 'gbdt',
#    "num_class": 199,
#    "num_leaves" : 13,
#    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
#}
#evals_result = {}
#feature_impor = pd.DataFrame(list(X_train_mod.columns), columns=["Feature"])
#for i , (train_index, test_index) in enumerate(kf.split(X_train_mod, y_train)):
#    X_train2= X_train_mod.iloc[train_index,:]
#    y_train2= y_train.iloc[train_index]
#    X_test2= X_train_mod.iloc[test_index,:]
#    y_test2= y_train.iloc[test_index]
#    lgb_train = lgb.Dataset(X_train2, y_train2)
#    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
#    clf = lgb.train(
#        lgbm_params, lgb_train,
#        valid_sets=lgb_eval,
#        num_boost_round=100000,
#        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
#    )
    
    #models.append(clf)
#    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
#    score = simple_crps(y_test2, temp_predict)
#    print(score)
#    crps_scores.append(score)
#    average_crps += score / n_folds
#    feature_impor["Fold_"+str(i+1)] = clf.feature_importance()
    
#feature_impor["Average"] = np.mean(feature_impor.iloc[:,1:n_folds+1], axis=1)
#feature_impor["Std"] = np.std(feature_impor.iloc[:,1:n_folds+1], axis=1)
#feature_impor["Cv"] = feature_impor["Std"] / feature_impor["Average"]
#print('crps list:', crps_scores)
#print('average crps:',average_crps)

# %%
#X_train_mod.columns

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

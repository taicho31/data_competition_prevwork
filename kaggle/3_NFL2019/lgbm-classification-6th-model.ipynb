# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold
import xgboost as xgb
from datetime import datetime
from bayes_opt import BayesianOptimization
from kaggle.competitions import nflrush
import math
import tqdm
from scipy.special import expit
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d, ConvexHull
pd.set_option("display.max_rows",1000)
env = nflrush.make_env()

# %%
def crps_score(y_pred, data):
    y_pred = y_pred.reshape(-1,199)
    y_true = np.array(data.get_label()).astype("int")
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return "CRPS", ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0]), False

def simple_crps(y_true, y_pred):
    y_true_cdf = np.zeros([y_true.shape[0], 199])
    for i, y in enumerate(y_true):
        y_true_cdf[i, y] = 1
    y_true_cdf = np.clip(np.cumsum(y_true_cdf, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true_cdf - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
train = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv',low_memory=False)

# %% [markdown]
# # preprocess and feature engineering

# %%
def transform_time_quarter(str1):
    return int(str1[:2])*60 + int(str1[3:5])
  
def transform_time_all(str1,quarter):
    if quarter<=4:
        return 15*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
    if quarter ==5:
        return 10*60 - (int(str1[:2])*60 + int(str1[3:5])) + (quarter-1)*15*60
      
def back_direction(orientation):
    if orientation > 180.0:
        return 1
    else:
        return 0

def voronoi_volumes(points, selected_index):
    v = Voronoi(points)
    vol = np.zeros(v.npoints)
      
    for i, reg_num in enumerate(v.point_region):
        if reg_num == v.point_region[selected_index]:
            indices = v.regions[reg_num]
            if -1 in indices: # some regions can be opened
                vol = -999 ## insert missing value when the area is open
            else:
                vol = ConvexHull(v.vertices[indices]).volume      
            break
    return vol

def radius_calc(dist_to_ball):
    return 4 + 6 * (dist_to_ball >= 15) + (dist_to_ball ** 3) / 560 * (dist_to_ball < 15)

def compute_influence_to_ball(row):
    point = np.array([row["RushX"], row["RushY"]])
    theta = math.radians(row['Orientation'])
    speed = row['S']
    player_coords = row[['X', 'Y']].values
    dist_to_ball = row["DisToRusher"]    

    S_ratio = (speed / 13) ** 2    # we set max_speed to 13 m/s ((dominance_df["S"]*0.9144).max() #8.64m/s)
    RADIUS = radius_calc(dist_to_ball)  # updated

    S_matrix = np.matrix([[RADIUS * (1 + S_ratio), 0], [0, RADIUS * (1 - S_ratio)]])
    R_matrix = np.matrix([[np.cos(theta), - np.sin(theta)], [np.sin(theta), np.cos(theta)]])
    COV_matrix = np.dot(np.dot(np.dot(R_matrix, S_matrix), S_matrix), np.linalg.inv(R_matrix))
    
    norm_fact = (1 / 2 * np.pi) * (1 / np.sqrt(np.linalg.det(COV_matrix)))    
    mu_play = player_coords + speed * np.array([np.cos(theta), np.sin(theta)]) / 2
    
    intermed_scalar_player = np.dot(np.dot((player_coords - mu_play),
                                    np.linalg.inv(COV_matrix)),
                             np.transpose((player_coords - mu_play)))
    player_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_player[0, 0])
    
    intermed_scalar_point = np.dot(np.dot((point - mu_play), 
                                    np.linalg.inv(COV_matrix)), 
                             np.transpose((point - mu_play)))
    point_influence = norm_fact * np.exp(- 0.5 * intermed_scalar_point[0, 0])
    
    return point_influence / player_influence

# %%
remove_features = ['GameId','PlayId','DisplayName','GameClock','TimeHandoff','TimeSnap', 'PlayDirection', 'TeamOnOffense', 
                    'PlayerBirthDate', 'is_run', 'NflIdRusher', 'date_game', 'RushX', 'RushY', 'PossessionTeam', 
                   'FieldPosition', 'Position', 'PlayerHeight', 'HomeTeamAbbr', 'VisitorTeamAbbr', 'Turf']

# %%
def transform_data(df):
    df.loc[df.VisitorTeamAbbr == "ARI",'VisitorTeamAbbr'] = "ARZ"
    df.loc[df.HomeTeamAbbr == "ARI",'HomeTeamAbbr'] = "ARZ"

    df.loc[df.VisitorTeamAbbr == "BAL",'VisitorTeamAbbr'] = "BLT"
    df.loc[df.HomeTeamAbbr == "BAL",'HomeTeamAbbr'] = "BLT"

    df.loc[df.VisitorTeamAbbr == "CLE",'VisitorTeamAbbr'] = "CLV"
    df.loc[df.HomeTeamAbbr == "CLE",'HomeTeamAbbr'] = "CLV"

    df.loc[df.VisitorTeamAbbr == "HOU",'VisitorTeamAbbr'] = "HST"
    df.loc[df.HomeTeamAbbr == "HOU",'HomeTeamAbbr'] = "HST"

    df['is_run'] = df.NflId == df.NflIdRusher

    if 2017 in list(df["Season"].unique()):
        df.loc[df['Season'] == 2017, 'S'] = (df['S'][df['Season'] == 2017] - 2.4355) / 1.2930 * 1.4551 + 2.7570

    df['ToLeft'] = df.PlayDirection == "left"
    df['TeamOnOffense'] = "home"
    df.loc[df.PossessionTeam != df.HomeTeamAbbr, 'TeamOnOffense'] = "away"
    df['OnOffense'] = df.Team == df.TeamOnOffense 
    df['YardLine_std'] = 100 - df.YardLine.copy()
    df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
            'YardLine_std'
             ] = df.loc[df.FieldPosition.fillna('') == df.PossessionTeam,  
              'YardLine']
    df['X_std'] = df.X.copy()
    df.loc[df.ToLeft, 'X_std'] = 120 - df.loc[df.ToLeft, 'X'] 
    df['Y_std'] = df.Y.copy()
    df.loc[df.ToLeft, 'Y_std'] = 53.3 - df.loc[df.ToLeft, 'Y'] 
    df['Orientation_std'] = df.Orientation.copy()
    df.loc[df.ToLeft, 'Orientation_std'] = np.mod(180 + df.loc[df.ToLeft, 'Orientation_std'], 360)
    df['Dir_std'] = df.Dir.copy()
    df.loc[df.ToLeft, 'Dir_std'] = np.mod(180 + df.loc[df.ToLeft, 'Dir_std'], 360)
    df.loc[df['Season'] == 2017, 'Orientation_std'] = np.mod(90 + df.loc[df['Season'] == 2017, 'Orientation_std'], 360) 
    df.drop(["X", "Y", "Orientation", "YardLine", "Dir", "ToLeft"], axis=1, inplace=True)
    df.rename(columns={'X_std': 'X', 'Y_std': 'Y', 'Orientation_std': 'Orientation', 'Dir_std': 'Dir', "YardLine_std": "YardLine"}, inplace=True)
    
    df['date_game'] = df.GameId.map(lambda x:pd.to_datetime(str(x)[:8]))
    df['age'] = (df.date_game.map(pd.to_datetime) - df.PlayerBirthDate.map(pd.to_datetime)).map(lambda x:x.days)/365

    df["Momentum"] = df["S"] * df["PlayerWeight"]

    #df["F"] = df["A"] * df["PlayerWeight"]

    rusher_x = np.array(df.groupby(["PlayId", "is_run"])["X"].agg(np.mean)[1::2])
    df["RushX"] = np.repeat(rusher_x, 22) # repeat each elemnt 22 times
    rusher_y = np.array(df.groupby(["PlayId", "is_run"])["Y"].agg(np.mean)[1::2])
    df["RushY"] = np.repeat(rusher_y, 22) 
    df["DisToRusher"] = np.sqrt((df["X"] - df["RushX"]) ** 2 + (df["Y"] - df["RushY"]) ** 2)
    df["TackleTimeToRusher"] = df["DisToRusher"] / df["S"] # includes nan when the speed of rusher is 0
    #df.loc[df.is_run==True, "TackleTimeToRusher"] = 0
    
    df["InfluToBall"] = df.apply(compute_influence_to_ball, axis=1)

    #df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.cos((450-x) * np.pi/ 180))
    #df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.sin((450-x) * np.pi/ 180))
    
    df["Momentum_cos"] = df["Momentum"] * df["Dir_cos"]
    #df["Momentum_sin"] = df["Momentum"] * df["Dir_sin"]

    #rusher_s = np.array(df.groupby(["PlayId", "is_run"]).agg(np.mean)["S"][1::2])
    #rusher_s[rusher_s == 0] = 1e-15 # replace velocity 0 with very small values
    #rusher_s = np.repeat(rusher_s, 22)
    #df["RatioSToRusher"] = df["S"] / rusher_s
    #df.loc[df.is_run==True, "RatioSToRusher"] = 1

    df_single = df[df.is_run==True].copy()
    
    #df_single["NecDisPerDown"] = df_single["Distance"] / (5 - df_single["Down"])
        
    df_single['time_quarter'] = df_single.GameClock.map(lambda x:transform_time_quarter(x))
    df_single['time_end'] = df_single.apply(lambda x:transform_time_all(x.loc['GameClock'],x.loc['Quarter']),axis=1)

    df_single["Stadium"] = df_single["Stadium"].map(lambda x: "Broncos Stadium at Mile High" if x=="Broncos Stadium At Mile High" 
                                             else ("CenturyLink Field" if x == "CenturyField" or x == x=="CenturyLink"
                                             else ("Everbank Field" if x == "EverBank Field"
                                             else ("FirstEnergy Stadium" if x =="First Energy Stadium" or x=="FirstEnergy" or x == "FirstEnergyStadium"
                                             else ("Lambeau Field" if x == "Lambeau field"
                                             else ("Los Angeles Memorial Coliseum" if x == "Los Angeles Memorial Coliesum"
                                             else ("M&T Bank Stadium" if x == "M & T Bank Stadium" or x == "M&T Stadium"
                                             else ("Mercedes-Benz Superdome" if x == "Mercedes-Benz Dome"
                                             else ("MetLife Stadium" if x == "MetLife" or x == "Metlife Stadium"
                                             else ("NRG Stadium" if x == "NRG"
                                             else ("Oakland-Alameda County Coliseum" if x == "Oakland Alameda-County Coliseum"
                                             else ("Paul Brown Stadium" if x == "Paul Brown Stdium"
                                             else ("Twickenham Stadium" if x == "Twickenham" else x)))))))))))))
                                             #"State Farm Stadium" if x == "University of Phoenix Stadium"
                                             #"Empower Field at Mile High" if x == "Sports Authority Field at Mile High" or x == "Broncos Stadium at Mile High" 

    df_single["Location"] = df_single["Location"].map(lambda x: "Arlington, TX" if x == "Arlington, Texas"
                                            else ("Baltimore, MD" if x == "Baltimore, Maryland" or x == "Baltimore, Md."
                                            else ("Charlotte, NC" if x == "Charlotte, North Carolina"
                                            else ("Chicago, IL" if x == "Chicago. IL"
                                            else ("Cincinnati, OH" if x == "Cincinnati, Ohio"
                                            else ("Cleveland, OH" if x == "Cleveland" or x == "Cleveland Ohio" or x == "Cleveland, Ohio" or x == "Cleveland,Ohio"
                                            else ("Detroit, MI" if x == "Detroit"
                                            else ("East Rutherford, NJ" if x == "E. Rutherford, NJ" or x == "East Rutherford, N.J."
                                            else ("Foxborough, MA" if x == "Foxborough, Ma"
                                            else ("Houston, TX" if x == "Houston, Texas"
                                            else ("Jacksonville, FL" if x == "Jacksonville Florida" or x == "Jacksonville, Fl" or x == "Jacksonville, Florida"
                                            else ("London" if x == "London, England"
                                            else ("Los Angeles, CA" if x == "Los Angeles, Calif."
                                            else ("Miami Gardens, FLA" if x == "Miami Gardens, Fla."
                                            else ("New Orleans, LA" if x == "New Orleans" or x == "New Orleans, La."
                                            else ("Orchard Park, NY" if x == "Orchard Park NY"
                                            else ("Philadelphia, PA" if x == "Philadelphia, Pa."
                                            else ("Pittsburgh, PA" if x == "Pittsburgh"
                                            else ("Seattle, WA" if x == "Seattle" else x)))))))))))))))))))

    grass_labels = ['grass', 'natural grass', 'natural', 'naturall grass']
    df_single['Grass'] = np.where(df_single.Turf.str.lower().isin(grass_labels), "Natural", "Artificial")
                                                                 
    #top20_weather = list(df.GameWeather.value_counts(normalize=True, dropna=False).cumsum().head(20).index)
    #df_single["GameWeather"] = df_single["GameWeather"].apply(lambda x: "Others" if x not in top20_weather else x)
                                                                 
    df_single["OffenseFormation"] = df_single["OffenseFormation"].fillna("Unknown") 
    df_single['DefendersInTheBox_vs_Distance'] = df_single['DefendersInTheBox'] / df_single['Distance']
                                                                 
    #df_single['back_oriented_down_field'] = df_single['Orientation'].apply(lambda x: back_direction(x))
    #df_single['back_moving_down_field'] = df_single['Dir'].apply(lambda x: back_direction(x))

    #arr = [[int(s[0]) for s in t.split(", ")] for t in df_single["DefensePersonnel"]]
    #df_single["DefenseDL"] = np.array([a[0] for a in arr])
    #df_single["DefenseLB"] = np.array([a[1] for a in arr])
    #df_single["DefenseDB"] = np.array([a[2] for a in arr])
    #df_single["DefenseOL"] = np.array([a[3] if len(a) == 4 else 0 for a in arr])
  
    #df_single["OffenseRB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" RB")[0][-1]) if "RB" in x else 0)
    #df_single["OffenseTE"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" TE")[0][-1]) if "TE" in x else 0)
    #df_single["OffenseWR"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" WR")[0][-1]) if "WR" in x else 0)
    #df_single["OffenseOL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" OL")[0][-1]) if "OL" in x else 0)
    #df_single["OffenseDL"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" DL")[0][-1]) if "DL" in x else 0)
    #df_single["OffenseQB"] = df_single["OffensePersonnel"].apply(lambda x: 
    #                        int(x.replace(",", "").split(" QB")[0][-1]) if "QB" in x else 0)
  
    #df_single["DisToQB"] = np.array(df[(df.Position=="QB") | (df.Position=="C")].groupby(["PlayId"]).agg(np.mean)["DisToRusher"])

    df_single["OffenseFormation"] = df_single["OffenseFormation"].apply(lambda x: "SHOTGUN" if x== "ACE" else x)

    #df_single["Margin"] = df_single["HomeScoreBeforePlay"] - df_single["VisitorScoreBeforePlay"]
    #df_single.loc[df_single['Team'] == "away", 'Margin'] = (df_single['VisitorScoreBeforePlay'][df_single['Team'] == "away"] - df_single['HomeScoreBeforePlay'][df_single['Team'] == "away"])

    df_single.drop(remove_features,axis=1,inplace=True) 

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(np.mean)[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseAveX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseAveX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseAveY"] = np.array(tmp[0::2]["Y"]) 
    df_single["OffenseAveY"] = np.array(tmp[1::2]["Y"]) 
    df_single["DefenseAveMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseAveMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseAveMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseAveMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    #df_single["DefenseAveAge"] = np.array(tmp[0::2]["age"])
    #df_single["OffenseAveAge"] = np.array(tmp[1::2]["age"])

    tmp = df.groupby(["PlayId", "OnOffense"]).agg(["std"])[["X", "Y", "Momentum", "Momentum_cos"]]
    df_single["DefenseStdX"] = np.array(tmp[0::2]["X"])
    df_single["OffenseStdX"] = np.array(tmp[1::2]["X"])
    df_single["DefenseStdY"] = np.array(tmp[0::2]["Y"])
    df_single["OffenseStdY"] = np.array(tmp[1::2]["Y"])
    df_single["DefenseStdMomentum"] = np.array(tmp[0::2]["Momentum"])
    df_single["OffenseStdMomentum"] = np.array(tmp[1::2]["Momentum"])
    df_single["DefenseStdMomentum_cos"] = np.array(tmp[0::2]["Momentum_cos"])
    df_single["OffenseStdMomentum_cos"] = np.array(tmp[1::2]["Momentum_cos"])
    
    df_single["RunnerToDefenseCentoid"] = np.sqrt((df_single["X"] - df_single["DefenseAveX"]) ** 2 + (df_single["Y"] - df_single["DefenseAveY"]) ** 2)
    df_single["RunnerToOffenseCentoid"] = np.sqrt((df_single["X"] - df_single["OffenseAveX"]) ** 2 + (df_single["Y"] - df_single["OffenseAveY"]) ** 2)

    tmp_max = df.groupby(["PlayId", "OnOffense"])["X"].max()
    tmp_min = df.groupby(["PlayId", "OnOffense"])["X"].min()
    df_single["DefenseSpreadX"] = np.array(tmp_max[0::2]- tmp_min[0::2])
    df_single["OffenseSpreadX"] = np.array(tmp_max[1::2]- tmp_min[1::2])

    #df_single["RunnerToScrimmage"] = df_single["X"] - df_single["YardLine"]
    df_single["RunnerToScrimmage"] = df_single["X"] - (df_single["YardLine"] + 10)

    df_single["MinTackleTime"] = np.array(df.groupby(["PlayId", "OnOffense"])["TackleTimeToRusher"].min()[0::2])
    df_single["1stDefender_Momentum_cos"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_cos"])
    first_offenser_index =df.groupby(["PlayId", "OnOffense"])["DisToRusher"].nsmallest(2)[3::4].reset_index()["level_2"]
    df_single["1stOffenser_Momentum_cos"] = np.array(df.loc[first_offenser_index]["Momentum_cos"])
    #df_single["1stDefender_Momentum_sin"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["Momentum_sin"])
    #df_single["1stDefender_A"] = np.array(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["A"])

    #df_single["Rusher1stDefSpeedRatio"] = df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]]["RatioSToRusher"]

    pts = np.array(df[["X", "Y"]]).reshape(df.shape[0]//22, 22, 2) # plays * players * (X, Y, rusher)
    rusher_index = list(df[df.is_run==True].index % 22) 
    closest_def_index = list(df.loc[df.groupby(["PlayId", "OnOffense"])["DisToRusher"].idxmin()[0::2]].index % 22)
    #closest_off_index = list(first_offenser_index % 22)
    rusher_voronoi = []
    closest_def_voronoi = []
    #closest_off_voronoi = []

    for i in range(0, df.shape[0] //22):
        rusher_voronoi.append(voronoi_volumes(pts[i], rusher_index[i]))
        closest_def_voronoi.append(voronoi_volumes(pts[i], closest_def_index[i]))
        #closest_off_voronoi.append(voronoi_volumes(pts[i], closest_off_index[i]))
    df_single["RusherVoronoi"] = rusher_voronoi    
    df_single["FirstDefenderVoronoi"] = closest_def_voronoi 
    #df_single["FirstOffenserVoronoi"] = closest_off_voronoi
    
    def_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][0::2])
    off_influ = np.array(df.groupby(["PlayId", "OnOffense"]).agg("sum")["InfluToBall"][1::2])
    df_single["PitchControl"] = expit(off_influ - def_influ)
    
    df_single.fillna(-999,inplace=True) 
    remove_features2 = ["OnOffense", "DisToRusher", "InfluToBall", "TackleTimeToRusher", "OffenseAveX", "OffenseAveY"]#, "RatioSToRusher"]
    df_single.drop(remove_features2, axis=1, inplace=True)

    return df_single

# %%
# %%time
train_single = transform_data(train)
y_train = train_single.Yards + 99 # to categorize
X_train = train_single.drop(['Yards'],axis=1)
for f in X_train.columns:
    if X_train[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f])+[-999])
        X_train[f] = lbl.transform(list(X_train[f]))
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# CPU times: user 17min 9s, sys: 7.6 s, total: 17min 17s
# Wall time: 17min 14s

# %% [markdown]
# # modelling

# %%
n_folds=5
kf=KFold(n_splits = n_folds, random_state=1108)
average_crps = 0
models = []
crps_scores = []
lgbm_params = {
    "objective" : "multiclass",
    "metric" : "multi_logloss", 
    "tree_learner": "serial",
    "max_depth" : -1,
    "boosting": 'gbdt',
    "num_class": 199,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
}
evals_result = {}
feature_importance_df = pd.DataFrame(list(X_train.columns), columns=["Feature"])
for i , (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
    X_train2= X_train.iloc[train_index,:]
    y_train2= y_train.iloc[train_index]
    X_test2= X_train.iloc[test_index,:]
    y_test2= y_train.iloc[test_index]
    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
    clf = lgb.train(
        lgbm_params, lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=100000,
        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
    )
    
    models.append(clf)
    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
    score = simple_crps(y_test2, temp_predict)
    print(score)
    crps_scores.append(score)
    average_crps += score / n_folds
    feature_importance_df["Fold_"+str(i+1)] = clf.feature_importance()
    
feature_importance_df["Average"] = np.mean(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Std"] = np.std(feature_importance_df.iloc[:,1:n_folds+1], axis=1)
feature_importance_df["Cv"] = feature_importance_df["Std"] / feature_importance_df["Average"]
print('crps list:', crps_scores)
print('average crps:',average_crps)
# Out:
# [1]	valid_0's multi_logloss: 2.86914
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.86672
# [3]	valid_0's multi_logloss: 2.8644
# [4]	valid_0's multi_logloss: 2.86221
# [5]	valid_0's multi_logloss: 2.86006
# [6]	valid_0's multi_logloss: 2.85803
# [7]	valid_0's multi_logloss: 2.85633
# [8]	valid_0's multi_logloss: 2.85468
# [9]	valid_0's multi_logloss: 2.85297
# [10]	valid_0's multi_logloss: 2.85122
# [11]	valid_0's multi_logloss: 2.84949
# [12]	valid_0's multi_logloss: 2.84769
# [13]	valid_0's multi_logloss: 2.84612
# [14]	valid_0's multi_logloss: 2.84439
# [15]	valid_0's multi_logloss: 2.84296
# [16]	valid_0's multi_logloss: 2.84137
# [17]	valid_0's multi_logloss: 2.83983
# [18]	valid_0's multi_logloss: 2.83843
# [19]	valid_0's multi_logloss: 2.83701
# [20]	valid_0's multi_logloss: 2.83561
# [21]	valid_0's multi_logloss: 2.83431
# [22]	valid_0's multi_logloss: 2.83294
# [23]	valid_0's multi_logloss: 2.83162
# [24]	valid_0's multi_logloss: 2.8302
# [25]	valid_0's multi_logloss: 2.82886
# [26]	valid_0's multi_logloss: 2.82757
# [27]	valid_0's multi_logloss: 2.8262
# [28]	valid_0's multi_logloss: 2.82496
# [29]	valid_0's multi_logloss: 2.82371
# [30]	valid_0's multi_logloss: 2.82246
# [31]	valid_0's multi_logloss: 2.82125
# [32]	valid_0's multi_logloss: 2.82006
# [33]	valid_0's multi_logloss: 2.81881
# [34]	valid_0's multi_logloss: 2.8177
# [35]	valid_0's multi_logloss: 2.8166
# [36]	valid_0's multi_logloss: 2.81549
# [37]	valid_0's multi_logloss: 2.81442
# [38]	valid_0's multi_logloss: 2.81322
# [39]	valid_0's multi_logloss: 2.81211
# [40]	valid_0's multi_logloss: 2.81111
# [41]	valid_0's multi_logloss: 2.80997
# [42]	valid_0's multi_logloss: 2.80893
# [43]	valid_0's multi_logloss: 2.80771
# [44]	valid_0's multi_logloss: 2.80663
# [45]	valid_0's multi_logloss: 2.80557
# [46]	valid_0's multi_logloss: 2.80461
# [47]	valid_0's multi_logloss: 2.80371
# [48]	valid_0's multi_logloss: 2.80268
# [49]	valid_0's multi_logloss: 2.80179
# [50]	valid_0's multi_logloss: 2.80086
# [51]	valid_0's multi_logloss: 2.79992
# [52]	valid_0's multi_logloss: 2.79882
# [53]	valid_0's multi_logloss: 2.79779
# [54]	valid_0's multi_logloss: 2.79689
# [55]	valid_0's multi_logloss: 2.79603
# [56]	valid_0's multi_logloss: 2.79513
# [57]	valid_0's multi_logloss: 2.79404
# [58]	valid_0's multi_logloss: 2.79304
# [59]	valid_0's multi_logloss: 2.79216
# [60]	valid_0's multi_logloss: 2.79106
# [61]	valid_0's multi_logloss: 2.79024
# [62]	valid_0's multi_logloss: 2.78924
# [63]	valid_0's multi_logloss: 2.78839
# [64]	valid_0's multi_logloss: 2.78739
# [65]	valid_0's multi_logloss: 2.7865
# [66]	valid_0's multi_logloss: 2.78549
# [67]	valid_0's multi_logloss: 2.78463
# [68]	valid_0's multi_logloss: 2.78386
# [69]	valid_0's multi_logloss: 2.78289
# [70]	valid_0's multi_logloss: 2.78207
# [71]	valid_0's multi_logloss: 2.7812
# [72]	valid_0's multi_logloss: 2.78048
# [73]	valid_0's multi_logloss: 2.77959
# [74]	valid_0's multi_logloss: 2.77875
# [75]	valid_0's multi_logloss: 2.77772
# [76]	valid_0's multi_logloss: 2.7769
# [77]	valid_0's multi_logloss: 2.77604
# [78]	valid_0's multi_logloss: 2.77525
# [79]	valid_0's multi_logloss: 2.77445
# [80]	valid_0's multi_logloss: 2.77361
# [81]	valid_0's multi_logloss: 2.77282
# [82]	valid_0's multi_logloss: 2.77197
# [83]	valid_0's multi_logloss: 2.7713
# [84]	valid_0's multi_logloss: 2.7705
# [85]	valid_0's multi_logloss: 2.76969
# [86]	valid_0's multi_logloss: 2.76882
# [87]	valid_0's multi_logloss: 2.768
# [88]	valid_0's multi_logloss: 2.76737
# [89]	valid_0's multi_logloss: 2.76662
# [90]	valid_0's multi_logloss: 2.76589
# [91]	valid_0's multi_logloss: 2.76512
# [92]	valid_0's multi_logloss: 2.76438
# [93]	valid_0's multi_logloss: 2.7636
# [94]	valid_0's multi_logloss: 2.76295
# [95]	valid_0's multi_logloss: 2.76232
# [96]	valid_0's multi_logloss: 2.76146
# [97]	valid_0's multi_logloss: 2.76089
# [98]	valid_0's multi_logloss: 2.76014
# [99]	valid_0's multi_logloss: 2.75957
# [100]	valid_0's multi_logloss: 2.75888
# [101]	valid_0's multi_logloss: 2.75817
# [102]	valid_0's multi_logloss: 2.75751
# [103]	valid_0's multi_logloss: 2.75696
# [104]	valid_0's multi_logloss: 2.75631
# [105]	valid_0's multi_logloss: 2.7558
# [106]	valid_0's multi_logloss: 2.75526
# [107]	valid_0's multi_logloss: 2.75465
# [108]	valid_0's multi_logloss: 2.75401
# [109]	valid_0's multi_logloss: 2.75346
# [110]	valid_0's multi_logloss: 2.75285
# [111]	valid_0's multi_logloss: 2.75227
# [112]	valid_0's multi_logloss: 2.75165
# [113]	valid_0's multi_logloss: 2.75108
# [114]	valid_0's multi_logloss: 2.75054
# [115]	valid_0's multi_logloss: 2.75004
# [116]	valid_0's multi_logloss: 2.74939
# [117]	valid_0's multi_logloss: 2.74884
# [118]	valid_0's multi_logloss: 2.74823
# [119]	valid_0's multi_logloss: 2.74764
# [120]	valid_0's multi_logloss: 2.74721
# [121]	valid_0's multi_logloss: 2.7467
# [122]	valid_0's multi_logloss: 2.74624
# [123]	valid_0's multi_logloss: 2.7457
# [124]	valid_0's multi_logloss: 2.74517
# [125]	valid_0's multi_logloss: 2.74466
# [126]	valid_0's multi_logloss: 2.74416
# [127]	valid_0's multi_logloss: 2.74354
# [128]	valid_0's multi_logloss: 2.74302
# [129]	valid_0's multi_logloss: 2.74256
# [130]	valid_0's multi_logloss: 2.74208
# [131]	valid_0's multi_logloss: 2.74167
# [132]	valid_0's multi_logloss: 2.74121
# [133]	valid_0's multi_logloss: 2.74072
# [134]	valid_0's multi_logloss: 2.74022
# [135]	valid_0's multi_logloss: 2.73978
# [136]	valid_0's multi_logloss: 2.73937
# [137]	valid_0's multi_logloss: 2.73875
# [138]	valid_0's multi_logloss: 2.73827
# [139]	valid_0's multi_logloss: 2.73781
# [140]	valid_0's multi_logloss: 2.73739
# [141]	valid_0's multi_logloss: 2.73691
# [142]	valid_0's multi_logloss: 2.73645
# [143]	valid_0's multi_logloss: 2.73602
# [144]	valid_0's multi_logloss: 2.73556
# [145]	valid_0's multi_logloss: 2.73514
# [146]	valid_0's multi_logloss: 2.73467
# [147]	valid_0's multi_logloss: 2.73416
# [148]	valid_0's multi_logloss: 2.73376
# [149]	valid_0's multi_logloss: 2.73336
# [150]	valid_0's multi_logloss: 2.73285
# [151]	valid_0's multi_logloss: 2.73241
# [152]	valid_0's multi_logloss: 2.732
# [153]	valid_0's multi_logloss: 2.73167
# [154]	valid_0's multi_logloss: 2.73124
# [155]	valid_0's multi_logloss: 2.73077
# [156]	valid_0's multi_logloss: 2.73036
# [157]	valid_0's multi_logloss: 2.72995
# [158]	valid_0's multi_logloss: 2.72948
# [159]	valid_0's multi_logloss: 2.72907
# [160]	valid_0's multi_logloss: 2.72861
# [161]	valid_0's multi_logloss: 2.72827
# [162]	valid_0's multi_logloss: 2.72773
# [163]	valid_0's multi_logloss: 2.72742
# [164]	valid_0's multi_logloss: 2.72697
# [165]	valid_0's multi_logloss: 2.72659
# [166]	valid_0's multi_logloss: 2.72631
# [167]	valid_0's multi_logloss: 2.72592
# [168]	valid_0's multi_logloss: 2.72548
# [169]	valid_0's multi_logloss: 2.72509
# [170]	valid_0's multi_logloss: 2.72476
# [171]	valid_0's multi_logloss: 2.72442
# [172]	valid_0's multi_logloss: 2.72411
# [173]	valid_0's multi_logloss: 2.72373
# [174]	valid_0's multi_logloss: 2.72339
# [175]	valid_0's multi_logloss: 2.72306
# [176]	valid_0's multi_logloss: 2.72271
# [177]	valid_0's multi_logloss: 2.72236
# [178]	valid_0's multi_logloss: 2.72201
# [179]	valid_0's multi_logloss: 2.7216
# [180]	valid_0's multi_logloss: 2.72121
# [181]	valid_0's multi_logloss: 2.72097
# [182]	valid_0's multi_logloss: 2.72067
# [183]	valid_0's multi_logloss: 2.72036
# [184]	valid_0's multi_logloss: 2.72007
# [185]	valid_0's multi_logloss: 2.71974
# [186]	valid_0's multi_logloss: 2.71938
# [187]	valid_0's multi_logloss: 2.71907
# [188]	valid_0's multi_logloss: 2.71882
# [189]	valid_0's multi_logloss: 2.71856
# [190]	valid_0's multi_logloss: 2.71823
# [191]	valid_0's multi_logloss: 2.71794
# [192]	valid_0's multi_logloss: 2.71769
# [193]	valid_0's multi_logloss: 2.71747
# [194]	valid_0's multi_logloss: 2.71716
# [195]	valid_0's multi_logloss: 2.7169
# [196]	valid_0's multi_logloss: 2.71673
# [197]	valid_0's multi_logloss: 2.71646
# [198]	valid_0's multi_logloss: 2.71619
# [199]	valid_0's multi_logloss: 2.71597
# [200]	valid_0's multi_logloss: 2.71574
# [201]	valid_0's multi_logloss: 2.71552
# [202]	valid_0's multi_logloss: 2.71527
# [203]	valid_0's multi_logloss: 2.71501
# [204]	valid_0's multi_logloss: 2.71475
# [205]	valid_0's multi_logloss: 2.71456
# [206]	valid_0's multi_logloss: 2.71434
# [207]	valid_0's multi_logloss: 2.71409
# [208]	valid_0's multi_logloss: 2.71384
# [209]	valid_0's multi_logloss: 2.71364
# [210]	valid_0's multi_logloss: 2.7134
# [211]	valid_0's multi_logloss: 2.71315
# [212]	valid_0's multi_logloss: 2.71286
# [213]	valid_0's multi_logloss: 2.71263
# [214]	valid_0's multi_logloss: 2.7124
# [215]	valid_0's multi_logloss: 2.71218
# [216]	valid_0's multi_logloss: 2.71196
# [217]	valid_0's multi_logloss: 2.71175
# [218]	valid_0's multi_logloss: 2.71153
# [219]	valid_0's multi_logloss: 2.71132
# [220]	valid_0's multi_logloss: 2.71117
# [221]	valid_0's multi_logloss: 2.71091
# [222]	valid_0's multi_logloss: 2.71072
# [223]	valid_0's multi_logloss: 2.71048
# [224]	valid_0's multi_logloss: 2.71024
# [225]	valid_0's multi_logloss: 2.71006
# [226]	valid_0's multi_logloss: 2.70989
# [227]	valid_0's multi_logloss: 2.70969
# [228]	valid_0's multi_logloss: 2.70948
# [229]	valid_0's multi_logloss: 2.70932
# [230]	valid_0's multi_logloss: 2.7091
# [231]	valid_0's multi_logloss: 2.70889
# [232]	valid_0's multi_logloss: 2.70875
# [233]	valid_0's multi_logloss: 2.70857
# [234]	valid_0's multi_logloss: 2.70837
# [235]	valid_0's multi_logloss: 2.7082
# [236]	valid_0's multi_logloss: 2.70802
# [237]	valid_0's multi_logloss: 2.70787
# [238]	valid_0's multi_logloss: 2.70765
# [239]	valid_0's multi_logloss: 2.70745
# [240]	valid_0's multi_logloss: 2.70722
# [241]	valid_0's multi_logloss: 2.70701
# [242]	valid_0's multi_logloss: 2.70686
# [243]	valid_0's multi_logloss: 2.70666
# [244]	valid_0's multi_logloss: 2.70647
# [245]	valid_0's multi_logloss: 2.70628
# [246]	valid_0's multi_logloss: 2.70611
# [247]	valid_0's multi_logloss: 2.70596
# [248]	valid_0's multi_logloss: 2.70582
# [249]	valid_0's multi_logloss: 2.70561
# [250]	valid_0's multi_logloss: 2.70545
# [251]	valid_0's multi_logloss: 2.7053
# [252]	valid_0's multi_logloss: 2.70515
# [253]	valid_0's multi_logloss: 2.70498
# [254]	valid_0's multi_logloss: 2.70476
# [255]	valid_0's multi_logloss: 2.70467
# [256]	valid_0's multi_logloss: 2.7045
# [257]	valid_0's multi_logloss: 2.70441
# [258]	valid_0's multi_logloss: 2.70432
# [259]	valid_0's multi_logloss: 2.70416
# [260]	valid_0's multi_logloss: 2.70405
# [261]	valid_0's multi_logloss: 2.70388
# [262]	valid_0's multi_logloss: 2.70376
# [263]	valid_0's multi_logloss: 2.70364
# [264]	valid_0's multi_logloss: 2.7035
# [265]	valid_0's multi_logloss: 2.70337
# [266]	valid_0's multi_logloss: 2.70321
# [267]	valid_0's multi_logloss: 2.70307
# [268]	valid_0's multi_logloss: 2.70291
# [269]	valid_0's multi_logloss: 2.70278
# [270]	valid_0's multi_logloss: 2.70267
# [271]	valid_0's multi_logloss: 2.70258
# [272]	valid_0's multi_logloss: 2.70238
# [273]	valid_0's multi_logloss: 2.70225
# [274]	valid_0's multi_logloss: 2.70214
# [275]	valid_0's multi_logloss: 2.70202
# [276]	valid_0's multi_logloss: 2.7019
# [277]	valid_0's multi_logloss: 2.70177
# [278]	valid_0's multi_logloss: 2.7017
# [279]	valid_0's multi_logloss: 2.70163
# [280]	valid_0's multi_logloss: 2.70156
# [281]	valid_0's multi_logloss: 2.7015
# [282]	valid_0's multi_logloss: 2.70138
# [283]	valid_0's multi_logloss: 2.70123
# [284]	valid_0's multi_logloss: 2.70109
# [285]	valid_0's multi_logloss: 2.70097
# [286]	valid_0's multi_logloss: 2.70088
# [287]	valid_0's multi_logloss: 2.70071
# [288]	valid_0's multi_logloss: 2.70062
# [289]	valid_0's multi_logloss: 2.70056
# [290]	valid_0's multi_logloss: 2.70047
# [291]	valid_0's multi_logloss: 2.70034
# [292]	valid_0's multi_logloss: 2.70027
# [293]	valid_0's multi_logloss: 2.70015
# [294]	valid_0's multi_logloss: 2.70002
# [295]	valid_0's multi_logloss: 2.69985
# [296]	valid_0's multi_logloss: 2.69978
# [297]	valid_0's multi_logloss: 2.69972
# [298]	valid_0's multi_logloss: 2.69961
# [299]	valid_0's multi_logloss: 2.69949
# [300]	valid_0's multi_logloss: 2.69944
# [301]	valid_0's multi_logloss: 2.69931
# [302]	valid_0's multi_logloss: 2.69918
# [303]	valid_0's multi_logloss: 2.69908
# [304]	valid_0's multi_logloss: 2.69901
# [305]	valid_0's multi_logloss: 2.69895
# [306]	valid_0's multi_logloss: 2.69886
# [307]	valid_0's multi_logloss: 2.6988
# [308]	valid_0's multi_logloss: 2.69869
# [309]	valid_0's multi_logloss: 2.69857
# [310]	valid_0's multi_logloss: 2.69842
# [311]	valid_0's multi_logloss: 2.69835
# [312]	valid_0's multi_logloss: 2.69823
# [313]	valid_0's multi_logloss: 2.6982
# [314]	valid_0's multi_logloss: 2.69808
# [315]	valid_0's multi_logloss: 2.69798
# [316]	valid_0's multi_logloss: 2.6979
# [317]	valid_0's multi_logloss: 2.69776
# [318]	valid_0's multi_logloss: 2.69767
# [319]	valid_0's multi_logloss: 2.69757
# [320]	valid_0's multi_logloss: 2.69745
# [321]	valid_0's multi_logloss: 2.69737
# [322]	valid_0's multi_logloss: 2.69736
# [323]	valid_0's multi_logloss: 2.6973
# [324]	valid_0's multi_logloss: 2.6972
# [325]	valid_0's multi_logloss: 2.69712
# [326]	valid_0's multi_logloss: 2.697
# [327]	valid_0's multi_logloss: 2.69693
# [328]	valid_0's multi_logloss: 2.69684
# [329]	valid_0's multi_logloss: 2.69678
# [330]	valid_0's multi_logloss: 2.6967
# [331]	valid_0's multi_logloss: 2.69661
# [332]	valid_0's multi_logloss: 2.69656
# [333]	valid_0's multi_logloss: 2.69647
# [334]	valid_0's multi_logloss: 2.69637
# [335]	valid_0's multi_logloss: 2.69636
# [336]	valid_0's multi_logloss: 2.69623
# [337]	valid_0's multi_logloss: 2.69621
# [338]	valid_0's multi_logloss: 2.69613
# [339]	valid_0's multi_logloss: 2.69611
# [340]	valid_0's multi_logloss: 2.69601
# [341]	valid_0's multi_logloss: 2.69594
# [342]	valid_0's multi_logloss: 2.69592
# [343]	valid_0's multi_logloss: 2.69591
# [344]	valid_0's multi_logloss: 2.69584
# [345]	valid_0's multi_logloss: 2.69579
# [346]	valid_0's multi_logloss: 2.69579
# [347]	valid_0's multi_logloss: 2.69571
# [348]	valid_0's multi_logloss: 2.69565
# [349]	valid_0's multi_logloss: 2.69564
# [350]	valid_0's multi_logloss: 2.69559
# [351]	valid_0's multi_logloss: 2.69553
# [352]	valid_0's multi_logloss: 2.6955
# [353]	valid_0's multi_logloss: 2.69546
# [354]	valid_0's multi_logloss: 2.69539
# [355]	valid_0's multi_logloss: 2.69535
# [356]	valid_0's multi_logloss: 2.69531
# [357]	valid_0's multi_logloss: 2.69522
# [358]	valid_0's multi_logloss: 2.69528
# [359]	valid_0's multi_logloss: 2.69518
# [360]	valid_0's multi_logloss: 2.69515
# [361]	valid_0's multi_logloss: 2.69508
# [362]	valid_0's multi_logloss: 2.69506
# [363]	valid_0's multi_logloss: 2.69504
# [364]	valid_0's multi_logloss: 2.69499
# [365]	valid_0's multi_logloss: 2.69495
# [366]	valid_0's multi_logloss: 2.69491
# [367]	valid_0's multi_logloss: 2.69493
# [368]	valid_0's multi_logloss: 2.69491
# [369]	valid_0's multi_logloss: 2.69488
# [370]	valid_0's multi_logloss: 2.69486
# [371]	valid_0's multi_logloss: 2.69478
# [372]	valid_0's multi_logloss: 2.69473
# [373]	valid_0's multi_logloss: 2.69471
# [374]	valid_0's multi_logloss: 2.69469
# [375]	valid_0's multi_logloss: 2.69466
# [376]	valid_0's multi_logloss: 2.69465
# [377]	valid_0's multi_logloss: 2.69466
# [378]	valid_0's multi_logloss: 2.69465
# [379]	valid_0's multi_logloss: 2.69461
# [380]	valid_0's multi_logloss: 2.6946
# [381]	valid_0's multi_logloss: 2.69455
# [382]	valid_0's multi_logloss: 2.6946
# [383]	valid_0's multi_logloss: 2.69458
# [384]	valid_0's multi_logloss: 2.69458
# [385]	valid_0's multi_logloss: 2.69459
# [386]	valid_0's multi_logloss: 2.69457
# [387]	valid_0's multi_logloss: 2.69456
# [388]	valid_0's multi_logloss: 2.69451
# [389]	valid_0's multi_logloss: 2.69452
# [390]	valid_0's multi_logloss: 2.6945
# [391]	valid_0's multi_logloss: 2.69445
# [392]	valid_0's multi_logloss: 2.69442
# [393]	valid_0's multi_logloss: 2.69439
# [394]	valid_0's multi_logloss: 2.69439
# [395]	valid_0's multi_logloss: 2.6944
# [396]	valid_0's multi_logloss: 2.69438
# [397]	valid_0's multi_logloss: 2.69436
# [398]	valid_0's multi_logloss: 2.69433
# [399]	valid_0's multi_logloss: 2.69425
# [400]	valid_0's multi_logloss: 2.69423
# [401]	valid_0's multi_logloss: 2.69423
# [402]	valid_0's multi_logloss: 2.69419
# [403]	valid_0's multi_logloss: 2.69413
# [404]	valid_0's multi_logloss: 2.69419
# [405]	valid_0's multi_logloss: 2.69409
# [406]	valid_0's multi_logloss: 2.69407
# [407]	valid_0's multi_logloss: 2.69406
# [408]	valid_0's multi_logloss: 2.69403
# [409]	valid_0's multi_logloss: 2.69401
# [410]	valid_0's multi_logloss: 2.69399
# [411]	valid_0's multi_logloss: 2.69395
# [412]	valid_0's multi_logloss: 2.69395
# [413]	valid_0's multi_logloss: 2.69392
# [414]	valid_0's multi_logloss: 2.6939
# [415]	valid_0's multi_logloss: 2.69387
# [416]	valid_0's multi_logloss: 2.69395
# [417]	valid_0's multi_logloss: 2.69397
# [418]	valid_0's multi_logloss: 2.69393
# [419]	valid_0's multi_logloss: 2.69392
# [420]	valid_0's multi_logloss: 2.69391
# [421]	valid_0's multi_logloss: 2.69387
# [422]	valid_0's multi_logloss: 2.69392
# [423]	valid_0's multi_logloss: 2.69396
# [424]	valid_0's multi_logloss: 2.694
# [425]	valid_0's multi_logloss: 2.69403
# [426]	valid_0's multi_logloss: 2.69402
# [427]	valid_0's multi_logloss: 2.69404
# [428]	valid_0's multi_logloss: 2.69407
# [429]	valid_0's multi_logloss: 2.69406
# [430]	valid_0's multi_logloss: 2.69404
# [431]	valid_0's multi_logloss: 2.69407
# Early stopping, best iteration is:
# [421]	valid_0's multi_logloss: 2.69387
# 0.012512199342127762
# [1]	valid_0's multi_logloss: 2.88686
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.88411
# [3]	valid_0's multi_logloss: 2.88192
# [4]	valid_0's multi_logloss: 2.87962
# [5]	valid_0's multi_logloss: 2.8776
# [6]	valid_0's multi_logloss: 2.87511
# [7]	valid_0's multi_logloss: 2.87318
# [8]	valid_0's multi_logloss: 2.87134
# [9]	valid_0's multi_logloss: 2.86954
# [10]	valid_0's multi_logloss: 2.86775
# [11]	valid_0's multi_logloss: 2.86582
# [12]	valid_0's multi_logloss: 2.86401
# [13]	valid_0's multi_logloss: 2.86232
# [14]	valid_0's multi_logloss: 2.86072
# [15]	valid_0's multi_logloss: 2.85897
# [16]	valid_0's multi_logloss: 2.85732
# [17]	valid_0's multi_logloss: 2.85587
# [18]	valid_0's multi_logloss: 2.85423
# [19]	valid_0's multi_logloss: 2.85263
# [20]	valid_0's multi_logloss: 2.85102
# [21]	valid_0's multi_logloss: 2.84946
# [22]	valid_0's multi_logloss: 2.84806
# [23]	valid_0's multi_logloss: 2.84662
# [24]	valid_0's multi_logloss: 2.84516
# [25]	valid_0's multi_logloss: 2.84372
# [26]	valid_0's multi_logloss: 2.84219
# [27]	valid_0's multi_logloss: 2.84064
# [28]	valid_0's multi_logloss: 2.83925
# [29]	valid_0's multi_logloss: 2.83784
# [30]	valid_0's multi_logloss: 2.83648
# [31]	valid_0's multi_logloss: 2.83497
# [32]	valid_0's multi_logloss: 2.83357
# [33]	valid_0's multi_logloss: 2.83226
# [34]	valid_0's multi_logloss: 2.83089
# [35]	valid_0's multi_logloss: 2.82967
# [36]	valid_0's multi_logloss: 2.8283
# [37]	valid_0's multi_logloss: 2.82707
# [38]	valid_0's multi_logloss: 2.82591
# [39]	valid_0's multi_logloss: 2.82467
# [40]	valid_0's multi_logloss: 2.82352
# [41]	valid_0's multi_logloss: 2.82243
# [42]	valid_0's multi_logloss: 2.82127
# [43]	valid_0's multi_logloss: 2.82025
# [44]	valid_0's multi_logloss: 2.8191
# [45]	valid_0's multi_logloss: 2.81802
# [46]	valid_0's multi_logloss: 2.81701
# [47]	valid_0's multi_logloss: 2.81593
# [48]	valid_0's multi_logloss: 2.81484
# [49]	valid_0's multi_logloss: 2.8137
# [50]	valid_0's multi_logloss: 2.81258
# [51]	valid_0's multi_logloss: 2.81157
# [52]	valid_0's multi_logloss: 2.81063
# [53]	valid_0's multi_logloss: 2.80966
# [54]	valid_0's multi_logloss: 2.80875
# [55]	valid_0's multi_logloss: 2.8077
# [56]	valid_0's multi_logloss: 2.80669
# [57]	valid_0's multi_logloss: 2.80583
# [58]	valid_0's multi_logloss: 2.80479
# [59]	valid_0's multi_logloss: 2.80395
# [60]	valid_0's multi_logloss: 2.80295
# [61]	valid_0's multi_logloss: 2.80204
# [62]	valid_0's multi_logloss: 2.8011
# [63]	valid_0's multi_logloss: 2.8002
# [64]	valid_0's multi_logloss: 2.79924
# [65]	valid_0's multi_logloss: 2.7983
# [66]	valid_0's multi_logloss: 2.79738
# [67]	valid_0's multi_logloss: 2.79647
# [68]	valid_0's multi_logloss: 2.79555
# [69]	valid_0's multi_logloss: 2.79465
# [70]	valid_0's multi_logloss: 2.79365
# [71]	valid_0's multi_logloss: 2.79291
# [72]	valid_0's multi_logloss: 2.79198
# [73]	valid_0's multi_logloss: 2.79108
# [74]	valid_0's multi_logloss: 2.79036
# [75]	valid_0's multi_logloss: 2.78958
# [76]	valid_0's multi_logloss: 2.78879
# [77]	valid_0's multi_logloss: 2.78792
# [78]	valid_0's multi_logloss: 2.78707
# [79]	valid_0's multi_logloss: 2.78631
# [80]	valid_0's multi_logloss: 2.78555
# [81]	valid_0's multi_logloss: 2.78474
# [82]	valid_0's multi_logloss: 2.78395
# [83]	valid_0's multi_logloss: 2.78313
# [84]	valid_0's multi_logloss: 2.78236
# [85]	valid_0's multi_logloss: 2.78163
# [86]	valid_0's multi_logloss: 2.78081
# [87]	valid_0's multi_logloss: 2.78006
# [88]	valid_0's multi_logloss: 2.77918
# [89]	valid_0's multi_logloss: 2.77847
# [90]	valid_0's multi_logloss: 2.77775
# [91]	valid_0's multi_logloss: 2.77696
# [92]	valid_0's multi_logloss: 2.77622
# [93]	valid_0's multi_logloss: 2.77543
# [94]	valid_0's multi_logloss: 2.77472
# [95]	valid_0's multi_logloss: 2.77402
# [96]	valid_0's multi_logloss: 2.77331
# [97]	valid_0's multi_logloss: 2.77259
# [98]	valid_0's multi_logloss: 2.77188
# [99]	valid_0's multi_logloss: 2.77117
# [100]	valid_0's multi_logloss: 2.77048
# [101]	valid_0's multi_logloss: 2.76978
# [102]	valid_0's multi_logloss: 2.76912
# [103]	valid_0's multi_logloss: 2.76834
# [104]	valid_0's multi_logloss: 2.76771
# [105]	valid_0's multi_logloss: 2.76699
# [106]	valid_0's multi_logloss: 2.76642
# [107]	valid_0's multi_logloss: 2.76583
# [108]	valid_0's multi_logloss: 2.76519
# [109]	valid_0's multi_logloss: 2.76451
# [110]	valid_0's multi_logloss: 2.76388
# [111]	valid_0's multi_logloss: 2.76334
# [112]	valid_0's multi_logloss: 2.76271
# [113]	valid_0's multi_logloss: 2.76205
# [114]	valid_0's multi_logloss: 2.76146
# [115]	valid_0's multi_logloss: 2.76089
# [116]	valid_0's multi_logloss: 2.76032
# [117]	valid_0's multi_logloss: 2.75968
# [118]	valid_0's multi_logloss: 2.75916
# [119]	valid_0's multi_logloss: 2.75865
# [120]	valid_0's multi_logloss: 2.75807
# [121]	valid_0's multi_logloss: 2.75753
# [122]	valid_0's multi_logloss: 2.75696
# [123]	valid_0's multi_logloss: 2.7564
# [124]	valid_0's multi_logloss: 2.7558
# [125]	valid_0's multi_logloss: 2.75536
# [126]	valid_0's multi_logloss: 2.75476
# [127]	valid_0's multi_logloss: 2.75416
# [128]	valid_0's multi_logloss: 2.75366
# [129]	valid_0's multi_logloss: 2.75313
# [130]	valid_0's multi_logloss: 2.75257
# [131]	valid_0's multi_logloss: 2.75204
# [132]	valid_0's multi_logloss: 2.75143
# [133]	valid_0's multi_logloss: 2.75087
# [134]	valid_0's multi_logloss: 2.75042
# [135]	valid_0's multi_logloss: 2.74996
# [136]	valid_0's multi_logloss: 2.74946
# [137]	valid_0's multi_logloss: 2.74896
# [138]	valid_0's multi_logloss: 2.74845
# [139]	valid_0's multi_logloss: 2.74786
# [140]	valid_0's multi_logloss: 2.74735
# [141]	valid_0's multi_logloss: 2.7469
# [142]	valid_0's multi_logloss: 2.74634
# [143]	valid_0's multi_logloss: 2.74585
# [144]	valid_0's multi_logloss: 2.74548
# [145]	valid_0's multi_logloss: 2.74494
# [146]	valid_0's multi_logloss: 2.74447
# [147]	valid_0's multi_logloss: 2.74395
# [148]	valid_0's multi_logloss: 2.74353
# [149]	valid_0's multi_logloss: 2.74311
# [150]	valid_0's multi_logloss: 2.74259
# [151]	valid_0's multi_logloss: 2.7421
# [152]	valid_0's multi_logloss: 2.74164
# [153]	valid_0's multi_logloss: 2.74113
# [154]	valid_0's multi_logloss: 2.74068
# [155]	valid_0's multi_logloss: 2.74022
# [156]	valid_0's multi_logloss: 2.73969
# [157]	valid_0's multi_logloss: 2.73926
# [158]	valid_0's multi_logloss: 2.73888
# [159]	valid_0's multi_logloss: 2.73843
# [160]	valid_0's multi_logloss: 2.73801
# [161]	valid_0's multi_logloss: 2.73761
# [162]	valid_0's multi_logloss: 2.7372
# [163]	valid_0's multi_logloss: 2.73683
# [164]	valid_0's multi_logloss: 2.73636
# [165]	valid_0's multi_logloss: 2.73594
# [166]	valid_0's multi_logloss: 2.73551
# [167]	valid_0's multi_logloss: 2.73502
# [168]	valid_0's multi_logloss: 2.7346
# [169]	valid_0's multi_logloss: 2.73429
# [170]	valid_0's multi_logloss: 2.73373
# [171]	valid_0's multi_logloss: 2.7334
# [172]	valid_0's multi_logloss: 2.73299
# [173]	valid_0's multi_logloss: 2.73263
# [174]	valid_0's multi_logloss: 2.73216
# [175]	valid_0's multi_logloss: 2.7317
# [176]	valid_0's multi_logloss: 2.73136
# [177]	valid_0's multi_logloss: 2.73098
# [178]	valid_0's multi_logloss: 2.73065
# [179]	valid_0's multi_logloss: 2.73023
# [180]	valid_0's multi_logloss: 2.7299
# [181]	valid_0's multi_logloss: 2.72952
# [182]	valid_0's multi_logloss: 2.72914
# [183]	valid_0's multi_logloss: 2.72879
# [184]	valid_0's multi_logloss: 2.72849
# [185]	valid_0's multi_logloss: 2.72805
# [186]	valid_0's multi_logloss: 2.72773
# [187]	valid_0's multi_logloss: 2.72741
# [188]	valid_0's multi_logloss: 2.72701
# [189]	valid_0's multi_logloss: 2.72663
# [190]	valid_0's multi_logloss: 2.7263
# [191]	valid_0's multi_logloss: 2.72594
# [192]	valid_0's multi_logloss: 2.7256
# [193]	valid_0's multi_logloss: 2.7254
# [194]	valid_0's multi_logloss: 2.72513
# [195]	valid_0's multi_logloss: 2.72478
# [196]	valid_0's multi_logloss: 2.72446
# [197]	valid_0's multi_logloss: 2.72416
# [198]	valid_0's multi_logloss: 2.72387
# [199]	valid_0's multi_logloss: 2.7236
# [200]	valid_0's multi_logloss: 2.72338
# [201]	valid_0's multi_logloss: 2.72302
# [202]	valid_0's multi_logloss: 2.72275
# [203]	valid_0's multi_logloss: 2.72241
# [204]	valid_0's multi_logloss: 2.72217
# [205]	valid_0's multi_logloss: 2.72183
# [206]	valid_0's multi_logloss: 2.72154
# [207]	valid_0's multi_logloss: 2.72121
# [208]	valid_0's multi_logloss: 2.72095
# [209]	valid_0's multi_logloss: 2.72063
# [210]	valid_0's multi_logloss: 2.72031
# [211]	valid_0's multi_logloss: 2.72006
# [212]	valid_0's multi_logloss: 2.71973
# [213]	valid_0's multi_logloss: 2.71944
# [214]	valid_0's multi_logloss: 2.71915
# [215]	valid_0's multi_logloss: 2.71891
# [216]	valid_0's multi_logloss: 2.71862
# [217]	valid_0's multi_logloss: 2.71829
# [218]	valid_0's multi_logloss: 2.71798
# [219]	valid_0's multi_logloss: 2.71774
# [220]	valid_0's multi_logloss: 2.71744
# [221]	valid_0's multi_logloss: 2.7172
# [222]	valid_0's multi_logloss: 2.71697
# [223]	valid_0's multi_logloss: 2.71672
# [224]	valid_0's multi_logloss: 2.71647
# [225]	valid_0's multi_logloss: 2.71621
# [226]	valid_0's multi_logloss: 2.7159
# [227]	valid_0's multi_logloss: 2.71567
# [228]	valid_0's multi_logloss: 2.71533
# [229]	valid_0's multi_logloss: 2.71513
# [230]	valid_0's multi_logloss: 2.71487
# [231]	valid_0's multi_logloss: 2.71467
# [232]	valid_0's multi_logloss: 2.71434
# [233]	valid_0's multi_logloss: 2.71413
# [234]	valid_0's multi_logloss: 2.71381
# [235]	valid_0's multi_logloss: 2.71357
# [236]	valid_0's multi_logloss: 2.7134
# [237]	valid_0's multi_logloss: 2.71317
# [238]	valid_0's multi_logloss: 2.71291
# [239]	valid_0's multi_logloss: 2.71267
# [240]	valid_0's multi_logloss: 2.7124
# [241]	valid_0's multi_logloss: 2.71218
# [242]	valid_0's multi_logloss: 2.71201
# [243]	valid_0's multi_logloss: 2.7118
# [244]	valid_0's multi_logloss: 2.71159
# [245]	valid_0's multi_logloss: 2.71136
# [246]	valid_0's multi_logloss: 2.71107
# [247]	valid_0's multi_logloss: 2.7109
# [248]	valid_0's multi_logloss: 2.71068
# [249]	valid_0's multi_logloss: 2.71045
# [250]	valid_0's multi_logloss: 2.71027
# [251]	valid_0's multi_logloss: 2.71006
# [252]	valid_0's multi_logloss: 2.70986
# [253]	valid_0's multi_logloss: 2.70961
# [254]	valid_0's multi_logloss: 2.70945
# [255]	valid_0's multi_logloss: 2.70931
# [256]	valid_0's multi_logloss: 2.70898
# [257]	valid_0's multi_logloss: 2.7088
# [258]	valid_0's multi_logloss: 2.70859
# [259]	valid_0's multi_logloss: 2.70839
# [260]	valid_0's multi_logloss: 2.70824
# [261]	valid_0's multi_logloss: 2.70799
# [262]	valid_0's multi_logloss: 2.70785
# [263]	valid_0's multi_logloss: 2.70763
# [264]	valid_0's multi_logloss: 2.70746
# [265]	valid_0's multi_logloss: 2.70728
# [266]	valid_0's multi_logloss: 2.70711
# [267]	valid_0's multi_logloss: 2.70697
# [268]	valid_0's multi_logloss: 2.70672
# [269]	valid_0's multi_logloss: 2.70651
# [270]	valid_0's multi_logloss: 2.70635
# [271]	valid_0's multi_logloss: 2.70615
# [272]	valid_0's multi_logloss: 2.70598
# [273]	valid_0's multi_logloss: 2.70577
# [274]	valid_0's multi_logloss: 2.70564
# [275]	valid_0's multi_logloss: 2.70546
# [276]	valid_0's multi_logloss: 2.70525
# [277]	valid_0's multi_logloss: 2.7051
# [278]	valid_0's multi_logloss: 2.70492
# [279]	valid_0's multi_logloss: 2.70476
# [280]	valid_0's multi_logloss: 2.70456
# [281]	valid_0's multi_logloss: 2.70443
# [282]	valid_0's multi_logloss: 2.70425
# [283]	valid_0's multi_logloss: 2.70407
# [284]	valid_0's multi_logloss: 2.70389
# [285]	valid_0's multi_logloss: 2.70364
# [286]	valid_0's multi_logloss: 2.70345
# [287]	valid_0's multi_logloss: 2.70334
# [288]	valid_0's multi_logloss: 2.70318
# [289]	valid_0's multi_logloss: 2.70302
# [290]	valid_0's multi_logloss: 2.70283
# [291]	valid_0's multi_logloss: 2.70266
# [292]	valid_0's multi_logloss: 2.70247
# [293]	valid_0's multi_logloss: 2.70229
# [294]	valid_0's multi_logloss: 2.70216
# [295]	valid_0's multi_logloss: 2.70204
# [296]	valid_0's multi_logloss: 2.70189
# [297]	valid_0's multi_logloss: 2.70169
# [298]	valid_0's multi_logloss: 2.70161
# [299]	valid_0's multi_logloss: 2.70147
# [300]	valid_0's multi_logloss: 2.70119
# [301]	valid_0's multi_logloss: 2.70106
# [302]	valid_0's multi_logloss: 2.70092
# [303]	valid_0's multi_logloss: 2.70074
# [304]	valid_0's multi_logloss: 2.70065
# [305]	valid_0's multi_logloss: 2.70049
# [306]	valid_0's multi_logloss: 2.70031
# [307]	valid_0's multi_logloss: 2.70015
# [308]	valid_0's multi_logloss: 2.69999
# [309]	valid_0's multi_logloss: 2.69983
# [310]	valid_0's multi_logloss: 2.6997
# [311]	valid_0's multi_logloss: 2.69961
# [312]	valid_0's multi_logloss: 2.69946
# [313]	valid_0's multi_logloss: 2.69935
# [314]	valid_0's multi_logloss: 2.69922
# [315]	valid_0's multi_logloss: 2.69906
# [316]	valid_0's multi_logloss: 2.69886
# [317]	valid_0's multi_logloss: 2.69878
# [318]	valid_0's multi_logloss: 2.69865
# [319]	valid_0's multi_logloss: 2.69855
# [320]	valid_0's multi_logloss: 2.69847
# [321]	valid_0's multi_logloss: 2.69835
# [322]	valid_0's multi_logloss: 2.69823
# [323]	valid_0's multi_logloss: 2.6981
# [324]	valid_0's multi_logloss: 2.69802
# [325]	valid_0's multi_logloss: 2.69794
# [326]	valid_0's multi_logloss: 2.69786
# [327]	valid_0's multi_logloss: 2.69773
# [328]	valid_0's multi_logloss: 2.69767
# [329]	valid_0's multi_logloss: 2.69754
# [330]	valid_0's multi_logloss: 2.69746
# [331]	valid_0's multi_logloss: 2.69736
# [332]	valid_0's multi_logloss: 2.69731
# [333]	valid_0's multi_logloss: 2.69718
# [334]	valid_0's multi_logloss: 2.6971
# [335]	valid_0's multi_logloss: 2.697
# [336]	valid_0's multi_logloss: 2.69695
# [337]	valid_0's multi_logloss: 2.69685
# [338]	valid_0's multi_logloss: 2.6968
# [339]	valid_0's multi_logloss: 2.69669
# [340]	valid_0's multi_logloss: 2.69655
# [341]	valid_0's multi_logloss: 2.69645
# [342]	valid_0's multi_logloss: 2.69637
# [343]	valid_0's multi_logloss: 2.69626
# [344]	valid_0's multi_logloss: 2.69615
# [345]	valid_0's multi_logloss: 2.69608
# [346]	valid_0's multi_logloss: 2.69598
# [347]	valid_0's multi_logloss: 2.69589
# [348]	valid_0's multi_logloss: 2.69584
# [349]	valid_0's multi_logloss: 2.6958
# [350]	valid_0's multi_logloss: 2.69572
# [351]	valid_0's multi_logloss: 2.69562
# [352]	valid_0's multi_logloss: 2.69548
# [353]	valid_0's multi_logloss: 2.69534
# [354]	valid_0's multi_logloss: 2.69523
# [355]	valid_0's multi_logloss: 2.69513
# [356]	valid_0's multi_logloss: 2.69508
# [357]	valid_0's multi_logloss: 2.69502
# [358]	valid_0's multi_logloss: 2.69492
# [359]	valid_0's multi_logloss: 2.69482
# [360]	valid_0's multi_logloss: 2.69475
# [361]	valid_0's multi_logloss: 2.69466
# [362]	valid_0's multi_logloss: 2.69459
# [363]	valid_0's multi_logloss: 2.69448
# [364]	valid_0's multi_logloss: 2.69441
# [365]	valid_0's multi_logloss: 2.69433
# [366]	valid_0's multi_logloss: 2.69424
# [367]	valid_0's multi_logloss: 2.69418
# [368]	valid_0's multi_logloss: 2.69412
# [369]	valid_0's multi_logloss: 2.694
# [370]	valid_0's multi_logloss: 2.69393
# [371]	valid_0's multi_logloss: 2.69383
# [372]	valid_0's multi_logloss: 2.69382
# [373]	valid_0's multi_logloss: 2.69376
# [374]	valid_0's multi_logloss: 2.69372
# [375]	valid_0's multi_logloss: 2.69365
# [376]	valid_0's multi_logloss: 2.69359
# [377]	valid_0's multi_logloss: 2.69351
# [378]	valid_0's multi_logloss: 2.69346
# [379]	valid_0's multi_logloss: 2.69342
# [380]	valid_0's multi_logloss: 2.69332
# [381]	valid_0's multi_logloss: 2.69328
# [382]	valid_0's multi_logloss: 2.69329
# [383]	valid_0's multi_logloss: 2.69321
# [384]	valid_0's multi_logloss: 2.69314
# [385]	valid_0's multi_logloss: 2.69311
# [386]	valid_0's multi_logloss: 2.69309
# [387]	valid_0's multi_logloss: 2.69304
# [388]	valid_0's multi_logloss: 2.69302
# [389]	valid_0's multi_logloss: 2.69294
# [390]	valid_0's multi_logloss: 2.69286
# [391]	valid_0's multi_logloss: 2.69277
# [392]	valid_0's multi_logloss: 2.6927
# [393]	valid_0's multi_logloss: 2.69266
# [394]	valid_0's multi_logloss: 2.6926
# [395]	valid_0's multi_logloss: 2.69261
# [396]	valid_0's multi_logloss: 2.69259
# [397]	valid_0's multi_logloss: 2.69249
# [398]	valid_0's multi_logloss: 2.69247
# [399]	valid_0's multi_logloss: 2.69237
# [400]	valid_0's multi_logloss: 2.69233
# [401]	valid_0's multi_logloss: 2.69226
# [402]	valid_0's multi_logloss: 2.69224
# [403]	valid_0's multi_logloss: 2.69214
# [404]	valid_0's multi_logloss: 2.69211
# [405]	valid_0's multi_logloss: 2.69206
# [406]	valid_0's multi_logloss: 2.69202
# [407]	valid_0's multi_logloss: 2.69197
# [408]	valid_0's multi_logloss: 2.69194
# [409]	valid_0's multi_logloss: 2.69188
# [410]	valid_0's multi_logloss: 2.69184
# [411]	valid_0's multi_logloss: 2.69175
# [412]	valid_0's multi_logloss: 2.69168
# [413]	valid_0's multi_logloss: 2.69161
# [414]	valid_0's multi_logloss: 2.69157
# [415]	valid_0's multi_logloss: 2.69155
# [416]	valid_0's multi_logloss: 2.6915
# [417]	valid_0's multi_logloss: 2.69144
# [418]	valid_0's multi_logloss: 2.69135
# [419]	valid_0's multi_logloss: 2.69127
# [420]	valid_0's multi_logloss: 2.69127
# [421]	valid_0's multi_logloss: 2.69123
# [422]	valid_0's multi_logloss: 2.69119
# [423]	valid_0's multi_logloss: 2.69119
# [424]	valid_0's multi_logloss: 2.6912
# [425]	valid_0's multi_logloss: 2.69113
# [426]	valid_0's multi_logloss: 2.69112
# [427]	valid_0's multi_logloss: 2.69107
# [428]	valid_0's multi_logloss: 2.69105
# [429]	valid_0's multi_logloss: 2.69094
# [430]	valid_0's multi_logloss: 2.6909
# [431]	valid_0's multi_logloss: 2.69085
# [432]	valid_0's multi_logloss: 2.69083
# [433]	valid_0's multi_logloss: 2.69077
# [434]	valid_0's multi_logloss: 2.69077
# [435]	valid_0's multi_logloss: 2.69074
# [436]	valid_0's multi_logloss: 2.69072
# [437]	valid_0's multi_logloss: 2.69068
# [438]	valid_0's multi_logloss: 2.6907
# [439]	valid_0's multi_logloss: 2.69072
# [440]	valid_0's multi_logloss: 2.69069
# [441]	valid_0's multi_logloss: 2.69068
# [442]	valid_0's multi_logloss: 2.69063
# [443]	valid_0's multi_logloss: 2.6906
# [444]	valid_0's multi_logloss: 2.69063
# [445]	valid_0's multi_logloss: 2.69054
# [446]	valid_0's multi_logloss: 2.69057
# [447]	valid_0's multi_logloss: 2.69052
# [448]	valid_0's multi_logloss: 2.69044
# [449]	valid_0's multi_logloss: 2.6904
# [450]	valid_0's multi_logloss: 2.69041
# [451]	valid_0's multi_logloss: 2.69042
# [452]	valid_0's multi_logloss: 2.69037
# [453]	valid_0's multi_logloss: 2.69033
# [454]	valid_0's multi_logloss: 2.69035
# [455]	valid_0's multi_logloss: 2.69031
# [456]	valid_0's multi_logloss: 2.69028
# [457]	valid_0's multi_logloss: 2.69024
# [458]	valid_0's multi_logloss: 2.6902
# [459]	valid_0's multi_logloss: 2.69015
# [460]	valid_0's multi_logloss: 2.6902
# [461]	valid_0's multi_logloss: 2.69014
# [462]	valid_0's multi_logloss: 2.69013
# [463]	valid_0's multi_logloss: 2.69014
# [464]	valid_0's multi_logloss: 2.69014
# [465]	valid_0's multi_logloss: 2.69016
# [466]	valid_0's multi_logloss: 2.69011
# [467]	valid_0's multi_logloss: 2.69007
# [468]	valid_0's multi_logloss: 2.69004
# [469]	valid_0's multi_logloss: 2.69
# [470]	valid_0's multi_logloss: 2.68996
# [471]	valid_0's multi_logloss: 2.68995
# [472]	valid_0's multi_logloss: 2.68992
# [473]	valid_0's multi_logloss: 2.68989
# [474]	valid_0's multi_logloss: 2.68988
# [475]	valid_0's multi_logloss: 2.68986
# [476]	valid_0's multi_logloss: 2.68984
# [477]	valid_0's multi_logloss: 2.68993
# [478]	valid_0's multi_logloss: 2.68988
# [479]	valid_0's multi_logloss: 2.68984
# [480]	valid_0's multi_logloss: 2.68985
# [481]	valid_0's multi_logloss: 2.68984
# [482]	valid_0's multi_logloss: 2.68988
# [483]	valid_0's multi_logloss: 2.68984
# [484]	valid_0's multi_logloss: 2.68983
# [485]	valid_0's multi_logloss: 2.68984
# [486]	valid_0's multi_logloss: 2.68985
# [487]	valid_0's multi_logloss: 2.68982
# [488]	valid_0's multi_logloss: 2.68982
# [489]	valid_0's multi_logloss: 2.68983
# [490]	valid_0's multi_logloss: 2.68981
# [491]	valid_0's multi_logloss: 2.68977
# [492]	valid_0's multi_logloss: 2.68976
# [493]	valid_0's multi_logloss: 2.68974
# [494]	valid_0's multi_logloss: 2.68976
# [495]	valid_0's multi_logloss: 2.68979
# [496]	valid_0's multi_logloss: 2.68979
# [497]	valid_0's multi_logloss: 2.68981
# [498]	valid_0's multi_logloss: 2.68983
# [499]	valid_0's multi_logloss: 2.68983
# [500]	valid_0's multi_logloss: 2.6898
# [501]	valid_0's multi_logloss: 2.6898
# [502]	valid_0's multi_logloss: 2.68981
# [503]	valid_0's multi_logloss: 2.68982
# Early stopping, best iteration is:
# [493]	valid_0's multi_logloss: 2.68974
# 0.012279083322790119
# [1]	valid_0's multi_logloss: 2.85883
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.85692
# [3]	valid_0's multi_logloss: 2.85503
# [4]	valid_0's multi_logloss: 2.85301
# [5]	valid_0's multi_logloss: 2.8512
# [6]	valid_0's multi_logloss: 2.84942
# [7]	valid_0's multi_logloss: 2.84777
# [8]	valid_0's multi_logloss: 2.84604
# [9]	valid_0's multi_logloss: 2.8442
# [10]	valid_0's multi_logloss: 2.84264
# [11]	valid_0's multi_logloss: 2.84104
# [12]	valid_0's multi_logloss: 2.83942
# [13]	valid_0's multi_logloss: 2.83765
# [14]	valid_0's multi_logloss: 2.83622
# [15]	valid_0's multi_logloss: 2.83467
# [16]	valid_0's multi_logloss: 2.83322
# [17]	valid_0's multi_logloss: 2.83181
# [18]	valid_0's multi_logloss: 2.83041
# [19]	valid_0's multi_logloss: 2.82913
# [20]	valid_0's multi_logloss: 2.82779
# [21]	valid_0's multi_logloss: 2.82653
# [22]	valid_0's multi_logloss: 2.8253
# [23]	valid_0's multi_logloss: 2.8242
# [24]	valid_0's multi_logloss: 2.82289
# [25]	valid_0's multi_logloss: 2.82186
# [26]	valid_0's multi_logloss: 2.82079
# [27]	valid_0's multi_logloss: 2.81968
# [28]	valid_0's multi_logloss: 2.81845
# [29]	valid_0's multi_logloss: 2.8174
# [30]	valid_0's multi_logloss: 2.81635
# [31]	valid_0's multi_logloss: 2.81535
# [32]	valid_0's multi_logloss: 2.81426
# [33]	valid_0's multi_logloss: 2.81326
# [34]	valid_0's multi_logloss: 2.81224
# [35]	valid_0's multi_logloss: 2.81132
# [36]	valid_0's multi_logloss: 2.81028
# [37]	valid_0's multi_logloss: 2.80936
# [38]	valid_0's multi_logloss: 2.80847
# [39]	valid_0's multi_logloss: 2.80756
# [40]	valid_0's multi_logloss: 2.80658
# [41]	valid_0's multi_logloss: 2.80581
# [42]	valid_0's multi_logloss: 2.8049
# [43]	valid_0's multi_logloss: 2.80409
# [44]	valid_0's multi_logloss: 2.8031
# [45]	valid_0's multi_logloss: 2.80228
# [46]	valid_0's multi_logloss: 2.8014
# [47]	valid_0's multi_logloss: 2.80049
# [48]	valid_0's multi_logloss: 2.79964
# [49]	valid_0's multi_logloss: 2.79878
# [50]	valid_0's multi_logloss: 2.79793
# [51]	valid_0's multi_logloss: 2.79712
# [52]	valid_0's multi_logloss: 2.79625
# [53]	valid_0's multi_logloss: 2.79538
# [54]	valid_0's multi_logloss: 2.79457
# [55]	valid_0's multi_logloss: 2.79374
# [56]	valid_0's multi_logloss: 2.79275
# [57]	valid_0's multi_logloss: 2.79203
# [58]	valid_0's multi_logloss: 2.79122
# [59]	valid_0's multi_logloss: 2.79048
# [60]	valid_0's multi_logloss: 2.78966
# [61]	valid_0's multi_logloss: 2.78879
# [62]	valid_0's multi_logloss: 2.78807
# [63]	valid_0's multi_logloss: 2.78722
# [64]	valid_0's multi_logloss: 2.78648
# [65]	valid_0's multi_logloss: 2.78565
# [66]	valid_0's multi_logloss: 2.78492
# [67]	valid_0's multi_logloss: 2.78405
# [68]	valid_0's multi_logloss: 2.7833
# [69]	valid_0's multi_logloss: 2.78262
# [70]	valid_0's multi_logloss: 2.78182
# [71]	valid_0's multi_logloss: 2.78114
# [72]	valid_0's multi_logloss: 2.78038
# [73]	valid_0's multi_logloss: 2.7797
# [74]	valid_0's multi_logloss: 2.779
# [75]	valid_0's multi_logloss: 2.77829
# [76]	valid_0's multi_logloss: 2.77762
# [77]	valid_0's multi_logloss: 2.77697
# [78]	valid_0's multi_logloss: 2.77637
# [79]	valid_0's multi_logloss: 2.77562
# [80]	valid_0's multi_logloss: 2.77511
# [81]	valid_0's multi_logloss: 2.77447
# [82]	valid_0's multi_logloss: 2.7738
# [83]	valid_0's multi_logloss: 2.77316
# [84]	valid_0's multi_logloss: 2.77258
# [85]	valid_0's multi_logloss: 2.77201
# [86]	valid_0's multi_logloss: 2.77139
# [87]	valid_0's multi_logloss: 2.77079
# [88]	valid_0's multi_logloss: 2.77023
# [89]	valid_0's multi_logloss: 2.76964
# [90]	valid_0's multi_logloss: 2.76907
# [91]	valid_0's multi_logloss: 2.76847
# [92]	valid_0's multi_logloss: 2.76787
# [93]	valid_0's multi_logloss: 2.76735
# [94]	valid_0's multi_logloss: 2.76674
# [95]	valid_0's multi_logloss: 2.76617
# [96]	valid_0's multi_logloss: 2.76565
# [97]	valid_0's multi_logloss: 2.76509
# [98]	valid_0's multi_logloss: 2.76443
# [99]	valid_0's multi_logloss: 2.76384
# [100]	valid_0's multi_logloss: 2.7633
# [101]	valid_0's multi_logloss: 2.76274
# [102]	valid_0's multi_logloss: 2.76223
# [103]	valid_0's multi_logloss: 2.76159
# [104]	valid_0's multi_logloss: 2.76111
# [105]	valid_0's multi_logloss: 2.76059
# [106]	valid_0's multi_logloss: 2.75998
# [107]	valid_0's multi_logloss: 2.75939
# [108]	valid_0's multi_logloss: 2.75881
# [109]	valid_0's multi_logloss: 2.75831
# [110]	valid_0's multi_logloss: 2.75783
# [111]	valid_0's multi_logloss: 2.75724
# [112]	valid_0's multi_logloss: 2.75668
# [113]	valid_0's multi_logloss: 2.7561
# [114]	valid_0's multi_logloss: 2.75555
# [115]	valid_0's multi_logloss: 2.75493
# [116]	valid_0's multi_logloss: 2.75446
# [117]	valid_0's multi_logloss: 2.75389
# [118]	valid_0's multi_logloss: 2.75331
# [119]	valid_0's multi_logloss: 2.75277
# [120]	valid_0's multi_logloss: 2.75226
# [121]	valid_0's multi_logloss: 2.75167
# [122]	valid_0's multi_logloss: 2.75121
# [123]	valid_0's multi_logloss: 2.75075
# [124]	valid_0's multi_logloss: 2.75022
# [125]	valid_0's multi_logloss: 2.74973
# [126]	valid_0's multi_logloss: 2.74921
# [127]	valid_0's multi_logloss: 2.74867
# [128]	valid_0's multi_logloss: 2.74829
# [129]	valid_0's multi_logloss: 2.74781
# [130]	valid_0's multi_logloss: 2.7473
# [131]	valid_0's multi_logloss: 2.74688
# [132]	valid_0's multi_logloss: 2.74642
# [133]	valid_0's multi_logloss: 2.74591
# [134]	valid_0's multi_logloss: 2.74548
# [135]	valid_0's multi_logloss: 2.74505
# [136]	valid_0's multi_logloss: 2.74463
# [137]	valid_0's multi_logloss: 2.74423
# [138]	valid_0's multi_logloss: 2.74382
# [139]	valid_0's multi_logloss: 2.74346
# [140]	valid_0's multi_logloss: 2.74304
# [141]	valid_0's multi_logloss: 2.74261
# [142]	valid_0's multi_logloss: 2.7422
# [143]	valid_0's multi_logloss: 2.74178
# [144]	valid_0's multi_logloss: 2.74138
# [145]	valid_0's multi_logloss: 2.74092
# [146]	valid_0's multi_logloss: 2.74053
# [147]	valid_0's multi_logloss: 2.74011
# [148]	valid_0's multi_logloss: 2.73974
# [149]	valid_0's multi_logloss: 2.7394
# [150]	valid_0's multi_logloss: 2.73904
# [151]	valid_0's multi_logloss: 2.73863
# [152]	valid_0's multi_logloss: 2.73823
# [153]	valid_0's multi_logloss: 2.73787
# [154]	valid_0's multi_logloss: 2.73755
# [155]	valid_0's multi_logloss: 2.73717
# [156]	valid_0's multi_logloss: 2.73682
# [157]	valid_0's multi_logloss: 2.73649
# [158]	valid_0's multi_logloss: 2.73612
# [159]	valid_0's multi_logloss: 2.73567
# [160]	valid_0's multi_logloss: 2.73535
# [161]	valid_0's multi_logloss: 2.73502
# [162]	valid_0's multi_logloss: 2.73468
# [163]	valid_0's multi_logloss: 2.73434
# [164]	valid_0's multi_logloss: 2.73403
# [165]	valid_0's multi_logloss: 2.73368
# [166]	valid_0's multi_logloss: 2.73333
# [167]	valid_0's multi_logloss: 2.73296
# [168]	valid_0's multi_logloss: 2.7327
# [169]	valid_0's multi_logloss: 2.73239
# [170]	valid_0's multi_logloss: 2.73206
# [171]	valid_0's multi_logloss: 2.7317
# [172]	valid_0's multi_logloss: 2.73136
# [173]	valid_0's multi_logloss: 2.73103
# [174]	valid_0's multi_logloss: 2.73078
# [175]	valid_0's multi_logloss: 2.73047
# [176]	valid_0's multi_logloss: 2.73017
# [177]	valid_0's multi_logloss: 2.72984
# [178]	valid_0's multi_logloss: 2.7296
# [179]	valid_0's multi_logloss: 2.72926
# [180]	valid_0's multi_logloss: 2.72896
# [181]	valid_0's multi_logloss: 2.72869
# [182]	valid_0's multi_logloss: 2.72835
# [183]	valid_0's multi_logloss: 2.72808
# [184]	valid_0's multi_logloss: 2.72779
# [185]	valid_0's multi_logloss: 2.72745
# [186]	valid_0's multi_logloss: 2.72722
# [187]	valid_0's multi_logloss: 2.72699
# [188]	valid_0's multi_logloss: 2.72668
# [189]	valid_0's multi_logloss: 2.72638
# [190]	valid_0's multi_logloss: 2.72612
# [191]	valid_0's multi_logloss: 2.7258
# [192]	valid_0's multi_logloss: 2.72559
# [193]	valid_0's multi_logloss: 2.72526
# [194]	valid_0's multi_logloss: 2.725
# [195]	valid_0's multi_logloss: 2.7247
# [196]	valid_0's multi_logloss: 2.72439
# [197]	valid_0's multi_logloss: 2.72414
# [198]	valid_0's multi_logloss: 2.72385
# [199]	valid_0's multi_logloss: 2.72358
# [200]	valid_0's multi_logloss: 2.72335
# [201]	valid_0's multi_logloss: 2.72307
# [202]	valid_0's multi_logloss: 2.72284
# [203]	valid_0's multi_logloss: 2.72257
# [204]	valid_0's multi_logloss: 2.72231
# [205]	valid_0's multi_logloss: 2.72206
# [206]	valid_0's multi_logloss: 2.7218
# [207]	valid_0's multi_logloss: 2.7216
# [208]	valid_0's multi_logloss: 2.72137
# [209]	valid_0's multi_logloss: 2.72113
# [210]	valid_0's multi_logloss: 2.72095
# [211]	valid_0's multi_logloss: 2.72075
# [212]	valid_0's multi_logloss: 2.72053
# [213]	valid_0's multi_logloss: 2.72031
# [214]	valid_0's multi_logloss: 2.7201
# [215]	valid_0's multi_logloss: 2.7199
# [216]	valid_0's multi_logloss: 2.71965
# [217]	valid_0's multi_logloss: 2.71945
# [218]	valid_0's multi_logloss: 2.71928
# [219]	valid_0's multi_logloss: 2.71908
# [220]	valid_0's multi_logloss: 2.71886
# [221]	valid_0's multi_logloss: 2.71865
# [222]	valid_0's multi_logloss: 2.71847
# [223]	valid_0's multi_logloss: 2.71829
# [224]	valid_0's multi_logloss: 2.71812
# [225]	valid_0's multi_logloss: 2.71794
# [226]	valid_0's multi_logloss: 2.7177
# [227]	valid_0's multi_logloss: 2.71752
# [228]	valid_0's multi_logloss: 2.71728
# [229]	valid_0's multi_logloss: 2.71711
# [230]	valid_0's multi_logloss: 2.71697
# [231]	valid_0's multi_logloss: 2.7168
# [232]	valid_0's multi_logloss: 2.71666
# [233]	valid_0's multi_logloss: 2.71648
# [234]	valid_0's multi_logloss: 2.71628
# [235]	valid_0's multi_logloss: 2.71608
# [236]	valid_0's multi_logloss: 2.71594
# [237]	valid_0's multi_logloss: 2.71581
# [238]	valid_0's multi_logloss: 2.7157
# [239]	valid_0's multi_logloss: 2.71551
# [240]	valid_0's multi_logloss: 2.71533
# [241]	valid_0's multi_logloss: 2.71514
# [242]	valid_0's multi_logloss: 2.71496
# [243]	valid_0's multi_logloss: 2.71481
# [244]	valid_0's multi_logloss: 2.71464
# [245]	valid_0's multi_logloss: 2.71446
# [246]	valid_0's multi_logloss: 2.71432
# [247]	valid_0's multi_logloss: 2.71418
# [248]	valid_0's multi_logloss: 2.71404
# [249]	valid_0's multi_logloss: 2.71396
# [250]	valid_0's multi_logloss: 2.71379
# [251]	valid_0's multi_logloss: 2.7136
# [252]	valid_0's multi_logloss: 2.71347
# [253]	valid_0's multi_logloss: 2.71329
# [254]	valid_0's multi_logloss: 2.71308
# [255]	valid_0's multi_logloss: 2.71292
# [256]	valid_0's multi_logloss: 2.71276
# [257]	valid_0's multi_logloss: 2.71262
# [258]	valid_0's multi_logloss: 2.7125
# [259]	valid_0's multi_logloss: 2.71233
# [260]	valid_0's multi_logloss: 2.71216
# [261]	valid_0's multi_logloss: 2.7119
# [262]	valid_0's multi_logloss: 2.71181
# [263]	valid_0's multi_logloss: 2.71168
# [264]	valid_0's multi_logloss: 2.71152
# [265]	valid_0's multi_logloss: 2.71141
# [266]	valid_0's multi_logloss: 2.71126
# [267]	valid_0's multi_logloss: 2.7111
# [268]	valid_0's multi_logloss: 2.71091
# [269]	valid_0's multi_logloss: 2.71078
# [270]	valid_0's multi_logloss: 2.71062
# [271]	valid_0's multi_logloss: 2.71043
# [272]	valid_0's multi_logloss: 2.71024
# [273]	valid_0's multi_logloss: 2.71005
# [274]	valid_0's multi_logloss: 2.70997
# [275]	valid_0's multi_logloss: 2.70978
# [276]	valid_0's multi_logloss: 2.70962
# [277]	valid_0's multi_logloss: 2.70945
# [278]	valid_0's multi_logloss: 2.70923
# [279]	valid_0's multi_logloss: 2.70914
# [280]	valid_0's multi_logloss: 2.70902
# [281]	valid_0's multi_logloss: 2.70886
# [282]	valid_0's multi_logloss: 2.70875
# [283]	valid_0's multi_logloss: 2.70854
# [284]	valid_0's multi_logloss: 2.70844
# [285]	valid_0's multi_logloss: 2.70833
# [286]	valid_0's multi_logloss: 2.70816
# [287]	valid_0's multi_logloss: 2.70807
# [288]	valid_0's multi_logloss: 2.70796
# [289]	valid_0's multi_logloss: 2.70783
# [290]	valid_0's multi_logloss: 2.70771
# [291]	valid_0's multi_logloss: 2.7076
# [292]	valid_0's multi_logloss: 2.70744
# [293]	valid_0's multi_logloss: 2.70727
# [294]	valid_0's multi_logloss: 2.70717
# [295]	valid_0's multi_logloss: 2.70703
# [296]	valid_0's multi_logloss: 2.70691
# [297]	valid_0's multi_logloss: 2.70684
# [298]	valid_0's multi_logloss: 2.70669
# [299]	valid_0's multi_logloss: 2.70657
# ...
# [194]	valid_0's multi_logloss: 2.91495
# [195]	valid_0's multi_logloss: 2.9149
# [196]	valid_0's multi_logloss: 2.91468
# [197]	valid_0's multi_logloss: 2.91457
# [198]	valid_0's multi_logloss: 2.91435
# [199]	valid_0's multi_logloss: 2.91418
# [200]	valid_0's multi_logloss: 2.91402
# [201]	valid_0's multi_logloss: 2.91386
# [202]	valid_0's multi_logloss: 2.91369
# [203]	valid_0's multi_logloss: 2.91361
# [204]	valid_0's multi_logloss: 2.91346
# [205]	valid_0's multi_logloss: 2.91337
# [206]	valid_0's multi_logloss: 2.91324
# [207]	valid_0's multi_logloss: 2.91317
# [208]	valid_0's multi_logloss: 2.913
# [209]	valid_0's multi_logloss: 2.91284
# [210]	valid_0's multi_logloss: 2.91272
# [211]	valid_0's multi_logloss: 2.91258
# [212]	valid_0's multi_logloss: 2.91232
# [213]	valid_0's multi_logloss: 2.91216
# [214]	valid_0's multi_logloss: 2.91204
# [215]	valid_0's multi_logloss: 2.91191
# [216]	valid_0's multi_logloss: 2.91181
# [217]	valid_0's multi_logloss: 2.91172
# [218]	valid_0's multi_logloss: 2.91156
# [219]	valid_0's multi_logloss: 2.91149
# [220]	valid_0's multi_logloss: 2.91143
# [221]	valid_0's multi_logloss: 2.91129
# [222]	valid_0's multi_logloss: 2.9112
# [223]	valid_0's multi_logloss: 2.91098
# [224]	valid_0's multi_logloss: 2.91088
# [225]	valid_0's multi_logloss: 2.91081
# [226]	valid_0's multi_logloss: 2.91072
# [227]	valid_0's multi_logloss: 2.91059
# [228]	valid_0's multi_logloss: 2.91051
# [229]	valid_0's multi_logloss: 2.91043
# [230]	valid_0's multi_logloss: 2.91033
# [231]	valid_0's multi_logloss: 2.9103
# [232]	valid_0's multi_logloss: 2.91021
# [233]	valid_0's multi_logloss: 2.91011
# [234]	valid_0's multi_logloss: 2.91003
# [235]	valid_0's multi_logloss: 2.90989
# [236]	valid_0's multi_logloss: 2.90975
# [237]	valid_0's multi_logloss: 2.9097
# [238]	valid_0's multi_logloss: 2.90967
# [239]	valid_0's multi_logloss: 2.90955
# [240]	valid_0's multi_logloss: 2.90948
# [241]	valid_0's multi_logloss: 2.90944
# [242]	valid_0's multi_logloss: 2.90931
# [243]	valid_0's multi_logloss: 2.90919
# [244]	valid_0's multi_logloss: 2.90916
# [245]	valid_0's multi_logloss: 2.90906
# [246]	valid_0's multi_logloss: 2.90901
# [247]	valid_0's multi_logloss: 2.90893
# [248]	valid_0's multi_logloss: 2.90887
# [249]	valid_0's multi_logloss: 2.90886
# [250]	valid_0's multi_logloss: 2.90879
# [251]	valid_0's multi_logloss: 2.90873
# [252]	valid_0's multi_logloss: 2.90876
# [253]	valid_0's multi_logloss: 2.90872
# [254]	valid_0's multi_logloss: 2.90868
# [255]	valid_0's multi_logloss: 2.90861
# [256]	valid_0's multi_logloss: 2.90857
# [257]	valid_0's multi_logloss: 2.90854
# [258]	valid_0's multi_logloss: 2.90848
# [259]	valid_0's multi_logloss: 2.90843
# [260]	valid_0's multi_logloss: 2.90844
# [261]	valid_0's multi_logloss: 2.9084
# [262]	valid_0's multi_logloss: 2.9084
# [263]	valid_0's multi_logloss: 2.90838
# [264]	valid_0's multi_logloss: 2.90834
# [265]	valid_0's multi_logloss: 2.90837
# [266]	valid_0's multi_logloss: 2.9083
# [267]	valid_0's multi_logloss: 2.90832
# [268]	valid_0's multi_logloss: 2.90828
# [269]	valid_0's multi_logloss: 2.90818
# [270]	valid_0's multi_logloss: 2.90817
# [271]	valid_0's multi_logloss: 2.90814
# [272]	valid_0's multi_logloss: 2.90817
# [273]	valid_0's multi_logloss: 2.90808
# [274]	valid_0's multi_logloss: 2.90808
# [275]	valid_0's multi_logloss: 2.90808
# [276]	valid_0's multi_logloss: 2.90803
# [277]	valid_0's multi_logloss: 2.90801
# [278]	valid_0's multi_logloss: 2.90796
# [279]	valid_0's multi_logloss: 2.90792
# [280]	valid_0's multi_logloss: 2.90793
# [281]	valid_0's multi_logloss: 2.90792
# [282]	valid_0's multi_logloss: 2.90787
# [283]	valid_0's multi_logloss: 2.90783
# [284]	valid_0's multi_logloss: 2.90779
# [285]	valid_0's multi_logloss: 2.90774
# [286]	valid_0's multi_logloss: 2.9077
# [287]	valid_0's multi_logloss: 2.9077
# [288]	valid_0's multi_logloss: 2.90761
# [289]	valid_0's multi_logloss: 2.90757
# [290]	valid_0's multi_logloss: 2.90752
# [291]	valid_0's multi_logloss: 2.90744
# [292]	valid_0's multi_logloss: 2.90736
# [293]	valid_0's multi_logloss: 2.9073
# [294]	valid_0's multi_logloss: 2.90731
# [295]	valid_0's multi_logloss: 2.90729
# [296]	valid_0's multi_logloss: 2.90717
# [297]	valid_0's multi_logloss: 2.90715
# [298]	valid_0's multi_logloss: 2.90709
# [299]	valid_0's multi_logloss: 2.90709
# [300]	valid_0's multi_logloss: 2.90711
# [301]	valid_0's multi_logloss: 2.90712
# [302]	valid_0's multi_logloss: 2.90708
# [303]	valid_0's multi_logloss: 2.90704
# [304]	valid_0's multi_logloss: 2.90698
# [305]	valid_0's multi_logloss: 2.907
# [306]	valid_0's multi_logloss: 2.90694
# [307]	valid_0's multi_logloss: 2.9069
# [308]	valid_0's multi_logloss: 2.90688
# [309]	valid_0's multi_logloss: 2.90684
# [310]	valid_0's multi_logloss: 2.9068
# [311]	valid_0's multi_logloss: 2.90679
# [312]	valid_0's multi_logloss: 2.90683
# [313]	valid_0's multi_logloss: 2.90685
# [314]	valid_0's multi_logloss: 2.90686
# [315]	valid_0's multi_logloss: 2.90684
# [316]	valid_0's multi_logloss: 2.90687
# [317]	valid_0's multi_logloss: 2.90688
# [318]	valid_0's multi_logloss: 2.90688
# [319]	valid_0's multi_logloss: 2.90688
# [320]	valid_0's multi_logloss: 2.9069
# [321]	valid_0's multi_logloss: 2.90686
# Early stopping, best iteration is:
# [311]	valid_0's multi_logloss: 2.90679
# 0.01430422062093496
# [1]	valid_0's multi_logloss: 2.92636
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 2.92527
# [3]	valid_0's multi_logloss: 2.92437
# [4]	valid_0's multi_logloss: 2.92341
# [5]	valid_0's multi_logloss: 2.92243
# [6]	valid_0's multi_logloss: 2.92163
# [7]	valid_0's multi_logloss: 2.9208
# [8]	valid_0's multi_logloss: 2.92009
# [9]	valid_0's multi_logloss: 2.91937
# [10]	valid_0's multi_logloss: 2.91856
# [11]	valid_0's multi_logloss: 2.91783
# [12]	valid_0's multi_logloss: 2.91718
# [13]	valid_0's multi_logloss: 2.91645
# [14]	valid_0's multi_logloss: 2.91564
# [15]	valid_0's multi_logloss: 2.91493
# [16]	valid_0's multi_logloss: 2.91432
# [17]	valid_0's multi_logloss: 2.91365
# [18]	valid_0's multi_logloss: 2.91296
# [19]	valid_0's multi_logloss: 2.91232
# [20]	valid_0's multi_logloss: 2.91159
# [21]	valid_0's multi_logloss: 2.91083
# [22]	valid_0's multi_logloss: 2.91035
# [23]	valid_0's multi_logloss: 2.90971
# [24]	valid_0's multi_logloss: 2.90913
# [25]	valid_0's multi_logloss: 2.90851
# [26]	valid_0's multi_logloss: 2.908
# [27]	valid_0's multi_logloss: 2.90746
# [28]	valid_0's multi_logloss: 2.90689
# [29]	valid_0's multi_logloss: 2.9064
# [30]	valid_0's multi_logloss: 2.90581
# [31]	valid_0's multi_logloss: 2.90529
# [32]	valid_0's multi_logloss: 2.90473
# [33]	valid_0's multi_logloss: 2.90426
# [34]	valid_0's multi_logloss: 2.90369
# [35]	valid_0's multi_logloss: 2.90317
# [36]	valid_0's multi_logloss: 2.90264
# [37]	valid_0's multi_logloss: 2.90203
# [38]	valid_0's multi_logloss: 2.90159
# [39]	valid_0's multi_logloss: 2.90116
# [40]	valid_0's multi_logloss: 2.90071
# [41]	valid_0's multi_logloss: 2.90012
# [42]	valid_0's multi_logloss: 2.89967
# [43]	valid_0's multi_logloss: 2.89919
# [44]	valid_0's multi_logloss: 2.89865
# [45]	valid_0's multi_logloss: 2.89812
# [46]	valid_0's multi_logloss: 2.89758
# [47]	valid_0's multi_logloss: 2.89706
# [48]	valid_0's multi_logloss: 2.89659
# [49]	valid_0's multi_logloss: 2.89615
# [50]	valid_0's multi_logloss: 2.89561
# [51]	valid_0's multi_logloss: 2.8951
# [52]	valid_0's multi_logloss: 2.89467
# [53]	valid_0's multi_logloss: 2.89429
# [54]	valid_0's multi_logloss: 2.89382
# [55]	valid_0's multi_logloss: 2.89338
# [56]	valid_0's multi_logloss: 2.89293
# [57]	valid_0's multi_logloss: 2.89259
# [58]	valid_0's multi_logloss: 2.8923
# [59]	valid_0's multi_logloss: 2.89195
# [60]	valid_0's multi_logloss: 2.89156
# [61]	valid_0's multi_logloss: 2.89122
# [62]	valid_0's multi_logloss: 2.89088
# [63]	valid_0's multi_logloss: 2.89047
# [64]	valid_0's multi_logloss: 2.89014
# [65]	valid_0's multi_logloss: 2.88991
# [66]	valid_0's multi_logloss: 2.88954
# [67]	valid_0's multi_logloss: 2.8892
# [68]	valid_0's multi_logloss: 2.88884
# [69]	valid_0's multi_logloss: 2.8885
# [70]	valid_0's multi_logloss: 2.88815
# [71]	valid_0's multi_logloss: 2.88777
# [72]	valid_0's multi_logloss: 2.88741
# [73]	valid_0's multi_logloss: 2.88713
# [74]	valid_0's multi_logloss: 2.8868
# [75]	valid_0's multi_logloss: 2.88645
# [76]	valid_0's multi_logloss: 2.88608
# [77]	valid_0's multi_logloss: 2.88574
# [78]	valid_0's multi_logloss: 2.88536
# [79]	valid_0's multi_logloss: 2.88501
# [80]	valid_0's multi_logloss: 2.88463
# [81]	valid_0's multi_logloss: 2.88438
# [82]	valid_0's multi_logloss: 2.88402
# [83]	valid_0's multi_logloss: 2.88377
# [84]	valid_0's multi_logloss: 2.8835
# [85]	valid_0's multi_logloss: 2.88322
# [86]	valid_0's multi_logloss: 2.8829
# [87]	valid_0's multi_logloss: 2.88264
# [88]	valid_0's multi_logloss: 2.88234
# [89]	valid_0's multi_logloss: 2.88202
# [90]	valid_0's multi_logloss: 2.88174
# [91]	valid_0's multi_logloss: 2.88141
# [92]	valid_0's multi_logloss: 2.88114
# [93]	valid_0's multi_logloss: 2.8809
# [94]	valid_0's multi_logloss: 2.88058
# [95]	valid_0's multi_logloss: 2.88032
# [96]	valid_0's multi_logloss: 2.88006
# [97]	valid_0's multi_logloss: 2.87984
# [98]	valid_0's multi_logloss: 2.87963
# [99]	valid_0's multi_logloss: 2.87935
# [100]	valid_0's multi_logloss: 2.87905
# [101]	valid_0's multi_logloss: 2.8788
# [102]	valid_0's multi_logloss: 2.87851
# [103]	valid_0's multi_logloss: 2.87829
# [104]	valid_0's multi_logloss: 2.87806
# [105]	valid_0's multi_logloss: 2.87779
# [106]	valid_0's multi_logloss: 2.87747
# [107]	valid_0's multi_logloss: 2.87718
# [108]	valid_0's multi_logloss: 2.87691
# [109]	valid_0's multi_logloss: 2.8767
# [110]	valid_0's multi_logloss: 2.87643
# [111]	valid_0's multi_logloss: 2.87619
# [112]	valid_0's multi_logloss: 2.87594
# [113]	valid_0's multi_logloss: 2.8757
# [114]	valid_0's multi_logloss: 2.87549
# [115]	valid_0's multi_logloss: 2.87524
# [116]	valid_0's multi_logloss: 2.87507
# [117]	valid_0's multi_logloss: 2.87484
# [118]	valid_0's multi_logloss: 2.87463
# [119]	valid_0's multi_logloss: 2.87445
# [120]	valid_0's multi_logloss: 2.87419
# [121]	valid_0's multi_logloss: 2.87399
# [122]	valid_0's multi_logloss: 2.87387
# [123]	valid_0's multi_logloss: 2.87364
# [124]	valid_0's multi_logloss: 2.87341
# [125]	valid_0's multi_logloss: 2.87329
# [126]	valid_0's multi_logloss: 2.87308
# [127]	valid_0's multi_logloss: 2.8729
# [128]	valid_0's multi_logloss: 2.87273
# [129]	valid_0's multi_logloss: 2.87252
# [130]	valid_0's multi_logloss: 2.87232
# [131]	valid_0's multi_logloss: 2.87217
# [132]	valid_0's multi_logloss: 2.87201
# [133]	valid_0's multi_logloss: 2.87178
# [134]	valid_0's multi_logloss: 2.87163
# [135]	valid_0's multi_logloss: 2.87146
# [136]	valid_0's multi_logloss: 2.87121
# [137]	valid_0's multi_logloss: 2.87097
# [138]	valid_0's multi_logloss: 2.8708
# [139]	valid_0's multi_logloss: 2.87057
# [140]	valid_0's multi_logloss: 2.8703
# [141]	valid_0's multi_logloss: 2.87012
# [142]	valid_0's multi_logloss: 2.86996
# [143]	valid_0's multi_logloss: 2.86966
# [144]	valid_0's multi_logloss: 2.86949
# [145]	valid_0's multi_logloss: 2.86925
# [146]	valid_0's multi_logloss: 2.8691
# [147]	valid_0's multi_logloss: 2.86884
# [148]	valid_0's multi_logloss: 2.8686
# [149]	valid_0's multi_logloss: 2.86846
# [150]	valid_0's multi_logloss: 2.86816
# [151]	valid_0's multi_logloss: 2.86797
# [152]	valid_0's multi_logloss: 2.86768
# [153]	valid_0's multi_logloss: 2.86752
# [154]	valid_0's multi_logloss: 2.86733
# [155]	valid_0's multi_logloss: 2.86706
# [156]	valid_0's multi_logloss: 2.86686
# [157]	valid_0's multi_logloss: 2.86669
# [158]	valid_0's multi_logloss: 2.86657
# [159]	valid_0's multi_logloss: 2.86635
# [160]	valid_0's multi_logloss: 2.86617
# [161]	valid_0's multi_logloss: 2.86601
# [162]	valid_0's multi_logloss: 2.8658
# [163]	valid_0's multi_logloss: 2.86568
# [164]	valid_0's multi_logloss: 2.86553
# [165]	valid_0's multi_logloss: 2.86541
# [166]	valid_0's multi_logloss: 2.86522
# [167]	valid_0's multi_logloss: 2.86507
# [168]	valid_0's multi_logloss: 2.86491
# [169]	valid_0's multi_logloss: 2.8648
# [170]	valid_0's multi_logloss: 2.86461
# [171]	valid_0's multi_logloss: 2.86446
# [172]	valid_0's multi_logloss: 2.86435
# [173]	valid_0's multi_logloss: 2.8642
# [174]	valid_0's multi_logloss: 2.86406
# [175]	valid_0's multi_logloss: 2.86392
# [176]	valid_0's multi_logloss: 2.86379
# [177]	valid_0's multi_logloss: 2.86362
# [178]	valid_0's multi_logloss: 2.8635
# [179]	valid_0's multi_logloss: 2.8634
# [180]	valid_0's multi_logloss: 2.86327
# [181]	valid_0's multi_logloss: 2.8632
# [182]	valid_0's multi_logloss: 2.86309
# [183]	valid_0's multi_logloss: 2.86293
# [184]	valid_0's multi_logloss: 2.86282
# [185]	valid_0's multi_logloss: 2.86266
# [186]	valid_0's multi_logloss: 2.86252
# [187]	valid_0's multi_logloss: 2.86238
# [188]	valid_0's multi_logloss: 2.86226
# [189]	valid_0's multi_logloss: 2.86203
# [190]	valid_0's multi_logloss: 2.86193
# [191]	valid_0's multi_logloss: 2.86183
# [192]	valid_0's multi_logloss: 2.86177
# [193]	valid_0's multi_logloss: 2.86161
# [194]	valid_0's multi_logloss: 2.86147
# [195]	valid_0's multi_logloss: 2.8614
# [196]	valid_0's multi_logloss: 2.86122
# [197]	valid_0's multi_logloss: 2.86111
# [198]	valid_0's multi_logloss: 2.86104
# [199]	valid_0's multi_logloss: 2.8609
# [200]	valid_0's multi_logloss: 2.86083
# [201]	valid_0's multi_logloss: 2.86078
# [202]	valid_0's multi_logloss: 2.86066
# [203]	valid_0's multi_logloss: 2.86057
# [204]	valid_0's multi_logloss: 2.86044
# [205]	valid_0's multi_logloss: 2.86039
# [206]	valid_0's multi_logloss: 2.86022
# [207]	valid_0's multi_logloss: 2.8601
# [208]	valid_0's multi_logloss: 2.85999
# [209]	valid_0's multi_logloss: 2.85986
# [210]	valid_0's multi_logloss: 2.85979
# [211]	valid_0's multi_logloss: 2.85972
# [212]	valid_0's multi_logloss: 2.85955
# [213]	valid_0's multi_logloss: 2.85946
# [214]	valid_0's multi_logloss: 2.85937
# [215]	valid_0's multi_logloss: 2.85929
# [216]	valid_0's multi_logloss: 2.85926
# [217]	valid_0's multi_logloss: 2.85916
# [218]	valid_0's multi_logloss: 2.85907
# [219]	valid_0's multi_logloss: 2.85893
# [220]	valid_0's multi_logloss: 2.85888
# [221]	valid_0's multi_logloss: 2.85884
# [222]	valid_0's multi_logloss: 2.85878
# [223]	valid_0's multi_logloss: 2.85871
# [224]	valid_0's multi_logloss: 2.85866
# [225]	valid_0's multi_logloss: 2.85853
# [226]	valid_0's multi_logloss: 2.85843
# [227]	valid_0's multi_logloss: 2.85838
# [228]	valid_0's multi_logloss: 2.8583
# [229]	valid_0's multi_logloss: 2.85823
# [230]	valid_0's multi_logloss: 2.85819
# [231]	valid_0's multi_logloss: 2.85815
# [232]	valid_0's multi_logloss: 2.85807
# [233]	valid_0's multi_logloss: 2.85804
# [234]	valid_0's multi_logloss: 2.85799
# [235]	valid_0's multi_logloss: 2.8579
# [236]	valid_0's multi_logloss: 2.85787
# [237]	valid_0's multi_logloss: 2.85777
# [238]	valid_0's multi_logloss: 2.85775
# [239]	valid_0's multi_logloss: 2.85775
# [240]	valid_0's multi_logloss: 2.85773
# [241]	valid_0's multi_logloss: 2.85768
# [242]	valid_0's multi_logloss: 2.85761
# [243]	valid_0's multi_logloss: 2.85759
# [244]	valid_0's multi_logloss: 2.85762
# [245]	valid_0's multi_logloss: 2.85752
# [246]	valid_0's multi_logloss: 2.85748
# [247]	valid_0's multi_logloss: 2.85743
# [248]	valid_0's multi_logloss: 2.85739
# [249]	valid_0's multi_logloss: 2.85735
# [250]	valid_0's multi_logloss: 2.85737
# [251]	valid_0's multi_logloss: 2.85736
# [252]	valid_0's multi_logloss: 2.85731
# [253]	valid_0's multi_logloss: 2.8573
# [254]	valid_0's multi_logloss: 2.85731
# [255]	valid_0's multi_logloss: 2.85724
# [256]	valid_0's multi_logloss: 2.85715
# [257]	valid_0's multi_logloss: 2.85717
# [258]	valid_0's multi_logloss: 2.85713
# [259]	valid_0's multi_logloss: 2.85712
# [260]	valid_0's multi_logloss: 2.8571
# [261]	valid_0's multi_logloss: 2.85703
# [262]	valid_0's multi_logloss: 2.85703
# [263]	valid_0's multi_logloss: 2.85703
# [264]	valid_0's multi_logloss: 2.85705
# [265]	valid_0's multi_logloss: 2.85698
# [266]	valid_0's multi_logloss: 2.85696
# [267]	valid_0's multi_logloss: 2.857
# [268]	valid_0's multi_logloss: 2.85699
# [269]	valid_0's multi_logloss: 2.85697
# [270]	valid_0's multi_logloss: 2.85701
# [271]	valid_0's multi_logloss: 2.85701
# [272]	valid_0's multi_logloss: 2.85702
# [273]	valid_0's multi_logloss: 2.85698
# [274]	valid_0's multi_logloss: 2.857
# [275]	valid_0's multi_logloss: 2.85701
# [276]	valid_0's multi_logloss: 2.85702
# Early stopping, best iteration is:
# [266]	valid_0's multi_logloss: 2.85696
# 0.014107804925202371
# crps list: [0.012512199342127762, 0.012279083322790119, 0.011910765460093366, 0.01430422062093496, 0.014107804925202371]
# average crps: 0.013022814734229716

# %% [markdown]
# * when remove distance not remove
# - crps list: [0.012514359748910374, 0.012293136540622739, 0.011917542973168584, 0.014300445408400187, 0.014112479366658283]
# - average crps: 0.013027592807552033
# -
# * when remove runner_height let's remove
# - crps list: [0.012518957380868919, 0.012294457382043053, 0.01190779864856263, 0.01430314087491144, 0.01409385891437838]
# - average crps: 0.013023642640152884
# -
# * when remove rushervoronoi
# - average crps: 0.013035
# -
# - when remove stadyumtype
# - didn't change very much
# -
# - add turf without removing grass: not add original turf
# - crps list: [0.012523522833408027, 0.012294163855566078, 0.011910469763969561, 0.014306666173715683, 0.014099070102064456]
# - average crps: 0.013026778545744761
# -
# - when add quarter: let's add quarter
# - crps list: [0.012512204814002014, 0.012288398968811972, 0.011909900326202445, 0.01429841305381303, 0.014103696707896272]
# - average crps: 0.013022522774145145
# -
# - modify offenseformation ace to shotgun
# - crps list: [0.012512199342127762, 0.012279083322790119, 0.011910765460093366, 0.01430422062093496, 0.014107804925202371]
# - average crps: 0.013022814734229716

# %%
X_train.columns
# Out:
# Index(['Team', 'S', 'A', 'Dis', 'NflId', 'JerseyNumber', 'Season', 'Quarter',
#        'Down', 'Distance', 'HomeScoreBeforePlay', 'VisitorScoreBeforePlay',
#        'OffenseFormation', 'OffensePersonnel', 'DefendersInTheBox',
#        'DefensePersonnel', 'PlayerWeight', 'PlayerCollegeName', 'Week',
#        'Stadium', 'Location', 'StadiumType', 'GameWeather', 'Temperature',
#        'Humidity', 'WindSpeed', 'WindDirection', 'YardLine', 'X', 'Y',
#        'Orientation', 'Dir', 'age', 'Momentum', 'Dir_cos', 'Momentum_cos',
#        'time_quarter', 'time_end', 'Grass', 'DefendersInTheBox_vs_Distance',
#        'DefenseAveX', 'DefenseAveY', 'DefenseAveMomentum',
#        'OffenseAveMomentum', 'DefenseAveMomentum_cos',
#        'OffenseAveMomentum_cos', 'DefenseStdX', 'OffenseStdX', 'DefenseStdY',
#        'OffenseStdY', 'DefenseStdMomentum', 'OffenseStdMomentum',
#        'DefenseStdMomentum_cos', 'OffenseStdMomentum_cos',
#        'RunnerToDefenseCentoid', 'RunnerToOffenseCentoid', 'DefenseSpreadX',
#        'OffenseSpreadX', 'RunnerToScrimmage', 'MinTackleTime',
#        '1stDefender_Momentum_cos', '1stOffenser_Momentum_cos', 'RusherVoronoi',
#        'FirstDefenderVoronoi', 'PitchControl'],
#       dtype='object')

# %%
feature_importance_df.sort_values("Average").head(70).reset_index(drop=True)
# Out:
#                           Feature  Fold_1  Fold_2  Fold_3  Fold_4  Fold_5  \
# 0                         Quarter     230     164     199     145     204
# 1                           Grass     466     251     298     221     158
# 2                            Team     356     709     531     318     331
# 3                OffenseFormation    1139     786    1089     669     466
# 4                            Down     907    1305    1250     693     498
# 5                          Season    1978    1908    2591    1503    1491
# 6               DefendersInTheBox    2356    1574    2309    1955    1555
# 7                DefensePersonnel    2387    3145    2033    1559    1713
# 8                     StadiumType    3013    4802    3866    1863    1711
# 9                OffensePersonnel    2575    3757    3817    3164    2499
# 10                    GameWeather    3811    3985    4341    3260    1775
# 11            HomeScoreBeforePlay    3805    4962    4089    2062    3183
# 12                           Week    5472    5200    3811    2013    2736
# 13                       Distance    3596    6149    5862    3909    1301
# 14                  RusherVoronoi    4180    4683    5895    3741    2883
# 15                            Dis    4667    6057    4149    3516    3398
# 16         VisitorScoreBeforePlay    4388    6198    4282    3813    3586
# 17                       Location    4667    6698    4292    4103    2594
# 18                      WindSpeed    5588    5407    4649    2836    4035
# 19                  WindDirection    5423    6853    5003    3235    2701
# 20                   PlayerWeight    6154    5977    4493    3901    2970
# 21                        Stadium    5829    5886    5915    4607    3371
# 22                   JerseyNumber    5796    7549    5728    4229    3238
# 23  DefendersInTheBox_vs_Distance    9432    6131    4306    4317    3291
# 24                    Orientation    6628    6704    6585    3750    4116
# 25                       Humidity    6749    7473    5924    3799    4152
# 26                    Temperature    6705    6853    6599    4296    4249
# 27                              S    7503    7118    6338    3890    4544
# 28                    OffenseStdY    5646    7315    6665    5351    4456
# 29             OffenseAveMomentum    7450    7843    6016    3932    4257
# 30                    DefenseStdY    7350    7311    6503    4781    4209
# 31                    OffenseStdX    7874    7976    6325    4962    4167
# 32                              X    7164    7337    8567    4355    4434
# 33         RunnerToDefenseCentoid    6647    7915    7905    5297    4267
# 34                       Momentum    7258    9035    8216    4819    4729
# 35                              Y    8058   10230    8991    4257    4657
# 36                    DefenseAveX    7151   10395    8435    6567    3802
# 37                 OffenseSpreadX    8343   10706    6473    5747    5322
# 38                          NflId    8056    8880   10483    5251    4695
# 39                    DefenseStdX    9014    9471    7829    6962    5263
# 40         RunnerToOffenseCentoid    8700   10991    8837    5199    4889
# 41                            Dir    8897   10059    9035    5767    4970
# 42         OffenseStdMomentum_cos    7935   11024    8068    5925    5850
# 43              PlayerCollegeName    8595    9843    8284    6454    5804
# 44             DefenseAveMomentum    7796   10508    9327    6348    5024
# 45                    DefenseAveY    8435    9826   10165    6689    5157
# 46                   time_quarter    8595   12302    9229    5077    5501
# 47                            age   10963    9504    9524    5665    5238
# 48         OffenseAveMomentum_cos    9711   10726   10239    5285    5337
# 49                       time_end    8801   12130    8915    6263    6427
# 50                 DefenseSpreadX   10214   11756    9155    6214    5704
# 51         DefenseStdMomentum_cos    9926    9995   10913    6788    6090
# 52             DefenseStdMomentum    9191   11339   11669    6442    5158
# 53                        Dir_cos    9757   12716   10550    5991    5775
# 54             OffenseStdMomentum   10025   12915   10431    7264    5947
# 55                  MinTackleTime   11281   13656    9938    5313    7167
# 56              RunnerToScrimmage   11067   13697    9877    7423    5742
# 57                   PitchControl   11626   13101   10438    7201    5623
# 58           FirstDefenderVoronoi   10347   13616   11435    6799    6139
# 59                       YardLine   11332   12925   12863    7171    6983
# 60         DefenseAveMomentum_cos   14275   13076   12210    7979    6704
# 61       1stOffenser_Momentum_cos   13195   12974   12741    8559    7560
# 62                   Momentum_cos   13190   14316   14111   10311    8388
# 63       1stDefender_Momentum_cos   13920   16180   13749   10010    8526
# 64                              A   21292   22386   19559   19157   18539
#
#     Average          Std        Cv
# 0     188.4    30.216552  0.160385
# 1     278.8   104.037301  0.373161
# 2     449.0   151.035095  0.336381
# 3     829.8   254.131777  0.306257
# 4     930.6   311.879849  0.335138
# 5    1894.2   402.082280  0.212270
# 6    1949.8   343.843802  0.176348
# 7    2167.4   565.441279  0.260885
# 8    3051.0  1178.016468  0.386108
# 9    3162.4   559.855553  0.177035
# 10   3434.4   900.103905  0.262085
# 11   3620.2   966.797062  0.267056
# 12   3846.4  1346.878257  0.350166
# 13   4163.4  1755.439842  0.421636
# 14   4276.4  1002.267350  0.234372
# 15   4357.4   965.020746  0.221467
# 16   4453.4   920.845177  0.206774
# 17   4470.8  1318.221438  0.294851
# 18   4503.0  1001.366067  0.222378
# 19   4643.0  1508.371837  0.324870
# 20   4699.0  1218.112474  0.259228
# 21   5121.6  1004.352448  0.196101
# 22   5308.0  1475.517943  0.277980
# 23   5495.4  2170.874718  0.395035
# 24   5556.6  1331.252283  0.239580
# 25   5619.4  1433.298936  0.255063
# 26   5740.4  1201.340185  0.209278
# 27   5878.6  1422.780601  0.242027
# 28   5886.6  1003.753476  0.170515
# 29   5899.6  1597.728212  0.270820
# 30   6030.8  1302.545876  0.215982
# 31   6260.8  1524.422960  0.243487
# 32   6371.4  1685.268240  0.264505
# 33   6406.2  1441.344150  0.224992
# 34   6811.4  1756.291388  0.257846
# 35   7238.6  2376.779047  0.328348
# 36   7270.0  2175.235344  0.299207
# 37   7318.2  1984.704048  0.271201
# 38   7473.0  2192.450957  0.293383
# 39   7707.8  1507.513635  0.195583
# 40   7723.2  2335.700357  0.302427
# 41   7745.6  1997.944304  0.257946
# 42   7760.4  1886.505192  0.243094
# 43   7796.0  1472.126489  0.188831
# 44   7800.6  1973.802787  0.253032
# 45   8054.4  1897.224246  0.235551
# 46   8140.8  2648.073896  0.325284
# 47   8178.8  2292.814114  0.280336
# 48   8259.6  2428.890743  0.294069
# 49   8507.2  2132.649282  0.250688
# 50   8608.6  2321.757920  0.269702
# 51   8742.4  1925.425937  0.220240
# 52   8759.8  2594.101417  0.296137
# 53   8957.8  2691.839772  0.300502
# 54   9316.4  2460.063869  0.264057
# 55   9471.0  2953.160815  0.311811
# 56   9561.2  2779.575248  0.290714
# 57   9597.8  2779.770739  0.289626
# 58   9667.2  2823.297108  0.292049
# 59  10254.8  2657.349537  0.259132
# 60  10848.8  2965.375214  0.273337
# 61  11005.8  2430.542935  0.220842
# 62  12063.2  2328.758072  0.193046
# 63  12477.0  2796.745680  0.224152
# 64  20186.6  1430.231674  0.070851

# %%
#cv_low_feats = list(feature_importance_df[feature_importance_df.Cv <= 0.25]["Feature"])
#X_train_mod = X_train[cv_low_feats]
#n_folds=5
#kf=KFold(n_splits = n_folds, random_state=1108)
#average_crps = 0
##models = []
#crps_scores = []
#lgbm_params = {
#    "objective" : "multiclass",
#    "metric" : "multi_logloss", 
#    "tree_learner": "serial",
#    "max_depth" : -1,
#    "boosting": 'gbdt',
#    "num_class": 199,
#    "num_leaves" : 13,
#    "learning_rate" : 0.01,
    #"bagging_freq": 5,
    #"bagging_fraction" : 0.4,
    #"feature_fraction" : 0.05,
    #"min_data_in_leaf": 80,
#}
#evals_result = {}
#feature_impor = pd.DataFrame(list(X_train_mod.columns), columns=["Feature"])
#for i , (train_index, test_index) in enumerate(kf.split(X_train_mod, y_train)):
#    X_train2= X_train_mod.iloc[train_index,:]
#    y_train2= y_train.iloc[train_index]
#    X_test2= X_train_mod.iloc[test_index,:]
#    y_test2= y_train.iloc[test_index]
#    lgb_train = lgb.Dataset(X_train2, y_train2)
#    lgb_eval = lgb.Dataset(X_test2, y_test2, reference=lgb_train)
    
#    clf = lgb.train(
#        lgbm_params, lgb_train,
#        valid_sets=lgb_eval,
#        num_boost_round=100000,
#        early_stopping_rounds=10,
        #evals_result=evals_result,
        #feval=crps_score,
#    )
    
    #models.append(clf)
#    temp_predict = clf.predict(X_test2, num_iteration = clf.best_iteration)
#    score = simple_crps(y_test2, temp_predict)
#    print(score)
#    crps_scores.append(score)
#    average_crps += score / n_folds
#    feature_impor["Fold_"+str(i+1)] = clf.feature_importance()
    
#feature_impor["Average"] = np.mean(feature_impor.iloc[:,1:n_folds+1], axis=1)
#feature_impor["Std"] = np.std(feature_impor.iloc[:,1:n_folds+1], axis=1)
#feature_impor["Cv"] = feature_impor["Std"] / feature_impor["Average"]
#print('crps list:', crps_scores)
#print('average crps:',average_crps)

# %%
#X_train_mod.columns

# %%
#feature_impor.sort_values("Average").head(70).reset_index(drop=True)

# %% [markdown]
# # prediction

# %%
for (test_df, sample_prediction_df) in env.iter_test():
    X_test = transform_data(test_df)
    for f in X_test.columns:
        if X_test[f].dtype=='object':
            X_test[f] = X_test[f].map(lambda x:x if x in set(X_train[f]) else -999)
    for f in X_test.columns:
        if X_test[f].dtype=='object': 
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(X_train[f])+[-999])
            X_test[f] = lbl.transform(list(X_test[f])) 
    pred_value = 0
    for model in models:
        pred_value += model.predict(X_test)[0]/5
    pred_data = np.clip(np.cumsum(pred_value), 0, 1)
    pred_data = np.array(pred_data).reshape(1,199)
    pred_target = pd.DataFrame(index = sample_prediction_df.index, \
                               columns = sample_prediction_df.columns, \
                               data = pred_data)
    env.predict(pred_target)
env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.

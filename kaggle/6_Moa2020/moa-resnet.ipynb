# %% [markdown]
# - 1st resnet

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
json_file_path = '../input/moapredictors/main_predictors.json'

with open(json_file_path, 'r') as j:
    predictors = json.loads(j.read())
    predictors = predictors['start_predictors']

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 14

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[(vc==6)|(vc==12)|(vc==18)].index.sort_values()
vc2 = vc.loc[(vc!=6)&(vc!=12)&(vc!=18)].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[0, 6, 5, ..., 1, 1, 6]], dtype=int8)

# %%
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
nontarget_dists.columns = ["target", "number"]
nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
print("first drop", len(drop_list1))
non_targets.drop(drop_list1, axis=1, inplace=True)
print("shape after 1st drop:", non_targets.shape)
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
print(len(non_target_feats))
# Out:
# first drop 71
# shape after 1st drop: (21948, 332)
# 331

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.6)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
len(drop_feats)

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=500, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 933) (3624, 933)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
predictors_index = []
for i in range(len(train.columns)):
    if train.columns[i] in predictors:
        predictors_index.append(i)

# %%
fn_train = train.copy()
fn_test = test.copy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_non_targets = non_targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.Linear(num_columns, 512)
        self.relu1 = nn.ELU()
        self.dense12 = nn.Linear(512, 256)
        
        self.batch_norm2 = nn.BatchNorm1d(256+len(predictors_index))
        self.dropout2 = nn.Dropout(0.1)
        self.dense2 = nn.Linear(256+len(predictors_index), 512)
        self.relu2 = nn.ReLU()
        self.batch_norm22 = nn.BatchNorm1d(512)
        self.dense22 = nn.Linear(512, 512)
        self.relu22 = nn.ELU()
        self.batch_norm23 = nn.BatchNorm1d(512)
        self.dense23 = nn.Linear(512, 256)
        self.relu23 = nn.ReLU()
        self.batch_norm24 = nn.BatchNorm1d(256)
        self.dense24 = nn.Linear(256, 256)
        self.relu24 = nn.ELU()
                
        self.batch_norm3 = nn.BatchNorm1d(256)
        self.dense3 = nn.Linear(256, 256)
        self.relu3 = nn.SELU()
        self.batch_norm32 = nn.BatchNorm1d(256)
        self.dense32 = nn.Linear(256, last_num)
        self.relu32 = nn.SELU()
        self.dense33 = nn.Linear(last_num, last_num)
        
    def forward(self, x1, x2):
        x1 = self.batch_norm1(x1)
        x1 = self.dropout1(x1)
        x1 = self.relu1(self.dense1(x1))
        x1 = self.dense12(x1)
        
        x3 = torch.cat([x1,x2],axis=1)
                
        x3 = self.batch_norm2(x3)
        x3 = self.dropout2(x3)
        x3 = self.relu2(self.dense2(x3))
        x3 = self.batch_norm22(x3)
        x3 = self.relu22(self.dense22(x3))
        x3 = self.batch_norm23(x3)
        x3 = self.relu23(self.dense23(x3))
        x3 = self.batch_norm24(x3)
        x3 = self.relu24(self.dense24(x3))
        
        x4 = (x1 + x3) / 2
        
        x4 = self.batch_norm3(x4)
        x4 = self.relu3(self.dense3(x4))
        x4 = self.batch_norm32(x4)
        x4 = self.relu32(self.dense32(x4))
        x4 = self.dense33(x4)
        
        return x4
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    train_epochs = 20
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te.values, dtype=torch.float32)
    X_test2 = torch.tensor(te.iloc[:][predictors].values, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test, X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr["fold"] == fold
        train_index = tr["fold"] != fold
        print("Fold "+str(fold+1))
        X_train1 = torch.tensor(tr[train_index].values, dtype=torch.float32)
        X_valid1 = torch.tensor(tr[valid_index].values, dtype=torch.float32)
        X_train2 = torch.tensor(tr[train_index][predictors].values, dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index][predictors].values, dtype=torch.float32)
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        X_train1 = X_train1[:,:-1]
        X_valid1 = X_valid1[:,:-1]
        
        train = torch.utils.data.TensorDataset(X_train1, X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid1, X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
            
        optimizer = optim.Adam(clf.parameters(), lr = 0.01, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))            
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, x_batch2, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Best: Epoch {} \t loss={:.5f} \t val_loss={:.5f} \t sm_loss={:.5f} \t sm_val_loss={:.5f} \t time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        pred_model = MoaModel(init_num, len(target_feats))
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
        for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
            y_pred = pred_model(x_batch, x_batch2).detach()
            oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        

        # test predcition --------------
        test_preds = np.zeros([test_len, target.shape[1]])
        for i, (x_batch,x_batch2,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch,x_batch2).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
    
    print("Seed {}".format(sample_seed))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4] 
    
for seed_ in seeds:
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Best: Epoch 1 	 loss=0.28359 	 val_loss=0.02099 	 sm_loss=0.28291 	 sm_val_loss=0.02092 	 time=2.44s
# Best: Epoch 2 	 loss=0.02080 	 val_loss=0.02058 	 sm_loss=0.02076 	 sm_val_loss=0.02059 	 time=1.75s
# Best: Epoch 3 	 loss=0.01958 	 val_loss=0.01904 	 sm_loss=0.01961 	 sm_val_loss=0.01899 	 time=1.80s
# Best: Epoch 6 	 loss=0.01841 	 val_loss=0.01874 	 sm_loss=0.01850 	 sm_val_loss=0.01881 	 time=1.99s
# Best: Epoch 7 	 loss=0.01803 	 val_loss=0.01834 	 sm_loss=0.01815 	 sm_val_loss=0.01840 	 time=2.17s
# Best: Epoch 9 	 loss=0.01775 	 val_loss=0.01790 	 sm_loss=0.01789 	 sm_val_loss=0.01796 	 time=1.86s
# Best: Epoch 10 	 loss=0.01750 	 val_loss=0.01786 	 sm_loss=0.01765 	 sm_val_loss=0.01789 	 time=1.79s
# Best: Epoch 11 	 loss=0.01737 	 val_loss=0.01761 	 sm_loss=0.01753 	 sm_val_loss=0.01770 	 time=1.87s
# Best: Epoch 12 	 loss=0.01720 	 val_loss=0.01761 	 sm_loss=0.01736 	 sm_val_loss=0.01763 	 time=1.90s
# Best: Epoch 13 	 loss=0.01694 	 val_loss=0.01732 	 sm_loss=0.01712 	 sm_val_loss=0.01743 	 time=1.78s
# Best: Epoch 14 	 loss=0.01672 	 val_loss=0.01720 	 sm_loss=0.01691 	 sm_val_loss=0.01729 	 time=1.81s
# Best: Epoch 15 	 loss=0.01649 	 val_loss=0.01709 	 sm_loss=0.01670 	 sm_val_loss=0.01718 	 time=1.78s
# Best: Epoch 16 	 loss=0.01626 	 val_loss=0.01700 	 sm_loss=0.01649 	 sm_val_loss=0.01707 	 time=1.79s
# Best: Epoch 18 	 loss=0.01585 	 val_loss=0.01693 	 sm_loss=0.01610 	 sm_val_loss=0.01700 	 time=1.88s
# Best: Epoch 20 	 loss=0.01557 	 val_loss=0.01693 	 sm_loss=0.01583 	 sm_val_loss=0.01700 	 time=1.73s
# Fold 1 log loss: 0.017012467890473126
# Fold 2
# Best: Epoch 1 	 loss=0.28745 	 val_loss=0.02170 	 sm_loss=0.28636 	 sm_val_loss=0.02138 	 time=1.77s
# Best: Epoch 2 	 loss=0.02122 	 val_loss=0.01999 	 sm_loss=0.02118 	 sm_val_loss=0.01999 	 time=1.76s
# Best: Epoch 3 	 loss=0.02025 	 val_loss=0.01981 	 sm_loss=0.02028 	 sm_val_loss=0.01976 	 time=1.97s
# Best: Epoch 4 	 loss=0.01940 	 val_loss=0.01915 	 sm_loss=0.01944 	 sm_val_loss=0.01915 	 time=2.61s
# Best: Epoch 5 	 loss=0.01913 	 val_loss=0.01909 	 sm_loss=0.01918 	 sm_val_loss=0.01910 	 time=1.77s
# Best: Epoch 8 	 loss=0.01797 	 val_loss=0.01822 	 sm_loss=0.01809 	 sm_val_loss=0.01826 	 time=1.81s
# Best: Epoch 10 	 loss=0.01762 	 val_loss=0.01807 	 sm_loss=0.01776 	 sm_val_loss=0.01810 	 time=1.78s
# Best: Epoch 11 	 loss=0.01739 	 val_loss=0.01788 	 sm_loss=0.01755 	 sm_val_loss=0.01794 	 time=1.75s
# Best: Epoch 12 	 loss=0.01727 	 val_loss=0.01779 	 sm_loss=0.01744 	 sm_val_loss=0.01782 	 time=1.73s
# Best: Epoch 13 	 loss=0.01698 	 val_loss=0.01770 	 sm_loss=0.01716 	 sm_val_loss=0.01777 	 time=1.75s
# Best: Epoch 15 	 loss=0.01658 	 val_loss=0.01757 	 sm_loss=0.01679 	 sm_val_loss=0.01762 	 time=1.76s
# Best: Epoch 16 	 loss=0.01634 	 val_loss=0.01749 	 sm_loss=0.01656 	 sm_val_loss=0.01749 	 time=1.75s
# Best: Epoch 18 	 loss=0.01585 	 val_loss=0.01747 	 sm_loss=0.01610 	 sm_val_loss=0.01745 	 time=1.76s
# Best: Epoch 19 	 loss=0.01571 	 val_loss=0.01746 	 sm_loss=0.01598 	 sm_val_loss=0.01744 	 time=1.78s
# Fold 2 log loss: 0.01742263786235545
# Fold 3
# Best: Epoch 1 	 loss=0.27927 	 val_loss=0.02231 	 sm_loss=0.27834 	 sm_val_loss=0.02210 	 time=2.10s
# Best: Epoch 2 	 loss=0.02079 	 val_loss=0.01986 	 sm_loss=0.02075 	 sm_val_loss=0.01982 	 time=1.75s
# Best: Epoch 3 	 loss=0.01944 	 val_loss=0.01929 	 sm_loss=0.01948 	 sm_val_loss=0.01920 	 time=1.77s
# Best: Epoch 5 	 loss=0.01831 	 val_loss=0.01907 	 sm_loss=0.01843 	 sm_val_loss=0.01905 	 time=1.84s
# Best: Epoch 6 	 loss=0.01804 	 val_loss=0.01891 	 sm_loss=0.01816 	 sm_val_loss=0.01886 	 time=1.92s
# Best: Epoch 8 	 loss=0.01771 	 val_loss=0.01854 	 sm_loss=0.01785 	 sm_val_loss=0.01853 	 time=1.80s
# Best: Epoch 10 	 loss=0.01734 	 val_loss=0.01842 	 sm_loss=0.01750 	 sm_val_loss=0.01831 	 time=1.79s
# Best: Epoch 11 	 loss=0.01722 	 val_loss=0.01823 	 sm_loss=0.01738 	 sm_val_loss=0.01822 	 time=1.85s
# Best: Epoch 12 	 loss=0.01704 	 val_loss=0.01806 	 sm_loss=0.01722 	 sm_val_loss=0.01810 	 time=2.04s
# Best: Epoch 14 	 loss=0.01656 	 val_loss=0.01794 	 sm_loss=0.01676 	 sm_val_loss=0.01793 	 time=1.78s
# Best: Epoch 15 	 loss=0.01636 	 val_loss=0.01798 	 sm_loss=0.01659 	 sm_val_loss=0.01784 	 time=1.80s
# Best: Epoch 16 	 loss=0.01612 	 val_loss=0.01791 	 sm_loss=0.01636 	 sm_val_loss=0.01781 	 time=2.17s
# Best: Epoch 17 	 loss=0.01587 	 val_loss=0.01785 	 sm_loss=0.01614 	 sm_val_loss=0.01775 	 time=1.86s
# Best: Epoch 18 	 loss=0.01570 	 val_loss=0.01782 	 sm_loss=0.01597 	 sm_val_loss=0.01771 	 time=2.76s
# Best: Epoch 20 	 loss=0.01543 	 val_loss=0.01784 	 sm_loss=0.01572 	 sm_val_loss=0.01771 	 time=1.86s
# Fold 3 log loss: 0.017714779519293244
# Fold 4
# Best: Epoch 1 	 loss=0.28453 	 val_loss=0.02392 	 sm_loss=0.28395 	 sm_val_loss=0.02384 	 time=1.77s
# Best: Epoch 2 	 loss=0.02088 	 val_loss=0.01956 	 sm_loss=0.02084 	 sm_val_loss=0.01959 	 time=1.98s
# Best: Epoch 3 	 loss=0.01961 	 val_loss=0.01901 	 sm_loss=0.01963 	 sm_val_loss=0.01905 	 time=1.77s
# Best: Epoch 4 	 loss=0.01893 	 val_loss=0.01875 	 sm_loss=0.01900 	 sm_val_loss=0.01877 	 time=1.75s
# Best: Epoch 5 	 loss=0.01867 	 val_loss=0.01865 	 sm_loss=0.01876 	 sm_val_loss=0.01866 	 time=1.78s
# Best: Epoch 6 	 loss=0.01829 	 val_loss=0.01837 	 sm_loss=0.01839 	 sm_val_loss=0.01833 	 time=1.75s
# Best: Epoch 7 	 loss=0.01812 	 val_loss=0.01792 	 sm_loss=0.01823 	 sm_val_loss=0.01786 	 time=1.76s
# Best: Epoch 11 	 loss=0.01754 	 val_loss=0.01772 	 sm_loss=0.01769 	 sm_val_loss=0.01771 	 time=1.73s
# Best: Epoch 12 	 loss=0.01727 	 val_loss=0.01765 	 sm_loss=0.01743 	 sm_val_loss=0.01768 	 time=1.75s
# Best: Epoch 13 	 loss=0.01713 	 val_loss=0.01751 	 sm_loss=0.01730 	 sm_val_loss=0.01750 	 time=1.76s
# Best: Epoch 14 	 loss=0.01693 	 val_loss=0.01739 	 sm_loss=0.01712 	 sm_val_loss=0.01739 	 time=2.01s
# Best: Epoch 15 	 loss=0.01666 	 val_loss=0.01725 	 sm_loss=0.01686 	 sm_val_loss=0.01722 	 time=2.11s
# Best: Epoch 16 	 loss=0.01648 	 val_loss=0.01727 	 sm_loss=0.01670 	 sm_val_loss=0.01719 	 time=1.79s
# Best: Epoch 17 	 loss=0.01627 	 val_loss=0.01711 	 sm_loss=0.01650 	 sm_val_loss=0.01707 	 time=1.73s
# Best: Epoch 18 	 loss=0.01604 	 val_loss=0.01707 	 sm_loss=0.01629 	 sm_val_loss=0.01702 	 time=1.74s
# Best: Epoch 19 	 loss=0.01587 	 val_loss=0.01705 	 sm_loss=0.01613 	 sm_val_loss=0.01701 	 time=1.80s
# Best: Epoch 20 	 loss=0.01582 	 val_loss=0.01705 	 sm_loss=0.01608 	 sm_val_loss=0.01700 	 time=2.26s
# Fold 4 log loss: 0.017061708214114877
# Fold 5
# Best: Epoch 1 	 loss=0.28102 	 val_loss=0.02233 	 sm_loss=0.28021 	 sm_val_loss=0.02172 	 time=1.87s
# Best: Epoch 3 	 loss=0.02097 	 val_loss=0.01992 	 sm_loss=0.02084 	 sm_val_loss=0.01977 	 time=1.77s
# Best: Epoch 4 	 loss=0.01915 	 val_loss=0.01932 	 sm_loss=0.01921 	 sm_val_loss=0.01931 	 time=1.78s
# Best: Epoch 12 	 loss=0.01837 	 val_loss=0.01864 	 sm_loss=0.01847 	 sm_val_loss=0.01850 	 time=1.98s
# Best: Epoch 14 	 loss=0.01789 	 val_loss=0.01827 	 sm_loss=0.01803 	 sm_val_loss=0.01823 	 time=1.80s
# Best: Epoch 15 	 loss=0.01759 	 val_loss=0.01819 	 sm_loss=0.01775 	 sm_val_loss=0.01812 	 time=1.79s
# Best: Epoch 16 	 loss=0.01741 	 val_loss=0.01811 	 sm_loss=0.01758 	 sm_val_loss=0.01806 	 time=1.95s
# Best: Epoch 18 	 loss=0.01693 	 val_loss=0.01782 	 sm_loss=0.01713 	 sm_val_loss=0.01779 	 time=1.77s
# Best: Epoch 19 	 loss=0.01684 	 val_loss=0.01777 	 sm_loss=0.01704 	 sm_val_loss=0.01771 	 time=1.79s
# Fold 5 log loss: 0.017711210447153364
# Fold 6
# Best: Epoch 1 	 loss=0.27828 	 val_loss=0.02464 	 sm_loss=0.27729 	 sm_val_loss=0.02440 	 time=1.79s
# Best: Epoch 2 	 loss=0.02120 	 val_loss=0.02220 	 sm_loss=0.02098 	 sm_val_loss=0.02209 	 time=1.96s
# Best: Epoch 8 	 loss=0.02013 	 val_loss=0.02233 	 sm_loss=0.02001 	 sm_val_loss=0.02144 	 time=1.95s
# Best: Epoch 9 	 loss=0.02009 	 val_loss=0.02072 	 sm_loss=0.01980 	 sm_val_loss=0.02037 	 time=2.05s
# Best: Epoch 11 	 loss=0.01939 	 val_loss=0.02048 	 sm_loss=0.01934 	 sm_val_loss=0.02012 	 time=1.73s
# Best: Epoch 12 	 loss=0.01920 	 val_loss=0.01992 	 sm_loss=0.01918 	 sm_val_loss=0.01962 	 time=1.78s
# Best: Epoch 13 	 loss=0.01859 	 val_loss=0.01930 	 sm_loss=0.01869 	 sm_val_loss=0.01880 	 time=1.74s
# Best: Epoch 15 	 loss=0.01810 	 val_loss=0.01865 	 sm_loss=0.01824 	 sm_val_loss=0.01857 	 time=1.75s
# Best: Epoch 16 	 loss=0.01761 	 val_loss=0.01860 	 sm_loss=0.01778 	 sm_val_loss=0.01832 	 time=1.75s
# Best: Epoch 19 	 loss=0.01715 	 val_loss=0.01828 	 sm_loss=0.01735 	 sm_val_loss=0.01804 	 time=1.75s
# Best: Epoch 20 	 loss=0.01717 	 val_loss=0.01832 	 sm_loss=0.01735 	 sm_val_loss=0.01802 	 time=2.17s
# Fold 6 log loss: 0.018072541467938588
# Fold 7
# Best: Epoch 1 	 loss=0.27958 	 val_loss=0.02164 	 sm_loss=0.27877 	 sm_val_loss=0.02162 	 time=1.79s
# Best: Epoch 2 	 loss=0.02085 	 val_loss=0.02091 	 sm_loss=0.02084 	 sm_val_loss=0.02088 	 time=1.83s
# Best: Epoch 3 	 loss=0.01974 	 val_loss=0.01957 	 sm_loss=0.01978 	 sm_val_loss=0.01956 	 time=1.77s
# Best: Epoch 4 	 loss=0.01891 	 val_loss=0.01880 	 sm_loss=0.01897 	 sm_val_loss=0.01882 	 time=1.80s
# Best: Epoch 7 	 loss=0.01848 	 val_loss=0.01833 	 sm_loss=0.01855 	 sm_val_loss=0.01831 	 time=1.84s
# Best: Epoch 9 	 loss=0.01779 	 val_loss=0.01791 	 sm_loss=0.01792 	 sm_val_loss=0.01798 	 time=1.77s
# Best: Epoch 11 	 loss=0.01745 	 val_loss=0.01767 	 sm_loss=0.01759 	 sm_val_loss=0.01775 	 time=2.00s
# Best: Epoch 12 	 loss=0.01721 	 val_loss=0.01765 	 sm_loss=0.01738 	 sm_val_loss=0.01771 	 time=1.79s
# Best: Epoch 13 	 loss=0.01708 	 val_loss=0.01757 	 sm_loss=0.01725 	 sm_val_loss=0.01763 	 time=1.76s
# Best: Epoch 14 	 loss=0.01692 	 val_loss=0.01745 	 sm_loss=0.01710 	 sm_val_loss=0.01748 	 time=1.78s
# Best: Epoch 15 	 loss=0.01670 	 val_loss=0.01738 	 sm_loss=0.01690 	 sm_val_loss=0.01742 	 time=1.78s
# Best: Epoch 16 	 loss=0.01647 	 val_loss=0.01734 	 sm_loss=0.01669 	 sm_val_loss=0.01737 	 time=1.75s
# Best: Epoch 17 	 loss=0.01625 	 val_loss=0.01728 	 sm_loss=0.01649 	 sm_val_loss=0.01728 	 time=1.98s
# Best: Epoch 18 	 loss=0.01604 	 val_loss=0.01723 	 sm_loss=0.01628 	 sm_val_loss=0.01723 	 time=1.76s
# Best: Epoch 20 	 loss=0.01579 	 val_loss=0.01723 	 sm_loss=0.01605 	 sm_val_loss=0.01721 	 time=1.78s
# Fold 7 log loss: 0.017326002755983123
# Seed 0
# Fold 1 log loss: 0.017012467890473126
# Fold 2 log loss: 0.01742263786235545
# Fold 3 log loss: 0.017714779519293244
# Fold 4 log loss: 0.017061708214114877
# Fold 5 log loss: 0.017711210447153364
# Fold 6 log loss: 0.018072541467938588
# Fold 7 log loss: 0.017326002755983123
# Std of log loss: 0.0003545684537562104
# Total log loss: 0.01747461232933979
# Fold 1
# Best: Epoch 1 	 loss=0.28002 	 val_loss=0.02099 	 sm_loss=0.27925 	 sm_val_loss=0.02087 	 time=1.95s
# Best: Epoch 2 	 loss=0.02078 	 val_loss=0.01991 	 sm_loss=0.02075 	 sm_val_loss=0.01986 	 time=2.05s
# Best: Epoch 3 	 loss=0.01952 	 val_loss=0.01888 	 sm_loss=0.01955 	 sm_val_loss=0.01892 	 time=1.94s
# Best: Epoch 5 	 loss=0.01855 	 val_loss=0.01857 	 sm_loss=0.01863 	 sm_val_loss=0.01865 	 time=1.75s
# Best: Epoch 6 	 loss=0.01823 	 val_loss=0.01840 	 sm_loss=0.01834 	 sm_val_loss=0.01843 	 time=1.78s
# Best: Epoch 7 	 loss=0.01811 	 val_loss=0.01805 	 sm_loss=0.01822 	 sm_val_loss=0.01810 	 time=1.97s
# Best: Epoch 9 	 loss=0.01767 	 val_loss=0.01782 	 sm_loss=0.01780 	 sm_val_loss=0.01789 	 time=2.00s
# Best: Epoch 10 	 loss=0.01750 	 val_loss=0.01751 	 sm_loss=0.01765 	 sm_val_loss=0.01755 	 time=1.78s
# Best: Epoch 12 	 loss=0.01718 	 val_loss=0.01747 	 sm_loss=0.01734 	 sm_val_loss=0.01752 	 time=1.84s
# Best: Epoch 14 	 loss=0.01670 	 val_loss=0.01728 	 sm_loss=0.01690 	 sm_val_loss=0.01731 	 time=1.76s
# Best: Epoch 15 	 loss=0.01650 	 val_loss=0.01724 	 sm_loss=0.01671 	 sm_val_loss=0.01726 	 time=1.74s
# Best: Epoch 16 	 loss=0.01630 	 val_loss=0.01721 	 sm_loss=0.01653 	 sm_val_loss=0.01723 	 time=1.75s
# Best: Epoch 17 	 loss=0.01604 	 val_loss=0.01711 	 sm_loss=0.01628 	 sm_val_loss=0.01712 	 time=1.75s
# Best: Epoch 19 	 loss=0.01572 	 val_loss=0.01711 	 sm_loss=0.01598 	 sm_val_loss=0.01711 	 time=1.96s
# Fold 1 log loss: 0.01712696816466698
# Fold 2
# Best: Epoch 1 	 loss=0.27953 	 val_loss=0.02089 	 sm_loss=0.27897 	 sm_val_loss=0.02075 	 time=1.76s
# Best: Epoch 2 	 loss=0.02087 	 val_loss=0.02058 	 sm_loss=0.02083 	 sm_val_loss=0.02057 	 time=1.92s
# Best: Epoch 3 	 loss=0.01980 	 val_loss=0.01944 	 sm_loss=0.01982 	 sm_val_loss=0.01941 	 time=1.72s
# Best: Epoch 4 	 loss=0.01902 	 val_loss=0.01895 	 sm_loss=0.01907 	 sm_val_loss=0.01898 	 time=1.93s
# Best: Epoch 6 	 loss=0.01832 	 val_loss=0.01842 	 sm_loss=0.01842 	 sm_val_loss=0.01844 	 time=1.75s
# Best: Epoch 7 	 loss=0.01808 	 val_loss=0.01825 	 sm_loss=0.01819 	 sm_val_loss=0.01827 	 time=1.75s
# Best: Epoch 9 	 loss=0.01762 	 val_loss=0.01802 	 sm_loss=0.01776 	 sm_val_loss=0.01803 	 time=1.74s
# Best: Epoch 10 	 loss=0.01752 	 val_loss=0.01798 	 sm_loss=0.01767 	 sm_val_loss=0.01799 	 time=1.92s
# Best: Epoch 11 	 loss=0.01729 	 val_loss=0.01774 	 sm_loss=0.01745 	 sm_val_loss=0.01780 	 time=1.76s
# Best: Epoch 13 	 loss=0.01697 	 val_loss=0.01757 	 sm_loss=0.01715 	 sm_val_loss=0.01760 	 time=1.80s
# Best: Epoch 14 	 loss=0.01672 	 val_loss=0.01758 	 sm_loss=0.01692 	 sm_val_loss=0.01760 	 time=1.77s
# Best: Epoch 15 	 loss=0.01650 	 val_loss=0.01747 	 sm_loss=0.01670 	 sm_val_loss=0.01749 	 time=1.80s
# Best: Epoch 16 	 loss=0.01627 	 val_loss=0.01744 	 sm_loss=0.01651 	 sm_val_loss=0.01744 	 time=2.01s
# Best: Epoch 17 	 loss=0.01606 	 val_loss=0.01729 	 sm_loss=0.01630 	 sm_val_loss=0.01730 	 time=1.87s
# Best: Epoch 19 	 loss=0.01569 	 val_loss=0.01732 	 sm_loss=0.01596 	 sm_val_loss=0.01729 	 time=2.08s
# Fold 2 log loss: 0.017275400946645685
# Fold 3
# Best: Epoch 1 	 loss=0.28327 	 val_loss=0.02173 	 sm_loss=0.28227 	 sm_val_loss=0.02158 	 time=1.86s
# Best: Epoch 2 	 loss=0.02104 	 val_loss=0.02089 	 sm_loss=0.02096 	 sm_val_loss=0.02062 	 time=2.05s
# Best: Epoch 3 	 loss=0.01958 	 val_loss=0.02003 	 sm_loss=0.01961 	 sm_val_loss=0.01976 	 time=1.95s
# Best: Epoch 4 	 loss=0.01881 	 val_loss=0.01912 	 sm_loss=0.01888 	 sm_val_loss=0.01911 	 time=1.81s
# Best: Epoch 6 	 loss=0.01834 	 val_loss=0.01901 	 sm_loss=0.01844 	 sm_val_loss=0.01901 	 time=1.78s
# Best: Epoch 7 	 loss=0.01795 	 val_loss=0.01901 	 sm_loss=0.01808 	 sm_val_loss=0.01888 	 time=1.98s
# Best: Epoch 8 	 loss=0.01784 	 val_loss=0.01894 	 sm_loss=0.01796 	 sm_val_loss=0.01879 	 time=1.76s
# Best: Epoch 9 	 loss=0.01761 	 val_loss=0.01885 	 sm_loss=0.01775 	 sm_val_loss=0.01859 	 time=1.76s
# Best: Epoch 10 	 loss=0.01744 	 val_loss=0.01838 	 sm_loss=0.01760 	 sm_val_loss=0.01834 	 time=1.78s
# Best: Epoch 11 	 loss=0.01723 	 val_loss=0.01838 	 sm_loss=0.01740 	 sm_val_loss=0.01829 	 time=1.78s
# Best: Epoch 12 	 loss=0.01710 	 val_loss=0.01817 	 sm_loss=0.01727 	 sm_val_loss=0.01817 	 time=1.77s
# Best: Epoch 13 	 loss=0.01682 	 val_loss=0.01809 	 sm_loss=0.01703 	 sm_val_loss=0.01806 	 time=2.00s
# Best: Epoch 14 	 loss=0.01657 	 val_loss=0.01804 	 sm_loss=0.01678 	 sm_val_loss=0.01800 	 time=2.05s
# Best: Epoch 15 	 loss=0.01637 	 val_loss=0.01807 	 sm_loss=0.01659 	 sm_val_loss=0.01797 	 time=1.75s
# Best: Epoch 16 	 loss=0.01606 	 val_loss=0.01786 	 sm_loss=0.01630 	 sm_val_loss=0.01784 	 time=1.75s
# Best: Epoch 17 	 loss=0.01584 	 val_loss=0.01778 	 sm_loss=0.01611 	 sm_val_loss=0.01769 	 time=1.73s
# Best: Epoch 18 	 loss=0.01563 	 val_loss=0.01777 	 sm_loss=0.01590 	 sm_val_loss=0.01767 	 time=1.75s
# Best: Epoch 19 	 loss=0.01547 	 val_loss=0.01778 	 sm_loss=0.01575 	 sm_val_loss=0.01766 	 time=2.01s
# Fold 3 log loss: 0.017670594685870126
# Fold 4
# Best: Epoch 1 	 loss=0.28317 	 val_loss=0.02132 	 sm_loss=0.28238 	 sm_val_loss=0.02103 	 time=1.67s
# Best: Epoch 2 	 loss=0.02057 	 val_loss=0.01950 	 sm_loss=0.02056 	 sm_val_loss=0.01950 	 time=1.67s
# Best: Epoch 3 	 loss=0.01961 	 val_loss=0.01886 	 sm_loss=0.01962 	 sm_val_loss=0.01886 	 time=1.69s
# Best: Epoch 5 	 loss=0.01877 	 val_loss=0.01854 	 sm_loss=0.01883 	 sm_val_loss=0.01855 	 time=1.73s
# Best: Epoch 8 	 loss=0.01802 	 val_loss=0.01828 	 sm_loss=0.01815 	 sm_val_loss=0.01827 	 time=1.70s
# Best: Epoch 9 	 loss=0.01785 	 val_loss=0.01859 	 sm_loss=0.01798 	 sm_val_loss=0.01823 	 time=1.74s
# Best: Epoch 10 	 loss=0.01766 	 val_loss=0.01791 	 sm_loss=0.01780 	 sm_val_loss=0.01793 	 time=1.97s
# Best: Epoch 11 	 loss=0.01745 	 val_loss=0.01777 	 sm_loss=0.01761 	 sm_val_loss=0.01771 	 time=2.78s
# Best: Epoch 12 	 loss=0.01731 	 val_loss=0.01766 	 sm_loss=0.01747 	 sm_val_loss=0.01765 	 time=1.68s
# Best: Epoch 13 	 loss=0.01717 	 val_loss=0.01745 	 sm_loss=0.01734 	 sm_val_loss=0.01746 	 time=1.70s
# Best: Epoch 14 	 loss=0.01696 	 val_loss=0.01734 	 sm_loss=0.01715 	 sm_val_loss=0.01734 	 time=1.76s
# Best: Epoch 15 	 loss=0.01675 	 val_loss=0.01733 	 sm_loss=0.01695 	 sm_val_loss=0.01732 	 time=1.72s
# Best: Epoch 16 	 loss=0.01653 	 val_loss=0.01721 	 sm_loss=0.01675 	 sm_val_loss=0.01719 	 time=1.94s
# Best: Epoch 17 	 loss=0.01634 	 val_loss=0.01714 	 sm_loss=0.01657 	 sm_val_loss=0.01710 	 time=1.70s
# Best: Epoch 18 	 loss=0.01619 	 val_loss=0.01706 	 sm_loss=0.01643 	 sm_val_loss=0.01702 	 time=1.70s
# Best: Epoch 19 	 loss=0.01605 	 val_loss=0.01707 	 sm_loss=0.01630 	 sm_val_loss=0.01702 	 time=1.70s
# Best: Epoch 20 	 loss=0.01598 	 val_loss=0.01706 	 sm_loss=0.01623 	 sm_val_loss=0.01701 	 time=1.69s
# Fold 4 log loss: 0.017076935217809147
# Fold 5
# Best: Epoch 1 	 loss=0.28230 	 val_loss=0.02175 	 sm_loss=0.28156 	 sm_val_loss=0.02162 	 time=1.78s
# Best: Epoch 2 	 loss=0.02083 	 val_loss=0.02030 	 sm_loss=0.02079 	 sm_val_loss=0.02029 	 time=1.99s
# Best: Epoch 3 	 loss=0.01968 	 val_loss=0.01950 	 sm_loss=0.01971 	 sm_val_loss=0.01948 	 time=1.79s
# Best: Epoch 5 	 loss=0.01873 	 val_loss=0.01941 	 sm_loss=0.01880 	 sm_val_loss=0.01941 	 time=1.82s
# Best: Epoch 6 	 loss=0.01855 	 val_loss=0.01927 	 sm_loss=0.01865 	 sm_val_loss=0.01926 	 time=1.83s
# Best: Epoch 8 	 loss=0.01804 	 val_loss=0.01863 	 sm_loss=0.01815 	 sm_val_loss=0.01860 	 time=2.03s
# Best: Epoch 9 	 loss=0.01781 	 val_loss=0.01852 	 sm_loss=0.01795 	 sm_val_loss=0.01852 	 time=1.92s
# Best: Epoch 10 	 loss=0.01760 	 val_loss=0.01841 	 sm_loss=0.01775 	 sm_val_loss=0.01840 	 time=1.78s
# Best: Epoch 11 	 loss=0.01738 	 val_loss=0.01824 	 sm_loss=0.01754 	 sm_val_loss=0.01817 	 time=1.76s
# Best: Epoch 13 	 loss=0.01711 	 val_loss=0.01782 	 sm_loss=0.01729 	 sm_val_loss=0.01780 	 time=1.96s
# Best: Epoch 15 	 loss=0.01671 	 val_loss=0.01773 	 sm_loss=0.01691 	 sm_val_loss=0.01771 	 time=1.77s
# Best: Epoch 16 	 loss=0.01645 	 val_loss=0.01770 	 sm_loss=0.01667 	 sm_val_loss=0.01766 	 time=1.76s
# Best: Epoch 17 	 loss=0.01625 	 val_loss=0.01756 	 sm_loss=0.01648 	 sm_val_loss=0.01751 	 time=1.79s
# Best: Epoch 18 	 loss=0.01605 	 val_loss=0.01751 	 sm_loss=0.01630 	 sm_val_loss=0.01748 	 time=1.78s
# Best: Epoch 20 	 loss=0.01590 	 val_loss=0.01755 	 sm_loss=0.01616 	 sm_val_loss=0.01748 	 time=1.78s
# Fold 5 log loss: 0.017483119877906645
# Fold 6
# Best: Epoch 1 	 loss=0.28645 	 val_loss=0.02191 	 sm_loss=0.28565 	 sm_val_loss=0.02159 	 time=2.06s
# Best: Epoch 7 	 loss=0.02115 	 val_loss=0.02182 	 sm_loss=0.02100 	 sm_val_loss=0.02121 	 time=1.73s
# Best: Epoch 10 	 loss=0.02001 	 val_loss=0.02055 	 sm_loss=0.01995 	 sm_val_loss=0.02025 	 time=1.80s
# Best: Epoch 16 	 loss=0.01950 	 val_loss=0.02021 	 sm_loss=0.01951 	 sm_val_loss=0.01990 	 time=1.67s
# Best: Epoch 17 	 loss=0.01911 	 val_loss=0.02010 	 sm_loss=0.01921 	 sm_val_loss=0.01978 	 time=1.90s
# Best: Epoch 18 	 loss=0.01884 	 val_loss=0.01954 	 sm_loss=0.01895 	 sm_val_loss=0.01934 	 time=1.65s
# Best: Epoch 19 	 loss=0.01865 	 val_loss=0.01943 	 sm_loss=0.01879 	 sm_val_loss=0.01919 	 time=1.70s
# Best: Epoch 20 	 loss=0.01846 	 val_loss=0.01948 	 sm_loss=0.01859 	 sm_val_loss=0.01915 	 time=1.70s
# Fold 6 log loss: 0.01921728134055903
# Fold 7
# Best: Epoch 1 	 loss=0.27836 	 val_loss=0.02155 	 sm_loss=0.27784 	 sm_val_loss=0.02149 	 time=1.77s
# Best: Epoch 2 	 loss=0.02065 	 val_loss=0.02046 	 sm_loss=0.02062 	 sm_val_loss=0.02051 	 time=1.98s
# Best: Epoch 4 	 loss=0.01924 	 val_loss=0.01911 	 sm_loss=0.01925 	 sm_val_loss=0.01916 	 time=1.88s
# Best: Epoch 6 	 loss=0.01841 	 val_loss=0.01886 	 sm_loss=0.01849 	 sm_val_loss=0.01887 	 time=1.75s
# Best: Epoch 8 	 loss=0.01799 	 val_loss=0.01823 	 sm_loss=0.01811 	 sm_val_loss=0.01818 	 time=1.98s
# Best: Epoch 10 	 loss=0.01753 	 val_loss=0.01800 	 sm_loss=0.01768 	 sm_val_loss=0.01801 	 time=1.77s
# Best: Epoch 11 	 loss=0.01742 	 val_loss=0.01789 	 sm_loss=0.01758 	 sm_val_loss=0.01797 	 time=1.75s
# Best: Epoch 12 	 loss=0.01726 	 val_loss=0.01765 	 sm_loss=0.01743 	 sm_val_loss=0.01769 	 time=1.75s
# Best: Epoch 13 	 loss=0.01695 	 val_loss=0.01761 	 sm_loss=0.01713 	 sm_val_loss=0.01765 	 time=1.80s
# Best: Epoch 14 	 loss=0.01677 	 val_loss=0.01760 	 sm_loss=0.01697 	 sm_val_loss=0.01755 	 time=2.16s
# Best: Epoch 15 	 loss=0.01657 	 val_loss=0.01743 	 sm_loss=0.01679 	 sm_val_loss=0.01744 	 time=2.06s
# Best: Epoch 16 	 loss=0.01633 	 val_loss=0.01731 	 sm_loss=0.01656 	 sm_val_loss=0.01733 	 time=2.07s
# Best: Epoch 18 	 loss=0.01596 	 val_loss=0.01724 	 sm_loss=0.01621 	 sm_val_loss=0.01722 	 time=1.86s
# Best: Epoch 19 	 loss=0.01579 	 val_loss=0.01722 	 sm_loss=0.01606 	 sm_val_loss=0.01722 	 time=1.91s
# Best: Epoch 20 	 loss=0.01569 	 val_loss=0.01724 	 sm_loss=0.01596 	 sm_val_loss=0.01722 	 time=2.07s
# Fold 7 log loss: 0.017325329910369558
# Seed 1
# Fold 1 log loss: 0.01712696816466698
# Fold 2 log loss: 0.017275400946645685
# Fold 3 log loss: 0.017670594685870126
# Fold 4 log loss: 0.017076935217809147
# Fold 5 log loss: 0.017483119877906645
# Fold 6 log loss: 0.01921728134055903
# Fold 7 log loss: 0.017325329910369558
# Std of log loss: 0.0006878873197701826
# Total log loss: 0.01759643073925627
# Fold 1
# Best: Epoch 1 	 loss=0.28075 	 val_loss=0.02162 	 sm_loss=0.28001 	 sm_val_loss=0.02147 	 time=1.72s
# Best: Epoch 2 	 loss=0.02103 	 val_loss=0.02120 	 sm_loss=0.02095 	 sm_val_loss=0.02107 	 time=1.73s
# Best: Epoch 3 	 loss=0.01968 	 val_loss=0.01899 	 sm_loss=0.01967 	 sm_val_loss=0.01898 	 time=1.76s
# Best: Epoch 4 	 loss=0.01890 	 val_loss=0.01870 	 sm_loss=0.01896 	 sm_val_loss=0.01876 	 time=1.95s
# Best: Epoch 6 	 loss=0.01840 	 val_loss=0.01823 	 sm_loss=0.01850 	 sm_val_loss=0.01828 	 time=1.72s
# Best: Epoch 7 	 loss=0.01818 	 val_loss=0.01800 	 sm_loss=0.01828 	 sm_val_loss=0.01803 	 time=1.75s
# Best: Epoch 10 	 loss=0.01754 	 val_loss=0.01793 	 sm_loss=0.01769 	 sm_val_loss=0.01799 	 time=1.79s
# Best: Epoch 12 	 loss=0.01724 	 val_loss=0.01761 	 sm_loss=0.01740 	 sm_val_loss=0.01767 	 time=1.72s
# Best: Epoch 13 	 loss=0.01700 	 val_loss=0.01752 	 sm_loss=0.01718 	 sm_val_loss=0.01760 	 time=1.73s
# Best: Epoch 14 	 loss=0.01677 	 val_loss=0.01736 	 sm_loss=0.01697 	 sm_val_loss=0.01745 	 time=1.71s
# Best: Epoch 15 	 loss=0.01655 	 val_loss=0.01715 	 sm_loss=0.01676 	 sm_val_loss=0.01721 	 time=1.74s
# Best: Epoch 16 	 loss=0.01631 	 val_loss=0.01707 	 sm_loss=0.01654 	 sm_val_loss=0.01714 	 time=1.76s
# Best: Epoch 17 	 loss=0.01610 	 val_loss=0.01702 	 sm_loss=0.01633 	 sm_val_loss=0.01710 	 time=1.93s
# Best: Epoch 18 	 loss=0.01592 	 val_loss=0.01699 	 sm_loss=0.01617 	 sm_val_loss=0.01704 	 time=2.11s
# Best: Epoch 19 	 loss=0.01578 	 val_loss=0.01698 	 sm_loss=0.01604 	 sm_val_loss=0.01702 	 time=1.75s
# Best: Epoch 20 	 loss=0.01568 	 val_loss=0.01696 	 sm_loss=0.01594 	 sm_val_loss=0.01701 	 time=1.73s
# Fold 1 log loss: 0.01702774158321948
# Fold 2
# Best: Epoch 1 	 loss=0.28949 	 val_loss=0.02192 	 sm_loss=0.28873 	 sm_val_loss=0.02146 	 time=1.73s
# Best: Epoch 2 	 loss=0.02084 	 val_loss=0.01958 	 sm_loss=0.02079 	 sm_val_loss=0.01957 	 time=1.97s
# Best: Epoch 3 	 loss=0.01966 	 val_loss=0.01960 	 sm_loss=0.01969 	 sm_val_loss=0.01951 	 time=1.78s
# Best: Epoch 5 	 loss=0.01869 	 val_loss=0.01855 	 sm_loss=0.01877 	 sm_val_loss=0.01858 	 time=2.00s
# Best: Epoch 8 	 loss=0.01798 	 val_loss=0.01816 	 sm_loss=0.01809 	 sm_val_loss=0.01821 	 time=1.95s
# Best: Epoch 9 	 loss=0.01788 	 val_loss=0.01807 	 sm_loss=0.01800 	 sm_val_loss=0.01815 	 time=1.80s
# Best: Epoch 10 	 loss=0.01777 	 val_loss=0.01802 	 sm_loss=0.01791 	 sm_val_loss=0.01808 	 time=1.79s
# Best: Epoch 12 	 loss=0.01733 	 val_loss=0.01776 	 sm_loss=0.01748 	 sm_val_loss=0.01780 	 time=1.73s
# Best: Epoch 13 	 loss=0.01719 	 val_loss=0.01770 	 sm_loss=0.01735 	 sm_val_loss=0.01777 	 time=1.85s
# Best: Epoch 14 	 loss=0.01697 	 val_loss=0.01746 	 sm_loss=0.01715 	 sm_val_loss=0.01751 	 time=2.08s
# Best: Epoch 15 	 loss=0.01671 	 val_loss=0.01743 	 sm_loss=0.01691 	 sm_val_loss=0.01751 	 time=1.95s
# Best: Epoch 16 	 loss=0.01651 	 val_loss=0.01730 	 sm_loss=0.01672 	 sm_val_loss=0.01739 	 time=1.72s
# Best: Epoch 17 	 loss=0.01635 	 val_loss=0.01731 	 sm_loss=0.01657 	 sm_val_loss=0.01736 	 time=1.72s
# Best: Epoch 18 	 loss=0.01616 	 val_loss=0.01722 	 sm_loss=0.01639 	 sm_val_loss=0.01727 	 time=1.74s
# Fold 2 log loss: 0.01725485508185023
# Fold 3
# Best: Epoch 1 	 loss=0.28408 	 val_loss=0.02143 	 sm_loss=0.28369 	 sm_val_loss=0.02138 	 time=1.75s
# Best: Epoch 2 	 loss=0.02047 	 val_loss=0.01993 	 sm_loss=0.02045 	 sm_val_loss=0.01995 	 time=1.74s
# Best: Epoch 3 	 loss=0.01957 	 val_loss=0.01922 	 sm_loss=0.01959 	 sm_val_loss=0.01920 	 time=1.74s
# Best: Epoch 5 	 loss=0.01841 	 val_loss=0.01929 	 sm_loss=0.01849 	 sm_val_loss=0.01920 	 time=1.93s
# Best: Epoch 7 	 loss=0.01789 	 val_loss=0.01904 	 sm_loss=0.01801 	 sm_val_loss=0.01907 	 time=1.74s
# Best: Epoch 8 	 loss=0.01781 	 val_loss=0.01878 	 sm_loss=0.01795 	 sm_val_loss=0.01867 	 time=1.89s
# Best: Epoch 9 	 loss=0.01753 	 val_loss=0.01839 	 sm_loss=0.01768 	 sm_val_loss=0.01833 	 time=1.75s
# Best: Epoch 11 	 loss=0.01722 	 val_loss=0.01833 	 sm_loss=0.01739 	 sm_val_loss=0.01830 	 time=1.94s
# Best: Epoch 13 	 loss=0.01681 	 val_loss=0.01809 	 sm_loss=0.01701 	 sm_val_loss=0.01804 	 time=1.75s
# Best: Epoch 14 	 loss=0.01658 	 val_loss=0.01801 	 sm_loss=0.01679 	 sm_val_loss=0.01800 	 time=1.72s
# Best: Epoch 15 	 loss=0.01634 	 val_loss=0.01787 	 sm_loss=0.01657 	 sm_val_loss=0.01778 	 time=1.83s
# Best: Epoch 17 	 loss=0.01587 	 val_loss=0.01779 	 sm_loss=0.01614 	 sm_val_loss=0.01768 	 time=2.15s
# Best: Epoch 18 	 loss=0.01567 	 val_loss=0.01781 	 sm_loss=0.01594 	 sm_val_loss=0.01766 	 time=1.91s
# Best: Epoch 19 	 loss=0.01549 	 val_loss=0.01780 	 sm_loss=0.01577 	 sm_val_loss=0.01765 	 time=1.85s
# Best: Epoch 20 	 loss=0.01539 	 val_loss=0.01780 	 sm_loss=0.01568 	 sm_val_loss=0.01764 	 time=1.81s
# Fold 3 log loss: 0.017646149593237685
# Fold 4
# Best: Epoch 1 	 loss=0.28381 	 val_loss=0.02124 	 sm_loss=0.28289 	 sm_val_loss=0.02122 	 time=1.82s
# Best: Epoch 2 	 loss=0.02065 	 val_loss=0.02045 	 sm_loss=0.02067 	 sm_val_loss=0.02050 	 time=2.02s
# Best: Epoch 3 	 loss=0.01975 	 val_loss=0.01912 	 sm_loss=0.01980 	 sm_val_loss=0.01914 	 time=1.79s
# Best: Epoch 4 	 loss=0.01899 	 val_loss=0.01889 	 sm_loss=0.01906 	 sm_val_loss=0.01890 	 time=1.78s
# Best: Epoch 6 	 loss=0.01830 	 val_loss=0.01867 	 sm_loss=0.01842 	 sm_val_loss=0.01854 	 time=1.76s
# Best: Epoch 7 	 loss=0.01820 	 val_loss=0.01841 	 sm_loss=0.01830 	 sm_val_loss=0.01831 	 time=1.87s
# Best: Epoch 9 	 loss=0.01773 	 val_loss=0.01784 	 sm_loss=0.01787 	 sm_val_loss=0.01786 	 time=2.01s
# Best: Epoch 11 	 loss=0.01740 	 val_loss=0.01786 	 sm_loss=0.01756 	 sm_val_loss=0.01781 	 time=1.76s
# Best: Epoch 12 	 loss=0.01716 	 val_loss=0.01787 	 sm_loss=0.01733 	 sm_val_loss=0.01778 	 time=1.76s
# Best: Epoch 13 	 loss=0.01700 	 val_loss=0.01748 	 sm_loss=0.01719 	 sm_val_loss=0.01741 	 time=2.00s
# Best: Epoch 14 	 loss=0.01678 	 val_loss=0.01740 	 sm_loss=0.01698 	 sm_val_loss=0.01733 	 time=1.77s
# Best: Epoch 15 	 loss=0.01660 	 val_loss=0.01736 	 sm_loss=0.01682 	 sm_val_loss=0.01729 	 time=1.81s
# Best: Epoch 16 	 loss=0.01633 	 val_loss=0.01723 	 sm_loss=0.01656 	 sm_val_loss=0.01717 	 time=1.76s
# Best: Epoch 17 	 loss=0.01610 	 val_loss=0.01715 	 sm_loss=0.01634 	 sm_val_loss=0.01709 	 time=1.75s
# Best: Epoch 18 	 loss=0.01588 	 val_loss=0.01713 	 sm_loss=0.01614 	 sm_val_loss=0.01705 	 time=1.77s
# Fold 4 log loss: 0.01709753289727597
# Fold 5
# Best: Epoch 1 	 loss=0.28174 	 val_loss=0.02161 	 sm_loss=0.28079 	 sm_val_loss=0.02134 	 time=1.73s
# Best: Epoch 3 	 loss=0.01976 	 val_loss=0.02002 	 sm_loss=0.01977 	 sm_val_loss=0.01990 	 time=1.70s
# Best: Epoch 5 	 loss=0.01902 	 val_loss=0.01917 	 sm_loss=0.01906 	 sm_val_loss=0.01916 	 time=1.95s
# Best: Epoch 7 	 loss=0.01830 	 val_loss=0.01867 	 sm_loss=0.01838 	 sm_val_loss=0.01865 	 time=1.76s
# Best: Epoch 9 	 loss=0.01789 	 val_loss=0.01841 	 sm_loss=0.01802 	 sm_val_loss=0.01844 	 time=2.04s
# Best: Epoch 10 	 loss=0.01761 	 val_loss=0.01821 	 sm_loss=0.01775 	 sm_val_loss=0.01823 	 time=1.77s
# Best: Epoch 11 	 loss=0.01752 	 val_loss=0.01810 	 sm_loss=0.01766 	 sm_val_loss=0.01816 	 time=2.05s
# Best: Epoch 12 	 loss=0.01724 	 val_loss=0.01792 	 sm_loss=0.01741 	 sm_val_loss=0.01793 	 time=1.71s
# Best: Epoch 13 	 loss=0.01712 	 val_loss=0.01801 	 sm_loss=0.01729 	 sm_val_loss=0.01789 	 time=1.73s
# Best: Epoch 14 	 loss=0.01695 	 val_loss=0.01768 	 sm_loss=0.01714 	 sm_val_loss=0.01767 	 time=1.72s
# Best: Epoch 15 	 loss=0.01672 	 val_loss=0.01762 	 sm_loss=0.01692 	 sm_val_loss=0.01760 	 time=1.80s
# Best: Epoch 16 	 loss=0.01650 	 val_loss=0.01757 	 sm_loss=0.01671 	 sm_val_loss=0.01759 	 time=1.87s
# Best: Epoch 17 	 loss=0.01626 	 val_loss=0.01749 	 sm_loss=0.01649 	 sm_val_loss=0.01746 	 time=1.78s
# Best: Epoch 18 	 loss=0.01606 	 val_loss=0.01747 	 sm_loss=0.01630 	 sm_val_loss=0.01743 	 time=1.71s
# Fold 5 log loss: 0.017430829502727545
# Fold 6
# Best: Epoch 1 	 loss=0.28595 	 val_loss=0.02273 	 sm_loss=0.28504 	 sm_val_loss=0.02230 	 time=1.78s
# Best: Epoch 4 	 loss=0.02243 	 val_loss=0.02172 	 sm_loss=0.02151 	 sm_val_loss=0.02117 	 time=1.75s
# Best: Epoch 6 	 loss=0.01966 	 val_loss=0.02179 	 sm_loss=0.01955 	 sm_val_loss=0.02056 	 time=1.78s
# Best: Epoch 7 	 loss=0.01916 	 val_loss=0.02025 	 sm_loss=0.01915 	 sm_val_loss=0.01957 	 time=1.74s
# Best: Epoch 11 	 loss=0.01844 	 val_loss=0.01930 	 sm_loss=0.01851 	 sm_val_loss=0.01882 	 time=1.78s
# Best: Epoch 14 	 loss=0.01781 	 val_loss=0.01897 	 sm_loss=0.01795 	 sm_val_loss=0.01874 	 time=2.01s
# Best: Epoch 15 	 loss=0.01744 	 val_loss=0.01854 	 sm_loss=0.01762 	 sm_val_loss=0.01841 	 time=1.75s
# Best: Epoch 16 	 loss=0.01728 	 val_loss=0.01837 	 sm_loss=0.01748 	 sm_val_loss=0.01798 	 time=1.75s
# Best: Epoch 18 	 loss=0.01682 	 val_loss=0.01811 	 sm_loss=0.01699 	 sm_val_loss=0.01782 	 time=2.34s
# Fold 6 log loss: 0.017877445981629766
# Fold 7
# Best: Epoch 1 	 loss=0.29222 	 val_loss=0.02188 	 sm_loss=0.29099 	 sm_val_loss=0.02167 	 time=1.81s
# Best: Epoch 2 	 loss=0.02135 	 val_loss=0.02082 	 sm_loss=0.02113 	 sm_val_loss=0.02087 	 time=1.73s
# Best: Epoch 3 	 loss=0.01975 	 val_loss=0.01950 	 sm_loss=0.01975 	 sm_val_loss=0.01952 	 time=1.74s
# Best: Epoch 4 	 loss=0.01924 	 val_loss=0.01927 	 sm_loss=0.01927 	 sm_val_loss=0.01928 	 time=1.98s
# Best: Epoch 5 	 loss=0.01876 	 val_loss=0.01916 	 sm_loss=0.01884 	 sm_val_loss=0.01924 	 time=1.75s
# Best: Epoch 7 	 loss=0.01865 	 val_loss=0.01850 	 sm_loss=0.01872 	 sm_val_loss=0.01855 	 time=1.75s
# Best: Epoch 9 	 loss=0.01797 	 val_loss=0.01827 	 sm_loss=0.01809 	 sm_val_loss=0.01832 	 time=1.74s
# Best: Epoch 11 	 loss=0.01775 	 val_loss=0.01828 	 sm_loss=0.01788 	 sm_val_loss=0.01827 	 time=1.76s
# Best: Epoch 12 	 loss=0.01743 	 val_loss=0.01780 	 sm_loss=0.01759 	 sm_val_loss=0.01785 	 time=1.76s
# Best: Epoch 13 	 loss=0.01725 	 val_loss=0.01771 	 sm_loss=0.01742 	 sm_val_loss=0.01775 	 time=1.74s
# Best: Epoch 14 	 loss=0.01704 	 val_loss=0.01763 	 sm_loss=0.01723 	 sm_val_loss=0.01769 	 time=1.74s
# Best: Epoch 15 	 loss=0.01689 	 val_loss=0.01747 	 sm_loss=0.01709 	 sm_val_loss=0.01754 	 time=1.76s
# Best: Epoch 16 	 loss=0.01665 	 val_loss=0.01748 	 sm_loss=0.01686 	 sm_val_loss=0.01750 	 time=1.97s
# Best: Epoch 17 	 loss=0.01653 	 val_loss=0.01742 	 sm_loss=0.01675 	 sm_val_loss=0.01745 	 time=1.78s
# Best: Epoch 18 	 loss=0.01630 	 val_loss=0.01739 	 sm_loss=0.01653 	 sm_val_loss=0.01742 	 time=2.07s
# Best: Epoch 19 	 loss=0.01618 	 val_loss=0.01738 	 sm_loss=0.01642 	 sm_val_loss=0.01740 	 time=1.73s
# Fold 7 log loss: 0.017514910550539768
# Seed 2
# Fold 1 log loss: 0.01702774158321948
# Fold 2 log loss: 0.01725485508185023
# Fold 3 log loss: 0.017646149593237685
# Fold 4 log loss: 0.01709753289727597
# Fold 5 log loss: 0.017430829502727545
# Fold 6 log loss: 0.017877445981629766
# Fold 7 log loss: 0.017514910550539768
# Std of log loss: 0.0002811911808378412
# Total log loss: 0.017407004826352997
# Fold 1
# Best: Epoch 1 	 loss=0.28064 	 val_loss=0.02113 	 sm_loss=0.27991 	 sm_val_loss=0.02093 	 time=1.93s
# Best: Epoch 2 	 loss=0.02094 	 val_loss=0.02010 	 sm_loss=0.02090 	 sm_val_loss=0.02002 	 time=1.71s
# Best: Epoch 3 	 loss=0.01957 	 val_loss=0.01929 	 sm_loss=0.01959 	 sm_val_loss=0.01934 	 time=1.72s
# Best: Epoch 4 	 loss=0.01898 	 val_loss=0.01919 	 sm_loss=0.01903 	 sm_val_loss=0.01903 	 time=1.78s
# Best: Epoch 5 	 loss=0.01859 	 val_loss=0.01866 	 sm_loss=0.01869 	 sm_val_loss=0.01870 	 time=1.71s
# Best: Epoch 6 	 loss=0.01824 	 val_loss=0.01824 	 sm_loss=0.01834 	 sm_val_loss=0.01833 	 time=1.75s
# Best: Epoch 7 	 loss=0.01803 	 val_loss=0.01820 	 sm_loss=0.01816 	 sm_val_loss=0.01822 	 time=2.02s
# Best: Epoch 8 	 loss=0.01785 	 val_loss=0.01792 	 sm_loss=0.01798 	 sm_val_loss=0.01795 	 time=2.20s
# Best: Epoch 10 	 loss=0.01752 	 val_loss=0.01754 	 sm_loss=0.01767 	 sm_val_loss=0.01756 	 time=2.00s
# Best: Epoch 12 	 loss=0.01712 	 val_loss=0.01745 	 sm_loss=0.01729 	 sm_val_loss=0.01755 	 time=1.79s
# Best: Epoch 13 	 loss=0.01693 	 val_loss=0.01734 	 sm_loss=0.01712 	 sm_val_loss=0.01739 	 time=2.00s
# Best: Epoch 15 	 loss=0.01653 	 val_loss=0.01718 	 sm_loss=0.01675 	 sm_val_loss=0.01725 	 time=1.71s
# Best: Epoch 16 	 loss=0.01629 	 val_loss=0.01716 	 sm_loss=0.01652 	 sm_val_loss=0.01720 	 time=1.75s
# Best: Epoch 17 	 loss=0.01607 	 val_loss=0.01704 	 sm_loss=0.01632 	 sm_val_loss=0.01709 	 time=1.70s
# Best: Epoch 18 	 loss=0.01588 	 val_loss=0.01702 	 sm_loss=0.01614 	 sm_val_loss=0.01706 	 time=1.72s
# Fold 1 log loss: 0.017078791952565352
# Fold 2
# Best: Epoch 1 	 loss=0.27836 	 val_loss=0.02137 	 sm_loss=0.27773 	 sm_val_loss=0.02130 	 time=1.73s
# Best: Epoch 2 	 loss=0.02091 	 val_loss=0.02044 	 sm_loss=0.02087 	 sm_val_loss=0.02039 	 time=1.75s
# Best: Epoch 3 	 loss=0.01978 	 val_loss=0.01922 	 sm_loss=0.01980 	 sm_val_loss=0.01922 	 time=1.73s
# Best: Epoch 4 	 loss=0.01895 	 val_loss=0.01888 	 sm_loss=0.01900 	 sm_val_loss=0.01883 	 time=1.92s
# Best: Epoch 5 	 loss=0.01850 	 val_loss=0.01868 	 sm_loss=0.01859 	 sm_val_loss=0.01872 	 time=1.77s
# Best: Epoch 6 	 loss=0.01829 	 val_loss=0.01827 	 sm_loss=0.01839 	 sm_val_loss=0.01832 	 time=1.72s
# Best: Epoch 10 	 loss=0.01749 	 val_loss=0.01810 	 sm_loss=0.01764 	 sm_val_loss=0.01807 	 time=1.93s
# Best: Epoch 11 	 loss=0.01734 	 val_loss=0.01772 	 sm_loss=0.01750 	 sm_val_loss=0.01775 	 time=2.03s
# Best: Epoch 13 	 loss=0.01693 	 val_loss=0.01761 	 sm_loss=0.01711 	 sm_val_loss=0.01762 	 time=1.75s
# Best: Epoch 14 	 loss=0.01672 	 val_loss=0.01756 	 sm_loss=0.01692 	 sm_val_loss=0.01761 	 time=1.73s
# Best: Epoch 15 	 loss=0.01648 	 val_loss=0.01743 	 sm_loss=0.01670 	 sm_val_loss=0.01746 	 time=1.73s
# Best: Epoch 16 	 loss=0.01628 	 val_loss=0.01737 	 sm_loss=0.01651 	 sm_val_loss=0.01739 	 time=1.94s
# Best: Epoch 17 	 loss=0.01601 	 val_loss=0.01732 	 sm_loss=0.01626 	 sm_val_loss=0.01733 	 time=1.74s
# Best: Epoch 18 	 loss=0.01585 	 val_loss=0.01727 	 sm_loss=0.01611 	 sm_val_loss=0.01726 	 time=1.78s
# Fold 2 log loss: 0.017243148275496764
# Fold 3
# Best: Epoch 1 	 loss=0.28040 	 val_loss=0.02208 	 sm_loss=0.27981 	 sm_val_loss=0.02168 	 time=1.71s
# Best: Epoch 2 	 loss=0.02067 	 val_loss=0.02017 	 sm_loss=0.02066 	 sm_val_loss=0.02018 	 time=2.00s
# Best: Epoch 3 	 loss=0.01955 	 val_loss=0.01944 	 sm_loss=0.01955 	 sm_val_loss=0.01945 	 time=1.67s
# Best: Epoch 4 	 loss=0.01869 	 val_loss=0.01938 	 sm_loss=0.01876 	 sm_val_loss=0.01929 	 time=1.69s
# Best: Epoch 5 	 loss=0.01840 	 val_loss=0.01898 	 sm_loss=0.01851 	 sm_val_loss=0.01892 	 time=1.68s
# Best: Epoch 7 	 loss=0.01792 	 val_loss=0.01840 	 sm_loss=0.01804 	 sm_val_loss=0.01839 	 time=1.67s
# Best: Epoch 9 	 loss=0.01755 	 val_loss=0.01838 	 sm_loss=0.01770 	 sm_val_loss=0.01837 	 time=2.00s
# Best: Epoch 11 	 loss=0.01719 	 val_loss=0.01822 	 sm_loss=0.01736 	 sm_val_loss=0.01818 	 time=1.68s
# Best: Epoch 13 	 loss=0.01680 	 val_loss=0.01801 	 sm_loss=0.01699 	 sm_val_loss=0.01794 	 time=1.66s
# Best: Epoch 14 	 loss=0.01656 	 val_loss=0.01787 	 sm_loss=0.01676 	 sm_val_loss=0.01787 	 time=1.93s
# Best: Epoch 15 	 loss=0.01637 	 val_loss=0.01782 	 sm_loss=0.01659 	 sm_val_loss=0.01784 	 time=1.77s
# Best: Epoch 16 	 loss=0.01607 	 val_loss=0.01783 	 sm_loss=0.01631 	 sm_val_loss=0.01774 	 time=1.68s
# Best: Epoch 17 	 loss=0.01587 	 val_loss=0.01772 	 sm_loss=0.01612 	 sm_val_loss=0.01764 	 time=1.67s
# Best: Epoch 20 	 loss=0.01544 	 val_loss=0.01775 	 sm_loss=0.01572 	 sm_val_loss=0.01762 	 time=1.89s
# Fold 3 log loss: 0.017626004726082122
# Fold 4
# Best: Epoch 1 	 loss=0.28926 	 val_loss=0.02106 	 sm_loss=0.28846 	 sm_val_loss=0.02098 	 time=1.73s
# Best: Epoch 2 	 loss=0.02057 	 val_loss=0.02004 	 sm_loss=0.02055 	 sm_val_loss=0.01993 	 time=1.73s
# Best: Epoch 4 	 loss=0.01889 	 val_loss=0.01927 	 sm_loss=0.01895 	 sm_val_loss=0.01915 	 time=1.74s
# Best: Epoch 5 	 loss=0.01848 	 val_loss=0.01868 	 sm_loss=0.01857 	 sm_val_loss=0.01855 	 time=1.75s
# Best: Epoch 6 	 loss=0.01833 	 val_loss=0.01848 	 sm_loss=0.01844 	 sm_val_loss=0.01850 	 time=1.97s
# Best: Epoch 9 	 loss=0.01770 	 val_loss=0.01794 	 sm_loss=0.01784 	 sm_val_loss=0.01793 	 time=1.74s
# Best: Epoch 11 	 loss=0.01734 	 val_loss=0.01763 	 sm_loss=0.01750 	 sm_val_loss=0.01759 	 time=1.76s
# Best: Epoch 13 	 loss=0.01692 	 val_loss=0.01737 	 sm_loss=0.01711 	 sm_val_loss=0.01733 	 time=1.92s
# Best: Epoch 14 	 loss=0.01673 	 val_loss=0.01737 	 sm_loss=0.01693 	 sm_val_loss=0.01731 	 time=1.78s
# Best: Epoch 15 	 loss=0.01649 	 val_loss=0.01728 	 sm_loss=0.01671 	 sm_val_loss=0.01721 	 time=2.02s
# Best: Epoch 16 	 loss=0.01621 	 val_loss=0.01720 	 sm_loss=0.01645 	 sm_val_loss=0.01714 	 time=1.78s
# Best: Epoch 17 	 loss=0.01599 	 val_loss=0.01715 	 sm_loss=0.01624 	 sm_val_loss=0.01709 	 time=2.08s
# Best: Epoch 18 	 loss=0.01580 	 val_loss=0.01710 	 sm_loss=0.01607 	 sm_val_loss=0.01703 	 time=1.76s
# Best: Epoch 19 	 loss=0.01564 	 val_loss=0.01707 	 sm_loss=0.01592 	 sm_val_loss=0.01699 	 time=1.77s
# Fold 4 log loss: 0.017036836554471003
# Fold 5
# Best: Epoch 1 	 loss=0.28600 	 val_loss=0.02109 	 sm_loss=0.28477 	 sm_val_loss=0.02103 	 time=1.79s
# Best: Epoch 3 	 loss=0.02025 	 val_loss=0.02044 	 sm_loss=0.02026 	 sm_val_loss=0.02037 	 time=1.94s
# Best: Epoch 4 	 loss=0.01921 	 val_loss=0.01937 	 sm_loss=0.01927 	 sm_val_loss=0.01938 	 time=1.97s
# Best: Epoch 7 	 loss=0.01859 	 val_loss=0.01887 	 sm_loss=0.01867 	 sm_val_loss=0.01872 	 time=1.74s
# Best: Epoch 9 	 loss=0.01787 	 val_loss=0.01874 	 sm_loss=0.01801 	 sm_val_loss=0.01868 	 time=1.73s
# Best: Epoch 10 	 loss=0.01755 	 val_loss=0.01839 	 sm_loss=0.01770 	 sm_val_loss=0.01832 	 time=1.74s
# Best: Epoch 11 	 loss=0.01751 	 val_loss=0.01805 	 sm_loss=0.01766 	 sm_val_loss=0.01802 	 time=1.73s
# Best: Epoch 13 	 loss=0.01701 	 val_loss=0.01801 	 sm_loss=0.01720 	 sm_val_loss=0.01794 	 time=1.74s
# Best: Epoch 14 	 loss=0.01679 	 val_loss=0.01772 	 sm_loss=0.01700 	 sm_val_loss=0.01768 	 time=1.87s
# Best: Epoch 15 	 loss=0.01659 	 val_loss=0.01767 	 sm_loss=0.01681 	 sm_val_loss=0.01757 	 time=1.95s
# Best: Epoch 16 	 loss=0.01640 	 val_loss=0.01762 	 sm_loss=0.01664 	 sm_val_loss=0.01754 	 time=1.84s
# Best: Epoch 17 	 loss=0.01615 	 val_loss=0.01757 	 sm_loss=0.01640 	 sm_val_loss=0.01749 	 time=1.74s
# Best: Epoch 18 	 loss=0.01594 	 val_loss=0.01754 	 sm_loss=0.01620 	 sm_val_loss=0.01743 	 time=1.74s
# Best: Epoch 19 	 loss=0.01581 	 val_loss=0.01754 	 sm_loss=0.01608 	 sm_val_loss=0.01742 	 time=1.74s
# Best: Epoch 20 	 loss=0.01572 	 val_loss=0.01750 	 sm_loss=0.01599 	 sm_val_loss=0.01740 	 time=1.89s
# Fold 5 log loss: 0.017404278240427545
# Fold 6
# Best: Epoch 1 	 loss=0.28343 	 val_loss=0.02201 	 sm_loss=0.28289 	 sm_val_loss=0.02179 	 time=2.06s
# Best: Epoch 6 	 loss=0.02145 	 val_loss=0.02167 	 sm_loss=0.02041 	 sm_val_loss=0.02046 	 time=2.01s
# Best: Epoch 9 	 loss=0.02117 	 val_loss=0.02168 	 sm_loss=0.02041 	 sm_val_loss=0.02030 	 time=1.74s
# Best: Epoch 10 	 loss=0.01942 	 val_loss=0.02074 	 sm_loss=0.01939 	 sm_val_loss=0.01986 	 time=1.74s
# Best: Epoch 12 	 loss=0.01873 	 val_loss=0.01966 	 sm_loss=0.01877 	 sm_val_loss=0.01951 	 time=1.76s
# Best: Epoch 13 	 loss=0.01850 	 val_loss=0.01941 	 sm_loss=0.01860 	 sm_val_loss=0.01910 	 time=1.73s
# Best: Epoch 15 	 loss=0.01808 	 val_loss=0.01885 	 sm_loss=0.01817 	 sm_val_loss=0.01852 	 time=1.72s
# Best: Epoch 17 	 loss=0.01767 	 val_loss=0.01882 	 sm_loss=0.01782 	 sm_val_loss=0.01839 	 time=1.90s
# Best: Epoch 18 	 loss=0.01730 	 val_loss=0.01846 	 sm_loss=0.01747 	 sm_val_loss=0.01820 	 time=2.18s
# Best: Epoch 19 	 loss=0.01721 	 val_loss=0.01827 	 sm_loss=0.01738 	 sm_val_loss=0.01807 	 time=1.84s
# Fold 6 log loss: 0.018139790980709652
# Fold 7
# Best: Epoch 1 	 loss=0.27907 	 val_loss=0.02328 	 sm_loss=0.27807 	 sm_val_loss=0.02328 	 time=1.72s
# Best: Epoch 2 	 loss=0.02056 	 val_loss=0.02010 	 sm_loss=0.02056 	 sm_val_loss=0.02002 	 time=1.76s
# Best: Epoch 3 	 loss=0.01954 	 val_loss=0.01970 	 sm_loss=0.01958 	 sm_val_loss=0.01945 	 time=2.22s
# Best: Epoch 4 	 loss=0.01902 	 val_loss=0.01939 	 sm_loss=0.01906 	 sm_val_loss=0.01931 	 time=1.77s
# Best: Epoch 7 	 loss=0.01795 	 val_loss=0.01850 	 sm_loss=0.01807 	 sm_val_loss=0.01850 	 time=1.72s
# Best: Epoch 9 	 loss=0.01766 	 val_loss=0.01827 	 sm_loss=0.01780 	 sm_val_loss=0.01829 	 time=1.94s
# Best: Epoch 10 	 loss=0.01758 	 val_loss=0.01821 	 sm_loss=0.01773 	 sm_val_loss=0.01827 	 time=1.75s
# Best: Epoch 11 	 loss=0.01736 	 val_loss=0.01795 	 sm_loss=0.01752 	 sm_val_loss=0.01798 	 time=1.74s
# Best: Epoch 12 	 loss=0.01716 	 val_loss=0.01790 	 sm_loss=0.01733 	 sm_val_loss=0.01792 	 time=1.73s
# Best: Epoch 13 	 loss=0.01697 	 val_loss=0.01768 	 sm_loss=0.01715 	 sm_val_loss=0.01772 	 time=1.78s
# Best: Epoch 14 	 loss=0.01672 	 val_loss=0.01753 	 sm_loss=0.01691 	 sm_val_loss=0.01756 	 time=1.78s
# Best: Epoch 15 	 loss=0.01660 	 val_loss=0.01744 	 sm_loss=0.01681 	 sm_val_loss=0.01744 	 time=2.65s
# Best: Epoch 18 	 loss=0.01597 	 val_loss=0.01735 	 sm_loss=0.01622 	 sm_val_loss=0.01731 	 time=1.83s
# Best: Epoch 19 	 loss=0.01578 	 val_loss=0.01732 	 sm_loss=0.01604 	 sm_val_loss=0.01728 	 time=1.77s
# Fold 7 log loss: 0.01739918166394125
# Seed 3
# Fold 1 log loss: 0.017078791952565352
# Fold 2 log loss: 0.017243148275496764
# Fold 3 log loss: 0.017626004726082122
# Fold 4 log loss: 0.017036836554471003
# Fold 5 log loss: 0.017404278240427545
# Fold 6 log loss: 0.018139790980709652
# Fold 7 log loss: 0.01739918166394125
# Std of log loss: 0.00034963466841192984
# Total log loss: 0.0174183923018131
# Fold 1
# Best: Epoch 1 	 loss=0.28115 	 val_loss=0.02137 	 sm_loss=0.28040 	 sm_val_loss=0.02128 	 time=1.73s
# Best: Epoch 2 	 loss=0.02069 	 val_loss=0.02042 	 sm_loss=0.02066 	 sm_val_loss=0.02028 	 time=1.74s
# Best: Epoch 3 	 loss=0.01951 	 val_loss=0.01932 	 sm_loss=0.01955 	 sm_val_loss=0.01932 	 time=1.76s
# Best: Epoch 4 	 loss=0.01916 	 val_loss=0.01902 	 sm_loss=0.01920 	 sm_val_loss=0.01890 	 time=1.74s
# Best: Epoch 5 	 loss=0.01858 	 val_loss=0.01842 	 sm_loss=0.01866 	 sm_val_loss=0.01842 	 time=1.96s
# Best: Epoch 7 	 loss=0.01812 	 val_loss=0.01832 	 sm_loss=0.01822 	 sm_val_loss=0.01836 	 time=1.72s
# Best: Epoch 8 	 loss=0.01795 	 val_loss=0.01829 	 sm_loss=0.01806 	 sm_val_loss=0.01825 	 time=1.75s
# Best: Epoch 9 	 loss=0.01775 	 val_loss=0.01792 	 sm_loss=0.01787 	 sm_val_loss=0.01797 	 time=1.71s
# Best: Epoch 11 	 loss=0.01744 	 val_loss=0.01754 	 sm_loss=0.01758 	 sm_val_loss=0.01756 	 time=1.97s
# Best: Epoch 13 	 loss=0.01704 	 val_loss=0.01748 	 sm_loss=0.01722 	 sm_val_loss=0.01754 	 time=1.71s
# Best: Epoch 14 	 loss=0.01684 	 val_loss=0.01746 	 sm_loss=0.01703 	 sm_val_loss=0.01749 	 time=1.73s
# Best: Epoch 15 	 loss=0.01662 	 val_loss=0.01732 	 sm_loss=0.01682 	 sm_val_loss=0.01733 	 time=1.72s
# Best: Epoch 16 	 loss=0.01639 	 val_loss=0.01714 	 sm_loss=0.01661 	 sm_val_loss=0.01717 	 time=1.97s
# Best: Epoch 17 	 loss=0.01621 	 val_loss=0.01711 	 sm_loss=0.01644 	 sm_val_loss=0.01716 	 time=1.94s
# Best: Epoch 18 	 loss=0.01602 	 val_loss=0.01707 	 sm_loss=0.01626 	 sm_val_loss=0.01711 	 time=1.70s
# Best: Epoch 19 	 loss=0.01588 	 val_loss=0.01705 	 sm_loss=0.01614 	 sm_val_loss=0.01708 	 time=1.73s
# Fold 1 log loss: 0.017102193732513454
# Fold 2
# Best: Epoch 1 	 loss=0.28602 	 val_loss=0.02157 	 sm_loss=0.28535 	 sm_val_loss=0.02144 	 time=1.70s
# Best: Epoch 2 	 loss=0.02054 	 val_loss=0.02006 	 sm_loss=0.02053 	 sm_val_loss=0.02002 	 time=1.83s
# Best: Epoch 3 	 loss=0.01972 	 val_loss=0.01903 	 sm_loss=0.01976 	 sm_val_loss=0.01904 	 time=1.87s
# Best: Epoch 5 	 loss=0.01865 	 val_loss=0.01841 	 sm_loss=0.01873 	 sm_val_loss=0.01846 	 time=2.14s
# Best: Epoch 7 	 loss=0.01822 	 val_loss=0.01822 	 sm_loss=0.01833 	 sm_val_loss=0.01826 	 time=1.85s
# Best: Epoch 8 	 loss=0.01788 	 val_loss=0.01794 	 sm_loss=0.01800 	 sm_val_loss=0.01802 	 time=1.78s
# Best: Epoch 10 	 loss=0.01754 	 val_loss=0.01795 	 sm_loss=0.01768 	 sm_val_loss=0.01799 	 time=1.74s
# Best: Epoch 11 	 loss=0.01737 	 val_loss=0.01786 	 sm_loss=0.01752 	 sm_val_loss=0.01788 	 time=1.73s
# Best: Epoch 13 	 loss=0.01701 	 val_loss=0.01780 	 sm_loss=0.01719 	 sm_val_loss=0.01781 	 time=1.70s
# Best: Epoch 14 	 loss=0.01681 	 val_loss=0.01754 	 sm_loss=0.01700 	 sm_val_loss=0.01759 	 time=1.96s
# Best: Epoch 15 	 loss=0.01657 	 val_loss=0.01746 	 sm_loss=0.01678 	 sm_val_loss=0.01751 	 time=1.71s
# Best: Epoch 16 	 loss=0.01637 	 val_loss=0.01746 	 sm_loss=0.01660 	 sm_val_loss=0.01747 	 time=1.70s
# Best: Epoch 17 	 loss=0.01615 	 val_loss=0.01737 	 sm_loss=0.01639 	 sm_val_loss=0.01739 	 time=1.70s
# Best: Epoch 18 	 loss=0.01596 	 val_loss=0.01737 	 sm_loss=0.01621 	 sm_val_loss=0.01738 	 time=1.73s
# Best: Epoch 19 	 loss=0.01586 	 val_loss=0.01736 	 sm_loss=0.01611 	 sm_val_loss=0.01736 	 time=1.72s
# Best: Epoch 20 	 loss=0.01573 	 val_loss=0.01736 	 sm_loss=0.01599 	 sm_val_loss=0.01735 	 time=1.99s
# Fold 2 log loss: 0.017333072708754175
# Fold 3
# Best: Epoch 1 	 loss=0.28464 	 val_loss=0.02286 	 sm_loss=0.28356 	 sm_val_loss=0.02227 	 time=1.83s
# Best: Epoch 2 	 loss=0.02066 	 val_loss=0.02059 	 sm_loss=0.02063 	 sm_val_loss=0.02030 	 time=1.75s
# Best: Epoch 4 	 loss=0.01897 	 val_loss=0.01914 	 sm_loss=0.01902 	 sm_val_loss=0.01914 	 time=1.76s
# Best: Epoch 6 	 loss=0.01825 	 val_loss=0.01888 	 sm_loss=0.01836 	 sm_val_loss=0.01888 	 time=2.04s
# Best: Epoch 9 	 loss=0.01767 	 val_loss=0.01848 	 sm_loss=0.01782 	 sm_val_loss=0.01852 	 time=1.75s
# Best: Epoch 10 	 loss=0.01748 	 val_loss=0.01839 	 sm_loss=0.01763 	 sm_val_loss=0.01833 	 time=1.84s
# Best: Epoch 11 	 loss=0.01726 	 val_loss=0.01813 	 sm_loss=0.01743 	 sm_val_loss=0.01811 	 time=1.94s
# Best: Epoch 14 	 loss=0.01674 	 val_loss=0.01796 	 sm_loss=0.01695 	 sm_val_loss=0.01791 	 time=1.72s
# Best: Epoch 15 	 loss=0.01649 	 val_loss=0.01790 	 sm_loss=0.01672 	 sm_val_loss=0.01788 	 time=1.72s
# Best: Epoch 16 	 loss=0.01629 	 val_loss=0.01791 	 sm_loss=0.01652 	 sm_val_loss=0.01787 	 time=1.75s
# Best: Epoch 17 	 loss=0.01609 	 val_loss=0.01783 	 sm_loss=0.01634 	 sm_val_loss=0.01774 	 time=2.18s
# Best: Epoch 18 	 loss=0.01585 	 val_loss=0.01779 	 sm_loss=0.01611 	 sm_val_loss=0.01767 	 time=2.14s
# Fold 3 log loss: 0.017673093661584365
# Fold 4
# Best: Epoch 1 	 loss=0.28997 	 val_loss=0.02128 	 sm_loss=0.28916 	 sm_val_loss=0.02115 	 time=1.77s
# Best: Epoch 2 	 loss=0.02041 	 val_loss=0.01956 	 sm_loss=0.02042 	 sm_val_loss=0.01957 	 time=1.97s
# Best: Epoch 3 	 loss=0.01945 	 val_loss=0.01955 	 sm_loss=0.01950 	 sm_val_loss=0.01955 	 time=1.80s
# Best: Epoch 4 	 loss=0.01910 	 val_loss=0.01907 	 sm_loss=0.01913 	 sm_val_loss=0.01909 	 time=2.13s
# Best: Epoch 5 	 loss=0.01858 	 val_loss=0.01851 	 sm_loss=0.01867 	 sm_val_loss=0.01846 	 time=1.79s
# Best: Epoch 7 	 loss=0.01815 	 val_loss=0.01845 	 sm_loss=0.01826 	 sm_val_loss=0.01828 	 time=1.74s
# Best: Epoch 8 	 loss=0.01786 	 val_loss=0.01821 	 sm_loss=0.01799 	 sm_val_loss=0.01814 	 time=1.93s
# Best: Epoch 11 	 loss=0.01737 	 val_loss=0.01791 	 sm_loss=0.01754 	 sm_val_loss=0.01793 	 time=1.76s
# Best: Epoch 12 	 loss=0.01718 	 val_loss=0.01756 	 sm_loss=0.01736 	 sm_val_loss=0.01760 	 time=1.74s
# Best: Epoch 13 	 loss=0.01698 	 val_loss=0.01741 	 sm_loss=0.01717 	 sm_val_loss=0.01739 	 time=1.73s
# Best: Epoch 14 	 loss=0.01678 	 val_loss=0.01732 	 sm_loss=0.01698 	 sm_val_loss=0.01729 	 time=1.96s
# Best: Epoch 15 	 loss=0.01653 	 val_loss=0.01734 	 sm_loss=0.01675 	 sm_val_loss=0.01727 	 time=1.86s
# Best: Epoch 16 	 loss=0.01634 	 val_loss=0.01727 	 sm_loss=0.01656 	 sm_val_loss=0.01725 	 time=1.84s
# Best: Epoch 17 	 loss=0.01611 	 val_loss=0.01720 	 sm_loss=0.01635 	 sm_val_loss=0.01716 	 time=1.75s
# Best: Epoch 18 	 loss=0.01592 	 val_loss=0.01713 	 sm_loss=0.01617 	 sm_val_loss=0.01705 	 time=1.77s
# Best: Epoch 19 	 loss=0.01575 	 val_loss=0.01712 	 sm_loss=0.01602 	 sm_val_loss=0.01704 	 time=1.73s
# Best: Epoch 20 	 loss=0.01566 	 val_loss=0.01711 	 sm_loss=0.01593 	 sm_val_loss=0.01702 	 time=1.99s
# Fold 4 log loss: 0.017084246392612353
# Fold 5
# Best: Epoch 1 	 loss=0.28464 	 val_loss=0.02231 	 sm_loss=0.28404 	 sm_val_loss=0.02218 	 time=1.96s
# Best: Epoch 2 	 loss=0.02057 	 val_loss=0.02029 	 sm_loss=0.02057 	 sm_val_loss=0.02010 	 time=1.87s
# Best: Epoch 3 	 loss=0.01959 	 val_loss=0.01999 	 sm_loss=0.01961 	 sm_val_loss=0.01986 	 time=1.80s
# Best: Epoch 8 	 loss=0.01961 	 val_loss=0.01983 	 sm_loss=0.01968 	 sm_val_loss=0.01973 	 time=1.86s
# Best: Epoch 9 	 loss=0.01898 	 val_loss=0.01899 	 sm_loss=0.01906 	 sm_val_loss=0.01892 	 time=1.92s
# Best: Epoch 10 	 loss=0.01852 	 val_loss=0.01876 	 sm_loss=0.01862 	 sm_val_loss=0.01872 	 time=1.81s
# Best: Epoch 11 	 loss=0.01818 	 val_loss=0.01854 	 sm_loss=0.01829 	 sm_val_loss=0.01857 	 time=2.02s
# Best: Epoch 12 	 loss=0.01796 	 val_loss=0.01854 	 sm_loss=0.01809 	 sm_val_loss=0.01846 	 time=1.96s
# Best: Epoch 13 	 loss=0.01783 	 val_loss=0.01839 	 sm_loss=0.01798 	 sm_val_loss=0.01833 	 time=1.80s
# Best: Epoch 14 	 loss=0.01767 	 val_loss=0.01811 	 sm_loss=0.01783 	 sm_val_loss=0.01803 	 time=1.78s
# Best: Epoch 15 	 loss=0.01740 	 val_loss=0.01792 	 sm_loss=0.01757 	 sm_val_loss=0.01786 	 time=1.76s
# Best: Epoch 16 	 loss=0.01716 	 val_loss=0.01780 	 sm_loss=0.01735 	 sm_val_loss=0.01773 	 time=1.79s
# Best: Epoch 17 	 loss=0.01693 	 val_loss=0.01773 	 sm_loss=0.01713 	 sm_val_loss=0.01767 	 time=2.01s
# Best: Epoch 19 	 loss=0.01657 	 val_loss=0.01770 	 sm_loss=0.01680 	 sm_val_loss=0.01761 	 time=2.05s
# Fold 5 log loss: 0.017606223478878538
# Fold 6
# Best: Epoch 1 	 loss=0.28098 	 val_loss=0.02225 	 sm_loss=0.28026 	 sm_val_loss=0.02189 	 time=1.75s
# Best: Epoch 7 	 loss=0.02099 	 val_loss=0.02371 	 sm_loss=0.02070 	 sm_val_loss=0.02091 	 time=1.71s
# Best: Epoch 11 	 loss=0.02067 	 val_loss=0.02128 	 sm_loss=0.02030 	 sm_val_loss=0.02008 	 time=1.67s
# Best: Epoch 12 	 loss=0.01936 	 val_loss=0.02138 	 sm_loss=0.01941 	 sm_val_loss=0.02005 	 time=1.71s
# Best: Epoch 13 	 loss=0.01900 	 val_loss=0.02015 	 sm_loss=0.01909 	 sm_val_loss=0.02002 	 time=1.72s
# Best: Epoch 14 	 loss=0.01868 	 val_loss=0.01976 	 sm_loss=0.01879 	 sm_val_loss=0.01922 	 time=2.10s
# Best: Epoch 15 	 loss=0.01849 	 val_loss=0.01963 	 sm_loss=0.01862 	 sm_val_loss=0.01904 	 time=2.02s
# Best: Epoch 17 	 loss=0.01839 	 val_loss=0.01920 	 sm_loss=0.01853 	 sm_val_loss=0.01875 	 time=1.67s
# Best: Epoch 18 	 loss=0.01805 	 val_loss=0.01910 	 sm_loss=0.01820 	 sm_val_loss=0.01865 	 time=1.73s
# Best: Epoch 19 	 loss=0.01796 	 val_loss=0.01907 	 sm_loss=0.01812 	 sm_val_loss=0.01847 	 time=2.11s
# Best: Epoch 20 	 loss=0.01765 	 val_loss=0.01908 	 sm_loss=0.01782 	 sm_val_loss=0.01844 	 time=2.00s
# Fold 6 log loss: 0.01850133959227627
# Fold 7
# Best: Epoch 1 	 loss=0.27682 	 val_loss=0.02404 	 sm_loss=0.27577 	 sm_val_loss=0.02396 	 time=1.89s
# Best: Epoch 2 	 loss=0.02132 	 val_loss=0.02052 	 sm_loss=0.02121 	 sm_val_loss=0.02046 	 time=1.84s
# Best: Epoch 3 	 loss=0.01982 	 val_loss=0.02025 	 sm_loss=0.01984 	 sm_val_loss=0.02012 	 time=1.89s
# Best: Epoch 4 	 loss=0.01940 	 val_loss=0.01980 	 sm_loss=0.01944 	 sm_val_loss=0.01974 	 time=1.82s
# Best: Epoch 5 	 loss=0.01874 	 val_loss=0.01955 	 sm_loss=0.01881 	 sm_val_loss=0.01944 	 time=2.07s
# Best: Epoch 6 	 loss=0.01827 	 val_loss=0.01941 	 sm_loss=0.01836 	 sm_val_loss=0.01928 	 time=1.79s
# Best: Epoch 7 	 loss=0.01808 	 val_loss=0.01918 	 sm_loss=0.01819 	 sm_val_loss=0.01917 	 time=1.79s
# Best: Epoch 8 	 loss=0.01805 	 val_loss=0.01849 	 sm_loss=0.01816 	 sm_val_loss=0.01847 	 time=1.80s
# Best: Epoch 9 	 loss=0.01769 	 val_loss=0.01788 	 sm_loss=0.01783 	 sm_val_loss=0.01791 	 time=1.76s
# Best: Epoch 13 	 loss=0.01715 	 val_loss=0.01765 	 sm_loss=0.01732 	 sm_val_loss=0.01772 	 time=1.76s
# Best: Epoch 14 	 loss=0.01689 	 val_loss=0.01756 	 sm_loss=0.01708 	 sm_val_loss=0.01758 	 time=1.76s
# Best: Epoch 15 	 loss=0.01680 	 val_loss=0.01741 	 sm_loss=0.01700 	 sm_val_loss=0.01741 	 time=1.81s
# Best: Epoch 17 	 loss=0.01634 	 val_loss=0.01731 	 sm_loss=0.01657 	 sm_val_loss=0.01732 	 time=1.81s
# Best: Epoch 18 	 loss=0.01612 	 val_loss=0.01732 	 sm_loss=0.01635 	 sm_val_loss=0.01729 	 time=1.81s
# Best: Epoch 19 	 loss=0.01604 	 val_loss=0.01729 	 sm_loss=0.01629 	 sm_val_loss=0.01727 	 time=1.86s
# Best: Epoch 20 	 loss=0.01597 	 val_loss=0.01728 	 sm_loss=0.01621 	 sm_val_loss=0.01726 	 time=1.86s
# Fold 7 log loss: 0.01737442550040495
# Seed 4
# Fold 1 log loss: 0.017102193732513454
# Fold 2 log loss: 0.017333072708754175
# Fold 3 log loss: 0.017673093661584365
# Fold 4 log loss: 0.017084246392612353
# Fold 5 log loss: 0.017606223478878538
# Fold 6 log loss: 0.01850133959227627
# Fold 7 log loss: 0.01737442550040495
# Std of log loss: 0.00044949266789646726
# Total log loss: 0.017524928405923672
# Total log loss in targets: 0.017235061354364388

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6454559479053382

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015884569018459364

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

# %% [markdown]
# - add dropout in the last layer of the second block
# - cpu

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
json_file_path = '../input/moapredictors/main_predictors.json'

with open(json_file_path, 'r') as j:
    predictors = json.loads(j.read())
    predictors = predictors['start_predictors']

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 14

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[(vc==6)|(vc==12)|(vc==18)].index.sort_values()
vc2 = vc.loc[(vc!=6)&(vc!=12)&(vc!=18)].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[0, 6, 5, ..., 1, 1, 6]], dtype=int8)

# %% [markdown]
# # Feature enginnering

# %%
X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.6)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
len(drop_feats)

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=500, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 933) (3624, 933)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
predictors_index = []
for i in range(len(train.columns)):
    if train.columns[i] in predictors:
        predictors_index.append(i)

# %%
fn_train = train.copy()
fn_test = test.copy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.Linear(num_columns, 512)
        self.relu1 = nn.ELU()
        self.dense12 = nn.Linear(512, 256)
        
        self.batch_norm2 = nn.BatchNorm1d(256+len(predictors_index))
        self.dropout2 = nn.Dropout(0.1)
        self.dense2 = nn.Linear(256+len(predictors_index), 512)
        self.relu2 = nn.ReLU()
        self.batch_norm22 = nn.BatchNorm1d(512)
        self.dense22 = nn.Linear(512, 512)
        self.relu22 = nn.ELU()
        self.batch_norm23 = nn.BatchNorm1d(512)
        self.dense23 = nn.Linear(512, 256)
        self.relu23 = nn.ReLU()
        self.batch_norm24 = nn.BatchNorm1d(256)
        self.dropout24 = nn.Dropout(0.1)
        self.dense24 = nn.Linear(256, 256)
        self.relu24 = nn.ELU()
                
        self.batch_norm3 = nn.BatchNorm1d(256)
        self.dense3 = nn.Linear(256, 256)
        self.relu3 = nn.SELU()
        self.batch_norm32 = nn.BatchNorm1d(256)
        self.dense32 = nn.Linear(256, last_num)

    def forward(self, x1, x2):
        x1 = self.batch_norm1(x1)
        x1 = self.dropout1(x1)
        x1 = self.relu1(self.dense1(x1))
        x1 = self.dense12(x1)
        
        x3 = torch.cat([x1,x2],axis=1)
                
        x3 = self.batch_norm2(x3)
        x3 = self.dropout2(x3)
        x3 = self.relu2(self.dense2(x3))
        x3 = self.batch_norm22(x3)
        x3 = self.relu22(self.dense22(x3))
        x3 = self.batch_norm23(x3)
        x3 = self.relu23(self.dense23(x3))
        x3 = self.batch_norm24(x3)
        x3 = self.dropout24(x3)
        x3 = self.relu24(self.dense24(x3))
        
        x4 = (x1 + x3) / 2
        
        x4 = self.batch_norm3(x4)
        x4 = self.relu3(self.dense3(x4))
        x4 = self.batch_norm32(x4)
        x4 = self.dense32(x4)
        
        return x4
# Out:
# cpu

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    train_epochs = 20
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te.values, dtype=torch.float32)
    X_test2 = torch.tensor(te.iloc[:][predictors].values, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test, X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr["fold"] == fold
        train_index = tr["fold"] != fold
        print("Fold "+str(fold+1))
        X_train1 = torch.tensor(tr[train_index].values, dtype=torch.float32)
        X_valid1 = torch.tensor(tr[valid_index].values, dtype=torch.float32)
        X_train2 = torch.tensor(tr[train_index][predictors].values, dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index][predictors].values, dtype=torch.float32)
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        X_train1 = X_train1[:,:-1]
        X_valid1 = X_valid1[:,:-1]
        
        train = torch.utils.data.TensorDataset(X_train1, X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid1, X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
            
        optimizer = optim.Adam(clf.parameters(), lr = 0.01, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))            
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, x_batch2, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        pred_model = MoaModel(init_num, len(target_feats))
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
        for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
            y_pred = pred_model(x_batch, x_batch2).detach()
            oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        

        # test predcition --------------
        test_preds = np.zeros([test_len, target.shape[1]])
        for i, (x_batch,x_batch2,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch,x_batch2).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
    
    print("Seed {}".format(sample_seed))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4] 
    
for seed_ in seeds:
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.43194  val_loss=0.02085  sm_loss=0.43193  sm_val_loss=0.02082  time=9.09s
# Epoch 2  loss=0.01926  val_loss=0.01854  sm_loss=0.01927  sm_val_loss=0.01857  time=9.23s
# Epoch 3  loss=0.01830  val_loss=0.01848  sm_loss=0.01835  sm_val_loss=0.01849  time=9.67s
# Epoch 4  loss=0.01800  val_loss=0.01814  sm_loss=0.01808  sm_val_loss=0.01819  time=10.37s
# Epoch 5  loss=0.01781  val_loss=0.01796  sm_loss=0.01790  sm_val_loss=0.01802  time=9.22s
# Epoch 6  loss=0.01775  val_loss=0.01777  sm_loss=0.01784  sm_val_loss=0.01785  time=9.77s
# Epoch 8  loss=0.01750  val_loss=0.01775  sm_loss=0.01760  sm_val_loss=0.01783  time=9.00s
# Epoch 9  loss=0.01740  val_loss=0.01753  sm_loss=0.01750  sm_val_loss=0.01760  time=8.93s
# Epoch 12  loss=0.01701  val_loss=0.01741  sm_loss=0.01714  sm_val_loss=0.01748  time=9.22s
# Epoch 13  loss=0.01678  val_loss=0.01740  sm_loss=0.01692  sm_val_loss=0.01748  time=9.50s
# Epoch 14  loss=0.01662  val_loss=0.01724  sm_loss=0.01677  sm_val_loss=0.01733  time=9.47s
# Epoch 15  loss=0.01637  val_loss=0.01722  sm_loss=0.01653  sm_val_loss=0.01729  time=9.80s
# Epoch 16  loss=0.01614  val_loss=0.01699  sm_loss=0.01631  sm_val_loss=0.01707  time=11.28s
# Epoch 18  loss=0.01575  val_loss=0.01692  sm_loss=0.01593  sm_val_loss=0.01700  time=12.62s
# Fold 1 log loss: 0.017020428237846448
# Fold 2
# Epoch 1  loss=0.42879  val_loss=0.02107  sm_loss=0.42878  sm_val_loss=0.02106  time=8.80s
# Epoch 2  loss=0.01940  val_loss=0.01877  sm_loss=0.01941  sm_val_loss=0.01876  time=8.80s
# Epoch 4  loss=0.01800  val_loss=0.01802  sm_loss=0.01808  sm_val_loss=0.01808  time=9.25s
# Epoch 8  loss=0.01744  val_loss=0.01792  sm_loss=0.01755  sm_val_loss=0.01796  time=8.75s
# Epoch 10  loss=0.01722  val_loss=0.01770  sm_loss=0.01735  sm_val_loss=0.01774  time=9.61s
# Epoch 11  loss=0.01710  val_loss=0.01767  sm_loss=0.01723  sm_val_loss=0.01773  time=9.27s
# Epoch 12  loss=0.01698  val_loss=0.01745  sm_loss=0.01711  sm_val_loss=0.01750  time=8.84s
# Epoch 15  loss=0.01636  val_loss=0.01735  sm_loss=0.01653  sm_val_loss=0.01741  time=9.85s
# Epoch 16  loss=0.01613  val_loss=0.01727  sm_loss=0.01631  sm_val_loss=0.01733  time=11.62s
# Epoch 17  loss=0.01590  val_loss=0.01719  sm_loss=0.01608  sm_val_loss=0.01726  time=12.70s
# Epoch 18  loss=0.01572  val_loss=0.01716  sm_loss=0.01591  sm_val_loss=0.01722  time=12.50s
# Epoch 19  loss=0.01554  val_loss=0.01710  sm_loss=0.01573  sm_val_loss=0.01716  time=13.28s
# Fold 2 log loss: 0.017140321589703713
# Fold 3
# Epoch 1  loss=0.42982  val_loss=0.02090  sm_loss=0.42981  sm_val_loss=0.02086  time=9.58s
# Epoch 2  loss=0.01929  val_loss=0.01894  sm_loss=0.01931  sm_val_loss=0.01893  time=9.08s
# Epoch 3  loss=0.01810  val_loss=0.01861  sm_loss=0.01816  sm_val_loss=0.01861  time=9.31s
# Epoch 4  loss=0.01782  val_loss=0.01839  sm_loss=0.01791  sm_val_loss=0.01843  time=9.08s
# Epoch 8  loss=0.01730  val_loss=0.01824  sm_loss=0.01741  sm_val_loss=0.01830  time=9.37s
# Epoch 10  loss=0.01712  val_loss=0.01818  sm_loss=0.01724  sm_val_loss=0.01820  time=9.30s
# Epoch 11  loss=0.01694  val_loss=0.01802  sm_loss=0.01707  sm_val_loss=0.01807  time=9.12s
# Epoch 13  loss=0.01664  val_loss=0.01788  sm_loss=0.01679  sm_val_loss=0.01793  time=9.41s
# Epoch 14  loss=0.01636  val_loss=0.01773  sm_loss=0.01652  sm_val_loss=0.01776  time=9.92s
# Epoch 15  loss=0.01617  val_loss=0.01766  sm_loss=0.01634  sm_val_loss=0.01768  time=9.49s
# Epoch 17  loss=0.01572  val_loss=0.01754  sm_loss=0.01591  sm_val_loss=0.01755  time=10.75s
# Epoch 18  loss=0.01549  val_loss=0.01751  sm_loss=0.01568  sm_val_loss=0.01752  time=10.90s
# Fold 3 log loss: 0.0175328046852445
# Fold 4
# Epoch 1  loss=0.42717  val_loss=0.02078  sm_loss=0.42716  sm_val_loss=0.02077  time=8.85s
# Epoch 2  loss=0.01955  val_loss=0.01911  sm_loss=0.01956  sm_val_loss=0.01907  time=8.99s
# Epoch 3  loss=0.01841  val_loss=0.01836  sm_loss=0.01846  sm_val_loss=0.01836  time=9.40s
# Epoch 4  loss=0.01810  val_loss=0.01788  sm_loss=0.01818  sm_val_loss=0.01791  time=8.98s
# Epoch 6  loss=0.01774  val_loss=0.01783  sm_loss=0.01784  sm_val_loss=0.01784  time=9.98s
# Epoch 7  loss=0.01761  val_loss=0.01776  sm_loss=0.01772  sm_val_loss=0.01780  time=9.34s
# Epoch 10  loss=0.01731  val_loss=0.01750  sm_loss=0.01744  sm_val_loss=0.01755  time=9.34s
# Epoch 12  loss=0.01701  val_loss=0.01745  sm_loss=0.01715  sm_val_loss=0.01746  time=9.65s
# Epoch 13  loss=0.01688  val_loss=0.01732  sm_loss=0.01704  sm_val_loss=0.01735  time=10.14s
# Epoch 14  loss=0.01669  val_loss=0.01721  sm_loss=0.01685  sm_val_loss=0.01726  time=10.00s
# Epoch 15  loss=0.01642  val_loss=0.01716  sm_loss=0.01659  sm_val_loss=0.01715  time=11.35s
# Epoch 16  loss=0.01621  val_loss=0.01709  sm_loss=0.01638  sm_val_loss=0.01713  time=14.04s
# Epoch 17  loss=0.01600  val_loss=0.01700  sm_loss=0.01618  sm_val_loss=0.01701  time=16.99s
# Epoch 19  loss=0.01562  val_loss=0.01697  sm_loss=0.01581  sm_val_loss=0.01699  time=18.72s
# Epoch 20  loss=0.01553  val_loss=0.01695  sm_loss=0.01572  sm_val_loss=0.01698  time=19.41s
# Fold 4 log loss: 0.01703751656997083
# Fold 5
# Epoch 1  loss=0.42768  val_loss=0.02110  sm_loss=0.42767  sm_val_loss=0.02106  time=9.38s
# Epoch 2  loss=0.01934  val_loss=0.01996  sm_loss=0.01936  sm_val_loss=0.01997  time=8.85s
# Epoch 3  loss=0.01832  val_loss=0.01934  sm_loss=0.01838  sm_val_loss=0.01932  time=9.39s
# Epoch 4  loss=0.01805  val_loss=0.01834  sm_loss=0.01811  sm_val_loss=0.01836  time=9.04s
# Epoch 8  loss=0.01754  val_loss=0.01795  sm_loss=0.01765  sm_val_loss=0.01795  time=8.84s
# Epoch 12  loss=0.01703  val_loss=0.01784  sm_loss=0.01716  sm_val_loss=0.01785  time=8.93s
# Epoch 14  loss=0.01668  val_loss=0.01753  sm_loss=0.01684  sm_val_loss=0.01753  time=10.01s
# Epoch 16  loss=0.01618  val_loss=0.01741  sm_loss=0.01635  sm_val_loss=0.01742  time=13.54s
# Epoch 17  loss=0.01591  val_loss=0.01737  sm_loss=0.01609  sm_val_loss=0.01739  time=16.24s
# Epoch 18  loss=0.01577  val_loss=0.01734  sm_loss=0.01595  sm_val_loss=0.01736  time=17.71s
# Epoch 19  loss=0.01564  val_loss=0.01734  sm_loss=0.01583  sm_val_loss=0.01735  time=18.76s
# Epoch 20  loss=0.01550  val_loss=0.01733  sm_loss=0.01570  sm_val_loss=0.01734  time=18.94s
# Fold 5 log loss: 0.01736144785089984
# Fold 6
# Epoch 1  loss=0.42906  val_loss=0.02113  sm_loss=0.42905  sm_val_loss=0.02106  time=9.73s
# Epoch 2  loss=0.01943  val_loss=0.02001  sm_loss=0.01944  sm_val_loss=0.02000  time=9.86s
# Epoch 3  loss=0.01831  val_loss=0.01905  sm_loss=0.01835  sm_val_loss=0.01897  time=9.10s
# Epoch 4  loss=0.01811  val_loss=0.01889  sm_loss=0.01817  sm_val_loss=0.01887  time=8.89s
# Epoch 12  loss=0.01794  val_loss=0.01830  sm_loss=0.01804  sm_val_loss=0.01826  time=8.85s
# Epoch 15  loss=0.01739  val_loss=0.01805  sm_loss=0.01750  sm_val_loss=0.01805  time=9.84s
# Epoch 16  loss=0.01736  val_loss=0.01803  sm_loss=0.01739  sm_val_loss=0.01802  time=9.75s
# Epoch 17  loss=0.01710  val_loss=0.01774  sm_loss=0.01723  sm_val_loss=0.01776  time=10.43s
# Epoch 19  loss=0.01684  val_loss=0.01772  sm_loss=0.01698  sm_val_loss=0.01773  time=10.40s
# Fold 6 log loss: 0.017797729943288026
# Fold 7
# Epoch 1  loss=0.42789  val_loss=0.02056  sm_loss=0.42789  sm_val_loss=0.02058  time=9.27s
# Epoch 2  loss=0.01921  val_loss=0.01887  sm_loss=0.01922  sm_val_loss=0.01892  time=8.83s
# Epoch 3  loss=0.01840  val_loss=0.01824  sm_loss=0.01846  sm_val_loss=0.01829  time=8.83s
# Epoch 4  loss=0.01806  val_loss=0.01817  sm_loss=0.01813  sm_val_loss=0.01822  time=9.25s
# Epoch 6  loss=0.01783  val_loss=0.01813  sm_loss=0.01792  sm_val_loss=0.01820  time=8.82s
# Epoch 7  loss=0.01766  val_loss=0.01805  sm_loss=0.01775  sm_val_loss=0.01809  time=10.78s
# Epoch 8  loss=0.01760  val_loss=0.01789  sm_loss=0.01770  sm_val_loss=0.01793  time=9.53s
# Epoch 10  loss=0.01734  val_loss=0.01770  sm_loss=0.01745  sm_val_loss=0.01774  time=8.78s
# Epoch 12  loss=0.01708  val_loss=0.01763  sm_loss=0.01721  sm_val_loss=0.01769  time=8.92s
# Epoch 13  loss=0.01686  val_loss=0.01761  sm_loss=0.01700  sm_val_loss=0.01765  time=9.60s
# Epoch 14  loss=0.01666  val_loss=0.01754  sm_loss=0.01681  sm_val_loss=0.01758  time=10.40s
# Epoch 15  loss=0.01647  val_loss=0.01736  sm_loss=0.01663  sm_val_loss=0.01739  time=9.62s
# Epoch 17  loss=0.01600  val_loss=0.01730  sm_loss=0.01617  sm_val_loss=0.01734  time=11.22s
# Epoch 18  loss=0.01585  val_loss=0.01727  sm_loss=0.01603  sm_val_loss=0.01732  time=12.05s
# Epoch 19  loss=0.01568  val_loss=0.01725  sm_loss=0.01587  sm_val_loss=0.01727  time=13.61s
# Epoch 20  loss=0.01561  val_loss=0.01723  sm_loss=0.01580  sm_val_loss=0.01726  time=13.67s
# Fold 7 log loss: 0.017369043611638362
# Seed 0
# Fold 1 log loss: 0.017020428237846448
# Fold 2 log loss: 0.017140321589703713
# Fold 3 log loss: 0.0175328046852445
# Fold 4 log loss: 0.01703751656997083
# Fold 5 log loss: 0.01736144785089984
# Fold 6 log loss: 0.017797729943288026
# Fold 7 log loss: 0.017369043611638362
# Std of log loss: 0.0002616994518158512
# Total log loss: 0.01732271276172987
# Fold 1
# Epoch 1  loss=0.42985  val_loss=0.02061  sm_loss=0.42984  sm_val_loss=0.02060  time=8.82s
# Epoch 2  loss=0.01937  val_loss=0.01856  sm_loss=0.01938  sm_val_loss=0.01861  time=8.85s
# Epoch 5  loss=0.01785  val_loss=0.01796  sm_loss=0.01794  sm_val_loss=0.01799  time=9.30s
# Epoch 7  loss=0.01761  val_loss=0.01769  sm_loss=0.01771  sm_val_loss=0.01774  time=9.07s
# Epoch 8  loss=0.01749  val_loss=0.01760  sm_loss=0.01760  sm_val_loss=0.01769  time=8.91s
# Epoch 12  loss=0.01695  val_loss=0.01742  sm_loss=0.01709  sm_val_loss=0.01751  time=8.94s
# Epoch 13  loss=0.01675  val_loss=0.01738  sm_loss=0.01689  sm_val_loss=0.01749  time=8.90s
# Epoch 14  loss=0.01657  val_loss=0.01727  sm_loss=0.01673  sm_val_loss=0.01736  time=9.27s
# Epoch 15  loss=0.01633  val_loss=0.01719  sm_loss=0.01649  sm_val_loss=0.01729  time=9.06s
# Epoch 16  loss=0.01609  val_loss=0.01698  sm_loss=0.01627  sm_val_loss=0.01709  time=9.18s
# Epoch 18  loss=0.01566  val_loss=0.01696  sm_loss=0.01585  sm_val_loss=0.01707  time=10.07s
# Epoch 19  loss=0.01552  val_loss=0.01695  sm_loss=0.01571  sm_val_loss=0.01706  time=9.32s
# Epoch 20  loss=0.01544  val_loss=0.01694  sm_loss=0.01563  sm_val_loss=0.01705  time=9.81s
# Fold 1 log loss: 0.01706975878680218
# Fold 2
# Epoch 1  loss=0.42989  val_loss=0.02096  sm_loss=0.42989  sm_val_loss=0.02095  time=10.04s
# Epoch 2  loss=0.01932  val_loss=0.01853  sm_loss=0.01934  sm_val_loss=0.01854  time=9.01s
# Epoch 3  loss=0.01821  val_loss=0.01840  sm_loss=0.01826  sm_val_loss=0.01844  time=9.04s
# Epoch 4  loss=0.01792  val_loss=0.01830  sm_loss=0.01799  sm_val_loss=0.01835  time=9.61s
# Epoch 5  loss=0.01786  val_loss=0.01797  sm_loss=0.01794  sm_val_loss=0.01804  time=9.26s
# Epoch 6  loss=0.01766  val_loss=0.01791  sm_loss=0.01775  sm_val_loss=0.01796  time=9.31s
# Epoch 8  loss=0.01752  val_loss=0.01788  sm_loss=0.01762  sm_val_loss=0.01793  time=9.19s
# Epoch 11  loss=0.01712  val_loss=0.01774  sm_loss=0.01725  sm_val_loss=0.01780  time=8.94s
# Epoch 12  loss=0.01699  val_loss=0.01761  sm_loss=0.01713  sm_val_loss=0.01765  time=9.07s
# Epoch 13  loss=0.01675  val_loss=0.01746  sm_loss=0.01690  sm_val_loss=0.01751  time=9.15s
# Epoch 14  loss=0.01660  val_loss=0.01740  sm_loss=0.01675  sm_val_loss=0.01747  time=9.04s
# Epoch 16  loss=0.01615  val_loss=0.01730  sm_loss=0.01631  sm_val_loss=0.01736  time=9.51s
# Epoch 17  loss=0.01595  val_loss=0.01718  sm_loss=0.01612  sm_val_loss=0.01724  time=10.16s
# Fold 2 log loss: 0.01722574304696921
# Fold 3
# Epoch 1  loss=0.42944  val_loss=0.02106  sm_loss=0.42944  sm_val_loss=0.02105  time=8.76s
# Epoch 2  loss=0.01916  val_loss=0.01945  sm_loss=0.01918  sm_val_loss=0.01946  time=9.69s
# Epoch 3  loss=0.01818  val_loss=0.01879  sm_loss=0.01823  sm_val_loss=0.01882  time=9.11s
# Epoch 4  loss=0.01783  val_loss=0.01854  sm_loss=0.01791  sm_val_loss=0.01860  time=8.75s
# Epoch 6  loss=0.01758  val_loss=0.01832  sm_loss=0.01768  sm_val_loss=0.01834  time=8.79s
# Epoch 8  loss=0.01732  val_loss=0.01810  sm_loss=0.01744  sm_val_loss=0.01813  time=8.84s
# Epoch 11  loss=0.01692  val_loss=0.01807  sm_loss=0.01706  sm_val_loss=0.01810  time=8.85s
# Epoch 12  loss=0.01679  val_loss=0.01782  sm_loss=0.01694  sm_val_loss=0.01786  time=8.72s
# Epoch 14  loss=0.01637  val_loss=0.01768  sm_loss=0.01654  sm_val_loss=0.01773  time=9.02s
# Epoch 16  loss=0.01593  val_loss=0.01762  sm_loss=0.01611  sm_val_loss=0.01766  time=11.63s
# Epoch 17  loss=0.01572  val_loss=0.01758  sm_loss=0.01592  sm_val_loss=0.01761  time=9.57s
# Epoch 18  loss=0.01553  val_loss=0.01750  sm_loss=0.01573  sm_val_loss=0.01753  time=10.27s
# Epoch 20  loss=0.01530  val_loss=0.01751  sm_loss=0.01551  sm_val_loss=0.01753  time=9.71s
# Fold 3 log loss: 0.017537011604454898
# Fold 4
# Epoch 1  loss=0.43019  val_loss=0.02055  sm_loss=0.43019  sm_val_loss=0.02056  time=9.51s
# Epoch 2  loss=0.01931  val_loss=0.01946  sm_loss=0.01935  sm_val_loss=0.01944  time=10.08s
# Epoch 3  loss=0.01835  val_loss=0.01856  sm_loss=0.01841  sm_val_loss=0.01857  time=9.22s
# Epoch 4  loss=0.01804  val_loss=0.01810  sm_loss=0.01813  sm_val_loss=0.01816  time=9.18s
# Epoch 5  loss=0.01782  val_loss=0.01806  sm_loss=0.01791  sm_val_loss=0.01802  time=9.25s
# Epoch 6  loss=0.01773  val_loss=0.01797  sm_loss=0.01783  sm_val_loss=0.01799  time=9.36s
# Epoch 8  loss=0.01756  val_loss=0.01780  sm_loss=0.01768  sm_val_loss=0.01783  time=9.44s
# Epoch 10  loss=0.01737  val_loss=0.01780  sm_loss=0.01750  sm_val_loss=0.01780  time=9.10s
# Epoch 11  loss=0.01719  val_loss=0.01759  sm_loss=0.01732  sm_val_loss=0.01762  time=8.85s
# Epoch 12  loss=0.01700  val_loss=0.01745  sm_loss=0.01714  sm_val_loss=0.01746  time=8.99s
# Epoch 14  loss=0.01668  val_loss=0.01735  sm_loss=0.01683  sm_val_loss=0.01738  time=10.15s
# Epoch 15  loss=0.01647  val_loss=0.01713  sm_loss=0.01663  sm_val_loss=0.01715  time=10.86s
# Epoch 17  loss=0.01599  val_loss=0.01705  sm_loss=0.01617  sm_val_loss=0.01708  time=12.42s
# Epoch 18  loss=0.01584  val_loss=0.01696  sm_loss=0.01602  sm_val_loss=0.01698  time=13.03s
# Epoch 19  loss=0.01569  val_loss=0.01695  sm_loss=0.01588  sm_val_loss=0.01698  time=14.26s
# Fold 4 log loss: 0.01703993594817357
# Fold 5
# Epoch 1  loss=0.42819  val_loss=0.02108  sm_loss=0.42818  sm_val_loss=0.02096  time=9.27s
# Epoch 2  loss=0.01932  val_loss=0.01921  sm_loss=0.01935  sm_val_loss=0.01917  time=8.89s
# Epoch 3  loss=0.01827  val_loss=0.01855  sm_loss=0.01832  sm_val_loss=0.01856  time=8.86s
# Epoch 4  loss=0.01801  val_loss=0.01836  sm_loss=0.01808  sm_val_loss=0.01834  time=8.89s
# Epoch 5  loss=0.01781  val_loss=0.01823  sm_loss=0.01790  sm_val_loss=0.01825  time=10.31s
# Epoch 7  loss=0.01757  val_loss=0.01823  sm_loss=0.01768  sm_val_loss=0.01822  time=9.82s
# Epoch 8  loss=0.01748  val_loss=0.01819  sm_loss=0.01759  sm_val_loss=0.01818  time=10.66s
# Epoch 10  loss=0.01723  val_loss=0.01802  sm_loss=0.01736  sm_val_loss=0.01805  time=10.75s
# Epoch 11  loss=0.01713  val_loss=0.01792  sm_loss=0.01726  sm_val_loss=0.01797  time=9.78s
# Epoch 12  loss=0.01693  val_loss=0.01782  sm_loss=0.01707  sm_val_loss=0.01784  time=8.94s
# Epoch 13  loss=0.01681  val_loss=0.01768  sm_loss=0.01695  sm_val_loss=0.01771  time=8.98s
# Epoch 14  loss=0.01659  val_loss=0.01765  sm_loss=0.01675  sm_val_loss=0.01766  time=9.02s
# Epoch 15  loss=0.01637  val_loss=0.01765  sm_loss=0.01654  sm_val_loss=0.01765  time=9.66s
# Epoch 16  loss=0.01621  val_loss=0.01750  sm_loss=0.01638  sm_val_loss=0.01747  time=9.29s
# Epoch 17  loss=0.01593  val_loss=0.01741  sm_loss=0.01611  sm_val_loss=0.01742  time=10.08s
# Epoch 19  loss=0.01567  val_loss=0.01740  sm_loss=0.01586  sm_val_loss=0.01739  time=9.70s
# Fold 5 log loss: 0.017402917950441032
# Fold 6
# Epoch 1  loss=0.42834  val_loss=0.02108  sm_loss=0.42833  sm_val_loss=0.02086  time=8.82s
# Epoch 2  loss=0.01955  val_loss=0.01934  sm_loss=0.01957  sm_val_loss=0.01931  time=9.13s
# Epoch 6  loss=0.01835  val_loss=0.01901  sm_loss=0.01841  sm_val_loss=0.01898  time=8.74s
# Epoch 7  loss=0.01796  val_loss=0.01862  sm_loss=0.01804  sm_val_loss=0.01862  time=8.79s
# Epoch 8  loss=0.01773  val_loss=0.01844  sm_loss=0.01783  sm_val_loss=0.01846  time=8.95s
# Epoch 9  loss=0.01769  val_loss=0.01817  sm_loss=0.01779  sm_val_loss=0.01822  time=9.39s
# Epoch 11  loss=0.01740  val_loss=0.01805  sm_loss=0.01752  sm_val_loss=0.01806  time=8.86s
# Epoch 12  loss=0.01717  val_loss=0.01780  sm_loss=0.01731  sm_val_loss=0.01778  time=8.86s
# Epoch 13  loss=0.01703  val_loss=0.01778  sm_loss=0.01716  sm_val_loss=0.01778  time=9.06s
# Epoch 14  loss=0.01685  val_loss=0.01779  sm_loss=0.01700  sm_val_loss=0.01777  time=8.87s
# Epoch 15  loss=0.01664  val_loss=0.01768  sm_loss=0.01679  sm_val_loss=0.01767  time=8.83s
# Epoch 16  loss=0.01630  val_loss=0.01751  sm_loss=0.01646  sm_val_loss=0.01753  time=9.51s
# Epoch 17  loss=0.01631  val_loss=0.01749  sm_loss=0.01647  sm_val_loss=0.01752  time=9.35s
# Epoch 18  loss=0.01602  val_loss=0.01743  sm_loss=0.01619  sm_val_loss=0.01744  time=8.84s
# Epoch 19  loss=0.01586  val_loss=0.01737  sm_loss=0.01603  sm_val_loss=0.01737  time=8.99s
# Epoch 20  loss=0.01575  val_loss=0.01733  sm_loss=0.01593  sm_val_loss=0.01734  time=9.26s
# Fold 6 log loss: 0.017394837096589327
# Fold 7
# Epoch 1  loss=0.42895  val_loss=0.02055  sm_loss=0.42895  sm_val_loss=0.02055  time=11.46s
# Epoch 2  loss=0.01929  val_loss=0.01936  sm_loss=0.01930  sm_val_loss=0.01940  time=11.90s
# Epoch 3  loss=0.01823  val_loss=0.01877  sm_loss=0.01828  sm_val_loss=0.01873  time=9.59s
# Epoch 5  loss=0.01808  val_loss=0.01795  sm_loss=0.01815  sm_val_loss=0.01799  time=8.92s
# Epoch 9  loss=0.01748  val_loss=0.01796  sm_loss=0.01759  sm_val_loss=0.01796  time=9.53s
# Epoch 10  loss=0.01737  val_loss=0.01788  sm_loss=0.01749  sm_val_loss=0.01788  time=9.30s
# Epoch 11  loss=0.01711  val_loss=0.01786  sm_loss=0.01723  sm_val_loss=0.01786  time=8.92s
# Epoch 12  loss=0.01704  val_loss=0.01773  sm_loss=0.01717  sm_val_loss=0.01775  time=8.91s
# Epoch 13  loss=0.01679  val_loss=0.01771  sm_loss=0.01694  sm_val_loss=0.01772  time=9.09s
# Epoch 14  loss=0.01666  val_loss=0.01745  sm_loss=0.01681  sm_val_loss=0.01747  time=9.50s
# Epoch 15  loss=0.01642  val_loss=0.01733  sm_loss=0.01657  sm_val_loss=0.01735  time=10.22s
# Epoch 16  loss=0.01617  val_loss=0.01730  sm_loss=0.01634  sm_val_loss=0.01731  time=11.16s
# Epoch 17  loss=0.01593  val_loss=0.01721  sm_loss=0.01611  sm_val_loss=0.01724  time=12.45s
# Epoch 18  loss=0.01572  val_loss=0.01720  sm_loss=0.01591  sm_val_loss=0.01722  time=12.81s
# Epoch 19  loss=0.01558  val_loss=0.01718  sm_loss=0.01577  sm_val_loss=0.01720  time=13.91s
# Fold 7 log loss: 0.01730878215227671
# Seed 1
# Fold 1 log loss: 0.01706975878680218
# Fold 2 log loss: 0.01722574304696921
# Fold 3 log loss: 0.017537011604454898
# Fold 4 log loss: 0.01703993594817357
# Fold 5 log loss: 0.017402917950441032
# Fold 6 log loss: 0.017394837096589327
# Fold 7 log loss: 0.01730878215227671
# Std of log loss: 0.00016899036043194066
# Total log loss: 0.017282937296821135
# Fold 1
# Epoch 1  loss=0.42971  val_loss=0.02057  sm_loss=0.42971  sm_val_loss=0.02048  time=8.86s
# Epoch 2  loss=0.01933  val_loss=0.01865  sm_loss=0.01935  sm_val_loss=0.01866  time=9.24s
# Epoch 3  loss=0.01851  val_loss=0.01799  sm_loss=0.01855  sm_val_loss=0.01807  time=8.88s
# Epoch 5  loss=0.01789  val_loss=0.01792  sm_loss=0.01797  sm_val_loss=0.01799  time=9.06s
# Epoch 7  loss=0.01764  val_loss=0.01766  sm_loss=0.01774  sm_val_loss=0.01774  time=8.93s
# Epoch 11  loss=0.01717  val_loss=0.01747  sm_loss=0.01729  sm_val_loss=0.01754  time=8.90s
# Epoch 13  loss=0.01684  val_loss=0.01738  sm_loss=0.01698  sm_val_loss=0.01746  time=13.15s
# Epoch 14  loss=0.01669  val_loss=0.01733  sm_loss=0.01683  sm_val_loss=0.01740  time=10.28s
# Epoch 15  loss=0.01645  val_loss=0.01723  sm_loss=0.01661  sm_val_loss=0.01730  time=9.42s
# Epoch 16  loss=0.01623  val_loss=0.01710  sm_loss=0.01639  sm_val_loss=0.01718  time=9.31s
# Epoch 17  loss=0.01602  val_loss=0.01703  sm_loss=0.01619  sm_val_loss=0.01710  time=9.36s
# Epoch 18  loss=0.01583  val_loss=0.01700  sm_loss=0.01601  sm_val_loss=0.01708  time=10.54s
# Fold 1 log loss: 0.017097998355518968
# Fold 2
# Epoch 1  loss=0.43164  val_loss=0.02031  sm_loss=0.43164  sm_val_loss=0.02032  time=8.85s
# Epoch 2  loss=0.01922  val_loss=0.01912  sm_loss=0.01925  sm_val_loss=0.01913  time=9.39s
# Epoch 3  loss=0.01838  val_loss=0.01830  sm_loss=0.01841  sm_val_loss=0.01834  time=8.87s
# Epoch 5  loss=0.01791  val_loss=0.01811  sm_loss=0.01799  sm_val_loss=0.01817  time=8.88s
# Epoch 6  loss=0.01778  val_loss=0.01780  sm_loss=0.01787  sm_val_loss=0.01788  time=9.28s
# Epoch 9  loss=0.01740  val_loss=0.01773  sm_loss=0.01752  sm_val_loss=0.01780  time=9.05s
# Epoch 11  loss=0.01720  val_loss=0.01769  sm_loss=0.01732  sm_val_loss=0.01776  time=9.40s
# Epoch 12  loss=0.01700  val_loss=0.01762  sm_loss=0.01713  sm_val_loss=0.01767  time=8.91s
# Epoch 13  loss=0.01682  val_loss=0.01744  sm_loss=0.01696  sm_val_loss=0.01751  time=9.54s
# Epoch 15  loss=0.01644  val_loss=0.01739  sm_loss=0.01660  sm_val_loss=0.01746  time=18.41s
# Epoch 16  loss=0.01622  val_loss=0.01733  sm_loss=0.01638  sm_val_loss=0.01739  time=25.14s
# Epoch 17  loss=0.01599  val_loss=0.01724  sm_loss=0.01616  sm_val_loss=0.01731  time=30.36s
# Epoch 18  loss=0.01582  val_loss=0.01719  sm_loss=0.01600  sm_val_loss=0.01726  time=32.43s
# Epoch 19  loss=0.01565  val_loss=0.01717  sm_loss=0.01583  sm_val_loss=0.01724  time=34.12s
# Epoch 20  loss=0.01558  val_loss=0.01717  sm_loss=0.01576  sm_val_loss=0.01724  time=33.52s
# Fold 2 log loss: 0.017222343361783594
# Fold 3
# Epoch 1  loss=0.43115  val_loss=0.02072  sm_loss=0.43114  sm_val_loss=0.02070  time=9.24s
# Epoch 2  loss=0.01919  val_loss=0.01943  sm_loss=0.01921  sm_val_loss=0.01946  time=8.87s
# Epoch 3  loss=0.01827  val_loss=0.01847  sm_loss=0.01831  sm_val_loss=0.01850  time=9.10s
# Epoch 7  loss=0.01748  val_loss=0.01839  sm_loss=0.01759  sm_val_loss=0.01842  time=9.11s
# Epoch 8  loss=0.01738  val_loss=0.01838  sm_loss=0.01750  sm_val_loss=0.01839  time=9.31s
# Epoch 9  loss=0.01726  val_loss=0.01816  sm_loss=0.01738  sm_val_loss=0.01818  time=8.97s
# Epoch 10  loss=0.01718  val_loss=0.01811  sm_loss=0.01730  sm_val_loss=0.01817  time=9.41s
# Epoch 11  loss=0.01693  val_loss=0.01812  sm_loss=0.01707  sm_val_loss=0.01810  time=9.00s
# Epoch 12  loss=0.01687  val_loss=0.01805  sm_loss=0.01701  sm_val_loss=0.01807  time=9.34s
# Epoch 13  loss=0.01671  val_loss=0.01789  sm_loss=0.01687  sm_val_loss=0.01789  time=9.00s
# Epoch 14  loss=0.01647  val_loss=0.01781  sm_loss=0.01663  sm_val_loss=0.01784  time=9.18s
# Epoch 15  loss=0.01622  val_loss=0.01780  sm_loss=0.01640  sm_val_loss=0.01782  time=9.69s
# Epoch 16  loss=0.01601  val_loss=0.01778  sm_loss=0.01619  sm_val_loss=0.01778  time=9.93s
# Epoch 17  loss=0.01580  val_loss=0.01764  sm_loss=0.01599  sm_val_loss=0.01766  time=10.20s
# Epoch 18  loss=0.01558  val_loss=0.01758  sm_loss=0.01578  sm_val_loss=0.01759  time=10.06s
# Epoch 20  loss=0.01535  val_loss=0.01759  sm_loss=0.01556  sm_val_loss=0.01758  time=10.09s
# Fold 3 log loss: 0.017593305550899798
# Fold 4
# Epoch 1  loss=0.43011  val_loss=0.02081  sm_loss=0.43011  sm_val_loss=0.02079  time=8.86s
# Epoch 2  loss=0.01956  val_loss=0.01900  sm_loss=0.01958  sm_val_loss=0.01902  time=9.84s
# Epoch 3  loss=0.01840  val_loss=0.01837  sm_loss=0.01846  sm_val_loss=0.01839  time=9.05s
# Epoch 4  loss=0.01801  val_loss=0.01813  sm_loss=0.01809  sm_val_loss=0.01815  time=9.55s
# Epoch 5  loss=0.01782  val_loss=0.01811  sm_loss=0.01792  sm_val_loss=0.01809  time=9.56s
# Epoch 6  loss=0.01774  val_loss=0.01786  sm_loss=0.01784  sm_val_loss=0.01788  time=8.89s
# Epoch 7  loss=0.01759  val_loss=0.01786  sm_loss=0.01770  sm_val_loss=0.01785  time=8.97s
# Epoch 8  loss=0.01754  val_loss=0.01778  sm_loss=0.01766  sm_val_loss=0.01780  time=10.53s
# Epoch 10  loss=0.01734  val_loss=0.01776  sm_loss=0.01746  sm_val_loss=0.01778  time=10.22s
# Epoch 11  loss=0.01719  val_loss=0.01745  sm_loss=0.01732  sm_val_loss=0.01749  time=9.07s
# Epoch 12  loss=0.01707  val_loss=0.01731  sm_loss=0.01720  sm_val_loss=0.01734  time=9.31s
# Epoch 14  loss=0.01663  val_loss=0.01711  sm_loss=0.01679  sm_val_loss=0.01715  time=9.37s
# Epoch 15  loss=0.01645  val_loss=0.01709  sm_loss=0.01661  sm_val_loss=0.01714  time=10.80s
# Epoch 16  loss=0.01626  val_loss=0.01697  sm_loss=0.01643  sm_val_loss=0.01701  time=12.16s
# Epoch 17  loss=0.01609  val_loss=0.01696  sm_loss=0.01628  sm_val_loss=0.01700  time=13.44s
# Epoch 18  loss=0.01586  val_loss=0.01694  sm_loss=0.01605  sm_val_loss=0.01698  time=16.31s
# Epoch 19  loss=0.01570  val_loss=0.01693  sm_loss=0.01589  sm_val_loss=0.01696  time=17.35s
# Epoch 20  loss=0.01563  val_loss=0.01692  sm_loss=0.01582  sm_val_loss=0.01696  time=18.29s
# Fold 4 log loss: 0.017027810568025645
# Fold 5
# Epoch 1  loss=0.42914  val_loss=0.02069  sm_loss=0.42912  sm_val_loss=0.02059  time=8.87s
# Epoch 2  loss=0.01934  val_loss=0.01940  sm_loss=0.01937  sm_val_loss=0.01935  time=8.85s
# Epoch 3  loss=0.01826  val_loss=0.01876  sm_loss=0.01832  sm_val_loss=0.01877  time=9.36s
# Epoch 7  loss=0.01764  val_loss=0.01812  sm_loss=0.01774  sm_val_loss=0.01817  time=8.83s
# Epoch 10  loss=0.01732  val_loss=0.01803  sm_loss=0.01743  sm_val_loss=0.01807  time=9.48s
# Epoch 11  loss=0.01718  val_loss=0.01797  sm_loss=0.01731  sm_val_loss=0.01800  time=9.44s
# Epoch 12  loss=0.01699  val_loss=0.01775  sm_loss=0.01712  sm_val_loss=0.01779  time=8.99s
# Epoch 14  loss=0.01670  val_loss=0.01756  sm_loss=0.01686  sm_val_loss=0.01757  time=9.69s
# Epoch 16  loss=0.01632  val_loss=0.01742  sm_loss=0.01648  sm_val_loss=0.01745  time=9.98s
# Epoch 18  loss=0.01590  val_loss=0.01731  sm_loss=0.01608  sm_val_loss=0.01735  time=10.40s
# Fold 5 log loss: 0.017361948725470443
# Fold 6
# Epoch 1  loss=0.42749  val_loss=0.02127  sm_loss=0.42746  sm_val_loss=0.02099  time=8.85s
# Epoch 3  loss=0.02035  val_loss=0.02033  sm_loss=0.02034  sm_val_loss=0.02025  time=9.59s
# Epoch 8  loss=0.01896  val_loss=0.01944  sm_loss=0.01902  sm_val_loss=0.01945  time=8.86s
# Epoch 9  loss=0.01884  val_loss=0.01947  sm_loss=0.01891  sm_val_loss=0.01940  time=9.20s
# Epoch 11  loss=0.01856  val_loss=0.01899  sm_loss=0.01864  sm_val_loss=0.01899  time=9.15s
# Epoch 13  loss=0.01809  val_loss=0.01846  sm_loss=0.01818  sm_val_loss=0.01846  time=8.81s
# Epoch 15  loss=0.01774  val_loss=0.01818  sm_loss=0.01785  sm_val_loss=0.01818  time=8.99s
# Epoch 17  loss=0.01736  val_loss=0.01805  sm_loss=0.01748  sm_val_loss=0.01808  time=8.89s
# Epoch 18  loss=0.01717  val_loss=0.01800  sm_loss=0.01730  sm_val_loss=0.01803  time=9.36s
# Epoch 19  loss=0.01701  val_loss=0.01791  sm_loss=0.01715  sm_val_loss=0.01794  time=8.83s
# Fold 6 log loss: 0.018010271792211676
# Fold 7
# Epoch 1  loss=0.42889  val_loss=0.02144  sm_loss=0.42888  sm_val_loss=0.02135  time=9.35s
# Epoch 2  loss=0.01961  val_loss=0.02040  sm_loss=0.01961  sm_val_loss=0.02038  time=9.61s
# Epoch 3  loss=0.01858  val_loss=0.01849  sm_loss=0.01861  sm_val_loss=0.01851  time=9.25s
# Epoch 6  loss=0.01792  val_loss=0.01789  sm_loss=0.01802  sm_val_loss=0.01795  time=9.72s
# Epoch 11  loss=0.01719  val_loss=0.01785  sm_loss=0.01732  sm_val_loss=0.01789  time=8.97s
# Epoch 12  loss=0.01698  val_loss=0.01768  sm_loss=0.01712  sm_val_loss=0.01770  time=9.87s
# Epoch 13  loss=0.01680  val_loss=0.01748  sm_loss=0.01695  sm_val_loss=0.01749  time=9.80s
# Epoch 15  loss=0.01646  val_loss=0.01728  sm_loss=0.01662  sm_val_loss=0.01730  time=10.36s
# Epoch 16  loss=0.01625  val_loss=0.01726  sm_loss=0.01642  sm_val_loss=0.01728  time=9.82s
# Epoch 17  loss=0.01602  val_loss=0.01720  sm_loss=0.01620  sm_val_loss=0.01722  time=10.28s
# Epoch 20  loss=0.01558  val_loss=0.01720  sm_loss=0.01577  sm_val_loss=0.01721  time=11.43s
# Fold 7 log loss: 0.017312728058795936
# Seed 2
# Fold 1 log loss: 0.017097998355518968
# Fold 2 log loss: 0.017222343361783594
# Fold 3 log loss: 0.017593305550899798
# Fold 4 log loss: 0.017027810568025645
# Fold 5 log loss: 0.017361948725470443
# Fold 6 log loss: 0.018010271792211676
# Fold 7 log loss: 0.017312728058795936
# Std of log loss: 0.0003107249296408358
# Total log loss: 0.017375411008322288
# Fold 1
# Epoch 1  loss=0.42971  val_loss=0.02093  sm_loss=0.42970  sm_val_loss=0.02086  time=9.24s
# Epoch 2  loss=0.01940  val_loss=0.01842  sm_loss=0.01942  sm_val_loss=0.01847  time=9.06s
# Epoch 3  loss=0.01831  val_loss=0.01808  sm_loss=0.01837  sm_val_loss=0.01813  time=9.00s
# Epoch 5  loss=0.01784  val_loss=0.01801  sm_loss=0.01793  sm_val_loss=0.01807  time=9.26s
# Epoch 6  loss=0.01774  val_loss=0.01795  sm_loss=0.01784  sm_val_loss=0.01802  time=8.95s
# Epoch 7  loss=0.01757  val_loss=0.01761  sm_loss=0.01767  sm_val_loss=0.01769  time=9.53s
# Epoch 10  loss=0.01728  val_loss=0.01755  sm_loss=0.01740  sm_val_loss=0.01759  time=8.75s
# Epoch 13  loss=0.01680  val_loss=0.01723  sm_loss=0.01694  sm_val_loss=0.01731  time=9.33s
# Epoch 14  loss=0.01663  val_loss=0.01710  sm_loss=0.01678  sm_val_loss=0.01718  time=9.50s
# Epoch 15  loss=0.01639  val_loss=0.01710  sm_loss=0.01655  sm_val_loss=0.01717  time=9.52s
# Epoch 16  loss=0.01617  val_loss=0.01706  sm_loss=0.01634  sm_val_loss=0.01715  time=9.79s
# Epoch 17  loss=0.01594  val_loss=0.01697  sm_loss=0.01612  sm_val_loss=0.01706  time=9.81s
# Epoch 18  loss=0.01578  val_loss=0.01696  sm_loss=0.01596  sm_val_loss=0.01705  time=11.27s
# Epoch 19  loss=0.01561  val_loss=0.01692  sm_loss=0.01580  sm_val_loss=0.01701  time=11.01s
# Epoch 20  loss=0.01554  val_loss=0.01692  sm_loss=0.01573  sm_val_loss=0.01701  time=10.47s
# Fold 1 log loss: 0.01702546694686211
# Fold 2
# Epoch 1  loss=0.42943  val_loss=0.02053  sm_loss=0.42943  sm_val_loss=0.02053  time=8.88s
# Epoch 2  loss=0.01930  val_loss=0.01850  sm_loss=0.01933  sm_val_loss=0.01853  time=9.16s
# Epoch 3  loss=0.01826  val_loss=0.01829  sm_loss=0.01833  sm_val_loss=0.01832  time=9.02s
# Epoch 4  loss=0.01804  val_loss=0.01806  sm_loss=0.01811  sm_val_loss=0.01809  time=9.03s
# Epoch 7  loss=0.01755  val_loss=0.01782  sm_loss=0.01765  sm_val_loss=0.01788  time=9.59s
# Epoch 8  loss=0.01748  val_loss=0.01781  sm_loss=0.01758  sm_val_loss=0.01786  time=9.44s
# Epoch 10  loss=0.01725  val_loss=0.01777  sm_loss=0.01737  sm_val_loss=0.01784  time=8.96s
# Epoch 11  loss=0.01712  val_loss=0.01768  sm_loss=0.01725  sm_val_loss=0.01774  time=9.48s
# Epoch 12  loss=0.01690  val_loss=0.01758  sm_loss=0.01703  sm_val_loss=0.01765  time=9.73s
# Epoch 13  loss=0.01674  val_loss=0.01755  sm_loss=0.01688  sm_val_loss=0.01762  time=9.06s
# Epoch 14  loss=0.01656  val_loss=0.01738  sm_loss=0.01671  sm_val_loss=0.01746  time=9.49s
# Epoch 15  loss=0.01632  val_loss=0.01730  sm_loss=0.01648  sm_val_loss=0.01736  time=10.32s
# Epoch 16  loss=0.01606  val_loss=0.01722  sm_loss=0.01623  sm_val_loss=0.01729  time=10.95s
# Epoch 17  loss=0.01587  val_loss=0.01719  sm_loss=0.01605  sm_val_loss=0.01724  time=11.71s
# Epoch 18  loss=0.01566  val_loss=0.01718  sm_loss=0.01585  sm_val_loss=0.01724  time=13.79s
# Epoch 20  loss=0.01542  val_loss=0.01715  sm_loss=0.01562  sm_val_loss=0.01720  time=14.87s
# Fold 2 log loss: 0.017189900771991107
# Fold 3
# Epoch 1  loss=0.42973  val_loss=0.02164  sm_loss=0.42973  sm_val_loss=0.02161  time=8.96s
# Epoch 2  loss=0.01937  val_loss=0.01908  sm_loss=0.01940  sm_val_loss=0.01908  time=9.45s
# Epoch 3  loss=0.01823  val_loss=0.01853  sm_loss=0.01829  sm_val_loss=0.01856  time=9.04s
# Epoch 5  loss=0.01773  val_loss=0.01826  sm_loss=0.01782  sm_val_loss=0.01830  time=9.04s
# Epoch 9  loss=0.01728  val_loss=0.01830  sm_loss=0.01740  sm_val_loss=0.01829  time=9.17s
# Epoch 10  loss=0.01714  val_loss=0.01809  sm_loss=0.01726  sm_val_loss=0.01808  time=9.05s
# Epoch 13  loss=0.01664  val_loss=0.01796  sm_loss=0.01679  sm_val_loss=0.01797  time=8.92s
# Epoch 14  loss=0.01644  val_loss=0.01786  sm_loss=0.01660  sm_val_loss=0.01790  time=9.09s
# Epoch 15  loss=0.01623  val_loss=0.01768  sm_loss=0.01639  sm_val_loss=0.01771  time=10.01s
# Epoch 16  loss=0.01597  val_loss=0.01757  sm_loss=0.01614  sm_val_loss=0.01760  time=9.25s
# Epoch 18  loss=0.01556  val_loss=0.01757  sm_loss=0.01575  sm_val_loss=0.01759  time=10.88s
# Epoch 19  loss=0.01544  val_loss=0.01753  sm_loss=0.01563  sm_val_loss=0.01756  time=9.87s
# Epoch 20  loss=0.01536  val_loss=0.01753  sm_loss=0.01556  sm_val_loss=0.01756  time=9.40s
# Fold 3 log loss: 0.017567633181857827
# Fold 4
# Epoch 1  loss=0.42889  val_loss=0.02029  sm_loss=0.42889  sm_val_loss=0.02033  time=9.95s
# Epoch 2  loss=0.01933  val_loss=0.01918  sm_loss=0.01934  sm_val_loss=0.01919  time=9.00s
# Epoch 3  loss=0.01835  val_loss=0.01820  sm_loss=0.01841  sm_val_loss=0.01821  time=9.07s
# Epoch 4  loss=0.01793  val_loss=0.01806  sm_loss=0.01802  sm_val_loss=0.01809  time=8.92s
# Epoch 7  loss=0.01763  val_loss=0.01790  sm_loss=0.01773  sm_val_loss=0.01790  time=9.47s
# Epoch 8  loss=0.01757  val_loss=0.01779  sm_loss=0.01768  sm_val_loss=0.01780  time=9.65s
# Epoch 11  loss=0.01719  val_loss=0.01763  sm_loss=0.01732  sm_val_loss=0.01766  time=8.86s
# Epoch 12  loss=0.01704  val_loss=0.01749  sm_loss=0.01718  sm_val_loss=0.01754  time=9.29s
# Epoch 13  loss=0.01689  val_loss=0.01727  sm_loss=0.01703  sm_val_loss=0.01732  time=9.45s
# Epoch 14  loss=0.01665  val_loss=0.01722  sm_loss=0.01680  sm_val_loss=0.01725  time=10.45s
# Epoch 15  loss=0.01648  val_loss=0.01710  sm_loss=0.01664  sm_val_loss=0.01715  time=11.48s
# Epoch 17  loss=0.01606  val_loss=0.01697  sm_loss=0.01624  sm_val_loss=0.01701  time=14.93s
# Epoch 18  loss=0.01586  val_loss=0.01697  sm_loss=0.01605  sm_val_loss=0.01700  time=18.40s
# Epoch 19  loss=0.01569  val_loss=0.01697  sm_loss=0.01588  sm_val_loss=0.01699  time=18.07s
# Epoch 20  loss=0.01564  val_loss=0.01695  sm_loss=0.01583  sm_val_loss=0.01699  time=18.64s
# Fold 4 log loss: 0.017046512504051474
# Fold 5
# Epoch 1  loss=0.42776  val_loss=0.02068  sm_loss=0.42775  sm_val_loss=0.02065  time=8.92s
# Epoch 2  loss=0.01929  val_loss=0.02014  sm_loss=0.01931  sm_val_loss=0.02015  time=9.88s
# Epoch 4  loss=0.01817  val_loss=0.01899  sm_loss=0.01823  sm_val_loss=0.01898  time=8.91s
# Epoch 5  loss=0.01797  val_loss=0.01871  sm_loss=0.01807  sm_val_loss=0.01869  time=9.48s
# Epoch 7  loss=0.01762  val_loss=0.01808  sm_loss=0.01773  sm_val_loss=0.01811  time=9.55s
# Epoch 10  loss=0.01726  val_loss=0.01805  sm_loss=0.01739  sm_val_loss=0.01808  time=8.82s
# Epoch 11  loss=0.01719  val_loss=0.01777  sm_loss=0.01732  sm_val_loss=0.01777  time=9.09s
# Epoch 14  loss=0.01662  val_loss=0.01762  sm_loss=0.01677  sm_val_loss=0.01761  time=9.09s
# Epoch 15  loss=0.01643  val_loss=0.01759  sm_loss=0.01660  sm_val_loss=0.01761  time=9.89s
# Epoch 16  loss=0.01617  val_loss=0.01748  sm_loss=0.01634  sm_val_loss=0.01750  time=10.02s
# Epoch 17  loss=0.01597  val_loss=0.01739  sm_loss=0.01615  sm_val_loss=0.01741  time=9.81s
# Epoch 18  loss=0.01580  val_loss=0.01736  sm_loss=0.01598  sm_val_loss=0.01737  time=9.92s
# Epoch 19  loss=0.01565  val_loss=0.01735  sm_loss=0.01584  sm_val_loss=0.01737  time=10.32s
# Epoch 20  loss=0.01559  val_loss=0.01732  sm_loss=0.01578  sm_val_loss=0.01733  time=9.94s
# Fold 5 log loss: 0.01734583244533875
# Fold 6
# Epoch 1  loss=0.42944  val_loss=0.02132  sm_loss=0.42943  sm_val_loss=0.02126  time=9.65s
# Epoch 7  loss=0.01959  val_loss=0.02057  sm_loss=0.01958  sm_val_loss=0.02035  time=9.56s
# Epoch 8  loss=0.01914  val_loss=0.02006  sm_loss=0.01917  sm_val_loss=0.02003  time=9.33s
# Epoch 9  loss=0.01896  val_loss=0.01969  sm_loss=0.01900  sm_val_loss=0.01966  time=10.15s
# Epoch 10  loss=0.01876  val_loss=0.01945  sm_loss=0.01883  sm_val_loss=0.01943  time=9.13s
# Epoch 11  loss=0.01850  val_loss=0.01908  sm_loss=0.01857  sm_val_loss=0.01906  time=9.07s
# Epoch 12  loss=0.01832  val_loss=0.01906  sm_loss=0.01841  sm_val_loss=0.01902  time=9.21s
# Epoch 13  loss=0.01823  val_loss=0.01856  sm_loss=0.01833  sm_val_loss=0.01854  time=9.49s
# Epoch 14  loss=0.01783  val_loss=0.01833  sm_loss=0.01794  sm_val_loss=0.01832  time=9.53s
# Epoch 15  loss=0.01751  val_loss=0.01827  sm_loss=0.01763  sm_val_loss=0.01826  time=9.02s
# Epoch 16  loss=0.01762  val_loss=0.01822  sm_loss=0.01774  sm_val_loss=0.01822  time=9.57s
# Epoch 17  loss=0.01710  val_loss=0.01799  sm_loss=0.01723  sm_val_loss=0.01801  time=9.00s
# Epoch 18  loss=0.01704  val_loss=0.01787  sm_loss=0.01716  sm_val_loss=0.01790  time=8.90s
# Epoch 19  loss=0.01700  val_loss=0.01786  sm_loss=0.01714  sm_val_loss=0.01788  time=9.30s
# Fold 6 log loss: 0.017940174693426597
# Fold 7
# Epoch 1  loss=0.42748  val_loss=0.02077  sm_loss=0.42747  sm_val_loss=0.02075  time=9.95s
# Epoch 2  loss=0.01933  val_loss=0.01952  sm_loss=0.01936  sm_val_loss=0.01941  time=10.87s
# Epoch 3  loss=0.01837  val_loss=0.01927  sm_loss=0.01843  sm_val_loss=0.01929  time=10.47s
# Epoch 5  loss=0.01797  val_loss=0.01919  sm_loss=0.01805  sm_val_loss=0.01919  time=9.06s
# Epoch 6  loss=0.01785  val_loss=0.01801  sm_loss=0.01795  sm_val_loss=0.01808  time=9.96s
# Epoch 7  loss=0.01766  val_loss=0.01787  sm_loss=0.01777  sm_val_loss=0.01795  time=9.27s
# Epoch 10  loss=0.01732  val_loss=0.01769  sm_loss=0.01744  sm_val_loss=0.01775  time=9.33s
# Epoch 12  loss=0.01695  val_loss=0.01760  sm_loss=0.01709  sm_val_loss=0.01764  time=9.47s
# Epoch 13  loss=0.01678  val_loss=0.01752  sm_loss=0.01693  sm_val_loss=0.01755  time=9.83s
# Epoch 14  loss=0.01654  val_loss=0.01736  sm_loss=0.01669  sm_val_loss=0.01739  time=9.10s
# Epoch 15  loss=0.01632  val_loss=0.01732  sm_loss=0.01648  sm_val_loss=0.01735  time=9.41s
# Epoch 16  loss=0.01609  val_loss=0.01724  sm_loss=0.01626  sm_val_loss=0.01727  time=9.63s
# Epoch 17  loss=0.01587  val_loss=0.01716  sm_loss=0.01605  sm_val_loss=0.01718  time=10.22s
# Epoch 20  loss=0.01545  val_loss=0.01714  sm_loss=0.01565  sm_val_loss=0.01717  time=10.84s
# Fold 7 log loss: 0.017280207596382945
# Seed 3
# Fold 1 log loss: 0.01702546694686211
# Fold 2 log loss: 0.017189900771991107
# Fold 3 log loss: 0.017567633181857827
# Fold 4 log loss: 0.017046512504051474
# Fold 5 log loss: 0.01734583244533875
# Fold 6 log loss: 0.017940174693426597
# Fold 7 log loss: 0.017280207596382945
# Std of log loss: 0.0002983756184760464
# Total log loss: 0.017342336595328474
# Fold 1
# Epoch 1  loss=0.43029  val_loss=0.02112  sm_loss=0.43028  sm_val_loss=0.02104  time=9.28s
# Epoch 2  loss=0.01954  val_loss=0.01842  sm_loss=0.01953  sm_val_loss=0.01846  time=9.01s
# Epoch 3  loss=0.01828  val_loss=0.01818  sm_loss=0.01834  sm_val_loss=0.01824  time=9.30s
# Epoch 5  loss=0.01791  val_loss=0.01805  sm_loss=0.01800  sm_val_loss=0.01811  time=9.47s
# Epoch 7  loss=0.01766  val_loss=0.01777  sm_loss=0.01776  sm_val_loss=0.01784  time=9.35s
# Epoch 8  loss=0.01761  val_loss=0.01775  sm_loss=0.01772  sm_val_loss=0.01783  time=9.16s
# Epoch 9  loss=0.01745  val_loss=0.01756  sm_loss=0.01756  sm_val_loss=0.01765  time=9.20s
# Epoch 13  loss=0.01682  val_loss=0.01742  sm_loss=0.01696  sm_val_loss=0.01749  time=9.26s
# Epoch 14  loss=0.01663  val_loss=0.01738  sm_loss=0.01678  sm_val_loss=0.01746  time=10.40s
# Epoch 15  loss=0.01642  val_loss=0.01717  sm_loss=0.01658  sm_val_loss=0.01724  time=11.13s
# Epoch 16  loss=0.01621  val_loss=0.01713  sm_loss=0.01637  sm_val_loss=0.01721  time=12.20s
# Epoch 17  loss=0.01599  val_loss=0.01708  sm_loss=0.01616  sm_val_loss=0.01716  time=12.11s
# Epoch 18  loss=0.01582  val_loss=0.01707  sm_loss=0.01600  sm_val_loss=0.01715  time=11.78s
# Epoch 19  loss=0.01566  val_loss=0.01704  sm_loss=0.01585  sm_val_loss=0.01711  time=12.40s
# Fold 1 log loss: 0.017130901308192573
# Fold 2
# Epoch 1  loss=0.42747  val_loss=0.02044  sm_loss=0.42747  sm_val_loss=0.02043  time=8.96s
# Epoch 2  loss=0.01942  val_loss=0.01846  sm_loss=0.01944  sm_val_loss=0.01850  time=9.96s
# Epoch 3  loss=0.01834  val_loss=0.01839  sm_loss=0.01839  sm_val_loss=0.01841  time=9.78s
# Epoch 4  loss=0.01803  val_loss=0.01832  sm_loss=0.01811  sm_val_loss=0.01835  time=12.61s
# Epoch 5  loss=0.01784  val_loss=0.01813  sm_loss=0.01792  sm_val_loss=0.01820  time=9.41s
# Epoch 6  loss=0.01767  val_loss=0.01794  sm_loss=0.01777  sm_val_loss=0.01800  time=9.07s
# Epoch 9  loss=0.01733  val_loss=0.01770  sm_loss=0.01744  sm_val_loss=0.01776  time=9.25s
# Epoch 10  loss=0.01725  val_loss=0.01753  sm_loss=0.01737  sm_val_loss=0.01759  time=9.13s
# Epoch 13  loss=0.01682  val_loss=0.01747  sm_loss=0.01695  sm_val_loss=0.01752  time=9.25s
# Epoch 14  loss=0.01655  val_loss=0.01746  sm_loss=0.01671  sm_val_loss=0.01751  time=10.21s
# Epoch 15  loss=0.01633  val_loss=0.01733  sm_loss=0.01649  sm_val_loss=0.01738  time=10.15s
# Epoch 17  loss=0.01591  val_loss=0.01724  sm_loss=0.01609  sm_val_loss=0.01729  time=12.18s
# Epoch 18  loss=0.01571  val_loss=0.01724  sm_loss=0.01590  sm_val_loss=0.01726  time=13.69s
# Epoch 19  loss=0.01557  val_loss=0.01722  sm_loss=0.01576  sm_val_loss=0.01725  time=14.51s
# Fold 2 log loss: 0.01723393738106665
# Fold 3
# Epoch 1  loss=0.42955  val_loss=0.02115  sm_loss=0.42954  sm_val_loss=0.02110  time=9.22s
# Epoch 2  loss=0.01942  val_loss=0.01894  sm_loss=0.01941  sm_val_loss=0.01895  time=9.05s
# Epoch 4  loss=0.01782  val_loss=0.01879  sm_loss=0.01790  sm_val_loss=0.01881  time=10.24s
# Epoch 5  loss=0.01769  val_loss=0.01842  sm_loss=0.01778  sm_val_loss=0.01846  time=10.58s
# Epoch 6  loss=0.01763  val_loss=0.01845  sm_loss=0.01773  sm_val_loss=0.01842  time=10.03s
# Epoch 8  loss=0.01745  val_loss=0.01838  sm_loss=0.01756  sm_val_loss=0.01840  time=9.00s
# Epoch 9  loss=0.01735  val_loss=0.01822  sm_loss=0.01746  sm_val_loss=0.01824  time=8.93s
# Epoch 10  loss=0.01719  val_loss=0.01817  sm_loss=0.01731  sm_val_loss=0.01818  time=8.96s
# Epoch 11  loss=0.01705  val_loss=0.01814  sm_loss=0.01718  sm_val_loss=0.01813  time=10.04s
# Epoch 12  loss=0.01694  val_loss=0.01801  sm_loss=0.01708  sm_val_loss=0.01805  time=9.15s
# Epoch 13  loss=0.01669  val_loss=0.01801  sm_loss=0.01683  sm_val_loss=0.01802  time=9.25s
# Epoch 14  loss=0.01655  val_loss=0.01772  sm_loss=0.01670  sm_val_loss=0.01778  time=9.46s
# Epoch 15  loss=0.01634  val_loss=0.01772  sm_loss=0.01650  sm_val_loss=0.01774  time=9.62s
# Epoch 16  loss=0.01607  val_loss=0.01761  sm_loss=0.01625  sm_val_loss=0.01766  time=9.54s
# Epoch 17  loss=0.01587  val_loss=0.01756  sm_loss=0.01605  sm_val_loss=0.01761  time=10.61s
# Epoch 18  loss=0.01567  val_loss=0.01749  sm_loss=0.01586  sm_val_loss=0.01755  time=10.63s
# Epoch 19  loss=0.01554  val_loss=0.01750  sm_loss=0.01574  sm_val_loss=0.01754  time=10.29s
# Fold 3 log loss: 0.017552466558470824
# Fold 4
# Epoch 1  loss=0.42967  val_loss=0.02050  sm_loss=0.42967  sm_val_loss=0.02052  time=10.56s
# Epoch 2  loss=0.01953  val_loss=0.01933  sm_loss=0.01952  sm_val_loss=0.01931  time=9.15s
# Epoch 3  loss=0.01843  val_loss=0.01814  sm_loss=0.01846  sm_val_loss=0.01817  time=9.76s
# Epoch 4  loss=0.01807  val_loss=0.01804  sm_loss=0.01815  sm_val_loss=0.01807  time=9.50s
# Epoch 6  loss=0.01776  val_loss=0.01801  sm_loss=0.01785  sm_val_loss=0.01804  time=9.21s
# Epoch 7  loss=0.01764  val_loss=0.01776  sm_loss=0.01774  sm_val_loss=0.01781  time=9.31s
# Epoch 8  loss=0.01752  val_loss=0.01770  sm_loss=0.01763  sm_val_loss=0.01774  time=9.46s
# Epoch 11  loss=0.01716  val_loss=0.01760  sm_loss=0.01729  sm_val_loss=0.01763  time=9.49s
# Epoch 12  loss=0.01702  val_loss=0.01755  sm_loss=0.01716  sm_val_loss=0.01757  time=9.23s
# Epoch 13  loss=0.01683  val_loss=0.01733  sm_loss=0.01698  sm_val_loss=0.01735  time=9.26s
# Epoch 14  loss=0.01666  val_loss=0.01721  sm_loss=0.01681  sm_val_loss=0.01726  time=9.59s
# Epoch 15  loss=0.01643  val_loss=0.01718  sm_loss=0.01660  sm_val_loss=0.01722  time=11.04s
# Epoch 16  loss=0.01626  val_loss=0.01706  sm_loss=0.01643  sm_val_loss=0.01709  time=11.23s
# Epoch 17  loss=0.01605  val_loss=0.01706  sm_loss=0.01623  sm_val_loss=0.01708  time=12.20s
# Epoch 18  loss=0.01586  val_loss=0.01693  sm_loss=0.01605  sm_val_loss=0.01695  time=13.52s
# Epoch 19  loss=0.01574  val_loss=0.01693  sm_loss=0.01593  sm_val_loss=0.01694  time=12.66s
# Epoch 20  loss=0.01562  val_loss=0.01692  sm_loss=0.01582  sm_val_loss=0.01693  time=13.74s
# Fold 4 log loss: 0.017002004822013715
# Fold 5
# Epoch 1  loss=0.42839  val_loss=0.02108  sm_loss=0.42838  sm_val_loss=0.02092  time=9.09s
# Epoch 3  loss=0.01841  val_loss=0.01880  sm_loss=0.01846  sm_val_loss=0.01878  time=12.58s
# Epoch 4  loss=0.01800  val_loss=0.01825  sm_loss=0.01807  sm_val_loss=0.01828  time=10.57s
# Epoch 8  loss=0.01757  val_loss=0.01802  sm_loss=0.01768  sm_val_loss=0.01802  time=8.89s
# Epoch 10  loss=0.01729  val_loss=0.01789  sm_loss=0.01741  sm_val_loss=0.01794  time=9.31s
# Epoch 12  loss=0.01705  val_loss=0.01788  sm_loss=0.01718  sm_val_loss=0.01788  time=9.64s
# Epoch 13  loss=0.01685  val_loss=0.01773  sm_loss=0.01699  sm_val_loss=0.01774  time=9.98s
# Epoch 14  loss=0.01674  val_loss=0.01754  sm_loss=0.01689  sm_val_loss=0.01758  time=9.38s
# Epoch 16  loss=0.01629  val_loss=0.01753  sm_loss=0.01645  sm_val_loss=0.01755  time=9.97s
# Epoch 17  loss=0.01610  val_loss=0.01741  sm_loss=0.01627  sm_val_loss=0.01744  time=10.82s
# Epoch 18  loss=0.01593  val_loss=0.01735  sm_loss=0.01611  sm_val_loss=0.01737  time=11.71s
# Epoch 20  loss=0.01568  val_loss=0.01732  sm_loss=0.01586  sm_val_loss=0.01734  time=11.74s
# Fold 5 log loss: 0.017343398246595088
# Fold 6
# Epoch 1  loss=0.42842  val_loss=0.02146  sm_loss=0.42842  sm_val_loss=0.02131  time=9.07s
# Epoch 2  loss=0.01944  val_loss=0.01958  sm_loss=0.01946  sm_val_loss=0.01959  time=8.98s
# Epoch 13  loss=0.01820  val_loss=0.01917  sm_loss=0.01831  sm_val_loss=0.01903  time=9.47s
# Epoch 14  loss=0.01784  val_loss=0.01835  sm_loss=0.01796  sm_val_loss=0.01836  time=9.28s
# Epoch 18  loss=0.01699  val_loss=0.01773  sm_loss=0.01714  sm_val_loss=0.01776  time=8.94s
# Epoch 19  loss=0.01687  val_loss=0.01769  sm_loss=0.01702  sm_val_loss=0.01775  time=9.16s
# Epoch 20  loss=0.01706  val_loss=0.01765  sm_loss=0.01721  sm_val_loss=0.01771  time=9.45s
# Fold 6 log loss: 0.017772604605764217
# Fold 7
# Epoch 1  loss=0.42832  val_loss=0.02062  sm_loss=0.42832  sm_val_loss=0.02063  time=9.04s
# Epoch 2  loss=0.01945  val_loss=0.01909  sm_loss=0.01945  sm_val_loss=0.01911  time=9.65s
# Epoch 4  loss=0.01811  val_loss=0.01877  sm_loss=0.01816  sm_val_loss=0.01883  time=9.08s
# Epoch 5  loss=0.01778  val_loss=0.01842  sm_loss=0.01788  sm_val_loss=0.01846  time=9.05s
# Epoch 7  loss=0.01759  val_loss=0.01818  sm_loss=0.01769  sm_val_loss=0.01823  time=9.29s
# Epoch 9  loss=0.01741  val_loss=0.01794  sm_loss=0.01752  sm_val_loss=0.01796  time=9.80s
# Epoch 11  loss=0.01704  val_loss=0.01781  sm_loss=0.01718  sm_val_loss=0.01783  time=9.07s
# Epoch 12  loss=0.01695  val_loss=0.01771  sm_loss=0.01709  sm_val_loss=0.01773  time=9.12s
# Epoch 13  loss=0.01679  val_loss=0.01744  sm_loss=0.01694  sm_val_loss=0.01747  time=9.39s
# Epoch 14  loss=0.01659  val_loss=0.01738  sm_loss=0.01675  sm_val_loss=0.01743  time=9.98s
# Epoch 15  loss=0.01649  val_loss=0.01733  sm_loss=0.01665  sm_val_loss=0.01737  time=11.04s
# Epoch 16  loss=0.01613  val_loss=0.01719  sm_loss=0.01630  sm_val_loss=0.01723  time=11.61s
# Epoch 17  loss=0.01585  val_loss=0.01716  sm_loss=0.01603  sm_val_loss=0.01722  time=12.99s
# Epoch 18  loss=0.01567  val_loss=0.01717  sm_loss=0.01586  sm_val_loss=0.01721  time=14.08s
# Epoch 19  loss=0.01556  val_loss=0.01715  sm_loss=0.01575  sm_val_loss=0.01719  time=14.83s
# Epoch 20  loss=0.01543  val_loss=0.01713  sm_loss=0.01562  sm_val_loss=0.01717  time=15.16s
# Fold 7 log loss: 0.01726892468157531
# Seed 4
# Fold 1 log loss: 0.017130901308192573
# Fold 2 log loss: 0.01723393738106665
# Fold 3 log loss: 0.017552466558470824
# Fold 4 log loss: 0.017002004822013715
# Fold 5 log loss: 0.017343398246595088
# Fold 6 log loss: 0.017772604605764217
# Fold 7 log loss: 0.01726892468157531
# Std of log loss: 0.0002407560482048298
# Total log loss: 0.017329538921096017
# Total log loss in targets: 0.01720584047432963

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6447155909152301

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.01585763780677705

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

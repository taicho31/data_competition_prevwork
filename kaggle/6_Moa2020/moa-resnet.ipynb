# %% [markdown]
# - incorporate f selection method
# - change location of dropping features
# - batch size 256

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
json_file_path = '../input/moapredictors/main_predictors.json'

with open(json_file_path, 'r') as j:
    predictors = json.loads(j.read())
    predictors = predictors['start_predictors']

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 14

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[(vc==6)|(vc==12)|(vc==18)].index.sort_values()
vc2 = vc.loc[(vc!=6)&(vc!=12)&(vc!=18)].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[0, 6, 5, ..., 1, 1, 6]], dtype=int8)

# %% [markdown]
# # Feature enginnering

# %%
importance = pd.read_csv('../input/moa-feat-importance-rapids/output_source.csv')
importance = importance.set_index("Feature")

imp_scaled = importance.copy(deep=True)
for c in imp_scaled.columns:
    imp_scaled[c] = (1 - preprocessing.MinMaxScaler().fit_transform(imp_scaled[[c]])).round(14)

print(imp_scaled.min().min(), imp_scaled.max().max(), imp_scaled.std().mean())

imp_scaled["MeanImp"] = imp_scaled[target_feats].mean(axis=1)
imp_scaled["MaxImp"]  = imp_scaled[target_feats].max(axis=1)

thresh_mean, thresh_max = 0.35, 0.975
#fs_both = imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) & (imp_scaled.MaxImp >= thresh_max), Targets]
fs_any = list(imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) | (imp_scaled.MaxImp >= thresh_max), target_feats].index)
len(fs_any)
# Out:
# -1e-14 1.0 0.1447830667695532
# 187

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=500, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
#X = train.iloc[:,4:].copy().values
#select = VarianceThreshold(threshold=0.6)
#X_new = select.fit_transform(X)
#drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
#len(drop_feats)

drop_feats = [i for i in c_feats+g_feats if i not in fs_any]
train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

predictors = list(set(predictors) & set(fs_any))

g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

# %%
print(train.shape, test.shape)
# Out:
# (21948, 266) (3624, 266)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy()
fn_test = test.copy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.Linear(num_columns, 512)
        self.relu1 = nn.ELU()
        self.dense12 = nn.Linear(512, 256)
        
        self.batch_norm2 = nn.BatchNorm1d(256+len(predictors))
        self.dropout2 = nn.Dropout(0.1)
        self.dense2 = nn.Linear(256+len(predictors), 512)
        self.relu2 = nn.ReLU()
        self.batch_norm22 = nn.BatchNorm1d(512)
        self.dense22 = nn.Linear(512, 512)
        self.relu22 = nn.ELU()
        self.batch_norm23 = nn.BatchNorm1d(512)
        self.dense23 = nn.Linear(512, 256)
        self.relu23 = nn.ReLU()
        self.batch_norm24 = nn.BatchNorm1d(256)
        self.dense24 = nn.Linear(256, 256)
        self.relu24 = nn.ELU()
                
        self.batch_norm3 = nn.BatchNorm1d(256)
        self.dense3 = nn.Linear(256, 256)
        self.relu3 = nn.SELU()
        self.batch_norm32 = nn.BatchNorm1d(256)
        self.dense32 = nn.Linear(256, last_num)

    def forward(self, x1, x2):
        x1 = self.batch_norm1(x1)
        x1 = self.dropout1(x1)
        x1 = self.relu1(self.dense1(x1))
        x1 = self.dense12(x1)
        
        x3 = torch.cat([x1,x2],axis=1)
                
        x3 = self.batch_norm2(x3)
        x3 = self.dropout2(x3)
        x3 = self.relu2(self.dense2(x3))
        x3 = self.batch_norm22(x3)
        x3 = self.relu22(self.dense22(x3))
        x3 = self.batch_norm23(x3)
        x3 = self.relu23(self.dense23(x3))
        x3 = self.batch_norm24(x3)
        x3 = self.relu24(self.dense24(x3))
        
        x4 = (x1 + x3) / 2
        
        x4 = self.batch_norm3(x4)
        x4 = self.relu3(self.dense3(x4))
        x4 = self.batch_norm32(x4)
        x4 = self.dense32(x4)
        
        return x4
# Out:
# cuda

# %%
batch_size = 256
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    train_epochs = 20
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te.values, dtype=torch.float32)
    X_test2 = torch.tensor(te.iloc[:][predictors].values, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test, X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr["fold"] == fold
        train_index = tr["fold"] != fold
        print("Fold "+str(fold+1))
        X_train1 = torch.tensor(tr[train_index].values, dtype=torch.float32)
        X_valid1 = torch.tensor(tr[valid_index].values, dtype=torch.float32)
        X_train2 = torch.tensor(tr[train_index][predictors].values, dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index][predictors].values, dtype=torch.float32)
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        X_train1 = X_train1[:,:-1]
        X_valid1 = X_valid1[:,:-1]
        
        train = torch.utils.data.TensorDataset(X_train1, X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid1, X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
            
        optimizer = optim.Adam(clf.parameters(), lr = 0.01, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))                   
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, x_batch2, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        pred_model = MoaModel(init_num, len(target_feats))
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
        for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
            y_pred = pred_model(x_batch, x_batch2).detach()
            oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        

        # test predcition --------------
        test_preds = np.zeros([test_len, target.shape[1]])
        for i, (x_batch,x_batch2,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch,x_batch2).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
    
    print("Seed {}".format(sample_seed))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4] 
    
for seed_ in seeds:
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.55921  val_loss=0.02938  sm_loss=0.55921  sm_val_loss=0.02937  time=1.70s
# Epoch 2  loss=0.02064  val_loss=0.01845  sm_loss=0.02061  sm_val_loss=0.01851  time=0.89s
# Epoch 3  loss=0.01827  val_loss=0.01820  sm_loss=0.01836  sm_val_loss=0.01826  time=0.90s
# Epoch 4  loss=0.01782  val_loss=0.01784  sm_loss=0.01791  sm_val_loss=0.01789  time=0.93s
# Epoch 6  loss=0.01750  val_loss=0.01777  sm_loss=0.01759  sm_val_loss=0.01783  time=0.85s
# Epoch 8  loss=0.01718  val_loss=0.01757  sm_loss=0.01730  sm_val_loss=0.01759  time=0.99s
# Epoch 9  loss=0.01704  val_loss=0.01724  sm_loss=0.01717  sm_val_loss=0.01732  time=0.99s
# Epoch 10  loss=0.01690  val_loss=0.01724  sm_loss=0.01704  sm_val_loss=0.01730  time=1.09s
# Epoch 13  loss=0.01651  val_loss=0.01713  sm_loss=0.01666  sm_val_loss=0.01722  time=0.85s
# Epoch 14  loss=0.01632  val_loss=0.01692  sm_loss=0.01649  sm_val_loss=0.01701  time=0.91s
# Fold 1 log loss: 0.017091069452598046
# Fold 2
# Epoch 1  loss=0.56178  val_loss=0.03704  sm_loss=0.56178  sm_val_loss=0.03703  time=1.11s
# Epoch 2  loss=0.02155  val_loss=0.02028  sm_loss=0.02151  sm_val_loss=0.02030  time=1.05s
# Epoch 3  loss=0.01905  val_loss=0.01963  sm_loss=0.01911  sm_val_loss=0.01966  time=1.16s
# Epoch 4  loss=0.01816  val_loss=0.01835  sm_loss=0.01824  sm_val_loss=0.01839  time=0.93s
# Epoch 5  loss=0.01777  val_loss=0.01801  sm_loss=0.01785  sm_val_loss=0.01808  time=1.04s
# Epoch 7  loss=0.01733  val_loss=0.01771  sm_loss=0.01744  sm_val_loss=0.01777  time=1.04s
# Epoch 9  loss=0.01707  val_loss=0.01758  sm_loss=0.01720  sm_val_loss=0.01766  time=0.88s
# Epoch 10  loss=0.01695  val_loss=0.01743  sm_loss=0.01708  sm_val_loss=0.01750  time=0.87s
# Epoch 12  loss=0.01664  val_loss=0.01735  sm_loss=0.01679  sm_val_loss=0.01743  time=0.87s
# Epoch 14  loss=0.01628  val_loss=0.01735  sm_loss=0.01645  sm_val_loss=0.01742  time=1.06s
# Epoch 15  loss=0.01616  val_loss=0.01721  sm_loss=0.01633  sm_val_loss=0.01729  time=1.01s
# Epoch 17  loss=0.01577  val_loss=0.01722  sm_loss=0.01596  sm_val_loss=0.01728  time=0.85s
# Epoch 18  loss=0.01565  val_loss=0.01714  sm_loss=0.01584  sm_val_loss=0.01721  time=0.85s
# Epoch 19  loss=0.01554  val_loss=0.01714  sm_loss=0.01574  sm_val_loss=0.01720  time=1.05s
# Fold 2 log loss: 0.01712988751788483
# Fold 3
# Epoch 1  loss=0.55828  val_loss=0.02985  sm_loss=0.55828  sm_val_loss=0.02984  time=1.08s
# Epoch 2  loss=0.02063  val_loss=0.01884  sm_loss=0.02060  sm_val_loss=0.01890  time=1.07s
# Epoch 4  loss=0.01778  val_loss=0.01842  sm_loss=0.01785  sm_val_loss=0.01844  time=0.85s
# Epoch 5  loss=0.01752  val_loss=0.01818  sm_loss=0.01763  sm_val_loss=0.01822  time=0.88s
# Epoch 8  loss=0.01708  val_loss=0.01802  sm_loss=0.01721  sm_val_loss=0.01808  time=0.84s
# Epoch 9  loss=0.01698  val_loss=0.01803  sm_loss=0.01711  sm_val_loss=0.01807  time=1.37s
# Epoch 10  loss=0.01685  val_loss=0.01798  sm_loss=0.01699  sm_val_loss=0.01805  time=0.91s
# Epoch 11  loss=0.01673  val_loss=0.01782  sm_loss=0.01688  sm_val_loss=0.01788  time=0.85s
# Epoch 12  loss=0.01654  val_loss=0.01775  sm_loss=0.01670  sm_val_loss=0.01781  time=0.85s
# Epoch 13  loss=0.01643  val_loss=0.01762  sm_loss=0.01659  sm_val_loss=0.01769  time=1.08s
# Epoch 15  loss=0.01606  val_loss=0.01756  sm_loss=0.01624  sm_val_loss=0.01762  time=1.03s
# Epoch 16  loss=0.01593  val_loss=0.01754  sm_loss=0.01611  sm_val_loss=0.01759  time=0.90s
# Epoch 17  loss=0.01576  val_loss=0.01746  sm_loss=0.01595  sm_val_loss=0.01752  time=0.84s
# Epoch 18  loss=0.01564  val_loss=0.01742  sm_loss=0.01583  sm_val_loss=0.01747  time=0.87s
# Fold 3 log loss: 0.017488018074251783
# Fold 4
# Epoch 1  loss=0.55973  val_loss=0.03246  sm_loss=0.55973  sm_val_loss=0.03245  time=0.85s
# Epoch 2  loss=0.02066  val_loss=0.01915  sm_loss=0.02059  sm_val_loss=0.01919  time=0.87s
# Epoch 3  loss=0.01828  val_loss=0.01810  sm_loss=0.01836  sm_val_loss=0.01813  time=1.25s
# Epoch 5  loss=0.01758  val_loss=0.01784  sm_loss=0.01768  sm_val_loss=0.01787  time=0.86s
# Epoch 7  loss=0.01732  val_loss=0.01771  sm_loss=0.01744  sm_val_loss=0.01772  time=0.88s
# Epoch 8  loss=0.01723  val_loss=0.01755  sm_loss=0.01734  sm_val_loss=0.01757  time=1.01s
# Epoch 9  loss=0.01704  val_loss=0.01745  sm_loss=0.01716  sm_val_loss=0.01749  time=0.89s
# Epoch 10  loss=0.01698  val_loss=0.01725  sm_loss=0.01711  sm_val_loss=0.01728  time=0.87s
# Epoch 11  loss=0.01685  val_loss=0.01720  sm_loss=0.01698  sm_val_loss=0.01724  time=0.86s
# Epoch 14  loss=0.01650  val_loss=0.01715  sm_loss=0.01665  sm_val_loss=0.01718  time=0.98s
# Epoch 15  loss=0.01634  val_loss=0.01706  sm_loss=0.01649  sm_val_loss=0.01709  time=1.09s
# Epoch 16  loss=0.01620  val_loss=0.01696  sm_loss=0.01636  sm_val_loss=0.01697  time=0.88s
# Epoch 18  loss=0.01593  val_loss=0.01691  sm_loss=0.01610  sm_val_loss=0.01694  time=0.94s
# Epoch 19  loss=0.01588  val_loss=0.01688  sm_loss=0.01605  sm_val_loss=0.01691  time=1.18s
# Fold 4 log loss: 0.017073422549832153
# Fold 5
# Epoch 1  loss=0.55921  val_loss=0.02912  sm_loss=0.55921  sm_val_loss=0.02911  time=1.72s
# Epoch 2  loss=0.02070  val_loss=0.01914  sm_loss=0.02070  sm_val_loss=0.01918  time=0.96s
# Epoch 3  loss=0.01831  val_loss=0.01896  sm_loss=0.01840  sm_val_loss=0.01900  time=0.89s
# Epoch 4  loss=0.01767  val_loss=0.01818  sm_loss=0.01776  sm_val_loss=0.01822  time=0.83s
# Epoch 7  loss=0.01719  val_loss=0.01789  sm_loss=0.01732  sm_val_loss=0.01789  time=1.05s
# Epoch 8  loss=0.01705  val_loss=0.01773  sm_loss=0.01718  sm_val_loss=0.01774  time=0.88s
# Epoch 10  loss=0.01685  val_loss=0.01769  sm_loss=0.01699  sm_val_loss=0.01772  time=1.02s
# Epoch 12  loss=0.01653  val_loss=0.01764  sm_loss=0.01669  sm_val_loss=0.01768  time=0.84s
# Epoch 13  loss=0.01645  val_loss=0.01749  sm_loss=0.01661  sm_val_loss=0.01754  time=0.88s
# Epoch 14  loss=0.01627  val_loss=0.01738  sm_loss=0.01644  sm_val_loss=0.01740  time=0.99s
# Epoch 17  loss=0.01581  val_loss=0.01729  sm_loss=0.01600  sm_val_loss=0.01734  time=1.03s
# Epoch 18  loss=0.01566  val_loss=0.01728  sm_loss=0.01585  sm_val_loss=0.01732  time=0.94s
# Epoch 19  loss=0.01554  val_loss=0.01728  sm_loss=0.01574  sm_val_loss=0.01732  time=1.10s
# Epoch 20  loss=0.01552  val_loss=0.01727  sm_loss=0.01571  sm_val_loss=0.01731  time=1.18s
# Fold 5 log loss: 0.01734994673219989
# Fold 6
# Epoch 1  loss=0.55901  val_loss=0.02841  sm_loss=0.55901  sm_val_loss=0.02841  time=0.83s
# Epoch 2  loss=0.02049  val_loss=0.01998  sm_loss=0.02045  sm_val_loss=0.01999  time=0.82s
# Epoch 3  loss=0.01828  val_loss=0.01820  sm_loss=0.01836  sm_val_loss=0.01823  time=0.83s
# Epoch 5  loss=0.01764  val_loss=0.01805  sm_loss=0.01774  sm_val_loss=0.01807  time=0.82s
# Epoch 7  loss=0.01731  val_loss=0.01783  sm_loss=0.01742  sm_val_loss=0.01784  time=0.82s
# Epoch 8  loss=0.01722  val_loss=0.01774  sm_loss=0.01734  sm_val_loss=0.01778  time=0.82s
# Epoch 9  loss=0.01702  val_loss=0.01775  sm_loss=0.01715  sm_val_loss=0.01774  time=0.82s
# Epoch 10  loss=0.01698  val_loss=0.01767  sm_loss=0.01711  sm_val_loss=0.01768  time=1.00s
# Epoch 11  loss=0.01681  val_loss=0.01757  sm_loss=0.01696  sm_val_loss=0.01760  time=1.03s
# Epoch 12  loss=0.01664  val_loss=0.01752  sm_loss=0.01678  sm_val_loss=0.01753  time=0.84s
# Epoch 13  loss=0.01650  val_loss=0.01744  sm_loss=0.01666  sm_val_loss=0.01747  time=0.82s
# Epoch 14  loss=0.01632  val_loss=0.01723  sm_loss=0.01648  sm_val_loss=0.01728  time=1.11s
# Epoch 16  loss=0.01601  val_loss=0.01723  sm_loss=0.01618  sm_val_loss=0.01727  time=0.85s
# Epoch 17  loss=0.01587  val_loss=0.01720  sm_loss=0.01604  sm_val_loss=0.01722  time=0.82s
# Epoch 18  loss=0.01576  val_loss=0.01716  sm_loss=0.01593  sm_val_loss=0.01720  time=1.15s
# Epoch 19  loss=0.01566  val_loss=0.01716  sm_loss=0.01584  sm_val_loss=0.01718  time=0.93s
# Fold 6 log loss: 0.017311977387211658
# Fold 7
# Epoch 1  loss=0.55640  val_loss=0.03376  sm_loss=0.55640  sm_val_loss=0.03375  time=0.89s
# Epoch 2  loss=0.02061  val_loss=0.01931  sm_loss=0.02054  sm_val_loss=0.01936  time=0.96s
# Epoch 3  loss=0.01857  val_loss=0.01879  sm_loss=0.01864  sm_val_loss=0.01882  time=0.84s
# Epoch 4  loss=0.01801  val_loss=0.01809  sm_loss=0.01809  sm_val_loss=0.01813  time=0.84s
# Epoch 5  loss=0.01777  val_loss=0.01773  sm_loss=0.01786  sm_val_loss=0.01776  time=0.83s
# Epoch 7  loss=0.01741  val_loss=0.01760  sm_loss=0.01751  sm_val_loss=0.01769  time=1.00s
# Epoch 9  loss=0.01714  val_loss=0.01741  sm_loss=0.01726  sm_val_loss=0.01749  time=1.09s
# Epoch 12  loss=0.01676  val_loss=0.01724  sm_loss=0.01690  sm_val_loss=0.01732  time=0.97s
# Epoch 13  loss=0.01661  val_loss=0.01726  sm_loss=0.01676  sm_val_loss=0.01731  time=0.91s
# Epoch 15  loss=0.01628  val_loss=0.01704  sm_loss=0.01644  sm_val_loss=0.01711  time=0.92s
# Epoch 16  loss=0.01614  val_loss=0.01701  sm_loss=0.01630  sm_val_loss=0.01709  time=0.95s
# Epoch 17  loss=0.01600  val_loss=0.01699  sm_loss=0.01617  sm_val_loss=0.01706  time=1.08s
# Epoch 18  loss=0.01589  val_loss=0.01695  sm_loss=0.01606  sm_val_loss=0.01702  time=1.02s
# Epoch 19  loss=0.01582  val_loss=0.01692  sm_loss=0.01599  sm_val_loss=0.01699  time=1.08s
# Fold 7 log loss: 0.01727642235687778
# Seed 0
# Fold 1 log loss: 0.017091069452598046
# Fold 2 log loss: 0.01712988751788483
# Fold 3 log loss: 0.017488018074251783
# Fold 4 log loss: 0.017073422549832153
# Fold 5 log loss: 0.01734994673219989
# Fold 6 log loss: 0.017311977387211658
# Fold 7 log loss: 0.01727642235687778
# Std of log loss: 0.00014239007831188058
# Total log loss: 0.017245940516531794
# Fold 1
# Epoch 1  loss=0.55954  val_loss=0.03054  sm_loss=0.55954  sm_val_loss=0.03053  time=0.83s
# Epoch 2  loss=0.02079  val_loss=0.01887  sm_loss=0.02070  sm_val_loss=0.01886  time=0.92s
# Epoch 4  loss=0.01789  val_loss=0.01827  sm_loss=0.01798  sm_val_loss=0.01831  time=0.98s
# Epoch 5  loss=0.01770  val_loss=0.01816  sm_loss=0.01779  sm_val_loss=0.01822  time=1.38s
# Epoch 6  loss=0.01754  val_loss=0.01759  sm_loss=0.01765  sm_val_loss=0.01765  time=0.89s
# Epoch 9  loss=0.01715  val_loss=0.01757  sm_loss=0.01727  sm_val_loss=0.01761  time=0.93s
# Epoch 10  loss=0.01704  val_loss=0.01734  sm_loss=0.01716  sm_val_loss=0.01741  time=0.93s
# Epoch 11  loss=0.01692  val_loss=0.01721  sm_loss=0.01705  sm_val_loss=0.01728  time=1.07s
# Epoch 14  loss=0.01648  val_loss=0.01711  sm_loss=0.01663  sm_val_loss=0.01719  time=1.06s
# Epoch 16  loss=0.01624  val_loss=0.01704  sm_loss=0.01639  sm_val_loss=0.01712  time=1.03s
# Epoch 17  loss=0.01612  val_loss=0.01696  sm_loss=0.01628  sm_val_loss=0.01705  time=0.87s
# Epoch 19  loss=0.01592  val_loss=0.01696  sm_loss=0.01608  sm_val_loss=0.01704  time=1.23s
# Fold 1 log loss: 0.017117312593185545
# Fold 2
# Epoch 1  loss=0.56064  val_loss=0.02982  sm_loss=0.56063  sm_val_loss=0.02981  time=0.82s
# Epoch 2  loss=0.02121  val_loss=0.02028  sm_loss=0.02112  sm_val_loss=0.02032  time=0.85s
# Epoch 3  loss=0.01892  val_loss=0.01880  sm_loss=0.01898  sm_val_loss=0.01883  time=0.95s
# Epoch 4  loss=0.01796  val_loss=0.01804  sm_loss=0.01804  sm_val_loss=0.01811  time=0.89s
# Epoch 6  loss=0.01751  val_loss=0.01791  sm_loss=0.01760  sm_val_loss=0.01797  time=0.92s
# Epoch 7  loss=0.01746  val_loss=0.01788  sm_loss=0.01756  sm_val_loss=0.01794  time=0.83s
# Epoch 8  loss=0.01721  val_loss=0.01777  sm_loss=0.01733  sm_val_loss=0.01783  time=0.82s
# Epoch 10  loss=0.01699  val_loss=0.01761  sm_loss=0.01712  sm_val_loss=0.01769  time=1.22s
# Epoch 11  loss=0.01692  val_loss=0.01761  sm_loss=0.01705  sm_val_loss=0.01767  time=0.84s
# Epoch 12  loss=0.01672  val_loss=0.01742  sm_loss=0.01686  sm_val_loss=0.01751  time=1.07s
# Epoch 14  loss=0.01643  val_loss=0.01735  sm_loss=0.01659  sm_val_loss=0.01741  time=0.82s
# Epoch 15  loss=0.01625  val_loss=0.01728  sm_loss=0.01641  sm_val_loss=0.01736  time=0.86s
# Epoch 16  loss=0.01610  val_loss=0.01717  sm_loss=0.01626  sm_val_loss=0.01724  time=0.85s
# Epoch 17  loss=0.01594  val_loss=0.01717  sm_loss=0.01611  sm_val_loss=0.01723  time=0.91s
# Epoch 18  loss=0.01580  val_loss=0.01715  sm_loss=0.01597  sm_val_loss=0.01721  time=1.02s
# Epoch 19  loss=0.01571  val_loss=0.01713  sm_loss=0.01589  sm_val_loss=0.01718  time=1.14s
# Epoch 20  loss=0.01563  val_loss=0.01711  sm_loss=0.01581  sm_val_loss=0.01716  time=0.84s
# Fold 2 log loss: 0.01709533932368075
# Fold 3
# Epoch 1  loss=0.56095  val_loss=0.03522  sm_loss=0.56094  sm_val_loss=0.03521  time=1.28s
# Epoch 2  loss=0.02072  val_loss=0.01917  sm_loss=0.02066  sm_val_loss=0.01922  time=1.01s
# Epoch 3  loss=0.01842  val_loss=0.01903  sm_loss=0.01848  sm_val_loss=0.01906  time=1.02s
# Epoch 4  loss=0.01787  val_loss=0.01852  sm_loss=0.01795  sm_val_loss=0.01856  time=0.90s
# Epoch 5  loss=0.01758  val_loss=0.01845  sm_loss=0.01767  sm_val_loss=0.01851  time=0.96s
# Epoch 7  loss=0.01735  val_loss=0.01824  sm_loss=0.01746  sm_val_loss=0.01828  time=0.92s
# Epoch 8  loss=0.01721  val_loss=0.01806  sm_loss=0.01733  sm_val_loss=0.01811  time=0.98s
# Epoch 9  loss=0.01701  val_loss=0.01796  sm_loss=0.01714  sm_val_loss=0.01802  time=0.84s
# Epoch 11  loss=0.01684  val_loss=0.01790  sm_loss=0.01698  sm_val_loss=0.01791  time=0.83s
# Epoch 12  loss=0.01673  val_loss=0.01776  sm_loss=0.01687  sm_val_loss=0.01780  time=1.10s
# Epoch 14  loss=0.01636  val_loss=0.01758  sm_loss=0.01651  sm_val_loss=0.01764  time=0.83s
# Epoch 16  loss=0.01606  val_loss=0.01757  sm_loss=0.01623  sm_val_loss=0.01760  time=0.90s
# Epoch 17  loss=0.01591  val_loss=0.01754  sm_loss=0.01608  sm_val_loss=0.01760  time=0.84s
# Epoch 18  loss=0.01579  val_loss=0.01753  sm_loss=0.01596  sm_val_loss=0.01757  time=0.88s
# Epoch 19  loss=0.01568  val_loss=0.01753  sm_loss=0.01585  sm_val_loss=0.01756  time=1.00s
# Epoch 20  loss=0.01567  val_loss=0.01750  sm_loss=0.01584  sm_val_loss=0.01754  time=1.16s
# Fold 3 log loss: 0.017558716115544062
# Fold 4
# Epoch 1  loss=0.55715  val_loss=0.02973  sm_loss=0.55715  sm_val_loss=0.02972  time=0.89s
# Epoch 2  loss=0.02068  val_loss=0.01907  sm_loss=0.02066  sm_val_loss=0.01911  time=0.88s
# Epoch 3  loss=0.01840  val_loss=0.01846  sm_loss=0.01847  sm_val_loss=0.01849  time=1.12s
# Epoch 4  loss=0.01780  val_loss=0.01813  sm_loss=0.01787  sm_val_loss=0.01814  time=0.89s
# Epoch 5  loss=0.01758  val_loss=0.01801  sm_loss=0.01768  sm_val_loss=0.01801  time=0.85s
# Epoch 6  loss=0.01744  val_loss=0.01774  sm_loss=0.01754  sm_val_loss=0.01776  time=0.95s
# Epoch 7  loss=0.01728  val_loss=0.01772  sm_loss=0.01740  sm_val_loss=0.01775  time=1.08s
# Epoch 8  loss=0.01714  val_loss=0.01747  sm_loss=0.01727  sm_val_loss=0.01749  time=0.88s
# Epoch 9  loss=0.01704  val_loss=0.01747  sm_loss=0.01718  sm_val_loss=0.01749  time=0.99s
# Epoch 10  loss=0.01693  val_loss=0.01739  sm_loss=0.01708  sm_val_loss=0.01742  time=1.17s
# Epoch 11  loss=0.01678  val_loss=0.01731  sm_loss=0.01693  sm_val_loss=0.01736  time=1.24s
# Epoch 12  loss=0.01665  val_loss=0.01717  sm_loss=0.01681  sm_val_loss=0.01719  time=0.88s
# Epoch 13  loss=0.01650  val_loss=0.01710  sm_loss=0.01667  sm_val_loss=0.01711  time=1.24s
# Epoch 15  loss=0.01617  val_loss=0.01699  sm_loss=0.01635  sm_val_loss=0.01699  time=0.91s
# Epoch 16  loss=0.01601  val_loss=0.01698  sm_loss=0.01619  sm_val_loss=0.01699  time=0.84s
# Epoch 17  loss=0.01582  val_loss=0.01697  sm_loss=0.01601  sm_val_loss=0.01696  time=0.83s
# Epoch 18  loss=0.01572  val_loss=0.01691  sm_loss=0.01591  sm_val_loss=0.01691  time=0.89s
# Epoch 19  loss=0.01561  val_loss=0.01687  sm_loss=0.01580  sm_val_loss=0.01687  time=1.02s
# Epoch 20  loss=0.01555  val_loss=0.01687  sm_loss=0.01574  sm_val_loss=0.01686  time=0.84s
# Fold 4 log loss: 0.017033520409107786
# Fold 5
# Epoch 1  loss=0.55705  val_loss=0.04297  sm_loss=0.55705  sm_val_loss=0.04296  time=0.93s
# Epoch 2  loss=0.02066  val_loss=0.01969  sm_loss=0.02064  sm_val_loss=0.01970  time=0.93s
# Epoch 3  loss=0.01826  val_loss=0.01845  sm_loss=0.01834  sm_val_loss=0.01846  time=0.85s
# Epoch 4  loss=0.01775  val_loss=0.01813  sm_loss=0.01784  sm_val_loss=0.01818  time=1.09s
# Epoch 5  loss=0.01753  val_loss=0.01814  sm_loss=0.01763  sm_val_loss=0.01817  time=0.84s
# Epoch 6  loss=0.01747  val_loss=0.01813  sm_loss=0.01757  sm_val_loss=0.01816  time=0.85s
# Epoch 7  loss=0.01731  val_loss=0.01792  sm_loss=0.01742  sm_val_loss=0.01792  time=1.01s
# Epoch 9  loss=0.01706  val_loss=0.01788  sm_loss=0.01719  sm_val_loss=0.01792  time=1.04s
# Epoch 10  loss=0.01689  val_loss=0.01776  sm_loss=0.01703  sm_val_loss=0.01781  time=0.86s
# Epoch 11  loss=0.01670  val_loss=0.01768  sm_loss=0.01684  sm_val_loss=0.01773  time=0.87s
# Epoch 12  loss=0.01659  val_loss=0.01756  sm_loss=0.01674  sm_val_loss=0.01759  time=0.85s
# Epoch 13  loss=0.01641  val_loss=0.01753  sm_loss=0.01657  sm_val_loss=0.01757  time=1.04s
# Epoch 14  loss=0.01633  val_loss=0.01738  sm_loss=0.01649  sm_val_loss=0.01741  time=0.89s
# Epoch 18  loss=0.01573  val_loss=0.01729  sm_loss=0.01591  sm_val_loss=0.01733  time=0.86s
# Fold 5 log loss: 0.017354492952526623
# Fold 6
# Epoch 1  loss=0.55857  val_loss=0.02981  sm_loss=0.55856  sm_val_loss=0.02980  time=0.84s
# Epoch 2  loss=0.02054  val_loss=0.02003  sm_loss=0.02049  sm_val_loss=0.02000  time=0.98s
# Epoch 3  loss=0.01828  val_loss=0.01876  sm_loss=0.01836  sm_val_loss=0.01874  time=1.04s
# Epoch 4  loss=0.01774  val_loss=0.01812  sm_loss=0.01783  sm_val_loss=0.01816  time=0.83s
# Epoch 6  loss=0.01752  val_loss=0.01801  sm_loss=0.01761  sm_val_loss=0.01804  time=1.05s
# Epoch 8  loss=0.01725  val_loss=0.01782  sm_loss=0.01737  sm_val_loss=0.01785  time=0.86s
# Epoch 10  loss=0.01696  val_loss=0.01766  sm_loss=0.01709  sm_val_loss=0.01767  time=1.00s
# Epoch 11  loss=0.01686  val_loss=0.01758  sm_loss=0.01699  sm_val_loss=0.01762  time=0.83s
# Epoch 12  loss=0.01672  val_loss=0.01745  sm_loss=0.01686  sm_val_loss=0.01748  time=0.82s
# Epoch 13  loss=0.01653  val_loss=0.01741  sm_loss=0.01667  sm_val_loss=0.01744  time=0.98s
# Epoch 15  loss=0.01625  val_loss=0.01726  sm_loss=0.01640  sm_val_loss=0.01732  time=0.88s
# Epoch 16  loss=0.01612  val_loss=0.01715  sm_loss=0.01627  sm_val_loss=0.01720  time=0.89s
# Epoch 17  loss=0.01598  val_loss=0.01714  sm_loss=0.01614  sm_val_loss=0.01719  time=0.87s
# Epoch 18  loss=0.01585  val_loss=0.01711  sm_loss=0.01602  sm_val_loss=0.01716  time=1.15s
# Epoch 20  loss=0.01574  val_loss=0.01708  sm_loss=0.01590  sm_val_loss=0.01713  time=0.83s
# Fold 6 log loss: 0.017261453071970724
# Fold 7
# Epoch 1  loss=0.55883  val_loss=0.02802  sm_loss=0.55883  sm_val_loss=0.02802  time=1.04s
# Epoch 2  loss=0.02062  val_loss=0.01896  sm_loss=0.02058  sm_val_loss=0.01900  time=0.97s
# Epoch 3  loss=0.01828  val_loss=0.01834  sm_loss=0.01836  sm_val_loss=0.01837  time=1.00s
# Epoch 4  loss=0.01780  val_loss=0.01778  sm_loss=0.01789  sm_val_loss=0.01784  time=0.92s
# Epoch 5  loss=0.01764  val_loss=0.01775  sm_loss=0.01773  sm_val_loss=0.01778  time=0.89s
# Epoch 7  loss=0.01735  val_loss=0.01770  sm_loss=0.01745  sm_val_loss=0.01774  time=1.26s
# Epoch 8  loss=0.01721  val_loss=0.01747  sm_loss=0.01733  sm_val_loss=0.01755  time=0.91s
# Epoch 10  loss=0.01696  val_loss=0.01737  sm_loss=0.01710  sm_val_loss=0.01743  time=0.91s
# Epoch 12  loss=0.01659  val_loss=0.01724  sm_loss=0.01675  sm_val_loss=0.01731  time=0.95s
# Epoch 13  loss=0.01650  val_loss=0.01717  sm_loss=0.01666  sm_val_loss=0.01724  time=1.03s
# Epoch 15  loss=0.01617  val_loss=0.01716  sm_loss=0.01634  sm_val_loss=0.01723  time=1.23s
# Epoch 16  loss=0.01602  val_loss=0.01710  sm_loss=0.01620  sm_val_loss=0.01715  time=0.89s
# Epoch 17  loss=0.01588  val_loss=0.01699  sm_loss=0.01606  sm_val_loss=0.01703  time=0.89s
# Epoch 19  loss=0.01565  val_loss=0.01696  sm_loss=0.01583  sm_val_loss=0.01702  time=1.25s
# Epoch 20  loss=0.01559  val_loss=0.01695  sm_loss=0.01578  sm_val_loss=0.01701  time=0.88s
# Fold 7 log loss: 0.017276668409803138
# Seed 1
# Fold 1 log loss: 0.017117312593185545
# Fold 2 log loss: 0.01709533932368075
# Fold 3 log loss: 0.017558716115544062
# Fold 4 log loss: 0.017033520409107786
# Fold 5 log loss: 0.017354492952526623
# Fold 6 log loss: 0.017261453071970724
# Fold 7 log loss: 0.017276668409803138
# Std of log loss: 0.00016693128321000467
# Total log loss: 0.01724276168703413
# Fold 1
# Epoch 1  loss=0.56069  val_loss=0.02844  sm_loss=0.56068  sm_val_loss=0.02843  time=0.87s
# Epoch 2  loss=0.02077  val_loss=0.01925  sm_loss=0.02072  sm_val_loss=0.01929  time=0.89s
# Epoch 3  loss=0.01834  val_loss=0.01800  sm_loss=0.01843  sm_val_loss=0.01806  time=0.86s
# Epoch 4  loss=0.01788  val_loss=0.01765  sm_loss=0.01796  sm_val_loss=0.01770  time=0.93s
# Epoch 6  loss=0.01753  val_loss=0.01758  sm_loss=0.01763  sm_val_loss=0.01765  time=0.87s
# Epoch 7  loss=0.01732  val_loss=0.01745  sm_loss=0.01743  sm_val_loss=0.01753  time=0.89s
# Epoch 9  loss=0.01712  val_loss=0.01746  sm_loss=0.01724  sm_val_loss=0.01753  time=0.87s
# Epoch 10  loss=0.01694  val_loss=0.01733  sm_loss=0.01707  sm_val_loss=0.01743  time=0.87s
# Epoch 11  loss=0.01690  val_loss=0.01732  sm_loss=0.01703  sm_val_loss=0.01740  time=0.92s
# Epoch 12  loss=0.01679  val_loss=0.01721  sm_loss=0.01692  sm_val_loss=0.01729  time=0.89s
# Epoch 13  loss=0.01666  val_loss=0.01706  sm_loss=0.01680  sm_val_loss=0.01716  time=1.08s
# Epoch 15  loss=0.01632  val_loss=0.01705  sm_loss=0.01647  sm_val_loss=0.01714  time=0.90s
# Epoch 16  loss=0.01619  val_loss=0.01705  sm_loss=0.01634  sm_val_loss=0.01713  time=0.89s
# Epoch 17  loss=0.01605  val_loss=0.01696  sm_loss=0.01621  sm_val_loss=0.01705  time=0.94s
# Epoch 18  loss=0.01597  val_loss=0.01694  sm_loss=0.01613  sm_val_loss=0.01703  time=1.00s
# Epoch 19  loss=0.01587  val_loss=0.01693  sm_loss=0.01604  sm_val_loss=0.01702  time=1.37s
# Fold 1 log loss: 0.017099000752915542
# Fold 2
# Epoch 1  loss=0.55821  val_loss=0.02858  sm_loss=0.55821  sm_val_loss=0.02857  time=0.93s
# Epoch 2  loss=0.02042  val_loss=0.02001  sm_loss=0.02041  sm_val_loss=0.02004  time=0.92s
# Epoch 3  loss=0.01825  val_loss=0.01851  sm_loss=0.01833  sm_val_loss=0.01855  time=0.89s
# Epoch 4  loss=0.01781  val_loss=0.01814  sm_loss=0.01790  sm_val_loss=0.01817  time=0.88s
# Epoch 6  loss=0.01745  val_loss=0.01787  sm_loss=0.01755  sm_val_loss=0.01793  time=1.28s
# Epoch 7  loss=0.01737  val_loss=0.01776  sm_loss=0.01747  sm_val_loss=0.01783  time=1.02s
# Epoch 8  loss=0.01727  val_loss=0.01775  sm_loss=0.01739  sm_val_loss=0.01781  time=0.92s
# Epoch 9  loss=0.01704  val_loss=0.01756  sm_loss=0.01716  sm_val_loss=0.01761  time=1.10s
# Epoch 13  loss=0.01650  val_loss=0.01742  sm_loss=0.01665  sm_val_loss=0.01749  time=0.93s
# Epoch 14  loss=0.01635  val_loss=0.01733  sm_loss=0.01651  sm_val_loss=0.01739  time=1.11s
# Epoch 16  loss=0.01604  val_loss=0.01725  sm_loss=0.01621  sm_val_loss=0.01731  time=1.08s
# Epoch 18  loss=0.01574  val_loss=0.01723  sm_loss=0.01592  sm_val_loss=0.01728  time=0.95s
# Epoch 20  loss=0.01560  val_loss=0.01722  sm_loss=0.01578  sm_val_loss=0.01727  time=1.00s
# Fold 2 log loss: 0.01719799590423055
# Fold 3
# Epoch 1  loss=0.55882  val_loss=0.03371  sm_loss=0.55882  sm_val_loss=0.03370  time=0.91s
# Epoch 2  loss=0.02049  val_loss=0.01937  sm_loss=0.02044  sm_val_loss=0.01941  time=1.02s
# Epoch 3  loss=0.01836  val_loss=0.01854  sm_loss=0.01844  sm_val_loss=0.01857  time=0.94s
# Epoch 4  loss=0.01772  val_loss=0.01814  sm_loss=0.01780  sm_val_loss=0.01819  time=0.90s
# Epoch 7  loss=0.01721  val_loss=0.01803  sm_loss=0.01732  sm_val_loss=0.01807  time=0.87s
# Epoch 8  loss=0.01707  val_loss=0.01800  sm_loss=0.01720  sm_val_loss=0.01801  time=0.87s
# Epoch 10  loss=0.01686  val_loss=0.01790  sm_loss=0.01699  sm_val_loss=0.01794  time=0.95s
# Epoch 12  loss=0.01658  val_loss=0.01785  sm_loss=0.01673  sm_val_loss=0.01788  time=0.89s
# Epoch 13  loss=0.01642  val_loss=0.01770  sm_loss=0.01658  sm_val_loss=0.01775  time=0.91s
# Epoch 14  loss=0.01626  val_loss=0.01767  sm_loss=0.01642  sm_val_loss=0.01773  time=0.89s
# Epoch 15  loss=0.01612  val_loss=0.01760  sm_loss=0.01629  sm_val_loss=0.01765  time=1.05s
# Epoch 16  loss=0.01595  val_loss=0.01756  sm_loss=0.01612  sm_val_loss=0.01761  time=0.88s
# Epoch 17  loss=0.01582  val_loss=0.01754  sm_loss=0.01600  sm_val_loss=0.01759  time=1.31s
# Epoch 18  loss=0.01570  val_loss=0.01750  sm_loss=0.01587  sm_val_loss=0.01755  time=0.87s
# Fold 3 log loss: 0.017571199951574343
# Fold 4
# Epoch 1  loss=0.55841  val_loss=0.02993  sm_loss=0.55841  sm_val_loss=0.02992  time=0.88s
# Epoch 2  loss=0.02059  val_loss=0.01921  sm_loss=0.02056  sm_val_loss=0.01925  time=0.86s
# Epoch 3  loss=0.01832  val_loss=0.01795  sm_loss=0.01839  sm_val_loss=0.01798  time=1.02s
# Epoch 4  loss=0.01771  val_loss=0.01792  sm_loss=0.01780  sm_val_loss=0.01794  time=0.94s
# Epoch 5  loss=0.01759  val_loss=0.01780  sm_loss=0.01767  sm_val_loss=0.01782  time=1.09s
# Epoch 6  loss=0.01742  val_loss=0.01752  sm_loss=0.01752  sm_val_loss=0.01754  time=0.95s
# Epoch 7  loss=0.01732  val_loss=0.01741  sm_loss=0.01743  sm_val_loss=0.01743  time=0.96s
# Epoch 9  loss=0.01698  val_loss=0.01737  sm_loss=0.01712  sm_val_loss=0.01737  time=1.01s
# Epoch 11  loss=0.01677  val_loss=0.01723  sm_loss=0.01692  sm_val_loss=0.01726  time=0.89s
# Epoch 13  loss=0.01641  val_loss=0.01719  sm_loss=0.01657  sm_val_loss=0.01719  time=0.92s
# Epoch 14  loss=0.01632  val_loss=0.01706  sm_loss=0.01649  sm_val_loss=0.01708  time=0.88s
# Epoch 15  loss=0.01611  val_loss=0.01702  sm_loss=0.01628  sm_val_loss=0.01705  time=0.86s
# Epoch 16  loss=0.01599  val_loss=0.01696  sm_loss=0.01617  sm_val_loss=0.01697  time=0.93s
# Epoch 17  loss=0.01582  val_loss=0.01687  sm_loss=0.01600  sm_val_loss=0.01688  time=0.95s
# Epoch 18  loss=0.01568  val_loss=0.01686  sm_loss=0.01587  sm_val_loss=0.01687  time=1.29s
# Epoch 20  loss=0.01551  val_loss=0.01687  sm_loss=0.01570  sm_val_loss=0.01687  time=0.88s
# Fold 4 log loss: 0.017037468006449525
# Fold 5
# Epoch 1  loss=0.55859  val_loss=0.03012  sm_loss=0.55859  sm_val_loss=0.03011  time=0.89s
# Epoch 2  loss=0.02085  val_loss=0.01925  sm_loss=0.02079  sm_val_loss=0.01925  time=0.91s
# Epoch 3  loss=0.01841  val_loss=0.01903  sm_loss=0.01849  sm_val_loss=0.01906  time=0.90s
# Epoch 4  loss=0.01785  val_loss=0.01851  sm_loss=0.01793  sm_val_loss=0.01854  time=0.96s
# Epoch 6  loss=0.01745  val_loss=0.01823  sm_loss=0.01755  sm_val_loss=0.01827  time=0.87s
# Epoch 7  loss=0.01731  val_loss=0.01821  sm_loss=0.01742  sm_val_loss=0.01821  time=1.58s
# Epoch 8  loss=0.01723  val_loss=0.01793  sm_loss=0.01735  sm_val_loss=0.01798  time=1.22s
# Epoch 11  loss=0.01683  val_loss=0.01783  sm_loss=0.01696  sm_val_loss=0.01784  time=1.89s
# Epoch 13  loss=0.01663  val_loss=0.01758  sm_loss=0.01678  sm_val_loss=0.01762  time=0.90s
# Epoch 14  loss=0.01648  val_loss=0.01743  sm_loss=0.01663  sm_val_loss=0.01747  time=0.89s
# Epoch 16  loss=0.01616  val_loss=0.01742  sm_loss=0.01632  sm_val_loss=0.01745  time=0.91s
# Epoch 17  loss=0.01601  val_loss=0.01734  sm_loss=0.01618  sm_val_loss=0.01737  time=0.87s
# Epoch 18  loss=0.01588  val_loss=0.01733  sm_loss=0.01605  sm_val_loss=0.01735  time=1.07s
# Fold 5 log loss: 0.01737414427561364
# Fold 6
# Epoch 1  loss=0.55890  val_loss=0.03235  sm_loss=0.55890  sm_val_loss=0.03234  time=0.89s
# Epoch 2  loss=0.02056  val_loss=0.01968  sm_loss=0.02052  sm_val_loss=0.01967  time=0.85s
# Epoch 3  loss=0.01819  val_loss=0.01849  sm_loss=0.01827  sm_val_loss=0.01848  time=0.92s
# Epoch 4  loss=0.01775  val_loss=0.01828  sm_loss=0.01784  sm_val_loss=0.01829  time=0.85s
# Epoch 5  loss=0.01759  val_loss=0.01820  sm_loss=0.01768  sm_val_loss=0.01822  time=0.89s
# Epoch 6  loss=0.01745  val_loss=0.01817  sm_loss=0.01755  sm_val_loss=0.01820  time=0.97s
# Epoch 7  loss=0.01727  val_loss=0.01791  sm_loss=0.01738  sm_val_loss=0.01795  time=0.85s
# Epoch 8  loss=0.01715  val_loss=0.01747  sm_loss=0.01727  sm_val_loss=0.01752  time=0.85s
# Epoch 13  loss=0.01657  val_loss=0.01732  sm_loss=0.01672  sm_val_loss=0.01736  time=0.92s
# Epoch 14  loss=0.01637  val_loss=0.01731  sm_loss=0.01652  sm_val_loss=0.01735  time=1.06s
# Epoch 15  loss=0.01616  val_loss=0.01726  sm_loss=0.01633  sm_val_loss=0.01730  time=0.90s
# Epoch 16  loss=0.01602  val_loss=0.01721  sm_loss=0.01619  sm_val_loss=0.01726  time=0.90s
# Epoch 17  loss=0.01588  val_loss=0.01716  sm_loss=0.01605  sm_val_loss=0.01719  time=0.95s
# Epoch 18  loss=0.01573  val_loss=0.01711  sm_loss=0.01591  sm_val_loss=0.01714  time=1.05s
# Epoch 19  loss=0.01565  val_loss=0.01708  sm_loss=0.01583  sm_val_loss=0.01711  time=1.20s
# Fold 6 log loss: 0.017248530642196776
# Fold 7
# Epoch 1  loss=0.55894  val_loss=0.02877  sm_loss=0.55894  sm_val_loss=0.02876  time=0.86s
# Epoch 2  loss=0.02045  val_loss=0.01871  sm_loss=0.02040  sm_val_loss=0.01875  time=1.22s
# Epoch 3  loss=0.01821  val_loss=0.01812  sm_loss=0.01829  sm_val_loss=0.01818  time=1.07s
# Epoch 4  loss=0.01779  val_loss=0.01796  sm_loss=0.01788  sm_val_loss=0.01802  time=0.89s
# Epoch 5  loss=0.01755  val_loss=0.01767  sm_loss=0.01764  sm_val_loss=0.01770  time=0.84s
# Epoch 9  loss=0.01704  val_loss=0.01756  sm_loss=0.01716  sm_val_loss=0.01763  time=0.83s
# Epoch 10  loss=0.01696  val_loss=0.01754  sm_loss=0.01709  sm_val_loss=0.01761  time=1.08s
# Epoch 11  loss=0.01679  val_loss=0.01725  sm_loss=0.01693  sm_val_loss=0.01734  time=1.02s
# Epoch 12  loss=0.01669  val_loss=0.01728  sm_loss=0.01684  sm_val_loss=0.01734  time=1.03s
# Epoch 13  loss=0.01649  val_loss=0.01714  sm_loss=0.01664  sm_val_loss=0.01722  time=1.11s
# Epoch 14  loss=0.01635  val_loss=0.01715  sm_loss=0.01652  sm_val_loss=0.01719  time=1.01s
# Epoch 15  loss=0.01621  val_loss=0.01707  sm_loss=0.01638  sm_val_loss=0.01714  time=0.86s
# Epoch 17  loss=0.01591  val_loss=0.01702  sm_loss=0.01609  sm_val_loss=0.01707  time=0.82s
# Epoch 18  loss=0.01577  val_loss=0.01698  sm_loss=0.01595  sm_val_loss=0.01703  time=0.99s
# Epoch 19  loss=0.01568  val_loss=0.01695  sm_loss=0.01586  sm_val_loss=0.01701  time=1.02s
# Fold 7 log loss: 0.017287443150562663
# Seed 2
# Fold 1 log loss: 0.017099000752915542
# Fold 2 log loss: 0.01719799590423055
# Fold 3 log loss: 0.017571199951574343
# Fold 4 log loss: 0.017037468006449525
# Fold 5 log loss: 0.01737414427561364
# Fold 6 log loss: 0.017248530642196776
# Fold 7 log loss: 0.017287443150562663
# Std of log loss: 0.00016476919397464193
# Total log loss: 0.017259740943171394
# Fold 1
# Epoch 1  loss=0.55981  val_loss=0.02858  sm_loss=0.55981  sm_val_loss=0.02858  time=1.00s
# Epoch 2  loss=0.02084  val_loss=0.01870  sm_loss=0.02077  sm_val_loss=0.01878  time=1.03s
# Epoch 3  loss=0.01850  val_loss=0.01804  sm_loss=0.01857  sm_val_loss=0.01809  time=1.31s
# Epoch 4  loss=0.01790  val_loss=0.01782  sm_loss=0.01798  sm_val_loss=0.01787  time=0.95s
# Epoch 5  loss=0.01770  val_loss=0.01778  sm_loss=0.01778  sm_val_loss=0.01786  time=0.86s
# Epoch 6  loss=0.01752  val_loss=0.01764  sm_loss=0.01762  sm_val_loss=0.01771  time=0.91s
# Epoch 7  loss=0.01741  val_loss=0.01754  sm_loss=0.01751  sm_val_loss=0.01761  time=1.06s
# Epoch 8  loss=0.01728  val_loss=0.01748  sm_loss=0.01739  sm_val_loss=0.01754  time=1.21s
# Epoch 9  loss=0.01706  val_loss=0.01740  sm_loss=0.01718  sm_val_loss=0.01747  time=0.92s
# Epoch 10  loss=0.01699  val_loss=0.01717  sm_loss=0.01711  sm_val_loss=0.01724  time=1.38s
# Epoch 15  loss=0.01628  val_loss=0.01713  sm_loss=0.01642  sm_val_loss=0.01723  time=0.93s
# Epoch 16  loss=0.01614  val_loss=0.01695  sm_loss=0.01629  sm_val_loss=0.01703  time=0.86s
# Epoch 18  loss=0.01586  val_loss=0.01693  sm_loss=0.01602  sm_val_loss=0.01701  time=1.13s
# Epoch 19  loss=0.01576  val_loss=0.01693  sm_loss=0.01593  sm_val_loss=0.01701  time=0.93s
# Fold 1 log loss: 0.017083776486153952
# Fold 2
# Epoch 1  loss=0.56185  val_loss=0.03132  sm_loss=0.56185  sm_val_loss=0.03131  time=0.83s
# Epoch 2  loss=0.02060  val_loss=0.01895  sm_loss=0.02057  sm_val_loss=0.01901  time=0.85s
# Epoch 3  loss=0.01828  val_loss=0.01854  sm_loss=0.01836  sm_val_loss=0.01858  time=1.11s
# Epoch 5  loss=0.01764  val_loss=0.01790  sm_loss=0.01773  sm_val_loss=0.01795  time=0.84s
# Epoch 7  loss=0.01732  val_loss=0.01783  sm_loss=0.01743  sm_val_loss=0.01791  time=1.00s
# Epoch 9  loss=0.01706  val_loss=0.01783  sm_loss=0.01719  sm_val_loss=0.01790  time=0.84s
# Epoch 11  loss=0.01686  val_loss=0.01745  sm_loss=0.01699  sm_val_loss=0.01752  time=0.94s
# Epoch 14  loss=0.01640  val_loss=0.01738  sm_loss=0.01656  sm_val_loss=0.01743  time=0.84s
# Epoch 15  loss=0.01618  val_loss=0.01731  sm_loss=0.01634  sm_val_loss=0.01736  time=1.08s
# Epoch 17  loss=0.01593  val_loss=0.01724  sm_loss=0.01610  sm_val_loss=0.01729  time=0.86s
# Epoch 18  loss=0.01578  val_loss=0.01724  sm_loss=0.01596  sm_val_loss=0.01729  time=0.99s
# Epoch 19  loss=0.01572  val_loss=0.01720  sm_loss=0.01590  sm_val_loss=0.01724  time=0.84s
# Fold 2 log loss: 0.017154545158625738
# Fold 3
# Epoch 1  loss=0.55854  val_loss=0.02775  sm_loss=0.55854  sm_val_loss=0.02774  time=1.05s
# Epoch 2  loss=0.02046  val_loss=0.01949  sm_loss=0.02043  sm_val_loss=0.01953  time=1.34s
# Epoch 3  loss=0.01824  val_loss=0.01870  sm_loss=0.01831  sm_val_loss=0.01873  time=0.93s
# Epoch 4  loss=0.01772  val_loss=0.01846  sm_loss=0.01781  sm_val_loss=0.01850  time=0.87s
# Epoch 6  loss=0.01740  val_loss=0.01840  sm_loss=0.01751  sm_val_loss=0.01843  time=0.88s
# Epoch 7  loss=0.01724  val_loss=0.01817  sm_loss=0.01734  sm_val_loss=0.01823  time=1.01s
# Epoch 8  loss=0.01706  val_loss=0.01813  sm_loss=0.01718  sm_val_loss=0.01819  time=0.87s
# Epoch 10  loss=0.01683  val_loss=0.01790  sm_loss=0.01697  sm_val_loss=0.01793  time=0.85s
# Epoch 11  loss=0.01664  val_loss=0.01785  sm_loss=0.01678  sm_val_loss=0.01786  time=0.86s
# Epoch 13  loss=0.01642  val_loss=0.01772  sm_loss=0.01658  sm_val_loss=0.01778  time=0.83s
# Epoch 14  loss=0.01623  val_loss=0.01769  sm_loss=0.01639  sm_val_loss=0.01774  time=0.84s
# Epoch 15  loss=0.01608  val_loss=0.01764  sm_loss=0.01625  sm_val_loss=0.01769  time=0.93s
# Epoch 16  loss=0.01594  val_loss=0.01751  sm_loss=0.01611  sm_val_loss=0.01758  time=0.96s
# Epoch 18  loss=0.01566  val_loss=0.01752  sm_loss=0.01584  sm_val_loss=0.01757  time=1.06s
# Epoch 19  loss=0.01559  val_loss=0.01751  sm_loss=0.01578  sm_val_loss=0.01755  time=0.89s
# Epoch 20  loss=0.01553  val_loss=0.01750  sm_loss=0.01572  sm_val_loss=0.01755  time=0.85s
# Fold 3 log loss: 0.017562644377285747
# Fold 4
# Epoch 1  loss=0.55825  val_loss=0.03309  sm_loss=0.55824  sm_val_loss=0.03308  time=1.25s
# Epoch 2  loss=0.02124  val_loss=0.01970  sm_loss=0.02116  sm_val_loss=0.01973  time=1.14s
# Epoch 3  loss=0.01884  val_loss=0.01864  sm_loss=0.01891  sm_val_loss=0.01867  time=0.89s
# Epoch 4  loss=0.01810  val_loss=0.01805  sm_loss=0.01817  sm_val_loss=0.01806  time=0.98s
# Epoch 5  loss=0.01784  val_loss=0.01794  sm_loss=0.01792  sm_val_loss=0.01796  time=1.02s
# Epoch 6  loss=0.01757  val_loss=0.01787  sm_loss=0.01766  sm_val_loss=0.01785  time=1.10s
# Epoch 7  loss=0.01739  val_loss=0.01770  sm_loss=0.01750  sm_val_loss=0.01770  time=1.27s
# Epoch 8  loss=0.01725  val_loss=0.01743  sm_loss=0.01737  sm_val_loss=0.01745  time=0.86s
# Epoch 10  loss=0.01698  val_loss=0.01734  sm_loss=0.01711  sm_val_loss=0.01736  time=1.07s
# Epoch 11  loss=0.01684  val_loss=0.01733  sm_loss=0.01698  sm_val_loss=0.01735  time=1.04s
# Epoch 12  loss=0.01670  val_loss=0.01716  sm_loss=0.01684  sm_val_loss=0.01720  time=1.00s
# Epoch 13  loss=0.01656  val_loss=0.01709  sm_loss=0.01671  sm_val_loss=0.01708  time=0.85s
# Epoch 14  loss=0.01639  val_loss=0.01702  sm_loss=0.01655  sm_val_loss=0.01703  time=1.31s
# Epoch 15  loss=0.01627  val_loss=0.01690  sm_loss=0.01643  sm_val_loss=0.01692  time=0.91s
# Epoch 17  loss=0.01597  val_loss=0.01686  sm_loss=0.01614  sm_val_loss=0.01688  time=1.15s
# Epoch 18  loss=0.01585  val_loss=0.01682  sm_loss=0.01602  sm_val_loss=0.01684  time=1.17s
# Epoch 19  loss=0.01577  val_loss=0.01681  sm_loss=0.01594  sm_val_loss=0.01682  time=1.04s
# Fold 4 log loss: 0.017000418340806907
# Fold 5
# Epoch 1  loss=0.55927  val_loss=0.03733  sm_loss=0.55926  sm_val_loss=0.03732  time=0.91s
# Epoch 2  loss=0.02070  val_loss=0.01967  sm_loss=0.02068  sm_val_loss=0.01969  time=0.89s
# Epoch 3  loss=0.01821  val_loss=0.01839  sm_loss=0.01829  sm_val_loss=0.01843  time=0.84s
# Epoch 5  loss=0.01759  val_loss=0.01831  sm_loss=0.01769  sm_val_loss=0.01830  time=1.02s
# Epoch 6  loss=0.01745  val_loss=0.01797  sm_loss=0.01755  sm_val_loss=0.01800  time=0.84s
# Epoch 9  loss=0.01698  val_loss=0.01779  sm_loss=0.01711  sm_val_loss=0.01782  time=1.02s
# Epoch 11  loss=0.01673  val_loss=0.01770  sm_loss=0.01688  sm_val_loss=0.01773  time=0.98s
# Epoch 12  loss=0.01661  val_loss=0.01745  sm_loss=0.01676  sm_val_loss=0.01750  time=0.99s
# Epoch 14  loss=0.01628  val_loss=0.01741  sm_loss=0.01645  sm_val_loss=0.01742  time=0.85s
# Epoch 16  loss=0.01597  val_loss=0.01733  sm_loss=0.01615  sm_val_loss=0.01736  time=0.84s
# Epoch 18  loss=0.01571  val_loss=0.01727  sm_loss=0.01589  sm_val_loss=0.01730  time=0.84s
# Epoch 19  loss=0.01562  val_loss=0.01727  sm_loss=0.01581  sm_val_loss=0.01730  time=1.09s
# Fold 5 log loss: 0.017338447918002
# Fold 6
# Epoch 1  loss=0.56029  val_loss=0.02955  sm_loss=0.56029  sm_val_loss=0.02954  time=1.05s
# Epoch 2  loss=0.02079  val_loss=0.02007  sm_loss=0.02076  sm_val_loss=0.02003  time=0.84s
# Epoch 3  loss=0.01840  val_loss=0.01845  sm_loss=0.01847  sm_val_loss=0.01847  time=0.86s
# Epoch 4  loss=0.01783  val_loss=0.01803  sm_loss=0.01792  sm_val_loss=0.01806  time=0.98s
# Epoch 8  loss=0.01725  val_loss=0.01798  sm_loss=0.01737  sm_val_loss=0.01798  time=0.84s
# Epoch 10  loss=0.01694  val_loss=0.01758  sm_loss=0.01708  sm_val_loss=0.01760  time=0.91s
# Epoch 13  loss=0.01642  val_loss=0.01749  sm_loss=0.01658  sm_val_loss=0.01747  time=0.92s
# Epoch 15  loss=0.01614  val_loss=0.01733  sm_loss=0.01632  sm_val_loss=0.01731  time=1.05s
# Epoch 16  loss=0.01594  val_loss=0.01721  sm_loss=0.01612  sm_val_loss=0.01723  time=0.91s
# Epoch 17  loss=0.01577  val_loss=0.01717  sm_loss=0.01595  sm_val_loss=0.01719  time=0.99s
# Epoch 18  loss=0.01565  val_loss=0.01715  sm_loss=0.01583  sm_val_loss=0.01715  time=0.87s
# Epoch 19  loss=0.01552  val_loss=0.01711  sm_loss=0.01571  sm_val_loss=0.01713  time=0.85s
# Fold 6 log loss: 0.01725921817429088
# Fold 7
# Epoch 1  loss=0.55890  val_loss=0.03644  sm_loss=0.55890  sm_val_loss=0.03643  time=0.88s
# Epoch 2  loss=0.02099  val_loss=0.02073  sm_loss=0.02092  sm_val_loss=0.02078  time=1.05s
# Epoch 3  loss=0.01871  val_loss=0.01847  sm_loss=0.01877  sm_val_loss=0.01849  time=0.86s
# Epoch 4  loss=0.01796  val_loss=0.01787  sm_loss=0.01803  sm_val_loss=0.01792  time=1.30s
# Epoch 5  loss=0.01766  val_loss=0.01766  sm_loss=0.01774  sm_val_loss=0.01770  time=0.94s
# Epoch 10  loss=0.01694  val_loss=0.01733  sm_loss=0.01707  sm_val_loss=0.01739  time=1.12s
# Epoch 12  loss=0.01669  val_loss=0.01731  sm_loss=0.01684  sm_val_loss=0.01739  time=0.83s
# Epoch 13  loss=0.01649  val_loss=0.01717  sm_loss=0.01664  sm_val_loss=0.01725  time=0.84s
# Epoch 15  loss=0.01622  val_loss=0.01705  sm_loss=0.01639  sm_val_loss=0.01713  time=0.84s
# Epoch 16  loss=0.01603  val_loss=0.01703  sm_loss=0.01621  sm_val_loss=0.01708  time=0.87s
# Epoch 17  loss=0.01589  val_loss=0.01700  sm_loss=0.01607  sm_val_loss=0.01706  time=0.98s
# Epoch 18  loss=0.01578  val_loss=0.01699  sm_loss=0.01596  sm_val_loss=0.01704  time=1.04s
# Epoch 19  loss=0.01567  val_loss=0.01698  sm_loss=0.01585  sm_val_loss=0.01703  time=1.39s
# Epoch 20  loss=0.01564  val_loss=0.01696  sm_loss=0.01582  sm_val_loss=0.01701  time=1.08s
# Fold 7 log loss: 0.01728686676364244
# Seed 3
# Fold 1 log loss: 0.017083776486153952
# Fold 2 log loss: 0.017154545158625738
# Fold 3 log loss: 0.017562644377285747
# Fold 4 log loss: 0.017000418340806907
# Fold 5 log loss: 0.017338447918002
# Fold 6 log loss: 0.01725921817429088
# Fold 7 log loss: 0.01728686676364244
# Std of log loss: 0.00017132254634350647
# Total log loss: 0.01724119611879829
# Fold 1
# Epoch 1  loss=0.56138  val_loss=0.03236  sm_loss=0.56138  sm_val_loss=0.03235  time=0.88s
# Epoch 2  loss=0.02084  val_loss=0.01877  sm_loss=0.02080  sm_val_loss=0.01882  time=0.86s
# Epoch 3  loss=0.01850  val_loss=0.01834  sm_loss=0.01857  sm_val_loss=0.01838  time=0.87s
# Epoch 4  loss=0.01784  val_loss=0.01802  sm_loss=0.01793  sm_val_loss=0.01808  time=0.87s
# Epoch 5  loss=0.01768  val_loss=0.01787  sm_loss=0.01778  sm_val_loss=0.01793  time=0.86s
# Epoch 7  loss=0.01736  val_loss=0.01754  sm_loss=0.01746  sm_val_loss=0.01761  time=0.83s
# Epoch 10  loss=0.01699  val_loss=0.01744  sm_loss=0.01713  sm_val_loss=0.01751  time=0.82s
# Epoch 11  loss=0.01686  val_loss=0.01734  sm_loss=0.01700  sm_val_loss=0.01742  time=0.87s
# Epoch 12  loss=0.01669  val_loss=0.01730  sm_loss=0.01684  sm_val_loss=0.01738  time=1.10s
# Epoch 13  loss=0.01650  val_loss=0.01718  sm_loss=0.01666  sm_val_loss=0.01724  time=0.89s
# Epoch 14  loss=0.01637  val_loss=0.01711  sm_loss=0.01654  sm_val_loss=0.01718  time=0.92s
# Epoch 15  loss=0.01622  val_loss=0.01707  sm_loss=0.01639  sm_val_loss=0.01716  time=0.92s
# Epoch 16  loss=0.01606  val_loss=0.01694  sm_loss=0.01623  sm_val_loss=0.01703  time=0.83s
# Epoch 18  loss=0.01577  val_loss=0.01692  sm_loss=0.01596  sm_val_loss=0.01700  time=0.96s
# Fold 1 log loss: 0.017076663112545718
# Fold 2
# Epoch 1  loss=0.56004  val_loss=0.02719  sm_loss=0.56004  sm_val_loss=0.02718  time=0.84s
# Epoch 2  loss=0.02097  val_loss=0.02051  sm_loss=0.02090  sm_val_loss=0.02053  time=1.00s
# Epoch 3  loss=0.01860  val_loss=0.01838  sm_loss=0.01866  sm_val_loss=0.01843  time=1.03s
# Epoch 5  loss=0.01770  val_loss=0.01813  sm_loss=0.01779  sm_val_loss=0.01818  time=0.84s
# Epoch 6  loss=0.01753  val_loss=0.01790  sm_loss=0.01763  sm_val_loss=0.01795  time=0.86s
# Epoch 8  loss=0.01733  val_loss=0.01767  sm_loss=0.01744  sm_val_loss=0.01772  time=0.93s
# Epoch 9  loss=0.01712  val_loss=0.01767  sm_loss=0.01725  sm_val_loss=0.01772  time=1.12s
# Epoch 10  loss=0.01701  val_loss=0.01768  sm_loss=0.01714  sm_val_loss=0.01772  time=1.20s
# Epoch 12  loss=0.01671  val_loss=0.01741  sm_loss=0.01685  sm_val_loss=0.01748  time=0.91s
# Epoch 13  loss=0.01652  val_loss=0.01740  sm_loss=0.01668  sm_val_loss=0.01746  time=0.84s
# Epoch 14  loss=0.01640  val_loss=0.01740  sm_loss=0.01656  sm_val_loss=0.01744  time=1.11s
# Epoch 15  loss=0.01626  val_loss=0.01726  sm_loss=0.01643  sm_val_loss=0.01733  time=0.84s
# Epoch 16  loss=0.01606  val_loss=0.01726  sm_loss=0.01623  sm_val_loss=0.01732  time=0.84s
# Epoch 17  loss=0.01593  val_loss=0.01718  sm_loss=0.01611  sm_val_loss=0.01725  time=0.99s
# Fold 2 log loss: 0.017176226790828454
# Fold 3
# Epoch 1  loss=0.55900  val_loss=0.02977  sm_loss=0.55899  sm_val_loss=0.02976  time=0.88s
# Epoch 2  loss=0.02048  val_loss=0.01931  sm_loss=0.02043  sm_val_loss=0.01936  time=0.88s
# Epoch 3  loss=0.01822  val_loss=0.01888  sm_loss=0.01831  sm_val_loss=0.01891  time=0.90s
# Epoch 4  loss=0.01770  val_loss=0.01813  sm_loss=0.01779  sm_val_loss=0.01820  time=0.95s
# Epoch 8  loss=0.01705  val_loss=0.01805  sm_loss=0.01716  sm_val_loss=0.01810  time=0.82s
# Epoch 11  loss=0.01669  val_loss=0.01791  sm_loss=0.01683  sm_val_loss=0.01796  time=0.84s
# Epoch 12  loss=0.01654  val_loss=0.01763  sm_loss=0.01669  sm_val_loss=0.01768  time=0.95s
# Epoch 14  loss=0.01626  val_loss=0.01757  sm_loss=0.01643  sm_val_loss=0.01762  time=0.86s
# Epoch 15  loss=0.01609  val_loss=0.01745  sm_loss=0.01626  sm_val_loss=0.01751  time=0.83s
# Epoch 17  loss=0.01579  val_loss=0.01742  sm_loss=0.01596  sm_val_loss=0.01748  time=1.14s
# Epoch 19  loss=0.01557  val_loss=0.01741  sm_loss=0.01575  sm_val_loss=0.01746  time=0.83s
# Epoch 20  loss=0.01551  val_loss=0.01741  sm_loss=0.01569  sm_val_loss=0.01746  time=1.02s
# Fold 3 log loss: 0.0174806863605754
# Fold 4
# Epoch 1  loss=0.55584  val_loss=0.03467  sm_loss=0.55583  sm_val_loss=0.03466  time=0.85s
# Epoch 2  loss=0.02064  val_loss=0.01873  sm_loss=0.02061  sm_val_loss=0.01878  time=0.88s
# Epoch 3  loss=0.01833  val_loss=0.01859  sm_loss=0.01842  sm_val_loss=0.01863  time=1.22s
# Epoch 4  loss=0.01784  val_loss=0.01788  sm_loss=0.01793  sm_val_loss=0.01791  time=0.86s
# Epoch 5  loss=0.01762  val_loss=0.01787  sm_loss=0.01771  sm_val_loss=0.01788  time=0.86s
# Epoch 6  loss=0.01756  val_loss=0.01767  sm_loss=0.01765  sm_val_loss=0.01768  time=1.03s
# Epoch 7  loss=0.01730  val_loss=0.01762  sm_loss=0.01742  sm_val_loss=0.01763  time=0.88s
# Epoch 9  loss=0.01704  val_loss=0.01748  sm_loss=0.01717  sm_val_loss=0.01749  time=0.85s
# Epoch 10  loss=0.01692  val_loss=0.01734  sm_loss=0.01706  sm_val_loss=0.01738  time=0.84s
# Epoch 11  loss=0.01677  val_loss=0.01733  sm_loss=0.01691  sm_val_loss=0.01734  time=0.84s
# Epoch 13  loss=0.01651  val_loss=0.01720  sm_loss=0.01667  sm_val_loss=0.01724  time=0.97s
# Epoch 14  loss=0.01643  val_loss=0.01709  sm_loss=0.01659  sm_val_loss=0.01710  time=0.85s
# Epoch 15  loss=0.01621  val_loss=0.01702  sm_loss=0.01638  sm_val_loss=0.01704  time=1.07s
# Epoch 16  loss=0.01604  val_loss=0.01694  sm_loss=0.01621  sm_val_loss=0.01696  time=0.84s
# Epoch 17  loss=0.01593  val_loss=0.01687  sm_loss=0.01611  sm_val_loss=0.01688  time=1.18s
# Epoch 18  loss=0.01578  val_loss=0.01685  sm_loss=0.01596  sm_val_loss=0.01686  time=1.14s
# Epoch 19  loss=0.01567  val_loss=0.01684  sm_loss=0.01585  sm_val_loss=0.01685  time=1.00s
# Fold 4 log loss: 0.017013950013486153
# Fold 5
# Epoch 1  loss=0.55954  val_loss=0.04188  sm_loss=0.55954  sm_val_loss=0.04188  time=0.83s
# Epoch 2  loss=0.02099  val_loss=0.01938  sm_loss=0.02096  sm_val_loss=0.01940  time=1.03s
# Epoch 3  loss=0.01836  val_loss=0.01834  sm_loss=0.01843  sm_val_loss=0.01835  time=0.99s
# Epoch 4  loss=0.01775  val_loss=0.01823  sm_loss=0.01784  sm_val_loss=0.01826  time=1.02s
# Epoch 6  loss=0.01753  val_loss=0.01819  sm_loss=0.01763  sm_val_loss=0.01822  time=1.00s
# Epoch 7  loss=0.01731  val_loss=0.01790  sm_loss=0.01743  sm_val_loss=0.01795  time=0.84s
# Epoch 8  loss=0.01716  val_loss=0.01782  sm_loss=0.01729  sm_val_loss=0.01782  time=1.19s
# Epoch 11  loss=0.01678  val_loss=0.01778  sm_loss=0.01693  sm_val_loss=0.01779  time=1.07s
# Epoch 12  loss=0.01663  val_loss=0.01766  sm_loss=0.01679  sm_val_loss=0.01768  time=1.23s
# Epoch 13  loss=0.01650  val_loss=0.01760  sm_loss=0.01666  sm_val_loss=0.01764  time=0.86s
# Epoch 14  loss=0.01635  val_loss=0.01759  sm_loss=0.01652  sm_val_loss=0.01761  time=1.04s
# Epoch 15  loss=0.01618  val_loss=0.01744  sm_loss=0.01636  sm_val_loss=0.01748  time=1.27s
# Epoch 16  loss=0.01601  val_loss=0.01735  sm_loss=0.01619  sm_val_loss=0.01738  time=1.04s
# Epoch 17  loss=0.01585  val_loss=0.01729  sm_loss=0.01603  sm_val_loss=0.01733  time=1.37s
# Epoch 18  loss=0.01571  val_loss=0.01726  sm_loss=0.01590  sm_val_loss=0.01729  time=0.97s
# Fold 5 log loss: 0.01732593648232143
# Fold 6
# Epoch 1  loss=0.56005  val_loss=0.03529  sm_loss=0.56005  sm_val_loss=0.03528  time=1.06s
# Epoch 2  loss=0.02090  val_loss=0.01930  sm_loss=0.02083  sm_val_loss=0.01925  time=1.06s
# Epoch 3  loss=0.01843  val_loss=0.01851  sm_loss=0.01851  sm_val_loss=0.01857  time=1.01s
# Epoch 4  loss=0.01793  val_loss=0.01820  sm_loss=0.01802  sm_val_loss=0.01821  time=0.86s
# Epoch 6  loss=0.01748  val_loss=0.01809  sm_loss=0.01758  sm_val_loss=0.01807  time=1.00s
# Epoch 8  loss=0.01724  val_loss=0.01780  sm_loss=0.01736  sm_val_loss=0.01781  time=1.16s
# Epoch 9  loss=0.01710  val_loss=0.01766  sm_loss=0.01722  sm_val_loss=0.01768  time=0.92s
# Epoch 10  loss=0.01703  val_loss=0.01766  sm_loss=0.01715  sm_val_loss=0.01764  time=1.05s
# Epoch 11  loss=0.01680  val_loss=0.01745  sm_loss=0.01694  sm_val_loss=0.01749  time=0.85s
# Epoch 12  loss=0.01668  val_loss=0.01745  sm_loss=0.01682  sm_val_loss=0.01748  time=0.87s
# Epoch 13  loss=0.01654  val_loss=0.01740  sm_loss=0.01668  sm_val_loss=0.01744  time=0.85s
# Epoch 15  loss=0.01625  val_loss=0.01728  sm_loss=0.01641  sm_val_loss=0.01730  time=0.97s
# Epoch 16  loss=0.01610  val_loss=0.01725  sm_loss=0.01626  sm_val_loss=0.01728  time=0.90s
# Epoch 17  loss=0.01595  val_loss=0.01714  sm_loss=0.01612  sm_val_loss=0.01718  time=1.10s
# Epoch 19  loss=0.01575  val_loss=0.01709  sm_loss=0.01592  sm_val_loss=0.01713  time=1.09s
# Fold 6 log loss: 0.01725735400580284
# Fold 7
# Epoch 1  loss=0.55889  val_loss=0.03518  sm_loss=0.55889  sm_val_loss=0.03517  time=0.83s
# Epoch 2  loss=0.02054  val_loss=0.01886  sm_loss=0.02051  sm_val_loss=0.01891  time=0.84s
# Epoch 3  loss=0.01827  val_loss=0.01784  sm_loss=0.01836  sm_val_loss=0.01790  time=0.87s
# Epoch 7  loss=0.01721  val_loss=0.01765  sm_loss=0.01733  sm_val_loss=0.01769  time=1.13s
# Epoch 8  loss=0.01711  val_loss=0.01735  sm_loss=0.01723  sm_val_loss=0.01743  time=0.96s
# Epoch 11  loss=0.01668  val_loss=0.01735  sm_loss=0.01683  sm_val_loss=0.01741  time=0.95s
# Epoch 12  loss=0.01650  val_loss=0.01733  sm_loss=0.01666  sm_val_loss=0.01738  time=0.83s
# Epoch 13  loss=0.01641  val_loss=0.01722  sm_loss=0.01657  sm_val_loss=0.01728  time=0.86s
# Epoch 14  loss=0.01620  val_loss=0.01711  sm_loss=0.01637  sm_val_loss=0.01717  time=0.84s
# Epoch 15  loss=0.01603  val_loss=0.01709  sm_loss=0.01621  sm_val_loss=0.01715  time=1.02s
# Epoch 16  loss=0.01592  val_loss=0.01699  sm_loss=0.01610  sm_val_loss=0.01707  time=0.99s
# Epoch 17  loss=0.01576  val_loss=0.01701  sm_loss=0.01594  sm_val_loss=0.01706  time=1.02s
# Epoch 18  loss=0.01563  val_loss=0.01701  sm_loss=0.01582  sm_val_loss=0.01705  time=0.84s
# Epoch 19  loss=0.01555  val_loss=0.01699  sm_loss=0.01574  sm_val_loss=0.01704  time=0.84s
# Epoch 20  loss=0.01551  val_loss=0.01698  sm_loss=0.01570  sm_val_loss=0.01703  time=0.85s
# Fold 7 log loss: 0.017323484610868214
# Seed 4
# Fold 1 log loss: 0.017076663112545718
# Fold 2 log loss: 0.017176226790828454
# Fold 3 log loss: 0.0174806863605754
# Fold 4 log loss: 0.017013950013486153
# Fold 5 log loss: 0.01732593648232143
# Fold 6 log loss: 0.01725735400580284
# Fold 7 log loss: 0.017323484610868214
# Std of log loss: 0.00014848571683912223
# Total log loss: 0.017236563647216683
# Total log loss in targets: 0.017174330106739535

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.652218878396031

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015828596505531253

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

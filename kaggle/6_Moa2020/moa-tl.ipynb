# %% [markdown]
# - reproduce ver 32 in mlp

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
nontarget_dists.columns = ["target", "number"]
nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
print("first drop", len(drop_list1))
non_targets.drop(drop_list1, axis=1, inplace=True)
print("shape after 1st drop:", non_targets.shape)
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
print(len(non_target_feats))
# Out:
# first drop 71
# shape after 1st drop: (21948, 332)
# 331

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.7)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
len(drop_feats)

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 914) (3624, 914)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 1024))
        self.relu1 = nn.LeakyReLU()
        
        self.batch_norm2 = nn.BatchNorm1d(1024)
        self.dropout2 = nn.Dropout(0.1)
        self.dense2 = nn.utils.weight_norm(nn.Linear(1024, 1024))
        self.relu2 = nn.LeakyReLU()
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.1)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, last_num))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = self.relu1(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = self.relu2(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x
# Out:
# cuda

# %%
batch_size = 128
n_folds=5
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    if files == []:
        train_epochs = 10
        mskf=MultilabelStratifiedKFold(n_splits = n_folds, shuffle=True, random_state=224)
        ans = []
    else:
        train_epochs = 20
        mskf=MultilabelStratifiedKFold(n_splits = n_folds, shuffle=True, random_state=2)
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(X_test, dtype=torch.float32)
    X_test = torch.utils.data.TensorDataset(X_test) 
    test_loader = torch.utils.data.DataLoader(X_test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    for fold, (train_index, valid_index) in enumerate(mskf.split(X_train, y_train)):
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)

        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(non_target_feats)+len(target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            for param in clf.parameters():
                param.requires_grad = False
            # reinitialze
            clf.dense3 = nn.utils.weight_norm(nn.Linear(1024, len(target_feats)))
            for param in clf.dense3.parameters():
                param.requires_grad = True
            optimizer = optim.Adam(clf.parameters(), lr = 0.001, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))
            
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 0.001, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))
        
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time 
                    
            if sm_avg_val_loss < best_val_loss:
                stop_counts = 0
                best_val_loss = sm_avg_val_loss
                print('Best: Epoch {} \t loss={:.5f} \t val_loss={:.5f} \t sm_loss={:.5f} \t sm_val_loss={:.5f} \t time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-model-parameters.pt')
            else:
                stop_counts += 1
                
        if files == []:
            pred_model = MoaModel(init_num, len(non_target_feats)+len(target_feats))
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        if files != []:
            # test predcition --------------
            test_preds = np.zeros([test_len, y_train.shape[1]])
            for i, (x_batch,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
        
    print("Seed {}".format(sample_seed))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
files = torch_tl(fn_train, fn_all_targets, fn_test, 0, fn_train.shape[1], [])

seeds = [0,1,2,3,4] 
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])
    
for seed_ in seeds:
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1], files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Best: Epoch 1 	 loss=0.28681 	 val_loss=0.01191 	 sm_loss=0.28679 	 sm_val_loss=0.01189 	 time=1.52s
# Best: Epoch 2 	 loss=0.01107 	 val_loss=0.01091 	 sm_loss=0.01110 	 sm_val_loss=0.01086 	 time=0.87s
# Best: Epoch 3 	 loss=0.01058 	 val_loss=0.01026 	 sm_loss=0.01068 	 sm_val_loss=0.01041 	 time=0.87s
# Best: Epoch 5 	 loss=0.01020 	 val_loss=0.01014 	 sm_loss=0.01036 	 sm_val_loss=0.01032 	 time=0.85s
# Best: Epoch 6 	 loss=0.01007 	 val_loss=0.01001 	 sm_loss=0.01024 	 sm_val_loss=0.01020 	 time=0.85s
# Best: Epoch 7 	 loss=0.00994 	 val_loss=0.00985 	 sm_loss=0.01011 	 sm_val_loss=0.01004 	 time=1.12s
# Best: Epoch 8 	 loss=0.00973 	 val_loss=0.00966 	 sm_loss=0.00991 	 sm_val_loss=0.00985 	 time=0.85s
# Best: Epoch 9 	 loss=0.00944 	 val_loss=0.00950 	 sm_loss=0.00963 	 sm_val_loss=0.00969 	 time=0.86s
# Best: Epoch 10 	 loss=0.00920 	 val_loss=0.00945 	 sm_loss=0.00941 	 sm_val_loss=0.00964 	 time=0.85s
# Fold 1 log loss: 0.01662170138916034
# Fold 2
# Best: Epoch 1 	 loss=0.28617 	 val_loss=0.01215 	 sm_loss=0.28614 	 sm_val_loss=0.01215 	 time=0.86s
# Best: Epoch 2 	 loss=0.01128 	 val_loss=0.01057 	 sm_loss=0.01128 	 sm_val_loss=0.01067 	 time=0.87s
# Best: Epoch 3 	 loss=0.01043 	 val_loss=0.01032 	 sm_loss=0.01055 	 sm_val_loss=0.01049 	 time=0.88s
# Best: Epoch 4 	 loss=0.01047 	 val_loss=0.01013 	 sm_loss=0.01060 	 sm_val_loss=0.01032 	 time=0.86s
# Best: Epoch 5 	 loss=0.01023 	 val_loss=0.00999 	 sm_loss=0.01039 	 sm_val_loss=0.01018 	 time=0.85s
# Best: Epoch 6 	 loss=0.01009 	 val_loss=0.00991 	 sm_loss=0.01026 	 sm_val_loss=0.01010 	 time=0.86s
# Best: Epoch 7 	 loss=0.00992 	 val_loss=0.00978 	 sm_loss=0.01009 	 sm_val_loss=0.00996 	 time=1.09s
# Best: Epoch 8 	 loss=0.00973 	 val_loss=0.00958 	 sm_loss=0.00991 	 sm_val_loss=0.00977 	 time=0.89s
# Best: Epoch 9 	 loss=0.00947 	 val_loss=0.00942 	 sm_loss=0.00966 	 sm_val_loss=0.00962 	 time=0.88s
# Best: Epoch 10 	 loss=0.00922 	 val_loss=0.00939 	 sm_loss=0.00944 	 sm_val_loss=0.00959 	 time=0.89s
# Fold 2 log loss: 0.0165247633721942
# Fold 3
# Best: Epoch 1 	 loss=0.28672 	 val_loss=0.01180 	 sm_loss=0.28670 	 sm_val_loss=0.01180 	 time=0.86s
# Best: Epoch 2 	 loss=0.01122 	 val_loss=0.01044 	 sm_loss=0.01123 	 sm_val_loss=0.01057 	 time=0.87s
# Best: Epoch 3 	 loss=0.01051 	 val_loss=0.01034 	 sm_loss=0.01064 	 sm_val_loss=0.01050 	 time=0.87s
# Best: Epoch 4 	 loss=0.01027 	 val_loss=0.01017 	 sm_loss=0.01042 	 sm_val_loss=0.01034 	 time=0.88s
# Best: Epoch 5 	 loss=0.01019 	 val_loss=0.01012 	 sm_loss=0.01034 	 sm_val_loss=0.01030 	 time=0.86s
# Best: Epoch 6 	 loss=0.01009 	 val_loss=0.00995 	 sm_loss=0.01025 	 sm_val_loss=0.01012 	 time=1.12s
# Best: Epoch 7 	 loss=0.00992 	 val_loss=0.00981 	 sm_loss=0.01008 	 sm_val_loss=0.00998 	 time=1.28s
# Best: Epoch 8 	 loss=0.00971 	 val_loss=0.00961 	 sm_loss=0.00989 	 sm_val_loss=0.00981 	 time=0.87s
# Best: Epoch 9 	 loss=0.00943 	 val_loss=0.00946 	 sm_loss=0.00962 	 sm_val_loss=0.00966 	 time=0.89s
# Best: Epoch 10 	 loss=0.00919 	 val_loss=0.00940 	 sm_loss=0.00939 	 sm_val_loss=0.00960 	 time=0.85s
# Fold 3 log loss: 0.016521083941555933
# Fold 4
# Best: Epoch 1 	 loss=0.28665 	 val_loss=0.01182 	 sm_loss=0.28664 	 sm_val_loss=0.01181 	 time=0.86s
# Best: Epoch 2 	 loss=0.01112 	 val_loss=0.01070 	 sm_loss=0.01114 	 sm_val_loss=0.01078 	 time=0.87s
# Best: Epoch 3 	 loss=0.01044 	 val_loss=0.01028 	 sm_loss=0.01056 	 sm_val_loss=0.01045 	 time=0.86s
# Best: Epoch 4 	 loss=0.01023 	 val_loss=0.01027 	 sm_loss=0.01039 	 sm_val_loss=0.01043 	 time=0.87s
# Best: Epoch 5 	 loss=0.01018 	 val_loss=0.01008 	 sm_loss=0.01034 	 sm_val_loss=0.01026 	 time=0.87s
# Best: Epoch 6 	 loss=0.01008 	 val_loss=0.00995 	 sm_loss=0.01024 	 sm_val_loss=0.01013 	 time=0.90s
# Best: Epoch 7 	 loss=0.00994 	 val_loss=0.00988 	 sm_loss=0.01010 	 sm_val_loss=0.01006 	 time=1.14s
# Best: Epoch 8 	 loss=0.00971 	 val_loss=0.00971 	 sm_loss=0.00989 	 sm_val_loss=0.00988 	 time=0.91s
# Best: Epoch 9 	 loss=0.00944 	 val_loss=0.00954 	 sm_loss=0.00964 	 sm_val_loss=0.00973 	 time=0.87s
# Best: Epoch 10 	 loss=0.00922 	 val_loss=0.00950 	 sm_loss=0.00943 	 sm_val_loss=0.00970 	 time=0.88s
# Fold 4 log loss: 0.01664419558550897
# Fold 5
# Best: Epoch 1 	 loss=0.28605 	 val_loss=0.01218 	 sm_loss=0.28602 	 sm_val_loss=0.01217 	 time=0.88s
# Best: Epoch 2 	 loss=0.01166 	 val_loss=0.01114 	 sm_loss=0.01163 	 sm_val_loss=0.01122 	 time=1.31s
# Best: Epoch 3 	 loss=0.01062 	 val_loss=0.01029 	 sm_loss=0.01075 	 sm_val_loss=0.01046 	 time=0.94s
# Best: Epoch 4 	 loss=0.01032 	 val_loss=0.01020 	 sm_loss=0.01048 	 sm_val_loss=0.01038 	 time=0.92s
# Best: Epoch 6 	 loss=0.01007 	 val_loss=0.00996 	 sm_loss=0.01024 	 sm_val_loss=0.01014 	 time=0.89s
# Best: Epoch 7 	 loss=0.00990 	 val_loss=0.00985 	 sm_loss=0.01007 	 sm_val_loss=0.01003 	 time=1.61s
# Best: Epoch 8 	 loss=0.00967 	 val_loss=0.00960 	 sm_loss=0.00985 	 sm_val_loss=0.00979 	 time=0.90s
# Best: Epoch 9 	 loss=0.00938 	 val_loss=0.00942 	 sm_loss=0.00958 	 sm_val_loss=0.00962 	 time=0.89s
# Best: Epoch 10 	 loss=0.00911 	 val_loss=0.00941 	 sm_loss=0.00933 	 sm_val_loss=0.00960 	 time=0.90s
# Fold 5 log loss: 0.01649330410221096
# Seed 0
# Fold 1 log loss: 0.01662170138916034
# Fold 2 log loss: 0.0165247633721942
# Fold 3 log loss: 0.016521083941555933
# Fold 4 log loss: 0.01664419558550897
# Fold 5 log loss: 0.01649330410221096
# Std of log loss: 6.0158595594903e-05
# Total log loss: 0.016561008564338713
# Fold 1
# Best: Epoch 1 	 loss=0.17332 	 val_loss=0.02042 	 sm_loss=0.17332 	 sm_val_loss=0.02041 	 time=0.79s
# Best: Epoch 2 	 loss=0.01849 	 val_loss=0.01701 	 sm_loss=0.01849 	 sm_val_loss=0.01704 	 time=0.62s
# Best: Epoch 3 	 loss=0.01680 	 val_loss=0.01629 	 sm_loss=0.01684 	 sm_val_loss=0.01636 	 time=0.68s
# Best: Epoch 4 	 loss=0.01633 	 val_loss=0.01606 	 sm_loss=0.01641 	 sm_val_loss=0.01615 	 time=0.66s
# Best: Epoch 5 	 loss=0.01612 	 val_loss=0.01593 	 sm_loss=0.01623 	 sm_val_loss=0.01605 	 time=0.57s
# Best: Epoch 6 	 loss=0.01605 	 val_loss=0.01583 	 sm_loss=0.01618 	 sm_val_loss=0.01597 	 time=0.58s
# Best: Epoch 8 	 loss=0.01593 	 val_loss=0.01580 	 sm_loss=0.01609 	 sm_val_loss=0.01596 	 time=0.57s
# Best: Epoch 9 	 loss=0.01591 	 val_loss=0.01576 	 sm_loss=0.01607 	 sm_val_loss=0.01592 	 time=0.58s
# Best: Epoch 10 	 loss=0.01585 	 val_loss=0.01575 	 sm_loss=0.01602 	 sm_val_loss=0.01591 	 time=0.61s
# Best: Epoch 11 	 loss=0.01581 	 val_loss=0.01570 	 sm_loss=0.01598 	 sm_val_loss=0.01586 	 time=0.57s
# Best: Epoch 12 	 loss=0.01582 	 val_loss=0.01569 	 sm_loss=0.01599 	 sm_val_loss=0.01586 	 time=0.57s
# Best: Epoch 13 	 loss=0.01574 	 val_loss=0.01566 	 sm_loss=0.01591 	 sm_val_loss=0.01582 	 time=0.58s
# Best: Epoch 14 	 loss=0.01566 	 val_loss=0.01562 	 sm_loss=0.01583 	 sm_val_loss=0.01578 	 time=0.57s
# Best: Epoch 15 	 loss=0.01560 	 val_loss=0.01556 	 sm_loss=0.01578 	 sm_val_loss=0.01573 	 time=0.58s
# Best: Epoch 16 	 loss=0.01554 	 val_loss=0.01552 	 sm_loss=0.01572 	 sm_val_loss=0.01569 	 time=0.58s
# Best: Epoch 17 	 loss=0.01551 	 val_loss=0.01548 	 sm_loss=0.01568 	 sm_val_loss=0.01565 	 time=0.57s
# Best: Epoch 18 	 loss=0.01544 	 val_loss=0.01545 	 sm_loss=0.01562 	 sm_val_loss=0.01562 	 time=0.64s
# Fold 1 log loss: 0.01572115589189806
# Fold 2
# Best: Epoch 1 	 loss=0.16919 	 val_loss=0.02036 	 sm_loss=0.16918 	 sm_val_loss=0.02035 	 time=0.57s
# Best: Epoch 2 	 loss=0.01856 	 val_loss=0.01695 	 sm_loss=0.01857 	 sm_val_loss=0.01697 	 time=0.58s
# Best: Epoch 3 	 loss=0.01685 	 val_loss=0.01629 	 sm_loss=0.01689 	 sm_val_loss=0.01637 	 time=0.60s
# Best: Epoch 4 	 loss=0.01641 	 val_loss=0.01602 	 sm_loss=0.01650 	 sm_val_loss=0.01612 	 time=0.59s
# Best: Epoch 5 	 loss=0.01621 	 val_loss=0.01589 	 sm_loss=0.01632 	 sm_val_loss=0.01602 	 time=0.58s
# Best: Epoch 7 	 loss=0.01604 	 val_loss=0.01582 	 sm_loss=0.01618 	 sm_val_loss=0.01598 	 time=0.57s
# Best: Epoch 8 	 loss=0.01597 	 val_loss=0.01580 	 sm_loss=0.01612 	 sm_val_loss=0.01595 	 time=0.58s
# Best: Epoch 9 	 loss=0.01597 	 val_loss=0.01573 	 sm_loss=0.01612 	 sm_val_loss=0.01588 	 time=0.58s
# Best: Epoch 12 	 loss=0.01586 	 val_loss=0.01570 	 sm_loss=0.01602 	 sm_val_loss=0.01586 	 time=0.58s
# Best: Epoch 13 	 loss=0.01582 	 val_loss=0.01563 	 sm_loss=0.01599 	 sm_val_loss=0.01580 	 time=0.60s
# Best: Epoch 14 	 loss=0.01575 	 val_loss=0.01562 	 sm_loss=0.01592 	 sm_val_loss=0.01578 	 time=0.61s
# Best: Epoch 15 	 loss=0.01570 	 val_loss=0.01556 	 sm_loss=0.01587 	 sm_val_loss=0.01572 	 time=0.58s
# Best: Epoch 16 	 loss=0.01560 	 val_loss=0.01552 	 sm_loss=0.01578 	 sm_val_loss=0.01569 	 time=0.67s
# Best: Epoch 17 	 loss=0.01553 	 val_loss=0.01550 	 sm_loss=0.01570 	 sm_val_loss=0.01566 	 time=0.72s
# Best: Epoch 18 	 loss=0.01546 	 val_loss=0.01546 	 sm_loss=0.01564 	 sm_val_loss=0.01563 	 time=0.58s
# Best: Epoch 19 	 loss=0.01547 	 val_loss=0.01543 	 sm_loss=0.01565 	 sm_val_loss=0.01561 	 time=0.57s
# Fold 2 log loss: 0.015663617320168327
# Fold 3
# Best: Epoch 1 	 loss=0.17084 	 val_loss=0.02032 	 sm_loss=0.17083 	 sm_val_loss=0.02031 	 time=0.57s
# Best: Epoch 2 	 loss=0.01853 	 val_loss=0.01689 	 sm_loss=0.01853 	 sm_val_loss=0.01691 	 time=0.57s
# Best: Epoch 3 	 loss=0.01685 	 val_loss=0.01603 	 sm_loss=0.01689 	 sm_val_loss=0.01610 	 time=0.59s
# Best: Epoch 4 	 loss=0.01633 	 val_loss=0.01583 	 sm_loss=0.01641 	 sm_val_loss=0.01593 	 time=0.58s
# Best: Epoch 5 	 loss=0.01614 	 val_loss=0.01569 	 sm_loss=0.01624 	 sm_val_loss=0.01581 	 time=0.59s
# Best: Epoch 6 	 loss=0.01603 	 val_loss=0.01560 	 sm_loss=0.01616 	 sm_val_loss=0.01574 	 time=0.62s
# Best: Epoch 7 	 loss=0.01599 	 val_loss=0.01552 	 sm_loss=0.01613 	 sm_val_loss=0.01566 	 time=0.80s
# Best: Epoch 12 	 loss=0.01581 	 val_loss=0.01535 	 sm_loss=0.01598 	 sm_val_loss=0.01551 	 time=0.60s
# Best: Epoch 15 	 loss=0.01564 	 val_loss=0.01531 	 sm_loss=0.01581 	 sm_val_loss=0.01548 	 time=0.57s
# Best: Epoch 16 	 loss=0.01565 	 val_loss=0.01525 	 sm_loss=0.01582 	 sm_val_loss=0.01542 	 time=0.57s
# Best: Epoch 18 	 loss=0.01549 	 val_loss=0.01521 	 sm_loss=0.01567 	 sm_val_loss=0.01537 	 time=0.59s
# Best: Epoch 19 	 loss=0.01541 	 val_loss=0.01520 	 sm_loss=0.01558 	 sm_val_loss=0.01537 	 time=0.59s
# Best: Epoch 20 	 loss=0.01537 	 val_loss=0.01518 	 sm_loss=0.01554 	 sm_val_loss=0.01535 	 time=0.59s
# Fold 3 log loss: 0.015352757852644153
# Fold 4
# Best: Epoch 1 	 loss=0.17110 	 val_loss=0.02024 	 sm_loss=0.17109 	 sm_val_loss=0.02023 	 time=0.59s
# Best: Epoch 2 	 loss=0.01859 	 val_loss=0.01681 	 sm_loss=0.01859 	 sm_val_loss=0.01683 	 time=0.58s
# Best: Epoch 3 	 loss=0.01689 	 val_loss=0.01613 	 sm_loss=0.01694 	 sm_val_loss=0.01620 	 time=0.59s
# Best: Epoch 4 	 loss=0.01637 	 val_loss=0.01587 	 sm_loss=0.01646 	 sm_val_loss=0.01596 	 time=0.59s
# Best: Epoch 5 	 loss=0.01622 	 val_loss=0.01573 	 sm_loss=0.01633 	 sm_val_loss=0.01585 	 time=0.58s
# Best: Epoch 6 	 loss=0.01610 	 val_loss=0.01565 	 sm_loss=0.01624 	 sm_val_loss=0.01580 	 time=1.36s
# Best: Epoch 7 	 loss=0.01600 	 val_loss=0.01564 	 sm_loss=0.01614 	 sm_val_loss=0.01579 	 time=0.64s
# Best: Epoch 8 	 loss=0.01599 	 val_loss=0.01562 	 sm_loss=0.01614 	 sm_val_loss=0.01577 	 time=0.63s
# Best: Epoch 10 	 loss=0.01597 	 val_loss=0.01557 	 sm_loss=0.01613 	 sm_val_loss=0.01572 	 time=0.61s
# Best: Epoch 12 	 loss=0.01590 	 val_loss=0.01551 	 sm_loss=0.01606 	 sm_val_loss=0.01569 	 time=0.56s
# Best: Epoch 14 	 loss=0.01577 	 val_loss=0.01546 	 sm_loss=0.01594 	 sm_val_loss=0.01563 	 time=0.66s
# Best: Epoch 15 	 loss=0.01568 	 val_loss=0.01542 	 sm_loss=0.01585 	 sm_val_loss=0.01558 	 time=0.61s
# Best: Epoch 16 	 loss=0.01565 	 val_loss=0.01538 	 sm_loss=0.01582 	 sm_val_loss=0.01555 	 time=0.60s
# Best: Epoch 17 	 loss=0.01555 	 val_loss=0.01532 	 sm_loss=0.01573 	 sm_val_loss=0.01549 	 time=0.66s
# Best: Epoch 18 	 loss=0.01553 	 val_loss=0.01529 	 sm_loss=0.01571 	 sm_val_loss=0.01546 	 time=0.60s
# Fold 4 log loss: 0.015517144351644708
# Fold 5
# Best: Epoch 1 	 loss=0.16921 	 val_loss=0.02031 	 sm_loss=0.16920 	 sm_val_loss=0.02030 	 time=0.58s
# Best: Epoch 2 	 loss=0.01835 	 val_loss=0.01688 	 sm_loss=0.01835 	 sm_val_loss=0.01691 	 time=0.58s
# Best: Epoch 3 	 loss=0.01665 	 val_loss=0.01624 	 sm_loss=0.01669 	 sm_val_loss=0.01631 	 time=0.59s
# Best: Epoch 4 	 loss=0.01621 	 val_loss=0.01592 	 sm_loss=0.01630 	 sm_val_loss=0.01603 	 time=0.59s
# Best: Epoch 5 	 loss=0.01603 	 val_loss=0.01588 	 sm_loss=0.01615 	 sm_val_loss=0.01601 	 time=0.59s
# Best: Epoch 6 	 loss=0.01584 	 val_loss=0.01577 	 sm_loss=0.01597 	 sm_val_loss=0.01591 	 time=0.58s
# Best: Epoch 7 	 loss=0.01581 	 val_loss=0.01574 	 sm_loss=0.01596 	 sm_val_loss=0.01590 	 time=0.60s
# Best: Epoch 8 	 loss=0.01580 	 val_loss=0.01572 	 sm_loss=0.01596 	 sm_val_loss=0.01587 	 time=0.56s
# Best: Epoch 9 	 loss=0.01576 	 val_loss=0.01569 	 sm_loss=0.01592 	 sm_val_loss=0.01586 	 time=0.58s
# Best: Epoch 11 	 loss=0.01564 	 val_loss=0.01566 	 sm_loss=0.01581 	 sm_val_loss=0.01583 	 time=0.73s
# Best: Epoch 12 	 loss=0.01563 	 val_loss=0.01564 	 sm_loss=0.01581 	 sm_val_loss=0.01580 	 time=0.78s
# Best: Epoch 13 	 loss=0.01560 	 val_loss=0.01557 	 sm_loss=0.01577 	 sm_val_loss=0.01575 	 time=0.59s
# Best: Epoch 14 	 loss=0.01554 	 val_loss=0.01555 	 sm_loss=0.01572 	 sm_val_loss=0.01571 	 time=0.58s
# Best: Epoch 15 	 loss=0.01547 	 val_loss=0.01549 	 sm_loss=0.01564 	 sm_val_loss=0.01566 	 time=0.60s
# Best: Epoch 16 	 loss=0.01542 	 val_loss=0.01544 	 sm_loss=0.01560 	 sm_val_loss=0.01562 	 time=0.73s
# Best: Epoch 17 	 loss=0.01534 	 val_loss=0.01544 	 sm_loss=0.01553 	 sm_val_loss=0.01561 	 time=0.67s
# Best: Epoch 18 	 loss=0.01529 	 val_loss=0.01539 	 sm_loss=0.01547 	 sm_val_loss=0.01556 	 time=0.58s
# Best: Epoch 19 	 loss=0.01523 	 val_loss=0.01539 	 sm_loss=0.01541 	 sm_val_loss=0.01556 	 time=0.57s
# Fold 5 log loss: 0.015564292849675995
# Seed 0
# Fold 1 log loss: 0.01572115589189806
# Fold 2 log loss: 0.015663617320168327
# Fold 3 log loss: 0.015352757852644153
# Fold 4 log loss: 0.015517144351644708
# Fold 5 log loss: 0.015564292849675995
# Std of log loss: 0.0001276245699730533
# Total log loss: 0.015563789082272067
# Fold 1
# Best: Epoch 1 	 loss=0.17183 	 val_loss=0.02042 	 sm_loss=0.17182 	 sm_val_loss=0.02041 	 time=0.57s
# Best: Epoch 2 	 loss=0.01849 	 val_loss=0.01704 	 sm_loss=0.01850 	 sm_val_loss=0.01706 	 time=0.57s
# Best: Epoch 3 	 loss=0.01678 	 val_loss=0.01629 	 sm_loss=0.01683 	 sm_val_loss=0.01636 	 time=0.57s
# Best: Epoch 4 	 loss=0.01634 	 val_loss=0.01599 	 sm_loss=0.01642 	 sm_val_loss=0.01608 	 time=0.58s
# Best: Epoch 5 	 loss=0.01617 	 val_loss=0.01592 	 sm_loss=0.01628 	 sm_val_loss=0.01605 	 time=0.57s
# Best: Epoch 6 	 loss=0.01596 	 val_loss=0.01585 	 sm_loss=0.01609 	 sm_val_loss=0.01598 	 time=0.57s
# Best: Epoch 7 	 loss=0.01598 	 val_loss=0.01578 	 sm_loss=0.01613 	 sm_val_loss=0.01593 	 time=0.77s
# Best: Epoch 9 	 loss=0.01591 	 val_loss=0.01575 	 sm_loss=0.01607 	 sm_val_loss=0.01590 	 time=0.57s
# Best: Epoch 11 	 loss=0.01583 	 val_loss=0.01572 	 sm_loss=0.01599 	 sm_val_loss=0.01588 	 time=0.56s
# Best: Epoch 13 	 loss=0.01573 	 val_loss=0.01564 	 sm_loss=0.01590 	 sm_val_loss=0.01580 	 time=0.57s
# Best: Epoch 15 	 loss=0.01564 	 val_loss=0.01558 	 sm_loss=0.01581 	 sm_val_loss=0.01574 	 time=0.59s
# Best: Epoch 16 	 loss=0.01559 	 val_loss=0.01555 	 sm_loss=0.01577 	 sm_val_loss=0.01572 	 time=0.60s
# Best: Epoch 17 	 loss=0.01553 	 val_loss=0.01552 	 sm_loss=0.01571 	 sm_val_loss=0.01568 	 time=0.59s
# Best: Epoch 18 	 loss=0.01543 	 val_loss=0.01546 	 sm_loss=0.01561 	 sm_val_loss=0.01563 	 time=0.61s
# Fold 1 log loss: 0.01572792230806568
# Fold 2
# Best: Epoch 1 	 loss=0.17141 	 val_loss=0.02032 	 sm_loss=0.17140 	 sm_val_loss=0.02031 	 time=0.60s
# Best: Epoch 2 	 loss=0.01862 	 val_loss=0.01700 	 sm_loss=0.01863 	 sm_val_loss=0.01702 	 time=0.84s
# Best: Epoch 3 	 loss=0.01686 	 val_loss=0.01634 	 sm_loss=0.01691 	 sm_val_loss=0.01640 	 time=0.61s
# Best: Epoch 4 	 loss=0.01640 	 val_loss=0.01599 	 sm_loss=0.01649 	 sm_val_loss=0.01609 	 time=0.62s
# Best: Epoch 5 	 loss=0.01623 	 val_loss=0.01591 	 sm_loss=0.01634 	 sm_val_loss=0.01604 	 time=0.59s
# Best: Epoch 6 	 loss=0.01610 	 val_loss=0.01582 	 sm_loss=0.01623 	 sm_val_loss=0.01596 	 time=0.60s
# Best: Epoch 10 	 loss=0.01589 	 val_loss=0.01573 	 sm_loss=0.01605 	 sm_val_loss=0.01591 	 time=0.57s
# Best: Epoch 12 	 loss=0.01582 	 val_loss=0.01565 	 sm_loss=0.01599 	 sm_val_loss=0.01582 	 time=0.56s
# Best: Epoch 13 	 loss=0.01577 	 val_loss=0.01564 	 sm_loss=0.01594 	 sm_val_loss=0.01581 	 time=0.78s
# Best: Epoch 14 	 loss=0.01573 	 val_loss=0.01564 	 sm_loss=0.01591 	 sm_val_loss=0.01580 	 time=0.70s
# Best: Epoch 15 	 loss=0.01568 	 val_loss=0.01557 	 sm_loss=0.01585 	 sm_val_loss=0.01573 	 time=0.57s
# Best: Epoch 16 	 loss=0.01563 	 val_loss=0.01553 	 sm_loss=0.01580 	 sm_val_loss=0.01570 	 time=0.57s
# Best: Epoch 17 	 loss=0.01553 	 val_loss=0.01550 	 sm_loss=0.01571 	 sm_val_loss=0.01567 	 time=0.58s
# Best: Epoch 18 	 loss=0.01548 	 val_loss=0.01550 	 sm_loss=0.01566 	 sm_val_loss=0.01566 	 time=0.56s
# Best: Epoch 19 	 loss=0.01542 	 val_loss=0.01546 	 sm_loss=0.01559 	 sm_val_loss=0.01563 	 time=0.80s
# Best: Epoch 20 	 loss=0.01539 	 val_loss=0.01544 	 sm_loss=0.01557 	 sm_val_loss=0.01562 	 time=0.61s
# Fold 2 log loss: 0.01567113099101501
# Fold 3
# Best: Epoch 1 	 loss=0.16875 	 val_loss=0.02032 	 sm_loss=0.16874 	 sm_val_loss=0.02032 	 time=0.59s
# Best: Epoch 2 	 loss=0.01852 	 val_loss=0.01680 	 sm_loss=0.01852 	 sm_val_loss=0.01683 	 time=0.57s
# Best: Epoch 3 	 loss=0.01682 	 val_loss=0.01600 	 sm_loss=0.01686 	 sm_val_loss=0.01607 	 time=0.59s
# Best: Epoch 4 	 loss=0.01633 	 val_loss=0.01575 	 sm_loss=0.01641 	 sm_val_loss=0.01585 	 time=0.82s
# Best: Epoch 5 	 loss=0.01616 	 val_loss=0.01568 	 sm_loss=0.01627 	 sm_val_loss=0.01580 	 time=0.75s
# Best: Epoch 6 	 loss=0.01603 	 val_loss=0.01561 	 sm_loss=0.01616 	 sm_val_loss=0.01574 	 time=0.60s
# Best: Epoch 7 	 loss=0.01597 	 val_loss=0.01555 	 sm_loss=0.01611 	 sm_val_loss=0.01570 	 time=0.76s
# Best: Epoch 8 	 loss=0.01597 	 val_loss=0.01551 	 sm_loss=0.01612 	 sm_val_loss=0.01567 	 time=0.64s
# Best: Epoch 11 	 loss=0.01586 	 val_loss=0.01544 	 sm_loss=0.01602 	 sm_val_loss=0.01560 	 time=0.58s
# Best: Epoch 12 	 loss=0.01580 	 val_loss=0.01543 	 sm_loss=0.01596 	 sm_val_loss=0.01560 	 time=0.59s
# Best: Epoch 13 	 loss=0.01577 	 val_loss=0.01542 	 sm_loss=0.01593 	 sm_val_loss=0.01558 	 time=0.75s
# Best: Epoch 14 	 loss=0.01571 	 val_loss=0.01538 	 sm_loss=0.01588 	 sm_val_loss=0.01553 	 time=0.76s
# Best: Epoch 15 	 loss=0.01566 	 val_loss=0.01529 	 sm_loss=0.01582 	 sm_val_loss=0.01546 	 time=0.65s
# Best: Epoch 16 	 loss=0.01561 	 val_loss=0.01525 	 sm_loss=0.01578 	 sm_val_loss=0.01542 	 time=0.59s
# Best: Epoch 17 	 loss=0.01555 	 val_loss=0.01522 	 sm_loss=0.01572 	 sm_val_loss=0.01539 	 time=0.63s
# Best: Epoch 18 	 loss=0.01546 	 val_loss=0.01519 	 sm_loss=0.01563 	 sm_val_loss=0.01536 	 time=0.58s
# Fold 3 log loss: 0.015362327927999214
# Fold 4
# Best: Epoch 1 	 loss=0.17211 	 val_loss=0.02041 	 sm_loss=0.17211 	 sm_val_loss=0.02040 	 time=0.58s
# Best: Epoch 2 	 loss=0.01858 	 val_loss=0.01685 	 sm_loss=0.01859 	 sm_val_loss=0.01688 	 time=0.57s
# Best: Epoch 3 	 loss=0.01688 	 val_loss=0.01613 	 sm_loss=0.01693 	 sm_val_loss=0.01620 	 time=0.57s
# Best: Epoch 4 	 loss=0.01646 	 val_loss=0.01595 	 sm_loss=0.01655 	 sm_val_loss=0.01604 	 time=0.58s
# Best: Epoch 5 	 loss=0.01622 	 val_loss=0.01578 	 sm_loss=0.01633 	 sm_val_loss=0.01590 	 time=0.58s
# Best: Epoch 6 	 loss=0.01606 	 val_loss=0.01574 	 sm_loss=0.01619 	 sm_val_loss=0.01588 	 time=0.57s
# Best: Epoch 7 	 loss=0.01602 	 val_loss=0.01570 	 sm_loss=0.01616 	 sm_val_loss=0.01584 	 time=0.62s
# Best: Epoch 8 	 loss=0.01598 	 val_loss=0.01567 	 sm_loss=0.01613 	 sm_val_loss=0.01583 	 time=0.79s
# Best: Epoch 9 	 loss=0.01601 	 val_loss=0.01560 	 sm_loss=0.01617 	 sm_val_loss=0.01577 	 time=0.57s
# Best: Epoch 10 	 loss=0.01599 	 val_loss=0.01557 	 sm_loss=0.01616 	 sm_val_loss=0.01573 	 time=0.60s
# Best: Epoch 13 	 loss=0.01583 	 val_loss=0.01553 	 sm_loss=0.01600 	 sm_val_loss=0.01570 	 time=0.56s
# Best: Epoch 14 	 loss=0.01577 	 val_loss=0.01544 	 sm_loss=0.01595 	 sm_val_loss=0.01560 	 time=0.58s
# Best: Epoch 15 	 loss=0.01570 	 val_loss=0.01541 	 sm_loss=0.01588 	 sm_val_loss=0.01558 	 time=0.56s
# Best: Epoch 16 	 loss=0.01561 	 val_loss=0.01537 	 sm_loss=0.01578 	 sm_val_loss=0.01554 	 time=0.59s
# Best: Epoch 17 	 loss=0.01554 	 val_loss=0.01536 	 sm_loss=0.01572 	 sm_val_loss=0.01552 	 time=0.73s
# Best: Epoch 18 	 loss=0.01555 	 val_loss=0.01532 	 sm_loss=0.01573 	 sm_val_loss=0.01548 	 time=0.76s
# Best: Epoch 19 	 loss=0.01543 	 val_loss=0.01528 	 sm_loss=0.01561 	 sm_val_loss=0.01545 	 time=0.59s
# Best: Epoch 20 	 loss=0.01545 	 val_loss=0.01528 	 sm_loss=0.01563 	 sm_val_loss=0.01545 	 time=0.63s
# Fold 4 log loss: 0.01550433616794346
# Fold 5
# Best: Epoch 1 	 loss=0.16966 	 val_loss=0.02041 	 sm_loss=0.16965 	 sm_val_loss=0.02040 	 time=0.58s
# Best: Epoch 2 	 loss=0.01840 	 val_loss=0.01688 	 sm_loss=0.01841 	 sm_val_loss=0.01691 	 time=0.78s
# Best: Epoch 3 	 loss=0.01668 	 val_loss=0.01620 	 sm_loss=0.01673 	 sm_val_loss=0.01628 	 time=0.60s
# Best: Epoch 4 	 loss=0.01619 	 val_loss=0.01597 	 sm_loss=0.01627 	 sm_val_loss=0.01607 	 time=0.58s
# Best: Epoch 5 	 loss=0.01600 	 val_loss=0.01587 	 sm_loss=0.01612 	 sm_val_loss=0.01600 	 time=0.59s
# Best: Epoch 6 	 loss=0.01589 	 val_loss=0.01575 	 sm_loss=0.01602 	 sm_val_loss=0.01589 	 time=0.58s
# Best: Epoch 8 	 loss=0.01578 	 val_loss=0.01571 	 sm_loss=0.01594 	 sm_val_loss=0.01587 	 time=0.56s
# Best: Epoch 10 	 loss=0.01567 	 val_loss=0.01566 	 sm_loss=0.01584 	 sm_val_loss=0.01583 	 time=0.56s
# Best: Epoch 12 	 loss=0.01564 	 val_loss=0.01564 	 sm_loss=0.01581 	 sm_val_loss=0.01580 	 time=0.58s
# Best: Epoch 13 	 loss=0.01560 	 val_loss=0.01558 	 sm_loss=0.01578 	 sm_val_loss=0.01575 	 time=0.59s
# Best: Epoch 14 	 loss=0.01555 	 val_loss=0.01554 	 sm_loss=0.01573 	 sm_val_loss=0.01570 	 time=0.60s
# Best: Epoch 15 	 loss=0.01547 	 val_loss=0.01552 	 sm_loss=0.01565 	 sm_val_loss=0.01568 	 time=0.58s
# Best: Epoch 16 	 loss=0.01540 	 val_loss=0.01544 	 sm_loss=0.01558 	 sm_val_loss=0.01562 	 time=0.58s
# Best: Epoch 17 	 loss=0.01531 	 val_loss=0.01541 	 sm_loss=0.01549 	 sm_val_loss=0.01559 	 time=0.58s
# Best: Epoch 18 	 loss=0.01530 	 val_loss=0.01538 	 sm_loss=0.01548 	 sm_val_loss=0.01556 	 time=0.58s
# Best: Epoch 20 	 loss=0.01521 	 val_loss=0.01538 	 sm_loss=0.01539 	 sm_val_loss=0.01555 	 time=0.78s
# Fold 5 log loss: 0.015557088412021853
# Seed 1
# Fold 1 log loss: 0.01572792230806568
# Fold 2 log loss: 0.01567113099101501
# Fold 3 log loss: 0.015362327927999214
# Fold 4 log loss: 0.01550433616794346
# Fold 5 log loss: 0.015557088412021853
# Std of log loss: 0.0001285497299382178
# Total log loss: 0.01556455664632429
# Fold 1
# Best: Epoch 1 	 loss=0.16892 	 val_loss=0.02030 	 sm_loss=0.16892 	 sm_val_loss=0.02029 	 time=0.58s
# Best: Epoch 2 	 loss=0.01852 	 val_loss=0.01705 	 sm_loss=0.01853 	 sm_val_loss=0.01708 	 time=0.59s
# Best: Epoch 3 	 loss=0.01678 	 val_loss=0.01632 	 sm_loss=0.01683 	 sm_val_loss=0.01639 	 time=0.57s
# Best: Epoch 4 	 loss=0.01637 	 val_loss=0.01608 	 sm_loss=0.01645 	 sm_val_loss=0.01619 	 time=0.58s
# Best: Epoch 5 	 loss=0.01612 	 val_loss=0.01593 	 sm_loss=0.01623 	 sm_val_loss=0.01604 	 time=0.57s
# Best: Epoch 6 	 loss=0.01601 	 val_loss=0.01589 	 sm_loss=0.01614 	 sm_val_loss=0.01602 	 time=0.57s
# Best: Epoch 7 	 loss=0.01595 	 val_loss=0.01582 	 sm_loss=0.01609 	 sm_val_loss=0.01596 	 time=0.57s
# Best: Epoch 9 	 loss=0.01590 	 val_loss=0.01575 	 sm_loss=0.01606 	 sm_val_loss=0.01591 	 time=0.58s
# Best: Epoch 11 	 loss=0.01581 	 val_loss=0.01567 	 sm_loss=0.01598 	 sm_val_loss=0.01582 	 time=0.81s
# Best: Epoch 13 	 loss=0.01579 	 val_loss=0.01564 	 sm_loss=0.01596 	 sm_val_loss=0.01580 	 time=0.57s
# Best: Epoch 15 	 loss=0.01563 	 val_loss=0.01556 	 sm_loss=0.01580 	 sm_val_loss=0.01573 	 time=0.59s
# Best: Epoch 16 	 loss=0.01556 	 val_loss=0.01554 	 sm_loss=0.01574 	 sm_val_loss=0.01570 	 time=0.57s
# Best: Epoch 17 	 loss=0.01553 	 val_loss=0.01553 	 sm_loss=0.01570 	 sm_val_loss=0.01570 	 time=0.58s
# Best: Epoch 18 	 loss=0.01544 	 val_loss=0.01548 	 sm_loss=0.01562 	 sm_val_loss=0.01564 	 time=0.58s
# Best: Epoch 19 	 loss=0.01539 	 val_loss=0.01544 	 sm_loss=0.01556 	 sm_val_loss=0.01561 	 time=0.85s
# Fold 1 log loss: 0.01571403291530887
# Fold 2
# Best: Epoch 1 	 loss=0.17006 	 val_loss=0.02023 	 sm_loss=0.17005 	 sm_val_loss=0.02022 	 time=0.58s
# Best: Epoch 2 	 loss=0.01847 	 val_loss=0.01695 	 sm_loss=0.01848 	 sm_val_loss=0.01698 	 time=0.58s
# Best: Epoch 3 	 loss=0.01685 	 val_loss=0.01623 	 sm_loss=0.01689 	 sm_val_loss=0.01630 	 time=0.64s
# Best: Epoch 4 	 loss=0.01640 	 val_loss=0.01599 	 sm_loss=0.01648 	 sm_val_loss=0.01609 	 time=0.98s
# Best: Epoch 5 	 loss=0.01618 	 val_loss=0.01595 	 sm_loss=0.01629 	 sm_val_loss=0.01608 	 time=0.76s
# Best: Epoch 6 	 loss=0.01610 	 val_loss=0.01589 	 sm_loss=0.01623 	 sm_val_loss=0.01603 	 time=0.76s
# Best: Epoch 7 	 loss=0.01599 	 val_loss=0.01576 	 sm_loss=0.01613 	 sm_val_loss=0.01591 	 time=0.60s
# Best: Epoch 10 	 loss=0.01592 	 val_loss=0.01572 	 sm_loss=0.01608 	 sm_val_loss=0.01588 	 time=0.58s
# Best: Epoch 13 	 loss=0.01578 	 val_loss=0.01565 	 sm_loss=0.01595 	 sm_val_loss=0.01582 	 time=0.57s
# Best: Epoch 14 	 loss=0.01578 	 val_loss=0.01564 	 sm_loss=0.01595 	 sm_val_loss=0.01580 	 time=0.63s
# Best: Epoch 15 	 loss=0.01569 	 val_loss=0.01557 	 sm_loss=0.01586 	 sm_val_loss=0.01573 	 time=0.61s
# Best: Epoch 16 	 loss=0.01563 	 val_loss=0.01550 	 sm_loss=0.01580 	 sm_val_loss=0.01567 	 time=0.65s
# Best: Epoch 17 	 loss=0.01556 	 val_loss=0.01550 	 sm_loss=0.01573 	 sm_val_loss=0.01567 	 time=0.59s
# Best: Epoch 18 	 loss=0.01549 	 val_loss=0.01546 	 sm_loss=0.01567 	 sm_val_loss=0.01563 	 time=0.60s
# Best: Epoch 19 	 loss=0.01543 	 val_loss=0.01546 	 sm_loss=0.01561 	 sm_val_loss=0.01563 	 time=0.60s
# Fold 2 log loss: 0.015683343114263774
# Fold 3
# Best: Epoch 1 	 loss=0.16897 	 val_loss=0.02036 	 sm_loss=0.16896 	 sm_val_loss=0.02035 	 time=0.58s
# Best: Epoch 2 	 loss=0.01851 	 val_loss=0.01686 	 sm_loss=0.01851 	 sm_val_loss=0.01688 	 time=0.61s
# Best: Epoch 3 	 loss=0.01679 	 val_loss=0.01612 	 sm_loss=0.01683 	 sm_val_loss=0.01618 	 time=0.59s
# Best: Epoch 4 	 loss=0.01634 	 val_loss=0.01584 	 sm_loss=0.01642 	 sm_val_loss=0.01593 	 time=0.58s
# Best: Epoch 5 	 loss=0.01618 	 val_loss=0.01564 	 sm_loss=0.01628 	 sm_val_loss=0.01576 	 time=0.57s
# Best: Epoch 6 	 loss=0.01602 	 val_loss=0.01561 	 sm_loss=0.01615 	 sm_val_loss=0.01574 	 time=0.57s
# Best: Epoch 9 	 loss=0.01592 	 val_loss=0.01554 	 sm_loss=0.01608 	 sm_val_loss=0.01571 	 time=0.57s
# Best: Epoch 10 	 loss=0.01587 	 val_loss=0.01549 	 sm_loss=0.01603 	 sm_val_loss=0.01565 	 time=0.73s
# Best: Epoch 11 	 loss=0.01584 	 val_loss=0.01548 	 sm_loss=0.01600 	 sm_val_loss=0.01563 	 time=0.60s
# Best: Epoch 12 	 loss=0.01581 	 val_loss=0.01540 	 sm_loss=0.01598 	 sm_val_loss=0.01557 	 time=0.58s
# Best: Epoch 14 	 loss=0.01576 	 val_loss=0.01535 	 sm_loss=0.01593 	 sm_val_loss=0.01552 	 time=0.56s
# Best: Epoch 15 	 loss=0.01572 	 val_loss=0.01535 	 sm_loss=0.01588 	 sm_val_loss=0.01551 	 time=0.57s
# Best: Epoch 16 	 loss=0.01563 	 val_loss=0.01531 	 sm_loss=0.01580 	 sm_val_loss=0.01548 	 time=0.76s
# Best: Epoch 17 	 loss=0.01549 	 val_loss=0.01526 	 sm_loss=0.01566 	 sm_val_loss=0.01543 	 time=0.67s
# Best: Epoch 18 	 loss=0.01547 	 val_loss=0.01519 	 sm_loss=0.01564 	 sm_val_loss=0.01536 	 time=0.61s
# Best: Epoch 19 	 loss=0.01542 	 val_loss=0.01519 	 sm_loss=0.01560 	 sm_val_loss=0.01536 	 time=0.69s
# Fold 3 log loss: 0.015361647376247135
# Fold 4
# Best: Epoch 1 	 loss=0.17027 	 val_loss=0.02024 	 sm_loss=0.17027 	 sm_val_loss=0.02023 	 time=0.57s
# Best: Epoch 2 	 loss=0.01857 	 val_loss=0.01689 	 sm_loss=0.01857 	 sm_val_loss=0.01691 	 time=0.57s
# Best: Epoch 3 	 loss=0.01688 	 val_loss=0.01610 	 sm_loss=0.01693 	 sm_val_loss=0.01617 	 time=0.57s
# Best: Epoch 4 	 loss=0.01645 	 val_loss=0.01585 	 sm_loss=0.01653 	 sm_val_loss=0.01595 	 time=0.59s
# Best: Epoch 6 	 loss=0.01611 	 val_loss=0.01575 	 sm_loss=0.01624 	 sm_val_loss=0.01588 	 time=0.57s
# Best: Epoch 7 	 loss=0.01603 	 val_loss=0.01571 	 sm_loss=0.01617 	 sm_val_loss=0.01585 	 time=0.58s
# Best: Epoch 8 	 loss=0.01600 	 val_loss=0.01562 	 sm_loss=0.01615 	 sm_val_loss=0.01577 	 time=0.58s
# Best: Epoch 10 	 loss=0.01591 	 val_loss=0.01559 	 sm_loss=0.01607 	 sm_val_loss=0.01574 	 time=0.66s
# Best: Epoch 11 	 loss=0.01594 	 val_loss=0.01554 	 sm_loss=0.01610 	 sm_val_loss=0.01570 	 time=0.72s
# Best: Epoch 14 	 loss=0.01573 	 val_loss=0.01546 	 sm_loss=0.01590 	 sm_val_loss=0.01563 	 time=0.56s
# Best: Epoch 15 	 loss=0.01569 	 val_loss=0.01542 	 sm_loss=0.01587 	 sm_val_loss=0.01559 	 time=0.58s
# Best: Epoch 16 	 loss=0.01563 	 val_loss=0.01541 	 sm_loss=0.01580 	 sm_val_loss=0.01557 	 time=0.58s
# Best: Epoch 17 	 loss=0.01557 	 val_loss=0.01534 	 sm_loss=0.01575 	 sm_val_loss=0.01551 	 time=0.58s
# Best: Epoch 18 	 loss=0.01552 	 val_loss=0.01529 	 sm_loss=0.01570 	 sm_val_loss=0.01546 	 time=0.57s
# Best: Epoch 20 	 loss=0.01544 	 val_loss=0.01527 	 sm_loss=0.01562 	 sm_val_loss=0.01545 	 time=0.57s
# Fold 4 log loss: 0.015503967271175255
# Fold 5
# Best: Epoch 1 	 loss=0.16785 	 val_loss=0.02025 	 sm_loss=0.16784 	 sm_val_loss=0.02024 	 time=0.57s
# Best: Epoch 2 	 loss=0.01834 	 val_loss=0.01690 	 sm_loss=0.01835 	 sm_val_loss=0.01693 	 time=0.57s
# Best: Epoch 3 	 loss=0.01666 	 val_loss=0.01621 	 sm_loss=0.01671 	 sm_val_loss=0.01629 	 time=0.58s
# Best: Epoch 4 	 loss=0.01618 	 val_loss=0.01596 	 sm_loss=0.01626 	 sm_val_loss=0.01607 	 time=0.58s
# Best: Epoch 5 	 loss=0.01597 	 val_loss=0.01582 	 sm_loss=0.01609 	 sm_val_loss=0.01595 	 time=0.61s
# Best: Epoch 6 	 loss=0.01588 	 val_loss=0.01581 	 sm_loss=0.01601 	 sm_val_loss=0.01595 	 time=0.78s
# Best: Epoch 7 	 loss=0.01580 	 val_loss=0.01576 	 sm_loss=0.01595 	 sm_val_loss=0.01591 	 time=0.60s
# Best: Epoch 9 	 loss=0.01574 	 val_loss=0.01573 	 sm_loss=0.01590 	 sm_val_loss=0.01590 	 time=0.59s
# Best: Epoch 11 	 loss=0.01569 	 val_loss=0.01564 	 sm_loss=0.01585 	 sm_val_loss=0.01581 	 time=0.58s
# Best: Epoch 12 	 loss=0.01560 	 val_loss=0.01563 	 sm_loss=0.01577 	 sm_val_loss=0.01580 	 time=0.58s
# Best: Epoch 13 	 loss=0.01563 	 val_loss=0.01557 	 sm_loss=0.01581 	 sm_val_loss=0.01575 	 time=0.58s
# Best: Epoch 14 	 loss=0.01555 	 val_loss=0.01555 	 sm_loss=0.01572 	 sm_val_loss=0.01571 	 time=0.57s
# Best: Epoch 16 	 loss=0.01545 	 val_loss=0.01548 	 sm_loss=0.01563 	 sm_val_loss=0.01566 	 time=0.57s
# Best: Epoch 17 	 loss=0.01535 	 val_loss=0.01542 	 sm_loss=0.01553 	 sm_val_loss=0.01559 	 time=0.58s
# Best: Epoch 18 	 loss=0.01529 	 val_loss=0.01538 	 sm_loss=0.01547 	 sm_val_loss=0.01556 	 time=0.58s
# Best: Epoch 20 	 loss=0.01517 	 val_loss=0.01537 	 sm_loss=0.01536 	 sm_val_loss=0.01554 	 time=0.58s
# Fold 5 log loss: 0.015547119681466796
# Seed 2
# Fold 1 log loss: 0.01571403291530887
# Fold 2 log loss: 0.015683343114263774
# Fold 3 log loss: 0.015361647376247135
# Fold 4 log loss: 0.015503967271175255
# Fold 5 log loss: 0.015547119681466796
# Std of log loss: 0.00012772513583465117
# Total log loss: 0.015562017223020398
# Fold 1
# Best: Epoch 1 	 loss=0.17068 	 val_loss=0.02033 	 sm_loss=0.17068 	 sm_val_loss=0.02032 	 time=0.84s
# Best: Epoch 2 	 loss=0.01856 	 val_loss=0.01692 	 sm_loss=0.01857 	 sm_val_loss=0.01695 	 time=1.03s
# Best: Epoch 3 	 loss=0.01685 	 val_loss=0.01626 	 sm_loss=0.01690 	 sm_val_loss=0.01633 	 time=0.61s
# Best: Epoch 4 	 loss=0.01632 	 val_loss=0.01601 	 sm_loss=0.01641 	 sm_val_loss=0.01611 	 time=0.59s
# Best: Epoch 5 	 loss=0.01614 	 val_loss=0.01595 	 sm_loss=0.01625 	 sm_val_loss=0.01607 	 time=0.58s
# Best: Epoch 6 	 loss=0.01601 	 val_loss=0.01585 	 sm_loss=0.01614 	 sm_val_loss=0.01599 	 time=0.60s
# Best: Epoch 7 	 loss=0.01598 	 val_loss=0.01582 	 sm_loss=0.01612 	 sm_val_loss=0.01597 	 time=0.57s
# Best: Epoch 8 	 loss=0.01594 	 val_loss=0.01581 	 sm_loss=0.01609 	 sm_val_loss=0.01596 	 time=0.67s
# Best: Epoch 10 	 loss=0.01588 	 val_loss=0.01574 	 sm_loss=0.01604 	 sm_val_loss=0.01590 	 time=0.59s
# Best: Epoch 11 	 loss=0.01583 	 val_loss=0.01570 	 sm_loss=0.01600 	 sm_val_loss=0.01587 	 time=0.60s
# Best: Epoch 13 	 loss=0.01576 	 val_loss=0.01571 	 sm_loss=0.01593 	 sm_val_loss=0.01586 	 time=0.75s
# Best: Epoch 14 	 loss=0.01568 	 val_loss=0.01559 	 sm_loss=0.01585 	 sm_val_loss=0.01575 	 time=0.60s
# Best: Epoch 15 	 loss=0.01564 	 val_loss=0.01557 	 sm_loss=0.01581 	 sm_val_loss=0.01573 	 time=0.60s
# Best: Epoch 16 	 loss=0.01560 	 val_loss=0.01550 	 sm_loss=0.01577 	 sm_val_loss=0.01568 	 time=0.66s
# Best: Epoch 17 	 loss=0.01554 	 val_loss=0.01549 	 sm_loss=0.01571 	 sm_val_loss=0.01565 	 time=0.64s
# Best: Epoch 18 	 loss=0.01548 	 val_loss=0.01547 	 sm_loss=0.01566 	 sm_val_loss=0.01563 	 time=0.59s
# Best: Epoch 19 	 loss=0.01540 	 val_loss=0.01546 	 sm_loss=0.01558 	 sm_val_loss=0.01562 	 time=0.62s
# Fold 1 log loss: 0.0157246310681496
# Fold 2
# Best: Epoch 1 	 loss=0.16834 	 val_loss=0.02032 	 sm_loss=0.16834 	 sm_val_loss=0.02031 	 time=0.59s
# Best: Epoch 2 	 loss=0.01852 	 val_loss=0.01701 	 sm_loss=0.01853 	 sm_val_loss=0.01704 	 time=0.59s
# Best: Epoch 3 	 loss=0.01686 	 val_loss=0.01628 	 sm_loss=0.01690 	 sm_val_loss=0.01636 	 time=0.58s
# Best: Epoch 4 	 loss=0.01644 	 val_loss=0.01607 	 sm_loss=0.01652 	 sm_val_loss=0.01617 	 time=0.59s
# Best: Epoch 5 	 loss=0.01617 	 val_loss=0.01597 	 sm_loss=0.01629 	 sm_val_loss=0.01609 	 time=0.58s
# Best: Epoch 6 	 loss=0.01608 	 val_loss=0.01587 	 sm_loss=0.01621 	 sm_val_loss=0.01601 	 time=0.59s
# Best: Epoch 7 	 loss=0.01605 	 val_loss=0.01584 	 sm_loss=0.01620 	 sm_val_loss=0.01597 	 time=0.83s
# Best: Epoch 9 	 loss=0.01597 	 val_loss=0.01581 	 sm_loss=0.01612 	 sm_val_loss=0.01596 	 time=0.61s
# Best: Epoch 10 	 loss=0.01591 	 val_loss=0.01575 	 sm_loss=0.01608 	 sm_val_loss=0.01592 	 time=0.62s
# Best: Epoch 11 	 loss=0.01590 	 val_loss=0.01571 	 sm_loss=0.01606 	 sm_val_loss=0.01587 	 time=0.60s
# Best: Epoch 12 	 loss=0.01585 	 val_loss=0.01564 	 sm_loss=0.01601 	 sm_val_loss=0.01581 	 time=0.61s
# Best: Epoch 14 	 loss=0.01577 	 val_loss=0.01559 	 sm_loss=0.01594 	 sm_val_loss=0.01576 	 time=0.57s
# Best: Epoch 15 	 loss=0.01569 	 val_loss=0.01556 	 sm_loss=0.01586 	 sm_val_loss=0.01573 	 time=0.58s
# Best: Epoch 16 	 loss=0.01565 	 val_loss=0.01552 	 sm_loss=0.01583 	 sm_val_loss=0.01569 	 time=0.58s
# Best: Epoch 17 	 loss=0.01552 	 val_loss=0.01549 	 sm_loss=0.01569 	 sm_val_loss=0.01566 	 time=0.60s
# Best: Epoch 18 	 loss=0.01549 	 val_loss=0.01544 	 sm_loss=0.01567 	 sm_val_loss=0.01561 	 time=0.57s
# Fold 2 log loss: 0.015668037739806028
# Fold 3
# Best: Epoch 1 	 loss=0.16928 	 val_loss=0.02024 	 sm_loss=0.16927 	 sm_val_loss=0.02023 	 time=0.67s
# Best: Epoch 2 	 loss=0.01851 	 val_loss=0.01678 	 sm_loss=0.01852 	 sm_val_loss=0.01681 	 time=0.72s
# Best: Epoch 3 	 loss=0.01679 	 val_loss=0.01608 	 sm_loss=0.01683 	 sm_val_loss=0.01614 	 time=0.59s
# Best: Epoch 4 	 loss=0.01635 	 val_loss=0.01589 	 sm_loss=0.01643 	 sm_val_loss=0.01599 	 time=0.60s
# Best: Epoch 5 	 loss=0.01617 	 val_loss=0.01568 	 sm_loss=0.01628 	 sm_val_loss=0.01581 	 time=0.79s
# Best: Epoch 6 	 loss=0.01605 	 val_loss=0.01563 	 sm_loss=0.01617 	 sm_val_loss=0.01577 	 time=0.64s
# Best: Epoch 7 	 loss=0.01604 	 val_loss=0.01549 	 sm_loss=0.01618 	 sm_val_loss=0.01565 	 time=0.57s
# Best: Epoch 9 	 loss=0.01592 	 val_loss=0.01546 	 sm_loss=0.01608 	 sm_val_loss=0.01563 	 time=0.56s
# Best: Epoch 11 	 loss=0.01585 	 val_loss=0.01546 	 sm_loss=0.01601 	 sm_val_loss=0.01562 	 time=0.58s
# Best: Epoch 12 	 loss=0.01577 	 val_loss=0.01543 	 sm_loss=0.01593 	 sm_val_loss=0.01560 	 time=0.58s
# Best: Epoch 13 	 loss=0.01578 	 val_loss=0.01543 	 sm_loss=0.01595 	 sm_val_loss=0.01559 	 time=0.57s
# Best: Epoch 14 	 loss=0.01570 	 val_loss=0.01538 	 sm_loss=0.01587 	 sm_val_loss=0.01554 	 time=0.57s
# Best: Epoch 15 	 loss=0.01564 	 val_loss=0.01530 	 sm_loss=0.01581 	 sm_val_loss=0.01546 	 time=0.57s
# Best: Epoch 17 	 loss=0.01559 	 val_loss=0.01524 	 sm_loss=0.01576 	 sm_val_loss=0.01541 	 time=0.57s
# Best: Epoch 18 	 loss=0.01551 	 val_loss=0.01519 	 sm_loss=0.01568 	 sm_val_loss=0.01536 	 time=0.59s
# Best: Epoch 19 	 loss=0.01544 	 val_loss=0.01519 	 sm_loss=0.01561 	 sm_val_loss=0.01536 	 time=0.94s
# Best: Epoch 20 	 loss=0.01539 	 val_loss=0.01518 	 sm_loss=0.01556 	 sm_val_loss=0.01535 	 time=0.60s
# Fold 3 log loss: 0.015356431581992406
# Fold 4
# Best: Epoch 1 	 loss=0.16863 	 val_loss=0.02029 	 sm_loss=0.16862 	 sm_val_loss=0.02028 	 time=0.57s
# Best: Epoch 2 	 loss=0.01857 	 val_loss=0.01685 	 sm_loss=0.01857 	 sm_val_loss=0.01688 	 time=0.57s
# Best: Epoch 3 	 loss=0.01687 	 val_loss=0.01615 	 sm_loss=0.01692 	 sm_val_loss=0.01622 	 time=0.57s
# Best: Epoch 4 	 loss=0.01641 	 val_loss=0.01589 	 sm_loss=0.01650 	 sm_val_loss=0.01598 	 time=0.63s
# Best: Epoch 5 	 loss=0.01620 	 val_loss=0.01582 	 sm_loss=0.01631 	 sm_val_loss=0.01594 	 time=0.59s
# Best: Epoch 6 	 loss=0.01606 	 val_loss=0.01568 	 sm_loss=0.01619 	 sm_val_loss=0.01582 	 time=0.57s
# Best: Epoch 7 	 loss=0.01602 	 val_loss=0.01560 	 sm_loss=0.01617 	 sm_val_loss=0.01575 	 time=0.58s
# Best: Epoch 8 	 loss=0.01597 	 val_loss=0.01559 	 sm_loss=0.01612 	 sm_val_loss=0.01574 	 time=0.57s
# Best: Epoch 9 	 loss=0.01594 	 val_loss=0.01557 	 sm_loss=0.01610 	 sm_val_loss=0.01573 	 time=0.57s
# Best: Epoch 10 	 loss=0.01591 	 val_loss=0.01556 	 sm_loss=0.01607 	 sm_val_loss=0.01572 	 time=0.57s
# Best: Epoch 13 	 loss=0.01580 	 val_loss=0.01546 	 sm_loss=0.01596 	 sm_val_loss=0.01564 	 time=0.57s
# Best: Epoch 15 	 loss=0.01575 	 val_loss=0.01545 	 sm_loss=0.01592 	 sm_val_loss=0.01561 	 time=0.57s
# Best: Epoch 16 	 loss=0.01563 	 val_loss=0.01533 	 sm_loss=0.01580 	 sm_val_loss=0.01550 	 time=0.57s
# Best: Epoch 18 	 loss=0.01549 	 val_loss=0.01531 	 sm_loss=0.01567 	 sm_val_loss=0.01548 	 time=0.58s
# Best: Epoch 20 	 loss=0.01545 	 val_loss=0.01529 	 sm_loss=0.01563 	 sm_val_loss=0.01546 	 time=0.61s
# Fold 4 log loss: 0.01552091083412295
# Fold 5
# Best: Epoch 1 	 loss=0.16941 	 val_loss=0.02030 	 sm_loss=0.16940 	 sm_val_loss=0.02030 	 time=0.58s
# Best: Epoch 2 	 loss=0.01837 	 val_loss=0.01692 	 sm_loss=0.01838 	 sm_val_loss=0.01695 	 time=0.57s
# Best: Epoch 3 	 loss=0.01661 	 val_loss=0.01618 	 sm_loss=0.01665 	 sm_val_loss=0.01625 	 time=0.57s
# Best: Epoch 4 	 loss=0.01618 	 val_loss=0.01595 	 sm_loss=0.01627 	 sm_val_loss=0.01605 	 time=0.58s
# Best: Epoch 5 	 loss=0.01596 	 val_loss=0.01581 	 sm_loss=0.01608 	 sm_val_loss=0.01593 	 time=0.57s
# Best: Epoch 7 	 loss=0.01582 	 val_loss=0.01575 	 sm_loss=0.01597 	 sm_val_loss=0.01590 	 time=0.85s
# Best: Epoch 8 	 loss=0.01584 	 val_loss=0.01567 	 sm_loss=0.01599 	 sm_val_loss=0.01585 	 time=0.82s
# Best: Epoch 10 	 loss=0.01571 	 val_loss=0.01566 	 sm_loss=0.01588 	 sm_val_loss=0.01583 	 time=0.74s
# Best: Epoch 11 	 loss=0.01569 	 val_loss=0.01565 	 sm_loss=0.01586 	 sm_val_loss=0.01582 	 time=0.61s
# Best: Epoch 12 	 loss=0.01564 	 val_loss=0.01562 	 sm_loss=0.01581 	 sm_val_loss=0.01578 	 time=0.65s
# Best: Epoch 13 	 loss=0.01558 	 val_loss=0.01558 	 sm_loss=0.01576 	 sm_val_loss=0.01575 	 time=0.57s
# Best: Epoch 14 	 loss=0.01558 	 val_loss=0.01556 	 sm_loss=0.01575 	 sm_val_loss=0.01574 	 time=0.61s
# Best: Epoch 15 	 loss=0.01547 	 val_loss=0.01549 	 sm_loss=0.01564 	 sm_val_loss=0.01567 	 time=0.64s
# Best: Epoch 16 	 loss=0.01541 	 val_loss=0.01547 	 sm_loss=0.01559 	 sm_val_loss=0.01565 	 time=0.61s
# Best: Epoch 17 	 loss=0.01534 	 val_loss=0.01541 	 sm_loss=0.01552 	 sm_val_loss=0.01558 	 time=0.67s
# Best: Epoch 19 	 loss=0.01527 	 val_loss=0.01538 	 sm_loss=0.01546 	 sm_val_loss=0.01556 	 time=0.62s
# Best: Epoch 20 	 loss=0.01517 	 val_loss=0.01538 	 sm_loss=0.01535 	 sm_val_loss=0.01555 	 time=0.72s
# Fold 5 log loss: 0.015561157727627657
# Seed 3
# Fold 1 log loss: 0.0157246310681496
# Fold 2 log loss: 0.015668037739806028
# Fold 3 log loss: 0.015356431581992406
# Fold 4 log loss: 0.01552091083412295
# Fold 5 log loss: 0.015561157727627657
# Std of log loss: 0.0001277111155262632
# Total log loss: 0.015566229383200732
# Fold 1
# Best: Epoch 1 	 loss=0.16891 	 val_loss=0.02028 	 sm_loss=0.16891 	 sm_val_loss=0.02028 	 time=0.58s
# Best: Epoch 2 	 loss=0.01849 	 val_loss=0.01705 	 sm_loss=0.01850 	 sm_val_loss=0.01707 	 time=0.58s
# Best: Epoch 3 	 loss=0.01677 	 val_loss=0.01629 	 sm_loss=0.01682 	 sm_val_loss=0.01636 	 time=0.57s
# Best: Epoch 4 	 loss=0.01633 	 val_loss=0.01602 	 sm_loss=0.01641 	 sm_val_loss=0.01613 	 time=0.59s
# Best: Epoch 6 	 loss=0.01602 	 val_loss=0.01592 	 sm_loss=0.01615 	 sm_val_loss=0.01605 	 time=0.58s
# Best: Epoch 7 	 loss=0.01597 	 val_loss=0.01578 	 sm_loss=0.01611 	 sm_val_loss=0.01593 	 time=0.58s
# Best: Epoch 10 	 loss=0.01588 	 val_loss=0.01572 	 sm_loss=0.01604 	 sm_val_loss=0.01589 	 time=0.58s
# Best: Epoch 11 	 loss=0.01587 	 val_loss=0.01571 	 sm_loss=0.01603 	 sm_val_loss=0.01587 	 time=0.59s
# Best: Epoch 12 	 loss=0.01579 	 val_loss=0.01566 	 sm_loss=0.01596 	 sm_val_loss=0.01582 	 time=0.59s
# Best: Epoch 14 	 loss=0.01568 	 val_loss=0.01563 	 sm_loss=0.01585 	 sm_val_loss=0.01579 	 time=0.67s
# Best: Epoch 15 	 loss=0.01569 	 val_loss=0.01556 	 sm_loss=0.01586 	 sm_val_loss=0.01573 	 time=0.72s
# Best: Epoch 16 	 loss=0.01556 	 val_loss=0.01556 	 sm_loss=0.01574 	 sm_val_loss=0.01572 	 time=0.61s
# Best: Epoch 17 	 loss=0.01550 	 val_loss=0.01551 	 sm_loss=0.01567 	 sm_val_loss=0.01569 	 time=0.60s
# Best: Epoch 18 	 loss=0.01545 	 val_loss=0.01545 	 sm_loss=0.01563 	 sm_val_loss=0.01562 	 time=0.60s
# Best: Epoch 19 	 loss=0.01537 	 val_loss=0.01545 	 sm_loss=0.01555 	 sm_val_loss=0.01562 	 time=0.58s
# Best: Epoch 20 	 loss=0.01539 	 val_loss=0.01544 	 sm_loss=0.01557 	 sm_val_loss=0.01561 	 time=0.59s
# Fold 1 log loss: 0.015715186550735775
# Fold 2
# Best: Epoch 1 	 loss=0.17147 	 val_loss=0.02032 	 sm_loss=0.17146 	 sm_val_loss=0.02031 	 time=0.57s
# Best: Epoch 2 	 loss=0.01850 	 val_loss=0.01699 	 sm_loss=0.01850 	 sm_val_loss=0.01701 	 time=0.57s
# Best: Epoch 3 	 loss=0.01688 	 val_loss=0.01629 	 sm_loss=0.01693 	 sm_val_loss=0.01636 	 time=0.57s
# Best: Epoch 4 	 loss=0.01640 	 val_loss=0.01606 	 sm_loss=0.01648 	 sm_val_loss=0.01615 	 time=0.57s
# Best: Epoch 5 	 loss=0.01617 	 val_loss=0.01587 	 sm_loss=0.01628 	 sm_val_loss=0.01599 	 time=0.60s
# Best: Epoch 7 	 loss=0.01605 	 val_loss=0.01584 	 sm_loss=0.01619 	 sm_val_loss=0.01599 	 time=0.56s
# Best: Epoch 9 	 loss=0.01595 	 val_loss=0.01578 	 sm_loss=0.01610 	 sm_val_loss=0.01593 	 time=0.70s
# Best: Epoch 10 	 loss=0.01596 	 val_loss=0.01572 	 sm_loss=0.01612 	 sm_val_loss=0.01589 	 time=1.15s
# Best: Epoch 11 	 loss=0.01588 	 val_loss=0.01571 	 sm_loss=0.01604 	 sm_val_loss=0.01587 	 time=0.58s
# Best: Epoch 12 	 loss=0.01589 	 val_loss=0.01566 	 sm_loss=0.01605 	 sm_val_loss=0.01582 	 time=0.59s
# Best: Epoch 14 	 loss=0.01573 	 val_loss=0.01562 	 sm_loss=0.01590 	 sm_val_loss=0.01578 	 time=0.56s
# Best: Epoch 15 	 loss=0.01567 	 val_loss=0.01560 	 sm_loss=0.01584 	 sm_val_loss=0.01576 	 time=0.57s
# Best: Epoch 16 	 loss=0.01561 	 val_loss=0.01552 	 sm_loss=0.01578 	 sm_val_loss=0.01569 	 time=0.57s
# Best: Epoch 18 	 loss=0.01552 	 val_loss=0.01545 	 sm_loss=0.01569 	 sm_val_loss=0.01562 	 time=0.57s
# Fold 2 log loss: 0.015671060615937076
# Fold 3
# Best: Epoch 1 	 loss=0.17112 	 val_loss=0.02035 	 sm_loss=0.17111 	 sm_val_loss=0.02034 	 time=0.56s
# Best: Epoch 2 	 loss=0.01848 	 val_loss=0.01680 	 sm_loss=0.01848 	 sm_val_loss=0.01682 	 time=0.58s
# Best: Epoch 3 	 loss=0.01683 	 val_loss=0.01611 	 sm_loss=0.01687 	 sm_val_loss=0.01617 	 time=0.57s
# Best: Epoch 4 	 loss=0.01633 	 val_loss=0.01579 	 sm_loss=0.01641 	 sm_val_loss=0.01589 	 time=0.80s
# Best: Epoch 5 	 loss=0.01616 	 val_loss=0.01572 	 sm_loss=0.01626 	 sm_val_loss=0.01584 	 time=0.58s
# Best: Epoch 6 	 loss=0.01610 	 val_loss=0.01561 	 sm_loss=0.01623 	 sm_val_loss=0.01575 	 time=0.57s
# Best: Epoch 7 	 loss=0.01598 	 val_loss=0.01554 	 sm_loss=0.01612 	 sm_val_loss=0.01569 	 time=0.58s
# Best: Epoch 9 	 loss=0.01593 	 val_loss=0.01549 	 sm_loss=0.01609 	 sm_val_loss=0.01565 	 time=0.56s
# Best: Epoch 10 	 loss=0.01588 	 val_loss=0.01544 	 sm_loss=0.01603 	 sm_val_loss=0.01561 	 time=0.58s
# Best: Epoch 11 	 loss=0.01586 	 val_loss=0.01543 	 sm_loss=0.01602 	 sm_val_loss=0.01560 	 time=0.59s
# Best: Epoch 12 	 loss=0.01585 	 val_loss=0.01536 	 sm_loss=0.01601 	 sm_val_loss=0.01552 	 time=0.58s
# Best: Epoch 15 	 loss=0.01569 	 val_loss=0.01534 	 sm_loss=0.01586 	 sm_val_loss=0.01551 	 time=0.57s
# Best: Epoch 16 	 loss=0.01563 	 val_loss=0.01526 	 sm_loss=0.01580 	 sm_val_loss=0.01543 	 time=0.57s
# Best: Epoch 17 	 loss=0.01552 	 val_loss=0.01524 	 sm_loss=0.01570 	 sm_val_loss=0.01540 	 time=0.58s
# Best: Epoch 18 	 loss=0.01546 	 val_loss=0.01521 	 sm_loss=0.01563 	 sm_val_loss=0.01538 	 time=0.58s
# Best: Epoch 19 	 loss=0.01539 	 val_loss=0.01520 	 sm_loss=0.01556 	 sm_val_loss=0.01536 	 time=0.61s
# Best: Epoch 20 	 loss=0.01542 	 val_loss=0.01519 	 sm_loss=0.01560 	 sm_val_loss=0.01536 	 time=0.59s
# Fold 3 log loss: 0.015357589289354528
# Fold 4
# Best: Epoch 1 	 loss=0.17129 	 val_loss=0.02030 	 sm_loss=0.17128 	 sm_val_loss=0.02029 	 time=0.59s
# Best: Epoch 2 	 loss=0.01856 	 val_loss=0.01684 	 sm_loss=0.01857 	 sm_val_loss=0.01686 	 time=0.62s
# Best: Epoch 3 	 loss=0.01687 	 val_loss=0.01613 	 sm_loss=0.01691 	 sm_val_loss=0.01621 	 time=0.60s
# Best: Epoch 4 	 loss=0.01644 	 val_loss=0.01578 	 sm_loss=0.01652 	 sm_val_loss=0.01588 	 time=0.97s
# Best: Epoch 6 	 loss=0.01613 	 val_loss=0.01569 	 sm_loss=0.01626 	 sm_val_loss=0.01582 	 time=0.59s
# Best: Epoch 8 	 loss=0.01599 	 val_loss=0.01563 	 sm_loss=0.01615 	 sm_val_loss=0.01579 	 time=0.60s
# Best: Epoch 9 	 loss=0.01593 	 val_loss=0.01561 	 sm_loss=0.01609 	 sm_val_loss=0.01577 	 time=0.58s
# Best: Epoch 11 	 loss=0.01591 	 val_loss=0.01558 	 sm_loss=0.01607 	 sm_val_loss=0.01574 	 time=0.63s
# Best: Epoch 12 	 loss=0.01585 	 val_loss=0.01549 	 sm_loss=0.01602 	 sm_val_loss=0.01566 	 time=0.58s
# Best: Epoch 13 	 loss=0.01582 	 val_loss=0.01544 	 sm_loss=0.01599 	 sm_val_loss=0.01561 	 time=0.58s
# Best: Epoch 15 	 loss=0.01569 	 val_loss=0.01541 	 sm_loss=0.01586 	 sm_val_loss=0.01557 	 time=0.75s
# Best: Epoch 16 	 loss=0.01564 	 val_loss=0.01540 	 sm_loss=0.01582 	 sm_val_loss=0.01557 	 time=1.22s
# Best: Epoch 17 	 loss=0.01557 	 val_loss=0.01537 	 sm_loss=0.01575 	 sm_val_loss=0.01553 	 time=0.65s
# Best: Epoch 18 	 loss=0.01546 	 val_loss=0.01529 	 sm_loss=0.01563 	 sm_val_loss=0.01547 	 time=0.57s
# Best: Epoch 19 	 loss=0.01546 	 val_loss=0.01529 	 sm_loss=0.01564 	 sm_val_loss=0.01547 	 time=0.60s
# Best: Epoch 20 	 loss=0.01549 	 val_loss=0.01527 	 sm_loss=0.01567 	 sm_val_loss=0.01545 	 time=0.71s
# Fold 4 log loss: 0.015504373070327484
# Fold 5
# Best: Epoch 1 	 loss=0.16914 	 val_loss=0.02034 	 sm_loss=0.16913 	 sm_val_loss=0.02033 	 time=0.57s
# Best: Epoch 2 	 loss=0.01838 	 val_loss=0.01683 	 sm_loss=0.01839 	 sm_val_loss=0.01685 	 time=0.59s
# Best: Epoch 3 	 loss=0.01665 	 val_loss=0.01615 	 sm_loss=0.01670 	 sm_val_loss=0.01623 	 time=0.57s
# Best: Epoch 4 	 loss=0.01621 	 val_loss=0.01593 	 sm_loss=0.01630 	 sm_val_loss=0.01603 	 time=0.58s
# Best: Epoch 5 	 loss=0.01601 	 val_loss=0.01587 	 sm_loss=0.01612 	 sm_val_loss=0.01599 	 time=0.58s
# Best: Epoch 6 	 loss=0.01586 	 val_loss=0.01572 	 sm_loss=0.01600 	 sm_val_loss=0.01587 	 time=0.59s
# Best: Epoch 10 	 loss=0.01574 	 val_loss=0.01565 	 sm_loss=0.01591 	 sm_val_loss=0.01582 	 time=0.65s
# Best: Epoch 11 	 loss=0.01568 	 val_loss=0.01560 	 sm_loss=0.01585 	 sm_val_loss=0.01577 	 time=0.58s
# Best: Epoch 14 	 loss=0.01554 	 val_loss=0.01555 	 sm_loss=0.01572 	 sm_val_loss=0.01572 	 time=0.58s
# Best: Epoch 15 	 loss=0.01547 	 val_loss=0.01553 	 sm_loss=0.01565 	 sm_val_loss=0.01569 	 time=0.58s
# Best: Epoch 16 	 loss=0.01538 	 val_loss=0.01544 	 sm_loss=0.01556 	 sm_val_loss=0.01561 	 time=0.58s
# Best: Epoch 17 	 loss=0.01534 	 val_loss=0.01537 	 sm_loss=0.01552 	 sm_val_loss=0.01556 	 time=0.58s
# Best: Epoch 18 	 loss=0.01528 	 val_loss=0.01536 	 sm_loss=0.01547 	 sm_val_loss=0.01554 	 time=0.57s
# Best: Epoch 20 	 loss=0.01519 	 val_loss=0.01535 	 sm_loss=0.01537 	 sm_val_loss=0.01553 	 time=0.60s
# Fold 5 log loss: 0.015538036174470993
# Seed 4
# Fold 1 log loss: 0.015715186550735775
# Fold 2 log loss: 0.015671060615937076
# Fold 3 log loss: 0.015357589289354528
# Fold 4 log loss: 0.015504373070327484
# Fold 5 log loss: 0.015538036174470993
# Std of log loss: 0.00012722134295243122
# Total log loss: 0.015557244830045341
# Total log loss in targets: 0.01554933179713928

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.7972424596700348

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.014330928625330242

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

# %% [markdown]
# - change model architectures
# - 6 ensembles

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 34

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[vc <= 19].index.sort_values()
vc2 = vc.loc[vc > 19].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[1, 4, 5, ..., 4, 4, 5]], dtype=int8)

# %%
#non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
#nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
#nontarget_dists.columns = ["target", "number"]
#nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
#drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
#print("first drop", len(drop_list1))
#non_targets.drop(drop_list1, axis=1, inplace=True)
#print("shape after 1st drop:", non_targets.shape)
#non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
#print(len(non_target_feats))

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
#importance = pd.read_csv('../input/moa-feat-importance-rapids/output_source.csv')
#importance = importance.set_index("Feature")

#imp_scaled = importance.copy(deep=True)
#for c in imp_scaled.columns:
#    imp_scaled[c] = (1 - preprocessing.MinMaxScaler().fit_transform(imp_scaled[[c]])).round(14)

#print(imp_scaled.min().min(), imp_scaled.max().max(), imp_scaled.std().mean())

#imp_scaled["MeanImp"] = imp_scaled[target_feats].mean(axis=1)
#imp_scaled["MaxImp"]  = imp_scaled[target_feats].max(axis=1)

#thresh_mean, thresh_max = 0.35, 0.975
#fs_both = imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) & (imp_scaled.MaxImp >= thresh_max), Targets]
#fs_any = list(imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) | (imp_scaled.MaxImp >= thresh_max), target_feats].index)
#len(fs_any)

X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.7)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
print(len(drop_feats))

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)
# Out:
# 33

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 918) (3624, 918)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_non_targets = non_targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1

        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
            
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_features, num_targets):
        super(MoaModel, self).__init__()
        self.hidden_size = [2048, 1024, 512]
        self.dropout_value = [0.5, 0.35, 0.25]

        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dense1 = nn.Linear(num_features, self.hidden_size[0])
        
        self.batch_norm2 = nn.BatchNorm1d(self.hidden_size[0])
        self.dropout2 = nn.Dropout(self.dropout_value[0])
        self.dense2 = nn.Linear(self.hidden_size[0], self.hidden_size[1])

        self.batch_norm3 = nn.BatchNorm1d(self.hidden_size[1])
        self.dropout3 = nn.Dropout(self.dropout_value[1])
        self.dense3 = nn.Linear(self.hidden_size[1], self.hidden_size[2])

        self.batch_norm5 = nn.BatchNorm1d(self.hidden_size[2])
        self.dropout5 = nn.Dropout(self.dropout_value[2])
        self.dense5 = nn.utils.weight_norm(nn.Linear(self.hidden_size[2], num_targets))
        
    def forward(self, x):
        x = self.batch_norm1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))

        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.leaky_relu(self.dense3(x))

        x = self.batch_norm5(x)
        x = self.dropout5(x)
        x = self.dense5(x)
        return x
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

hidden_size = [2048, 1024, 512]
dropout_value = [0.5, 0.35, 0.25]

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    if files == []:
        train_epochs = 25
        ans = []   
    else:
        train_epochs = 20
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr[:,-1] == fold
        train_index = tr[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(tr[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index,:], dtype=torch.float32)
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, 608)

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            clf.batch_norm5 = nn.BatchNorm1d(hidden_size[2])
            clf.dropout5 = nn.Dropout(dropout_value[2])
            clf.dense5 = nn.utils.weight_norm(nn.Linear(hidden_size[-1], len(target_feats)))
            optimizer = optim.Adam(clf.parameters(), lr = 1e-3, weight_decay=3e-6) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e2, 
                                              max_lr=2e-3, epochs=train_epochs, steps_per_epoch=len(train_loader))         
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 1e-3, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))   
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-params_seed'+str(sample_seed)+'_fold'+str(fold+1)+'.pt')
                
        if files == []:
            pred_model = MoaModel(init_num, 608)
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-params_seed'+str(sample_seed)+'_fold'+str(fold+1)+'.pt'))         
        pred_model.eval()
        
        if files != []:
            # validation check ----------------
            oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
            print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
            scores.append(mean_log_loss(target_epoch, oof_epoch))
            oof[valid_index,:] = oof_epoch
            oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
            # test predcition --------------
            test_preds = np.zeros([test_len, target.shape[1]])
            for i, (x_batch,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
    
    if files != []:
        print("Seed {}".format(sample_seed))
        for i, ele in enumerate(scores):
            print("Fold {} log loss: {}".format(i+1, scores[i]))
        print("Std of log loss: {}".format(np.std(scores)))
        print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4,5] 
    
for seed_ in seeds:
    files = torch_tl(fn_train, fn_all_targets, fn_test, seed_, fn_train.shape[1]-1, [])
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.52584  val_loss=0.04305  sm_loss=0.52583  sm_val_loss=0.04300  time=1.63s
# Epoch 2  loss=0.01418  val_loss=0.01092  sm_loss=0.01414  sm_val_loss=0.01093  time=1.30s
# Epoch 3  loss=0.00999  val_loss=0.01010  sm_loss=0.01000  sm_val_loss=0.01018  time=0.96s
# Epoch 4  loss=0.00947  val_loss=0.00996  sm_loss=0.00960  sm_val_loss=0.01005  time=1.22s
# Epoch 5  loss=0.00927  val_loss=0.00994  sm_loss=0.00945  sm_val_loss=0.01003  time=0.94s
# Epoch 6  loss=0.00920  val_loss=0.00981  sm_loss=0.00940  sm_val_loss=0.00991  time=1.38s
# Epoch 11  loss=0.00921  val_loss=0.00976  sm_loss=0.00941  sm_val_loss=0.00986  time=0.95s
# Epoch 17  loss=0.00905  val_loss=0.00970  sm_loss=0.00926  sm_val_loss=0.00979  time=1.01s
# Epoch 18  loss=0.00897  val_loss=0.00963  sm_loss=0.00918  sm_val_loss=0.00974  time=0.95s
# Epoch 19  loss=0.00891  val_loss=0.00960  sm_loss=0.00913  sm_val_loss=0.00970  time=0.97s
# Epoch 20  loss=0.00880  val_loss=0.00952  sm_loss=0.00902  sm_val_loss=0.00963  time=1.19s
# Epoch 21  loss=0.00872  val_loss=0.00950  sm_loss=0.00895  sm_val_loss=0.00962  time=0.96s
# Epoch 22  loss=0.00861  val_loss=0.00943  sm_loss=0.00884  sm_val_loss=0.00955  time=0.95s
# Epoch 23  loss=0.00847  val_loss=0.00937  sm_loss=0.00872  sm_val_loss=0.00949  time=0.98s
# Epoch 25  loss=0.00833  val_loss=0.00935  sm_loss=0.00858  sm_val_loss=0.00948  time=0.95s
# Fold 2
# Epoch 1  loss=0.52515  val_loss=0.03060  sm_loss=0.52513  sm_val_loss=0.03061  time=0.95s
# Epoch 2  loss=0.01405  val_loss=0.01060  sm_loss=0.01402  sm_val_loss=0.01061  time=0.95s
# Epoch 3  loss=0.01005  val_loss=0.00968  sm_loss=0.01007  sm_val_loss=0.00977  time=0.94s
# Epoch 4  loss=0.00958  val_loss=0.00952  sm_loss=0.00969  sm_val_loss=0.00961  time=0.95s
# Epoch 7  loss=0.00929  val_loss=0.00946  sm_loss=0.00949  sm_val_loss=0.00953  time=0.95s
# Epoch 14  loss=0.00922  val_loss=0.00934  sm_loss=0.00942  sm_val_loss=0.00944  time=0.95s
# Epoch 16  loss=0.00910  val_loss=0.00931  sm_loss=0.00930  sm_val_loss=0.00938  time=1.19s
# Epoch 17  loss=0.00905  val_loss=0.00929  sm_loss=0.00927  sm_val_loss=0.00938  time=0.97s
# Epoch 18  loss=0.00900  val_loss=0.00924  sm_loss=0.00922  sm_val_loss=0.00932  time=0.95s
# Epoch 19  loss=0.00891  val_loss=0.00920  sm_loss=0.00913  sm_val_loss=0.00928  time=0.94s
# Epoch 21  loss=0.00873  val_loss=0.00911  sm_loss=0.00896  sm_val_loss=0.00921  time=0.95s
# Epoch 22  loss=0.00861  val_loss=0.00910  sm_loss=0.00886  sm_val_loss=0.00920  time=0.95s
# Epoch 23  loss=0.00848  val_loss=0.00903  sm_loss=0.00872  sm_val_loss=0.00914  time=0.95s
# Fold 3
# Epoch 1  loss=0.52742  val_loss=0.03133  sm_loss=0.52741  sm_val_loss=0.03128  time=1.07s
# Epoch 2  loss=0.01391  val_loss=0.01019  sm_loss=0.01388  sm_val_loss=0.01020  time=1.05s
# Epoch 3  loss=0.00999  val_loss=0.00951  sm_loss=0.00999  sm_val_loss=0.00960  time=1.02s
# Epoch 5  loss=0.00985  val_loss=0.00931  sm_loss=0.00999  sm_val_loss=0.00943  time=0.94s
# Epoch 6  loss=0.00944  val_loss=0.00928  sm_loss=0.00962  sm_val_loss=0.00936  time=0.95s
# Epoch 9  loss=0.00933  val_loss=0.00922  sm_loss=0.00954  sm_val_loss=0.00932  time=1.32s
# Epoch 13  loss=0.00928  val_loss=0.00921  sm_loss=0.00948  sm_val_loss=0.00932  time=1.01s
# Epoch 15  loss=0.00926  val_loss=0.00918  sm_loss=0.00946  sm_val_loss=0.00927  time=1.00s
# Epoch 16  loss=0.00920  val_loss=0.00912  sm_loss=0.00940  sm_val_loss=0.00921  time=1.02s
# Epoch 18  loss=0.00906  val_loss=0.00910  sm_loss=0.00927  sm_val_loss=0.00920  time=1.16s
# Epoch 19  loss=0.00900  val_loss=0.00900  sm_loss=0.00922  sm_val_loss=0.00910  time=0.99s
# Epoch 20  loss=0.00891  val_loss=0.00897  sm_loss=0.00913  sm_val_loss=0.00907  time=0.97s
# Epoch 21  loss=0.00879  val_loss=0.00895  sm_loss=0.00902  sm_val_loss=0.00904  time=1.04s
# Epoch 22  loss=0.00869  val_loss=0.00891  sm_loss=0.00892  sm_val_loss=0.00901  time=1.08s
# Epoch 23  loss=0.00856  val_loss=0.00885  sm_loss=0.00881  sm_val_loss=0.00895  time=0.94s
# Epoch 24  loss=0.00846  val_loss=0.00884  sm_loss=0.00871  sm_val_loss=0.00895  time=0.96s
# Epoch 25  loss=0.00841  val_loss=0.00884  sm_loss=0.00867  sm_val_loss=0.00894  time=0.96s
# Fold 4
# Epoch 1  loss=0.52505  val_loss=0.02850  sm_loss=0.52504  sm_val_loss=0.02844  time=0.95s
# Epoch 2  loss=0.01380  val_loss=0.01073  sm_loss=0.01378  sm_val_loss=0.01068  time=0.95s
# Epoch 4  loss=0.00949  val_loss=0.00970  sm_loss=0.00964  sm_val_loss=0.00977  time=0.99s
# Epoch 5  loss=0.00943  val_loss=0.00969  sm_loss=0.00960  sm_val_loss=0.00970  time=0.97s
# Epoch 9  loss=0.00924  val_loss=0.00963  sm_loss=0.00945  sm_val_loss=0.00970  time=0.94s
# Epoch 10  loss=0.00921  val_loss=0.00954  sm_loss=0.00942  sm_val_loss=0.00964  time=0.95s
# Epoch 13  loss=0.00923  val_loss=0.00954  sm_loss=0.00943  sm_val_loss=0.00963  time=0.95s
# Epoch 14  loss=0.00917  val_loss=0.00953  sm_loss=0.00937  sm_val_loss=0.00962  time=0.94s
# Epoch 15  loss=0.00915  val_loss=0.00949  sm_loss=0.00935  sm_val_loss=0.00959  time=0.95s
# Epoch 17  loss=0.00905  val_loss=0.00935  sm_loss=0.00926  sm_val_loss=0.00945  time=0.93s
# Epoch 18  loss=0.00898  val_loss=0.00932  sm_loss=0.00920  sm_val_loss=0.00943  time=1.16s
# Epoch 20  loss=0.00880  val_loss=0.00920  sm_loss=0.00902  sm_val_loss=0.00931  time=0.94s
# Epoch 22  loss=0.00858  val_loss=0.00913  sm_loss=0.00882  sm_val_loss=0.00924  time=0.93s
# Epoch 23  loss=0.00846  val_loss=0.00911  sm_loss=0.00870  sm_val_loss=0.00923  time=1.07s
# Epoch 24  loss=0.00833  val_loss=0.00907  sm_loss=0.00859  sm_val_loss=0.00919  time=1.16s
# Epoch 25  loss=0.00826  val_loss=0.00906  sm_loss=0.00852  sm_val_loss=0.00919  time=0.94s
# Fold 5
# Epoch 1  loss=0.52677  val_loss=0.03202  sm_loss=0.52674  sm_val_loss=0.03182  time=0.94s
# Epoch 2  loss=0.01396  val_loss=0.01064  sm_loss=0.01393  sm_val_loss=0.01064  time=0.94s
# Epoch 3  loss=0.01012  val_loss=0.00988  sm_loss=0.01011  sm_val_loss=0.00995  time=1.16s
# Epoch 4  loss=0.00941  val_loss=0.00974  sm_loss=0.00956  sm_val_loss=0.00983  time=0.93s
# Epoch 5  loss=0.00929  val_loss=0.00971  sm_loss=0.00947  sm_val_loss=0.00979  time=0.93s
# Epoch 9  loss=0.00924  val_loss=0.00966  sm_loss=0.00943  sm_val_loss=0.00973  time=0.92s
# Epoch 14  loss=0.00919  val_loss=0.00958  sm_loss=0.00939  sm_val_loss=0.00969  time=1.01s
# Epoch 16  loss=0.00910  val_loss=0.00958  sm_loss=0.00930  sm_val_loss=0.00967  time=1.20s
# Epoch 17  loss=0.00905  val_loss=0.00952  sm_loss=0.00926  sm_val_loss=0.00962  time=1.06s
# Epoch 18  loss=0.00900  val_loss=0.00940  sm_loss=0.00921  sm_val_loss=0.00950  time=0.94s
# Epoch 19  loss=0.00892  val_loss=0.00935  sm_loss=0.00914  sm_val_loss=0.00946  time=0.96s
# Epoch 21  loss=0.00872  val_loss=0.00926  sm_loss=0.00895  sm_val_loss=0.00936  time=0.96s
# Epoch 22  loss=0.00859  val_loss=0.00922  sm_loss=0.00883  sm_val_loss=0.00933  time=0.95s
# Epoch 24  loss=0.00838  val_loss=0.00917  sm_loss=0.00863  sm_val_loss=0.00929  time=0.93s
# Fold 6
# Epoch 1  loss=0.52424  val_loss=0.02905  sm_loss=0.52422  sm_val_loss=0.02899  time=0.94s
# Epoch 2  loss=0.01433  val_loss=0.01070  sm_loss=0.01427  sm_val_loss=0.01066  time=1.00s
# Epoch 3  loss=0.01019  val_loss=0.00952  sm_loss=0.01022  sm_val_loss=0.00958  time=1.07s
# Epoch 4  loss=0.00986  val_loss=0.00940  sm_loss=0.00995  sm_val_loss=0.00953  time=1.22s
# Epoch 6  loss=0.00947  val_loss=0.00918  sm_loss=0.00964  sm_val_loss=0.00931  time=0.95s
# Epoch 7  loss=0.00944  val_loss=0.00915  sm_loss=0.00961  sm_val_loss=0.00929  time=0.96s
# Epoch 11  loss=0.00935  val_loss=0.00905  sm_loss=0.00954  sm_val_loss=0.00917  time=0.97s
# Epoch 17  loss=0.00912  val_loss=0.00897  sm_loss=0.00933  sm_val_loss=0.00909  time=0.93s
# Epoch 18  loss=0.00908  val_loss=0.00893  sm_loss=0.00929  sm_val_loss=0.00906  time=0.96s
# Epoch 19  loss=0.00903  val_loss=0.00889  sm_loss=0.00924  sm_val_loss=0.00901  time=0.94s
# Epoch 20  loss=0.00893  val_loss=0.00883  sm_loss=0.00915  sm_val_loss=0.00895  time=0.94s
# Epoch 21  loss=0.00882  val_loss=0.00877  sm_loss=0.00904  sm_val_loss=0.00891  time=1.19s
# Epoch 22  loss=0.00870  val_loss=0.00868  sm_loss=0.00893  sm_val_loss=0.00883  time=0.94s
# Epoch 23  loss=0.00858  val_loss=0.00866  sm_loss=0.00883  sm_val_loss=0.00881  time=0.96s
# Epoch 24  loss=0.00848  val_loss=0.00866  sm_loss=0.00873  sm_val_loss=0.00881  time=0.93s
# Epoch 25  loss=0.00842  val_loss=0.00865  sm_loss=0.00867  sm_val_loss=0.00880  time=0.94s
# Fold 7
# Epoch 1  loss=0.52747  val_loss=0.09800  sm_loss=0.52746  sm_val_loss=0.09787  time=0.93s
# Epoch 2  loss=0.01411  val_loss=0.01002  sm_loss=0.01407  sm_val_loss=0.01002  time=0.96s
# Epoch 3  loss=0.01008  val_loss=0.00921  sm_loss=0.01009  sm_val_loss=0.00928  time=0.94s
# Epoch 4  loss=0.00948  val_loss=0.00893  sm_loss=0.00962  sm_val_loss=0.00908  time=0.94s
# Epoch 5  loss=0.00954  val_loss=0.00887  sm_loss=0.00969  sm_val_loss=0.00906  time=0.94s
# Epoch 11  loss=0.00934  val_loss=0.00885  sm_loss=0.00953  sm_val_loss=0.00901  time=0.93s
# Epoch 13  loss=0.00932  val_loss=0.00879  sm_loss=0.00951  sm_val_loss=0.00896  time=0.92s
# Epoch 17  loss=0.00917  val_loss=0.00881  sm_loss=0.00937  sm_val_loss=0.00896  time=1.14s
# Epoch 18  loss=0.00911  val_loss=0.00873  sm_loss=0.00931  sm_val_loss=0.00887  time=0.96s
# Epoch 19  loss=0.00904  val_loss=0.00870  sm_loss=0.00924  sm_val_loss=0.00887  time=0.98s
# Epoch 20  loss=0.00894  val_loss=0.00863  sm_loss=0.00915  sm_val_loss=0.00879  time=0.92s
# Epoch 21  loss=0.00883  val_loss=0.00855  sm_loss=0.00906  sm_val_loss=0.00872  time=0.92s
# Epoch 22  loss=0.00872  val_loss=0.00849  sm_loss=0.00894  sm_val_loss=0.00866  time=0.92s
# Epoch 23  loss=0.00859  val_loss=0.00845  sm_loss=0.00883  sm_val_loss=0.00862  time=0.99s
# Epoch 24  loss=0.00848  val_loss=0.00843  sm_loss=0.00873  sm_val_loss=0.00861  time=1.37s
# Epoch 25  loss=0.00842  val_loss=0.00843  sm_loss=0.00867  sm_val_loss=0.00861  time=0.99s
# Fold 1
# Epoch 1  loss=0.67067  val_loss=0.67851  sm_loss=0.67060  sm_val_loss=0.67774  time=0.95s
# Epoch 2  loss=0.09105  val_loss=0.02455  sm_loss=0.09096  sm_val_loss=0.02454  time=1.08s
# Epoch 3  loss=0.02250  val_loss=0.01967  sm_loss=0.02249  sm_val_loss=0.01968  time=1.30s
# Epoch 4  loss=0.01907  val_loss=0.01830  sm_loss=0.01906  sm_val_loss=0.01832  time=0.93s
# Epoch 5  loss=0.01791  val_loss=0.01762  sm_loss=0.01793  sm_val_loss=0.01765  time=0.96s
# Epoch 6  loss=0.01729  val_loss=0.01754  sm_loss=0.01736  sm_val_loss=0.01758  time=0.92s
# Epoch 8  loss=0.01667  val_loss=0.01731  sm_loss=0.01678  sm_val_loss=0.01731  time=0.98s
# Epoch 10  loss=0.01615  val_loss=0.01712  sm_loss=0.01629  sm_val_loss=0.01714  time=0.94s
# Epoch 11  loss=0.01574  val_loss=0.01717  sm_loss=0.01593  sm_val_loss=0.01713  time=0.91s
# Fold 1 log loss: 0.017235614062200227
# Fold 2
# Epoch 1  loss=0.66973  val_loss=0.43280  sm_loss=0.66968  sm_val_loss=0.43277  time=0.92s
# Epoch 2  loss=0.08968  val_loss=0.02507  sm_loss=0.08953  sm_val_loss=0.02509  time=1.02s
# Epoch 3  loss=0.02232  val_loss=0.01910  sm_loss=0.02229  sm_val_loss=0.01911  time=1.03s
# Epoch 4  loss=0.01896  val_loss=0.01758  sm_loss=0.01897  sm_val_loss=0.01761  time=0.92s
# Epoch 5  loss=0.01796  val_loss=0.01724  sm_loss=0.01798  sm_val_loss=0.01729  time=0.92s
# Epoch 6  loss=0.01739  val_loss=0.01714  sm_loss=0.01745  sm_val_loss=0.01721  time=0.94s
# Epoch 7  loss=0.01707  val_loss=0.01687  sm_loss=0.01714  sm_val_loss=0.01694  time=0.92s
# Epoch 12  loss=0.01541  val_loss=0.01684  sm_loss=0.01561  sm_val_loss=0.01688  time=0.93s
# Fold 2 log loss: 0.017028953352541742
# Fold 3
# Epoch 1  loss=0.67040  val_loss=0.42104  sm_loss=0.67036  sm_val_loss=0.42064  time=0.90s
# Epoch 2  loss=0.09053  val_loss=0.02401  sm_loss=0.09041  sm_val_loss=0.02401  time=0.93s
# Epoch 3  loss=0.02204  val_loss=0.01943  sm_loss=0.02201  sm_val_loss=0.01943  time=1.10s
# Epoch 4  loss=0.01898  val_loss=0.01891  sm_loss=0.01897  sm_val_loss=0.01891  time=0.98s
# Epoch 5  loss=0.01798  val_loss=0.01824  sm_loss=0.01800  sm_val_loss=0.01828  time=1.22s
# Epoch 6  loss=0.01742  val_loss=0.01780  sm_loss=0.01745  sm_val_loss=0.01785  time=0.90s
# Epoch 7  loss=0.01693  val_loss=0.01776  sm_loss=0.01701  sm_val_loss=0.01780  time=0.91s
# Epoch 8  loss=0.01664  val_loss=0.01778  sm_loss=0.01674  sm_val_loss=0.01780  time=0.92s
# Epoch 9  loss=0.01631  val_loss=0.01756  sm_loss=0.01645  sm_val_loss=0.01758  time=0.91s
# Epoch 11  loss=0.01567  val_loss=0.01758  sm_loss=0.01587  sm_val_loss=0.01755  time=0.93s
# Fold 3 log loss: 0.017506587119997266
# Fold 4
# Epoch 1  loss=0.66881  val_loss=0.51572  sm_loss=0.66878  sm_val_loss=0.51549  time=0.91s
# Epoch 2  loss=0.08811  val_loss=0.02556  sm_loss=0.08806  sm_val_loss=0.02555  time=0.94s
# Epoch 3  loss=0.02214  val_loss=0.01970  sm_loss=0.02213  sm_val_loss=0.01969  time=1.15s
# Epoch 4  loss=0.01910  val_loss=0.01842  sm_loss=0.01910  sm_val_loss=0.01839  time=1.03s
# Epoch 5  loss=0.01816  val_loss=0.01811  sm_loss=0.01819  sm_val_loss=0.01808  time=0.98s
# Epoch 6  loss=0.01743  val_loss=0.01778  sm_loss=0.01749  sm_val_loss=0.01784  time=0.95s
# Epoch 7  loss=0.01693  val_loss=0.01769  sm_loss=0.01703  sm_val_loss=0.01773  time=0.96s
# Epoch 8  loss=0.01658  val_loss=0.01761  sm_loss=0.01670  sm_val_loss=0.01767  time=0.95s
# Fold 4 log loss: 0.017771338159492826
# Fold 5
# Epoch 1  loss=0.67009  val_loss=0.50445  sm_loss=0.67005  sm_val_loss=0.50427  time=0.91s
# Epoch 2  loss=0.09118  val_loss=0.02361  sm_loss=0.09110  sm_val_loss=0.02360  time=0.90s
# Epoch 3  loss=0.02287  val_loss=0.01959  sm_loss=0.02282  sm_val_loss=0.01961  time=0.90s
# Epoch 4  loss=0.01909  val_loss=0.01808  sm_loss=0.01908  sm_val_loss=0.01810  time=1.15s
# Epoch 5  loss=0.01826  val_loss=0.01779  sm_loss=0.01828  sm_val_loss=0.01782  time=0.93s
# Epoch 6  loss=0.01764  val_loss=0.01751  sm_loss=0.01768  sm_val_loss=0.01756  time=0.91s
# Epoch 7  loss=0.01702  val_loss=0.01732  sm_loss=0.01712  sm_val_loss=0.01735  time=0.91s
# Epoch 8  loss=0.01663  val_loss=0.01729  sm_loss=0.01675  sm_val_loss=0.01731  time=0.90s
# Epoch 9  loss=0.01631  val_loss=0.01721  sm_loss=0.01646  sm_val_loss=0.01722  time=0.96s
# Epoch 10  loss=0.01605  val_loss=0.01720  sm_loss=0.01622  sm_val_loss=0.01720  time=0.92s
# Epoch 11  loss=0.01568  val_loss=0.01719  sm_loss=0.01589  sm_val_loss=0.01719  time=0.96s
# Epoch 12  loss=0.01539  val_loss=0.01722  sm_loss=0.01562  sm_val_loss=0.01719  time=0.91s
# Fold 5 log loss: 0.01737795531128333
# Fold 6
# Epoch 1  loss=0.66783  val_loss=0.44955  sm_loss=0.66777  sm_val_loss=0.44917  time=1.07s
# Epoch 2  loss=0.09024  val_loss=0.02430  sm_loss=0.09014  sm_val_loss=0.02429  time=0.91s
# Epoch 3  loss=0.02212  val_loss=0.01905  sm_loss=0.02208  sm_val_loss=0.01906  time=0.91s
# Epoch 4  loss=0.01883  val_loss=0.01829  sm_loss=0.01883  sm_val_loss=0.01831  time=0.91s
# Epoch 5  loss=0.01774  val_loss=0.01779  sm_loss=0.01776  sm_val_loss=0.01782  time=1.19s
# Epoch 6  loss=0.01725  val_loss=0.01767  sm_loss=0.01731  sm_val_loss=0.01773  time=1.10s
# Epoch 7  loss=0.01696  val_loss=0.01750  sm_loss=0.01704  sm_val_loss=0.01757  time=1.09s
# Epoch 10  loss=0.01606  val_loss=0.01743  sm_loss=0.01621  sm_val_loss=0.01749  time=1.08s
# Fold 6 log loss: 0.017504190296091456
# Fold 7
# Epoch 1  loss=0.66775  val_loss=0.51049  sm_loss=0.66771  sm_val_loss=0.50995  time=0.91s
# Epoch 2  loss=0.08858  val_loss=0.02243  sm_loss=0.08842  sm_val_loss=0.02242  time=0.91s
# Epoch 3  loss=0.02210  val_loss=0.01930  sm_loss=0.02208  sm_val_loss=0.01930  time=0.91s
# Epoch 4  loss=0.01946  val_loss=0.01866  sm_loss=0.01942  sm_val_loss=0.01864  time=0.97s
# Epoch 5  loss=0.01873  val_loss=0.01784  sm_loss=0.01870  sm_val_loss=0.01790  time=1.16s
# Epoch 6  loss=0.01781  val_loss=0.01743  sm_loss=0.01784  sm_val_loss=0.01751  time=0.95s
# Epoch 7  loss=0.01723  val_loss=0.01732  sm_loss=0.01732  sm_val_loss=0.01739  time=0.94s
# Epoch 8  loss=0.01689  val_loss=0.01726  sm_loss=0.01701  sm_val_loss=0.01734  time=0.94s
# Epoch 9  loss=0.01662  val_loss=0.01716  sm_loss=0.01675  sm_val_loss=0.01725  time=0.93s
# Epoch 11  loss=0.01603  val_loss=0.01705  sm_loss=0.01621  sm_val_loss=0.01714  time=0.92s
# Epoch 14  loss=0.01519  val_loss=0.01704  sm_loss=0.01541  sm_val_loss=0.01712  time=0.93s
# Fold 7 log loss: 0.017159318588381132
# Seed 0
# Fold 1 log loss: 0.017235614062200227
# Fold 2 log loss: 0.017028953352541742
# Fold 3 log loss: 0.017506587119997266
# Fold 4 log loss: 0.017771338159492826
# Fold 5 log loss: 0.01737795531128333
# Fold 6 log loss: 0.017504190296091456
# Fold 7 log loss: 0.017159318588381132
# Std of log loss: 0.00023193364764025827
# Total log loss: 0.017369296861121264
# Fold 1
# Epoch 1  loss=0.52615  val_loss=0.08914  sm_loss=0.52614  sm_val_loss=0.08891  time=0.91s
# Epoch 2  loss=0.01420  val_loss=0.01096  sm_loss=0.01412  sm_val_loss=0.01096  time=0.91s
# Epoch 3  loss=0.00998  val_loss=0.01014  sm_loss=0.00999  sm_val_loss=0.01022  time=0.93s
# Epoch 4  loss=0.00931  val_loss=0.00991  sm_loss=0.00947  sm_val_loss=0.01002  time=1.14s
# Epoch 8  loss=0.00925  val_loss=0.00990  sm_loss=0.00945  sm_val_loss=0.00999  time=0.94s
# Epoch 10  loss=0.00927  val_loss=0.00989  sm_loss=0.00946  sm_val_loss=0.00996  time=0.90s
# Epoch 12  loss=0.00917  val_loss=0.00988  sm_loss=0.00936  sm_val_loss=0.00995  time=0.91s
# Epoch 13  loss=0.00917  val_loss=0.00980  sm_loss=0.00937  sm_val_loss=0.00988  time=0.92s
# Epoch 16  loss=0.00908  val_loss=0.00974  sm_loss=0.00928  sm_val_loss=0.00985  time=0.94s
# Epoch 18  loss=0.00895  val_loss=0.00966  sm_loss=0.00916  sm_val_loss=0.00976  time=0.91s
# Epoch 19  loss=0.00888  val_loss=0.00960  sm_loss=0.00910  sm_val_loss=0.00970  time=0.91s
# Epoch 20  loss=0.00880  val_loss=0.00959  sm_loss=0.00902  sm_val_loss=0.00970  time=0.92s
# Epoch 21  loss=0.00869  val_loss=0.00952  sm_loss=0.00891  sm_val_loss=0.00963  time=0.92s
# Epoch 22  loss=0.00858  val_loss=0.00942  sm_loss=0.00882  sm_val_loss=0.00955  time=0.95s
# Epoch 23  loss=0.00846  val_loss=0.00939  sm_loss=0.00871  sm_val_loss=0.00952  time=0.92s
# Epoch 24  loss=0.00837  val_loss=0.00937  sm_loss=0.00862  sm_val_loss=0.00950  time=0.94s
# Fold 2
# Epoch 1  loss=0.52328  val_loss=0.02956  sm_loss=0.52326  sm_val_loss=0.02954  time=2.16s
# Epoch 2  loss=0.01406  val_loss=0.01064  sm_loss=0.01401  sm_val_loss=0.01065  time=0.97s
# Epoch 3  loss=0.01006  val_loss=0.00964  sm_loss=0.01009  sm_val_loss=0.00973  time=0.93s
# Epoch 4  loss=0.00951  val_loss=0.00958  sm_loss=0.00964  sm_val_loss=0.00968  time=0.96s
# Epoch 6  loss=0.00927  val_loss=0.00957  sm_loss=0.00947  sm_val_loss=0.00964  time=1.04s
# Epoch 8  loss=0.00932  val_loss=0.00948  sm_loss=0.00952  sm_val_loss=0.00953  time=0.96s
# Epoch 11  loss=0.00929  val_loss=0.00946  sm_loss=0.00949  sm_val_loss=0.00953  time=1.18s
# Epoch 12  loss=0.00926  val_loss=0.00938  sm_loss=0.00946  sm_val_loss=0.00946  time=0.97s
# Epoch 16  loss=0.00913  val_loss=0.00936  sm_loss=0.00934  sm_val_loss=0.00942  time=0.95s
# Epoch 17  loss=0.00908  val_loss=0.00930  sm_loss=0.00929  sm_val_loss=0.00939  time=0.97s
# Epoch 18  loss=0.00901  val_loss=0.00926  sm_loss=0.00922  sm_val_loss=0.00934  time=0.94s
# Epoch 19  loss=0.00894  val_loss=0.00921  sm_loss=0.00916  sm_val_loss=0.00930  time=0.94s
# Epoch 21  loss=0.00874  val_loss=0.00918  sm_loss=0.00897  sm_val_loss=0.00928  time=0.94s
# Epoch 22  loss=0.00863  val_loss=0.00912  sm_loss=0.00887  sm_val_loss=0.00922  time=1.15s
# Epoch 23  loss=0.00850  val_loss=0.00904  sm_loss=0.00874  sm_val_loss=0.00914  time=0.94s
# Fold 3
# Epoch 1  loss=0.52754  val_loss=0.02868  sm_loss=0.52753  sm_val_loss=0.02863  time=0.91s
# Epoch 2  loss=0.01420  val_loss=0.01018  sm_loss=0.01416  sm_val_loss=0.01018  time=0.94s
# Epoch 3  loss=0.01005  val_loss=0.00945  sm_loss=0.01007  sm_val_loss=0.00954  time=0.93s
# Epoch 4  loss=0.00942  val_loss=0.00940  sm_loss=0.00956  sm_val_loss=0.00950  time=0.93s
# Epoch 5  loss=0.00949  val_loss=0.00925  sm_loss=0.00964  sm_val_loss=0.00936  time=0.91s
# Epoch 9  loss=0.00932  val_loss=0.00926  sm_loss=0.00952  sm_val_loss=0.00936  time=0.90s
# Epoch 13  loss=0.00925  val_loss=0.00926  sm_loss=0.00946  sm_val_loss=0.00935  time=0.93s
# Epoch 14  loss=0.00921  val_loss=0.00917  sm_loss=0.00942  sm_val_loss=0.00927  time=0.91s
# Epoch 16  loss=0.00916  val_loss=0.00912  sm_loss=0.00937  sm_val_loss=0.00921  time=0.93s
# Epoch 18  loss=0.00902  val_loss=0.00904  sm_loss=0.00924  sm_val_loss=0.00913  time=0.96s
# Epoch 19  loss=0.00894  val_loss=0.00902  sm_loss=0.00916  sm_val_loss=0.00912  time=1.17s
# Epoch 20  loss=0.00885  val_loss=0.00893  sm_loss=0.00907  sm_val_loss=0.00903  time=0.97s
# Epoch 21  loss=0.00875  val_loss=0.00889  sm_loss=0.00898  sm_val_loss=0.00900  time=0.95s
# Epoch 22  loss=0.00863  val_loss=0.00889  sm_loss=0.00887  sm_val_loss=0.00899  time=1.00s
# Epoch 23  loss=0.00849  val_loss=0.00888  sm_loss=0.00874  sm_val_loss=0.00899  time=0.98s
# Epoch 24  loss=0.00838  val_loss=0.00882  sm_loss=0.00863  sm_val_loss=0.00893  time=0.98s
# Fold 4
# Epoch 1  loss=0.52583  val_loss=0.03510  sm_loss=0.52581  sm_val_loss=0.03505  time=0.93s
# Epoch 2  loss=0.01377  val_loss=0.01112  sm_loss=0.01375  sm_val_loss=0.01101  time=0.92s
# Epoch 3  loss=0.01069  val_loss=0.01119  sm_loss=0.01069  sm_val_loss=0.01067  time=0.92s
# Epoch 4  loss=0.00957  val_loss=0.00979  sm_loss=0.00975  sm_val_loss=0.00985  time=1.17s
# Epoch 5  loss=0.00940  val_loss=0.00966  sm_loss=0.00960  sm_val_loss=0.00976  time=0.93s
# Epoch 6  loss=0.00930  val_loss=0.00965  sm_loss=0.00951  sm_val_loss=0.00976  time=0.92s
# Epoch 8  loss=0.00929  val_loss=0.00963  sm_loss=0.00948  sm_val_loss=0.00974  time=0.92s
# Epoch 11  loss=0.00927  val_loss=0.00962  sm_loss=0.00947  sm_val_loss=0.00973  time=0.95s
# Epoch 12  loss=0.00925  val_loss=0.00959  sm_loss=0.00945  sm_val_loss=0.00970  time=0.93s
# Epoch 13  loss=0.00920  val_loss=0.00950  sm_loss=0.00939  sm_val_loss=0.00959  time=1.16s
# Epoch 16  loss=0.00912  val_loss=0.00948  sm_loss=0.00933  sm_val_loss=0.00957  time=0.93s
# Epoch 17  loss=0.00906  val_loss=0.00939  sm_loss=0.00927  sm_val_loss=0.00948  time=0.97s
# Epoch 18  loss=0.00901  val_loss=0.00937  sm_loss=0.00922  sm_val_loss=0.00947  time=0.94s
# Epoch 19  loss=0.00888  val_loss=0.00929  sm_loss=0.00910  sm_val_loss=0.00939  time=0.95s
# Epoch 20  loss=0.00882  val_loss=0.00927  sm_loss=0.00905  sm_val_loss=0.00937  time=0.97s
# Epoch 21  loss=0.00873  val_loss=0.00918  sm_loss=0.00896  sm_val_loss=0.00930  time=0.93s
# Epoch 22  loss=0.00860  val_loss=0.00917  sm_loss=0.00884  sm_val_loss=0.00928  time=0.98s
# Epoch 23  loss=0.00846  val_loss=0.00911  sm_loss=0.00871  sm_val_loss=0.00923  time=1.00s
# Epoch 24  loss=0.00837  val_loss=0.00909  sm_loss=0.00862  sm_val_loss=0.00921  time=1.01s
# Fold 5
# Epoch 1  loss=0.52518  val_loss=0.03597  sm_loss=0.52517  sm_val_loss=0.03595  time=0.91s
# Epoch 2  loss=0.01383  val_loss=0.01063  sm_loss=0.01379  sm_val_loss=0.01065  time=0.93s
# Epoch 3  loss=0.00995  val_loss=0.00992  sm_loss=0.00999  sm_val_loss=0.01000  time=0.92s
# Epoch 4  loss=0.00940  val_loss=0.00981  sm_loss=0.00954  sm_val_loss=0.00989  time=0.94s
# Epoch 5  loss=0.00923  val_loss=0.00960  sm_loss=0.00942  sm_val_loss=0.00969  time=0.99s
# Epoch 8  loss=0.00931  val_loss=0.00960  sm_loss=0.00951  sm_val_loss=0.00969  time=0.93s
# Epoch 9  loss=0.00925  val_loss=0.00960  sm_loss=0.00945  sm_val_loss=0.00969  time=0.96s
# Epoch 11  loss=0.00927  val_loss=0.00960  sm_loss=0.00946  sm_val_loss=0.00969  time=0.95s
# Epoch 13  loss=0.00922  val_loss=0.00957  sm_loss=0.00941  sm_val_loss=0.00968  time=0.96s
# Epoch 14  loss=0.00920  val_loss=0.00956  sm_loss=0.00940  sm_val_loss=0.00964  time=0.97s
# Epoch 17  loss=0.00905  val_loss=0.00944  sm_loss=0.00925  sm_val_loss=0.00955  time=0.92s
# Epoch 18  loss=0.00901  val_loss=0.00944  sm_loss=0.00922  sm_val_loss=0.00953  time=0.93s
# Epoch 19  loss=0.00893  val_loss=0.00940  sm_loss=0.00914  sm_val_loss=0.00949  time=0.95s
# Epoch 20  loss=0.00883  val_loss=0.00932  sm_loss=0.00905  sm_val_loss=0.00941  time=1.23s
# Epoch 21  loss=0.00872  val_loss=0.00931  sm_loss=0.00895  sm_val_loss=0.00941  time=1.16s
# Epoch 22  loss=0.00860  val_loss=0.00925  sm_loss=0.00884  sm_val_loss=0.00936  time=0.94s
# Epoch 23  loss=0.00850  val_loss=0.00919  sm_loss=0.00875  sm_val_loss=0.00930  time=0.95s
# Epoch 24  loss=0.00839  val_loss=0.00917  sm_loss=0.00864  sm_val_loss=0.00928  time=0.96s
# Epoch 25  loss=0.00833  val_loss=0.00916  sm_loss=0.00859  sm_val_loss=0.00927  time=0.94s
# Fold 6
# Epoch 1  loss=0.52717  val_loss=0.09164  sm_loss=0.52713  sm_val_loss=0.09127  time=0.94s
# Epoch 2  loss=0.01460  val_loss=0.01070  sm_loss=0.01456  sm_val_loss=0.01065  time=1.00s
# Epoch 3  loss=0.01045  val_loss=0.01015  sm_loss=0.01045  sm_val_loss=0.01014  time=0.93s
# Epoch 5  loss=0.00972  val_loss=0.00972  sm_loss=0.00986  sm_val_loss=0.00981  time=0.97s
# Epoch 7  loss=0.00950  val_loss=0.00934  sm_loss=0.00968  sm_val_loss=0.00947  time=0.95s
# Epoch 8  loss=0.00940  val_loss=0.00923  sm_loss=0.00961  sm_val_loss=0.00936  time=0.94s
# Epoch 10  loss=0.00934  val_loss=0.00917  sm_loss=0.00954  sm_val_loss=0.00929  time=0.92s
# Epoch 11  loss=0.00931  val_loss=0.00906  sm_loss=0.00951  sm_val_loss=0.00919  time=0.92s
# Epoch 14  loss=0.00925  val_loss=0.00904  sm_loss=0.00945  sm_val_loss=0.00916  time=0.92s
# Epoch 16  loss=0.00918  val_loss=0.00893  sm_loss=0.00938  sm_val_loss=0.00907  time=1.10s
# Epoch 17  loss=0.00911  val_loss=0.00893  sm_loss=0.00932  sm_val_loss=0.00905  time=1.32s
# Epoch 19  loss=0.00898  val_loss=0.00886  sm_loss=0.00920  sm_val_loss=0.00899  time=1.01s
# Epoch 20  loss=0.00886  val_loss=0.00886  sm_loss=0.00907  sm_val_loss=0.00898  time=1.08s
# Epoch 21  loss=0.00874  val_loss=0.00881  sm_loss=0.00897  sm_val_loss=0.00894  time=0.95s
# Epoch 22  loss=0.00862  val_loss=0.00875  sm_loss=0.00886  sm_val_loss=0.00888  time=0.98s
# Epoch 23  loss=0.00851  val_loss=0.00870  sm_loss=0.00875  sm_val_loss=0.00885  time=0.95s
# Epoch 24  loss=0.00841  val_loss=0.00869  sm_loss=0.00866  sm_val_loss=0.00883  time=0.96s
# Fold 7
# Epoch 1  loss=0.52597  val_loss=0.02908  sm_loss=0.52595  sm_val_loss=0.02904  time=1.20s
# Epoch 2  loss=0.01404  val_loss=0.01007  sm_loss=0.01401  sm_val_loss=0.01005  time=1.23s
# Epoch 3  loss=0.01012  val_loss=0.00964  sm_loss=0.01012  sm_val_loss=0.00968  time=0.93s
# Epoch 4  loss=0.00974  val_loss=0.00896  sm_loss=0.00986  sm_val_loss=0.00911  time=0.97s
# Epoch 5  loss=0.00942  val_loss=0.00892  sm_loss=0.00961  sm_val_loss=0.00908  time=0.98s
# Epoch 7  loss=0.00941  val_loss=0.00892  sm_loss=0.00959  sm_val_loss=0.00907  time=0.96s
# Epoch 10  loss=0.00938  val_loss=0.00888  sm_loss=0.00956  sm_val_loss=0.00903  time=0.92s
# Epoch 15  loss=0.00925  val_loss=0.00886  sm_loss=0.00945  sm_val_loss=0.00902  time=0.95s
# Epoch 16  loss=0.00921  val_loss=0.00873  sm_loss=0.00942  sm_val_loss=0.00890  time=0.96s
# Epoch 17  loss=0.00914  val_loss=0.00871  sm_loss=0.00933  sm_val_loss=0.00888  time=0.95s
# Epoch 19  loss=0.00901  val_loss=0.00863  sm_loss=0.00922  sm_val_loss=0.00880  time=0.91s
# Epoch 21  loss=0.00881  val_loss=0.00852  sm_loss=0.00903  sm_val_loss=0.00870  time=0.91s
# Epoch 22  loss=0.00868  val_loss=0.00847  sm_loss=0.00891  sm_val_loss=0.00864  time=0.95s
# Epoch 23  loss=0.00856  val_loss=0.00845  sm_loss=0.00880  sm_val_loss=0.00862  time=0.93s
# Epoch 24  loss=0.00844  val_loss=0.00841  sm_loss=0.00869  sm_val_loss=0.00859  time=1.15s
# Epoch 25  loss=0.00839  val_loss=0.00840  sm_loss=0.00864  sm_val_loss=0.00858  time=0.93s
# Fold 1
# Epoch 1  loss=0.66874  val_loss=0.43924  sm_loss=0.66870  sm_val_loss=0.43894  time=0.91s
# Epoch 2  loss=0.09166  val_loss=0.02532  sm_loss=0.09162  sm_val_loss=0.02530  time=0.92s
# Epoch 3  loss=0.02223  val_loss=0.01942  sm_loss=0.02222  sm_val_loss=0.01942  time=0.90s
# Epoch 4  loss=0.01912  val_loss=0.01810  sm_loss=0.01912  sm_val_loss=0.01811  time=0.92s
# Epoch 5  loss=0.01812  val_loss=0.01778  sm_loss=0.01815  sm_val_loss=0.01782  time=0.93s
# Epoch 6  loss=0.01747  val_loss=0.01752  sm_loss=0.01753  sm_val_loss=0.01755  time=0.91s
# Epoch 7  loss=0.01691  val_loss=0.01729  sm_loss=0.01701  sm_val_loss=0.01733  time=0.93s
# Epoch 8  loss=0.01665  val_loss=0.01731  sm_loss=0.01676  sm_val_loss=0.01731  time=0.94s
# Epoch 9  loss=0.01630  val_loss=0.01724  sm_loss=0.01645  sm_val_loss=0.01725  time=1.28s
# Epoch 10  loss=0.01593  val_loss=0.01716  sm_loss=0.01612  sm_val_loss=0.01715  time=1.11s
# Fold 1 log loss: 0.01725485085733952
# Fold 2
# Epoch 1  loss=0.66928  val_loss=0.45584  sm_loss=0.66924  sm_val_loss=0.45580  time=0.93s
# Epoch 2  loss=0.08941  val_loss=0.02318  sm_loss=0.08930  sm_val_loss=0.02318  time=0.92s
# Epoch 3  loss=0.02206  val_loss=0.01898  sm_loss=0.02206  sm_val_loss=0.01899  time=1.09s
# Epoch 4  loss=0.01886  val_loss=0.01749  sm_loss=0.01887  sm_val_loss=0.01751  time=1.16s
# Epoch 6  loss=0.01738  val_loss=0.01715  sm_loss=0.01744  sm_val_loss=0.01721  time=1.14s
# Epoch 7  loss=0.01683  val_loss=0.01690  sm_loss=0.01693  sm_val_loss=0.01695  time=0.93s
# Epoch 10  loss=0.01590  val_loss=0.01687  sm_loss=0.01608  sm_val_loss=0.01690  time=1.21s
# Fold 2 log loss: 0.01704018325976219
# Fold 3
# Epoch 1  loss=0.66896  val_loss=0.41645  sm_loss=0.66893  sm_val_loss=0.41629  time=0.91s
# Epoch 2  loss=0.09111  val_loss=0.02358  sm_loss=0.09101  sm_val_loss=0.02357  time=0.90s
# Epoch 3  loss=0.02203  val_loss=0.01939  sm_loss=0.02201  sm_val_loss=0.01939  time=0.91s
# Epoch 4  loss=0.01891  val_loss=0.01840  sm_loss=0.01892  sm_val_loss=0.01843  time=0.96s
# Epoch 6  loss=0.01726  val_loss=0.01767  sm_loss=0.01731  sm_val_loss=0.01770  time=0.90s
# Epoch 7  loss=0.01678  val_loss=0.01753  sm_loss=0.01689  sm_val_loss=0.01756  time=0.90s
# Epoch 10  loss=0.01584  val_loss=0.01752  sm_loss=0.01602  sm_val_loss=0.01755  time=0.92s
# Fold 3 log loss: 0.01749958471924908
# Fold 4
# Epoch 1  loss=0.66948  val_loss=0.51158  sm_loss=0.66943  sm_val_loss=0.51126  time=1.19s
# Epoch 2  loss=0.08863  val_loss=0.02759  sm_loss=0.08851  sm_val_loss=0.02758  time=0.96s
# Epoch 3  loss=0.02200  val_loss=0.01981  sm_loss=0.02198  sm_val_loss=0.01981  time=0.99s
# Epoch 4  loss=0.01861  val_loss=0.01844  sm_loss=0.01862  sm_val_loss=0.01846  time=0.96s
# Epoch 5  loss=0.01771  val_loss=0.01805  sm_loss=0.01775  sm_val_loss=0.01811  time=0.96s
# Epoch 6  loss=0.01758  val_loss=0.01863  sm_loss=0.01762  sm_val_loss=0.01803  time=0.92s
# Epoch 7  loss=0.01695  val_loss=0.01773  sm_loss=0.01703  sm_val_loss=0.01772  time=0.90s
# Epoch 10  loss=0.01572  val_loss=0.01761  sm_loss=0.01591  sm_val_loss=0.01765  time=0.95s
# Fold 4 log loss: 0.017752393669572857
# Fold 5
# Epoch 1  loss=0.66739  val_loss=0.37018  sm_loss=0.66735  sm_val_loss=0.37017  time=0.98s
# Epoch 2  loss=0.08881  val_loss=0.02422  sm_loss=0.08875  sm_val_loss=0.02421  time=1.13s
# Epoch 3  loss=0.02242  val_loss=0.02324  sm_loss=0.02236  sm_val_loss=0.02324  time=0.92s
# Epoch 4  loss=0.01918  val_loss=0.01822  sm_loss=0.01916  sm_val_loss=0.01825  time=0.95s
# Epoch 5  loss=0.01801  val_loss=0.01768  sm_loss=0.01802  sm_val_loss=0.01772  time=1.17s
# Epoch 6  loss=0.01735  val_loss=0.01741  sm_loss=0.01741  sm_val_loss=0.01745  time=0.94s
# Epoch 7  loss=0.01698  val_loss=0.01737  sm_loss=0.01706  sm_val_loss=0.01740  time=0.94s
# Epoch 8  loss=0.01659  val_loss=0.01723  sm_loss=0.01671  sm_val_loss=0.01728  time=1.10s
# Epoch 10  loss=0.01596  val_loss=0.01711  sm_loss=0.01613  sm_val_loss=0.01714  time=0.95s
# Epoch 13  loss=0.01493  val_loss=0.01714  sm_loss=0.01515  sm_val_loss=0.01714  time=0.90s
# Fold 5 log loss: 0.017345523024056696
# Fold 6
# Epoch 1  loss=0.67131  val_loss=0.39576  sm_loss=0.67127  sm_val_loss=0.39568  time=1.28s
# Epoch 2  loss=0.08985  val_loss=0.02333  sm_loss=0.08976  sm_val_loss=0.02332  time=1.18s
# Epoch 3  loss=0.02222  val_loss=0.01959  sm_loss=0.02217  sm_val_loss=0.01959  time=0.93s
# Epoch 4  loss=0.01927  val_loss=0.01832  sm_loss=0.01924  sm_val_loss=0.01835  time=0.94s
# Epoch 5  loss=0.01814  val_loss=0.01792  sm_loss=0.01816  sm_val_loss=0.01796  time=0.92s
# Epoch 6  loss=0.01759  val_loss=0.01775  sm_loss=0.01763  sm_val_loss=0.01780  time=0.93s
# Epoch 7  loss=0.01693  val_loss=0.01756  sm_loss=0.01702  sm_val_loss=0.01764  time=0.94s
# Epoch 8  loss=0.01672  val_loss=0.01752  sm_loss=0.01683  sm_val_loss=0.01760  time=0.93s
# Epoch 9  loss=0.01671  val_loss=0.01747  sm_loss=0.01684  sm_val_loss=0.01755  time=0.93s
# Epoch 10  loss=0.01616  val_loss=0.01739  sm_loss=0.01632  sm_val_loss=0.01748  time=0.93s
# Epoch 12  loss=0.01548  val_loss=0.01736  sm_loss=0.01569  sm_val_loss=0.01746  time=0.91s
# Fold 6 log loss: 0.017486357942718737
# Fold 7
# Epoch 1  loss=0.66760  val_loss=0.40542  sm_loss=0.66756  sm_val_loss=0.40511  time=0.89s
# Epoch 2  loss=0.08889  val_loss=0.02342  sm_loss=0.08881  sm_val_loss=0.02342  time=0.91s
# Epoch 3  loss=0.02220  val_loss=0.02034  sm_loss=0.02217  sm_val_loss=0.02035  time=1.19s
# Epoch 4  loss=0.01916  val_loss=0.01818  sm_loss=0.01916  sm_val_loss=0.01820  time=0.97s
# Epoch 5  loss=0.01796  val_loss=0.01784  sm_loss=0.01795  sm_val_loss=0.01788  time=0.95s
# Epoch 6  loss=0.01740  val_loss=0.01735  sm_loss=0.01741  sm_val_loss=0.01740  time=0.95s
# Epoch 7  loss=0.01683  val_loss=0.01715  sm_loss=0.01691  sm_val_loss=0.01722  time=0.93s
# Epoch 8  loss=0.01648  val_loss=0.01706  sm_loss=0.01660  sm_val_loss=0.01715  time=0.92s
# Epoch 10  loss=0.01587  val_loss=0.01704  sm_loss=0.01604  sm_val_loss=0.01713  time=0.92s
# Fold 7 log loss: 0.01716740943730963
# Seed 1
# Fold 1 log loss: 0.01725485085733952
# Fold 2 log loss: 0.01704018325976219
# Fold 3 log loss: 0.01749958471924908
# Fold 4 log loss: 0.017752393669572857
# Fold 5 log loss: 0.017345523024056696
# Fold 6 log loss: 0.017486357942718737
# Fold 7 log loss: 0.01716740943730963
# Std of log loss: 0.00022037759088185983
# Total log loss: 0.017363817197206893
# Fold 1
# Epoch 1  loss=0.52617  val_loss=0.02928  sm_loss=0.52615  sm_val_loss=0.02920  time=1.00s
# Epoch 2  loss=0.01380  val_loss=0.01079  sm_loss=0.01376  sm_val_loss=0.01080  time=1.18s
# Epoch 3  loss=0.00985  val_loss=0.01008  sm_loss=0.00989  sm_val_loss=0.01017  time=0.93s
# Epoch 4  loss=0.00941  val_loss=0.00995  sm_loss=0.00955  sm_val_loss=0.01004  time=0.92s
# Epoch 6  loss=0.00929  val_loss=0.00987  sm_loss=0.00950  sm_val_loss=0.00996  time=0.90s
# Epoch 7  loss=0.00921  val_loss=0.00987  sm_loss=0.00942  sm_val_loss=0.00995  time=0.93s
# Epoch 8  loss=0.00924  val_loss=0.00982  sm_loss=0.00944  sm_val_loss=0.00992  time=0.91s
# Epoch 11  loss=0.00917  val_loss=0.00984  sm_loss=0.00936  sm_val_loss=0.00991  time=0.91s
# Epoch 14  loss=0.00915  val_loss=0.00981  sm_loss=0.00935  sm_val_loss=0.00991  time=0.91s
# Epoch 15  loss=0.00910  val_loss=0.00979  sm_loss=0.00930  sm_val_loss=0.00988  time=0.91s
# Epoch 17  loss=0.00902  val_loss=0.00960  sm_loss=0.00923  sm_val_loss=0.00971  time=0.91s
# Epoch 19  loss=0.00886  val_loss=0.00954  sm_loss=0.00907  sm_val_loss=0.00965  time=0.92s
# Epoch 20  loss=0.00877  val_loss=0.00953  sm_loss=0.00899  sm_val_loss=0.00963  time=0.90s
# Epoch 22  loss=0.00856  val_loss=0.00942  sm_loss=0.00879  sm_val_loss=0.00954  time=1.10s
# Epoch 23  loss=0.00844  val_loss=0.00939  sm_loss=0.00868  sm_val_loss=0.00951  time=0.94s
# Epoch 24  loss=0.00834  val_loss=0.00936  sm_loss=0.00859  sm_val_loss=0.00948  time=1.10s
# Fold 2
# Epoch 1  loss=0.52573  val_loss=0.03461  sm_loss=0.52572  sm_val_loss=0.03454  time=0.91s
# Epoch 2  loss=0.01413  val_loss=0.01040  sm_loss=0.01407  sm_val_loss=0.01040  time=0.92s
# Epoch 3  loss=0.01012  val_loss=0.00982  sm_loss=0.01013  sm_val_loss=0.00990  time=0.92s
# Epoch 4  loss=0.00969  val_loss=0.00958  sm_loss=0.00981  sm_val_loss=0.00967  time=0.92s
# Epoch 7  loss=0.00931  val_loss=0.00951  sm_loss=0.00951  sm_val_loss=0.00959  time=0.92s
# Epoch 9  loss=0.00921  val_loss=0.00944  sm_loss=0.00941  sm_val_loss=0.00952  time=1.05s
# Epoch 10  loss=0.00919  val_loss=0.00944  sm_loss=0.00939  sm_val_loss=0.00952  time=1.06s
# Epoch 12  loss=0.00917  val_loss=0.00936  sm_loss=0.00937  sm_val_loss=0.00943  time=0.93s
# Epoch 16  loss=0.00906  val_loss=0.00933  sm_loss=0.00927  sm_val_loss=0.00941  time=0.92s
# Epoch 17  loss=0.00903  val_loss=0.00927  sm_loss=0.00925  sm_val_loss=0.00938  time=0.92s
# Epoch 18  loss=0.00894  val_loss=0.00929  sm_loss=0.00916  sm_val_loss=0.00936  time=0.92s
# Epoch 19  loss=0.00885  val_loss=0.00916  sm_loss=0.00908  sm_val_loss=0.00927  time=0.91s
# Epoch 21  loss=0.00866  val_loss=0.00913  sm_loss=0.00889  sm_val_loss=0.00920  time=1.19s
# Epoch 22  loss=0.00852  val_loss=0.00909  sm_loss=0.00876  sm_val_loss=0.00919  time=0.98s
# Epoch 23  loss=0.00841  val_loss=0.00904  sm_loss=0.00866  sm_val_loss=0.00914  time=1.06s
# Epoch 25  loss=0.00821  val_loss=0.00903  sm_loss=0.00847  sm_val_loss=0.00913  time=0.95s
# Fold 3
# Epoch 1  loss=0.52486  val_loss=0.03187  sm_loss=0.52485  sm_val_loss=0.03188  time=0.93s
# Epoch 2  loss=0.01387  val_loss=0.01036  sm_loss=0.01383  sm_val_loss=0.01036  time=1.07s
# Epoch 3  loss=0.01003  val_loss=0.00955  sm_loss=0.01003  sm_val_loss=0.00963  time=1.59s
# Epoch 4  loss=0.00945  val_loss=0.00940  sm_loss=0.00960  sm_val_loss=0.00949  time=0.94s
# Epoch 6  loss=0.00958  val_loss=0.00941  sm_loss=0.00977  sm_val_loss=0.00949  time=1.05s
# Epoch 8  loss=0.00934  val_loss=0.00927  sm_loss=0.00954  sm_val_loss=0.00936  time=0.92s
# Epoch 10  loss=0.00929  val_loss=0.00924  sm_loss=0.00950  sm_val_loss=0.00933  time=0.95s
# Epoch 13  loss=0.00926  val_loss=0.00923  sm_loss=0.00946  sm_val_loss=0.00933  time=0.92s
# Epoch 14  loss=0.00924  val_loss=0.00921  sm_loss=0.00944  sm_val_loss=0.00931  time=0.93s
# Epoch 15  loss=0.00921  val_loss=0.00918  sm_loss=0.00941  sm_val_loss=0.00929  time=0.94s
# Epoch 16  loss=0.00916  val_loss=0.00913  sm_loss=0.00937  sm_val_loss=0.00923  time=1.13s
# Epoch 19  loss=0.00898  val_loss=0.00903  sm_loss=0.00919  sm_val_loss=0.00914  time=0.90s
# Epoch 20  loss=0.00889  val_loss=0.00897  sm_loss=0.00912  sm_val_loss=0.00908  time=0.92s
# Epoch 21  loss=0.00877  val_loss=0.00892  sm_loss=0.00900  sm_val_loss=0.00903  time=0.91s
# Epoch 22  loss=0.00864  val_loss=0.00890  sm_loss=0.00889  sm_val_loss=0.00900  time=0.92s
# Epoch 23  loss=0.00853  val_loss=0.00883  sm_loss=0.00878  sm_val_loss=0.00894  time=0.91s
# Epoch 24  loss=0.00842  val_loss=0.00880  sm_loss=0.00867  sm_val_loss=0.00892  time=0.92s
# Fold 4
# Epoch 1  loss=0.52628  val_loss=0.02939  sm_loss=0.52627  sm_val_loss=0.02927  time=0.92s
# Epoch 2  loss=0.01387  val_loss=0.01074  sm_loss=0.01385  sm_val_loss=0.01072  time=1.28s
# Epoch 3  loss=0.01017  val_loss=0.01005  sm_loss=0.01020  sm_val_loss=0.00996  time=0.93s
# Epoch 6  loss=0.00926  val_loss=0.00968  sm_loss=0.00946  sm_val_loss=0.00972  time=0.93s
# Epoch 7  loss=0.00923  val_loss=0.00955  sm_loss=0.00944  sm_val_loss=0.00964  time=0.94s
# Epoch 12  loss=0.00922  val_loss=0.00953  sm_loss=0.00942  sm_val_loss=0.00961  time=1.04s
# Epoch 14  loss=0.00920  val_loss=0.00949  sm_loss=0.00940  sm_val_loss=0.00960  time=1.01s
# Epoch 17  loss=0.00905  val_loss=0.00934  sm_loss=0.00926  sm_val_loss=0.00945  time=0.95s
# Epoch 18  loss=0.00898  val_loss=0.00932  sm_loss=0.00919  sm_val_loss=0.00941  time=0.98s
# Epoch 20  loss=0.00880  val_loss=0.00924  sm_loss=0.00902  sm_val_loss=0.00935  time=0.94s
# Epoch 21  loss=0.00869  val_loss=0.00917  sm_loss=0.00892  sm_val_loss=0.00928  time=0.91s
# Epoch 22  loss=0.00856  val_loss=0.00914  sm_loss=0.00880  sm_val_loss=0.00925  time=0.92s
# Epoch 23  loss=0.00846  val_loss=0.00909  sm_loss=0.00871  sm_val_loss=0.00921  time=1.20s
# Epoch 24  loss=0.00835  val_loss=0.00908  sm_loss=0.00860  sm_val_loss=0.00920  time=0.93s
# Epoch 25  loss=0.00831  val_loss=0.00907  sm_loss=0.00856  sm_val_loss=0.00920  time=0.93s
# Fold 5
# Epoch 1  loss=0.52721  val_loss=0.03245  sm_loss=0.52718  sm_val_loss=0.03237  time=0.91s
# Epoch 2  loss=0.01423  val_loss=0.01088  sm_loss=0.01417  sm_val_loss=0.01087  time=0.93s
# Epoch 3  loss=0.01010  val_loss=0.00996  sm_loss=0.01009  sm_val_loss=0.01003  time=0.94s
# Epoch 4  loss=0.00942  val_loss=0.00973  sm_loss=0.00956  sm_val_loss=0.00984  time=0.93s
# Epoch 8  loss=0.00932  val_loss=0.00969  sm_loss=0.00953  sm_val_loss=0.00978  time=0.91s
# Epoch 9  loss=0.00930  val_loss=0.00966  sm_loss=0.00949  sm_val_loss=0.00975  time=1.26s
# Epoch 11  loss=0.00925  val_loss=0.00966  sm_loss=0.00945  sm_val_loss=0.00974  time=1.29s
# Epoch 12  loss=0.00923  val_loss=0.00962  sm_loss=0.00943  sm_val_loss=0.00971  time=0.98s
# Epoch 13  loss=0.00921  val_loss=0.00959  sm_loss=0.00940  sm_val_loss=0.00968  time=1.16s
# Epoch 14  loss=0.00919  val_loss=0.00951  sm_loss=0.00939  sm_val_loss=0.00961  time=0.96s
# Epoch 17  loss=0.00907  val_loss=0.00943  sm_loss=0.00928  sm_val_loss=0.00953  time=1.01s
# Epoch 18  loss=0.00901  val_loss=0.00944  sm_loss=0.00922  sm_val_loss=0.00953  time=0.93s
# Epoch 19  loss=0.00893  val_loss=0.00935  sm_loss=0.00914  sm_val_loss=0.00945  time=1.17s
# Epoch 20  loss=0.00884  val_loss=0.00932  sm_loss=0.00907  sm_val_loss=0.00941  time=0.94s
# Epoch 21  loss=0.00873  val_loss=0.00932  sm_loss=0.00896  sm_val_loss=0.00941  time=0.92s
# Epoch 22  loss=0.00864  val_loss=0.00923  sm_loss=0.00887  sm_val_loss=0.00934  time=0.94s
# Epoch 23  loss=0.00851  val_loss=0.00920  sm_loss=0.00876  sm_val_loss=0.00931  time=0.93s
# Epoch 24  loss=0.00839  val_loss=0.00918  sm_loss=0.00865  sm_val_loss=0.00929  time=0.94s
# Fold 6
# Epoch 1  loss=0.52364  val_loss=0.02742  sm_loss=0.52362  sm_val_loss=0.02735  time=0.91s
# Epoch 2  loss=0.01374  val_loss=0.01030  sm_loss=0.01371  sm_val_loss=0.01030  time=0.92s
# Epoch 3  loss=0.01015  val_loss=0.00997  sm_loss=0.01018  sm_val_loss=0.00997  time=0.92s
# Epoch 4  loss=0.00976  val_loss=0.01003  sm_loss=0.00986  sm_val_loss=0.00991  time=1.07s
# Epoch 6  loss=0.00958  val_loss=0.00999  sm_loss=0.00974  sm_val_loss=0.00975  time=0.92s
# Epoch 7  loss=0.00943  val_loss=0.00912  sm_loss=0.00961  sm_val_loss=0.00924  time=0.93s
# Epoch 11  loss=0.00934  val_loss=0.00910  sm_loss=0.00954  sm_val_loss=0.00923  time=0.91s
# Epoch 14  loss=0.00933  val_loss=0.00904  sm_loss=0.00952  sm_val_loss=0.00916  time=0.91s
# Epoch 16  loss=0.00924  val_loss=0.00902  sm_loss=0.00944  sm_val_loss=0.00915  time=1.16s
# Epoch 17  loss=0.00917  val_loss=0.00895  sm_loss=0.00937  sm_val_loss=0.00909  time=0.92s
# Epoch 18  loss=0.00910  val_loss=0.00893  sm_loss=0.00931  sm_val_loss=0.00908  time=0.92s
# Epoch 19  loss=0.00902  val_loss=0.00885  sm_loss=0.00923  sm_val_loss=0.00898  time=0.97s
# Epoch 20  loss=0.00893  val_loss=0.00881  sm_loss=0.00914  sm_val_loss=0.00895  time=0.92s
# Epoch 21  loss=0.00885  val_loss=0.00878  sm_loss=0.00908  sm_val_loss=0.00892  time=0.93s
# Epoch 22  loss=0.00872  val_loss=0.00869  sm_loss=0.00895  sm_val_loss=0.00884  time=1.12s
# Epoch 23  loss=0.00861  val_loss=0.00867  sm_loss=0.00885  sm_val_loss=0.00882  time=1.06s
# Epoch 24  loss=0.00852  val_loss=0.00865  sm_loss=0.00877  sm_val_loss=0.00880  time=0.92s
# Fold 7
# Epoch 1  loss=0.52621  val_loss=0.02785  sm_loss=0.52619  sm_val_loss=0.02782  time=1.15s
# Epoch 2  loss=0.01413  val_loss=0.01010  sm_loss=0.01410  sm_val_loss=0.01010  time=0.92s
# Epoch 4  loss=0.00962  val_loss=0.00906  sm_loss=0.00976  sm_val_loss=0.00921  time=0.91s
# Epoch 5  loss=0.00957  val_loss=0.00892  sm_loss=0.00971  sm_val_loss=0.00909  time=0.91s
# Epoch 7  loss=0.00943  val_loss=0.00893  sm_loss=0.00961  sm_val_loss=0.00909  time=0.91s
# Epoch 9  loss=0.00937  val_loss=0.00883  sm_loss=0.00956  sm_val_loss=0.00899  time=0.92s
# Epoch 17  loss=0.00918  val_loss=0.00875  sm_loss=0.00938  sm_val_loss=0.00890  time=0.98s
# Epoch 18  loss=0.00912  val_loss=0.00871  sm_loss=0.00932  sm_val_loss=0.00887  time=0.92s
# Epoch 19  loss=0.00904  val_loss=0.00868  sm_loss=0.00924  sm_val_loss=0.00884  time=1.21s
# Epoch 20  loss=0.00896  val_loss=0.00863  sm_loss=0.00917  sm_val_loss=0.00880  time=1.08s
# Epoch 21  loss=0.00887  val_loss=0.00858  sm_loss=0.00909  sm_val_loss=0.00875  time=0.93s
# Epoch 22  loss=0.00874  val_loss=0.00851  sm_loss=0.00897  sm_val_loss=0.00868  time=0.96s
# Epoch 23  loss=0.00861  val_loss=0.00846  sm_loss=0.00885  sm_val_loss=0.00864  time=1.54s
# Epoch 24  loss=0.00852  val_loss=0.00845  sm_loss=0.00877  sm_val_loss=0.00863  time=0.93s
# Epoch 25  loss=0.00846  val_loss=0.00844  sm_loss=0.00871  sm_val_loss=0.00862  time=0.97s
# Fold 1
# Epoch 1  loss=0.66770  val_loss=0.41837  sm_loss=0.66763  sm_val_loss=0.41807  time=0.93s
# Epoch 2  loss=0.08948  val_loss=0.02512  sm_loss=0.08937  sm_val_loss=0.02511  time=0.96s
# Epoch 3  loss=0.02221  val_loss=0.01890  sm_loss=0.02218  sm_val_loss=0.01890  time=0.90s
# Epoch 4  loss=0.01924  val_loss=0.01811  sm_loss=0.01926  sm_val_loss=0.01812  time=1.21s
# Epoch 5  loss=0.01808  val_loss=0.01782  sm_loss=0.01810  sm_val_loss=0.01782  time=0.93s
# Epoch 6  loss=0.01743  val_loss=0.01733  sm_loss=0.01747  sm_val_loss=0.01734  time=0.92s
# Epoch 7  loss=0.01697  val_loss=0.01731  sm_loss=0.01706  sm_val_loss=0.01733  time=0.90s
# Epoch 9  loss=0.01631  val_loss=0.01726  sm_loss=0.01644  sm_val_loss=0.01728  time=0.89s
# Epoch 10  loss=0.01602  val_loss=0.01718  sm_loss=0.01619  sm_val_loss=0.01717  time=0.89s
# Fold 1 log loss: 0.017275270716681154
# Fold 2
# Epoch 1  loss=0.66876  val_loss=0.36820  sm_loss=0.66868  sm_val_loss=0.36808  time=0.89s
# Epoch 2  loss=0.08830  val_loss=0.02592  sm_loss=0.08821  sm_val_loss=0.02592  time=0.89s
# Epoch 3  loss=0.02192  val_loss=0.01910  sm_loss=0.02189  sm_val_loss=0.01910  time=0.90s
# Epoch 4  loss=0.01881  val_loss=0.01764  sm_loss=0.01882  sm_val_loss=0.01767  time=1.02s
# Epoch 5  loss=0.01780  val_loss=0.01712  sm_loss=0.01783  sm_val_loss=0.01718  time=0.92s
# Epoch 6  loss=0.01713  val_loss=0.01700  sm_loss=0.01719  sm_val_loss=0.01707  time=0.90s
# Epoch 7  loss=0.01671  val_loss=0.01683  sm_loss=0.01680  sm_val_loss=0.01692  time=0.90s
# Fold 2 log loss: 0.01706664617448897
# Fold 3
# Epoch 1  loss=0.66944  val_loss=0.38109  sm_loss=0.66941  sm_val_loss=0.38081  time=0.89s
# Epoch 2  loss=0.08841  val_loss=0.02596  sm_loss=0.08831  sm_val_loss=0.02596  time=0.90s
# Epoch 3  loss=0.02236  val_loss=0.02031  sm_loss=0.02234  sm_val_loss=0.02032  time=0.91s
# Epoch 4  loss=0.01941  val_loss=0.01849  sm_loss=0.01940  sm_val_loss=0.01851  time=0.91s
# Epoch 5  loss=0.01805  val_loss=0.01785  sm_loss=0.01809  sm_val_loss=0.01788  time=0.92s
# Epoch 6  loss=0.01739  val_loss=0.01764  sm_loss=0.01741  sm_val_loss=0.01769  time=0.90s
# Epoch 8  loss=0.01657  val_loss=0.01763  sm_loss=0.01669  sm_val_loss=0.01765  time=0.89s
# Epoch 9  loss=0.01628  val_loss=0.01756  sm_loss=0.01642  sm_val_loss=0.01756  time=0.91s
# Epoch 11  loss=0.01575  val_loss=0.01757  sm_loss=0.01592  sm_val_loss=0.01752  time=1.36s
# Epoch 12  loss=0.01538  val_loss=0.01758  sm_loss=0.01560  sm_val_loss=0.01751  time=1.21s
# Fold 3 log loss: 0.01746357457003319
# Fold 4
# Epoch 1  loss=0.66851  val_loss=0.41433  sm_loss=0.66850  sm_val_loss=0.41397  time=0.94s
# Epoch 2  loss=0.08882  val_loss=0.02499  sm_loss=0.08871  sm_val_loss=0.02498  time=0.95s
# Epoch 3  loss=0.02197  val_loss=0.01967  sm_loss=0.02195  sm_val_loss=0.01967  time=0.93s
# Epoch 4  loss=0.01896  val_loss=0.01874  sm_loss=0.01896  sm_val_loss=0.01873  time=0.91s
# Epoch 5  loss=0.01800  val_loss=0.01801  sm_loss=0.01802  sm_val_loss=0.01799  time=0.90s
# Epoch 6  loss=0.01724  val_loss=0.01793  sm_loss=0.01730  sm_val_loss=0.01794  time=0.90s
# Epoch 7  loss=0.01683  val_loss=0.01767  sm_loss=0.01692  sm_val_loss=0.01770  time=1.19s
# Epoch 8  loss=0.01648  val_loss=0.01760  sm_loss=0.01661  sm_val_loss=0.01765  time=0.90s
# Fold 4 log loss: 0.017753659663779262
# Fold 5
# Epoch 1  loss=0.66834  val_loss=0.45974  sm_loss=0.66828  sm_val_loss=0.45973  time=1.11s
# Epoch 2  loss=0.08933  val_loss=0.02489  sm_loss=0.08925  sm_val_loss=0.02489  time=0.91s
# Epoch 3  loss=0.02197  val_loss=0.01936  sm_loss=0.02194  sm_val_loss=0.01937  time=0.91s
# Epoch 4  loss=0.01904  val_loss=0.01816  sm_loss=0.01904  sm_val_loss=0.01818  time=0.93s
# Epoch 5  loss=0.01789  val_loss=0.01766  sm_loss=0.01792  sm_val_loss=0.01770  time=0.92s
# Epoch 6  loss=0.01732  val_loss=0.01748  sm_loss=0.01737  sm_val_loss=0.01751  time=0.90s
# Epoch 7  loss=0.01690  val_loss=0.01732  sm_loss=0.01699  sm_val_loss=0.01734  time=0.90s
# Epoch 9  loss=0.01624  val_loss=0.01724  sm_loss=0.01639  sm_val_loss=0.01726  time=0.90s
# Epoch 12  loss=0.01516  val_loss=0.01715  sm_loss=0.01539  sm_val_loss=0.01716  time=1.11s
# Fold 5 log loss: 0.017324748484413947
# Fold 6
# Epoch 1  loss=0.66953  val_loss=0.36401  sm_loss=0.66944  sm_val_loss=0.36381  time=0.90s
# ...
# Epoch 4  loss=0.00947  val_loss=0.00973  sm_loss=0.00965  sm_val_loss=0.00981  time=0.98s
# Epoch 5  loss=0.00936  val_loss=0.00953  sm_loss=0.00954  sm_val_loss=0.00961  time=0.97s
# Epoch 8  loss=0.00926  val_loss=0.00946  sm_loss=0.00946  sm_val_loss=0.00956  time=1.10s
# Epoch 11  loss=0.00926  val_loss=0.00946  sm_loss=0.00946  sm_val_loss=0.00954  time=0.97s
# Epoch 13  loss=0.00923  val_loss=0.00945  sm_loss=0.00943  sm_val_loss=0.00952  time=1.17s
# Epoch 14  loss=0.00921  val_loss=0.00939  sm_loss=0.00941  sm_val_loss=0.00947  time=0.96s
# Epoch 15  loss=0.00920  val_loss=0.00926  sm_loss=0.00940  sm_val_loss=0.00935  time=0.92s
# Epoch 18  loss=0.00900  val_loss=0.00926  sm_loss=0.00922  sm_val_loss=0.00935  time=1.15s
# Epoch 19  loss=0.00891  val_loss=0.00920  sm_loss=0.00913  sm_val_loss=0.00930  time=0.93s
# Epoch 20  loss=0.00881  val_loss=0.00918  sm_loss=0.00903  sm_val_loss=0.00928  time=0.92s
# Epoch 21  loss=0.00873  val_loss=0.00914  sm_loss=0.00897  sm_val_loss=0.00924  time=0.93s
# Epoch 22  loss=0.00860  val_loss=0.00905  sm_loss=0.00885  sm_val_loss=0.00915  time=1.11s
# Epoch 23  loss=0.00848  val_loss=0.00903  sm_loss=0.00873  sm_val_loss=0.00913  time=0.92s
# Epoch 25  loss=0.00832  val_loss=0.00901  sm_loss=0.00858  sm_val_loss=0.00912  time=0.92s
# Fold 3
# Epoch 1  loss=0.52441  val_loss=0.04839  sm_loss=0.52440  sm_val_loss=0.04839  time=0.91s
# Epoch 2  loss=0.01448  val_loss=0.01016  sm_loss=0.01444  sm_val_loss=0.01018  time=0.92s
# Epoch 3  loss=0.00998  val_loss=0.00944  sm_loss=0.01002  sm_val_loss=0.00954  time=1.03s
# Epoch 5  loss=0.00951  val_loss=0.00938  sm_loss=0.00970  sm_val_loss=0.00946  time=0.91s
# Epoch 6  loss=0.00934  val_loss=0.00935  sm_loss=0.00956  sm_val_loss=0.00946  time=0.91s
# Epoch 7  loss=0.00935  val_loss=0.00933  sm_loss=0.00954  sm_val_loss=0.00943  time=0.91s
# Epoch 8  loss=0.00932  val_loss=0.00922  sm_loss=0.00953  sm_val_loss=0.00933  time=0.92s
# Epoch 13  loss=0.00927  val_loss=0.00920  sm_loss=0.00947  sm_val_loss=0.00929  time=0.93s
# Epoch 15  loss=0.00921  val_loss=0.00918  sm_loss=0.00941  sm_val_loss=0.00928  time=1.14s
# Epoch 16  loss=0.00916  val_loss=0.00909  sm_loss=0.00936  sm_val_loss=0.00919  time=0.92s
# Epoch 18  loss=0.00905  val_loss=0.00902  sm_loss=0.00926  sm_val_loss=0.00911  time=0.93s
# Epoch 19  loss=0.00897  val_loss=0.00899  sm_loss=0.00919  sm_val_loss=0.00909  time=0.91s
# Epoch 20  loss=0.00886  val_loss=0.00899  sm_loss=0.00909  sm_val_loss=0.00908  time=1.27s
# Epoch 21  loss=0.00875  val_loss=0.00889  sm_loss=0.00898  sm_val_loss=0.00900  time=0.96s
# Epoch 22  loss=0.00865  val_loss=0.00884  sm_loss=0.00889  sm_val_loss=0.00895  time=0.92s
# Epoch 24  loss=0.00841  val_loss=0.00882  sm_loss=0.00867  sm_val_loss=0.00893  time=0.94s
# Epoch 25  loss=0.00834  val_loss=0.00882  sm_loss=0.00860  sm_val_loss=0.00893  time=1.06s
# Fold 4
# Epoch 1  loss=0.52649  val_loss=0.03462  sm_loss=0.52648  sm_val_loss=0.03445  time=0.92s
# Epoch 2  loss=0.01530  val_loss=0.01099  sm_loss=0.01523  sm_val_loss=0.01072  time=1.10s
# Epoch 3  loss=0.01022  val_loss=0.01056  sm_loss=0.01027  sm_val_loss=0.01050  time=0.96s
# Epoch 4  loss=0.00973  val_loss=0.01017  sm_loss=0.00989  sm_val_loss=0.01014  time=0.93s
# Epoch 7  loss=0.00937  val_loss=0.00964  sm_loss=0.00958  sm_val_loss=0.00975  time=0.97s
# Epoch 8  loss=0.00929  val_loss=0.00963  sm_loss=0.00949  sm_val_loss=0.00973  time=1.12s
# Epoch 10  loss=0.00924  val_loss=0.00960  sm_loss=0.00944  sm_val_loss=0.00970  time=1.23s
# Epoch 13  loss=0.00916  val_loss=0.00951  sm_loss=0.00937  sm_val_loss=0.00962  time=1.04s
# Epoch 14  loss=0.00913  val_loss=0.00952  sm_loss=0.00934  sm_val_loss=0.00961  time=0.96s
# Epoch 15  loss=0.00907  val_loss=0.00949  sm_loss=0.00928  sm_val_loss=0.00959  time=0.94s
# Epoch 16  loss=0.00906  val_loss=0.00942  sm_loss=0.00927  sm_val_loss=0.00953  time=0.94s
# Epoch 17  loss=0.00901  val_loss=0.00939  sm_loss=0.00922  sm_val_loss=0.00950  time=0.95s
# Epoch 18  loss=0.00891  val_loss=0.00932  sm_loss=0.00913  sm_val_loss=0.00942  time=0.93s
# Epoch 19  loss=0.00883  val_loss=0.00930  sm_loss=0.00905  sm_val_loss=0.00940  time=0.92s
# Epoch 20  loss=0.00879  val_loss=0.00926  sm_loss=0.00902  sm_val_loss=0.00937  time=0.93s
# Epoch 21  loss=0.00864  val_loss=0.00919  sm_loss=0.00887  sm_val_loss=0.00932  time=1.19s
# Epoch 22  loss=0.00852  val_loss=0.00916  sm_loss=0.00876  sm_val_loss=0.00928  time=0.97s
# Epoch 23  loss=0.00838  val_loss=0.00912  sm_loss=0.00863  sm_val_loss=0.00924  time=0.94s
# Epoch 24  loss=0.00829  val_loss=0.00910  sm_loss=0.00855  sm_val_loss=0.00923  time=1.21s
# Epoch 25  loss=0.00822  val_loss=0.00909  sm_loss=0.00848  sm_val_loss=0.00922  time=0.95s
# Fold 5
# Epoch 1  loss=0.52554  val_loss=0.03230  sm_loss=0.52552  sm_val_loss=0.03212  time=0.93s
# Epoch 2  loss=0.01402  val_loss=0.01055  sm_loss=0.01397  sm_val_loss=0.01056  time=0.92s
# Epoch 3  loss=0.01005  val_loss=0.00982  sm_loss=0.01005  sm_val_loss=0.00992  time=0.92s
# Epoch 5  loss=0.00940  val_loss=0.00965  sm_loss=0.00957  sm_val_loss=0.00974  time=0.90s
# Epoch 6  loss=0.00926  val_loss=0.00965  sm_loss=0.00946  sm_val_loss=0.00973  time=1.45s
# Epoch 9  loss=0.00922  val_loss=0.00961  sm_loss=0.00942  sm_val_loss=0.00972  time=0.91s
# Epoch 11  loss=0.00921  val_loss=0.00957  sm_loss=0.00941  sm_val_loss=0.00966  time=0.91s
# Epoch 14  loss=0.00916  val_loss=0.00955  sm_loss=0.00936  sm_val_loss=0.00964  time=0.91s
# Epoch 15  loss=0.00915  val_loss=0.00954  sm_loss=0.00935  sm_val_loss=0.00959  time=0.92s
# Epoch 17  loss=0.00907  val_loss=0.00948  sm_loss=0.00928  sm_val_loss=0.00958  time=1.12s
# Epoch 18  loss=0.00899  val_loss=0.00938  sm_loss=0.00921  sm_val_loss=0.00948  time=0.92s
# Epoch 20  loss=0.00883  val_loss=0.00933  sm_loss=0.00906  sm_val_loss=0.00943  time=0.94s
# Epoch 21  loss=0.00873  val_loss=0.00928  sm_loss=0.00896  sm_val_loss=0.00938  time=0.92s
# Epoch 22  loss=0.00862  val_loss=0.00919  sm_loss=0.00886  sm_val_loss=0.00929  time=0.93s
# Epoch 23  loss=0.00851  val_loss=0.00918  sm_loss=0.00875  sm_val_loss=0.00929  time=0.92s
# Epoch 24  loss=0.00839  val_loss=0.00916  sm_loss=0.00865  sm_val_loss=0.00927  time=0.96s
# Epoch 25  loss=0.00834  val_loss=0.00915  sm_loss=0.00860  sm_val_loss=0.00926  time=0.91s
# Fold 6
# Epoch 1  loss=0.52697  val_loss=0.03835  sm_loss=0.52695  sm_val_loss=0.03806  time=0.91s
# Epoch 2  loss=0.01396  val_loss=0.01059  sm_loss=0.01393  sm_val_loss=0.01059  time=0.94s
# Epoch 3  loss=0.01009  val_loss=0.00946  sm_loss=0.01011  sm_val_loss=0.00955  time=1.19s
# Epoch 7  loss=0.00950  val_loss=0.00920  sm_loss=0.00972  sm_val_loss=0.00933  time=0.92s
# Epoch 10  loss=0.00937  val_loss=0.00909  sm_loss=0.00957  sm_val_loss=0.00920  time=0.91s
# Epoch 12  loss=0.00934  val_loss=0.00907  sm_loss=0.00954  sm_val_loss=0.00919  time=0.91s
# Epoch 15  loss=0.00929  val_loss=0.00900  sm_loss=0.00949  sm_val_loss=0.00914  time=0.92s
# Epoch 16  loss=0.00926  val_loss=0.00903  sm_loss=0.00947  sm_val_loss=0.00914  time=0.97s
# Epoch 17  loss=0.00917  val_loss=0.00899  sm_loss=0.00937  sm_val_loss=0.00912  time=1.17s
# Epoch 18  loss=0.00910  val_loss=0.00888  sm_loss=0.00931  sm_val_loss=0.00900  time=0.97s
# Epoch 21  loss=0.00885  val_loss=0.00878  sm_loss=0.00907  sm_val_loss=0.00891  time=0.93s
# Epoch 22  loss=0.00874  val_loss=0.00872  sm_loss=0.00897  sm_val_loss=0.00886  time=0.99s
# Epoch 23  loss=0.00862  val_loss=0.00869  sm_loss=0.00885  sm_val_loss=0.00884  time=0.92s
# Epoch 24  loss=0.00851  val_loss=0.00865  sm_loss=0.00875  sm_val_loss=0.00880  time=1.17s
# Epoch 25  loss=0.00849  val_loss=0.00865  sm_loss=0.00874  sm_val_loss=0.00880  time=0.92s
# Fold 7
# Epoch 1  loss=0.52528  val_loss=0.02700  sm_loss=0.52525  sm_val_loss=0.02699  time=0.93s
# Epoch 2  loss=0.01403  val_loss=0.01002  sm_loss=0.01400  sm_val_loss=0.01003  time=0.93s
# Epoch 3  loss=0.01017  val_loss=0.00919  sm_loss=0.01018  sm_val_loss=0.00929  time=0.93s
# Epoch 4  loss=0.00946  val_loss=0.00903  sm_loss=0.00962  sm_val_loss=0.00917  time=0.93s
# Epoch 5  loss=0.00941  val_loss=0.00896  sm_loss=0.00959  sm_val_loss=0.00912  time=0.92s
# Epoch 6  loss=0.00944  val_loss=0.00898  sm_loss=0.00961  sm_val_loss=0.00911  time=0.92s
# Epoch 7  loss=0.00937  val_loss=0.00896  sm_loss=0.00956  sm_val_loss=0.00910  time=0.94s
# Epoch 8  loss=0.00938  val_loss=0.00893  sm_loss=0.00956  sm_val_loss=0.00908  time=0.93s
# Epoch 11  loss=0.00935  val_loss=0.00892  sm_loss=0.00954  sm_val_loss=0.00908  time=1.14s
# Epoch 13  loss=0.00931  val_loss=0.00883  sm_loss=0.00950  sm_val_loss=0.00900  time=0.95s
# Epoch 15  loss=0.00925  val_loss=0.00880  sm_loss=0.00944  sm_val_loss=0.00896  time=0.91s
# Epoch 18  loss=0.00909  val_loss=0.00872  sm_loss=0.00929  sm_val_loss=0.00888  time=0.93s
# Epoch 19  loss=0.00901  val_loss=0.00868  sm_loss=0.00922  sm_val_loss=0.00884  time=1.12s
# Epoch 20  loss=0.00893  val_loss=0.00856  sm_loss=0.00914  sm_val_loss=0.00873  time=1.22s
# Epoch 21  loss=0.00881  val_loss=0.00851  sm_loss=0.00903  sm_val_loss=0.00869  time=0.96s
# Epoch 22  loss=0.00870  val_loss=0.00847  sm_loss=0.00893  sm_val_loss=0.00864  time=0.97s
# Epoch 23  loss=0.00856  val_loss=0.00844  sm_loss=0.00880  sm_val_loss=0.00862  time=0.95s
# Epoch 24  loss=0.00845  val_loss=0.00841  sm_loss=0.00870  sm_val_loss=0.00859  time=0.92s
# Epoch 25  loss=0.00839  val_loss=0.00840  sm_loss=0.00865  sm_val_loss=0.00859  time=0.92s
# Fold 1
# Epoch 1  loss=0.66818  val_loss=0.41497  sm_loss=0.66817  sm_val_loss=0.41476  time=0.90s
# Epoch 2  loss=0.08950  val_loss=0.02448  sm_loss=0.08940  sm_val_loss=0.02447  time=0.92s
# Epoch 3  loss=0.02195  val_loss=0.01899  sm_loss=0.02194  sm_val_loss=0.01899  time=0.90s
# Epoch 4  loss=0.01900  val_loss=0.01810  sm_loss=0.01900  sm_val_loss=0.01812  time=0.90s
# Epoch 5  loss=0.01800  val_loss=0.01760  sm_loss=0.01804  sm_val_loss=0.01762  time=0.95s
# Epoch 6  loss=0.01732  val_loss=0.01750  sm_loss=0.01739  sm_val_loss=0.01752  time=1.07s
# Epoch 8  loss=0.01712  val_loss=0.01745  sm_loss=0.01721  sm_val_loss=0.01747  time=0.92s
# Epoch 9  loss=0.01664  val_loss=0.01735  sm_loss=0.01679  sm_val_loss=0.01734  time=0.95s
# Epoch 10  loss=0.01625  val_loss=0.01729  sm_loss=0.01643  sm_val_loss=0.01729  time=0.93s
# Epoch 11  loss=0.01593  val_loss=0.01725  sm_loss=0.01613  sm_val_loss=0.01722  time=0.94s
# Epoch 12  loss=0.01566  val_loss=0.01720  sm_loss=0.01588  sm_val_loss=0.01718  time=0.93s
# Fold 1 log loss: 0.017287584563189174
# Fold 2
# Epoch 1  loss=0.66900  val_loss=0.45913  sm_loss=0.66896  sm_val_loss=0.45910  time=0.91s
# Epoch 2  loss=0.08807  val_loss=0.02289  sm_loss=0.08801  sm_val_loss=0.02288  time=0.93s
# Epoch 3  loss=0.02193  val_loss=0.01910  sm_loss=0.02191  sm_val_loss=0.01911  time=1.11s
# Epoch 4  loss=0.01899  val_loss=0.01769  sm_loss=0.01900  sm_val_loss=0.01772  time=1.22s
# Epoch 5  loss=0.01795  val_loss=0.01713  sm_loss=0.01797  sm_val_loss=0.01719  time=0.95s
# Epoch 6  loss=0.01731  val_loss=0.01706  sm_loss=0.01737  sm_val_loss=0.01711  time=1.19s
# Epoch 7  loss=0.01690  val_loss=0.01686  sm_loss=0.01699  sm_val_loss=0.01693  time=0.94s
# Epoch 10  loss=0.01591  val_loss=0.01691  sm_loss=0.01610  sm_val_loss=0.01693  time=0.97s
# Fold 2 log loss: 0.01705572104842388
# Fold 3
# Epoch 1  loss=0.66973  val_loss=0.38986  sm_loss=0.66969  sm_val_loss=0.38981  time=0.90s
# Epoch 2  loss=0.09042  val_loss=0.03739  sm_loss=0.09030  sm_val_loss=0.03739  time=0.89s
# Epoch 3  loss=0.02250  val_loss=0.01962  sm_loss=0.02248  sm_val_loss=0.01962  time=0.89s
# Epoch 4  loss=0.01899  val_loss=0.01865  sm_loss=0.01899  sm_val_loss=0.01866  time=0.91s
# Epoch 5  loss=0.01812  val_loss=0.01798  sm_loss=0.01813  sm_val_loss=0.01801  time=0.90s
# Epoch 6  loss=0.01730  val_loss=0.01775  sm_loss=0.01737  sm_val_loss=0.01780  time=1.00s
# Epoch 8  loss=0.01645  val_loss=0.01765  sm_loss=0.01658  sm_val_loss=0.01769  time=0.88s
# Epoch 10  loss=0.01584  val_loss=0.01759  sm_loss=0.01602  sm_val_loss=0.01761  time=0.92s
# Epoch 11  loss=0.01568  val_loss=0.01762  sm_loss=0.01584  sm_val_loss=0.01760  time=0.90s
# Fold 3 log loss: 0.01755119250445054
# Fold 4
# Epoch 1  loss=0.67236  val_loss=0.34856  sm_loss=0.67235  sm_val_loss=0.34847  time=0.89s
# Epoch 2  loss=0.09061  val_loss=0.03218  sm_loss=0.09055  sm_val_loss=0.03209  time=0.92s
# Epoch 3  loss=0.02278  val_loss=0.02002  sm_loss=0.02275  sm_val_loss=0.02003  time=0.91s
# Epoch 4  loss=0.01947  val_loss=0.01885  sm_loss=0.01946  sm_val_loss=0.01885  time=0.91s
# Epoch 5  loss=0.01830  val_loss=0.01823  sm_loss=0.01831  sm_val_loss=0.01825  time=0.91s
# Epoch 6  loss=0.01761  val_loss=0.01806  sm_loss=0.01766  sm_val_loss=0.01811  time=0.91s
# Epoch 7  loss=0.01711  val_loss=0.01778  sm_loss=0.01719  sm_val_loss=0.01779  time=0.91s
# Epoch 8  loss=0.01672  val_loss=0.01759  sm_loss=0.01683  sm_val_loss=0.01761  time=1.15s
# Fold 4 log loss: 0.0177117120164324
# Fold 5
# Epoch 1  loss=0.66851  val_loss=0.45631  sm_loss=0.66849  sm_val_loss=0.45619  time=0.89s
# Epoch 2  loss=0.09034  val_loss=0.02725  sm_loss=0.09021  sm_val_loss=0.02725  time=0.93s
# Epoch 3  loss=0.02227  val_loss=0.01928  sm_loss=0.02225  sm_val_loss=0.01928  time=0.90s
# Epoch 4  loss=0.01906  val_loss=0.01818  sm_loss=0.01906  sm_val_loss=0.01821  time=0.92s
# Epoch 5  loss=0.01797  val_loss=0.01785  sm_loss=0.01801  sm_val_loss=0.01788  time=0.95s
# Epoch 6  loss=0.01739  val_loss=0.01742  sm_loss=0.01744  sm_val_loss=0.01745  time=0.92s
# Epoch 7  loss=0.01703  val_loss=0.01728  sm_loss=0.01711  sm_val_loss=0.01732  time=0.94s
# Epoch 10  loss=0.01600  val_loss=0.01729  sm_loss=0.01614  sm_val_loss=0.01729  time=0.93s
# Epoch 11  loss=0.01559  val_loss=0.01723  sm_loss=0.01580  sm_val_loss=0.01722  time=1.12s
# Epoch 12  loss=0.01521  val_loss=0.01721  sm_loss=0.01542  sm_val_loss=0.01721  time=0.90s
# Fold 5 log loss: 0.017366159552640027
# Fold 6
# Epoch 1  loss=0.67009  val_loss=0.32101  sm_loss=0.66999  sm_val_loss=0.32038  time=0.95s
# Epoch 2  loss=0.08970  val_loss=0.02508  sm_loss=0.08962  sm_val_loss=0.02508  time=0.96s
# Epoch 3  loss=0.02192  val_loss=0.01967  sm_loss=0.02190  sm_val_loss=0.01968  time=0.95s
# Epoch 4  loss=0.01887  val_loss=0.01834  sm_loss=0.01889  sm_val_loss=0.01837  time=0.91s
# Epoch 5  loss=0.01791  val_loss=0.01775  sm_loss=0.01793  sm_val_loss=0.01780  time=0.92s
# Epoch 6  loss=0.01738  val_loss=0.01760  sm_loss=0.01741  sm_val_loss=0.01766  time=0.91s
# Epoch 7  loss=0.01699  val_loss=0.01755  sm_loss=0.01708  sm_val_loss=0.01762  time=1.24s
# Epoch 8  loss=0.01676  val_loss=0.01750  sm_loss=0.01686  sm_val_loss=0.01760  time=0.96s
# Epoch 9  loss=0.01651  val_loss=0.01735  sm_loss=0.01664  sm_val_loss=0.01745  time=1.21s
# Epoch 10  loss=0.01606  val_loss=0.01729  sm_loss=0.01623  sm_val_loss=0.01740  time=0.90s
# Epoch 11  loss=0.01579  val_loss=0.01725  sm_loss=0.01598  sm_val_loss=0.01735  time=0.91s
# Fold 6 log loss: 0.01737984337214005
# Fold 7
# Epoch 1  loss=0.66797  val_loss=0.40411  sm_loss=0.66793  sm_val_loss=0.40355  time=0.89s
# Epoch 2  loss=0.08907  val_loss=0.02375  sm_loss=0.08896  sm_val_loss=0.02373  time=0.89s
# Epoch 3  loss=0.02192  val_loss=0.01919  sm_loss=0.02191  sm_val_loss=0.01920  time=0.91s
# Epoch 4  loss=0.01887  val_loss=0.01807  sm_loss=0.01886  sm_val_loss=0.01809  time=0.90s
# Epoch 5  loss=0.01774  val_loss=0.01756  sm_loss=0.01778  sm_val_loss=0.01760  time=0.91s
# Epoch 6  loss=0.01713  val_loss=0.01731  sm_loss=0.01718  sm_val_loss=0.01735  time=0.89s
# Epoch 8  loss=0.01641  val_loss=0.01712  sm_loss=0.01653  sm_val_loss=0.01720  time=0.89s
# Epoch 11  loss=0.01538  val_loss=0.01708  sm_loss=0.01557  sm_val_loss=0.01715  time=0.92s
# Epoch 12  loss=0.01505  val_loss=0.01707  sm_loss=0.01527  sm_val_loss=0.01714  time=0.90s
# Fold 7 log loss: 0.017174002550282223
# Seed 5
# Fold 1 log loss: 0.017287584563189174
# Fold 2 log loss: 0.01705572104842388
# Fold 3 log loss: 0.01755119250445054
# Fold 4 log loss: 0.0177117120164324
# Fold 5 log loss: 0.017366159552640027
# Fold 6 log loss: 0.01737984337214005
# Fold 7 log loss: 0.017174002550282223
# Std of log loss: 0.00020462747470145672
# Total log loss: 0.017361112397728015
# Total log loss in targets: 0.01710564547149861

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6429294973475078

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015765293810718617

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

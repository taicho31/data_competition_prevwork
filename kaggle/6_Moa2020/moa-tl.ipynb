# %% [markdown]
# - change model architectures
# - 7 ensembles

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 34

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[vc <= 19].index.sort_values()
vc2 = vc.loc[vc > 19].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[1, 4, 5, ..., 4, 4, 5]], dtype=int8)

# %%
#non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
#nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
#nontarget_dists.columns = ["target", "number"]
#nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
#drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
#print("first drop", len(drop_list1))
#non_targets.drop(drop_list1, axis=1, inplace=True)
#print("shape after 1st drop:", non_targets.shape)
#non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
#print(len(non_target_feats))

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
#importance = pd.read_csv('../input/moa-feat-importance-rapids/output_source.csv')
#importance = importance.set_index("Feature")

#imp_scaled = importance.copy(deep=True)
#for c in imp_scaled.columns:
#    imp_scaled[c] = (1 - preprocessing.MinMaxScaler().fit_transform(imp_scaled[[c]])).round(14)

#print(imp_scaled.min().min(), imp_scaled.max().max(), imp_scaled.std().mean())

#imp_scaled["MeanImp"] = imp_scaled[target_feats].mean(axis=1)
#imp_scaled["MaxImp"]  = imp_scaled[target_feats].max(axis=1)

#thresh_mean, thresh_max = 0.35, 0.975
#fs_both = imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) & (imp_scaled.MaxImp >= thresh_max), Targets]
#fs_any = list(imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) | (imp_scaled.MaxImp >= thresh_max), target_feats].index)
#len(fs_any)

X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.7)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
print(len(drop_feats))

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)
# Out:
# 33

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 918) (3624, 918)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_non_targets = non_targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1

        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
            
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_features, num_targets):
        super(MoaModel, self).__init__()
        self.hidden_size = [2048, 1024, 512]
        self.dropout_value = [0.5, 0.5, 0.5]

        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dense1 = nn.Linear(num_features, self.hidden_size[0])
        
        self.batch_norm2 = nn.BatchNorm1d(self.hidden_size[0])
        self.dropout2 = nn.Dropout(self.dropout_value[0])
        self.dense2 = nn.Linear(self.hidden_size[0], self.hidden_size[1])

        self.batch_norm3 = nn.BatchNorm1d(self.hidden_size[1])
        self.dropout3 = nn.Dropout(self.dropout_value[1])
        self.dense3 = nn.Linear(self.hidden_size[1], self.hidden_size[2])

        self.batch_norm5 = nn.BatchNorm1d(self.hidden_size[2])
        self.dropout5 = nn.Dropout(self.dropout_value[2])
        self.dense5 = nn.utils.weight_norm(nn.Linear(self.hidden_size[2], num_targets))
        
    def forward(self, x):
        x = self.batch_norm1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))

        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.leaky_relu(self.dense3(x))

        x = self.batch_norm5(x)
        x = self.dropout5(x)
        x = self.dense5(x)
        return x
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

hidden_size = [2048, 1024, 512]
dropout_value = [0.5, 0.5, 0.5]

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    if files == []:
        train_epochs = 25
        ans = []   
    else:
        train_epochs = 20
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr[:,-1] == fold
        train_index = tr[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(tr[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index,:], dtype=torch.float32)
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, 608)

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            clf.batch_norm5 = nn.BatchNorm1d(hidden_size[2])
            clf.dropout5 = nn.Dropout(dropout_value[2])
            clf.dense5 = nn.utils.weight_norm(nn.Linear(hidden_size[-1], len(target_feats)))
            optimizer = optim.Adam(clf.parameters(), lr = 1e-3, weight_decay=3e-6) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=2e2, 
                                              max_lr=3e-3, epochs=train_epochs, steps_per_epoch=len(train_loader))         
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 1e-3, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=2e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))   
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-params_seed'+str(sample_seed)+'_fold'+str(fold+1)+'.pt')
                
        if files == []:
            pred_model = MoaModel(init_num, 608)
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-params_seed'+str(sample_seed)+'_fold'+str(fold+1)+'.pt'))         
        pred_model.eval()
        
        if files != []:
            # validation check ----------------
            oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
            print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
            scores.append(mean_log_loss(target_epoch, oof_epoch))
            oof[valid_index,:] = oof_epoch
            oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
            # test predcition --------------
            test_preds = np.zeros([test_len, target.shape[1]])
            for i, (x_batch,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
    
    if files != []:
        print("Seed {}".format(sample_seed))
        for i, ele in enumerate(scores):
            print("Fold {} log loss: {}".format(i+1, scores[i]))
        print("Std of log loss: {}".format(np.std(scores)))
        print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4,5,6] 
    
for seed_ in seeds:
    files = torch_tl(fn_train, fn_all_targets, fn_test, seed_, fn_train.shape[1]-1, [])
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.46328  val_loss=0.01385  sm_loss=0.46314  sm_val_loss=0.01374  time=1.74s
# Epoch 2  loss=0.01135  val_loss=0.01069  sm_loss=0.01125  sm_val_loss=0.01071  time=0.97s
# Epoch 3  loss=0.01000  val_loss=0.01025  sm_loss=0.01007  sm_val_loss=0.01031  time=0.97s
# Epoch 4  loss=0.00991  val_loss=0.01017  sm_loss=0.01007  sm_val_loss=0.01023  time=1.00s
# Epoch 5  loss=0.00970  val_loss=0.01008  sm_loss=0.00986  sm_val_loss=0.01013  time=0.94s
# Epoch 6  loss=0.00951  val_loss=0.01005  sm_loss=0.00970  sm_val_loss=0.01012  time=0.93s
# Epoch 8  loss=0.00954  val_loss=0.01003  sm_loss=0.00971  sm_val_loss=0.01007  time=1.07s
# Epoch 11  loss=0.00958  val_loss=0.00998  sm_loss=0.00975  sm_val_loss=0.01006  time=0.94s
# Epoch 16  loss=0.00941  val_loss=0.00995  sm_loss=0.00959  sm_val_loss=0.01004  time=0.93s
# Epoch 17  loss=0.00937  val_loss=0.00991  sm_loss=0.00955  sm_val_loss=0.00997  time=0.93s
# Epoch 18  loss=0.00929  val_loss=0.00980  sm_loss=0.00948  sm_val_loss=0.00989  time=0.94s
# Epoch 19  loss=0.00924  val_loss=0.00976  sm_loss=0.00944  sm_val_loss=0.00985  time=1.04s
# Epoch 20  loss=0.00912  val_loss=0.00967  sm_loss=0.00932  sm_val_loss=0.00976  time=1.05s
# Epoch 21  loss=0.00903  val_loss=0.00964  sm_loss=0.00925  sm_val_loss=0.00975  time=0.93s
# Epoch 22  loss=0.00889  val_loss=0.00952  sm_loss=0.00911  sm_val_loss=0.00963  time=0.94s
# Epoch 23  loss=0.00875  val_loss=0.00944  sm_loss=0.00899  sm_val_loss=0.00956  time=0.97s
# Epoch 24  loss=0.00865  val_loss=0.00942  sm_loss=0.00890  sm_val_loss=0.00954  time=0.98s
# Epoch 25  loss=0.00859  val_loss=0.00940  sm_loss=0.00884  sm_val_loss=0.00953  time=0.95s
# Fold 2
# Epoch 1  loss=0.46229  val_loss=0.01607  sm_loss=0.46216  sm_val_loss=0.01568  time=0.95s
# Epoch 2  loss=0.01122  val_loss=0.01023  sm_loss=0.01116  sm_val_loss=0.01028  time=0.95s
# Epoch 3  loss=0.01004  val_loss=0.00998  sm_loss=0.01015  sm_val_loss=0.01007  time=0.99s
# Epoch 4  loss=0.01014  val_loss=0.00975  sm_loss=0.01025  sm_val_loss=0.00982  time=0.96s
# Epoch 5  loss=0.00965  val_loss=0.00962  sm_loss=0.00984  sm_val_loss=0.00967  time=1.60s
# Epoch 16  loss=0.00947  val_loss=0.00951  sm_loss=0.00965  sm_val_loss=0.00956  time=1.26s
# Epoch 17  loss=0.00942  val_loss=0.00950  sm_loss=0.00961  sm_val_loss=0.00955  time=1.27s
# Epoch 18  loss=0.00938  val_loss=0.00947  sm_loss=0.00957  sm_val_loss=0.00952  time=0.95s
# Epoch 19  loss=0.00927  val_loss=0.00941  sm_loss=0.00948  sm_val_loss=0.00946  time=0.98s
# Epoch 20  loss=0.00920  val_loss=0.00929  sm_loss=0.00941  sm_val_loss=0.00936  time=0.93s
# Epoch 21  loss=0.00906  val_loss=0.00921  sm_loss=0.00928  sm_val_loss=0.00930  time=0.98s
# Epoch 22  loss=0.00898  val_loss=0.00912  sm_loss=0.00920  sm_val_loss=0.00921  time=0.97s
# Epoch 23  loss=0.00883  val_loss=0.00906  sm_loss=0.00907  sm_val_loss=0.00916  time=0.93s
# Epoch 24  loss=0.00869  val_loss=0.00903  sm_loss=0.00894  sm_val_loss=0.00914  time=0.94s
# Fold 3
# Epoch 1  loss=0.46436  val_loss=0.01417  sm_loss=0.46417  sm_val_loss=0.01334  time=0.99s
# Epoch 2  loss=0.01108  val_loss=0.01004  sm_loss=0.01101  sm_val_loss=0.01006  time=0.95s
# Epoch 3  loss=0.01023  val_loss=0.00969  sm_loss=0.01027  sm_val_loss=0.00979  time=0.94s
# Epoch 5  loss=0.00972  val_loss=0.00948  sm_loss=0.00989  sm_val_loss=0.00955  time=0.93s
# Epoch 14  loss=0.00964  val_loss=0.00944  sm_loss=0.00981  sm_val_loss=0.00951  time=0.92s
# Epoch 16  loss=0.00954  val_loss=0.00934  sm_loss=0.00972  sm_val_loss=0.00942  time=0.93s
# Epoch 17  loss=0.00946  val_loss=0.00930  sm_loss=0.00965  sm_val_loss=0.00937  time=0.94s
# Epoch 18  loss=0.00940  val_loss=0.00929  sm_loss=0.00960  sm_val_loss=0.00937  time=0.92s
# Epoch 19  loss=0.00934  val_loss=0.00917  sm_loss=0.00954  sm_val_loss=0.00927  time=0.93s
# Epoch 20  loss=0.00922  val_loss=0.00910  sm_loss=0.00942  sm_val_loss=0.00920  time=1.01s
# Epoch 21  loss=0.00911  val_loss=0.00905  sm_loss=0.00933  sm_val_loss=0.00913  time=0.96s
# Epoch 22  loss=0.00899  val_loss=0.00898  sm_loss=0.00922  sm_val_loss=0.00908  time=1.20s
# Epoch 23  loss=0.00886  val_loss=0.00888  sm_loss=0.00910  sm_val_loss=0.00899  time=0.95s
# Epoch 24  loss=0.00874  val_loss=0.00885  sm_loss=0.00899  sm_val_loss=0.00897  time=0.96s
# Epoch 25  loss=0.00867  val_loss=0.00886  sm_loss=0.00893  sm_val_loss=0.00897  time=0.98s
# Fold 4
# Epoch 1  loss=0.45998  val_loss=0.01412  sm_loss=0.45986  sm_val_loss=0.01367  time=0.93s
# Epoch 2  loss=0.01105  val_loss=0.01044  sm_loss=0.01102  sm_val_loss=0.01039  time=0.94s
# Epoch 4  loss=0.00965  val_loss=0.00997  sm_loss=0.00984  sm_val_loss=0.00992  time=0.94s
# Epoch 5  loss=0.00958  val_loss=0.00974  sm_loss=0.00976  sm_val_loss=0.00979  time=0.98s
# Epoch 17  loss=0.00947  val_loss=0.00965  sm_loss=0.00965  sm_val_loss=0.00973  time=1.11s
# Epoch 18  loss=0.00939  val_loss=0.00954  sm_loss=0.00958  sm_val_loss=0.00963  time=1.24s
# Epoch 19  loss=0.00927  val_loss=0.00952  sm_loss=0.00947  sm_val_loss=0.00960  time=1.00s
# Epoch 20  loss=0.00917  val_loss=0.00941  sm_loss=0.00938  sm_val_loss=0.00950  time=1.32s
# Epoch 21  loss=0.00910  val_loss=0.00939  sm_loss=0.00931  sm_val_loss=0.00949  time=0.98s
# Epoch 22  loss=0.00896  val_loss=0.00927  sm_loss=0.00919  sm_val_loss=0.00937  time=1.04s
# Epoch 23  loss=0.00883  val_loss=0.00924  sm_loss=0.00907  sm_val_loss=0.00935  time=1.27s
# Epoch 24  loss=0.00870  val_loss=0.00916  sm_loss=0.00895  sm_val_loss=0.00928  time=1.04s
# Epoch 25  loss=0.00864  val_loss=0.00915  sm_loss=0.00890  sm_val_loss=0.00927  time=1.02s
# Fold 5
# Epoch 1  loss=0.46177  val_loss=0.01324  sm_loss=0.46165  sm_val_loss=0.01321  time=1.05s
# Epoch 2  loss=0.01147  val_loss=0.01050  sm_loss=0.01138  sm_val_loss=0.01053  time=1.01s
# Epoch 3  loss=0.00992  val_loss=0.00999  sm_loss=0.01004  sm_val_loss=0.01006  time=1.23s
# Epoch 4  loss=0.00961  val_loss=0.00993  sm_loss=0.00978  sm_val_loss=0.01001  time=0.96s
# Epoch 5  loss=0.00974  val_loss=0.00996  sm_loss=0.00990  sm_val_loss=0.01000  time=0.94s
# Epoch 9  loss=0.00964  val_loss=0.00985  sm_loss=0.00981  sm_val_loss=0.00990  time=0.97s
# Epoch 12  loss=0.00962  val_loss=0.00981  sm_loss=0.00978  sm_val_loss=0.00987  time=0.95s
# Epoch 15  loss=0.00953  val_loss=0.00980  sm_loss=0.00970  sm_val_loss=0.00987  time=0.96s
# Epoch 16  loss=0.00945  val_loss=0.00973  sm_loss=0.00963  sm_val_loss=0.00981  time=0.94s
# Epoch 18  loss=0.00935  val_loss=0.00959  sm_loss=0.00954  sm_val_loss=0.00968  time=0.95s
# Epoch 19  loss=0.00927  val_loss=0.00948  sm_loss=0.00947  sm_val_loss=0.00958  time=0.96s
# Epoch 21  loss=0.00906  val_loss=0.00940  sm_loss=0.00927  sm_val_loss=0.00950  time=0.95s
# Epoch 22  loss=0.00894  val_loss=0.00931  sm_loss=0.00916  sm_val_loss=0.00941  time=1.26s
# Epoch 23  loss=0.00880  val_loss=0.00929  sm_loss=0.00904  sm_val_loss=0.00939  time=1.01s
# Epoch 24  loss=0.00871  val_loss=0.00922  sm_loss=0.00896  sm_val_loss=0.00934  time=1.15s
# Fold 6
# Epoch 1  loss=0.46185  val_loss=0.01838  sm_loss=0.46168  sm_val_loss=0.01766  time=1.01s
# Epoch 2  loss=0.01161  val_loss=0.01114  sm_loss=0.01152  sm_val_loss=0.01074  time=0.95s
# Epoch 3  loss=0.01065  val_loss=0.00981  sm_loss=0.01069  sm_val_loss=0.00989  time=0.93s
# Epoch 4  loss=0.01004  val_loss=0.00954  sm_loss=0.01019  sm_val_loss=0.00965  time=0.94s
# Epoch 6  loss=0.00979  val_loss=0.00942  sm_loss=0.00996  sm_val_loss=0.00952  time=0.93s
# Epoch 7  loss=0.00972  val_loss=0.00929  sm_loss=0.00989  sm_val_loss=0.00942  time=0.99s
# Epoch 14  loss=0.00962  val_loss=0.00925  sm_loss=0.00978  sm_val_loss=0.00939  time=0.93s
# Epoch 15  loss=0.00957  val_loss=0.00926  sm_loss=0.00975  sm_val_loss=0.00936  time=0.94s
# Epoch 16  loss=0.00954  val_loss=0.00913  sm_loss=0.00972  sm_val_loss=0.00926  time=0.95s
# Epoch 17  loss=0.00945  val_loss=0.00905  sm_loss=0.00963  sm_val_loss=0.00916  time=0.94s
# Epoch 19  loss=0.00932  val_loss=0.00900  sm_loss=0.00951  sm_val_loss=0.00912  time=0.95s
# Epoch 20  loss=0.00920  val_loss=0.00892  sm_loss=0.00940  sm_val_loss=0.00904  time=1.13s
# Epoch 21  loss=0.00912  val_loss=0.00890  sm_loss=0.00933  sm_val_loss=0.00904  time=1.01s
# Epoch 22  loss=0.00900  val_loss=0.00874  sm_loss=0.00922  sm_val_loss=0.00888  time=0.94s
# Epoch 23  loss=0.00886  val_loss=0.00872  sm_loss=0.00909  sm_val_loss=0.00887  time=0.94s
# Epoch 24  loss=0.00874  val_loss=0.00870  sm_loss=0.00899  sm_val_loss=0.00885  time=0.96s
# Epoch 25  loss=0.00866  val_loss=0.00869  sm_loss=0.00892  sm_val_loss=0.00884  time=0.96s
# Fold 7
# Epoch 1  loss=0.46573  val_loss=0.01291  sm_loss=0.46557  sm_val_loss=0.01281  time=1.07s
# Epoch 2  loss=0.01160  val_loss=0.00989  sm_loss=0.01148  sm_val_loss=0.00986  time=1.57s
# Epoch 3  loss=0.01010  val_loss=0.00930  sm_loss=0.01017  sm_val_loss=0.00942  time=0.94s
# Epoch 4  loss=0.00979  val_loss=0.00908  sm_loss=0.00993  sm_val_loss=0.00923  time=0.99s
# Epoch 11  loss=0.00973  val_loss=0.00904  sm_loss=0.00988  sm_val_loss=0.00921  time=0.96s
# Epoch 13  loss=0.00972  val_loss=0.00904  sm_loss=0.00988  sm_val_loss=0.00919  time=0.96s
# Epoch 17  loss=0.00954  val_loss=0.00898  sm_loss=0.00971  sm_val_loss=0.00913  time=0.97s
# Epoch 18  loss=0.00947  val_loss=0.00900  sm_loss=0.00964  sm_val_loss=0.00913  time=0.97s
# Epoch 19  loss=0.00939  val_loss=0.00883  sm_loss=0.00958  sm_val_loss=0.00899  time=0.97s
# Epoch 20  loss=0.00929  val_loss=0.00874  sm_loss=0.00949  sm_val_loss=0.00889  time=0.96s
# Epoch 21  loss=0.00918  val_loss=0.00868  sm_loss=0.00938  sm_val_loss=0.00885  time=0.94s
# Epoch 22  loss=0.00905  val_loss=0.00860  sm_loss=0.00926  sm_val_loss=0.00877  time=0.94s
# Epoch 23  loss=0.00891  val_loss=0.00852  sm_loss=0.00913  sm_val_loss=0.00870  time=0.98s
# Epoch 24  loss=0.00880  val_loss=0.00847  sm_loss=0.00904  sm_val_loss=0.00866  time=0.95s
# Epoch 25  loss=0.00872  val_loss=0.00847  sm_loss=0.00897  sm_val_loss=0.00866  time=0.99s
# Fold 1
# Epoch 1  loss=0.66684  val_loss=0.30114  sm_loss=0.66667  sm_val_loss=0.30094  time=0.99s
# Epoch 2  loss=0.06118  val_loss=0.02226  sm_loss=0.06105  sm_val_loss=0.02225  time=0.94s
# Epoch 3  loss=0.02122  val_loss=0.01879  sm_loss=0.02119  sm_val_loss=0.01880  time=0.96s
# Epoch 4  loss=0.01926  val_loss=0.01830  sm_loss=0.01925  sm_val_loss=0.01832  time=0.97s
# Epoch 5  loss=0.01848  val_loss=0.01782  sm_loss=0.01852  sm_val_loss=0.01786  time=0.93s
# Epoch 6  loss=0.01804  val_loss=0.01761  sm_loss=0.01812  sm_val_loss=0.01767  time=1.08s
# Epoch 8  loss=0.01743  val_loss=0.01743  sm_loss=0.01755  sm_val_loss=0.01747  time=0.99s
# Epoch 9  loss=0.01733  val_loss=0.01740  sm_loss=0.01745  sm_val_loss=0.01743  time=0.95s
# Epoch 10  loss=0.01707  val_loss=0.01720  sm_loss=0.01720  sm_val_loss=0.01724  time=0.95s
# Epoch 13  loss=0.01627  val_loss=0.01720  sm_loss=0.01645  sm_val_loss=0.01721  time=0.93s
# Epoch 14  loss=0.01608  val_loss=0.01719  sm_loss=0.01629  sm_val_loss=0.01717  time=0.91s
# Epoch 17  loss=0.01523  val_loss=0.01717  sm_loss=0.01550  sm_val_loss=0.01716  time=0.92s
# Epoch 18  loss=0.01499  val_loss=0.01718  sm_loss=0.01526  sm_val_loss=0.01716  time=0.95s
# Epoch 19  loss=0.01482  val_loss=0.01719  sm_loss=0.01510  sm_val_loss=0.01716  time=0.99s
# Fold 1 log loss: 0.017262207014484943
# Fold 2
# Epoch 1  loss=0.66827  val_loss=0.38796  sm_loss=0.66812  sm_val_loss=0.38780  time=1.02s
# Epoch 2  loss=0.06207  val_loss=0.02079  sm_loss=0.06196  sm_val_loss=0.02082  time=0.92s
# Epoch 3  loss=0.02111  val_loss=0.01868  sm_loss=0.02107  sm_val_loss=0.01872  time=0.93s
# Epoch 4  loss=0.01947  val_loss=0.01785  sm_loss=0.01948  sm_val_loss=0.01790  time=0.93s
# Epoch 5  loss=0.01864  val_loss=0.01752  sm_loss=0.01867  sm_val_loss=0.01758  time=0.92s
# Epoch 6  loss=0.01818  val_loss=0.01728  sm_loss=0.01824  sm_val_loss=0.01736  time=0.93s
# Epoch 7  loss=0.01798  val_loss=0.01712  sm_loss=0.01803  sm_val_loss=0.01720  time=0.95s
# Epoch 8  loss=0.01762  val_loss=0.01703  sm_loss=0.01773  sm_val_loss=0.01712  time=0.92s
# Epoch 10  loss=0.01708  val_loss=0.01684  sm_loss=0.01723  sm_val_loss=0.01693  time=0.96s
# Epoch 12  loss=0.01660  val_loss=0.01676  sm_loss=0.01680  sm_val_loss=0.01683  time=1.02s
# Epoch 17  loss=0.01516  val_loss=0.01681  sm_loss=0.01543  sm_val_loss=0.01683  time=1.10s
# Fold 2 log loss: 0.01696034314467535
# Fold 3
# Epoch 1  loss=0.66722  val_loss=0.33303  sm_loss=0.66708  sm_val_loss=0.33196  time=0.95s
# Epoch 2  loss=0.06155  val_loss=0.02439  sm_loss=0.06141  sm_val_loss=0.02438  time=0.93s
# Epoch 3  loss=0.02191  val_loss=0.01951  sm_loss=0.02184  sm_val_loss=0.01954  time=0.93s
# Epoch 4  loss=0.01981  val_loss=0.01883  sm_loss=0.01977  sm_val_loss=0.01888  time=0.93s
# Epoch 5  loss=0.01908  val_loss=0.01838  sm_loss=0.01905  sm_val_loss=0.01841  time=0.94s
# Epoch 6  loss=0.01838  val_loss=0.01835  sm_loss=0.01839  sm_val_loss=0.01837  time=0.94s
# Epoch 7  loss=0.01803  val_loss=0.01805  sm_loss=0.01809  sm_val_loss=0.01807  time=0.94s
# Epoch 8  loss=0.01775  val_loss=0.01787  sm_loss=0.01784  sm_val_loss=0.01790  time=0.95s
# Epoch 9  loss=0.01742  val_loss=0.01779  sm_loss=0.01756  sm_val_loss=0.01779  time=0.94s
# Epoch 11  loss=0.01699  val_loss=0.01782  sm_loss=0.01717  sm_val_loss=0.01772  time=1.03s
# Epoch 12  loss=0.01685  val_loss=0.01763  sm_loss=0.01703  sm_val_loss=0.01760  time=0.96s
# Epoch 14  loss=0.01635  val_loss=0.01761  sm_loss=0.01657  sm_val_loss=0.01754  time=0.91s
# Epoch 15  loss=0.01620  val_loss=0.01759  sm_loss=0.01643  sm_val_loss=0.01748  time=0.92s
# Epoch 16  loss=0.01601  val_loss=0.01752  sm_loss=0.01624  sm_val_loss=0.01743  time=0.94s
# Epoch 17  loss=0.01586  val_loss=0.01754  sm_loss=0.01610  sm_val_loss=0.01742  time=0.93s
# Fold 3 log loss: 0.017373675812907764
# Fold 4
# Epoch 1  loss=0.66781  val_loss=0.46087  sm_loss=0.66764  sm_val_loss=0.45270  time=0.95s
# Epoch 2  loss=0.06183  val_loss=0.02184  sm_loss=0.06151  sm_val_loss=0.02175  time=0.96s
# Epoch 3  loss=0.02169  val_loss=0.01985  sm_loss=0.02161  sm_val_loss=0.01955  time=0.93s
# Epoch 4  loss=0.01962  val_loss=0.01919  sm_loss=0.01960  sm_val_loss=0.01893  time=1.25s
# Epoch 5  loss=0.01885  val_loss=0.01865  sm_loss=0.01888  sm_val_loss=0.01848  time=0.95s
# Epoch 6  loss=0.01828  val_loss=0.01832  sm_loss=0.01833  sm_val_loss=0.01818  time=0.92s
# Epoch 7  loss=0.01789  val_loss=0.01821  sm_loss=0.01799  sm_val_loss=0.01801  time=0.92s
# Epoch 8  loss=0.01760  val_loss=0.01798  sm_loss=0.01771  sm_val_loss=0.01790  time=0.92s
# Epoch 9  loss=0.01729  val_loss=0.01789  sm_loss=0.01744  sm_val_loss=0.01783  time=1.02s
# Epoch 10  loss=0.01705  val_loss=0.01783  sm_loss=0.01721  sm_val_loss=0.01771  time=0.97s
# Epoch 11  loss=0.01690  val_loss=0.01769  sm_loss=0.01708  sm_val_loss=0.01762  time=1.17s
# Epoch 13  loss=0.01641  val_loss=0.01757  sm_loss=0.01662  sm_val_loss=0.01755  time=0.91s
# Epoch 14  loss=0.01613  val_loss=0.01757  sm_loss=0.01634  sm_val_loss=0.01754  time=0.94s
# Epoch 16  loss=0.01558  val_loss=0.01756  sm_loss=0.01584  sm_val_loss=0.01754  time=0.96s
# Fold 4 log loss: 0.01763419709298953
# Fold 5
# Epoch 1  loss=0.66632  val_loss=0.51835  sm_loss=0.66622  sm_val_loss=0.51717  time=0.97s
# Epoch 2  loss=0.06258  val_loss=0.03060  sm_loss=0.06250  sm_val_loss=0.03061  time=0.95s
# Epoch 3  loss=0.02133  val_loss=0.01917  sm_loss=0.02127  sm_val_loss=0.01918  time=0.94s
# Epoch 4  loss=0.01919  val_loss=0.01826  sm_loss=0.01918  sm_val_loss=0.01828  time=0.92s
# Epoch 5  loss=0.01848  val_loss=0.01785  sm_loss=0.01851  sm_val_loss=0.01788  time=0.93s
# Epoch 7  loss=0.01771  val_loss=0.01764  sm_loss=0.01781  sm_val_loss=0.01769  time=1.25s
# Epoch 8  loss=0.01749  val_loss=0.01749  sm_loss=0.01761  sm_val_loss=0.01754  time=0.97s
# Epoch 9  loss=0.01719  val_loss=0.01737  sm_loss=0.01732  sm_val_loss=0.01740  time=1.22s
# Epoch 10  loss=0.01697  val_loss=0.01730  sm_loss=0.01712  sm_val_loss=0.01732  time=0.97s
# Epoch 11  loss=0.01672  val_loss=0.01720  sm_loss=0.01691  sm_val_loss=0.01723  time=1.26s
# Epoch 13  loss=0.01630  val_loss=0.01717  sm_loss=0.01652  sm_val_loss=0.01716  time=1.25s
# Epoch 14  loss=0.01600  val_loss=0.01712  sm_loss=0.01623  sm_val_loss=0.01710  time=1.08s
# Epoch 15  loss=0.01576  val_loss=0.01711  sm_loss=0.01601  sm_val_loss=0.01709  time=0.93s
# Epoch 16  loss=0.01548  val_loss=0.01708  sm_loss=0.01573  sm_val_loss=0.01705  time=0.93s
# Fold 5 log loss: 0.01721958323374678
# Fold 6
# Epoch 1  loss=0.66541  val_loss=0.46278  sm_loss=0.66528  sm_val_loss=0.46016  time=1.10s
# Epoch 2  loss=0.06013  val_loss=0.02321  sm_loss=0.06007  sm_val_loss=0.02321  time=0.91s
# Epoch 3  loss=0.02139  val_loss=0.01899  sm_loss=0.02134  sm_val_loss=0.01901  time=0.92s
# Epoch 4  loss=0.01919  val_loss=0.01824  sm_loss=0.01918  sm_val_loss=0.01828  time=0.91s
# Epoch 5  loss=0.01850  val_loss=0.01787  sm_loss=0.01852  sm_val_loss=0.01794  time=0.92s
# Epoch 6  loss=0.01798  val_loss=0.01776  sm_loss=0.01805  sm_val_loss=0.01785  time=0.92s
# Epoch 7  loss=0.01774  val_loss=0.01761  sm_loss=0.01783  sm_val_loss=0.01770  time=0.93s
# Epoch 8  loss=0.01735  val_loss=0.01754  sm_loss=0.01746  sm_val_loss=0.01761  time=0.95s
# Epoch 9  loss=0.01725  val_loss=0.01748  sm_loss=0.01739  sm_val_loss=0.01760  time=0.95s
# Epoch 10  loss=0.01698  val_loss=0.01742  sm_loss=0.01712  sm_val_loss=0.01751  time=1.08s
# Epoch 13  loss=0.01622  val_loss=0.01724  sm_loss=0.01644  sm_val_loss=0.01735  time=0.96s
# Fold 6 log loss: 0.017379000403406793
# Fold 7
# Epoch 1  loss=0.66667  val_loss=0.30746  sm_loss=0.66654  sm_val_loss=0.30706  time=0.95s
# Epoch 2  loss=0.05936  val_loss=0.02354  sm_loss=0.05928  sm_val_loss=0.02354  time=0.93s
# Epoch 3  loss=0.02147  val_loss=0.01926  sm_loss=0.02137  sm_val_loss=0.01929  time=1.08s
# Epoch 4  loss=0.01951  val_loss=0.01817  sm_loss=0.01952  sm_val_loss=0.01823  time=1.08s
# Epoch 5  loss=0.01849  val_loss=0.01776  sm_loss=0.01849  sm_val_loss=0.01783  time=0.92s
# Epoch 7  loss=0.01765  val_loss=0.01739  sm_loss=0.01776  sm_val_loss=0.01749  time=0.92s
# Epoch 8  loss=0.01735  val_loss=0.01730  sm_loss=0.01747  sm_val_loss=0.01740  time=0.91s
# Epoch 9  loss=0.01707  val_loss=0.01723  sm_loss=0.01722  sm_val_loss=0.01734  time=0.92s
# Epoch 10  loss=0.01695  val_loss=0.01719  sm_loss=0.01707  sm_val_loss=0.01729  time=0.94s
# Epoch 11  loss=0.01663  val_loss=0.01710  sm_loss=0.01682  sm_val_loss=0.01720  time=1.16s
# Epoch 12  loss=0.01636  val_loss=0.01707  sm_loss=0.01657  sm_val_loss=0.01716  time=0.94s
# Epoch 13  loss=0.01618  val_loss=0.01693  sm_loss=0.01638  sm_val_loss=0.01703  time=0.93s
# Epoch 17  loss=0.01494  val_loss=0.01692  sm_loss=0.01522  sm_val_loss=0.01699  time=0.91s
# Fold 7 log loss: 0.017019857724459037
# Seed 0
# Fold 1 log loss: 0.017262207014484943
# Fold 2 log loss: 0.01696034314467535
# Fold 3 log loss: 0.017373675812907764
# Fold 4 log loss: 0.01763419709298953
# Fold 5 log loss: 0.01721958323374678
# Fold 6 log loss: 0.017379000403406793
# Fold 7 log loss: 0.017019857724459037
# Std of log loss: 0.00021249828841138902
# Total log loss: 0.017264102798822054
# Fold 1
# Epoch 1  loss=0.46159  val_loss=0.01296  sm_loss=0.46145  sm_val_loss=0.01290  time=0.97s
# Epoch 2  loss=0.01135  val_loss=0.01067  sm_loss=0.01123  sm_val_loss=0.01072  time=0.95s
# Epoch 3  loss=0.00996  val_loss=0.01018  sm_loss=0.01005  sm_val_loss=0.01027  time=1.07s
# Epoch 4  loss=0.00963  val_loss=0.01013  sm_loss=0.00979  sm_val_loss=0.01019  time=1.08s
# Epoch 5  loss=0.00966  val_loss=0.00994  sm_loss=0.00982  sm_val_loss=0.01003  time=0.96s
# Epoch 16  loss=0.00943  val_loss=0.00985  sm_loss=0.00961  sm_val_loss=0.00993  time=0.95s
# Epoch 19  loss=0.00926  val_loss=0.00982  sm_loss=0.00945  sm_val_loss=0.00992  time=0.92s
# Epoch 20  loss=0.00914  val_loss=0.00979  sm_loss=0.00935  sm_val_loss=0.00988  time=0.93s
# Epoch 21  loss=0.00904  val_loss=0.00965  sm_loss=0.00925  sm_val_loss=0.00974  time=1.24s
# Epoch 22  loss=0.00891  val_loss=0.00952  sm_loss=0.00914  sm_val_loss=0.00963  time=1.01s
# Epoch 23  loss=0.00878  val_loss=0.00947  sm_loss=0.00901  sm_val_loss=0.00959  time=0.98s
# Epoch 24  loss=0.00866  val_loss=0.00942  sm_loss=0.00890  sm_val_loss=0.00954  time=0.96s
# Fold 2
# Epoch 1  loss=0.46178  val_loss=0.01311  sm_loss=0.46163  sm_val_loss=0.01308  time=0.93s
# Epoch 2  loss=0.01108  val_loss=0.01033  sm_loss=0.01104  sm_val_loss=0.01038  time=0.94s
# Epoch 3  loss=0.01004  val_loss=0.00976  sm_loss=0.01013  sm_val_loss=0.00983  time=0.94s
# Epoch 5  loss=0.00959  val_loss=0.00966  sm_loss=0.00978  sm_val_loss=0.00973  time=0.94s
# Epoch 7  loss=0.00960  val_loss=0.00963  sm_loss=0.00977  sm_val_loss=0.00970  time=1.02s
# Epoch 11  loss=0.00967  val_loss=0.00963  sm_loss=0.00984  sm_val_loss=0.00967  time=0.93s
# Epoch 16  loss=0.00950  val_loss=0.00955  sm_loss=0.00968  sm_val_loss=0.00961  time=0.95s
# Epoch 17  loss=0.00945  val_loss=0.00945  sm_loss=0.00963  sm_val_loss=0.00951  time=1.21s
# Epoch 18  loss=0.00937  val_loss=0.00945  sm_loss=0.00957  sm_val_loss=0.00950  time=1.20s
# Epoch 19  loss=0.00930  val_loss=0.00935  sm_loss=0.00950  sm_val_loss=0.00942  time=1.02s
# Epoch 20  loss=0.00921  val_loss=0.00933  sm_loss=0.00941  sm_val_loss=0.00941  time=0.93s
# Epoch 21  loss=0.00910  val_loss=0.00928  sm_loss=0.00931  sm_val_loss=0.00936  time=0.93s
# Epoch 22  loss=0.00896  val_loss=0.00916  sm_loss=0.00918  sm_val_loss=0.00925  time=0.99s
# Epoch 23  loss=0.00883  val_loss=0.00911  sm_loss=0.00906  sm_val_loss=0.00921  time=0.94s
# Epoch 24  loss=0.00871  val_loss=0.00909  sm_loss=0.00896  sm_val_loss=0.00920  time=0.95s
# Epoch 25  loss=0.00864  val_loss=0.00908  sm_loss=0.00890  sm_val_loss=0.00919  time=0.93s
# Fold 3
# Epoch 1  loss=0.46085  val_loss=0.01298  sm_loss=0.46069  sm_val_loss=0.01265  time=0.96s
# Epoch 2  loss=0.01133  val_loss=0.00995  sm_loss=0.01126  sm_val_loss=0.01002  time=1.14s
# Epoch 3  loss=0.01009  val_loss=0.00960  sm_loss=0.01018  sm_val_loss=0.00970  time=0.96s
# Epoch 4  loss=0.00967  val_loss=0.00941  sm_loss=0.00983  sm_val_loss=0.00951  time=0.93s
# Epoch 5  loss=0.00965  val_loss=0.00936  sm_loss=0.00983  sm_val_loss=0.00947  time=0.96s
# Epoch 16  loss=0.00955  val_loss=0.00930  sm_loss=0.00973  sm_val_loss=0.00938  time=0.95s
# Epoch 18  loss=0.00940  val_loss=0.00925  sm_loss=0.00959  sm_val_loss=0.00933  time=0.92s
# Epoch 19  loss=0.00932  val_loss=0.00919  sm_loss=0.00953  sm_val_loss=0.00927  time=0.91s
# Epoch 20  loss=0.00922  val_loss=0.00910  sm_loss=0.00942  sm_val_loss=0.00919  time=0.95s
# Epoch 21  loss=0.00911  val_loss=0.00901  sm_loss=0.00932  sm_val_loss=0.00911  time=0.94s
# Epoch 22  loss=0.00899  val_loss=0.00897  sm_loss=0.00922  sm_val_loss=0.00907  time=0.99s
# Epoch 23  loss=0.00884  val_loss=0.00891  sm_loss=0.00907  sm_val_loss=0.00902  time=0.92s
# Epoch 24  loss=0.00873  val_loss=0.00885  sm_loss=0.00898  sm_val_loss=0.00897  time=1.66s
# Fold 4
# Epoch 1  loss=0.45971  val_loss=0.01354  sm_loss=0.45958  sm_val_loss=0.01326  time=0.94s
# Epoch 2  loss=0.01112  val_loss=0.01064  sm_loss=0.01107  sm_val_loss=0.01040  time=0.96s
# Epoch 3  loss=0.01039  val_loss=0.01020  sm_loss=0.01045  sm_val_loss=0.01014  time=0.94s
# Epoch 4  loss=0.00977  val_loss=0.00993  sm_loss=0.00993  sm_val_loss=0.00998  time=0.96s
# Epoch 5  loss=0.00962  val_loss=0.00986  sm_loss=0.00979  sm_val_loss=0.00992  time=0.94s
# Epoch 7  loss=0.00956  val_loss=0.00979  sm_loss=0.00974  sm_val_loss=0.00989  time=0.95s
# Epoch 13  loss=0.00960  val_loss=0.00975  sm_loss=0.00977  sm_val_loss=0.00982  time=0.95s
# Epoch 16  loss=0.00952  val_loss=0.00973  sm_loss=0.00970  sm_val_loss=0.00978  time=0.96s
# Epoch 17  loss=0.00944  val_loss=0.00961  sm_loss=0.00962  sm_val_loss=0.00968  time=0.96s
# Epoch 19  loss=0.00932  val_loss=0.00953  sm_loss=0.00951  sm_val_loss=0.00962  time=0.97s
# Epoch 20  loss=0.00921  val_loss=0.00946  sm_loss=0.00942  sm_val_loss=0.00956  time=1.18s
# Epoch 21  loss=0.00910  val_loss=0.00935  sm_loss=0.00931  sm_val_loss=0.00945  time=0.94s
# Epoch 22  loss=0.00898  val_loss=0.00931  sm_loss=0.00920  sm_val_loss=0.00942  time=0.94s
# Epoch 23  loss=0.00883  val_loss=0.00922  sm_loss=0.00907  sm_val_loss=0.00933  time=0.95s
# Epoch 24  loss=0.00873  val_loss=0.00918  sm_loss=0.00898  sm_val_loss=0.00930  time=0.93s
# Fold 5
# Epoch 1  loss=0.46209  val_loss=0.01351  sm_loss=0.46195  sm_val_loss=0.01339  time=0.96s
# Epoch 2  loss=0.01129  val_loss=0.01056  sm_loss=0.01119  sm_val_loss=0.01057  time=0.95s
# Epoch 3  loss=0.01016  val_loss=0.01011  sm_loss=0.01023  sm_val_loss=0.01017  time=0.94s
# Epoch 4  loss=0.00963  val_loss=0.00985  sm_loss=0.00981  sm_val_loss=0.00992  time=0.95s
# Epoch 9  loss=0.00968  val_loss=0.00985  sm_loss=0.00984  sm_val_loss=0.00992  time=0.94s
# Epoch 11  loss=0.00967  val_loss=0.00979  sm_loss=0.00983  sm_val_loss=0.00985  time=0.92s
# Epoch 17  loss=0.00939  val_loss=0.00966  sm_loss=0.00958  sm_val_loss=0.00975  time=0.97s
# Epoch 18  loss=0.00936  val_loss=0.00966  sm_loss=0.00955  sm_val_loss=0.00974  time=1.03s
# Epoch 19  loss=0.00928  val_loss=0.00957  sm_loss=0.00947  sm_val_loss=0.00964  time=0.98s
# Epoch 20  loss=0.00918  val_loss=0.00949  sm_loss=0.00938  sm_val_loss=0.00958  time=1.27s
# Epoch 21  loss=0.00906  val_loss=0.00943  sm_loss=0.00928  sm_val_loss=0.00952  time=0.95s
# Epoch 22  loss=0.00895  val_loss=0.00933  sm_loss=0.00917  sm_val_loss=0.00945  time=0.96s
# Epoch 23  loss=0.00883  val_loss=0.00927  sm_loss=0.00907  sm_val_loss=0.00938  time=0.96s
# Epoch 24  loss=0.00871  val_loss=0.00925  sm_loss=0.00896  sm_val_loss=0.00936  time=1.03s
# Epoch 25  loss=0.00865  val_loss=0.00923  sm_loss=0.00890  sm_val_loss=0.00934  time=0.98s
# Fold 6
# Epoch 1  loss=0.46108  val_loss=0.01469  sm_loss=0.46089  sm_val_loss=0.01408  time=1.11s
# Epoch 2  loss=0.01131  val_loss=0.01009  sm_loss=0.01125  sm_val_loss=0.01007  time=0.96s
# Epoch 4  loss=0.01020  val_loss=0.00944  sm_loss=0.01027  sm_val_loss=0.00954  time=0.96s
# Epoch 6  loss=0.00972  val_loss=0.00930  sm_loss=0.00989  sm_val_loss=0.00942  time=0.96s
# Epoch 13  loss=0.00973  val_loss=0.00927  sm_loss=0.00989  sm_val_loss=0.00942  time=0.95s
# Epoch 14  loss=0.00968  val_loss=0.00931  sm_loss=0.00985  sm_val_loss=0.00940  time=1.05s
# Epoch 15  loss=0.00963  val_loss=0.00926  sm_loss=0.00980  sm_val_loss=0.00935  time=0.98s
# Epoch 16  loss=0.00960  val_loss=0.00914  sm_loss=0.00977  sm_val_loss=0.00927  time=0.96s
# Epoch 17  loss=0.00954  val_loss=0.00914  sm_loss=0.00972  sm_val_loss=0.00924  time=0.96s
# Epoch 18  loss=0.00945  val_loss=0.00903  sm_loss=0.00963  sm_val_loss=0.00916  time=0.97s
# Epoch 19  loss=0.00940  val_loss=0.00900  sm_loss=0.00959  sm_val_loss=0.00913  time=0.99s
# Epoch 21  loss=0.00914  val_loss=0.00890  sm_loss=0.00935  sm_val_loss=0.00904  time=0.94s
# Epoch 22  loss=0.00902  val_loss=0.00885  sm_loss=0.00924  sm_val_loss=0.00898  time=1.19s
# Epoch 23  loss=0.00890  val_loss=0.00874  sm_loss=0.00913  sm_val_loss=0.00890  time=0.95s
# Epoch 24  loss=0.00879  val_loss=0.00869  sm_loss=0.00903  sm_val_loss=0.00885  time=0.94s
# Fold 7
# Epoch 1  loss=0.46250  val_loss=0.01335  sm_loss=0.46239  sm_val_loss=0.01287  time=0.94s
# Epoch 2  loss=0.01135  val_loss=0.00978  sm_loss=0.01126  sm_val_loss=0.00976  time=0.95s
# Epoch 3  loss=0.01004  val_loss=0.00944  sm_loss=0.01014  sm_val_loss=0.00949  time=0.94s
# Epoch 5  loss=0.01002  val_loss=0.00908  sm_loss=0.01013  sm_val_loss=0.00924  time=0.96s
# Epoch 6  loss=0.00970  val_loss=0.00907  sm_loss=0.00987  sm_val_loss=0.00924  time=0.95s
# Epoch 10  loss=0.00976  val_loss=0.00910  sm_loss=0.00991  sm_val_loss=0.00923  time=0.95s
# Epoch 14  loss=0.00968  val_loss=0.00902  sm_loss=0.00984  sm_val_loss=0.00917  time=0.96s
# Epoch 16  loss=0.00961  val_loss=0.00894  sm_loss=0.00978  sm_val_loss=0.00911  time=1.09s
# Epoch 17  loss=0.00950  val_loss=0.00884  sm_loss=0.00968  sm_val_loss=0.00902  time=1.19s
# Epoch 19  loss=0.00938  val_loss=0.00884  sm_loss=0.00956  sm_val_loss=0.00900  time=1.00s
# Epoch 20  loss=0.00928  val_loss=0.00880  sm_loss=0.00948  sm_val_loss=0.00896  time=1.08s
# Epoch 21  loss=0.00918  val_loss=0.00865  sm_loss=0.00938  sm_val_loss=0.00883  time=1.01s
# Epoch 22  loss=0.00904  val_loss=0.00858  sm_loss=0.00925  sm_val_loss=0.00875  time=1.31s
# Epoch 23  loss=0.00892  val_loss=0.00853  sm_loss=0.00915  sm_val_loss=0.00871  time=0.97s
# Epoch 24  loss=0.00878  val_loss=0.00847  sm_loss=0.00902  sm_val_loss=0.00866  time=0.96s
# Epoch 25  loss=0.00873  val_loss=0.00847  sm_loss=0.00898  sm_val_loss=0.00866  time=0.99s
# Fold 1
# Epoch 1  loss=0.66527  val_loss=0.48175  sm_loss=0.66518  sm_val_loss=0.48158  time=1.01s
# Epoch 2  loss=0.05996  val_loss=0.02433  sm_loss=0.05990  sm_val_loss=0.02430  time=1.13s
# Epoch 3  loss=0.02148  val_loss=0.01894  sm_loss=0.02144  sm_val_loss=0.01896  time=1.14s
# Epoch 4  loss=0.01929  val_loss=0.01804  sm_loss=0.01928  sm_val_loss=0.01807  time=0.97s
# Epoch 5  loss=0.01846  val_loss=0.01779  sm_loss=0.01851  sm_val_loss=0.01783  time=0.95s
# Epoch 6  loss=0.01795  val_loss=0.01763  sm_loss=0.01803  sm_val_loss=0.01767  time=0.99s
# Epoch 7  loss=0.01767  val_loss=0.01757  sm_loss=0.01777  sm_val_loss=0.01761  time=0.98s
# Epoch 8  loss=0.01747  val_loss=0.01740  sm_loss=0.01757  sm_val_loss=0.01745  time=0.93s
# Epoch 10  loss=0.01696  val_loss=0.01731  sm_loss=0.01713  sm_val_loss=0.01732  time=0.91s
# Epoch 11  loss=0.01681  val_loss=0.01723  sm_loss=0.01698  sm_val_loss=0.01725  time=0.94s
# Epoch 13  loss=0.01639  val_loss=0.01716  sm_loss=0.01659  sm_val_loss=0.01715  time=0.92s
# Epoch 16  loss=0.01575  val_loss=0.01715  sm_loss=0.01597  sm_val_loss=0.01711  time=0.90s
# Epoch 17  loss=0.01554  val_loss=0.01711  sm_loss=0.01580  sm_val_loss=0.01707  time=0.92s
# Fold 1 log loss: 0.017172150365098903
# Fold 2
# Epoch 1  loss=0.66776  val_loss=0.39347  sm_loss=0.66755  sm_val_loss=0.39219  time=1.15s
# Epoch 2  loss=0.06201  val_loss=0.02315  sm_loss=0.06183  sm_val_loss=0.02316  time=0.93s
# Epoch 3  loss=0.02171  val_loss=0.01890  sm_loss=0.02166  sm_val_loss=0.01894  time=1.22s
# Epoch 4  loss=0.01969  val_loss=0.01808  sm_loss=0.01969  sm_val_loss=0.01813  time=0.94s
# Epoch 5  loss=0.01889  val_loss=0.01769  sm_loss=0.01890  sm_val_loss=0.01774  time=0.92s
# Epoch 6  loss=0.01861  val_loss=0.01754  sm_loss=0.01865  sm_val_loss=0.01760  time=0.93s
# Epoch 7  loss=0.01824  val_loss=0.01726  sm_loss=0.01832  sm_val_loss=0.01733  time=0.92s
# Epoch 9  loss=0.01759  val_loss=0.01711  sm_loss=0.01772  sm_val_loss=0.01716  time=0.93s
# Epoch 10  loss=0.01738  val_loss=0.01708  sm_loss=0.01752  sm_val_loss=0.01713  time=0.93s
# Epoch 11  loss=0.01723  val_loss=0.01706  sm_loss=0.01740  sm_val_loss=0.01711  time=0.93s
# Epoch 12  loss=0.01706  val_loss=0.01696  sm_loss=0.01724  sm_val_loss=0.01698  time=0.92s
# Epoch 13  loss=0.01685  val_loss=0.01689  sm_loss=0.01702  sm_val_loss=0.01692  time=0.93s
# Epoch 15  loss=0.01643  val_loss=0.01686  sm_loss=0.01665  sm_val_loss=0.01690  time=0.97s
# Epoch 16  loss=0.01632  val_loss=0.01685  sm_loss=0.01654  sm_val_loss=0.01687  time=0.93s
# Epoch 19  loss=0.01594  val_loss=0.01685  sm_loss=0.01618  sm_val_loss=0.01687  time=0.95s
# Fold 2 log loss: 0.017010477428667216
# Fold 3
# Epoch 1  loss=0.66646  val_loss=0.31048  sm_loss=0.66637  sm_val_loss=0.31027  time=0.91s
# Epoch 2  loss=0.06033  val_loss=0.02441  sm_loss=0.06022  sm_val_loss=0.02440  time=0.93s
# Epoch 3  loss=0.02147  val_loss=0.01948  sm_loss=0.02141  sm_val_loss=0.01950  time=0.94s
# Epoch 4  loss=0.01938  val_loss=0.01855  sm_loss=0.01937  sm_val_loss=0.01860  time=1.14s
# Epoch 5  loss=0.01982  val_loss=0.01854  sm_loss=0.01973  sm_val_loss=0.01858  time=0.93s
# Epoch 6  loss=0.01851  val_loss=0.01825  sm_loss=0.01853  sm_val_loss=0.01826  time=0.93s
# Epoch 7  loss=0.01801  val_loss=0.01811  sm_loss=0.01811  sm_val_loss=0.01812  time=0.95s
# Epoch 8  loss=0.01789  val_loss=0.01803  sm_loss=0.01799  sm_val_loss=0.01804  time=0.94s
# Epoch 9  loss=0.01750  val_loss=0.01786  sm_loss=0.01764  sm_val_loss=0.01787  time=0.93s
# Epoch 11  loss=0.01714  val_loss=0.01772  sm_loss=0.01729  sm_val_loss=0.01773  time=1.26s
# Epoch 12  loss=0.01692  val_loss=0.01773  sm_loss=0.01708  sm_val_loss=0.01772  time=1.19s
# Epoch 13  loss=0.01670  val_loss=0.01765  sm_loss=0.01690  sm_val_loss=0.01763  time=1.10s
# Epoch 14  loss=0.01651  val_loss=0.01767  sm_loss=0.01672  sm_val_loss=0.01760  time=1.16s
# Epoch 15  loss=0.01635  val_loss=0.01766  sm_loss=0.01656  sm_val_loss=0.01759  time=0.99s
# Epoch 16  loss=0.01614  val_loss=0.01758  sm_loss=0.01637  sm_val_loss=0.01752  time=0.92s
# Epoch 18  loss=0.01589  val_loss=0.01758  sm_loss=0.01613  sm_val_loss=0.01751  time=0.92s
# Epoch 19  loss=0.01577  val_loss=0.01758  sm_loss=0.01603  sm_val_loss=0.01749  time=1.01s
# Fold 3 log loss: 0.017442679217425993
# Fold 4
# Epoch 1  loss=0.66405  val_loss=0.34981  sm_loss=0.66395  sm_val_loss=0.34962  time=0.96s
# Epoch 2  loss=0.06044  val_loss=0.02175  sm_loss=0.06037  sm_val_loss=0.02175  time=0.94s
# Epoch 3  loss=0.02139  val_loss=0.01952  sm_loss=0.02130  sm_val_loss=0.01948  time=1.20s
# Epoch 4  loss=0.01921  val_loss=0.01881  sm_loss=0.01918  sm_val_loss=0.01875  time=0.94s
# Epoch 5  loss=0.01890  val_loss=0.01841  sm_loss=0.01887  sm_val_loss=0.01838  time=0.94s
# Epoch 6  loss=0.01817  val_loss=0.01810  sm_loss=0.01822  sm_val_loss=0.01809  time=0.94s
# Epoch 7  loss=0.01774  val_loss=0.01793  sm_loss=0.01784  sm_val_loss=0.01796  time=0.95s
# Epoch 8  loss=0.01750  val_loss=0.01785  sm_loss=0.01762  sm_val_loss=0.01784  time=0.93s
# Epoch 10  loss=0.01693  val_loss=0.01764  sm_loss=0.01710  sm_val_loss=0.01766  time=0.92s
# Epoch 13  loss=0.01639  val_loss=0.01752  sm_loss=0.01660  sm_val_loss=0.01757  time=0.99s
# Fold 4 log loss: 0.017672078549821855
# Fold 5
# Epoch 1  loss=0.66894  val_loss=0.48669  sm_loss=0.66882  sm_val_loss=0.48300  time=0.92s
# Epoch 2  loss=0.06280  val_loss=0.02126  sm_loss=0.06274  sm_val_loss=0.02125  time=0.96s
# Epoch 3  loss=0.02129  val_loss=0.01914  sm_loss=0.02120  sm_val_loss=0.01915  time=1.12s
# Epoch 4  loss=0.01968  val_loss=0.01847  sm_loss=0.01967  sm_val_loss=0.01849  time=0.94s
# Epoch 5  loss=0.01872  val_loss=0.01794  sm_loss=0.01872  sm_val_loss=0.01797  time=0.92s
# Epoch 6  loss=0.01815  val_loss=0.01771  sm_loss=0.01822  sm_val_loss=0.01776  time=0.92s
# Epoch 7  loss=0.01783  val_loss=0.01763  sm_loss=0.01792  sm_val_loss=0.01769  time=0.93s
# Epoch 8  loss=0.01752  val_loss=0.01754  sm_loss=0.01765  sm_val_loss=0.01757  time=1.08s
# Epoch 9  loss=0.01734  val_loss=0.01735  sm_loss=0.01749  sm_val_loss=0.01738  time=0.91s
# Epoch 11  loss=0.01683  val_loss=0.01732  sm_loss=0.01702  sm_val_loss=0.01732  time=0.91s
# Epoch 12  loss=0.01661  val_loss=0.01732  sm_loss=0.01680  sm_val_loss=0.01730  time=0.93s
# Epoch 13  loss=0.01646  val_loss=0.01716  sm_loss=0.01665  sm_val_loss=0.01716  time=0.95s
# Epoch 14  loss=0.01622  val_loss=0.01717  sm_loss=0.01644  sm_val_loss=0.01713  time=1.14s
# Epoch 15  loss=0.01599  val_loss=0.01714  sm_loss=0.01623  sm_val_loss=0.01709  time=0.94s
# Epoch 16  loss=0.01577  val_loss=0.01709  sm_loss=0.01602  sm_val_loss=0.01702  time=0.92s
# Fold 5 log loss: 0.01720410810305466
# Fold 6
# Epoch 1  loss=0.66464  val_loss=0.34648  sm_loss=0.66455  sm_val_loss=0.34531  time=0.91s
# Epoch 2  loss=0.05991  val_loss=0.02180  sm_loss=0.05983  sm_val_loss=0.02179  time=0.92s
# Epoch 3  loss=0.02142  val_loss=0.01995  sm_loss=0.02134  sm_val_loss=0.01997  time=1.03s
# Epoch 4  loss=0.01943  val_loss=0.01844  sm_loss=0.01940  sm_val_loss=0.01848  time=1.00s
# Epoch 5  loss=0.01858  val_loss=0.01810  sm_loss=0.01861  sm_val_loss=0.01804  time=0.93s
# Epoch 6  loss=0.01820  val_loss=0.01785  sm_loss=0.01823  sm_val_loss=0.01792  time=0.96s
# Epoch 7  loss=0.01776  val_loss=0.01772  sm_loss=0.01786  sm_val_loss=0.01781  time=1.30s
# Epoch 8  loss=0.01765  val_loss=0.01758  sm_loss=0.01776  sm_val_loss=0.01767  time=1.19s
# Epoch 9  loss=0.01746  val_loss=0.01759  sm_loss=0.01758  sm_val_loss=0.01766  time=1.40s
# Epoch 10  loss=0.01713  val_loss=0.01750  sm_loss=0.01728  sm_val_loss=0.01756  time=0.93s
# Epoch 11  loss=0.01698  val_loss=0.01737  sm_loss=0.01714  sm_val_loss=0.01747  time=0.95s
# Epoch 12  loss=0.01682  val_loss=0.01735  sm_loss=0.01700  sm_val_loss=0.01746  time=0.96s
# Epoch 13  loss=0.01664  val_loss=0.01729  sm_loss=0.01681  sm_val_loss=0.01740  time=0.96s
# Epoch 14  loss=0.01639  val_loss=0.01726  sm_loss=0.01660  sm_val_loss=0.01736  time=1.28s
# Epoch 15  loss=0.01618  val_loss=0.01726  sm_loss=0.01639  sm_val_loss=0.01736  time=0.93s
# Epoch 16  loss=0.01604  val_loss=0.01720  sm_loss=0.01628  sm_val_loss=0.01730  time=0.96s
# Epoch 18  loss=0.01560  val_loss=0.01719  sm_loss=0.01586  sm_val_loss=0.01729  time=0.94s
# Fold 6 log loss: 0.01730969047779075
# Fold 7
# Epoch 1  loss=0.66542  val_loss=0.33396  sm_loss=0.66533  sm_val_loss=0.33343  time=0.91s
# Epoch 2  loss=0.06163  val_loss=0.02198  sm_loss=0.06153  sm_val_loss=0.02198  time=0.91s
# Epoch 3  loss=0.02119  val_loss=0.01901  sm_loss=0.02113  sm_val_loss=0.01904  time=1.16s
# Epoch 4  loss=0.01951  val_loss=0.01896  sm_loss=0.01949  sm_val_loss=0.01899  time=0.96s
# Epoch 5  loss=0.01881  val_loss=0.01786  sm_loss=0.01878  sm_val_loss=0.01792  time=0.90s
# Epoch 6  loss=0.01829  val_loss=0.01773  sm_loss=0.01832  sm_val_loss=0.01781  time=0.91s
# Epoch 7  loss=0.01777  val_loss=0.01748  sm_loss=0.01785  sm_val_loss=0.01758  time=0.92s
# Epoch 8  loss=0.01745  val_loss=0.01733  sm_loss=0.01757  sm_val_loss=0.01743  time=0.96s
# Epoch 9  loss=0.01730  val_loss=0.01728  sm_loss=0.01742  sm_val_loss=0.01738  time=0.95s
# Epoch 10  loss=0.01697  val_loss=0.01722  sm_loss=0.01712  sm_val_loss=0.01733  time=0.91s
# Epoch 11  loss=0.01686  val_loss=0.01716  sm_loss=0.01702  sm_val_loss=0.01725  time=0.93s
# Epoch 12  loss=0.01658  val_loss=0.01712  sm_loss=0.01674  sm_val_loss=0.01720  time=0.91s
# Epoch 13  loss=0.01631  val_loss=0.01705  sm_loss=0.01650  sm_val_loss=0.01715  time=0.95s
# Epoch 14  loss=0.01602  val_loss=0.01699  sm_loss=0.01623  sm_val_loss=0.01707  time=1.14s
# Epoch 15  loss=0.01571  val_loss=0.01690  sm_loss=0.01596  sm_val_loss=0.01699  time=0.93s
# Epoch 16  loss=0.01540  val_loss=0.01690  sm_loss=0.01565  sm_val_loss=0.01697  time=0.94s
# Epoch 17  loss=0.01514  val_loss=0.01689  sm_loss=0.01541  sm_val_loss=0.01697  time=0.93s
# Fold 7 log loss: 0.017002617227708607
# Seed 1
# Fold 1 log loss: 0.017172150365098903
# Fold 2 log loss: 0.017010477428667216
# Fold 3 log loss: 0.017442679217425993
# Fold 4 log loss: 0.017672078549821855
# Fold 5 log loss: 0.01720410810305466
# Fold 6 log loss: 0.01730969047779075
# Fold 7 log loss: 0.017002617227708607
# Std of log loss: 0.0002220015926121491
# Total log loss: 0.017258945560199624
# Fold 1
# Epoch 1  loss=0.46054  val_loss=0.01439  sm_loss=0.46042  sm_val_loss=0.01404  time=0.94s
# Epoch 2  loss=0.01113  val_loss=0.01069  sm_loss=0.01103  sm_val_loss=0.01071  time=1.21s
# Epoch 3  loss=0.00999  val_loss=0.01021  sm_loss=0.01008  sm_val_loss=0.01030  time=0.98s
# Epoch 4  loss=0.00960  val_loss=0.01012  sm_loss=0.00977  sm_val_loss=0.01018  time=0.98s
# Epoch 8  loss=0.00956  val_loss=0.01010  sm_loss=0.00973  sm_val_loss=0.01017  time=0.95s
# Epoch 10  loss=0.00957  val_loss=0.01005  sm_loss=0.00973  sm_val_loss=0.01012  time=0.95s
# Epoch 11  loss=0.00955  val_loss=0.01001  sm_loss=0.00972  sm_val_loss=0.01005  time=0.94s
# Epoch 16  loss=0.00945  val_loss=0.00989  sm_loss=0.00963  sm_val_loss=0.00996  time=0.93s
# Epoch 18  loss=0.00930  val_loss=0.00982  sm_loss=0.00949  sm_val_loss=0.00990  time=0.92s
# Epoch 19  loss=0.00924  val_loss=0.00973  sm_loss=0.00943  sm_val_loss=0.00982  time=0.93s
# Epoch 20  loss=0.00913  val_loss=0.00965  sm_loss=0.00934  sm_val_loss=0.00973  time=0.92s
# Epoch 22  loss=0.00889  val_loss=0.00953  sm_loss=0.00911  sm_val_loss=0.00964  time=1.04s
# Epoch 23  loss=0.00877  val_loss=0.00946  sm_loss=0.00901  sm_val_loss=0.00958  time=0.94s
# Epoch 24  loss=0.00867  val_loss=0.00942  sm_loss=0.00892  sm_val_loss=0.00955  time=1.24s
# Fold 2
# Epoch 1  loss=0.46148  val_loss=0.01480  sm_loss=0.46133  sm_val_loss=0.01421  time=1.46s
# Epoch 2  loss=0.01109  val_loss=0.01021  sm_loss=0.01103  sm_val_loss=0.01027  time=0.96s
# Epoch 3  loss=0.01001  val_loss=0.00973  sm_loss=0.01012  sm_val_loss=0.00981  time=0.98s
# Epoch 6  loss=0.00963  val_loss=0.00974  sm_loss=0.00980  sm_val_loss=0.00980  time=0.94s
# Epoch 7  loss=0.00961  val_loss=0.00961  sm_loss=0.00979  sm_val_loss=0.00967  time=0.98s
# Epoch 16  loss=0.00947  val_loss=0.00961  sm_loss=0.00965  sm_val_loss=0.00967  time=0.93s
# Epoch 17  loss=0.00948  val_loss=0.00953  sm_loss=0.00966  sm_val_loss=0.00959  time=0.95s
# Epoch 18  loss=0.00938  val_loss=0.00949  sm_loss=0.00957  sm_val_loss=0.00953  time=0.95s
# Epoch 19  loss=0.00928  val_loss=0.00938  sm_loss=0.00948  sm_val_loss=0.00946  time=1.10s
# Epoch 20  loss=0.00922  val_loss=0.00938  sm_loss=0.00943  sm_val_loss=0.00944  time=1.01s
# Epoch 21  loss=0.00908  val_loss=0.00925  sm_loss=0.00929  sm_val_loss=0.00931  time=0.97s
# Epoch 22  loss=0.00895  val_loss=0.00915  sm_loss=0.00917  sm_val_loss=0.00925  time=0.97s
# Epoch 23  loss=0.00883  val_loss=0.00911  sm_loss=0.00907  sm_val_loss=0.00920  time=0.94s
# Epoch 24  loss=0.00870  val_loss=0.00906  sm_loss=0.00895  sm_val_loss=0.00916  time=0.94s
# Epoch 25  loss=0.00862  val_loss=0.00905  sm_loss=0.00888  sm_val_loss=0.00916  time=0.93s
# Fold 3
# Epoch 1  loss=0.46141  val_loss=0.01370  sm_loss=0.46130  sm_val_loss=0.01347  time=0.92s
# Epoch 2  loss=0.01137  val_loss=0.01005  sm_loss=0.01127  sm_val_loss=0.01009  time=0.96s
# Epoch 3  loss=0.01005  val_loss=0.00966  sm_loss=0.01011  sm_val_loss=0.00974  time=0.94s
# Epoch 5  loss=0.00968  val_loss=0.00942  sm_loss=0.00987  sm_val_loss=0.00951  time=1.11s
# Epoch 8  loss=0.00965  val_loss=0.00941  sm_loss=0.00982  sm_val_loss=0.00948  time=0.93s
# Epoch 14  loss=0.00961  val_loss=0.00936  sm_loss=0.00979  sm_val_loss=0.00944  time=0.93s
# Epoch 16  loss=0.00955  val_loss=0.00934  sm_loss=0.00973  sm_val_loss=0.00943  time=1.16s
# Epoch 17  loss=0.00947  val_loss=0.00929  sm_loss=0.00966  sm_val_loss=0.00938  time=0.92s
# Epoch 19  loss=0.00933  val_loss=0.00915  sm_loss=0.00953  sm_val_loss=0.00925  time=0.93s
# Epoch 20  loss=0.00924  val_loss=0.00912  sm_loss=0.00945  sm_val_loss=0.00921  time=0.97s
# Epoch 21  loss=0.00911  val_loss=0.00906  sm_loss=0.00933  sm_val_loss=0.00916  time=0.94s
# Epoch 22  loss=0.00898  val_loss=0.00898  sm_loss=0.00921  sm_val_loss=0.00908  time=0.95s
# Epoch 23  loss=0.00886  val_loss=0.00889  sm_loss=0.00910  sm_val_loss=0.00901  time=0.95s
# Epoch 24  loss=0.00873  val_loss=0.00886  sm_loss=0.00898  sm_val_loss=0.00897  time=0.94s
# Fold 4
# Epoch 1  loss=0.46157  val_loss=0.01400  sm_loss=0.46145  sm_val_loss=0.01340  time=1.15s
# Epoch 2  loss=0.01144  val_loss=0.01059  sm_loss=0.01137  sm_val_loss=0.01051  time=0.98s
# Epoch 3  loss=0.01030  val_loss=0.01051  sm_loss=0.01040  sm_val_loss=0.01030  time=1.25s
# Epoch 4  loss=0.00984  val_loss=0.01006  sm_loss=0.01001  sm_val_loss=0.01005  time=1.02s
# Epoch 5  loss=0.00960  val_loss=0.00988  sm_loss=0.00979  sm_val_loss=0.00995  time=1.09s
# Epoch 6  loss=0.00959  val_loss=0.00983  sm_loss=0.00976  sm_val_loss=0.00989  time=1.11s
# Epoch 7  loss=0.00958  val_loss=0.00976  sm_loss=0.00976  sm_val_loss=0.00985  time=0.94s
# Epoch 8  loss=0.00958  val_loss=0.00977  sm_loss=0.00976  sm_val_loss=0.00985  time=1.04s
# Epoch 9  loss=0.00957  val_loss=0.00977  sm_loss=0.00974  sm_val_loss=0.00984  time=0.98s
# Epoch 12  loss=0.00955  val_loss=0.00977  sm_loss=0.00972  sm_val_loss=0.00982  time=1.31s
# Epoch 14  loss=0.00954  val_loss=0.00969  sm_loss=0.00971  sm_val_loss=0.00978  time=0.94s
# Epoch 15  loss=0.00948  val_loss=0.00963  sm_loss=0.00966  sm_val_loss=0.00972  time=0.99s
# Epoch 17  loss=0.00937  val_loss=0.00956  sm_loss=0.00956  sm_val_loss=0.00964  time=0.94s
# Epoch 18  loss=0.00930  val_loss=0.00945  sm_loss=0.00949  sm_val_loss=0.00954  time=0.95s
# Epoch 20  loss=0.00911  val_loss=0.00937  sm_loss=0.00931  sm_val_loss=0.00947  time=0.94s
# Epoch 21  loss=0.00900  val_loss=0.00927  sm_loss=0.00922  sm_val_loss=0.00937  time=1.07s
# Epoch 22  loss=0.00887  val_loss=0.00925  sm_loss=0.00909  sm_val_loss=0.00936  time=1.02s
# Epoch 23  loss=0.00874  val_loss=0.00914  sm_loss=0.00898  sm_val_loss=0.00926  time=0.94s
# Epoch 24  loss=0.00862  val_loss=0.00913  sm_loss=0.00887  sm_val_loss=0.00925  time=0.94s
# Epoch 25  loss=0.00856  val_loss=0.00911  sm_loss=0.00882  sm_val_loss=0.00924  time=0.94s
# Fold 5
# Epoch 1  loss=0.46380  val_loss=0.01350  sm_loss=0.46360  sm_val_loss=0.01330  time=0.92s
# Epoch 2  loss=0.01132  val_loss=0.01040  sm_loss=0.01120  sm_val_loss=0.01045  time=0.94s
# Epoch 3  loss=0.01002  val_loss=0.00997  sm_loss=0.01010  sm_val_loss=0.01005  time=0.93s
# Epoch 4  loss=0.01025  val_loss=0.00995  sm_loss=0.01033  sm_val_loss=0.01000  time=0.93s
# Epoch 5  loss=0.00962  val_loss=0.00987  sm_loss=0.00980  sm_val_loss=0.00993  time=0.93s
# Epoch 8  loss=0.00959  val_loss=0.00977  sm_loss=0.00976  sm_val_loss=0.00985  time=0.96s
# Epoch 15  loss=0.00953  val_loss=0.00970  sm_loss=0.00970  sm_val_loss=0.00978  time=0.94s
# Epoch 16  loss=0.00948  val_loss=0.00974  sm_loss=0.00966  sm_val_loss=0.00978  time=1.07s
# Epoch 17  loss=0.00943  val_loss=0.00968  sm_loss=0.00961  sm_val_loss=0.00976  time=0.98s
# Epoch 18  loss=0.00939  val_loss=0.00964  sm_loss=0.00957  sm_val_loss=0.00971  time=1.68s
# Epoch 19  loss=0.00927  val_loss=0.00949  sm_loss=0.00947  sm_val_loss=0.00959  time=1.00s
# Epoch 20  loss=0.00918  val_loss=0.00950  sm_loss=0.00938  sm_val_loss=0.00958  time=1.00s
# Epoch 21  loss=0.00907  val_loss=0.00940  sm_loss=0.00928  sm_val_loss=0.00948  time=1.00s
# Epoch 22  loss=0.00895  val_loss=0.00934  sm_loss=0.00918  sm_val_loss=0.00944  time=0.97s
# Epoch 23  loss=0.00881  val_loss=0.00928  sm_loss=0.00905  sm_val_loss=0.00939  time=0.94s
# Epoch 24  loss=0.00870  val_loss=0.00924  sm_loss=0.00894  sm_val_loss=0.00935  time=0.94s
# Fold 6
# Epoch 1  loss=0.45959  val_loss=0.01490  sm_loss=0.45943  sm_val_loss=0.01420  time=0.95s
# Epoch 2  loss=0.01133  val_loss=0.01076  sm_loss=0.01125  sm_val_loss=0.01067  time=0.93s
# Epoch 3  loss=0.01028  val_loss=0.01000  sm_loss=0.01035  sm_val_loss=0.01008  time=1.14s
# Epoch 4  loss=0.00987  val_loss=0.00983  sm_loss=0.01001  sm_val_loss=0.00991  time=0.95s
# Epoch 5  loss=0.00975  val_loss=0.00939  sm_loss=0.00992  sm_val_loss=0.00950  time=0.94s
# Epoch 7  loss=0.00967  val_loss=0.00939  sm_loss=0.00984  sm_val_loss=0.00948  time=0.96s
# Epoch 11  loss=0.00974  val_loss=0.00932  sm_loss=0.00989  sm_val_loss=0.00943  time=0.97s
# Epoch 14  loss=0.00972  val_loss=0.00926  sm_loss=0.00988  sm_val_loss=0.00936  time=1.19s
# Epoch 16  loss=0.00962  val_loss=0.00919  sm_loss=0.00980  sm_val_loss=0.00929  time=0.97s
# Epoch 17  loss=0.00954  val_loss=0.00911  sm_loss=0.00972  sm_val_loss=0.00924  time=0.98s
# Epoch 18  loss=0.00950  val_loss=0.00910  sm_loss=0.00968  sm_val_loss=0.00924  time=0.97s
# Epoch 19  loss=0.00940  val_loss=0.00901  sm_loss=0.00959  sm_val_loss=0.00914  time=0.95s
# Epoch 20  loss=0.00929  val_loss=0.00896  sm_loss=0.00949  sm_val_loss=0.00909  time=1.11s
# Epoch 21  loss=0.00918  val_loss=0.00893  sm_loss=0.00939  sm_val_loss=0.00905  time=0.98s
# Epoch 22  loss=0.00907  val_loss=0.00879  sm_loss=0.00928  sm_val_loss=0.00894  time=1.04s
# Epoch 23  loss=0.00894  val_loss=0.00875  sm_loss=0.00917  sm_val_loss=0.00890  time=1.44s
# Epoch 24  loss=0.00883  val_loss=0.00872  sm_loss=0.00907  sm_val_loss=0.00887  time=0.98s
# Fold 7
# Epoch 1  loss=0.45980  val_loss=0.01289  sm_loss=0.45959  sm_val_loss=0.01264  time=0.94s
# Epoch 2  loss=0.01132  val_loss=0.00968  sm_loss=0.01119  sm_val_loss=0.00975  time=0.96s
# Epoch 3  loss=0.01012  val_loss=0.00937  sm_loss=0.01021  sm_val_loss=0.00950  time=0.95s
# Epoch 4  loss=0.00984  val_loss=0.00913  sm_loss=0.00999  sm_val_loss=0.00929  time=0.94s
# Epoch 5  loss=0.00986  val_loss=0.00898  sm_loss=0.01000  sm_val_loss=0.00916  time=0.93s
# Epoch 17  loss=0.00954  val_loss=0.00896  sm_loss=0.00971  sm_val_loss=0.00908  time=0.95s
# Epoch 18  loss=0.00949  val_loss=0.00889  sm_loss=0.00967  sm_val_loss=0.00903  time=0.93s
# Epoch 19  loss=0.00940  val_loss=0.00881  sm_loss=0.00959  sm_val_loss=0.00897  time=0.93s
# Epoch 20  loss=0.00932  val_loss=0.00875  sm_loss=0.00951  sm_val_loss=0.00892  time=1.13s
# Epoch 21  loss=0.00920  val_loss=0.00869  sm_loss=0.00940  sm_val_loss=0.00885  time=0.97s
# Epoch 22  loss=0.00906  val_loss=0.00862  sm_loss=0.00928  sm_val_loss=0.00879  time=0.95s
# Epoch 23  loss=0.00893  val_loss=0.00852  sm_loss=0.00916  sm_val_loss=0.00870  time=0.93s
# ...
# Epoch 25  loss=0.00861  val_loss=0.00905  sm_loss=0.00887  sm_val_loss=0.00916  time=0.96s
# Fold 3
# Epoch 1  loss=0.46111  val_loss=0.01271  sm_loss=0.46098  sm_val_loss=0.01254  time=0.96s
# Epoch 2  loss=0.01139  val_loss=0.00988  sm_loss=0.01129  sm_val_loss=0.00996  time=0.97s
# Epoch 3  loss=0.01017  val_loss=0.00964  sm_loss=0.01024  sm_val_loss=0.00971  time=0.94s
# Epoch 4  loss=0.00986  val_loss=0.00946  sm_loss=0.01001  sm_val_loss=0.00952  time=0.93s
# Epoch 16  loss=0.00956  val_loss=0.00936  sm_loss=0.00973  sm_val_loss=0.00944  time=0.95s
# Epoch 17  loss=0.00949  val_loss=0.00929  sm_loss=0.00967  sm_val_loss=0.00938  time=1.19s
# Epoch 18  loss=0.00944  val_loss=0.00923  sm_loss=0.00963  sm_val_loss=0.00932  time=0.94s
# Epoch 19  loss=0.00932  val_loss=0.00913  sm_loss=0.00952  sm_val_loss=0.00921  time=1.16s
# Epoch 20  loss=0.00922  val_loss=0.00912  sm_loss=0.00943  sm_val_loss=0.00920  time=0.96s
# Epoch 21  loss=0.00912  val_loss=0.00908  sm_loss=0.00934  sm_val_loss=0.00916  time=0.96s
# Epoch 22  loss=0.00901  val_loss=0.00901  sm_loss=0.00924  sm_val_loss=0.00911  time=0.94s
# Epoch 23  loss=0.00887  val_loss=0.00889  sm_loss=0.00911  sm_val_loss=0.00900  time=0.94s
# Epoch 24  loss=0.00874  val_loss=0.00887  sm_loss=0.00899  sm_val_loss=0.00899  time=0.95s
# Epoch 25  loss=0.00867  val_loss=0.00886  sm_loss=0.00892  sm_val_loss=0.00898  time=0.97s
# Fold 4
# Epoch 1  loss=0.46074  val_loss=0.01460  sm_loss=0.46058  sm_val_loss=0.01402  time=0.96s
# Epoch 2  loss=0.01164  val_loss=0.01061  sm_loss=0.01153  sm_val_loss=0.01030  time=1.07s
# Epoch 3  loss=0.00986  val_loss=0.00995  sm_loss=0.01002  sm_val_loss=0.01000  time=1.16s
# Epoch 5  loss=0.00958  val_loss=0.00977  sm_loss=0.00976  sm_val_loss=0.00985  time=0.99s
# Epoch 8  loss=0.00960  val_loss=0.00974  sm_loss=0.00977  sm_val_loss=0.00985  time=0.95s
# Epoch 17  loss=0.00947  val_loss=0.00960  sm_loss=0.00965  sm_val_loss=0.00969  time=0.94s
# Epoch 18  loss=0.00935  val_loss=0.00955  sm_loss=0.00954  sm_val_loss=0.00964  time=0.94s
# Epoch 19  loss=0.00926  val_loss=0.00951  sm_loss=0.00946  sm_val_loss=0.00960  time=0.93s
# Epoch 20  loss=0.00919  val_loss=0.00945  sm_loss=0.00939  sm_val_loss=0.00955  time=0.95s
# Epoch 21  loss=0.00911  val_loss=0.00930  sm_loss=0.00932  sm_val_loss=0.00941  time=0.94s
# Epoch 22  loss=0.00897  val_loss=0.00925  sm_loss=0.00919  sm_val_loss=0.00936  time=1.69s
# Epoch 23  loss=0.00884  val_loss=0.00920  sm_loss=0.00908  sm_val_loss=0.00932  time=1.01s
# Epoch 24  loss=0.00873  val_loss=0.00918  sm_loss=0.00898  sm_val_loss=0.00930  time=1.25s
# Epoch 25  loss=0.00864  val_loss=0.00916  sm_loss=0.00890  sm_val_loss=0.00929  time=1.29s
# Fold 5
# Epoch 1  loss=0.46105  val_loss=0.01395  sm_loss=0.46095  sm_val_loss=0.01376  time=0.98s
# Epoch 2  loss=0.01163  val_loss=0.01030  sm_loss=0.01149  sm_val_loss=0.01038  time=1.00s
# Epoch 3  loss=0.01002  val_loss=0.01000  sm_loss=0.01011  sm_val_loss=0.01009  time=1.02s
# Epoch 4  loss=0.00965  val_loss=0.00985  sm_loss=0.00981  sm_val_loss=0.00993  time=1.00s
# Epoch 8  loss=0.00957  val_loss=0.00976  sm_loss=0.00974  sm_val_loss=0.00985  time=0.95s
# Epoch 15  loss=0.00954  val_loss=0.00979  sm_loss=0.00971  sm_val_loss=0.00984  time=0.94s
# Epoch 16  loss=0.00948  val_loss=0.00968  sm_loss=0.00965  sm_val_loss=0.00977  time=0.95s
# Epoch 17  loss=0.00938  val_loss=0.00962  sm_loss=0.00957  sm_val_loss=0.00972  time=0.94s
# Epoch 18  loss=0.00934  val_loss=0.00958  sm_loss=0.00953  sm_val_loss=0.00967  time=0.95s
# Epoch 19  loss=0.00924  val_loss=0.00954  sm_loss=0.00944  sm_val_loss=0.00964  time=0.94s
# Epoch 20  loss=0.00915  val_loss=0.00942  sm_loss=0.00936  sm_val_loss=0.00951  time=1.09s
# Epoch 21  loss=0.00905  val_loss=0.00940  sm_loss=0.00927  sm_val_loss=0.00950  time=1.07s
# Epoch 22  loss=0.00891  val_loss=0.00930  sm_loss=0.00914  sm_val_loss=0.00941  time=0.94s
# Epoch 23  loss=0.00880  val_loss=0.00927  sm_loss=0.00904  sm_val_loss=0.00938  time=0.94s
# Epoch 24  loss=0.00868  val_loss=0.00923  sm_loss=0.00893  sm_val_loss=0.00934  time=0.95s
# Fold 6
# Epoch 1  loss=0.45906  val_loss=0.01273  sm_loss=0.45892  sm_val_loss=0.01257  time=1.14s
# Epoch 2  loss=0.01135  val_loss=0.00998  sm_loss=0.01130  sm_val_loss=0.00999  time=0.95s
# Epoch 3  loss=0.01052  val_loss=0.00947  sm_loss=0.01058  sm_val_loss=0.00956  time=0.96s
# Epoch 6  loss=0.00967  val_loss=0.00939  sm_loss=0.00984  sm_val_loss=0.00951  time=1.20s
# Epoch 8  loss=0.00972  val_loss=0.00938  sm_loss=0.00988  sm_val_loss=0.00949  time=0.95s
# Epoch 10  loss=0.00974  val_loss=0.00926  sm_loss=0.00990  sm_val_loss=0.00938  time=0.97s
# Epoch 16  loss=0.00957  val_loss=0.00909  sm_loss=0.00974  sm_val_loss=0.00919  time=1.15s
# Epoch 18  loss=0.00946  val_loss=0.00905  sm_loss=0.00964  sm_val_loss=0.00917  time=0.94s
# Epoch 19  loss=0.00934  val_loss=0.00896  sm_loss=0.00954  sm_val_loss=0.00910  time=0.95s
# Epoch 20  loss=0.00921  val_loss=0.00892  sm_loss=0.00941  sm_val_loss=0.00905  time=0.97s
# Epoch 21  loss=0.00912  val_loss=0.00885  sm_loss=0.00933  sm_val_loss=0.00900  time=0.95s
# Epoch 22  loss=0.00904  val_loss=0.00879  sm_loss=0.00926  sm_val_loss=0.00893  time=0.98s
# Epoch 23  loss=0.00890  val_loss=0.00874  sm_loss=0.00913  sm_val_loss=0.00888  time=0.94s
# Epoch 24  loss=0.00878  val_loss=0.00868  sm_loss=0.00903  sm_val_loss=0.00884  time=0.95s
# Fold 7
# Epoch 1  loss=0.46291  val_loss=0.01248  sm_loss=0.46281  sm_val_loss=0.01240  time=1.00s
# Epoch 2  loss=0.01187  val_loss=0.00982  sm_loss=0.01173  sm_val_loss=0.00987  time=1.08s
# Epoch 3  loss=0.01034  val_loss=0.00930  sm_loss=0.01041  sm_val_loss=0.00943  time=1.42s
# Epoch 4  loss=0.00970  val_loss=0.00913  sm_loss=0.00989  sm_val_loss=0.00929  time=1.01s
# Epoch 7  loss=0.00966  val_loss=0.00907  sm_loss=0.00982  sm_val_loss=0.00922  time=0.97s
# Epoch 12  loss=0.00972  val_loss=0.00909  sm_loss=0.00987  sm_val_loss=0.00921  time=1.25s
# Epoch 16  loss=0.00959  val_loss=0.00901  sm_loss=0.00975  sm_val_loss=0.00916  time=0.98s
# Epoch 17  loss=0.00954  val_loss=0.00897  sm_loss=0.00971  sm_val_loss=0.00912  time=1.21s
# Epoch 18  loss=0.00946  val_loss=0.00892  sm_loss=0.00964  sm_val_loss=0.00908  time=1.02s
# Epoch 19  loss=0.00939  val_loss=0.00885  sm_loss=0.00958  sm_val_loss=0.00899  time=0.95s
# Epoch 20  loss=0.00928  val_loss=0.00873  sm_loss=0.00948  sm_val_loss=0.00889  time=0.94s
# Epoch 21  loss=0.00917  val_loss=0.00866  sm_loss=0.00937  sm_val_loss=0.00883  time=1.09s
# Epoch 22  loss=0.00906  val_loss=0.00862  sm_loss=0.00927  sm_val_loss=0.00879  time=1.05s
# Epoch 23  loss=0.00892  val_loss=0.00852  sm_loss=0.00915  sm_val_loss=0.00870  time=0.97s
# Epoch 24  loss=0.00880  val_loss=0.00849  sm_loss=0.00904  sm_val_loss=0.00868  time=0.97s
# Epoch 25  loss=0.00872  val_loss=0.00849  sm_loss=0.00897  sm_val_loss=0.00868  time=0.95s
# Fold 1
# Epoch 1  loss=0.66592  val_loss=0.31118  sm_loss=0.66575  sm_val_loss=0.31088  time=0.92s
# Epoch 2  loss=0.06076  val_loss=0.02173  sm_loss=0.06068  sm_val_loss=0.02169  time=0.92s
# Epoch 3  loss=0.02164  val_loss=0.01937  sm_loss=0.02154  sm_val_loss=0.01940  time=0.92s
# Epoch 4  loss=0.01986  val_loss=0.01848  sm_loss=0.01981  sm_val_loss=0.01851  time=0.92s
# Epoch 5  loss=0.01899  val_loss=0.01797  sm_loss=0.01899  sm_val_loss=0.01804  time=0.94s
# Epoch 6  loss=0.01835  val_loss=0.01773  sm_loss=0.01840  sm_val_loss=0.01778  time=0.93s
# Epoch 8  loss=0.01777  val_loss=0.01752  sm_loss=0.01788  sm_val_loss=0.01756  time=0.93s
# Epoch 9  loss=0.01749  val_loss=0.01751  sm_loss=0.01762  sm_val_loss=0.01752  time=1.19s
# Epoch 10  loss=0.01725  val_loss=0.01737  sm_loss=0.01741  sm_val_loss=0.01740  time=0.93s
# Epoch 11  loss=0.01696  val_loss=0.01729  sm_loss=0.01714  sm_val_loss=0.01729  time=0.92s
# Epoch 12  loss=0.01676  val_loss=0.01726  sm_loss=0.01695  sm_val_loss=0.01727  time=0.94s
# Epoch 13  loss=0.01663  val_loss=0.01720  sm_loss=0.01683  sm_val_loss=0.01721  time=0.93s
# Epoch 14  loss=0.01642  val_loss=0.01722  sm_loss=0.01663  sm_val_loss=0.01721  time=0.95s
# Epoch 15  loss=0.01618  val_loss=0.01715  sm_loss=0.01640  sm_val_loss=0.01714  time=0.93s
# Epoch 16  loss=0.01595  val_loss=0.01714  sm_loss=0.01619  sm_val_loss=0.01712  time=0.94s
# Epoch 18  loss=0.01565  val_loss=0.01715  sm_loss=0.01591  sm_val_loss=0.01711  time=1.13s
# Epoch 19  loss=0.01554  val_loss=0.01713  sm_loss=0.01580  sm_val_loss=0.01710  time=0.94s
# Epoch 20  loss=0.01552  val_loss=0.01713  sm_loss=0.01578  sm_val_loss=0.01709  time=1.11s
# Fold 1 log loss: 0.017192443675890172
# Fold 2
# Epoch 1  loss=0.66494  val_loss=0.40084  sm_loss=0.66483  sm_val_loss=0.40040  time=1.29s
# Epoch 2  loss=0.05937  val_loss=0.02111  sm_loss=0.05927  sm_val_loss=0.02103  time=0.97s
# Epoch 3  loss=0.02120  val_loss=0.01894  sm_loss=0.02113  sm_val_loss=0.01891  time=0.93s
# Epoch 4  loss=0.01937  val_loss=0.01768  sm_loss=0.01936  sm_val_loss=0.01772  time=0.92s
# Epoch 5  loss=0.01854  val_loss=0.01758  sm_loss=0.01857  sm_val_loss=0.01748  time=0.93s
# Epoch 6  loss=0.01805  val_loss=0.01722  sm_loss=0.01813  sm_val_loss=0.01721  time=0.94s
# Epoch 7  loss=0.01764  val_loss=0.01712  sm_loss=0.01774  sm_val_loss=0.01704  time=1.16s
# Epoch 8  loss=0.01730  val_loss=0.01694  sm_loss=0.01743  sm_val_loss=0.01694  time=0.92s
# Epoch 11  loss=0.01656  val_loss=0.01688  sm_loss=0.01676  sm_val_loss=0.01686  time=0.91s
# Epoch 12  loss=0.01633  val_loss=0.01676  sm_loss=0.01654  sm_val_loss=0.01681  time=0.92s
# Epoch 14  loss=0.01580  val_loss=0.01680  sm_loss=0.01604  sm_val_loss=0.01680  time=0.94s
# Fold 2 log loss: 0.01695208305173098
# Fold 3
# Epoch 1  loss=0.66407  val_loss=0.41408  sm_loss=0.66398  sm_val_loss=0.41401  time=0.94s
# Epoch 2  loss=0.06203  val_loss=0.02522  sm_loss=0.06200  sm_val_loss=0.02514  time=0.93s
# Epoch 3  loss=0.02137  val_loss=0.01996  sm_loss=0.02132  sm_val_loss=0.01999  time=0.92s
# Epoch 4  loss=0.01938  val_loss=0.01855  sm_loss=0.01936  sm_val_loss=0.01859  time=0.93s
# Epoch 5  loss=0.01859  val_loss=0.01818  sm_loss=0.01862  sm_val_loss=0.01822  time=0.92s
# Epoch 6  loss=0.01873  val_loss=0.01817  sm_loss=0.01876  sm_val_loss=0.01821  time=1.16s
# Epoch 7  loss=0.01805  val_loss=0.01806  sm_loss=0.01812  sm_val_loss=0.01809  time=0.94s
# Epoch 8  loss=0.01768  val_loss=0.01786  sm_loss=0.01780  sm_val_loss=0.01788  time=0.93s
# Epoch 9  loss=0.01732  val_loss=0.01778  sm_loss=0.01747  sm_val_loss=0.01777  time=0.92s
# Epoch 10  loss=0.01720  val_loss=0.01776  sm_loss=0.01733  sm_val_loss=0.01777  time=1.22s
# Epoch 11  loss=0.01707  val_loss=0.01756  sm_loss=0.01724  sm_val_loss=0.01758  time=0.97s
# Epoch 14  loss=0.01629  val_loss=0.01760  sm_loss=0.01652  sm_val_loss=0.01757  time=0.92s
# Epoch 15  loss=0.01614  val_loss=0.01760  sm_loss=0.01637  sm_val_loss=0.01754  time=0.94s
# Epoch 16  loss=0.01593  val_loss=0.01756  sm_loss=0.01616  sm_val_loss=0.01750  time=0.94s
# Epoch 17  loss=0.01571  val_loss=0.01757  sm_loss=0.01597  sm_val_loss=0.01749  time=1.16s
# Epoch 18  loss=0.01557  val_loss=0.01756  sm_loss=0.01584  sm_val_loss=0.01749  time=0.92s
# Fold 3 log loss: 0.01743408062917586
# Fold 4
# Epoch 1  loss=0.66672  val_loss=0.43227  sm_loss=0.66665  sm_val_loss=0.43193  time=0.91s
# Epoch 2  loss=0.05998  val_loss=0.02349  sm_loss=0.05995  sm_val_loss=0.02347  time=0.95s
# Epoch 3  loss=0.02107  val_loss=0.01943  sm_loss=0.02106  sm_val_loss=0.01935  time=0.92s
# Epoch 4  loss=0.01913  val_loss=0.01859  sm_loss=0.01915  sm_val_loss=0.01856  time=0.92s
# Epoch 5  loss=0.01841  val_loss=0.01821  sm_loss=0.01845  sm_val_loss=0.01820  time=0.92s
# Epoch 7  loss=0.01759  val_loss=0.01800  sm_loss=0.01770  sm_val_loss=0.01796  time=0.99s
# Epoch 8  loss=0.01742  val_loss=0.01783  sm_loss=0.01755  sm_val_loss=0.01778  time=0.92s
# Epoch 10  loss=0.01685  val_loss=0.01775  sm_loss=0.01703  sm_val_loss=0.01776  time=0.92s
# Epoch 11  loss=0.01661  val_loss=0.01767  sm_loss=0.01681  sm_val_loss=0.01766  time=0.93s
# Epoch 12  loss=0.01637  val_loss=0.01764  sm_loss=0.01658  sm_val_loss=0.01762  time=0.94s
# Epoch 13  loss=0.01621  val_loss=0.01762  sm_loss=0.01643  sm_val_loss=0.01759  time=0.93s
# Fold 4 log loss: 0.017686318565499907
# Fold 5
# Epoch 1  loss=0.66829  val_loss=0.49457  sm_loss=0.66820  sm_val_loss=0.49421  time=0.99s
# Epoch 2  loss=0.06248  val_loss=0.02084  sm_loss=0.06236  sm_val_loss=0.02083  time=0.96s
# Epoch 3  loss=0.02093  val_loss=0.01923  sm_loss=0.02090  sm_val_loss=0.01919  time=0.96s
# Epoch 4  loss=0.01925  val_loss=0.01825  sm_loss=0.01927  sm_val_loss=0.01827  time=0.99s
# Epoch 5  loss=0.01849  val_loss=0.01791  sm_loss=0.01853  sm_val_loss=0.01794  time=0.94s
# Epoch 6  loss=0.01807  val_loss=0.01775  sm_loss=0.01816  sm_val_loss=0.01776  time=1.08s
# Epoch 7  loss=0.01770  val_loss=0.01761  sm_loss=0.01780  sm_val_loss=0.01761  time=1.39s
# Epoch 8  loss=0.01739  val_loss=0.01757  sm_loss=0.01752  sm_val_loss=0.01759  time=0.94s
# Epoch 9  loss=0.01723  val_loss=0.01730  sm_loss=0.01737  sm_val_loss=0.01731  time=0.94s
# Epoch 10  loss=0.01695  val_loss=0.01727  sm_loss=0.01712  sm_val_loss=0.01731  time=1.21s
# Epoch 11  loss=0.01676  val_loss=0.01717  sm_loss=0.01694  sm_val_loss=0.01715  time=1.06s
# Epoch 12  loss=0.01652  val_loss=0.01700  sm_loss=0.01670  sm_val_loss=0.01700  time=0.94s
# Epoch 15  loss=0.01571  val_loss=0.01698  sm_loss=0.01596  sm_val_loss=0.01697  time=0.98s
# Fold 5 log loss: 0.017162165263356507
# Fold 6
# Epoch 1  loss=0.66818  val_loss=0.49285  sm_loss=0.66807  sm_val_loss=0.48691  time=0.92s
# Epoch 2  loss=0.06019  val_loss=0.02299  sm_loss=0.06009  sm_val_loss=0.02299  time=0.92s
# Epoch 3  loss=0.02146  val_loss=0.02051  sm_loss=0.02135  sm_val_loss=0.02048  time=0.93s
# Epoch 4  loss=0.01946  val_loss=0.01842  sm_loss=0.01941  sm_val_loss=0.01845  time=0.92s
# Epoch 5  loss=0.01861  val_loss=0.01811  sm_loss=0.01863  sm_val_loss=0.01814  time=0.93s
# Epoch 6  loss=0.01825  val_loss=0.01785  sm_loss=0.01829  sm_val_loss=0.01792  time=1.23s
# Epoch 7  loss=0.01781  val_loss=0.01778  sm_loss=0.01791  sm_val_loss=0.01784  time=0.94s
# Epoch 8  loss=0.01748  val_loss=0.01758  sm_loss=0.01761  sm_val_loss=0.01770  time=1.27s
# Epoch 9  loss=0.01728  val_loss=0.01746  sm_loss=0.01742  sm_val_loss=0.01757  time=0.98s
# Epoch 11  loss=0.01683  val_loss=0.01730  sm_loss=0.01700  sm_val_loss=0.01743  time=0.94s
# Epoch 12  loss=0.01661  val_loss=0.01726  sm_loss=0.01681  sm_val_loss=0.01738  time=0.97s
# Epoch 14  loss=0.01623  val_loss=0.01720  sm_loss=0.01644  sm_val_loss=0.01731  time=0.95s
# Epoch 16  loss=0.01571  val_loss=0.01710  sm_loss=0.01595  sm_val_loss=0.01723  time=1.17s
# Fold 6 log loss: 0.017258316338828527
# Fold 7
# Epoch 1  loss=0.66819  val_loss=0.42276  sm_loss=0.66809  sm_val_loss=0.42272  time=0.92s
# Epoch 2  loss=0.06084  val_loss=0.02504  sm_loss=0.06077  sm_val_loss=0.02505  time=0.92s
# Epoch 3  loss=0.02096  val_loss=0.01868  sm_loss=0.02091  sm_val_loss=0.01871  time=0.93s
# Epoch 4  loss=0.01899  val_loss=0.01785  sm_loss=0.01901  sm_val_loss=0.01790  time=0.93s
# Epoch 5  loss=0.01824  val_loss=0.01768  sm_loss=0.01829  sm_val_loss=0.01775  time=0.94s
# Epoch 6  loss=0.01780  val_loss=0.01737  sm_loss=0.01787  sm_val_loss=0.01745  time=1.15s
# Epoch 7  loss=0.01752  val_loss=0.01735  sm_loss=0.01760  sm_val_loss=0.01745  time=0.94s
# Epoch 8  loss=0.01723  val_loss=0.01720  sm_loss=0.01732  sm_val_loss=0.01729  time=0.94s
# Epoch 9  loss=0.01697  val_loss=0.01715  sm_loss=0.01712  sm_val_loss=0.01724  time=1.20s
# Epoch 11  loss=0.01652  val_loss=0.01705  sm_loss=0.01670  sm_val_loss=0.01714  time=0.93s
# Epoch 12  loss=0.01626  val_loss=0.01709  sm_loss=0.01646  sm_val_loss=0.01712  time=0.93s
# Epoch 13  loss=0.01593  val_loss=0.01689  sm_loss=0.01616  sm_val_loss=0.01698  time=0.93s
# Fold 7 log loss: 0.01701926024594376
# Seed 6
# Fold 1 log loss: 0.017192443675890172
# Fold 2 log loss: 0.01695208305173098
# Fold 3 log loss: 0.01743408062917586
# Fold 4 log loss: 0.017686318565499907
# Fold 5 log loss: 0.017162165263356507
# Fold 6 log loss: 0.017258316338828527
# Fold 7 log loss: 0.01701926024594376
# Std of log loss: 0.00023208932107453213
# Total log loss: 0.017243334939993065
# Total log loss in targets: 0.01708981017266422

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6508563832372676

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015750699322652058

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

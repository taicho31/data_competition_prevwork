# %% [markdown]
# - change scheduler param

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 34

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[vc <= 19].index.sort_values()
vc2 = vc.loc[vc > 19].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[1, 4, 5, ..., 4, 4, 5]], dtype=int8)

# %%
#non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
#nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
#nontarget_dists.columns = ["target", "number"]
#nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
#drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
#print("first drop", len(drop_list1))
#non_targets.drop(drop_list1, axis=1, inplace=True)
#print("shape after 1st drop:", non_targets.shape)
#non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
#print(len(non_target_feats))

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
#importance = pd.read_csv('../input/moa-feat-importance-rapids/output_source.csv')
#importance = importance.set_index("Feature")

#imp_scaled = importance.copy(deep=True)
#for c in imp_scaled.columns:
#    imp_scaled[c] = (1 - preprocessing.MinMaxScaler().fit_transform(imp_scaled[[c]])).round(14)

#print(imp_scaled.min().min(), imp_scaled.max().max(), imp_scaled.std().mean())

#imp_scaled["MeanImp"] = imp_scaled[target_feats].mean(axis=1)
#imp_scaled["MaxImp"]  = imp_scaled[target_feats].max(axis=1)

#thresh_mean, thresh_max = 0.35, 0.975
#fs_both = imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) & (imp_scaled.MaxImp >= thresh_max), Targets]
#fs_any = list(imp_scaled.loc[(imp_scaled.MeanImp >= thresh_mean) | (imp_scaled.MaxImp >= thresh_max), target_feats].index)
#len(fs_any)

X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.7)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
print(len(drop_feats))

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)
# Out:
# 33

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 918) (3624, 918)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_non_targets = non_targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1

        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
            
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_features, num_targets):
        super(MoaModel, self).__init__()
        self.hidden_size = [1500, 1250, 1000, 750]
        self.dropout_value = [0.5, 0.35, 0.3, 0.25]

        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dense1 = nn.Linear(num_features, self.hidden_size[0])
        
        self.batch_norm2 = nn.BatchNorm1d(self.hidden_size[0])
        self.dropout2 = nn.Dropout(self.dropout_value[0])
        self.dense2 = nn.Linear(self.hidden_size[0], self.hidden_size[1])

        self.batch_norm3 = nn.BatchNorm1d(self.hidden_size[1])
        self.dropout3 = nn.Dropout(self.dropout_value[1])
        self.dense3 = nn.Linear(self.hidden_size[1], self.hidden_size[2])

        self.batch_norm4 = nn.BatchNorm1d(self.hidden_size[2])
        self.dropout4 = nn.Dropout(self.dropout_value[2])
        self.dense4 = nn.Linear(self.hidden_size[2], self.hidden_size[3])

        self.batch_norm5 = nn.BatchNorm1d(self.hidden_size[3])
        self.dropout5 = nn.Dropout(self.dropout_value[3])
        self.dense5 = nn.utils.weight_norm(nn.Linear(self.hidden_size[3], num_targets))
        
    def forward(self, x):
        x = self.batch_norm1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))

        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.leaky_relu(self.dense3(x))

        x = self.batch_norm4(x)
        x = self.dropout4(x)
        x = F.leaky_relu(self.dense4(x))

        x = self.batch_norm5(x)
        x = self.dropout5(x)
        x = self.dense5(x)
        return x
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing
train_epochs = 25

hidden_size = [1500, 1250, 1000, 750]
dropout_value = [0.5, 0.35, 0.3, 0.25]

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    if files == []:
        ans = []        
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr[:,-1] == fold
        train_index = tr[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(tr[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index,:], dtype=torch.float32)
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, 608)

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            clf.batch_norm5 = nn.BatchNorm1d(hidden_size[3])
            clf.dropout5 = nn.Dropout(dropout_value[3])
            clf.dense5 = nn.utils.weight_norm(nn.Linear(hidden_size[-1], len(target_feats)))
            optimizer = optim.Adam(clf.parameters(), lr = 1e-3, weight_decay=3e-6) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e2, 
                                              max_lr=4e-3, epochs=train_epochs, steps_per_epoch=len(train_loader))         
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 1e-3, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))   
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        if files == []:
            pred_model = MoaModel(init_num, 608)
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        if files != []:
            # validation check ----------------
            oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
            print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
            scores.append(mean_log_loss(target_epoch, oof_epoch))
            oof[valid_index,:] = oof_epoch
            oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
            # test predcition --------------
            test_preds = np.zeros([test_len, target.shape[1]])
            for i, (x_batch,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
    
    if files != []:
        print("Seed {}".format(sample_seed))
        for i, ele in enumerate(scores):
            print("Fold {} log loss: {}".format(i+1, scores[i]))
        print("Std of log loss: {}".format(np.std(scores)))
        print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4,5,6] 
    
for seed_ in seeds:
    files = torch_tl(fn_train, fn_all_targets, fn_test, seed_, fn_train.shape[1]-1, [])
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.50956  val_loss=0.02330  sm_loss=0.50955  sm_val_loss=0.02324  time=1.92s
# Epoch 2  loss=0.01280  val_loss=0.01067  sm_loss=0.01271  sm_val_loss=0.01069  time=1.06s
# Epoch 3  loss=0.01028  val_loss=0.01043  sm_loss=0.01030  sm_val_loss=0.01041  time=1.07s
# Epoch 4  loss=0.00948  val_loss=0.01001  sm_loss=0.00966  sm_val_loss=0.01009  time=1.13s
# Epoch 7  loss=0.00923  val_loss=0.00992  sm_loss=0.00945  sm_val_loss=0.01001  time=1.06s
# Epoch 8  loss=0.00923  val_loss=0.00991  sm_loss=0.00943  sm_val_loss=0.00999  time=1.07s
# Epoch 10  loss=0.00924  val_loss=0.00984  sm_loss=0.00945  sm_val_loss=0.00994  time=1.04s
# Epoch 11  loss=0.00924  val_loss=0.00985  sm_loss=0.00944  sm_val_loss=0.00993  time=1.08s
# Epoch 13  loss=0.00924  val_loss=0.00982  sm_loss=0.00944  sm_val_loss=0.00991  time=1.06s
# Epoch 16  loss=0.00913  val_loss=0.00979  sm_loss=0.00934  sm_val_loss=0.00988  time=1.10s
# Epoch 18  loss=0.00905  val_loss=0.00970  sm_loss=0.00926  sm_val_loss=0.00981  time=1.09s
# Epoch 19  loss=0.00894  val_loss=0.00961  sm_loss=0.00916  sm_val_loss=0.00972  time=1.07s
# Epoch 21  loss=0.00876  val_loss=0.00950  sm_loss=0.00898  sm_val_loss=0.00962  time=1.03s
# Epoch 22  loss=0.00865  val_loss=0.00947  sm_loss=0.00888  sm_val_loss=0.00959  time=1.04s
# Epoch 23  loss=0.00855  val_loss=0.00943  sm_loss=0.00879  sm_val_loss=0.00955  time=1.04s
# Epoch 24  loss=0.00846  val_loss=0.00941  sm_loss=0.00871  sm_val_loss=0.00953  time=1.29s
# Fold 2
# Epoch 1  loss=0.50753  val_loss=0.02311  sm_loss=0.50748  sm_val_loss=0.02279  time=1.05s
# Epoch 2  loss=0.01282  val_loss=0.01056  sm_loss=0.01276  sm_val_loss=0.01056  time=1.03s
# Epoch 3  loss=0.00992  val_loss=0.00987  sm_loss=0.00997  sm_val_loss=0.00995  time=1.36s
# Epoch 4  loss=0.00944  val_loss=0.00958  sm_loss=0.00960  sm_val_loss=0.00968  time=1.07s
# Epoch 6  loss=0.00956  val_loss=0.00961  sm_loss=0.00975  sm_val_loss=0.00966  time=1.08s
# Epoch 7  loss=0.00934  val_loss=0.00957  sm_loss=0.00957  sm_val_loss=0.00965  time=1.12s
# Epoch 8  loss=0.00935  val_loss=0.00955  sm_loss=0.00955  sm_val_loss=0.00962  time=1.37s
# Epoch 11  loss=0.00929  val_loss=0.00952  sm_loss=0.00950  sm_val_loss=0.00962  time=1.07s
# Epoch 12  loss=0.00928  val_loss=0.00950  sm_loss=0.00948  sm_val_loss=0.00957  time=1.08s
# Epoch 14  loss=0.00927  val_loss=0.00938  sm_loss=0.00947  sm_val_loss=0.00946  time=1.05s
# Epoch 18  loss=0.00907  val_loss=0.00930  sm_loss=0.00929  sm_val_loss=0.00938  time=1.30s
# Epoch 20  loss=0.00890  val_loss=0.00916  sm_loss=0.00912  sm_val_loss=0.00925  time=1.16s
# Epoch 21  loss=0.00878  val_loss=0.00913  sm_loss=0.00902  sm_val_loss=0.00922  time=1.22s
# Epoch 22  loss=0.00867  val_loss=0.00911  sm_loss=0.00891  sm_val_loss=0.00920  time=1.28s
# Epoch 23  loss=0.00856  val_loss=0.00904  sm_loss=0.00880  sm_val_loss=0.00914  time=1.15s
# Epoch 25  loss=0.00841  val_loss=0.00903  sm_loss=0.00867  sm_val_loss=0.00914  time=1.12s
# Fold 3
# Epoch 1  loss=0.50803  val_loss=0.02241  sm_loss=0.50800  sm_val_loss=0.02238  time=1.08s
# Epoch 2  loss=0.01282  val_loss=0.00992  sm_loss=0.01275  sm_val_loss=0.00996  time=1.31s
# Epoch 3  loss=0.00985  val_loss=0.00943  sm_loss=0.00991  sm_val_loss=0.00954  time=1.06s
# Epoch 4  loss=0.00932  val_loss=0.00924  sm_loss=0.00951  sm_val_loss=0.00936  time=1.06s
# Epoch 10  loss=0.00930  val_loss=0.00924  sm_loss=0.00950  sm_val_loss=0.00933  time=1.06s
# Epoch 15  loss=0.00927  val_loss=0.00915  sm_loss=0.00948  sm_val_loss=0.00925  time=1.08s
# Epoch 18  loss=0.00912  val_loss=0.00907  sm_loss=0.00933  sm_val_loss=0.00916  time=1.10s
# Epoch 19  loss=0.00905  val_loss=0.00902  sm_loss=0.00927  sm_val_loss=0.00913  time=1.08s
# Epoch 20  loss=0.00894  val_loss=0.00900  sm_loss=0.00916  sm_val_loss=0.00910  time=1.23s
# Epoch 21  loss=0.00886  val_loss=0.00895  sm_loss=0.00908  sm_val_loss=0.00905  time=1.11s
# Epoch 22  loss=0.00875  val_loss=0.00889  sm_loss=0.00898  sm_val_loss=0.00900  time=1.06s
# Epoch 23  loss=0.00863  val_loss=0.00886  sm_loss=0.00888  sm_val_loss=0.00897  time=1.11s
# Epoch 24  loss=0.00854  val_loss=0.00883  sm_loss=0.00880  sm_val_loss=0.00894  time=1.11s
# Fold 4
# Epoch 1  loss=0.50557  val_loss=0.02140  sm_loss=0.50555  sm_val_loss=0.02139  time=1.18s
# Epoch 2  loss=0.01264  val_loss=0.01040  sm_loss=0.01261  sm_val_loss=0.01039  time=1.13s
# Epoch 3  loss=0.00974  val_loss=0.00983  sm_loss=0.00982  sm_val_loss=0.00992  time=1.10s
# Epoch 9  loss=0.00940  val_loss=0.00975  sm_loss=0.00960  sm_val_loss=0.00983  time=1.27s
# Epoch 10  loss=0.00937  val_loss=0.00973  sm_loss=0.00956  sm_val_loss=0.00982  time=1.06s
# Epoch 11  loss=0.00934  val_loss=0.00963  sm_loss=0.00954  sm_val_loss=0.00975  time=1.08s
# Epoch 14  loss=0.00929  val_loss=0.00959  sm_loss=0.00949  sm_val_loss=0.00968  time=1.35s
# Epoch 16  loss=0.00921  val_loss=0.00951  sm_loss=0.00942  sm_val_loss=0.00960  time=1.07s
# Epoch 17  loss=0.00916  val_loss=0.00951  sm_loss=0.00937  sm_val_loss=0.00960  time=1.05s
# Epoch 18  loss=0.00907  val_loss=0.00940  sm_loss=0.00928  sm_val_loss=0.00950  time=1.06s
# Epoch 20  loss=0.00894  val_loss=0.00935  sm_loss=0.00916  sm_val_loss=0.00944  time=1.20s
# Epoch 21  loss=0.00883  val_loss=0.00929  sm_loss=0.00905  sm_val_loss=0.00940  time=1.06s
# Epoch 22  loss=0.00873  val_loss=0.00921  sm_loss=0.00897  sm_val_loss=0.00932  time=1.42s
# Epoch 23  loss=0.00862  val_loss=0.00917  sm_loss=0.00886  sm_val_loss=0.00928  time=1.40s
# Epoch 24  loss=0.00853  val_loss=0.00913  sm_loss=0.00878  sm_val_loss=0.00925  time=1.18s
# Fold 5
# Epoch 1  loss=0.50752  val_loss=0.02496  sm_loss=0.50748  sm_val_loss=0.02495  time=1.15s
# Epoch 2  loss=0.01307  val_loss=0.01037  sm_loss=0.01301  sm_val_loss=0.01039  time=1.08s
# Epoch 3  loss=0.00983  val_loss=0.01014  sm_loss=0.00989  sm_val_loss=0.01022  time=1.08s
# Epoch 4  loss=0.00934  val_loss=0.00996  sm_loss=0.00952  sm_val_loss=0.01005  time=1.05s
# Epoch 5  loss=0.00942  val_loss=0.00988  sm_loss=0.00961  sm_val_loss=0.00996  time=1.06s
# Epoch 6  loss=0.00925  val_loss=0.00976  sm_loss=0.00946  sm_val_loss=0.00985  time=1.14s
# Epoch 7  loss=0.00926  val_loss=0.00973  sm_loss=0.00947  sm_val_loss=0.00981  time=1.17s
# Epoch 9  loss=0.00930  val_loss=0.00970  sm_loss=0.00950  sm_val_loss=0.00979  time=1.10s
# Epoch 10  loss=0.00927  val_loss=0.00968  sm_loss=0.00948  sm_val_loss=0.00977  time=1.41s
# Epoch 12  loss=0.00929  val_loss=0.00966  sm_loss=0.00949  sm_val_loss=0.00976  time=1.05s
# Epoch 15  loss=0.00920  val_loss=0.00953  sm_loss=0.00941  sm_val_loss=0.00963  time=1.06s
# Epoch 18  loss=0.00905  val_loss=0.00947  sm_loss=0.00926  sm_val_loss=0.00957  time=1.06s
# Epoch 19  loss=0.00899  val_loss=0.00942  sm_loss=0.00921  sm_val_loss=0.00951  time=1.09s
# Epoch 20  loss=0.00890  val_loss=0.00936  sm_loss=0.00912  sm_val_loss=0.00946  time=1.11s
# Epoch 22  loss=0.00871  val_loss=0.00923  sm_loss=0.00894  sm_val_loss=0.00934  time=1.05s
# Epoch 25  loss=0.00845  val_loss=0.00921  sm_loss=0.00870  sm_val_loss=0.00932  time=1.05s
# Fold 6
# Epoch 1  loss=0.50728  val_loss=0.02556  sm_loss=0.50723  sm_val_loss=0.02552  time=1.16s
# Epoch 2  loss=0.01315  val_loss=0.01060  sm_loss=0.01307  sm_val_loss=0.01041  time=1.04s
# Epoch 3  loss=0.01005  val_loss=0.00944  sm_loss=0.01007  sm_val_loss=0.00950  time=1.09s
# Epoch 4  loss=0.00955  val_loss=0.00924  sm_loss=0.00972  sm_val_loss=0.00936  time=1.06s
# Epoch 5  loss=0.01032  val_loss=0.00920  sm_loss=0.01034  sm_val_loss=0.00934  time=1.08s
# Epoch 7  loss=0.00938  val_loss=0.00913  sm_loss=0.00959  sm_val_loss=0.00923  time=1.07s
# Epoch 14  loss=0.00936  val_loss=0.00907  sm_loss=0.00955  sm_val_loss=0.00919  time=1.23s
# Epoch 15  loss=0.00932  val_loss=0.00902  sm_loss=0.00952  sm_val_loss=0.00916  time=1.11s
# Epoch 17  loss=0.00925  val_loss=0.00899  sm_loss=0.00945  sm_val_loss=0.00911  time=1.10s
# Epoch 18  loss=0.00914  val_loss=0.00893  sm_loss=0.00934  sm_val_loss=0.00907  time=1.11s
# Epoch 19  loss=0.00909  val_loss=0.00887  sm_loss=0.00930  sm_val_loss=0.00901  time=1.31s
# Epoch 21  loss=0.00892  val_loss=0.00880  sm_loss=0.00915  sm_val_loss=0.00892  time=1.06s
# Epoch 22  loss=0.00877  val_loss=0.00876  sm_loss=0.00901  sm_val_loss=0.00890  time=1.27s
# Epoch 23  loss=0.00869  val_loss=0.00870  sm_loss=0.00893  sm_val_loss=0.00884  time=1.15s
# Epoch 24  loss=0.00857  val_loss=0.00867  sm_loss=0.00881  sm_val_loss=0.00882  time=1.11s
# Fold 7
# Epoch 1  loss=0.50656  val_loss=0.02286  sm_loss=0.50651  sm_val_loss=0.02268  time=1.13s
# Epoch 2  loss=0.01333  val_loss=0.00968  sm_loss=0.01325  sm_val_loss=0.00966  time=1.09s
# Epoch 3  loss=0.00992  val_loss=0.00916  sm_loss=0.00995  sm_val_loss=0.00928  time=1.31s
# Epoch 5  loss=0.00984  val_loss=0.00900  sm_loss=0.00997  sm_val_loss=0.00916  time=1.06s
# Epoch 6  loss=0.00940  val_loss=0.00896  sm_loss=0.00961  sm_val_loss=0.00911  time=1.06s
# Epoch 13  loss=0.00940  val_loss=0.00890  sm_loss=0.00959  sm_val_loss=0.00906  time=1.32s
# Epoch 14  loss=0.00937  val_loss=0.00891  sm_loss=0.00956  sm_val_loss=0.00905  time=1.05s
# Epoch 15  loss=0.00934  val_loss=0.00883  sm_loss=0.00953  sm_val_loss=0.00898  time=1.06s
# Epoch 17  loss=0.00924  val_loss=0.00881  sm_loss=0.00943  sm_val_loss=0.00898  time=1.05s
# Epoch 18  loss=0.00916  val_loss=0.00874  sm_loss=0.00936  sm_val_loss=0.00891  time=1.06s
# Epoch 19  loss=0.00912  val_loss=0.00869  sm_loss=0.00933  sm_val_loss=0.00885  time=1.07s
# Epoch 21  loss=0.00890  val_loss=0.00855  sm_loss=0.00912  sm_val_loss=0.00872  time=1.07s
# Epoch 22  loss=0.00879  val_loss=0.00854  sm_loss=0.00902  sm_val_loss=0.00872  time=1.31s
# Epoch 23  loss=0.00869  val_loss=0.00846  sm_loss=0.00892  sm_val_loss=0.00864  time=1.05s
# Epoch 24  loss=0.00858  val_loss=0.00845  sm_loss=0.00882  sm_val_loss=0.00863  time=1.06s
# Fold 1
# Epoch 1  loss=0.61125  val_loss=0.32227  sm_loss=0.61118  sm_val_loss=0.32123  time=1.04s
# Epoch 2  loss=0.04178  val_loss=0.02057  sm_loss=0.04165  sm_val_loss=0.02055  time=1.08s
# Epoch 3  loss=0.02020  val_loss=0.01877  sm_loss=0.02019  sm_val_loss=0.01877  time=1.09s
# Epoch 4  loss=0.01838  val_loss=0.01805  sm_loss=0.01844  sm_val_loss=0.01809  time=1.05s
# Epoch 5  loss=0.01776  val_loss=0.01781  sm_loss=0.01784  sm_val_loss=0.01782  time=1.04s
# Epoch 6  loss=0.01758  val_loss=0.01769  sm_loss=0.01766  sm_val_loss=0.01762  time=1.04s
# Epoch 7  loss=0.01714  val_loss=0.01749  sm_loss=0.01728  sm_val_loss=0.01751  time=1.31s
# Epoch 8  loss=0.01687  val_loss=0.01749  sm_loss=0.01704  sm_val_loss=0.01745  time=1.04s
# Epoch 11  loss=0.01628  val_loss=0.01743  sm_loss=0.01651  sm_val_loss=0.01739  time=1.06s
# Epoch 12  loss=0.01615  val_loss=0.01719  sm_loss=0.01638  sm_val_loss=0.01715  time=1.04s
# Fold 1 log loss: 0.017252484360028585
# Fold 2
# Epoch 1  loss=0.60996  val_loss=0.20111  sm_loss=0.60990  sm_val_loss=0.20105  time=1.16s
# Epoch 2  loss=0.04222  val_loss=0.01974  sm_loss=0.04215  sm_val_loss=0.01973  time=1.14s
# Epoch 3  loss=0.01992  val_loss=0.01818  sm_loss=0.01990  sm_val_loss=0.01821  time=1.07s
# Epoch 4  loss=0.01865  val_loss=0.01767  sm_loss=0.01860  sm_val_loss=0.01774  time=1.11s
# Epoch 5  loss=0.01779  val_loss=0.01726  sm_loss=0.01787  sm_val_loss=0.01733  time=1.08s
# Epoch 7  loss=0.01727  val_loss=0.01704  sm_loss=0.01741  sm_val_loss=0.01712  time=1.04s
# Epoch 12  loss=0.01630  val_loss=0.01700  sm_loss=0.01653  sm_val_loss=0.01703  time=1.04s
# Epoch 13  loss=0.01607  val_loss=0.01705  sm_loss=0.01632  sm_val_loss=0.01703  time=1.03s
# Epoch 16  loss=0.01538  val_loss=0.01708  sm_loss=0.01568  sm_val_loss=0.01700  time=1.05s
# Fold 2 log loss: 0.017134071871139862
# Fold 3
# Epoch 1  loss=0.61171  val_loss=0.22401  sm_loss=0.61158  sm_val_loss=0.22323  time=1.05s
# Epoch 2  loss=0.04178  val_loss=0.02033  sm_loss=0.04166  sm_val_loss=0.02032  time=1.24s
# Epoch 3  loss=0.01922  val_loss=0.01844  sm_loss=0.01922  sm_val_loss=0.01844  time=1.09s
# Epoch 4  loss=0.01799  val_loss=0.01836  sm_loss=0.01803  sm_val_loss=0.01838  time=1.08s
# Epoch 6  loss=0.01718  val_loss=0.01783  sm_loss=0.01730  sm_val_loss=0.01785  time=1.02s
# Epoch 7  loss=0.01691  val_loss=0.01786  sm_loss=0.01707  sm_val_loss=0.01785  time=1.04s
# Epoch 9  loss=0.01657  val_loss=0.01772  sm_loss=0.01675  sm_val_loss=0.01772  time=1.11s
# Epoch 12  loss=0.01592  val_loss=0.01777  sm_loss=0.01617  sm_val_loss=0.01769  time=1.28s
# Epoch 13  loss=0.01574  val_loss=0.01773  sm_loss=0.01601  sm_val_loss=0.01767  time=1.05s
# Epoch 17  loss=0.01494  val_loss=0.01777  sm_loss=0.01525  sm_val_loss=0.01760  time=1.04s
# Fold 3 log loss: 0.017552193089033278
# Fold 4
# Epoch 1  loss=0.61459  val_loss=0.33402  sm_loss=0.61447  sm_val_loss=0.31480  time=1.08s
# Epoch 2  loss=0.04272  val_loss=0.02070  sm_loss=0.04262  sm_val_loss=0.02069  time=1.12s
# Epoch 3  loss=0.02078  val_loss=0.01959  sm_loss=0.02076  sm_val_loss=0.01910  time=1.13s
# Epoch 4  loss=0.01870  val_loss=0.01857  sm_loss=0.01873  sm_val_loss=0.01853  time=1.36s
# Epoch 5  loss=0.01810  val_loss=0.01842  sm_loss=0.01818  sm_val_loss=0.01839  time=1.03s
# Epoch 6  loss=0.01776  val_loss=0.01849  sm_loss=0.01786  sm_val_loss=0.01838  time=1.04s
# Epoch 7  loss=0.01743  val_loss=0.01839  sm_loss=0.01757  sm_val_loss=0.01830  time=1.03s
# Epoch 8  loss=0.01721  val_loss=0.01797  sm_loss=0.01737  sm_val_loss=0.01795  time=1.06s
# Epoch 9  loss=0.01694  val_loss=0.01784  sm_loss=0.01712  sm_val_loss=0.01787  time=1.05s
# Epoch 10  loss=0.01682  val_loss=0.01788  sm_loss=0.01702  sm_val_loss=0.01781  time=1.05s
# Epoch 15  loss=0.01587  val_loss=0.01785  sm_loss=0.01613  sm_val_loss=0.01774  time=1.03s
# Epoch 16  loss=0.01565  val_loss=0.01772  sm_loss=0.01593  sm_val_loss=0.01763  time=1.08s
# Fold 4 log loss: 0.01773088352898418
# Fold 5
# Epoch 1  loss=0.61431  val_loss=0.15351  sm_loss=0.61426  sm_val_loss=0.15328  time=1.04s
# Epoch 2  loss=0.04241  val_loss=0.01989  sm_loss=0.04231  sm_val_loss=0.01989  time=1.04s
# Epoch 3  loss=0.01965  val_loss=0.01856  sm_loss=0.01967  sm_val_loss=0.01859  time=1.21s
# Epoch 4  loss=0.01833  val_loss=0.01803  sm_loss=0.01836  sm_val_loss=0.01805  time=1.09s
# Epoch 5  loss=0.01778  val_loss=0.01794  sm_loss=0.01785  sm_val_loss=0.01787  time=1.03s
# Epoch 6  loss=0.01740  val_loss=0.01779  sm_loss=0.01750  sm_val_loss=0.01782  time=1.05s
# Epoch 7  loss=0.01714  val_loss=0.01748  sm_loss=0.01729  sm_val_loss=0.01750  time=1.25s
# Epoch 8  loss=0.01678  val_loss=0.01740  sm_loss=0.01695  sm_val_loss=0.01738  time=1.07s
# Epoch 11  loss=0.01618  val_loss=0.01733  sm_loss=0.01641  sm_val_loss=0.01729  time=1.07s
# Epoch 13  loss=0.01584  val_loss=0.01731  sm_loss=0.01609  sm_val_loss=0.01727  time=1.04s
# Epoch 14  loss=0.01560  val_loss=0.01724  sm_loss=0.01587  sm_val_loss=0.01718  time=1.06s
# Fold 5 log loss: 0.017356389716575216
# Fold 6
# Epoch 1  loss=0.61190  val_loss=0.17523  sm_loss=0.61185  sm_val_loss=0.17523  time=1.12s
# Epoch 2  loss=0.04227  val_loss=0.02105  sm_loss=0.04217  sm_val_loss=0.02094  time=1.09s
# Epoch 3  loss=0.02014  val_loss=0.01961  sm_loss=0.02013  sm_val_loss=0.01932  time=1.24s
# Epoch 4  loss=0.01871  val_loss=0.01847  sm_loss=0.01873  sm_val_loss=0.01850  time=1.07s
# Epoch 5  loss=0.01841  val_loss=0.01809  sm_loss=0.01848  sm_val_loss=0.01818  time=1.08s
# Epoch 6  loss=0.01775  val_loss=0.01783  sm_loss=0.01786  sm_val_loss=0.01793  time=1.07s
# Epoch 7  loss=0.01742  val_loss=0.01766  sm_loss=0.01756  sm_val_loss=0.01777  time=1.15s
# Epoch 9  loss=0.01699  val_loss=0.01764  sm_loss=0.01715  sm_val_loss=0.01774  time=1.08s
# Epoch 10  loss=0.01681  val_loss=0.01751  sm_loss=0.01697  sm_val_loss=0.01764  time=1.07s
# Epoch 11  loss=0.01671  val_loss=0.01750  sm_loss=0.01691  sm_val_loss=0.01761  time=1.08s
# Epoch 13  loss=0.01627  val_loss=0.01737  sm_loss=0.01651  sm_val_loss=0.01749  time=1.04s
# Epoch 17  loss=0.01555  val_loss=0.01737  sm_loss=0.01583  sm_val_loss=0.01747  time=1.06s
# Epoch 18  loss=0.01532  val_loss=0.01729  sm_loss=0.01562  sm_val_loss=0.01736  time=1.30s
# Fold 6 log loss: 0.01739256184981064
# Fold 7
# Epoch 1  loss=0.61425  val_loss=0.26876  sm_loss=0.61415  sm_val_loss=0.26861  time=1.78s
# Epoch 2  loss=0.04308  val_loss=0.02014  sm_loss=0.04299  sm_val_loss=0.02014  time=1.07s
# Epoch 3  loss=0.01972  val_loss=0.01858  sm_loss=0.01971  sm_val_loss=0.01863  time=1.14s
# Epoch 4  loss=0.01850  val_loss=0.01874  sm_loss=0.01853  sm_val_loss=0.01838  time=1.09s
# Epoch 5  loss=0.01790  val_loss=0.01777  sm_loss=0.01798  sm_val_loss=0.01770  time=1.07s
# Epoch 6  loss=0.01737  val_loss=0.01746  sm_loss=0.01751  sm_val_loss=0.01755  time=1.15s
# Epoch 8  loss=0.01688  val_loss=0.01747  sm_loss=0.01707  sm_val_loss=0.01755  time=1.15s
# Epoch 9  loss=0.01677  val_loss=0.01727  sm_loss=0.01694  sm_val_loss=0.01737  time=1.11s
# Epoch 10  loss=0.01640  val_loss=0.01722  sm_loss=0.01662  sm_val_loss=0.01732  time=1.36s
# Epoch 12  loss=0.01624  val_loss=0.01718  sm_loss=0.01647  sm_val_loss=0.01725  time=1.11s
# Epoch 13  loss=0.01591  val_loss=0.01709  sm_loss=0.01618  sm_val_loss=0.01709  time=1.10s
# Fold 7 log loss: 0.01711980080886571
# Seed 0
# Fold 1 log loss: 0.017252484360028585
# Fold 2 log loss: 0.017134071871139862
# Fold 3 log loss: 0.017552193089033278
# Fold 4 log loss: 0.01773088352898418
# Fold 5 log loss: 0.017356389716575216
# Fold 6 log loss: 0.01739256184981064
# Fold 7 log loss: 0.01711980080886571
# Std of log loss: 0.00020557118313735756
# Total log loss: 0.017362646507475384
# Fold 1
# Epoch 1  loss=0.50752  val_loss=0.02445  sm_loss=0.50749  sm_val_loss=0.02428  time=1.42s
# Epoch 2  loss=0.01291  val_loss=0.01071  sm_loss=0.01282  sm_val_loss=0.01068  time=1.13s
# Epoch 3  loss=0.00978  val_loss=0.01006  sm_loss=0.00982  sm_val_loss=0.01015  time=1.07s
# Epoch 4  loss=0.00931  val_loss=0.00998  sm_loss=0.00949  sm_val_loss=0.01008  time=1.09s
# Epoch 5  loss=0.00925  val_loss=0.00997  sm_loss=0.00944  sm_val_loss=0.01007  time=1.10s
# Epoch 8  loss=0.00927  val_loss=0.00991  sm_loss=0.00947  sm_val_loss=0.00998  time=1.09s
# Epoch 9  loss=0.00921  val_loss=0.00988  sm_loss=0.00941  sm_val_loss=0.00997  time=1.06s
# Epoch 11  loss=0.00924  val_loss=0.00980  sm_loss=0.00944  sm_val_loss=0.00989  time=1.08s
# Epoch 14  loss=0.00920  val_loss=0.00978  sm_loss=0.00940  sm_val_loss=0.00985  time=1.09s
# Epoch 18  loss=0.00901  val_loss=0.00969  sm_loss=0.00923  sm_val_loss=0.00978  time=1.05s
# Epoch 20  loss=0.00886  val_loss=0.00956  sm_loss=0.00908  sm_val_loss=0.00967  time=1.34s
# Epoch 21  loss=0.00877  val_loss=0.00951  sm_loss=0.00899  sm_val_loss=0.00962  time=1.06s
# Epoch 22  loss=0.00865  val_loss=0.00948  sm_loss=0.00888  sm_val_loss=0.00959  time=1.07s
# Epoch 23  loss=0.00854  val_loss=0.00941  sm_loss=0.00878  sm_val_loss=0.00953  time=1.07s
# Epoch 24  loss=0.00845  val_loss=0.00939  sm_loss=0.00870  sm_val_loss=0.00951  time=1.06s
# Epoch 25  loss=0.00840  val_loss=0.00938  sm_loss=0.00865  sm_val_loss=0.00950  time=1.07s
# Fold 2
# Epoch 1  loss=0.50597  val_loss=0.02762  sm_loss=0.50593  sm_val_loss=0.02755  time=1.11s
# Epoch 2  loss=0.01315  val_loss=0.01031  sm_loss=0.01308  sm_val_loss=0.01033  time=1.38s
# Epoch 3  loss=0.00998  val_loss=0.00962  sm_loss=0.01002  sm_val_loss=0.00972  time=1.22s
# Epoch 6  loss=0.00940  val_loss=0.00961  sm_loss=0.00962  sm_val_loss=0.00967  time=1.15s
# Epoch 8  loss=0.00934  val_loss=0.00949  sm_loss=0.00954  sm_val_loss=0.00957  time=1.11s
# Epoch 14  loss=0.00929  val_loss=0.00940  sm_loss=0.00949  sm_val_loss=0.00948  time=1.06s
# Epoch 17  loss=0.00916  val_loss=0.00938  sm_loss=0.00937  sm_val_loss=0.00945  time=1.16s
# Epoch 18  loss=0.00908  val_loss=0.00936  sm_loss=0.00929  sm_val_loss=0.00943  time=1.38s
# Epoch 19  loss=0.00900  val_loss=0.00922  sm_loss=0.00922  sm_val_loss=0.00932  time=1.10s
# Epoch 20  loss=0.00894  val_loss=0.00921  sm_loss=0.00916  sm_val_loss=0.00928  time=1.13s
# Epoch 21  loss=0.00882  val_loss=0.00918  sm_loss=0.00905  sm_val_loss=0.00927  time=1.11s
# Epoch 22  loss=0.00871  val_loss=0.00912  sm_loss=0.00895  sm_val_loss=0.00922  time=1.25s
# Epoch 23  loss=0.00857  val_loss=0.00905  sm_loss=0.00882  sm_val_loss=0.00915  time=1.47s
# Epoch 24  loss=0.00849  val_loss=0.00902  sm_loss=0.00875  sm_val_loss=0.00913  time=1.16s
# Epoch 25  loss=0.00844  val_loss=0.00902  sm_loss=0.00870  sm_val_loss=0.00912  time=1.18s
# Fold 3
# Epoch 1  loss=0.50664  val_loss=0.02695  sm_loss=0.50661  sm_val_loss=0.02692  time=1.12s
# Epoch 2  loss=0.01313  val_loss=0.01006  sm_loss=0.01304  sm_val_loss=0.01009  time=1.09s
# Epoch 3  loss=0.00990  val_loss=0.00962  sm_loss=0.00994  sm_val_loss=0.00970  time=1.48s
# Epoch 4  loss=0.00946  val_loss=0.00942  sm_loss=0.00962  sm_val_loss=0.00950  time=1.10s
# Epoch 5  loss=0.00931  val_loss=0.00935  sm_loss=0.00949  sm_val_loss=0.00945  time=1.34s
# Epoch 7  loss=0.00929  val_loss=0.00930  sm_loss=0.00951  sm_val_loss=0.00939  time=1.07s
# Epoch 10  loss=0.00930  val_loss=0.00927  sm_loss=0.00950  sm_val_loss=0.00936  time=1.04s
# Epoch 11  loss=0.00930  val_loss=0.00928  sm_loss=0.00950  sm_val_loss=0.00936  time=1.05s
# Epoch 12  loss=0.00930  val_loss=0.00920  sm_loss=0.00950  sm_val_loss=0.00931  time=1.08s
# Epoch 14  loss=0.00926  val_loss=0.00913  sm_loss=0.00946  sm_val_loss=0.00924  time=1.06s
# Epoch 17  loss=0.00914  val_loss=0.00908  sm_loss=0.00935  sm_val_loss=0.00917  time=1.10s
# Epoch 19  loss=0.00898  val_loss=0.00904  sm_loss=0.00920  sm_val_loss=0.00914  time=1.08s
# Epoch 20  loss=0.00889  val_loss=0.00893  sm_loss=0.00912  sm_val_loss=0.00903  time=1.11s
# Epoch 22  loss=0.00867  val_loss=0.00883  sm_loss=0.00891  sm_val_loss=0.00893  time=1.07s
# Epoch 24  loss=0.00844  val_loss=0.00880  sm_loss=0.00869  sm_val_loss=0.00891  time=1.24s
# Fold 4
# Epoch 1  loss=0.50847  val_loss=0.02283  sm_loss=0.50845  sm_val_loss=0.02251  time=1.10s
# Epoch 2  loss=0.01273  val_loss=0.01048  sm_loss=0.01272  sm_val_loss=0.01045  time=1.11s
# Epoch 3  loss=0.00978  val_loss=0.00987  sm_loss=0.00985  sm_val_loss=0.00993  time=1.13s
# Epoch 5  loss=0.00935  val_loss=0.00969  sm_loss=0.00952  sm_val_loss=0.00978  time=1.50s
# Epoch 7  loss=0.00948  val_loss=0.00967  sm_loss=0.00968  sm_val_loss=0.00975  time=1.12s
# Epoch 8  loss=0.00928  val_loss=0.00963  sm_loss=0.00949  sm_val_loss=0.00972  time=1.35s
# Epoch 12  loss=0.00925  val_loss=0.00957  sm_loss=0.00946  sm_val_loss=0.00965  time=1.08s
# Epoch 14  loss=0.00926  val_loss=0.00955  sm_loss=0.00946  sm_val_loss=0.00963  time=1.09s
# Epoch 15  loss=0.00921  val_loss=0.00949  sm_loss=0.00942  sm_val_loss=0.00958  time=1.22s
# Epoch 17  loss=0.00913  val_loss=0.00945  sm_loss=0.00933  sm_val_loss=0.00955  time=1.36s
# Epoch 18  loss=0.00904  val_loss=0.00939  sm_loss=0.00925  sm_val_loss=0.00949  time=1.41s
# Epoch 19  loss=0.00900  val_loss=0.00938  sm_loss=0.00921  sm_val_loss=0.00948  time=1.15s
# Epoch 20  loss=0.00894  val_loss=0.00935  sm_loss=0.00916  sm_val_loss=0.00945  time=1.10s
# Epoch 21  loss=0.00880  val_loss=0.00927  sm_loss=0.00903  sm_val_loss=0.00938  time=1.12s
# Epoch 22  loss=0.00870  val_loss=0.00918  sm_loss=0.00893  sm_val_loss=0.00930  time=1.23s
# Epoch 23  loss=0.00856  val_loss=0.00911  sm_loss=0.00881  sm_val_loss=0.00923  time=1.11s
# Epoch 24  loss=0.00847  val_loss=0.00909  sm_loss=0.00872  sm_val_loss=0.00921  time=1.15s
# Epoch 25  loss=0.00844  val_loss=0.00908  sm_loss=0.00869  sm_val_loss=0.00920  time=1.18s
# Fold 5
# Epoch 1  loss=0.50711  val_loss=0.02319  sm_loss=0.50707  sm_val_loss=0.02321  time=1.32s
# Epoch 2  loss=0.01294  val_loss=0.01060  sm_loss=0.01287  sm_val_loss=0.01061  time=1.14s
# Epoch 3  loss=0.01012  val_loss=0.01053  sm_loss=0.01016  sm_val_loss=0.01051  time=1.14s
# Epoch 4  loss=0.00948  val_loss=0.00975  sm_loss=0.00964  sm_val_loss=0.00983  time=1.22s
# Epoch 5  loss=0.00921  val_loss=0.00967  sm_loss=0.00943  sm_val_loss=0.00975  time=1.35s
# Epoch 6  loss=0.00927  val_loss=0.00962  sm_loss=0.00948  sm_val_loss=0.00972  time=1.26s
# Epoch 12  loss=0.00925  val_loss=0.00962  sm_loss=0.00945  sm_val_loss=0.00969  time=1.09s
# Epoch 14  loss=0.00922  val_loss=0.00955  sm_loss=0.00942  sm_val_loss=0.00964  time=1.08s
# Epoch 16  loss=0.00914  val_loss=0.00953  sm_loss=0.00935  sm_val_loss=0.00962  time=1.10s
# Epoch 19  loss=0.00896  val_loss=0.00943  sm_loss=0.00918  sm_val_loss=0.00953  time=1.38s
# Epoch 20  loss=0.00887  val_loss=0.00931  sm_loss=0.00909  sm_val_loss=0.00941  time=1.11s
# Epoch 21  loss=0.00876  val_loss=0.00929  sm_loss=0.00899  sm_val_loss=0.00940  time=1.12s
# Epoch 22  loss=0.00865  val_loss=0.00922  sm_loss=0.00888  sm_val_loss=0.00933  time=1.09s
# Epoch 23  loss=0.00852  val_loss=0.00919  sm_loss=0.00876  sm_val_loss=0.00930  time=1.09s
# Epoch 24  loss=0.00843  val_loss=0.00918  sm_loss=0.00868  sm_val_loss=0.00930  time=1.11s
# Fold 6
# Epoch 1  loss=0.50636  val_loss=0.02351  sm_loss=0.50631  sm_val_loss=0.02293  time=1.09s
# Epoch 2  loss=0.01284  val_loss=0.00996  sm_loss=0.01279  sm_val_loss=0.00997  time=1.11s
# Epoch 3  loss=0.00997  val_loss=0.00940  sm_loss=0.01000  sm_val_loss=0.00949  time=1.41s
# Epoch 4  loss=0.00957  val_loss=0.00923  sm_loss=0.00972  sm_val_loss=0.00937  time=1.28s
# Epoch 5  loss=0.00935  val_loss=0.00922  sm_loss=0.00955  sm_val_loss=0.00934  time=1.19s
# Epoch 6  loss=0.00937  val_loss=0.00917  sm_loss=0.00956  sm_val_loss=0.00932  time=1.17s
# Epoch 11  loss=0.00935  val_loss=0.00914  sm_loss=0.00955  sm_val_loss=0.00928  time=1.13s
# Epoch 12  loss=0.00937  val_loss=0.00912  sm_loss=0.00956  sm_val_loss=0.00925  time=1.30s
# Epoch 14  loss=0.00935  val_loss=0.00909  sm_loss=0.00955  sm_val_loss=0.00921  time=1.52s
# Epoch 15  loss=0.00931  val_loss=0.00906  sm_loss=0.00951  sm_val_loss=0.00919  time=1.12s
# Epoch 17  loss=0.00923  val_loss=0.00906  sm_loss=0.00943  sm_val_loss=0.00918  time=1.14s
# Epoch 18  loss=0.00914  val_loss=0.00893  sm_loss=0.00934  sm_val_loss=0.00908  time=1.10s
# Epoch 19  loss=0.00908  val_loss=0.00892  sm_loss=0.00929  sm_val_loss=0.00904  time=1.14s
# Epoch 20  loss=0.00896  val_loss=0.00885  sm_loss=0.00918  sm_val_loss=0.00898  time=1.11s
# Epoch 21  loss=0.00890  val_loss=0.00878  sm_loss=0.00913  sm_val_loss=0.00892  time=1.45s
# Epoch 22  loss=0.00877  val_loss=0.00871  sm_loss=0.00900  sm_val_loss=0.00885  time=1.13s
# Epoch 23  loss=0.00865  val_loss=0.00867  sm_loss=0.00889  sm_val_loss=0.00882  time=1.11s
# Epoch 24  loss=0.00854  val_loss=0.00866  sm_loss=0.00879  sm_val_loss=0.00881  time=1.13s
# Fold 7
# Epoch 1  loss=0.50722  val_loss=0.02194  sm_loss=0.50718  sm_val_loss=0.02193  time=1.09s
# Epoch 2  loss=0.01328  val_loss=0.00999  sm_loss=0.01317  sm_val_loss=0.00993  time=1.10s
# Epoch 3  loss=0.01017  val_loss=0.00981  sm_loss=0.01016  sm_val_loss=0.00959  time=1.23s
# Epoch 4  loss=0.00955  val_loss=0.00900  sm_loss=0.00972  sm_val_loss=0.00916  time=1.33s
# Epoch 6  loss=0.00940  val_loss=0.00888  sm_loss=0.00959  sm_val_loss=0.00905  time=1.11s
# Epoch 10  loss=0.00940  val_loss=0.00888  sm_loss=0.00960  sm_val_loss=0.00905  time=1.15s
# Epoch 15  loss=0.00929  val_loss=0.00885  sm_loss=0.00948  sm_val_loss=0.00900  time=1.11s
# Epoch 18  loss=0.00918  val_loss=0.00871  sm_loss=0.00938  sm_val_loss=0.00887  time=1.09s
# Epoch 20  loss=0.00896  val_loss=0.00862  sm_loss=0.00917  sm_val_loss=0.00878  time=1.12s
# Epoch 21  loss=0.00886  val_loss=0.00857  sm_loss=0.00908  sm_val_loss=0.00874  time=1.13s
# Epoch 22  loss=0.00876  val_loss=0.00852  sm_loss=0.00899  sm_val_loss=0.00870  time=1.42s
# Epoch 23  loss=0.00865  val_loss=0.00845  sm_loss=0.00889  sm_val_loss=0.00863  time=1.18s
# Epoch 25  loss=0.00849  val_loss=0.00844  sm_loss=0.00874  sm_val_loss=0.00862  time=1.10s
# Fold 1
# Epoch 1  loss=0.61163  val_loss=0.21213  sm_loss=0.61159  sm_val_loss=0.21203  time=1.08s
# Epoch 2  loss=0.04286  val_loss=0.02140  sm_loss=0.04278  sm_val_loss=0.02139  time=1.14s
# Epoch 3  loss=0.01967  val_loss=0.01826  sm_loss=0.01966  sm_val_loss=0.01828  time=1.16s
# Epoch 4  loss=0.01835  val_loss=0.01783  sm_loss=0.01836  sm_val_loss=0.01788  time=1.11s
# Epoch 5  loss=0.01782  val_loss=0.01775  sm_loss=0.01790  sm_val_loss=0.01776  time=1.12s
# Epoch 6  loss=0.01744  val_loss=0.01762  sm_loss=0.01753  sm_val_loss=0.01767  time=1.41s
# Epoch 7  loss=0.01715  val_loss=0.01768  sm_loss=0.01730  sm_val_loss=0.01763  time=1.10s
# Epoch 8  loss=0.01696  val_loss=0.01735  sm_loss=0.01714  sm_val_loss=0.01737  time=1.33s
# Epoch 12  loss=0.01620  val_loss=0.01738  sm_loss=0.01642  sm_val_loss=0.01734  time=1.49s
# Epoch 13  loss=0.01594  val_loss=0.01742  sm_loss=0.01619  sm_val_loss=0.01733  time=1.13s
# Epoch 14  loss=0.01586  val_loss=0.01731  sm_loss=0.01612  sm_val_loss=0.01726  time=1.12s
# Epoch 19  loss=0.01453  val_loss=0.01741  sm_loss=0.01487  sm_val_loss=0.01723  time=1.09s
# Fold 1 log loss: 0.017331621861762927
# Fold 2
# Epoch 1  loss=0.61013  val_loss=0.17884  sm_loss=0.61004  sm_val_loss=0.17843  time=1.09s
# Epoch 2  loss=0.04168  val_loss=0.02007  sm_loss=0.04158  sm_val_loss=0.02007  time=1.17s
# Epoch 3  loss=0.01966  val_loss=0.01821  sm_loss=0.01966  sm_val_loss=0.01823  time=1.10s
# Epoch 4  loss=0.01834  val_loss=0.01734  sm_loss=0.01838  sm_val_loss=0.01741  time=1.09s
# Epoch 5  loss=0.01782  val_loss=0.01720  sm_loss=0.01787  sm_val_loss=0.01728  time=1.11s
# Epoch 6  loss=0.01736  val_loss=0.01712  sm_loss=0.01749  sm_val_loss=0.01719  time=1.19s
# Epoch 7  loss=0.01721  val_loss=0.01705  sm_loss=0.01737  sm_val_loss=0.01710  time=1.27s
# Epoch 9  loss=0.01676  val_loss=0.01689  sm_loss=0.01694  sm_val_loss=0.01696  time=1.32s
# Epoch 11  loss=0.01633  val_loss=0.01693  sm_loss=0.01655  sm_val_loss=0.01693  time=1.11s
# Fold 2 log loss: 0.017087234890599073
# Fold 3
# Epoch 1  loss=0.61323  val_loss=0.16739  sm_loss=0.61319  sm_val_loss=0.16662  time=1.17s
# Epoch 2  loss=0.04285  val_loss=0.02056  sm_loss=0.04268  sm_val_loss=0.02056  time=1.08s
# Epoch 3  loss=0.01976  val_loss=0.01887  sm_loss=0.01969  sm_val_loss=0.01890  time=1.27s
# Epoch 4  loss=0.01826  val_loss=0.01819  sm_loss=0.01829  sm_val_loss=0.01826  time=1.09s
# Epoch 5  loss=0.01773  val_loss=0.01780  sm_loss=0.01781  sm_val_loss=0.01785  time=1.10s
# Epoch 9  loss=0.01677  val_loss=0.01787  sm_loss=0.01695  sm_val_loss=0.01784  time=2.06s
# Epoch 10  loss=0.01646  val_loss=0.01779  sm_loss=0.01666  sm_val_loss=0.01778  time=1.20s
# Epoch 11  loss=0.01627  val_loss=0.01764  sm_loss=0.01650  sm_val_loss=0.01761  time=1.16s
# Epoch 13  loss=0.01581  val_loss=0.01756  sm_loss=0.01608  sm_val_loss=0.01752  time=1.20s
# Fold 3 log loss: 0.01748193771672767
# Fold 4
# Epoch 1  loss=0.61166  val_loss=0.21121  sm_loss=0.61158  sm_val_loss=0.19434  time=1.10s
# Epoch 2  loss=0.04304  val_loss=0.02050  sm_loss=0.04284  sm_val_loss=0.02046  time=1.11s
# Epoch 3  loss=0.02005  val_loss=0.01924  sm_loss=0.02004  sm_val_loss=0.01921  time=1.12s
# Epoch 4  loss=0.01856  val_loss=0.01848  sm_loss=0.01860  sm_val_loss=0.01852  time=1.09s
# Epoch 5  loss=0.01785  val_loss=0.01851  sm_loss=0.01796  sm_val_loss=0.01850  time=1.11s
# Epoch 6  loss=0.01751  val_loss=0.01818  sm_loss=0.01762  sm_val_loss=0.01822  time=1.11s
# Epoch 7  loss=0.01716  val_loss=0.01801  sm_loss=0.01731  sm_val_loss=0.01804  time=1.12s
# Epoch 8  loss=0.01692  val_loss=0.01799  sm_loss=0.01709  sm_val_loss=0.01798  time=1.45s
# Epoch 10  loss=0.01642  val_loss=0.01788  sm_loss=0.01664  sm_val_loss=0.01786  time=1.09s
# Epoch 12  loss=0.01608  val_loss=0.01791  sm_loss=0.01631  sm_val_loss=0.01781  time=1.11s
# Epoch 15  loss=0.01542  val_loss=0.01786  sm_loss=0.01571  sm_val_loss=0.01777  time=1.07s
# Fold 4 log loss: 0.01786928750522297
# Fold 5
# Epoch 1  loss=0.61392  val_loss=0.23908  sm_loss=0.61386  sm_val_loss=0.23906  time=1.08s
# Epoch 2  loss=0.04254  val_loss=0.02113  sm_loss=0.04248  sm_val_loss=0.02114  time=1.12s
# Epoch 3  loss=0.01994  val_loss=0.01870  sm_loss=0.01995  sm_val_loss=0.01873  time=1.11s
# Epoch 4  loss=0.01833  val_loss=0.01813  sm_loss=0.01839  sm_val_loss=0.01816  time=1.14s
# Epoch 5  loss=0.01778  val_loss=0.01766  sm_loss=0.01787  sm_val_loss=0.01772  time=1.08s
# Epoch 6  loss=0.01747  val_loss=0.01759  sm_loss=0.01757  sm_val_loss=0.01761  time=1.54s
# Epoch 7  loss=0.01709  val_loss=0.01758  sm_loss=0.01726  sm_val_loss=0.01760  time=1.17s
# Epoch 10  loss=0.01640  val_loss=0.01739  sm_loss=0.01663  sm_val_loss=0.01733  time=1.15s
# Epoch 11  loss=0.01620  val_loss=0.01735  sm_loss=0.01645  sm_val_loss=0.01727  time=1.13s
# Epoch 12  loss=0.01612  val_loss=0.01725  sm_loss=0.01636  sm_val_loss=0.01723  time=1.12s
# Fold 5 log loss: 0.017377562801704063
# Fold 6
# Epoch 1  loss=0.61149  val_loss=0.33667  sm_loss=0.61145  sm_val_loss=0.33614  time=1.21s
# Epoch 2  loss=0.04212  val_loss=0.02128  sm_loss=0.04199  sm_val_loss=0.02127  time=1.13s
# Epoch 3  loss=0.01994  val_loss=0.01875  sm_loss=0.01990  sm_val_loss=0.01879  time=1.14s
# Epoch 4  loss=0.01842  val_loss=0.01853  sm_loss=0.01846  sm_val_loss=0.01860  time=1.12s
# Epoch 6  loss=0.01752  val_loss=0.01848  sm_loss=0.01762  sm_val_loss=0.01857  time=1.10s
# Epoch 7  loss=0.01737  val_loss=0.01776  sm_loss=0.01749  sm_val_loss=0.01782  time=1.14s
# Epoch 10  loss=0.01695  val_loss=0.01754  sm_loss=0.01712  sm_val_loss=0.01763  time=1.80s
# Epoch 13  loss=0.01631  val_loss=0.01742  sm_loss=0.01654  sm_val_loss=0.01751  time=1.10s
# Epoch 15  loss=0.01589  val_loss=0.01742  sm_loss=0.01614  sm_val_loss=0.01749  time=1.08s
# Epoch 16  loss=0.01564  val_loss=0.01738  sm_loss=0.01591  sm_val_loss=0.01745  time=1.09s
# Epoch 17  loss=0.01540  val_loss=0.01737  sm_loss=0.01567  sm_val_loss=0.01742  time=1.11s
# Epoch 19  loss=0.01486  val_loss=0.01736  sm_loss=0.01517  sm_val_loss=0.01739  time=1.41s
# Fold 6 log loss: 0.017428633572008183
# Fold 7
# Epoch 1  loss=0.61106  val_loss=0.14553  sm_loss=0.61100  sm_val_loss=0.14552  time=1.14s
# Epoch 2  loss=0.04229  val_loss=0.02829  sm_loss=0.04218  sm_val_loss=0.02825  time=1.77s
# Epoch 3  loss=0.01977  val_loss=0.01819  sm_loss=0.01976  sm_val_loss=0.01823  time=1.25s
# Epoch 4  loss=0.01819  val_loss=0.01787  sm_loss=0.01824  sm_val_loss=0.01791  time=1.39s
# Epoch 5  loss=0.01763  val_loss=0.01751  sm_loss=0.01772  sm_val_loss=0.01760  time=1.11s
# Epoch 7  loss=0.01708  val_loss=0.01737  sm_loss=0.01723  sm_val_loss=0.01747  time=1.21s
# Epoch 9  loss=0.01673  val_loss=0.01731  sm_loss=0.01691  sm_val_loss=0.01735  time=1.31s
# Epoch 10  loss=0.01653  val_loss=0.01715  sm_loss=0.01674  sm_val_loss=0.01723  time=1.69s
# Epoch 11  loss=0.01640  val_loss=0.01711  sm_loss=0.01662  sm_val_loss=0.01718  time=1.22s
# Epoch 16  loss=0.01529  val_loss=0.01713  sm_loss=0.01559  sm_val_loss=0.01713  time=1.11s
# Epoch 17  loss=0.01502  val_loss=0.01702  sm_loss=0.01533  sm_val_loss=0.01703  time=1.10s
# Epoch 18  loss=0.01469  val_loss=0.01705  sm_loss=0.01501  sm_val_loss=0.01701  time=1.23s
# Fold 7 log loss: 0.017040449220305943
# Seed 1
# Fold 1 log loss: 0.017331621861762927
# Fold 2 log loss: 0.017087234890599073
# Fold 3 log loss: 0.01748193771672767
# Fold 4 log loss: 0.01786928750522297
# Fold 5 log loss: 0.017377562801704063
# Fold 6 log loss: 0.017428633572008183
# Fold 7 log loss: 0.017040449220305943
# Std of log loss: 0.0002550192738306911
# Total log loss: 0.017373847202451966
# Fold 1
# Epoch 1  loss=0.50726  val_loss=0.02503  sm_loss=0.50723  sm_val_loss=0.02470  time=1.20s
# Epoch 2  loss=0.01264  val_loss=0.01083  sm_loss=0.01260  sm_val_loss=0.01085  time=1.18s
# Epoch 3  loss=0.00975  val_loss=0.01004  sm_loss=0.00982  sm_val_loss=0.01014  time=1.16s
# Epoch 4  loss=0.00961  val_loss=0.00994  sm_loss=0.00970  sm_val_loss=0.01003  time=1.14s
# Epoch 5  loss=0.00920  val_loss=0.00992  sm_loss=0.00941  sm_val_loss=0.01002  time=1.14s
# Epoch 6  loss=0.00919  val_loss=0.00988  sm_loss=0.00940  sm_val_loss=0.00996  time=1.15s
# Epoch 12  loss=0.00922  val_loss=0.00980  sm_loss=0.00942  sm_val_loss=0.00990  time=1.12s
# Epoch 15  loss=0.00916  val_loss=0.00979  sm_loss=0.00936  sm_val_loss=0.00989  time=1.12s
# Epoch 18  loss=0.00902  val_loss=0.00963  sm_loss=0.00923  sm_val_loss=0.00974  time=1.30s
# Epoch 20  loss=0.00884  val_loss=0.00956  sm_loss=0.00906  sm_val_loss=0.00967  time=1.14s
# Epoch 21  loss=0.00875  val_loss=0.00953  sm_loss=0.00898  sm_val_loss=0.00964  time=1.12s
# Epoch 22  loss=0.00864  val_loss=0.00946  sm_loss=0.00887  sm_val_loss=0.00958  time=1.10s
# Epoch 23  loss=0.00853  val_loss=0.00943  sm_loss=0.00877  sm_val_loss=0.00955  time=1.55s
# Epoch 24  loss=0.00844  val_loss=0.00940  sm_loss=0.00869  sm_val_loss=0.00952  time=1.31s
# Epoch 25  loss=0.00839  val_loss=0.00939  sm_loss=0.00864  sm_val_loss=0.00951  time=1.19s
# Fold 2
# Epoch 1  loss=0.50925  val_loss=0.02200  sm_loss=0.50921  sm_val_loss=0.02198  time=1.50s
# Epoch 2  loss=0.01310  val_loss=0.01044  sm_loss=0.01302  sm_val_loss=0.01047  time=1.44s
# Epoch 3  loss=0.00985  val_loss=0.00973  sm_loss=0.00991  sm_val_loss=0.00981  time=1.22s
# Epoch 4  loss=0.00940  val_loss=0.00957  sm_loss=0.00956  sm_val_loss=0.00968  time=1.17s
# Epoch 5  loss=0.00925  val_loss=0.00958  sm_loss=0.00944  sm_val_loss=0.00967  time=1.18s
# Epoch 7  loss=0.00935  val_loss=0.00948  sm_loss=0.00956  sm_val_loss=0.00956  time=1.12s
# Epoch 13  loss=0.00927  val_loss=0.00937  sm_loss=0.00947  sm_val_loss=0.00946  time=1.10s
# Epoch 15  loss=0.00922  val_loss=0.00936  sm_loss=0.00943  sm_val_loss=0.00944  time=1.10s
# Epoch 17  loss=0.00911  val_loss=0.00933  sm_loss=0.00932  sm_val_loss=0.00941  time=1.13s
# Epoch 18  loss=0.00908  val_loss=0.00926  sm_loss=0.00929  sm_val_loss=0.00935  time=1.13s
# Epoch 20  loss=0.00890  val_loss=0.00915  sm_loss=0.00912  sm_val_loss=0.00924  time=1.15s
# Epoch 21  loss=0.00879  val_loss=0.00912  sm_loss=0.00902  sm_val_loss=0.00921  time=1.13s
# Epoch 22  loss=0.00868  val_loss=0.00909  sm_loss=0.00892  sm_val_loss=0.00918  time=1.12s
# Epoch 23  loss=0.00855  val_loss=0.00902  sm_loss=0.00880  sm_val_loss=0.00913  time=1.23s
# Epoch 24  loss=0.00845  val_loss=0.00901  sm_loss=0.00871  sm_val_loss=0.00912  time=1.15s
# Fold 3
# Epoch 1  loss=0.50698  val_loss=0.02455  sm_loss=0.50695  sm_val_loss=0.02437  time=1.12s
# Epoch 2  loss=0.01317  val_loss=0.01026  sm_loss=0.01310  sm_val_loss=0.01028  time=1.12s
# Epoch 3  loss=0.00998  val_loss=0.00952  sm_loss=0.01003  sm_val_loss=0.00962  time=1.37s
# Epoch 4  loss=0.00936  val_loss=0.00937  sm_loss=0.00956  sm_val_loss=0.00947  time=1.12s
# Epoch 5  loss=0.00942  val_loss=0.00932  sm_loss=0.00961  sm_val_loss=0.00941  time=1.16s
# Epoch 8  loss=0.00937  val_loss=0.00927  sm_loss=0.00957  sm_val_loss=0.00937  time=1.12s
# Epoch 10  loss=0.00937  val_loss=0.00923  sm_loss=0.00958  sm_val_loss=0.00932  time=1.15s
# Epoch 12  loss=0.00934  val_loss=0.00921  sm_loss=0.00954  sm_val_loss=0.00932  time=1.37s
# Epoch 15  loss=0.00924  val_loss=0.00921  sm_loss=0.00944  sm_val_loss=0.00930  time=1.18s
# Epoch 16  loss=0.00923  val_loss=0.00923  sm_loss=0.00943  sm_val_loss=0.00929  time=1.12s
# Epoch 18  loss=0.00909  val_loss=0.00904  sm_loss=0.00931  sm_val_loss=0.00914  time=1.15s
# Epoch 20  loss=0.00892  val_loss=0.00899  sm_loss=0.00915  sm_val_loss=0.00908  time=1.15s
# Epoch 21  loss=0.00884  val_loss=0.00894  sm_loss=0.00907  sm_val_loss=0.00904  time=1.99s
# Epoch 22  loss=0.00872  val_loss=0.00890  sm_loss=0.00896  sm_val_loss=0.00901  time=1.35s
# Epoch 23  loss=0.00861  val_loss=0.00884  sm_loss=0.00885  sm_val_loss=0.00895  time=1.16s
# Epoch 24  loss=0.00850  val_loss=0.00882  sm_loss=0.00875  sm_val_loss=0.00894  time=1.46s
# Fold 4
# Epoch 1  loss=0.50566  val_loss=0.02623  sm_loss=0.50561  sm_val_loss=0.02614  time=1.15s
# Epoch 2  loss=0.01282  val_loss=0.01139  sm_loss=0.01278  sm_val_loss=0.01099  time=1.16s
# Epoch 3  loss=0.01026  val_loss=0.01038  sm_loss=0.01031  sm_val_loss=0.01020  time=1.45s
# Epoch 4  loss=0.00935  val_loss=0.00972  sm_loss=0.00955  sm_val_loss=0.00979  time=1.19s
# Epoch 8  loss=0.00928  val_loss=0.00969  sm_loss=0.00948  sm_val_loss=0.00976  time=1.52s
# Epoch 13  loss=0.00924  val_loss=0.00959  sm_loss=0.00944  sm_val_loss=0.00969  time=1.10s
# Epoch 14  loss=0.00923  val_loss=0.00952  sm_loss=0.00943  sm_val_loss=0.00962  time=1.13s
# Epoch 15  loss=0.00920  val_loss=0.00953  sm_loss=0.00940  sm_val_loss=0.00962  time=1.14s
# Epoch 16  loss=0.00913  val_loss=0.00950  sm_loss=0.00933  sm_val_loss=0.00958  time=1.15s
# Epoch 18  loss=0.00908  val_loss=0.00946  sm_loss=0.00930  sm_val_loss=0.00954  time=1.12s
# Epoch 19  loss=0.00898  val_loss=0.00938  sm_loss=0.00920  sm_val_loss=0.00948  time=1.13s
# Epoch 20  loss=0.00887  val_loss=0.00932  sm_loss=0.00909  sm_val_loss=0.00941  time=1.14s
# Epoch 21  loss=0.00878  val_loss=0.00921  sm_loss=0.00901  sm_val_loss=0.00932  time=1.50s
# Epoch 22  loss=0.00867  val_loss=0.00916  sm_loss=0.00890  sm_val_loss=0.00927  time=1.12s
# Epoch 23  loss=0.00856  val_loss=0.00911  sm_loss=0.00880  sm_val_loss=0.00924  time=1.15s
# Epoch 24  loss=0.00846  val_loss=0.00909  sm_loss=0.00871  sm_val_loss=0.00922  time=1.12s
# Fold 5
# Epoch 1  loss=0.50802  val_loss=0.02675  sm_loss=0.50799  sm_val_loss=0.02670  time=1.12s
# Epoch 2  loss=0.01346  val_loss=0.01055  sm_loss=0.01334  sm_val_loss=0.01051  time=1.11s
# Epoch 3  loss=0.00999  val_loss=0.00988  sm_loss=0.01004  sm_val_loss=0.00998  time=1.12s
# Epoch 4  loss=0.00931  val_loss=0.00979  sm_loss=0.00951  sm_val_loss=0.00988  time=1.17s
# Epoch 5  loss=0.00927  val_loss=0.00965  sm_loss=0.00946  sm_val_loss=0.00975  time=1.31s
# Epoch 12  loss=0.00926  val_loss=0.00958  sm_loss=0.00946  sm_val_loss=0.00969  time=1.12s
# Epoch 16  loss=0.00915  val_loss=0.00953  sm_loss=0.00936  sm_val_loss=0.00962  time=1.13s
# Epoch 17  loss=0.00910  val_loss=0.00947  sm_loss=0.00931  sm_val_loss=0.00957  time=1.34s
# Epoch 19  loss=0.00898  val_loss=0.00936  sm_loss=0.00919  sm_val_loss=0.00947  time=1.12s
# Epoch 21  loss=0.00879  val_loss=0.00932  sm_loss=0.00902  sm_val_loss=0.00942  time=1.18s
# Epoch 22  loss=0.00868  val_loss=0.00926  sm_loss=0.00892  sm_val_loss=0.00937  time=1.82s
# Epoch 23  loss=0.00855  val_loss=0.00923  sm_loss=0.00879  sm_val_loss=0.00934  time=1.32s
# Epoch 24  loss=0.00847  val_loss=0.00920  sm_loss=0.00872  sm_val_loss=0.00932  time=1.19s
# Epoch 25  loss=0.00842  val_loss=0.00919  sm_loss=0.00867  sm_val_loss=0.00930  time=1.21s
# Fold 6
# Epoch 1  loss=0.50910  val_loss=0.02488  sm_loss=0.50905  sm_val_loss=0.02441  time=1.15s
# Epoch 2  loss=0.01312  val_loss=0.01197  sm_loss=0.01300  sm_val_loss=0.01140  time=1.15s
# Epoch 3  loss=0.01102  val_loss=0.01525  sm_loss=0.01094  sm_val_loss=0.01135  time=1.20s
# Epoch 4  loss=0.01009  val_loss=0.01015  sm_loss=0.01016  sm_val_loss=0.00992  time=1.15s
# Epoch 5  loss=0.00958  val_loss=0.01029  sm_loss=0.00977  sm_val_loss=0.00988  time=1.46s
# Epoch 6  loss=0.00950  val_loss=0.00931  sm_loss=0.00971  sm_val_loss=0.00945  time=1.16s
# Epoch 8  loss=0.00946  val_loss=0.00930  sm_loss=0.00966  sm_val_loss=0.00943  time=1.36s
# Epoch 9  loss=0.00938  val_loss=0.00916  sm_loss=0.00958  sm_val_loss=0.00929  time=1.21s
# Epoch 12  loss=0.00935  val_loss=0.00909  sm_loss=0.00955  sm_val_loss=0.00922  time=1.13s
# Epoch 13  loss=0.00936  val_loss=0.00907  sm_loss=0.00955  sm_val_loss=0.00919  time=1.15s
# Epoch 16  loss=0.00926  val_loss=0.00901  sm_loss=0.00947  sm_val_loss=0.00914  time=1.13s
# Epoch 18  loss=0.00914  val_loss=0.00898  sm_loss=0.00934  sm_val_loss=0.00910  time=1.12s
# Epoch 19  loss=0.00905  val_loss=0.00888  sm_loss=0.00926  sm_val_loss=0.00901  time=1.14s
# Epoch 20  loss=0.00904  val_loss=0.00884  sm_loss=0.00926  sm_val_loss=0.00896  time=1.13s
# Epoch 21  loss=0.00888  val_loss=0.00876  sm_loss=0.00910  sm_val_loss=0.00890  time=1.22s
# Epoch 22  loss=0.00875  val_loss=0.00874  sm_loss=0.00898  sm_val_loss=0.00888  time=1.14s
# Epoch 23  loss=0.00866  val_loss=0.00868  sm_loss=0.00890  sm_val_loss=0.00883  time=1.41s
# Epoch 24  loss=0.00857  val_loss=0.00866  sm_loss=0.00882  sm_val_loss=0.00881  time=1.11s
# Epoch 25  loss=0.00854  val_loss=0.00864  sm_loss=0.00879  sm_val_loss=0.00879  time=1.14s
# Fold 7
# Epoch 1  loss=0.50830  val_loss=0.02769  sm_loss=0.50827  sm_val_loss=0.02759  time=1.13s
# Epoch 2  loss=0.01346  val_loss=0.00988  sm_loss=0.01342  sm_val_loss=0.00991  time=1.13s
# Epoch 3  loss=0.00993  val_loss=0.00921  sm_loss=0.00997  sm_val_loss=0.00932  time=1.16s
# Epoch 4  loss=0.00947  val_loss=0.00901  sm_loss=0.00963  sm_val_loss=0.00916  time=1.12s
# Epoch 6  loss=0.00941  val_loss=0.00897  sm_loss=0.00961  sm_val_loss=0.00913  time=1.39s
# Epoch 7  loss=0.00942  val_loss=0.00893  sm_loss=0.00959  sm_val_loss=0.00910  time=1.17s
# Epoch 8  loss=0.00942  val_loss=0.00888  sm_loss=0.00961  sm_val_loss=0.00905  time=1.16s
# Epoch 15  loss=0.00932  val_loss=0.00877  sm_loss=0.00951  sm_val_loss=0.00893  time=1.39s
# Epoch 18  loss=0.00916  val_loss=0.00873  sm_loss=0.00936  sm_val_loss=0.00889  time=1.22s
# Epoch 19  loss=0.00907  val_loss=0.00870  sm_loss=0.00928  sm_val_loss=0.00886  time=1.19s
# Epoch 20  loss=0.00897  val_loss=0.00862  sm_loss=0.00918  sm_val_loss=0.00879  time=1.31s
# Epoch 21  loss=0.00886  val_loss=0.00857  sm_loss=0.00908  sm_val_loss=0.00874  time=1.13s
# Epoch 22  loss=0.00875  val_loss=0.00850  sm_loss=0.00898  sm_val_loss=0.00867  time=1.13s
# Epoch 23  loss=0.00862  val_loss=0.00847  sm_loss=0.00886  sm_val_loss=0.00865  time=1.40s
# Epoch 24  loss=0.00853  val_loss=0.00844  sm_loss=0.00877  sm_val_loss=0.00862  time=1.18s
# Epoch 25  loss=0.00846  val_loss=0.00842  sm_loss=0.00871  sm_val_loss=0.00861  time=1.13s
# Fold 1
# Epoch 1  loss=0.61226  val_loss=0.38224  sm_loss=0.61221  sm_val_loss=0.38207  time=1.09s
# Epoch 2  loss=0.04238  val_loss=0.01990  sm_loss=0.04227  sm_val_loss=0.01990  time=1.13s
# Epoch 3  loss=0.01952  val_loss=0.01840  sm_loss=0.01953  sm_val_loss=0.01842  time=1.28s
# Epoch 4  loss=0.01822  val_loss=0.01790  sm_loss=0.01826  sm_val_loss=0.01794  time=1.12s
# Epoch 5  loss=0.01786  val_loss=0.01784  sm_loss=0.01792  sm_val_loss=0.01787  time=1.10s
# Epoch 6  loss=0.01748  val_loss=0.01773  sm_loss=0.01760  sm_val_loss=0.01771  time=1.19s
# Epoch 7  loss=0.01722  val_loss=0.01761  sm_loss=0.01735  sm_val_loss=0.01758  time=1.13s
# Epoch 9  loss=0.01681  val_loss=0.01745  sm_loss=0.01699  sm_val_loss=0.01742  time=1.13s
# Epoch 11  loss=0.01642  val_loss=0.01748  sm_loss=0.01664  sm_val_loss=0.01742  time=1.13s
# Epoch 13  loss=0.01606  val_loss=0.01749  sm_loss=0.01631  sm_val_loss=0.01737  time=1.13s
# Epoch 15  loss=0.01562  val_loss=0.01742  sm_loss=0.01589  sm_val_loss=0.01726  time=1.35s
# Epoch 18  loss=0.01489  val_loss=0.01738  sm_loss=0.01521  sm_val_loss=0.01719  time=1.14s
# Epoch 19  loss=0.01460  val_loss=0.01736  sm_loss=0.01493  sm_val_loss=0.01719  time=1.14s
# Fold 1 log loss: 0.01728781159752463
# Fold 2
# Epoch 1  loss=0.61090  val_loss=0.21362  sm_loss=0.61074  sm_val_loss=0.21361  time=1.10s
# Epoch 2  loss=0.04151  val_loss=0.01992  sm_loss=0.04147  sm_val_loss=0.01991  time=1.14s
# Epoch 3  loss=0.01983  val_loss=0.01965  sm_loss=0.01983  sm_val_loss=0.01969  time=1.11s
# Epoch 4  loss=0.01829  val_loss=0.01759  sm_loss=0.01833  sm_val_loss=0.01765  time=1.13s
# Epoch 5  loss=0.01774  val_loss=0.01729  sm_loss=0.01782  sm_val_loss=0.01732  time=1.15s
# Epoch 6  loss=0.01758  val_loss=0.01716  sm_loss=0.01764  sm_val_loss=0.01722  time=1.20s
# Epoch 7  loss=0.01709  val_loss=0.01706  sm_loss=0.01725  sm_val_loss=0.01709  time=1.41s
# Epoch 8  loss=0.01704  val_loss=0.01708  sm_loss=0.01722  sm_val_loss=0.01709  time=1.51s
# Epoch 11  loss=0.01630  val_loss=0.01703  sm_loss=0.01654  sm_val_loss=0.01702  time=1.51s
# Epoch 13  loss=0.01594  val_loss=0.01696  sm_loss=0.01620  sm_val_loss=0.01694  time=1.13s
# Epoch 20  loss=0.01404  val_loss=0.01713  sm_loss=0.01440  sm_val_loss=0.01693  time=1.09s
# Fold 2 log loss: 0.017059822174363755
# Fold 3
# Epoch 1  loss=0.61340  val_loss=0.26160  sm_loss=0.61334  sm_val_loss=0.26100  time=1.14s
# Epoch 2  loss=0.04182  val_loss=0.02053  sm_loss=0.04168  sm_val_loss=0.02053  time=1.16s
# Epoch 3  loss=0.01926  val_loss=0.01844  sm_loss=0.01927  sm_val_loss=0.01848  time=1.13s
# Epoch 4  loss=0.01813  val_loss=0.01794  sm_loss=0.01817  sm_val_loss=0.01802  time=1.12s
# Epoch 5  loss=0.01750  val_loss=0.01788  sm_loss=0.01759  sm_val_loss=0.01792  time=1.08s
# Epoch 8  loss=0.01661  val_loss=0.01780  sm_loss=0.01680  sm_val_loss=0.01779  time=1.32s
# Epoch 9  loss=0.01644  val_loss=0.01768  sm_loss=0.01664  sm_val_loss=0.01764  time=1.30s
# Epoch 10  loss=0.01617  val_loss=0.01769  sm_loss=0.01640  sm_val_loss=0.01763  time=1.09s
# Epoch 11  loss=0.01602  val_loss=0.01767  sm_loss=0.01626  sm_val_loss=0.01762  time=1.11s
# Epoch 13  loss=0.01559  val_loss=0.01759  sm_loss=0.01587  sm_val_loss=0.01750  time=1.09s
# Fold 3 log loss: 0.017458916216024235
# Fold 4
# ...
# Epoch 24  loss=0.00845  val_loss=0.00941  sm_loss=0.00870  sm_val_loss=0.00953  time=1.10s
# Epoch 25  loss=0.00839  val_loss=0.00940  sm_loss=0.00865  sm_val_loss=0.00952  time=1.31s
# Fold 2
# Epoch 1  loss=0.50565  val_loss=0.02273  sm_loss=0.50564  sm_val_loss=0.02272  time=1.11s
# Epoch 2  loss=0.01282  val_loss=0.01048  sm_loss=0.01276  sm_val_loss=0.01051  time=1.11s
# Epoch 3  loss=0.00984  val_loss=0.00966  sm_loss=0.00990  sm_val_loss=0.00975  time=1.07s
# Epoch 5  loss=0.00929  val_loss=0.00945  sm_loss=0.00947  sm_val_loss=0.00955  time=1.32s
# Epoch 6  loss=0.00924  val_loss=0.00943  sm_loss=0.00944  sm_val_loss=0.00950  time=1.09s
# Epoch 13  loss=0.00924  val_loss=0.00941  sm_loss=0.00944  sm_val_loss=0.00948  time=1.12s
# Epoch 17  loss=0.00907  val_loss=0.00930  sm_loss=0.00928  sm_val_loss=0.00938  time=1.08s
# Epoch 19  loss=0.00893  val_loss=0.00920  sm_loss=0.00915  sm_val_loss=0.00928  time=1.08s
# Epoch 21  loss=0.00873  val_loss=0.00913  sm_loss=0.00896  sm_val_loss=0.00922  time=1.09s
# Epoch 22  loss=0.00860  val_loss=0.00906  sm_loss=0.00884  sm_val_loss=0.00916  time=1.09s
# Epoch 23  loss=0.00849  val_loss=0.00904  sm_loss=0.00874  sm_val_loss=0.00915  time=1.33s
# Epoch 24  loss=0.00839  val_loss=0.00902  sm_loss=0.00865  sm_val_loss=0.00912  time=1.19s
# Epoch 25  loss=0.00833  val_loss=0.00901  sm_loss=0.00860  sm_val_loss=0.00911  time=1.38s
# Fold 3
# Epoch 1  loss=0.50888  val_loss=0.02071  sm_loss=0.50885  sm_val_loss=0.02067  time=1.17s
# Epoch 2  loss=0.01324  val_loss=0.01003  sm_loss=0.01315  sm_val_loss=0.01004  time=1.15s
# Epoch 3  loss=0.01005  val_loss=0.00943  sm_loss=0.01006  sm_val_loss=0.00953  time=1.09s
# Epoch 4  loss=0.00935  val_loss=0.00931  sm_loss=0.00955  sm_val_loss=0.00942  time=1.07s
# Epoch 6  loss=0.00929  val_loss=0.00923  sm_loss=0.00950  sm_val_loss=0.00934  time=1.08s
# Epoch 14  loss=0.00930  val_loss=0.00923  sm_loss=0.00951  sm_val_loss=0.00932  time=1.33s
# Epoch 16  loss=0.00924  val_loss=0.00920  sm_loss=0.00945  sm_val_loss=0.00930  time=1.20s
# Epoch 18  loss=0.00912  val_loss=0.00908  sm_loss=0.00933  sm_val_loss=0.00918  time=1.10s
# Epoch 19  loss=0.00903  val_loss=0.00900  sm_loss=0.00925  sm_val_loss=0.00910  time=1.10s
# Epoch 21  loss=0.00884  val_loss=0.00892  sm_loss=0.00907  sm_val_loss=0.00902  time=1.12s
# Epoch 22  loss=0.00872  val_loss=0.00887  sm_loss=0.00896  sm_val_loss=0.00898  time=1.10s
# Epoch 23  loss=0.00861  val_loss=0.00884  sm_loss=0.00886  sm_val_loss=0.00895  time=1.11s
# Epoch 24  loss=0.00851  val_loss=0.00883  sm_loss=0.00876  sm_val_loss=0.00894  time=1.13s
# Epoch 25  loss=0.00845  val_loss=0.00882  sm_loss=0.00871  sm_val_loss=0.00893  time=1.10s
# Fold 4
# Epoch 1  loss=0.50691  val_loss=0.02449  sm_loss=0.50687  sm_val_loss=0.02442  time=1.28s
# Epoch 2  loss=0.01298  val_loss=0.01052  sm_loss=0.01294  sm_val_loss=0.01042  time=1.09s
# Epoch 3  loss=0.00983  val_loss=0.00984  sm_loss=0.00989  sm_val_loss=0.00989  time=1.12s
# Epoch 5  loss=0.00930  val_loss=0.00968  sm_loss=0.00948  sm_val_loss=0.00976  time=1.09s
# Epoch 8  loss=0.00925  val_loss=0.00962  sm_loss=0.00946  sm_val_loss=0.00973  time=1.41s
# Epoch 10  loss=0.00923  val_loss=0.00964  sm_loss=0.00944  sm_val_loss=0.00973  time=1.23s
# Epoch 12  loss=0.00928  val_loss=0.00957  sm_loss=0.00948  sm_val_loss=0.00966  time=1.14s
# Epoch 13  loss=0.00925  val_loss=0.00956  sm_loss=0.00945  sm_val_loss=0.00966  time=1.22s
# Epoch 15  loss=0.00919  val_loss=0.00949  sm_loss=0.00939  sm_val_loss=0.00960  time=1.20s
# Epoch 17  loss=0.00913  val_loss=0.00949  sm_loss=0.00934  sm_val_loss=0.00958  time=1.14s
# Epoch 18  loss=0.00906  val_loss=0.00938  sm_loss=0.00927  sm_val_loss=0.00948  time=1.36s
# Epoch 19  loss=0.00896  val_loss=0.00933  sm_loss=0.00917  sm_val_loss=0.00943  time=1.05s
# Epoch 20  loss=0.00885  val_loss=0.00932  sm_loss=0.00907  sm_val_loss=0.00941  time=1.15s
# Epoch 21  loss=0.00879  val_loss=0.00925  sm_loss=0.00902  sm_val_loss=0.00936  time=1.10s
# Epoch 22  loss=0.00867  val_loss=0.00915  sm_loss=0.00890  sm_val_loss=0.00927  time=1.10s
# Epoch 23  loss=0.00854  val_loss=0.00913  sm_loss=0.00879  sm_val_loss=0.00925  time=1.08s
# Epoch 24  loss=0.00845  val_loss=0.00911  sm_loss=0.00870  sm_val_loss=0.00923  time=1.07s
# Epoch 25  loss=0.00840  val_loss=0.00910  sm_loss=0.00865  sm_val_loss=0.00922  time=1.12s
# Fold 5
# Epoch 1  loss=0.50733  val_loss=0.02315  sm_loss=0.50731  sm_val_loss=0.02315  time=1.48s
# Epoch 2  loss=0.01290  val_loss=0.01086  sm_loss=0.01282  sm_val_loss=0.01082  time=1.09s
# Epoch 3  loss=0.00986  val_loss=0.00981  sm_loss=0.00990  sm_val_loss=0.00991  time=1.08s
# Epoch 4  loss=0.00929  val_loss=0.00972  sm_loss=0.00948  sm_val_loss=0.00981  time=1.10s
# Epoch 5  loss=0.00924  val_loss=0.00960  sm_loss=0.00943  sm_val_loss=0.00973  time=1.18s
# Epoch 10  loss=0.00929  val_loss=0.00959  sm_loss=0.00948  sm_val_loss=0.00968  time=1.13s
# Epoch 11  loss=0.00927  val_loss=0.00958  sm_loss=0.00947  sm_val_loss=0.00966  time=1.26s
# Epoch 16  loss=0.00912  val_loss=0.00949  sm_loss=0.00932  sm_val_loss=0.00958  time=1.42s
# Epoch 18  loss=0.00902  val_loss=0.00945  sm_loss=0.00924  sm_val_loss=0.00955  time=1.09s
# Epoch 19  loss=0.00897  val_loss=0.00943  sm_loss=0.00918  sm_val_loss=0.00952  time=1.12s
# Epoch 20  loss=0.00886  val_loss=0.00934  sm_loss=0.00908  sm_val_loss=0.00944  time=1.37s
# Epoch 21  loss=0.00877  val_loss=0.00931  sm_loss=0.00900  sm_val_loss=0.00941  time=1.13s
# Epoch 22  loss=0.00867  val_loss=0.00922  sm_loss=0.00890  sm_val_loss=0.00933  time=1.10s
# Epoch 23  loss=0.00855  val_loss=0.00920  sm_loss=0.00879  sm_val_loss=0.00931  time=1.12s
# Epoch 24  loss=0.00845  val_loss=0.00917  sm_loss=0.00871  sm_val_loss=0.00928  time=1.12s
# Epoch 25  loss=0.00840  val_loss=0.00916  sm_loss=0.00866  sm_val_loss=0.00927  time=1.12s
# Fold 6
# Epoch 1  loss=0.50612  val_loss=0.02336  sm_loss=0.50610  sm_val_loss=0.02331  time=1.10s
# Epoch 2  loss=0.01309  val_loss=0.01099  sm_loss=0.01302  sm_val_loss=0.01064  time=1.37s
# Epoch 3  loss=0.01008  val_loss=0.00931  sm_loss=0.01010  sm_val_loss=0.00943  time=1.31s
# Epoch 10  loss=0.00938  val_loss=0.00916  sm_loss=0.00957  sm_val_loss=0.00928  time=1.20s
# Epoch 11  loss=0.00939  val_loss=0.00911  sm_loss=0.00958  sm_val_loss=0.00923  time=1.17s
# Epoch 16  loss=0.00930  val_loss=0.00896  sm_loss=0.00949  sm_val_loss=0.00909  time=1.48s
# Epoch 19  loss=0.00906  val_loss=0.00886  sm_loss=0.00927  sm_val_loss=0.00900  time=1.09s
# Epoch 20  loss=0.00899  val_loss=0.00883  sm_loss=0.00921  sm_val_loss=0.00896  time=1.08s
# Epoch 21  loss=0.00888  val_loss=0.00879  sm_loss=0.00911  sm_val_loss=0.00892  time=1.34s
# Epoch 22  loss=0.00878  val_loss=0.00873  sm_loss=0.00901  sm_val_loss=0.00888  time=1.10s
# Epoch 23  loss=0.00866  val_loss=0.00870  sm_loss=0.00889  sm_val_loss=0.00885  time=1.09s
# Epoch 24  loss=0.00856  val_loss=0.00868  sm_loss=0.00881  sm_val_loss=0.00883  time=1.13s
# Epoch 25  loss=0.00852  val_loss=0.00867  sm_loss=0.00877  sm_val_loss=0.00882  time=1.17s
# Fold 7
# Epoch 1  loss=0.50751  val_loss=0.02398  sm_loss=0.50749  sm_val_loss=0.02391  time=1.14s
# Epoch 2  loss=0.01288  val_loss=0.00986  sm_loss=0.01283  sm_val_loss=0.00986  time=1.36s
# Epoch 3  loss=0.01033  val_loss=0.00914  sm_loss=0.01037  sm_val_loss=0.00929  time=1.12s
# Epoch 4  loss=0.00940  val_loss=0.00906  sm_loss=0.00961  sm_val_loss=0.00921  time=1.25s
# Epoch 5  loss=0.00928  val_loss=0.00898  sm_loss=0.00950  sm_val_loss=0.00913  time=1.16s
# Epoch 8  loss=0.00932  val_loss=0.00889  sm_loss=0.00953  sm_val_loss=0.00906  time=1.09s
# Epoch 14  loss=0.00931  val_loss=0.00887  sm_loss=0.00951  sm_val_loss=0.00903  time=1.39s
# Epoch 16  loss=0.00926  val_loss=0.00876  sm_loss=0.00945  sm_val_loss=0.00894  time=1.12s
# Epoch 18  loss=0.00914  val_loss=0.00876  sm_loss=0.00935  sm_val_loss=0.00894  time=1.45s
# Epoch 19  loss=0.00905  val_loss=0.00868  sm_loss=0.00926  sm_val_loss=0.00885  time=1.12s
# Epoch 20  loss=0.00895  val_loss=0.00861  sm_loss=0.00916  sm_val_loss=0.00877  time=1.12s
# Epoch 21  loss=0.00883  val_loss=0.00860  sm_loss=0.00905  sm_val_loss=0.00876  time=1.11s
# Epoch 22  loss=0.00872  val_loss=0.00849  sm_loss=0.00895  sm_val_loss=0.00867  time=1.24s
# Epoch 23  loss=0.00860  val_loss=0.00847  sm_loss=0.00884  sm_val_loss=0.00865  time=1.26s
# Epoch 24  loss=0.00850  val_loss=0.00845  sm_loss=0.00875  sm_val_loss=0.00863  time=1.10s
# Epoch 25  loss=0.00844  val_loss=0.00844  sm_loss=0.00869  sm_val_loss=0.00862  time=1.12s
# Fold 1
# Epoch 1  loss=0.61314  val_loss=0.27707  sm_loss=0.61308  sm_val_loss=0.27694  time=1.07s
# Epoch 2  loss=0.04195  val_loss=0.02034  sm_loss=0.04186  sm_val_loss=0.02033  time=1.86s
# Epoch 3  loss=0.01966  val_loss=0.01823  sm_loss=0.01964  sm_val_loss=0.01824  time=1.11s
# Epoch 4  loss=0.01826  val_loss=0.01781  sm_loss=0.01829  sm_val_loss=0.01784  time=1.35s
# Epoch 5  loss=0.01765  val_loss=0.01762  sm_loss=0.01775  sm_val_loss=0.01766  time=1.11s
# Epoch 6  loss=0.01736  val_loss=0.01754  sm_loss=0.01748  sm_val_loss=0.01755  time=1.33s
# Epoch 8  loss=0.01680  val_loss=0.01761  sm_loss=0.01697  sm_val_loss=0.01754  time=1.18s
# Epoch 9  loss=0.01670  val_loss=0.01740  sm_loss=0.01687  sm_val_loss=0.01732  time=1.09s
# Epoch 16  loss=0.01526  val_loss=0.01739  sm_loss=0.01556  sm_val_loss=0.01725  time=1.22s
# Fold 1 log loss: 0.01735161648966673
# Fold 2
# Epoch 1  loss=0.60897  val_loss=0.35346  sm_loss=0.60881  sm_val_loss=0.32096  time=1.09s
# Epoch 2  loss=0.04178  val_loss=0.01962  sm_loss=0.04170  sm_val_loss=0.01964  time=1.39s
# Epoch 3  loss=0.01942  val_loss=0.01783  sm_loss=0.01942  sm_val_loss=0.01787  time=1.07s
# Epoch 4  loss=0.01822  val_loss=0.01753  sm_loss=0.01825  sm_val_loss=0.01759  time=1.14s
# Epoch 5  loss=0.01754  val_loss=0.01716  sm_loss=0.01765  sm_val_loss=0.01722  time=1.06s
# Epoch 6  loss=0.01732  val_loss=0.01703  sm_loss=0.01744  sm_val_loss=0.01711  time=1.12s
# Epoch 7  loss=0.01712  val_loss=0.01699  sm_loss=0.01726  sm_val_loss=0.01703  time=1.26s
# Epoch 9  loss=0.01659  val_loss=0.01695  sm_loss=0.01678  sm_val_loss=0.01697  time=1.09s
# Fold 2 log loss: 0.0170935381600316
# Fold 3
# Epoch 1  loss=0.61174  val_loss=0.21829  sm_loss=0.61163  sm_val_loss=0.21818  time=1.24s
# Epoch 2  loss=0.04244  val_loss=0.02058  sm_loss=0.04237  sm_val_loss=0.02059  time=1.45s
# Epoch 3  loss=0.01954  val_loss=0.01841  sm_loss=0.01949  sm_val_loss=0.01845  time=1.09s
# Epoch 4  loss=0.01827  val_loss=0.01828  sm_loss=0.01829  sm_val_loss=0.01829  time=1.10s
# Epoch 5  loss=0.01773  val_loss=0.01794  sm_loss=0.01781  sm_val_loss=0.01797  time=1.13s
# Epoch 6  loss=0.01731  val_loss=0.01777  sm_loss=0.01745  sm_val_loss=0.01779  time=1.11s
# Epoch 9  loss=0.01668  val_loss=0.01775  sm_loss=0.01687  sm_val_loss=0.01774  time=1.20s
# Epoch 13  loss=0.01590  val_loss=0.01781  sm_loss=0.01616  sm_val_loss=0.01771  time=1.06s
# Epoch 14  loss=0.01569  val_loss=0.01778  sm_loss=0.01595  sm_val_loss=0.01766  time=1.13s
# Epoch 17  loss=0.01497  val_loss=0.01774  sm_loss=0.01529  sm_val_loss=0.01761  time=1.26s
# Fold 3 log loss: 0.017564416212057423
# Fold 4
# Epoch 1  loss=0.61243  val_loss=0.21395  sm_loss=0.61238  sm_val_loss=0.21360  time=1.23s
# Epoch 3  loss=0.02139  val_loss=0.01976  sm_loss=0.02133  sm_val_loss=0.01967  time=1.05s
# Epoch 4  loss=0.01908  val_loss=0.01906  sm_loss=0.01911  sm_val_loss=0.01899  time=1.08s
# Epoch 5  loss=0.01844  val_loss=0.01875  sm_loss=0.01850  sm_val_loss=0.01869  time=1.06s
# Epoch 6  loss=0.01793  val_loss=0.01909  sm_loss=0.01804  sm_val_loss=0.01860  time=1.07s
# Epoch 7  loss=0.01772  val_loss=0.01823  sm_loss=0.01785  sm_val_loss=0.01808  time=1.07s
# Epoch 8  loss=0.01734  val_loss=0.01804  sm_loss=0.01750  sm_val_loss=0.01802  time=1.09s
# Epoch 9  loss=0.01717  val_loss=0.01795  sm_loss=0.01734  sm_val_loss=0.01791  time=1.12s
# Epoch 10  loss=0.01693  val_loss=0.01791  sm_loss=0.01712  sm_val_loss=0.01789  time=1.31s
# Epoch 14  loss=0.01626  val_loss=0.01788  sm_loss=0.01650  sm_val_loss=0.01787  time=1.10s
# Epoch 15  loss=0.01598  val_loss=0.01785  sm_loss=0.01625  sm_val_loss=0.01780  time=1.09s
# Epoch 16  loss=0.01588  val_loss=0.01789  sm_loss=0.01615  sm_val_loss=0.01779  time=1.08s
# Epoch 17  loss=0.01555  val_loss=0.01785  sm_loss=0.01585  sm_val_loss=0.01777  time=1.07s
# Epoch 18  loss=0.01522  val_loss=0.01786  sm_loss=0.01552  sm_val_loss=0.01777  time=1.06s
# Fold 4 log loss: 0.01785398533980963
# Fold 5
# Epoch 1  loss=0.61131  val_loss=0.18898  sm_loss=0.61122  sm_val_loss=0.18865  time=1.48s
# Epoch 2  loss=0.04200  val_loss=0.02668  sm_loss=0.04192  sm_val_loss=0.02671  time=1.73s
# Epoch 3  loss=0.01981  val_loss=0.01834  sm_loss=0.01979  sm_val_loss=0.01839  time=1.07s
# Epoch 4  loss=0.01820  val_loss=0.01809  sm_loss=0.01825  sm_val_loss=0.01814  time=1.05s
# Epoch 5  loss=0.01774  val_loss=0.01772  sm_loss=0.01782  sm_val_loss=0.01777  time=1.09s
# Epoch 6  loss=0.01729  val_loss=0.01764  sm_loss=0.01741  sm_val_loss=0.01765  time=1.05s
# Epoch 7  loss=0.01698  val_loss=0.01759  sm_loss=0.01714  sm_val_loss=0.01760  time=1.08s
# Epoch 8  loss=0.01679  val_loss=0.01749  sm_loss=0.01699  sm_val_loss=0.01746  time=1.07s
# Epoch 9  loss=0.01662  val_loss=0.01744  sm_loss=0.01681  sm_val_loss=0.01739  time=1.08s
# Epoch 10  loss=0.01638  val_loss=0.01734  sm_loss=0.01659  sm_val_loss=0.01728  time=1.08s
# Epoch 12  loss=0.01596  val_loss=0.01732  sm_loss=0.01621  sm_val_loss=0.01725  time=1.05s
# Epoch 13  loss=0.01577  val_loss=0.01728  sm_loss=0.01604  sm_val_loss=0.01721  time=1.05s
# Epoch 14  loss=0.01555  val_loss=0.01723  sm_loss=0.01583  sm_val_loss=0.01712  time=1.06s
# Fold 5 log loss: 0.017335764948884586
# Fold 6
# Epoch 1  loss=0.61328  val_loss=0.29175  sm_loss=0.61309  sm_val_loss=0.28744  time=1.03s
# Epoch 2  loss=0.04251  val_loss=0.02010  sm_loss=0.04242  sm_val_loss=0.02010  time=1.04s
# Epoch 3  loss=0.01966  val_loss=0.01894  sm_loss=0.01966  sm_val_loss=0.01892  time=1.40s
# Epoch 4  loss=0.01834  val_loss=0.01820  sm_loss=0.01838  sm_val_loss=0.01827  time=1.24s
# Epoch 5  loss=0.01778  val_loss=0.01788  sm_loss=0.01787  sm_val_loss=0.01797  time=1.07s
# Epoch 7  loss=0.01717  val_loss=0.01769  sm_loss=0.01732  sm_val_loss=0.01778  time=1.07s
# Epoch 8  loss=0.01694  val_loss=0.01761  sm_loss=0.01711  sm_val_loss=0.01772  time=1.07s
# Epoch 9  loss=0.01669  val_loss=0.01760  sm_loss=0.01688  sm_val_loss=0.01770  time=1.06s
# Epoch 10  loss=0.01641  val_loss=0.01750  sm_loss=0.01662  sm_val_loss=0.01762  time=1.05s
# Epoch 11  loss=0.01632  val_loss=0.01746  sm_loss=0.01655  sm_val_loss=0.01756  time=1.10s
# Epoch 12  loss=0.01618  val_loss=0.01747  sm_loss=0.01641  sm_val_loss=0.01754  time=1.10s
# Epoch 14  loss=0.01576  val_loss=0.01734  sm_loss=0.01603  sm_val_loss=0.01741  time=1.05s
# Fold 6 log loss: 0.017426746684023563
# Fold 7
# Epoch 1  loss=0.61185  val_loss=0.23481  sm_loss=0.61180  sm_val_loss=0.23301  time=1.09s
# Epoch 2  loss=0.04167  val_loss=0.02067  sm_loss=0.04161  sm_val_loss=0.02059  time=1.08s
# Epoch 3  loss=0.01932  val_loss=0.01823  sm_loss=0.01933  sm_val_loss=0.01827  time=1.35s
# Epoch 4  loss=0.01807  val_loss=0.01769  sm_loss=0.01812  sm_val_loss=0.01776  time=1.06s
# Epoch 5  loss=0.01748  val_loss=0.01751  sm_loss=0.01755  sm_val_loss=0.01759  time=1.34s
# Epoch 6  loss=0.01707  val_loss=0.01739  sm_loss=0.01722  sm_val_loss=0.01747  time=1.13s
# Epoch 7  loss=0.01684  val_loss=0.01726  sm_loss=0.01699  sm_val_loss=0.01731  time=1.15s
# Epoch 9  loss=0.01648  val_loss=0.01704  sm_loss=0.01667  sm_val_loss=0.01708  time=1.08s
# Epoch 13  loss=0.01566  val_loss=0.01702  sm_loss=0.01593  sm_val_loss=0.01706  time=1.09s
# Epoch 14  loss=0.01542  val_loss=0.01702  sm_loss=0.01571  sm_val_loss=0.01704  time=1.36s
# Fold 7 log loss: 0.017077536450754494
# Seed 6
# Fold 1 log loss: 0.01735161648966673
# Fold 2 log loss: 0.0170935381600316
# Fold 3 log loss: 0.017564416212057423
# Fold 4 log loss: 0.01785398533980963
# Fold 5 log loss: 0.017335764948884586
# Fold 6 log loss: 0.017426746684023563
# Fold 7 log loss: 0.017077536450754494
# Std of log loss: 0.0002498262318318028
# Total log loss: 0.017386121668557106
# Total log loss in targets: 0.017033775356865122

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6495340563729194

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.01569905524197856

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

# %% [markdown]
# - change validation method
# - also change seed when collecting files
# - 7 folds
# - threshold 1000

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
drug = drug[drug.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 14

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[vc <= 1000].index.sort_values()
vc2 = vc.loc[vc > 1000].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
#skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
#tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
#for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
#    dd = {k:fold for k in tmp.sig_id[idxV].values}
#    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
#train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[6, 2, 5, ..., 4, 2, 2]], dtype=int8)

# %%
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
nontarget_dists.columns = ["target", "number"]
nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
print("first drop", len(drop_list1))
non_targets.drop(drop_list1, axis=1, inplace=True)
print("shape after 1st drop:", non_targets.shape)
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
print(len(non_target_feats))
# Out:
# first drop 71
# shape after 1st drop: (21948, 332)
# 331

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.7)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
len(drop_feats)

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 914) (3624, 914)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 1024))
        self.relu1 = nn.LeakyReLU()
        
        self.batch_norm2 = nn.BatchNorm1d(1024)
        self.dropout2 = nn.Dropout(0.1)
        self.dense2 = nn.utils.weight_norm(nn.Linear(1024, 1024))
        self.relu2 = nn.LeakyReLU()
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.1)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, last_num))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = self.relu1(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = self.relu2(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    if files == []:
        train_epochs = 10
        ans = []
    else:
        train_epochs = 15
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(X_test, dtype=torch.float32)
    X_test = torch.utils.data.TensorDataset(X_test) 
    test_loader = torch.utils.data.DataLoader(X_test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = X_train[:,-1] == fold
        train_index = X_train[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)

        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(non_target_feats)+len(target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            for param in clf.parameters():
                param.requires_grad = False
            # reinitialze
            clf.dense3 = nn.utils.weight_norm(nn.Linear(1024, len(target_feats)))
            for param in clf.dense3.parameters():
                param.requires_grad = True
            optimizer = optim.Adam(clf.parameters(), lr = 0.01, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, eps=1e-4, verbose=True)
            
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 0.001, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))
        
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                if files == []:
                    scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
            if files != []:
                scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Best: Epoch {} \t loss={:.5f} \t val_loss={:.5f} \t sm_loss={:.5f} \t sm_val_loss={:.5f} \t time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        if files == []:
            pred_model = MoaModel(init_num, len(non_target_feats)+len(target_feats))
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        if files != []:
            # test predcition --------------
            test_preds = np.zeros([test_len, y_train.shape[1]])
            for i, (x_batch,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
        
    print("Seed {}".format(sample_seed))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4] 
    
for seed_ in seeds:
    files = torch_tl(fn_train, fn_all_targets, fn_test, seed_, fn_train.shape[1]-1, [])
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Best: Epoch 1 	 loss=0.27656 	 val_loss=0.01220 	 sm_loss=0.27654 	 sm_val_loss=0.01220 	 time=1.97s
# Best: Epoch 2 	 loss=0.01083 	 val_loss=0.01179 	 sm_loss=0.01087 	 sm_val_loss=0.01177 	 time=1.23s
# Best: Epoch 3 	 loss=0.01021 	 val_loss=0.01167 	 sm_loss=0.01036 	 sm_val_loss=0.01156 	 time=1.25s
# Best: Epoch 4 	 loss=0.01010 	 val_loss=0.01149 	 sm_loss=0.01028 	 sm_val_loss=0.01147 	 time=1.09s
# Best: Epoch 5 	 loss=0.01002 	 val_loss=0.01149 	 sm_loss=0.01020 	 sm_val_loss=0.01145 	 time=1.10s
# Best: Epoch 6 	 loss=0.00995 	 val_loss=0.01138 	 sm_loss=0.01013 	 sm_val_loss=0.01133 	 time=1.07s
# Best: Epoch 7 	 loss=0.00979 	 val_loss=0.01121 	 sm_loss=0.00998 	 sm_val_loss=0.01120 	 time=1.04s
# Best: Epoch 8 	 loss=0.00956 	 val_loss=0.01109 	 sm_loss=0.00976 	 sm_val_loss=0.01108 	 time=1.10s
# Best: Epoch 9 	 loss=0.00927 	 val_loss=0.01101 	 sm_loss=0.00948 	 sm_val_loss=0.01099 	 time=1.00s
# Best: Epoch 10 	 loss=0.00905 	 val_loss=0.01099 	 sm_loss=0.00927 	 sm_val_loss=0.01097 	 time=1.29s
# Fold 1 log loss: 0.0183812564111792
# Fold 2
# Best: Epoch 1 	 loss=0.27931 	 val_loss=0.01096 	 sm_loss=0.27927 	 sm_val_loss=0.01096 	 time=0.98s
# Best: Epoch 2 	 loss=0.01110 	 val_loss=0.01049 	 sm_loss=0.01115 	 sm_val_loss=0.01055 	 time=0.99s
# Best: Epoch 4 	 loss=0.01036 	 val_loss=0.01026 	 sm_loss=0.01053 	 sm_val_loss=0.01030 	 time=0.96s
# Best: Epoch 6 	 loss=0.01019 	 val_loss=0.00970 	 sm_loss=0.01036 	 sm_val_loss=0.00976 	 time=0.97s
# Best: Epoch 9 	 loss=0.00950 	 val_loss=0.00959 	 sm_loss=0.00970 	 sm_val_loss=0.00965 	 time=0.98s
# Fold 2 log loss: 0.017180074913277207
# Fold 3
# Best: Epoch 1 	 loss=0.27816 	 val_loss=0.01329 	 sm_loss=0.27814 	 sm_val_loss=0.01329 	 time=0.99s
# Best: Epoch 2 	 loss=0.01100 	 val_loss=0.01274 	 sm_loss=0.01103 	 sm_val_loss=0.01279 	 time=0.98s
# Best: Epoch 4 	 loss=0.01026 	 val_loss=0.01235 	 sm_loss=0.01042 	 sm_val_loss=0.01239 	 time=0.98s
# Best: Epoch 5 	 loss=0.01016 	 val_loss=0.01213 	 sm_loss=0.01033 	 sm_val_loss=0.01218 	 time=0.98s
# Best: Epoch 6 	 loss=0.01008 	 val_loss=0.01196 	 sm_loss=0.01024 	 sm_val_loss=0.01199 	 time=0.98s
# Best: Epoch 7 	 loss=0.00996 	 val_loss=0.01149 	 sm_loss=0.01013 	 sm_val_loss=0.01153 	 time=0.98s
# Best: Epoch 9 	 loss=0.00945 	 val_loss=0.01143 	 sm_loss=0.00965 	 sm_val_loss=0.01150 	 time=0.97s
# Fold 3 log loss: 0.021551664652356358
# Fold 4
# Best: Epoch 1 	 loss=0.27914 	 val_loss=0.01212 	 sm_loss=0.27913 	 sm_val_loss=0.01212 	 time=0.98s
# Best: Epoch 2 	 loss=0.01097 	 val_loss=0.01186 	 sm_loss=0.01101 	 sm_val_loss=0.01190 	 time=0.98s
# Best: Epoch 4 	 loss=0.01030 	 val_loss=0.01160 	 sm_loss=0.01046 	 sm_val_loss=0.01163 	 time=1.01s
# Best: Epoch 6 	 loss=0.01010 	 val_loss=0.01142 	 sm_loss=0.01028 	 sm_val_loss=0.01146 	 time=1.10s
# Best: Epoch 8 	 loss=0.00977 	 val_loss=0.01100 	 sm_loss=0.00996 	 sm_val_loss=0.01104 	 time=0.98s
# Best: Epoch 9 	 loss=0.00947 	 val_loss=0.01094 	 sm_loss=0.00968 	 sm_val_loss=0.01098 	 time=1.26s
# Fold 4 log loss: 0.02038518304247651
# Fold 5
# Best: Epoch 1 	 loss=0.27721 	 val_loss=0.01238 	 sm_loss=0.27717 	 sm_val_loss=0.01237 	 time=0.98s
# Best: Epoch 2 	 loss=0.01095 	 val_loss=0.01191 	 sm_loss=0.01099 	 sm_val_loss=0.01190 	 time=1.00s
# Best: Epoch 3 	 loss=0.01013 	 val_loss=0.01174 	 sm_loss=0.01030 	 sm_val_loss=0.01168 	 time=0.99s
# Best: Epoch 4 	 loss=0.01001 	 val_loss=0.01173 	 sm_loss=0.01019 	 sm_val_loss=0.01166 	 time=0.99s
# Best: Epoch 6 	 loss=0.00985 	 val_loss=0.01157 	 sm_loss=0.01003 	 sm_val_loss=0.01152 	 time=0.99s
# Best: Epoch 7 	 loss=0.00971 	 val_loss=0.01154 	 sm_loss=0.00990 	 sm_val_loss=0.01151 	 time=1.00s
# Best: Epoch 8 	 loss=0.00950 	 val_loss=0.01136 	 sm_loss=0.00970 	 sm_val_loss=0.01136 	 time=1.24s
# Best: Epoch 9 	 loss=0.00920 	 val_loss=0.01128 	 sm_loss=0.00942 	 sm_val_loss=0.01127 	 time=1.54s
# Best: Epoch 10 	 loss=0.00897 	 val_loss=0.01124 	 sm_loss=0.00920 	 sm_val_loss=0.01123 	 time=1.06s
# Fold 5 log loss: 0.019069213775439166
# Fold 6
# Best: Epoch 1 	 loss=0.27647 	 val_loss=0.01271 	 sm_loss=0.27646 	 sm_val_loss=0.01270 	 time=1.04s
# Best: Epoch 2 	 loss=0.01072 	 val_loss=0.01200 	 sm_loss=0.01079 	 sm_val_loss=0.01195 	 time=1.02s
# Best: Epoch 4 	 loss=0.01002 	 val_loss=0.01196 	 sm_loss=0.01019 	 sm_val_loss=0.01192 	 time=1.10s
# Best: Epoch 5 	 loss=0.00993 	 val_loss=0.01196 	 sm_loss=0.01011 	 sm_val_loss=0.01189 	 time=1.05s
# Best: Epoch 6 	 loss=0.00985 	 val_loss=0.01195 	 sm_loss=0.01003 	 sm_val_loss=0.01189 	 time=1.30s
# Best: Epoch 7 	 loss=0.00971 	 val_loss=0.01176 	 sm_loss=0.00990 	 sm_val_loss=0.01171 	 time=1.03s
# Best: Epoch 8 	 loss=0.00947 	 val_loss=0.01154 	 sm_loss=0.00967 	 sm_val_loss=0.01150 	 time=1.02s
# Best: Epoch 9 	 loss=0.00919 	 val_loss=0.01144 	 sm_loss=0.00940 	 sm_val_loss=0.01141 	 time=1.06s
# Best: Epoch 10 	 loss=0.00898 	 val_loss=0.01144 	 sm_loss=0.00921 	 sm_val_loss=0.01141 	 time=1.04s
# Fold 6 log loss: 0.01919727709421163
# Fold 7
# Best: Epoch 1 	 loss=0.28276 	 val_loss=0.01761 	 sm_loss=0.28271 	 sm_val_loss=0.01527 	 time=0.96s
# Best: Epoch 2 	 loss=0.01181 	 val_loss=0.01456 	 sm_loss=0.01171 	 sm_val_loss=0.01324 	 time=1.05s
# Best: Epoch 5 	 loss=0.01035 	 val_loss=0.01277 	 sm_loss=0.01051 	 sm_val_loss=0.01280 	 time=1.23s
# Best: Epoch 7 	 loss=0.01010 	 val_loss=0.01258 	 sm_loss=0.01028 	 sm_val_loss=0.01270 	 time=0.97s
# Best: Epoch 8 	 loss=0.00989 	 val_loss=0.01223 	 sm_loss=0.01008 	 sm_val_loss=0.01230 	 time=0.96s
# Best: Epoch 10 	 loss=0.00930 	 val_loss=0.01217 	 sm_loss=0.00951 	 sm_val_loss=0.01224 	 time=0.96s
# Fold 7 log loss: 0.022398431777308124
# Seed 0
# Fold 1 log loss: 0.0183812564111792
# Fold 2 log loss: 0.017180074913277207
# Fold 3 log loss: 0.021551664652356358
# Fold 4 log loss: 0.02038518304247651
# Fold 5 log loss: 0.019069213775439166
# Fold 6 log loss: 0.01919727709421163
# Fold 7 log loss: 0.022398431777308124
# Std of log loss: 0.0016864803413973164
# Total log loss: 0.019847790492142903
# Fold 1
# Best: Epoch 1 	 loss=0.02487 	 val_loss=0.01932 	 sm_loss=0.02492 	 sm_val_loss=0.01931 	 time=0.64s
# Best: Epoch 2 	 loss=0.01679 	 val_loss=0.01865 	 sm_loss=0.01686 	 sm_val_loss=0.01865 	 time=0.64s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01554 	 val_loss=0.01837 	 sm_loss=0.01570 	 sm_val_loss=0.01838 	 time=0.63s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01516 	 val_loss=0.01834 	 sm_loss=0.01534 	 sm_val_loss=0.01835 	 time=0.64s
# Fold 1 log loss: 0.018352851140331014
# Fold 2
# Best: Epoch 1 	 loss=0.02523 	 val_loss=0.01811 	 sm_loss=0.02528 	 sm_val_loss=0.01814 	 time=0.65s
# Best: Epoch 2 	 loss=0.01715 	 val_loss=0.01787 	 sm_loss=0.01722 	 sm_val_loss=0.01790 	 time=0.70s
# Best: Epoch 6 	 loss=0.01643 	 val_loss=0.01759 	 sm_loss=0.01657 	 sm_val_loss=0.01758 	 time=0.64s
# Epoch    10: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Fold 2 log loss: 0.017631518353004243
# Fold 3
# Best: Epoch 1 	 loss=0.02484 	 val_loss=0.02263 	 sm_loss=0.02488 	 sm_val_loss=0.02265 	 time=0.91s
# Best: Epoch 2 	 loss=0.01713 	 val_loss=0.02213 	 sm_loss=0.01721 	 sm_val_loss=0.02215 	 time=0.65s
# Best: Epoch 3 	 loss=0.01640 	 val_loss=0.02166 	 sm_loss=0.01650 	 sm_val_loss=0.02169 	 time=0.64s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 10 	 loss=0.01567 	 val_loss=0.02150 	 sm_loss=0.01583 	 sm_val_loss=0.02156 	 time=1.04s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Fold 3 log loss: 0.021689824917764687
# Fold 4
# Best: Epoch 1 	 loss=0.02492 	 val_loss=0.02199 	 sm_loss=0.02496 	 sm_val_loss=0.02200 	 time=0.72s
# Best: Epoch 2 	 loss=0.01706 	 val_loss=0.02107 	 sm_loss=0.01713 	 sm_val_loss=0.02107 	 time=0.72s
# Best: Epoch 3 	 loss=0.01637 	 val_loss=0.02079 	 sm_loss=0.01648 	 sm_val_loss=0.02076 	 time=0.67s
# Best: Epoch 6 	 loss=0.01647 	 val_loss=0.02065 	 sm_loss=0.01661 	 sm_val_loss=0.02056 	 time=0.63s
# Best: Epoch 9 	 loss=0.01647 	 val_loss=0.02056 	 sm_loss=0.01660 	 sm_val_loss=0.02052 	 time=0.63s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 14 	 loss=0.01584 	 val_loss=0.02040 	 sm_loss=0.01598 	 sm_val_loss=0.02036 	 time=0.70s
# Fold 4 log loss: 0.020301281525052332
# Fold 5
# Best: Epoch 1 	 loss=0.02466 	 val_loss=0.01980 	 sm_loss=0.02471 	 sm_val_loss=0.01980 	 time=0.65s
# Best: Epoch 2 	 loss=0.01662 	 val_loss=0.01932 	 sm_loss=0.01671 	 sm_val_loss=0.01933 	 time=0.64s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01538 	 val_loss=0.01910 	 sm_loss=0.01555 	 sm_val_loss=0.01910 	 time=0.89s
# Best: Epoch 8 	 loss=0.01525 	 val_loss=0.01907 	 sm_loss=0.01543 	 sm_val_loss=0.01908 	 time=0.65s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01500 	 val_loss=0.01905 	 sm_loss=0.01519 	 sm_val_loss=0.01905 	 time=0.65s
# Fold 5 log loss: 0.019052500273697464
# Fold 6
# Best: Epoch 1 	 loss=0.02470 	 val_loss=0.02014 	 sm_loss=0.02475 	 sm_val_loss=0.02011 	 time=0.64s
# Best: Epoch 2 	 loss=0.01664 	 val_loss=0.01941 	 sm_loss=0.01672 	 sm_val_loss=0.01938 	 time=0.64s
# Best: Epoch 3 	 loss=0.01594 	 val_loss=0.01939 	 sm_loss=0.01605 	 sm_val_loss=0.01938 	 time=0.64s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01537 	 val_loss=0.01916 	 sm_loss=0.01554 	 sm_val_loss=0.01911 	 time=0.64s
# Best: Epoch 8 	 loss=0.01521 	 val_loss=0.01914 	 sm_loss=0.01538 	 sm_val_loss=0.01911 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Fold 6 log loss: 0.01914187354134475
# Fold 7
# Best: Epoch 1 	 loss=0.02528 	 val_loss=0.02705 	 sm_loss=0.02532 	 sm_val_loss=0.02698 	 time=0.63s
# Best: Epoch 2 	 loss=0.01743 	 val_loss=0.02270 	 sm_loss=0.01750 	 sm_val_loss=0.02273 	 time=0.63s
# Best: Epoch 4 	 loss=0.01653 	 val_loss=0.02218 	 sm_loss=0.01667 	 sm_val_loss=0.02223 	 time=0.63s
# Best: Epoch 7 	 loss=0.01664 	 val_loss=0.02200 	 sm_loss=0.01678 	 sm_val_loss=0.02205 	 time=0.63s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 14 	 loss=0.01585 	 val_loss=0.02071 	 sm_loss=0.01601 	 sm_val_loss=0.02077 	 time=0.63s
# Fold 7 log loss: 0.020836659808334372
# Seed 0
# Fold 1 log loss: 0.018352851140331014
# Fold 2 log loss: 0.017631518353004243
# Fold 3 log loss: 0.021689824917764687
# Fold 4 log loss: 0.020301281525052332
# Fold 5 log loss: 0.019052500273697464
# Fold 6 log loss: 0.01914187354134475
# Fold 7 log loss: 0.020836659808334372
# Std of log loss: 0.0013268156916159848
# Total log loss: 0.01964229183182477
# Fold 1
# Best: Epoch 1 	 loss=0.27673 	 val_loss=0.01223 	 sm_loss=0.27671 	 sm_val_loss=0.01223 	 time=0.99s
# Best: Epoch 3 	 loss=0.01021 	 val_loss=0.01152 	 sm_loss=0.01036 	 sm_val_loss=0.01150 	 time=0.99s
# Best: Epoch 4 	 loss=0.01009 	 val_loss=0.01148 	 sm_loss=0.01026 	 sm_val_loss=0.01143 	 time=0.99s
# Best: Epoch 6 	 loss=0.00994 	 val_loss=0.01132 	 sm_loss=0.01012 	 sm_val_loss=0.01130 	 time=1.27s
# Best: Epoch 7 	 loss=0.00981 	 val_loss=0.01123 	 sm_loss=0.01000 	 sm_val_loss=0.01122 	 time=1.06s
# Best: Epoch 8 	 loss=0.00956 	 val_loss=0.01118 	 sm_loss=0.00976 	 sm_val_loss=0.01116 	 time=1.02s
# Best: Epoch 9 	 loss=0.00929 	 val_loss=0.01099 	 sm_loss=0.00950 	 sm_val_loss=0.01098 	 time=1.04s
# Best: Epoch 10 	 loss=0.00904 	 val_loss=0.01096 	 sm_loss=0.00927 	 sm_val_loss=0.01095 	 time=1.09s
# Fold 1 log loss: 0.01831065371423221
# Fold 2
# Best: Epoch 1 	 loss=0.27974 	 val_loss=0.01099 	 sm_loss=0.27971 	 sm_val_loss=0.01098 	 time=0.99s
# Best: Epoch 2 	 loss=0.01122 	 val_loss=0.01034 	 sm_loss=0.01124 	 sm_val_loss=0.01040 	 time=1.01s
# Best: Epoch 4 	 loss=0.01043 	 val_loss=0.01001 	 sm_loss=0.01059 	 sm_val_loss=0.01007 	 time=1.03s
# Best: Epoch 8 	 loss=0.00980 	 val_loss=0.00989 	 sm_loss=0.00999 	 sm_val_loss=0.00996 	 time=0.97s
# Best: Epoch 9 	 loss=0.00953 	 val_loss=0.00982 	 sm_loss=0.00973 	 sm_val_loss=0.00989 	 time=0.98s
# Best: Epoch 10 	 loss=0.00929 	 val_loss=0.00974 	 sm_loss=0.00951 	 sm_val_loss=0.00981 	 time=1.00s
# Fold 2 log loss: 0.01757730797814727
# Fold 3
# Best: Epoch 1 	 loss=0.27922 	 val_loss=0.01326 	 sm_loss=0.27921 	 sm_val_loss=0.01325 	 time=0.98s
# Best: Epoch 3 	 loss=0.01046 	 val_loss=0.01234 	 sm_loss=0.01060 	 sm_val_loss=0.01240 	 time=1.07s
# Best: Epoch 4 	 loss=0.01024 	 val_loss=0.01226 	 sm_loss=0.01041 	 sm_val_loss=0.01231 	 time=1.00s
# Best: Epoch 5 	 loss=0.01016 	 val_loss=0.01219 	 sm_loss=0.01033 	 sm_val_loss=0.01224 	 time=0.98s
# Best: Epoch 6 	 loss=0.01006 	 val_loss=0.01217 	 sm_loss=0.01024 	 sm_val_loss=0.01221 	 time=0.99s
# Best: Epoch 7 	 loss=0.00990 	 val_loss=0.01195 	 sm_loss=0.01007 	 sm_val_loss=0.01201 	 time=1.40s
# Best: Epoch 8 	 loss=0.00968 	 val_loss=0.01164 	 sm_loss=0.00987 	 sm_val_loss=0.01171 	 time=1.02s
# Best: Epoch 9 	 loss=0.00940 	 val_loss=0.01135 	 sm_loss=0.00960 	 sm_val_loss=0.01142 	 time=0.99s
# Fold 3 log loss: 0.021360720107019327
# Fold 4
# Best: Epoch 1 	 loss=0.27878 	 val_loss=0.01204 	 sm_loss=0.27875 	 sm_val_loss=0.01204 	 time=1.27s
# Best: Epoch 2 	 loss=0.01106 	 val_loss=0.01175 	 sm_loss=0.01111 	 sm_val_loss=0.01180 	 time=1.12s
# Best: Epoch 3 	 loss=0.01043 	 val_loss=0.01140 	 sm_loss=0.01057 	 sm_val_loss=0.01144 	 time=1.04s
# Best: Epoch 6 	 loss=0.01015 	 val_loss=0.01134 	 sm_loss=0.01032 	 sm_val_loss=0.01137 	 time=1.01s
# Best: Epoch 7 	 loss=0.01001 	 val_loss=0.01123 	 sm_loss=0.01018 	 sm_val_loss=0.01128 	 time=1.00s
# Best: Epoch 8 	 loss=0.00976 	 val_loss=0.01100 	 sm_loss=0.00995 	 sm_val_loss=0.01104 	 time=0.99s
# Fold 4 log loss: 0.020571313433574278
# Fold 5
# Best: Epoch 1 	 loss=0.27680 	 val_loss=0.01231 	 sm_loss=0.27678 	 sm_val_loss=0.01231 	 time=1.09s
# Best: Epoch 2 	 loss=0.01083 	 val_loss=0.01190 	 sm_loss=0.01086 	 sm_val_loss=0.01182 	 time=1.00s
# Best: Epoch 3 	 loss=0.01014 	 val_loss=0.01171 	 sm_loss=0.01030 	 sm_val_loss=0.01169 	 time=0.99s
# Best: Epoch 4 	 loss=0.01003 	 val_loss=0.01174 	 sm_loss=0.01021 	 sm_val_loss=0.01168 	 time=1.01s
# Best: Epoch 6 	 loss=0.00991 	 val_loss=0.01159 	 sm_loss=0.01008 	 sm_val_loss=0.01155 	 time=0.99s
# Best: Epoch 7 	 loss=0.00975 	 val_loss=0.01153 	 sm_loss=0.00993 	 sm_val_loss=0.01151 	 time=0.99s
# Best: Epoch 8 	 loss=0.00953 	 val_loss=0.01141 	 sm_loss=0.00973 	 sm_val_loss=0.01138 	 time=1.00s
# Best: Epoch 9 	 loss=0.00926 	 val_loss=0.01126 	 sm_loss=0.00947 	 sm_val_loss=0.01124 	 time=0.99s
# Best: Epoch 10 	 loss=0.00902 	 val_loss=0.01124 	 sm_loss=0.00924 	 sm_val_loss=0.01123 	 time=1.00s
# Fold 5 log loss: 0.019029897475658017
# Fold 6
# Best: Epoch 1 	 loss=0.27735 	 val_loss=0.01253 	 sm_loss=0.27733 	 sm_val_loss=0.01253 	 time=1.01s
# Best: Epoch 2 	 loss=0.01086 	 val_loss=0.01216 	 sm_loss=0.01091 	 sm_val_loss=0.01208 	 time=1.03s
# Best: Epoch 3 	 loss=0.01010 	 val_loss=0.01206 	 sm_loss=0.01027 	 sm_val_loss=0.01200 	 time=1.34s
# Best: Epoch 4 	 loss=0.00999 	 val_loss=0.01190 	 sm_loss=0.01017 	 sm_val_loss=0.01182 	 time=1.43s
# Best: Epoch 6 	 loss=0.00985 	 val_loss=0.01179 	 sm_loss=0.01003 	 sm_val_loss=0.01175 	 time=1.21s
# Best: Epoch 7 	 loss=0.00968 	 val_loss=0.01164 	 sm_loss=0.00986 	 sm_val_loss=0.01161 	 time=1.00s
# Best: Epoch 8 	 loss=0.00945 	 val_loss=0.01154 	 sm_loss=0.00965 	 sm_val_loss=0.01151 	 time=1.09s
# Best: Epoch 9 	 loss=0.00917 	 val_loss=0.01151 	 sm_loss=0.00939 	 sm_val_loss=0.01149 	 time=1.25s
# Best: Epoch 10 	 loss=0.00895 	 val_loss=0.01148 	 sm_loss=0.00917 	 sm_val_loss=0.01145 	 time=1.06s
# Fold 6 log loss: 0.019232410785954706
# Fold 7
# Best: Epoch 1 	 loss=0.28327 	 val_loss=0.01494 	 sm_loss=0.28320 	 sm_val_loss=0.01499 	 time=0.98s
# Best: Epoch 2 	 loss=0.01171 	 val_loss=0.01895 	 sm_loss=0.01158 	 sm_val_loss=0.01469 	 time=0.97s
# Best: Epoch 3 	 loss=0.01092 	 val_loss=0.01374 	 sm_loss=0.01098 	 sm_val_loss=0.01380 	 time=0.97s
# Best: Epoch 4 	 loss=0.01052 	 val_loss=0.01293 	 sm_loss=0.01068 	 sm_val_loss=0.01292 	 time=0.97s
# Best: Epoch 6 	 loss=0.01027 	 val_loss=0.01205 	 sm_loss=0.01044 	 sm_val_loss=0.01214 	 time=0.96s
# Best: Epoch 7 	 loss=0.01011 	 val_loss=0.01198 	 sm_loss=0.01030 	 sm_val_loss=0.01203 	 time=0.98s
# Best: Epoch 8 	 loss=0.00989 	 val_loss=0.01195 	 sm_loss=0.01008 	 sm_val_loss=0.01200 	 time=1.19s
# Best: Epoch 9 	 loss=0.00959 	 val_loss=0.01179 	 sm_loss=0.00980 	 sm_val_loss=0.01186 	 time=1.02s
# Best: Epoch 10 	 loss=0.00933 	 val_loss=0.01169 	 sm_loss=0.00955 	 sm_val_loss=0.01174 	 time=0.97s
# Fold 7 log loss: 0.02117777827763705
# Seed 1
# Fold 1 log loss: 0.01831065371423221
# Fold 2 log loss: 0.01757730797814727
# Fold 3 log loss: 0.021360720107019327
# Fold 4 log loss: 0.020571313433574278
# Fold 5 log loss: 0.019029897475658017
# Fold 6 log loss: 0.019232410785954706
# Fold 7 log loss: 0.02117777827763705
# Std of log loss: 0.0013494067090414057
# Total log loss: 0.019687580669736273
# Fold 1
# Best: Epoch 1 	 loss=0.02488 	 val_loss=0.01926 	 sm_loss=0.02493 	 sm_val_loss=0.01926 	 time=0.64s
# Best: Epoch 2 	 loss=0.01677 	 val_loss=0.01847 	 sm_loss=0.01685 	 sm_val_loss=0.01848 	 time=0.64s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01551 	 val_loss=0.01827 	 sm_loss=0.01567 	 sm_val_loss=0.01829 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01516 	 val_loss=0.01826 	 sm_loss=0.01534 	 sm_val_loss=0.01827 	 time=0.79s
# Fold 1 log loss: 0.018270748237811774
# Fold 2
# Best: Epoch 1 	 loss=0.02518 	 val_loss=0.01777 	 sm_loss=0.02522 	 sm_val_loss=0.01780 	 time=0.64s
# Best: Epoch 2 	 loss=0.01705 	 val_loss=0.01749 	 sm_loss=0.01713 	 sm_val_loss=0.01754 	 time=0.70s
# Best: Epoch 5 	 loss=0.01633 	 val_loss=0.01724 	 sm_loss=0.01647 	 sm_val_loss=0.01728 	 time=0.64s
# Epoch     9: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 2 log loss: 0.017327290312889692
# Fold 3
# Best: Epoch 1 	 loss=0.02471 	 val_loss=0.02335 	 sm_loss=0.02475 	 sm_val_loss=0.02337 	 time=0.64s
# Best: Epoch 2 	 loss=0.01699 	 val_loss=0.02172 	 sm_loss=0.01706 	 sm_val_loss=0.02174 	 time=0.64s
# Best: Epoch 4 	 loss=0.01622 	 val_loss=0.02165 	 sm_loss=0.01635 	 sm_val_loss=0.02167 	 time=0.64s
# Best: Epoch 5 	 loss=0.01625 	 val_loss=0.02160 	 sm_loss=0.01638 	 sm_val_loss=0.02159 	 time=0.64s
# Best: Epoch 8 	 loss=0.01631 	 val_loss=0.02130 	 sm_loss=0.01644 	 sm_val_loss=0.02132 	 time=0.65s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-03.
# Fold 3 log loss: 0.021434053954852775
# Fold 4
# Best: Epoch 1 	 loss=0.02478 	 val_loss=0.02203 	 sm_loss=0.02482 	 sm_val_loss=0.02202 	 time=0.65s
# Best: Epoch 2 	 loss=0.01723 	 val_loss=0.02121 	 sm_loss=0.01730 	 sm_val_loss=0.02119 	 time=0.64s
# Best: Epoch 4 	 loss=0.01659 	 val_loss=0.02111 	 sm_loss=0.01671 	 sm_val_loss=0.02106 	 time=1.17s
# Epoch     8: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 9 	 loss=0.01615 	 val_loss=0.02042 	 sm_loss=0.01630 	 sm_val_loss=0.02039 	 time=0.64s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 4 log loss: 0.02033517211496178
# Fold 5
# Best: Epoch 1 	 loss=0.02468 	 val_loss=0.01979 	 sm_loss=0.02473 	 sm_val_loss=0.01979 	 time=0.65s
# Best: Epoch 2 	 loss=0.01666 	 val_loss=0.01915 	 sm_loss=0.01675 	 sm_val_loss=0.01914 	 time=0.96s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01539 	 val_loss=0.01901 	 sm_loss=0.01555 	 sm_val_loss=0.01903 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01509 	 val_loss=0.01899 	 sm_loss=0.01527 	 sm_val_loss=0.01901 	 time=0.64s
# Best: Epoch 13 	 loss=0.01506 	 val_loss=0.01897 	 sm_loss=0.01524 	 sm_val_loss=0.01898 	 time=0.66s
# Fold 5 log loss: 0.019007693041995115
# Fold 6
# Best: Epoch 1 	 loss=0.02460 	 val_loss=0.02018 	 sm_loss=0.02465 	 sm_val_loss=0.02016 	 time=0.88s
# Best: Epoch 2 	 loss=0.01659 	 val_loss=0.01942 	 sm_loss=0.01667 	 sm_val_loss=0.01938 	 time=0.65s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01534 	 val_loss=0.01924 	 sm_loss=0.01551 	 sm_val_loss=0.01917 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Fold 6 log loss: 0.01919800584931317
# Fold 7
# Best: Epoch 1 	 loss=0.02520 	 val_loss=0.02681 	 sm_loss=0.02524 	 sm_val_loss=0.02673 	 time=0.64s
# Best: Epoch 2 	 loss=0.01741 	 val_loss=0.02333 	 sm_loss=0.01748 	 sm_val_loss=0.02337 	 time=0.66s
# Best: Epoch 3 	 loss=0.01672 	 val_loss=0.02294 	 sm_loss=0.01683 	 sm_val_loss=0.02298 	 time=1.06s
# Best: Epoch 5 	 loss=0.01670 	 val_loss=0.02112 	 sm_loss=0.01685 	 sm_val_loss=0.02114 	 time=0.68s
# Epoch     9: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 10 	 loss=0.01611 	 val_loss=0.02080 	 sm_loss=0.01627 	 sm_val_loss=0.02085 	 time=0.63s
# Best: Epoch 14 	 loss=0.01584 	 val_loss=0.01986 	 sm_loss=0.01602 	 sm_val_loss=0.01991 	 time=0.63s
# Fold 7 log loss: 0.020008217393166865
# Seed 1
# Fold 1 log loss: 0.018270748237811774
# Fold 2 log loss: 0.017327290312889692
# Fold 3 log loss: 0.021434053954852775
# Fold 4 log loss: 0.02033517211496178
# Fold 5 log loss: 0.019007693041995115
# Fold 6 log loss: 0.01919800584931317
# Fold 7 log loss: 0.020008217393166865
# Std of log loss: 0.0012615779174307185
# Total log loss: 0.01941428101445853
# Fold 1
# Best: Epoch 1 	 loss=0.27689 	 val_loss=0.01217 	 sm_loss=0.27686 	 sm_val_loss=0.01217 	 time=1.00s
# Best: Epoch 3 	 loss=0.01014 	 val_loss=0.01157 	 sm_loss=0.01031 	 sm_val_loss=0.01153 	 time=0.99s
# Best: Epoch 4 	 loss=0.01008 	 val_loss=0.01136 	 sm_loss=0.01025 	 sm_val_loss=0.01132 	 time=0.99s
# Best: Epoch 6 	 loss=0.00992 	 val_loss=0.01134 	 sm_loss=0.01010 	 sm_val_loss=0.01130 	 time=0.99s
# Best: Epoch 7 	 loss=0.00979 	 val_loss=0.01129 	 sm_loss=0.00998 	 sm_val_loss=0.01126 	 time=1.01s
# Best: Epoch 8 	 loss=0.00952 	 val_loss=0.01120 	 sm_loss=0.00972 	 sm_val_loss=0.01118 	 time=1.32s
# Best: Epoch 9 	 loss=0.00926 	 val_loss=0.01100 	 sm_loss=0.00948 	 sm_val_loss=0.01099 	 time=1.06s
# Best: Epoch 10 	 loss=0.00903 	 val_loss=0.01098 	 sm_loss=0.00925 	 sm_val_loss=0.01096 	 time=1.06s
# Fold 1 log loss: 0.01836813001081257
# Fold 2
# Best: Epoch 1 	 loss=0.27959 	 val_loss=0.01111 	 sm_loss=0.27955 	 sm_val_loss=0.01111 	 time=1.17s
# Best: Epoch 2 	 loss=0.01138 	 val_loss=0.01094 	 sm_loss=0.01141 	 sm_val_loss=0.01096 	 time=1.01s
# Best: Epoch 3 	 loss=0.01062 	 val_loss=0.01062 	 sm_loss=0.01075 	 sm_val_loss=0.01065 	 time=1.03s
# Best: Epoch 4 	 loss=0.01042 	 val_loss=0.01012 	 sm_loss=0.01058 	 sm_val_loss=0.01014 	 time=1.31s
# Best: Epoch 5 	 loss=0.01028 	 val_loss=0.01007 	 sm_loss=0.01045 	 sm_val_loss=0.01012 	 time=1.03s
# Best: Epoch 7 	 loss=0.01000 	 val_loss=0.00983 	 sm_loss=0.01019 	 sm_val_loss=0.00987 	 time=1.28s
# Best: Epoch 9 	 loss=0.00948 	 val_loss=0.00968 	 sm_loss=0.00969 	 sm_val_loss=0.00974 	 time=0.99s
# Best: Epoch 10 	 loss=0.00925 	 val_loss=0.00967 	 sm_loss=0.00947 	 sm_val_loss=0.00974 	 time=0.99s
# Fold 2 log loss: 0.017423656266668898
# Fold 3
# Best: Epoch 1 	 loss=0.27857 	 val_loss=0.01327 	 sm_loss=0.27852 	 sm_val_loss=0.01327 	 time=1.01s
# Best: Epoch 3 	 loss=0.01035 	 val_loss=0.01245 	 sm_loss=0.01049 	 sm_val_loss=0.01249 	 time=0.98s
# Best: Epoch 4 	 loss=0.01030 	 val_loss=0.01234 	 sm_loss=0.01046 	 sm_val_loss=0.01238 	 time=1.01s
# Best: Epoch 5 	 loss=0.01016 	 val_loss=0.01230 	 sm_loss=0.01033 	 sm_val_loss=0.01232 	 time=1.29s
# Best: Epoch 6 	 loss=0.01005 	 val_loss=0.01219 	 sm_loss=0.01022 	 sm_val_loss=0.01226 	 time=1.01s
# Best: Epoch 7 	 loss=0.00992 	 val_loss=0.01153 	 sm_loss=0.01009 	 sm_val_loss=0.01159 	 time=1.02s
# Best: Epoch 9 	 loss=0.00941 	 val_loss=0.01132 	 sm_loss=0.00961 	 sm_val_loss=0.01139 	 time=1.00s
# Fold 3 log loss: 0.021304543643638638
# Fold 4
# Best: Epoch 1 	 loss=0.27917 	 val_loss=0.01221 	 sm_loss=0.27914 	 sm_val_loss=0.01221 	 time=1.02s
# Best: Epoch 2 	 loss=0.01111 	 val_loss=0.01167 	 sm_loss=0.01113 	 sm_val_loss=0.01168 	 time=0.99s
# Best: Epoch 3 	 loss=0.01037 	 val_loss=0.01137 	 sm_loss=0.01052 	 sm_val_loss=0.01141 	 time=1.00s
# Best: Epoch 6 	 loss=0.01012 	 val_loss=0.01131 	 sm_loss=0.01030 	 sm_val_loss=0.01135 	 time=0.98s
# Best: Epoch 8 	 loss=0.00975 	 val_loss=0.01111 	 sm_loss=0.00994 	 sm_val_loss=0.01116 	 time=0.98s
# Best: Epoch 10 	 loss=0.00924 	 val_loss=0.01085 	 sm_loss=0.00946 	 sm_val_loss=0.01091 	 time=0.99s
# Fold 4 log loss: 0.020203678217594275
# Fold 5
# Best: Epoch 1 	 loss=0.27601 	 val_loss=0.01225 	 sm_loss=0.27598 	 sm_val_loss=0.01225 	 time=1.04s
# Best: Epoch 3 	 loss=0.01018 	 val_loss=0.01179 	 sm_loss=0.01033 	 sm_val_loss=0.01172 	 time=1.27s
# Best: Epoch 4 	 loss=0.01002 	 val_loss=0.01164 	 sm_loss=0.01020 	 sm_val_loss=0.01159 	 time=1.19s
# Best: Epoch 7 	 loss=0.00975 	 val_loss=0.01150 	 sm_loss=0.00994 	 sm_val_loss=0.01147 	 time=1.00s
# Best: Epoch 8 	 loss=0.00952 	 val_loss=0.01137 	 sm_loss=0.00972 	 sm_val_loss=0.01136 	 time=1.01s
# Best: Epoch 9 	 loss=0.00924 	 val_loss=0.01124 	 sm_loss=0.00945 	 sm_val_loss=0.01123 	 time=1.00s
# Best: Epoch 10 	 loss=0.00901 	 val_loss=0.01124 	 sm_loss=0.00924 	 sm_val_loss=0.01123 	 time=1.01s
# Fold 5 log loss: 0.019067091031784736
# Fold 6
# Best: Epoch 1 	 loss=0.27712 	 val_loss=0.01267 	 sm_loss=0.27711 	 sm_val_loss=0.01267 	 time=0.99s
# Best: Epoch 2 	 loss=0.01065 	 val_loss=0.01196 	 sm_loss=0.01072 	 sm_val_loss=0.01196 	 time=1.26s
# Best: Epoch 3 	 loss=0.01003 	 val_loss=0.01195 	 sm_loss=0.01020 	 sm_val_loss=0.01187 	 time=1.01s
# Best: Epoch 5 	 loss=0.00994 	 val_loss=0.01185 	 sm_loss=0.01012 	 sm_val_loss=0.01181 	 time=1.00s
# Best: Epoch 7 	 loss=0.00973 	 val_loss=0.01171 	 sm_loss=0.00992 	 sm_val_loss=0.01166 	 time=1.00s
# Best: Epoch 8 	 loss=0.00951 	 val_loss=0.01159 	 sm_loss=0.00970 	 sm_val_loss=0.01155 	 time=1.02s
# Best: Epoch 9 	 loss=0.00923 	 val_loss=0.01149 	 sm_loss=0.00944 	 sm_val_loss=0.01146 	 time=1.00s
# Best: Epoch 10 	 loss=0.00900 	 val_loss=0.01146 	 sm_loss=0.00922 	 sm_val_loss=0.01143 	 time=1.23s
# Fold 6 log loss: 0.019249031052370608
# Fold 7
# Best: Epoch 1 	 loss=0.28368 	 val_loss=0.01790 	 sm_loss=0.28363 	 sm_val_loss=0.01568 	 time=1.66s
# Best: Epoch 2 	 loss=0.01159 	 val_loss=0.01498 	 sm_loss=0.01153 	 sm_val_loss=0.01442 	 time=0.98s
# Best: Epoch 3 	 loss=0.01071 	 val_loss=0.01341 	 sm_loss=0.01084 	 sm_val_loss=0.01350 	 time=1.02s
# Best: Epoch 4 	 loss=0.01044 	 val_loss=0.01212 	 sm_loss=0.01062 	 sm_val_loss=0.01219 	 time=1.00s
# Best: Epoch 7 	 loss=0.01009 	 val_loss=0.01171 	 sm_loss=0.01027 	 sm_val_loss=0.01178 	 time=1.01s
# Best: Epoch 10 	 loss=0.00929 	 val_loss=0.01146 	 sm_loss=0.00951 	 sm_val_loss=0.01153 	 time=1.03s
# Fold 7 log loss: 0.020944855271733346
# Seed 2
# Fold 1 log loss: 0.01836813001081257
# Fold 2 log loss: 0.017423656266668898
# Fold 3 log loss: 0.021304543643638638
# Fold 4 log loss: 0.020203678217594275
# Fold 5 log loss: 0.019067091031784736
# Fold 6 log loss: 0.019249031052370608
# Fold 7 log loss: 0.020944855271733346
# Std of log loss: 0.001291806309680946
# Total log loss: 0.019576835847893576
# Fold 1
# Best: Epoch 1 	 loss=0.02488 	 val_loss=0.01934 	 sm_loss=0.02493 	 sm_val_loss=0.01934 	 time=0.64s
# Best: Epoch 2 	 loss=0.01676 	 val_loss=0.01855 	 sm_loss=0.01684 	 sm_val_loss=0.01854 	 time=0.65s
# Best: Epoch 3 	 loss=0.01604 	 val_loss=0.01852 	 sm_loss=0.01615 	 sm_val_loss=0.01850 	 time=0.65s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01547 	 val_loss=0.01839 	 sm_loss=0.01564 	 sm_val_loss=0.01840 	 time=0.63s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01512 	 val_loss=0.01832 	 sm_loss=0.01530 	 sm_val_loss=0.01833 	 time=0.67s
# Fold 1 log loss: 0.018333100947345613
# Fold 2
# Best: Epoch 1 	 loss=0.02493 	 val_loss=0.01781 	 sm_loss=0.02497 	 sm_val_loss=0.01784 	 time=0.65s
# Best: Epoch 2 	 loss=0.01700 	 val_loss=0.01778 	 sm_loss=0.01708 	 sm_val_loss=0.01783 	 time=0.66s
# Best: Epoch 4 	 loss=0.01628 	 val_loss=0.01770 	 sm_loss=0.01642 	 sm_val_loss=0.01775 	 time=0.64s
# Best: Epoch 7 	 loss=0.01635 	 val_loss=0.01770 	 sm_loss=0.01649 	 sm_val_loss=0.01768 	 time=0.63s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 12 	 loss=0.01582 	 val_loss=0.01732 	 sm_loss=0.01598 	 sm_val_loss=0.01738 	 time=0.64s
# Fold 2 log loss: 0.01742923198201529
# Fold 3
# Best: Epoch 1 	 loss=0.02469 	 val_loss=0.02269 	 sm_loss=0.02474 	 sm_val_loss=0.02271 	 time=0.66s
# Best: Epoch 2 	 loss=0.01694 	 val_loss=0.02191 	 sm_loss=0.01701 	 sm_val_loss=0.02190 	 time=0.64s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01572 	 val_loss=0.02132 	 sm_loss=0.01588 	 sm_val_loss=0.02136 	 time=0.74s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01535 	 val_loss=0.02131 	 sm_loss=0.01553 	 sm_val_loss=0.02134 	 time=0.64s
# Fold 3 log loss: 0.02146713580526391
# Fold 4
# Best: Epoch 1 	 loss=0.02491 	 val_loss=0.02206 	 sm_loss=0.02495 	 sm_val_loss=0.02206 	 time=0.64s
# Best: Epoch 2 	 loss=0.01698 	 val_loss=0.02098 	 sm_loss=0.01706 	 sm_val_loss=0.02098 	 time=0.64s
# Best: Epoch 3 	 loss=0.01629 	 val_loss=0.02049 	 sm_loss=0.01641 	 sm_val_loss=0.02046 	 time=0.64s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01569 	 val_loss=0.02006 	 sm_loss=0.01585 	 sm_val_loss=0.02003 	 time=0.85s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Fold 4 log loss: 0.019985495370857864
# Fold 5
# Best: Epoch 1 	 loss=0.02464 	 val_loss=0.01979 	 sm_loss=0.02469 	 sm_val_loss=0.01980 	 time=0.68s
# Best: Epoch 2 	 loss=0.01669 	 val_loss=0.01923 	 sm_loss=0.01678 	 sm_val_loss=0.01922 	 time=0.66s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01545 	 val_loss=0.01911 	 sm_loss=0.01561 	 sm_val_loss=0.01910 	 time=0.68s
# Best: Epoch 10 	 loss=0.01524 	 val_loss=0.01909 	 sm_loss=0.01542 	 sm_val_loss=0.01909 	 time=0.65s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 15 	 loss=0.01513 	 val_loss=0.01907 	 sm_loss=0.01532 	 sm_val_loss=0.01906 	 time=0.72s
# Fold 5 log loss: 0.019052338449445178
# Fold 6
# Best: Epoch 1 	 loss=0.02455 	 val_loss=0.02013 	 sm_loss=0.02460 	 sm_val_loss=0.02010 	 time=0.66s
# Best: Epoch 2 	 loss=0.01664 	 val_loss=0.01946 	 sm_loss=0.01672 	 sm_val_loss=0.01942 	 time=0.69s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01548 	 val_loss=0.01933 	 sm_loss=0.01563 	 sm_val_loss=0.01928 	 time=0.64s
# Best: Epoch 11 	 loss=0.01529 	 val_loss=0.01929 	 sm_loss=0.01547 	 sm_val_loss=0.01924 	 time=0.64s
# Epoch    15: reducing learning rate of group 0 to 1.0000e-04.
# Fold 6 log loss: 0.019268753868108193
# Fold 7
# Best: Epoch 1 	 loss=0.02529 	 val_loss=0.02659 	 sm_loss=0.02532 	 sm_val_loss=0.02647 	 time=0.64s
# Best: Epoch 2 	 loss=0.01748 	 val_loss=0.02292 	 sm_loss=0.01755 	 sm_val_loss=0.02296 	 time=0.83s
# Best: Epoch 3 	 loss=0.01661 	 val_loss=0.02271 	 sm_loss=0.01672 	 sm_val_loss=0.02275 	 time=0.71s
# Best: Epoch 4 	 loss=0.01649 	 val_loss=0.02164 	 sm_loss=0.01663 	 sm_val_loss=0.02168 	 time=0.64s
# Epoch     8: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 9 	 loss=0.01598 	 val_loss=0.02141 	 sm_loss=0.01614 	 sm_val_loss=0.02147 	 time=0.64s
# Best: Epoch 10 	 loss=0.01583 	 val_loss=0.02105 	 sm_loss=0.01599 	 sm_val_loss=0.02111 	 time=0.64s
# Best: Epoch 12 	 loss=0.01577 	 val_loss=0.02038 	 sm_loss=0.01595 	 sm_val_loss=0.02044 	 time=0.63s
# Fold 7 log loss: 0.02052227322436936
# Seed 2
# Fold 1 log loss: 0.018333100947345613
# Fold 2 log loss: 0.01742923198201529
# Fold 3 log loss: 0.02146713580526391
# Fold 4 log loss: 0.019985495370857864
# Fold 5 log loss: 0.019052338449445178
# Fold 6 log loss: 0.019268753868108193
# Fold 7 log loss: 0.02052227322436936
# Std of log loss: 0.0012550534006208283
# Total log loss: 0.01949322830188828
# Fold 1
# Best: Epoch 1 	 loss=0.27616 	 val_loss=0.01212 	 sm_loss=0.27612 	 sm_val_loss=0.01212 	 time=0.98s
# Best: Epoch 2 	 loss=0.01127 	 val_loss=0.01167 	 sm_loss=0.01129 	 sm_val_loss=0.01164 	 time=1.01s
# Best: Epoch 3 	 loss=0.01032 	 val_loss=0.01156 	 sm_loss=0.01048 	 sm_val_loss=0.01149 	 time=1.01s
# Best: Epoch 4 	 loss=0.01007 	 val_loss=0.01142 	 sm_loss=0.01026 	 sm_val_loss=0.01139 	 time=1.10s
# Best: Epoch 5 	 loss=0.00999 	 val_loss=0.01131 	 sm_loss=0.01018 	 sm_val_loss=0.01129 	 time=1.00s
# Best: Epoch 6 	 loss=0.00991 	 val_loss=0.01131 	 sm_loss=0.01010 	 sm_val_loss=0.01128 	 time=1.03s
# Best: Epoch 7 	 loss=0.00976 	 val_loss=0.01126 	 sm_loss=0.00995 	 sm_val_loss=0.01124 	 time=1.02s
# Best: Epoch 8 	 loss=0.00953 	 val_loss=0.01114 	 sm_loss=0.00973 	 sm_val_loss=0.01111 	 time=1.10s
# Best: Epoch 9 	 loss=0.00923 	 val_loss=0.01101 	 sm_loss=0.00945 	 sm_val_loss=0.01099 	 time=1.41s
# Best: Epoch 10 	 loss=0.00899 	 val_loss=0.01098 	 sm_loss=0.00922 	 sm_val_loss=0.01096 	 time=1.17s
# Fold 1 log loss: 0.018340844667099926
# Fold 2
# Best: Epoch 1 	 loss=0.27949 	 val_loss=0.01116 	 sm_loss=0.27947 	 sm_val_loss=0.01116 	 time=0.99s
# Best: Epoch 2 	 loss=0.01120 	 val_loss=0.01038 	 sm_loss=0.01123 	 sm_val_loss=0.01043 	 time=1.02s
# Best: Epoch 3 	 loss=0.01048 	 val_loss=0.00988 	 sm_loss=0.01063 	 sm_val_loss=0.00993 	 time=1.00s
# Best: Epoch 9 	 loss=0.00951 	 val_loss=0.00980 	 sm_loss=0.00971 	 sm_val_loss=0.00986 	 time=1.31s
# Best: Epoch 10 	 loss=0.00927 	 val_loss=0.00974 	 sm_loss=0.00949 	 sm_val_loss=0.00980 	 time=1.21s
# Fold 2 log loss: 0.01755764657622549
# Fold 3
# Best: Epoch 1 	 loss=0.27866 	 val_loss=0.01338 	 sm_loss=0.27864 	 sm_val_loss=0.01337 	 time=1.08s
# Best: Epoch 2 	 loss=0.01093 	 val_loss=0.01302 	 sm_loss=0.01097 	 sm_val_loss=0.01305 	 time=1.02s
# Best: Epoch 3 	 loss=0.01038 	 val_loss=0.01279 	 sm_loss=0.01052 	 sm_val_loss=0.01287 	 time=1.01s
# Best: Epoch 4 	 loss=0.01020 	 val_loss=0.01269 	 sm_loss=0.01037 	 sm_val_loss=0.01261 	 time=1.03s
# Best: Epoch 5 	 loss=0.01012 	 val_loss=0.01172 	 sm_loss=0.01029 	 sm_val_loss=0.01179 	 time=1.00s
# Best: Epoch 8 	 loss=0.00971 	 val_loss=0.01157 	 sm_loss=0.00989 	 sm_val_loss=0.01164 	 time=1.02s
# Best: Epoch 9 	 loss=0.00940 	 val_loss=0.01155 	 sm_loss=0.00960 	 sm_val_loss=0.01161 	 time=1.10s
# Best: Epoch 10 	 loss=0.00918 	 val_loss=0.01146 	 sm_loss=0.00939 	 sm_val_loss=0.01152 	 time=1.01s
# Fold 3 log loss: 0.021612058272368558
# Fold 4
# Best: Epoch 1 	 loss=0.27988 	 val_loss=0.01221 	 sm_loss=0.27986 	 sm_val_loss=0.01221 	 time=1.00s
# Best: Epoch 2 	 loss=0.01198 	 val_loss=0.01184 	 sm_loss=0.01197 	 sm_val_loss=0.01186 	 time=1.00s
# Best: Epoch 3 	 loss=0.01073 	 val_loss=0.01174 	 sm_loss=0.01087 	 sm_val_loss=0.01177 	 time=1.17s
# Best: Epoch 4 	 loss=0.01039 	 val_loss=0.01159 	 sm_loss=0.01056 	 sm_val_loss=0.01163 	 time=1.21s
# Best: Epoch 5 	 loss=0.01025 	 val_loss=0.01139 	 sm_loss=0.01042 	 sm_val_loss=0.01141 	 time=1.05s
# Best: Epoch 7 	 loss=0.00993 	 val_loss=0.01124 	 sm_loss=0.01012 	 sm_val_loss=0.01128 	 time=1.01s
# Best: Epoch 8 	 loss=0.00972 	 val_loss=0.01108 	 sm_loss=0.00992 	 sm_val_loss=0.01111 	 time=1.02s
# Best: Epoch 9 	 loss=0.00946 	 val_loss=0.01096 	 sm_loss=0.00967 	 sm_val_loss=0.01101 	 time=1.00s
# Best: Epoch 10 	 loss=0.00918 	 val_loss=0.01096 	 sm_loss=0.00940 	 sm_val_loss=0.01100 	 time=1.00s
# Fold 4 log loss: 0.02039024730809663
# Fold 5
# Best: Epoch 1 	 loss=0.27636 	 val_loss=0.01240 	 sm_loss=0.27634 	 sm_val_loss=0.01240 	 time=1.00s
# Best: Epoch 2 	 loss=0.01076 	 val_loss=0.01182 	 sm_loss=0.01081 	 sm_val_loss=0.01183 	 time=1.02s
# Best: Epoch 3 	 loss=0.01014 	 val_loss=0.01173 	 sm_loss=0.01030 	 sm_val_loss=0.01169 	 time=1.02s
# Best: Epoch 4 	 loss=0.01003 	 val_loss=0.01169 	 sm_loss=0.01021 	 sm_val_loss=0.01165 	 time=1.10s
# Best: Epoch 7 	 loss=0.00972 	 val_loss=0.01149 	 sm_loss=0.00991 	 sm_val_loss=0.01147 	 time=1.00s
# Best: Epoch 8 	 loss=0.00950 	 val_loss=0.01134 	 sm_loss=0.00970 	 sm_val_loss=0.01134 	 time=0.99s
# Best: Epoch 9 	 loss=0.00922 	 val_loss=0.01125 	 sm_loss=0.00943 	 sm_val_loss=0.01124 	 time=1.01s
# Best: Epoch 10 	 loss=0.00899 	 val_loss=0.01123 	 sm_loss=0.00922 	 sm_val_loss=0.01123 	 time=1.00s
# Fold 5 log loss: 0.0190609462320987
# Fold 6
# Best: Epoch 1 	 loss=0.27663 	 val_loss=0.01254 	 sm_loss=0.27661 	 sm_val_loss=0.01254 	 time=1.02s
# Best: Epoch 3 	 loss=0.01013 	 val_loss=0.01235 	 sm_loss=0.01028 	 sm_val_loss=0.01224 	 time=1.02s
# Best: Epoch 4 	 loss=0.01003 	 val_loss=0.01198 	 sm_loss=0.01020 	 sm_val_loss=0.01192 	 time=1.46s
# Best: Epoch 5 	 loss=0.00993 	 val_loss=0.01184 	 sm_loss=0.01011 	 sm_val_loss=0.01180 	 time=1.01s
# Best: Epoch 6 	 loss=0.00984 	 val_loss=0.01186 	 sm_loss=0.01003 	 sm_val_loss=0.01180 	 time=1.02s
# Best: Epoch 7 	 loss=0.00972 	 val_loss=0.01173 	 sm_loss=0.00990 	 sm_val_loss=0.01167 	 time=1.19s
# Best: Epoch 8 	 loss=0.00949 	 val_loss=0.01156 	 sm_loss=0.00969 	 sm_val_loss=0.01154 	 time=1.02s
# Best: Epoch 9 	 loss=0.00921 	 val_loss=0.01149 	 sm_loss=0.00942 	 sm_val_loss=0.01146 	 time=1.00s
# Best: Epoch 10 	 loss=0.00899 	 val_loss=0.01144 	 sm_loss=0.00922 	 sm_val_loss=0.01141 	 time=1.35s
# Fold 6 log loss: 0.019211604008149696
# Fold 7
# Best: Epoch 1 	 loss=0.28231 	 val_loss=0.01515 	 sm_loss=0.28227 	 sm_val_loss=0.01518 	 time=0.99s
# Best: Epoch 2 	 loss=0.01195 	 val_loss=0.01773 	 sm_loss=0.01178 	 sm_val_loss=0.01494 	 time=1.27s
# Best: Epoch 3 	 loss=0.01115 	 val_loss=0.01572 	 sm_loss=0.01114 	 sm_val_loss=0.01461 	 time=0.98s
# Best: Epoch 4 	 loss=0.01062 	 val_loss=0.01339 	 sm_loss=0.01077 	 sm_val_loss=0.01344 	 time=1.47s
# Best: Epoch 5 	 loss=0.01039 	 val_loss=0.01286 	 sm_loss=0.01057 	 sm_val_loss=0.01289 	 time=0.98s
# Best: Epoch 7 	 loss=0.01009 	 val_loss=0.01219 	 sm_loss=0.01028 	 sm_val_loss=0.01229 	 time=0.99s
# Best: Epoch 8 	 loss=0.00982 	 val_loss=0.01195 	 sm_loss=0.01002 	 sm_val_loss=0.01200 	 time=1.02s
# Best: Epoch 10 	 loss=0.00927 	 val_loss=0.01181 	 sm_loss=0.00951 	 sm_val_loss=0.01189 	 time=1.03s
# Fold 7 log loss: 0.021780620238561057
# Seed 3
# Fold 1 log loss: 0.018340844667099926
# Fold 2 log loss: 0.01755764657622549
# Fold 3 log loss: 0.021612058272368558
# Fold 4 log loss: 0.02039024730809663
# Fold 5 log loss: 0.0190609462320987
# Fold 6 log loss: 0.019211604008149696
# Fold 7 log loss: 0.021780620238561057
# Std of log loss: 0.0014902001048614616
# Total log loss: 0.019803055502673316
# Fold 1
# Best: Epoch 1 	 loss=0.02462 	 val_loss=0.01927 	 sm_loss=0.02467 	 sm_val_loss=0.01925 	 time=0.67s
# Best: Epoch 2 	 loss=0.01664 	 val_loss=0.01846 	 sm_loss=0.01672 	 sm_val_loss=0.01845 	 time=0.67s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01534 	 val_loss=0.01836 	 sm_loss=0.01550 	 sm_val_loss=0.01836 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01504 	 val_loss=0.01835 	 sm_loss=0.01523 	 sm_val_loss=0.01834 	 time=0.76s
# Best: Epoch 14 	 loss=0.01501 	 val_loss=0.01831 	 sm_loss=0.01519 	 sm_val_loss=0.01831 	 time=0.90s
# Fold 1 log loss: 0.01831353527964986
# Fold 2
# Best: Epoch 1 	 loss=0.02509 	 val_loss=0.01790 	 sm_loss=0.02513 	 sm_val_loss=0.01792 	 time=0.65s
# Best: Epoch 2 	 loss=0.01705 	 val_loss=0.01750 	 sm_loss=0.01713 	 sm_val_loss=0.01753 	 time=0.68s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    10: reducing learning rate of group 0 to 1.0000e-04.
# Fold 2 log loss: 0.01757448785978627
# Fold 3
# Best: Epoch 1 	 loss=0.02471 	 val_loss=0.02269 	 sm_loss=0.02475 	 sm_val_loss=0.02270 	 time=0.64s
# Best: Epoch 2 	 loss=0.01695 	 val_loss=0.02225 	 sm_loss=0.01703 	 sm_val_loss=0.02223 	 time=0.64s
# Best: Epoch 4 	 loss=0.01620 	 val_loss=0.02209 	 sm_loss=0.01633 	 sm_val_loss=0.02205 	 time=0.65s
# Epoch     8: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 9 	 loss=0.01568 	 val_loss=0.02191 	 sm_loss=0.01584 	 sm_val_loss=0.02192 	 time=0.64s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 3 log loss: 0.022033911689548318
# Fold 4
# Best: Epoch 1 	 loss=0.02463 	 val_loss=0.02206 	 sm_loss=0.02468 	 sm_val_loss=0.02207 	 time=0.64s
# Best: Epoch 2 	 loss=0.01683 	 val_loss=0.02145 	 sm_loss=0.01691 	 sm_val_loss=0.02144 	 time=0.66s
# Best: Epoch 3 	 loss=0.01612 	 val_loss=0.02075 	 sm_loss=0.01624 	 sm_val_loss=0.02070 	 time=0.64s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01559 	 val_loss=0.02035 	 sm_loss=0.01575 	 sm_val_loss=0.02028 	 time=0.65s
# Best: Epoch 10 	 loss=0.01538 	 val_loss=0.02012 	 sm_loss=0.01556 	 sm_val_loss=0.02006 	 time=0.91s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Fold 4 log loss: 0.020000047053459525
# Fold 5
# Best: Epoch 1 	 loss=0.02469 	 val_loss=0.01974 	 sm_loss=0.02474 	 sm_val_loss=0.01974 	 time=0.91s
# Best: Epoch 2 	 loss=0.01659 	 val_loss=0.01927 	 sm_loss=0.01667 	 sm_val_loss=0.01928 	 time=1.00s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01533 	 val_loss=0.01899 	 sm_loss=0.01549 	 sm_val_loss=0.01900 	 time=0.82s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Fold 5 log loss: 0.019026583834387323
# Fold 6
# Best: Epoch 1 	 loss=0.02462 	 val_loss=0.02023 	 sm_loss=0.02467 	 sm_val_loss=0.02018 	 time=0.64s
# Best: Epoch 2 	 loss=0.01670 	 val_loss=0.01942 	 sm_loss=0.01677 	 sm_val_loss=0.01940 	 time=0.66s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01545 	 val_loss=0.01919 	 sm_loss=0.01561 	 sm_val_loss=0.01916 	 time=0.67s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01513 	 val_loss=0.01917 	 sm_loss=0.01531 	 sm_val_loss=0.01913 	 time=0.75s
# Best: Epoch 14 	 loss=0.01509 	 val_loss=0.01915 	 sm_loss=0.01527 	 sm_val_loss=0.01911 	 time=0.64s
# Fold 6 log loss: 0.019147880701998514
# Fold 7
# Best: Epoch 1 	 loss=0.02520 	 val_loss=0.02637 	 sm_loss=0.02524 	 sm_val_loss=0.02639 	 time=0.64s
# Best: Epoch 2 	 loss=0.01736 	 val_loss=0.02370 	 sm_loss=0.01744 	 sm_val_loss=0.02373 	 time=0.63s
# Best: Epoch 3 	 loss=0.01657 	 val_loss=0.02012 	 sm_loss=0.01668 	 sm_val_loss=0.02015 	 time=0.63s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 9 	 loss=0.01576 	 val_loss=0.01989 	 sm_loss=0.01593 	 sm_val_loss=0.01995 	 time=0.64s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 7 log loss: 0.020014405249197013
# Seed 3
# Fold 1 log loss: 0.01831353527964986
# Fold 2 log loss: 0.01757448785978627
# Fold 3 log loss: 0.022033911689548318
# Fold 4 log loss: 0.020000047053459525
# Fold 5 log loss: 0.019026583834387323
# Fold 6 log loss: 0.019147880701998514
# Fold 7 log loss: 0.020014405249197013
# Std of log loss: 0.0013297228976768204
# Total log loss: 0.019491782135579196
# Fold 1
# Best: Epoch 1 	 loss=0.27659 	 val_loss=0.01231 	 sm_loss=0.27655 	 sm_val_loss=0.01231 	 time=1.15s
# Best: Epoch 2 	 loss=0.01093 	 val_loss=0.01156 	 sm_loss=0.01095 	 sm_val_loss=0.01156 	 time=0.99s
# Best: Epoch 3 	 loss=0.01017 	 val_loss=0.01154 	 sm_loss=0.01034 	 sm_val_loss=0.01150 	 time=0.99s
# Best: Epoch 4 	 loss=0.01013 	 val_loss=0.01149 	 sm_loss=0.01030 	 sm_val_loss=0.01147 	 time=1.00s
# Best: Epoch 5 	 loss=0.01001 	 val_loss=0.01149 	 sm_loss=0.01019 	 sm_val_loss=0.01144 	 time=1.00s
# Best: Epoch 6 	 loss=0.00996 	 val_loss=0.01126 	 sm_loss=0.01013 	 sm_val_loss=0.01121 	 time=0.99s
# Best: Epoch 8 	 loss=0.00957 	 val_loss=0.01115 	 sm_loss=0.00976 	 sm_val_loss=0.01112 	 time=1.01s
# Best: Epoch 9 	 loss=0.00929 	 val_loss=0.01105 	 sm_loss=0.00950 	 sm_val_loss=0.01102 	 time=0.99s
# Best: Epoch 10 	 loss=0.00905 	 val_loss=0.01099 	 sm_loss=0.00927 	 sm_val_loss=0.01097 	 time=1.00s
# Fold 1 log loss: 0.01841076227607237
# Fold 2
# Best: Epoch 1 	 loss=0.27920 	 val_loss=0.01110 	 sm_loss=0.27918 	 sm_val_loss=0.01110 	 time=0.98s
# Best: Epoch 3 	 loss=0.01053 	 val_loss=0.01022 	 sm_loss=0.01067 	 sm_val_loss=0.01026 	 time=0.98s
# Best: Epoch 4 	 loss=0.01039 	 val_loss=0.01008 	 sm_loss=0.01055 	 sm_val_loss=0.01014 	 time=0.99s
# Best: Epoch 6 	 loss=0.01022 	 val_loss=0.01008 	 sm_loss=0.01038 	 sm_val_loss=0.01013 	 time=0.98s
# Best: Epoch 7 	 loss=0.01006 	 val_loss=0.00990 	 sm_loss=0.01023 	 sm_val_loss=0.00995 	 time=0.99s
# Best: Epoch 8 	 loss=0.00984 	 val_loss=0.00976 	 sm_loss=0.01002 	 sm_val_loss=0.00982 	 time=0.98s
# Best: Epoch 9 	 loss=0.00955 	 val_loss=0.00974 	 sm_loss=0.00975 	 sm_val_loss=0.00981 	 time=1.00s
# Best: Epoch 10 	 loss=0.00932 	 val_loss=0.00973 	 sm_loss=0.00953 	 sm_val_loss=0.00980 	 time=1.25s
# Fold 2 log loss: 0.017544639228774594
# Fold 3
# Best: Epoch 1 	 loss=0.27919 	 val_loss=0.01313 	 sm_loss=0.27917 	 sm_val_loss=0.01313 	 time=1.11s
# Best: Epoch 2 	 loss=0.01104 	 val_loss=0.01233 	 sm_loss=0.01108 	 sm_val_loss=0.01239 	 time=1.45s
# Best: Epoch 3 	 loss=0.01030 	 val_loss=0.01188 	 sm_loss=0.01045 	 sm_val_loss=0.01193 	 time=1.08s
# Best: Epoch 8 	 loss=0.00970 	 val_loss=0.01160 	 sm_loss=0.00988 	 sm_val_loss=0.01165 	 time=1.24s
# Best: Epoch 9 	 loss=0.00939 	 val_loss=0.01142 	 sm_loss=0.00959 	 sm_val_loss=0.01150 	 time=1.06s
# Best: Epoch 10 	 loss=0.00915 	 val_loss=0.01140 	 sm_loss=0.00937 	 sm_val_loss=0.01148 	 time=0.99s
# Fold 3 log loss: 0.021513742478634672
# Fold 4
# Best: Epoch 1 	 loss=0.27938 	 val_loss=0.01221 	 sm_loss=0.27937 	 sm_val_loss=0.01220 	 time=1.00s
# Best: Epoch 3 	 loss=0.01057 	 val_loss=0.01166 	 sm_loss=0.01070 	 sm_val_loss=0.01171 	 time=0.99s
# Best: Epoch 5 	 loss=0.01020 	 val_loss=0.01125 	 sm_loss=0.01037 	 sm_val_loss=0.01129 	 time=0.98s
# Best: Epoch 7 	 loss=0.00996 	 val_loss=0.01124 	 sm_loss=0.01014 	 sm_val_loss=0.01127 	 time=1.27s
# Best: Epoch 8 	 loss=0.00976 	 val_loss=0.01122 	 sm_loss=0.00995 	 sm_val_loss=0.01126 	 time=1.19s
# Best: Epoch 9 	 loss=0.00949 	 val_loss=0.01097 	 sm_loss=0.00969 	 sm_val_loss=0.01101 	 time=1.05s
# Best: Epoch 10 	 loss=0.00926 	 val_loss=0.01095 	 sm_loss=0.00947 	 sm_val_loss=0.01100 	 time=1.02s
# Fold 4 log loss: 0.02049308984847364
# Fold 5
# Best: Epoch 1 	 loss=0.27754 	 val_loss=0.01237 	 sm_loss=0.27753 	 sm_val_loss=0.01237 	 time=0.99s
# Best: Epoch 2 	 loss=0.01095 	 val_loss=0.01184 	 sm_loss=0.01096 	 sm_val_loss=0.01184 	 time=1.02s
# Best: Epoch 3 	 loss=0.01030 	 val_loss=0.01191 	 sm_loss=0.01043 	 sm_val_loss=0.01183 	 time=1.01s
# Best: Epoch 4 	 loss=0.01012 	 val_loss=0.01173 	 sm_loss=0.01028 	 sm_val_loss=0.01167 	 time=1.00s
# Best: Epoch 6 	 loss=0.00994 	 val_loss=0.01166 	 sm_loss=0.01012 	 sm_val_loss=0.01164 	 time=1.26s
# Best: Epoch 7 	 loss=0.00978 	 val_loss=0.01149 	 sm_loss=0.00996 	 sm_val_loss=0.01146 	 time=1.01s
# Best: Epoch 8 	 loss=0.00952 	 val_loss=0.01133 	 sm_loss=0.00972 	 sm_val_loss=0.01131 	 time=1.34s
# Best: Epoch 9 	 loss=0.00926 	 val_loss=0.01123 	 sm_loss=0.00947 	 sm_val_loss=0.01122 	 time=1.03s
# Fold 5 log loss: 0.0190557369110881
# Fold 6
# Best: Epoch 1 	 loss=0.27716 	 val_loss=0.01260 	 sm_loss=0.27714 	 sm_val_loss=0.01260 	 time=1.01s
# Best: Epoch 2 	 loss=0.01069 	 val_loss=0.01221 	 sm_loss=0.01076 	 sm_val_loss=0.01211 	 time=1.00s
# Best: Epoch 3 	 loss=0.01009 	 val_loss=0.01201 	 sm_loss=0.01025 	 sm_val_loss=0.01197 	 time=1.00s
# Best: Epoch 4 	 loss=0.00999 	 val_loss=0.01197 	 sm_loss=0.01016 	 sm_val_loss=0.01193 	 time=1.01s
# Best: Epoch 5 	 loss=0.00994 	 val_loss=0.01184 	 sm_loss=0.01012 	 sm_val_loss=0.01181 	 time=1.29s
# Best: Epoch 6 	 loss=0.00981 	 val_loss=0.01181 	 sm_loss=0.01000 	 sm_val_loss=0.01177 	 time=1.01s
# Best: Epoch 7 	 loss=0.00969 	 val_loss=0.01170 	 sm_loss=0.00988 	 sm_val_loss=0.01164 	 time=1.02s
# Best: Epoch 8 	 loss=0.00947 	 val_loss=0.01154 	 sm_loss=0.00967 	 sm_val_loss=0.01151 	 time=0.99s
# Best: Epoch 9 	 loss=0.00921 	 val_loss=0.01145 	 sm_loss=0.00942 	 sm_val_loss=0.01142 	 time=1.00s
# Best: Epoch 10 	 loss=0.00896 	 val_loss=0.01144 	 sm_loss=0.00919 	 sm_val_loss=0.01141 	 time=1.00s
# Fold 6 log loss: 0.019155356399165484
# Fold 7
# Best: Epoch 1 	 loss=0.28318 	 val_loss=0.01684 	 sm_loss=0.28314 	 sm_val_loss=0.01516 	 time=0.98s
# Best: Epoch 3 	 loss=0.01090 	 val_loss=0.01378 	 sm_loss=0.01094 	 sm_val_loss=0.01378 	 time=0.97s
# Best: Epoch 4 	 loss=0.01045 	 val_loss=0.01290 	 sm_loss=0.01062 	 sm_val_loss=0.01295 	 time=1.36s
# Best: Epoch 5 	 loss=0.01037 	 val_loss=0.01193 	 sm_loss=0.01054 	 sm_val_loss=0.01197 	 time=0.97s
# Best: Epoch 6 	 loss=0.01026 	 val_loss=0.01187 	 sm_loss=0.01044 	 sm_val_loss=0.01193 	 time=0.97s
# Fold 7 log loss: 0.022006567225982498
# Seed 4
# Fold 1 log loss: 0.01841076227607237
# Fold 2 log loss: 0.017544639228774594
# Fold 3 log loss: 0.021513742478634672
# Fold 4 log loss: 0.02049308984847364
# Fold 5 log loss: 0.0190557369110881
# Fold 6 log loss: 0.019155356399165484
# Fold 7 log loss: 0.022006567225982498
# Std of log loss: 0.001523489399188719
# Total log loss: 0.019841515695733947
# Fold 1
# Best: Epoch 1 	 loss=0.02483 	 val_loss=0.01930 	 sm_loss=0.02488 	 sm_val_loss=0.01929 	 time=0.66s
# Best: Epoch 2 	 loss=0.01679 	 val_loss=0.01854 	 sm_loss=0.01687 	 sm_val_loss=0.01854 	 time=1.02s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01553 	 val_loss=0.01836 	 sm_loss=0.01569 	 sm_val_loss=0.01839 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01516 	 val_loss=0.01834 	 sm_loss=0.01534 	 sm_val_loss=0.01837 	 time=0.63s
# Best: Epoch 14 	 loss=0.01518 	 val_loss=0.01833 	 sm_loss=0.01536 	 sm_val_loss=0.01836 	 time=0.67s
# Fold 1 log loss: 0.018356682199431158
# Fold 2
# Best: Epoch 1 	 loss=0.02500 	 val_loss=0.01780 	 sm_loss=0.02504 	 sm_val_loss=0.01783 	 time=0.64s
# Best: Epoch 2 	 loss=0.01709 	 val_loss=0.01751 	 sm_loss=0.01716 	 sm_val_loss=0.01755 	 time=0.65s
# Best: Epoch 3 	 loss=0.01643 	 val_loss=0.01738 	 sm_loss=0.01653 	 sm_val_loss=0.01744 	 time=0.65s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01551 	 val_loss=0.01726 	 sm_loss=0.01569 	 sm_val_loss=0.01732 	 time=0.64s
# Fold 2 log loss: 0.017371676245378134
# Fold 3
# Best: Epoch 1 	 loss=0.02473 	 val_loss=0.02314 	 sm_loss=0.02478 	 sm_val_loss=0.02316 	 time=0.67s
# Best: Epoch 2 	 loss=0.01696 	 val_loss=0.02213 	 sm_loss=0.01703 	 sm_val_loss=0.02211 	 time=0.67s
# Best: Epoch 3 	 loss=0.01620 	 val_loss=0.02191 	 sm_loss=0.01630 	 sm_val_loss=0.02189 	 time=0.67s
# Best: Epoch 5 	 loss=0.01613 	 val_loss=0.02182 	 sm_loss=0.01626 	 sm_val_loss=0.02177 	 time=0.64s
# Epoch     9: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 11 	 loss=0.01545 	 val_loss=0.02164 	 sm_loss=0.01561 	 sm_val_loss=0.02166 	 time=0.66s
# Best: Epoch 13 	 loss=0.01546 	 val_loss=0.02148 	 sm_loss=0.01563 	 sm_val_loss=0.02150 	 time=0.64s
# Fold 3 log loss: 0.021643043914116256
# Fold 4
# Best: Epoch 1 	 loss=0.02476 	 val_loss=0.02213 	 sm_loss=0.02480 	 sm_val_loss=0.02212 	 time=0.64s
# Best: Epoch 2 	 loss=0.01701 	 val_loss=0.02125 	 sm_loss=0.01708 	 sm_val_loss=0.02124 	 time=0.65s
# Best: Epoch 4 	 loss=0.01624 	 val_loss=0.02116 	 sm_loss=0.01638 	 sm_val_loss=0.02107 	 time=0.65s
# Best: Epoch 5 	 loss=0.01633 	 val_loss=0.02109 	 sm_loss=0.01647 	 sm_val_loss=0.02097 	 time=0.64s
# Best: Epoch 6 	 loss=0.01635 	 val_loss=0.02103 	 sm_loss=0.01648 	 sm_val_loss=0.02093 	 time=0.65s
# Best: Epoch 8 	 loss=0.01632 	 val_loss=0.02079 	 sm_loss=0.01646 	 sm_val_loss=0.02070 	 time=0.63s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 13 	 loss=0.01585 	 val_loss=0.02044 	 sm_loss=0.01600 	 sm_val_loss=0.02040 	 time=0.70s
# Fold 4 log loss: 0.020342750999288613
# Fold 5
# Best: Epoch 1 	 loss=0.02468 	 val_loss=0.01977 	 sm_loss=0.02473 	 sm_val_loss=0.01978 	 time=0.64s
# Best: Epoch 2 	 loss=0.01671 	 val_loss=0.01925 	 sm_loss=0.01680 	 sm_val_loss=0.01926 	 time=0.64s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01551 	 val_loss=0.01902 	 sm_loss=0.01567 	 sm_val_loss=0.01903 	 time=0.79s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01517 	 val_loss=0.01902 	 sm_loss=0.01535 	 sm_val_loss=0.01902 	 time=0.69s
# Fold 5 log loss: 0.019013702068929873
# Fold 6
# Best: Epoch 1 	 loss=0.02447 	 val_loss=0.02006 	 sm_loss=0.02452 	 sm_val_loss=0.02004 	 time=0.70s
# Best: Epoch 2 	 loss=0.01656 	 val_loss=0.01940 	 sm_loss=0.01664 	 sm_val_loss=0.01935 	 time=0.65s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01531 	 val_loss=0.01922 	 sm_loss=0.01547 	 sm_val_loss=0.01919 	 time=0.65s
# Best: Epoch 8 	 loss=0.01519 	 val_loss=0.01918 	 sm_loss=0.01535 	 sm_val_loss=0.01914 	 time=0.90s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01504 	 val_loss=0.01915 	 sm_loss=0.01523 	 sm_val_loss=0.01911 	 time=0.64s
# Fold 6 log loss: 0.01913483941768963
# Fold 7
# Best: Epoch 1 	 loss=0.02546 	 val_loss=0.02712 	 sm_loss=0.02549 	 sm_val_loss=0.02705 	 time=0.64s
# Best: Epoch 2 	 loss=0.01808 	 val_loss=0.02396 	 sm_loss=0.01814 	 sm_val_loss=0.02398 	 time=0.64s
# Best: Epoch 3 	 loss=0.01751 	 val_loss=0.02112 	 sm_loss=0.01760 	 sm_val_loss=0.02114 	 time=0.64s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 9 	 loss=0.01685 	 val_loss=0.02039 	 sm_loss=0.01699 	 sm_val_loss=0.02044 	 time=0.65s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 7 log loss: 0.02054616139402531
# Seed 4
# Fold 1 log loss: 0.018356682199431158
# Fold 2 log loss: 0.017371676245378134
# Fold 3 log loss: 0.021643043914116256
# Fold 4 log loss: 0.020342750999288613
# Fold 5 log loss: 0.019013702068929873
# Fold 6 log loss: 0.01913483941768963
# Fold 7 log loss: 0.02054616139402531
# Std of log loss: 0.0013417951148933258
# Total log loss: 0.019548200930937225
# Total log loss in targets: 0.019223209873159237

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6196597733897771

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.017716931649286168

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

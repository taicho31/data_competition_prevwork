# %% [markdown]
# - change validation method
# - also change seed when collecting files
# - 7 folds

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
drug = drug[drug.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 14

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[vc <= 18].index.sort_values()
vc2 = vc.loc[vc > 18].index.sort_values()

# STRATIFY DRUGS 18X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[0, 5, 3, ..., 6, 3, 0]], dtype=int8)

# %%
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
nontarget_dists.columns = ["target", "number"]
nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
print("first drop", len(drop_list1))
non_targets.drop(drop_list1, axis=1, inplace=True)
print("shape after 1st drop:", non_targets.shape)
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
print(len(non_target_feats))
# Out:
# first drop 71
# shape after 1st drop: (21948, 332)
# 331

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.7)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
len(drop_feats)

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 914) (3624, 914)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 1024))
        self.relu1 = nn.LeakyReLU()
        
        self.batch_norm2 = nn.BatchNorm1d(1024)
        self.dropout2 = nn.Dropout(0.1)
        self.dense2 = nn.utils.weight_norm(nn.Linear(1024, 1024))
        self.relu2 = nn.LeakyReLU()
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.1)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, last_num))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = self.relu1(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = self.relu2(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    if files == []:
        train_epochs = 10
        ans = []
    else:
        train_epochs = 15
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(X_test, dtype=torch.float32)
    X_test = torch.utils.data.TensorDataset(X_test) 
    test_loader = torch.utils.data.DataLoader(X_test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = X_train[:,-1] == fold
        train_index = X_train[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)

        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(non_target_feats)+len(target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            for param in clf.parameters():
                param.requires_grad = False
            # reinitialze
            clf.dense3 = nn.utils.weight_norm(nn.Linear(1024, len(target_feats)))
            for param in clf.dense3.parameters():
                param.requires_grad = True
            optimizer = optim.Adam(clf.parameters(), lr = 0.01, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, eps=1e-4, verbose=True)
            
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 0.001, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))
        
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                if files == []:
                    scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
            if files != []:
                scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Best: Epoch {} \t loss={:.5f} \t val_loss={:.5f} \t sm_loss={:.5f} \t sm_val_loss={:.5f} \t time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        if files == []:
            pred_model = MoaModel(init_num, len(non_target_feats)+len(target_feats))
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        if files != []:
            # test predcition --------------
            test_preds = np.zeros([test_len, y_train.shape[1]])
            for i, (x_batch,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
        
    print("Seed {}".format(sample_seed))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4] 
    
for seed_ in seeds:
    files = torch_tl(fn_train, fn_all_targets, fn_test, seed_, fn_train.shape[1]-1, [])
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Best: Epoch 1 	 loss=0.27767 	 val_loss=0.01171 	 sm_loss=0.27765 	 sm_val_loss=0.01171 	 time=1.70s
# Best: Epoch 2 	 loss=0.01113 	 val_loss=0.01036 	 sm_loss=0.01116 	 sm_val_loss=0.01043 	 time=0.89s
# Best: Epoch 4 	 loss=0.01027 	 val_loss=0.01016 	 sm_loss=0.01043 	 sm_val_loss=0.01020 	 time=0.88s
# Best: Epoch 5 	 loss=0.01022 	 val_loss=0.01006 	 sm_loss=0.01038 	 sm_val_loss=0.01014 	 time=0.91s
# Best: Epoch 6 	 loss=0.01012 	 val_loss=0.00998 	 sm_loss=0.01029 	 sm_val_loss=0.01006 	 time=0.90s
# Best: Epoch 7 	 loss=0.00998 	 val_loss=0.00984 	 sm_loss=0.01015 	 sm_val_loss=0.00991 	 time=0.89s
# Best: Epoch 8 	 loss=0.00979 	 val_loss=0.00974 	 sm_loss=0.00997 	 sm_val_loss=0.00981 	 time=1.06s
# Best: Epoch 9 	 loss=0.00948 	 val_loss=0.00967 	 sm_loss=0.00967 	 sm_val_loss=0.00975 	 time=1.46s
# Best: Epoch 10 	 loss=0.00924 	 val_loss=0.00966 	 sm_loss=0.00945 	 sm_val_loss=0.00973 	 time=0.99s
# Fold 1 log loss: 0.017525539298682394
# Fold 2
# Best: Epoch 1 	 loss=0.27902 	 val_loss=0.01155 	 sm_loss=0.27900 	 sm_val_loss=0.01155 	 time=0.88s
# Best: Epoch 2 	 loss=0.01120 	 val_loss=0.01037 	 sm_loss=0.01123 	 sm_val_loss=0.01043 	 time=0.88s
# Best: Epoch 3 	 loss=0.01045 	 val_loss=0.01034 	 sm_loss=0.01059 	 sm_val_loss=0.01034 	 time=1.16s
# Best: Epoch 5 	 loss=0.01020 	 val_loss=0.01017 	 sm_loss=0.01038 	 sm_val_loss=0.01024 	 time=0.86s
# Best: Epoch 6 	 loss=0.01012 	 val_loss=0.00997 	 sm_loss=0.01030 	 sm_val_loss=0.01003 	 time=0.89s
# Best: Epoch 7 	 loss=0.00996 	 val_loss=0.00987 	 sm_loss=0.01015 	 sm_val_loss=0.00991 	 time=0.91s
# Best: Epoch 8 	 loss=0.00973 	 val_loss=0.00974 	 sm_loss=0.00992 	 sm_val_loss=0.00980 	 time=1.15s
# Best: Epoch 9 	 loss=0.00944 	 val_loss=0.00960 	 sm_loss=0.00965 	 sm_val_loss=0.00966 	 time=0.87s
# Best: Epoch 10 	 loss=0.00920 	 val_loss=0.00959 	 sm_loss=0.00943 	 sm_val_loss=0.00965 	 time=0.87s
# Fold 2 log loss: 0.01667687023756815
# Fold 3
# Best: Epoch 1 	 loss=0.27889 	 val_loss=0.01195 	 sm_loss=0.27888 	 sm_val_loss=0.01194 	 time=0.87s
# Best: Epoch 2 	 loss=0.01103 	 val_loss=0.01094 	 sm_loss=0.01105 	 sm_val_loss=0.01098 	 time=0.90s
# Best: Epoch 4 	 loss=0.01019 	 val_loss=0.01078 	 sm_loss=0.01036 	 sm_val_loss=0.01083 	 time=0.85s
# Best: Epoch 5 	 loss=0.01009 	 val_loss=0.01066 	 sm_loss=0.01026 	 sm_val_loss=0.01071 	 time=0.87s
# Best: Epoch 6 	 loss=0.01004 	 val_loss=0.01061 	 sm_loss=0.01021 	 sm_val_loss=0.01066 	 time=0.89s
# Best: Epoch 7 	 loss=0.00987 	 val_loss=0.01050 	 sm_loss=0.01005 	 sm_val_loss=0.01056 	 time=0.89s
# Best: Epoch 8 	 loss=0.00963 	 val_loss=0.01031 	 sm_loss=0.00982 	 sm_val_loss=0.01038 	 time=1.04s
# Best: Epoch 9 	 loss=0.00934 	 val_loss=0.01024 	 sm_loss=0.00955 	 sm_val_loss=0.01032 	 time=1.40s
# Best: Epoch 10 	 loss=0.00910 	 val_loss=0.01022 	 sm_loss=0.00932 	 sm_val_loss=0.01029 	 time=0.88s
# Fold 3 log loss: 0.01745487408989468
# Fold 4
# Best: Epoch 1 	 loss=0.27888 	 val_loss=0.01192 	 sm_loss=0.27885 	 sm_val_loss=0.01192 	 time=0.89s
# Best: Epoch 2 	 loss=0.01099 	 val_loss=0.01075 	 sm_loss=0.01104 	 sm_val_loss=0.01075 	 time=0.87s
# Best: Epoch 3 	 loss=0.01046 	 val_loss=0.01065 	 sm_loss=0.01057 	 sm_val_loss=0.01069 	 time=0.86s
# Best: Epoch 4 	 loss=0.01024 	 val_loss=0.01048 	 sm_loss=0.01040 	 sm_val_loss=0.01050 	 time=0.86s
# Best: Epoch 5 	 loss=0.01017 	 val_loss=0.01043 	 sm_loss=0.01034 	 sm_val_loss=0.01046 	 time=0.87s
# Best: Epoch 6 	 loss=0.01006 	 val_loss=0.01033 	 sm_loss=0.01024 	 sm_val_loss=0.01037 	 time=0.87s
# Best: Epoch 7 	 loss=0.00991 	 val_loss=0.01024 	 sm_loss=0.01009 	 sm_val_loss=0.01029 	 time=0.89s
# Best: Epoch 8 	 loss=0.00972 	 val_loss=0.01011 	 sm_loss=0.00991 	 sm_val_loss=0.01015 	 time=1.01s
# Best: Epoch 9 	 loss=0.00942 	 val_loss=0.01000 	 sm_loss=0.00962 	 sm_val_loss=0.01004 	 time=1.03s
# Best: Epoch 10 	 loss=0.00918 	 val_loss=0.00998 	 sm_loss=0.00940 	 sm_val_loss=0.01002 	 time=0.87s
# Fold 4 log loss: 0.016917056884926215
# Fold 5
# Best: Epoch 1 	 loss=0.27884 	 val_loss=0.01245 	 sm_loss=0.27883 	 sm_val_loss=0.01245 	 time=0.89s
# Best: Epoch 2 	 loss=0.01106 	 val_loss=0.01123 	 sm_loss=0.01108 	 sm_val_loss=0.01128 	 time=0.89s
# Best: Epoch 3 	 loss=0.01029 	 val_loss=0.01086 	 sm_loss=0.01044 	 sm_val_loss=0.01087 	 time=0.88s
# Best: Epoch 5 	 loss=0.01010 	 val_loss=0.01081 	 sm_loss=0.01027 	 sm_val_loss=0.01083 	 time=0.88s
# Best: Epoch 6 	 loss=0.01004 	 val_loss=0.01073 	 sm_loss=0.01021 	 sm_val_loss=0.01074 	 time=0.88s
# Best: Epoch 7 	 loss=0.00990 	 val_loss=0.01067 	 sm_loss=0.01008 	 sm_val_loss=0.01069 	 time=0.87s
# Best: Epoch 8 	 loss=0.00969 	 val_loss=0.01041 	 sm_loss=0.00987 	 sm_val_loss=0.01045 	 time=0.87s
# Best: Epoch 9 	 loss=0.00938 	 val_loss=0.01033 	 sm_loss=0.00959 	 sm_val_loss=0.01038 	 time=1.14s
# Best: Epoch 10 	 loss=0.00916 	 val_loss=0.01029 	 sm_loss=0.00937 	 sm_val_loss=0.01033 	 time=0.87s
# Fold 5 log loss: 0.01669837615821958
# Fold 6
# Best: Epoch 1 	 loss=0.27933 	 val_loss=0.01256 	 sm_loss=0.27931 	 sm_val_loss=0.01256 	 time=0.89s
# Best: Epoch 2 	 loss=0.01089 	 val_loss=0.01256 	 sm_loss=0.01095 	 sm_val_loss=0.01204 	 time=0.88s
# Best: Epoch 3 	 loss=0.01032 	 val_loss=0.01110 	 sm_loss=0.01047 	 sm_val_loss=0.01110 	 time=0.86s
# Best: Epoch 5 	 loss=0.01004 	 val_loss=0.01089 	 sm_loss=0.01022 	 sm_val_loss=0.01092 	 time=0.88s
# Best: Epoch 7 	 loss=0.00980 	 val_loss=0.01078 	 sm_loss=0.00998 	 sm_val_loss=0.01079 	 time=0.86s
# Best: Epoch 8 	 loss=0.00957 	 val_loss=0.01058 	 sm_loss=0.00977 	 sm_val_loss=0.01062 	 time=0.87s
# Best: Epoch 9 	 loss=0.00929 	 val_loss=0.01050 	 sm_loss=0.00950 	 sm_val_loss=0.01053 	 time=1.31s
# Best: Epoch 10 	 loss=0.00905 	 val_loss=0.01048 	 sm_loss=0.00927 	 sm_val_loss=0.01051 	 time=0.98s
# Fold 6 log loss: 0.018137170872180877
# Fold 7
# Best: Epoch 1 	 loss=0.27965 	 val_loss=0.01204 	 sm_loss=0.27964 	 sm_val_loss=0.01204 	 time=0.88s
# Best: Epoch 2 	 loss=0.01111 	 val_loss=0.01088 	 sm_loss=0.01112 	 sm_val_loss=0.01092 	 time=0.88s
# Best: Epoch 3 	 loss=0.01028 	 val_loss=0.01076 	 sm_loss=0.01042 	 sm_val_loss=0.01081 	 time=0.86s
# Best: Epoch 4 	 loss=0.01016 	 val_loss=0.01068 	 sm_loss=0.01034 	 sm_val_loss=0.01071 	 time=1.13s
# Best: Epoch 6 	 loss=0.01005 	 val_loss=0.01062 	 sm_loss=0.01022 	 sm_val_loss=0.01065 	 time=0.90s
# Best: Epoch 7 	 loss=0.00986 	 val_loss=0.01046 	 sm_loss=0.01003 	 sm_val_loss=0.01049 	 time=1.09s
# Best: Epoch 8 	 loss=0.00965 	 val_loss=0.01037 	 sm_loss=0.00984 	 sm_val_loss=0.01040 	 time=0.94s
# Best: Epoch 9 	 loss=0.00935 	 val_loss=0.01021 	 sm_loss=0.00955 	 sm_val_loss=0.01026 	 time=0.91s
# Best: Epoch 10 	 loss=0.00912 	 val_loss=0.01020 	 sm_loss=0.00934 	 sm_val_loss=0.01024 	 time=1.08s
# Fold 7 log loss: 0.01746714726428423
# Seed 0
# Fold 1 log loss: 0.017525539298682394
# Fold 2 log loss: 0.01667687023756815
# Fold 3 log loss: 0.01745487408989468
# Fold 4 log loss: 0.016917056884926215
# Fold 5 log loss: 0.01669837615821958
# Fold 6 log loss: 0.018137170872180877
# Fold 7 log loss: 0.01746714726428423
# Std of log loss: 0.0004918525748868469
# Total log loss: 0.017269762129202677
# Fold 1
# Best: Epoch 1 	 loss=0.02494 	 val_loss=0.01818 	 sm_loss=0.02498 	 sm_val_loss=0.01820 	 time=0.57s
# Best: Epoch 2 	 loss=0.01700 	 val_loss=0.01761 	 sm_loss=0.01707 	 sm_val_loss=0.01765 	 time=0.59s
# Best: Epoch 3 	 loss=0.01625 	 val_loss=0.01764 	 sm_loss=0.01636 	 sm_val_loss=0.01765 	 time=0.61s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01570 	 val_loss=0.01738 	 sm_loss=0.01585 	 sm_val_loss=0.01742 	 time=0.60s
# Best: Epoch 8 	 loss=0.01552 	 val_loss=0.01732 	 sm_loss=0.01568 	 sm_val_loss=0.01735 	 time=0.58s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Fold 1 log loss: 0.01741855128191688
# Fold 2
# Best: Epoch 1 	 loss=0.02502 	 val_loss=0.01791 	 sm_loss=0.02506 	 sm_val_loss=0.01796 	 time=0.57s
# Best: Epoch 2 	 loss=0.01700 	 val_loss=0.01686 	 sm_loss=0.01707 	 sm_val_loss=0.01689 	 time=0.57s
# Best: Epoch 3 	 loss=0.01628 	 val_loss=0.01673 	 sm_loss=0.01638 	 sm_val_loss=0.01679 	 time=0.57s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01569 	 val_loss=0.01653 	 sm_loss=0.01585 	 sm_val_loss=0.01661 	 time=0.56s
# Best: Epoch 9 	 loss=0.01555 	 val_loss=0.01650 	 sm_loss=0.01572 	 sm_val_loss=0.01658 	 time=0.56s
# Best: Epoch 10 	 loss=0.01553 	 val_loss=0.01650 	 sm_loss=0.01570 	 sm_val_loss=0.01658 	 time=0.76s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 15 	 loss=0.01537 	 val_loss=0.01641 	 sm_loss=0.01555 	 sm_val_loss=0.01650 	 time=0.56s
# Fold 2 log loss: 0.016508568428869528
# Fold 3
# Best: Epoch 1 	 loss=0.02491 	 val_loss=0.01822 	 sm_loss=0.02495 	 sm_val_loss=0.01826 	 time=0.56s
# Best: Epoch 2 	 loss=0.01687 	 val_loss=0.01760 	 sm_loss=0.01695 	 sm_val_loss=0.01762 	 time=0.56s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01555 	 val_loss=0.01745 	 sm_loss=0.01570 	 sm_val_loss=0.01750 	 time=0.56s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01524 	 val_loss=0.01747 	 sm_loss=0.01542 	 sm_val_loss=0.01749 	 time=0.58s
# Best: Epoch 15 	 loss=0.01519 	 val_loss=0.01744 	 sm_loss=0.01537 	 sm_val_loss=0.01747 	 time=0.78s
# Fold 3 log loss: 0.017469309818501342
# Fold 4
# Best: Epoch 1 	 loss=0.02508 	 val_loss=0.01793 	 sm_loss=0.02513 	 sm_val_loss=0.01794 	 time=0.57s
# Best: Epoch 2 	 loss=0.01709 	 val_loss=0.01706 	 sm_loss=0.01717 	 sm_val_loss=0.01707 	 time=0.56s
# Best: Epoch 3 	 loss=0.01634 	 val_loss=0.01698 	 sm_loss=0.01644 	 sm_val_loss=0.01696 	 time=0.57s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01574 	 val_loss=0.01682 	 sm_loss=0.01589 	 sm_val_loss=0.01684 	 time=0.57s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01543 	 val_loss=0.01678 	 sm_loss=0.01561 	 sm_val_loss=0.01680 	 time=0.59s
# Best: Epoch 14 	 loss=0.01537 	 val_loss=0.01678 	 sm_loss=0.01554 	 sm_val_loss=0.01680 	 time=0.57s
# Best: Epoch 15 	 loss=0.01537 	 val_loss=0.01676 	 sm_loss=0.01554 	 sm_val_loss=0.01678 	 time=0.58s
# Fold 4 log loss: 0.016815323140307654
# Fold 5
# Best: Epoch 1 	 loss=0.02510 	 val_loss=0.01760 	 sm_loss=0.02514 	 sm_val_loss=0.01764 	 time=0.57s
# Best: Epoch 2 	 loss=0.01705 	 val_loss=0.01683 	 sm_loss=0.01712 	 sm_val_loss=0.01689 	 time=0.57s
# Best: Epoch 3 	 loss=0.01639 	 val_loss=0.01680 	 sm_loss=0.01650 	 sm_val_loss=0.01682 	 time=0.57s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01575 	 val_loss=0.01659 	 sm_loss=0.01591 	 sm_val_loss=0.01665 	 time=0.57s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01544 	 val_loss=0.01658 	 sm_loss=0.01561 	 sm_val_loss=0.01664 	 time=0.59s
# Fold 5 log loss: 0.016646283024479253
# Fold 6
# Best: Epoch 1 	 loss=0.02483 	 val_loss=0.01897 	 sm_loss=0.02487 	 sm_val_loss=0.01898 	 time=0.59s
# Best: Epoch 2 	 loss=0.01672 	 val_loss=0.01828 	 sm_loss=0.01679 	 sm_val_loss=0.01828 	 time=0.60s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01542 	 val_loss=0.01813 	 sm_loss=0.01558 	 sm_val_loss=0.01815 	 time=0.81s
# Best: Epoch 9 	 loss=0.01525 	 val_loss=0.01813 	 sm_loss=0.01542 	 sm_val_loss=0.01813 	 time=0.59s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 6 log loss: 0.018183089377560076
# Fold 7
# Best: Epoch 1 	 loss=0.02476 	 val_loss=0.01827 	 sm_loss=0.02481 	 sm_val_loss=0.01830 	 time=0.56s
# Best: Epoch 2 	 loss=0.01686 	 val_loss=0.01760 	 sm_loss=0.01694 	 sm_val_loss=0.01761 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01562 	 val_loss=0.01740 	 sm_loss=0.01578 	 sm_val_loss=0.01742 	 time=0.57s
# Best: Epoch 8 	 loss=0.01541 	 val_loss=0.01740 	 sm_loss=0.01558 	 sm_val_loss=0.01742 	 time=0.57s
# Best: Epoch 10 	 loss=0.01542 	 val_loss=0.01738 	 sm_loss=0.01559 	 sm_val_loss=0.01740 	 time=0.57s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 15 	 loss=0.01527 	 val_loss=0.01734 	 sm_loss=0.01545 	 sm_val_loss=0.01736 	 time=0.56s
# Fold 7 log loss: 0.017351607165287223
# Seed 0
# Fold 1 log loss: 0.01741855128191688
# Fold 2 log loss: 0.016508568428869528
# Fold 3 log loss: 0.017469309818501342
# Fold 4 log loss: 0.016815323140307654
# Fold 5 log loss: 0.016646283024479253
# Fold 6 log loss: 0.018183089377560076
# Fold 7 log loss: 0.017351607165287223
# Std of log loss: 0.0005401574830092992
# Total log loss: 0.01720065667657904
# Fold 1
# Best: Epoch 1 	 loss=0.27910 	 val_loss=0.01181 	 sm_loss=0.27908 	 sm_val_loss=0.01182 	 time=0.87s
# Best: Epoch 3 	 loss=0.01047 	 val_loss=0.01035 	 sm_loss=0.01061 	 sm_val_loss=0.01043 	 time=0.87s
# Best: Epoch 4 	 loss=0.01030 	 val_loss=0.01016 	 sm_loss=0.01047 	 sm_val_loss=0.01022 	 time=0.87s
# Best: Epoch 5 	 loss=0.01023 	 val_loss=0.01007 	 sm_loss=0.01040 	 sm_val_loss=0.01014 	 time=0.91s
# Best: Epoch 6 	 loss=0.01010 	 val_loss=0.00994 	 sm_loss=0.01027 	 sm_val_loss=0.01000 	 time=1.03s
# Best: Epoch 7 	 loss=0.00997 	 val_loss=0.00981 	 sm_loss=0.01015 	 sm_val_loss=0.00988 	 time=1.02s
# Best: Epoch 9 	 loss=0.00947 	 val_loss=0.00965 	 sm_loss=0.00967 	 sm_val_loss=0.00972 	 time=0.87s
# Fold 1 log loss: 0.017489984596119383
# Fold 2
# Best: Epoch 1 	 loss=0.27865 	 val_loss=0.01155 	 sm_loss=0.27863 	 sm_val_loss=0.01155 	 time=0.88s
# Best: Epoch 2 	 loss=0.01102 	 val_loss=0.01079 	 sm_loss=0.01107 	 sm_val_loss=0.01078 	 time=0.88s
# Best: Epoch 3 	 loss=0.01046 	 val_loss=0.01020 	 sm_loss=0.01059 	 sm_val_loss=0.01025 	 time=0.88s
# Best: Epoch 4 	 loss=0.01030 	 val_loss=0.01009 	 sm_loss=0.01047 	 sm_val_loss=0.01011 	 time=0.89s
# Best: Epoch 6 	 loss=0.01014 	 val_loss=0.00991 	 sm_loss=0.01031 	 sm_val_loss=0.00996 	 time=0.89s
# Best: Epoch 7 	 loss=0.00998 	 val_loss=0.00988 	 sm_loss=0.01016 	 sm_val_loss=0.00993 	 time=0.88s
# Best: Epoch 8 	 loss=0.00974 	 val_loss=0.00970 	 sm_loss=0.00993 	 sm_val_loss=0.00976 	 time=0.87s
# Best: Epoch 9 	 loss=0.00947 	 val_loss=0.00964 	 sm_loss=0.00967 	 sm_val_loss=0.00969 	 time=0.88s
# Best: Epoch 10 	 loss=0.00922 	 val_loss=0.00960 	 sm_loss=0.00944 	 sm_val_loss=0.00965 	 time=0.89s
# Fold 2 log loss: 0.016678516700999107
# Fold 3
# Best: Epoch 1 	 loss=0.27848 	 val_loss=0.01203 	 sm_loss=0.27846 	 sm_val_loss=0.01202 	 time=0.96s
# Best: Epoch 2 	 loss=0.01097 	 val_loss=0.01097 	 sm_loss=0.01101 	 sm_val_loss=0.01102 	 time=0.91s
# Best: Epoch 3 	 loss=0.01047 	 val_loss=0.01086 	 sm_loss=0.01058 	 sm_val_loss=0.01090 	 time=0.90s
# Best: Epoch 4 	 loss=0.01023 	 val_loss=0.01074 	 sm_loss=0.01039 	 sm_val_loss=0.01078 	 time=0.88s
# Best: Epoch 5 	 loss=0.01012 	 val_loss=0.01074 	 sm_loss=0.01029 	 sm_val_loss=0.01076 	 time=0.92s
# Best: Epoch 6 	 loss=0.01001 	 val_loss=0.01048 	 sm_loss=0.01019 	 sm_val_loss=0.01055 	 time=0.87s
# Best: Epoch 8 	 loss=0.00963 	 val_loss=0.01036 	 sm_loss=0.00982 	 sm_val_loss=0.01042 	 time=0.88s
# Best: Epoch 9 	 loss=0.00934 	 val_loss=0.01028 	 sm_loss=0.00955 	 sm_val_loss=0.01035 	 time=0.89s
# Best: Epoch 10 	 loss=0.00911 	 val_loss=0.01026 	 sm_loss=0.00933 	 sm_val_loss=0.01032 	 time=0.89s
# Fold 3 log loss: 0.01751946906587078
# Fold 4
# Best: Epoch 1 	 loss=0.28003 	 val_loss=0.01204 	 sm_loss=0.28001 	 sm_val_loss=0.01204 	 time=1.11s
# Best: Epoch 2 	 loss=0.01111 	 val_loss=0.01072 	 sm_loss=0.01113 	 sm_val_loss=0.01078 	 time=0.87s
# Best: Epoch 3 	 loss=0.01071 	 val_loss=0.01065 	 sm_loss=0.01080 	 sm_val_loss=0.01066 	 time=0.89s
# Best: Epoch 4 	 loss=0.01030 	 val_loss=0.01040 	 sm_loss=0.01047 	 sm_val_loss=0.01044 	 time=0.89s
# Best: Epoch 6 	 loss=0.01008 	 val_loss=0.01037 	 sm_loss=0.01026 	 sm_val_loss=0.01040 	 time=1.65s
# Best: Epoch 7 	 loss=0.00991 	 val_loss=0.01019 	 sm_loss=0.01009 	 sm_val_loss=0.01023 	 time=0.93s
# Best: Epoch 8 	 loss=0.00971 	 val_loss=0.01010 	 sm_loss=0.00991 	 sm_val_loss=0.01014 	 time=1.11s
# Best: Epoch 9 	 loss=0.00942 	 val_loss=0.01003 	 sm_loss=0.00962 	 sm_val_loss=0.01007 	 time=0.98s
# Best: Epoch 10 	 loss=0.00919 	 val_loss=0.00998 	 sm_loss=0.00941 	 sm_val_loss=0.01003 	 time=0.90s
# Fold 4 log loss: 0.016953514807968337
# Fold 5
# Best: Epoch 1 	 loss=0.27855 	 val_loss=0.01235 	 sm_loss=0.27850 	 sm_val_loss=0.01236 	 time=1.12s
# Best: Epoch 2 	 loss=0.01099 	 val_loss=0.01136 	 sm_loss=0.01100 	 sm_val_loss=0.01140 	 time=0.94s
# Best: Epoch 3 	 loss=0.01061 	 val_loss=0.01090 	 sm_loss=0.01071 	 sm_val_loss=0.01092 	 time=0.90s
# Best: Epoch 4 	 loss=0.01022 	 val_loss=0.01083 	 sm_loss=0.01039 	 sm_val_loss=0.01087 	 time=0.87s
# Best: Epoch 5 	 loss=0.01018 	 val_loss=0.01082 	 sm_loss=0.01034 	 sm_val_loss=0.01085 	 time=0.88s
# Best: Epoch 6 	 loss=0.01004 	 val_loss=0.01070 	 sm_loss=0.01022 	 sm_val_loss=0.01070 	 time=0.87s
# Best: Epoch 7 	 loss=0.00989 	 val_loss=0.01056 	 sm_loss=0.01008 	 sm_val_loss=0.01059 	 time=0.90s
# Best: Epoch 8 	 loss=0.00967 	 val_loss=0.01046 	 sm_loss=0.00987 	 sm_val_loss=0.01051 	 time=0.88s
# Best: Epoch 9 	 loss=0.00942 	 val_loss=0.01032 	 sm_loss=0.00962 	 sm_val_loss=0.01036 	 time=0.88s
# Best: Epoch 10 	 loss=0.00919 	 val_loss=0.01031 	 sm_loss=0.00941 	 sm_val_loss=0.01036 	 time=0.87s
# Fold 5 log loss: 0.01677274869965345
# Fold 6
# Best: Epoch 1 	 loss=0.28047 	 val_loss=0.01247 	 sm_loss=0.28045 	 sm_val_loss=0.01246 	 time=1.01s
# Best: Epoch 3 	 loss=0.01026 	 val_loss=0.01111 	 sm_loss=0.01043 	 sm_val_loss=0.01101 	 time=0.86s
# Best: Epoch 4 	 loss=0.01010 	 val_loss=0.01096 	 sm_loss=0.01028 	 sm_val_loss=0.01095 	 time=0.91s
# Best: Epoch 6 	 loss=0.00995 	 val_loss=0.01080 	 sm_loss=0.01014 	 sm_val_loss=0.01083 	 time=0.86s
# Best: Epoch 7 	 loss=0.00979 	 val_loss=0.01069 	 sm_loss=0.00999 	 sm_val_loss=0.01071 	 time=0.88s
# Best: Epoch 8 	 loss=0.00954 	 val_loss=0.01062 	 sm_loss=0.00974 	 sm_val_loss=0.01065 	 time=0.88s
# Best: Epoch 9 	 loss=0.00924 	 val_loss=0.01049 	 sm_loss=0.00946 	 sm_val_loss=0.01053 	 time=0.88s
# Best: Epoch 10 	 loss=0.00902 	 val_loss=0.01046 	 sm_loss=0.00925 	 sm_val_loss=0.01050 	 time=0.89s
# Fold 6 log loss: 0.01810762811791369
# Fold 7
# Best: Epoch 1 	 loss=0.27989 	 val_loss=0.01205 	 sm_loss=0.27987 	 sm_val_loss=0.01204 	 time=1.05s
# Best: Epoch 2 	 loss=0.01103 	 val_loss=0.01121 	 sm_loss=0.01105 	 sm_val_loss=0.01124 	 time=1.00s
# Best: Epoch 3 	 loss=0.01040 	 val_loss=0.01072 	 sm_loss=0.01054 	 sm_val_loss=0.01074 	 time=0.98s
# Best: Epoch 4 	 loss=0.01017 	 val_loss=0.01072 	 sm_loss=0.01034 	 sm_val_loss=0.01074 	 time=0.93s
# Best: Epoch 6 	 loss=0.00998 	 val_loss=0.01059 	 sm_loss=0.01016 	 sm_val_loss=0.01062 	 time=1.02s
# Best: Epoch 7 	 loss=0.00985 	 val_loss=0.01045 	 sm_loss=0.01004 	 sm_val_loss=0.01048 	 time=0.94s
# Best: Epoch 8 	 loss=0.00960 	 val_loss=0.01039 	 sm_loss=0.00980 	 sm_val_loss=0.01042 	 time=0.93s
# Best: Epoch 9 	 loss=0.00935 	 val_loss=0.01021 	 sm_loss=0.00956 	 sm_val_loss=0.01026 	 time=0.93s
# Best: Epoch 10 	 loss=0.00908 	 val_loss=0.01020 	 sm_loss=0.00930 	 sm_val_loss=0.01024 	 time=0.87s
# Fold 7 log loss: 0.017456015893588455
# Seed 1
# Fold 1 log loss: 0.017489984596119383
# Fold 2 log loss: 0.016678516700999107
# Fold 3 log loss: 0.01751946906587078
# Fold 4 log loss: 0.016953514807968337
# Fold 5 log loss: 0.01677274869965345
# Fold 6 log loss: 0.01810762811791369
# Fold 7 log loss: 0.017456015893588455
# Std of log loss: 0.0004695015323206277
# Total log loss: 0.01728412196015036
# Fold 1
# Best: Epoch 1 	 loss=0.02488 	 val_loss=0.01822 	 sm_loss=0.02492 	 sm_val_loss=0.01825 	 time=0.57s
# Best: Epoch 2 	 loss=0.01700 	 val_loss=0.01749 	 sm_loss=0.01708 	 sm_val_loss=0.01753 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01572 	 val_loss=0.01735 	 sm_loss=0.01587 	 sm_val_loss=0.01739 	 time=0.57s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01539 	 val_loss=0.01735 	 sm_loss=0.01557 	 sm_val_loss=0.01739 	 time=0.58s
# Fold 1 log loss: 0.017456545480830594
# Fold 2
# Best: Epoch 1 	 loss=0.02521 	 val_loss=0.01793 	 sm_loss=0.02525 	 sm_val_loss=0.01796 	 time=0.72s
# Best: Epoch 2 	 loss=0.01706 	 val_loss=0.01687 	 sm_loss=0.01713 	 sm_val_loss=0.01691 	 time=0.63s
# Best: Epoch 3 	 loss=0.01637 	 val_loss=0.01681 	 sm_loss=0.01648 	 sm_val_loss=0.01688 	 time=0.59s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01578 	 val_loss=0.01650 	 sm_loss=0.01594 	 sm_val_loss=0.01658 	 time=0.59s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01545 	 val_loss=0.01646 	 sm_loss=0.01563 	 sm_val_loss=0.01654 	 time=0.57s
# Fold 2 log loss: 0.016549527346201985
# Fold 3
# Best: Epoch 1 	 loss=0.02483 	 val_loss=0.01828 	 sm_loss=0.02487 	 sm_val_loss=0.01830 	 time=0.58s
# Best: Epoch 2 	 loss=0.01686 	 val_loss=0.01767 	 sm_loss=0.01694 	 sm_val_loss=0.01766 	 time=0.79s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01560 	 val_loss=0.01750 	 sm_loss=0.01576 	 sm_val_loss=0.01753 	 time=0.58s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01528 	 val_loss=0.01751 	 sm_loss=0.01546 	 sm_val_loss=0.01752 	 time=0.61s
# Fold 3 log loss: 0.017522234741821966
# Fold 4
# Best: Epoch 1 	 loss=0.02518 	 val_loss=0.01787 	 sm_loss=0.02523 	 sm_val_loss=0.01788 	 time=0.71s
# Best: Epoch 2 	 loss=0.01704 	 val_loss=0.01707 	 sm_loss=0.01711 	 sm_val_loss=0.01709 	 time=0.59s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01577 	 val_loss=0.01686 	 sm_loss=0.01593 	 sm_val_loss=0.01687 	 time=0.55s
# Best: Epoch 9 	 loss=0.01561 	 val_loss=0.01682 	 sm_loss=0.01577 	 sm_val_loss=0.01684 	 time=0.56s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01544 	 val_loss=0.01679 	 sm_loss=0.01562 	 sm_val_loss=0.01681 	 time=0.56s
# Best: Epoch 15 	 loss=0.01538 	 val_loss=0.01677 	 sm_loss=0.01556 	 sm_val_loss=0.01680 	 time=0.58s
# Fold 4 log loss: 0.0168345827202616
# Fold 5
# Best: Epoch 1 	 loss=0.02499 	 val_loss=0.01751 	 sm_loss=0.02503 	 sm_val_loss=0.01755 	 time=0.56s
# Best: Epoch 2 	 loss=0.01708 	 val_loss=0.01691 	 sm_loss=0.01715 	 sm_val_loss=0.01694 	 time=0.83s
# Best: Epoch 3 	 loss=0.01642 	 val_loss=0.01688 	 sm_loss=0.01653 	 sm_val_loss=0.01691 	 time=0.56s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01590 	 val_loss=0.01671 	 sm_loss=0.01606 	 sm_val_loss=0.01677 	 time=0.56s
# Best: Epoch 9 	 loss=0.01572 	 val_loss=0.01668 	 sm_loss=0.01588 	 sm_val_loss=0.01674 	 time=0.57s
# Best: Epoch 10 	 loss=0.01568 	 val_loss=0.01665 	 sm_loss=0.01584 	 sm_val_loss=0.01671 	 time=0.57s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Fold 5 log loss: 0.01672343266704386
# Fold 6
# Best: Epoch 1 	 loss=0.02467 	 val_loss=0.01899 	 sm_loss=0.02472 	 sm_val_loss=0.01900 	 time=0.61s
# Best: Epoch 2 	 loss=0.01670 	 val_loss=0.01833 	 sm_loss=0.01678 	 sm_val_loss=0.01831 	 time=0.58s
# Best: Epoch 3 	 loss=0.01596 	 val_loss=0.01831 	 sm_loss=0.01608 	 sm_val_loss=0.01830 	 time=0.77s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01534 	 val_loss=0.01809 	 sm_loss=0.01552 	 sm_val_loss=0.01809 	 time=0.58s
# Best: Epoch 9 	 loss=0.01522 	 val_loss=0.01807 	 sm_loss=0.01540 	 sm_val_loss=0.01808 	 time=0.56s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Fold 6 log loss: 0.018133947749316964
# Fold 7
# Best: Epoch 1 	 loss=0.02484 	 val_loss=0.01830 	 sm_loss=0.02488 	 sm_val_loss=0.01834 	 time=0.58s
# Best: Epoch 2 	 loss=0.01682 	 val_loss=0.01775 	 sm_loss=0.01690 	 sm_val_loss=0.01775 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01553 	 val_loss=0.01745 	 sm_loss=0.01570 	 sm_val_loss=0.01745 	 time=0.58s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01520 	 val_loss=0.01741 	 sm_loss=0.01538 	 sm_val_loss=0.01742 	 time=0.57s
# Best: Epoch 13 	 loss=0.01514 	 val_loss=0.01739 	 sm_loss=0.01532 	 sm_val_loss=0.01741 	 time=0.57s
# Best: Epoch 14 	 loss=0.01516 	 val_loss=0.01738 	 sm_loss=0.01535 	 sm_val_loss=0.01740 	 time=0.58s
# Fold 7 log loss: 0.017382823789132106
# Seed 1
# Fold 1 log loss: 0.017456545480830594
# Fold 2 log loss: 0.016549527346201985
# Fold 3 log loss: 0.017522234741821966
# Fold 4 log loss: 0.0168345827202616
# Fold 5 log loss: 0.01672343266704386
# Fold 6 log loss: 0.018133947749316964
# Fold 7 log loss: 0.017382823789132106
# Std of log loss: 0.000514531985878839
# Total log loss: 0.01723055257454192
# Fold 1
# Best: Epoch 1 	 loss=0.27820 	 val_loss=0.01190 	 sm_loss=0.27818 	 sm_val_loss=0.01191 	 time=0.87s
# Best: Epoch 2 	 loss=0.01329 	 val_loss=0.01108 	 sm_loss=0.01325 	 sm_val_loss=0.01112 	 time=1.11s
# Best: Epoch 3 	 loss=0.01130 	 val_loss=0.01068 	 sm_loss=0.01140 	 sm_val_loss=0.01071 	 time=0.89s
# Best: Epoch 4 	 loss=0.01077 	 val_loss=0.01061 	 sm_loss=0.01092 	 sm_val_loss=0.01065 	 time=0.89s
# Best: Epoch 5 	 loss=0.01045 	 val_loss=0.01027 	 sm_loss=0.01062 	 sm_val_loss=0.01030 	 time=0.87s
# Best: Epoch 6 	 loss=0.01029 	 val_loss=0.01007 	 sm_loss=0.01047 	 sm_val_loss=0.01013 	 time=1.28s
# Best: Epoch 7 	 loss=0.01011 	 val_loss=0.00998 	 sm_loss=0.01029 	 sm_val_loss=0.01005 	 time=1.19s
# Best: Epoch 8 	 loss=0.00988 	 val_loss=0.00993 	 sm_loss=0.01007 	 sm_val_loss=0.00998 	 time=0.96s
# Best: Epoch 9 	 loss=0.00961 	 val_loss=0.00976 	 sm_loss=0.00981 	 sm_val_loss=0.00984 	 time=0.91s
# Best: Epoch 10 	 loss=0.00939 	 val_loss=0.00975 	 sm_loss=0.00961 	 sm_val_loss=0.00982 	 time=0.94s
# Fold 1 log loss: 0.017708503444669624
# Fold 2
# Best: Epoch 1 	 loss=0.27898 	 val_loss=0.01180 	 sm_loss=0.27896 	 sm_val_loss=0.01180 	 time=0.94s
# Best: Epoch 2 	 loss=0.01115 	 val_loss=0.01044 	 sm_loss=0.01115 	 sm_val_loss=0.01048 	 time=1.54s
# Best: Epoch 3 	 loss=0.01042 	 val_loss=0.01031 	 sm_loss=0.01056 	 sm_val_loss=0.01035 	 time=0.91s
# Best: Epoch 4 	 loss=0.01031 	 val_loss=0.01021 	 sm_loss=0.01047 	 sm_val_loss=0.01027 	 time=0.87s
# Best: Epoch 5 	 loss=0.01023 	 val_loss=0.01008 	 sm_loss=0.01041 	 sm_val_loss=0.01015 	 time=0.90s
# Best: Epoch 6 	 loss=0.01013 	 val_loss=0.01003 	 sm_loss=0.01030 	 sm_val_loss=0.01008 	 time=0.86s
# Best: Epoch 7 	 loss=0.00997 	 val_loss=0.00985 	 sm_loss=0.01015 	 sm_val_loss=0.00990 	 time=0.88s
# Best: Epoch 8 	 loss=0.00974 	 val_loss=0.00976 	 sm_loss=0.00993 	 sm_val_loss=0.00981 	 time=0.87s
# Best: Epoch 9 	 loss=0.00946 	 val_loss=0.00966 	 sm_loss=0.00966 	 sm_val_loss=0.00972 	 time=0.88s
# Best: Epoch 10 	 loss=0.00922 	 val_loss=0.00963 	 sm_loss=0.00944 	 sm_val_loss=0.00968 	 time=0.90s
# Fold 2 log loss: 0.016772500883006337
# Fold 3
# Best: Epoch 1 	 loss=0.27877 	 val_loss=0.01187 	 sm_loss=0.27876 	 sm_val_loss=0.01187 	 time=1.04s
# Best: Epoch 2 	 loss=0.01140 	 val_loss=0.01109 	 sm_loss=0.01138 	 sm_val_loss=0.01113 	 time=0.98s
# Best: Epoch 3 	 loss=0.01039 	 val_loss=0.01090 	 sm_loss=0.01054 	 sm_val_loss=0.01098 	 time=0.89s
# Best: Epoch 4 	 loss=0.01018 	 val_loss=0.01086 	 sm_loss=0.01035 	 sm_val_loss=0.01091 	 time=0.88s
# Best: Epoch 5 	 loss=0.01008 	 val_loss=0.01062 	 sm_loss=0.01026 	 sm_val_loss=0.01067 	 time=0.90s
# Best: Epoch 6 	 loss=0.00997 	 val_loss=0.01051 	 sm_loss=0.01015 	 sm_val_loss=0.01056 	 time=0.90s
# Best: Epoch 8 	 loss=0.00954 	 val_loss=0.01033 	 sm_loss=0.00974 	 sm_val_loss=0.01041 	 time=0.87s
# Best: Epoch 9 	 loss=0.00927 	 val_loss=0.01024 	 sm_loss=0.00948 	 sm_val_loss=0.01032 	 time=0.89s
# Best: Epoch 10 	 loss=0.00901 	 val_loss=0.01023 	 sm_loss=0.00923 	 sm_val_loss=0.01030 	 time=0.89s
# Fold 3 log loss: 0.017498424729162066
# Fold 4
# Best: Epoch 1 	 loss=0.27939 	 val_loss=0.01210 	 sm_loss=0.27936 	 sm_val_loss=0.01210 	 time=0.90s
# Best: Epoch 2 	 loss=0.01115 	 val_loss=0.01065 	 sm_loss=0.01116 	 sm_val_loss=0.01069 	 time=1.10s
# Best: Epoch 3 	 loss=0.01046 	 val_loss=0.01060 	 sm_loss=0.01059 	 sm_val_loss=0.01060 	 time=0.88s
# Best: Epoch 5 	 loss=0.01016 	 val_loss=0.01039 	 sm_loss=0.01033 	 sm_val_loss=0.01042 	 time=0.88s
# Best: Epoch 6 	 loss=0.01005 	 val_loss=0.01034 	 sm_loss=0.01023 	 sm_val_loss=0.01036 	 time=0.89s
# Best: Epoch 7 	 loss=0.00989 	 val_loss=0.01023 	 sm_loss=0.01008 	 sm_val_loss=0.01026 	 time=0.87s
# Best: Epoch 8 	 loss=0.00967 	 val_loss=0.01011 	 sm_loss=0.00987 	 sm_val_loss=0.01015 	 time=0.88s
# Best: Epoch 9 	 loss=0.00937 	 val_loss=0.01001 	 sm_loss=0.00958 	 sm_val_loss=0.01005 	 time=0.89s
# Best: Epoch 10 	 loss=0.00913 	 val_loss=0.00999 	 sm_loss=0.00935 	 sm_val_loss=0.01003 	 time=0.88s
# Fold 4 log loss: 0.01691599389140479
# Fold 5
# Best: Epoch 1 	 loss=0.27882 	 val_loss=0.01233 	 sm_loss=0.27880 	 sm_val_loss=0.01233 	 time=0.88s
# Best: Epoch 2 	 loss=0.01098 	 val_loss=0.01099 	 sm_loss=0.01100 	 sm_val_loss=0.01103 	 time=1.20s
# Best: Epoch 4 	 loss=0.01021 	 val_loss=0.01081 	 sm_loss=0.01040 	 sm_val_loss=0.01081 	 time=0.87s
# Best: Epoch 5 	 loss=0.01012 	 val_loss=0.01072 	 sm_loss=0.01031 	 sm_val_loss=0.01074 	 time=0.91s
# Best: Epoch 6 	 loss=0.01000 	 val_loss=0.01061 	 sm_loss=0.01019 	 sm_val_loss=0.01065 	 time=0.87s
# Best: Epoch 7 	 loss=0.00987 	 val_loss=0.01054 	 sm_loss=0.01006 	 sm_val_loss=0.01057 	 time=0.88s
# Best: Epoch 8 	 loss=0.00964 	 val_loss=0.01036 	 sm_loss=0.00984 	 sm_val_loss=0.01041 	 time=0.88s
# Best: Epoch 9 	 loss=0.00936 	 val_loss=0.01032 	 sm_loss=0.00957 	 sm_val_loss=0.01037 	 time=0.87s
# Best: Epoch 10 	 loss=0.00914 	 val_loss=0.01030 	 sm_loss=0.00936 	 sm_val_loss=0.01034 	 time=0.89s
# Fold 5 log loss: 0.01671921285154072
# Fold 6
# Best: Epoch 1 	 loss=0.27957 	 val_loss=0.01218 	 sm_loss=0.27956 	 sm_val_loss=0.01218 	 time=0.87s
# Best: Epoch 2 	 loss=0.01100 	 val_loss=0.01116 	 sm_loss=0.01105 	 sm_val_loss=0.01114 	 time=0.88s
# Best: Epoch 4 	 loss=0.01016 	 val_loss=0.01106 	 sm_loss=0.01034 	 sm_val_loss=0.01102 	 time=0.91s
# Best: Epoch 5 	 loss=0.01012 	 val_loss=0.01100 	 sm_loss=0.01029 	 sm_val_loss=0.01101 	 time=0.87s
# Best: Epoch 6 	 loss=0.01001 	 val_loss=0.01084 	 sm_loss=0.01019 	 sm_val_loss=0.01085 	 time=0.96s
# Best: Epoch 7 	 loss=0.00987 	 val_loss=0.01071 	 sm_loss=0.01005 	 sm_val_loss=0.01073 	 time=0.87s
# Best: Epoch 8 	 loss=0.00963 	 val_loss=0.01054 	 sm_loss=0.00982 	 sm_val_loss=0.01057 	 time=0.89s
# Best: Epoch 9 	 loss=0.00934 	 val_loss=0.01047 	 sm_loss=0.00955 	 sm_val_loss=0.01051 	 time=0.87s
# Best: Epoch 10 	 loss=0.00911 	 val_loss=0.01044 	 sm_loss=0.00934 	 sm_val_loss=0.01048 	 time=0.88s
# Fold 6 log loss: 0.01807772963673037
# Fold 7
# Best: Epoch 1 	 loss=0.27952 	 val_loss=0.01179 	 sm_loss=0.27949 	 sm_val_loss=0.01179 	 time=1.23s
# Best: Epoch 2 	 loss=0.01097 	 val_loss=0.01114 	 sm_loss=0.01099 	 sm_val_loss=0.01117 	 time=0.88s
# Best: Epoch 3 	 loss=0.01028 	 val_loss=0.01084 	 sm_loss=0.01043 	 sm_val_loss=0.01088 	 time=0.90s
# Best: Epoch 4 	 loss=0.01015 	 val_loss=0.01065 	 sm_loss=0.01032 	 sm_val_loss=0.01070 	 time=1.21s
# Best: Epoch 6 	 loss=0.01001 	 val_loss=0.01063 	 sm_loss=0.01019 	 sm_val_loss=0.01066 	 time=0.87s
# Best: Epoch 7 	 loss=0.00986 	 val_loss=0.01049 	 sm_loss=0.01004 	 sm_val_loss=0.01053 	 time=0.95s
# Best: Epoch 8 	 loss=0.00964 	 val_loss=0.01034 	 sm_loss=0.00983 	 sm_val_loss=0.01036 	 time=0.87s
# Best: Epoch 9 	 loss=0.00932 	 val_loss=0.01021 	 sm_loss=0.00953 	 sm_val_loss=0.01025 	 time=0.87s
# Best: Epoch 10 	 loss=0.00910 	 val_loss=0.01019 	 sm_loss=0.00932 	 sm_val_loss=0.01023 	 time=0.95s
# Fold 7 log loss: 0.017413921542736095
# Seed 2
# Fold 1 log loss: 0.017708503444669624
# Fold 2 log loss: 0.016772500883006337
# Fold 3 log loss: 0.017498424729162066
# Fold 4 log loss: 0.01691599389140479
# Fold 5 log loss: 0.01671921285154072
# Fold 6 log loss: 0.01807772963673037
# Fold 7 log loss: 0.017413921542736095
# Std of log loss: 0.00047616218999925924
# Total log loss: 0.017302321688719823
# Fold 1
# Best: Epoch 1 	 loss=0.02476 	 val_loss=0.01820 	 sm_loss=0.02481 	 sm_val_loss=0.01823 	 time=0.81s
# Best: Epoch 2 	 loss=0.01708 	 val_loss=0.01777 	 sm_loss=0.01717 	 sm_val_loss=0.01779 	 time=0.86s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01591 	 val_loss=0.01762 	 sm_loss=0.01607 	 sm_val_loss=0.01766 	 time=0.56s
# Best: Epoch 9 	 loss=0.01579 	 val_loss=0.01757 	 sm_loss=0.01596 	 sm_val_loss=0.01760 	 time=0.56s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01560 	 val_loss=0.01752 	 sm_loss=0.01578 	 sm_val_loss=0.01758 	 time=0.56s
# Fold 1 log loss: 0.01764233302147703
# Fold 2
# Best: Epoch 1 	 loss=0.02496 	 val_loss=0.01791 	 sm_loss=0.02501 	 sm_val_loss=0.01794 	 time=0.57s
# Best: Epoch 2 	 loss=0.01700 	 val_loss=0.01693 	 sm_loss=0.01707 	 sm_val_loss=0.01696 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01577 	 val_loss=0.01661 	 sm_loss=0.01593 	 sm_val_loss=0.01668 	 time=0.65s
# Best: Epoch 8 	 loss=0.01558 	 val_loss=0.01658 	 sm_loss=0.01574 	 sm_val_loss=0.01664 	 time=0.57s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01539 	 val_loss=0.01656 	 sm_loss=0.01556 	 sm_val_loss=0.01662 	 time=0.56s
# Best: Epoch 14 	 loss=0.01536 	 val_loss=0.01653 	 sm_loss=0.01553 	 sm_val_loss=0.01660 	 time=0.56s
# Best: Epoch 15 	 loss=0.01535 	 val_loss=0.01651 	 sm_loss=0.01553 	 sm_val_loss=0.01658 	 time=0.59s
# Fold 2 log loss: 0.016588588873051594
# Fold 3
# Best: Epoch 1 	 loss=0.02488 	 val_loss=0.01821 	 sm_loss=0.02493 	 sm_val_loss=0.01823 	 time=0.59s
# Best: Epoch 2 	 loss=0.01673 	 val_loss=0.01769 	 sm_loss=0.01681 	 sm_val_loss=0.01772 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01532 	 val_loss=0.01751 	 sm_loss=0.01550 	 sm_val_loss=0.01753 	 time=0.57s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01502 	 val_loss=0.01744 	 sm_loss=0.01522 	 sm_val_loss=0.01748 	 time=0.57s
# Fold 3 log loss: 0.0174826588647644
# Fold 4
# Best: Epoch 1 	 loss=0.02497 	 val_loss=0.01778 	 sm_loss=0.02501 	 sm_val_loss=0.01779 	 time=0.61s
# Best: Epoch 2 	 loss=0.01695 	 val_loss=0.01704 	 sm_loss=0.01702 	 sm_val_loss=0.01704 	 time=0.80s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01563 	 val_loss=0.01681 	 sm_loss=0.01580 	 sm_val_loss=0.01682 	 time=0.59s
# Best: Epoch 8 	 loss=0.01548 	 val_loss=0.01677 	 sm_loss=0.01565 	 sm_val_loss=0.01679 	 time=0.57s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01528 	 val_loss=0.01676 	 sm_loss=0.01547 	 sm_val_loss=0.01678 	 time=0.56s
# Best: Epoch 15 	 loss=0.01527 	 val_loss=0.01675 	 sm_loss=0.01545 	 sm_val_loss=0.01678 	 time=0.56s
# Fold 4 log loss: 0.016808594399909223
# Fold 5
# Best: Epoch 1 	 loss=0.02497 	 val_loss=0.01754 	 sm_loss=0.02501 	 sm_val_loss=0.01757 	 time=0.57s
# Best: Epoch 2 	 loss=0.01698 	 val_loss=0.01687 	 sm_loss=0.01706 	 sm_val_loss=0.01691 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01573 	 val_loss=0.01665 	 sm_loss=0.01589 	 sm_val_loss=0.01671 	 time=0.64s
# Best: Epoch 8 	 loss=0.01558 	 val_loss=0.01665 	 sm_loss=0.01575 	 sm_val_loss=0.01670 	 time=0.57s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01542 	 val_loss=0.01660 	 sm_loss=0.01560 	 sm_val_loss=0.01665 	 time=0.59s
# Fold 5 log loss: 0.016659150281827934
# Fold 6
# Best: Epoch 1 	 loss=0.02483 	 val_loss=0.01903 	 sm_loss=0.02488 	 sm_val_loss=0.01902 	 time=0.58s
# Best: Epoch 2 	 loss=0.01678 	 val_loss=0.01823 	 sm_loss=0.01686 	 sm_val_loss=0.01824 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01549 	 val_loss=0.01812 	 sm_loss=0.01565 	 sm_val_loss=0.01811 	 time=0.68s
# Best: Epoch 9 	 loss=0.01533 	 val_loss=0.01810 	 sm_loss=0.01551 	 sm_val_loss=0.01810 	 time=0.56s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 15 	 loss=0.01517 	 val_loss=0.01804 	 sm_loss=0.01535 	 sm_val_loss=0.01806 	 time=0.56s
# Fold 6 log loss: 0.01810613292808204
# Fold 7
# Best: Epoch 1 	 loss=0.02501 	 val_loss=0.01824 	 sm_loss=0.02505 	 sm_val_loss=0.01827 	 time=0.65s
# Best: Epoch 2 	 loss=0.01679 	 val_loss=0.01768 	 sm_loss=0.01686 	 sm_val_loss=0.01770 	 time=0.79s
# Best: Epoch 3 	 loss=0.01610 	 val_loss=0.01767 	 sm_loss=0.01621 	 sm_val_loss=0.01770 	 time=0.57s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01550 	 val_loss=0.01743 	 sm_loss=0.01567 	 sm_val_loss=0.01746 	 time=0.56s
# Best: Epoch 9 	 loss=0.01535 	 val_loss=0.01740 	 sm_loss=0.01552 	 sm_val_loss=0.01742 	 time=0.57s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01519 	 val_loss=0.01738 	 sm_loss=0.01537 	 sm_val_loss=0.01741 	 time=0.57s
# Fold 7 log loss: 0.017397744629246484
# Seed 2
# Fold 1 log loss: 0.01764233302147703
# Fold 2 log loss: 0.016588588873051594
# Fold 3 log loss: 0.0174826588647644
# Fold 4 log loss: 0.016808594399909223
# Fold 5 log loss: 0.016659150281827934
# Fold 6 log loss: 0.01810613292808204
# Fold 7 log loss: 0.017397744629246484
# Std of log loss: 0.0005269392182179453
# Total log loss: 0.01724217271869575
# Fold 1
# Best: Epoch 1 	 loss=0.27830 	 val_loss=0.01163 	 sm_loss=0.27828 	 sm_val_loss=0.01164 	 time=0.88s
# Best: Epoch 2 	 loss=0.01108 	 val_loss=0.01055 	 sm_loss=0.01111 	 sm_val_loss=0.01060 	 time=0.96s
# Best: Epoch 3 	 loss=0.01065 	 val_loss=0.01018 	 sm_loss=0.01076 	 sm_val_loss=0.01021 	 time=0.89s
# Best: Epoch 4 	 loss=0.01033 	 val_loss=0.01011 	 sm_loss=0.01050 	 sm_val_loss=0.01018 	 time=1.13s
# Best: Epoch 6 	 loss=0.01015 	 val_loss=0.00997 	 sm_loss=0.01031 	 sm_val_loss=0.01002 	 time=0.87s
# Best: Epoch 7 	 loss=0.00997 	 val_loss=0.00987 	 sm_loss=0.01015 	 sm_val_loss=0.00993 	 time=0.91s
# Best: Epoch 8 	 loss=0.00975 	 val_loss=0.00973 	 sm_loss=0.00994 	 sm_val_loss=0.00981 	 time=0.89s
# Best: Epoch 9 	 loss=0.00949 	 val_loss=0.00968 	 sm_loss=0.00969 	 sm_val_loss=0.00975 	 time=0.89s
# Best: Epoch 10 	 loss=0.00927 	 val_loss=0.00965 	 sm_loss=0.00948 	 sm_val_loss=0.00972 	 time=0.88s
# Fold 1 log loss: 0.01751819482232092
# Fold 2
# Best: Epoch 1 	 loss=0.28045 	 val_loss=0.01190 	 sm_loss=0.28042 	 sm_val_loss=0.01190 	 time=0.87s
# Best: Epoch 2 	 loss=0.01114 	 val_loss=0.01039 	 sm_loss=0.01117 	 sm_val_loss=0.01044 	 time=0.88s
# Best: Epoch 4 	 loss=0.01033 	 val_loss=0.01008 	 sm_loss=0.01050 	 sm_val_loss=0.01013 	 time=0.96s
# Best: Epoch 6 	 loss=0.01013 	 val_loss=0.01002 	 sm_loss=0.01030 	 sm_val_loss=0.01007 	 time=0.88s
# Best: Epoch 7 	 loss=0.00996 	 val_loss=0.00985 	 sm_loss=0.01014 	 sm_val_loss=0.00989 	 time=0.88s
# Best: Epoch 8 	 loss=0.00974 	 val_loss=0.00973 	 sm_loss=0.00993 	 sm_val_loss=0.00979 	 time=0.87s
# Best: Epoch 9 	 loss=0.00946 	 val_loss=0.00959 	 sm_loss=0.00967 	 sm_val_loss=0.00964 	 time=0.90s
# Best: Epoch 10 	 loss=0.00923 	 val_loss=0.00958 	 sm_loss=0.00944 	 sm_val_loss=0.00963 	 time=0.88s
# Fold 2 log loss: 0.016633550709126137
# Fold 3
# Best: Epoch 1 	 loss=0.27875 	 val_loss=0.01210 	 sm_loss=0.27874 	 sm_val_loss=0.01210 	 time=0.87s
# Best: Epoch 3 	 loss=0.01056 	 val_loss=0.01080 	 sm_loss=0.01070 	 sm_val_loss=0.01084 	 time=1.17s
# Best: Epoch 4 	 loss=0.01023 	 val_loss=0.01068 	 sm_loss=0.01041 	 sm_val_loss=0.01071 	 time=0.90s
# Best: Epoch 5 	 loss=0.01013 	 val_loss=0.01066 	 sm_loss=0.01030 	 sm_val_loss=0.01071 	 time=1.08s
# Best: Epoch 6 	 loss=0.01005 	 val_loss=0.01060 	 sm_loss=0.01022 	 sm_val_loss=0.01065 	 time=0.88s
# Best: Epoch 7 	 loss=0.00989 	 val_loss=0.01048 	 sm_loss=0.01007 	 sm_val_loss=0.01055 	 time=0.88s
# Best: Epoch 8 	 loss=0.00965 	 val_loss=0.01041 	 sm_loss=0.00984 	 sm_val_loss=0.01047 	 time=0.88s
# Best: Epoch 9 	 loss=0.00939 	 val_loss=0.01027 	 sm_loss=0.00959 	 sm_val_loss=0.01033 	 time=0.88s
# Best: Epoch 10 	 loss=0.00915 	 val_loss=0.01024 	 sm_loss=0.00937 	 sm_val_loss=0.01031 	 time=0.88s
# Fold 3 log loss: 0.017510218912774655
# Fold 4
# Best: Epoch 1 	 loss=0.27924 	 val_loss=0.01170 	 sm_loss=0.27922 	 sm_val_loss=0.01170 	 time=0.97s
# Best: Epoch 2 	 loss=0.01124 	 val_loss=0.01055 	 sm_loss=0.01121 	 sm_val_loss=0.01062 	 time=1.24s
# Best: Epoch 3 	 loss=0.01039 	 val_loss=0.01046 	 sm_loss=0.01054 	 sm_val_loss=0.01050 	 time=0.91s
# Best: Epoch 5 	 loss=0.01018 	 val_loss=0.01045 	 sm_loss=0.01035 	 sm_val_loss=0.01047 	 time=0.95s
# Best: Epoch 6 	 loss=0.01003 	 val_loss=0.01042 	 sm_loss=0.01020 	 sm_val_loss=0.01046 	 time=1.22s
# Best: Epoch 7 	 loss=0.00991 	 val_loss=0.01022 	 sm_loss=0.01009 	 sm_val_loss=0.01025 	 time=1.24s
# Best: Epoch 8 	 loss=0.00966 	 val_loss=0.01011 	 sm_loss=0.00985 	 sm_val_loss=0.01014 	 time=0.99s
# Best: Epoch 9 	 loss=0.00938 	 val_loss=0.00999 	 sm_loss=0.00958 	 sm_val_loss=0.01004 	 time=0.93s
# Best: Epoch 10 	 loss=0.00914 	 val_loss=0.00998 	 sm_loss=0.00936 	 sm_val_loss=0.01002 	 time=0.89s
# Fold 4 log loss: 0.01691469536899491
# Fold 5
# Best: Epoch 1 	 loss=0.27927 	 val_loss=0.01244 	 sm_loss=0.27925 	 sm_val_loss=0.01245 	 time=0.89s
# Best: Epoch 2 	 loss=0.01101 	 val_loss=0.01094 	 sm_loss=0.01104 	 sm_val_loss=0.01097 	 time=0.90s
# Best: Epoch 3 	 loss=0.01030 	 val_loss=0.01093 	 sm_loss=0.01044 	 sm_val_loss=0.01095 	 time=0.87s
# Best: Epoch 4 	 loss=0.01018 	 val_loss=0.01083 	 sm_loss=0.01035 	 sm_val_loss=0.01081 	 time=0.88s
# Best: Epoch 5 	 loss=0.01009 	 val_loss=0.01075 	 sm_loss=0.01027 	 sm_val_loss=0.01078 	 time=1.10s
# Best: Epoch 6 	 loss=0.00998 	 val_loss=0.01074 	 sm_loss=0.01016 	 sm_val_loss=0.01076 	 time=0.88s
# Best: Epoch 7 	 loss=0.00985 	 val_loss=0.01053 	 sm_loss=0.01004 	 sm_val_loss=0.01056 	 time=0.88s
# Best: Epoch 8 	 loss=0.00963 	 val_loss=0.01047 	 sm_loss=0.00983 	 sm_val_loss=0.01050 	 time=1.03s
# Best: Epoch 9 	 loss=0.00933 	 val_loss=0.01033 	 sm_loss=0.00954 	 sm_val_loss=0.01037 	 time=0.90s
# Best: Epoch 10 	 loss=0.00911 	 val_loss=0.01031 	 sm_loss=0.00934 	 sm_val_loss=0.01035 	 time=0.92s
# Fold 5 log loss: 0.01676666506620894
# Fold 6
# Best: Epoch 1 	 loss=0.27967 	 val_loss=0.01222 	 sm_loss=0.27965 	 sm_val_loss=0.01221 	 time=0.89s
# Best: Epoch 2 	 loss=0.01097 	 val_loss=0.01120 	 sm_loss=0.01102 	 sm_val_loss=0.01121 	 time=1.20s
# Best: Epoch 3 	 loss=0.01024 	 val_loss=0.01111 	 sm_loss=0.01040 	 sm_val_loss=0.01110 	 time=0.90s
# Best: Epoch 4 	 loss=0.01012 	 val_loss=0.01110 	 sm_loss=0.01030 	 sm_val_loss=0.01109 	 time=0.89s
# Best: Epoch 5 	 loss=0.01007 	 val_loss=0.01087 	 sm_loss=0.01025 	 sm_val_loss=0.01088 	 time=1.09s
# Best: Epoch 7 	 loss=0.00980 	 val_loss=0.01081 	 sm_loss=0.00999 	 sm_val_loss=0.01082 	 time=0.87s
# Best: Epoch 8 	 loss=0.00957 	 val_loss=0.01057 	 sm_loss=0.00977 	 sm_val_loss=0.01061 	 time=0.86s
# Best: Epoch 9 	 loss=0.00928 	 val_loss=0.01049 	 sm_loss=0.00949 	 sm_val_loss=0.01053 	 time=0.88s
# Best: Epoch 10 	 loss=0.00905 	 val_loss=0.01045 	 sm_loss=0.00927 	 sm_val_loss=0.01048 	 time=0.96s
# Fold 6 log loss: 0.01806911932227691
# Fold 7
# Best: Epoch 1 	 loss=0.27995 	 val_loss=0.01187 	 sm_loss=0.27992 	 sm_val_loss=0.01187 	 time=0.87s
# Best: Epoch 2 	 loss=0.01092 	 val_loss=0.01118 	 sm_loss=0.01096 	 sm_val_loss=0.01121 	 time=0.90s
# Best: Epoch 3 	 loss=0.01036 	 val_loss=0.01099 	 sm_loss=0.01050 	 sm_val_loss=0.01088 	 time=0.87s
# Best: Epoch 4 	 loss=0.01016 	 val_loss=0.01075 	 sm_loss=0.01034 	 sm_val_loss=0.01077 	 time=0.90s
# Best: Epoch 5 	 loss=0.01011 	 val_loss=0.01059 	 sm_loss=0.01029 	 sm_val_loss=0.01061 	 time=1.05s
# Best: Epoch 7 	 loss=0.00987 	 val_loss=0.01045 	 sm_loss=0.01005 	 sm_val_loss=0.01049 	 time=0.88s
# Best: Epoch 8 	 loss=0.00964 	 val_loss=0.01032 	 sm_loss=0.00984 	 sm_val_loss=0.01037 	 time=0.88s
# Best: Epoch 9 	 loss=0.00936 	 val_loss=0.01022 	 sm_loss=0.00957 	 sm_val_loss=0.01027 	 time=0.89s
# Best: Epoch 10 	 loss=0.00913 	 val_loss=0.01021 	 sm_loss=0.00936 	 sm_val_loss=0.01025 	 time=0.87s
# Fold 7 log loss: 0.01747248585137294
# Seed 3
# Fold 1 log loss: 0.01751819482232092
# Fold 2 log loss: 0.016633550709126137
# Fold 3 log loss: 0.017510218912774655
# Fold 4 log loss: 0.01691469536899491
# Fold 5 log loss: 0.01676666506620894
# Fold 6 log loss: 0.01806911932227691
# Fold 7 log loss: 0.01747248585137294
# Std of log loss: 0.0004756273257971071
# Total log loss: 0.01727072307262093
# Fold 1
# Best: Epoch 1 	 loss=0.02506 	 val_loss=0.01829 	 sm_loss=0.02511 	 sm_val_loss=0.01832 	 time=0.56s
# Best: Epoch 2 	 loss=0.01695 	 val_loss=0.01763 	 sm_loss=0.01703 	 sm_val_loss=0.01765 	 time=0.56s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01567 	 val_loss=0.01741 	 sm_loss=0.01584 	 sm_val_loss=0.01743 	 time=0.80s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01539 	 val_loss=0.01740 	 sm_loss=0.01557 	 sm_val_loss=0.01742 	 time=0.56s
# Best: Epoch 13 	 loss=0.01534 	 val_loss=0.01738 	 sm_loss=0.01552 	 sm_val_loss=0.01741 	 time=0.57s
# Best: Epoch 15 	 loss=0.01535 	 val_loss=0.01737 	 sm_loss=0.01553 	 sm_val_loss=0.01740 	 time=0.59s
# Fold 1 log loss: 0.017468176456692353
# Fold 2
# Best: Epoch 1 	 loss=0.02484 	 val_loss=0.01784 	 sm_loss=0.02488 	 sm_val_loss=0.01787 	 time=0.57s
# Best: Epoch 2 	 loss=0.01701 	 val_loss=0.01684 	 sm_loss=0.01708 	 sm_val_loss=0.01688 	 time=0.62s
# Best: Epoch 3 	 loss=0.01635 	 val_loss=0.01681 	 sm_loss=0.01645 	 sm_val_loss=0.01687 	 time=0.84s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01573 	 val_loss=0.01642 	 sm_loss=0.01589 	 sm_val_loss=0.01651 	 time=0.69s
# Best: Epoch 9 	 loss=0.01558 	 val_loss=0.01643 	 sm_loss=0.01574 	 sm_val_loss=0.01651 	 time=0.58s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01538 	 val_loss=0.01641 	 sm_loss=0.01556 	 sm_val_loss=0.01648 	 time=0.75s
# Fold 2 log loss: 0.016490784780813058
# Fold 3
# Best: Epoch 1 	 loss=0.02487 	 val_loss=0.01822 	 sm_loss=0.02492 	 sm_val_loss=0.01824 	 time=0.61s
# Best: Epoch 2 	 loss=0.01686 	 val_loss=0.01767 	 sm_loss=0.01694 	 sm_val_loss=0.01769 	 time=0.58s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01560 	 val_loss=0.01747 	 sm_loss=0.01576 	 sm_val_loss=0.01749 	 time=0.59s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01528 	 val_loss=0.01747 	 sm_loss=0.01546 	 sm_val_loss=0.01749 	 time=0.60s
# Fold 3 log loss: 0.017487625046075476
# Fold 4
# Best: Epoch 1 	 loss=0.02499 	 val_loss=0.01782 	 sm_loss=0.02504 	 sm_val_loss=0.01784 	 time=0.56s
# Best: Epoch 2 	 loss=0.01691 	 val_loss=0.01698 	 sm_loss=0.01699 	 sm_val_loss=0.01699 	 time=0.58s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01566 	 val_loss=0.01682 	 sm_loss=0.01582 	 sm_val_loss=0.01683 	 time=0.60s
# Best: Epoch 10 	 loss=0.01545 	 val_loss=0.01680 	 sm_loss=0.01562 	 sm_val_loss=0.01683 	 time=0.58s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 15 	 loss=0.01530 	 val_loss=0.01678 	 sm_loss=0.01548 	 sm_val_loss=0.01681 	 time=0.57s
# Fold 4 log loss: 0.016843135033633973
# Fold 5
# Best: Epoch 1 	 loss=0.02498 	 val_loss=0.01759 	 sm_loss=0.02503 	 sm_val_loss=0.01763 	 time=0.59s
# Best: Epoch 2 	 loss=0.01702 	 val_loss=0.01692 	 sm_loss=0.01709 	 sm_val_loss=0.01696 	 time=0.57s
# Best: Epoch 3 	 loss=0.01630 	 val_loss=0.01683 	 sm_loss=0.01642 	 sm_val_loss=0.01688 	 time=0.58s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01571 	 val_loss=0.01672 	 sm_loss=0.01587 	 sm_val_loss=0.01678 	 time=0.57s
# Best: Epoch 9 	 loss=0.01557 	 val_loss=0.01668 	 sm_loss=0.01574 	 sm_val_loss=0.01673 	 time=0.79s
# Best: Epoch 10 	 loss=0.01549 	 val_loss=0.01668 	 sm_loss=0.01566 	 sm_val_loss=0.01673 	 time=0.57s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01538 	 val_loss=0.01666 	 sm_loss=0.01557 	 sm_val_loss=0.01671 	 time=0.56s
# Fold 5 log loss: 0.01671627144897924
# Fold 6
# Best: Epoch 1 	 loss=0.02474 	 val_loss=0.01901 	 sm_loss=0.02478 	 sm_val_loss=0.01902 	 time=0.56s
# Best: Epoch 2 	 loss=0.01672 	 val_loss=0.01823 	 sm_loss=0.01680 	 sm_val_loss=0.01824 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01540 	 val_loss=0.01817 	 sm_loss=0.01557 	 sm_val_loss=0.01815 	 time=0.56s
# Best: Epoch 8 	 loss=0.01524 	 val_loss=0.01814 	 sm_loss=0.01541 	 sm_val_loss=0.01814 	 time=0.57s
# Best: Epoch 9 	 loss=0.01523 	 val_loss=0.01812 	 sm_loss=0.01541 	 sm_val_loss=0.01812 	 time=0.57s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01510 	 val_loss=0.01810 	 sm_loss=0.01529 	 sm_val_loss=0.01810 	 time=0.59s
# Best: Epoch 15 	 loss=0.01502 	 val_loss=0.01809 	 sm_loss=0.01521 	 sm_val_loss=0.01809 	 time=0.57s
# Fold 6 log loss: 0.018142766551667473
# Fold 7
# Best: Epoch 1 	 loss=0.02494 	 val_loss=0.01829 	 sm_loss=0.02499 	 sm_val_loss=0.01832 	 time=0.56s
# Best: Epoch 2 	 loss=0.01689 	 val_loss=0.01769 	 sm_loss=0.01697 	 sm_val_loss=0.01771 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01559 	 val_loss=0.01739 	 sm_loss=0.01576 	 sm_val_loss=0.01739 	 time=0.57s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Fold 7 log loss: 0.017377100894149195
# Seed 3
# Fold 1 log loss: 0.017468176456692353
# Fold 2 log loss: 0.016490784780813058
# Fold 3 log loss: 0.017487625046075476
# Fold 4 log loss: 0.016843135033633973
# Fold 5 log loss: 0.01671627144897924
# Fold 6 log loss: 0.018142766551667473
# Fold 7 log loss: 0.017377100894149195
# Std of log loss: 0.0005260213804318422
# Total log loss: 0.017219414884331725
# Fold 1
# Best: Epoch 1 	 loss=0.27864 	 val_loss=0.01160 	 sm_loss=0.27862 	 sm_val_loss=0.01160 	 time=0.87s
# Best: Epoch 2 	 loss=0.01104 	 val_loss=0.01060 	 sm_loss=0.01107 	 sm_val_loss=0.01066 	 time=1.15s
# Best: Epoch 3 	 loss=0.01046 	 val_loss=0.01027 	 sm_loss=0.01059 	 sm_val_loss=0.01033 	 time=1.26s
# Best: Epoch 4 	 loss=0.01026 	 val_loss=0.01016 	 sm_loss=0.01043 	 sm_val_loss=0.01023 	 time=1.05s
# Best: Epoch 6 	 loss=0.01012 	 val_loss=0.00990 	 sm_loss=0.01029 	 sm_val_loss=0.00998 	 time=0.88s
# Best: Epoch 8 	 loss=0.00973 	 val_loss=0.00975 	 sm_loss=0.00992 	 sm_val_loss=0.00982 	 time=0.91s
# Best: Epoch 9 	 loss=0.00943 	 val_loss=0.00964 	 sm_loss=0.00963 	 sm_val_loss=0.00972 	 time=0.90s
# Best: Epoch 10 	 loss=0.00919 	 val_loss=0.00962 	 sm_loss=0.00941 	 sm_val_loss=0.00970 	 time=0.95s
# Fold 1 log loss: 0.017443053255104316
# Fold 2
# Best: Epoch 1 	 loss=0.27877 	 val_loss=0.01199 	 sm_loss=0.27875 	 sm_val_loss=0.01199 	 time=0.91s
# Best: Epoch 2 	 loss=0.01119 	 val_loss=0.01034 	 sm_loss=0.01121 	 sm_val_loss=0.01041 	 time=0.87s
# Best: Epoch 3 	 loss=0.01041 	 val_loss=0.01026 	 sm_loss=0.01055 	 sm_val_loss=0.01027 	 time=0.86s
# Best: Epoch 4 	 loss=0.01026 	 val_loss=0.01004 	 sm_loss=0.01044 	 sm_val_loss=0.01010 	 time=0.87s
# Best: Epoch 6 	 loss=0.01009 	 val_loss=0.00998 	 sm_loss=0.01026 	 sm_val_loss=0.01003 	 time=1.11s
# Best: Epoch 7 	 loss=0.00994 	 val_loss=0.00982 	 sm_loss=0.01012 	 sm_val_loss=0.00988 	 time=0.88s
# Best: Epoch 8 	 loss=0.00969 	 val_loss=0.00971 	 sm_loss=0.00989 	 sm_val_loss=0.00978 	 time=0.88s
# Best: Epoch 9 	 loss=0.00941 	 val_loss=0.00959 	 sm_loss=0.00962 	 sm_val_loss=0.00966 	 time=0.87s
# Best: Epoch 10 	 loss=0.00917 	 val_loss=0.00959 	 sm_loss=0.00939 	 sm_val_loss=0.00965 	 time=0.90s
# Fold 2 log loss: 0.016666514954137332
# Fold 3
# Best: Epoch 1 	 loss=0.27976 	 val_loss=0.01236 	 sm_loss=0.27974 	 sm_val_loss=0.01236 	 time=0.87s
# Best: Epoch 3 	 loss=0.01062 	 val_loss=0.01079 	 sm_loss=0.01073 	 sm_val_loss=0.01086 	 time=0.90s
# Best: Epoch 4 	 loss=0.01020 	 val_loss=0.01071 	 sm_loss=0.01037 	 sm_val_loss=0.01076 	 time=0.87s
# Best: Epoch 5 	 loss=0.01012 	 val_loss=0.01064 	 sm_loss=0.01029 	 sm_val_loss=0.01070 	 time=0.88s
# Best: Epoch 7 	 loss=0.00988 	 val_loss=0.01051 	 sm_loss=0.01006 	 sm_val_loss=0.01058 	 time=1.07s
# Best: Epoch 8 	 loss=0.00965 	 val_loss=0.01042 	 sm_loss=0.00984 	 sm_val_loss=0.01048 	 time=0.89s
# Best: Epoch 9 	 loss=0.00936 	 val_loss=0.01026 	 sm_loss=0.00956 	 sm_val_loss=0.01033 	 time=0.87s
# Best: Epoch 10 	 loss=0.00914 	 val_loss=0.01023 	 sm_loss=0.00935 	 sm_val_loss=0.01031 	 time=0.88s
# Fold 3 log loss: 0.01750075154848
# Fold 4
# Best: Epoch 1 	 loss=0.27895 	 val_loss=0.01193 	 sm_loss=0.27893 	 sm_val_loss=0.01193 	 time=0.87s
# Best: Epoch 2 	 loss=0.01101 	 val_loss=0.01058 	 sm_loss=0.01105 	 sm_val_loss=0.01063 	 time=0.87s
# Best: Epoch 3 	 loss=0.01038 	 val_loss=0.01043 	 sm_loss=0.01052 	 sm_val_loss=0.01046 	 time=0.92s
# Best: Epoch 7 	 loss=0.00992 	 val_loss=0.01024 	 sm_loss=0.01009 	 sm_val_loss=0.01029 	 time=1.13s
# Best: Epoch 8 	 loss=0.00967 	 val_loss=0.01008 	 sm_loss=0.00986 	 sm_val_loss=0.01013 	 time=1.06s
# Best: Epoch 9 	 loss=0.00938 	 val_loss=0.01003 	 sm_loss=0.00959 	 sm_val_loss=0.01007 	 time=0.88s
# Best: Epoch 10 	 loss=0.00917 	 val_loss=0.01000 	 sm_loss=0.00939 	 sm_val_loss=0.01005 	 time=0.89s
# Fold 4 log loss: 0.01697039397360861
# Fold 5
# Best: Epoch 1 	 loss=0.27860 	 val_loss=0.01225 	 sm_loss=0.27859 	 sm_val_loss=0.01226 	 time=0.88s
# Best: Epoch 2 	 loss=0.01103 	 val_loss=0.01132 	 sm_loss=0.01103 	 sm_val_loss=0.01135 	 time=0.95s
# Best: Epoch 4 	 loss=0.01017 	 val_loss=0.01089 	 sm_loss=0.01034 	 sm_val_loss=0.01091 	 time=0.87s
# Best: Epoch 5 	 loss=0.01009 	 val_loss=0.01083 	 sm_loss=0.01027 	 sm_val_loss=0.01086 	 time=0.87s
# Best: Epoch 6 	 loss=0.01003 	 val_loss=0.01069 	 sm_loss=0.01020 	 sm_val_loss=0.01073 	 time=0.88s
# Best: Epoch 7 	 loss=0.00985 	 val_loss=0.01055 	 sm_loss=0.01004 	 sm_val_loss=0.01057 	 time=1.09s
# Best: Epoch 8 	 loss=0.00964 	 val_loss=0.01047 	 sm_loss=0.00983 	 sm_val_loss=0.01049 	 time=0.93s
# Best: Epoch 9 	 loss=0.00935 	 val_loss=0.01029 	 sm_loss=0.00956 	 sm_val_loss=0.01033 	 time=0.88s
# Best: Epoch 10 	 loss=0.00912 	 val_loss=0.01027 	 sm_loss=0.00934 	 sm_val_loss=0.01031 	 time=0.87s
# Fold 5 log loss: 0.016648872389087487
# Fold 6
# Best: Epoch 1 	 loss=0.27874 	 val_loss=0.01238 	 sm_loss=0.27871 	 sm_val_loss=0.01238 	 time=0.88s
# Best: Epoch 2 	 loss=0.01205 	 val_loss=0.01173 	 sm_loss=0.01203 	 sm_val_loss=0.01160 	 time=0.87s
# Best: Epoch 3 	 loss=0.01063 	 val_loss=0.01121 	 sm_loss=0.01079 	 sm_val_loss=0.01112 	 time=0.87s
# Best: Epoch 4 	 loss=0.01027 	 val_loss=0.01104 	 sm_loss=0.01045 	 sm_val_loss=0.01103 	 time=0.89s
# Best: Epoch 5 	 loss=0.01005 	 val_loss=0.01084 	 sm_loss=0.01024 	 sm_val_loss=0.01083 	 time=0.90s
# Best: Epoch 6 	 loss=0.00994 	 val_loss=0.01079 	 sm_loss=0.01013 	 sm_val_loss=0.01080 	 time=0.89s
# Best: Epoch 7 	 loss=0.00977 	 val_loss=0.01072 	 sm_loss=0.00996 	 sm_val_loss=0.01074 	 time=0.87s
# Best: Epoch 8 	 loss=0.00952 	 val_loss=0.01053 	 sm_loss=0.00972 	 sm_val_loss=0.01055 	 time=1.17s
# Best: Epoch 9 	 loss=0.00921 	 val_loss=0.01050 	 sm_loss=0.00943 	 sm_val_loss=0.01054 	 time=1.16s
# Best: Epoch 10 	 loss=0.00895 	 val_loss=0.01047 	 sm_loss=0.00918 	 sm_val_loss=0.01051 	 time=0.88s
# Fold 6 log loss: 0.018136988632744072
# Fold 7
# Best: Epoch 1 	 loss=0.27931 	 val_loss=0.01219 	 sm_loss=0.27930 	 sm_val_loss=0.01219 	 time=1.14s
# Best: Epoch 2 	 loss=0.01100 	 val_loss=0.01075 	 sm_loss=0.01105 	 sm_val_loss=0.01079 	 time=0.90s
# Best: Epoch 4 	 loss=0.01017 	 val_loss=0.01073 	 sm_loss=0.01033 	 sm_val_loss=0.01077 	 time=1.05s
# Best: Epoch 6 	 loss=0.01003 	 val_loss=0.01064 	 sm_loss=0.01020 	 sm_val_loss=0.01066 	 time=0.89s
# Best: Epoch 7 	 loss=0.00985 	 val_loss=0.01041 	 sm_loss=0.01003 	 sm_val_loss=0.01045 	 time=1.25s
# Best: Epoch 8 	 loss=0.00963 	 val_loss=0.01036 	 sm_loss=0.00982 	 sm_val_loss=0.01040 	 time=0.93s
# Best: Epoch 9 	 loss=0.00935 	 val_loss=0.01022 	 sm_loss=0.00955 	 sm_val_loss=0.01026 	 time=0.89s
# Best: Epoch 10 	 loss=0.00911 	 val_loss=0.01020 	 sm_loss=0.00933 	 sm_val_loss=0.01024 	 time=0.88s
# Fold 7 log loss: 0.017476030207549564
# Seed 4
# Fold 1 log loss: 0.017443053255104316
# Fold 2 log loss: 0.016666514954137332
# Fold 3 log loss: 0.01750075154848
# Fold 4 log loss: 0.01697039397360861
# Fold 5 log loss: 0.016648872389087487
# Fold 6 log loss: 0.018136988632744072
# Fold 7 log loss: 0.017476030207549564
# Std of log loss: 0.000495226935583312
# Total log loss: 0.017265283150857777
# Fold 1
# Best: Epoch 1 	 loss=0.02523 	 val_loss=0.01824 	 sm_loss=0.02528 	 sm_val_loss=0.01827 	 time=0.56s
# Best: Epoch 2 	 loss=0.01690 	 val_loss=0.01754 	 sm_loss=0.01698 	 sm_val_loss=0.01755 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01555 	 val_loss=0.01730 	 sm_loss=0.01572 	 sm_val_loss=0.01734 	 time=0.56s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Fold 1 log loss: 0.017403861026328404
# Fold 2
# Best: Epoch 1 	 loss=0.02497 	 val_loss=0.01779 	 sm_loss=0.02502 	 sm_val_loss=0.01784 	 time=0.57s
# Best: Epoch 2 	 loss=0.01691 	 val_loss=0.01684 	 sm_loss=0.01699 	 sm_val_loss=0.01689 	 time=0.56s
# Best: Epoch 3 	 loss=0.01619 	 val_loss=0.01681 	 sm_loss=0.01630 	 sm_val_loss=0.01686 	 time=0.56s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01561 	 val_loss=0.01654 	 sm_loss=0.01577 	 sm_val_loss=0.01662 	 time=0.56s
# Best: Epoch 10 	 loss=0.01543 	 val_loss=0.01652 	 sm_loss=0.01561 	 sm_val_loss=0.01661 	 time=0.56s
# Best: Epoch 11 	 loss=0.01541 	 val_loss=0.01651 	 sm_loss=0.01559 	 sm_val_loss=0.01658 	 time=0.71s
# Epoch    15: reducing learning rate of group 0 to 1.0000e-04.
# Fold 2 log loss: 0.016595411252761053
# Fold 3
# Best: Epoch 1 	 loss=0.02503 	 val_loss=0.01827 	 sm_loss=0.02508 	 sm_val_loss=0.01828 	 time=0.59s
# Best: Epoch 2 	 loss=0.01694 	 val_loss=0.01776 	 sm_loss=0.01701 	 sm_val_loss=0.01777 	 time=0.59s
# Best: Epoch 3 	 loss=0.01619 	 val_loss=0.01766 	 sm_loss=0.01630 	 sm_val_loss=0.01768 	 time=0.57s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01560 	 val_loss=0.01753 	 sm_loss=0.01576 	 sm_val_loss=0.01755 	 time=0.80s
# Epoch    12: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 13 	 loss=0.01527 	 val_loss=0.01751 	 sm_loss=0.01546 	 sm_val_loss=0.01753 	 time=0.56s
# Best: Epoch 14 	 loss=0.01527 	 val_loss=0.01746 	 sm_loss=0.01545 	 sm_val_loss=0.01748 	 time=0.57s
# Fold 3 log loss: 0.017484620940935242
# Fold 4
# Best: Epoch 1 	 loss=0.02514 	 val_loss=0.01788 	 sm_loss=0.02518 	 sm_val_loss=0.01790 	 time=0.56s
# Best: Epoch 2 	 loss=0.01698 	 val_loss=0.01709 	 sm_loss=0.01706 	 sm_val_loss=0.01711 	 time=0.56s
# Best: Epoch 3 	 loss=0.01629 	 val_loss=0.01701 	 sm_loss=0.01639 	 sm_val_loss=0.01702 	 time=0.58s
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 8 	 loss=0.01573 	 val_loss=0.01690 	 sm_loss=0.01589 	 sm_val_loss=0.01691 	 time=0.56s
# Best: Epoch 9 	 loss=0.01557 	 val_loss=0.01687 	 sm_loss=0.01573 	 sm_val_loss=0.01688 	 time=0.57s
# Best: Epoch 10 	 loss=0.01556 	 val_loss=0.01680 	 sm_loss=0.01573 	 sm_val_loss=0.01682 	 time=0.57s
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 15 	 loss=0.01542 	 val_loss=0.01679 	 sm_loss=0.01560 	 sm_val_loss=0.01681 	 time=0.56s
# Fold 4 log loss: 0.01684402469552758
# Fold 5
# Best: Epoch 1 	 loss=0.02497 	 val_loss=0.01758 	 sm_loss=0.02501 	 sm_val_loss=0.01762 	 time=0.59s
# Best: Epoch 2 	 loss=0.01700 	 val_loss=0.01678 	 sm_loss=0.01707 	 sm_val_loss=0.01683 	 time=0.56s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01570 	 val_loss=0.01661 	 sm_loss=0.01586 	 sm_val_loss=0.01666 	 time=0.60s
# Best: Epoch 10 	 loss=0.01554 	 val_loss=0.01661 	 sm_loss=0.01571 	 sm_val_loss=0.01666 	 time=0.64s
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 12 	 loss=0.01539 	 val_loss=0.01656 	 sm_loss=0.01557 	 sm_val_loss=0.01662 	 time=0.58s
# Fold 5 log loss: 0.01662631092127784
# Fold 6
# Best: Epoch 1 	 loss=0.02469 	 val_loss=0.01893 	 sm_loss=0.02474 	 sm_val_loss=0.01893 	 time=0.57s
# Best: Epoch 2 	 loss=0.01654 	 val_loss=0.01816 	 sm_loss=0.01662 	 sm_val_loss=0.01817 	 time=0.59s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    10: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 11 	 loss=0.01488 	 val_loss=0.01813 	 sm_loss=0.01508 	 sm_val_loss=0.01814 	 time=0.57s
# Fold 6 log loss: 0.01819512670572795
# Fold 7
# Best: Epoch 1 	 loss=0.02496 	 val_loss=0.01831 	 sm_loss=0.02500 	 sm_val_loss=0.01834 	 time=0.57s
# Best: Epoch 2 	 loss=0.01683 	 val_loss=0.01768 	 sm_loss=0.01690 	 sm_val_loss=0.01770 	 time=0.57s
# Epoch     6: reducing learning rate of group 0 to 1.0000e-03.
# Best: Epoch 7 	 loss=0.01554 	 val_loss=0.01748 	 sm_loss=0.01570 	 sm_val_loss=0.01750 	 time=0.58s
# Best: Epoch 9 	 loss=0.01537 	 val_loss=0.01745 	 sm_loss=0.01554 	 sm_val_loss=0.01747 	 time=0.56s
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 14 	 loss=0.01524 	 val_loss=0.01741 	 sm_loss=0.01543 	 sm_val_loss=0.01744 	 time=0.66s
# Best: Epoch 15 	 loss=0.01517 	 val_loss=0.01741 	 sm_loss=0.01535 	 sm_val_loss=0.01743 	 time=0.72s
# Fold 7 log loss: 0.017420764290443477
# Seed 4
# Fold 1 log loss: 0.017403861026328404
# Fold 2 log loss: 0.016595411252761053
# Fold 3 log loss: 0.017484620940935242
# Fold 4 log loss: 0.01684402469552758
# Fold 5 log loss: 0.01662631092127784
# Fold 6 log loss: 0.01819512670572795
# Fold 7 log loss: 0.017420764290443477
# Std of log loss: 0.000531683736048537
# Total log loss: 0.017226256462714435
# Total log loss in targets: 0.01709680333800478

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6400092359319818

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015757144522656034

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

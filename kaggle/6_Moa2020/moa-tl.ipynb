# %% [markdown]
# - change validation method
# - 1st resnet

# %%
import os
import sys
import json
import random
import warnings
import numpy as np
import pandas as pd 
from umap import UMAP
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from tqdm import tqdm_notebook as tqdm
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

# %%
json_file_path = '../input/moapredictors/main_predictors.json'

with open(json_file_path, 'r') as j:
    predictors = json.loads(j.read())
    predictors = predictors['start_predictors']

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
non_targets = pd.read_csv(DATA_DIR + 'train_targets_nonscored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

# %% [markdown]
# # preprocess

# %%
train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)
non_targets = non_targets[non_targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
# https://www.kaggle.com/c/lish-moa/discussion/195195
NB_SPLITS = 7
seed = 14

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[vc <= 18].index.sort_values()
vc2 = vc.loc[vc > 18].index.sort_values()

# STRATIFY DRUGS 1000X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)

# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[0, 5, 3, ..., 6, 3, 0]], dtype=int8)

# %%
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
nontarget_dists = pd.DataFrame(np.sum(non_targets[non_target_feats])).reset_index(drop=False)
nontarget_dists.columns = ["target", "number"]
nontarget_dists = nontarget_dists.sort_values("number", ascending=False).reset_index(drop=True)
drop_list1 = list(nontarget_dists[nontarget_dists.number==0]["target"].values)
print("first drop", len(drop_list1))
non_targets.drop(drop_list1, axis=1, inplace=True)
print("shape after 1st drop:", non_targets.shape)
non_target_feats = [i for i in non_targets.columns if i != "sig_id"]
print(len(non_target_feats))
# Out:
# first drop 71
# shape after 1st drop: (21948, 332)
# 331

# %%
all_targets = pd.concat([targets, non_targets], axis=1)

# %% [markdown]
# # Feature enginnering

# %%
X = train.iloc[:,4:].copy().values
select = VarianceThreshold(threshold=0.6)
X_new = select.fit_transform(X)
drop_feats = list(np.array(train.iloc[:,4:].columns)[select.get_support()==False])
len(drop_feats)

train.drop(drop_feats, axis=1, inplace=True)
test.drop(drop_feats, axis=1, inplace=True)

# %%
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
# rank gauss
for i in c_feats + g_feats:
    ss = preprocessing.QuantileTransformer(n_quantiles=1000, random_state=0, output_distribution="normal")
    ss.fit(train[i].values.reshape(-1,1))
    train[i] = ss.transform(train[i].values.reshape(-1,1))
    test[i] = ss.transform(test[i].values.reshape(-1,1))

# %%
c_num = 10
pca_c_cols = ["pca-c"+str(i+1) for i in range(c_num)]
pca = PCA(n_components=c_num,random_state=42)
c_train = pca.fit_transform(train[c_feats])
c_test = pca.transform(test[c_feats])
c_train = pd.DataFrame(c_train, columns=pca_c_cols)
c_test = pd.DataFrame(c_test, columns=pca_c_cols)

g_num = 60
pca_g_cols = ["pca-g"+str(i+1) for i in range(g_num)]
pca = PCA(n_components=g_num, random_state=42)
g_train = pca.fit_transform(train[g_feats])
g_test = pca.transform(test[g_feats])
g_train = pd.DataFrame(g_train, columns=pca_g_cols)
g_test = pd.DataFrame(g_test, columns=pca_g_cols)

train = pd.concat([train, c_train],axis=1)
test = pd.concat([test, c_test],axis=1)
train = pd.concat([train, g_train],axis=1)
test = pd.concat([test, g_test],axis=1)

# %%
def fe(df):
    tmp = df.copy()
    tmp['g_kurt'] = tmp[g_feats].kurtosis(axis = 1)
    tmp['g_skew'] = tmp[g_feats].skew(axis = 1)
    tmp['c_kurt'] = tmp[c_feats].kurtosis(axis = 1)
    tmp['c_skew'] = tmp[c_feats].skew(axis = 1)
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["cp_type", "sig_id"], axis=1, inplace=True) 
    return tmp

train = fe(train)
test = fe(test)

print(train.shape, test.shape)
# Out:
# (21948, 933) (3624, 933)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
predictors_index = []
for i in range(len(train.columns)):
    if train.columns[i] in predictors:
        predictors_index.append(i)

# %%
fn_train = train.copy()
fn_test = test.copy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()
fn_non_targets = non_targets.drop("sig_id", axis=1).copy().to_numpy()
fn_all_targets = all_targets.drop("sig_id", axis=1).copy().to_numpy()

# %% [markdown]
# # modelling

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def seed_everything(seed=42): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class MoaModel(nn.Module):
    def __init__(self, num_columns, last_num):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.Linear(num_columns, 512)
        self.relu1 = nn.ELU()
        self.dense12 = nn.Linear(512, 256)
        
        self.batch_norm2 = nn.BatchNorm1d(256+len(predictors_index))
        self.dropout2 = nn.Dropout(0.3)
        self.dense2 = nn.Linear(256+len(predictors_index), 512)
        self.relu2 = nn.ReLU()
        self.batch_norm22 = nn.BatchNorm1d(512)
        self.dense22 = nn.Linear(512, 512)
        self.relu22 = nn.ELU()
        self.batch_norm23 = nn.BatchNorm1d(512)
        self.dense23 = nn.Linear(512, 256)
        self.relu23 = nn.ReLU()
        self.batch_norm24 = nn.BatchNorm1d(256)
        self.dense24 = nn.Linear(256, 256)
        self.relu24 = nn.ELU()
                
        self.batch_norm3 = nn.BatchNorm1d(256)
        self.dense3 = nn.Linear(256, 256)
        self.relu3 = nn.SELU()
        self.batch_norm32 = nn.BatchNorm1d(256)
        self.dense32 = nn.Linear(256, last_num)
        self.relu32 = nn.SELU()
        self.batch_norm33 = nn.BatchNorm1d(last_num)
        self.dense33 = nn.Linear(last_num, last_num)
        
    def forward(self, x1, x2):
        x1 = self.batch_norm1(x1)
        x1 = self.dropout1(x1)
        x1 = self.relu1(self.dense1(x1))
        x1 = self.dense12(x1)
        
        x3 = torch.cat([x1,x2],axis=1)
                
        x3 = self.batch_norm2(x3)
        x3 = self.dropout2(x3)
        x3 = self.relu2(self.dense2(x3))
        x3 = self.batch_norm22(x3)
        x3 = self.relu22(self.dense22(x3))
        x3 = self.batch_norm23(x3)
        x3 = self.relu23(self.dense23(x3))
        x3 = self.batch_norm24(x3)
        x3 = self.relu24(self.dense24(x3))
        
        x4 = (x1 + x3) / 2
        
        x4 = self.batch_norm3(x4)
        x4 = self.relu3(self.dense3(x4))
        x4 = self.batch_norm32(x4)
        x4 = self.relu32(self.dense32(x4))
        x4 = self.batch_norm33(x4)
        x4 = self.dense33(x4)
        
        return x4
# Out:
# cuda

# %%
batch_size = 128
n_folds=7
EARLY_STOPPING_STEPS = 10
smoothing = 0.001
p_min = smoothing
p_max = 1 - smoothing

def torch_tl(tr, target, te, sample_seed, init_num, files):
    seed_everything(seed=sample_seed) 
    test_len = te.shape[0]
    
    if files == []:
        train_epochs = 20
        ans = []
    else:
        train_epochs = 40
        
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)
    models = []
    
    X_test = torch.tensor(te.values, dtype=torch.float32)
    X_test2 = torch.tensor(te.iloc[:][predictors].values, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test, X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(tr),target.shape[1]])
    oof_targets = np.zeros([len(tr),target.shape[1]])
    pred_value = np.zeros([test_len, target.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = tr["fold"] == fold
        train_index = tr["fold"] != fold
        print("Fold "+str(fold+1))
        X_train1 = torch.tensor(tr[train_index].values, dtype=torch.float32)
        X_valid1 = torch.tensor(tr[valid_index].values, dtype=torch.float32)
        X_train2 = torch.tensor(tr[train_index][predictors].values, dtype=torch.float32)
        X_valid2 = torch.tensor(tr[valid_index][predictors].values, dtype=torch.float32)
        
        y_train2 = torch.tensor(target[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(target[valid_index], dtype=torch.float32)
        
        X_train1 = X_train1[:,:-1]
        X_valid1 = X_valid1[:,:-1]
        
        train = torch.utils.data.TensorDataset(X_train1, X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid1, X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = MoaModel(init_num, len(non_target_feats))

        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)
        if files != []:
            clf.load_state_dict(torch.load(files[fold]))
            clf.dense32 = nn.Linear(256, len(target_feats))
            clf.relu32 = nn.SELU()
            clf.batch_norm33 = nn.BatchNorm1d(len(target_feats))
            clf.dense33 = nn.Linear(len(target_feats), len(target_feats))
            
            optimizer = optim.Adam(clf.parameters(), lr = 0.01, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=train_epochs, steps_per_epoch=len(train_loader))            
        else:
            optimizer = optim.Adam(clf.parameters(), lr = 0.001, weight_decay=1e-5) 
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, eps=1e-4, verbose=True)
       
        clf.to(device)
        best_val_loss = np.inf
        stop_counts = 0
        
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, x_batch2, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                if files != []:
                    scheduler.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader)      
            
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            
            for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                x_batch2 = x_batch2.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch, x_batch2).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
                
            elapsed_time = time.time() - start_time
            if files == []:
                scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Best: Epoch {} \t loss={:.5f} \t val_loss={:.5f} \t sm_loss={:.5f} \t sm_val_loss={:.5f} \t time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                if files == []:
                    torch.save(clf.state_dict(), 'parameters'+str(fold+1)+'.pt')
                else:    
                    torch.save(clf.state_dict(), 'best-model-parameters.pt')
                
        if files == []:
            pred_model = MoaModel(init_num, len(non_target_feats))
            ans.append('parameters'+str(fold+1)+'.pt')
            pred_model.load_state_dict(torch.load('parameters'+str(fold+1)+'.pt'))
        else:
            pred_model = MoaModel(init_num, len(target_feats))
            pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        if files != []:
            # validation check ----------------
            oof_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            target_epoch = np.zeros([X_valid2.size(0), target.shape[1]])
            for i, (x_batch, x_batch2, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch, x_batch2).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
            print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
            scores.append(mean_log_loss(target_epoch, oof_epoch))
            oof[valid_index,:] = oof_epoch
            oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        

            # test predcition --------------
            test_preds = np.zeros([test_len, target.shape[1]])
            for i, (x_batch,x_batch2,) in enumerate(test_loader): 
                y_pred = pred_model(x_batch,x_batch2).detach()
                test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
            pred_value += test_preds / n_folds
            # ------------------------------
    
    if files != []:
        print("Seed {}".format(sample_seed))
        for i, ele in enumerate(scores):
            print("Fold {} log loss: {}".format(i+1, scores[i]))
        print("Std of log loss: {}".format(np.std(scores)))
        print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    if files != []:
        return oof, oof_targets, pred_value
    else:
        return ans

# %%
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

seeds = [0,1,2,3,4] 
    
for seed_ in seeds:
    files = torch_tl(fn_train, fn_non_targets, fn_test, seed_, fn_train.shape[1]-1, [])
    oof, oof_targets, pytorch_pred = torch_tl(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, files)
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Best: Epoch 1 	 loss=0.28218 	 val_loss=0.01878 	 sm_loss=0.28218 	 sm_val_loss=0.01877 	 time=3.41s
# Best: Epoch 2 	 loss=0.01154 	 val_loss=0.00755 	 sm_loss=0.01153 	 sm_val_loss=0.00753 	 time=2.41s
# Best: Epoch 3 	 loss=0.00731 	 val_loss=0.00604 	 sm_loss=0.00730 	 sm_val_loss=0.00603 	 time=2.40s
# Best: Epoch 4 	 loss=0.00646 	 val_loss=0.00555 	 sm_loss=0.00645 	 sm_val_loss=0.00554 	 time=2.41s
# Best: Epoch 5 	 loss=0.00615 	 val_loss=0.00552 	 sm_loss=0.00615 	 sm_val_loss=0.00551 	 time=2.74s
# Best: Epoch 6 	 loss=0.00600 	 val_loss=0.00535 	 sm_loss=0.00601 	 sm_val_loss=0.00535 	 time=2.56s
# Best: Epoch 9 	 loss=0.00581 	 val_loss=0.00529 	 sm_loss=0.00585 	 sm_val_loss=0.00530 	 time=2.38s
# Best: Epoch 11 	 loss=0.00571 	 val_loss=0.00524 	 sm_loss=0.00576 	 sm_val_loss=0.00526 	 time=2.44s
# Best: Epoch 12 	 loss=0.00565 	 val_loss=0.00515 	 sm_loss=0.00572 	 sm_val_loss=0.00517 	 time=2.44s
# Epoch    16: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 17 	 loss=0.00532 	 val_loss=0.00506 	 sm_loss=0.00543 	 sm_val_loss=0.00511 	 time=2.37s
# Best: Epoch 19 	 loss=0.00527 	 val_loss=0.00506 	 sm_loss=0.00539 	 sm_val_loss=0.00509 	 time=2.52s
# Fold 2
# Best: Epoch 1 	 loss=0.28454 	 val_loss=0.01922 	 sm_loss=0.28453 	 sm_val_loss=0.01921 	 time=2.58s
# Best: Epoch 2 	 loss=0.01168 	 val_loss=0.00794 	 sm_loss=0.01166 	 sm_val_loss=0.00793 	 time=3.34s
# Best: Epoch 3 	 loss=0.00732 	 val_loss=0.00640 	 sm_loss=0.00730 	 sm_val_loss=0.00639 	 time=2.42s
# Best: Epoch 4 	 loss=0.00641 	 val_loss=0.00585 	 sm_loss=0.00640 	 sm_val_loss=0.00584 	 time=2.39s
# Best: Epoch 5 	 loss=0.00609 	 val_loss=0.00574 	 sm_loss=0.00608 	 sm_val_loss=0.00573 	 time=2.44s
# Best: Epoch 6 	 loss=0.00593 	 val_loss=0.00565 	 sm_loss=0.00594 	 sm_val_loss=0.00566 	 time=2.76s
# Best: Epoch 8 	 loss=0.00579 	 val_loss=0.00564 	 sm_loss=0.00581 	 sm_val_loss=0.00565 	 time=2.38s
# Best: Epoch 9 	 loss=0.00574 	 val_loss=0.00558 	 sm_loss=0.00578 	 sm_val_loss=0.00560 	 time=2.37s
# Best: Epoch 10 	 loss=0.00568 	 val_loss=0.00555 	 sm_loss=0.00572 	 sm_val_loss=0.00556 	 time=2.38s
# Best: Epoch 11 	 loss=0.00562 	 val_loss=0.00553 	 sm_loss=0.00568 	 sm_val_loss=0.00554 	 time=2.54s
# Best: Epoch 12 	 loss=0.00558 	 val_loss=0.00552 	 sm_loss=0.00564 	 sm_val_loss=0.00554 	 time=2.35s
# Best: Epoch 13 	 loss=0.00553 	 val_loss=0.00548 	 sm_loss=0.00561 	 sm_val_loss=0.00551 	 time=2.35s
# Best: Epoch 14 	 loss=0.00548 	 val_loss=0.00547 	 sm_loss=0.00557 	 sm_val_loss=0.00550 	 time=2.36s
# Best: Epoch 15 	 loss=0.00543 	 val_loss=0.00542 	 sm_loss=0.00553 	 sm_val_loss=0.00546 	 time=3.11s
# Best: Epoch 17 	 loss=0.00535 	 val_loss=0.00540 	 sm_loss=0.00548 	 sm_val_loss=0.00544 	 time=2.32s
# Best: Epoch 20 	 loss=0.00524 	 val_loss=0.00539 	 sm_loss=0.00541 	 sm_val_loss=0.00543 	 time=2.38s
# Fold 3
# Best: Epoch 1 	 loss=0.28217 	 val_loss=0.01914 	 sm_loss=0.28216 	 sm_val_loss=0.01913 	 time=2.82s
# Best: Epoch 2 	 loss=0.01144 	 val_loss=0.00838 	 sm_loss=0.01143 	 sm_val_loss=0.00837 	 time=2.39s
# Best: Epoch 3 	 loss=0.00720 	 val_loss=0.00692 	 sm_loss=0.00719 	 sm_val_loss=0.00691 	 time=2.74s
# Best: Epoch 4 	 loss=0.00633 	 val_loss=0.00644 	 sm_loss=0.00632 	 sm_val_loss=0.00643 	 time=2.65s
# Best: Epoch 5 	 loss=0.00602 	 val_loss=0.00634 	 sm_loss=0.00601 	 sm_val_loss=0.00633 	 time=2.38s
# Best: Epoch 6 	 loss=0.00587 	 val_loss=0.00627 	 sm_loss=0.00588 	 sm_val_loss=0.00627 	 time=2.30s
# Best: Epoch 7 	 loss=0.00578 	 val_loss=0.00622 	 sm_loss=0.00579 	 sm_val_loss=0.00623 	 time=2.42s
# Best: Epoch 8 	 loss=0.00571 	 val_loss=0.00616 	 sm_loss=0.00574 	 sm_val_loss=0.00617 	 time=2.85s
# Best: Epoch 9 	 loss=0.00568 	 val_loss=0.00612 	 sm_loss=0.00571 	 sm_val_loss=0.00613 	 time=2.38s
# Best: Epoch 10 	 loss=0.00562 	 val_loss=0.00608 	 sm_loss=0.00566 	 sm_val_loss=0.00609 	 time=2.33s
# Best: Epoch 12 	 loss=0.00552 	 val_loss=0.00603 	 sm_loss=0.00558 	 sm_val_loss=0.00604 	 time=2.55s
# Best: Epoch 14 	 loss=0.00542 	 val_loss=0.00598 	 sm_loss=0.00550 	 sm_val_loss=0.00601 	 time=2.36s
# Epoch    18: reducing learning rate of group 0 to 1.0000e-04.
# Best: Epoch 19 	 loss=0.00518 	 val_loss=0.00592 	 sm_loss=0.00531 	 sm_val_loss=0.00597 	 time=2.35s
# Best: Epoch 20 	 loss=0.00513 	 val_loss=0.00591 	 sm_loss=0.00526 	 sm_val_loss=0.00596 	 time=2.38s
# Fold 4
# Best: Epoch 1 	 loss=0.28369 	 val_loss=0.02006 	 sm_loss=0.28369 	 sm_val_loss=0.02005 	 time=2.84s
# Best: Epoch 2 	 loss=0.01172 	 val_loss=0.00828 	 sm_loss=0.01171 	 sm_val_loss=0.00827 	 time=2.27s
# Best: Epoch 3 	 loss=0.00727 	 val_loss=0.00687 	 sm_loss=0.00726 	 sm_val_loss=0.00686 	 time=2.28s
# Best: Epoch 4 	 loss=0.00636 	 val_loss=0.00635 	 sm_loss=0.00635 	 sm_val_loss=0.00634 	 time=2.27s
# Best: Epoch 5 	 loss=0.00602 	 val_loss=0.00608 	 sm_loss=0.00602 	 sm_val_loss=0.00607 	 time=2.74s
# Best: Epoch 8 	 loss=0.00573 	 val_loss=0.00606 	 sm_loss=0.00576 	 sm_val_loss=0.00607 	 time=2.36s
# Best: Epoch 11 	 loss=0.00557 	 val_loss=0.00597 	 sm_loss=0.00563 	 sm_val_loss=0.00599 	 time=2.19s
# Best: Epoch 12 	 loss=0.00551 	 val_loss=0.00594 	 sm_loss=0.00558 	 sm_val_loss=0.00596 	 time=2.22s
# Best: Epoch 13 	 loss=0.00548 	 val_loss=0.00592 	 sm_loss=0.00556 	 sm_val_loss=0.00594 	 time=2.51s
# Best: Epoch 14 	 loss=0.00541 	 val_loss=0.00593 	 sm_loss=0.00550 	 sm_val_loss=0.00594 	 time=2.56s
# Best: Epoch 15 	 loss=0.00537 	 val_loss=0.00590 	 sm_loss=0.00547 	 sm_val_loss=0.00592 	 time=2.33s
# Best: Epoch 16 	 loss=0.00532 	 val_loss=0.00585 	 sm_loss=0.00544 	 sm_val_loss=0.00589 	 time=2.20s
# Best: Epoch 17 	 loss=0.00529 	 val_loss=0.00584 	 sm_loss=0.00542 	 sm_val_loss=0.00588 	 time=2.26s
# Best: Epoch 18 	 loss=0.00526 	 val_loss=0.00582 	 sm_loss=0.00541 	 sm_val_loss=0.00586 	 time=2.25s
# Best: Epoch 19 	 loss=0.00523 	 val_loss=0.00581 	 sm_loss=0.00539 	 sm_val_loss=0.00583 	 time=2.46s
# Fold 5
# Best: Epoch 1 	 loss=0.28158 	 val_loss=0.01944 	 sm_loss=0.28157 	 sm_val_loss=0.01943 	 time=2.35s
# Best: Epoch 2 	 loss=0.01140 	 val_loss=0.00884 	 sm_loss=0.01139 	 sm_val_loss=0.00883 	 time=2.30s
# Best: Epoch 3 	 loss=0.00709 	 val_loss=0.00741 	 sm_loss=0.00708 	 sm_val_loss=0.00740 	 time=2.36s
# Best: Epoch 4 	 loss=0.00622 	 val_loss=0.00701 	 sm_loss=0.00620 	 sm_val_loss=0.00700 	 time=2.53s
# Best: Epoch 5 	 loss=0.00589 	 val_loss=0.00680 	 sm_loss=0.00589 	 sm_val_loss=0.00681 	 time=2.29s
# Best: Epoch 6 	 loss=0.00574 	 val_loss=0.00674 	 sm_loss=0.00575 	 sm_val_loss=0.00674 	 time=2.43s
# Best: Epoch 7 	 loss=0.00566 	 val_loss=0.00668 	 sm_loss=0.00568 	 sm_val_loss=0.00668 	 time=2.76s
# Best: Epoch 11 	 loss=0.00546 	 val_loss=0.00660 	 sm_loss=0.00551 	 sm_val_loss=0.00661 	 time=2.58s
# Best: Epoch 13 	 loss=0.00534 	 val_loss=0.00653 	 sm_loss=0.00542 	 sm_val_loss=0.00657 	 time=2.52s
# Best: Epoch 14 	 loss=0.00529 	 val_loss=0.00651 	 sm_loss=0.00539 	 sm_val_loss=0.00655 	 time=2.40s
# Best: Epoch 16 	 loss=0.00520 	 val_loss=0.00652 	 sm_loss=0.00532 	 sm_val_loss=0.00654 	 time=2.34s
# Best: Epoch 17 	 loss=0.00516 	 val_loss=0.00650 	 sm_loss=0.00529 	 sm_val_loss=0.00651 	 time=2.61s
# Best: Epoch 20 	 loss=0.00509 	 val_loss=0.00647 	 sm_loss=0.00526 	 sm_val_loss=0.00650 	 time=2.33s
# Fold 6
# Best: Epoch 1 	 loss=0.28230 	 val_loss=0.01913 	 sm_loss=0.28229 	 sm_val_loss=0.01912 	 time=2.48s
# Best: Epoch 2 	 loss=0.01144 	 val_loss=0.00827 	 sm_loss=0.01143 	 sm_val_loss=0.00826 	 time=2.25s
# Best: Epoch 3 	 loss=0.00720 	 val_loss=0.00683 	 sm_loss=0.00719 	 sm_val_loss=0.00681 	 time=2.29s
# Best: Epoch 4 	 loss=0.00632 	 val_loss=0.00652 	 sm_loss=0.00631 	 sm_val_loss=0.00651 	 time=2.29s
# Best: Epoch 5 	 loss=0.00599 	 val_loss=0.00636 	 sm_loss=0.00599 	 sm_val_loss=0.00636 	 time=2.30s
# Best: Epoch 6 	 loss=0.00585 	 val_loss=0.00617 	 sm_loss=0.00585 	 sm_val_loss=0.00617 	 time=2.56s
# Best: Epoch 8 	 loss=0.00571 	 val_loss=0.00611 	 sm_loss=0.00574 	 sm_val_loss=0.00612 	 time=2.24s
# Best: Epoch 9 	 loss=0.00565 	 val_loss=0.00605 	 sm_loss=0.00568 	 sm_val_loss=0.00606 	 time=2.25s
# Best: Epoch 11 	 loss=0.00553 	 val_loss=0.00601 	 sm_loss=0.00558 	 sm_val_loss=0.00602 	 time=2.25s
# Best: Epoch 13 	 loss=0.00544 	 val_loss=0.00599 	 sm_loss=0.00552 	 sm_val_loss=0.00602 	 time=2.38s
# Best: Epoch 16 	 loss=0.00532 	 val_loss=0.00599 	 sm_loss=0.00543 	 sm_val_loss=0.00601 	 time=2.33s
# Best: Epoch 18 	 loss=0.00525 	 val_loss=0.00600 	 sm_loss=0.00539 	 sm_val_loss=0.00600 	 time=2.35s
# Best: Epoch 19 	 loss=0.00522 	 val_loss=0.00596 	 sm_loss=0.00537 	 sm_val_loss=0.00598 	 time=2.62s
# Fold 7
# Best: Epoch 1 	 loss=0.28111 	 val_loss=0.01904 	 sm_loss=0.28110 	 sm_val_loss=0.01903 	 time=2.32s
# Best: Epoch 2 	 loss=0.01141 	 val_loss=0.00831 	 sm_loss=0.01140 	 sm_val_loss=0.00830 	 time=2.34s
# Best: Epoch 3 	 loss=0.00718 	 val_loss=0.00682 	 sm_loss=0.00717 	 sm_val_loss=0.00680 	 time=2.29s
# Best: Epoch 4 	 loss=0.00633 	 val_loss=0.00638 	 sm_loss=0.00631 	 sm_val_loss=0.00638 	 time=2.57s
# Best: Epoch 5 	 loss=0.00602 	 val_loss=0.00629 	 sm_loss=0.00601 	 sm_val_loss=0.00628 	 time=2.74s
# Best: Epoch 6 	 loss=0.00585 	 val_loss=0.00624 	 sm_loss=0.00586 	 sm_val_loss=0.00626 	 time=2.46s
# Best: Epoch 7 	 loss=0.00576 	 val_loss=0.00611 	 sm_loss=0.00577 	 sm_val_loss=0.00612 	 time=2.44s
# Best: Epoch 8 	 loss=0.00568 	 val_loss=0.00610 	 sm_loss=0.00571 	 sm_val_loss=0.00609 	 time=2.62s
# Best: Epoch 10 	 loss=0.00556 	 val_loss=0.00604 	 sm_loss=0.00561 	 sm_val_loss=0.00605 	 time=2.33s
# Best: Epoch 11 	 loss=0.00549 	 val_loss=0.00604 	 sm_loss=0.00555 	 sm_val_loss=0.00605 	 time=2.29s
# Best: Epoch 13 	 loss=0.00541 	 val_loss=0.00600 	 sm_loss=0.00549 	 sm_val_loss=0.00605 	 time=2.34s
# Best: Epoch 14 	 loss=0.00535 	 val_loss=0.00592 	 sm_loss=0.00544 	 sm_val_loss=0.00596 	 time=2.31s
# Best: Epoch 15 	 loss=0.00530 	 val_loss=0.00590 	 sm_loss=0.00542 	 sm_val_loss=0.00594 	 time=2.31s
# Best: Epoch 17 	 loss=0.00524 	 val_loss=0.00589 	 sm_loss=0.00538 	 sm_val_loss=0.00591 	 time=2.57s
# Best: Epoch 18 	 loss=0.00521 	 val_loss=0.00585 	 sm_loss=0.00536 	 sm_val_loss=0.00590 	 time=3.19s
# Best: Epoch 19 	 loss=0.00517 	 val_loss=0.00585 	 sm_loss=0.00533 	 sm_val_loss=0.00589 	 time=2.58s
# Fold 1
# Best: Epoch 1 	 loss=0.65022 	 val_loss=0.30760 	 sm_loss=0.65013 	 sm_val_loss=0.30758 	 time=2.71s
# Best: Epoch 2 	 loss=0.04599 	 val_loss=0.02027 	 sm_loss=0.04572 	 sm_val_loss=0.02029 	 time=2.34s
# Best: Epoch 3 	 loss=0.01930 	 val_loss=0.01968 	 sm_loss=0.01932 	 sm_val_loss=0.01971 	 time=2.36s
# Best: Epoch 5 	 loss=0.01861 	 val_loss=0.01870 	 sm_loss=0.01867 	 sm_val_loss=0.01873 	 time=2.41s
# Best: Epoch 6 	 loss=0.01821 	 val_loss=0.01867 	 sm_loss=0.01829 	 sm_val_loss=0.01868 	 time=2.47s
# Best: Epoch 9 	 loss=0.01804 	 val_loss=0.01850 	 sm_loss=0.01813 	 sm_val_loss=0.01851 	 time=2.27s
# Best: Epoch 10 	 loss=0.01797 	 val_loss=0.01848 	 sm_loss=0.01806 	 sm_val_loss=0.01848 	 time=2.65s
# Best: Epoch 14 	 loss=0.01783 	 val_loss=0.01845 	 sm_loss=0.01793 	 sm_val_loss=0.01844 	 time=2.28s
# Best: Epoch 15 	 loss=0.01783 	 val_loss=0.01840 	 sm_loss=0.01794 	 sm_val_loss=0.01841 	 time=2.58s
# Best: Epoch 16 	 loss=0.01778 	 val_loss=0.01829 	 sm_loss=0.01789 	 sm_val_loss=0.01829 	 time=2.29s
# Best: Epoch 20 	 loss=0.01759 	 val_loss=0.01821 	 sm_loss=0.01771 	 sm_val_loss=0.01821 	 time=2.31s
# Best: Epoch 21 	 loss=0.01754 	 val_loss=0.01817 	 sm_loss=0.01766 	 sm_val_loss=0.01820 	 time=2.25s
# Best: Epoch 22 	 loss=0.01741 	 val_loss=0.01815 	 sm_loss=0.01753 	 sm_val_loss=0.01817 	 time=2.27s
# Best: Epoch 23 	 loss=0.01742 	 val_loss=0.01808 	 sm_loss=0.01755 	 sm_val_loss=0.01807 	 time=2.73s
# Best: Epoch 24 	 loss=0.01735 	 val_loss=0.01795 	 sm_loss=0.01748 	 sm_val_loss=0.01796 	 time=3.27s
# Best: Epoch 26 	 loss=0.01712 	 val_loss=0.01786 	 sm_loss=0.01727 	 sm_val_loss=0.01789 	 time=2.30s
# Best: Epoch 27 	 loss=0.01705 	 val_loss=0.01780 	 sm_loss=0.01720 	 sm_val_loss=0.01782 	 time=2.29s
# Best: Epoch 29 	 loss=0.01680 	 val_loss=0.01772 	 sm_loss=0.01696 	 sm_val_loss=0.01777 	 time=2.28s
# Best: Epoch 30 	 loss=0.01676 	 val_loss=0.01770 	 sm_loss=0.01692 	 sm_val_loss=0.01774 	 time=2.31s
# Best: Epoch 31 	 loss=0.01661 	 val_loss=0.01762 	 sm_loss=0.01679 	 sm_val_loss=0.01765 	 time=2.29s
# Best: Epoch 33 	 loss=0.01643 	 val_loss=0.01760 	 sm_loss=0.01661 	 sm_val_loss=0.01764 	 time=2.52s
# Best: Epoch 34 	 loss=0.01631 	 val_loss=0.01749 	 sm_loss=0.01649 	 sm_val_loss=0.01754 	 time=2.33s
# Best: Epoch 37 	 loss=0.01611 	 val_loss=0.01749 	 sm_loss=0.01630 	 sm_val_loss=0.01753 	 time=2.79s
# Best: Epoch 40 	 loss=0.01601 	 val_loss=0.01749 	 sm_loss=0.01621 	 sm_val_loss=0.01752 	 time=2.34s
# Fold 1 log loss: 0.01759960374674056
# Fold 2
# Best: Epoch 1 	 loss=0.64939 	 val_loss=0.31738 	 sm_loss=0.64936 	 sm_val_loss=0.31723 	 time=2.90s
# Best: Epoch 2 	 loss=0.04389 	 val_loss=0.01950 	 sm_loss=0.04381 	 sm_val_loss=0.01952 	 time=2.59s
# Best: Epoch 3 	 loss=0.01908 	 val_loss=0.01873 	 sm_loss=0.01910 	 sm_val_loss=0.01877 	 time=2.43s
# Best: Epoch 4 	 loss=0.01868 	 val_loss=0.01816 	 sm_loss=0.01872 	 sm_val_loss=0.01819 	 time=2.30s
# Best: Epoch 5 	 loss=0.01837 	 val_loss=0.01809 	 sm_loss=0.01843 	 sm_val_loss=0.01814 	 time=2.32s
# Best: Epoch 7 	 loss=0.01812 	 val_loss=0.01797 	 sm_loss=0.01820 	 sm_val_loss=0.01803 	 time=2.28s
# Best: Epoch 8 	 loss=0.01805 	 val_loss=0.01773 	 sm_loss=0.01813 	 sm_val_loss=0.01778 	 time=2.30s
# Best: Epoch 16 	 loss=0.01792 	 val_loss=0.01763 	 sm_loss=0.01802 	 sm_val_loss=0.01769 	 time=2.26s
# Best: Epoch 20 	 loss=0.01772 	 val_loss=0.01761 	 sm_loss=0.01782 	 sm_val_loss=0.01767 	 time=2.53s
# Best: Epoch 21 	 loss=0.01770 	 val_loss=0.01748 	 sm_loss=0.01780 	 sm_val_loss=0.01753 	 time=2.37s
# Best: Epoch 23 	 loss=0.01750 	 val_loss=0.01737 	 sm_loss=0.01762 	 sm_val_loss=0.01742 	 time=2.71s
# Best: Epoch 24 	 loss=0.01747 	 val_loss=0.01729 	 sm_loss=0.01759 	 sm_val_loss=0.01740 	 time=2.67s
# Best: Epoch 25 	 loss=0.01735 	 val_loss=0.01728 	 sm_loss=0.01748 	 sm_val_loss=0.01737 	 time=2.55s
# Best: Epoch 26 	 loss=0.01725 	 val_loss=0.01724 	 sm_loss=0.01738 	 sm_val_loss=0.01730 	 time=2.46s
# Best: Epoch 28 	 loss=0.01708 	 val_loss=0.01715 	 sm_loss=0.01722 	 sm_val_loss=0.01724 	 time=2.58s
# Best: Epoch 29 	 loss=0.01698 	 val_loss=0.01700 	 sm_loss=0.01712 	 sm_val_loss=0.01708 	 time=2.37s
# Best: Epoch 31 	 loss=0.01676 	 val_loss=0.01690 	 sm_loss=0.01692 	 sm_val_loss=0.01699 	 time=2.35s
# Best: Epoch 32 	 loss=0.01663 	 val_loss=0.01684 	 sm_loss=0.01679 	 sm_val_loss=0.01693 	 time=2.57s
# Best: Epoch 33 	 loss=0.01654 	 val_loss=0.01683 	 sm_loss=0.01671 	 sm_val_loss=0.01691 	 time=2.32s
# Best: Epoch 34 	 loss=0.01642 	 val_loss=0.01677 	 sm_loss=0.01660 	 sm_val_loss=0.01685 	 time=2.27s
# Best: Epoch 36 	 loss=0.01625 	 val_loss=0.01674 	 sm_loss=0.01644 	 sm_val_loss=0.01683 	 time=2.30s
# Best: Epoch 37 	 loss=0.01618 	 val_loss=0.01672 	 sm_loss=0.01637 	 sm_val_loss=0.01680 	 time=2.74s
# Best: Epoch 38 	 loss=0.01612 	 val_loss=0.01670 	 sm_loss=0.01631 	 sm_val_loss=0.01679 	 time=2.29s
# Fold 2 log loss: 0.01680677777811255
# Fold 3
# Best: Epoch 1 	 loss=0.64912 	 val_loss=0.29601 	 sm_loss=0.64909 	 sm_val_loss=0.29583 	 time=2.64s
# Best: Epoch 2 	 loss=0.04569 	 val_loss=0.02032 	 sm_loss=0.04562 	 sm_val_loss=0.02032 	 time=2.32s
# Best: Epoch 3 	 loss=0.01914 	 val_loss=0.01911 	 sm_loss=0.01917 	 sm_val_loss=0.01912 	 time=2.82s
# Best: Epoch 5 	 loss=0.01833 	 val_loss=0.01906 	 sm_loss=0.01840 	 sm_val_loss=0.01907 	 time=2.38s
# Best: Epoch 6 	 loss=0.01806 	 val_loss=0.01844 	 sm_loss=0.01813 	 sm_val_loss=0.01848 	 time=2.71s
# Best: Epoch 12 	 loss=0.01783 	 val_loss=0.01842 	 sm_loss=0.01793 	 sm_val_loss=0.01840 	 time=2.51s
# Best: Epoch 16 	 loss=0.01766 	 val_loss=0.01840 	 sm_loss=0.01777 	 sm_val_loss=0.01836 	 time=2.30s
# Best: Epoch 20 	 loss=0.01746 	 val_loss=0.01834 	 sm_loss=0.01759 	 sm_val_loss=0.01832 	 time=2.39s
# Best: Epoch 22 	 loss=0.01735 	 val_loss=0.01822 	 sm_loss=0.01748 	 sm_val_loss=0.01820 	 time=2.45s
# Best: Epoch 23 	 loss=0.01731 	 val_loss=0.01811 	 sm_loss=0.01744 	 sm_val_loss=0.01811 	 time=2.85s
# Best: Epoch 25 	 loss=0.01712 	 val_loss=0.01811 	 sm_loss=0.01726 	 sm_val_loss=0.01810 	 time=2.90s
# Best: Epoch 26 	 loss=0.01694 	 val_loss=0.01800 	 sm_loss=0.01709 	 sm_val_loss=0.01798 	 time=2.50s
# Best: Epoch 27 	 loss=0.01688 	 val_loss=0.01795 	 sm_loss=0.01705 	 sm_val_loss=0.01793 	 time=2.35s
# Best: Epoch 29 	 loss=0.01666 	 val_loss=0.01789 	 sm_loss=0.01682 	 sm_val_loss=0.01787 	 time=2.29s
# Best: Epoch 30 	 loss=0.01661 	 val_loss=0.01786 	 sm_loss=0.01679 	 sm_val_loss=0.01782 	 time=2.61s
# Best: Epoch 31 	 loss=0.01645 	 val_loss=0.01778 	 sm_loss=0.01662 	 sm_val_loss=0.01776 	 time=2.36s
# Best: Epoch 32 	 loss=0.01631 	 val_loss=0.01777 	 sm_loss=0.01649 	 sm_val_loss=0.01775 	 time=2.67s
# Best: Epoch 33 	 loss=0.01622 	 val_loss=0.01777 	 sm_loss=0.01642 	 sm_val_loss=0.01773 	 time=2.32s
# Best: Epoch 35 	 loss=0.01602 	 val_loss=0.01769 	 sm_loss=0.01622 	 sm_val_loss=0.01765 	 time=2.34s
# Best: Epoch 36 	 loss=0.01595 	 val_loss=0.01766 	 sm_loss=0.01615 	 sm_val_loss=0.01763 	 time=2.35s
# Fold 3 log loss: 0.017630136931717763
# Fold 4
# Best: Epoch 1 	 loss=0.65125 	 val_loss=0.31821 	 sm_loss=0.65125 	 sm_val_loss=0.31821 	 time=2.33s
# Best: Epoch 2 	 loss=0.04711 	 val_loss=0.01950 	 sm_loss=0.04711 	 sm_val_loss=0.01952 	 time=2.60s
# Best: Epoch 3 	 loss=0.01898 	 val_loss=0.01854 	 sm_loss=0.01901 	 sm_val_loss=0.01859 	 time=2.32s
# Best: Epoch 4 	 loss=0.01860 	 val_loss=0.01833 	 sm_loss=0.01865 	 sm_val_loss=0.01838 	 time=2.34s
# Best: Epoch 5 	 loss=0.01827 	 val_loss=0.01786 	 sm_loss=0.01835 	 sm_val_loss=0.01791 	 time=2.31s
# Best: Epoch 6 	 loss=0.01808 	 val_loss=0.01781 	 sm_loss=0.01816 	 sm_val_loss=0.01785 	 time=2.58s
# Best: Epoch 7 	 loss=0.01808 	 val_loss=0.01775 	 sm_loss=0.01817 	 sm_val_loss=0.01780 	 time=2.31s
# Best: Epoch 14 	 loss=0.01787 	 val_loss=0.01764 	 sm_loss=0.01798 	 sm_val_loss=0.01770 	 time=2.42s
# Best: Epoch 17 	 loss=0.01777 	 val_loss=0.01751 	 sm_loss=0.01787 	 sm_val_loss=0.01757 	 time=2.28s
# Best: Epoch 19 	 loss=0.01762 	 val_loss=0.01749 	 sm_loss=0.01773 	 sm_val_loss=0.01756 	 time=2.30s
# Best: Epoch 21 	 loss=0.01747 	 val_loss=0.01745 	 sm_loss=0.01759 	 sm_val_loss=0.01751 	 time=3.25s
# Best: Epoch 24 	 loss=0.01728 	 val_loss=0.01734 	 sm_loss=0.01741 	 sm_val_loss=0.01740 	 time=2.79s
# Best: Epoch 27 	 loss=0.01699 	 val_loss=0.01732 	 sm_loss=0.01714 	 sm_val_loss=0.01738 	 time=2.26s
# Best: Epoch 28 	 loss=0.01693 	 val_loss=0.01727 	 sm_loss=0.01709 	 sm_val_loss=0.01733 	 time=2.53s
# Best: Epoch 29 	 loss=0.01679 	 val_loss=0.01720 	 sm_loss=0.01694 	 sm_val_loss=0.01724 	 time=2.31s
# Best: Epoch 31 	 loss=0.01658 	 val_loss=0.01712 	 sm_loss=0.01675 	 sm_val_loss=0.01719 	 time=2.26s
# Best: Epoch 32 	 loss=0.01647 	 val_loss=0.01708 	 sm_loss=0.01664 	 sm_val_loss=0.01715 	 time=2.33s
# Best: Epoch 33 	 loss=0.01637 	 val_loss=0.01707 	 sm_loss=0.01655 	 sm_val_loss=0.01714 	 time=2.67s
# Best: Epoch 34 	 loss=0.01627 	 val_loss=0.01698 	 sm_loss=0.01645 	 sm_val_loss=0.01705 	 time=2.69s
# Best: Epoch 35 	 loss=0.01618 	 val_loss=0.01696 	 sm_loss=0.01637 	 sm_val_loss=0.01704 	 time=2.34s
# Best: Epoch 36 	 loss=0.01611 	 val_loss=0.01694 	 sm_loss=0.01630 	 sm_val_loss=0.01701 	 time=2.36s
# Fold 4 log loss: 0.0170401711529069
# Fold 5
# Best: Epoch 1 	 loss=0.65009 	 val_loss=0.28312 	 sm_loss=0.65009 	 sm_val_loss=0.28312 	 time=2.74s
# Best: Epoch 2 	 loss=0.04439 	 val_loss=0.01918 	 sm_loss=0.04439 	 sm_val_loss=0.01920 	 time=2.33s
# Best: Epoch 3 	 loss=0.01912 	 val_loss=0.01925 	 sm_loss=0.01914 	 sm_val_loss=0.01917 	 time=2.35s
# Best: Epoch 4 	 loss=0.01852 	 val_loss=0.01819 	 sm_loss=0.01857 	 sm_val_loss=0.01821 	 time=2.33s
# Best: Epoch 5 	 loss=0.01826 	 val_loss=0.01793 	 sm_loss=0.01833 	 sm_val_loss=0.01800 	 time=3.15s
# Best: Epoch 6 	 loss=0.01813 	 val_loss=0.01789 	 sm_loss=0.01820 	 sm_val_loss=0.01796 	 time=2.97s
# Best: Epoch 7 	 loss=0.01804 	 val_loss=0.01736 	 sm_loss=0.01812 	 sm_val_loss=0.01741 	 time=2.43s
# Best: Epoch 22 	 loss=0.01752 	 val_loss=0.01731 	 sm_loss=0.01764 	 sm_val_loss=0.01735 	 time=2.29s
# Best: Epoch 25 	 loss=0.01725 	 val_loss=0.01714 	 sm_loss=0.01738 	 sm_val_loss=0.01718 	 time=2.33s
# Best: Epoch 27 	 loss=0.01706 	 val_loss=0.01703 	 sm_loss=0.01721 	 sm_val_loss=0.01711 	 time=2.31s
# Best: Epoch 29 	 loss=0.01679 	 val_loss=0.01694 	 sm_loss=0.01695 	 sm_val_loss=0.01701 	 time=3.05s
# Best: Epoch 33 	 loss=0.01639 	 val_loss=0.01685 	 sm_loss=0.01657 	 sm_val_loss=0.01692 	 time=2.38s
# Best: Epoch 34 	 loss=0.01629 	 val_loss=0.01685 	 sm_loss=0.01648 	 sm_val_loss=0.01691 	 time=2.34s
# Best: Epoch 35 	 loss=0.01618 	 val_loss=0.01682 	 sm_loss=0.01638 	 sm_val_loss=0.01688 	 time=2.41s
# Best: Epoch 37 	 loss=0.01603 	 val_loss=0.01677 	 sm_loss=0.01623 	 sm_val_loss=0.01686 	 time=2.41s
# Best: Epoch 38 	 loss=0.01597 	 val_loss=0.01677 	 sm_loss=0.01617 	 sm_val_loss=0.01685 	 time=2.41s
# Fold 5 log loss: 0.016859304013400918
# Fold 6
# Best: Epoch 1 	 loss=0.65004 	 val_loss=0.27278 	 sm_loss=0.65004 	 sm_val_loss=0.27277 	 time=2.43s
# Best: Epoch 2 	 loss=0.04409 	 val_loss=0.02021 	 sm_loss=0.04409 	 sm_val_loss=0.02016 	 time=2.44s
# Best: Epoch 3 	 loss=0.01883 	 val_loss=0.02018 	 sm_loss=0.01887 	 sm_val_loss=0.02008 	 time=2.71s
# Best: Epoch 4 	 loss=0.01833 	 val_loss=0.01951 	 sm_loss=0.01839 	 sm_val_loss=0.01942 	 time=2.76s
# Best: Epoch 6 	 loss=0.01800 	 val_loss=0.01922 	 sm_loss=0.01807 	 sm_val_loss=0.01920 	 time=2.38s
# Best: Epoch 8 	 loss=0.01776 	 val_loss=0.01919 	 sm_loss=0.01785 	 sm_val_loss=0.01912 	 time=2.54s
# Best: Epoch 11 	 loss=0.01770 	 val_loss=0.01906 	 sm_loss=0.01780 	 sm_val_loss=0.01903 	 time=2.27s
# Best: Epoch 12 	 loss=0.01774 	 val_loss=0.01900 	 sm_loss=0.01785 	 sm_val_loss=0.01895 	 time=2.84s
# Best: Epoch 19 	 loss=0.01748 	 val_loss=0.01901 	 sm_loss=0.01761 	 sm_val_loss=0.01889 	 time=2.39s
# Best: Epoch 20 	 loss=0.01743 	 val_loss=0.01877 	 sm_loss=0.01755 	 sm_val_loss=0.01864 	 time=2.43s
# Best: Epoch 24 	 loss=0.01716 	 val_loss=0.01872 	 sm_loss=0.01729 	 sm_val_loss=0.01862 	 time=2.32s
# Best: Epoch 27 	 loss=0.01687 	 val_loss=0.01871 	 sm_loss=0.01703 	 sm_val_loss=0.01862 	 time=2.26s
# Best: Epoch 30 	 loss=0.01657 	 val_loss=0.01861 	 sm_loss=0.01674 	 sm_val_loss=0.01859 	 time=2.43s
# Best: Epoch 31 	 loss=0.01642 	 val_loss=0.01852 	 sm_loss=0.01659 	 sm_val_loss=0.01846 	 time=2.47s
# Best: Epoch 32 	 loss=0.01634 	 val_loss=0.01853 	 sm_loss=0.01652 	 sm_val_loss=0.01845 	 time=2.34s
# Best: Epoch 34 	 loss=0.01615 	 val_loss=0.01842 	 sm_loss=0.01634 	 sm_val_loss=0.01835 	 time=2.28s
# Best: Epoch 39 	 loss=0.01578 	 val_loss=0.01840 	 sm_loss=0.01599 	 sm_val_loss=0.01834 	 time=2.62s
# Fold 6 log loss: 0.01839108405717928
# Fold 7
# Best: Epoch 1 	 loss=0.64799 	 val_loss=0.30118 	 sm_loss=0.64797 	 sm_val_loss=0.29583 	 time=2.70s
# Best: Epoch 2 	 loss=0.04455 	 val_loss=0.01998 	 sm_loss=0.04442 	 sm_val_loss=0.01998 	 time=2.30s
# Best: Epoch 3 	 loss=0.01917 	 val_loss=0.01983 	 sm_loss=0.01919 	 sm_val_loss=0.01973 	 time=2.55s
# Best: Epoch 4 	 loss=0.01867 	 val_loss=0.01905 	 sm_loss=0.01871 	 sm_val_loss=0.01905 	 time=2.33s
# Best: Epoch 5 	 loss=0.01825 	 val_loss=0.01863 	 sm_loss=0.01831 	 sm_val_loss=0.01864 	 time=2.48s
# Best: Epoch 8 	 loss=0.01793 	 val_loss=0.01862 	 sm_loss=0.01802 	 sm_val_loss=0.01862 	 time=2.29s
# Best: Epoch 9 	 loss=0.01785 	 val_loss=0.01846 	 sm_loss=0.01794 	 sm_val_loss=0.01847 	 time=2.36s
# Best: Epoch 13 	 loss=0.01774 	 val_loss=0.01843 	 sm_loss=0.01784 	 sm_val_loss=0.01845 	 time=2.34s
# Best: Epoch 16 	 loss=0.01770 	 val_loss=0.01841 	 sm_loss=0.01781 	 sm_val_loss=0.01840 	 time=2.56s
# Best: Epoch 20 	 loss=0.01746 	 val_loss=0.01822 	 sm_loss=0.01758 	 sm_val_loss=0.01825 	 time=2.30s
# Best: Epoch 21 	 loss=0.01737 	 val_loss=0.01817 	 sm_loss=0.01749 	 sm_val_loss=0.01814 	 time=2.90s
# Best: Epoch 24 	 loss=0.01715 	 val_loss=0.01803 	 sm_loss=0.01729 	 sm_val_loss=0.01803 	 time=2.25s
# Best: Epoch 25 	 loss=0.01711 	 val_loss=0.01801 	 sm_loss=0.01725 	 sm_val_loss=0.01802 	 time=2.52s
# Best: Epoch 26 	 loss=0.01699 	 val_loss=0.01801 	 sm_loss=0.01714 	 sm_val_loss=0.01802 	 time=2.29s
# Best: Epoch 27 	 loss=0.01692 	 val_loss=0.01789 	 sm_loss=0.01707 	 sm_val_loss=0.01790 	 time=2.68s
# Best: Epoch 28 	 loss=0.01683 	 val_loss=0.01785 	 sm_loss=0.01699 	 sm_val_loss=0.01785 	 time=2.29s
# Best: Epoch 30 	 loss=0.01661 	 val_loss=0.01774 	 sm_loss=0.01679 	 sm_val_loss=0.01773 	 time=2.47s
# Best: Epoch 31 	 loss=0.01652 	 val_loss=0.01770 	 sm_loss=0.01669 	 sm_val_loss=0.01770 	 time=2.39s
# Best: Epoch 32 	 loss=0.01639 	 val_loss=0.01767 	 sm_loss=0.01658 	 sm_val_loss=0.01768 	 time=2.37s
# Best: Epoch 33 	 loss=0.01629 	 val_loss=0.01766 	 sm_loss=0.01647 	 sm_val_loss=0.01767 	 time=2.33s
# Best: Epoch 34 	 loss=0.01618 	 val_loss=0.01762 	 sm_loss=0.01637 	 sm_val_loss=0.01762 	 time=2.61s
# Best: Epoch 36 	 loss=0.01602 	 val_loss=0.01758 	 sm_loss=0.01623 	 sm_val_loss=0.01758 	 time=2.34s
# Best: Epoch 37 	 loss=0.01594 	 val_loss=0.01757 	 sm_loss=0.01614 	 sm_val_loss=0.01756 	 time=2.31s
# Best: Epoch 38 	 loss=0.01594 	 val_loss=0.01757 	 sm_loss=0.01615 	 sm_val_loss=0.01756 	 time=2.30s
# Best: Epoch 39 	 loss=0.01588 	 val_loss=0.01755 	 sm_loss=0.01609 	 sm_val_loss=0.01755 	 time=2.58s
# Best: Epoch 40 	 loss=0.01586 	 val_loss=0.01755 	 sm_loss=0.01607 	 sm_val_loss=0.01754 	 time=2.67s
# Fold 7 log loss: 0.017524787469950315
# Seed 0
# Fold 1 log loss: 0.01759960374674056
# Fold 2 log loss: 0.01680677777811255
# Fold 3 log loss: 0.017630136931717763
# Fold 4 log loss: 0.0170401711529069
# Fold 5 log loss: 0.016859304013400918
# Fold 6 log loss: 0.01839108405717928
# Fold 7 log loss: 0.017524787469950315
# Std of log loss: 0.0005160262248241967
# Total log loss: 0.017409093388558207
# Fold 1
# Best: Epoch 1 	 loss=0.28141 	 val_loss=0.01866 	 sm_loss=0.28140 	 sm_val_loss=0.01865 	 time=2.32s
# Best: Epoch 2 	 loss=0.01157 	 val_loss=0.00760 	 sm_loss=0.01156 	 sm_val_loss=0.00758 	 time=2.59s
# Best: Epoch 3 	 loss=0.00731 	 val_loss=0.00598 	 sm_loss=0.00730 	 sm_val_loss=0.00596 	 time=2.71s
# Best: Epoch 4 	 loss=0.00645 	 val_loss=0.00560 	 sm_loss=0.00644 	 sm_val_loss=0.00559 	 time=2.38s
# Best: Epoch 5 	 loss=0.00613 	 val_loss=0.00538 	 sm_loss=0.00613 	 sm_val_loss=0.00539 	 time=2.33s
# Best: Epoch 6 	 loss=0.00600 	 val_loss=0.00534 	 sm_loss=0.00601 	 sm_val_loss=0.00534 	 time=2.33s
# Best: Epoch 7 	 loss=0.00591 	 val_loss=0.00531 	 sm_loss=0.00593 	 sm_val_loss=0.00531 	 time=2.58s
# Best: Epoch 8 	 loss=0.00586 	 val_loss=0.00526 	 sm_loss=0.00589 	 sm_val_loss=0.00526 	 time=2.40s
# Best: Epoch 9 	 loss=0.00580 	 val_loss=0.00525 	 sm_loss=0.00584 	 sm_val_loss=0.00526 	 time=2.36s
# Best: Epoch 10 	 loss=0.00576 	 val_loss=0.00521 	 sm_loss=0.00581 	 sm_val_loss=0.00523 	 time=2.35s
# Best: Epoch 12 	 loss=0.00568 	 val_loss=0.00518 	 sm_loss=0.00574 	 sm_val_loss=0.00519 	 time=2.37s
# Best: Epoch 14 	 loss=0.00557 	 val_loss=0.00514 	 sm_loss=0.00565 	 sm_val_loss=0.00517 	 time=2.34s
# Best: Epoch 15 	 loss=0.00551 	 val_loss=0.00513 	 sm_loss=0.00560 	 sm_val_loss=0.00516 	 time=2.38s
# Best: Epoch 16 	 loss=0.00548 	 val_loss=0.00510 	 sm_loss=0.00559 	 sm_val_loss=0.00514 	 time=3.00s
# Best: Epoch 18 	 loss=0.00542 	 val_loss=0.00505 	 sm_loss=0.00555 	 sm_val_loss=0.00511 	 time=2.96s
# Best: Epoch 20 	 loss=0.00533 	 val_loss=0.00505 	 sm_loss=0.00549 	 sm_val_loss=0.00509 	 time=2.85s
# Fold 2
# Best: Epoch 1 	 loss=0.28256 	 val_loss=0.01919 	 sm_loss=0.28255 	 sm_val_loss=0.01918 	 time=2.35s
# Best: Epoch 2 	 loss=0.01176 	 val_loss=0.00789 	 sm_loss=0.01175 	 sm_val_loss=0.00788 	 time=2.35s
# Best: Epoch 3 	 loss=0.00734 	 val_loss=0.00633 	 sm_loss=0.00733 	 sm_val_loss=0.00631 	 time=2.31s
# Best: Epoch 4 	 loss=0.00643 	 val_loss=0.00590 	 sm_loss=0.00642 	 sm_val_loss=0.00589 	 time=2.59s
# Best: Epoch 5 	 loss=0.00610 	 val_loss=0.00575 	 sm_loss=0.00610 	 sm_val_loss=0.00574 	 time=2.32s
# Best: Epoch 6 	 loss=0.00593 	 val_loss=0.00569 	 sm_loss=0.00594 	 sm_val_loss=0.00570 	 time=2.33s
# Best: Epoch 7 	 loss=0.00583 	 val_loss=0.00555 	 sm_loss=0.00585 	 sm_val_loss=0.00556 	 time=2.32s
# Best: Epoch 9 	 loss=0.00570 	 val_loss=0.00554 	 sm_loss=0.00574 	 sm_val_loss=0.00555 	 time=3.20s
# Best: Epoch 11 	 loss=0.00558 	 val_loss=0.00552 	 sm_loss=0.00564 	 sm_val_loss=0.00555 	 time=2.32s
# Best: Epoch 12 	 loss=0.00554 	 val_loss=0.00542 	 sm_loss=0.00561 	 sm_val_loss=0.00546 	 time=2.32s
# Epoch    16: reducing learning rate of group 0 to 1.0000e-04.
# Fold 3
# Best: Epoch 1 	 loss=0.28392 	 val_loss=0.01952 	 sm_loss=0.28392 	 sm_val_loss=0.01951 	 time=2.34s
# Best: Epoch 2 	 loss=0.01154 	 val_loss=0.00823 	 sm_loss=0.01152 	 sm_val_loss=0.00822 	 time=3.95s
# Best: Epoch 3 	 loss=0.00719 	 val_loss=0.00689 	 sm_loss=0.00718 	 sm_val_loss=0.00688 	 time=2.40s
# Best: Epoch 4 	 loss=0.00632 	 val_loss=0.00645 	 sm_loss=0.00631 	 sm_val_loss=0.00644 	 time=2.42s
# Best: Epoch 5 	 loss=0.00600 	 val_loss=0.00633 	 sm_loss=0.00600 	 sm_val_loss=0.00633 	 time=2.33s
# Best: Epoch 6 	 loss=0.00587 	 val_loss=0.00624 	 sm_loss=0.00587 	 sm_val_loss=0.00624 	 time=2.64s
# Best: Epoch 7 	 loss=0.00578 	 val_loss=0.00616 	 sm_loss=0.00580 	 sm_val_loss=0.00618 	 time=2.32s
# Best: Epoch 9 	 loss=0.00565 	 val_loss=0.00612 	 sm_loss=0.00568 	 sm_val_loss=0.00613 	 time=2.31s
# Best: Epoch 11 	 loss=0.00555 	 val_loss=0.00608 	 sm_loss=0.00560 	 sm_val_loss=0.00610 	 time=2.30s
# Best: Epoch 13 	 loss=0.00544 	 val_loss=0.00604 	 sm_loss=0.00552 	 sm_val_loss=0.00607 	 time=2.32s
# Best: Epoch 15 	 loss=0.00536 	 val_loss=0.00603 	 sm_loss=0.00546 	 sm_val_loss=0.00606 	 time=2.78s
# Best: Epoch 16 	 loss=0.00531 	 val_loss=0.00597 	 sm_loss=0.00542 	 sm_val_loss=0.00602 	 time=2.27s
# Best: Epoch 18 	 loss=0.00526 	 val_loss=0.00594 	 sm_loss=0.00539 	 sm_val_loss=0.00598 	 time=2.28s
# Fold 4
# Best: Epoch 1 	 loss=0.28112 	 val_loss=0.01899 	 sm_loss=0.28112 	 sm_val_loss=0.01898 	 time=2.26s
# Best: Epoch 2 	 loss=0.01136 	 val_loss=0.00810 	 sm_loss=0.01135 	 sm_val_loss=0.00809 	 time=2.31s
# Best: Epoch 3 	 loss=0.00719 	 val_loss=0.00686 	 sm_loss=0.00718 	 sm_val_loss=0.00684 	 time=2.33s
# Best: Epoch 4 	 loss=0.00634 	 val_loss=0.00647 	 sm_loss=0.00633 	 sm_val_loss=0.00646 	 time=2.59s
# Best: Epoch 5 	 loss=0.00603 	 val_loss=0.00623 	 sm_loss=0.00603 	 sm_val_loss=0.00624 	 time=2.38s
# Best: Epoch 6 	 loss=0.00586 	 val_loss=0.00606 	 sm_loss=0.00587 	 sm_val_loss=0.00606 	 time=2.78s
# Best: Epoch 8 	 loss=0.00571 	 val_loss=0.00607 	 sm_loss=0.00574 	 sm_val_loss=0.00605 	 time=3.24s
# Best: Epoch 10 	 loss=0.00561 	 val_loss=0.00599 	 sm_loss=0.00565 	 sm_val_loss=0.00601 	 time=2.30s
# Best: Epoch 11 	 loss=0.00556 	 val_loss=0.00596 	 sm_loss=0.00561 	 sm_val_loss=0.00597 	 time=2.28s
# Best: Epoch 12 	 loss=0.00551 	 val_loss=0.00594 	 sm_loss=0.00557 	 sm_val_loss=0.00596 	 time=2.30s
# Best: Epoch 14 	 loss=0.00541 	 val_loss=0.00591 	 sm_loss=0.00550 	 sm_val_loss=0.00593 	 time=2.31s
# Best: Epoch 15 	 loss=0.00536 	 val_loss=0.00590 	 sm_loss=0.00546 	 sm_val_loss=0.00592 	 time=2.29s
# Best: Epoch 18 	 loss=0.00527 	 val_loss=0.00585 	 sm_loss=0.00541 	 sm_val_loss=0.00589 	 time=2.28s
# Best: Epoch 20 	 loss=0.00521 	 val_loss=0.00587 	 sm_loss=0.00537 	 sm_val_loss=0.00588 	 time=2.29s
# Fold 5
# Best: Epoch 1 	 loss=0.28275 	 val_loss=0.01998 	 sm_loss=0.28275 	 sm_val_loss=0.01997 	 time=2.71s
# Best: Epoch 2 	 loss=0.01137 	 val_loss=0.00878 	 sm_loss=0.01136 	 sm_val_loss=0.00877 	 time=2.52s
# Best: Epoch 3 	 loss=0.00709 	 val_loss=0.00742 	 sm_loss=0.00707 	 sm_val_loss=0.00741 	 time=2.29s
# Best: Epoch 4 	 loss=0.00624 	 val_loss=0.00693 	 sm_loss=0.00623 	 sm_val_loss=0.00692 	 time=2.29s
# Best: Epoch 5 	 loss=0.00592 	 val_loss=0.00678 	 sm_loss=0.00592 	 sm_val_loss=0.00678 	 time=2.30s
# Best: Epoch 7 	 loss=0.00569 	 val_loss=0.00673 	 sm_loss=0.00570 	 sm_val_loss=0.00674 	 time=2.27s
# Best: Epoch 8 	 loss=0.00562 	 val_loss=0.00668 	 sm_loss=0.00564 	 sm_val_loss=0.00671 	 time=2.27s
# Best: Epoch 9 	 loss=0.00558 	 val_loss=0.00667 	 sm_loss=0.00561 	 sm_val_loss=0.00667 	 time=2.35s
# Best: Epoch 11 	 loss=0.00548 	 val_loss=0.00665 	 sm_loss=0.00553 	 sm_val_loss=0.00665 	 time=3.51s
# Best: Epoch 12 	 loss=0.00541 	 val_loss=0.00658 	 sm_loss=0.00548 	 sm_val_loss=0.00661 	 time=2.50s
# Best: Epoch 14 	 loss=0.00531 	 val_loss=0.00654 	 sm_loss=0.00540 	 sm_val_loss=0.00657 	 time=2.42s
# Best: Epoch 15 	 loss=0.00529 	 val_loss=0.00652 	 sm_loss=0.00539 	 sm_val_loss=0.00655 	 time=2.60s
# Best: Epoch 16 	 loss=0.00526 	 val_loss=0.00651 	 sm_loss=0.00537 	 sm_val_loss=0.00652 	 time=2.30s
# Best: Epoch 17 	 loss=0.00521 	 val_loss=0.00646 	 sm_loss=0.00533 	 sm_val_loss=0.00650 	 time=2.27s
# Best: Epoch 19 	 loss=0.00514 	 val_loss=0.00646 	 sm_loss=0.00529 	 sm_val_loss=0.00648 	 time=2.52s
# Best: Epoch 20 	 loss=0.00512 	 val_loss=0.00642 	 sm_loss=0.00528 	 sm_val_loss=0.00644 	 time=2.29s
# Fold 6
# Best: Epoch 1 	 loss=0.28309 	 val_loss=0.01949 	 sm_loss=0.28308 	 sm_val_loss=0.01948 	 time=2.29s
# Best: Epoch 2 	 loss=0.01152 	 val_loss=0.00835 	 sm_loss=0.01151 	 sm_val_loss=0.00834 	 time=2.30s
# Best: Epoch 3 	 loss=0.00721 	 val_loss=0.00690 	 sm_loss=0.00719 	 sm_val_loss=0.00689 	 time=2.30s
# Best: Epoch 4 	 loss=0.00633 	 val_loss=0.00640 	 sm_loss=0.00632 	 sm_val_loss=0.00639 	 time=2.52s
# Best: Epoch 5 	 loss=0.00600 	 val_loss=0.00635 	 sm_loss=0.00600 	 sm_val_loss=0.00635 	 time=2.32s
# Best: Epoch 6 	 loss=0.00586 	 val_loss=0.00623 	 sm_loss=0.00586 	 sm_val_loss=0.00623 	 time=2.62s
# Best: Epoch 7 	 loss=0.00576 	 val_loss=0.00618 	 sm_loss=0.00578 	 sm_val_loss=0.00619 	 time=2.36s
# Best: Epoch 9 	 loss=0.00566 	 val_loss=0.00613 	 sm_loss=0.00569 	 sm_val_loss=0.00615 	 time=2.31s
# Best: Epoch 10 	 loss=0.00561 	 val_loss=0.00614 	 sm_loss=0.00565 	 sm_val_loss=0.00614 	 time=2.31s
# Best: Epoch 11 	 loss=0.00556 	 val_loss=0.00605 	 sm_loss=0.00561 	 sm_val_loss=0.00608 	 time=2.34s
# Best: Epoch 13 	 loss=0.00548 	 val_loss=0.00603 	 sm_loss=0.00556 	 sm_val_loss=0.00606 	 time=2.59s
# Best: Epoch 14 	 loss=0.00544 	 val_loss=0.00596 	 sm_loss=0.00553 	 sm_val_loss=0.00598 	 time=2.63s
# Best: Epoch 16 	 loss=0.00534 	 val_loss=0.00595 	 sm_loss=0.00545 	 sm_val_loss=0.00597 	 time=2.41s
# Best: Epoch 17 	 loss=0.00531 	 val_loss=0.00592 	 sm_loss=0.00543 	 sm_val_loss=0.00595 	 time=2.79s
# Best: Epoch 18 	 loss=0.00528 	 val_loss=0.00589 	 sm_loss=0.00541 	 sm_val_loss=0.00594 	 time=2.38s
# Fold 7
# Best: Epoch 1 	 loss=0.28390 	 val_loss=0.01937 	 sm_loss=0.28390 	 sm_val_loss=0.01936 	 time=2.49s
# Best: Epoch 2 	 loss=0.01158 	 val_loss=0.00835 	 sm_loss=0.01157 	 sm_val_loss=0.00834 	 time=2.27s
# Best: Epoch 3 	 loss=0.00722 	 val_loss=0.00675 	 sm_loss=0.00720 	 sm_val_loss=0.00673 	 time=2.24s
# Best: Epoch 4 	 loss=0.00634 	 val_loss=0.00644 	 sm_loss=0.00633 	 sm_val_loss=0.00643 	 time=2.23s
# Best: Epoch 5 	 loss=0.00602 	 val_loss=0.00616 	 sm_loss=0.00602 	 sm_val_loss=0.00615 	 time=2.25s
# Best: Epoch 8 	 loss=0.00572 	 val_loss=0.00609 	 sm_loss=0.00575 	 sm_val_loss=0.00609 	 time=2.24s
# Best: Epoch 11 	 loss=0.00557 	 val_loss=0.00606 	 sm_loss=0.00562 	 sm_val_loss=0.00609 	 time=2.41s
# Best: Epoch 12 	 loss=0.00550 	 val_loss=0.00598 	 sm_loss=0.00557 	 sm_val_loss=0.00601 	 time=2.49s
# Best: Epoch 13 	 loss=0.00547 	 val_loss=0.00598 	 sm_loss=0.00555 	 sm_val_loss=0.00599 	 time=2.46s
# Best: Epoch 15 	 loss=0.00540 	 val_loss=0.00596 	 sm_loss=0.00550 	 sm_val_loss=0.00597 	 time=2.52s
# Best: Epoch 16 	 loss=0.00536 	 val_loss=0.00592 	 sm_loss=0.00547 	 sm_val_loss=0.00596 	 time=2.25s
# Best: Epoch 18 	 loss=0.00529 	 val_loss=0.00588 	 sm_loss=0.00542 	 sm_val_loss=0.00591 	 time=2.27s
# Best: Epoch 19 	 loss=0.00525 	 val_loss=0.00586 	 sm_loss=0.00540 	 sm_val_loss=0.00590 	 time=2.84s
# Fold 1
# Best: Epoch 1 	 loss=0.65353 	 val_loss=0.30779 	 sm_loss=0.65353 	 sm_val_loss=0.30779 	 time=2.33s
# Best: Epoch 2 	 loss=0.04629 	 val_loss=0.01975 	 sm_loss=0.04624 	 sm_val_loss=0.01977 	 time=2.36s
# Best: Epoch 4 	 loss=0.01865 	 val_loss=0.01899 	 sm_loss=0.01870 	 sm_val_loss=0.01898 	 time=2.69s
# Best: Epoch 5 	 loss=0.01826 	 val_loss=0.01867 	 sm_loss=0.01832 	 sm_val_loss=0.01866 	 time=2.55s
# Best: Epoch 6 	 loss=0.01801 	 val_loss=0.01861 	 sm_loss=0.01809 	 sm_val_loss=0.01864 	 time=2.42s
# Best: Epoch 7 	 loss=0.01799 	 val_loss=0.01857 	 sm_loss=0.01808 	 sm_val_loss=0.01856 	 time=2.35s
# Best: Epoch 8 	 loss=0.01788 	 val_loss=0.01849 	 sm_loss=0.01797 	 sm_val_loss=0.01852 	 time=2.54s
# Best: Epoch 10 	 loss=0.01788 	 val_loss=0.01823 	 sm_loss=0.01798 	 sm_val_loss=0.01825 	 time=2.27s
# Best: Epoch 17 	 loss=0.01774 	 val_loss=0.01817 	 sm_loss=0.01784 	 sm_val_loss=0.01816 	 time=2.39s
# Best: Epoch 23 	 loss=0.01740 	 val_loss=0.01804 	 sm_loss=0.01753 	 sm_val_loss=0.01802 	 time=2.87s
# Best: Epoch 25 	 loss=0.01723 	 val_loss=0.01790 	 sm_loss=0.01737 	 sm_val_loss=0.01794 	 time=2.38s
# Best: Epoch 26 	 loss=0.01711 	 val_loss=0.01782 	 sm_loss=0.01726 	 sm_val_loss=0.01787 	 time=2.54s
# Best: Epoch 27 	 loss=0.01698 	 val_loss=0.01776 	 sm_loss=0.01712 	 sm_val_loss=0.01779 	 time=2.44s
# Best: Epoch 30 	 loss=0.01669 	 val_loss=0.01769 	 sm_loss=0.01686 	 sm_val_loss=0.01771 	 time=2.33s
# Best: Epoch 31 	 loss=0.01658 	 val_loss=0.01770 	 sm_loss=0.01676 	 sm_val_loss=0.01768 	 time=2.94s
# Best: Epoch 33 	 loss=0.01634 	 val_loss=0.01763 	 sm_loss=0.01652 	 sm_val_loss=0.01765 	 time=2.29s
# Best: Epoch 35 	 loss=0.01620 	 val_loss=0.01761 	 sm_loss=0.01639 	 sm_val_loss=0.01764 	 time=2.59s
# Best: Epoch 36 	 loss=0.01613 	 val_loss=0.01759 	 sm_loss=0.01633 	 sm_val_loss=0.01762 	 time=2.32s
# Best: Epoch 37 	 loss=0.01604 	 val_loss=0.01756 	 sm_loss=0.01624 	 sm_val_loss=0.01758 	 time=2.37s
# Best: Epoch 38 	 loss=0.01597 	 val_loss=0.01755 	 sm_loss=0.01617 	 sm_val_loss=0.01757 	 time=2.28s
# Fold 1 log loss: 0.017644740526410012
# Fold 2
# Best: Epoch 1 	 loss=0.65367 	 val_loss=0.32093 	 sm_loss=0.65365 	 sm_val_loss=0.32089 	 time=2.68s
# Best: Epoch 2 	 loss=0.04848 	 val_loss=0.01912 	 sm_loss=0.04844 	 sm_val_loss=0.01913 	 time=2.91s
# Best: Epoch 3 	 loss=0.01906 	 val_loss=0.01899 	 sm_loss=0.01909 	 sm_val_loss=0.01898 	 time=2.37s
# Best: Epoch 4 	 loss=0.01862 	 val_loss=0.01805 	 sm_loss=0.01868 	 sm_val_loss=0.01812 	 time=2.35s
# Best: Epoch 5 	 loss=0.01835 	 val_loss=0.01795 	 sm_loss=0.01841 	 sm_val_loss=0.01799 	 time=2.26s
# Best: Epoch 8 	 loss=0.01799 	 val_loss=0.01791 	 sm_loss=0.01809 	 sm_val_loss=0.01797 	 time=2.55s
# Best: Epoch 10 	 loss=0.01801 	 val_loss=0.01774 	 sm_loss=0.01810 	 sm_val_loss=0.01779 	 time=2.23s
# Best: Epoch 13 	 loss=0.01794 	 val_loss=0.01774 	 sm_loss=0.01804 	 sm_val_loss=0.01777 	 time=2.26s
# Best: Epoch 17 	 loss=0.01779 	 val_loss=0.01767 	 sm_loss=0.01790 	 sm_val_loss=0.01773 	 time=2.28s
# Best: Epoch 22 	 loss=0.01748 	 val_loss=0.01730 	 sm_loss=0.01761 	 sm_val_loss=0.01737 	 time=2.29s
# Best: Epoch 25 	 loss=0.01728 	 val_loss=0.01734 	 sm_loss=0.01742 	 sm_val_loss=0.01735 	 time=3.34s
# Best: Epoch 26 	 loss=0.01720 	 val_loss=0.01713 	 sm_loss=0.01734 	 sm_val_loss=0.01718 	 time=2.67s
# Best: Epoch 28 	 loss=0.01697 	 val_loss=0.01699 	 sm_loss=0.01712 	 sm_val_loss=0.01705 	 time=2.31s
# Best: Epoch 30 	 loss=0.01674 	 val_loss=0.01691 	 sm_loss=0.01691 	 sm_val_loss=0.01698 	 time=2.27s
# Best: Epoch 31 	 loss=0.01666 	 val_loss=0.01687 	 sm_loss=0.01683 	 sm_val_loss=0.01694 	 time=2.46s
# Best: Epoch 33 	 loss=0.01645 	 val_loss=0.01681 	 sm_loss=0.01663 	 sm_val_loss=0.01687 	 time=2.54s
# Best: Epoch 34 	 loss=0.01634 	 val_loss=0.01671 	 sm_loss=0.01652 	 sm_val_loss=0.01677 	 time=2.51s
# Best: Epoch 37 	 loss=0.01611 	 val_loss=0.01670 	 sm_loss=0.01631 	 sm_val_loss=0.01676 	 time=2.28s
# Fold 2 log loss: 0.016776654387531696
# Fold 3
# Best: Epoch 1 	 loss=0.64942 	 val_loss=0.28126 	 sm_loss=0.64941 	 sm_val_loss=0.28125 	 time=2.35s
# Best: Epoch 2 	 loss=0.04517 	 val_loss=0.02005 	 sm_loss=0.04516 	 sm_val_loss=0.02005 	 time=2.30s
# Best: Epoch 3 	 loss=0.01909 	 val_loss=0.01899 	 sm_loss=0.01911 	 sm_val_loss=0.01899 	 time=2.33s
# Best: Epoch 4 	 loss=0.01858 	 val_loss=0.01865 	 sm_loss=0.01863 	 sm_val_loss=0.01864 	 time=2.57s
# Best: Epoch 9 	 loss=0.01798 	 val_loss=0.01854 	 sm_loss=0.01806 	 sm_val_loss=0.01856 	 time=2.68s
# Best: Epoch 12 	 loss=0.01786 	 val_loss=0.01847 	 sm_loss=0.01796 	 sm_val_loss=0.01844 	 time=2.54s
# Best: Epoch 18 	 loss=0.01769 	 val_loss=0.01845 	 sm_loss=0.01779 	 sm_val_loss=0.01840 	 time=2.29s
# Best: Epoch 21 	 loss=0.01750 	 val_loss=0.01828 	 sm_loss=0.01762 	 sm_val_loss=0.01825 	 time=2.63s
# Best: Epoch 22 	 loss=0.01744 	 val_loss=0.01813 	 sm_loss=0.01756 	 sm_val_loss=0.01814 	 time=2.34s
# Best: Epoch 25 	 loss=0.01715 	 val_loss=0.01814 	 sm_loss=0.01729 	 sm_val_loss=0.01811 	 time=2.38s
# Best: Epoch 27 	 loss=0.01697 	 val_loss=0.01793 	 sm_loss=0.01712 	 sm_val_loss=0.01793 	 time=2.30s
# Best: Epoch 29 	 loss=0.01674 	 val_loss=0.01779 	 sm_loss=0.01690 	 sm_val_loss=0.01780 	 time=2.36s
# Best: Epoch 32 	 loss=0.01638 	 val_loss=0.01777 	 sm_loss=0.01656 	 sm_val_loss=0.01776 	 time=2.67s
# Best: Epoch 34 	 loss=0.01618 	 val_loss=0.01774 	 sm_loss=0.01637 	 sm_val_loss=0.01771 	 time=2.82s
# Best: Epoch 36 	 loss=0.01601 	 val_loss=0.01773 	 sm_loss=0.01621 	 sm_val_loss=0.01769 	 time=2.37s
# Best: Epoch 37 	 loss=0.01591 	 val_loss=0.01772 	 sm_loss=0.01612 	 sm_val_loss=0.01769 	 time=2.37s
# Best: Epoch 39 	 loss=0.01580 	 val_loss=0.01771 	 sm_loss=0.01601 	 sm_val_loss=0.01767 	 time=2.65s
# Fold 3 log loss: 0.017674057102757296
# Fold 4
# Best: Epoch 1 	 loss=0.65270 	 val_loss=0.31014 	 sm_loss=0.65269 	 sm_val_loss=0.31013 	 time=2.34s
# Best: Epoch 2 	 loss=0.04528 	 val_loss=0.01959 	 sm_loss=0.04521 	 sm_val_loss=0.01961 	 time=2.62s
# Best: Epoch 3 	 loss=0.01911 	 val_loss=0.01888 	 sm_loss=0.01913 	 sm_val_loss=0.01891 	 time=2.33s
# Best: Epoch 4 	 loss=0.01865 	 val_loss=0.01817 	 sm_loss=0.01868 	 sm_val_loss=0.01822 	 time=2.34s
# Best: Epoch 5 	 loss=0.01835 	 val_loss=0.01811 	 sm_loss=0.01842 	 sm_val_loss=0.01814 	 time=2.69s
# Best: Epoch 6 	 loss=0.01820 	 val_loss=0.01795 	 sm_loss=0.01827 	 sm_val_loss=0.01800 	 time=2.53s
# Best: Epoch 7 	 loss=0.01809 	 val_loss=0.01792 	 sm_loss=0.01817 	 sm_val_loss=0.01796 	 time=2.34s
# Best: Epoch 8 	 loss=0.01806 	 val_loss=0.01787 	 sm_loss=0.01814 	 sm_val_loss=0.01794 	 time=2.27s
# Best: Epoch 9 	 loss=0.01799 	 val_loss=0.01771 	 sm_loss=0.01808 	 sm_val_loss=0.01777 	 time=2.29s
# Best: Epoch 19 	 loss=0.01772 	 val_loss=0.01755 	 sm_loss=0.01783 	 sm_val_loss=0.01757 	 time=2.27s
# Best: Epoch 26 	 loss=0.01717 	 val_loss=0.01736 	 sm_loss=0.01731 	 sm_val_loss=0.01740 	 time=2.36s
# Best: Epoch 27 	 loss=0.01706 	 val_loss=0.01731 	 sm_loss=0.01721 	 sm_val_loss=0.01736 	 time=2.46s
# Best: Epoch 29 	 loss=0.01689 	 val_loss=0.01723 	 sm_loss=0.01705 	 sm_val_loss=0.01727 	 time=2.59s
# Best: Epoch 30 	 loss=0.01677 	 val_loss=0.01704 	 sm_loss=0.01694 	 sm_val_loss=0.01711 	 time=2.54s
# Best: Epoch 34 	 loss=0.01633 	 val_loss=0.01699 	 sm_loss=0.01652 	 sm_val_loss=0.01703 	 time=2.34s
# Best: Epoch 37 	 loss=0.01613 	 val_loss=0.01698 	 sm_loss=0.01632 	 sm_val_loss=0.01703 	 time=2.30s
# Best: Epoch 38 	 loss=0.01608 	 val_loss=0.01694 	 sm_loss=0.01627 	 sm_val_loss=0.01699 	 time=3.18s
# Fold 4 log loss: 0.01701761802329232
# Fold 5
# Best: Epoch 1 	 loss=0.65374 	 val_loss=0.30316 	 sm_loss=0.65374 	 sm_val_loss=0.30316 	 time=2.61s
# Best: Epoch 2 	 loss=0.04485 	 val_loss=0.01961 	 sm_loss=0.04485 	 sm_val_loss=0.01960 	 time=2.37s
# Best: Epoch 3 	 loss=0.01910 	 val_loss=0.01950 	 sm_loss=0.01913 	 sm_val_loss=0.01954 	 time=2.36s
# Best: Epoch 4 	 loss=0.01870 	 val_loss=0.01810 	 sm_loss=0.01875 	 sm_val_loss=0.01814 	 time=2.33s
# Best: Epoch 5 	 loss=0.01832 	 val_loss=0.01783 	 sm_loss=0.01839 	 sm_val_loss=0.01787 	 time=2.45s
# Best: Epoch 6 	 loss=0.01821 	 val_loss=0.01782 	 sm_loss=0.01828 	 sm_val_loss=0.01786 	 time=2.56s
# Best: Epoch 7 	 loss=0.01807 	 val_loss=0.01756 	 sm_loss=0.01815 	 sm_val_loss=0.01762 	 time=2.45s
# Best: Epoch 18 	 loss=0.01780 	 val_loss=0.01733 	 sm_loss=0.01792 	 sm_val_loss=0.01741 	 time=2.64s
# Best: Epoch 24 	 loss=0.01741 	 val_loss=0.01725 	 sm_loss=0.01755 	 sm_val_loss=0.01732 	 time=2.39s
# Best: Epoch 25 	 loss=0.01735 	 val_loss=0.01722 	 sm_loss=0.01749 	 sm_val_loss=0.01726 	 time=2.35s
# Best: Epoch 27 	 loss=0.01711 	 val_loss=0.01706 	 sm_loss=0.01726 	 sm_val_loss=0.01713 	 time=2.63s
# Best: Epoch 29 	 loss=0.01691 	 val_loss=0.01700 	 sm_loss=0.01707 	 sm_val_loss=0.01707 	 time=2.35s
# Best: Epoch 30 	 loss=0.01679 	 val_loss=0.01695 	 sm_loss=0.01696 	 sm_val_loss=0.01702 	 time=2.42s
# Best: Epoch 31 	 loss=0.01673 	 val_loss=0.01692 	 sm_loss=0.01691 	 sm_val_loss=0.01699 	 time=2.39s
# Best: Epoch 33 	 loss=0.01649 	 val_loss=0.01694 	 sm_loss=0.01667 	 sm_val_loss=0.01699 	 time=2.38s
# Best: Epoch 34 	 loss=0.01636 	 val_loss=0.01683 	 sm_loss=0.01655 	 sm_val_loss=0.01690 	 time=2.37s
# Best: Epoch 36 	 loss=0.01620 	 val_loss=0.01685 	 sm_loss=0.01639 	 sm_val_loss=0.01689 	 time=3.18s
# Best: Epoch 37 	 loss=0.01612 	 val_loss=0.01680 	 sm_loss=0.01631 	 sm_val_loss=0.01686 	 time=2.34s
# Best: Epoch 38 	 loss=0.01609 	 val_loss=0.01680 	 sm_loss=0.01628 	 sm_val_loss=0.01685 	 time=2.38s
# Best: Epoch 39 	 loss=0.01602 	 val_loss=0.01678 	 sm_loss=0.01622 	 sm_val_loss=0.01684 	 time=2.40s
# Best: Epoch 40 	 loss=0.01601 	 val_loss=0.01678 	 sm_loss=0.01621 	 sm_val_loss=0.01683 	 time=3.59s
# Fold 5 log loss: 0.016840835887002494
# Fold 6
# Best: Epoch 1 	 loss=0.65293 	 val_loss=0.31620 	 sm_loss=0.65293 	 sm_val_loss=0.31617 	 time=2.50s
# Best: Epoch 2 	 loss=0.04710 	 val_loss=0.02124 	 sm_loss=0.04704 	 sm_val_loss=0.02121 	 time=2.39s
# Best: Epoch 3 	 loss=0.01896 	 val_loss=0.01973 	 sm_loss=0.01899 	 sm_val_loss=0.01961 	 time=2.77s
# Best: Epoch 5 	 loss=0.01820 	 val_loss=0.01943 	 sm_loss=0.01828 	 sm_val_loss=0.01940 	 time=2.37s
# Best: Epoch 6 	 loss=0.01805 	 val_loss=0.01919 	 sm_loss=0.01813 	 sm_val_loss=0.01914 	 time=2.34s
# Best: Epoch 7 	 loss=0.01792 	 val_loss=0.01922 	 sm_loss=0.01801 	 sm_val_loss=0.01913 	 time=2.85s
# Best: Epoch 11 	 loss=0.01778 	 val_loss=0.01905 	 sm_loss=0.01788 	 sm_val_loss=0.01901 	 time=2.38s
# Best: Epoch 19 	 loss=0.01753 	 val_loss=0.01903 	 sm_loss=0.01765 	 sm_val_loss=0.01893 	 time=2.35s
# Best: Epoch 21 	 loss=0.01738 	 val_loss=0.01883 	 sm_loss=0.01751 	 sm_val_loss=0.01875 	 time=2.67s
# Best: Epoch 22 	 loss=0.01736 	 val_loss=0.01881 	 sm_loss=0.01748 	 sm_val_loss=0.01875 	 time=2.28s
# Best: Epoch 25 	 loss=0.01703 	 val_loss=0.01886 	 sm_loss=0.01718 	 sm_val_loss=0.01873 	 time=2.77s
# Best: Epoch 27 	 loss=0.01690 	 val_loss=0.01883 	 sm_loss=0.01705 	 sm_val_loss=0.01872 	 time=2.39s
# Best: Epoch 28 	 loss=0.01678 	 val_loss=0.01881 	 sm_loss=0.01694 	 sm_val_loss=0.01867 	 time=2.30s
# Best: Epoch 29 	 loss=0.01668 	 val_loss=0.01879 	 sm_loss=0.01684 	 sm_val_loss=0.01866 	 time=2.31s
# Best: Epoch 30 	 loss=0.01658 	 val_loss=0.01867 	 sm_loss=0.01675 	 sm_val_loss=0.01854 	 time=2.57s
# Best: Epoch 31 	 loss=0.01648 	 val_loss=0.01859 	 sm_loss=0.01666 	 sm_val_loss=0.01849 	 time=2.36s
# Best: Epoch 32 	 loss=0.01635 	 val_loss=0.01858 	 sm_loss=0.01653 	 sm_val_loss=0.01848 	 time=2.41s
# Best: Epoch 34 	 loss=0.01617 	 val_loss=0.01852 	 sm_loss=0.01636 	 sm_val_loss=0.01842 	 time=2.60s
# Best: Epoch 35 	 loss=0.01611 	 val_loss=0.01849 	 sm_loss=0.01630 	 sm_val_loss=0.01839 	 time=2.36s
# Best: Epoch 36 	 loss=0.01600 	 val_loss=0.01849 	 sm_loss=0.01620 	 sm_val_loss=0.01839 	 time=2.34s
# Best: Epoch 37 	 loss=0.01594 	 val_loss=0.01847 	 sm_loss=0.01613 	 sm_val_loss=0.01838 	 time=2.34s
# Best: Epoch 38 	 loss=0.01585 	 val_loss=0.01845 	 sm_loss=0.01606 	 sm_val_loss=0.01837 	 time=2.35s
# Best: Epoch 40 	 loss=0.01578 	 val_loss=0.01846 	 sm_loss=0.01599 	 sm_val_loss=0.01837 	 time=2.49s
# Fold 6 log loss: 0.01841630807814791
# Fold 7
# Best: Epoch 1 	 loss=0.65114 	 val_loss=0.29607 	 sm_loss=0.65111 	 sm_val_loss=0.29602 	 time=3.05s
# Best: Epoch 2 	 loss=0.04825 	 val_loss=0.01972 	 sm_loss=0.04813 	 sm_val_loss=0.01972 	 time=3.15s
# ...
# Best: Epoch 7 	 loss=0.00580 	 val_loss=0.00610 	 sm_loss=0.00581 	 sm_val_loss=0.00610 	 time=2.28s
# Best: Epoch 8 	 loss=0.00575 	 val_loss=0.00611 	 sm_loss=0.00577 	 sm_val_loss=0.00610 	 time=2.21s
# Best: Epoch 9 	 loss=0.00570 	 val_loss=0.00606 	 sm_loss=0.00572 	 sm_val_loss=0.00606 	 time=2.73s
# Best: Epoch 10 	 loss=0.00565 	 val_loss=0.00604 	 sm_loss=0.00569 	 sm_val_loss=0.00605 	 time=2.33s
# Best: Epoch 12 	 loss=0.00556 	 val_loss=0.00603 	 sm_loss=0.00561 	 sm_val_loss=0.00604 	 time=2.26s
# Best: Epoch 14 	 loss=0.00546 	 val_loss=0.00598 	 sm_loss=0.00554 	 sm_val_loss=0.00599 	 time=2.52s
# Best: Epoch 15 	 loss=0.00540 	 val_loss=0.00594 	 sm_loss=0.00549 	 sm_val_loss=0.00596 	 time=2.47s
# Best: Epoch 17 	 loss=0.00531 	 val_loss=0.00586 	 sm_loss=0.00543 	 sm_val_loss=0.00588 	 time=2.26s
# Best: Epoch 20 	 loss=0.00523 	 val_loss=0.00585 	 sm_loss=0.00539 	 sm_val_loss=0.00588 	 time=2.27s
# Fold 1
# Best: Epoch 1 	 loss=0.64922 	 val_loss=0.28624 	 sm_loss=0.64922 	 sm_val_loss=0.28624 	 time=2.33s
# Best: Epoch 2 	 loss=0.04440 	 val_loss=0.01930 	 sm_loss=0.04440 	 sm_val_loss=0.01931 	 time=2.80s
# Best: Epoch 3 	 loss=0.01885 	 val_loss=0.01862 	 sm_loss=0.01888 	 sm_val_loss=0.01864 	 time=3.68s
# Best: Epoch 7 	 loss=0.01788 	 val_loss=0.01851 	 sm_loss=0.01796 	 sm_val_loss=0.01849 	 time=2.60s
# Best: Epoch 9 	 loss=0.01793 	 val_loss=0.01830 	 sm_loss=0.01803 	 sm_val_loss=0.01833 	 time=2.39s
# Best: Epoch 17 	 loss=0.01766 	 val_loss=0.01835 	 sm_loss=0.01778 	 sm_val_loss=0.01832 	 time=2.32s
# Best: Epoch 18 	 loss=0.01765 	 val_loss=0.01823 	 sm_loss=0.01776 	 sm_val_loss=0.01828 	 time=2.30s
# Best: Epoch 19 	 loss=0.01758 	 val_loss=0.01817 	 sm_loss=0.01770 	 sm_val_loss=0.01815 	 time=2.30s
# Best: Epoch 20 	 loss=0.01754 	 val_loss=0.01801 	 sm_loss=0.01766 	 sm_val_loss=0.01806 	 time=2.61s
# Best: Epoch 23 	 loss=0.01726 	 val_loss=0.01800 	 sm_loss=0.01739 	 sm_val_loss=0.01802 	 time=2.34s
# Best: Epoch 26 	 loss=0.01709 	 val_loss=0.01784 	 sm_loss=0.01723 	 sm_val_loss=0.01787 	 time=2.58s
# Best: Epoch 28 	 loss=0.01692 	 val_loss=0.01780 	 sm_loss=0.01708 	 sm_val_loss=0.01784 	 time=2.54s
# Best: Epoch 29 	 loss=0.01683 	 val_loss=0.01778 	 sm_loss=0.01699 	 sm_val_loss=0.01779 	 time=2.93s
# Best: Epoch 30 	 loss=0.01668 	 val_loss=0.01768 	 sm_loss=0.01685 	 sm_val_loss=0.01770 	 time=2.34s
# Best: Epoch 31 	 loss=0.01652 	 val_loss=0.01762 	 sm_loss=0.01669 	 sm_val_loss=0.01766 	 time=2.30s
# Best: Epoch 32 	 loss=0.01641 	 val_loss=0.01758 	 sm_loss=0.01658 	 sm_val_loss=0.01759 	 time=2.30s
# Best: Epoch 34 	 loss=0.01623 	 val_loss=0.01752 	 sm_loss=0.01642 	 sm_val_loss=0.01755 	 time=2.39s
# Best: Epoch 35 	 loss=0.01611 	 val_loss=0.01752 	 sm_loss=0.01630 	 sm_val_loss=0.01754 	 time=2.56s
# Best: Epoch 36 	 loss=0.01606 	 val_loss=0.01745 	 sm_loss=0.01625 	 sm_val_loss=0.01747 	 time=2.25s
# Fold 1 log loss: 0.017548372551330137
# Fold 2
# Best: Epoch 1 	 loss=0.64811 	 val_loss=0.29631 	 sm_loss=0.64807 	 sm_val_loss=0.29602 	 time=2.93s
# Best: Epoch 2 	 loss=0.04394 	 val_loss=0.02001 	 sm_loss=0.04378 	 sm_val_loss=0.02001 	 time=2.26s
# Best: Epoch 3 	 loss=0.01937 	 val_loss=0.01886 	 sm_loss=0.01939 	 sm_val_loss=0.01889 	 time=2.31s
# Best: Epoch 4 	 loss=0.01894 	 val_loss=0.01886 	 sm_loss=0.01896 	 sm_val_loss=0.01885 	 time=2.29s
# Best: Epoch 5 	 loss=0.01867 	 val_loss=0.01849 	 sm_loss=0.01873 	 sm_val_loss=0.01851 	 time=2.35s
# Best: Epoch 6 	 loss=0.01832 	 val_loss=0.01814 	 sm_loss=0.01840 	 sm_val_loss=0.01820 	 time=2.52s
# Best: Epoch 8 	 loss=0.01810 	 val_loss=0.01761 	 sm_loss=0.01819 	 sm_val_loss=0.01770 	 time=2.29s
# Best: Epoch 19 	 loss=0.01776 	 val_loss=0.01747 	 sm_loss=0.01787 	 sm_val_loss=0.01755 	 time=2.63s
# Best: Epoch 24 	 loss=0.01739 	 val_loss=0.01736 	 sm_loss=0.01751 	 sm_val_loss=0.01744 	 time=2.41s
# Best: Epoch 26 	 loss=0.01727 	 val_loss=0.01723 	 sm_loss=0.01740 	 sm_val_loss=0.01731 	 time=2.29s
# Best: Epoch 27 	 loss=0.01714 	 val_loss=0.01719 	 sm_loss=0.01729 	 sm_val_loss=0.01726 	 time=2.67s
# Best: Epoch 28 	 loss=0.01702 	 val_loss=0.01696 	 sm_loss=0.01717 	 sm_val_loss=0.01705 	 time=2.60s
# Best: Epoch 31 	 loss=0.01674 	 val_loss=0.01687 	 sm_loss=0.01690 	 sm_val_loss=0.01697 	 time=2.29s
# Best: Epoch 32 	 loss=0.01659 	 val_loss=0.01685 	 sm_loss=0.01676 	 sm_val_loss=0.01693 	 time=2.60s
# Best: Epoch 33 	 loss=0.01647 	 val_loss=0.01681 	 sm_loss=0.01665 	 sm_val_loss=0.01689 	 time=3.40s
# Best: Epoch 34 	 loss=0.01643 	 val_loss=0.01676 	 sm_loss=0.01660 	 sm_val_loss=0.01685 	 time=2.44s
# Best: Epoch 35 	 loss=0.01633 	 val_loss=0.01675 	 sm_loss=0.01651 	 sm_val_loss=0.01684 	 time=2.37s
# Best: Epoch 36 	 loss=0.01619 	 val_loss=0.01671 	 sm_loss=0.01638 	 sm_val_loss=0.01679 	 time=2.41s
# Best: Epoch 37 	 loss=0.01616 	 val_loss=0.01669 	 sm_loss=0.01635 	 sm_val_loss=0.01677 	 time=2.58s
# Best: Epoch 38 	 loss=0.01611 	 val_loss=0.01669 	 sm_loss=0.01631 	 sm_val_loss=0.01677 	 time=2.34s
# Best: Epoch 40 	 loss=0.01608 	 val_loss=0.01668 	 sm_loss=0.01628 	 sm_val_loss=0.01676 	 time=2.31s
# Fold 2 log loss: 0.01677306808793102
# Fold 3
# Best: Epoch 1 	 loss=0.65149 	 val_loss=0.27190 	 sm_loss=0.65147 	 sm_val_loss=0.27184 	 time=2.52s
# Best: Epoch 2 	 loss=0.04633 	 val_loss=0.02055 	 sm_loss=0.04610 	 sm_val_loss=0.02055 	 time=2.30s
# Best: Epoch 3 	 loss=0.01938 	 val_loss=0.01937 	 sm_loss=0.01939 	 sm_val_loss=0.01938 	 time=2.69s
# Best: Epoch 4 	 loss=0.01865 	 val_loss=0.01907 	 sm_loss=0.01870 	 sm_val_loss=0.01905 	 time=2.40s
# Best: Epoch 5 	 loss=0.01839 	 val_loss=0.01879 	 sm_loss=0.01846 	 sm_val_loss=0.01879 	 time=2.39s
# Best: Epoch 6 	 loss=0.01808 	 val_loss=0.01856 	 sm_loss=0.01815 	 sm_val_loss=0.01859 	 time=2.64s
# Best: Epoch 7 	 loss=0.01797 	 val_loss=0.01855 	 sm_loss=0.01806 	 sm_val_loss=0.01856 	 time=2.41s
# Best: Epoch 8 	 loss=0.01789 	 val_loss=0.01839 	 sm_loss=0.01799 	 sm_val_loss=0.01843 	 time=2.50s
# Best: Epoch 19 	 loss=0.01754 	 val_loss=0.01841 	 sm_loss=0.01766 	 sm_val_loss=0.01840 	 time=2.49s
# Best: Epoch 20 	 loss=0.01755 	 val_loss=0.01838 	 sm_loss=0.01766 	 sm_val_loss=0.01834 	 time=2.80s
# Best: Epoch 21 	 loss=0.01743 	 val_loss=0.01821 	 sm_loss=0.01755 	 sm_val_loss=0.01816 	 time=2.40s
# Best: Epoch 24 	 loss=0.01719 	 val_loss=0.01808 	 sm_loss=0.01733 	 sm_val_loss=0.01809 	 time=2.36s
# Best: Epoch 26 	 loss=0.01699 	 val_loss=0.01804 	 sm_loss=0.01714 	 sm_val_loss=0.01805 	 time=2.44s
# Best: Epoch 28 	 loss=0.01684 	 val_loss=0.01793 	 sm_loss=0.01700 	 sm_val_loss=0.01790 	 time=2.32s
# Best: Epoch 30 	 loss=0.01661 	 val_loss=0.01786 	 sm_loss=0.01677 	 sm_val_loss=0.01785 	 time=2.46s
# Best: Epoch 32 	 loss=0.01640 	 val_loss=0.01774 	 sm_loss=0.01657 	 sm_val_loss=0.01773 	 time=2.34s
# Best: Epoch 35 	 loss=0.01608 	 val_loss=0.01774 	 sm_loss=0.01628 	 sm_val_loss=0.01772 	 time=2.74s
# Best: Epoch 36 	 loss=0.01601 	 val_loss=0.01771 	 sm_loss=0.01621 	 sm_val_loss=0.01767 	 time=2.52s
# Best: Epoch 37 	 loss=0.01598 	 val_loss=0.01769 	 sm_loss=0.01617 	 sm_val_loss=0.01766 	 time=2.44s
# Best: Epoch 40 	 loss=0.01584 	 val_loss=0.01768 	 sm_loss=0.01604 	 sm_val_loss=0.01765 	 time=2.32s
# Fold 3 log loss: 0.017650261592857677
# Fold 4
# Best: Epoch 1 	 loss=0.65217 	 val_loss=0.31310 	 sm_loss=0.65217 	 sm_val_loss=0.31305 	 time=2.33s
# Best: Epoch 2 	 loss=0.04740 	 val_loss=0.01939 	 sm_loss=0.04739 	 sm_val_loss=0.01941 	 time=2.44s
# Best: Epoch 3 	 loss=0.01897 	 val_loss=0.01904 	 sm_loss=0.01900 	 sm_val_loss=0.01907 	 time=2.50s
# Best: Epoch 4 	 loss=0.01862 	 val_loss=0.01826 	 sm_loss=0.01867 	 sm_val_loss=0.01830 	 time=2.35s
# Best: Epoch 5 	 loss=0.01826 	 val_loss=0.01818 	 sm_loss=0.01834 	 sm_val_loss=0.01822 	 time=2.39s
# Best: Epoch 6 	 loss=0.01815 	 val_loss=0.01814 	 sm_loss=0.01823 	 sm_val_loss=0.01819 	 time=2.33s
# Best: Epoch 7 	 loss=0.01807 	 val_loss=0.01787 	 sm_loss=0.01816 	 sm_val_loss=0.01793 	 time=2.63s
# Best: Epoch 9 	 loss=0.01794 	 val_loss=0.01782 	 sm_loss=0.01803 	 sm_val_loss=0.01786 	 time=2.90s
# Best: Epoch 12 	 loss=0.01792 	 val_loss=0.01774 	 sm_loss=0.01802 	 sm_val_loss=0.01779 	 time=2.43s
# Best: Epoch 16 	 loss=0.01776 	 val_loss=0.01771 	 sm_loss=0.01787 	 sm_val_loss=0.01773 	 time=2.31s
# Best: Epoch 19 	 loss=0.01773 	 val_loss=0.01759 	 sm_loss=0.01783 	 sm_val_loss=0.01764 	 time=2.32s
# Best: Epoch 22 	 loss=0.01742 	 val_loss=0.01751 	 sm_loss=0.01754 	 sm_val_loss=0.01755 	 time=2.34s
# Best: Epoch 23 	 loss=0.01740 	 val_loss=0.01742 	 sm_loss=0.01753 	 sm_val_loss=0.01747 	 time=2.57s
# Best: Epoch 24 	 loss=0.01729 	 val_loss=0.01742 	 sm_loss=0.01742 	 sm_val_loss=0.01744 	 time=2.62s
# Best: Epoch 25 	 loss=0.01716 	 val_loss=0.01730 	 sm_loss=0.01730 	 sm_val_loss=0.01737 	 time=2.30s
# Best: Epoch 26 	 loss=0.01709 	 val_loss=0.01726 	 sm_loss=0.01723 	 sm_val_loss=0.01731 	 time=2.29s
# Best: Epoch 27 	 loss=0.01696 	 val_loss=0.01715 	 sm_loss=0.01711 	 sm_val_loss=0.01719 	 time=2.30s
# Best: Epoch 32 	 loss=0.01646 	 val_loss=0.01700 	 sm_loss=0.01663 	 sm_val_loss=0.01706 	 time=2.32s
# Best: Epoch 33 	 loss=0.01634 	 val_loss=0.01700 	 sm_loss=0.01652 	 sm_val_loss=0.01704 	 time=3.72s
# Best: Epoch 35 	 loss=0.01615 	 val_loss=0.01698 	 sm_loss=0.01634 	 sm_val_loss=0.01703 	 time=2.39s
# Best: Epoch 36 	 loss=0.01608 	 val_loss=0.01694 	 sm_loss=0.01627 	 sm_val_loss=0.01699 	 time=2.73s
# Best: Epoch 38 	 loss=0.01595 	 val_loss=0.01691 	 sm_loss=0.01615 	 sm_val_loss=0.01696 	 time=2.37s
# Best: Epoch 39 	 loss=0.01591 	 val_loss=0.01690 	 sm_loss=0.01611 	 sm_val_loss=0.01695 	 time=2.37s
# Fold 4 log loss: 0.01698252023910561
# Fold 5
# Best: Epoch 1 	 loss=0.64910 	 val_loss=0.26461 	 sm_loss=0.64910 	 sm_val_loss=0.26460 	 time=2.62s
# Best: Epoch 2 	 loss=0.04258 	 val_loss=0.01857 	 sm_loss=0.04257 	 sm_val_loss=0.01858 	 time=2.34s
# Best: Epoch 3 	 loss=0.01901 	 val_loss=0.01850 	 sm_loss=0.01904 	 sm_val_loss=0.01854 	 time=2.38s
# Best: Epoch 4 	 loss=0.01863 	 val_loss=0.01840 	 sm_loss=0.01868 	 sm_val_loss=0.01845 	 time=2.43s
# Best: Epoch 5 	 loss=0.01826 	 val_loss=0.01778 	 sm_loss=0.01833 	 sm_val_loss=0.01782 	 time=3.24s
# Best: Epoch 7 	 loss=0.01799 	 val_loss=0.01753 	 sm_loss=0.01808 	 sm_val_loss=0.01760 	 time=2.36s
# Best: Epoch 11 	 loss=0.01793 	 val_loss=0.01752 	 sm_loss=0.01803 	 sm_val_loss=0.01757 	 time=2.30s
# Best: Epoch 16 	 loss=0.01786 	 val_loss=0.01744 	 sm_loss=0.01797 	 sm_val_loss=0.01749 	 time=3.01s
# Best: Epoch 19 	 loss=0.01770 	 val_loss=0.01740 	 sm_loss=0.01782 	 sm_val_loss=0.01748 	 time=2.37s
# Best: Epoch 23 	 loss=0.01745 	 val_loss=0.01738 	 sm_loss=0.01758 	 sm_val_loss=0.01741 	 time=2.35s
# Best: Epoch 24 	 loss=0.01736 	 val_loss=0.01726 	 sm_loss=0.01749 	 sm_val_loss=0.01732 	 time=2.33s
# Best: Epoch 25 	 loss=0.01728 	 val_loss=0.01725 	 sm_loss=0.01742 	 sm_val_loss=0.01730 	 time=2.34s
# Best: Epoch 26 	 loss=0.01715 	 val_loss=0.01712 	 sm_loss=0.01729 	 sm_val_loss=0.01719 	 time=2.31s
# Best: Epoch 29 	 loss=0.01689 	 val_loss=0.01696 	 sm_loss=0.01706 	 sm_val_loss=0.01703 	 time=2.36s
# Best: Epoch 31 	 loss=0.01665 	 val_loss=0.01688 	 sm_loss=0.01683 	 sm_val_loss=0.01696 	 time=3.15s
# Best: Epoch 33 	 loss=0.01640 	 val_loss=0.01687 	 sm_loss=0.01659 	 sm_val_loss=0.01695 	 time=2.34s
# Best: Epoch 34 	 loss=0.01632 	 val_loss=0.01677 	 sm_loss=0.01652 	 sm_val_loss=0.01684 	 time=2.63s
# Best: Epoch 35 	 loss=0.01624 	 val_loss=0.01675 	 sm_loss=0.01643 	 sm_val_loss=0.01683 	 time=2.48s
# Best: Epoch 37 	 loss=0.01605 	 val_loss=0.01676 	 sm_loss=0.01625 	 sm_val_loss=0.01683 	 time=2.36s
# Fold 5 log loss: 0.016834003777563448
# Fold 6
# Best: Epoch 1 	 loss=0.64892 	 val_loss=0.27125 	 sm_loss=0.64890 	 sm_val_loss=0.27118 	 time=2.48s
# Best: Epoch 2 	 loss=0.04487 	 val_loss=0.02044 	 sm_loss=0.04473 	 sm_val_loss=0.02035 	 time=2.88s
# Best: Epoch 3 	 loss=0.01893 	 val_loss=0.01999 	 sm_loss=0.01896 	 sm_val_loss=0.01994 	 time=2.66s
# Best: Epoch 4 	 loss=0.01854 	 val_loss=0.01952 	 sm_loss=0.01860 	 sm_val_loss=0.01950 	 time=2.39s
# Best: Epoch 5 	 loss=0.01828 	 val_loss=0.01934 	 sm_loss=0.01836 	 sm_val_loss=0.01927 	 time=2.64s
# Best: Epoch 7 	 loss=0.01790 	 val_loss=0.01897 	 sm_loss=0.01800 	 sm_val_loss=0.01897 	 time=2.61s
# Best: Epoch 15 	 loss=0.01763 	 val_loss=0.01893 	 sm_loss=0.01774 	 sm_val_loss=0.01884 	 time=2.69s
# Best: Epoch 19 	 loss=0.01737 	 val_loss=0.01883 	 sm_loss=0.01750 	 sm_val_loss=0.01876 	 time=2.32s
# Best: Epoch 20 	 loss=0.01729 	 val_loss=0.01874 	 sm_loss=0.01743 	 sm_val_loss=0.01870 	 time=2.59s
# Best: Epoch 22 	 loss=0.01716 	 val_loss=0.01868 	 sm_loss=0.01731 	 sm_val_loss=0.01858 	 time=2.76s
# Best: Epoch 26 	 loss=0.01684 	 val_loss=0.01859 	 sm_loss=0.01700 	 sm_val_loss=0.01849 	 time=2.50s
# Best: Epoch 28 	 loss=0.01667 	 val_loss=0.01853 	 sm_loss=0.01683 	 sm_val_loss=0.01847 	 time=2.70s
# Best: Epoch 29 	 loss=0.01653 	 val_loss=0.01852 	 sm_loss=0.01670 	 sm_val_loss=0.01843 	 time=2.64s
# Best: Epoch 30 	 loss=0.01646 	 val_loss=0.01851 	 sm_loss=0.01664 	 sm_val_loss=0.01841 	 time=2.42s
# Best: Epoch 31 	 loss=0.01633 	 val_loss=0.01839 	 sm_loss=0.01651 	 sm_val_loss=0.01830 	 time=2.37s
# Best: Epoch 34 	 loss=0.01606 	 val_loss=0.01835 	 sm_loss=0.01625 	 sm_val_loss=0.01826 	 time=2.57s
# Best: Epoch 38 	 loss=0.01577 	 val_loss=0.01836 	 sm_loss=0.01598 	 sm_val_loss=0.01825 	 time=2.59s
# Best: Epoch 39 	 loss=0.01575 	 val_loss=0.01835 	 sm_loss=0.01596 	 sm_val_loss=0.01825 	 time=2.27s
# Best: Epoch 40 	 loss=0.01574 	 val_loss=0.01834 	 sm_loss=0.01596 	 sm_val_loss=0.01825 	 time=2.48s
# Fold 6 log loss: 0.018296122894588956
# Fold 7
# Best: Epoch 1 	 loss=0.65161 	 val_loss=0.32689 	 sm_loss=0.65156 	 sm_val_loss=0.32689 	 time=2.99s
# Best: Epoch 2 	 loss=0.04420 	 val_loss=0.02023 	 sm_loss=0.04411 	 sm_val_loss=0.02022 	 time=2.55s
# Best: Epoch 3 	 loss=0.01892 	 val_loss=0.01932 	 sm_loss=0.01894 	 sm_val_loss=0.01932 	 time=2.31s
# Best: Epoch 5 	 loss=0.01817 	 val_loss=0.01847 	 sm_loss=0.01824 	 sm_val_loss=0.01850 	 time=2.33s
# Best: Epoch 7 	 loss=0.01781 	 val_loss=0.01833 	 sm_loss=0.01790 	 sm_val_loss=0.01836 	 time=2.37s
# Best: Epoch 12 	 loss=0.01774 	 val_loss=0.01821 	 sm_loss=0.01784 	 sm_val_loss=0.01822 	 time=2.27s
# Best: Epoch 16 	 loss=0.01761 	 val_loss=0.01819 	 sm_loss=0.01772 	 sm_val_loss=0.01819 	 time=2.27s
# Best: Epoch 23 	 loss=0.01730 	 val_loss=0.01813 	 sm_loss=0.01744 	 sm_val_loss=0.01817 	 time=3.06s
# Best: Epoch 24 	 loss=0.01720 	 val_loss=0.01804 	 sm_loss=0.01734 	 sm_val_loss=0.01806 	 time=2.60s
# Best: Epoch 26 	 loss=0.01700 	 val_loss=0.01795 	 sm_loss=0.01715 	 sm_val_loss=0.01796 	 time=2.44s
# Best: Epoch 28 	 loss=0.01682 	 val_loss=0.01798 	 sm_loss=0.01698 	 sm_val_loss=0.01795 	 time=2.32s
# Best: Epoch 29 	 loss=0.01672 	 val_loss=0.01784 	 sm_loss=0.01687 	 sm_val_loss=0.01784 	 time=2.60s
# Best: Epoch 30 	 loss=0.01660 	 val_loss=0.01776 	 sm_loss=0.01677 	 sm_val_loss=0.01780 	 time=2.32s
# Best: Epoch 31 	 loss=0.01647 	 val_loss=0.01777 	 sm_loss=0.01665 	 sm_val_loss=0.01779 	 time=2.66s
# Best: Epoch 32 	 loss=0.01641 	 val_loss=0.01776 	 sm_loss=0.01658 	 sm_val_loss=0.01778 	 time=2.68s
# Best: Epoch 33 	 loss=0.01632 	 val_loss=0.01766 	 sm_loss=0.01650 	 sm_val_loss=0.01767 	 time=2.30s
# Best: Epoch 35 	 loss=0.01608 	 val_loss=0.01764 	 sm_loss=0.01628 	 sm_val_loss=0.01766 	 time=2.59s
# Best: Epoch 36 	 loss=0.01598 	 val_loss=0.01764 	 sm_loss=0.01618 	 sm_val_loss=0.01765 	 time=2.32s
# Best: Epoch 37 	 loss=0.01594 	 val_loss=0.01761 	 sm_loss=0.01614 	 sm_val_loss=0.01762 	 time=2.28s
# Best: Epoch 38 	 loss=0.01587 	 val_loss=0.01760 	 sm_loss=0.01607 	 sm_val_loss=0.01760 	 time=2.34s
# Fold 7 log loss: 0.01758852866983563
# Seed 4
# Fold 1 log loss: 0.017548372551330137
# Fold 2 log loss: 0.01677306808793102
# Fold 3 log loss: 0.017650261592857677
# Fold 4 log loss: 0.01698252023910561
# Fold 5 log loss: 0.016834003777563448
# Fold 6 log loss: 0.018296122894588956
# Fold 7 log loss: 0.01758852866983563
# Std of log loss: 0.0005083025952997041
# Total log loss: 0.017383632387861607
# Total log loss in targets: 0.01726256396855493

# %%
aucs = []
for task_id in range(targets.shape[1]-1):
    aucs.append(roc_auc_score(y_true=targets.iloc[:, task_id+1].values,
                              y_score=target_oof[:, task_id]))
print(f"Overall AUC : {np.mean(aucs)}")
# Out:
# Overall AUC : 0.6319849271109889

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015909916602916154

# %%
sub.loc[cons_test_index,target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

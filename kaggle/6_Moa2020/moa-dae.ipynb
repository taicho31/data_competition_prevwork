# %% [markdown]
# - only consider dae features
# - increase to 3 seeds

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from tqdm import tqdm_notebook as tqdm
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

from sklearn.pipeline import make_pipeline,make_union
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.base import BaseEstimator,TransformerMixin

# %% [markdown]
# # functions

# %%
def train_short_form_loader(feature_file,target_file,extra_target_file=None):
    '''takes the original target and features and creates a train dataset 
    in col long format'''
    train_features = pd.read_csv(feature_file)
    train_targets = pd.read_csv(target_file)

    if extra_target_file is not None:
        extra_targets = pd.read_csv(extra_target_file)
        train_targets = pd.merge(train_targets,extra_targets,on ='sig_id')
        del extra_targets

    targets = train_targets.columns[1:]

    train_melt=train_targets.merge(train_features,how="left",on="sig_id")

    del train_features,train_targets
    
    train_melt.set_index("sig_id",inplace=True)

    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt , targets.to_list()

def test_short_form_loader(feature_file):
    '''takes the original target and features and creates a train dataset 
    in col long format'''

    train_features = pd.read_csv(feature_file)

    train_melt =  train_features.copy()
    del train_features

    train_melt.set_index("sig_id",inplace=True)
    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt

# %%
# feature selection transformer
class CatIntMapper( BaseEstimator, TransformerMixin ):
    #Class constructor method that takes in a list of values as its argument
    def __init__(self ,col,dicti):
        self.col = col
        self.dicti = dicti
        
    def fit(self, X, y = None):
        
        return self
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
    def transform( self, X):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
class NamedOutTWrapper(BaseEstimator, TransformerMixin):
    
    def __init__(self,transformer,columns,inplace=False,prefix='_' ):
        self.transformer = transformer
        self.cols = columns
        self.inplace =  inplace
        self.prefix = prefix
        self.transformer_name = self._get_transformer_name()
        
    def fit(self, X, y = None): 
        self.transformer =   self.transformer.fit(X[self.cols] , y )
        return self
    
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ): 
        transformed_columns = self.transformer.fit_transform(X[self.cols] , y )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
            return   pd.concat([X,out],axis=1)
        
    def transform( self, X):
        transformed_columns = self.transformer.transform(X[self.cols]  )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
        return   pd.concat([X,out],axis=1)
    
    def _get_transformer_name(self):
        return str(self.transformer.__class__).split('.')[-1][0:-2]

# %%
# cv folds
def multifold_indexer(train,target_columns,n_splits=10,random_state=12347,**kwargs):
    folds = train.copy()

    mskf = MultilabelStratifiedKFold(n_splits=n_splits,random_state=random_state,**kwargs)
    folds[ 'kfold']=0
    for f, (t_idx, v_idx) in enumerate(mskf.split(X=train, y=train[target_columns])):
        folds.iloc[v_idx,-1] = int(f)

    folds['kfold'] = folds['kfold'].astype(int)
    return folds

# %%
# dataset class
class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
        }
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }
        return dct
    
class ColumnDropper( BaseEstimator, TransformerMixin ):
    #Class Constructor 
    def __init__( self, cols ):
        self.cols=cols
    #Return self nothing else to do here    
    def fit( self, X, y = None ):
        return self 
    
    #Method that describes what we need this transformer to do
    def transform( self, X, y = None ):
        return X.drop(self.cols,axis=1)

# %%
# dae model
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class DAE_Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size=1100,hidden_size2=1300):
        super(DAE_Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        #self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size))
        
        self.batch_norm2 = nn.BatchNorm1d(hidden_size)
        #self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size, hidden_size2))
        
        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        #self.dropout3 = nn.Dropout(drop_rate2)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, hidden_size))
        
        #self.batch_norm4 = nn.BatchNorm1d(hidden_size)
        #self.dropout4 = nn.Dropout(drop_rate3)
        self.dense4 = nn.utils.weight_norm(nn.Linear(hidden_size, num_features))
        
    def forward(self, x,mode='DAE'):
        #x = self.batch_norm1(x)
        #x1 = self.dropout1(x1)
        x1 = F.relu(self.dense1(x))
            
        x2 = self.batch_norm2(x1)
        #x = self.dropout2(x)
        x2 = F.relu(self.dense2(x2))
        
        x3 = self.batch_norm3(x2)
      
        x3 = F.relu(self.dense3(x3))
        
        out = self.dense4(x3)
        
        if mode == 'DAE':
            return out
        else:
            return x1,x2,x3

# %%
def infer_features_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs,mode='get_features')
        
        preds.append(torch.cat(outputs,axis=1).detach().cpu().numpy())
    preds = np.concatenate(preds)
    
    return preds

def run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=False,**kwargs):
    seed_everything(seed)
    if not  inference_only:
        train_dataset = MoADataset(X_train, y_train)
        valid_dataset = MoADataset(X_valid, y_valid)
        trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)

    testdataset = TestDataset(X_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = DAE_Model(
        num_features= X_train.shape[1] ,
        num_targets=  X_train.shape[1],
       # hidden_size=hidden_size,
        **kwargs
    )

    model.to(DEVICE)
    
    if not  inference_only:
        oof = inference_infer_features_fn(model, validloader, DEVICE)    
    else:
        oof= 0
    
    predictions = infer_features_fn(model, testloader, DEVICE)
    predictions = predictions
    
    return oof, predictions

# %% [markdown]
# # denosing auto encoder

# %%
DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 1000
BATCH_SIZE = 640
LEARNING_RATE = 4e-3
WEIGHT_DECAY = 1e-8
NFOLDS = 10
EARLY_STOPPING_STEPS = 10
EARLY_STOP = False
hidden_size=1100
hidden_size2=1300
PATIENCE=10
THRESHOLD = 5e-3

# %%
SEED = [0]
train,target_cols = train_short_form_loader('../input/lish-moa/train_features.csv','../input/lish-moa/train_targets_scored.csv')
test = test_short_form_loader("../input/lish-moa/test_features.csv")

train = pd.concat([train,test])
train[target_cols]= train[target_cols].fillna(0)
test = train.copy()

GENES = [col for col in train.columns if col.startswith('g-')]
CELLS = [col for col in train.columns if col.startswith('c-')]

map_controls = CatIntMapper('cp_type',{'ctl_vehicle': 0, 'trt_cp': 1})    
map_dose = CatIntMapper('cp_dose',{'D1': 1, 'D2': 0})    
map_time = CatIntMapper('cp_time',{24: 0, 48: 1, 72: 2})  

Rankg_g_tansform = NamedOutTWrapper(preprocessing.QuantileTransformer(n_quantiles=1000,random_state=0, output_distribution="normal"),columns= GENES+CELLS,inplace=True)
PCA_g_tansform =  NamedOutTWrapper(PCA(20),columns= GENES,prefix ='_g' )
PCA_c_tansform =  NamedOutTWrapper(PCA(20),columns= CELLS,prefix ='_c' )

CatDropper =ColumnDropper(cols=['cp_type','cp_time','cp_dose'])
transformers_list=[map_controls,map_dose,map_time,Rankg_g_tansform,CatDropper]
exp_name = 'test_DAE_0.2_all_together'

oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

for seed in SEED:
    
    train = multifold_indexer(train,target_cols,n_splits=NFOLDS)
    
    for fold in range(NFOLDS):
            
        train_df = train[train['kfold'] != fold]
        valid_df = train[train['kfold'] == fold]
            
        feature_cols = [col for col in train_df.columns if not (col in target_cols+['kfold'])]
                
        pipeline_val = make_pipeline(*transformers_list)
        
        X_train, y_train  = train_df[feature_cols], train_df[target_cols]
        X_valid, y_valid =  valid_df[feature_cols], valid_df[target_cols].values
        
        X_train = pipeline_val.fit_transform(X_train)
        X_train = X_train.values
        X_valid = pipeline_val.transform(X_valid)
        
        valid_index = X_valid.index
        X_valid = X_valid.values
        
        y_train = y_train.values
        
        X_test = test[feature_cols]
        X_test = pipeline_val.transform(X_test).values
        
        pred_ = run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=True)    
        break
        
transformed_features = pd.DataFrame(pred_[1],index=test.index)

# %%
print(transformed_features.shape)
transformed_features.columns = [str(i) for i in range(len(transformed_features.columns))]
transformed_features.reset_index().to_feather('./features_0.2_altogether.fth')
transformed_features = transformed_features.reset_index(drop=False)
# Out:
# (27796, 3500)

# %% [markdown]
# # prediction

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')

noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
train = train.drop(g_feats + c_feats + ["cp_type"], axis=1)
test = test.drop(g_feats + c_feats + ["cp_type"], axis=1)

# %%
train = train.merge(transformed_features, on="sig_id", how="left")
test = test.merge(transformed_features, on="sig_id", how="left")

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["sig_id"], axis=1, inplace=True)
    return tmp
train = fe(train)
test = fe(test)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()

# %%
class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size1=388,hidden_size2=512,drop_rate1=0.0,drop_rate2=0.3,drop_rate3=0.3):
        super(Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size1))

        self.batch_norm2 = nn.BatchNorm1d(hidden_size1)
        self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size1, hidden_size2))

        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        self.dropout3 = nn.Dropout(drop_rate3)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, num_targets))
        
    def forward(self, x):
        
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x

# %%
#params for one cycle schedule
device = ('cuda' if torch.cuda.is_available() else 'cpu')
train_epochs = 40
batch_size = 256
n_folds = 7

smoothing = 0.001
p_min = smoothing
p_max = 1 - p_min

def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def modelling_dae(tr, target, te, sample_seed, init_num, last_num):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    mskf=MultilabelStratifiedKFold(n_splits = n_folds, shuffle=True, random_state=224)
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)

    models = []
    
    X_test2 = torch.tensor(X_test, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    for fold, (train_index, valid_index) in enumerate(mskf.split(X_train, y_train)):
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)

        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = Model(init_num, last_num)
        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)

        optimizer = optim.Adam(clf.parameters(), lr = 5e-3, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.1, eps=1e-4, verbose=True)                   
        
        clf.to(device)
        
        best_val_loss = np.inf
        stop_counts = 0
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader) 
                
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
        
            elapsed_time = time.time() - start_time 
            scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}   loss={:.5f}   val_loss={:.5f}   sm_loss={:.5f}   sm_val_loss={:.5f}   time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
            else:
                stop_counts += 1
        
        pred_model = Model(init_num, last_num)
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        # test predcition --------------
        test_preds = np.zeros([test_len, y_train.shape[1]])
        for i, (x_batch,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
        
    print("Seed {}".format(seed_))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
seeds = [0,1,2]
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

for seed_ in seeds:
    oof, oof_targets, pytorch_pred = modelling_dae(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1], fn_targets.shape[1])
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1   loss=0.21784   val_loss=0.02529   sm_loss=0.21783   sm_val_loss=0.02529   time=0.82s
# Epoch 2   loss=0.02284   val_loss=0.02110   sm_loss=0.02282   sm_val_loss=0.02106   time=0.65s
# Epoch 3   loss=0.02018   val_loss=0.01922   sm_loss=0.02018   sm_val_loss=0.01924   time=0.65s
# Epoch 4   loss=0.01886   val_loss=0.01844   sm_loss=0.01890   sm_val_loss=0.01845   time=0.65s
# Epoch 5   loss=0.01805   val_loss=0.01799   sm_loss=0.01810   sm_val_loss=0.01804   time=0.65s
# Epoch 6   loss=0.01751   val_loss=0.01778   sm_loss=0.01759   sm_val_loss=0.01784   time=0.65s
# Epoch 7   loss=0.01730   val_loss=0.01775   sm_loss=0.01739   sm_val_loss=0.01783   time=0.65s
# Epoch 8   loss=0.01679   val_loss=0.01750   sm_loss=0.01691   sm_val_loss=0.01763   time=0.64s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13   loss=0.01505   val_loss=0.01709   sm_loss=0.01524   sm_val_loss=0.01723   time=0.63s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017434605999642454
# Fold 2
# Epoch 1   loss=0.22180   val_loss=0.02577   sm_loss=0.22178   sm_val_loss=0.02576   time=0.67s
# Epoch 2   loss=0.02268   val_loss=0.02083   sm_loss=0.02267   sm_val_loss=0.02082   time=0.70s
# Epoch 3   loss=0.02009   val_loss=0.01939   sm_loss=0.02009   sm_val_loss=0.01940   time=0.67s
# Epoch 4   loss=0.01880   val_loss=0.01856   sm_loss=0.01884   sm_val_loss=0.01859   time=0.65s
# Epoch 5   loss=0.01796   val_loss=0.01854   sm_loss=0.01803   sm_val_loss=0.01857   time=1.00s
# Epoch 6   loss=0.01740   val_loss=0.01821   sm_loss=0.01748   sm_val_loss=0.01827   time=0.92s
# Epoch 7   loss=0.01703   val_loss=0.01808   sm_loss=0.01714   sm_val_loss=0.01817   time=0.69s
# Epoch 8   loss=0.01679   val_loss=0.01778   sm_loss=0.01691   sm_val_loss=0.01788   time=0.68s
# Epoch 9   loss=0.01643   val_loss=0.01776   sm_loss=0.01657   sm_val_loss=0.01786   time=0.67s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01482   val_loss=0.01716   sm_loss=0.01502   sm_val_loss=0.01731   time=0.65s
# Epoch 15   loss=0.01410   val_loss=0.01715   sm_loss=0.01431   sm_val_loss=0.01730   time=0.64s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01734163096013881
# Fold 3
# Epoch 1   loss=0.22052   val_loss=0.02527   sm_loss=0.22050   sm_val_loss=0.02526   time=0.65s
# Epoch 2   loss=0.02281   val_loss=0.02090   sm_loss=0.02280   sm_val_loss=0.02089   time=0.73s
# Epoch 3   loss=0.02016   val_loss=0.01897   sm_loss=0.02016   sm_val_loss=0.01897   time=0.65s
# Epoch 4   loss=0.01894   val_loss=0.01813   sm_loss=0.01897   sm_val_loss=0.01815   time=0.73s
# Epoch 5   loss=0.01808   val_loss=0.01774   sm_loss=0.01814   sm_val_loss=0.01780   time=0.64s
# Epoch 6   loss=0.01755   val_loss=0.01752   sm_loss=0.01763   sm_val_loss=0.01759   time=0.80s
# Epoch 7   loss=0.01715   val_loss=0.01732   sm_loss=0.01725   sm_val_loss=0.01743   time=0.65s
# Epoch 8   loss=0.01686   val_loss=0.01712   sm_loss=0.01698   sm_val_loss=0.01723   time=0.64s
# Epoch 10   loss=0.01651   val_loss=0.01710   sm_loss=0.01666   sm_val_loss=0.01722   time=0.83s
# Epoch 13   loss=0.01625   val_loss=0.01711   sm_loss=0.01639   sm_val_loss=0.01722   time=0.63s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18   loss=0.01496   val_loss=0.01656   sm_loss=0.01516   sm_val_loss=0.01671   time=0.65s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.016930345525517743
# Fold 4
# Epoch 1   loss=0.22086   val_loss=0.02564   sm_loss=0.22085   sm_val_loss=0.02563   time=0.89s
# Epoch 2   loss=0.02306   val_loss=0.02080   sm_loss=0.02304   sm_val_loss=0.02080   time=0.88s
# Epoch 3   loss=0.02022   val_loss=0.01921   sm_loss=0.02021   sm_val_loss=0.01922   time=0.65s
# Epoch 4   loss=0.01892   val_loss=0.01847   sm_loss=0.01896   sm_val_loss=0.01849   time=0.64s
# Epoch 5   loss=0.01809   val_loss=0.01785   sm_loss=0.01815   sm_val_loss=0.01790   time=0.70s
# Epoch 9   loss=0.01671   val_loss=0.01758   sm_loss=0.01684   sm_val_loss=0.01767   time=0.66s
# Epoch 12   loss=0.01627   val_loss=0.01743   sm_loss=0.01642   sm_val_loss=0.01753   time=0.64s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17   loss=0.01492   val_loss=0.01701   sm_loss=0.01512   sm_val_loss=0.01715   time=0.79s
# Epoch 18   loss=0.01424   val_loss=0.01700   sm_loss=0.01446   sm_val_loss=0.01713   time=0.64s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017296111134760712
# Fold 5
# Epoch 1   loss=0.22154   val_loss=0.02537   sm_loss=0.22152   sm_val_loss=0.02536   time=0.64s
# Epoch 2   loss=0.02288   val_loss=0.02085   sm_loss=0.02285   sm_val_loss=0.02085   time=0.65s
# Epoch 3   loss=0.02019   val_loss=0.01945   sm_loss=0.02018   sm_val_loss=0.01945   time=0.64s
# Epoch 4   loss=0.01900   val_loss=0.01859   sm_loss=0.01902   sm_val_loss=0.01862   time=0.88s
# Epoch 5   loss=0.01809   val_loss=0.01814   sm_loss=0.01815   sm_val_loss=0.01817   time=0.82s
# Epoch 6   loss=0.01748   val_loss=0.01801   sm_loss=0.01757   sm_val_loss=0.01810   time=0.85s
# Epoch 7   loss=0.01711   val_loss=0.01787   sm_loss=0.01721   sm_val_loss=0.01794   time=0.66s
# Epoch 9   loss=0.01660   val_loss=0.01780   sm_loss=0.01674   sm_val_loss=0.01789   time=0.63s
# Epoch 10   loss=0.01636   val_loss=0.01767   sm_loss=0.01651   sm_val_loss=0.01780   time=0.65s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01491   val_loss=0.01718   sm_loss=0.01511   sm_val_loss=0.01732   time=0.63s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.01741703913384327
# Fold 6
# Epoch 1   loss=0.22298   val_loss=0.02564   sm_loss=0.22296   sm_val_loss=0.02563   time=0.92s
# Epoch 2   loss=0.02287   val_loss=0.02110   sm_loss=0.02285   sm_val_loss=0.02109   time=0.92s
# Epoch 3   loss=0.02026   val_loss=0.01923   sm_loss=0.02026   sm_val_loss=0.01923   time=0.76s
# Epoch 4   loss=0.01895   val_loss=0.01834   sm_loss=0.01897   sm_val_loss=0.01836   time=0.66s
# Epoch 5   loss=0.01808   val_loss=0.01789   sm_loss=0.01813   sm_val_loss=0.01793   time=0.68s
# Epoch 6   loss=0.01748   val_loss=0.01772   sm_loss=0.01757   sm_val_loss=0.01782   time=0.85s
# Epoch 7   loss=0.01716   val_loss=0.01762   sm_loss=0.01726   sm_val_loss=0.01772   time=0.66s
# Epoch 9   loss=0.01670   val_loss=0.01753   sm_loss=0.01683   sm_val_loss=0.01766   time=0.85s
# Epoch 10   loss=0.01641   val_loss=0.01753   sm_loss=0.01656   sm_val_loss=0.01764   time=1.12s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01479   val_loss=0.01695   sm_loss=0.01499   sm_val_loss=0.01709   time=0.65s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017032685935564142
# Fold 7
# Epoch 1   loss=0.22402   val_loss=0.02542   sm_loss=0.22400   sm_val_loss=0.02541   time=0.63s
# Epoch 2   loss=0.02274   val_loss=0.02154   sm_loss=0.02273   sm_val_loss=0.02153   time=0.62s
# Epoch 3   loss=0.02013   val_loss=0.01933   sm_loss=0.02014   sm_val_loss=0.01935   time=0.62s
# Epoch 4   loss=0.01889   val_loss=0.01873   sm_loss=0.01892   sm_val_loss=0.01878   time=0.63s
# Epoch 5   loss=0.01803   val_loss=0.01786   sm_loss=0.01810   sm_val_loss=0.01793   time=0.62s
# Epoch 6   loss=0.01755   val_loss=0.01778   sm_loss=0.01763   sm_val_loss=0.01787   time=0.63s
# Epoch 8   loss=0.01687   val_loss=0.01769   sm_loss=0.01699   sm_val_loss=0.01779   time=0.62s
# Epoch 9   loss=0.01660   val_loss=0.01760   sm_loss=0.01674   sm_val_loss=0.01772   time=0.65s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01499   val_loss=0.01705   sm_loss=0.01518   sm_val_loss=0.01720   time=0.63s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017127326629407753
# Seed 0
# Fold 1 log loss: 0.017434605999642454
# Fold 2 log loss: 0.01734163096013881
# Fold 3 log loss: 0.016930345525517743
# Fold 4 log loss: 0.017296111134760712
# Fold 5 log loss: 0.01741703913384327
# Fold 6 log loss: 0.017032685935564142
# Fold 7 log loss: 0.017127326629407753
# Std of log loss: 0.00018237171911623872
# Total log loss: 0.01722568742351905
# Fold 1
# Epoch 1   loss=0.21895   val_loss=0.02523   sm_loss=0.21890   sm_val_loss=0.02523   time=0.82s
# Epoch 2   loss=0.02272   val_loss=0.02086   sm_loss=0.02271   sm_val_loss=0.02085   time=0.63s
# Epoch 3   loss=0.02015   val_loss=0.01910   sm_loss=0.02015   sm_val_loss=0.01913   time=1.20s
# Epoch 4   loss=0.01888   val_loss=0.01831   sm_loss=0.01891   sm_val_loss=0.01833   time=0.67s
# Epoch 5   loss=0.01797   val_loss=0.01789   sm_loss=0.01803   sm_val_loss=0.01792   time=0.64s
# Epoch 9   loss=0.01665   val_loss=0.01763   sm_loss=0.01679   sm_val_loss=0.01772   time=0.64s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01495   val_loss=0.01703   sm_loss=0.01514   sm_val_loss=0.01717   time=0.61s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017405276679051656
# Fold 2
# Epoch 1   loss=0.21712   val_loss=0.02547   sm_loss=0.21710   sm_val_loss=0.02547   time=0.63s
# Epoch 2   loss=0.02294   val_loss=0.02077   sm_loss=0.02292   sm_val_loss=0.02076   time=0.63s
# Epoch 3   loss=0.02029   val_loss=0.01966   sm_loss=0.02029   sm_val_loss=0.01966   time=0.63s
# Epoch 4   loss=0.01895   val_loss=0.01863   sm_loss=0.01897   sm_val_loss=0.01867   time=0.62s
# Epoch 5   loss=0.01801   val_loss=0.01812   sm_loss=0.01807   sm_val_loss=0.01817   time=0.61s
# Epoch 6   loss=0.01751   val_loss=0.01789   sm_loss=0.01759   sm_val_loss=0.01798   time=0.77s
# Epoch 8   loss=0.01678   val_loss=0.01774   sm_loss=0.01690   sm_val_loss=0.01786   time=0.62s
# Epoch 10   loss=0.01639   val_loss=0.01762   sm_loss=0.01653   sm_val_loss=0.01774   time=0.63s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01487   val_loss=0.01713   sm_loss=0.01507   sm_val_loss=0.01728   time=0.66s
# Epoch 16   loss=0.01420   val_loss=0.01708   sm_loss=0.01441   sm_val_loss=0.01722   time=0.62s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017256718230077562
# Fold 3
# Epoch 1   loss=0.22129   val_loss=0.02489   sm_loss=0.22123   sm_val_loss=0.02488   time=0.93s
# Epoch 2   loss=0.02275   val_loss=0.02034   sm_loss=0.02274   sm_val_loss=0.02034   time=0.62s
# Epoch 3   loss=0.02019   val_loss=0.01892   sm_loss=0.02019   sm_val_loss=0.01891   time=0.62s
# Epoch 4   loss=0.01891   val_loss=0.01812   sm_loss=0.01894   sm_val_loss=0.01814   time=0.61s
# Epoch 5   loss=0.01801   val_loss=0.01791   sm_loss=0.01807   sm_val_loss=0.01794   time=0.70s
# Epoch 6   loss=0.01749   val_loss=0.01749   sm_loss=0.01758   sm_val_loss=0.01756   time=0.90s
# Epoch 7   loss=0.01711   val_loss=0.01743   sm_loss=0.01722   sm_val_loss=0.01753   time=0.80s
# Epoch 8   loss=0.01687   val_loss=0.01737   sm_loss=0.01700   sm_val_loss=0.01746   time=0.62s
# Epoch 9   loss=0.01655   val_loss=0.01716   sm_loss=0.01668   sm_val_loss=0.01728   time=0.63s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01490   val_loss=0.01666   sm_loss=0.01510   sm_val_loss=0.01679   time=0.61s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.016990093876515115
# Fold 4
# Epoch 1   loss=0.22678   val_loss=0.02602   sm_loss=0.22672   sm_val_loss=0.02601   time=0.64s
# Epoch 2   loss=0.02278   val_loss=0.02132   sm_loss=0.02277   sm_val_loss=0.02131   time=0.62s
# Epoch 3   loss=0.02040   val_loss=0.01922   sm_loss=0.02041   sm_val_loss=0.01923   time=0.61s
# Epoch 4   loss=0.01890   val_loss=0.01840   sm_loss=0.01893   sm_val_loss=0.01843   time=0.61s
# Epoch 5   loss=0.01801   val_loss=0.01813   sm_loss=0.01807   sm_val_loss=0.01819   time=0.62s
# Epoch 6   loss=0.01746   val_loss=0.01805   sm_loss=0.01755   sm_val_loss=0.01812   time=0.62s
# Epoch 7   loss=0.01711   val_loss=0.01781   sm_loss=0.01722   sm_val_loss=0.01791   time=0.70s
# Epoch 8   loss=0.01682   val_loss=0.01779   sm_loss=0.01695   sm_val_loss=0.01787   time=0.76s
# Epoch 9   loss=0.01661   val_loss=0.01759   sm_loss=0.01675   sm_val_loss=0.01769   time=0.64s
# Epoch 10   loss=0.01638   val_loss=0.01748   sm_loss=0.01653   sm_val_loss=0.01759   time=0.63s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01505   val_loss=0.01703   sm_loss=0.01525   sm_val_loss=0.01715   time=0.62s
# Epoch 16   loss=0.01433   val_loss=0.01700   sm_loss=0.01453   sm_val_loss=0.01712   time=0.64s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017316346746326584
# Fold 5
# Epoch 1   loss=0.22194   val_loss=0.02675   sm_loss=0.22192   sm_val_loss=0.02674   time=0.60s
# Epoch 2   loss=0.02279   val_loss=0.02120   sm_loss=0.02278   sm_val_loss=0.02120   time=0.60s
# Epoch 3   loss=0.02017   val_loss=0.01964   sm_loss=0.02018   sm_val_loss=0.01964   time=0.63s
# Epoch 4   loss=0.01890   val_loss=0.01873   sm_loss=0.01891   sm_val_loss=0.01874   time=0.60s
# Epoch 5   loss=0.01798   val_loss=0.01799   sm_loss=0.01804   sm_val_loss=0.01804   time=0.65s
# Epoch 6   loss=0.01748   val_loss=0.01793   sm_loss=0.01756   sm_val_loss=0.01799   time=0.61s
# Epoch 7   loss=0.01708   val_loss=0.01781   sm_loss=0.01719   sm_val_loss=0.01789   time=0.75s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12   loss=0.01499   val_loss=0.01727   sm_loss=0.01517   sm_val_loss=0.01739   time=0.98s
# Epoch 13   loss=0.01427   val_loss=0.01726   sm_loss=0.01447   sm_val_loss=0.01739   time=0.62s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017486482015584788
# Fold 6
# Epoch 1   loss=0.22020   val_loss=0.02594   sm_loss=0.22016   sm_val_loss=0.02593   time=1.07s
# Epoch 2   loss=0.02287   val_loss=0.02109   sm_loss=0.02286   sm_val_loss=0.02109   time=0.64s
# Epoch 3   loss=0.02038   val_loss=0.01907   sm_loss=0.02037   sm_val_loss=0.01908   time=0.65s
# Epoch 4   loss=0.01896   val_loss=0.01826   sm_loss=0.01898   sm_val_loss=0.01828   time=0.61s
# Epoch 5   loss=0.01806   val_loss=0.01792   sm_loss=0.01812   sm_val_loss=0.01795   time=0.60s
# Epoch 7   loss=0.01723   val_loss=0.01758   sm_loss=0.01733   sm_val_loss=0.01769   time=0.67s
# Epoch 8   loss=0.01692   val_loss=0.01753   sm_loss=0.01703   sm_val_loss=0.01762   time=0.61s
# Epoch 9   loss=0.01669   val_loss=0.01745   sm_loss=0.01682   sm_val_loss=0.01757   time=0.60s
# Epoch 12   loss=0.01633   val_loss=0.01736   sm_loss=0.01649   sm_val_loss=0.01746   time=0.61s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17   loss=0.01520   val_loss=0.01693   sm_loss=0.01539   sm_val_loss=0.01707   time=0.60s
# Epoch 18   loss=0.01450   val_loss=0.01692   sm_loss=0.01470   sm_val_loss=0.01705   time=0.74s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017005513521897584
# Fold 7
# Epoch 1   loss=0.21853   val_loss=0.02608   sm_loss=0.21852   sm_val_loss=0.02608   time=0.61s
# Epoch 2   loss=0.02288   val_loss=0.02104   sm_loss=0.02286   sm_val_loss=0.02103   time=0.59s
# Epoch 3   loss=0.02020   val_loss=0.01933   sm_loss=0.02020   sm_val_loss=0.01936   time=0.62s
# Epoch 4   loss=0.01895   val_loss=0.01850   sm_loss=0.01898   sm_val_loss=0.01851   time=0.62s
# Epoch 5   loss=0.01806   val_loss=0.01796   sm_loss=0.01812   sm_val_loss=0.01801   time=0.62s
# Epoch 6   loss=0.01746   val_loss=0.01778   sm_loss=0.01754   sm_val_loss=0.01785   time=0.64s
# Epoch 7   loss=0.01710   val_loss=0.01766   sm_loss=0.01721   sm_val_loss=0.01773   time=0.64s
# Epoch 9   loss=0.01655   val_loss=0.01747   sm_loss=0.01668   sm_val_loss=0.01758   time=0.65s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01493   val_loss=0.01713   sm_loss=0.01512   sm_val_loss=0.01727   time=0.64s
# Epoch 15   loss=0.01425   val_loss=0.01708   sm_loss=0.01445   sm_val_loss=0.01722   time=0.81s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.01715832926513754
# Seed 1
# Fold 1 log loss: 0.017405276679051656
# Fold 2 log loss: 0.017256718230077562
# Fold 3 log loss: 0.016990093876515115
# Fold 4 log loss: 0.017316346746326584
# Fold 5 log loss: 0.017486482015584788
# Fold 6 log loss: 0.017005513521897584
# Fold 7 log loss: 0.01715832926513754
# Std of log loss: 0.0001763719368582198
# Total log loss: 0.017231260943067844
# Fold 1
# Epoch 1   loss=0.22140   val_loss=0.02538   sm_loss=0.22136   sm_val_loss=0.02538   time=0.79s
# Epoch 2   loss=0.02284   val_loss=0.02129   sm_loss=0.02282   sm_val_loss=0.02128   time=0.64s
# Epoch 3   loss=0.02016   val_loss=0.01922   sm_loss=0.02017   sm_val_loss=0.01922   time=0.61s
# Epoch 4   loss=0.01884   val_loss=0.01840   sm_loss=0.01887   sm_val_loss=0.01840   time=0.62s
# Epoch 5   loss=0.01799   val_loss=0.01797   sm_loss=0.01805   sm_val_loss=0.01799   time=0.60s
# Epoch 6   loss=0.01746   val_loss=0.01769   sm_loss=0.01755   sm_val_loss=0.01776   time=0.62s
# Epoch 10   loss=0.01628   val_loss=0.01761   sm_loss=0.01642   sm_val_loss=0.01772   time=0.74s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01476   val_loss=0.01711   sm_loss=0.01496   sm_val_loss=0.01725   time=0.59s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01747535445516668
# Fold 2
# Epoch 1   loss=0.21918   val_loss=0.02526   sm_loss=0.21916   sm_val_loss=0.02525   time=0.73s
# Epoch 2   loss=0.02278   val_loss=0.02111   sm_loss=0.02277   sm_val_loss=0.02111   time=0.61s
# Epoch 3   loss=0.02008   val_loss=0.01930   sm_loss=0.02008   sm_val_loss=0.01931   time=0.61s
# Epoch 4   loss=0.01882   val_loss=0.01868   sm_loss=0.01885   sm_val_loss=0.01869   time=0.60s
# Epoch 5   loss=0.01806   val_loss=0.01821   sm_loss=0.01813   sm_val_loss=0.01826   time=0.60s
# Epoch 6   loss=0.01744   val_loss=0.01794   sm_loss=0.01753   sm_val_loss=0.01803   time=0.60s
# Epoch 9   loss=0.01656   val_loss=0.01772   sm_loss=0.01670   sm_val_loss=0.01785   time=0.60s
# Epoch 10   loss=0.01637   val_loss=0.01771   sm_loss=0.01652   sm_val_loss=0.01784   time=0.77s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01482   val_loss=0.01713   sm_loss=0.01502   sm_val_loss=0.01726   time=0.67s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01730884271264506
# Fold 3
# Epoch 1   loss=0.22097   val_loss=0.02539   sm_loss=0.22095   sm_val_loss=0.02538   time=0.86s
# Epoch 2   loss=0.02267   val_loss=0.02059   sm_loss=0.02266   sm_val_loss=0.02058   time=0.66s
# Epoch 3   loss=0.02023   val_loss=0.01898   sm_loss=0.02022   sm_val_loss=0.01898   time=0.63s
# Epoch 4   loss=0.01889   val_loss=0.01802   sm_loss=0.01892   sm_val_loss=0.01806   time=0.63s
# Epoch 5   loss=0.01807   val_loss=0.01768   sm_loss=0.01814   sm_val_loss=0.01773   time=0.64s
# Epoch 6   loss=0.01749   val_loss=0.01747   sm_loss=0.01758   sm_val_loss=0.01755   time=0.65s
# Epoch 8   loss=0.01678   val_loss=0.01743   sm_loss=0.01691   sm_val_loss=0.01754   time=0.59s
# Epoch 9   loss=0.01666   val_loss=0.01714   sm_loss=0.01680   sm_val_loss=0.01726   time=0.62s
# Epoch 11   loss=0.01627   val_loss=0.01706   sm_loss=0.01643   sm_val_loss=0.01719   time=0.60s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16   loss=0.01488   val_loss=0.01669   sm_loss=0.01508   sm_val_loss=0.01682   time=0.61s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.01703526998367515
# Fold 4
# Epoch 1   loss=0.22122   val_loss=0.02546   sm_loss=0.22119   sm_val_loss=0.02545   time=0.63s
# Epoch 2   loss=0.02284   val_loss=0.02119   sm_loss=0.02281   sm_val_loss=0.02118   time=0.62s
# Epoch 3   loss=0.02012   val_loss=0.01917   sm_loss=0.02013   sm_val_loss=0.01917   time=0.64s
# Epoch 4   loss=0.01888   val_loss=0.01826   sm_loss=0.01891   sm_val_loss=0.01828   time=0.61s
# Epoch 5   loss=0.01805   val_loss=0.01825   sm_loss=0.01810   sm_val_loss=0.01827   time=0.61s
# Epoch 6   loss=0.01750   val_loss=0.01780   sm_loss=0.01758   sm_val_loss=0.01787   time=0.59s
# Epoch 7   loss=0.01720   val_loss=0.01771   sm_loss=0.01728   sm_val_loss=0.01781   time=0.75s
# Epoch 8   loss=0.01687   val_loss=0.01768   sm_loss=0.01699   sm_val_loss=0.01777   time=0.60s
# Epoch 10   loss=0.01648   val_loss=0.01754   sm_loss=0.01662   sm_val_loss=0.01766   time=0.84s
# Epoch 11   loss=0.01635   val_loss=0.01752   sm_loss=0.01650   sm_val_loss=0.01765   time=0.60s
# Epoch 14   loss=0.01616   val_loss=0.01745   sm_loss=0.01632   sm_val_loss=0.01755   time=0.59s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19   loss=0.01504   val_loss=0.01704   sm_loss=0.01523   sm_val_loss=0.01716   time=0.59s
# Epoch 20   loss=0.01438   val_loss=0.01703   sm_loss=0.01459   sm_val_loss=0.01716   time=0.60s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.01733891326526709
# Fold 5
# Epoch 1   loss=0.22169   val_loss=0.02559   sm_loss=0.22164   sm_val_loss=0.02558   time=0.68s
# Epoch 2   loss=0.02281   val_loss=0.02096   sm_loss=0.02279   sm_val_loss=0.02095   time=0.99s
# Epoch 3   loss=0.02022   val_loss=0.01945   sm_loss=0.02021   sm_val_loss=0.01948   time=0.70s
# Epoch 4   loss=0.01887   val_loss=0.01861   sm_loss=0.01891   sm_val_loss=0.01864   time=0.64s
# Epoch 5   loss=0.01800   val_loss=0.01802   sm_loss=0.01806   sm_val_loss=0.01807   time=0.66s
# Epoch 6   loss=0.01745   val_loss=0.01796   sm_loss=0.01753   sm_val_loss=0.01804   time=0.64s
# Epoch 7   loss=0.01726   val_loss=0.01792   sm_loss=0.01735   sm_val_loss=0.01802   time=0.63s
# Epoch 8   loss=0.01685   val_loss=0.01784   sm_loss=0.01697   sm_val_loss=0.01793   time=0.61s
# Epoch 9   loss=0.01662   val_loss=0.01783   sm_loss=0.01675   sm_val_loss=0.01792   time=0.62s
# Epoch 10   loss=0.01652   val_loss=0.01773   sm_loss=0.01665   sm_val_loss=0.01785   time=0.61s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01499   val_loss=0.01721   sm_loss=0.01518   sm_val_loss=0.01735   time=0.61s
# Epoch 16   loss=0.01433   val_loss=0.01720   sm_loss=0.01453   sm_val_loss=0.01734   time=0.59s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017438678564378893
# Fold 6
# Epoch 1   loss=0.22037   val_loss=0.02635   sm_loss=0.22036   sm_val_loss=0.02635   time=0.59s
# Epoch 2   loss=0.02270   val_loss=0.02071   sm_loss=0.02270   sm_val_loss=0.02070   time=0.60s
# Epoch 3   loss=0.02013   val_loss=0.01909   sm_loss=0.02014   sm_val_loss=0.01910   time=0.59s
# Epoch 4   loss=0.01886   val_loss=0.01822   sm_loss=0.01889   sm_val_loss=0.01824   time=0.60s
# Epoch 5   loss=0.01803   val_loss=0.01798   sm_loss=0.01809   sm_val_loss=0.01802   time=0.65s
# Epoch 7   loss=0.01718   val_loss=0.01764   sm_loss=0.01728   sm_val_loss=0.01773   time=0.62s
# Epoch 10   loss=0.01644   val_loss=0.01740   sm_loss=0.01659   sm_val_loss=0.01752   time=0.86s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01498   val_loss=0.01688   sm_loss=0.01518   sm_val_loss=0.01702   time=0.58s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.01698065796808638
# Fold 7
# Epoch 1   loss=0.21883   val_loss=0.02602   sm_loss=0.21880   sm_val_loss=0.02601   time=0.61s
# Epoch 2   loss=0.02287   val_loss=0.02090   sm_loss=0.02285   sm_val_loss=0.02089   time=0.64s
# Epoch 3   loss=0.02011   val_loss=0.01931   sm_loss=0.02012   sm_val_loss=0.01932   time=1.40s
# Epoch 4   loss=0.01892   val_loss=0.01830   sm_loss=0.01894   sm_val_loss=0.01833   time=0.85s
# Epoch 5   loss=0.01809   val_loss=0.01802   sm_loss=0.01815   sm_val_loss=0.01807   time=0.66s
# Epoch 6   loss=0.01749   val_loss=0.01794   sm_loss=0.01757   sm_val_loss=0.01801   time=0.62s
# Epoch 8   loss=0.01684   val_loss=0.01787   sm_loss=0.01696   sm_val_loss=0.01798   time=0.78s
# Epoch 10   loss=0.01644   val_loss=0.01776   sm_loss=0.01658   sm_val_loss=0.01788   time=0.60s
# Epoch 11   loss=0.01620   val_loss=0.01760   sm_loss=0.01636   sm_val_loss=0.01773   time=0.58s
# Epoch 14   loss=0.01608   val_loss=0.01749   sm_loss=0.01625   sm_val_loss=0.01762   time=0.58s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19   loss=0.01472   val_loss=0.01718   sm_loss=0.01493   sm_val_loss=0.01731   time=0.67s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.01721799946392184
# Seed 2
# Fold 1 log loss: 0.01747535445516668
# Fold 2 log loss: 0.01730884271264506
# Fold 3 log loss: 0.01703526998367515
# Fold 4 log loss: 0.01733891326526709
# Fold 5 log loss: 0.017438678564378893
# Fold 6 log loss: 0.01698065796808638
# Fold 7 log loss: 0.01721799946392184
# Std of log loss: 0.00017612164586908792
# Total log loss: 0.01725653984308084
# Total log loss in targets: 0.017028472434397854

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.015694167842032654

# %%
train_checkscore.to_csv("dae_oof.csv")

# %%
sub.loc[cons_test_index, target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

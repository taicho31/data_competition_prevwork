# %% [markdown]
# - go back to version 10 model structure
# - go back to multilabel cv

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from tqdm import tqdm_notebook as tqdm
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

from sklearn.pipeline import make_pipeline,make_union
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.base import BaseEstimator,TransformerMixin

# %% [markdown]
# # functions

# %%
def train_short_form_loader(feature_file,target_file,extra_target_file=None):
    '''takes the original target and features and creates a train dataset 
    in col long format'''
    train_features = pd.read_csv(feature_file)
    train_targets = pd.read_csv(target_file)

    if extra_target_file is not None:
        extra_targets = pd.read_csv(extra_target_file)
        train_targets = pd.merge(train_targets,extra_targets,on ='sig_id')
        del extra_targets

    targets = train_targets.columns[1:]

    train_melt=train_targets.merge(train_features,how="left",on="sig_id")

    del train_features,train_targets
    
    train_melt.set_index("sig_id",inplace=True)

    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt , targets.to_list()

def test_short_form_loader(feature_file):
    '''takes the original target and features and creates a train dataset 
    in col long format'''

    train_features = pd.read_csv(feature_file)

    train_melt =  train_features.copy()
    del train_features

    train_melt.set_index("sig_id",inplace=True)
    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt

# %%
# feature selection transformer
class CatIntMapper( BaseEstimator, TransformerMixin ):
    #Class constructor method that takes in a list of values as its argument
    def __init__(self ,col,dicti):
        self.col = col
        self.dicti = dicti
        
    def fit(self, X, y = None):
        
        return self
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
    def transform( self, X):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
class NamedOutTWrapper(BaseEstimator, TransformerMixin):
    
    def __init__(self,transformer,columns,inplace=False,prefix='_' ):
        self.transformer = transformer
        self.cols = columns
        self.inplace =  inplace
        self.prefix = prefix
        self.transformer_name = self._get_transformer_name()
        
    def fit(self, X, y = None): 
        self.transformer =   self.transformer.fit(X[self.cols] , y )
        return self
    
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ): 
        transformed_columns = self.transformer.fit_transform(X[self.cols] , y )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
            return   pd.concat([X,out],axis=1)
        
    def transform( self, X):
        transformed_columns = self.transformer.transform(X[self.cols]  )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
        return   pd.concat([X,out],axis=1)
    
    def _get_transformer_name(self):
        return str(self.transformer.__class__).split('.')[-1][0:-2]

# %%
# cv folds
def multifold_indexer(train,target_columns,n_splits=10,random_state=12347,**kwargs):
    folds = train.copy()

    mskf = MultilabelStratifiedKFold(n_splits=n_splits,random_state=random_state,**kwargs)
    folds[ 'kfold']=0
    for f, (t_idx, v_idx) in enumerate(mskf.split(X=train, y=train[target_columns])):
        folds.iloc[v_idx,-1] = int(f)

    folds['kfold'] = folds['kfold'].astype(int)
    return folds

# %%
# dataset class
class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
        }
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }
        return dct
    
class ColumnDropper( BaseEstimator, TransformerMixin ):
    #Class Constructor 
    def __init__( self, cols ):
        self.cols=cols
    #Return self nothing else to do here    
    def fit( self, X, y = None ):
        return self 
    
    #Method that describes what we need this transformer to do
    def transform( self, X, y = None ):
        return X.drop(self.cols,axis=1)

# %%
# dae model
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class DAE_Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size=1100,hidden_size2=1300):
        super(DAE_Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        #self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size))
        
        self.batch_norm2 = nn.BatchNorm1d(hidden_size)
        #self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size, hidden_size2))
        
        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        #self.dropout3 = nn.Dropout(drop_rate2)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, hidden_size))
        
        #self.batch_norm4 = nn.BatchNorm1d(hidden_size)
        #self.dropout4 = nn.Dropout(drop_rate3)
        self.dense4 = nn.utils.weight_norm(nn.Linear(hidden_size, num_features))
        
    def forward(self, x,mode='DAE'):
        #x = self.batch_norm1(x)
        #x1 = self.dropout1(x1)
        x1 = F.relu(self.dense1(x))
            
        x2 = self.batch_norm2(x1)
        #x = self.dropout2(x)
        x2 = F.relu(self.dense2(x2))
        
        x3 = self.batch_norm3(x2)
      
        x3 = F.relu(self.dense3(x3))
        
        out = self.dense4(x3)
        
        if mode == 'DAE':
            return out
        else:
            return x1,x2,x3

# %%
def infer_features_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs,mode='get_features')
        
        preds.append(torch.cat(outputs,axis=1).detach().cpu().numpy())
    preds = np.concatenate(preds)
    
    return preds

def run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=False,**kwargs):
    seed_everything(seed)
    if not  inference_only:
        train_dataset = MoADataset(X_train, y_train)
        valid_dataset = MoADataset(X_valid, y_valid)
        trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)

    testdataset = TestDataset(X_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = DAE_Model(
        num_features= X_train.shape[1] ,
        num_targets=  X_train.shape[1],
       # hidden_size=hidden_size,
        **kwargs
    )

    model.to(DEVICE)
    
    if not  inference_only:
        oof = inference_infer_features_fn(model, validloader, DEVICE)    
    else:
        oof= 0
    
    predictions = infer_features_fn(model, testloader, DEVICE)
    predictions = predictions
    
    return oof, predictions

# %% [markdown]
# # denosing auto encoder

# %%
DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 1000
BATCH_SIZE = 640
LEARNING_RATE = 4e-3
WEIGHT_DECAY = 1e-8
NFOLDS = 10
EARLY_STOPPING_STEPS = 10
EARLY_STOP = False
hidden_size=1100
hidden_size2=1300
PATIENCE=10
THRESHOLD = 5e-3

# %%
SEED = [0]
train,target_cols = train_short_form_loader('../input/lish-moa/train_features.csv','../input/lish-moa/train_targets_scored.csv')
test = test_short_form_loader("../input/lish-moa/test_features.csv")

train = pd.concat([train,test])
train[target_cols]= train[target_cols].fillna(0)
test = train.copy()

GENES = [col for col in train.columns if col.startswith('g-')]
CELLS = [col for col in train.columns if col.startswith('c-')]

map_controls = CatIntMapper('cp_type',{'ctl_vehicle': 0, 'trt_cp': 1})    
map_dose = CatIntMapper('cp_dose',{'D1': 1, 'D2': 0})    
map_time = CatIntMapper('cp_time',{24: 0, 48: 1, 72: 2})  

Rankg_g_tansform = NamedOutTWrapper(preprocessing.QuantileTransformer(n_quantiles=1000,random_state=0, output_distribution="normal"),columns= GENES+CELLS,inplace=True)
PCA_g_tansform =  NamedOutTWrapper(PCA(20),columns= GENES,prefix ='_g' )
PCA_c_tansform =  NamedOutTWrapper(PCA(20),columns= CELLS,prefix ='_c' )

CatDropper =ColumnDropper(cols=['cp_type','cp_time','cp_dose'])
transformers_list=[map_controls,map_dose,map_time,Rankg_g_tansform,CatDropper]
exp_name = 'test_DAE_0.2_all_together'

oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

for seed in SEED:
    
    train = multifold_indexer(train,target_cols,n_splits=NFOLDS)
    
    for fold in range(NFOLDS):
            
        train_df = train[train['kfold'] != fold]
        valid_df = train[train['kfold'] == fold]
            
        feature_cols = [col for col in train_df.columns if not (col in target_cols+['kfold'])]
                
        pipeline_val = make_pipeline(*transformers_list)
        
        X_train, y_train  = train_df[feature_cols], train_df[target_cols]
        X_valid, y_valid =  valid_df[feature_cols], valid_df[target_cols].values
        
        X_train = pipeline_val.fit_transform(X_train)
        X_train = X_train.values
        X_valid = pipeline_val.transform(X_valid)
        
        valid_index = X_valid.index
        X_valid = X_valid.values
        
        y_train = y_train.values
        
        X_test = test[feature_cols]
        X_test = pipeline_val.transform(X_test).values
        
        pred_ = run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=True)    
        break
        
transformed_features = pd.DataFrame(pred_[1],index=test.index)

# %%
print(transformed_features.shape)
transformed_features.columns = [str(i) for i in range(len(transformed_features.columns))]
transformed_features.reset_index().to_feather('./features_0.2_altogether.fth')
transformed_features = transformed_features.reset_index(drop=False)
# Out:
# (27796, 3500)

# %% [markdown]
# # prediction

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
NB_SPLITS = 7
seed = 34

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[(vc==6)|(vc==12)|(vc==18)].index.sort_values()
vc2 = vc.loc[(vc!=6)&(vc!=12)&(vc!=18)].index.sort_values()
    
# STRATIFY DRUGS 18X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)
    
# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[6, 4, 3, ..., 3, 3, 2]], dtype=int8)

# %%
train = train.drop(g_feats + c_feats + ["cp_type"], axis=1)
test = test.drop(g_feats + c_feats + ["cp_type"], axis=1)

# %%
train = train.merge(transformed_features, on="sig_id", how="left")
test = test.merge(transformed_features, on="sig_id", how="left")

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["sig_id"], axis=1, inplace=True)
    return tmp
train = fe(train)
test = fe(test)

# %%
#train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size1=1024,hidden_size2=1024,drop_rate1=0.1,drop_rate2=0.3,drop_rate3=0.3):
        super(Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size1))

        self.batch_norm2 = nn.BatchNorm1d(hidden_size1)
        self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size1, hidden_size2))

        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        self.dropout3 = nn.Dropout(drop_rate3)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, num_targets))
        
    def forward(self, x):
        
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x

# %%
#params for one cycle schedule
device = ('cuda' if torch.cuda.is_available() else 'cpu')
train_epochs = 30
batch_size = 256
n_folds = 7

smoothing = 0.001
p_min = smoothing
p_max = 1 - p_min

def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def modelling_dae(tr, target, te, sample_seed, init_num, last_num):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)

    models = []
    
    X_test2 = torch.tensor(X_test, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    mskf=MultilabelStratifiedKFold(n_splits = n_folds, shuffle=True, random_state=224)
    for fold, (train_index, valid_index) in enumerate(mskf.split(X_train, y_train)):
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)

        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = Model(init_num, last_num)
        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)

        optimizer = optim.Adam(clf.parameters(), lr = 5e-3, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.1, eps=1e-4, verbose=True)                   
        
        clf.to(device)
        
        best_val_loss = np.inf
        stop_counts = 0
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader) 
                
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
        
            elapsed_time = time.time() - start_time 
            scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
            else:
                stop_counts += 1
        
        pred_model = Model(init_num, last_num)
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        # test predcition --------------
        test_preds = np.zeros([test_len, y_train.shape[1]])
        for i, (x_batch,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
        
    print("Seed {}".format(seed_))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
#    for fold in range(n_folds):
#        valid_index = X_train[:,-1] == fold
#        train_index = X_train[:,-1] != fold
#        print("Fold "+str(fold+1))
#        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
#        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)
#        X_train2 = X_train2[:,:-1]
#        X_valid2 = X_valid2[:,:-1]

# %%
seeds = [0,1,2,3,4]
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

for seed_ in seeds:
    oof, oof_targets, pytorch_pred = modelling_dae(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1], fn_targets.shape[1])
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.20983  val_loss=0.02300  sm_loss=0.20979  sm_val_loss=0.02299  time=0.69s
# Epoch 2  loss=0.02125  val_loss=0.02087  sm_loss=0.02124  sm_val_loss=0.02087  time=0.64s
# Epoch 3  loss=0.01950  val_loss=0.01886  sm_loss=0.01951  sm_val_loss=0.01886  time=0.61s
# Epoch 4  loss=0.01835  val_loss=0.01805  sm_loss=0.01840  sm_val_loss=0.01807  time=0.75s
# Epoch 5  loss=0.01762  val_loss=0.01801  sm_loss=0.01770  sm_val_loss=0.01804  time=0.66s
# Epoch 6  loss=0.01731  val_loss=0.01774  sm_loss=0.01741  sm_val_loss=0.01783  time=0.62s
# Epoch 7  loss=0.01692  val_loss=0.01774  sm_loss=0.01705  sm_val_loss=0.01782  time=0.63s
# Epoch 8  loss=0.01681  val_loss=0.01744  sm_loss=0.01694  sm_val_loss=0.01756  time=0.72s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01546  val_loss=0.01689  sm_loss=0.01564  sm_val_loss=0.01703  time=0.62s
# Epoch 14  loss=0.01480  val_loss=0.01687  sm_loss=0.01499  sm_val_loss=0.01701  time=0.61s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01722277489838017
# Fold 2
# Epoch 1  loss=0.20586  val_loss=0.02240  sm_loss=0.20578  sm_val_loss=0.02240  time=0.74s
# Epoch 2  loss=0.02116  val_loss=0.02066  sm_loss=0.02114  sm_val_loss=0.02066  time=0.70s
# Epoch 3  loss=0.01934  val_loss=0.01905  sm_loss=0.01935  sm_val_loss=0.01907  time=0.76s
# Epoch 4  loss=0.01827  val_loss=0.01872  sm_loss=0.01832  sm_val_loss=0.01873  time=1.10s
# Epoch 5  loss=0.01760  val_loss=0.01810  sm_loss=0.01768  sm_val_loss=0.01816  time=0.65s
# Epoch 6  loss=0.01731  val_loss=0.01797  sm_loss=0.01740  sm_val_loss=0.01807  time=0.61s
# Epoch 7  loss=0.01698  val_loss=0.01759  sm_loss=0.01710  sm_val_loss=0.01770  time=0.63s
# Epoch 10  loss=0.01661  val_loss=0.01756  sm_loss=0.01676  sm_val_loss=0.01767  time=0.62s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01559  val_loss=0.01705  sm_loss=0.01576  sm_val_loss=0.01718  time=0.62s
# Epoch 16  loss=0.01496  val_loss=0.01697  sm_loss=0.01514  sm_val_loss=0.01710  time=0.65s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017137349313961825
# Fold 3
# Epoch 1  loss=0.21037  val_loss=0.02240  sm_loss=0.21026  sm_val_loss=0.02239  time=0.77s
# Epoch 2  loss=0.02125  val_loss=0.02008  sm_loss=0.02125  sm_val_loss=0.02007  time=0.74s
# Epoch 3  loss=0.01945  val_loss=0.01837  sm_loss=0.01946  sm_val_loss=0.01839  time=0.61s
# Epoch 4  loss=0.01841  val_loss=0.01776  sm_loss=0.01847  sm_val_loss=0.01780  time=0.61s
# Epoch 5  loss=0.01771  val_loss=0.01744  sm_loss=0.01780  sm_val_loss=0.01753  time=0.62s
# Epoch 6  loss=0.01732  val_loss=0.01718  sm_loss=0.01743  sm_val_loss=0.01729  time=0.63s
# Epoch 9  loss=0.01670  val_loss=0.01711  sm_loss=0.01685  sm_val_loss=0.01725  time=0.60s
# Epoch 11  loss=0.01658  val_loss=0.01702  sm_loss=0.01674  sm_val_loss=0.01717  time=0.71s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01557  val_loss=0.01651  sm_loss=0.01574  sm_val_loss=0.01666  time=0.64s
# Epoch 17  loss=0.01490  val_loss=0.01647  sm_loss=0.01508  sm_val_loss=0.01661  time=0.76s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.01681132434371775
# Fold 4
# Epoch 1  loss=0.21550  val_loss=0.02257  sm_loss=0.21546  sm_val_loss=0.02256  time=0.71s
# Epoch 2  loss=0.02130  val_loss=0.02059  sm_loss=0.02129  sm_val_loss=0.02058  time=0.70s
# Epoch 3  loss=0.01944  val_loss=0.01897  sm_loss=0.01946  sm_val_loss=0.01898  time=0.72s
# Epoch 4  loss=0.01849  val_loss=0.01818  sm_loss=0.01853  sm_val_loss=0.01822  time=0.66s
# Epoch 5  loss=0.01776  val_loss=0.01799  sm_loss=0.01783  sm_val_loss=0.01807  time=0.62s
# Epoch 6  loss=0.01734  val_loss=0.01783  sm_loss=0.01745  sm_val_loss=0.01792  time=0.64s
# Epoch 7  loss=0.01707  val_loss=0.01751  sm_loss=0.01720  sm_val_loss=0.01764  time=0.61s
# Epoch 11  loss=0.01657  val_loss=0.01752  sm_loss=0.01673  sm_val_loss=0.01763  time=0.60s
# Epoch 13  loss=0.01646  val_loss=0.01741  sm_loss=0.01662  sm_val_loss=0.01753  time=0.83s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18  loss=0.01568  val_loss=0.01694  sm_loss=0.01585  sm_val_loss=0.01707  time=0.64s
# Epoch 19  loss=0.01502  val_loss=0.01684  sm_loss=0.01521  sm_val_loss=0.01697  time=0.70s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017142427195160008
# Fold 5
# Epoch 1  loss=0.20221  val_loss=0.02281  sm_loss=0.20217  sm_val_loss=0.02280  time=0.61s
# Epoch 2  loss=0.02125  val_loss=0.02087  sm_loss=0.02124  sm_val_loss=0.02086  time=0.62s
# Epoch 3  loss=0.01941  val_loss=0.01895  sm_loss=0.01943  sm_val_loss=0.01898  time=0.60s
# Epoch 4  loss=0.01834  val_loss=0.01870  sm_loss=0.01838  sm_val_loss=0.01872  time=0.63s
# Epoch 5  loss=0.01790  val_loss=0.01855  sm_loss=0.01796  sm_val_loss=0.01858  time=0.63s
# Epoch 6  loss=0.01727  val_loss=0.01778  sm_loss=0.01738  sm_val_loss=0.01787  time=0.64s
# Epoch 9  loss=0.01666  val_loss=0.01770  sm_loss=0.01680  sm_val_loss=0.01782  time=0.62s
# Epoch 10  loss=0.01661  val_loss=0.01766  sm_loss=0.01675  sm_val_loss=0.01779  time=0.63s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01553  val_loss=0.01725  sm_loss=0.01570  sm_val_loss=0.01737  time=0.62s
# Epoch 16  loss=0.01487  val_loss=0.01716  sm_loss=0.01505  sm_val_loss=0.01729  time=0.84s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017364794232994904
# Fold 6
# Epoch 1  loss=0.19349  val_loss=0.02242  sm_loss=0.19347  sm_val_loss=0.02241  time=0.62s
# Epoch 2  loss=0.02115  val_loss=0.02044  sm_loss=0.02115  sm_val_loss=0.02043  time=0.62s
# Epoch 3  loss=0.01943  val_loss=0.01876  sm_loss=0.01944  sm_val_loss=0.01879  time=0.74s
# Epoch 4  loss=0.01847  val_loss=0.01814  sm_loss=0.01851  sm_val_loss=0.01820  time=0.61s
# Epoch 5  loss=0.01774  val_loss=0.01778  sm_loss=0.01781  sm_val_loss=0.01785  time=0.62s
# Epoch 6  loss=0.01720  val_loss=0.01771  sm_loss=0.01730  sm_val_loss=0.01780  time=0.62s
# Epoch 8  loss=0.01677  val_loss=0.01749  sm_loss=0.01692  sm_val_loss=0.01762  time=0.70s
# Epoch 10  loss=0.01663  val_loss=0.01735  sm_loss=0.01678  sm_val_loss=0.01748  time=0.71s
# Epoch 13  loss=0.01653  val_loss=0.01722  sm_loss=0.01668  sm_val_loss=0.01734  time=0.84s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18  loss=0.01569  val_loss=0.01677  sm_loss=0.01586  sm_val_loss=0.01690  time=0.60s
# Epoch 19  loss=0.01504  val_loss=0.01673  sm_loss=0.01522  sm_val_loss=0.01687  time=0.60s
# Epoch 20  loss=0.01465  val_loss=0.01672  sm_loss=0.01484  sm_val_loss=0.01685  time=0.61s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.016824435988740852
# Fold 7
# Epoch 1  loss=0.22287  val_loss=0.02272  sm_loss=0.22275  sm_val_loss=0.02271  time=0.66s
# Epoch 2  loss=0.02121  val_loss=0.02062  sm_loss=0.02121  sm_val_loss=0.02061  time=0.63s
# Epoch 3  loss=0.01940  val_loss=0.01911  sm_loss=0.01942  sm_val_loss=0.01910  time=0.63s
# Epoch 4  loss=0.01839  val_loss=0.01814  sm_loss=0.01844  sm_val_loss=0.01816  time=0.66s
# Epoch 5  loss=0.01770  val_loss=0.01814  sm_loss=0.01778  sm_val_loss=0.01813  time=0.63s
# Epoch 6  loss=0.01734  val_loss=0.01776  sm_loss=0.01745  sm_val_loss=0.01786  time=0.60s
# Epoch 7  loss=0.01709  val_loss=0.01764  sm_loss=0.01721  sm_val_loss=0.01775  time=0.74s
# Epoch 8  loss=0.01689  val_loss=0.01753  sm_loss=0.01702  sm_val_loss=0.01765  time=0.98s
# Epoch 11  loss=0.01668  val_loss=0.01751  sm_loss=0.01683  sm_val_loss=0.01765  time=0.62s
# Epoch 12  loss=0.01667  val_loss=0.01749  sm_loss=0.01682  sm_val_loss=0.01763  time=0.82s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01579  val_loss=0.01693  sm_loss=0.01596  sm_val_loss=0.01707  time=0.60s
# Epoch 18  loss=0.01519  val_loss=0.01690  sm_loss=0.01537  sm_val_loss=0.01704  time=0.61s
# Epoch 19  loss=0.01487  val_loss=0.01689  sm_loss=0.01505  sm_val_loss=0.01703  time=0.61s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.016954252830765043
# Seed 0
# Fold 1 log loss: 0.01722277489838017
# Fold 2 log loss: 0.017137349313961825
# Fold 3 log loss: 0.01681132434371775
# Fold 4 log loss: 0.017142427195160008
# Fold 5 log loss: 0.017364794232994904
# Fold 6 log loss: 0.016824435988740852
# Fold 7 log loss: 0.016954252830765043
# Std of log loss: 0.00019290464603126452
# Total log loss: 0.017065348835704465
# Fold 1
# Epoch 1  loss=0.19849  val_loss=0.02222  sm_loss=0.19847  sm_val_loss=0.02221  time=0.61s
# Epoch 2  loss=0.02105  val_loss=0.02012  sm_loss=0.02104  sm_val_loss=0.02012  time=0.60s
# Epoch 3  loss=0.01927  val_loss=0.01878  sm_loss=0.01927  sm_val_loss=0.01879  time=0.62s
# Epoch 4  loss=0.01825  val_loss=0.01808  sm_loss=0.01830  sm_val_loss=0.01813  time=0.62s
# Epoch 5  loss=0.01764  val_loss=0.01782  sm_loss=0.01773  sm_val_loss=0.01791  time=0.72s
# Epoch 7  loss=0.01691  val_loss=0.01762  sm_loss=0.01703  sm_val_loss=0.01774  time=0.78s
# Epoch 8  loss=0.01665  val_loss=0.01741  sm_loss=0.01680  sm_val_loss=0.01754  time=0.62s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01538  val_loss=0.01694  sm_loss=0.01556  sm_val_loss=0.01708  time=0.61s
# Epoch 14  loss=0.01470  val_loss=0.01691  sm_loss=0.01489  sm_val_loss=0.01706  time=0.60s
# Epoch 15  loss=0.01429  val_loss=0.01690  sm_loss=0.01448  sm_val_loss=0.01705  time=0.61s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017260494480068157
# Fold 2
# Epoch 1  loss=0.21736  val_loss=0.02295  sm_loss=0.21730  sm_val_loss=0.02295  time=0.82s
# Epoch 2  loss=0.02132  val_loss=0.02048  sm_loss=0.02130  sm_val_loss=0.02048  time=0.75s
# Epoch 3  loss=0.01958  val_loss=0.01944  sm_loss=0.01959  sm_val_loss=0.01944  time=0.75s
# Epoch 4  loss=0.01838  val_loss=0.01872  sm_loss=0.01843  sm_val_loss=0.01877  time=0.69s
# Epoch 5  loss=0.01774  val_loss=0.01810  sm_loss=0.01781  sm_val_loss=0.01816  time=0.70s
# Epoch 6  loss=0.01734  val_loss=0.01795  sm_loss=0.01744  sm_val_loss=0.01802  time=0.70s
# Epoch 7  loss=0.01703  val_loss=0.01783  sm_loss=0.01715  sm_val_loss=0.01794  time=0.72s
# Epoch 9  loss=0.01674  val_loss=0.01770  sm_loss=0.01689  sm_val_loss=0.01783  time=0.67s
# Epoch 11  loss=0.01661  val_loss=0.01763  sm_loss=0.01676  sm_val_loss=0.01778  time=0.63s
# Epoch 12  loss=0.01653  val_loss=0.01764  sm_loss=0.01668  sm_val_loss=0.01774  time=0.62s
# Epoch 14  loss=0.01659  val_loss=0.01761  sm_loss=0.01674  sm_val_loss=0.01772  time=0.60s
# Epoch 16  loss=0.01659  val_loss=0.01750  sm_loss=0.01674  sm_val_loss=0.01762  time=1.09s
# Epoch 17  loss=0.01660  val_loss=0.01751  sm_loss=0.01675  sm_val_loss=0.01761  time=0.71s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 22  loss=0.01575  val_loss=0.01705  sm_loss=0.01591  sm_val_loss=0.01718  time=0.76s
# Epoch 23  loss=0.01516  val_loss=0.01698  sm_loss=0.01534  sm_val_loss=0.01710  time=0.69s
# Epoch 24  loss=0.01480  val_loss=0.01694  sm_loss=0.01499  sm_val_loss=0.01707  time=0.74s
# Epoch    28: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01711945975699938
# Fold 3
# Epoch 1  loss=0.20941  val_loss=0.02232  sm_loss=0.20931  sm_val_loss=0.02231  time=0.64s
# Epoch 2  loss=0.02117  val_loss=0.02058  sm_loss=0.02116  sm_val_loss=0.02058  time=0.87s
# Epoch 3  loss=0.01940  val_loss=0.01841  sm_loss=0.01942  sm_val_loss=0.01844  time=0.76s
# Epoch 4  loss=0.01837  val_loss=0.01766  sm_loss=0.01841  sm_val_loss=0.01771  time=0.60s
# Epoch 5  loss=0.01774  val_loss=0.01747  sm_loss=0.01782  sm_val_loss=0.01757  time=0.70s
# Epoch 7  loss=0.01715  val_loss=0.01729  sm_loss=0.01726  sm_val_loss=0.01742  time=0.68s
# Epoch 8  loss=0.01688  val_loss=0.01722  sm_loss=0.01702  sm_val_loss=0.01733  time=0.65s
# Epoch 10  loss=0.01670  val_loss=0.01719  sm_loss=0.01685  sm_val_loss=0.01731  time=0.65s
# Epoch 11  loss=0.01672  val_loss=0.01703  sm_loss=0.01687  sm_val_loss=0.01716  time=0.79s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01567  val_loss=0.01652  sm_loss=0.01584  sm_val_loss=0.01666  time=0.60s
# Epoch 17  loss=0.01505  val_loss=0.01647  sm_loss=0.01523  sm_val_loss=0.01661  time=0.71s
# Epoch 19  loss=0.01432  val_loss=0.01646  sm_loss=0.01452  sm_val_loss=0.01660  time=0.60s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.016812590119363917
# Fold 4
# Epoch 1  loss=0.19533  val_loss=0.02212  sm_loss=0.19529  sm_val_loss=0.02211  time=0.68s
# Epoch 2  loss=0.02097  val_loss=0.02033  sm_loss=0.02097  sm_val_loss=0.02033  time=0.70s
# Epoch 3  loss=0.01921  val_loss=0.01894  sm_loss=0.01923  sm_val_loss=0.01894  time=0.60s
# Epoch 4  loss=0.01818  val_loss=0.01810  sm_loss=0.01823  sm_val_loss=0.01815  time=0.64s
# Epoch 6  loss=0.01713  val_loss=0.01755  sm_loss=0.01725  sm_val_loss=0.01764  time=0.65s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 11  loss=0.01538  val_loss=0.01692  sm_loss=0.01555  sm_val_loss=0.01705  time=0.60s
# Epoch 12  loss=0.01465  val_loss=0.01688  sm_loss=0.01484  sm_val_loss=0.01701  time=0.63s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017177987862479274
# Fold 5
# Epoch 1  loss=0.19258  val_loss=0.02232  sm_loss=0.19254  sm_val_loss=0.02231  time=0.75s
# Epoch 2  loss=0.02110  val_loss=0.02067  sm_loss=0.02108  sm_val_loss=0.02067  time=0.71s
# Epoch 3  loss=0.01940  val_loss=0.01898  sm_loss=0.01941  sm_val_loss=0.01901  time=0.95s
# Epoch 4  loss=0.01841  val_loss=0.01842  sm_loss=0.01845  sm_val_loss=0.01846  time=0.64s
# Epoch 5  loss=0.01755  val_loss=0.01812  sm_loss=0.01764  sm_val_loss=0.01818  time=0.68s
# Epoch 6  loss=0.01724  val_loss=0.01791  sm_loss=0.01735  sm_val_loss=0.01799  time=0.69s
# Epoch 8  loss=0.01670  val_loss=0.01768  sm_loss=0.01685  sm_val_loss=0.01780  time=0.67s
# Epoch 10  loss=0.01651  val_loss=0.01752  sm_loss=0.01666  sm_val_loss=0.01764  time=0.59s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01546  val_loss=0.01714  sm_loss=0.01564  sm_val_loss=0.01727  time=0.71s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.01736903538463907
# Fold 6
# Epoch 1  loss=0.18813  val_loss=0.02252  sm_loss=0.18810  sm_val_loss=0.02251  time=0.65s
# Epoch 2  loss=0.02115  val_loss=0.02035  sm_loss=0.02114  sm_val_loss=0.02034  time=0.60s
# Epoch 3  loss=0.01938  val_loss=0.01869  sm_loss=0.01938  sm_val_loss=0.01871  time=0.62s
# Epoch 4  loss=0.01835  val_loss=0.01813  sm_loss=0.01841  sm_val_loss=0.01817  time=0.68s
# Epoch 5  loss=0.01763  val_loss=0.01784  sm_loss=0.01772  sm_val_loss=0.01791  time=0.62s
# Epoch 6  loss=0.01729  val_loss=0.01760  sm_loss=0.01738  sm_val_loss=0.01768  time=0.62s
# Epoch 7  loss=0.01699  val_loss=0.01755  sm_loss=0.01712  sm_val_loss=0.01768  time=0.81s
# Epoch 8  loss=0.01668  val_loss=0.01748  sm_loss=0.01682  sm_val_loss=0.01757  time=0.67s
# Epoch 11  loss=0.01650  val_loss=0.01741  sm_loss=0.01665  sm_val_loss=0.01751  time=0.62s
# Epoch 15  loss=0.01655  val_loss=0.01736  sm_loss=0.01670  sm_val_loss=0.01747  time=0.69s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 20  loss=0.01570  val_loss=0.01677  sm_loss=0.01586  sm_val_loss=0.01690  time=0.60s
# Epoch 21  loss=0.01505  val_loss=0.01671  sm_loss=0.01523  sm_val_loss=0.01683  time=0.60s
# Epoch 22  loss=0.01467  val_loss=0.01670  sm_loss=0.01486  sm_val_loss=0.01683  time=0.66s
# Epoch    25: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.01679500520418037
# Fold 7
# Epoch 1  loss=0.20612  val_loss=0.02303  sm_loss=0.20607  sm_val_loss=0.02302  time=0.63s
# Epoch 2  loss=0.02127  val_loss=0.02063  sm_loss=0.02126  sm_val_loss=0.02063  time=0.61s
# Epoch 3  loss=0.01949  val_loss=0.01884  sm_loss=0.01950  sm_val_loss=0.01887  time=0.82s
# Epoch 4  loss=0.01834  val_loss=0.01820  sm_loss=0.01840  sm_val_loss=0.01822  time=0.62s
# Epoch 5  loss=0.01768  val_loss=0.01787  sm_loss=0.01776  sm_val_loss=0.01793  time=0.60s
# Epoch 6  loss=0.01727  val_loss=0.01787  sm_loss=0.01738  sm_val_loss=0.01793  time=0.62s
# Epoch 7  loss=0.01704  val_loss=0.01760  sm_loss=0.01716  sm_val_loss=0.01774  time=0.65s
# Epoch 9  loss=0.01674  val_loss=0.01760  sm_loss=0.01689  sm_val_loss=0.01773  time=0.68s
# Epoch 11  loss=0.01664  val_loss=0.01760  sm_loss=0.01679  sm_val_loss=0.01772  time=0.59s
# Epoch 12  loss=0.01659  val_loss=0.01750  sm_loss=0.01675  sm_val_loss=0.01762  time=0.60s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01559  val_loss=0.01695  sm_loss=0.01576  sm_val_loss=0.01709  time=0.66s
# Epoch 18  loss=0.01498  val_loss=0.01693  sm_loss=0.01516  sm_val_loss=0.01707  time=0.71s
# Epoch 19  loss=0.01458  val_loss=0.01688  sm_loss=0.01477  sm_val_loss=0.01703  time=0.61s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.016969042941196694
# Seed 1
# Fold 1 log loss: 0.017260494480068157
# Fold 2 log loss: 0.01711945975699938
# Fold 3 log loss: 0.016812590119363917
# Fold 4 log loss: 0.017177987862479274
# Fold 5 log loss: 0.01736903538463907
# Fold 6 log loss: 0.01679500520418037
# Fold 7 log loss: 0.016969042941196694
# Std of log loss: 0.00020419380927327882
# Total log loss: 0.017071956119508316
# Fold 1
# Epoch 1  loss=0.21421  val_loss=0.02336  sm_loss=0.21411  sm_val_loss=0.02335  time=0.67s
# Epoch 2  loss=0.02136  val_loss=0.02072  sm_loss=0.02134  sm_val_loss=0.02071  time=0.61s
# Epoch 3  loss=0.01945  val_loss=0.01872  sm_loss=0.01946  sm_val_loss=0.01874  time=0.60s
# Epoch 4  loss=0.01832  val_loss=0.01814  sm_loss=0.01837  sm_val_loss=0.01818  time=0.64s
# Epoch 5  loss=0.01770  val_loss=0.01810  sm_loss=0.01778  sm_val_loss=0.01814  time=0.63s
# Epoch 7  loss=0.01714  val_loss=0.01750  sm_loss=0.01726  sm_val_loss=0.01762  time=0.74s
# Epoch 11  loss=0.01662  val_loss=0.01748  sm_loss=0.01676  sm_val_loss=0.01761  time=0.64s
# Epoch 12  loss=0.01662  val_loss=0.01748  sm_loss=0.01677  sm_val_loss=0.01760  time=0.61s
# Epoch 13  loss=0.01659  val_loss=0.01741  sm_loss=0.01674  sm_val_loss=0.01754  time=0.61s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18  loss=0.01586  val_loss=0.01696  sm_loss=0.01602  sm_val_loss=0.01709  time=0.63s
# Epoch 19  loss=0.01522  val_loss=0.01693  sm_loss=0.01539  sm_val_loss=0.01707  time=0.66s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01727319705447968
# Fold 2
# Epoch 1  loss=0.21483  val_loss=0.02290  sm_loss=0.21476  sm_val_loss=0.02290  time=0.65s
# Epoch 2  loss=0.02133  val_loss=0.02069  sm_loss=0.02132  sm_val_loss=0.02069  time=0.69s
# Epoch 3  loss=0.01941  val_loss=0.01899  sm_loss=0.01942  sm_val_loss=0.01900  time=0.60s
# Epoch 4  loss=0.01843  val_loss=0.01855  sm_loss=0.01847  sm_val_loss=0.01857  time=0.60s
# Epoch 5  loss=0.01769  val_loss=0.01828  sm_loss=0.01777  sm_val_loss=0.01833  time=0.66s
# Epoch 6  loss=0.01734  val_loss=0.01800  sm_loss=0.01744  sm_val_loss=0.01810  time=0.68s
# Epoch 8  loss=0.01686  val_loss=0.01775  sm_loss=0.01699  sm_val_loss=0.01784  time=0.60s
# Epoch 11  loss=0.01662  val_loss=0.01763  sm_loss=0.01677  sm_val_loss=0.01775  time=0.62s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01564  val_loss=0.01702  sm_loss=0.01581  sm_val_loss=0.01715  time=0.62s
# Epoch 17  loss=0.01508  val_loss=0.01699  sm_loss=0.01526  sm_val_loss=0.01712  time=0.62s
# Epoch 18  loss=0.01469  val_loss=0.01695  sm_loss=0.01488  sm_val_loss=0.01708  time=0.61s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017117549142789082
# Fold 3
# Epoch 1  loss=0.21229  val_loss=0.02249  sm_loss=0.21225  sm_val_loss=0.02248  time=0.61s
# Epoch 2  loss=0.02124  val_loss=0.02027  sm_loss=0.02124  sm_val_loss=0.02026  time=0.64s
# Epoch 3  loss=0.01955  val_loss=0.01840  sm_loss=0.01956  sm_val_loss=0.01843  time=0.64s
# Epoch 4  loss=0.01845  val_loss=0.01765  sm_loss=0.01850  sm_val_loss=0.01771  time=0.64s
# Epoch 5  loss=0.01775  val_loss=0.01761  sm_loss=0.01783  sm_val_loss=0.01768  time=0.78s
# Epoch 7  loss=0.01716  val_loss=0.01743  sm_loss=0.01728  sm_val_loss=0.01755  time=0.61s
# Epoch 8  loss=0.01682  val_loss=0.01710  sm_loss=0.01696  sm_val_loss=0.01723  time=0.62s
# Epoch 10  loss=0.01662  val_loss=0.01701  sm_loss=0.01677  sm_val_loss=0.01716  time=1.14s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01555  val_loss=0.01651  sm_loss=0.01573  sm_val_loss=0.01666  time=0.61s
# Epoch 16  loss=0.01493  val_loss=0.01648  sm_loss=0.01511  sm_val_loss=0.01662  time=0.86s
# Epoch 17  loss=0.01451  val_loss=0.01644  sm_loss=0.01471  sm_val_loss=0.01659  time=0.68s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.016786062625576026
# Fold 4
# Epoch 1  loss=0.20628  val_loss=0.02239  sm_loss=0.20625  sm_val_loss=0.02238  time=0.60s
# Epoch 2  loss=0.02124  val_loss=0.02014  sm_loss=0.02122  sm_val_loss=0.02013  time=0.60s
# Epoch 3  loss=0.01937  val_loss=0.01880  sm_loss=0.01937  sm_val_loss=0.01880  time=0.73s
# Epoch 4  loss=0.01837  val_loss=0.01834  sm_loss=0.01842  sm_val_loss=0.01838  time=0.60s
# Epoch 6  loss=0.01718  val_loss=0.01777  sm_loss=0.01730  sm_val_loss=0.01784  time=0.69s
# Epoch 7  loss=0.01694  val_loss=0.01776  sm_loss=0.01707  sm_val_loss=0.01782  time=0.62s
# Epoch 8  loss=0.01677  val_loss=0.01767  sm_loss=0.01691  sm_val_loss=0.01777  time=0.72s
# Epoch 9  loss=0.01662  val_loss=0.01746  sm_loss=0.01677  sm_val_loss=0.01757  time=0.68s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01543  val_loss=0.01686  sm_loss=0.01562  sm_val_loss=0.01699  time=0.60s
# Epoch 15  loss=0.01480  val_loss=0.01677  sm_loss=0.01499  sm_val_loss=0.01690  time=0.61s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.01708490468104641
# Fold 5
# Epoch 1  loss=0.20966  val_loss=0.02305  sm_loss=0.20956  sm_val_loss=0.02304  time=0.59s
# Epoch 2  loss=0.02132  val_loss=0.02080  sm_loss=0.02131  sm_val_loss=0.02079  time=0.61s
# Epoch 3  loss=0.01951  val_loss=0.01902  sm_loss=0.01953  sm_val_loss=0.01904  time=0.60s
# Epoch 4  loss=0.01837  val_loss=0.01819  sm_loss=0.01842  sm_val_loss=0.01826  time=0.60s
# Epoch 6  loss=0.01723  val_loss=0.01771  sm_loss=0.01734  sm_val_loss=0.01781  time=0.62s
# Epoch 8  loss=0.01678  val_loss=0.01766  sm_loss=0.01692  sm_val_loss=0.01777  time=0.83s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01553  val_loss=0.01716  sm_loss=0.01570  sm_val_loss=0.01729  time=0.71s
# Epoch 14  loss=0.01490  val_loss=0.01710  sm_loss=0.01509  sm_val_loss=0.01724  time=0.67s
# Epoch 15  loss=0.01446  val_loss=0.01709  sm_loss=0.01465  sm_val_loss=0.01722  time=0.70s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.0173372387153202
# Fold 6
# Epoch 1  loss=0.21200  val_loss=0.02281  sm_loss=0.21192  sm_val_loss=0.02280  time=0.72s
# Epoch 2  loss=0.02134  val_loss=0.02054  sm_loss=0.02132  sm_val_loss=0.02053  time=0.71s
# Epoch 3  loss=0.01952  val_loss=0.01888  sm_loss=0.01953  sm_val_loss=0.01889  time=0.63s
# Epoch 4  loss=0.01844  val_loss=0.01807  sm_loss=0.01848  sm_val_loss=0.01813  time=0.60s
# Epoch 5  loss=0.01774  val_loss=0.01770  sm_loss=0.01783  sm_val_loss=0.01779  time=0.64s
# Epoch 6  loss=0.01734  val_loss=0.01766  sm_loss=0.01744  sm_val_loss=0.01775  time=0.65s
# Epoch 7  loss=0.01703  val_loss=0.01745  sm_loss=0.01715  sm_val_loss=0.01759  time=0.72s
# Epoch 10  loss=0.01664  val_loss=0.01732  sm_loss=0.01680  sm_val_loss=0.01744  time=0.61s
# Epoch 11  loss=0.01660  val_loss=0.01716  sm_loss=0.01676  sm_val_loss=0.01730  time=0.80s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01565  val_loss=0.01676  sm_loss=0.01583  sm_val_loss=0.01689  time=0.61s
# Epoch 17  loss=0.01501  val_loss=0.01669  sm_loss=0.01520  sm_val_loss=0.01682  time=0.62s
# Epoch 18  loss=0.01459  val_loss=0.01666  sm_loss=0.01479  sm_val_loss=0.01679  time=0.61s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.016768923115416653
# Fold 7
# Epoch 1  loss=0.21292  val_loss=0.02286  sm_loss=0.21284  sm_val_loss=0.02285  time=0.60s
# Epoch 2  loss=0.02122  val_loss=0.02050  sm_loss=0.02120  sm_val_loss=0.02050  time=0.62s
# Epoch 3  loss=0.01943  val_loss=0.01896  sm_loss=0.01944  sm_val_loss=0.01898  time=0.61s
# Epoch 4  loss=0.01832  val_loss=0.01848  sm_loss=0.01837  sm_val_loss=0.01851  time=0.60s
# Epoch 5  loss=0.01769  val_loss=0.01816  sm_loss=0.01778  sm_val_loss=0.01822  time=0.68s
# Epoch 6  loss=0.01722  val_loss=0.01764  sm_loss=0.01733  sm_val_loss=0.01777  time=0.81s
# Epoch 7  loss=0.01703  val_loss=0.01760  sm_loss=0.01716  sm_val_loss=0.01767  time=0.62s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01561  val_loss=0.01693  sm_loss=0.01579  sm_val_loss=0.01708  time=0.60s
# Epoch 13  loss=0.01493  val_loss=0.01691  sm_loss=0.01511  sm_val_loss=0.01705  time=0.60s
# Epoch 14  loss=0.01455  val_loss=0.01689  sm_loss=0.01474  sm_val_loss=0.01703  time=0.62s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.01695884058257282
# Seed 2
# Fold 1 log loss: 0.01727319705447968
# Fold 2 log loss: 0.017117549142789082
# Fold 3 log loss: 0.016786062625576026
# Fold 4 log loss: 0.01708490468104641
# Fold 5 log loss: 0.0173372387153202
# Fold 6 log loss: 0.016768923115416653
# Fold 7 log loss: 0.01695884058257282
# Std of log loss: 0.00020528863667002443
# Total log loss: 0.01704668616861971
# Fold 1
# Epoch 1  loss=0.18826  val_loss=0.02219  sm_loss=0.18821  sm_val_loss=0.02218  time=0.90s
# Epoch 2  loss=0.02102  val_loss=0.02021  sm_loss=0.02102  sm_val_loss=0.02020  time=0.67s
# Epoch 3  loss=0.01922  val_loss=0.01860  sm_loss=0.01924  sm_val_loss=0.01864  time=0.76s
# Epoch 4  loss=0.01823  val_loss=0.01819  sm_loss=0.01828  sm_val_loss=0.01822  time=0.62s
# Epoch 5  loss=0.01765  val_loss=0.01787  sm_loss=0.01773  sm_val_loss=0.01794  time=0.62s
# Epoch 6  loss=0.01711  val_loss=0.01773  sm_loss=0.01722  sm_val_loss=0.01782  time=0.74s
# Epoch 7  loss=0.01683  val_loss=0.01747  sm_loss=0.01695  sm_val_loss=0.01759  time=0.62s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01546  val_loss=0.01694  sm_loss=0.01563  sm_val_loss=0.01708  time=0.60s
# Epoch 13  loss=0.01472  val_loss=0.01687  sm_loss=0.01490  sm_val_loss=0.01702  time=0.61s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017209226009734114
# Fold 2
# Epoch 1  loss=0.19613  val_loss=0.02238  sm_loss=0.19607  sm_val_loss=0.02237  time=0.67s
# Epoch 2  loss=0.02111  val_loss=0.02108  sm_loss=0.02111  sm_val_loss=0.02107  time=0.62s
# Epoch 3  loss=0.01941  val_loss=0.01897  sm_loss=0.01942  sm_val_loss=0.01900  time=0.61s
# Epoch 4  loss=0.01835  val_loss=0.01849  sm_loss=0.01838  sm_val_loss=0.01853  time=0.64s
# Epoch 5  loss=0.01755  val_loss=0.01821  sm_loss=0.01764  sm_val_loss=0.01828  time=0.68s
# Epoch 6  loss=0.01717  val_loss=0.01796  sm_loss=0.01727  sm_val_loss=0.01804  time=0.67s
# Epoch 8  loss=0.01672  val_loss=0.01784  sm_loss=0.01686  sm_val_loss=0.01793  time=0.60s
# Epoch 9  loss=0.01661  val_loss=0.01770  sm_loss=0.01676  sm_val_loss=0.01784  time=0.61s
# Epoch 10  loss=0.01654  val_loss=0.01762  sm_loss=0.01669  sm_val_loss=0.01774  time=0.61s
# Epoch 11  loss=0.01652  val_loss=0.01759  sm_loss=0.01668  sm_val_loss=0.01773  time=0.61s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01556  val_loss=0.01709  sm_loss=0.01573  sm_val_loss=0.01722  time=0.89s
# Epoch 17  loss=0.01491  val_loss=0.01699  sm_loss=0.01509  sm_val_loss=0.01712  time=0.70s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01716108856366217
# Fold 3
# Epoch 1  loss=0.22322  val_loss=0.02286  sm_loss=0.22311  sm_val_loss=0.02285  time=0.59s
# Epoch 2  loss=0.02160  val_loss=0.02040  sm_loss=0.02158  sm_val_loss=0.02039  time=0.60s
# Epoch 3  loss=0.01976  val_loss=0.01853  sm_loss=0.01975  sm_val_loss=0.01853  time=0.61s
# Epoch 4  loss=0.01848  val_loss=0.01787  sm_loss=0.01853  sm_val_loss=0.01792  time=0.61s
# Epoch 6  loss=0.01745  val_loss=0.01749  sm_loss=0.01754  sm_val_loss=0.01758  time=0.62s
# Epoch 7  loss=0.01717  val_loss=0.01734  sm_loss=0.01730  sm_val_loss=0.01743  time=0.63s
# Epoch 8  loss=0.01695  val_loss=0.01721  sm_loss=0.01709  sm_val_loss=0.01735  time=0.61s
# Epoch 11  loss=0.01671  val_loss=0.01721  sm_loss=0.01686  sm_val_loss=0.01734  time=0.81s
# Epoch 12  loss=0.01666  val_loss=0.01720  sm_loss=0.01681  sm_val_loss=0.01732  time=0.61s
# Epoch 13  loss=0.01665  val_loss=0.01699  sm_loss=0.01680  sm_val_loss=0.01711  time=0.75s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18  loss=0.01579  val_loss=0.01648  sm_loss=0.01596  sm_val_loss=0.01662  time=0.66s
# Epoch 19  loss=0.01515  val_loss=0.01643  sm_loss=0.01534  sm_val_loss=0.01657  time=0.61s
# Epoch 20  loss=0.01482  val_loss=0.01641  sm_loss=0.01501  sm_val_loss=0.01656  time=0.62s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.016748704169088805
# Fold 4
# Epoch 1  loss=0.20752  val_loss=0.02219  sm_loss=0.20745  sm_val_loss=0.02219  time=0.60s
# Epoch 2  loss=0.02113  val_loss=0.02042  sm_loss=0.02111  sm_val_loss=0.02042  time=0.60s
# Epoch 3  loss=0.01938  val_loss=0.01897  sm_loss=0.01939  sm_val_loss=0.01899  time=0.61s
# Epoch 4  loss=0.01832  val_loss=0.01856  sm_loss=0.01838  sm_val_loss=0.01859  time=0.62s
# Epoch 5  loss=0.01764  val_loss=0.01796  sm_loss=0.01772  sm_val_loss=0.01803  time=0.86s
# Epoch 6  loss=0.01720  val_loss=0.01770  sm_loss=0.01731  sm_val_loss=0.01780  time=0.64s
# Epoch 7  loss=0.01701  val_loss=0.01766  sm_loss=0.01714  sm_val_loss=0.01777  time=0.60s
# Epoch 8  loss=0.01676  val_loss=0.01741  sm_loss=0.01691  sm_val_loss=0.01752  time=0.78s
# Epoch 9  loss=0.01663  val_loss=0.01737  sm_loss=0.01679  sm_val_loss=0.01749  time=0.62s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01558  val_loss=0.01691  sm_loss=0.01576  sm_val_loss=0.01704  time=0.67s
# Epoch 15  loss=0.01493  val_loss=0.01685  sm_loss=0.01511  sm_val_loss=0.01699  time=0.87s
# Epoch 16  loss=0.01451  val_loss=0.01686  sm_loss=0.01470  sm_val_loss=0.01698  time=0.79s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.01716197048053112
# Fold 5
# Epoch 1  loss=0.19681  val_loss=0.02251  sm_loss=0.19679  sm_val_loss=0.02251  time=0.60s
# Epoch 2  loss=0.02116  val_loss=0.02052  sm_loss=0.02114  sm_val_loss=0.02051  time=0.60s
# Epoch 3  loss=0.01928  val_loss=0.01906  sm_loss=0.01930  sm_val_loss=0.01906  time=0.75s
# Epoch 4  loss=0.01832  val_loss=0.01844  sm_loss=0.01836  sm_val_loss=0.01849  time=0.61s
# Epoch 5  loss=0.01761  val_loss=0.01797  sm_loss=0.01770  sm_val_loss=0.01804  time=0.61s
# Epoch 7  loss=0.01695  val_loss=0.01767  sm_loss=0.01708  sm_val_loss=0.01779  time=0.60s
# Epoch 10  loss=0.01656  val_loss=0.01763  sm_loss=0.01670  sm_val_loss=0.01776  time=0.60s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01559  val_loss=0.01713  sm_loss=0.01576  sm_val_loss=0.01725  time=0.65s
# Epoch 16  loss=0.01497  val_loss=0.01709  sm_loss=0.01514  sm_val_loss=0.01722  time=0.65s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017307218014068978
# Fold 6
# Epoch 1  loss=0.20967  val_loss=0.02282  sm_loss=0.20962  sm_val_loss=0.02281  time=0.65s
# Epoch 2  loss=0.02141  val_loss=0.02054  sm_loss=0.02140  sm_val_loss=0.02054  time=0.61s
# Epoch 3  loss=0.01956  val_loss=0.01895  sm_loss=0.01957  sm_val_loss=0.01896  time=0.60s
# Epoch 4  loss=0.01844  val_loss=0.01796  sm_loss=0.01849  sm_val_loss=0.01802  time=0.63s
# Epoch 5  loss=0.01767  val_loss=0.01778  sm_loss=0.01776  sm_val_loss=0.01785  time=0.62s
# Epoch 7  loss=0.01699  val_loss=0.01752  sm_loss=0.01713  sm_val_loss=0.01765  time=0.93s
# Epoch 9  loss=0.01668  val_loss=0.01742  sm_loss=0.01683  sm_val_loss=0.01756  time=0.68s
# Epoch 11  loss=0.01658  val_loss=0.01729  sm_loss=0.01673  sm_val_loss=0.01741  time=0.60s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01560  val_loss=0.01677  sm_loss=0.01577  sm_val_loss=0.01691  time=0.64s
# Epoch 17  loss=0.01498  val_loss=0.01668  sm_loss=0.01517  sm_val_loss=0.01683  time=0.61s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.01679772701977109
# Fold 7
# Epoch 1  loss=0.21363  val_loss=0.02283  sm_loss=0.21356  sm_val_loss=0.02282  time=0.71s
# Epoch 2  loss=0.02130  val_loss=0.02076  sm_loss=0.02129  sm_val_loss=0.02075  time=0.79s
# Epoch 3  loss=0.01959  val_loss=0.01899  sm_loss=0.01960  sm_val_loss=0.01902  time=0.67s
# Epoch 4  loss=0.01845  val_loss=0.01830  sm_loss=0.01850  sm_val_loss=0.01835  time=0.63s
# Epoch 5  loss=0.01773  val_loss=0.01810  sm_loss=0.01781  sm_val_loss=0.01814  time=0.67s
# Epoch 6  loss=0.01725  val_loss=0.01797  sm_loss=0.01735  sm_val_loss=0.01804  time=0.72s
# Epoch 7  loss=0.01711  val_loss=0.01766  sm_loss=0.01723  sm_val_loss=0.01780  time=0.63s
# Epoch 9  loss=0.01672  val_loss=0.01756  sm_loss=0.01686  sm_val_loss=0.01769  time=0.60s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01552  val_loss=0.01698  sm_loss=0.01570  sm_val_loss=0.01713  time=0.65s
# Epoch 15  loss=0.01492  val_loss=0.01693  sm_loss=0.01510  sm_val_loss=0.01709  time=0.63s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017030028187632024
# Seed 3
# Fold 1 log loss: 0.017209226009734114
# Fold 2 log loss: 0.01716108856366217
# Fold 3 log loss: 0.016748704169088805
# Fold 4 log loss: 0.01716197048053112
# Fold 5 log loss: 0.017307218014068978
# Fold 6 log loss: 0.01679772701977109
# Fold 7 log loss: 0.017030028187632024
# Std of log loss: 0.0001966106436101245
# Total log loss: 0.017059437789239847
# Fold 1
# Epoch 1  loss=0.20312  val_loss=0.02269  sm_loss=0.20306  sm_val_loss=0.02268  time=0.61s
# Epoch 2  loss=0.02103  val_loss=0.02042  sm_loss=0.02102  sm_val_loss=0.02041  time=0.62s
# Epoch 3  loss=0.01923  val_loss=0.01863  sm_loss=0.01924  sm_val_loss=0.01865  time=0.60s
# Epoch 4  loss=0.01822  val_loss=0.01811  sm_loss=0.01828  sm_val_loss=0.01817  time=0.61s
# Epoch 5  loss=0.01759  val_loss=0.01810  sm_loss=0.01767  sm_val_loss=0.01808  time=0.60s
# Epoch 6  loss=0.01726  val_loss=0.01788  sm_loss=0.01736  sm_val_loss=0.01797  time=0.61s
# Epoch 7  loss=0.01694  val_loss=0.01765  sm_loss=0.01707  sm_val_loss=0.01776  time=0.71s
# Epoch 8  loss=0.01679  val_loss=0.01735  sm_loss=0.01693  sm_val_loss=0.01748  time=0.67s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01550  val_loss=0.01685  sm_loss=0.01568  sm_val_loss=0.01699  time=0.62s
# Epoch 14  loss=0.01488  val_loss=0.01680  sm_loss=0.01506  sm_val_loss=0.01694  time=0.61s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01716020141552151
# Fold 2
# Epoch 1  loss=0.21760  val_loss=0.02256  sm_loss=0.21755  sm_val_loss=0.02255  time=0.60s
# Epoch 2  loss=0.02125  val_loss=0.02044  sm_loss=0.02124  sm_val_loss=0.02043  time=0.60s
# Epoch 3  loss=0.01954  val_loss=0.01911  sm_loss=0.01954  sm_val_loss=0.01914  time=0.73s
# Epoch 5  loss=0.01782  val_loss=0.01825  sm_loss=0.01790  sm_val_loss=0.01831  time=0.66s
# Epoch 6  loss=0.01730  val_loss=0.01803  sm_loss=0.01742  sm_val_loss=0.01812  time=0.62s
# Epoch 8  loss=0.01700  val_loss=0.01792  sm_loss=0.01713  sm_val_loss=0.01802  time=0.71s
# Epoch 9  loss=0.01680  val_loss=0.01786  sm_loss=0.01695  sm_val_loss=0.01794  time=0.68s
# Epoch 10  loss=0.01678  val_loss=0.01766  sm_loss=0.01693  sm_val_loss=0.01780  time=0.62s
# Epoch 11  loss=0.01670  val_loss=0.01762  sm_loss=0.01686  sm_val_loss=0.01775  time=0.63s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01559  val_loss=0.01704  sm_loss=0.01577  sm_val_loss=0.01716  time=0.74s
# Epoch 17  loss=0.01495  val_loss=0.01697  sm_loss=0.01514  sm_val_loss=0.01710  time=0.63s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01714088538771034
# Fold 3
# Epoch 1  loss=0.19637  val_loss=0.02235  sm_loss=0.19631  sm_val_loss=0.02234  time=0.61s
# Epoch 2  loss=0.02112  val_loss=0.02022  sm_loss=0.02111  sm_val_loss=0.02021  time=0.61s
# Epoch 3  loss=0.01939  val_loss=0.01851  sm_loss=0.01941  sm_val_loss=0.01851  time=0.62s
# Epoch 4  loss=0.01833  val_loss=0.01792  sm_loss=0.01838  sm_val_loss=0.01797  time=0.64s
# Epoch 5  loss=0.01769  val_loss=0.01756  sm_loss=0.01777  sm_val_loss=0.01764  time=0.66s
# Epoch 6  loss=0.01731  val_loss=0.01738  sm_loss=0.01742  sm_val_loss=0.01749  time=0.75s
# Epoch 7  loss=0.01698  val_loss=0.01714  sm_loss=0.01711  sm_val_loss=0.01726  time=0.81s
# Epoch 8  loss=0.01674  val_loss=0.01707  sm_loss=0.01687  sm_val_loss=0.01720  time=0.62s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01556  val_loss=0.01646  sm_loss=0.01574  sm_val_loss=0.01661  time=0.60s
# Epoch 14  loss=0.01487  val_loss=0.01642  sm_loss=0.01506  sm_val_loss=0.01656  time=0.61s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.016781719687906125
# Fold 4
# Epoch 1  loss=0.19365  val_loss=0.02230  sm_loss=0.19364  sm_val_loss=0.02229  time=0.60s
# Epoch 2  loss=0.02108  val_loss=0.02036  sm_loss=0.02107  sm_val_loss=0.02035  time=0.60s
# Epoch 3  loss=0.01927  val_loss=0.01863  sm_loss=0.01929  sm_val_loss=0.01864  time=0.62s
# Epoch 4  loss=0.01822  val_loss=0.01832  sm_loss=0.01827  sm_val_loss=0.01834  time=0.68s
# Epoch 5  loss=0.01752  val_loss=0.01793  sm_loss=0.01761  sm_val_loss=0.01799  time=0.60s
# Epoch 7  loss=0.01691  val_loss=0.01776  sm_loss=0.01704  sm_val_loss=0.01786  time=0.74s
# Epoch 8  loss=0.01676  val_loss=0.01747  sm_loss=0.01690  sm_val_loss=0.01759  time=0.61s
# Epoch 10  loss=0.01660  val_loss=0.01737  sm_loss=0.01675  sm_val_loss=0.01748  time=0.60s
# Epoch 12  loss=0.01651  val_loss=0.01735  sm_loss=0.01666  sm_val_loss=0.01746  time=0.61s
# Epoch 14  loss=0.01655  val_loss=0.01731  sm_loss=0.01670  sm_val_loss=0.01743  time=0.60s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19  loss=0.01572  val_loss=0.01695  sm_loss=0.01589  sm_val_loss=0.01708  time=0.70s
# Epoch 20  loss=0.01505  val_loss=0.01688  sm_loss=0.01523  sm_val_loss=0.01702  time=0.60s
# Epoch 21  loss=0.01465  val_loss=0.01686  sm_loss=0.01484  sm_val_loss=0.01699  time=0.63s
# Epoch    25: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017179856312527077
# Fold 5
# Epoch 1  loss=0.21965  val_loss=0.02315  sm_loss=0.21953  sm_val_loss=0.02315  time=0.87s
# Epoch 2  loss=0.02144  val_loss=0.02070  sm_loss=0.02142  sm_val_loss=0.02070  time=0.68s
# Epoch 3  loss=0.01951  val_loss=0.01923  sm_loss=0.01951  sm_val_loss=0.01927  time=0.60s
# Epoch 4  loss=0.01841  val_loss=0.01836  sm_loss=0.01845  sm_val_loss=0.01838  time=0.62s
# Epoch 5  loss=0.01761  val_loss=0.01829  sm_loss=0.01769  sm_val_loss=0.01834  time=0.88s
# Epoch 6  loss=0.01723  val_loss=0.01798  sm_loss=0.01734  sm_val_loss=0.01808  time=0.83s
# Epoch 7  loss=0.01700  val_loss=0.01771  sm_loss=0.01712  sm_val_loss=0.01781  time=0.61s
# Epoch 9  loss=0.01668  val_loss=0.01757  sm_loss=0.01682  sm_val_loss=0.01770  time=0.64s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01560  val_loss=0.01719  sm_loss=0.01578  sm_val_loss=0.01731  time=0.60s
# Epoch 15  loss=0.01491  val_loss=0.01715  sm_loss=0.01509  sm_val_loss=0.01728  time=0.73s
# Epoch 16  loss=0.01453  val_loss=0.01712  sm_loss=0.01472  sm_val_loss=0.01725  time=0.60s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.01732061651736292
# Fold 6
# Epoch 1  loss=0.20047  val_loss=0.02254  sm_loss=0.20041  sm_val_loss=0.02253  time=0.59s
# Epoch 2  loss=0.02112  val_loss=0.02037  sm_loss=0.02111  sm_val_loss=0.02036  time=0.72s
# Epoch 3  loss=0.01930  val_loss=0.01876  sm_loss=0.01930  sm_val_loss=0.01879  time=0.62s
# Epoch 4  loss=0.01828  val_loss=0.01846  sm_loss=0.01833  sm_val_loss=0.01846  time=0.62s
# Epoch 5  loss=0.01757  val_loss=0.01772  sm_loss=0.01765  sm_val_loss=0.01780  time=0.84s
# Epoch 6  loss=0.01721  val_loss=0.01762  sm_loss=0.01732  sm_val_loss=0.01772  time=0.72s
# Epoch 7  loss=0.01701  val_loss=0.01755  sm_loss=0.01713  sm_val_loss=0.01764  time=0.65s
# Epoch 9  loss=0.01672  val_loss=0.01744  sm_loss=0.01687  sm_val_loss=0.01758  time=0.63s
# Epoch 10  loss=0.01653  val_loss=0.01739  sm_loss=0.01669  sm_val_loss=0.01753  time=0.61s
# Epoch 12  loss=0.01652  val_loss=0.01725  sm_loss=0.01667  sm_val_loss=0.01738  time=0.60s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01552  val_loss=0.01673  sm_loss=0.01569  sm_val_loss=0.01686  time=0.60s
# Epoch 18  loss=0.01493  val_loss=0.01671  sm_loss=0.01511  sm_val_loss=0.01685  time=0.60s
# Epoch 19  loss=0.01449  val_loss=0.01668  sm_loss=0.01468  sm_val_loss=0.01681  time=0.60s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.016777577599256403
# Fold 7
# Epoch 1  loss=0.19970  val_loss=0.02228  sm_loss=0.19967  sm_val_loss=0.02227  time=0.59s
# Epoch 2  loss=0.02116  val_loss=0.02024  sm_loss=0.02114  sm_val_loss=0.02023  time=0.60s
# Epoch 3  loss=0.01938  val_loss=0.01881  sm_loss=0.01940  sm_val_loss=0.01884  time=0.60s
# Epoch 4  loss=0.01827  val_loss=0.01816  sm_loss=0.01832  sm_val_loss=0.01820  time=0.60s
# Epoch 5  loss=0.01768  val_loss=0.01808  sm_loss=0.01776  sm_val_loss=0.01813  time=0.80s
# Epoch 6  loss=0.01769  val_loss=0.01779  sm_loss=0.01775  sm_val_loss=0.01789  time=0.64s
# Epoch 8  loss=0.01690  val_loss=0.01775  sm_loss=0.01704  sm_val_loss=0.01788  time=0.60s
# Epoch 9  loss=0.01674  val_loss=0.01765  sm_loss=0.01689  sm_val_loss=0.01777  time=0.60s
# Epoch 11  loss=0.01659  val_loss=0.01749  sm_loss=0.01675  sm_val_loss=0.01764  time=0.63s
# Epoch 12  loss=0.01654  val_loss=0.01750  sm_loss=0.01670  sm_val_loss=0.01762  time=0.64s
# Epoch 15  loss=0.01655  val_loss=0.01748  sm_loss=0.01670  sm_val_loss=0.01760  time=0.61s
# Epoch 17  loss=0.01663  val_loss=0.01745  sm_loss=0.01678  sm_val_loss=0.01758  time=0.61s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 22  loss=0.01567  val_loss=0.01695  sm_loss=0.01585  sm_val_loss=0.01709  time=0.65s
# Epoch 23  loss=0.01508  val_loss=0.01691  sm_loss=0.01526  sm_val_loss=0.01705  time=0.61s
# Epoch 24  loss=0.01471  val_loss=0.01690  sm_loss=0.01490  sm_val_loss=0.01705  time=1.03s
# Epoch    28: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.016971715497705146
# Seed 4
# Fold 1 log loss: 0.01716020141552151
# Fold 2 log loss: 0.01714088538771034
# Fold 3 log loss: 0.016781719687906125
# Fold 4 log loss: 0.017179856312527077
# Fold 5 log loss: 0.01732061651736292
# Fold 6 log loss: 0.016777577599256403
# Fold 7 log loss: 0.016971715497705146
# Std of log loss: 0.00019375014543012662
# Total log loss: 0.017047523589748495
# Total log loss in targets: 0.016872100237018958

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.01555004854296187

# %%
train_checkscore.to_csv("dae_oof.csv")

# %%
sub.loc[cons_test_index, target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

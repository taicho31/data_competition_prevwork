# %% [markdown]
# - change final model structure again

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from tqdm import tqdm_notebook as tqdm
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

from sklearn.pipeline import make_pipeline,make_union
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.base import BaseEstimator,TransformerMixin

# %% [markdown]
# # functions

# %%
def train_short_form_loader(feature_file,target_file,extra_target_file=None):
    '''takes the original target and features and creates a train dataset 
    in col long format'''
    train_features = pd.read_csv(feature_file)
    train_targets = pd.read_csv(target_file)

    if extra_target_file is not None:
        extra_targets = pd.read_csv(extra_target_file)
        train_targets = pd.merge(train_targets,extra_targets,on ='sig_id')
        del extra_targets

    targets = train_targets.columns[1:]

    train_melt=train_targets.merge(train_features,how="left",on="sig_id")

    del train_features,train_targets
    
    train_melt.set_index("sig_id",inplace=True)

    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt , targets.to_list()

def test_short_form_loader(feature_file):
    '''takes the original target and features and creates a train dataset 
    in col long format'''

    train_features = pd.read_csv(feature_file)

    train_melt =  train_features.copy()
    del train_features

    train_melt.set_index("sig_id",inplace=True)
    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt

# %%
# feature selection transformer
class CatIntMapper( BaseEstimator, TransformerMixin ):
    #Class constructor method that takes in a list of values as its argument
    def __init__(self ,col,dicti):
        self.col = col
        self.dicti = dicti
        
    def fit(self, X, y = None):
        
        return self
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
    def transform( self, X):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
class NamedOutTWrapper(BaseEstimator, TransformerMixin):
    
    def __init__(self,transformer,columns,inplace=False,prefix='_' ):
        self.transformer = transformer
        self.cols = columns
        self.inplace =  inplace
        self.prefix = prefix
        self.transformer_name = self._get_transformer_name()
        
    def fit(self, X, y = None): 
        self.transformer =   self.transformer.fit(X[self.cols] , y )
        return self
    
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ): 
        transformed_columns = self.transformer.fit_transform(X[self.cols] , y )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
            return   pd.concat([X,out],axis=1)
        
    def transform( self, X):
        transformed_columns = self.transformer.transform(X[self.cols]  )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
        return   pd.concat([X,out],axis=1)
    
    def _get_transformer_name(self):
        return str(self.transformer.__class__).split('.')[-1][0:-2]

# %%
# cv folds
def multifold_indexer(train,target_columns,n_splits=10,random_state=12347,**kwargs):
    folds = train.copy()

    mskf = MultilabelStratifiedKFold(n_splits=n_splits,random_state=random_state,**kwargs)
    folds[ 'kfold']=0
    for f, (t_idx, v_idx) in enumerate(mskf.split(X=train, y=train[target_columns])):
        folds.iloc[v_idx,-1] = int(f)

    folds['kfold'] = folds['kfold'].astype(int)
    return folds

# %%
# dataset class
class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
        }
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }
        return dct
    
class ColumnDropper( BaseEstimator, TransformerMixin ):
    #Class Constructor 
    def __init__( self, cols ):
        self.cols=cols
    #Return self nothing else to do here    
    def fit( self, X, y = None ):
        return self 
    
    #Method that describes what we need this transformer to do
    def transform( self, X, y = None ):
        return X.drop(self.cols,axis=1)

# %%
# dae model
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class DAE_Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size=1100,hidden_size2=1300):
        super(DAE_Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        #self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size))
        
        self.batch_norm2 = nn.BatchNorm1d(hidden_size)
        #self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size, hidden_size2))
        
        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        #self.dropout3 = nn.Dropout(drop_rate2)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, hidden_size))
        
        #self.batch_norm4 = nn.BatchNorm1d(hidden_size)
        #self.dropout4 = nn.Dropout(drop_rate3)
        self.dense4 = nn.utils.weight_norm(nn.Linear(hidden_size, num_features))
        
    def forward(self, x,mode='DAE'):
        #x = self.batch_norm1(x)
        #x1 = self.dropout1(x1)
        x1 = F.relu(self.dense1(x))
            
        x2 = self.batch_norm2(x1)
        #x = self.dropout2(x)
        x2 = F.relu(self.dense2(x2))
        
        x3 = self.batch_norm3(x2)
      
        x3 = F.relu(self.dense3(x3))
        
        out = self.dense4(x3)
        
        if mode == 'DAE':
            return out
        else:
            return x1,x2,x3

# %%
def infer_features_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs,mode='get_features')
        
        preds.append(torch.cat(outputs,axis=1).detach().cpu().numpy())
    preds = np.concatenate(preds)
    
    return preds

def run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=False,**kwargs):
    seed_everything(seed)
    if not  inference_only:
        train_dataset = MoADataset(X_train, y_train)
        valid_dataset = MoADataset(X_valid, y_valid)
        trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)

    testdataset = TestDataset(X_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = DAE_Model(
        num_features= X_train.shape[1] ,
        num_targets=  X_train.shape[1],
       # hidden_size=hidden_size,
        **kwargs
    )

    model.to(DEVICE)
    
    if not  inference_only:
        oof = inference_infer_features_fn(model, validloader, DEVICE)    
    else:
        oof= 0
    
    predictions = infer_features_fn(model, testloader, DEVICE)
    predictions = predictions
    
    return oof, predictions

# %% [markdown]
# # denosing auto encoder

# %%
DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 1000
BATCH_SIZE = 640
LEARNING_RATE = 4e-3
WEIGHT_DECAY = 1e-8
NFOLDS = 10
EARLY_STOPPING_STEPS = 10
EARLY_STOP = False
hidden_size=1100
hidden_size2=1300
PATIENCE=10
THRESHOLD = 5e-3

# %%
SEED = [0]
train,target_cols = train_short_form_loader('../input/lish-moa/train_features.csv','../input/lish-moa/train_targets_scored.csv')
test = test_short_form_loader("../input/lish-moa/test_features.csv")

train = pd.concat([train,test])
train[target_cols]= train[target_cols].fillna(0)
test = train.copy()

GENES = [col for col in train.columns if col.startswith('g-')]
CELLS = [col for col in train.columns if col.startswith('c-')]

map_controls = CatIntMapper('cp_type',{'ctl_vehicle': 0, 'trt_cp': 1})    
map_dose = CatIntMapper('cp_dose',{'D1': 1, 'D2': 0})    
map_time = CatIntMapper('cp_time',{24: 0, 48: 1, 72: 2})  

Rankg_g_tansform = NamedOutTWrapper(preprocessing.QuantileTransformer(n_quantiles=1000,random_state=0, output_distribution="normal"),columns= GENES+CELLS,inplace=True)
PCA_g_tansform =  NamedOutTWrapper(PCA(20),columns= GENES,prefix ='_g' )
PCA_c_tansform =  NamedOutTWrapper(PCA(20),columns= CELLS,prefix ='_c' )

CatDropper =ColumnDropper(cols=['cp_type','cp_time','cp_dose'])
transformers_list=[map_controls,map_dose,map_time,Rankg_g_tansform,CatDropper]
exp_name = 'test_DAE_0.2_all_together'

oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

for seed in SEED:
    
    train = multifold_indexer(train,target_cols,n_splits=NFOLDS)
    
    for fold in range(NFOLDS):
            
        train_df = train[train['kfold'] != fold]
        valid_df = train[train['kfold'] == fold]
            
        feature_cols = [col for col in train_df.columns if not (col in target_cols+['kfold'])]
                
        pipeline_val = make_pipeline(*transformers_list)
        
        X_train, y_train  = train_df[feature_cols], train_df[target_cols]
        X_valid, y_valid =  valid_df[feature_cols], valid_df[target_cols].values
        
        X_train = pipeline_val.fit_transform(X_train)
        X_train = X_train.values
        X_valid = pipeline_val.transform(X_valid)
        
        valid_index = X_valid.index
        X_valid = X_valid.values
        
        y_train = y_train.values
        
        X_test = test[feature_cols]
        X_test = pipeline_val.transform(X_test).values
        
        pred_ = run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=True)    
        break
        
transformed_features = pd.DataFrame(pred_[1],index=test.index)

# %%
print(transformed_features.shape)
transformed_features.columns = [str(i) for i in range(len(transformed_features.columns))]
transformed_features.reset_index().to_feather('./features_0.2_altogether.fth')
transformed_features = transformed_features.reset_index(drop=False)
# Out:
# (27796, 3500)

# %% [markdown]
# # prediction

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
NB_SPLITS = 7
seed = 34

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[(vc==6)|(vc==12)|(vc==18)].index.sort_values()
vc2 = vc.loc[(vc!=6)&(vc!=12)&(vc!=18)].index.sort_values()
    
# STRATIFY DRUGS 18X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)
    
# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[6, 4, 3, ..., 3, 3, 2]], dtype=int8)

# %%
train = train.drop(g_feats + c_feats + ["cp_type"], axis=1)
test = test.drop(g_feats + c_feats + ["cp_type"], axis=1)

# %%
train = train.merge(transformed_features, on="sig_id", how="left")
test = test.merge(transformed_features, on="sig_id", how="left")

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["sig_id"], axis=1, inplace=True)
    return tmp
train = fe(train)
test = fe(test)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size1=2048,hidden_size2=1024,drop_rate1=0.1,drop_rate2=0.3,drop_rate3=0.3):
        super(Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size1))

        self.batch_norm2 = nn.BatchNorm1d(hidden_size1)
        self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size1, hidden_size2))

        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        self.dropout3 = nn.Dropout(drop_rate3)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, num_targets))
        
    def forward(self, x):
        
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x

# %%
#params for one cycle schedule
device = ('cuda' if torch.cuda.is_available() else 'cpu')
train_epochs = 30
batch_size = 256
n_folds = 7

smoothing = 0.001
p_min = smoothing
p_max = 1 - p_min

def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def modelling_dae(tr, target, te, sample_seed, init_num, last_num):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    mskf=MultilabelStratifiedKFold(n_splits = n_folds, shuffle=True, random_state=224)
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)

    models = []
    
    X_test2 = torch.tensor(X_test, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = X_train[:,-1] == fold
        train_index = X_train[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]

        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = Model(init_num, last_num)
        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)

        optimizer = optim.Adam(clf.parameters(), lr = 5e-3, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.1, eps=1e-4, verbose=True)                   
        
        clf.to(device)
        
        best_val_loss = np.inf
        stop_counts = 0
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader) 
                
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
        
            elapsed_time = time.time() - start_time 
            scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}  loss={:.5f}  val_loss={:.5f}  sm_loss={:.5f}  sm_val_loss={:.5f}  time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
            else:
                stop_counts += 1
        
        pred_model = Model(init_num, last_num)
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        # test predcition --------------
        test_preds = np.zeros([test_len, y_train.shape[1]])
        for i, (x_batch,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
        
    print("Seed {}".format(seed_))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
seeds = [0,1,3,4,6]
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

for seed_ in seeds:
    oof, oof_targets, pytorch_pred = modelling_dae(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, fn_targets.shape[1])
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1  loss=0.21292  val_loss=0.02213  sm_loss=0.21281  sm_val_loss=0.02212  time=0.86s
# Epoch 2  loss=0.02123  val_loss=0.02020  sm_loss=0.02121  sm_val_loss=0.02019  time=0.76s
# Epoch 3  loss=0.01933  val_loss=0.01870  sm_loss=0.01933  sm_val_loss=0.01873  time=0.93s
# Epoch 4  loss=0.01839  val_loss=0.01857  sm_loss=0.01844  sm_val_loss=0.01861  time=0.78s
# Epoch 5  loss=0.01812  val_loss=0.01811  sm_loss=0.01813  sm_val_loss=0.01819  time=0.81s
# Epoch 6  loss=0.01755  val_loss=0.01804  sm_loss=0.01765  sm_val_loss=0.01810  time=0.87s
# Epoch 7  loss=0.01743  val_loss=0.01779  sm_loss=0.01755  sm_val_loss=0.01785  time=0.76s
# Epoch 10  loss=0.01705  val_loss=0.01781  sm_loss=0.01721  sm_val_loss=0.01781  time=0.74s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01621  val_loss=0.01735  sm_loss=0.01638  sm_val_loss=0.01738  time=0.77s
# Epoch 16  loss=0.01563  val_loss=0.01729  sm_loss=0.01581  sm_val_loss=0.01732  time=0.76s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01748627775378504
# Fold 2
# Epoch 1  loss=0.21466  val_loss=0.02283  sm_loss=0.21453  sm_val_loss=0.02282  time=0.79s
# Epoch 2  loss=0.02119  val_loss=0.02086  sm_loss=0.02118  sm_val_loss=0.02085  time=0.78s
# Epoch 3  loss=0.01930  val_loss=0.01938  sm_loss=0.01933  sm_val_loss=0.01940  time=0.79s
# Epoch 4  loss=0.01837  val_loss=0.01870  sm_loss=0.01841  sm_val_loss=0.01874  time=0.92s
# Epoch 7  loss=0.01745  val_loss=0.01857  sm_loss=0.01756  sm_val_loss=0.01860  time=0.93s
# Epoch 9  loss=0.01712  val_loss=0.01820  sm_loss=0.01726  sm_val_loss=0.01828  time=0.79s
# Epoch 11  loss=0.01701  val_loss=0.01823  sm_loss=0.01716  sm_val_loss=0.01827  time=0.89s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01612  val_loss=0.01788  sm_loss=0.01628  sm_val_loss=0.01793  time=0.75s
# Epoch 17  loss=0.01561  val_loss=0.01779  sm_loss=0.01578  sm_val_loss=0.01784  time=0.76s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01788607729884531
# Fold 3
# Epoch 1  loss=0.22029  val_loss=0.02256  sm_loss=0.22021  sm_val_loss=0.02255  time=0.75s
# Epoch 2  loss=0.02132  val_loss=0.02056  sm_loss=0.02130  sm_val_loss=0.02055  time=0.78s
# Epoch 3  loss=0.01938  val_loss=0.01884  sm_loss=0.01940  sm_val_loss=0.01885  time=0.76s
# Epoch 6  loss=0.01755  val_loss=0.01816  sm_loss=0.01764  sm_val_loss=0.01822  time=0.75s
# Epoch 7  loss=0.01753  val_loss=0.01813  sm_loss=0.01761  sm_val_loss=0.01817  time=0.76s
# Epoch 8  loss=0.01716  val_loss=0.01803  sm_loss=0.01730  sm_val_loss=0.01808  time=0.91s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01606  val_loss=0.01762  sm_loss=0.01623  sm_val_loss=0.01767  time=0.78s
# Epoch 14  loss=0.01549  val_loss=0.01757  sm_loss=0.01567  sm_val_loss=0.01761  time=0.75s
# Epoch 15  loss=0.01517  val_loss=0.01755  sm_loss=0.01535  sm_val_loss=0.01759  time=0.75s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.01768721903309369
# Fold 4
# Epoch 1  loss=0.22287  val_loss=0.02283  sm_loss=0.22270  sm_val_loss=0.02283  time=0.76s
# Epoch 2  loss=0.02135  val_loss=0.02063  sm_loss=0.02134  sm_val_loss=0.02062  time=0.75s
# Epoch 3  loss=0.01941  val_loss=0.01920  sm_loss=0.01941  sm_val_loss=0.01920  time=0.78s
# Epoch 4  loss=0.01843  val_loss=0.01889  sm_loss=0.01848  sm_val_loss=0.01892  time=0.75s
# Epoch 5  loss=0.01776  val_loss=0.01859  sm_loss=0.01784  sm_val_loss=0.01862  time=0.76s
# Epoch 6  loss=0.01768  val_loss=0.01854  sm_loss=0.01777  sm_val_loss=0.01858  time=0.76s
# Epoch 7  loss=0.01732  val_loss=0.01823  sm_loss=0.01744  sm_val_loss=0.01830  time=0.76s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01615  val_loss=0.01772  sm_loss=0.01632  sm_val_loss=0.01779  time=0.90s
# Epoch 13  loss=0.01558  val_loss=0.01769  sm_loss=0.01576  sm_val_loss=0.01775  time=0.78s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017722370875780283
# Fold 5
# Epoch 1  loss=0.20077  val_loss=0.02259  sm_loss=0.20067  sm_val_loss=0.02258  time=0.74s
# Epoch 2  loss=0.02105  val_loss=0.02077  sm_loss=0.02105  sm_val_loss=0.02075  time=0.75s
# Epoch 3  loss=0.01927  val_loss=0.01935  sm_loss=0.01930  sm_val_loss=0.01934  time=0.88s
# Epoch 4  loss=0.01838  val_loss=0.01872  sm_loss=0.01844  sm_val_loss=0.01868  time=0.75s
# Epoch 6  loss=0.01759  val_loss=0.01809  sm_loss=0.01770  sm_val_loss=0.01812  time=0.76s
# Epoch 8  loss=0.01720  val_loss=0.01797  sm_loss=0.01734  sm_val_loss=0.01800  time=0.74s
# Epoch 12  loss=0.01706  val_loss=0.01793  sm_loss=0.01721  sm_val_loss=0.01795  time=0.75s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01622  val_loss=0.01745  sm_loss=0.01638  sm_val_loss=0.01749  time=0.93s
# Epoch 18  loss=0.01568  val_loss=0.01744  sm_loss=0.01586  sm_val_loss=0.01748  time=0.74s
# Epoch 19  loss=0.01537  val_loss=0.01743  sm_loss=0.01555  sm_val_loss=0.01746  time=0.75s
# Epoch 20  loss=0.01506  val_loss=0.01741  sm_loss=0.01525  sm_val_loss=0.01744  time=0.75s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017351061252781685
# Fold 6
# Epoch 1  loss=0.20114  val_loss=0.02231  sm_loss=0.20111  sm_val_loss=0.02230  time=0.75s
# Epoch 2  loss=0.02118  val_loss=0.02038  sm_loss=0.02116  sm_val_loss=0.02038  time=0.77s
# Epoch 3  loss=0.01927  val_loss=0.01939  sm_loss=0.01928  sm_val_loss=0.01940  time=0.89s
# Epoch 4  loss=0.01831  val_loss=0.01902  sm_loss=0.01836  sm_val_loss=0.01904  time=0.76s
# Epoch 5  loss=0.01775  val_loss=0.01842  sm_loss=0.01783  sm_val_loss=0.01847  time=0.76s
# Epoch 6  loss=0.01732  val_loss=0.01821  sm_loss=0.01743  sm_val_loss=0.01826  time=0.76s
# Epoch 8  loss=0.01710  val_loss=0.01820  sm_loss=0.01723  sm_val_loss=0.01820  time=0.75s
# Epoch 10  loss=0.01695  val_loss=0.01806  sm_loss=0.01710  sm_val_loss=0.01811  time=0.74s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01602  val_loss=0.01766  sm_loss=0.01618  sm_val_loss=0.01771  time=0.74s
# Epoch 16  loss=0.01550  val_loss=0.01763  sm_loss=0.01567  sm_val_loss=0.01767  time=0.74s
# Epoch 17  loss=0.01517  val_loss=0.01756  sm_loss=0.01535  sm_val_loss=0.01761  time=0.76s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017875846409401826
# Fold 7
# Epoch 1  loss=0.21658  val_loss=0.02298  sm_loss=0.21652  sm_val_loss=0.02297  time=0.74s
# Epoch 2  loss=0.02135  val_loss=0.02062  sm_loss=0.02134  sm_val_loss=0.02061  time=0.88s
# Epoch 3  loss=0.01951  val_loss=0.01915  sm_loss=0.01952  sm_val_loss=0.01918  time=0.75s
# Epoch 4  loss=0.01841  val_loss=0.01885  sm_loss=0.01846  sm_val_loss=0.01888  time=0.75s
# Epoch 5  loss=0.01782  val_loss=0.01840  sm_loss=0.01790  sm_val_loss=0.01845  time=0.75s
# Epoch 6  loss=0.01742  val_loss=0.01808  sm_loss=0.01752  sm_val_loss=0.01816  time=0.75s
# Epoch 10  loss=0.01696  val_loss=0.01804  sm_loss=0.01711  sm_val_loss=0.01811  time=0.77s
# Epoch 14  loss=0.01694  val_loss=0.01805  sm_loss=0.01709  sm_val_loss=0.01809  time=0.75s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19  loss=0.01615  val_loss=0.01766  sm_loss=0.01630  sm_val_loss=0.01773  time=0.75s
# Epoch 20  loss=0.01566  val_loss=0.01764  sm_loss=0.01583  sm_val_loss=0.01770  time=0.75s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.01786769665569578
# Seed 0
# Fold 1 log loss: 0.01748627775378504
# Fold 2 log loss: 0.01788607729884531
# Fold 3 log loss: 0.01768721903309369
# Fold 4 log loss: 0.017722370875780283
# Fold 5 log loss: 0.017351061252781685
# Fold 6 log loss: 0.017875846409401826
# Fold 7 log loss: 0.01786769665569578
# Std of log loss: 0.00019335000974698662
# Total log loss: 0.01769607655048295
# Fold 1
# Epoch 1  loss=0.20719  val_loss=0.02285  sm_loss=0.20714  sm_val_loss=0.02285  time=0.74s
# Epoch 2  loss=0.02135  val_loss=0.02057  sm_loss=0.02134  sm_val_loss=0.02056  time=0.91s
# Epoch 3  loss=0.01946  val_loss=0.01863  sm_loss=0.01947  sm_val_loss=0.01867  time=0.76s
# Epoch 4  loss=0.01849  val_loss=0.01818  sm_loss=0.01855  sm_val_loss=0.01822  time=0.75s
# Epoch 5  loss=0.01782  val_loss=0.01803  sm_loss=0.01791  sm_val_loss=0.01810  time=0.75s
# Epoch 6  loss=0.01751  val_loss=0.01774  sm_loss=0.01761  sm_val_loss=0.01780  time=0.74s
# Epoch 9  loss=0.01707  val_loss=0.01777  sm_loss=0.01722  sm_val_loss=0.01777  time=0.75s
# Epoch 11  loss=0.01699  val_loss=0.01769  sm_loss=0.01714  sm_val_loss=0.01772  time=0.74s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01621  val_loss=0.01731  sm_loss=0.01637  sm_val_loss=0.01733  time=0.77s
# Epoch 17  loss=0.01570  val_loss=0.01724  sm_loss=0.01587  sm_val_loss=0.01727  time=0.77s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017452892513390127
# Fold 2
# Epoch 1  loss=0.22026  val_loss=0.02284  sm_loss=0.22016  sm_val_loss=0.02283  time=0.74s
# Epoch 2  loss=0.02120  val_loss=0.02109  sm_loss=0.02119  sm_val_loss=0.02108  time=0.75s
# Epoch 3  loss=0.01932  val_loss=0.01923  sm_loss=0.01933  sm_val_loss=0.01928  time=0.75s
# Epoch 4  loss=0.01848  val_loss=0.01888  sm_loss=0.01851  sm_val_loss=0.01892  time=0.74s
# Epoch 5  loss=0.01781  val_loss=0.01883  sm_loss=0.01788  sm_val_loss=0.01887  time=0.75s
# Epoch 6  loss=0.01755  val_loss=0.01847  sm_loss=0.01765  sm_val_loss=0.01854  time=0.75s
# Epoch 7  loss=0.01733  val_loss=0.01836  sm_loss=0.01745  sm_val_loss=0.01846  time=0.93s
# Epoch 8  loss=0.01721  val_loss=0.01833  sm_loss=0.01734  sm_val_loss=0.01839  time=0.77s
# Epoch 11  loss=0.01707  val_loss=0.01824  sm_loss=0.01722  sm_val_loss=0.01830  time=0.75s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01621  val_loss=0.01777  sm_loss=0.01637  sm_val_loss=0.01783  time=0.89s
# Epoch 17  loss=0.01565  val_loss=0.01770  sm_loss=0.01582  sm_val_loss=0.01776  time=0.75s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017811660361350373
# Fold 3
# Epoch 1  loss=0.23237  val_loss=0.02301  sm_loss=0.23215  sm_val_loss=0.02300  time=0.94s
# Epoch 2  loss=0.02157  val_loss=0.02075  sm_loss=0.02155  sm_val_loss=0.02074  time=0.77s
# Epoch 3  loss=0.01954  val_loss=0.01913  sm_loss=0.01955  sm_val_loss=0.01913  time=1.03s
# Epoch 4  loss=0.01846  val_loss=0.01840  sm_loss=0.01851  sm_val_loss=0.01845  time=0.84s
# Epoch 6  loss=0.01763  val_loss=0.01800  sm_loss=0.01771  sm_val_loss=0.01807  time=0.75s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 11  loss=0.01620  val_loss=0.01760  sm_loss=0.01636  sm_val_loss=0.01766  time=0.74s
# Epoch 12  loss=0.01564  val_loss=0.01756  sm_loss=0.01581  sm_val_loss=0.01761  time=0.76s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.01770235119643463
# Fold 4
# Epoch 1  loss=0.21700  val_loss=0.02281  sm_loss=0.21693  sm_val_loss=0.02280  time=0.74s
# Epoch 2  loss=0.02122  val_loss=0.02069  sm_loss=0.02121  sm_val_loss=0.02068  time=0.74s
# Epoch 3  loss=0.01939  val_loss=0.01895  sm_loss=0.01940  sm_val_loss=0.01898  time=0.75s
# Epoch 4  loss=0.01836  val_loss=0.01868  sm_loss=0.01841  sm_val_loss=0.01870  time=0.76s
# Epoch 6  loss=0.01755  val_loss=0.01840  sm_loss=0.01762  sm_val_loss=0.01847  time=0.77s
# Epoch 7  loss=0.01732  val_loss=0.01825  sm_loss=0.01744  sm_val_loss=0.01831  time=0.95s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01614  val_loss=0.01775  sm_loss=0.01631  sm_val_loss=0.01782  time=0.74s
# Epoch 13  loss=0.01556  val_loss=0.01769  sm_loss=0.01573  sm_val_loss=0.01775  time=0.86s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017734915589612037
# Fold 5
# Epoch 1  loss=0.21730  val_loss=0.02300  sm_loss=0.21720  sm_val_loss=0.02299  time=0.76s
# Epoch 2  loss=0.02126  val_loss=0.02075  sm_loss=0.02125  sm_val_loss=0.02073  time=0.77s
# Epoch 3  loss=0.01941  val_loss=0.01895  sm_loss=0.01944  sm_val_loss=0.01894  time=0.75s
# Epoch 4  loss=0.01838  val_loss=0.01843  sm_loss=0.01844  sm_val_loss=0.01840  time=0.77s
# Epoch 5  loss=0.01789  val_loss=0.01838  sm_loss=0.01797  sm_val_loss=0.01836  time=0.79s
# Epoch 6  loss=0.01752  val_loss=0.01817  sm_loss=0.01763  sm_val_loss=0.01816  time=0.78s
# Epoch 9  loss=0.01720  val_loss=0.01795  sm_loss=0.01734  sm_val_loss=0.01795  time=0.74s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01634  val_loss=0.01745  sm_loss=0.01651  sm_val_loss=0.01745  time=0.75s
# Epoch 15  loss=0.01578  val_loss=0.01743  sm_loss=0.01596  sm_val_loss=0.01744  time=0.74s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017381075134113532
# Fold 6
# Epoch 1  loss=0.20748  val_loss=0.02249  sm_loss=0.20742  sm_val_loss=0.02248  time=0.75s
# Epoch 2  loss=0.02117  val_loss=0.02049  sm_loss=0.02116  sm_val_loss=0.02049  time=0.76s
# Epoch 3  loss=0.01930  val_loss=0.01911  sm_loss=0.01931  sm_val_loss=0.01916  time=0.76s
# Epoch 4  loss=0.01834  val_loss=0.01907  sm_loss=0.01840  sm_val_loss=0.01911  time=0.77s
# Epoch 5  loss=0.01788  val_loss=0.01840  sm_loss=0.01795  sm_val_loss=0.01843  time=0.93s
# Epoch 6  loss=0.01750  val_loss=0.01829  sm_loss=0.01760  sm_val_loss=0.01834  time=0.77s
# Epoch 7  loss=0.01727  val_loss=0.01830  sm_loss=0.01739  sm_val_loss=0.01834  time=0.77s
# Epoch 9  loss=0.01713  val_loss=0.01821  sm_loss=0.01726  sm_val_loss=0.01824  time=0.75s
# Epoch 10  loss=0.01708  val_loss=0.01807  sm_loss=0.01723  sm_val_loss=0.01812  time=0.80s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15  loss=0.01620  val_loss=0.01761  sm_loss=0.01637  sm_val_loss=0.01766  time=0.79s
# Epoch 16  loss=0.01567  val_loss=0.01757  sm_loss=0.01584  sm_val_loss=0.01763  time=0.89s
# Epoch 17  loss=0.01533  val_loss=0.01750  sm_loss=0.01551  sm_val_loss=0.01755  time=0.77s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017815520649338057
# Fold 7
# Epoch 1  loss=0.21101  val_loss=0.02235  sm_loss=0.21095  sm_val_loss=0.02234  time=0.87s
# Epoch 2  loss=0.02113  val_loss=0.02073  sm_loss=0.02111  sm_val_loss=0.02073  time=0.75s
# Epoch 3  loss=0.01930  val_loss=0.01931  sm_loss=0.01931  sm_val_loss=0.01933  time=0.88s
# Epoch 4  loss=0.01840  val_loss=0.01854  sm_loss=0.01845  sm_val_loss=0.01859  time=0.89s
# Epoch 8  loss=0.01716  val_loss=0.01827  sm_loss=0.01729  sm_val_loss=0.01835  time=0.77s
# Epoch 9  loss=0.01709  val_loss=0.01794  sm_loss=0.01723  sm_val_loss=0.01800  time=0.80s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01611  val_loss=0.01768  sm_loss=0.01627  sm_val_loss=0.01773  time=0.77s
# Epoch 15  loss=0.01554  val_loss=0.01762  sm_loss=0.01571  sm_val_loss=0.01768  time=0.76s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017848398938044952
# Seed 1
# Fold 1 log loss: 0.017452892513390127
# Fold 2 log loss: 0.017811660361350373
# Fold 3 log loss: 0.01770235119643463
# Fold 4 log loss: 0.017734915589612037
# Fold 5 log loss: 0.017381075134113532
# Fold 6 log loss: 0.017815520649338057
# Fold 7 log loss: 0.017848398938044952
# Std of log loss: 0.00017257828292037503
# Total log loss: 0.017677437311008536
# Fold 1
# Epoch 1  loss=0.19750  val_loss=0.02215  sm_loss=0.19746  sm_val_loss=0.02214  time=0.74s
# Epoch 2  loss=0.02113  val_loss=0.02010  sm_loss=0.02112  sm_val_loss=0.02009  time=0.91s
# Epoch 3  loss=0.01924  val_loss=0.01860  sm_loss=0.01926  sm_val_loss=0.01861  time=0.76s
# Epoch 5  loss=0.01774  val_loss=0.01806  sm_loss=0.01783  sm_val_loss=0.01812  time=0.74s
# Epoch 6  loss=0.01749  val_loss=0.01800  sm_loss=0.01760  sm_val_loss=0.01806  time=0.75s
# Epoch 7  loss=0.01724  val_loss=0.01786  sm_loss=0.01737  sm_val_loss=0.01788  time=0.88s
# Epoch 9  loss=0.01709  val_loss=0.01782  sm_loss=0.01723  sm_val_loss=0.01785  time=0.74s
# Epoch 11  loss=0.01700  val_loss=0.01780  sm_loss=0.01715  sm_val_loss=0.01784  time=0.75s
# Epoch 12  loss=0.01705  val_loss=0.01781  sm_loss=0.01720  sm_val_loss=0.01784  time=0.75s
# Epoch 14  loss=0.01698  val_loss=0.01772  sm_loss=0.01713  sm_val_loss=0.01774  time=0.74s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19  loss=0.01619  val_loss=0.01728  sm_loss=0.01635  sm_val_loss=0.01731  time=0.74s
# Epoch 20  loss=0.01565  val_loss=0.01725  sm_loss=0.01582  sm_val_loss=0.01729  time=0.74s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01744798455321567
# Fold 2
# Epoch 1  loss=0.21430  val_loss=0.02291  sm_loss=0.21424  sm_val_loss=0.02290  time=0.75s
# Epoch 2  loss=0.02114  val_loss=0.02076  sm_loss=0.02112  sm_val_loss=0.02075  time=0.74s
# Epoch 3  loss=0.01926  val_loss=0.01945  sm_loss=0.01927  sm_val_loss=0.01945  time=0.87s
# Epoch 4  loss=0.01843  val_loss=0.01911  sm_loss=0.01847  sm_val_loss=0.01915  time=0.75s
# Epoch 5  loss=0.01787  val_loss=0.01845  sm_loss=0.01794  sm_val_loss=0.01850  time=0.74s
# Epoch 7  loss=0.01739  val_loss=0.01837  sm_loss=0.01750  sm_val_loss=0.01843  time=0.86s
# Epoch 11  loss=0.01709  val_loss=0.01842  sm_loss=0.01723  sm_val_loss=0.01842  time=0.80s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01620  val_loss=0.01789  sm_loss=0.01637  sm_val_loss=0.01792  time=0.77s
# Epoch 17  loss=0.01568  val_loss=0.01786  sm_loss=0.01586  sm_val_loss=0.01790  time=0.76s
# Epoch 18  loss=0.01539  val_loss=0.01786  sm_loss=0.01557  sm_val_loss=0.01790  time=0.74s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017936482910471778
# Fold 3
# Epoch 1  loss=0.23516  val_loss=0.02342  sm_loss=0.23489  sm_val_loss=0.02341  time=0.74s
# Epoch 2  loss=0.02139  val_loss=0.02072  sm_loss=0.02137  sm_val_loss=0.02071  time=0.75s
# Epoch 3  loss=0.01936  val_loss=0.01894  sm_loss=0.01936  sm_val_loss=0.01894  time=0.74s
# Epoch 4  loss=0.01842  val_loss=0.01868  sm_loss=0.01847  sm_val_loss=0.01870  time=0.75s
# Epoch 5  loss=0.01783  val_loss=0.01858  sm_loss=0.01790  sm_val_loss=0.01865  time=0.75s
# Epoch 7  loss=0.01742  val_loss=0.01816  sm_loss=0.01752  sm_val_loss=0.01824  time=0.74s
# Epoch 8  loss=0.01720  val_loss=0.01809  sm_loss=0.01734  sm_val_loss=0.01813  time=0.75s
# Epoch 10  loss=0.01706  val_loss=0.01809  sm_loss=0.01721  sm_val_loss=0.01811  time=0.74s
# Epoch 11  loss=0.01700  val_loss=0.01799  sm_loss=0.01714  sm_val_loss=0.01805  time=0.76s
# Epoch 14  loss=0.01707  val_loss=0.01803  sm_loss=0.01721  sm_val_loss=0.01804  time=0.75s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19  loss=0.01626  val_loss=0.01760  sm_loss=0.01642  sm_val_loss=0.01763  time=0.74s
# Epoch 20  loss=0.01575  val_loss=0.01752  sm_loss=0.01592  sm_val_loss=0.01755  time=0.74s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.017675657849954212
# Fold 4
# Epoch 1  loss=0.22166  val_loss=0.02285  sm_loss=0.22156  sm_val_loss=0.02284  time=0.75s
# Epoch 2  loss=0.02137  val_loss=0.02122  sm_loss=0.02135  sm_val_loss=0.02121  time=0.76s
# Epoch 3  loss=0.01939  val_loss=0.01951  sm_loss=0.01940  sm_val_loss=0.01951  time=1.05s
# Epoch 4  loss=0.01841  val_loss=0.01882  sm_loss=0.01846  sm_val_loss=0.01885  time=0.92s
# Epoch 6  loss=0.01748  val_loss=0.01839  sm_loss=0.01758  sm_val_loss=0.01846  time=0.74s
# Epoch 7  loss=0.01722  val_loss=0.01834  sm_loss=0.01734  sm_val_loss=0.01841  time=0.78s
# Epoch 8  loss=0.01715  val_loss=0.01830  sm_loss=0.01729  sm_val_loss=0.01837  time=0.82s
# Epoch 12  loss=0.01697  val_loss=0.01828  sm_loss=0.01713  sm_val_loss=0.01832  time=0.78s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01613  val_loss=0.01774  sm_loss=0.01629  sm_val_loss=0.01778  time=0.75s
# Epoch 18  loss=0.01566  val_loss=0.01767  sm_loss=0.01584  sm_val_loss=0.01771  time=0.76s
# Epoch 19  loss=0.01534  val_loss=0.01765  sm_loss=0.01552  sm_val_loss=0.01770  time=0.77s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017671625665051198
# Fold 5
# Epoch 1  loss=0.22984  val_loss=0.02362  sm_loss=0.22969  sm_val_loss=0.02361  time=0.74s
# Epoch 2  loss=0.02148  val_loss=0.02061  sm_loss=0.02145  sm_val_loss=0.02060  time=0.78s
# Epoch 3  loss=0.01947  val_loss=0.01941  sm_loss=0.01949  sm_val_loss=0.01930  time=0.94s
# Epoch 4  loss=0.01846  val_loss=0.01869  sm_loss=0.01851  sm_val_loss=0.01865  time=0.76s
# Epoch 5  loss=0.01790  val_loss=0.01854  sm_loss=0.01798  sm_val_loss=0.01846  time=0.75s
# Epoch 6  loss=0.01753  val_loss=0.01818  sm_loss=0.01764  sm_val_loss=0.01819  time=0.76s
# Epoch 7  loss=0.01729  val_loss=0.01812  sm_loss=0.01742  sm_val_loss=0.01809  time=1.02s
# Epoch 9  loss=0.01713  val_loss=0.01817  sm_loss=0.01727  sm_val_loss=0.01809  time=0.74s
# Epoch 13  loss=0.01700  val_loss=0.01803  sm_loss=0.01715  sm_val_loss=0.01806  time=0.74s
# Epoch 14  loss=0.01705  val_loss=0.01783  sm_loss=0.01720  sm_val_loss=0.01784  time=0.75s
# Epoch 16  loss=0.01704  val_loss=0.01779  sm_loss=0.01719  sm_val_loss=0.01781  time=0.74s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 21  loss=0.01637  val_loss=0.01744  sm_loss=0.01653  sm_val_loss=0.01745  time=0.92s
# Epoch 22  loss=0.01580  val_loss=0.01741  sm_loss=0.01597  sm_val_loss=0.01744  time=0.74s
# Epoch    26: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017351159273655884
# Fold 6
# Epoch 1  loss=0.23057  val_loss=0.02323  sm_loss=0.23038  sm_val_loss=0.02322  time=0.76s
# Epoch 2  loss=0.02144  val_loss=0.02054  sm_loss=0.02143  sm_val_loss=0.02053  time=0.76s
# Epoch 3  loss=0.01950  val_loss=0.01923  sm_loss=0.01949  sm_val_loss=0.01926  time=0.76s
# Epoch 5  loss=0.01805  val_loss=0.01841  sm_loss=0.01811  sm_val_loss=0.01847  time=0.91s
# Epoch 6  loss=0.01748  val_loss=0.01831  sm_loss=0.01757  sm_val_loss=0.01836  time=0.80s
# Epoch 7  loss=0.01734  val_loss=0.01814  sm_loss=0.01745  sm_val_loss=0.01820  time=0.76s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01616  val_loss=0.01766  sm_loss=0.01632  sm_val_loss=0.01770  time=0.88s
# Epoch 13  loss=0.01556  val_loss=0.01761  sm_loss=0.01574  sm_val_loss=0.01766  time=0.75s
# Epoch 14  loss=0.01520  val_loss=0.01760  sm_loss=0.01539  sm_val_loss=0.01765  time=0.75s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017928850816551593
# Fold 7
# Epoch 1  loss=0.21536  val_loss=0.02266  sm_loss=0.21530  sm_val_loss=0.02266  time=0.75s
# Epoch 2  loss=0.02127  val_loss=0.02087  sm_loss=0.02126  sm_val_loss=0.02086  time=0.75s
# Epoch 3  loss=0.01944  val_loss=0.02066  sm_loss=0.01946  sm_val_loss=0.02065  time=0.75s
# Epoch 4  loss=0.01842  val_loss=0.01837  sm_loss=0.01847  sm_val_loss=0.01842  time=0.85s
# Epoch 6  loss=0.01741  val_loss=0.01826  sm_loss=0.01751  sm_val_loss=0.01832  time=0.74s
# Epoch 8  loss=0.01707  val_loss=0.01806  sm_loss=0.01721  sm_val_loss=0.01811  time=0.74s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01603  val_loss=0.01766  sm_loss=0.01620  sm_val_loss=0.01773  time=0.73s
# Epoch 14  loss=0.01545  val_loss=0.01764  sm_loss=0.01562  sm_val_loss=0.01770  time=0.73s
# Epoch 15  loss=0.01512  val_loss=0.01759  sm_loss=0.01531  sm_val_loss=0.01765  time=0.74s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.01780507407584917
# Seed 3
# Fold 1 log loss: 0.01744798455321567
# Fold 2 log loss: 0.017936482910471778
# Fold 3 log loss: 0.017675657849954212
# Fold 4 log loss: 0.017671625665051198
# Fold 5 log loss: 0.017351159273655884
# Fold 6 log loss: 0.017928850816551593
# Fold 7 log loss: 0.01780507407584917
# Std of log loss: 0.00020872013023588923
# Total log loss: 0.017687686766423363
# Fold 1
# Epoch 1  loss=0.21435  val_loss=0.02274  sm_loss=0.21425  sm_val_loss=0.02274  time=0.74s
# Epoch 2  loss=0.02136  val_loss=0.02104  sm_loss=0.02134  sm_val_loss=0.02103  time=1.26s
# Epoch 3  loss=0.01955  val_loss=0.01871  sm_loss=0.01952  sm_val_loss=0.01875  time=1.04s
# Epoch 4  loss=0.01850  val_loss=0.01827  sm_loss=0.01856  sm_val_loss=0.01830  time=0.75s
# Epoch 6  loss=0.01753  val_loss=0.01806  sm_loss=0.01764  sm_val_loss=0.01811  time=0.75s
# Epoch 7  loss=0.01736  val_loss=0.01771  sm_loss=0.01748  sm_val_loss=0.01777  time=0.83s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01610  val_loss=0.01734  sm_loss=0.01628  sm_val_loss=0.01738  time=0.75s
# Epoch 13  loss=0.01551  val_loss=0.01729  sm_loss=0.01569  sm_val_loss=0.01734  time=0.76s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01751756195667797
# Fold 2
# Epoch 1  loss=0.21762  val_loss=0.02290  sm_loss=0.21751  sm_val_loss=0.02289  time=0.75s
# Epoch 2  loss=0.02112  val_loss=0.02072  sm_loss=0.02112  sm_val_loss=0.02072  time=0.74s
# Epoch 3  loss=0.01923  val_loss=0.01907  sm_loss=0.01924  sm_val_loss=0.01911  time=0.74s
# Epoch 6  loss=0.01749  val_loss=0.01837  sm_loss=0.01759  sm_val_loss=0.01843  time=0.74s
# Epoch 8  loss=0.01715  val_loss=0.01836  sm_loss=0.01729  sm_val_loss=0.01841  time=0.88s
# Epoch 10  loss=0.01706  val_loss=0.01834  sm_loss=0.01720  sm_val_loss=0.01840  time=0.76s
# Epoch 12  loss=0.01700  val_loss=0.01822  sm_loss=0.01715  sm_val_loss=0.01827  time=0.74s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01619  val_loss=0.01786  sm_loss=0.01635  sm_val_loss=0.01791  time=0.93s
# Epoch 18  loss=0.01569  val_loss=0.01778  sm_loss=0.01586  sm_val_loss=0.01784  time=0.78s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017890409054204637
# Fold 3
# Epoch 1  loss=0.20228  val_loss=0.02221  sm_loss=0.20224  sm_val_loss=0.02220  time=0.78s
# Epoch 2  loss=0.02114  val_loss=0.02022  sm_loss=0.02112  sm_val_loss=0.02021  time=0.85s
# Epoch 3  loss=0.01924  val_loss=0.01934  sm_loss=0.01926  sm_val_loss=0.01934  time=0.74s
# Epoch 4  loss=0.01828  val_loss=0.01848  sm_loss=0.01833  sm_val_loss=0.01851  time=0.75s
# Epoch 5  loss=0.01771  val_loss=0.01840  sm_loss=0.01779  sm_val_loss=0.01846  time=0.76s
# Epoch 6  loss=0.01738  val_loss=0.01840  sm_loss=0.01749  sm_val_loss=0.01841  time=0.75s
# Epoch 7  loss=0.01721  val_loss=0.01826  sm_loss=0.01734  sm_val_loss=0.01834  time=0.92s
# Epoch 8  loss=0.01705  val_loss=0.01821  sm_loss=0.01719  sm_val_loss=0.01825  time=0.87s
# Epoch 9  loss=0.01699  val_loss=0.01814  sm_loss=0.01713  sm_val_loss=0.01817  time=0.78s
# Epoch 10  loss=0.01699  val_loss=0.01803  sm_loss=0.01714  sm_val_loss=0.01807  time=0.83s
# Epoch 12  loss=0.01688  val_loss=0.01797  sm_loss=0.01703  sm_val_loss=0.01800  time=0.74s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01606  val_loss=0.01761  sm_loss=0.01622  sm_val_loss=0.01764  time=0.78s
# Epoch 18  loss=0.01552  val_loss=0.01757  sm_loss=0.01569  sm_val_loss=0.01760  time=0.80s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.01772342430692751
# Fold 4
# Epoch 1  loss=0.20274  val_loss=0.02248  sm_loss=0.20270  sm_val_loss=0.02247  time=0.74s
# Epoch 2  loss=0.02104  val_loss=0.02095  sm_loss=0.02103  sm_val_loss=0.02094  time=0.74s
# Epoch 3  loss=0.01920  val_loss=0.01931  sm_loss=0.01921  sm_val_loss=0.01932  time=0.75s
# Epoch 4  loss=0.01833  val_loss=0.01871  sm_loss=0.01838  sm_val_loss=0.01874  time=0.75s
# Epoch 5  loss=0.01776  val_loss=0.01847  sm_loss=0.01783  sm_val_loss=0.01851  time=0.76s
# Epoch 8  loss=0.01712  val_loss=0.01845  sm_loss=0.01726  sm_val_loss=0.01850  time=0.74s
# Epoch 9  loss=0.01707  val_loss=0.01814  sm_loss=0.01720  sm_val_loss=0.01819  time=0.74s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01702  val_loss=0.01813  sm_loss=0.01716  sm_val_loss=0.01819  time=0.75s
# Epoch 14  loss=0.01613  val_loss=0.01771  sm_loss=0.01629  sm_val_loss=0.01778  time=0.74s
# Epoch 15  loss=0.01561  val_loss=0.01768  sm_loss=0.01578  sm_val_loss=0.01775  time=0.74s
# Epoch 16  loss=0.01522  val_loss=0.01766  sm_loss=0.01539  sm_val_loss=0.01773  time=0.89s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.01772080643641425
# Fold 5
# Epoch 1  loss=0.21184  val_loss=0.02303  sm_loss=0.21180  sm_val_loss=0.02302  time=0.74s
# Epoch 2  loss=0.02123  val_loss=0.02109  sm_loss=0.02122  sm_val_loss=0.02108  time=0.75s
# Epoch 3  loss=0.01942  val_loss=0.01935  sm_loss=0.01944  sm_val_loss=0.01932  time=0.87s
# Epoch 4  loss=0.01847  val_loss=0.01858  sm_loss=0.01852  sm_val_loss=0.01857  time=0.75s
# Epoch 5  loss=0.01781  val_loss=0.01836  sm_loss=0.01790  sm_val_loss=0.01830  time=0.76s
# Epoch 6  loss=0.01750  val_loss=0.01830  sm_loss=0.01761  sm_val_loss=0.01824  time=0.76s
# Epoch 9  loss=0.01702  val_loss=0.01806  sm_loss=0.01716  sm_val_loss=0.01805  time=0.76s
# Epoch 10  loss=0.01709  val_loss=0.01803  sm_loss=0.01724  sm_val_loss=0.01804  time=0.76s
# Epoch 14  loss=0.01698  val_loss=0.01799  sm_loss=0.01713  sm_val_loss=0.01801  time=0.74s
# Epoch 15  loss=0.01708  val_loss=0.01803  sm_loss=0.01723  sm_val_loss=0.01800  time=0.78s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 20  loss=0.01625  val_loss=0.01747  sm_loss=0.01641  sm_val_loss=0.01750  time=0.90s
# Epoch 21  loss=0.01573  val_loss=0.01745  sm_loss=0.01590  sm_val_loss=0.01748  time=0.74s
# Epoch    25: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017392219098965194
# Fold 6
# Epoch 1  loss=0.22757  val_loss=0.02276  sm_loss=0.22741  sm_val_loss=0.02276  time=0.74s
# Epoch 2  loss=0.02145  val_loss=0.02086  sm_loss=0.02143  sm_val_loss=0.02085  time=0.74s
# Epoch 3  loss=0.01945  val_loss=0.01901  sm_loss=0.01947  sm_val_loss=0.01903  time=0.76s
# Epoch 4  loss=0.01837  val_loss=0.01859  sm_loss=0.01842  sm_val_loss=0.01862  time=0.74s
# Epoch 6  loss=0.01746  val_loss=0.01823  sm_loss=0.01756  sm_val_loss=0.01828  time=0.74s
# Epoch 9  loss=0.01710  val_loss=0.01811  sm_loss=0.01723  sm_val_loss=0.01813  time=0.74s
# Epoch 13  loss=0.01692  val_loss=0.01803  sm_loss=0.01706  sm_val_loss=0.01810  time=0.88s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18  loss=0.01619  val_loss=0.01760  sm_loss=0.01635  sm_val_loss=0.01764  time=0.75s
# Epoch 19  loss=0.01564  val_loss=0.01750  sm_loss=0.01581  sm_val_loss=0.01755  time=0.74s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017795600651589142
# Fold 7
# Epoch 1  loss=0.19113  val_loss=0.02243  sm_loss=0.19112  sm_val_loss=0.02243  time=0.75s
# Epoch 2  loss=0.02109  val_loss=0.02057  sm_loss=0.02107  sm_val_loss=0.02056  time=0.75s
# Epoch 3  loss=0.01919  val_loss=0.01884  sm_loss=0.01921  sm_val_loss=0.01885  time=0.74s
# Epoch 4  loss=0.01829  val_loss=0.01855  sm_loss=0.01835  sm_val_loss=0.01859  time=0.75s
# Epoch 5  loss=0.01765  val_loss=0.01846  sm_loss=0.01773  sm_val_loss=0.01853  time=0.75s
# Epoch 6  loss=0.01742  val_loss=0.01823  sm_loss=0.01751  sm_val_loss=0.01831  time=0.90s
# Epoch 7  loss=0.01715  val_loss=0.01814  sm_loss=0.01728  sm_val_loss=0.01821  time=0.75s
# Epoch 9  loss=0.01698  val_loss=0.01810  sm_loss=0.01712  sm_val_loss=0.01818  time=0.76s
# Epoch 10  loss=0.01693  val_loss=0.01812  sm_loss=0.01708  sm_val_loss=0.01817  time=0.77s
# Epoch 12  loss=0.01691  val_loss=0.01808  sm_loss=0.01706  sm_val_loss=0.01815  time=0.87s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17  loss=0.01617  val_loss=0.01776  sm_loss=0.01633  sm_val_loss=0.01780  time=0.74s
# Epoch 18  loss=0.01557  val_loss=0.01770  sm_loss=0.01574  sm_val_loss=0.01775  time=0.78s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017924623092273738
# Seed 4
# Fold 1 log loss: 0.01751756195667797
# Fold 2 log loss: 0.017890409054204637
# Fold 3 log loss: 0.01772342430692751
# Fold 4 log loss: 0.01772080643641425
# Fold 5 log loss: 0.017392219098965194
# Fold 6 log loss: 0.017795600651589142
# Fold 7 log loss: 0.017924623092273738
# Std of log loss: 0.000178984422946192
# Total log loss: 0.01770871806531064
# Fold 1
# Epoch 1  loss=0.20472  val_loss=0.02239  sm_loss=0.20468  sm_val_loss=0.02239  time=0.78s
# Epoch 2  loss=0.02112  val_loss=0.02014  sm_loss=0.02112  sm_val_loss=0.02013  time=0.92s
# Epoch 3  loss=0.01930  val_loss=0.01854  sm_loss=0.01932  sm_val_loss=0.01857  time=0.74s
# Epoch 4  loss=0.01837  val_loss=0.01827  sm_loss=0.01842  sm_val_loss=0.01832  time=0.75s
# Epoch 5  loss=0.01783  val_loss=0.01820  sm_loss=0.01790  sm_val_loss=0.01825  time=0.76s
# Epoch 6  loss=0.01752  val_loss=0.01783  sm_loss=0.01762  sm_val_loss=0.01788  time=0.76s
# Epoch 7  loss=0.01766  val_loss=0.01781  sm_loss=0.01775  sm_val_loss=0.01788  time=0.75s
# Epoch 8  loss=0.01728  val_loss=0.01784  sm_loss=0.01741  sm_val_loss=0.01787  time=0.79s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01613  val_loss=0.01731  sm_loss=0.01629  sm_val_loss=0.01736  time=0.73s
# Epoch 14  loss=0.01554  val_loss=0.01731  sm_loss=0.01572  sm_val_loss=0.01734  time=0.75s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01750983618314807
# Fold 2
# Epoch 1  loss=0.22552  val_loss=0.02337  sm_loss=0.22546  sm_val_loss=0.02337  time=0.75s
# Epoch 2  loss=0.02132  val_loss=0.02088  sm_loss=0.02131  sm_val_loss=0.02087  time=0.87s
# Epoch 3  loss=0.01952  val_loss=0.01919  sm_loss=0.01952  sm_val_loss=0.01924  time=0.74s
# Epoch 5  loss=0.01786  val_loss=0.01850  sm_loss=0.01794  sm_val_loss=0.01856  time=0.74s
# Epoch 8  loss=0.01723  val_loss=0.01842  sm_loss=0.01735  sm_val_loss=0.01845  time=0.75s
# Epoch 10  loss=0.01711  val_loss=0.01834  sm_loss=0.01725  sm_val_loss=0.01841  time=0.74s
# Epoch 11  loss=0.01699  val_loss=0.01832  sm_loss=0.01714  sm_val_loss=0.01837  time=0.74s
# Epoch 14  loss=0.01703  val_loss=0.01822  sm_loss=0.01718  sm_val_loss=0.01828  time=0.90s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19  loss=0.01627  val_loss=0.01785  sm_loss=0.01643  sm_val_loss=0.01790  time=0.76s
# Epoch 20  loss=0.01573  val_loss=0.01783  sm_loss=0.01590  sm_val_loss=0.01789  time=0.90s
# Epoch    24: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.017919814816916943
# Fold 3
# Epoch 1  loss=0.21722  val_loss=0.02301  sm_loss=0.21718  sm_val_loss=0.02300  time=0.74s
# Epoch 2  loss=0.02144  val_loss=0.02058  sm_loss=0.02143  sm_val_loss=0.02057  time=0.74s
# Epoch 3  loss=0.01944  val_loss=0.01885  sm_loss=0.01946  sm_val_loss=0.01887  time=0.75s
# Epoch 4  loss=0.01846  val_loss=0.01858  sm_loss=0.01850  sm_val_loss=0.01861  time=0.74s
# Epoch 5  loss=0.01778  val_loss=0.01836  sm_loss=0.01787  sm_val_loss=0.01840  time=0.79s
# Epoch 8  loss=0.01715  val_loss=0.01799  sm_loss=0.01728  sm_val_loss=0.01806  time=0.78s
# Epoch 12  loss=0.01690  val_loss=0.01799  sm_loss=0.01705  sm_val_loss=0.01803  time=0.73s
# Epoch 13  loss=0.01693  val_loss=0.01798  sm_loss=0.01708  sm_val_loss=0.01802  time=0.74s
# Epoch 16  loss=0.01696  val_loss=0.01792  sm_loss=0.01710  sm_val_loss=0.01794  time=0.75s
# Epoch    20: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 21  loss=0.01609  val_loss=0.01757  sm_loss=0.01626  sm_val_loss=0.01761  time=0.89s
# Epoch 22  loss=0.01560  val_loss=0.01753  sm_loss=0.01578  sm_val_loss=0.01757  time=0.74s
# Epoch 23  loss=0.01530  val_loss=0.01751  sm_loss=0.01548  sm_val_loss=0.01755  time=0.73s
# Epoch    27: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.017647898272799584
# Fold 4
# Epoch 1  loss=0.21151  val_loss=0.02268  sm_loss=0.21144  sm_val_loss=0.02267  time=0.75s
# Epoch 2  loss=0.02125  val_loss=0.02095  sm_loss=0.02123  sm_val_loss=0.02094  time=0.75s
# Epoch 3  loss=0.01932  val_loss=0.01917  sm_loss=0.01933  sm_val_loss=0.01916  time=0.75s
# Epoch 4  loss=0.01841  val_loss=0.01902  sm_loss=0.01846  sm_val_loss=0.01904  time=0.80s
# Epoch 5  loss=0.01779  val_loss=0.01858  sm_loss=0.01787  sm_val_loss=0.01861  time=0.97s
# Epoch 6  loss=0.01741  val_loss=0.01834  sm_loss=0.01751  sm_val_loss=0.01840  time=0.81s
# Epoch 7  loss=0.01724  val_loss=0.01813  sm_loss=0.01735  sm_val_loss=0.01819  time=0.91s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12  loss=0.01611  val_loss=0.01776  sm_loss=0.01627  sm_val_loss=0.01782  time=0.84s
# Epoch 13  loss=0.01554  val_loss=0.01770  sm_loss=0.01571  sm_val_loss=0.01775  time=0.76s
# Epoch 14  loss=0.01521  val_loss=0.01770  sm_loss=0.01539  sm_val_loss=0.01775  time=0.76s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.01770172392434668
# Fold 5
# Epoch 1  loss=0.19795  val_loss=0.02260  sm_loss=0.19793  sm_val_loss=0.02259  time=0.74s
# Epoch 2  loss=0.02101  val_loss=0.02049  sm_loss=0.02101  sm_val_loss=0.02048  time=0.74s
# Epoch 3  loss=0.01926  val_loss=0.01913  sm_loss=0.01929  sm_val_loss=0.01912  time=0.81s
# Epoch 4  loss=0.01835  val_loss=0.01856  sm_loss=0.01840  sm_val_loss=0.01857  time=0.75s
# Epoch 5  loss=0.01796  val_loss=0.01833  sm_loss=0.01804  sm_val_loss=0.01832  time=0.75s
# Epoch 6  loss=0.01750  val_loss=0.01817  sm_loss=0.01761  sm_val_loss=0.01816  time=0.75s
# Epoch 7  loss=0.01725  val_loss=0.01806  sm_loss=0.01738  sm_val_loss=0.01805  time=0.76s
# Epoch 8  loss=0.01709  val_loss=0.01788  sm_loss=0.01722  sm_val_loss=0.01789  time=0.74s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13  loss=0.01614  val_loss=0.01761  sm_loss=0.01630  sm_val_loss=0.01762  time=0.75s
# Epoch 14  loss=0.01555  val_loss=0.01752  sm_loss=0.01572  sm_val_loss=0.01754  time=0.75s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017441756192033957
# Fold 6
# Epoch 1  loss=0.19538  val_loss=0.02209  sm_loss=0.19527  sm_val_loss=0.02208  time=0.74s
# Epoch 2  loss=0.02092  val_loss=0.02032  sm_loss=0.02091  sm_val_loss=0.02031  time=0.87s
# Epoch 3  loss=0.01912  val_loss=0.01928  sm_loss=0.01914  sm_val_loss=0.01927  time=0.80s
# Epoch 4  loss=0.01817  val_loss=0.01878  sm_loss=0.01822  sm_val_loss=0.01881  time=0.86s
# Epoch 5  loss=0.01772  val_loss=0.01853  sm_loss=0.01779  sm_val_loss=0.01857  time=0.75s
# Epoch 6  loss=0.01737  val_loss=0.01839  sm_loss=0.01748  sm_val_loss=0.01843  time=0.75s
# Epoch 8  loss=0.01705  val_loss=0.01827  sm_loss=0.01719  sm_val_loss=0.01829  time=0.74s
# Epoch 9  loss=0.01701  val_loss=0.01814  sm_loss=0.01715  sm_val_loss=0.01816  time=0.76s
# Epoch 11  loss=0.01690  val_loss=0.01800  sm_loss=0.01705  sm_val_loss=0.01805  time=0.75s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16  loss=0.01618  val_loss=0.01762  sm_loss=0.01634  sm_val_loss=0.01766  time=0.99s
# Epoch 17  loss=0.01559  val_loss=0.01761  sm_loss=0.01576  sm_val_loss=0.01765  time=0.92s
# Epoch 18  loss=0.01524  val_loss=0.01756  sm_loss=0.01542  sm_val_loss=0.01761  time=0.76s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017872285906731417
# Fold 7
# Epoch 1  loss=0.19990  val_loss=0.02287  sm_loss=0.19977  sm_val_loss=0.02286  time=0.76s
# Epoch 2  loss=0.02131  val_loss=0.02096  sm_loss=0.02128  sm_val_loss=0.02095  time=0.75s
# Epoch 3  loss=0.01933  val_loss=0.01899  sm_loss=0.01934  sm_val_loss=0.01899  time=0.74s
# Epoch 4  loss=0.01854  val_loss=0.01882  sm_loss=0.01858  sm_val_loss=0.01886  time=0.75s
# Epoch 5  loss=0.01775  val_loss=0.01860  sm_loss=0.01782  sm_val_loss=0.01865  time=0.76s
# Epoch 6  loss=0.01754  val_loss=0.01843  sm_loss=0.01764  sm_val_loss=0.01848  time=0.75s
# Epoch 8  loss=0.01712  val_loss=0.01823  sm_loss=0.01725  sm_val_loss=0.01830  time=0.74s
# Epoch 9  loss=0.01712  val_loss=0.01795  sm_loss=0.01726  sm_val_loss=0.01802  time=0.91s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14  loss=0.01618  val_loss=0.01767  sm_loss=0.01633  sm_val_loss=0.01773  time=0.73s
# Epoch 15  loss=0.01559  val_loss=0.01766  sm_loss=0.01575  sm_val_loss=0.01772  time=0.75s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017882632696607736
# Seed 6
# Fold 1 log loss: 0.01750983618314807
# Fold 2 log loss: 0.017919814816916943
# Fold 3 log loss: 0.017647898272799584
# Fold 4 log loss: 0.01770172392434668
# Fold 5 log loss: 0.017441756192033957
# Fold 6 log loss: 0.017872285906731417
# Fold 7 log loss: 0.017882632696607736
# Std of log loss: 0.0001757032314565705
# Total log loss: 0.017710564287127233
# Total log loss in targets: 0.01755184021340703

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.01617652595128326

# %%
train_checkscore.to_csv("dae_oof.csv")

# %%
sub.loc[cons_test_index, target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)

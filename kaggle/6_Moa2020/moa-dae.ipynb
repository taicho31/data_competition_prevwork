# %% [markdown]
# - only consider dae features
# - increase to 3 seeds
# - incorporate chris validation scheme
# - introduce dropout in the first layer as well *

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd 
from tqdm import tqdm_notebook as tqdm
from sklearn import preprocessing
from sklearn.metrics import log_loss,roc_auc_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_selection import VarianceThreshold

sys.path.append('../input/multilabelstraifier/')
from ml_stratifiers import MultilabelStratifiedKFold
warnings.filterwarnings('ignore')

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tensorflow as tf
from torch.nn.modules.loss import _WeightedLoss

from sklearn.pipeline import make_pipeline,make_union
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.base import BaseEstimator,TransformerMixin

# %% [markdown]
# # functions

# %%
def train_short_form_loader(feature_file,target_file,extra_target_file=None):
    '''takes the original target and features and creates a train dataset 
    in col long format'''
    train_features = pd.read_csv(feature_file)
    train_targets = pd.read_csv(target_file)

    if extra_target_file is not None:
        extra_targets = pd.read_csv(extra_target_file)
        train_targets = pd.merge(train_targets,extra_targets,on ='sig_id')
        del extra_targets

    targets = train_targets.columns[1:]

    train_melt=train_targets.merge(train_features,how="left",on="sig_id")

    del train_features,train_targets
    
    train_melt.set_index("sig_id",inplace=True)

    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt , targets.to_list()

def test_short_form_loader(feature_file):
    '''takes the original target and features and creates a train dataset 
    in col long format'''

    train_features = pd.read_csv(feature_file)

    train_melt =  train_features.copy()
    del train_features

    train_melt.set_index("sig_id",inplace=True)
    train_melt["cp_type"]= train_melt["cp_type"].astype('category')
    train_melt["cp_dose"]= train_melt["cp_dose"].astype('category')

    return train_melt

# %%
# feature selection transformer
class CatIntMapper( BaseEstimator, TransformerMixin ):
    #Class constructor method that takes in a list of values as its argument
    def __init__(self ,col,dicti):
        self.col = col
        self.dicti = dicti
        
    def fit(self, X, y = None):
        
        return self
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
    def transform( self, X):
        assert  X[self.col].isin(self.dicti.keys()).all() 
        
        return pd.concat([X.drop(self.col,axis=1),X[self.col].map(self.dicti).astype(int).rename(self.col)],axis=1) 
    
class NamedOutTWrapper(BaseEstimator, TransformerMixin):
    
    def __init__(self,transformer,columns,inplace=False,prefix='_' ):
        self.transformer = transformer
        self.cols = columns
        self.inplace =  inplace
        self.prefix = prefix
        self.transformer_name = self._get_transformer_name()
        
    def fit(self, X, y = None): 
        self.transformer =   self.transformer.fit(X[self.cols] , y )
        return self
    
    #Return self nothing else to do here
    def fit_transform( self, X, y = None  ): 
        transformed_columns = self.transformer.fit_transform(X[self.cols] , y )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
            return   pd.concat([X,out],axis=1)
        
    def transform( self, X):
        transformed_columns = self.transformer.transform(X[self.cols]  )
        out=pd.DataFrame(index=X.index)
        
        if self.inplace:
            out = X[self.cols]
            out[self.cols] = transformed_columns
            return pd.concat([X.drop(self.cols,axis=1),out],axis=1)
        else:
            for i,values in enumerate(transformed_columns.transpose()):
                out[ self.transformer_name + self.prefix + str(i)] = values
        return   pd.concat([X,out],axis=1)
    
    def _get_transformer_name(self):
        return str(self.transformer.__class__).split('.')[-1][0:-2]

# %%
# cv folds
def multifold_indexer(train,target_columns,n_splits=10,random_state=12347,**kwargs):
    folds = train.copy()

    mskf = MultilabelStratifiedKFold(n_splits=n_splits,random_state=random_state,**kwargs)
    folds[ 'kfold']=0
    for f, (t_idx, v_idx) in enumerate(mskf.split(X=train, y=train[target_columns])):
        folds.iloc[v_idx,-1] = int(f)

    folds['kfold'] = folds['kfold'].astype(int)
    return folds

# %%
# dataset class
class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)            
        }
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }
        return dct
    
class ColumnDropper( BaseEstimator, TransformerMixin ):
    #Class Constructor 
    def __init__( self, cols ):
        self.cols=cols
    #Return self nothing else to do here    
    def fit( self, X, y = None ):
        return self 
    
    #Method that describes what we need this transformer to do
    def transform( self, X, y = None ):
        return X.drop(self.cols,axis=1)

# %%
# dae model
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

class DAE_Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size=1100,hidden_size2=1300):
        super(DAE_Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        #self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size))
        
        self.batch_norm2 = nn.BatchNorm1d(hidden_size)
        #self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size, hidden_size2))
        
        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        #self.dropout3 = nn.Dropout(drop_rate2)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, hidden_size))
        
        #self.batch_norm4 = nn.BatchNorm1d(hidden_size)
        #self.dropout4 = nn.Dropout(drop_rate3)
        self.dense4 = nn.utils.weight_norm(nn.Linear(hidden_size, num_features))
        
    def forward(self, x,mode='DAE'):
        #x = self.batch_norm1(x)
        #x1 = self.dropout1(x1)
        x1 = F.relu(self.dense1(x))
            
        x2 = self.batch_norm2(x1)
        #x = self.dropout2(x)
        x2 = F.relu(self.dense2(x2))
        
        x3 = self.batch_norm3(x2)
      
        x3 = F.relu(self.dense3(x3))
        
        out = self.dense4(x3)
        
        if mode == 'DAE':
            return out
        else:
            return x1,x2,x3

# %%
def infer_features_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs,mode='get_features')
        
        preds.append(torch.cat(outputs,axis=1).detach().cpu().numpy())
    preds = np.concatenate(preds)
    
    return preds

def run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=False,**kwargs):
    seed_everything(seed)
    if not  inference_only:
        train_dataset = MoADataset(X_train, y_train)
        valid_dataset = MoADataset(X_valid, y_valid)
        trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)

    testdataset = TestDataset(X_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = DAE_Model(
        num_features= X_train.shape[1] ,
        num_targets=  X_train.shape[1],
       # hidden_size=hidden_size,
        **kwargs
    )

    model.to(DEVICE)
    
    if not  inference_only:
        oof = inference_infer_features_fn(model, validloader, DEVICE)    
    else:
        oof= 0
    
    predictions = infer_features_fn(model, testloader, DEVICE)
    predictions = predictions
    
    return oof, predictions

# %% [markdown]
# # denosing auto encoder

# %%
DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 1000
BATCH_SIZE = 640
LEARNING_RATE = 4e-3
WEIGHT_DECAY = 1e-8
NFOLDS = 10
EARLY_STOPPING_STEPS = 10
EARLY_STOP = False
hidden_size=1100
hidden_size2=1300
PATIENCE=10
THRESHOLD = 5e-3

# %%
SEED = [0]
train,target_cols = train_short_form_loader('../input/lish-moa/train_features.csv','../input/lish-moa/train_targets_scored.csv')
test = test_short_form_loader("../input/lish-moa/test_features.csv")

train = pd.concat([train,test])
train[target_cols]= train[target_cols].fillna(0)
test = train.copy()

GENES = [col for col in train.columns if col.startswith('g-')]
CELLS = [col for col in train.columns if col.startswith('c-')]

map_controls = CatIntMapper('cp_type',{'ctl_vehicle': 0, 'trt_cp': 1})    
map_dose = CatIntMapper('cp_dose',{'D1': 1, 'D2': 0})    
map_time = CatIntMapper('cp_time',{24: 0, 48: 1, 72: 2})  

Rankg_g_tansform = NamedOutTWrapper(preprocessing.QuantileTransformer(n_quantiles=1000,random_state=0, output_distribution="normal"),columns= GENES+CELLS,inplace=True)
PCA_g_tansform =  NamedOutTWrapper(PCA(20),columns= GENES,prefix ='_g' )
PCA_c_tansform =  NamedOutTWrapper(PCA(20),columns= CELLS,prefix ='_c' )

CatDropper =ColumnDropper(cols=['cp_type','cp_time','cp_dose'])
transformers_list=[map_controls,map_dose,map_time,Rankg_g_tansform,CatDropper]
exp_name = 'test_DAE_0.2_all_together'

oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

for seed in SEED:
    
    train = multifold_indexer(train,target_cols,n_splits=NFOLDS)
    
    for fold in range(NFOLDS):
            
        train_df = train[train['kfold'] != fold]
        valid_df = train[train['kfold'] == fold]
            
        feature_cols = [col for col in train_df.columns if not (col in target_cols+['kfold'])]
                
        pipeline_val = make_pipeline(*transformers_list)
        
        X_train, y_train  = train_df[feature_cols], train_df[target_cols]
        X_valid, y_valid =  valid_df[feature_cols], valid_df[target_cols].values
        
        X_train = pipeline_val.fit_transform(X_train)
        X_train = X_train.values
        X_valid = pipeline_val.transform(X_valid)
        
        valid_index = X_valid.index
        X_valid = X_valid.values
        
        y_train = y_train.values
        
        X_test = test[feature_cols]
        X_test = pipeline_val.transform(X_test).values
        
        pred_ = run_inference(X_train,y_train,X_valid,y_valid,X_test,fold, seed,inference_only=True)    
        break
        
transformed_features = pd.DataFrame(pred_[1],index=test.index)

# %%
print(transformed_features.shape)
transformed_features.columns = [str(i) for i in range(len(transformed_features.columns))]
transformed_features.reset_index().to_feather('./features_0.2_altogether.fth')
transformed_features = transformed_features.reset_index(drop=False)
# Out:
# (27796, 3500)

# %% [markdown]
# # prediction

# %%
DATA_DIR = '/kaggle/input/lish-moa/'
train = pd.read_csv(DATA_DIR + 'train_features.csv')
targets = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
test = pd.read_csv(DATA_DIR + 'test_features.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')
drug = pd.read_csv(DATA_DIR + 'train_drug.csv')

noncons_train_index = train[train.cp_type=="ctl_vehicle"].index
cons_train_index = train[train.cp_type!="ctl_vehicle"].index
noncons_test_index = test[test.cp_type=="ctl_vehicle"].index
cons_test_index = test[test.cp_type!="ctl_vehicle"].index

train = train[train.index.isin(cons_train_index)].copy().reset_index(drop=True)
test = test[test.index.isin(cons_test_index)].copy().reset_index(drop=True)
targets = targets[targets.index.isin(cons_train_index)].copy().reset_index(drop=True)

# %%
target_feats = [ i for i in targets.columns if i != "sig_id"]
g_feats = [i for i in train.columns if "g-" in i]
c_feats = [i for i in train.columns if "c-" in i]

# %%
NB_SPLITS = 7
seed = 34

folds = []
    
# LOAD FILES
train_score = targets.merge(drug, on='sig_id', how='left') 

# LOCATE DRUGS
vc = train_score.drug_id.value_counts()
vc1 = vc.loc[(vc==6)|(vc==12)|(vc==18)].index.sort_values()
vc2 = vc.loc[(vc!=6)&(vc!=12)&(vc!=18)].index.sort_values()
    
# STRATIFY DRUGS 18X OR LESS
dct1 = {}; dct2 = {}
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.groupby('drug_id')[target_feats].mean().loc[vc1]
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.index[idxV].values}
    dct1.update(dd)
    
# STRATIFY DRUGS MORE THAN 18X
skf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, shuffle = True, random_state = seed)
tmp = train_score.loc[train_score.drug_id.isin(vc2)].reset_index(drop = True)
for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[target_feats])):
    dd = {k:fold for k in tmp.sig_id[idxV].values}
    dct2.update(dd)

# ASSIGN FOLDS
train_score['fold'] = train_score.drug_id.map(dct1)
train_score.loc[train_score.fold.isna(),'fold'] = train_score.loc[train_score.fold.isna(),'sig_id'].map(dct2)
train_score.fold = train_score.fold.astype('int8')
folds.append(train_score.fold.values)
    
np.array(folds)
# Out:
# array([[6, 4, 3, ..., 3, 3, 2]], dtype=int8)

# %%
train = train.drop(g_feats + c_feats + ["cp_type"], axis=1)
test = test.drop(g_feats + c_feats + ["cp_type"], axis=1)

# %%
train = train.merge(transformed_features, on="sig_id", how="left")
test = test.merge(transformed_features, on="sig_id", how="left")

# %%
def fe(df):
    tmp = df.copy()
    tmp = pd.get_dummies(tmp, columns=['cp_time','cp_dose'])
    tmp.drop(["sig_id"], axis=1, inplace=True)
    return tmp
train = fe(train)
test = fe(test)

# %%
train["fold"] = np.array(folds).reshape(-1,1)

# %%
fn_train = train.copy().to_numpy()
fn_test = test.copy().to_numpy()

fn_targets = targets.drop("sig_id", axis=1).copy().to_numpy()

# %%
class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets, n_classes, smoothing=0.0):
        assert 0 <= smoothing <= 1
        with torch.no_grad():
            targets = targets * (1 - smoothing) + torch.ones_like(targets).to(device) * smoothing / n_classes
        return targets

    def forward(self, inputs, targets):
        targets = SmoothCrossEntropyLoss()._smooth(targets, inputs.shape[1], self.smoothing)

        if self.weight is not None:
            inputs = inputs * self.weight.unsqueeze(0)

        loss = F.binary_cross_entropy_with_logits(inputs, targets)

        return loss

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets, hidden_size1=388,hidden_size2=512,drop_rate1=0.1,drop_rate2=0.3,drop_rate3=0.3):
        super(Model, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dropout1 = nn.Dropout(drop_rate1)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_features, hidden_size1))

        self.batch_norm2 = nn.BatchNorm1d(hidden_size1)
        self.dropout2 = nn.Dropout(drop_rate2)
        self.dense2 = nn.utils.weight_norm(nn.Linear(hidden_size1, hidden_size2))

        self.batch_norm3 = nn.BatchNorm1d(hidden_size2)
        self.dropout3 = nn.Dropout(drop_rate3)
        self.dense3 = nn.utils.weight_norm(nn.Linear(hidden_size2, num_targets))
        
    def forward(self, x):
        
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x

# %%
#params for one cycle schedule
device = ('cuda' if torch.cuda.is_available() else 'cpu')
train_epochs = 30
batch_size = 256
n_folds = 7

smoothing = 0.001
p_min = smoothing
p_max = 1 - p_min

def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_feats):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

def modelling_dae(tr, target, te, sample_seed, init_num, last_num):
    seed_everything(seed=sample_seed) 
    X_train = tr.copy()
    y_train = target.copy()
    X_test = te.copy()
    test_len = X_test.shape[0]
    
    mskf=MultilabelStratifiedKFold(n_splits = n_folds, shuffle=True, random_state=224)
    metric = lambda inputs, targets : F.binary_cross_entropy((torch.clamp(torch.sigmoid(inputs), p_min, p_max)), targets)

    models = []
    
    X_test2 = torch.tensor(X_test, dtype=torch.float32)
    test = torch.utils.data.TensorDataset(X_test2) 
    test_loader = torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=False)
    
    oof = np.zeros([len(X_train),y_train.shape[1]])
    oof_targets = np.zeros([len(X_train),y_train.shape[1]])
    pred_value = np.zeros([test_len, y_train.shape[1]])
    scores = []
    for fold in range(n_folds):
        valid_index = X_train[:,-1] == fold
        train_index = X_train[:,-1] != fold
        print("Fold "+str(fold+1))
        X_train2 = torch.tensor(X_train[train_index,:], dtype=torch.float32)
        X_valid2 = torch.tensor(X_train[valid_index,:], dtype=torch.float32)
        X_train2 = X_train2[:,:-1]
        X_valid2 = X_valid2[:,:-1]

        y_train2 = torch.tensor(y_train[train_index], dtype=torch.float32)
        y_valid2 = torch.tensor(y_train[valid_index], dtype=torch.float32)
        
        train = torch.utils.data.TensorDataset(X_train2, y_train2)
        valid = torch.utils.data.TensorDataset(X_valid2, y_valid2)
        
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True) 
        valid_loader = torch.utils.data.DataLoader(valid, batch_size=batch_size, shuffle=False)
            
        clf = Model(init_num, last_num)
        loss_fn = SmoothCrossEntropyLoss(smoothing=smoothing)

        optimizer = optim.Adam(clf.parameters(), lr = 5e-3, weight_decay=1e-5) 
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.1, eps=1e-4, verbose=True)                   
        
        clf.to(device)
        
        best_val_loss = np.inf
        stop_counts = 0
        for epoch in range(train_epochs):
            start_time = time.time()
            clf.train()
            avg_loss = 0.
            sm_avg_loss = 0.
            for x_batch, y_batch in tqdm(train_loader, disable=True):
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch) 
                loss = loss_fn(y_pred, y_batch)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                avg_loss += loss.item() / len(train_loader)  
                sm_avg_loss += metric(y_pred, y_batch) / len(train_loader) 
                
            clf.eval()
            avg_val_loss = 0.
            sm_avg_val_loss = 0.
            for i, (x_batch, y_batch) in enumerate(valid_loader): 
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = clf(x_batch).detach()
                avg_val_loss += loss_fn(y_pred, y_batch).item() / len(valid_loader)
                sm_avg_val_loss += metric(y_pred, y_batch) / len(valid_loader)
        
            elapsed_time = time.time() - start_time 
            scheduler.step(sm_avg_val_loss)
                    
            if sm_avg_val_loss < best_val_loss:
                best_val_loss = sm_avg_val_loss
                print('Epoch {}   loss={:.5f}   val_loss={:.5f}   sm_loss={:.5f}   sm_val_loss={:.5f}   time={:.2f}s'.format(
                    epoch + 1, avg_loss, avg_val_loss, sm_avg_loss, sm_avg_val_loss, elapsed_time))
                torch.save(clf.state_dict(), 'best-model-parameters.pt')
            else:
                stop_counts += 1
        
        pred_model = Model(init_num, last_num)
        pred_model.load_state_dict(torch.load('best-model-parameters.pt'))         
        pred_model.eval()
        
        # validation check ----------------
        oof_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        target_epoch = np.zeros([X_valid2.size(0), y_train.shape[1]])
        for i, (x_batch, y_batch) in enumerate(valid_loader): 
                y_pred = pred_model(x_batch).detach()
                oof_epoch[i * batch_size:(i+1) * batch_size,:] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
                target_epoch[i * batch_size:(i+1) * batch_size,:] = y_batch.cpu().numpy()
        print("Fold {} log loss: {}".format(fold+1, mean_log_loss(target_epoch, oof_epoch)))
        scores.append(mean_log_loss(target_epoch, oof_epoch))
        oof[valid_index,:] = oof_epoch
        oof_targets[valid_index,:] = target_epoch
        #-----------------------------------
        
        # test predcition --------------
        test_preds = np.zeros([test_len, y_train.shape[1]])
        for i, (x_batch,) in enumerate(test_loader): 
            y_pred = pred_model(x_batch).detach()
            test_preds[i * batch_size:(i+1) * batch_size, :] = torch.clamp(torch.sigmoid(y_pred.cpu()), p_min, p_max)
        pred_value += test_preds / n_folds
        # ------------------------------
        
    print("Seed {}".format(seed_))
    for i, ele in enumerate(scores):
        print("Fold {} log loss: {}".format(i+1, scores[i]))
    print("Std of log loss: {}".format(np.std(scores)))
    print("Total log loss: {}".format(mean_log_loss(oof_targets, oof)))
    
    return oof, oof_targets, pred_value

# %%
seeds = [0,1,2]
target_oof = np.zeros([len(fn_train),fn_targets.shape[1]])
target_pred = np.zeros([len(fn_test),fn_targets.shape[1]])

for seed_ in seeds:
    oof, oof_targets, pytorch_pred = modelling_dae(fn_train, fn_targets, fn_test, seed_, fn_train.shape[1]-1, fn_targets.shape[1])
    target_oof += oof / len(seeds)
    target_pred += pytorch_pred / len(seeds)

print("Total log loss in targets: {}".format(mean_log_loss(oof_targets, target_oof)))
# Out:
# Fold 1
# Epoch 1   loss=0.22102   val_loss=0.02514   sm_loss=0.22099   sm_val_loss=0.02514   time=0.79s
# Epoch 2   loss=0.02283   val_loss=0.02098   sm_loss=0.02282   sm_val_loss=0.02098   time=0.69s
# Epoch 3   loss=0.02015   val_loss=0.01903   sm_loss=0.02015   sm_val_loss=0.01905   time=0.65s
# Epoch 4   loss=0.01884   val_loss=0.01833   sm_loss=0.01887   sm_val_loss=0.01835   time=0.62s
# Epoch 5   loss=0.01801   val_loss=0.01801   sm_loss=0.01808   sm_val_loss=0.01805   time=0.60s
# Epoch 7   loss=0.01723   val_loss=0.01785   sm_loss=0.01734   sm_val_loss=0.01790   time=0.59s
# Epoch 8   loss=0.01690   val_loss=0.01772   sm_loss=0.01703   sm_val_loss=0.01778   time=0.58s
# Epoch 9   loss=0.01662   val_loss=0.01770   sm_loss=0.01676   sm_val_loss=0.01775   time=0.61s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01529   val_loss=0.01734   sm_loss=0.01548   sm_val_loss=0.01736   time=0.59s
# Epoch 15   loss=0.01464   val_loss=0.01731   sm_loss=0.01484   sm_val_loss=0.01734   time=0.58s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.01750090520611265
# Fold 2
# Epoch 1   loss=0.22146   val_loss=0.02558   sm_loss=0.22145   sm_val_loss=0.02558   time=0.60s
# Epoch 2   loss=0.02273   val_loss=0.02160   sm_loss=0.02271   sm_val_loss=0.02159   time=0.61s
# Epoch 3   loss=0.02024   val_loss=0.01958   sm_loss=0.02023   sm_val_loss=0.01960   time=0.94s
# Epoch 4   loss=0.01889   val_loss=0.01881   sm_loss=0.01892   sm_val_loss=0.01885   time=0.98s
# Epoch 5   loss=0.01796   val_loss=0.01843   sm_loss=0.01802   sm_val_loss=0.01848   time=0.58s
# Epoch 7   loss=0.01715   val_loss=0.01842   sm_loss=0.01725   sm_val_loss=0.01848   time=0.61s
# Epoch     9: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 10   loss=0.01574   val_loss=0.01783   sm_loss=0.01591   sm_val_loss=0.01791   time=0.60s
# Epoch 11   loss=0.01515   val_loss=0.01785   sm_loss=0.01532   sm_val_loss=0.01791   time=0.59s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01795262789927255
# Fold 3
# Epoch 1   loss=0.21849   val_loss=0.02564   sm_loss=0.21848   sm_val_loss=0.02563   time=0.59s
# Epoch 2   loss=0.02272   val_loss=0.02070   sm_loss=0.02272   sm_val_loss=0.02069   time=0.59s
# Epoch 3   loss=0.02026   val_loss=0.01939   sm_loss=0.02026   sm_val_loss=0.01939   time=0.59s
# Epoch 4   loss=0.01898   val_loss=0.01907   sm_loss=0.01900   sm_val_loss=0.01907   time=0.58s
# Epoch 5   loss=0.01812   val_loss=0.01822   sm_loss=0.01817   sm_val_loss=0.01828   time=0.76s
# Epoch 7   loss=0.01712   val_loss=0.01815   sm_loss=0.01722   sm_val_loss=0.01819   time=0.58s
# Epoch 9   loss=0.01670   val_loss=0.01800   sm_loss=0.01683   sm_val_loss=0.01805   time=0.59s
# Epoch    13: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 14   loss=0.01528   val_loss=0.01771   sm_loss=0.01547   sm_val_loss=0.01775   time=0.58s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.017826648156047054
# Fold 4
# Epoch 1   loss=0.22010   val_loss=0.02523   sm_loss=0.22007   sm_val_loss=0.02522   time=0.58s
# Epoch 2   loss=0.02279   val_loss=0.02108   sm_loss=0.02278   sm_val_loss=0.02107   time=0.58s
# Epoch 3   loss=0.02012   val_loss=0.01980   sm_loss=0.02012   sm_val_loss=0.01979   time=0.60s
# Epoch 4   loss=0.01889   val_loss=0.01895   sm_loss=0.01893   sm_val_loss=0.01896   time=0.60s
# Epoch 5   loss=0.01805   val_loss=0.01838   sm_loss=0.01811   sm_val_loss=0.01842   time=0.58s
# Epoch 6   loss=0.01744   val_loss=0.01831   sm_loss=0.01753   sm_val_loss=0.01835   time=0.60s
# Epoch 8   loss=0.01690   val_loss=0.01828   sm_loss=0.01702   sm_val_loss=0.01834   time=0.80s
# Epoch 9   loss=0.01663   val_loss=0.01827   sm_loss=0.01676   sm_val_loss=0.01830   time=0.63s
# Epoch 11   loss=0.01644   val_loss=0.01812   sm_loss=0.01660   sm_val_loss=0.01819   time=0.58s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 16   loss=0.01518   val_loss=0.01778   sm_loss=0.01537   sm_val_loss=0.01784   time=0.58s
# Epoch 17   loss=0.01456   val_loss=0.01772   sm_loss=0.01477   sm_val_loss=0.01779   time=0.59s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017756614462591264
# Fold 5
# Epoch 1   loss=0.21988   val_loss=0.02592   sm_loss=0.21986   sm_val_loss=0.02591   time=0.60s
# Epoch 2   loss=0.02276   val_loss=0.02159   sm_loss=0.02276   sm_val_loss=0.02158   time=0.60s
# Epoch 3   loss=0.02021   val_loss=0.01957   sm_loss=0.02022   sm_val_loss=0.01955   time=0.58s
# Epoch 4   loss=0.01896   val_loss=0.01879   sm_loss=0.01899   sm_val_loss=0.01871   time=0.61s
# Epoch 5   loss=0.01807   val_loss=0.01839   sm_loss=0.01813   sm_val_loss=0.01827   time=0.59s
# Epoch 6   loss=0.01746   val_loss=0.01828   sm_loss=0.01755   sm_val_loss=0.01824   time=0.60s
# Epoch 7   loss=0.01712   val_loss=0.01804   sm_loss=0.01723   sm_val_loss=0.01807   time=0.59s
# Epoch 10   loss=0.01658   val_loss=0.01800   sm_loss=0.01673   sm_val_loss=0.01798   time=1.06s
# Epoch 13   loss=0.01632   val_loss=0.01796   sm_loss=0.01649   sm_val_loss=0.01795   time=0.59s
# Epoch 17   loss=0.01633   val_loss=0.01778   sm_loss=0.01650   sm_val_loss=0.01780   time=0.60s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 22   loss=0.01526   val_loss=0.01761   sm_loss=0.01546   sm_val_loss=0.01761   time=0.59s
# Epoch    26: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017515106064436077
# Fold 6
# Epoch 1   loss=0.22597   val_loss=0.02554   sm_loss=0.22592   sm_val_loss=0.02553   time=0.60s
# Epoch 2   loss=0.02266   val_loss=0.02103   sm_loss=0.02265   sm_val_loss=0.02102   time=0.59s
# Epoch 3   loss=0.02002   val_loss=0.01932   sm_loss=0.02002   sm_val_loss=0.01933   time=0.72s
# Epoch 4   loss=0.01882   val_loss=0.01860   sm_loss=0.01885   sm_val_loss=0.01865   time=0.59s
# Epoch 5   loss=0.01798   val_loss=0.01855   sm_loss=0.01804   sm_val_loss=0.01858   time=0.59s
# Epoch 6   loss=0.01744   val_loss=0.01813   sm_loss=0.01753   sm_val_loss=0.01817   time=0.59s
# Epoch 8   loss=0.01680   val_loss=0.01809   sm_loss=0.01693   sm_val_loss=0.01813   time=0.60s
# Epoch 10   loss=0.01645   val_loss=0.01803   sm_loss=0.01659   sm_val_loss=0.01809   time=0.58s
# Epoch 14   loss=0.01610   val_loss=0.01787   sm_loss=0.01627   sm_val_loss=0.01790   time=0.67s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 19   loss=0.01517   val_loss=0.01767   sm_loss=0.01537   sm_val_loss=0.01772   time=0.59s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017957703461163647
# Fold 7
# Epoch 1   loss=0.21927   val_loss=0.02559   sm_loss=0.21925   sm_val_loss=0.02558   time=0.59s
# Epoch 2   loss=0.02267   val_loss=0.02104   sm_loss=0.02265   sm_val_loss=0.02103   time=0.59s
# Epoch 3   loss=0.02011   val_loss=0.01922   sm_loss=0.02011   sm_val_loss=0.01924   time=0.61s
# Epoch 5   loss=0.01805   val_loss=0.01829   sm_loss=0.01810   sm_val_loss=0.01834   time=0.59s
# Epoch 6   loss=0.01745   val_loss=0.01817   sm_loss=0.01753   sm_val_loss=0.01824   time=0.63s
# Epoch 7   loss=0.01715   val_loss=0.01812   sm_loss=0.01725   sm_val_loss=0.01819   time=0.61s
# Epoch 8   loss=0.01682   val_loss=0.01811   sm_loss=0.01694   sm_val_loss=0.01818   time=0.72s
# Epoch 9   loss=0.01656   val_loss=0.01810   sm_loss=0.01670   sm_val_loss=0.01814   time=0.60s
# Epoch 13   loss=0.01618   val_loss=0.01811   sm_loss=0.01635   sm_val_loss=0.01813   time=0.58s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18   loss=0.01504   val_loss=0.01774   sm_loss=0.01523   sm_val_loss=0.01782   time=0.88s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017997877526581916
# Seed 0
# Fold 1 log loss: 0.01750090520611265
# Fold 2 log loss: 0.01795262789927255
# Fold 3 log loss: 0.017826648156047054
# Fold 4 log loss: 0.017756614462591264
# Fold 5 log loss: 0.017515106064436077
# Fold 6 log loss: 0.017957703461163647
# Fold 7 log loss: 0.017997877526581916
# Std of log loss: 0.00019247006278634246
# Total log loss: 0.01778615736226908
# Fold 1
# Epoch 1   loss=0.22155   val_loss=0.02504   sm_loss=0.22153   sm_val_loss=0.02503   time=0.59s
# Epoch 2   loss=0.02281   val_loss=0.02076   sm_loss=0.02279   sm_val_loss=0.02076   time=0.58s
# Epoch 3   loss=0.02013   val_loss=0.01918   sm_loss=0.02013   sm_val_loss=0.01918   time=0.62s
# Epoch 4   loss=0.01897   val_loss=0.01880   sm_loss=0.01899   sm_val_loss=0.01882   time=0.59s
# Epoch 5   loss=0.01821   val_loss=0.01805   sm_loss=0.01826   sm_val_loss=0.01809   time=0.60s
# Epoch 6   loss=0.01745   val_loss=0.01787   sm_loss=0.01755   sm_val_loss=0.01792   time=0.58s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 11   loss=0.01538   val_loss=0.01742   sm_loss=0.01556   sm_val_loss=0.01746   time=0.58s
# Epoch    15: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017625585727276412
# Fold 2
# Epoch 1   loss=0.22133   val_loss=0.02566   sm_loss=0.22131   sm_val_loss=0.02565   time=0.58s
# Epoch 2   loss=0.02283   val_loss=0.02136   sm_loss=0.02282   sm_val_loss=0.02136   time=0.67s
# Epoch 3   loss=0.02025   val_loss=0.01985   sm_loss=0.02025   sm_val_loss=0.01986   time=0.71s
# Epoch 4   loss=0.01902   val_loss=0.01892   sm_loss=0.01903   sm_val_loss=0.01896   time=0.61s
# Epoch 5   loss=0.01803   val_loss=0.01844   sm_loss=0.01809   sm_val_loss=0.01849   time=0.58s
# Epoch 6   loss=0.01742   val_loss=0.01839   sm_loss=0.01751   sm_val_loss=0.01846   time=0.58s
# Epoch 7   loss=0.01708   val_loss=0.01835   sm_loss=0.01719   sm_val_loss=0.01840   time=0.60s
# Epoch 10   loss=0.01649   val_loss=0.01827   sm_loss=0.01665   sm_val_loss=0.01831   time=0.58s
# Epoch 13   loss=0.01622   val_loss=0.01825   sm_loss=0.01639   sm_val_loss=0.01829   time=0.58s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18   loss=0.01514   val_loss=0.01793   sm_loss=0.01533   sm_val_loss=0.01798   time=0.61s
# Epoch 19   loss=0.01453   val_loss=0.01792   sm_loss=0.01474   sm_val_loss=0.01798   time=0.59s
# Epoch    23: reducing learning rate of group 0 to 5.0000e-05.
# Fold 2 log loss: 0.01802359327998507
# Fold 3
# Epoch 1   loss=0.21845   val_loss=0.02544   sm_loss=0.21843   sm_val_loss=0.02544   time=0.77s
# Epoch 2   loss=0.02281   val_loss=0.02066   sm_loss=0.02279   sm_val_loss=0.02066   time=0.62s
# Epoch 3   loss=0.02026   val_loss=0.01935   sm_loss=0.02025   sm_val_loss=0.01938   time=0.73s
# Epoch 4   loss=0.01891   val_loss=0.01850   sm_loss=0.01895   sm_val_loss=0.01853   time=0.60s
# Epoch 5   loss=0.01796   val_loss=0.01815   sm_loss=0.01802   sm_val_loss=0.01820   time=0.74s
# Epoch 7   loss=0.01709   val_loss=0.01804   sm_loss=0.01720   sm_val_loss=0.01812   time=0.59s
# Epoch 8   loss=0.01681   val_loss=0.01799   sm_loss=0.01694   sm_val_loss=0.01803   time=0.58s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13   loss=0.01515   val_loss=0.01773   sm_loss=0.01534   sm_val_loss=0.01778   time=0.59s
# Epoch 14   loss=0.01452   val_loss=0.01772   sm_loss=0.01472   sm_val_loss=0.01777   time=0.58s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.017849768961324827
# Fold 4
# Epoch 1   loss=0.21954   val_loss=0.02585   sm_loss=0.21951   sm_val_loss=0.02583   time=0.58s
# Epoch 2   loss=0.02281   val_loss=0.02106   sm_loss=0.02279   sm_val_loss=0.02105   time=0.59s
# Epoch 3   loss=0.02011   val_loss=0.01968   sm_loss=0.02012   sm_val_loss=0.01968   time=0.60s
# Epoch 4   loss=0.01894   val_loss=0.01885   sm_loss=0.01897   sm_val_loss=0.01888   time=0.60s
# Epoch 5   loss=0.01808   val_loss=0.01843   sm_loss=0.01814   sm_val_loss=0.01846   time=0.58s
# Epoch 6   loss=0.01739   val_loss=0.01821   sm_loss=0.01748   sm_val_loss=0.01827   time=0.59s
# Epoch 8   loss=0.01685   val_loss=0.01821   sm_loss=0.01697   sm_val_loss=0.01826   time=0.86s
# Epoch 9   loss=0.01665   val_loss=0.01817   sm_loss=0.01679   sm_val_loss=0.01823   time=0.59s
# Epoch 11   loss=0.01639   val_loss=0.01808   sm_loss=0.01655   sm_val_loss=0.01815   time=0.58s
# Epoch 13   loss=0.01621   val_loss=0.01809   sm_loss=0.01637   sm_val_loss=0.01813   time=0.61s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18   loss=0.01506   val_loss=0.01774   sm_loss=0.01527   sm_val_loss=0.01779   time=0.63s
# Epoch 19   loss=0.01441   val_loss=0.01774   sm_loss=0.01462   sm_val_loss=0.01779   time=0.58s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017769970265191556
# Fold 5
# Epoch 1   loss=0.21938   val_loss=0.02710   sm_loss=0.21935   sm_val_loss=0.02704   time=0.58s
# Epoch 2   loss=0.02284   val_loss=0.02105   sm_loss=0.02284   sm_val_loss=0.02103   time=0.58s
# Epoch 3   loss=0.02017   val_loss=0.01989   sm_loss=0.02017   sm_val_loss=0.01978   time=0.63s
# Epoch 4   loss=0.01892   val_loss=0.01873   sm_loss=0.01896   sm_val_loss=0.01872   time=0.60s
# Epoch 5   loss=0.01815   val_loss=0.01808   sm_loss=0.01821   sm_val_loss=0.01810   time=0.58s
# Epoch 6   loss=0.01750   val_loss=0.01796   sm_loss=0.01758   sm_val_loss=0.01796   time=0.58s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 11   loss=0.01542   val_loss=0.01761   sm_loss=0.01559   sm_val_loss=0.01764   time=0.79s
# Epoch 12   loss=0.01484   val_loss=0.01760   sm_loss=0.01502   sm_val_loss=0.01762   time=0.71s
# Epoch 13   loss=0.01444   val_loss=0.01761   sm_loss=0.01463   sm_val_loss=0.01762   time=0.61s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.01752755383611045
# Fold 6
# Epoch 1   loss=0.21981   val_loss=0.02555   sm_loss=0.21979   sm_val_loss=0.02555   time=0.61s
# Epoch 2   loss=0.02285   val_loss=0.02083   sm_loss=0.02283   sm_val_loss=0.02083   time=0.60s
# Epoch 3   loss=0.02020   val_loss=0.01943   sm_loss=0.02019   sm_val_loss=0.01944   time=0.65s
# Epoch 4   loss=0.01884   val_loss=0.01849   sm_loss=0.01888   sm_val_loss=0.01852   time=0.81s
# Epoch 5   loss=0.01799   val_loss=0.01839   sm_loss=0.01805   sm_val_loss=0.01845   time=0.71s
# Epoch 6   loss=0.01743   val_loss=0.01803   sm_loss=0.01751   sm_val_loss=0.01807   time=0.64s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 11   loss=0.01543   val_loss=0.01770   sm_loss=0.01561   sm_val_loss=0.01774   time=0.59s
# Epoch 12   loss=0.01488   val_loss=0.01768   sm_loss=0.01507   sm_val_loss=0.01773   time=0.61s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.01799076607864071
# Fold 7
# Epoch 1   loss=0.22260   val_loss=0.02541   sm_loss=0.22258   sm_val_loss=0.02541   time=0.58s
# Epoch 2   loss=0.02288   val_loss=0.02103   sm_loss=0.02287   sm_val_loss=0.02102   time=0.58s
# Epoch 3   loss=0.02015   val_loss=0.01938   sm_loss=0.02014   sm_val_loss=0.01940   time=0.72s
# Epoch 4   loss=0.01883   val_loss=0.01865   sm_loss=0.01886   sm_val_loss=0.01866   time=0.58s
# Epoch 5   loss=0.01803   val_loss=0.01823   sm_loss=0.01809   sm_val_loss=0.01828   time=0.58s
# Epoch 7   loss=0.01711   val_loss=0.01808   sm_loss=0.01721   sm_val_loss=0.01815   time=0.61s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12   loss=0.01531   val_loss=0.01776   sm_loss=0.01548   sm_val_loss=0.01781   time=0.59s
# Epoch 13   loss=0.01467   val_loss=0.01774   sm_loss=0.01486   sm_val_loss=0.01778   time=0.58s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.017937054767824652
# Seed 1
# Fold 1 log loss: 0.017625585727276412
# Fold 2 log loss: 0.01802359327998507
# Fold 3 log loss: 0.017849768961324827
# Fold 4 log loss: 0.017769970265191556
# Fold 5 log loss: 0.01752755383611045
# Fold 6 log loss: 0.01799076607864071
# Fold 7 log loss: 0.017937054767824652
# Std of log loss: 0.0001736123287821301
# Total log loss: 0.017817359027813156
# Fold 1
# Epoch 1   loss=0.22237   val_loss=0.02524   sm_loss=0.22234   sm_val_loss=0.02524   time=0.58s
# Epoch 2   loss=0.02285   val_loss=0.02095   sm_loss=0.02285   sm_val_loss=0.02095   time=0.58s
# Epoch 3   loss=0.02019   val_loss=0.01954   sm_loss=0.02020   sm_val_loss=0.01956   time=0.59s
# Epoch 4   loss=0.01894   val_loss=0.01849   sm_loss=0.01897   sm_val_loss=0.01852   time=0.58s
# Epoch 5   loss=0.01814   val_loss=0.01831   sm_loss=0.01820   sm_val_loss=0.01835   time=0.59s
# Epoch 6   loss=0.01758   val_loss=0.01796   sm_loss=0.01767   sm_val_loss=0.01801   time=0.59s
# Epoch 7   loss=0.01728   val_loss=0.01777   sm_loss=0.01739   sm_val_loss=0.01784   time=0.72s
# Epoch    11: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 12   loss=0.01533   val_loss=0.01732   sm_loss=0.01552   sm_val_loss=0.01737   time=0.58s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-05.
# Fold 1 log loss: 0.017539805221032337
# Fold 2
# Epoch 1   loss=0.21904   val_loss=0.02572   sm_loss=0.21903   sm_val_loss=0.02571   time=0.61s
# Epoch 2   loss=0.02274   val_loss=0.02131   sm_loss=0.02273   sm_val_loss=0.02130   time=0.59s
# Epoch 3   loss=0.02021   val_loss=0.01948   sm_loss=0.02021   sm_val_loss=0.01951   time=0.82s
# Epoch 4   loss=0.01887   val_loss=0.01883   sm_loss=0.01890   sm_val_loss=0.01888   time=0.60s
# Epoch 5   loss=0.01808   val_loss=0.01856   sm_loss=0.01813   sm_val_loss=0.01861   time=0.81s
# Epoch 6   loss=0.01746   val_loss=0.01855   sm_loss=0.01755   sm_val_loss=0.01860   time=0.65s
# Epoch 7   loss=0.01722   val_loss=0.01853   sm_loss=0.01733   sm_val_loss=0.01857   time=0.59s
# Epoch 8   loss=0.01699   val_loss=0.01839   sm_loss=0.01711   sm_val_loss=0.01842   time=0.58s
# Epoch 11   loss=0.01640   val_loss=0.01835   sm_loss=0.01656   sm_val_loss=0.01836   time=0.92s
# Epoch 15   loss=0.01623   val_loss=0.01834   sm_loss=0.01640   sm_val_loss=0.01836   time=0.61s
# Epoch 17   loss=0.01612   val_loss=0.01832   sm_loss=0.01629   sm_val_loss=0.01832   time=0.59s
# Epoch 21   loss=0.01622   val_loss=0.01827   sm_loss=0.01639   sm_val_loss=0.01832   time=0.61s
# Epoch    25: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 26   loss=0.01525   val_loss=0.01791   sm_loss=0.01544   sm_val_loss=0.01795   time=0.58s
# Epoch 27   loss=0.01467   val_loss=0.01790   sm_loss=0.01488   sm_val_loss=0.01794   time=0.58s
# Fold 2 log loss: 0.017968962404543265
# Fold 3
# Epoch 1   loss=0.22008   val_loss=0.02611   sm_loss=0.22003   sm_val_loss=0.02610   time=0.59s
# Epoch 2   loss=0.02289   val_loss=0.02072   sm_loss=0.02285   sm_val_loss=0.02072   time=0.59s
# Epoch 3   loss=0.02008   val_loss=0.01925   sm_loss=0.02007   sm_val_loss=0.01927   time=0.61s
# Epoch 4   loss=0.01889   val_loss=0.01844   sm_loss=0.01892   sm_val_loss=0.01848   time=0.71s
# Epoch 6   loss=0.01748   val_loss=0.01812   sm_loss=0.01756   sm_val_loss=0.01817   time=0.57s
# Epoch 10   loss=0.01653   val_loss=0.01809   sm_loss=0.01669   sm_val_loss=0.01811   time=0.58s
# Epoch    14: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 15   loss=0.01525   val_loss=0.01772   sm_loss=0.01544   sm_val_loss=0.01774   time=0.59s
# Epoch    19: reducing learning rate of group 0 to 5.0000e-05.
# Fold 3 log loss: 0.01779982603275965
# Fold 4
# Epoch 1   loss=0.21963   val_loss=0.02575   sm_loss=0.21961   sm_val_loss=0.02575   time=0.59s
# Epoch 2   loss=0.02275   val_loss=0.02112   sm_loss=0.02274   sm_val_loss=0.02110   time=0.60s
# Epoch 3   loss=0.02020   val_loss=0.01951   sm_loss=0.02019   sm_val_loss=0.01952   time=0.72s
# Epoch 4   loss=0.01889   val_loss=0.01881   sm_loss=0.01892   sm_val_loss=0.01884   time=0.60s
# Epoch 5   loss=0.01808   val_loss=0.01853   sm_loss=0.01814   sm_val_loss=0.01857   time=0.58s
# Epoch 6   loss=0.01769   val_loss=0.01837   sm_loss=0.01777   sm_val_loss=0.01843   time=0.58s
# Epoch 7   loss=0.01721   val_loss=0.01836   sm_loss=0.01732   sm_val_loss=0.01839   time=0.72s
# Epoch 8   loss=0.01688   val_loss=0.01831   sm_loss=0.01701   sm_val_loss=0.01837   time=0.71s
# Epoch 9   loss=0.01669   val_loss=0.01832   sm_loss=0.01683   sm_val_loss=0.01837   time=0.60s
# Epoch 12   loss=0.01629   val_loss=0.01795   sm_loss=0.01645   sm_val_loss=0.01799   time=0.58s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 17   loss=0.01512   val_loss=0.01772   sm_loss=0.01532   sm_val_loss=0.01775   time=0.65s
# Epoch    21: reducing learning rate of group 0 to 5.0000e-05.
# Fold 4 log loss: 0.017771175706042055
# Fold 5
# Epoch 1   loss=0.21801   val_loss=0.02594   sm_loss=0.21799   sm_val_loss=0.02593   time=0.58s
# Epoch 2   loss=0.02296   val_loss=0.02143   sm_loss=0.02295   sm_val_loss=0.02141   time=0.59s
# Epoch 3   loss=0.02022   val_loss=0.01945   sm_loss=0.02022   sm_val_loss=0.01942   time=0.59s
# Epoch 4   loss=0.01891   val_loss=0.01873   sm_loss=0.01895   sm_val_loss=0.01871   time=0.59s
# Epoch 5   loss=0.01816   val_loss=0.01852   sm_loss=0.01822   sm_val_loss=0.01841   time=0.61s
# Epoch 6   loss=0.01759   val_loss=0.01818   sm_loss=0.01768   sm_val_loss=0.01816   time=0.58s
# Epoch 7   loss=0.01714   val_loss=0.01819   sm_loss=0.01725   sm_val_loss=0.01814   time=0.73s
# Epoch 8   loss=0.01690   val_loss=0.01806   sm_loss=0.01703   sm_val_loss=0.01804   time=0.80s
# Epoch    12: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 13   loss=0.01523   val_loss=0.01766   sm_loss=0.01542   sm_val_loss=0.01765   time=0.59s
# Epoch 14   loss=0.01463   val_loss=0.01762   sm_loss=0.01483   sm_val_loss=0.01761   time=0.60s
# Epoch    18: reducing learning rate of group 0 to 5.0000e-05.
# Fold 5 log loss: 0.017518291098239762
# Fold 6
# Epoch 1   loss=0.22156   val_loss=0.02610   sm_loss=0.22150   sm_val_loss=0.02609   time=0.58s
# Epoch 2   loss=0.02284   val_loss=0.02095   sm_loss=0.02283   sm_val_loss=0.02094   time=0.58s
# Epoch 3   loss=0.02004   val_loss=0.01942   sm_loss=0.02005   sm_val_loss=0.01944   time=0.58s
# Epoch 4   loss=0.01896   val_loss=0.01870   sm_loss=0.01897   sm_val_loss=0.01875   time=0.59s
# Epoch 5   loss=0.01802   val_loss=0.01837   sm_loss=0.01807   sm_val_loss=0.01840   time=0.59s
# Epoch 6   loss=0.01745   val_loss=0.01832   sm_loss=0.01754   sm_val_loss=0.01836   time=0.59s
# Epoch 7   loss=0.01712   val_loss=0.01822   sm_loss=0.01722   sm_val_loss=0.01824   time=0.63s
# Epoch 8   loss=0.01685   val_loss=0.01822   sm_loss=0.01697   sm_val_loss=0.01824   time=0.60s
# Epoch 9   loss=0.01661   val_loss=0.01809   sm_loss=0.01675   sm_val_loss=0.01812   time=0.61s
# Epoch 13   loss=0.01618   val_loss=0.01807   sm_loss=0.01635   sm_val_loss=0.01809   time=0.66s
# Epoch    17: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 18   loss=0.01508   val_loss=0.01769   sm_loss=0.01528   sm_val_loss=0.01774   time=0.59s
# Epoch    22: reducing learning rate of group 0 to 5.0000e-05.
# Fold 6 log loss: 0.017972179391047487
# Fold 7
# Epoch 1   loss=0.22097   val_loss=0.02592   sm_loss=0.22095   sm_val_loss=0.02591   time=0.58s
# Epoch 2   loss=0.02285   val_loss=0.02142   sm_loss=0.02283   sm_val_loss=0.02141   time=0.58s
# Epoch 3   loss=0.02021   val_loss=0.01972   sm_loss=0.02020   sm_val_loss=0.01971   time=0.60s
# Epoch 4   loss=0.01891   val_loss=0.01855   sm_loss=0.01891   sm_val_loss=0.01858   time=0.59s
# Epoch 5   loss=0.01802   val_loss=0.01847   sm_loss=0.01808   sm_val_loss=0.01852   time=0.59s
# Epoch 6   loss=0.01750   val_loss=0.01812   sm_loss=0.01758   sm_val_loss=0.01819   time=0.58s
# Epoch    10: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 11   loss=0.01546   val_loss=0.01780   sm_loss=0.01563   sm_val_loss=0.01786   time=0.59s
# Epoch 12   loss=0.01489   val_loss=0.01777   sm_loss=0.01507   sm_val_loss=0.01784   time=0.59s
# Epoch    16: reducing learning rate of group 0 to 5.0000e-05.
# Fold 7 log loss: 0.018024849973196526
# Seed 2
# Fold 1 log loss: 0.017539805221032337
# Fold 2 log loss: 0.017968962404543265
# Fold 3 log loss: 0.01779982603275965
# Fold 4 log loss: 0.017771175706042055
# Fold 5 log loss: 0.017518291098239762
# Fold 6 log loss: 0.017972179391047487
# Fold 7 log loss: 0.018024849973196526
# Std of log loss: 0.00019147554918862172
# Total log loss: 0.01779873842208636
# Total log loss in targets: 0.017612981746771558

# %%
t = pd.read_csv(DATA_DIR + 'train_targets_scored.csv')
train_checkscore = t.copy()
train_checkscore.loc[train_checkscore.index.isin(cons_train_index),target_feats] = target_oof
train_checkscore.loc[train_checkscore.index.isin(noncons_train_index),target_feats] = 0
t.drop("sig_id", axis=1, inplace=True)
print('OOF log loss: ', log_loss(np.ravel(t), np.ravel(np.array(train_checkscore.iloc[:,1:]))))
# Out:
# OOF log loss:  0.01623287660108104

# %%
train_checkscore.to_csv("dae_oof.csv")

# %%
sub.loc[cons_test_index, target_feats] = target_pred
sub.loc[noncons_test_index,target_feats] = 0
sub.to_csv('submission.csv', index=False)
